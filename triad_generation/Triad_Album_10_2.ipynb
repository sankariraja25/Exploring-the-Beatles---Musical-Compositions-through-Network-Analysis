# %%
#9, 10, 11
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
#motifs, chord pregressoionn and trials

# %%
pwd
# Out:
# '/content'

# %%
album01 = pd.read_csv('/content/album_10_2_edges.csv')
G = nx.from_pandas_edgelist(album01, source="Source", target="Target", create_using=nx.DiGraph())
nx.draw(G, with_labels=True)

# %% [markdown]
# ## Visuals

# %%
nx.draw(G,node_size=300,font_size=8,  with_labels=True)

# %%
plt.figure(3,figsize=(12,12)) 
nx.draw(G, node_size=400,font_size=12,  with_labels=True)

# %% [markdown]
# ## Triads

# %%
# Triad Consensus
nx.triadic_census(G)
# Out:
# {'003': 108017,
#  '012': 12194,
#  '021C': 585,
#  '021D': 228,
#  '021U': 291,
#  '030C': 18,
#  '030T': 30,
#  '102': 3152,
#  '111D': 417,
#  '111U': 375,
#  '120C': 63,
#  '120D': 18,
#  '120U': 12,
#  '201': 121,
#  '210': 46,
#  '300': 13}

# %%
import networkx as nx
import itertools


def _tricode(G, v, u, w):
    """Returns the integer code of the given triad.

    This is some fancy magic that comes from Batagelj and Mrvar's paper. It
    treats each edge joining a pair of `v`, `u`, and `w` as a bit in
    the binary representation of an integer.

    """
    combos = ((v, u, 1), (u, v, 2), (v, w, 4), (w, v, 8), (u, w, 16),
              (w, u, 32))
    return sum(x for u, v, x in combos if v in G[u])


# G = nx.DiGraph()
# G.add_nodes_from([1, 2, 3, 4, 5])
# G.add_edges_from([(1, 2), (2, 3), (2, 4), (4, 5)])

#: The integer codes representing each type of triad.
#: Triads that are the same up to symmetry have the same code.
TRICODES = (1, 2, 2, 3, 2, 4, 6, 8, 2, 6, 5, 7, 3, 8, 7, 11, 2, 6, 4, 8, 5, 9,
            9, 13, 6, 10, 9, 14, 7, 14, 12, 15, 2, 5, 6, 7, 6, 9, 10, 14, 4, 9,
            9, 12, 8, 13, 14, 15, 3, 7, 8, 11, 7, 12, 14, 15, 8, 14, 13, 15,
            11, 15, 15, 16)

#: The names of each type of triad. The order of the elements is
#: important: it corresponds to the tricodes given in :data:`TRICODES`.
TRIAD_NAMES = ('003', '012', '102', '021D', '021U', '021C', '111D', '111U',
               '030T', '030C', '201', '120D', '120U', '120C', '210', '300')

#: A dictionary mapping triad code to triad name.
TRICODE_TO_NAME = {i: TRIAD_NAMES[code - 1] for i, code in enumerate(TRICODES)}

triad_nodes = {name: set([]) for name in TRIAD_NAMES}
m = {v: i for i, v in enumerate(G)}
for v in G:
    vnbrs = set(G.pred[v]) | set(G.succ[v])
    for u in vnbrs:
        if m[u] > m[v]:
            unbrs = set(G.pred[u]) | set(G.succ[u])
            neighbors = (vnbrs | unbrs) - {u, v}
            not_neighbors = set(G.nodes()) - neighbors - {u, v}
            # Find dyadic triads
            for w in not_neighbors:
                if v in G[u] and u in G[v]:
                    triad_nodes['102'].add(tuple(sorted([u, v, w])))
                else:
                    triad_nodes['012'].add(tuple(sorted([u, v, w])))
            for w in neighbors:
                if m[u] < m[w] or (m[v] < m[w] < m[u] and
                                   v not in G.pred[w] and
                                   v not in G.succ[w]):
                    code = _tricode(G, v, u, w)
                    triad_nodes[TRICODE_TO_NAME[code]].add(
                        tuple(sorted([u, v, w])))
# find null triads
all_tuples = set()
for s in triad_nodes.values():
    all_tuples = all_tuples.union(s)
new = triad_nodes['003'] = set(itertools.combinations(G.nodes(), 3)).difference(all_tuples)

triad_nodes
# Out:
# {'003': {('G:min/5', 'C:min', 'Eb'),
#   ('A', 'C/5', 'C#:(1,b3)/b3'),
#   ('D:maj(9)', 'B:min7', 'D:(1,5)'),
#   ('E:min', 'B:maj7', 'C:maj(#4)/5'),
#   ('B:min', 'G:min/5', 'E:(1)'),
#   ('B:min', 'E:(1,b7)/b7', 'C#:min'),
#   ('E:7', 'A:7/3', 'F#:min/5'),
#   ('D:maj6', 'G/3', 'E:min/3'),
#   ('E', 'F/5', 'E:sus4(2)'),
#   ('G/5', 'C:7', 'C#:hdim7'),
#   ('G:7/b2', 'D:sus4', 'D:sus4(2)'),
#   ('G:(1,b3,4)/b3', 'E:sus2(b7)', 'D/3'),
#   ('N', 'D:7', 'Eb'),
#   ('E', 'E:(1,5)', 'F/5'),
#   ('G:7/b3', 'Bb', 'C:(1,5)'),
#   ('Eb', 'E:min/5', 'E:sus4(2)'),
#   ('E:7', 'A/3', 'A:maj(*5)'),
#   ('G:7/2', 'D:maj6', 'A:min/4'),
#   ('G:7/b3', 'B', 'C#:dim/b3'),
#   ('B', 'E:9', 'G:min(4)'),
#   ('G:7', 'D:maj6', 'E:(1)'),
#   ('B', 'D/2', 'E:sus4(2)'),
#   ('D/5', 'B:min7', 'C:maj7'),
#   ('B:7', 'C:sus4', 'E:maj6'),
#   ('F#', 'A:min', 'B:maj7'),
#   ('C/3', 'G:(1,b3,4)/b3', 'Bb'),
#   ('Ab', 'Bb', 'E:min6'),
#   ('G:(1)', 'A:(1)', 'G:maj7'),
#   ('G:min', 'A:9', 'F#:dim/b3'),
#   ('A:min', 'E:maj6', 'B:maj7'),
#   ('G:7/b3', 'F/6', 'E:sus4(2)'),
#   ('E:(1,b7)/b7', 'C#', 'D:min'),
#   ('G:maj6', 'B:min7', 'Bb'),
#   ('C:min', 'F#/5', 'C#:hdim7'),
#   ('D:sus4', 'F/5', 'Ab:min'),
#   ('D:maj7', 'Eb', 'D/2'),
#   ('B', 'F/6', 'E:maj6'),
#   ('Bb', 'G/3', 'B:dim'),
#   ('D', 'Ab', 'C#:dim/b3'),
#   ('D:7', 'D/5', 'G/5'),
#   ('G:7/2', 'Eb', 'E:min6'),
#   ('G#:hdim7', 'C:7', 'C#'),
#   ('G:7', 'E:min', 'E:sus4(2)'),
#   ('G#:hdim7', 'G:(1,b3,4)/b3', 'B:dim'),
#   ('G:7/2', 'G:(1)', 'Eb'),
#   ('E/5', 'G/5', 'F/5'),
#   ('E/5', 'A', 'C#:hdim7'),
#   ('D:maj6', 'D/2', 'D:(1)'),
#   ('A:maj(*5)', 'D:min', 'A:(1)'),
#   ('A', 'F:min', 'G:maj7'),
#   ('E', 'D:maj7', 'E:maj6'),
#   ('C/5', 'B', 'C:(1)'),
#   ('A/3', 'E:min6', 'A:min7'),
#   ('D:7', 'A:min/4', 'F#:dim/b3'),
#   ('G:7', 'E:min/5', 'F#:dim/b3'),
#   ('F', 'Ab', 'C#:(1,b3)'),
#   ('G:min/5', 'G:min', 'F#:min'),
#   ('G:(1)', 'B:min', 'Eb'),
#   ('G:7/b3', 'B:7', 'A:min'),
#   ('G:maj6', 'Ab', 'A:9'),
#   ('C/5', 'F/6', 'Eb:aug'),
#   ('F#', 'C:(1)', 'C:(1,5)'),
#   ('G:7/b3', 'G:min', 'E:min6'),
#   ('D:7', 'C#:(1,b3)', 'A:(1)'),
#   ('G:7', 'E:9', 'F:min'),
#   ('B:min7', 'E:sus4(2)', 'E:min/3'),
#   ('C:9(*3)', 'E:sus2(b7)', 'E:maj6'),
#   ('E/5', 'F', 'F#:min'),
#   ('G:7/2', 'D:sus4(2)', 'A/3'),
#   ('D:maj7', 'F#/5', 'D:min'),
#   ('C', 'B', 'E:min/3'),
#   ('C:(1,5)', 'E:min/5', 'F#:dim/b3'),
#   ('C:9(*3)', 'F#:dim/b3', 'D:(1,5)'),
#   ('F', 'E:min/3', 'C:maj(#4)/5'),
#   ('D:maj(9)', 'C/3', 'F:min'),
#   ('E:7', 'G:(1)', 'E:9'),
#   ('B:7', 'B:min', 'E:9'),
#   ('E:9', 'D:min', 'C:maj(#4)/5'),
#   ('D:7', 'C:(1)', 'C:min'),
#   ('D:7', 'G:7', 'Bb'),
#   ('D', 'E:(1)', 'C#'),
#   ('G/5', 'E:(1)', 'E:(1,b7)/b7'),
#   ('F/6', 'A/3', 'F#:min'),
#   ('G:7', 'E:min', 'D:(1,5)'),
#   ('E', 'G:7/b2', 'B:maj7'),
#   ('N', 'D:maj(9)', 'Eb:aug'),
#   ('C:(1)', 'A:min/4', 'C#:dim/b3'),
#   ('D:maj6', 'E:maj6', 'D/2'),
#   ('N', 'G:min/5', 'D/3'),
#   ('D:maj7', 'B:min7', 'A:min7'),
#   ('E:7', 'G:7/b2', 'D:sus4(2)'),
#   ('G:7/2', 'D:maj(9)', 'E:(1,b7)/b7'),
#   ('G:min', 'Bb', 'F/5'),
#   ('C:9(*3)', 'A:9', 'D:min'),
#   ('G:7', 'E:(1)', 'E:min/5'),
#   ('C#:dim/b3', 'C#', 'G:maj7'),
#   ('E:7', 'C', 'C:(1)'),
#   ('A:7', 'D:sus4(2)', 'B:maj7'),
#   ('G:(1)', 'F', 'C#'),
#   ('D', 'G:min', 'C#:dim/b3'),
#   ('A:7', 'C#:(1,b3)', 'G:(1,b3,4)/b3'),
#   ('G:7', 'D:sus4', 'D:(1,5)'),
#   ('Ab', 'A:7/3', 'E:min6'),
#   ('G:min/5', 'E:min/3', 'F#:min'),
#   ('D:maj7', 'C:sus4', 'G/3'),
#   ('D:7', 'B:7', 'F#'),
#   ('G:7/b3', 'A:sus4(2)', 'B:maj7'),
#   ('D:maj(9)', 'C#:hdim7', 'C:maj(#4)/5'),
#   ('B', 'G/5', 'E:min'),
#   ('D:maj7', 'Ab', 'C:maj7'),
#   ('D:maj6', 'C#:(1,b3)', 'D/3'),
#   ('C#:(1,b3)', 'E:min/5', 'D:min'),
#   ('Bb', 'D:min', 'A:(1)'),
#   ('B:dim', 'D/3', 'C:maj7'),
#   ('G:min/5', 'C:7', 'D/3'),
#   ('F#', 'C:7', 'E:min'),
#   ('C:(1)', 'E:maj6', 'D:min'),
#   ('N', 'E:maj6', 'E:sus4(2)'),
#   ('A:7', 'C#:(1,b3)/b3', 'G/3'),
#   ('A:maj(*5)', 'E:(1,5)', 'D:(1)'),
#   ('A', 'G', 'C#'),
#   ('G:(1)', 'A:min/4', 'F:min'),
#   ('C', 'E:min/5', 'E:min6'),
#   ('G:7', 'D', 'F#:dim/b3'),
#   ('D:min', 'B:maj7', 'C:maj(#4)/5'),
#   ('G:7/b2', 'E:(1)', 'A:sus4(2)'),
#   ('F/6', 'G:min', 'A:7/3'),
#   ('D:7', 'G:7/b3', 'C:maj7'),
#   ('B:7', 'C:(1,5)', 'F#:min/5'),
#   ('A:7', 'G', 'C#:dim/b3'),
#   ('G:(1,b3,4)/b3', 'E:min/5', 'F#:dim/b3'),
#   ('C:min', 'D/3', 'C#:min'),
#   ('C/3', 'B:dim', 'D/2'),
#   ('N', 'B:7', 'G#:hdim7'),
#   ('G:7', 'F#', 'C#:(1,b3)'),
#   ('G:7/b3', 'D:sus4(2)', 'G:min(4)'),
#   ('E:9', 'D:sus4', 'E:min/3'),
#   ('A/3', 'C:(1,5)', 'E:min6'),
#   ('E', 'F/6', 'E:min'),
#   ('B:min', 'A:7/3', 'A:(1)'),
#   ('C', 'E:9', 'E:(1,5)'),
#   ('D/5', 'G:min(4)', 'C:maj(#4)/5'),
#   ('G/5', 'A/3', 'E:(1)'),
#   ('C:9(*3)', 'C:maj7', 'A:sus4(2)'),
#   ('C:7', 'E:sus2(b7)', 'C#:min'),
#   ('G:7/b2', 'B:min7', 'Ab:min'),
#   ('A:min', 'Eb', 'A:sus4(2)'),
#   ('D/5', 'A/3', 'G:min'),
#   ('G/3', 'C#:dim/b3', 'B:maj7'),
#   ('F#/5', 'C#:min', 'F#:min/5'),
#   ('G:(1)', 'C:sus4', 'C#:dim/b3'),
#   ('B', 'G#:hdim7', 'Eb:aug'),
#   ('E:9', 'F', 'C:min'),
#   ('G:min/5', 'C:(1)', 'B:maj7'),
#   ('D/2', 'G:maj7', 'C:maj(#4)/5'),
#   ('N', 'C:(1)', 'C#:min'),
#   ('D:7', 'G:min(4)', 'C:sus4'),
#   ('D', 'Ab:min', 'F#:min'),
#   ('D:maj(9)', 'C:min', 'D/3'),
#   ('F', 'F/5', 'Eb:aug'),
#   ('D:7', 'C', 'E:(1,b7)/b7'),
#   ('G:7/b2', 'E:(1)', 'Bb'),
#   ('C', 'C#:(1,b3)', 'B:maj7'),
#   ('A/3', 'B:dim', 'D/2'),
#   ('G:(1,b3,4)/b3', 'C#', 'Ab:min'),
#   ('C#:(1,b3)', 'C:sus4', 'A:min/4'),
#   ('D:7', 'G:7', 'B:min'),
#   ('G/5', 'C#', 'C#:min'),
#   ('G:min(4)', 'Eb:aug', 'G:maj7'),
#   ('F/6', 'C#:(1,b3)', 'C#:dim/b3'),
#   ('D:maj(9)', 'D:(1)', 'C:maj(#4)/5'),
#   ('F/6', 'A:maj(*5)', 'E:sus2(b7)'),
#   ('G:7/2', 'E:maj6', 'F:min'),
#   ('B:7', 'E:maj6', 'E:min6'),
#   ('G:min(4)', 'C:sus4', 'C#'),
#   ('G/5', 'G:(1,b3,4)/b3', 'Eb'),
#   ('B', 'G:maj6', 'F:min'),
#   ('E:(1,5)', 'C:(1)', 'B:maj7'),
#   ('N', 'C:sus4', 'C#:dim/b3'),
#   ('C:sus4', 'B:dim', 'Ab:min'),
#   ('C', 'D/5', 'Ab:min'),
#   ('D/5', 'E:9', 'Ab'),
#   ('E:9', 'E:(1,b7)/b7', 'Eb'),
#   ('G/5', 'C:7', 'C:min'),
#   ('G:7/b2', 'G:min/5', 'C#'),
#   ('D:sus4', 'C#:(1,b3)', 'Eb:aug'),
#   ('C:(1,5)', 'E:min/5', 'C#:min'),
#   ('C/3', 'G:(1,b3,4)/b3', 'G/3'),
#   ('G:(1,b3,4)/b3', 'C:9(*3)', 'E:min/5'),
#   ('E', 'E:sus2(b7)', 'B:dim'),
#   ('E/3', 'D:maj7', 'Eb:aug'),
#   ('D:maj7', 'D/3', 'A:(1)'),
#   ('B:min', 'G:min(4)', 'C:sus4'),
#   ('E/3', 'F#:dim/b3', 'C#:hdim7'),
#   ('E/3', 'G:min', 'F#:min'),
#   ('E/5', 'D', 'Eb'),
#   ('G#:hdim7', 'D:sus4', 'G:min/5'),
#   ('E:9', 'G/5', 'Ab'),
#   ('G:(1)', 'C#:min', 'G:maj7'),
#   ('E', 'G:(1,b3,4)/b3', 'C:(1)'),
#   ('G:7/b3', 'E:sus2(b7)', 'Eb'),
#   ('D:maj(9)', 'F#:dim/b3', 'A:sus4(2)'),
#   ('D:7', 'G:7/b2', 'D'),
#   ('D:7', 'C:maj7', 'D:min'),
#   ('G:(1)', 'E:sus2(b7)', 'D:(1,5)'),
#   ('B', 'G:maj6', 'C:sus4'),
#   ('B:min7', 'Eb', 'A:min7'),
#   ('F#', 'C:min', 'A:sus4(2)'),
#   ('G', 'D:maj7', 'C#:dim/b3'),
#   ('G', 'D/2', 'A:min7'),
#   ('F/6', 'C:9(*3)', 'D:(1)'),
#   ('D:7', 'D:maj(9)', 'C:9(*3)'),
#   ('G:min/5', 'C#:(1,b3)/b3', 'E:sus2(b7)'),
#   ('G', 'D:maj(9)', 'E:sus4(2)'),
#   ('A:maj(*5)', 'C:9(*3)', 'A:7/3'),
#   ('C#:(1,b3)', 'C/3', 'A:sus4(2)'),
#   ('C:sus4', 'G/3', 'F:min'),
#   ('G:7/2', 'D:sus4', 'C:min'),
#   ('D', 'D:sus4(2)', 'C/3'),
#   ('C', 'D:maj7', 'G/3'),
#   ('G:7', 'D/3', 'C:maj7'),
#   ('E', 'G:min(4)', 'E:min6'),
#   ('C/5', 'C:sus4', 'Eb'),
#   ('F/6', 'F#:min/5', 'F#:min'),
#   ('E:(1)', 'F#/5', 'F#:min'),
#   ('G#:hdim7', 'F#:dim/b3', 'E:min6'),
#   ('E/5', 'E/3', 'F'),
#   ('N', 'Ab:min', 'D:(1)'),
#   ('G:7/b2', 'G:min', 'G:(1,b3,4)/b3'),
#   ('B:min', 'E:9', 'C#:(1,b3)/b3'),
#   ('B', 'E:(1)', 'Ab:min'),
#   ('E:7', 'C/5', 'F'),
#   ('E/3', 'G:maj6', 'F#/5'),
#   ('G:7/b2', 'G#:hdim7', 'C:sus4'),
#   ('E:7', 'A/3', 'B:dim'),
#   ('C', 'G:7/b3', 'D:(1,5)'),
#   ('E/5', 'B:min7', 'A:min/4'),
#   ('A:7', 'G:min', 'A:sus4(2)'),
#   ('C/5', 'F/6', 'D:maj7'),
#   ('B', 'G/5', 'D:maj6'),
#   ('E', 'C', 'Eb:aug'),
#   ('G#:hdim7', 'F#', 'C:sus4'),
#   ('G:min/5', 'A:9', 'E:min/3'),
#   ('A/3', 'Bb', 'C:(1,5)'),
#   ('G:min', 'C:7', 'E:sus2(b7)'),
#   ('B:min', 'E:(1,5)', 'A:9'),
#   ('C', 'A/3', 'Ab:min'),
#   ('A', 'D:sus4', 'C:(1)'),
#   ('C/5', 'G:maj6', 'C#:min'),
#   ('D/5', 'G/5', 'G:maj7'),
#   ('C', 'C:7', 'A:7/3'),
#   ('E/5', 'A', 'B:min'),
#   ('A', 'G#:hdim7', 'C#:dim/b3'),
#   ('B:7', 'F#', 'G:(1,b3,4)/b3'),
#   ('G:7/2', 'D:sus4', 'A:9'),
#   ('E:(1)', 'B:min7', 'Ab:min'),
#   ('C/5', 'D/5', 'E:maj6'),
#   ('E:min/5', 'C#', 'E:min6'),
#   ('C:7', 'A:7/3', 'A:min7'),
#   ('G:(1)', 'G:min', 'C:maj(#4)/5'),
#   ('E/3', 'D', 'A:sus4(2)'),
#   ('A:7', 'C:sus4', 'A:9'),
#   ('E:7', 'B:min7', 'G:(1,b3,4)/b3'),
#   ('Ab', 'Eb:aug', 'C#'),
#   ('A:maj(*5)', 'D:maj6', 'F#/5'),
#   ('Bb', 'E:min/3', 'A:(1)'),
#   ('F#:dim/b3', 'F#:min/5', 'A:min7'),
#   ('E:(1,5)', 'F#:dim/b3', 'C#:min'),
#   ('B:7', 'D:sus4', 'E:sus4(2)'),
#   ('N', 'G', 'G:maj6'),
#   ('C', 'G:maj6', 'E:(1,b7)/b7'),
#   ('E:9', 'B:maj7', 'A:min7'),
#   ('A:7', 'B:min7', 'F#/5'),
#   ('C', 'G:7/b3', 'Eb'),
#   ('B:min', 'C:9(*3)', 'G:min(4)'),
#   ('E:9', 'C#:(1,b3)', 'F:min'),
#   ('G:min/5', 'E:maj6', 'D/2'),
#   ('G:7/b2', 'C:(1)', 'E:sus2(b7)'),
#   ('G:min(4)', 'B:dim', 'D/2'),
#   ('E/3', 'D:maj6', 'D:(1)'),
#   ('D:7', 'C:7', 'D:(1)'),
#   ('E/5', 'G:(1)', 'D:sus4(2)'),
#   ('A:min', 'C/3', 'B:maj7'),
#   ('C/5', 'G:maj6', 'D:min'),
#   ('G:7/b2', 'G/5', 'C:min'),
#   ('G:min/5', 'C#:(1,b3)/b3', 'F/5'),
#   ('C:min', 'Ab:min', 'D:min'),
#   ('E:9', 'C#:(1,b3)/b3', 'G:min'),
#   ('E:(1,b7)/b7', 'C#:(1,b3)/b3', 'E:min/5'),
#   ('C', 'C/5', 'A:(1)'),
#   ('B:min', 'A/3', 'C#'),
#   ('C', 'G:min/5', 'E:(1)'),
#   ('D/5', 'A:9', 'A:min7'),
#   ('E/3', 'C:(1)', 'F#:min/5'),
#   ('C:(1,5)', 'E:maj6', 'A:7/3'),
#   ('G:maj6', 'G:min(4)', 'A:min/4'),
#   ('B', 'A:min/4', 'D:(1)'),
#   ('E', 'G:maj6', 'C:maj(#4)/5'),
#   ('G:7/b2', 'E:min', 'G:maj7'),
#   ('C/5', 'E:min/5', 'A:7/3'),
#   ('D:7', 'G', 'F:min'),
#   ('C:(1,5)', 'F/5', 'D:min'),
#   ('B', 'G/3', 'A:(1)'),
#   ('E:maj6', 'C#:dim/b3', 'A:min7'),
#   ('E:(1,b7)/b7', 'G:min', 'B:dim'),
#   ('F/6', 'F#', 'D/2'),
#   ('C:7', 'C:sus4', 'E:sus2(b7)'),
#   ('C:(1)', 'F/5', 'D:(1)'),
#   ('G:7/2', 'A:7/3', 'E:sus4(2)'),
#   ('N', 'Bb', 'E:min6'),
#   ('B:min', 'A:min/4', 'A:sus4(2)'),
#   ('G:(1)', 'D/5', 'B:min7'),
#   ('G:7', 'C#:dim/b3', 'C:maj(#4)/5'),
#   ('D:maj7', 'B:dim', 'D:min'),
#   ('A:maj(*5)', 'G:min(4)', 'C:(1,5)'),
#   ('A', 'B:min', 'C/3'),
#   ('D:7', 'D:sus4', 'A/3'),
#   ('C/5', 'G', 'C#:min'),
#   ('A:7/3', 'E:sus4(2)', 'F:min'),
#   ('E:9', 'D:sus4', 'C:sus4'),
#   ('G:7/b2', 'A:7/3', 'F#:dim/b3'),
#   ('G:7/b3', 'F#:dim/b3', 'C#:hdim7'),
#   ('D:maj7', 'C#:(1,b3)', 'A:min/4'),
#   ('G:7/b3', 'A/3', 'F'),
#   ('G:min', 'C#:min', 'G:maj7'),
#   ('Ab:min', 'D:(1,5)', 'B:maj7'),
#   ('G:7', 'G:(1,b3,4)/b3', 'E:min/3'),
#   ('G:maj6', 'E:(1,5)', 'Eb:aug'),
#   ('D/5', 'E:min/5', 'D/3'),
#   ('E:(1,5)', 'A:min/4', 'G/3'),
#   ('B', 'B:min', 'Ab:min'),
#   ('B', 'E:9', 'C:7'),
#   ('D:7', 'B:7', 'C#:(1,b3)'),
#   ('N', 'D', 'D:maj6'),
#   ('E:sus2(b7)', 'E:min/5', 'G:maj7'),
#   ('D:7', 'C#:(1,b3)/b3', 'C#:min'),
#   ('G:7/b3', 'F', 'C:sus4'),
#   ('N', 'G/5', 'C:min'),
#   ('D:maj6', 'B:min7', 'F#/5'),
#   ('E:maj6', 'A:7/3', 'C#:min'),
#   ('E/5', 'D/5', 'E:(1,5)'),
#   ('D:7', 'G:min', 'G:min(4)'),
#   ('C#:(1,b3)', 'G:(1,b3,4)/b3', 'E:min'),
#   ('N', 'B:dim', 'C#'),
#   ('E:9', 'E:min', 'E:min6'),
#   ('G:(1,b3,4)/b3', 'F#:min/5', 'B:maj7'),
#   ('E', 'C:9(*3)', 'C:maj7'),
#   ('C', 'E:maj6', 'Eb:aug'),
#   ('F#', 'E:maj6', 'D:(1)'),
#   ('E:(1,5)', 'C:9(*3)', 'G/3'),
#   ('E:maj6', 'B:dim', 'A:(1)'),
#   ('A:7', 'A', 'G'),
#   ('G/3', 'F:min', 'E:min/3'),
#   ('E:(1,5)', 'A:9', 'G:maj7'),
#   ('D/5', 'F', 'C/3'),
#   ('D:7', 'E:7', 'A:sus4(2)'),
#   ('E', 'A:min/4', 'A:(1)'),
#   ('A:7', 'F#/5', 'A:7/3'),
#   ('E/5', 'A:min', 'C#:hdim7'),
#   ('G:7/b2', 'C/3', 'C:min'),
#   ('A', 'G/5', 'C:sus4'),
#   ('G:(1)', 'B', 'C#:(1,b3)'),
#   ('C/5', 'A/3', 'E:(1,5)'),
#   ('G:7', 'G', 'A:(1)'),
#   ('F#', 'C:sus4', 'C#'),
#   ('G:min(4)', 'A:7/3', 'C#:dim/b3'),
#   ('G:maj6', 'C#:min', 'D:(1,5)'),
#   ('C/5', 'F#', 'F#:min/5'),
#   ('B', 'G:maj6', 'C#:dim/b3'),
#   ('E:7', 'D', 'A:(1)'),
#   ('E:(1,b7)/b7', 'B:dim', 'D/3'),
#   ('G:7/b2', 'E/5', 'Ab:min'),
#   ('G:maj6', 'C:min', 'D:(1)'),
#   ('F#:dim/b3', 'D/2', 'C#:hdim7'),
#   ('E/3', 'D:sus4', 'C#'),
#   ('G:7', 'G:(1)', 'D:maj6'),
#   ('E:7', 'B:min', 'D/5'),
#   ('G:7/2', 'C#:(1,b3)', 'A:9'),
#   ('G:(1)', 'C:9(*3)', 'Eb'),
#   ('G:min/5', 'C:9(*3)', 'F#/5'),
#   ('A/3', 'G:(1,b3,4)/b3', 'A:sus4(2)'),
#   ('G', 'C:sus4', 'D/3'),
#   ('A:7', 'E:(1,5)', 'C/3'),
#   ('E', 'Bb', 'C#:min'),
#   ('B', 'C:(1)', 'E:maj6'),
#   ('G:7/b2', 'C#:min', 'F#:min'),
#   ('E/5', 'D:min', 'G:maj7'),
#   ('D:maj7', 'G:maj6', 'C#'),
#   ('E/3', 'G:min', 'E:sus4(2)'),
#   ('D/5', 'F#:dim/b3', 'D:min'),
#   ('C/5', 'D:maj6', 'C:sus4'),
#   ('G/5', 'F#', 'E:min'),
#   ('G#:hdim7', 'E:min/3', 'F#:min'),
#   ('G#:hdim7', 'C#:(1,b3)', 'C#'),
#   ('E:9', 'E:(1,5)', 'A:sus4(2)'),
#   ('E:sus2(b7)', 'G/3', 'B:dim'),
#   ('E:7', 'G:7', 'G:maj7'),
#   ('D:sus4(2)', 'F#/5', 'D:(1,5)'),
#   ('Ab', 'B:dim', 'A:(1)'),
#   ('F', 'C:(1)', 'F#/5'),
#   ('G#:hdim7', 'A:7/3', 'F#:dim/b3'),
#   ('D:maj7', 'E:(1,5)', 'E:sus4(2)'),
#   ('G:min/5', 'D:maj6', 'C:maj7'),
#   ('E:(1)', 'A:9', 'E:sus4(2)'),
#   ('G/3', 'F#:dim/b3', 'Eb:aug'),
#   ('G:maj6', 'A:min/4', 'A:9'),
#   ('C:min', 'C#:dim/b3', 'D:(1,5)'),
#   ('G:7/2', 'E:min/5', 'A:7/3'),
#   ('G:maj6', 'C#:hdim7', 'F#:min/5'),
#   ('N', 'F/5', 'C#:dim/b3'),
#   ('C', 'G:(1)', 'A:maj(*5)'),
#   ('G:7/b3', 'D:maj7', 'F:min'),
#   ('G:7/b3', 'B:7', 'F#:dim/b3'),
#   ('D:sus4', 'G/5', 'A:7/3'),
#   ('G/5', 'E:sus2(b7)', 'A:(1)'),
#   ('F/6', 'F', 'Ab'),
#   ('G:7/2', 'D:maj6', 'G:min'),
#   ('B', 'E:(1,b7)/b7', 'C:9(*3)'),
#   ('B:min', 'G#:hdim7', 'D/2'),
#   ('E:9', 'A:sus4(2)', 'Eb:aug'),
#   ('G:7/b2', 'C:9(*3)', 'Eb:aug'),
#   ('G:7/2', 'C#:(1,b3)/b3', 'D/2'),
#   ('G:min/5', 'Eb', 'B:dim'),
#   ('D:maj7', 'C#:(1,b3)', 'G:maj7'),
#   ('D', 'D:sus4', 'B:dim'),
#   ('G:min/5', 'G:(1,b3,4)/b3', 'Ab:min'),
#   ('B:7', 'C#:(1,b3)', 'C:9(*3)'),
#   ('E:9', 'Ab:min', 'A:min7'),
#   ('G:7/2', 'E:9', 'C#:dim/b3'),
#   ('A/3', 'C#:(1,b3)/b3', 'G:(1,b3,4)/b3'),
#   ('C#:(1,b3)', 'A:9', 'A:(1)'),
#   ('C', 'F', 'C:(1)'),
#   ('F#/5', 'A:7/3', 'F#:min/5'),
#   ('E:7', 'C/3', 'E:maj6'),
#   ('G:7/b3', 'C#', 'D:(1,5)'),
#   ('A:maj(*5)', 'C:sus4', 'C:maj7'),
#   ('C/3', 'Bb', 'E:min/5'),
#   ('E:sus4(2)', 'E:min/3', 'B:maj7'),
#   ('E/3', 'D', 'E:(1,5)'),
#   ('G:7/b3', 'E:min/5', 'A:sus4(2)'),
#   ('B', 'E:(1,b7)/b7', 'E:min/5'),
#   ('E:9', 'F#', 'A:(1)'),
#   ('G#:hdim7', 'C/3', 'Bb'),
#   ('F#/5', 'A:min7', 'C:maj(#4)/5'),
#   ('N', 'C#:min', 'F#:min'),
#   ('G/5', 'D:maj6', 'A:(1)'),
#   ('E:7', 'E:(1)', 'E:sus2(b7)'),
#   ('Ab:min', 'A:(1)', 'B:maj7'),
#   ('D:7', 'F/5', 'E:min6'),
#   ('B:7', 'A/3', 'D:maj6'),
#   ('D:7', 'Bb', 'Eb:aug'),
#   ('D:sus4', 'E:(1)', 'G/3'),
#   ('G', 'E:sus4(2)', 'C#:min'),
#   ('D', 'G/5', 'A:min'),
#   ('G', 'F#:min/5', 'G:maj7'),
#   ('F#', 'C:9(*3)', 'D/2'),
#   ('E/5', 'F/6', 'F'),
#   ('Ab', 'E:min', 'C#'),
#   ('Bb', 'E:sus2(b7)', 'A:9'),
#   ('A:7', 'D:maj7', 'G:(1,b3,4)/b3'),
#   ('G:(1)', 'A:9', 'F#/5'),
#   ('G:7/b2', 'D:sus4', 'C/3'),
#   ('E/5', 'G', 'Ab:min'),
#   ('E:7', 'E:min6', 'A:min7'),
#   ('G:7/b3', 'B:7', 'G:min/5'),
#   ('F', 'C:(1)', 'C:sus4'),
#   ('G:7/2', 'A:min/4', 'F/5'),
#   ('A:maj(*5)', 'B:min7', 'E:min6'),
#   ('G/3', 'D:(1,5)', 'F#:min'),
#   ('B', 'E:(1,5)', 'D:min'),
#   ('F/5', 'C:maj7', 'G:maj7'),
#   ('E:7', 'C:7', 'G:maj7'),
#   ('G:min(4)', 'A:9', 'C#:min'),
#   ('E/5', 'G/3', 'F#:dim/b3'),
#   ('N', 'C#:(1,b3)', 'G:(1,b3,4)/b3'),
#   ('G:7/b3', 'E:9', 'F#:dim/b3'),
#   ('C', 'D:maj6', 'A:(1)'),
#   ('A:7', 'E:min/5', 'C#:hdim7'),
#   ('E:9', 'C:min', 'C:maj(#4)/5'),
#   ('A:min/4', 'Eb:aug', 'D:(1,5)'),
#   ('C#:(1,b3)/b3', 'C:(1,5)', 'F#/5'),
#   ('G:7/b3', 'B:min7', 'A:(1)'),
#   ('G:min/5', 'Eb', 'F#:min'),
#   ('D:maj7', 'G/3', 'Ab:min'),
#   ('N', 'D:maj7', 'D/2'),
#   ('C#:(1,b3)/b3', 'E:sus2(b7)', 'A:9'),
#   ('E:(1)', 'A:7/3', 'Ab:min'),
#   ('C/5', 'E:sus2(b7)', 'A:9'),
#   ('B:7', 'D:sus4(2)', 'E:(1,b7)/b7'),
#   ('A/3', 'E:min/5', 'D:(1,5)'),
#   ('C', 'D:sus4', 'D/3'),
#   ('D:7', 'E/5', 'G'),
#   ('C/5', 'A:min', 'E:(1,b7)/b7'),
#   ('G:7/b3', 'A', 'E:min/3'),
#   ('A:min/4', 'F#:min/5', 'F#:min'),
#   ('E', 'Bb', 'F#:dim/b3'),
#   ('D/5', 'G:min/5', 'A:(1)'),
#   ('E:9', 'A:9', 'D:(1)'),
#   ('C:7', 'E:min/3', 'G:maj7'),
#   ('B:7', 'Eb', 'B:maj7'),
#   ('E:7', 'E:(1,5)', 'D:(1)'),
#   ('G:7/b3', 'A:min7', 'C:maj(#4)/5'),
#   ('D:7', 'E:(1,b7)/b7', 'C#:dim/b3'),
#   ('G/5', 'C#:(1,b3)', 'C#:hdim7'),
#   ('E:(1,5)', 'C#:(1,b3)', 'Ab:min'),
#   ('C:min', 'F:min', 'E:min/3'),
#   ('D:maj(9)', 'A:min', 'F#/5'),
#   ('N', 'F/6', 'G:maj7'),
#   ('F#', 'G:min', 'C:sus4'),
#   ('G:7/b2', 'E:sus2(b7)', 'D/3'),
#   ('C/5', 'D/3', 'Ab:min'),
#   ('G#:hdim7', 'A:sus4(2)', 'C#:min'),
#   ('G:7/2', 'Ab', 'E:(1,5)'),
#   ('F#', 'Ab', 'E:maj6'),
#   ('E:(1)', 'C/3', 'A:min7'),
#   ('C:(1,5)', 'C:min', 'Eb:aug'),
#   ('B:7', 'E:min/5', 'F#:min/5'),
#   ('D:maj7', 'Ab', 'G:(1,b3,4)/b3'),
#   ('E:7', 'E:(1,5)', 'C:7'),
#   ('A:7', 'A:min', 'C#:hdim7'),
#   ('E:7', 'G:7/b3', 'G/5'),
#   ('N', 'A:min', 'C:9(*3)'),
#   ('C', 'A:maj(*5)', 'B:maj7'),
#   ('G:7/b3', 'B:min', 'B:min7'),
#   ('B:min', 'C:(1,5)', 'C#:hdim7'),
#   ('F#/5', 'D/3', 'E:min/3'),
#   ('E:(1)', 'C/3', 'F#:dim/b3'),
#   ('N', 'E/3', 'C#:dim/b3'),
#   ('D:sus4', 'B:min7', 'C:maj(#4)/5'),
#   ('F#', 'C#:min', 'D:(1,5)'),
#   ('B', 'D', 'C:sus4'),
#   ('G:7/2', 'G:7/b3', 'Ab'),
#   ('G/5', 'B:min7', 'Eb:aug'),
#   ('A', 'C:sus4', 'Ab:min'),
#   ('A', 'Bb', 'C:(1,5)'),
#   ('G:maj6', 'C#:(1,b3)/b3', 'C:9(*3)'),
#   ('F/6', 'D/2', 'A:sus4(2)'),
#   ('C/5', 'G/3', 'C#:hdim7'),
#   ('G', 'A:min', 'C/3'),
#   ('G:(1,b3,4)/b3', 'C:(1)', 'D:(1,5)'),
#   ('G:(1,b3,4)/b3', 'E:min/5', 'F:min'),
#   ('G:(1)', 'E:9', 'C:(1)'),
#   ('Bb', 'C#:hdim7', 'B:maj7'),
#   ('N', 'G:7', 'G:7/b3'),
#   ('G', 'D:sus4(2)', 'C:maj(#4)/5'),
#   ('N', 'E:9', 'C:maj7'),
#   ('G:min', 'D/2', 'C:maj7'),
#   ('G:min', 'E:sus4(2)', 'E:min/3'),
#   ('D:7', 'G:(1)', 'C:7'),
#   ('E:(1,5)', 'E:min/3', 'Ab:min'),
#   ('F#', 'C:7', 'E:sus4(2)'),
#   ('A:7/3', 'A:sus4(2)', 'C:maj(#4)/5'),
#   ('G:min/5', 'A:min/4', 'A:(1)'),
#   ('G#:hdim7', 'E:sus4(2)', 'A:min7'),
#   ('E', 'G:7/b3', 'E/5'),
#   ('A', 'F/6', 'B:dim'),
#   ('G', 'F/5', 'Eb:aug'),
#   ('B', 'B:7', 'F'),
#   ('Bb', 'B:dim', 'D:(1,5)'),
#   ('B:7', 'E:sus4(2)', 'F#:min/5'),
#   ('N', 'F:min', 'D:(1)'),
#   ('D', 'G/5', 'D:maj6'),
#   ('G:7', 'E:sus4(2)', 'C:maj(#4)/5'),
#   ('A:7', 'D:maj(9)', 'A:min7'),
#   ('E:9', 'E:(1,5)', 'G/3'),
#   ('E:7', 'A:(1)', 'D:(1)'),
#   ('D', 'D:maj6', 'A:7/3'),
#   ('D:sus4(2)', 'G:min(4)', 'E:maj6'),
#   ('C#:dim/b3', 'C#:hdim7', 'C#'),
#   ('C', 'C:9(*3)', 'F#/5'),
#   ('D:7', 'G:(1)', 'B:min'),
#   ('G:7/2', 'Ab:min', 'D:(1)'),
#   ('G:(1)', 'B', 'F#'),
#   ('G:7/2', 'G:maj6', 'E:(1,5)'),
#   ('F', 'Ab', 'D/3'),
#   ('G', 'G:min', 'F#:min/5'),
#   ('B:7', 'E:maj6', 'A:sus4(2)'),
#   ('C#:(1,b3)/b3', 'F#/5', 'B:maj7'),
#   ('F#/5', 'D/2', 'B:maj7'),
#   ('B:7', 'E:(1)', 'E:min/5'),
#   ('C/3', 'G:min', 'Bb'),
#   ('G:min(4)', 'D:min', 'D:(1)'),
#   ('F#/5', 'A:sus4(2)', 'C#:hdim7'),
#   ('E/5', 'G:min(4)', 'C#:min'),
#   ('D:maj6', 'G:min', 'E:min/5'),
#   ('G#:hdim7', 'C:(1,5)', 'Ab:min'),
#   ('C:(1)', 'C#:min', 'A:min7'),
#   ('D:maj6', 'E:min6', 'D:(1,5)'),
#   ('G#:hdim7', 'D', 'G:maj6'),
#   ('E', 'D:maj7', 'A:min'),
#   ('G:7/2', 'G:min/5', 'A:(1)'),
#   ('E:(1)', 'C#:min', 'C:maj(#4)/5'),
#   ('F#', 'E:maj6', 'G/3'),
#   ('E:(1,5)', 'C:9(*3)', 'D:(1)'),
#   ('E:7', 'F/5', 'C#:dim/b3'),
#   ('F', 'C:7', 'E:sus4(2)'),
#   ('F/6', 'B:min7', 'F:min'),
#   ('E/3', 'Eb', 'A:min7'),
#   ('C#:(1,b3)', 'E:min/5', 'E:min/3'),
#   ('A:7', 'B:7', 'C:min'),
#   ('C/5', 'A:maj(*5)', 'E:(1,b7)/b7'),
#   ('B', 'F', 'F:min'),
#   ('C:min', 'F/5', 'D:min'),
#   ('G:7/2', 'D', 'A:sus4(2)'),
#   ('G/5', 'Ab', 'C#:dim/b3'),
#   ('D:sus4', 'C:9(*3)', 'D:(1)'),
#   ('D:maj(9)', 'G:min', 'E:min'),
#   ('C#', 'F#:min/5', 'C:maj(#4)/5'),
#   ('G:7/b3', 'E:(1,b7)/b7', 'G:maj7'),
#   ('E/5', 'G:(1,b3,4)/b3', 'E:sus2(b7)'),
#   ('G', 'C:(1,5)', 'E:min/3'),
#   ('E/3', 'G/3', 'A:min7'),
#   ('B:min7', 'C:maj7', 'C#:hdim7'),
#   ('G:min', 'F#/5', 'D/2'),
#   ('A:min', 'B:dim', 'E:sus4(2)'),
#   ('E', 'C', 'Ab:min'),
#   ('C:(1,5)', 'Eb:aug', 'D:(1,5)'),
#   ('G:7', 'C#:(1,b3)', 'C#:min'),
#   ('E/5', 'G:(1)', 'E:maj6'),
#   ('C#:(1,b3)/b3', 'F:min', 'Ab:min'),
#   ('E:7', 'G:maj6', 'G/3'),
#   ('E:7', 'D/5', 'D:(1,5)'),
#   ('E:(1,b7)/b7', 'A:sus4(2)', 'D:min'),
#   ('D/5', 'D:sus4(2)', 'E:(1)'),
#   ('G#:hdim7', 'C/3', 'A:min7'),
#   ('E:9', 'E:(1,5)', 'F/5'),
#   ('F/6', 'E:(1,5)', 'Bb'),
#   ('G:min/5', 'F#:dim/b3', 'D:(1)'),
#   ('B:dim', 'F:min', 'A:min7'),
#   ('A:7', 'D/5', 'D'),
#   ('F/6', 'D:(1,5)', 'C:maj(#4)/5'),
#   ('A:maj(*5)', 'E:sus2(b7)', 'D:(1)'),
#   ('A:7', 'F', 'Ab:min'),
#   ('F', 'C:(1)', 'E:min/3'),
#   ('G:maj6', 'D:maj6', 'C:(1,5)'),
#   ('G:(1,b3,4)/b3', 'E:min', 'E:min/5'),
#   ('G:7', 'B:dim', 'B:maj7'),
#   ('D:7', 'C#:(1,b3)', 'C:(1,5)'),
#   ('B:7', 'D:sus4', 'F/5'),
#   ('C', 'E:min/5', 'C:maj(#4)/5'),
#   ('G:7/b2', 'F/5', 'A:(1)'),
#   ('F#', 'C#:(1,b3)/b3', 'C:7'),
#   ('F#', 'G:min', 'B:dim'),
#   ('B:min7', 'C:7', 'B:dim'),
#   ('G:7/b3', 'G:min(4)', 'D:(1)'),
#   ('B:min7', 'G:min(4)', 'G:maj7'),
#   ('E', 'G:7/2', 'F#:min/5'),
#   ('Ab', 'C#:(1,b3)/b3', 'A:(1)'),
#   ('A:9', 'E:min/3', 'F#:min/5'),
#   ('G:7/2', 'A', 'G:maj6'),
#   ('E:min/5', 'Ab:min', 'A:(1)'),
#   ('N', 'C:min', 'F#:min/5'),
#   ('E', 'E/3', 'C#:(1,b3)'),
#   ('F', 'C:(1,5)', 'Eb'),
#   ('G:maj6', 'G:min(4)', 'A:min7'),
#   ('D:maj(9)', 'D:maj7', 'A:7/3'),
#   ('B', 'G/5', 'E:min6'),
#   ('E:7', 'G', 'E:(1,5)'),
#   ('E/3', 'G:min(4)', 'C:(1,5)'),
#   ('G:7/2', 'A:min', 'A:(1)'),
#   ('G:7/2', 'E:(1)', 'E:sus2(b7)'),
#   ('G#:hdim7', 'F#/5', 'F/5'),
#   ('C', 'F#', 'C:sus4'),
#   ('F', 'B:min7', 'E:(1,b7)/b7'),
#   ('A:min/4', 'D:min', 'F#:min'),
#   ('G:7', 'C#:dim/b3', 'F:min'),
#   ('C', 'F#', 'Eb:aug'),
#   ('C#:(1,b3)', 'B:maj7', 'G:maj7'),
#   ('G:(1)', 'G:(1,b3,4)/b3', 'E:min'),
#   ('C:(1,5)', 'Eb', 'A:7/3'),
#   ('E/3', 'G:min', 'D/3'),
#   ('E:sus2(b7)', 'E:min/5', 'C#:min'),
#   ('E/5', 'C:9(*3)', 'C:min'),
#   ('A:7', 'B:min', 'A:7/3'),
#   ('C/5', 'G#:hdim7', 'C:9(*3)'),
#   ('E:(1,b7)/b7', 'F#/5', 'C#'),
#   ('E:(1,5)', 'C:maj7', 'Ab:min'),
#   ('D', 'G:maj6', 'E:sus4(2)'),
#   ('C/3', 'A:min/4', 'E:min6'),
#   ('E:7', 'G:7/2', 'E:min'),
#   ('B', 'D:sus4', 'F#/5'),
#   ('D:7', 'G:min/5', 'A:(1)'),
#   ('D/5', 'D/3', 'A:sus4(2)'),
#   ('G:7/2', 'F/6', 'E:(1)'),
#   ('B:7', 'G/3', 'F#:min/5'),
#   ('E/3', 'G#:hdim7', 'F:min'),
#   ('G:7/b2', 'D/3', 'E:min/3'),
#   ('G:(1)', 'G/3', 'C:maj7'),
#   ('G#:hdim7', 'F#:dim/b3', 'D:min'),
#   ('N', 'B', 'Eb'),
#   ('G:7', 'E/5', 'G/5'),
#   ('G:7', 'B:min', 'C/3'),
#   ('D', 'A:min', 'C#:dim/b3'),
#   ('F', 'E:(1,b7)/b7', 'Eb'),
#   ('C', 'C:min', 'F/5'),
#   ('E:(1)', 'G/3', 'C:maj(#4)/5'),
#   ('D:7', 'C/3', 'G:min'),
#   ('E', 'F#', 'C#:(1,b3)/b3'),
#   ('D:maj(9)', 'G/3', 'Ab:min'),
#   ('A:7', 'E:sus2(b7)', 'D:(1,5)'),
#   ('E:7', 'A:maj(*5)', 'C:9(*3)'),
#   ('E/3', 'D:sus4', 'F:min'),
#   ('G:7', 'G:7/b3', 'F/6'),
#   ('E/3', 'D:maj(9)', 'D/3'),
#   ('F/6', 'E:min/5', 'G:maj7'),
#   ('D/5', 'B:min7', 'B:dim'),
#   ('E:(1,5)', 'E:(1,b7)/b7', 'C:min'),
#   ('E:maj6', 'E:min', 'C#:min'),
#   ('F/5', 'D:min', 'F#:min/5'),
#   ('E/5', 'C:7', 'Eb:aug'),
#   ('G:7/2', 'G:min', 'E:sus2(b7)'),
#   ('G:7', 'C#:(1,b3)/b3', 'C:maj(#4)/5'),
#   ('G#:hdim7', 'E:min', 'C#:hdim7'),
#   ('A', 'G/5', 'C:maj7'),
#   ('E', 'C:7', 'C#:dim/b3'),
#   ('G:(1,b3,4)/b3', 'G:min(4)', 'E:min6'),
#   ('C/5', 'C/3', 'A:min/4'),
#   ('B:7', 'E:9', 'E:maj6'),
#   ('C:(1)', 'C#:min', 'F#:min/5'),
#   ('G:min/5', 'A/3', 'Eb'),
#   ('G:min', 'G:min(4)', 'G/3'),
#   ('G:(1)', 'G:(1,b3,4)/b3', 'C:9(*3)'),
#   ('E:min/5', 'B:dim', 'E:min/3'),
#   ('G:7/b3', 'C#:(1,b3)', 'C:min'),
#   ('G:7/2', 'C:(1)', 'D/3'),
#   ('N', 'C#:(1,b3)', 'C:(1)'),
#   ('C/3', 'C:(1,5)', 'F#:min'),
#   ('E:7', 'G:7', 'D'),
#   ('G', 'G:min', 'F#:min'),
#   ('E:sus2(b7)', 'C:min', 'F:min'),
#   ('A:min', 'G/3', 'D:min'),
#   ('G:(1)', 'D:sus4(2)', 'A:min7'),
#   ('Bb', 'Eb', 'B:dim'),
#   ('C:sus4', 'E:sus4(2)', 'E:min6'),
#   ('G:7/b2', 'C:(1)', 'F#:min'),
#   ('B:min7', 'C#:(1,b3)/b3', 'C:(1,5)'),
#   ('D:7', 'G:maj6', 'D:(1)'),
#   ('E:7', 'G:7/b2', 'D/3'),
#   ('E', 'D:maj7', 'C/3'),
#   ('B', 'G#:hdim7', 'B:maj7'),
#   ('G/5', 'A:maj(*5)', 'C:maj7'),
#   ('E/5', 'G:min', 'C#:min'),
#   ('G:maj6', 'C#:(1,b3)/b3', 'G:min(4)'),
#   ('E:min', 'F#:dim/b3', 'D:min'),
#   ('D:7', 'Eb', 'Ab:min'),
#   ('E:7', 'E:9', 'C#:dim/b3'),
#   ('A', 'C/3', 'F#/5'),
#   ('G:7/b2', 'B', 'A:7/3'),
#   ('D:sus4', 'A:sus4(2)', 'A:(1)'),
#   ('G:7/2', 'C:9(*3)', 'Eb:aug'),
#   ('E', 'G:7', 'A:sus4(2)'),
#   ('E:(1,b7)/b7', 'F:min', 'D:min'),
#   ('D:7', 'G:7/b3', 'D:maj7'),
#   ('D:maj6', 'G:min(4)', 'C#:hdim7'),
#   ('A', 'A/3', 'C:maj(#4)/5'),
#   ('F#', 'G/3', 'E:min6'),
#   ('G#:hdim7', 'F/5', 'C:maj(#4)/5'),
#   ('E/5', 'B:7', 'G:min/5'),
#   ('E:9', 'E:min/5', 'Eb:aug'),
#   ('B:7', 'C/3', 'E:min/5'),
#   ('C', 'D:maj6', 'C:maj(#4)/5'),
#   ('G:min/5', 'F/5', 'C#:dim/b3'),
#   ('F#', 'E:(1,5)', 'A:7/3'),
#   ('B:7', 'B:min', 'C#:hdim7'),
#   ('E/3', 'D:maj(9)', 'C#:hdim7'),
#   ('D:maj(9)', 'C:(1)', 'Eb'),
#   ('D:maj(9)', 'D:min', 'F#:min/5'),
#   ('C:9(*3)', 'C#', 'C:maj(#4)/5'),
#   ('D/5', 'C#:(1,b3)', 'B:maj7'),
#   ('C:7', 'G/3', 'B:maj7'),
#   ('G:7', 'E:sus4(2)', 'C#'),
#   ('G:7/2', 'A/3', 'C:maj7'),
#   ('G:7/b3', 'G:min(4)', 'E:min/5'),
#   ('G:7/b3', 'C:(1,5)', 'C#:hdim7'),
#   ('C#:(1,b3)', 'F:min', 'G:maj7'),
#   ('D:7', 'B:min7', 'A:7/3'),
#   ('G:maj6', 'C/3', 'C:maj7'),
#   ('C/3', 'G:min(4)', 'A:min7'),
#   ('N', 'E', 'D:(1)'),
#   ('B', 'Eb', 'D:min'),
#   ('N', 'Eb:aug', 'E:min/3'),
#   ('A:min', 'F#:dim/b3', 'C#:dim/b3'),
#   ('A:7', 'B', 'E:(1,b7)/b7'),
#   ('C', 'A:7/3', 'E:sus4(2)'),
#   ('E/3', 'D', 'B:maj7'),
#   ('E:maj6', 'A:9', 'D:min'),
#   ('D:7', 'B', 'G/3'),
#   ('D:sus4(2)', 'C:(1)', 'B:dim'),
#   ('D:maj(9)', 'G:maj6', 'A:7/3'),
#   ('D:maj6', 'A:min/4', 'E:min6'),
#   ('F/6', 'D:maj6', 'E:min'),
#   ('E/3', 'D:maj7', 'C#:(1,b3)/b3'),
#   ('A:7', 'E/3', 'C:maj7'),
#   ('F:min', 'C#:min', 'E:min6'),
#   ('G:7/2', 'G:(1)', 'C#'),
#   ('D:maj7', 'G:min/5', 'G:min'),
#   ('E:(1,b7)/b7', 'C#:dim/b3', 'A:(1)'),
#   ('F/6', 'A:min', 'G:min'),
#   ('G:7/b3', 'B:min7', 'G:min'),
#   ('B:7', 'C#:hdim7', 'A:(1)'),
#   ('A:maj(*5)', 'E:sus2(b7)', 'D:min'),
#   ('E/3', 'E:(1,b7)/b7', 'A:7/3'),
#   ('E:9', 'F#/5', 'C:maj(#4)/5'),
#   ('G:7', 'D/3', 'C#'),
#   ('E/5', 'C/5', 'A:maj(*5)'),
#   ('Ab', 'D:(1)', 'B:maj7'),
#   ('E/5', 'E:maj6', 'Eb'),
#   ('E:sus2(b7)', 'B:dim', 'G:maj7'),
#   ('A', 'A:7/3', 'D/2'),
#   ('D:sus4', 'F', 'G:(1,b3,4)/b3'),
#   ('D:maj6', 'G:min', 'D:(1)'),
#   ('A:9', 'E:min6', 'G:maj7'),
#   ('D:7', 'E:(1)', 'C:maj(#4)/5'),
#   ('G:7/b3', 'B:maj7', 'G:maj7'),
#   ('E:(1,b7)/b7', 'A:7/3', 'D/2'),
#   ('C', 'E/3', 'F#:min/5'),
#   ('E:9', 'A:min', 'C:maj7'),
#   ('Bb', 'D/3', 'D:(1)'),
#   ('N', 'F/6', 'C#'),
#   ('A:min', 'G:min(4)', 'D:(1)'),
#   ('C/5', 'C:(1,5)', 'C#:dim/b3'),
#   ('A:7', 'G/5', 'G:maj7'),
#   ('G:min', 'E:min', 'A:min/4'),
#   ('B', 'F#/5', 'B:maj7'),
#   ('A', 'A:9', 'E:min6'),
#   ('D/5', 'E:sus4(2)', 'C#:hdim7'),
#   ('E:min', 'C#:min', 'C:maj(#4)/5'),
#   ('A', 'C:sus4', 'E:sus2(b7)'),
#   ('B', 'E:(1,5)', 'C/3'),
#   ('C#:(1,b3)', 'C:maj7', 'C#'),
#   ('N', 'A', 'Eb'),
#   ('E:7', 'G:min(4)', 'C:(1,5)'),
#   ('C', 'A:maj(*5)', 'G/3'),
#   ('E:(1)', 'C:9(*3)', 'A:7/3'),
#   ('D:7', 'A:7/3', 'B:maj7'),
#   ('G:7/2', 'B', 'E:(1)'),
#   ('B:min', 'D:sus4', 'A:9'),
#   ('G:7/b2', 'G#:hdim7', 'D/2'),
#   ('G/5', 'A/3', 'Eb'),
#   ('E/5', 'D:maj6', 'F#/5'),
#   ('G:7', 'A:min', 'C/3'),
#   ('D:sus4(2)', 'C#:(1,b3)', 'A:(1)'),
#   ('B:7', 'E:(1)', 'C:9(*3)'),
#   ('E:sus2(b7)', 'B:dim', 'D:(1,5)'),
#   ('D:sus4', 'E:min/5', 'D/2'),
#   ('C:9(*3)', 'C:sus4', 'C:maj(#4)/5'),
#   ('G:7', 'D:maj7', 'D/3'),
#   ('E:(1)', 'Ab', 'E:(1,b7)/b7'),
#   ('C:9(*3)', 'C:7', 'B:dim'),
#   ('G:(1)', 'E:min', 'C#:min'),
#   ('G:7', 'G:min/5', 'D:maj6'),
#   ('D:sus4(2)', 'C:(1,5)', 'D:(1)'),
#   ('G', 'B:dim', 'B:maj7'),
#   ('C/5', 'F/5', 'C#:hdim7'),
#   ('D', 'E:sus2(b7)', 'E:min6'),
#   ('A/3', 'A:(1)', 'F#:min'),
#   ('G:7/2', 'D:maj6', 'A:(1)'),
#   ('A:7/3', 'D/3', 'C:maj(#4)/5'),
#   ('G:7/2', 'G#:hdim7', 'D:sus4'),
#   ('A', 'C#:hdim7', 'A:min7'),
#   ('D:sus4', 'F:min', 'D:(1)'),
#   ('G#:hdim7', 'D/3', 'F#:min/5'),
#   ('G:7/2', 'E:(1)', 'D:(1,5)'),
#   ('G:7/b3', 'Ab:min', 'F#:min/5'),
#   ('G#:hdim7', 'E:(1,5)', 'E:sus2(b7)'),
#   ('B', 'G/3', 'D/2'),
#   ('D', 'C:(1)', 'F:min'),
#   ('C', 'G', 'D:(1,5)'),
#   ('F/6', 'Eb:aug', 'Ab:min'),
#   ('G:7/2', 'A:7/3', 'E:min/3'),
#   ('E:7', 'E:min', 'E:sus4(2)'),
#   ('G:(1)', 'F', 'E:(1,5)'),
#   ('G:7/b3', 'G:min(4)', 'E:min'),
#   ('D:7', 'F', 'C/3'),
#   ('G:maj6', 'D/2', 'E:sus4(2)'),
#   ('A:maj(*5)', 'A:7/3', 'C#:dim/b3'),
#   ('G:(1,b3,4)/b3', 'C:(1,5)', 'C#:hdim7'),
#   ('C:(1,5)', 'Eb', 'Eb:aug'),
#   ('E/3', 'D:maj7', 'D/2'),
#   ('C/3', 'Eb:aug', 'B:maj7'),
#   ('A:9', 'F#/5', 'B:dim'),
#   ('D/2', 'C#:min', 'E:min6'),
#   ('N', 'A:min', 'C:7'),
#   ('G/3', 'A:(1)', 'G:maj7'),
#   ('C#:(1,b3)', 'F:min', 'D:(1,5)'),
#   ('C/5', 'C:(1,5)', 'F#/5'),
#   ('G/5', 'E:maj6', 'C#:hdim7'),
#   ('A:7', 'D/5', 'C#:hdim7'),
#   ('A:maj(*5)', 'C:(1,5)', 'D:(1)'),
#   ('F#/5', 'D/2', 'D:min'),
#   ('G:7/b3', 'D:sus4(2)', 'G:maj7'),
#   ('E:min/5', 'C#:dim/b3', 'C:maj7'),
#   ('D/3', 'C#', 'A:(1)'),
#   ('E', 'D:sus4(2)', 'Eb'),
#   ('E:(1)', 'A:min', 'G:maj7'),
#   ('E', 'G:7/2', 'Eb:aug'),
#   ('G:(1)', 'C/5', 'A:(1)'),
#   ('E:9', 'D:sus4', 'G/5'),
#   ('E:7', 'G', 'G:(1,b3,4)/b3'),
#   ('D:sus4', 'D:maj(9)', 'Bb'),
#   ('C/5', 'F#', 'Ab'),
#   ('A:maj(*5)', 'G:min', 'C:9(*3)'),
#   ('F/6', 'G:min/5', 'E:(1)'),
#   ('D:sus4(2)', 'G:min', 'Eb:aug'),
#   ('E', 'B:dim', 'F#:min'),
#   ('G:7/b2', 'F#:dim/b3', 'A:sus4(2)'),
#   ('G:7', 'Bb', 'C#:dim/b3'),
#   ('C/5', 'C#:hdim7', 'D:(1)'),
#   ('E:(1,5)', 'C#', 'Ab:min'),
#   ('E:(1,5)', 'C:sus4', 'E:min/3'),
#   ('E/3', 'Bb', 'G:min(4)'),
#   ('E:7', 'C', 'G:min/5'),
#   ('C#:(1,b3)', 'F/5', 'C:maj7'),
#   ('F#:dim/b3', 'E:min6', 'G:maj7'),
#   ('B:min', 'G:maj6', 'C#:(1,b3)'),
#   ('G:7/b2', 'E:maj6', 'B:maj7'),
#   ('D:maj(9)', 'E:min', 'A:7/3'),
#   ('E:(1)', 'E:(1,b7)/b7', 'C#:(1,b3)/b3'),
#   ('B', 'D/5', 'C#:hdim7'),
#   ('D:sus4(2)', 'E:(1,b7)/b7', 'Bb'),
#   ('N', 'E:7', 'G:7'),
#   ('G/5', 'A:min', 'Bb'),
#   ('F#', 'E:min/3', 'E:min6'),
#   ('G', 'A:min/4', 'A:min7'),
#   ('G#:hdim7', 'G:min/5', 'B:min7'),
#   ('D:7', 'B', 'G:min'),
#   ('C#:(1,b3)', 'E:sus2(b7)', 'F:min'),
#   ('A', 'C:(1)', 'D:(1,5)'),
#   ('C#:(1,b3)', 'G:min(4)', 'G:maj7'),
#   ('B:min', 'F', 'E:(1,5)'),
#   ('C/5', 'F#', 'C:sus4'),
#   ('F#', 'F', 'A:7/3'),
#   ('D/5', 'Bb', 'Eb'),
#   ('G:(1,b3,4)/b3', 'C:(1)', 'F#:min'),
#   ('G:7/b2', 'D:sus4(2)', 'C:(1)'),
#   ('B', 'C/3', 'C:(1)'),
#   ('D:7', 'G/5', 'Eb'),
#   ('G:7', 'A', 'E:min6'),
#   ('D:sus4', 'D/2', 'B:maj7'),
#   ('D', 'G/5', 'E:sus2(b7)'),
#   ('G/5', 'B:min7', 'A:7/3'),
#   ('G:7/2', 'C#:(1,b3)', 'E:sus4(2)'),
#   ('A:7/3', 'C#:hdim7', 'D:(1,5)'),
#   ('C', 'A/3', 'G:(1,b3,4)/b3'),
#   ('N', 'A:maj(*5)', 'E:maj6'),
#   ('B:min', 'D:sus4', 'F/5'),
#   ('C/5', 'C/3', 'G:maj7'),
#   ('N', 'G', 'A:sus4(2)'),
#   ('A:7', 'G:(1)', 'D/2'),
#   ('G:min', 'C:(1)', 'C:sus4'),
#   ('C:9(*3)', 'C:sus4', 'A:7/3'),
#   ('E/5', 'E:min', 'F/5'),
#   ('C', 'E:sus2(b7)', 'A:min7'),
#   ('G', 'E:min/3', 'C#'),
#   ('A:7', 'D:maj6', 'Ab'),
#   ('D:7', 'G:maj6', 'G/3'),
#   ('B:min', 'D:maj7', 'C:maj7'),
#   ('D:maj(9)', 'A:min/4', 'G/3'),
#   ('C/5', 'G:min(4)', 'E:maj6'),
#   ('G/5', 'Ab', 'E:(1,b7)/b7'),
#   ('E:(1)', 'C:7', 'A:min/4'),
#   ('E:(1)', 'E:sus2(b7)', 'E:maj6'),
#   ('C/3', 'G:min(4)', 'C#:hdim7'),
#   ('Bb', 'B:dim', 'C:maj(#4)/5'),
#   ('A:7', 'G:maj6', 'E:(1,b7)/b7'),
#   ('E/3', 'D/3', 'Ab:min'),
#   ('F', 'C:(1)', 'G/3'),
#   ('B', 'D/5', 'A:min'),
#   ('C/5', 'E:maj6', 'E:min/3'),
#   ('G:min/5', 'C:sus4', 'E:min'),
#   ('A:min', 'C#:dim/b3', 'A:min7'),
#   ('C', 'A:9', 'Eb:aug'),
#   ('E/3', 'C:(1)', 'Ab:min'),
#   ('G:7/2', 'B:dim', 'B:maj7'),
#   ('A/3', 'F#:dim/b3', 'Ab:min'),
#   ('C#:(1,b3)', 'G:min', 'G:min(4)'),
#   ('C', 'D/2', 'Eb:aug'),
#   ('C#:(1,b3)', 'C:(1)', 'B:maj7'),
#   ('G:7/2', 'F#:dim/b3', 'D/3'),
#   ('G:min', 'D/2', 'F#:min'),
#   ('G:7/2', 'E:(1,5)', 'G:maj7'),
#   ('G', 'E:(1,5)', 'C#:dim/b3'),
#   ('G#:hdim7', 'A:maj(*5)', 'Eb:aug'),
#   ('A:maj(*5)', 'Eb', 'F:min'),
#   ('C:sus4', 'C#', 'Ab:min'),
#   ('G:7/b3', 'C#:(1,b3)', 'C#:hdim7'),
#   ('G:7/b2', 'A:7/3', 'C#:hdim7'),
#   ('C:min', 'C#:hdim7', 'F#:min'),
#   ('D:7', 'G:min/5', 'C#:(1,b3)'),
#   ('E/3', 'A/3', 'E:maj6'),
#   ('G:7/2', 'A:9', 'B:dim'),
#   ('D:maj(9)', 'F/6', 'D:(1)'),
#   ('D:sus4(2)', 'D/2', 'C:maj7'),
#   ('E/5', 'D:maj6', 'Eb'),
#   ('G:min/5', 'F/5', 'C#'),
#   ('C#:(1,b3)', 'C#:(1,b3)/b3', 'D/3'),
#   ('C:(1)', 'A:min/4', 'A:(1)'),
#   ('D/2', 'D:(1,5)', 'B:maj7'),
#   ('B:min', 'C:9(*3)', 'B:dim'),
#   ('G#:hdim7', 'F#', 'A:min/4'),
#   ...},
#  '012': {('A:sus4(2)', 'B:min', 'C#:min'),
#   ('A:min', 'Ab', 'D'),
#   ('A:7', 'E', 'E:min/5'),
#   ('C:(1)', 'C:(1,5)', 'E:maj6'),
#   ('C#:(1,b3)/b3', 'E', 'E:(1,b7)/b7'),
#   ('E:maj6', 'E:sus2(b7)', 'G:min/5'),
#   ('D/5', 'E:7', 'N'),
#   ('F#/5', 'F/5', 'G:7/2'),
#   ('A', 'A:7', 'C:min'),
#   ('C#:dim/b3', 'D:maj6', 'E:(1)'),
#   ('A:7/3', 'F', 'G/3'),
#   ('A:min7', 'C/5', 'E/3'),
#   ('A', 'E:maj6', 'E:sus2(b7)'),
#   ('A:min7', 'D:sus4', 'F/6'),
#   ('E', 'E:(1)', 'E:9'),
#   ('C:maj7', 'E:(1,b7)/b7', 'G'),
#   ('A', 'A:7', 'G:maj6'),
#   ('D/5', 'E:min/5', 'G#:hdim7'),
#   ('C#:(1,b3)/b3', 'C:(1)', 'C:(1,5)'),
#   ('B', 'D:sus4', 'G'),
#   ('A:min/4', 'C/3', 'E:min'),
#   ('A:(1)', 'E:min', 'G'),
#   ('A:min/4', 'C', 'G:min'),
#   ('C:(1)', 'D', 'Eb'),
#   ('A:min', 'F/6', 'G/5'),
#   ('A:min', 'F', 'G:maj6'),
#   ('B:dim', 'E:min', 'F:min'),
#   ('D:sus4(2)', 'E:min/3', 'G/5'),
#   ('C#:(1,b3)/b3', 'G:min', 'N'),
#   ('A:min', 'C/5', 'E'),
#   ('C:maj7', 'G/5', 'G:min/5'),
#   ('A:min', 'Bb', 'C:sus4'),
#   ('E:min', 'Eb:aug', 'F#:min/5'),
#   ('C:maj7', 'G:7/2', 'G:7/b2'),
#   ('D:maj(9)', 'D:sus4', 'G:7/2'),
#   ('C#', 'E:min', 'F:min'),
#   ('F#:min/5', 'G:7', 'G:7/b2'),
#   ('D', 'E:9', 'G:7'),
#   ('C:9(*3)', 'E:sus2(b7)', 'F'),
#   ('C#', 'F#', 'G'),
#   ('C#:(1,b3)/b3', 'C/3', 'E:9'),
#   ('Bb', 'C#:min', 'G/5'),
#   ('A', 'E:(1)', 'E:sus4(2)'),
#   ('D:maj(9)', 'E:min/3', 'N'),
#   ('A', 'A:min7', 'E:sus4(2)'),
#   ('B:min7', 'C', 'G:7/b2'),
#   ('C#:(1,b3)', 'C:(1)', 'E:(1,b7)/b7'),
#   ('A:7/3', 'B', 'E:min/5'),
#   ('B:7', 'Eb', 'F'),
#   ('B:min', 'E:(1,5)', 'F#'),
#   ('A:sus4(2)', 'G:min', 'N'),
#   ('D', 'Eb', 'F#:dim/b3'),
#   ('B:maj7', 'C:7', 'N'),
#   ('B:min', 'B:min7', 'C#:hdim7'),
#   ('B:min7', 'E:min/5', 'F/5'),
#   ('A', 'D:min', 'E:maj6'),
#   ('A:(1)', 'B:7', 'C'),
#   ('C:min', 'E:min', 'Eb:aug'),
#   ('A:7', 'D:maj6', 'G'),
#   ('D', 'F', 'G:7/2'),
#   ('C/5', 'D/2', 'G:min'),
#   ('B', 'B:maj7', 'C/3'),
#   ('E:min', 'F', 'G:7/b3'),
#   ('C', 'G/5', 'G:min/5'),
#   ('D', 'D/3', 'D/5'),
#   ('A', 'B:maj7', 'F'),
#   ('D:sus4', 'F#:dim/b3', 'G'),
#   ('C:(1)', 'D:7', 'N'),
#   ('A:min7', 'B:min', 'D:maj6'),
#   ('D', 'D:sus4(2)', 'E/3'),
#   ('C', 'E', 'F:min'),
#   ('A:min7', 'Ab:min', 'D:sus4'),
#   ('D:min', 'G', 'G:min'),
#   ('A', 'A:7', 'Eb:aug'),
#   ('A', 'D:sus4', 'E:9'),
#   ('C#', 'Eb', 'G'),
#   ('Ab:min', 'D/5', 'G#:hdim7'),
#   ('B:dim', 'C', 'C:min'),
#   ('A:min', 'E/5', 'Eb'),
#   ('E:min/5', 'F#', 'G'),
#   ('C#:hdim7', 'E:(1,5)', 'E:(1,b7)/b7'),
#   ('C#:dim/b3', 'C:sus4', 'N'),
#   ('B:min7', 'E:sus2(b7)', 'G'),
#   ('C#:(1,b3)/b3', 'D/3', 'G:maj7'),
#   ('D:sus4', 'E:min/5', 'F/5'),
#   ('A:maj(*5)', 'F/6', 'N'),
#   ('F', 'G:7/b2', 'G:min(4)'),
#   ('D:maj(9)', 'D:sus4', 'F/5'),
#   ('A:(1)', 'C', 'G:min/5'),
#   ('D:7', 'D:maj7', 'G/3'),
#   ('Ab', 'C', 'F#'),
#   ('A:min/4', 'B', 'B:maj7'),
#   ('A:min7', 'D:sus4', 'G:maj6'),
#   ('A:(1)', 'D:maj7', 'N'),
#   ('A:(1)', 'C#:(1,b3)/b3', 'E'),
#   ('C:7', 'E/3', 'G'),
#   ('C:9(*3)', 'F', 'G:7/b3'),
#   ('A/3', 'A:maj(*5)', 'E:(1)'),
#   ('D:maj7', 'E:min', 'F:min'),
#   ('B:min7', 'E:(1,5)', 'N'),
#   ('D:(1,5)', 'E:min/5', 'N'),
#   ('A:min/4', 'C:min', 'G:min'),
#   ('A:min/4', 'D:maj6', 'E:(1)'),
#   ('C:7', 'F', 'N'),
#   ('C', 'D:min', 'F#:dim/b3'),
#   ('A:min', 'A:sus4(2)', 'E/5'),
#   ('C', 'D:min', 'G:min(4)'),
#   ('A:min', 'Bb', 'G:7'),
#   ('C', 'C#:(1,b3)/b3', 'C/5'),
#   ('D/3', 'D:maj(9)', 'G:maj7'),
#   ('Bb', 'C:7', 'Eb'),
#   ('C/3', 'D:7', 'G'),
#   ('A:min', 'E:(1,5)', 'N'),
#   ('C', 'C:sus4', 'E/5'),
#   ('A', 'A:min/4', 'G:7/b3'),
#   ('C:(1,5)', 'D', 'D/5'),
#   ('A', 'A:min/4', 'C:7'),
#   ('A:9', 'E', 'Eb'),
#   ('C:9(*3)', 'E:min/5', 'F'),
#   ('B', 'Bb', 'E:min'),
#   ('C#', 'D:maj(9)', 'D:sus4'),
#   ('C:maj(#4)/5', 'E', 'Eb'),
#   ('C', 'E:7', 'G:(1)'),
#   ('Ab', 'D', 'D/5'),
#   ('A:sus4(2)', 'C#:(1,b3)/b3', 'E'),
#   ('E:min', 'G', 'G:maj7'),
#   ('A:min7', 'B:min7', 'G/3'),
#   ('D:maj(9)', 'D:sus4', 'G#:hdim7'),
#   ('B:dim', 'C:7', 'G'),
#   ('A', 'A:7', 'D:maj7'),
#   ('C:9(*3)', 'E:min/5', 'G:min'),
#   ('B:dim', 'C', 'E:(1)'),
#   ('C', 'C#:(1,b3)', 'E:(1)'),
#   ('D/5', 'E:min', 'G#:hdim7'),
#   ('D/2', 'Eb', 'G'),
#   ('C:(1)', 'C:(1,5)', 'C:min'),
#   ('A:min', 'E:sus4(2)', 'G:min(4)'),
#   ('B:min', 'C/5', 'F/5'),
#   ('B:min', 'D', 'E:sus4(2)'),
#   ('C/5', 'D', 'D:maj7'),
#   ('C/3', 'C:7', 'C:maj7'),
#   ('D/2', 'D:(1)', 'N'),
#   ('G#:hdim7', 'G/5', 'G:min/5'),
#   ('E:min', 'F/6', 'F:min'),
#   ('E:min/5', 'F#', 'F/5'),
#   ('A:min', 'Bb', 'F#:min/5'),
#   ('C/3', 'C:maj7', 'E:sus4(2)'),
#   ('C', 'D/3', 'D/5'),
#   ('A', 'C#:dim/b3', 'D:min'),
#   ('A', 'C:maj(#4)/5', 'E:sus4(2)'),
#   ('Ab', 'F/6', 'G'),
#   ('C/3', 'E:min', 'F/5'),
#   ('B:min7', 'G', 'G:min/5'),
#   ('Bb', 'C#:min', 'E:(1)'),
#   ('A:min7', 'B:min7', 'C:sus4'),
#   ('A:7/3', 'C', 'G:(1)'),
#   ('E/5', 'E:maj6', 'G:7/b3'),
#   ('E:min', 'G', 'G:maj6'),
#   ('A:min', 'A:min7', 'D'),
#   ('D', 'D:maj7', 'E:maj6'),
#   ('F#:dim/b3', 'G/5', 'G:min/5'),
#   ('A/3', 'A:maj(*5)', 'B:maj7'),
#   ('Ab', 'G', 'G:7'),
#   ('A:7/3', 'D', 'D:maj(9)'),
#   ('F/6', 'G:maj6', 'N'),
#   ('E:9', 'G#:hdim7', 'G:min(4)'),
#   ('B:dim', 'C/5', 'F#:dim/b3'),
#   ('D/5', 'D:7', 'D:maj7'),
#   ('A:min', 'B:min7', 'G:min(4)'),
#   ('A', 'D:min', 'G:min(4)'),
#   ('D', 'E:(1,b7)/b7', 'Eb'),
#   ('C#:(1,b3)/b3', 'C/3', 'F:min'),
#   ('C:7', 'E:(1,5)', 'G'),
#   ('E', 'G:7', 'G:7/b2'),
#   ('C:9(*3)', 'C:sus4', 'N'),
#   ('A', 'D:min', 'F#:dim/b3'),
#   ('Bb', 'D:(1,5)', 'G:min'),
#   ('B:min', 'C/5', 'G:7/b3'),
#   ('D', 'E:(1,b7)/b7', 'F'),
#   ('A', 'A:min/4', 'E:(1,b7)/b7'),
#   ('D', 'D:maj(9)', 'E:min'),
#   ('A:min', 'C/5', 'G/5'),
#   ('B:maj7', 'E:maj6', 'N'),
#   ('E:min6', 'F', 'G:min(4)'),
#   ('C:(1)', 'E:7', 'E:maj6'),
#   ('D:min', 'G:7', 'N'),
#   ('D', 'E:7', 'E:9'),
#   ('A:min/4', 'C:min', 'E:min6'),
#   ('Ab', 'B:min', 'C/5'),
#   ('E', 'E:7', 'F#:min/5'),
#   ('A:9', 'D', 'F#:min'),
#   ('E:maj6', 'E:min', 'F'),
#   ('C:(1)', 'C:(1,5)', 'D:sus4'),
#   ('C', 'F#/5', 'G:(1)'),
#   ('B:min', 'C/5', 'E:sus2(b7)'),
#   ('A:min', 'F', 'F#/5'),
#   ('A:7', 'E', 'G:min'),
#   ('A:min/4', 'B:maj7', 'C:min'),
#   ('D:(1)', 'D:(1,5)', 'D:7'),
#   ('A:7/3', 'B:min', 'C/5'),
#   ('Bb', 'E', 'G:min'),
#   ('B:min', 'D/5', 'E/3'),
#   ('C:sus4', 'G/5', 'N'),
#   ('A', 'D:(1,5)', 'D:min'),
#   ('C#:min', 'F', 'G:min'),
#   ('E:7', 'G/5', 'N'),
#   ('A:7/3', 'E:9', 'G/3'),
#   ('Bb', 'G:7/b3', 'G:min'),
#   ('C:maj(#4)/5', 'G', 'G:min(4)'),
#   ('C#:dim/b3', 'E:min', 'G'),
#   ('B:dim', 'E:(1,b7)/b7', 'F#:dim/b3'),
#   ('B:maj7', 'C/5', 'G:min'),
#   ('D:maj6', 'E:(1)', 'Eb'),
#   ('D:7', 'G:min', 'G:min/5'),
#   ('A', 'E/5', 'G:7'),
#   ('Bb', 'D:maj7', 'N'),
#   ('A', 'C#:(1,b3)/b3', 'F'),
#   ('C/5', 'Eb', 'G:min'),
#   ('C#', 'G/5', 'G:min/5'),
#   ('A:min', 'E:min', 'G:min'),
#   ('D', 'D/2', 'E/5'),
#   ('C:maj(#4)/5', 'Eb', 'F'),
#   ('B:min', 'E:7', 'G:7/b3'),
#   ('D', 'E:min6', 'F/6'),
#   ('C', 'C#:(1,b3)', 'E:sus4(2)'),
#   ('D/5', 'E', 'G:(1,b3,4)/b3'),
#   ('C', 'C:(1)', 'G:7/2'),
#   ('D/5', 'E', 'E:maj6'),
#   ('B:maj7', 'F', 'F#'),
#   ('D', 'G:7/2', 'G:maj6'),
#   ('C#:(1,b3)/b3', 'C/3', 'E:sus2(b7)'),
#   ('E', 'E/3', 'E:(1)'),
#   ('A:min7', 'B:maj7', 'C/5'),
#   ('A:7/3', 'C#:hdim7', 'G/3'),
#   ('C#:hdim7', 'C:min', 'G'),
#   ('C#', 'E', 'Eb'),
#   ('B:min7', 'E:7', 'E:maj6'),
#   ('A', 'A:7', 'C#:hdim7'),
#   ('A/3', 'C:min', 'E'),
#   ('D:sus4', 'E:min/3', 'N'),
#   ('C:9(*3)', 'E:(1)', 'N'),
#   ('Bb', 'C#:min', 'D/2'),
#   ('F#/5', 'F/5', 'N'),
#   ('A/3', 'A:maj(*5)', 'B'),
#   ('B:min', 'C/3', 'E:7'),
#   ('A', 'Ab', 'C/5'),
#   ('A:maj(*5)', 'E:(1,5)', 'E:(1,b7)/b7'),
#   ('C:(1,5)', 'C:sus4', 'G:maj7'),
#   ('A:(1)', 'F', 'G'),
#   ('E:sus2(b7)', 'F#:dim/b3', 'G'),
#   ('A:sus4(2)', 'D', 'E:9'),
#   ('D:maj(9)', 'D:sus4', 'F:min'),
#   ('Eb:aug', 'F', 'G/5'),
#   ('E:min', 'E:min6', 'F:min'),
#   ('A:min', 'E:maj6', 'E:sus2(b7)'),
#   ('B', 'E:min', 'F/5'),
#   ('E:(1,5)', 'F#/5', 'N'),
#   ('C:(1)', 'Eb:aug', 'G/5'),
#   ('C#:(1,b3)/b3', 'E:(1,5)', 'E:(1,b7)/b7'),
#   ('A:min', 'D', 'G/3'),
#   ('D:(1)', 'E/5', 'N'),
#   ('C#', 'C/5', 'D/3'),
#   ('C#', 'F', 'G'),
#   ('A:min7', 'B:min7', 'D:sus4(2)'),
#   ('C:(1)', 'C:(1,5)', 'D:7'),
#   ('C:maj(#4)/5', 'G:7/2', 'G:7/b3'),
#   ('A', 'D/3', 'F'),
#   ('B', 'D:(1,5)', 'E:min'),
#   ('D:(1)', 'E:min/5', 'F/5'),
#   ('A:min', 'D:maj6', 'E:(1)'),
#   ('A:min', 'C/5', 'D:maj7'),
#   ('F#', 'G', 'G:min(4)'),
#   ('B:maj7', 'C:min', 'G'),
#   ('A:min', 'D/2', 'D/3'),
#   ('D:sus4', 'E:(1)', 'N'),
#   ('B:min', 'C#:(1,b3)', 'E:7'),
#   ('A:min', 'D', 'D:7'),
#   ('A:7/3', 'A:9', 'D'),
#   ('C:(1)', 'C:(1,5)', 'G/5'),
#   ('D:maj6', 'D:sus4', 'N'),
#   ('C', 'D:maj6', 'G:min'),
#   ('C/3', 'Eb', 'F'),
#   ('Eb:aug', 'F', 'G:min(4)'),
#   ('A', 'A:7', 'G:(1,b3,4)/b3'),
#   ('C/5', 'C:maj(#4)/5', 'G:min'),
#   ('C:9(*3)', 'C:maj7', 'G:min'),
#   ('A:sus4(2)', 'F', 'G'),
#   ('C', 'G:(1)', 'G:min(4)'),
#   ('B:min', 'C#:min', 'E:sus2(b7)'),
#   ('A:min', 'D', 'D/3'),
#   ('D:(1)', 'D:maj6', 'E:(1)'),
#   ('A:7/3', 'D', 'G/3'),
#   ('Bb', 'D:sus4', 'G:min'),
#   ('A:min', 'B:7', 'D'),
#   ('B:maj7', 'E', 'E:7'),
#   ('A', 'E:9', 'E:sus2(b7)'),
#   ('F#:dim/b3', 'F/6', 'G'),
#   ('B', 'B:maj7', 'C:7'),
#   ('C:9(*3)', 'D/2', 'F'),
#   ('C:sus4', 'D', 'G:maj7'),
#   ('Ab', 'E', 'E:sus2(b7)'),
#   ('Bb', 'C:maj7', 'G'),
#   ('B:min', 'E:min/3', 'G:7/b3'),
#   ('A:sus4(2)', 'Bb', 'C#:min'),
#   ('C:(1)', 'C:(1,5)', 'G:(1)'),
#   ('A:min7', 'B:min7', 'D:(1,5)'),
#   ('B:min', 'D/5', 'D:7'),
#   ('C#:(1,b3)/b3', 'E', 'F/6'),
#   ('D:sus4(2)', 'F#', 'G/5'),
#   ('A:min', 'D:maj6', 'F'),
#   ('C', 'E', 'G#:hdim7'),
#   ('A:min', 'C', 'C:min'),
#   ('B:min', 'D/5', 'E:maj6'),
#   ('C:(1)', 'D', 'F'),
#   ('B:maj7', 'F/6', 'N'),
#   ('E:min', 'G/5', 'N'),
#   ('A:7/3', 'C/5', 'G:7/b2'),
#   ('B:maj7', 'F', 'G:min'),
#   ('E:min/3', 'F#:min', 'N'),
#   ('D:maj6', 'G:7', 'G:7/b2'),
#   ('A:maj(*5)', 'C', 'D/3'),
#   ('F', 'G:7', 'G:min/5'),
#   ('C:7', 'D:(1,5)', 'G'),
#   ('C/3', 'E', 'E:7'),
#   ('F#/5', 'G', 'G:(1)'),
#   ('E:9', 'F#:min/5', 'G#:hdim7'),
#   ('D:sus4', 'E:7', 'E:maj6'),
#   ('A:min7', 'D:sus4', 'E:min/3'),
#   ('G/5', 'G:7/2', 'G:7/b2'),
#   ('A:(1)', 'F#', 'G'),
#   ('A:maj(*5)', 'B:min', 'D'),
#   ('C', 'D:maj(9)', 'F#'),
#   ('E:7', 'E:maj6', 'G:7/2'),
#   ('A:min7', 'B:maj7', 'B:min'),
#   ('D:maj6', 'F#:min', 'G'),
#   ('C:(1,5)', 'C:sus4', 'Eb'),
#   ('C#:(1,b3)/b3', 'F', 'G:min(4)'),
#   ('A:min7', 'F', 'G:min/5'),
#   ('D:7', 'G:(1)', 'N'),
#   ('D', 'D/5', 'E/3'),
#   ('A:min', 'Bb', 'D:sus4(2)'),
#   ('E/5', 'F#:min', 'G:7/b3'),
#   ('E:min/3', 'G:7/b3', 'N'),
#   ('C/3', 'G/5', 'G:min/5'),
#   ('A:7', 'D/2', 'D/3'),
#   ('B', 'B:maj7', 'G:(1)'),
#   ('C/5', 'D/3', 'G:maj6'),
#   ('C:sus4', 'E:maj6', 'N'),
#   ('C#:min', 'D/3', 'G:maj7'),
#   ('D:maj(9)', 'F:min', 'N'),
#   ('B:min', 'C', 'F/6'),
#   ('F/6', 'G#:hdim7', 'G/5'),
#   ('F#/5', 'F/5', 'G:maj6'),
#   ('B:min7', 'C#:(1,b3)/b3', 'C/3'),
#   ('A:sus4(2)', 'D/5', 'E'),
#   ('A:maj(*5)', 'F#:min', 'N'),
#   ('C/3', 'E:9', 'G#:hdim7'),
#   ('C#:(1,b3)', 'E:(1,b7)/b7', 'F:min'),
#   ('A:min', 'Ab:min', 'C'),
#   ('C:maj7', 'G', 'G#:hdim7'),
#   ('B:min', 'B:min7', 'F:min'),
#   ('D', 'Eb', 'F#'),
#   ('E:(1,5)', 'E:(1,b7)/b7', 'E:min'),
#   ('C:min', 'E', 'E:7'),
#   ('B:min', 'D', 'F:min'),
#   ('A:7/3', 'G:7/2', 'G:7/b3'),
#   ('E', 'E/5', 'E:maj6'),
#   ('B:min', 'C#:hdim7', 'E:7'),
#   ('Ab:min', 'F', 'G:min/5'),
#   ('A:(1)', 'Eb:aug', 'N'),
#   ('B:maj7', 'D:maj6', 'E:(1)'),
#   ('C/5', 'E', 'E:9'),
#   ('D:(1)', 'E:min/5', 'N'),
#   ('C:9(*3)', 'D:(1)', 'D:(1,5)'),
#   ('B:maj7', 'D/3', 'N'),
#   ('A', 'Ab', 'G:7/b3'),
#   ('B:min', 'E:7', 'G:7'),
#   ('A:7/3', 'G:min', 'G:min/5'),
#   ('E/5', 'G:7', 'G:7/b3'),
#   ('D', 'D:(1,5)', 'D:maj(9)'),
#   ('E:9', 'Eb', 'G'),
#   ('A/3', 'D:(1)', 'N'),
#   ('C:(1)', 'F', 'G:min(4)'),
#   ('A:min', 'G/5', 'G:min(4)'),
#   ('B:min7', 'Eb:aug', 'G'),
#   ('E:(1,5)', 'E:min', 'G'),
#   ('A:min', 'C/5', 'G/3'),
#   ('Bb', 'C#:min', 'G:(1)'),
#   ('A:min', 'E:(1)', 'N'),
#   ('D/3', 'Eb:aug', 'G'),
#   ('C:min', 'G:7/2', 'G:7/b2'),
#   ('A', 'E/3', 'E:min/5'),
#   ('Ab', 'B', 'B:maj7'),
#   ('A:7/3', 'Ab:min', 'E:min/5'),
#   ('B', 'B:maj7', 'C#:hdim7'),
#   ('A', 'C:maj7', 'E:9'),
#   ('B:min', 'B:min7', 'C#:(1,b3)'),
#   ('B:min', 'C:(1,5)', 'D/5'),
#   ('C:(1,5)', 'C:sus4', 'D:sus4'),
#   ('A', 'E/5', 'G:min/5'),
#   ('D', 'E:min/5', 'F/6'),
#   ('Ab:min', 'D', 'E:9'),
#   ('E:(1)', 'G:(1)', 'N'),
#   ('A', 'A:min/4', 'C:(1)'),
#   ('A:min', 'D/5', 'G:min(4)'),
#   ('C:sus4', 'D', 'D:maj(9)'),
#   ('A:min', 'C', 'C#'),
#   ('C', 'C:(1)', 'E:7'),
#   ('Bb', 'E:sus4(2)', 'G:min'),
#   ('B:min', 'E/5', 'E:min6'),
#   ('D', 'D:(1)', 'D:maj(9)'),
#   ('A', 'A:min', 'E:(1,b7)/b7'),
#   ('A:7/3', 'D', 'D:sus4(2)'),
#   ('A:min7', 'B:min', 'C:(1)'),
#   ('C/3', 'C:maj7', 'D/3'),
#   ('B', 'C', 'C:7'),
#   ('Bb', 'E:(1,5)', 'E:(1,b7)/b7'),
#   ('E:min', 'F/5', 'F:min'),
#   ('C#', 'E:min', 'N'),
#   ('C#:hdim7', 'C:maj7', 'G'),
#   ('A/3', 'A:min', 'E'),
#   ('Eb', 'F', 'G:7/2'),
#   ('A', 'A:min', 'C#:dim/b3'),
#   ('C', 'G:7/2', 'G:7/b2'),
#   ('C#:dim/b3', 'E:7', 'E:maj6'),
#   ('C', 'D/3', 'G/3'),
#   ('B:min7', 'E:min/5', 'G'),
#   ('B', 'D', 'E:maj6'),
#   ('B:dim', 'Eb:aug', 'G/5'),
#   ('A:sus4(2)', 'C', 'G:min'),
#   ('Bb', 'E:min/3', 'G:min'),
#   ('B:dim', 'Eb', 'F'),
#   ('C:(1)', 'F:min', 'N'),
#   ('F#:dim/b3', 'F#:min', 'G'),
#   ('A:min', 'D', 'D:(1,5)'),
#   ('C:(1,5)', 'E:min6', 'N'),
#   ('A', 'C#:min', 'F'),
#   ('C', 'D:min', 'E:(1)'),
#   ('F#:dim/b3', 'G', 'G:maj7'),
#   ('E:min/5', 'F/5', 'G:(1,b3,4)/b3'),
#   ('D', 'E:min/3', 'F'),
#   ('A:min7', 'B:min', 'F:min'),
#   ('D:maj(9)', 'E', 'E/3'),
#   ('B:min7', 'E/5', 'G'),
#   ('A:min', 'E:sus2(b7)', 'G:min'),
#   ('C/3', 'E:7', 'E:min'),
#   ('D/5', 'E', 'G:min'),
#   ('D/5', 'D:maj(9)', 'E'),
#   ('E/5', 'F#/5', 'G:7/b3'),
#   ('C:sus4', 'D', 'G:min/5'),
#   ('B:min', 'C/5', 'E:(1,5)'),
#   ('A:(1)', 'D/2', 'D/3'),
#   ('C/3', 'C/5', 'D/3'),
#   ('D:sus4(2)', 'G:7', 'G:7/b2'),
#   ('A:7/3', 'A:min', 'E/5'),
#   ('C', 'D/2', 'E'),
#   ('C:(1)', 'D:maj6', 'E:(1)'),
#   ('D/5', 'G#:hdim7', 'N'),
#   ('D', 'G:(1)', 'G:maj7'),
#   ('D:(1)', 'G:min/5', 'N'),
#   ('B:min', 'C/5', 'E/3'),
#   ('D:sus4(2)', 'E:7', 'E:maj6'),
#   ('C/3', 'G', 'G:(1,b3,4)/b3'),
#   ('G/3', 'G:maj6', 'N'),
#   ('A:9', 'B:maj7', 'D'),
#   ('C:sus4', 'F#/5', 'G'),
#   ('B', 'E:min', 'G/3'),
#   ('C:(1,5)', 'C:sus4', 'G:min/5'),
#   ('A:maj(*5)', 'C/3', 'N'),
#   ('B:7', 'B:min', 'E:7'),
#   ('A', 'C', 'G:min(4)'),
#   ('A:(1)', 'A:min', 'Bb'),
#   ('A:7/3', 'C#:min', 'E:min/5'),
#   ('B:min', 'E:min/3', 'E:sus2(b7)'),
#   ('B', 'D', 'G:7'),
#   ('C/3', 'C:maj7', 'F#/5'),
#   ('A:min', 'Bb', 'G:7/b2'),
#   ('C', 'D/3', 'G:7/2'),
#   ('C:(1)', 'D', 'N'),
#   ('B:min', 'D/5', 'D:(1,5)'),
#   ('D', 'D:maj(9)', 'F#:dim/b3'),
#   ('D/2', 'D/3', 'Eb:aug'),
#   ('B:min', 'C#:(1,b3)/b3', 'D/5'),
#   ('B:min', 'E:(1,b7)/b7', 'E:min/3'),
#   ('A:sus4(2)', 'C#:hdim7', 'G/5'),
#   ('A/3', 'E:min/3', 'N'),
#   ('D', 'D:maj7', 'G:7/b3'),
#   ('Bb', 'C#:min', 'G:min(4)'),
#   ('C/5', 'C:7', 'G:min'),
#   ('Ab:min', 'B', 'B:min'),
#   ('C:9(*3)', 'C:maj(#4)/5', 'G:min'),
#   ('C', 'C#:min', 'F#'),
#   ('C#:(1,b3)', 'E:min6', 'N'),
#   ('C', 'D:7', 'E/5'),
#   ('D', 'D/3', 'N'),
#   ('F#:dim/b3', 'G', 'G/5'),
#   ('Ab:min', 'B:min', 'G'),
#   ('C:min', 'D:7', 'D:maj7'),
#   ('A:min', 'Bb', 'D/3'),
#   ('A', 'B:7', 'E:9'),
#   ('A:7', 'D:maj(9)', 'D:sus4'),
#   ('A', 'Ab', 'G:(1,b3,4)/b3'),
#   ('C#:hdim7', 'E:(1,5)', 'G/5'),
#   ('A:7/3', 'B', 'D'),
#   ('Ab', 'E:min/5', 'F/5'),
#   ('A/3', 'A:maj(*5)', 'B:min'),
#   ('Ab', 'C', 'D/3'),
#   ('A', 'C/5', 'D/3'),
#   ('B:dim', 'F#:dim/b3', 'G:7'),
#   ('B:min', 'E:(1,5)', 'G'),
#   ('D:(1)', 'D:(1,5)', 'G:(1,b3,4)/b3'),
#   ('C:maj(#4)/5', 'E:9', 'G#:hdim7'),
#   ('A:7/3', 'Eb', 'G/3'),
#   ('C:maj7', 'E:(1)', 'G'),
#   ('Bb', 'D:maj(9)', 'N'),
#   ('G/5', 'G:7', 'G:7/b2'),
#   ('C', 'C/5', 'G:7/2'),
#   ('E/3', 'F/6', 'G/5'),
#   ('B', 'D', 'F#:min/5'),
#   ('C:(1,5)', 'D', 'N'),
#   ('E', 'E:sus4(2)', 'Eb:aug'),
#   ('C:maj7', 'E:maj6', 'G'),
#   ('A:maj(*5)', 'E/5', 'G:7/b3'),
#   ('C', 'Eb:aug', 'F#'),
#   ('B:min', 'C/5', 'C:9(*3)'),
#   ('D:(1)', 'E:(1,5)', 'E:(1,b7)/b7'),
#   ('G/3', 'G/5', 'G:min/5'),
#   ('D:min', 'E:min/5', 'G'),
#   ('C:(1,5)', 'C:sus4', 'F:min'),
#   ('C/3', 'G:7', 'G:7/b2'),
#   ('D:maj7', 'F#', 'G'),
#   ('A:min', 'Bb', 'C#'),
#   ('B', 'C#:hdim7', 'E:min'),
#   ('A:min', 'F#/5', 'G:min(4)'),
#   ('B', 'G', 'G:min(4)'),
#   ('B:min', 'E:min6', 'Eb'),
#   ('Ab:min', 'G/5', 'G:min/5'),
#   ('A', 'D:maj(9)', 'E:9'),
#   ('C#:hdim7', 'C:7', 'F#/5'),
#   ('G:7/2', 'G:7/b3', 'G:min/5'),
#   ('A:7', 'D:min', 'G'),
#   ('D:sus4(2)', 'E:(1)', 'N'),
#   ('D:min', 'E', 'E:9'),
#   ('C/5', 'D/3', 'E:min/5'),
#   ('A', 'E/3', 'E:sus2(b7)'),
#   ('C#:(1,b3)', 'E:(1,b7)/b7', 'Eb'),
#   ('C', 'C#:min', 'C:(1)'),
#   ('B:min', 'C/5', 'E:(1,b7)/b7'),
#   ('A:9', 'C', 'C:7'),
#   ('D', 'G/3', 'G:min/5'),
#   ('C:(1)', 'G:7/2', 'G:7/b3'),
#   ('A/3', 'B', 'D'),
#   ('B:min', 'B:min7', 'G:maj7'),
#   ('A:maj(*5)', 'C/5', 'D/3'),
#   ('E:(1,5)', 'F#:dim/b3', 'G'),
#   ('D:maj(9)', 'Eb:aug', 'G/5'),
#   ('B:min', 'D', 'G:7/b3'),
# ...
#   ('Eb', 'F:min', 'N'),
#   ('Eb', 'G:maj6', 'N'),
#   ('F:min', 'G', 'N'),
#   ('G', 'G/3', 'N'),
#   ('G', 'G:maj6', 'N'),
#   ('G:(1,b3,4)/b3', 'G:min', 'N')},
#  '111U': {('A', 'A/3', 'E'),
#   ('A', 'A:7', 'D:7'),
#   ('A', 'A:9', 'G'),
#   ('A', 'A:min', 'B:min'),
#   ('A', 'A:min/4', 'A:sus4(2)'),
#   ('A', 'A:min/4', 'D'),
#   ('A', 'A:min/4', 'D/5'),
#   ('A', 'A:min/4', 'E'),
#   ('A', 'A:min/4', 'E:7'),
#   ('A', 'A:min/4', 'F#'),
#   ('A', 'A:min/4', 'G'),
#   ('A', 'A:min/4', 'G:(1)'),
#   ('A', 'A:min/4', 'N'),
#   ('A', 'A:sus4(2)', 'Ab'),
#   ('A', 'A:sus4(2)', 'D:min'),
#   ('A', 'A:sus4(2)', 'E/5'),
#   ('A', 'A:sus4(2)', 'E:sus4(2)'),
#   ('A', 'A:sus4(2)', 'F'),
#   ('A', 'Ab', 'D'),
#   ('A', 'Ab', 'D/5'),
#   ('A', 'Ab', 'E'),
#   ('A', 'Ab', 'E:7'),
#   ('A', 'Ab', 'F#'),
#   ('A', 'Ab', 'G:(1)'),
#   ('A', 'Ab', 'N'),
#   ('A', 'B', 'D'),
#   ('A', 'B', 'G'),
#   ('A', 'B:maj7', 'E:min'),
#   ('A', 'B:min', 'D'),
#   ('A', 'B:min', 'E:7'),
#   ('A', 'B:min', 'E:min'),
#   ('A', 'B:min', 'F#'),
#   ('A', 'B:min7', 'G'),
#   ('A', 'Bb', 'C'),
#   ('A', 'C', 'G:7'),
#   ('A', 'C#:(1,b3)/b3', 'E'),
#   ('A', 'D', 'D/2'),
#   ('A', 'D', 'D:maj7'),
#   ('A', 'D', 'D:min'),
#   ('A', 'D', 'D:sus4(2)'),
#   ('A', 'D', 'E/5'),
#   ('A', 'D', 'E:sus4(2)'),
#   ('A', 'D', 'F/6'),
#   ('A', 'D', 'G:maj6'),
#   ('A', 'D', 'G:maj7'),
#   ('A', 'D/5', 'D:min'),
#   ('A', 'D/5', 'E/5'),
#   ('A', 'D/5', 'E:sus4(2)'),
#   ('A', 'D/5', 'F'),
#   ('A', 'D/5', 'G#:hdim7'),
#   ('A', 'D:(1)', 'N'),
#   ('A', 'D:maj6', 'G'),
#   ('A', 'D:min', 'E'),
#   ('A', 'D:min', 'E:7'),
#   ('A', 'D:min', 'F#'),
#   ('A', 'D:min', 'G:(1)'),
#   ('A', 'E', 'E:sus2(b7)'),
#   ('A', 'E', 'F'),
#   ('A', 'E/5', 'E:7'),
#   ('A', 'E/5', 'F#'),
#   ('A', 'E/5', 'G'),
#   ('A', 'E/5', 'G:(1)'),
#   ('A', 'E/5', 'N'),
#   ('A', 'E:(1,5)', 'N'),
#   ('A', 'E:7', 'E:sus4(2)'),
#   ('A', 'E:7', 'F'),
#   ('A', 'E:min/3', 'N'),
#   ('A', 'E:min6', 'N'),
#   ('A', 'E:sus4(2)', 'F#'),
#   ('A', 'E:sus4(2)', 'G'),
#   ('A', 'E:sus4(2)', 'G:(1)'),
#   ('A', 'E:sus4(2)', 'N'),
#   ('A', 'Eb', 'G'),
#   ('A', 'F', 'G:(1)'),
#   ('A', 'F#/5', 'G'),
#   ('A', 'F#:dim/b3', 'G'),
#   ('A', 'G:maj7', 'N'),
#   ('A', 'G:min', 'N'),
#   ('A/3', 'B', 'E'),
#   ('A/3', 'B:7', 'E'),
#   ('A/3', 'B:min', 'E'),
#   ('A/3', 'D', 'E'),
#   ('A/3', 'E', 'F#'),
#   ('A/3', 'E', 'G'),
#   ('A/3', 'E', 'N'),
#   ('A:(1)', 'Bb', 'C'),
#   ('A:(1)', 'C', 'D'),
#   ('A:(1)', 'C', 'E:min'),
#   ('A:(1)', 'C', 'F'),
#   ('A:(1)', 'C', 'G'),
#   ('A:(1)', 'C', 'G:7'),
#   ('A:7', 'B', 'E'),
#   ('A:7', 'B:7', 'E'),
#   ('A:7', 'B:min', 'E'),
#   ('A:7', 'B:min', 'E:7'),
#   ('A:7', 'D', 'E'),
#   ('A:7', 'D', 'N'),
#   ('A:7', 'D:(1)', 'N'),
#   ('A:7', 'D:min', 'N'),
#   ('A:7', 'E', 'F#'),
#   ('A:7', 'E', 'G'),
#   ('A:7', 'E:(1,5)', 'N'),
#   ('A:7', 'E:9', 'N'),
#   ('A:7', 'E:min', 'N'),
#   ('A:7', 'E:min/3', 'N'),
#   ('A:7', 'E:min6', 'N'),
#   ('A:7', 'F', 'N'),
#   ('A:7', 'G:maj7', 'N'),
#   ('A:7', 'G:min', 'N'),
#   ('A:9', 'C', 'G'),
#   ('A:9', 'C/5', 'G'),
#   ('A:9', 'E', 'G'),
#   ('A:9', 'G', 'N'),
#   ('A:min', 'B', 'B:min'),
#   ('A:min', 'B:min', 'B:min7'),
#   ('A:min', 'B:min', 'D/5'),
#   ('A:min', 'B:min', 'F'),
#   ('A:min', 'B:min', 'G:min'),
#   ('A:min', 'B:min', 'G:min(4)'),
#   ('A:min', 'E', 'G'),
#   ('A:min', 'G', 'N'),
#   ('Ab:min', 'D', 'N'),
#   ('Ab:min', 'D:(1)', 'N'),
#   ('Ab:min', 'D:min', 'N'),
#   ('Ab:min', 'E:(1,5)', 'N'),
#   ('Ab:min', 'E:7', 'N'),
#   ('Ab:min', 'E:9', 'N'),
#   ('Ab:min', 'E:min', 'N'),
#   ('Ab:min', 'E:min/3', 'N'),
#   ('Ab:min', 'E:min6', 'N'),
#   ('Ab:min', 'F', 'N'),
#   ('Ab:min', 'G:maj7', 'N'),
#   ('Ab:min', 'G:min', 'N'),
#   ('B', 'B:maj7', 'E'),
#   ('B', 'B:min', 'C#'),
#   ('B', 'B:min', 'F#:min'),
#   ('B', 'B:min', 'F#:min/5'),
#   ('B', 'C', 'D'),
#   ('B', 'C', 'E'),
#   ('B', 'C', 'G'),
#   ('B', 'C#:(1,b3)/b3', 'E'),
#   ('B', 'C/5', 'G'),
#   ('B', 'D', 'D:sus4'),
#   ('B', 'D', 'G/5'),
#   ('B', 'D:(1)', 'N'),
#   ('B', 'D:min', 'N'),
#   ('B', 'E', 'E/3'),
#   ('B', 'E', 'E:min'),
#   ('B', 'E', 'E:sus2(b7)'),
#   ('B', 'E:(1,5)', 'N'),
#   ('B', 'E:7', 'N'),
#   ('B', 'E:9', 'N'),
#   ('B', 'E:min/3', 'N'),
#   ('B', 'E:min6', 'N'),
#   ('B', 'F', 'N'),
#   ('B', 'G:maj7', 'N'),
#   ('B', 'G:min', 'N'),
#   ('B:7', 'C', 'E'),
#   ('B:7', 'C#:(1,b3)/b3', 'E'),
#   ('B:7', 'E', 'E/3'),
#   ('B:7', 'E', 'E:sus2(b7)'),
#   ('B:maj7', 'C/3', 'E:min'),
#   ('B:maj7', 'E:min', 'Eb:aug'),
#   ('B:maj7', 'E:min', 'F:min'),
#   ('B:min', 'B:min7', 'C#'),
#   ('B:min', 'B:min7', 'E'),
#   ('B:min', 'B:min7', 'E:min'),
#   ('B:min', 'B:min7', 'F#:min'),
#   ('B:min', 'B:min7', 'F#:min/5'),
#   ('B:min', 'B:min7', 'N'),
#   ('B:min', 'C', 'C#'),
#   ('B:min', 'C', 'F#:min'),
#   ('B:min', 'C', 'F#:min/5'),
#   ('B:min', 'C#', 'D/5'),
#   ('B:min', 'C#', 'G'),
#   ('B:min', 'C#:(1,b3)/b3', 'E'),
#   ('B:min', 'C/3', 'E:min'),
#   ('B:min', 'C/5', 'G:maj7'),
#   ('B:min', 'D', 'D:sus4'),
#   ('B:min', 'D', 'G/5'),
#   ('B:min', 'D/5', 'E:min'),
#   ('B:min', 'D/5', 'F#:min'),
#   ('B:min', 'D/5', 'F#:min/5'),
#   ('B:min', 'D/5', 'N'),
#   ('B:min', 'D:(1)', 'N'),
#   ('B:min', 'D:min', 'N'),
#   ('B:min', 'E', 'E/3'),
#   ('B:min', 'E', 'E:sus2(b7)'),
#   ('B:min', 'E:(1,5)', 'N'),
#   ('B:min', 'E:9', 'N'),
#   ('B:min', 'E:min', 'Eb:aug'),
#   ('B:min', 'E:min', 'F:min'),
#   ('B:min', 'F', 'N'),
#   ('B:min', 'F#:min', 'G'),
#   ('B:min', 'F#:min/5', 'G'),
#   ('B:min', 'G:maj7', 'N'),
#   ('B:min', 'G:min', 'N'),
#   ('B:min7', 'C/5', 'G'),
#   ('B:min7', 'D', 'G'),
#   ('B:min7', 'E', 'G'),
#   ('B:min7', 'G', 'N'),
#   ('Bb', 'C', 'C/5'),
#   ('Bb', 'C', 'C:(1)'),
#   ('Bb', 'C', 'E/5'),
#   ('Bb', 'D', 'F'),
#   ('Bb', 'E:min', 'F'),
#   ('Bb', 'Eb', 'F'),
#   ('Bb', 'F', 'G'),
#   ('Bb', 'G:(1,b3,4)/b3', 'G:min'),
#   ('C', 'C/3', 'E:min'),
#   ('C', 'C/5', 'D'),
#   ('C', 'C/5', 'E:min'),
#   ('C', 'C/5', 'F'),
#   ('C', 'C/5', 'G:7'),
#   ('C', 'C/5', 'N'),
#   ('C', 'C:(1)', 'D'),
#   ('C', 'C:(1)', 'E:min'),
#   ('C', 'C:(1)', 'F'),
#   ('C', 'C:(1)', 'G'),
#   ('C', 'C:(1)', 'G:7'),
#   ('C', 'C:(1)', 'N'),
#   ('C', 'C:7', 'D'),
#   ('C', 'C:7', 'E:min'),
#   ('C', 'C:7', 'F'),
#   ('C', 'C:7', 'G:7'),
#   ('C', 'C:7', 'N'),
#   ('C', 'D', 'D/2'),
#   ('C', 'D', 'D:maj7'),
#   ('C', 'D', 'D:sus4(2)'),
#   ('C', 'D', 'E/5'),
#   ('C', 'D', 'F/6'),
#   ('C', 'D', 'G:maj6'),
#   ('C', 'D', 'G:maj7'),
#   ('C', 'D', 'G:min'),
#   ('C', 'D:(1)', 'N'),
#   ('C', 'D:maj6', 'G'),
#   ('C', 'E/5', 'E:min'),
#   ('C', 'E/5', 'F'),
#   ('C', 'E/5', 'G'),
#   ('C', 'E/5', 'G:7'),
#   ('C', 'E/5', 'N'),
#   ('C', 'E:(1,5)', 'N'),
#   ('C', 'E:7', 'N'),
#   ('C', 'E:9', 'N'),
#   ('C', 'E:min', 'Eb:aug'),
#   ('C', 'E:min', 'F:min'),
#   ('C', 'E:min', 'G:min'),
#   ('C', 'E:min/3', 'N'),
#   ('C', 'E:min6', 'N'),
#   ('C', 'Eb', 'F'),
#   ('C', 'Eb', 'G'),
#   ('C', 'F#/5', 'G'),
#   ('C', 'F#:dim/b3', 'G'),
#   ('C', 'G', 'G:min'),
#   ('C', 'G:7', 'G:7/b2'),
#   ('C', 'G:7', 'G:min'),
#   ('C', 'G:maj7', 'N'),
#   ('C#:(1,b3)/b3', 'D', 'E'),
#   ('C#:(1,b3)/b3', 'E', 'F#'),
#   ('C#:(1,b3)/b3', 'E', 'G'),
#   ('C#:(1,b3)/b3', 'E', 'N'),
#   ('C#:dim/b3', 'C/3', 'C:maj7'),
#   ('C#:dim/b3', 'C/3', 'G'),
#   ('C#:hdim7', 'D', 'G/5'),
#   ('C#:hdim7', 'D:7', 'G/5'),
#   ('C#:min', 'D', 'N'),
#   ('C#:min', 'D:(1)', 'N'),
#   ('C#:min', 'D:min', 'N'),
#   ('C#:min', 'E:(1,5)', 'N'),
#   ('C#:min', 'E:7', 'N'),
#   ('C#:min', 'E:9', 'N'),
#   ('C#:min', 'E:min', 'N'),
#   ('C#:min', 'E:min/3', 'N'),
#   ('C#:min', 'E:min6', 'N'),
#   ('C#:min', 'F', 'N'),
#   ('C#:min', 'G:maj7', 'N'),
#   ('C#:min', 'G:min', 'N'),
#   ('C/5', 'D:maj6', 'G'),
#   ('C/5', 'E:min', 'G'),
#   ('C/5', 'Eb', 'G'),
#   ('C/5', 'F#', 'G'),
#   ('C/5', 'F#/5', 'G'),
#   ('C/5', 'F#:dim/b3', 'G'),
#   ('C/5', 'G', 'G:7/b2'),
#   ('C/5', 'G', 'G:min'),
#   ('C/5', 'G:7/b2', 'G:maj7'),
#   ('C/5', 'G:maj7', 'G:min'),
#   ('C:9(*3)', 'G:(1,b3,4)/b3', 'G:min'),
#   ('C:maj(#4)/5', 'G', 'G:maj7'),
#   ('C:maj7', 'D', 'N'),
#   ('C:maj7', 'D:(1)', 'N'),
#   ('C:maj7', 'D:min', 'N'),
#   ('C:maj7', 'E:(1,5)', 'N'),
#   ('C:maj7', 'E:7', 'N'),
#   ('C:maj7', 'E:9', 'N'),
#   ('C:maj7', 'E:min', 'N'),
#   ('C:maj7', 'E:min/3', 'N'),
#   ('C:maj7', 'E:min6', 'N'),
#   ('C:maj7', 'F', 'N'),
#   ('C:maj7', 'G:maj7', 'N'),
#   ('C:maj7', 'G:min', 'N'),
#   ('D', 'D/2', 'D:sus4'),
#   ('D', 'D/2', 'E'),
#   ('D', 'D/2', 'G'),
#   ('D', 'D/2', 'G/5'),
#   ('D', 'D:maj6', 'G'),
#   ('D', 'D:maj7', 'D:sus4'),
#   ('D', 'D:maj7', 'E'),
#   ('D', 'D:maj7', 'G'),
#   ('D', 'D:maj7', 'G/5'),
#   ('D', 'D:sus4', 'D:sus4(2)'),
#   ('D', 'D:sus4', 'F/6'),
#   ('D', 'D:sus4', 'G:maj6'),
#   ('D', 'D:sus4', 'G:maj7'),
#   ('D', 'D:sus4(2)', 'E'),
#   ('D', 'D:sus4(2)', 'G'),
#   ('D', 'E', 'E/3'),
#   ('D', 'E', 'E:sus2(b7)'),
#   ('D', 'E', 'F/6'),
#   ('D', 'E', 'G:maj6'),
#   ('D', 'E', 'G:maj7'),
#   ('D', 'E:min', 'G'),
#   ('D', 'F#', 'G'),
#   ('D', 'F#/5', 'G'),
#   ('D', 'F#:dim/b3', 'G'),
#   ('D', 'F/6', 'G'),
#   ('D', 'G', 'G:maj6'),
#   ('D', 'G', 'G:maj7'),
#   ('D', 'G/5', 'G:maj6'),
#   ('D', 'G/5', 'G:maj7'),
#   ('D:(1)', 'E', 'N'),
#   ('D:(1)', 'Eb', 'N'),
#   ('D:(1)', 'G', 'N'),
#   ('D:7', 'G/5', 'G:min/5'),
#   ('D:7', 'G/5', 'N'),
#   ('D:maj6', 'E', 'G'),
#   ('D:min', 'E', 'N'),
#   ('D:min', 'Eb', 'N'),
#   ('E', 'E/3', 'F#'),
#   ('E', 'E/3', 'G'),
#   ('E', 'E/3', 'N'),
#   ('E', 'E:(1,5)', 'N'),
#   ('E', 'E:min', 'G'),
#   ('E', 'E:min', 'N'),
#   ('E', 'E:min/3', 'N'),
#   ('E', 'E:min6', 'N'),
#   ('E', 'E:sus2(b7)', 'F#'),
#   ('E', 'E:sus2(b7)', 'G'),
#   ('E', 'E:sus2(b7)', 'N'),
#   ('E', 'F', 'F#'),
#   ('E', 'F', 'N'),
#   ('E', 'F#/5', 'G'),
#   ('E', 'F#:dim/b3', 'G'),
#   ('E', 'G:maj7', 'N'),
#   ('E', 'G:min', 'N'),
#   ('E:(1,5)', 'Eb', 'N'),
#   ('E:(1,5)', 'G', 'N'),
#   ('E:7', 'Eb', 'N'),
#   ('E:7', 'G', 'N'),
#   ('E:9', 'Eb', 'N'),
#   ('E:9', 'G', 'N'),
#   ('E:min', 'Eb', 'N'),
#   ('E:min/3', 'Eb', 'N'),
#   ('E:min/3', 'G', 'N'),
#   ('E:min6', 'Eb', 'N'),
#   ('E:min6', 'G', 'N'),
#   ('Eb', 'G:maj7', 'N'),
#   ('Eb', 'G:min', 'N'),
#   ('F', 'G:(1,b3,4)/b3', 'G:min'),
#   ('F#', 'G', 'N'),
#   ('F#/5', 'G', 'N'),
#   ('F#:dim/b3', 'G', 'N'),
#   ('G', 'G:maj7', 'N'),
#   ('G', 'G:min', 'N'),
#   ('G:(1,b3,4)/b3', 'G:min', 'G:min/5')},
#  '120C': {('A', 'A:7', 'E'),
#   ('A', 'A:min', 'G'),
#   ('A', 'Ab', 'G'),
#   ('A', 'C', 'E'),
#   ('A', 'C', 'F'),
#   ('A', 'C', 'F#'),
#   ('A', 'C', 'G:(1)'),
#   ('A', 'D', 'F'),
#   ('A', 'D:min', 'G'),
#   ('A', 'E', 'E/3'),
#   ('A', 'E', 'E/5'),
#   ('A', 'E', 'E:sus4(2)'),
#   ('A', 'E:9', 'N'),
#   ('A', 'E:min', 'G'),
#   ('A', 'E:min', 'N'),
#   ('A', 'F', 'G'),
#   ('A:(1)', 'C', 'N'),
#   ('A:7', 'E', 'E:7'),
#   ('A:9', 'D', 'G'),
#   ('A:min', 'B:min', 'C/5'),
#   ('A:min', 'B:min', 'D'),
#   ('A:min', 'B:min', 'G'),
#   ('A:min', 'Bb', 'C'),
#   ('A:min', 'Bb', 'F'),
#   ('A:min', 'C', 'G'),
#   ('A:min', 'C/5', 'G'),
#   ('A:min', 'D', 'G'),
#   ('B', 'B:maj7', 'N'),
#   ('B', 'B:min', 'E:min'),
#   ('B', 'D', 'N'),
#   ('B:maj7', 'E:min', 'N'),
#   ('B:min', 'C', 'D'),
#   ('B:min', 'C/5', 'G'),
#   ('B:min', 'D', 'G'),
#   ('B:min', 'D', 'N'),
#   ('B:min', 'D/5', 'E'),
#   ('B:min', 'E:7', 'N'),
#   ('B:min', 'E:min', 'G'),
#   ('B:min', 'E:min/3', 'N'),
#   ('B:min', 'E:min6', 'N'),
#   ('B:min7', 'C', 'G'),
#   ('Bb', 'C', 'C:7'),
#   ('Bb', 'C', 'G:min'),
#   ('Bb', 'C#:min', 'N'),
#   ('Bb', 'F', 'N'),
#   ('C', 'C:7', 'G'),
#   ('C', 'D:min', 'N'),
#   ('C', 'F', 'G:min'),
#   ('C', 'F#', 'G'),
#   ('C/5', 'D/3', 'G'),
#   ('C/5', 'D/3', 'G:maj7'),
#   ('D', 'D:maj(9)', 'D:sus4'),
#   ('D', 'D:sus4(2)', 'G/5'),
#   ('D', 'Eb', 'G'),
#   ('D', 'F/6', 'G/5'),
#   ('D', 'G/5', 'G:min/5'),
#   ('D:maj6', 'G', 'N'),
#   ('D:min', 'G', 'N'),
#   ('E', 'E:7', 'N'),
#   ('E', 'E:9', 'N'),
#   ('E', 'Eb', 'G'),
#   ('Eb', 'F', 'N'),
#   ('F', 'G', 'N')},
#  '120D': {('A', 'A:min', 'D'),
#   ('A', 'D', 'E:9'),
#   ('A', 'E', 'E:9'),
#   ('A:min', 'C', 'D'),
#   ('A:min', 'C', 'F'),
#   ('B', 'B:maj7', 'E:min'),
#   ('B', 'E', 'E/5'),
#   ('B:min', 'C', 'G'),
#   ('B:min', 'E', 'E:7'),
#   ('Bb', 'F', 'G:min'),
#   ('C', 'C:maj7', 'G'),
#   ('C', 'D/3', 'G'),
#   ('C', 'D:min', 'G'),
#   ('C', 'F', 'F#'),
#   ('D', 'D/5', 'E'),
#   ('D', 'E', 'E:9'),
#   ('D', 'E', 'Eb'),
#   ('D', 'F', 'G')},
#  '120U': {('A', 'C', 'E:min'),
#   ('A', 'D:min', 'N'),
#   ('A', 'F', 'F#'),
#   ('A', 'F', 'N'),
#   ('A:min', 'B:min', 'C'),
#   ('B', 'D', 'G'),
#   ('B', 'E:min', 'N'),
#   ('B:min', 'C', 'E'),
#   ('C', 'E', 'F#'),
#   ('C', 'G:min', 'N'),
#   ('D', 'Eb', 'N'),
#   ('E:min', 'G', 'N')},
#  '201': {('A', 'A:sus4(2)', 'D'),
#   ('A', 'A:sus4(2)', 'D/5'),
#   ('A', 'A:sus4(2)', 'E'),
#   ('A', 'A:sus4(2)', 'E:7'),
#   ('A', 'A:sus4(2)', 'F#'),
#   ('A', 'A:sus4(2)', 'G'),
#   ('A', 'A:sus4(2)', 'G:(1)'),
#   ('A', 'A:sus4(2)', 'N'),
#   ('A', 'Ab:min', 'N'),
#   ('A', 'B', 'E'),
#   ('A', 'B', 'N'),
#   ('A', 'B:7', 'E'),
#   ('A', 'B:min', 'E'),
#   ('A', 'B:min', 'N'),
#   ('A', 'C#:min', 'N'),
#   ('A', 'C/5', 'G'),
#   ('A', 'C:maj7', 'N'),
#   ('A', 'D', 'D:sus4'),
#   ('A', 'D', 'E:7'),
#   ('A', 'D', 'F#'),
#   ('A', 'D', 'G/5'),
#   ('A', 'D', 'G:(1)'),
#   ('A', 'D/5', 'E:7'),
#   ('A', 'D/5', 'F#'),
#   ('A', 'D/5', 'G'),
#   ('A', 'D/5', 'G:(1)'),
#   ('A', 'D/5', 'N'),
#   ('A', 'E', 'G:(1)'),
#   ('A', 'E:7', 'F#'),
#   ('A', 'E:7', 'G'),
#   ('A', 'E:7', 'G:(1)'),
#   ('A', 'Eb', 'N'),
#   ('A', 'F#', 'G:(1)'),
#   ('A', 'F#', 'N'),
#   ('A', 'G', 'G:(1)'),
#   ('A', 'G:(1)', 'N'),
#   ('A:7', 'Ab:min', 'N'),
#   ('A:7', 'B', 'N'),
#   ('A:7', 'B:min', 'N'),
#   ('A:7', 'C', 'N'),
#   ('A:7', 'C#:min', 'N'),
#   ('A:7', 'C:maj7', 'N'),
#   ('A:7', 'D:7', 'E:7'),
#   ('A:7', 'D:7', 'G/5'),
#   ('A:7', 'Eb', 'N'),
#   ('A:7', 'G', 'N'),
#   ('A:min', 'B:min', 'C#'),
#   ('A:min', 'B:min', 'E'),
#   ('A:min', 'B:min', 'E:min'),
#   ('A:min', 'B:min', 'F#:min'),
#   ('A:min', 'B:min', 'F#:min/5'),
#   ('A:min', 'B:min', 'N'),
#   ('Ab:min', 'B', 'N'),
#   ('Ab:min', 'B:min', 'N'),
#   ('Ab:min', 'C', 'N'),
#   ('Ab:min', 'C#:min', 'N'),
#   ('Ab:min', 'C:maj7', 'N'),
#   ('Ab:min', 'E', 'N'),
#   ('Ab:min', 'Eb', 'N'),
#   ('Ab:min', 'G', 'N'),
#   ('B', 'B:7', 'E'),
#   ('B', 'C', 'N'),
#   ('B', 'C#:min', 'N'),
#   ('B', 'C:maj7', 'N'),
#   ('B', 'E', 'F#'),
#   ('B', 'Eb', 'N'),
#   ('B:7', 'B:min', 'E'),
#   ('B:7', 'D', 'E'),
#   ('B:7', 'E', 'F#'),
#   ('B:7', 'E', 'G'),
#   ('B:7', 'E', 'N'),
#   ('B:maj7', 'B:min', 'E:min'),
#   ('B:maj7', 'C', 'E:min'),
#   ('B:min', 'C#', 'E'),
#   ('B:min', 'C#', 'E:min'),
#   ('B:min', 'C#', 'F#:min'),
#   ('B:min', 'C#', 'F#:min/5'),
#   ('B:min', 'C#', 'N'),
#   ('B:min', 'C:maj7', 'N'),
#   ('B:min', 'E', 'E:min'),
#   ('B:min', 'E', 'F#:min'),
#   ('B:min', 'E', 'F#:min/5'),
#   ('B:min', 'E:min', 'F#:min'),
#   ('B:min', 'E:min', 'F#:min/5'),
#   ('B:min', 'Eb', 'N'),
#   ('B:min', 'F#:min', 'F#:min/5'),
#   ('B:min', 'F#:min', 'N'),
#   ('B:min', 'F#:min/5', 'N'),
#   ('Bb', 'C', 'D'),
#   ('Bb', 'C', 'E:min'),
#   ('Bb', 'C', 'G'),
#   ('Bb', 'C', 'G:7'),
#   ('C', 'C#:min', 'N'),
#   ('C', 'D', 'D:sus4'),
#   ('C', 'D', 'E:min'),
#   ('C', 'D', 'G/5'),
#   ('C', 'D', 'G:7'),
#   ('C', 'E:min', 'G:7'),
#   ('C', 'Eb', 'N'),
#   ('C', 'F', 'G:7'),
#   ('C', 'G', 'G:7'),
#   ('C', 'G:7', 'N'),
#   ('C#:min', 'C:maj7', 'N'),
#   ('C#:min', 'E', 'N'),
#   ('C#:min', 'Eb', 'N'),
#   ('C#:min', 'G', 'N'),
#   ('C/5', 'C:maj(#4)/5', 'G:maj7'),
#   ('C/5', 'D', 'G'),
#   ('C/5', 'E', 'G'),
#   ('C/5', 'G', 'G:maj7'),
#   ('C/5', 'G', 'N'),
#   ('C:maj7', 'E', 'N'),
#   ('C:maj7', 'Eb', 'N'),
#   ('D', 'D:7', 'G/5'),
#   ('D', 'D:sus4', 'E'),
#   ('D', 'D:sus4', 'G'),
#   ('D', 'D:sus4', 'G/5'),
#   ('D', 'E', 'F#'),
#   ('D', 'E', 'G/5'),
#   ('D', 'G', 'G/5'),
#   ('E', 'F#', 'N')},
#  '210': {('A', 'A:7', 'E:7'),
#   ('A', 'A:7', 'N'),
#   ('A', 'C', 'D'),
#   ('A', 'C', 'G'),
#   ('A', 'C', 'N'),
#   ('A', 'D', 'D/5'),
#   ('A', 'D', 'N'),
#   ('A', 'D/5', 'E'),
#   ('A', 'E', 'E:7'),
#   ('A', 'E:7', 'N'),
#   ('A', 'F#', 'G'),
#   ('A:7', 'D:7', 'N'),
#   ('A:7', 'E', 'N'),
#   ('A:7', 'E:7', 'N'),
#   ('B', 'B:min', 'E'),
#   ('B', 'B:min', 'N'),
#   ('B', 'D', 'E'),
#   ('B', 'E', 'G'),
#   ('B', 'G', 'N'),
#   ('B:min', 'C', 'E:min'),
#   ('B:min', 'C', 'N'),
#   ('B:min', 'C#:min', 'N'),
#   ('B:min', 'D', 'E'),
#   ('B:min', 'E', 'F#'),
#   ('B:min', 'E', 'G'),
#   ('B:min', 'E:min', 'N'),
#   ('B:min', 'G', 'N'),
#   ('Bb', 'C', 'N'),
#   ('C', 'C/5', 'G'),
#   ('C', 'C:maj7', 'N'),
#   ('C', 'D', 'E'),
#   ('C', 'D', 'F'),
#   ('C', 'D', 'N'),
#   ('C', 'E', 'G'),
#   ('C', 'E', 'N'),
#   ('C', 'E:min', 'F'),
#   ('C', 'E:min', 'G'),
#   ('C', 'E:min', 'N'),
#   ('C', 'F', 'G'),
#   ('C', 'F', 'N'),
#   ('C:maj7', 'G', 'N'),
#   ('D', 'E', 'N'),
#   ('D', 'G', 'N'),
#   ('E', 'Eb', 'N'),
#   ('E', 'F#', 'G'),
#   ('Eb', 'G', 'N')},
#  '300': {('A', 'D', 'E'),
#   ('A', 'D', 'G'),
#   ('A', 'E', 'F#'),
#   ('A', 'E', 'G'),
#   ('A', 'E', 'N'),
#   ('A', 'G', 'N'),
#   ('B', 'E', 'N'),
#   ('B:min', 'E', 'N'),
#   ('Bb', 'C', 'F'),
#   ('C', 'D', 'G'),
#   ('C', 'G', 'N'),
#   ('D', 'E', 'G'),
#   ('E', 'G', 'N')}}

# %%
from collections import Counter
counter=Counter(new)
print(counter)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
