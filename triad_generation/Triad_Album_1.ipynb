# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
album01 = pd.read_csv('album_01_edges.csv')
G = nx.from_pandas_edgelist(album01, source="Source", target="Target", create_using=nx.DiGraph())
nx.draw(G, with_labels=True)

# %% [markdown]
# ## Visuals

# %%
nx.draw(G,node_size=300,font_size=8,  with_labels=True)

# %%
plt.figure(3,figsize=(12,12)) 
nx.draw(G, node_size=400,font_size=12,  with_labels=True)

# %% [markdown]
# ## Triads

# %%
''' Conesus Motifs are: 
        021C
        111D
        201
        030C
        120C
        210
                    '''
# Out:
# ' Conesus Motifs are: \n        021C\n        111D\n        201\n        030C\n        120C\n        210\n                    '

# %%
# Triad Consensus
nx.triadic_census(G)
# Out:
# {'003': 10100,
#  '012': 2409,
#  '102': 914,
#  '021D': 67,
#  '021U': 73,
#  '021C': 173,
#  '111D': 166,
#  '111U': 142,
#  '030T': 8,
#  '030C': 7,
#  '201': 58,
#  '120D': 8,
#  '120U': 7,
#  '120C': 20,
#  '210': 25,
#  '300': 13}

# %%
import networkx as nx
import itertools

def _tricode(G, v, u, w):
    """Returns the integer code of the given triad.

    This is some fancy magic that comes from Batagelj and Mrvar's paper. It
    treats each edge joining a pair of `v`, `u`, and `w` as a bit in
    the binary representation of an integer.

    """
    combos = ((v, u, 1), (u, v, 2), (v, w, 4), (w, v, 8), (u, w, 16),
              (w, u, 32))
    return sum(x for u, v, x in combos if v in G[u])


# G = nx.DiGraph()
# G.add_nodes_from([1, 2, 3, 4, 5])
# G.add_edges_from([(1, 2), (2, 3), (2, 4), (4, 5)])

#: The integer codes representing each type of triad.
#: Triads that are the same up to symmetry have the same code.
TRICODES = (1, 2, 2, 3, 2, 4, 6, 8, 2, 6, 5, 7, 3, 8, 7, 11, 2, 6, 4, 8, 5, 9,
            9, 13, 6, 10, 9, 14, 7, 14, 12, 15, 2, 5, 6, 7, 6, 9, 10, 14, 4, 9,
            9, 12, 8, 13, 14, 15, 3, 7, 8, 11, 7, 12, 14, 15, 8, 14, 13, 15,
            11, 15, 15, 16)

#: The names of each type of triad. The order of the elements is
#: important: it corresponds to the tricodes given in :data:`TRICODES`.
TRIAD_NAMES = ('003', '012', '102', '021D', '021U', '021C', '111D', '111U',
               '030T', '030C', '201', '120D', '120U', '120C', '210', '300')

#: A dictionary mapping triad code to triad name.
TRICODE_TO_NAME = {i: TRIAD_NAMES[code - 1] for i, code in enumerate(TRICODES)}

triad_nodes = {name: set([]) for name in TRIAD_NAMES}
m = {v: i for i, v in enumerate(G)}
for v in G:
    vnbrs = set(G.pred[v]) | set(G.succ[v])
    for u in vnbrs:
        if m[u] > m[v]:
            unbrs = set(G.pred[u]) | set(G.succ[u])
            neighbors = (vnbrs | unbrs) - {u, v}
            not_neighbors = set(G.nodes()) - neighbors - {u, v}
            # Find dyadic triads
            for w in not_neighbors:
                if v in G[u] and u in G[v]:
                    triad_nodes['102'].add(tuple(sorted([u, v, w])))
                else:
                    triad_nodes['012'].add(tuple(sorted([u, v, w])))
            for w in neighbors:
                if m[u] < m[w] or (m[v] < m[w] < m[u] and
                                   v not in G.pred[w] and
                                   v not in G.succ[w]):
                    code = _tricode(G, v, u, w)
                    triad_nodes[TRICODE_TO_NAME[code]].add(
                        tuple(sorted([u, v, w])))
# find null triads
all_tuples = set()
for s in triad_nodes.values():
    all_tuples = all_tuples.union(s)
    
new = triad_nodes['210'] = set(itertools.combinations(G.nodes(), 3)).difference(all_tuples)

triad_nodes
# Out:
# {'003': set(),
#  '012': {('B:7', 'Eb:9', 'F#:min7'),
#   ('Bb:7', 'E:aug', 'Eb'),
#   ('B:min', 'D/3', 'G'),
#   ('C#:min', 'Eb', 'F#'),
#   ('A:min/b3', 'E', 'Eb:7'),
#   ('Bb:7', 'G', 'G#:min'),
#   ('A', 'Bb', 'C:min6'),
#   ('B', 'B:7', 'E:maj7'),
#   ('C#:7', 'E:7/3', 'G'),
#   ('B', 'Bb', 'D'),
#   ('A:maj7/5', 'Bb', 'Bb:7'),
#   ('C:min6', 'F#:min', 'G#:min'),
#   ('B:7', 'F#:min7', 'N'),
#   ('C:min6', 'E', 'Eb:min'),
#   ('A:min/b3', 'Bb:7', 'Eb'),
#   ('Bb:7', 'D/3', 'G'),
#   ('Bb', 'Bb:7', 'E:7/3'),
#   ('B:min', 'E:maj7', 'E:min'),
#   ('F#:9', 'G#:min', 'G:min'),
#   ('Bb', 'E:aug', 'N'),
#   ('A:maj7', 'F#:min', 'N'),
#   ('A:min/b3', 'G#:min', 'G:min'),
#   ('C:min6', 'F#:min', 'F#:min7'),
#   ('A:min', 'E', 'F#'),
#   ('C', 'E', 'E:min'),
#   ('D', 'D:9', 'F#:min'),
#   ('A:maj7', 'B:7', 'F#:min7'),
#   ('A:maj7', 'D', 'D/2'),
#   ('B', 'Eb:min', 'F#:min7'),
#   ('B', 'B:maj6', 'F#:min7'),
#   ('B:min', 'E:min', 'F#:min7'),
#   ('A', 'E:min', 'F'),
#   ('C:min6', 'D:9', 'N'),
#   ('A:min', 'C#:min', 'Eb'),
#   ('C', 'D:9', 'E:min'),
#   ('Eb', 'Eb:min', 'G#:min'),
#   ('A:maj7', 'A:min', 'F#:9'),
#   ('Bb:7', 'D:9', 'Eb'),
#   ('Bb', 'C', 'E:7/3'),
#   ('A:7', 'C#:min', 'G#'),
#   ('E:7', 'Eb', 'G'),
#   ('B:min', 'C#:min', 'Eb'),
#   ('A:maj7', 'C#:7', 'E'),
#   ('Bb', 'F#:min7', 'N'),
#   ('D', 'D/2', 'E:7'),
#   ('Bb:7', 'C', 'E:min'),
#   ('A:maj7', 'B:min', 'C#:min'),
#   ('A:maj7', 'E', 'F#:9'),
#   ('B:7', 'Bb', 'N'),
#   ('A', 'Bb', 'F#:min7'),
#   ('C#:min', 'E', 'Eb:7'),
#   ('D:9', 'E:7', 'G'),
#   ('C#:7', 'D', 'E:7/3'),
#   ('E', 'E:7/3', 'F#:9'),
#   ('B', 'Eb:9', 'F'),
#   ('B:min', 'C', 'N'),
#   ('Bb', 'Eb:9', 'G'),
#   ('A', 'D/2', 'E:7/3'),
#   ('D', 'D/2', 'F#:min7'),
#   ('A:min/b3', 'F#:min7', 'F#:minmaj7'),
#   ('Bb', 'E:maj7', 'Eb:9'),
#   ('A:maj7', 'E:7', 'G'),
#   ('C#:7', 'G', 'G#:min7'),
#   ('B:7', 'E:7/3', 'F#:min'),
#   ('A:min/b3', 'Bb', 'Bb:7'),
#   ('Bb', 'Bb:7', 'Eb:min'),
#   ('B:7', 'E:aug', 'F#:min7'),
#   ('C#:min', 'F', 'F#'),
#   ('A:maj7', 'D/2', 'E'),
#   ('B:maj6', 'Eb:7', 'G#:min'),
#   ('D:9', 'Eb', 'Eb:min'),
#   ('A:min', 'B', 'F'),
#   ('A:maj7', 'C#:min', 'G#:min7'),
#   ('A:min', 'C#:min/5', 'G'),
#   ('D/2', 'D/3', 'D:9'),
#   ('C#:min/5', 'F#:min', 'F#:min7'),
#   ('A', 'C#:min', 'D/2'),
#   ('D/3', 'D:9', 'N'),
#   ('Bb', 'C', 'Eb:min'),
#   ('Bb', 'C#:min', 'N'),
#   ('A:min', 'E', 'F#:min7'),
#   ('D/2', 'F', 'N'),
#   ('E', 'E:maj7', 'G#:min7'),
#   ('C', 'C#:min', 'G#'),
#   ('Bb', 'E:maj7', 'N'),
#   ('A:min', 'C:min6', 'E'),
#   ('C#:min/5', 'E:7/3', 'F#:min'),
#   ('B:min', 'C#:7', 'C#:min'),
#   ('A:maj7', 'F', 'N'),
#   ('D:9', 'E', 'G'),
#   ('B:maj6', 'F#:9', 'G#:min'),
#   ('E', 'E:aug', 'F'),
#   ('E', 'E:min', 'F#'),
#   ('Bb', 'E', 'F#:min'),
#   ('A:7', 'A:min', 'G'),
#   ('D/2', 'D/3', 'Eb:9'),
#   ('A:maj7', 'G', 'G:min'),
#   ('Bb', 'F:9', 'G#:min7'),
#   ('C#:7', 'D', 'Eb:min'),
#   ('A:min', 'F#', 'N'),
#   ('A', 'A:maj7/5', 'C#:min/5'),
#   ('Bb', 'F#:min7', 'F#:minmaj7'),
#   ('B:maj6', 'Bb:7', 'Eb'),
#   ('E', 'F#:minmaj7', 'G'),
#   ('A:min/b3', 'C#:7', 'E'),
#   ('C#:min', 'F#:min7', 'F#:minmaj7'),
#   ('C#:7', 'E:maj7', 'G'),
#   ('A:min/b3', 'B:min', 'C#:min'),
#   ('A:maj7/5', 'B:maj6', 'F:9'),
#   ('Bb', 'F#:min', 'G'),
#   ('A:min', 'A:min/b3', 'E'),
#   ('Bb:7', 'C:min6', 'E'),
#   ('A:maj7', 'D/3', 'G'),
#   ('Bb:7', 'Eb', 'G#'),
#   ('B:maj6', 'Bb', 'D'),
#   ('A:maj7', 'F#:min', 'G#:min7'),
#   ('A:min', 'D/2', 'F#:9'),
#   ('A:maj7', 'Eb', 'G#:min7'),
#   ('B', 'D:9', 'F#:min7'),
#   ('E', 'F#:min', 'G#:min7'),
#   ('E:9', 'F#:9', 'N'),
#   ('A', 'Bb:7', 'E:7/3'),
#   ('C#:7', 'E', 'F#:min'),
#   ('E', 'E:min', 'G#:min'),
#   ('C#:min', 'D', 'D/2'),
#   ('D/2', 'E', 'F#'),
#   ('C:min6', 'E:7', 'G:min'),
#   ('A:min', 'F', 'F#:9'),
#   ('C', 'Eb:9', 'N'),
#   ('B:min', 'E:9', 'F#'),
#   ('E', 'F#:9', 'G'),
#   ('E', 'E:min', 'F#:min7'),
#   ('A', 'C', 'E:7/3'),
#   ('Eb:9', 'F#:9', 'F:9'),
#   ('A', 'Eb', 'G#:min'),
#   ('A:7', 'F#:min', 'N'),
#   ('B:7', 'Eb:9', 'F#:min'),
#   ('A:7', 'B:7', 'F#:min7'),
#   ('B', 'D/2', 'F#:9'),
#   ('G', 'G#:min7', 'G:min'),
#   ('E', 'F#:min7', 'F:9'),
#   ('E', 'E:maj7', 'F#:9'),
#   ('E:7', 'E:9', 'G:min'),
#   ('A', 'E:7/3', 'Eb:7'),
#   ('E:7', 'F#', 'G:min'),
#   ('Bb', 'E:9', 'F:9'),
#   ('Bb', 'D', 'E:aug'),
#   ('A:maj7', 'C', 'N'),
#   ('D/2', 'D/3', 'E:9'),
#   ('C#:min', 'E:7', 'G'),
#   ('A:maj7/5', 'B:maj6', 'C#:min'),
#   ('C#:min', 'D', 'D:9'),
#   ('A:maj7/5', 'B:maj6', 'G:min'),
#   ('C:min6', 'G', 'G#:min'),
#   ('Eb:9', 'G', 'G#:min'),
#   ('D:9', 'F#:min7', 'N'),
#   ('C#:min', 'D/2', 'E'),
#   ('B', 'E:maj7', 'G'),
#   ('A', 'C#:7', 'G#:min'),
#   ('A:maj7/5', 'B:maj6', 'E:aug'),
#   ('Bb:7', 'Eb', 'N'),
#   ('C', 'E:min', 'Eb:7'),
#   ('A:7', 'G#:min', 'N'),
#   ('A:maj7', 'Bb', 'F:9'),
#   ('Bb', 'Eb:9', 'F#:min'),
#   ('C', 'E:aug', 'E:min'),
#   ('C#:min', 'D', 'G#'),
#   ('A:maj7', 'F', 'G#:min7'),
#   ('A:min', 'B:min', 'F#:9'),
#   ('A:7', 'E:7', 'G'),
#   ('A:maj7', 'E', 'E:7'),
#   ('B:min', 'F#', 'G#:min'),
#   ('A:7', 'D', 'D:9'),
#   ('A:maj7', 'B', 'F'),
#   ('D', 'D:9', 'Eb'),
#   ('D/2', 'E', 'F#:min7'),
#   ('C#:7', 'D', 'G#:min'),
#   ('A', 'E:min', 'G#'),
#   ('A', 'C#:min', 'N'),
#   ('A:min', 'C#:min', 'Eb:9'),
#   ('A:min', 'Bb:7', 'F#:9'),
#   ('E', 'E:7', 'F#:min'),
#   ('E', 'Eb:min', 'G#'),
#   ('B:min', 'C#:min', 'Eb:9'),
#   ('Eb:7', 'Eb:min', 'N'),
#   ('A:min', 'C#:min/5', 'F#:min'),
#   ('B:maj6', 'Bb', 'G#:min'),
#   ('A:7', 'F#:min', 'F#:minmaj7'),
#   ('E:7', 'G#', 'G:min'),
#   ('B:7', 'D', 'E'),
#   ('D', 'D/2', 'F#:min'),
#   ('A', 'F#:min7', 'F#:minmaj7'),
#   ('A:maj7/5', 'E:9', 'N'),
#   ('A:maj7', 'F#', 'N'),
#   ('C#:min', 'D/3', 'G'),
#   ('C', 'D/2', 'E:min'),
#   ('B:7', 'E:aug', 'F#:min'),
#   ('B', 'B:min', 'F'),
#   ('E:maj7', 'F#:min7', 'G#'),
#   ('D:9', 'E', 'F#:min'),
#   ('C#:min', 'E', 'F'),
#   ('B:maj6', 'E', 'F#:min7'),
#   ('B:7', 'E', 'Eb'),
#   ('C#:min/5', 'G', 'G#:min'),
#   ('A:7', 'A:maj7/5', 'B:maj6'),
#   ('Bb', 'G#:min7', 'N'),
#   ('B:maj6', 'Eb', 'Eb:min'),
#   ('D:9', 'F#:min7', 'F#:minmaj7'),
#   ('Bb', 'D', 'E:maj7'),
#   ('E:9', 'F:9', 'N'),
#   ('Bb', 'Bb:7', 'G'),
#   ('B', 'Bb:7', 'F'),
#   ('B:7', 'Eb:7', 'F#:min7'),
#   ('A:maj7', 'B:min', 'G#:min7'),
#   ('F#', 'G:min', 'N'),
#   ('Bb:7', 'Eb', 'F#:minmaj7'),
#   ('B:min', 'E:7', 'F#'),
#   ('C#:min', 'F#', 'G:min'),
#   ('C#:min/5', 'Eb', 'F#:min'),
#   ('Bb', 'E:min', 'F:9'),
#   ('A', 'C#:7', 'E:min'),
#   ('E', 'Eb:9', 'F#'),
#   ('Bb:7', 'F', 'N'),
#   ('A:maj7/5', 'C#:min', 'F#'),
#   ('B:7', 'Bb', 'C'),
#   ('E:7', 'E:9', 'N'),
#   ('E', 'F:9', 'G'),
#   ('A:min/b3', 'E', 'F:9'),
#   ('B:min', 'E:9', 'E:min'),
#   ('A', 'C#:min', 'F#:minmaj7'),
#   ('A:min', 'Eb', 'G'),
#   ('A', 'E:7', 'F#:min7'),
#   ('B:maj6', 'C#:7', 'D'),
#   ('C#:min', 'E:9', 'G#'),
#   ('B', 'E:maj7', 'Eb:7'),
#   ('C', 'F#:min', 'F#:minmaj7'),
#   ('E:aug', 'G#:min', 'G:min'),
#   ('B:7', 'E', 'F:9'),
#   ('A:maj7/5', 'Eb:min', 'N'),
#   ('A:maj7/5', 'B:maj6', 'N'),
#   ('A', 'A:min/b3', 'D/3'),
#   ('C:min6', 'E', 'Eb:7'),
#   ('A:7', 'C', 'E:min'),
#   ('A:min', 'F#', 'F#:9'),
#   ('A:min', 'C#:min', 'E:9'),
#   ('B', 'C', 'C#:7'),
#   ('Bb:7', 'Eb', 'G#:min7'),
#   ('B:7', 'F', 'F#:min'),
#   ('B:maj6', 'E:min', 'G#:min'),
#   ('A:min/b3', 'E:9', 'N'),
#   ('B:min', 'C#:min', 'E:9'),
#   ('Bb:7', 'F#:min', 'G'),
#   ('E', 'E:9', 'F#:minmaj7'),
#   ('C#:7', 'D', 'E'),
#   ('E', 'Eb:9', 'G#:min'),
#   ('E:7', 'F#:minmaj7', 'G:min'),
#   ('A:min', 'B', 'E:maj7'),
#   ('E:maj7', 'Eb:min', 'F#:min7'),
#   ('C:min6', 'G#:min', 'G:min'),
#   ('Eb:9', 'G#:min', 'G:min'),
#   ('Bb', 'Bb:7', 'C#:min/5'),
#   ('B', 'C:min6', 'F#:9'),
#   ('E:aug', 'F#:min7', 'F#:minmaj7'),
#   ('Bb', 'E', 'F:9'),
#   ('Bb:7', 'E', 'F#'),
#   ('A', 'B:7', 'C#:min'),
#   ('A', 'C#:min/5', 'F'),
#   ('C#:min', 'Eb:min', 'G#'),
#   ('A', 'Bb', 'D/3'),
#   ('B', 'E:7', 'G#:min'),
#   ('A:min/b3', 'C#:min', 'F#'),
#   ('Bb', 'D', 'F#:minmaj7'),
#   ('A', 'B:7', 'E:aug'),
#   ('Eb:7', 'G#:min', 'G:min'),
#   ('Bb', 'C', 'C#:min/5'),
#   ('C', 'G:min', 'N'),
#   ('B', 'D/2', 'F#:min7'),
#   ('A:maj7', 'E:9', 'G#:min7'),
#   ('A:7', 'B:7', 'F#:min'),
#   ('B', 'C#:7', 'G'),
#   ('A:7', 'Bb', 'F:9'),
#   ('A:maj7', 'Bb', 'Eb:9'),
#   ('E:maj7', 'G#:min', 'G:min'),
#   ('E', 'F#', 'F:9'),
#   ('A:maj7', 'F#', 'G#:min7'),
#   ('E:7', 'Eb:9', 'F:9'),
#   ('E', 'E:9', 'G#:min7'),
#   ('A:min/b3', 'E', 'G:min'),
#   ('A:7', 'B', 'F'),
#   ('A', 'E:aug', 'Eb:7'),
#   ('B:min', 'E', 'G#:min'),
#   ('A', 'E:min', 'F#:minmaj7'),
#   ('Eb:9', 'F:9', 'G'),
#   ('A:maj7', 'C#:min/5', 'F#:min'),
#   ('A:maj7/5', 'C:min6', 'F#:min'),
#   ('B:7', 'B:maj6', 'E'),
#   ('B:7', 'E', 'G:min'),
#   ('B:7', 'Bb:7', 'F#:min'),
#   ('A:7', 'C:min6', 'E'),
#   ('B', 'E:aug', 'E:maj7'),
#   ('A', 'E:7/3', 'F'),
#   ('D/3', 'G#:min', 'G:min'),
#   ('Bb:7', 'E', 'G#:min'),
#   ('B', 'F#:minmaj7', 'G#:min'),
#   ('B', 'F', 'G#'),
#   ('Eb:7', 'F#:min7', 'F#:minmaj7'),
#   ('C#:7', 'F#', 'G'),
#   ('B:min', 'E:7', 'E:min'),
#   ('A:min/b3', 'Eb:9', 'F:9'),
#   ('C#:min', 'Eb:9', 'F#'),
#   ('Bb', 'D', 'G#:min7'),
#   ('Bb:7', 'Eb', 'F#:9'),
#   ('A', 'A:maj7', 'E:7/3'),
#   ('A', 'E:9', 'E:aug'),
#   ('B:7', 'C', 'F#:min'),
#   ('B:min', 'E:min', 'Eb'),
#   ('E:aug', 'G#:min', 'N'),
#   ('Bb:7', 'E', 'F#:min7'),
#   ('C#:min/5', 'D', 'F#:min'),
#   ('B', 'D/3', 'G#:min'),
#   ('D', 'D:9', 'Eb:9'),
#   ('Bb', 'C:min6', 'Eb:9'),
#   ('C#:min', 'C#:min/5', 'G#'),
#   ('A:maj7', 'Eb:min', 'G#:min7'),
#   ('A:maj7/5', 'D:9', 'N'),
#   ('A:maj7', 'B:maj6', 'G#:min7'),
#   ('C', 'C:min6', 'E:min'),
#   ('Eb', 'F#:min', 'N'),
#   ('F#:9', 'F#:min', 'F#:minmaj7'),
#   ('A', 'A:min/b3', 'F:9'),
#   ('A', 'A:min', 'A:min/b3'),
#   ('B', 'C', 'D/2'),
#   ('Bb', 'Bb:7', 'F#:min'),
#   ('A:min/b3', 'E:maj7', 'F#:min7'),
#   ('Bb', 'E', 'E:aug'),
#   ('B:7', 'Bb', 'F#:min7'),
#   ('Bb:7', 'E:min', 'Eb'),
#   ('Bb:7', 'F#', 'N'),
#   ('C#:min', 'Eb', 'F'),
#   ('F#:min7', 'F#:minmaj7', 'F:9'),
#   ('D/2', 'Eb:min', 'N'),
#   ('B:maj6', 'G#', 'G#:min'),
#   ('F#:9', 'G', 'G:min'),
#   ('D', 'D/2', 'Eb'),
#   ('C:min6', 'G#:min', 'N'),
#   ('E', 'F#', 'G:min'),
#   ('Eb:9', 'G#:min', 'N'),
#   ('C', 'C:min6', 'E'),
#   ('B:maj6', 'E', 'F#:min'),
#   ('F#:min', 'G#:min7', 'N'),
#   ('C', 'Eb:7', 'N'),
#   ('C#:min/5', 'D/2', 'D/3'),
#   ('B:min', 'G', 'G#:min'),
#   ('B:min', 'E', 'E:min'),
#   ('A', 'Eb:min', 'G#:min'),
#   ('B:7', 'Eb:7', 'F#:min'),
#   ('B:7', 'E', 'Eb:9'),
#   ('D/2', 'D/3', 'F#'),
#   ('A', 'A:min', 'G#:min'),
#   ('D', 'G#:min', 'G:min'),
#   ('E:7', 'Eb:min', 'G'),
#   ('C#:7', 'Eb', 'G'),
#   ('B:maj6', 'Bb', 'Bb:7'),
#   ('C#:min', 'D:9', 'G#'),
#   ('Eb:7', 'G#:min', 'N'),
#   ('B', 'C', 'D:9'),
#   ('B:7', 'F#', 'F#:min'),
#   ('A:maj7', 'B', 'E:maj7'),
#   ('E:maj7', 'G#:min', 'N'),
#   ('C', 'F#:9', 'N'),
#   ('A:maj7/5', 'B:min', 'F#'),
#   ('A', 'Bb:7', 'C#:min/5'),
#   ('C#:7', 'E', 'E:aug'),
#   ('B:maj6', 'Eb:min', 'N'),
#   ('D/3', 'E', 'G#'),
#   ('A:7', 'E', 'G#'),
#   ('B:7', 'F#:min', 'F:9'),
#   ('Bb', 'E:maj7', 'F#:min7'),
#   ('Eb:min', 'G', 'G#:min'),
#   ('C#:min', 'E:maj7', 'F#:min7'),
#   ('B', 'C', 'G#'),
#   ('A:min/b3', 'D:9', 'N'),
#   ('A', 'C#:min/5', 'D/2'),
#   ('Bb', 'D', 'F#:9'),
#   ('C:min6', 'Eb:min', 'F#:min'),
#   ('Eb', 'F#:min', 'F#:minmaj7'),
#   ('E', 'F', 'F#:min7'),
#   ('D', 'E', 'E:9'),
#   ('B:maj6', 'C#:7', 'G'),
#   ('B:7', 'D:9', 'E'),
#   ('C#:min', 'F#', 'G#:min7'),
#   ('A', 'C', 'C#:min/5'),
#   ('C#:min/5', 'E:9', 'F#:min'),
#   ('C#:min/5', 'F#', 'F#:min'),
#   ('D/3', 'G#:min', 'N'),
#   ('E', 'G#', 'G:min'),
#   ('C', 'E:min', 'F:9'),
#   ('A', 'A:min/b3', 'G:min'),
#   ('A:maj7/5', 'B:maj6', 'F#:9'),
#   ('D/2', 'D/3', 'G#:min'),
#   ('Eb', 'G', 'G:min'),
#   ('A', 'E:9', 'N'),
#   ('B', 'C#:min/5', 'G#:min'),
#   ('B', 'B:min', 'E:maj7'),
#   ('B:7', 'E:min', 'F#:min7'),
#   ('A', 'A:maj7/5', 'C#:min'),
#   ('F#:min7', 'F#:minmaj7', 'G:min'),
#   ('A:min', 'C#:min', 'D'),
#   ('A:min', 'F#:9', 'G#'),
#   ('A', 'A:maj7/5', 'E:aug'),
#   ('B', 'Bb:7', 'E:maj7'),
#   ('E:7/3', 'Eb:min', 'N'),
#   ('D:9', 'E:7', 'G:min'),
#   ('B', 'C:min6', 'F#:min7'),
#   ('A:maj7', 'D:9', 'G#:min7'),
#   ('Bb', 'Eb:9', 'G:min'),
#   ('A', 'B:maj6', 'E:min'),
#   ('Bb', 'E:7/3', 'N'),
#   ('D/3', 'E:maj7', 'G'),
#   ('D/3', 'E', 'E:maj7'),
#   ('C', 'E', 'G#'),
#   ('A:7', 'E', 'E:maj7'),
#   ('Bb:7', 'E:maj7', 'F#:min7'),
#   ('A:maj7', 'E:7', 'G:min'),
#   ('A:maj7/5', 'B:maj6', 'C'),
#   ('A:min/b3', 'B:min', 'F#'),
#   ('B:maj6', 'D/3', 'G#:min'),
#   ('E', 'E:7', 'G:min'),
#   ('A', 'C#:min/5', 'G#'),
#   ('A:7', 'Bb', 'N'),
#   ('E', 'E:7', 'E:aug'),
#   ('A', 'C#:min', 'C:min6'),
#   ('E', 'Eb:7', 'F#'),
#   ('A', 'D:9', 'G#:min'),
#   ('A', 'Eb', 'F'),
#   ('Eb', 'F', 'F#:minmaj7'),
#   ('B', 'F:9', 'G#:min'),
#   ('Bb', 'D/2', 'F:9'),
#   ('A:min', 'Eb:min', 'G'),
#   ('E:7', 'G#:min', 'N'),
#   ('C#:min/5', 'E', 'E:9'),
#   ('A:min', 'B:maj6', 'G'),
#   ('B:min', 'F', 'F#'),
#   ('A:7', 'A:min', 'C#:min'),
#   ('A', 'A:min/b3', 'Eb:9'),
#   ('B', 'C', 'E:9'),
#   ('C#:min', 'F#', 'F#:9'),
#   ('B', 'E:min', 'F'),
#   ('A:maj7', 'G', 'G#:min'),
#   ('C', 'E:min', 'G:min'),
#   ('D:9', 'E', 'E:aug'),
#   ('B:7', 'Bb:7', 'Eb'),
#   ('D/2', 'D/3', 'E:min'),
#   ('A:7', 'F#:min', 'G'),
#   ('A', 'Eb:9', 'F:9'),
#   ('A', 'E:7/3', 'G#'),
#   ('E', 'E:aug', 'Eb:min'),
#   ('E:7', 'F', 'G:min'),
#   ('C', 'E', 'E:maj7'),
#   ('B', 'E:maj7', 'F:9'),
#   ('Bb', 'F#:min', 'G:min'),
#   ('Eb:9', 'F#:minmaj7', 'F:9'),
#   ('F#:min7', 'G', 'G:min'),
#   ('C:min6', 'D:9', 'F#:min'),
#   ('A:min', 'F#:9', 'N'),
#   ('A:maj7/5', 'B:min', 'E:min'),
#   ('C#:min', 'E', 'F#:minmaj7'),
#   ('A', 'Bb', 'D:9'),
#   ('B:min', 'E:min', 'Eb:9'),
#   ('A:maj7', 'B', 'G#:min7'),
#   ('D/2', 'D/3', 'E'),
#   ('A', 'C#:min', 'F#:min7'),
#   ('B', 'Eb', 'Eb:min'),
#   ('E', 'Eb:7', 'G#:min'),
#   ('A:maj7', 'E', 'Eb'),
#   ('Eb', 'F', 'G#:min7'),
#   ('F#:minmaj7', 'G', 'G:min'),
#   ('Bb:7', 'Eb', 'G'),
#   ('C#:7', 'C#:min', 'G#'),
#   ('B:7', 'Bb', 'F#:min'),
#   ('C#:7', 'D', 'F'),
#   ('A:maj7/5', 'B:maj6', 'F#'),
#   ('E', 'E:7/3', 'Eb'),
#   ('Eb', 'Eb:min', 'G#'),
#   ('C#:min', 'G#', 'G:min'),
#   ('A:7', 'B', 'E:maj7'),
#   ('A:min', 'D/2', 'D/3'),
#   ('A:min', 'C#:min', 'G#:min'),
#   ('C', 'E', 'E:9'),
#   ('C#:min', 'Eb', 'G#'),
#   ('B', 'C', 'F#:minmaj7'),
#   ('B:min', 'D/2', 'D/3'),
#   ('D:9', 'E:7', 'N'),
#   ('B:min', 'C#:min', 'G#:min'),
#   ('G#:min', 'G#:min7', 'G:min'),
#   ('A:maj7/5', 'B:maj6', 'C:min6'),
#   ('E:7', 'G', 'G#:min7'),
#   ('A:maj7/5', 'C', 'E:min'),
#   ('D', 'D/2', 'Eb:9'),
#   ('D', 'E', 'E:7/3'),
#   ('E', 'Eb', 'F#'),
#   ('Eb:min', 'F#:9', 'N'),
#   ('B:min', 'E:aug', 'E:min'),
#   ('B:maj6', 'C#:min/5', 'G#:min'),
#   ('A', 'D:9', 'E:min'),
#   ('C#:7', 'F#:min', 'G:min'),
#   ('C#:min', 'E', 'G#:min7'),
#   ('D:9', 'G', 'G:min'),
#   ('B', 'F#:min7', 'G#'),
#   ('A:maj7/5', 'Bb', 'D'),
#   ('A', 'B:7', 'F#:9'),
#   ('E:aug', 'Eb', 'F'),
#   ('C#:min/5', 'D:9', 'F#:min'),
#   ('B', 'D/2', 'D/3'),
#   ('C#:min', 'E:7', 'G:min'),
#   ('A:min', 'F#:9', 'F#:minmaj7'),
#   ('B:7', 'D', 'D/2'),
#   ('A', 'E:aug', 'F:9'),
#   ('F#:minmaj7', 'G#:min', 'G:min'),
#   ('A:min/b3', 'B:min', 'E:min'),
#   ('Bb', 'D', 'F#:min7'),
#   ('B', 'E:maj7', 'G:min'),
#   ('A:maj7/5', 'B:maj6', 'E:7'),
#   ('E', 'F', 'F#:min'),
#   ('A:min/b3', 'E', 'F#:9'),
#   ('A', 'E:7', 'Eb'),
#   ('B:maj6', 'E:7/3', 'G#:min'),
#   ('E:aug', 'Eb:9', 'F:9'),
#   ('C#:min', 'Eb:7', 'F#'),
#   ('C#:min/5', 'Eb:min', 'N'),
#   ('C#:min', 'D/2', 'G#'),
#   ('A:min', 'D:9', 'G'),
#   ('B:7', 'C#:7', 'E'),
#   ('A', 'D/3', 'E:7/3'),
#   ('E', 'Eb', 'G#:min'),
#   ('B:7', 'B:min', 'C#:min'),
#   ('A:7', 'A:maj7', 'G#:min7'),
#   ('A:maj7/5', 'B:maj6', 'F#:min7'),
#   ('A:7', 'E:7', 'G:min'),
#   ('C:min6', 'Eb', 'F'),
#   ('A', 'C#:min/5', 'F#:minmaj7'),
#   ('F#', 'G#:min7', 'N'),
#   ('A:maj7/5', 'B', 'F#:9'),
#   ('A:min/b3', 'B:min', 'E'),
#   ('B:7', 'E:min', 'F#:min'),
#   ('E:7', 'F', 'N'),
#   ('Eb', 'F', 'F#:9'),
#   ('B:maj6', 'F:9', 'G#:min'),
#   ('Bb', 'C:min6', 'D'),
#   ('E', 'Eb', 'F#:min7'),
#   ('A', 'E:9', 'F#:9'),
#   ('C#:min', 'F', 'G#'),
#   ('B:7', 'E:7', 'G'),
#   ('E:aug', 'E:maj7', 'F#:min7'),
#   ('B:maj6', 'Bb:7', 'G#:min'),
#   ('A:min/b3', 'Bb:7', 'E'),
#   ('A', 'Bb', 'E:9'),
#   ('D/3', 'E', 'E:7/3'),
#   ('B:maj6', 'E:7', 'G:min'),
#   ('A:7', 'E', 'E:7/3'),
#   ('C:min6', 'Eb:9', 'F:9'),
#   ('A:min', 'F#:9', 'G#:min7'),
#   ('C#:min/5', 'E', 'E:7/3'),
#   ('A:maj7/5', 'G#:min', 'G:min'),
#   ('A', 'E:7', 'F:9'),
#   ('E:maj7', 'Eb', 'F'),
#   ('B', 'C', 'E:7/3'),
#   ('E', 'Eb:min', 'G'),
#   ('D', 'D/2', 'E:9'),
#   ('B', 'Eb', 'G#:min'),
#   ('A:min/b3', 'Bb', 'D'),
#   ('Eb:9', 'Eb:min', 'F:9'),
#   ('E:7', 'Eb:7', 'G'),
#   ('A', 'A:maj7', 'C#:min/5'),
#   ('A:min/b3', 'F', 'N'),
#   ('C#:min', 'G#', 'N'),
#   ('A:maj7/5', 'B', 'C'),
#   ('A', 'E:7/3', 'F#:minmaj7'),
#   ('Bb', 'E:7', 'Eb:9'),
#   ('A:min/b3', 'G', 'G:min'),
#   ('B:7', 'D/3', 'F#:min7'),
#   ('C:min6', 'E:maj7', 'F#:min7'),
#   ('Bb', 'Bb:7', 'C#:min'),
#   ('G#:min', 'G#:min7', 'N'),
#   ('E:maj7', 'Eb:9', 'F:9'),
#   ('Bb', 'Bb:7', 'G:min'),
#   ('B:7', 'F', 'N'),
#   ('E', 'E:maj7', 'Eb'),
#   ('A', 'E:aug', 'G:min'),
#   ('B', 'E:7', 'F'),
#   ('E:maj7', 'F#:min7', 'G'),
#   ('B:maj6', 'C#:min', 'F#'),
#   ('A:maj7', 'D/2', 'G#:min7'),
#   ('Bb', 'Bb:7', 'E:aug'),
#   ('C#:7', 'F#:min', 'N'),
#   ('C#:7', 'C:min6', 'D'),
#   ('B', 'Bb', 'E:maj7'),
#   ('A:min', 'E', 'E:9'),
#   ('A:min/b3', 'D/3', 'G'),
#   ('Bb', 'D/2', 'N'),
#   ('Bb', 'C', 'C#:min'),
#   ('Bb', 'C', 'G:min'),
#   ('C#:min', 'F#', 'F#:min7'),
#   ('A:min', 'B', 'G'),
#   ('D', 'D:9', 'F#'),
#   ('A:min/b3', 'B', 'F#:9'),
#   ('F:9', 'G', 'G:min'),
#   ('A:min', 'D/3', 'F#:9'),
#   ('F#:9', 'F#:min', 'G'),
#   ('Eb', 'Eb:min', 'F#:minmaj7'),
#   ('C', 'E', 'E:7/3'),
#   ('Bb', 'C', 'E:aug'),
#   ('E:maj7', 'F#:9', 'F#:min7'),
#   ('Bb:7', 'Eb', 'F#:min'),
#   ('F#:minmaj7', 'G#:min', 'N'),
#   ('B', 'C', 'Eb:min'),
#   ('C', 'G#:min7', 'N'),
#   ('A:maj7/5', 'Eb', 'F'),
#   ('A:7', 'Bb', 'C'),
#   ('Bb', 'G', 'G:min'),
#   ('C:min6', 'D/3', 'E'),
#   ('Bb:7', 'E', 'Eb'),
#   ('C#:min', 'G', 'G:min'),
#   ('A:min', 'C#:7', 'C#:min'),
#   ('A', 'D/2', 'E:aug'),
#   ('Bb:7', 'E:7/3', 'Eb'),
#   ('A:min', 'Bb:7', 'Eb'),
#   ('B:maj6', 'D/2', 'D/3'),
#   ('Bb:7', 'F#:min', 'G:min'),
#   ('B:maj6', 'C#:min', 'G#:min'),
#   ('A:maj7/5', 'B:maj6', 'B:min'),
#   ('B:maj6', 'E:maj7', 'G#:min'),
#   ('C', 'E:min', 'G#:min7'),
#   ('A:min/b3', 'B', 'C'),
#   ('D', 'E', 'G#:min'),
#   ('A:maj7', 'E', 'Eb:9'),
#   ('B', 'D/3', 'F'),
#   ('Bb', 'D/3', 'G'),
#   ('B:min', 'F#', 'G#'),
#   ('C', 'G#', 'N'),
#   ('A', 'E:min', 'Eb:7'),
#   ('C#:7', 'D', 'G#'),
#   ('D', 'D:9', 'G#:min'),
#   ('E', 'E:7/3', 'Eb:9'),
#   ('F:9', 'G#:min', 'G:min'),
#   ('A:min/b3', 'C', 'N'),
#   ('C:min6', 'D/2', 'F#:min'),
#   ('G', 'G#', 'G#:min'),
#   ('A', 'A:maj7/5', 'F#:9'),
#   ('E:9', 'G#:min', 'G:min'),
#   ('A:maj7', 'C#:7', 'D'),
#   ('A:maj7', 'G#:min', 'N'),
#   ('A', 'B:7', 'E:7'),
#   ('C#:7', 'F', 'N'),
#   ('A:maj7/5', 'E:maj7', 'F#:min7'),
#   ('B:7', 'C', 'N'),
#   ('B:7', 'C#:min/5', 'F#:min7'),
#   ('Bb', 'Eb:9', 'F#:9'),
#   ('A', 'C#:min/5', 'Eb:min'),
#   ('B:maj6', 'G', 'G:min'),
#   ('B:maj6', 'C:min6', 'F#:min'),
#   ('A', 'B:7', 'F#:min7'),
#   ('D/3', 'G', 'G#'),
#   ('E:7', 'F#:min7', 'G:min'),
#   ('A:min/b3', 'E', 'E:7'),
#   ('B:min', 'Bb', 'F:9'),
#   ('A', 'A:min/b3', 'C'),
#   ('C#:min', 'C:min6', 'G#'),
#   ('D:9', 'F:9', 'N'),
#   ('Bb', 'F#:min7', 'F:9'),
#   ('D/2', 'G#:min', 'G:min'),
#   ('B:maj6', 'F#:min', 'G#:min'),
#   ('A:maj7', 'F#:9', 'G#:min7'),
#   ('A', 'E:aug', 'N'),
#   ('C', 'E:7', 'N'),
#   ('Bb', 'D', 'F#:min'),
#   ('C:min6', 'E', 'F#:minmaj7'),
#   ('D:9', 'Eb', 'N'),
#   ('B:7', 'E', 'E:7'),
#   ('F', 'F#:min', 'F#:minmaj7'),
#   ('A:maj7/5', 'B', 'G#:min'),
#   ('A:min', 'C#:min/5', 'F#:9'),
#   ('B:7', 'E:7', 'F#:min'),
#   ('B', 'D', 'G#:min'),
#   ('A:maj7', 'Bb', 'E'),
#   ('Bb:7', 'F#:min7', 'F#:minmaj7'),
#   ('C#:7', 'D', 'E:maj7'),
#   ('A', 'E:7', 'Eb:9'),
#   ('B:7', 'E:7/3', 'F#:min7'),
#   ('E:min', 'G#:min', 'G:min'),
#   ('A', 'Bb:7', 'C#:min'),
#   ('E', 'Eb:min', 'F#:min'),
#   ('E:7/3', 'F', 'N'),
#   ('A:maj7/5', 'B', 'F#:min7'),
#   ('B:maj6', 'D:9', 'N'),
#   ('Eb', 'F', 'F#:min7'),
#   ('D/2', 'E', 'E:9'),
#   ('A', 'Bb:7', 'E:aug'),
#   ('A:7', 'A:min', 'F#:9'),
#   ('E', 'E:aug', 'Eb:7'),
#   ('C#:7', 'F#:9', 'G'),
#   ('C', 'E:min', 'F#:9'),
#   ('B:min', 'D/3', 'F#'),
#   ('B:7', 'E:9', 'N'),
#   ('B:min', 'E:min', 'Eb:min'),
#   ('C#:7', 'E', 'F#'),
#   ('B:7', 'F#', 'N'),
#   ('E', 'G', 'G#:min7'),
#   ('A:maj7/5', 'B:maj6', 'Bb:7'),
#   ('C', 'F#:minmaj7', 'N'),
#   ('D/2', 'D/3', 'F'),
#   ('D/2', 'F#:min', 'G'),
#   ('B:maj6', 'C#:min', 'E'),
#   ('B', 'C#:min/5', 'F'),
#   ('Bb:7', 'F#:min', 'N'),
#   ('C:min6', 'E', 'G#:min7'),
#   ('A', 'C', 'E:aug'),
#   ('Bb:7', 'D', 'D/2'),
#   ('F#', 'F#:min', 'F#:minmaj7'),
#   ('Bb', 'E', 'F#:min7'),
#   ('A', 'C#:min', 'D/3'),
#   ('E:min', 'F#:min7', 'F#:minmaj7'),
#   ('A:maj7', 'C:min6', 'G#:min7'),
#   ('C', 'D/3', 'N'),
#   ('Bb:7', 'E:maj7', 'Eb'),
#   ('D', 'D:9', 'E'),
#   ('A', 'F', 'N'),
#   ('E', 'Eb:9', 'G#'),
#   ('Bb', 'C:min6', 'E'),
#   ('C#:min', 'Eb', 'Eb:min'),
#   ('B:maj6', 'C', 'N'),
#   ('B:min', 'Eb:min', 'F#'),
#   ('F', 'G:min', 'N'),
#   ('B:min', 'Bb', 'C#:min'),
#   ('B:7', 'D/3', 'F#:min'),
#   ('C:min6', 'E:maj7', 'F#:min'),
#   ('C#:min', 'E:min', 'F#'),
#   ('F#', 'G', 'G#:min'),
#   ('F:9', 'G#:min', 'N'),
#   ('A', 'A:min/b3', 'F#'),
#   ('A', 'A:maj7/5', 'B:maj6'),
#   ('B:maj6', 'F', 'G#:min'),
#   ('B:7', 'E', 'E:min'),
#   ('A:maj7', 'Bb:7', 'Eb'),
#   ('E:7', 'Eb:min', 'G:min'),
#   ('E', 'E:maj7', 'Eb:9'),
#   ('A:maj7', 'G#:min', 'G#:min7'),
#   ('A:min/b3', 'Bb', 'E'),
#   ('C:min6', 'D/2', 'D/3'),
#   ('C#:7', 'E', 'G#:min'),
#   ('D/3', 'Eb', 'Eb:min'),
#   ('Eb', 'F#', 'N'),
#   ('A:7', 'Eb', 'Eb:min'),
#   ('E', 'G#:min', 'G#:min7'),
#   ('B', 'E:9', 'G#:min'),
#   ('A:min/b3', 'B', 'F#:min7'),
#   ('A', 'C:min6', 'G#:min'),
#   ('B:min', 'F#', 'F#:minmaj7'),
#   ('Bb', 'Eb:9', 'F#'),
#   ('Eb:9', 'F:9', 'N'),
#   ('C#:7', 'E', 'F#:min7'),
#   ('C#:7', 'D', 'F#:minmaj7'),
#   ('D/2', 'G#:min', 'N'),
#   ('B:min', 'E', 'G#'),
#   ('A:min', 'B:7', 'E'),
#   ('Bb', 'Bb:7', 'G#:min7'),
#   ('A:7', 'E', 'G'),
#   ('E:7', 'E:min', 'G:min'),
#   ('E', 'E:7', 'F#'),
#   ('A', 'Eb:9', 'F#:9'),
#   ('A:7', 'C#:7', 'D'),
#   ('A', 'Bb', 'F#'),
#   ('C#:7', 'E:9', 'N'),
#   ('Eb:min', 'G#', 'N'),
#   ('Bb', 'D', 'D/3'),
#   ('Bb', 'E:aug', 'Eb:9'),
#   ('C', 'C#:min/5', 'E:min'),
#   ('Eb', 'G', 'G#:min'),
#   ('C#:7', 'F#', 'N'),
#   ('A:maj7/5', 'B:7', 'B:maj6'),
#   ('B:min', 'C#:min/5', 'F#'),
#   ('Bb', 'C', 'G#:min7'),
#   ('D', 'D/2', 'F#'),
#   ('B:maj6', 'B:min', 'G#:min'),
#   ('F#:min7', 'F#:minmaj7', 'G#:min'),
#   ('C#:min/5', 'F#:9', 'F#:min'),
#   ('A:maj7', 'Bb', 'Bb:7'),
#   ('A', 'C#:min', 'Eb'),
#   ('B:7', 'C#:min', 'F#:min7'),
#   ('A', 'A:maj7/5', 'E:7'),
#   ('A:maj7/5', 'B:maj6', 'D/3'),
#   ('E:maj7', 'F#:min', 'N'),
#   ('A', 'A:min/b3', 'F#:min7'),
#   ('D:9', 'E', 'F#'),
#   ('B', 'E:7', 'E:maj7'),
#   ('B:min', 'F#', 'G#:min7'),
#   ('E:aug', 'F#:min', 'F#:minmaj7'),
#   ('B', 'Eb:min', 'G#:min'),
#   ('Bb', 'Eb:9', 'G#:min'),
#   ('B:min', 'E:min', 'G#:min'),
#   ('Bb:7', 'C#:7', 'D'),
#   ('C#:7', 'D', 'G#:min7'),
#   ('A:min/b3', 'C#:min/5', 'F#:min'),
#   ('B:7', 'Bb', 'Eb:9'),
#   ('A', 'C', 'N'),
#   ('C:min6', 'D', 'D:9'),
#   ('Bb:7', 'Eb', 'F:9'),
#   ('C#:7', 'F:9', 'G'),
#   ('B:min', 'E', 'E:maj7'),
#   ('E', 'E:7', 'G#:min'),
#   ('A:min', 'C#:min', 'F'),
#   ('Bb', 'Eb:9', 'F#:min7'),
#   ('A:maj7/5', 'C#:7', 'G'),
#   ('A', 'C#:7', 'E:7/3'),
#   ('B:min', 'C#:min', 'F'),
#   ('A', 'C:min6', 'E:min'),
#   ('A', 'C#:min', 'F:9'),
#   ('B:min', 'D:9', 'F#'),
#   ('B:min', 'Bb', 'N'),
#   ('D', 'D/2', 'G#:min'),
#   ('F', 'F#:9', 'N'),
#   ('D/3', 'G', 'G#:min7'),
#   ('E', 'E:7', 'F#:min7'),
#   ('Bb', 'F#', 'F:9'),
#   ('E:7', 'Eb:min', 'N'),
#   ('A:min', 'B:maj6', 'C#:min'),
#   ('B', 'C', 'C#:min/5'),
#   ('D:9', 'E', 'G#:min'),
#   ('B:7', 'Eb', 'F#:min7'),
#   ('Bb', 'C#:min', 'Eb:9'),
#   ('Bb', 'Bb:7', 'F#:9'),
#   ('C', 'E:7/3', 'N'),
#   ('A', 'Eb', 'Eb:min'),
#   ('B:min', 'E', 'E:9'),
#   ('Eb:7', 'F#:min', 'F#:minmaj7'),
#   ('A:7', 'F#:min', 'G:min'),
#   ('Bb', 'C#:min/5', 'F#:min'),
#   ('B', 'D/3', 'E:maj7'),
#   ('C#:min/5', 'F#:min', 'G#:min'),
#   ('E:maj7', 'F#:min', 'F#:minmaj7'),
#   ('E', 'E:9', 'F:9'),
#   ('E', 'F#:minmaj7', 'G#:min'),
#   ('F#', 'G#:min', 'G:min'),
#   ('B:maj6', 'B:min', 'E:min'),
#   ('A:min', 'E', 'G#:min'),
#   ('Eb', 'F', 'F#:min'),
#   ('D:9', 'E', 'F#:min7'),
#   ('A:maj7/5', 'B:maj6', 'Eb'),
#   ('Bb', 'C', 'F#:9'),
#   ('A:min', 'C:min6', 'G'),
#   ('C', 'E:min', 'F#:min7'),
#   ('Eb:9', 'F:9', 'G#:min7'),
#   ('C', 'F:9', 'N'),
#   ('Eb:7', 'G', 'G:min'),
#   ('B', 'C', 'Eb:7'),
#   ('Bb:7', 'E', 'E:9'),
#   ('C:min6', 'F#:min7', 'F#:minmaj7'),
#   ('A:min', 'Eb', 'F#:9'),
#   ('D/3', 'Eb:9', 'G'),
#   ('Eb:9', 'F#:min7', 'F#:minmaj7'),
#   ('A:min/b3', 'Eb:min', 'N'),
#   ('B:maj6', 'E:9', 'G#:min'),
#   ('C#:7', 'E:maj7', 'F#:min7'),
#   ('B:maj6', 'F#', 'G#:min'),
#   ('Eb:9', 'F#:min', 'G'),
#   ('A:7', 'Bb:7', 'Eb'),
#   ('F#', 'F#:9', 'N'),
#   ('F#:minmaj7', 'G', 'G#:min'),
#   ('C#:min/5', 'D:9', 'N'),
#   ('Bb:7', 'Eb', 'G:min'),
#   ('C#:min', 'E:7', 'F#'),
#   ('A:maj7', 'E', 'Eb:min'),
#   ('A:min/b3', 'C#:7', 'G'),
#   ('D/2', 'D/3', 'G#'),
#   ('A', 'D/2', 'F#:9'),
#   ('A:7', 'G#:min', 'G:min'),
#   ('C#:min', 'G#', 'G#:min'),
#   ('B', 'E:maj7', 'F#'),
#   ('A:min', 'A:min/b3', 'G'),
#   ('C#:min/5', 'G#:min', 'G:min'),
#   ('A:maj7/5', 'D', 'D:9'),
#   ('A:min', 'C#:7', 'F#:9'),
#   ('C#:7', 'C#:min/5', 'F#:min'),
#   ('C#:7', 'C#:min', 'G'),
#   ('A', 'E:min', 'F:9'),
#   ('A', 'C#:min', 'G:min'),
#   ('Eb', 'Eb:min', 'G'),
#   ('B:maj6', 'G#:min', 'G#:min7'),
#   ('B', 'D:9', 'G#:min'),
#   ('B:7', 'B:min', 'F#'),
#   ('C', 'F#:min', 'G:min'),
#   ('A:maj7/5', 'F#:min', 'F#:minmaj7'),
#   ('B:7', 'F', 'F#:min7'),
#   ('Bb:7', 'E:9', 'N'),
#   ('A', 'A:maj7', 'C#:min'),
#   ('E', 'F#:9', 'F#:min7'),
#   ('D/3', 'F#:min7', 'F#:minmaj7'),
#   ('A:7', 'F#:min7', 'F#:minmaj7'),
#   ('A:maj7/5', 'A:min/b3', 'B:maj6'),
#   ('A', 'C#:min/5', 'Eb:7'),
#   ('B', 'Eb:9', 'F:9'),
#   ('C#:min/5', 'F#:min7', 'F#:minmaj7'),
#   ('D', 'D/2', 'E'),
#   ('A', 'A:maj7', 'E:aug'),
#   ('E', 'E:9', 'G:min'),
#   ('A:7', 'Bb', 'Bb:7'),
#   ('E:maj7', 'F#:min7', 'F:9'),
#   ('B', 'C#:7', 'F#:9'),
#   ('B', 'F#:min7', 'G'),
#   ('Bb', 'C#:7', 'G'),
#   ('A:min', 'Bb', 'G'),
#   ('E:aug', 'Eb', 'Eb:min'),
#   ('F#:min', 'F:9', 'G'),
#   ('C#:min', 'D/3', 'F#'),
#   ('D/2', 'D/3', 'E:maj7'),
#   ('A:min', 'C#:min', 'D/2'),
#   ('A:min', 'Eb:min', 'N'),
#   ('B', 'C#:min/5', 'E:maj7'),
#   ('D/3', 'E:aug', 'G'),
#   ('D', 'F#:min', 'F#:minmaj7'),
#   ('B:min', 'D:9', 'E:min'),
#   ('B:min', 'C#:min', 'D/2'),
#   ('Bb:7', 'Eb', 'Eb:9'),
#   ('E:7', 'F#:min', 'F#:minmaj7'),
#   ('A:min', 'F#:9', 'F#:min'),
#   ('C', 'C#:min', 'N'),
#   ('A:7', 'D', 'D/2'),
#   ('A', 'E:aug', 'F#'),
#   ('C', 'E:maj7', 'N'),
#   ('Bb', 'D', 'G:min'),
#   ('A:maj7/5', 'A:min', 'B:maj6'),
#   ('C:min6', 'Eb', 'Eb:min'),
#   ('E:9', 'Eb', 'F'),
#   ('Bb', 'Bb:7', 'C:min6'),
#   ('B:7', 'E:7', 'G:min'),
#   ('B:7', 'B:min', 'F#:min7'),
#   ('B:7', 'E:maj7', 'F#:min'),
#   ('F#:min', 'F#:minmaj7', 'G#'),
#   ('Bb:7', 'Eb:min', 'N'),
#   ('A', 'C#:min', 'Eb:9'),
#   ('B:maj6', 'E:7', 'G#:min'),
#   ('A', 'Bb:7', 'F#:9'),
#   ('C#:min', 'F#', 'F:9'),
#   ('B:maj6', 'E', 'F#'),
#   ('A', 'E:min', 'G:min'),
#   ('A:7', 'B:min', 'C#:min'),
#   ('C', 'F#:min7', 'F#:minmaj7'),
#   ('A:maj7', 'G#', 'G#:min7'),
#   ('B:7', 'Bb:7', 'F#:min7'),
#   ('B', 'E:7/3', 'E:maj7'),
#   ('B:min', 'E', 'E:7/3'),
#   ('D/2', 'E', 'G#:min'),
#   ('F#:min', 'F#:min7', 'G'),
#   ('A:min', 'C#:min', 'D:9'),
#   ('E', 'Eb:7', 'G#'),
#   ('Bb:7', 'C#:7', 'G'),
#   ('Bb', 'C', 'C:min6'),
#   ('Bb', 'D/3', 'F:9'),
#   ('A', 'A:min/b3', 'Bb:7'),
#   ('B:min', 'C#:min', 'D:9'),
#   ('A', 'C', 'F#:9'),
#   ('E:maj7', 'Eb', 'Eb:min'),
#   ('D', 'D:9', 'F'),
#   ('C#:min/5', 'G#:min', 'N'),
#   ('B', 'B:7', 'F#:9'),
#   ('A:min/b3', 'G', 'G#:min'),
#   ('E', 'E:9', 'Eb:9'),
#   ('C#:min/5', 'E:7', 'G'),
#   ('B:7', 'C', 'F#:min7'),
#   ('Bb:7', 'E', 'E:7/3'),
#   ('Bb', 'Bb:7', 'E:7'),
#   ('C', 'C#:7', 'E:min'),
#   ('E:maj7', 'F#:min7', 'G:min'),
#   ('A', 'E:7', 'F#'),
#   ('B:7', 'G', 'G#:min'),
#   ('E:7', 'G:min', 'N'),
#   ('A', 'G#', 'G#:min'),
#   ('B:maj6', 'F#:minmaj7', 'G#:min'),
#   ('A:min', 'C:min6', 'F#:min'),
#   ('E:min', 'Eb', 'F'),
#   ('B:7', 'Eb', 'F#:min'),
#   ('Bb', 'Bb:7', 'F#:min7'),
#   ('E', 'F:9', 'G#:min'),
#   ('A', 'E:aug', 'F#:min7'),
#   ('F:9', 'G', 'G#:min'),
#   ('F#:9', 'F#:min', 'G:min'),
#   ('Bb', 'C', 'E:7'),
#   ('A:maj7', 'E:9', 'N'),
#   ('D/2', 'D/3', 'F#:minmaj7'),
#   ('A:maj7/5', 'B:maj6', 'D:9'),
#   ('A:min/b3', 'E', 'Eb'),
#   ('A:maj7/5', 'B:7', 'F#:min'),
#   ('B:maj6', 'D:9', 'G#:min'),
#   ('B', 'B:7', 'C'),
#   ('B:7', 'E', 'F'),
#   ('C#:min/5', 'Eb:min', 'F#:min'),
#   ('E:min', 'Eb:9', 'F:9'),
#   ('A:7', 'B:7', 'E'),
#   ('A', 'Eb:7', 'F#:9'),
#   ('F#', 'F#:min', 'G'),
#   ...},
#  '102': {('A', 'A:7', 'A:maj7'),
#   ('A', 'A:7', 'A:maj7/5'),
#   ('A', 'A:7', 'A:min'),
#   ('A', 'A:7', 'B:7'),
#   ('A', 'A:7', 'B:maj6'),
#   ('A', 'A:7', 'Bb:7'),
#   ('A', 'A:7', 'C'),
#   ('A', 'A:7', 'C#:7'),
#   ('A', 'A:7', 'C:min6'),
#   ('A', 'A:7', 'D/2'),
#   ('A', 'A:7', 'D/3'),
#   ('A', 'A:7', 'D:9'),
#   ('A', 'A:7', 'E:9'),
#   ('A', 'A:7', 'Eb'),
#   ('A', 'A:7', 'Eb:7'),
#   ('A', 'A:7', 'Eb:9'),
#   ('A', 'A:7', 'Eb:min'),
#   ('A', 'A:7', 'F'),
#   ('A', 'A:7', 'F#'),
#   ('A', 'A:7', 'F#:min7'),
#   ('A', 'A:7', 'F#:minmaj7'),
#   ('A', 'A:7', 'F:9'),
#   ('A', 'A:7', 'G#'),
#   ('A', 'A:7', 'G:min'),
#   ('A', 'A:7', 'N'),
#   ('A', 'A:maj7', 'B'),
#   ('A', 'A:maj7', 'B:min'),
#   ('A', 'A:maj7', 'D'),
#   ('A', 'A:maj7', 'E:maj7'),
#   ('A', 'A:maj7', 'F#:min'),
#   ('A', 'A:maj7', 'G'),
#   ('A', 'A:maj7/5', 'B'),
#   ('A', 'A:maj7/5', 'B:min'),
#   ('A', 'A:maj7/5', 'D'),
#   ('A', 'A:maj7/5', 'E:maj7'),
#   ('A', 'A:maj7/5', 'F#:min'),
#   ('A', 'A:maj7/5', 'G'),
#   ('A', 'A:maj7/5', 'G#:min7'),
#   ('A', 'A:min', 'B'),
#   ('A', 'A:min', 'B:min'),
#   ('A', 'A:min', 'C'),
#   ('A', 'A:min', 'D'),
#   ('A', 'A:min', 'E'),
#   ('A', 'A:min', 'E:maj7'),
#   ('A', 'A:min', 'F#:min'),
#   ('A', 'A:min', 'G#:min7'),
#   ('A', 'B', 'B:7'),
#   ('A', 'B', 'B:maj6'),
#   ('A', 'B', 'Bb:7'),
#   ('A', 'B', 'C#:7'),
#   ('A', 'B', 'C:min6'),
#   ('A', 'B', 'D/2'),
#   ('A', 'B', 'D/3'),
#   ('A', 'B', 'D:9'),
#   ('A', 'B', 'E:9'),
#   ('A', 'B', 'Eb'),
#   ('A', 'B', 'Eb:7'),
#   ('A', 'B', 'Eb:9'),
#   ('A', 'B', 'Eb:min'),
#   ('A', 'B', 'F#'),
#   ('A', 'B', 'F#:minmaj7'),
#   ('A', 'B', 'F:9'),
#   ('A', 'B', 'G#'),
#   ('A', 'B', 'G:min'),
#   ('A', 'B:7', 'B:min'),
#   ('A', 'B:7', 'D'),
#   ('A', 'B:7', 'E:maj7'),
#   ('A', 'B:7', 'G'),
#   ('A', 'B:7', 'G#:min7'),
#   ('A', 'B:maj6', 'B:min'),
#   ('A', 'B:maj6', 'D'),
#   ('A', 'B:maj6', 'E'),
#   ('A', 'B:maj6', 'E:maj7'),
#   ('A', 'B:maj6', 'F#:min'),
#   ('A', 'B:maj6', 'G'),
#   ('A', 'B:maj6', 'G#:min7'),
#   ('A', 'B:min', 'Bb:7'),
#   ('A', 'B:min', 'C'),
#   ('A', 'B:min', 'C#:7'),
#   ('A', 'B:min', 'C:min6'),
#   ('A', 'B:min', 'D/2'),
#   ('A', 'B:min', 'D/3'),
#   ('A', 'B:min', 'D:9'),
#   ('A', 'B:min', 'E:9'),
#   ('A', 'B:min', 'Eb'),
#   ('A', 'B:min', 'Eb:7'),
#   ('A', 'B:min', 'Eb:9'),
#   ('A', 'B:min', 'Eb:min'),
#   ('A', 'B:min', 'F'),
#   ('A', 'B:min', 'F#:min7'),
#   ('A', 'B:min', 'F#:minmaj7'),
#   ('A', 'B:min', 'F:9'),
#   ('A', 'B:min', 'G#'),
#   ('A', 'B:min', 'G:min'),
#   ('A', 'B:min', 'N'),
#   ('A', 'Bb:7', 'D'),
#   ('A', 'Bb:7', 'E'),
#   ('A', 'Bb:7', 'E:maj7'),
#   ('A', 'Bb:7', 'F#:min'),
#   ('A', 'Bb:7', 'G'),
#   ('A', 'Bb:7', 'G#:min7'),
#   ('A', 'C', 'E'),
#   ('A', 'C', 'E:maj7'),
#   ('A', 'C', 'F'),
#   ('A', 'C', 'F#:min'),
#   ('A', 'C', 'G#:min7'),
#   ('A', 'C#:7', 'E'),
#   ('A', 'C#:7', 'E:maj7'),
#   ('A', 'C#:7', 'F#:min'),
#   ('A', 'C#:7', 'G#:min7'),
#   ('A', 'C:min6', 'D'),
#   ('A', 'C:min6', 'E:maj7'),
#   ('A', 'C:min6', 'G'),
#   ('A', 'C:min6', 'G#:min7'),
#   ('A', 'D', 'D/3'),
#   ('A', 'D', 'E:9'),
#   ('A', 'D', 'Eb'),
#   ('A', 'D', 'Eb:7'),
#   ('A', 'D', 'Eb:9'),
#   ('A', 'D', 'Eb:min'),
#   ('A', 'D', 'F'),
#   ('A', 'D', 'F#'),
#   ('A', 'D', 'F#:min7'),
#   ('A', 'D', 'F#:minmaj7'),
#   ('A', 'D', 'F:9'),
#   ('A', 'D', 'G#'),
#   ('A', 'D', 'G:min'),
#   ('A', 'D/2', 'E'),
#   ('A', 'D/2', 'E:maj7'),
#   ('A', 'D/2', 'F#:min'),
#   ('A', 'D/2', 'G'),
#   ('A', 'D/2', 'G#:min7'),
#   ('A', 'D/3', 'E'),
#   ('A', 'D/3', 'E:maj7'),
#   ('A', 'D/3', 'F#:min'),
#   ('A', 'D/3', 'G#:min7'),
#   ('A', 'D:9', 'E'),
#   ('A', 'D:9', 'E:maj7'),
#   ('A', 'D:9', 'F#:min'),
#   ('A', 'D:9', 'G'),
#   ('A', 'D:9', 'G#:min7'),
#   ('A', 'E', 'Eb'),
#   ('A', 'E', 'Eb:7'),
#   ('A', 'E', 'Eb:9'),
#   ('A', 'E', 'Eb:min'),
#   ('A', 'E', 'F'),
#   ('A', 'E', 'F#:minmaj7'),
#   ('A', 'E', 'F:9'),
#   ('A', 'E', 'G:min'),
#   ('A', 'E:9', 'E:maj7'),
#   ('A', 'E:9', 'F#:min'),
#   ('A', 'E:9', 'G'),
#   ('A', 'E:9', 'G#:min7'),
#   ('A', 'E:maj7', 'Eb'),
#   ('A', 'E:maj7', 'Eb:7'),
#   ('A', 'E:maj7', 'Eb:9'),
#   ('A', 'E:maj7', 'Eb:min'),
#   ('A', 'E:maj7', 'F'),
#   ('A', 'E:maj7', 'F#'),
#   ('A', 'E:maj7', 'F#:minmaj7'),
#   ('A', 'E:maj7', 'F:9'),
#   ('A', 'E:maj7', 'G#'),
#   ('A', 'E:maj7', 'G:min'),
#   ('A', 'E:maj7', 'N'),
#   ('A', 'Eb', 'F#:min'),
#   ('A', 'Eb', 'G'),
#   ('A', 'Eb', 'G#:min7'),
#   ('A', 'Eb:7', 'F#:min'),
#   ('A', 'Eb:7', 'G'),
#   ('A', 'Eb:7', 'G#:min7'),
#   ('A', 'Eb:9', 'F#:min'),
#   ('A', 'Eb:9', 'G'),
#   ('A', 'Eb:9', 'G#:min7'),
#   ('A', 'Eb:min', 'F#:min'),
#   ('A', 'Eb:min', 'G'),
#   ('A', 'Eb:min', 'G#:min7'),
#   ('A', 'F', 'F#:min'),
#   ('A', 'F', 'G#:min7'),
#   ('A', 'F#', 'F#:min'),
#   ('A', 'F#', 'G'),
#   ('A', 'F#', 'G#:min7'),
#   ('A', 'F#:min', 'F#:min7'),
#   ('A', 'F#:min', 'F:9'),
#   ('A', 'F#:min', 'G#'),
#   ('A', 'F#:min7', 'G'),
#   ('A', 'F#:minmaj7', 'G'),
#   ('A', 'F#:minmaj7', 'G#:min7'),
#   ('A', 'F:9', 'G'),
#   ('A', 'F:9', 'G#:min7'),
#   ('A', 'G', 'G#'),
#   ('A', 'G#', 'G#:min7'),
#   ('A', 'G#:min7', 'G:min'),
#   ('A', 'G#:min7', 'N'),
#   ('A:7', 'A:maj7/5', 'E'),
#   ('A:7', 'A:min', 'C'),
#   ('A:7', 'A:min', 'E:min'),
#   ('A:7', 'B', 'C#:min'),
#   ('A:7', 'B', 'E'),
#   ('A:7', 'B', 'F#:min'),
#   ('A:7', 'B', 'N'),
#   ('A:7', 'B:min', 'D'),
#   ('A:7', 'B:min', 'F#:min'),
#   ('A:7', 'Bb', 'Eb'),
#   ('A:7', 'Bb', 'Eb:7'),
#   ('A:7', 'Bb', 'F'),
#   ('A:7', 'C', 'D'),
#   ('A:7', 'C', 'F'),
#   ('A:7', 'C', 'G'),
#   ('A:7', 'C#:min', 'F#:min'),
#   ('A:7', 'D', 'E:min'),
#   ('A:7', 'D', 'G'),
#   ('A:7', 'D', 'N'),
#   ('A:7', 'E', 'N'),
#   ('A:7', 'E:min', 'G'),
#   ('A:7', 'E:min', 'N'),
#   ('A:7', 'F', 'G'),
#   ('A:7', 'F#:min7', 'G#:min7'),
#   ('A:7', 'G', 'N'),
#   ('A:maj7', 'A:min', 'C'),
#   ('A:maj7', 'A:min', 'E:min'),
#   ('A:maj7', 'B', 'C#:min'),
#   ('A:maj7', 'B', 'F#:min'),
#   ('A:maj7', 'B', 'N'),
#   ('A:maj7', 'B:min', 'D'),
#   ('A:maj7', 'B:min', 'F#:min'),
#   ('A:maj7', 'Bb', 'Eb'),
#   ('A:maj7', 'Bb', 'Eb:7'),
#   ('A:maj7', 'Bb', 'F'),
#   ('A:maj7', 'C', 'D'),
#   ('A:maj7', 'C', 'F'),
#   ('A:maj7', 'C', 'G'),
#   ('A:maj7', 'C#:min', 'F#:min'),
#   ('A:maj7', 'D', 'E:min'),
#   ('A:maj7', 'D', 'G'),
#   ('A:maj7', 'D', 'N'),
#   ('A:maj7', 'E:min', 'G'),
#   ('A:maj7', 'E:min', 'N'),
#   ('A:maj7', 'F', 'G'),
#   ('A:maj7', 'G', 'N'),
#   ('A:maj7/5', 'A:min', 'C'),
#   ('A:maj7/5', 'A:min', 'E'),
#   ('A:maj7/5', 'A:min', 'E:min'),
#   ('A:maj7/5', 'B', 'C#:min'),
#   ('A:maj7/5', 'B', 'F#:min'),
#   ('A:maj7/5', 'B', 'N'),
#   ('A:maj7/5', 'B:min', 'D'),
#   ('A:maj7/5', 'B:min', 'E'),
#   ('A:maj7/5', 'B:min', 'F#:min'),
#   ('A:maj7/5', 'Bb', 'E'),
#   ('A:maj7/5', 'Bb', 'Eb'),
#   ('A:maj7/5', 'Bb', 'Eb:7'),
#   ('A:maj7/5', 'Bb', 'F'),
#   ('A:maj7/5', 'Bb:7', 'E'),
#   ('A:maj7/5', 'C', 'D'),
#   ('A:maj7/5', 'C', 'E'),
#   ('A:maj7/5', 'C', 'F'),
#   ('A:maj7/5', 'C', 'G'),
#   ('A:maj7/5', 'C#:7', 'E'),
#   ('A:maj7/5', 'C#:min', 'F#:min'),
#   ('A:maj7/5', 'C#:min/5', 'E'),
#   ('A:maj7/5', 'D', 'E'),
#   ('A:maj7/5', 'D', 'E:min'),
#   ('A:maj7/5', 'D', 'G'),
#   ('A:maj7/5', 'D', 'N'),
#   ('A:maj7/5', 'D/2', 'E'),
#   ('A:maj7/5', 'D/3', 'E'),
#   ('A:maj7/5', 'D:9', 'E'),
#   ('A:maj7/5', 'E', 'E:7'),
#   ('A:maj7/5', 'E', 'E:min'),
#   ('A:maj7/5', 'E', 'Eb'),
#   ('A:maj7/5', 'E', 'Eb:7'),
#   ('A:maj7/5', 'E', 'Eb:9'),
#   ('A:maj7/5', 'E', 'Eb:min'),
#   ('A:maj7/5', 'E', 'F'),
#   ('A:maj7/5', 'E', 'F#:9'),
#   ('A:maj7/5', 'E', 'F#:minmaj7'),
#   ('A:maj7/5', 'E', 'F:9'),
#   ('A:maj7/5', 'E', 'G#:min7'),
#   ('A:maj7/5', 'E', 'G:min'),
#   ('A:maj7/5', 'E:min', 'G'),
#   ('A:maj7/5', 'E:min', 'N'),
#   ('A:maj7/5', 'F', 'G'),
#   ('A:maj7/5', 'F#:min7', 'G#:min7'),
#   ('A:maj7/5', 'G', 'N'),
#   ('A:min', 'A:min/b3', 'C'),
#   ('A:min', 'A:min/b3', 'E:min'),
#   ('A:min', 'B', 'E'),
#   ('A:min', 'B', 'E:min'),
#   ('A:min', 'B', 'F#:min'),
#   ('A:min', 'B', 'N'),
#   ('A:min', 'B:7', 'C'),
#   ('A:min', 'B:7', 'E:min'),
#   ('A:min', 'B:maj6', 'C'),
#   ('A:min', 'B:maj6', 'E:min'),
#   ('A:min', 'B:min', 'C'),
#   ('A:min', 'B:min', 'D'),
#   ('A:min', 'B:min', 'F#:min'),
#   ('A:min', 'Bb', 'E:min'),
#   ('A:min', 'Bb', 'Eb'),
#   ('A:min', 'Bb', 'Eb:7'),
#   ('A:min', 'Bb', 'F'),
#   ('A:min', 'Bb:7', 'C'),
#   ('A:min', 'Bb:7', 'E:min'),
#   ('A:min', 'C', 'C#:7'),
#   ('A:min', 'C', 'C#:min/5'),
#   ('A:min', 'C', 'C:min6'),
#   ('A:min', 'C', 'D/2'),
#   ('A:min', 'C', 'D/3'),
#   ('A:min', 'C', 'D:9'),
#   ('A:min', 'C', 'E'),
#   ('A:min', 'C', 'E:7'),
#   ('A:min', 'C', 'E:7/3'),
#   ('A:min', 'C', 'E:9'),
#   ('A:min', 'C', 'E:aug'),
#   ('A:min', 'C', 'E:maj7'),
#   ('A:min', 'C', 'Eb'),
#   ('A:min', 'C', 'Eb:7'),
#   ('A:min', 'C', 'Eb:9'),
#   ('A:min', 'C', 'Eb:min'),
#   ('A:min', 'C', 'F#'),
#   ('A:min', 'C', 'F#:min'),
#   ('A:min', 'C', 'F#:min7'),
#   ('A:min', 'C', 'F#:minmaj7'),
#   ('A:min', 'C', 'F:9'),
#   ('A:min', 'C', 'G#'),
#   ('A:min', 'C', 'G#:min'),
#   ('A:min', 'C', 'G#:min7'),
#   ('A:min', 'C', 'G:min'),
#   ('A:min', 'C#:7', 'E:min'),
#   ('A:min', 'C#:min/5', 'E:min'),
#   ('A:min', 'C:min6', 'E:min'),
#   ('A:min', 'D', 'N'),
#   ('A:min', 'D/2', 'E:min'),
#   ('A:min', 'D/3', 'E:min'),
#   ('A:min', 'D:9', 'E:min'),
#   ('A:min', 'E', 'E:min'),
#   ('A:min', 'E', 'N'),
#   ('A:min', 'E:7', 'E:min'),
#   ('A:min', 'E:7/3', 'E:min'),
#   ('A:min', 'E:9', 'E:min'),
#   ('A:min', 'E:aug', 'E:min'),
#   ('A:min', 'E:maj7', 'E:min'),
#   ('A:min', 'E:min', 'Eb'),
#   ('A:min', 'E:min', 'Eb:7'),
#   ('A:min', 'E:min', 'Eb:9'),
#   ('A:min', 'E:min', 'Eb:min'),
#   ('A:min', 'E:min', 'F'),
#   ('A:min', 'E:min', 'F#'),
#   ('A:min', 'E:min', 'F#:min'),
#   ('A:min', 'E:min', 'F#:min7'),
#   ('A:min', 'E:min', 'F#:minmaj7'),
#   ('A:min', 'E:min', 'F:9'),
#   ('A:min', 'E:min', 'G#'),
#   ('A:min', 'E:min', 'G#:min'),
#   ('A:min', 'E:min', 'G#:min7'),
#   ('A:min', 'E:min', 'G:min'),
#   ('A:min', 'F#:min7', 'G#:min7'),
#   ('A:min/b3', 'B', 'C#:min'),
#   ('A:min/b3', 'B', 'F#:min'),
#   ('A:min/b3', 'B', 'N'),
#   ('A:min/b3', 'B:min', 'D'),
#   ('A:min/b3', 'B:min', 'F#:min'),
#   ('A:min/b3', 'Bb', 'Eb'),
#   ('A:min/b3', 'Bb', 'Eb:7'),
#   ('A:min/b3', 'Bb', 'F'),
#   ('A:min/b3', 'C', 'D'),
#   ('A:min/b3', 'C', 'F'),
#   ('A:min/b3', 'C', 'G'),
#   ('A:min/b3', 'C#:min', 'F#:min'),
#   ('A:min/b3', 'D', 'E:min'),
#   ('A:min/b3', 'D', 'G'),
#   ('A:min/b3', 'D', 'N'),
#   ('A:min/b3', 'E:min', 'G'),
#   ('A:min/b3', 'E:min', 'N'),
#   ('A:min/b3', 'F', 'G'),
#   ('A:min/b3', 'F#:min7', 'G#:min7'),
#   ('A:min/b3', 'G', 'N'),
#   ('B', 'B:7', 'C#:min'),
#   ('B', 'B:7', 'N'),
#   ('B', 'B:maj6', 'C#:min'),
#   ('B', 'B:maj6', 'E'),
#   ('B', 'B:maj6', 'F#:min'),
#   ('B', 'B:maj6', 'N'),
#   ('B', 'B:min', 'D'),
#   ('B', 'B:min', 'E'),
#   ('B', 'B:min', 'N'),
#   ('B', 'Bb', 'C#:min'),
#   ('B', 'Bb', 'E'),
#   ('B', 'Bb', 'Eb'),
#   ('B', 'Bb', 'Eb:7'),
#   ('B', 'Bb', 'F#:min'),
#   ('B', 'Bb:7', 'C#:min'),
#   ('B', 'Bb:7', 'E'),
#   ('B', 'Bb:7', 'F#:min'),
#   ('B', 'Bb:7', 'N'),
#   ('B', 'C#:7', 'C#:min'),
#   ('B', 'C#:7', 'E'),
#   ('B', 'C#:7', 'F#:min'),
#   ('B', 'C#:7', 'N'),
#   ('B', 'C#:min', 'C#:min/5'),
#   ('B', 'C#:min', 'C:min6'),
#   ('B', 'C#:min', 'D'),
#   ('B', 'C#:min', 'D/2'),
#   ('B', 'C#:min', 'D/3'),
#   ('B', 'C#:min', 'D:9'),
#   ('B', 'C#:min', 'E:7'),
#   ('B', 'C#:min', 'E:7/3'),
#   ('B', 'C#:min', 'E:9'),
#   ('B', 'C#:min', 'E:aug'),
#   ('B', 'C#:min', 'E:min'),
#   ('B', 'C#:min', 'Eb'),
#   ('B', 'C#:min', 'Eb:7'),
#   ('B', 'C#:min', 'Eb:9'),
#   ('B', 'C#:min', 'Eb:min'),
#   ('B', 'C#:min', 'F#:minmaj7'),
#   ('B', 'C#:min', 'F:9'),
#   ('B', 'C#:min', 'G'),
#   ('B', 'C#:min', 'G#:min7'),
#   ('B', 'C#:min', 'G:min'),
#   ('B', 'C#:min/5', 'E'),
#   ('B', 'C#:min/5', 'N'),
#   ('B', 'C:min6', 'N'),
#   ('B', 'D', 'E'),
#   ('B', 'D', 'E:min'),
#   ('B', 'D', 'F#:min'),
#   ('B', 'D', 'G'),
#   ('B', 'D/2', 'E'),
#   ('B', 'D/2', 'F#:min'),
#   ('B', 'D/2', 'N'),
#   ('B', 'D/3', 'E'),
#   ('B', 'D/3', 'F#:min'),
#   ('B', 'D/3', 'N'),
#   ('B', 'D:9', 'E'),
#   ('B', 'D:9', 'F#:min'),
#   ('B', 'E', 'E:7'),
#   ('B', 'E', 'E:min'),
#   ('B', 'E', 'Eb'),
#   ('B', 'E', 'Eb:7'),
#   ('B', 'E', 'Eb:9'),
#   ('B', 'E', 'Eb:min'),
#   ('B', 'E', 'F#:minmaj7'),
#   ('B', 'E', 'F:9'),
#   ('B', 'E', 'G#:min7'),
#   ('B', 'E', 'G:min'),
#   ('B', 'E:7', 'F#:min'),
#   ('B', 'E:7', 'N'),
#   ('B', 'E:7/3', 'F#:min'),
#   ('B', 'E:7/3', 'N'),
#   ('B', 'E:9', 'F#:min'),
#   ('B', 'E:aug', 'F#:min'),
#   ('B', 'E:aug', 'N'),
#   ('B', 'E:min', 'F#:min'),
#   ('B', 'E:min', 'G'),
#   ('B', 'Eb', 'F#:min'),
#   ('B', 'Eb', 'N'),
#   ('B', 'Eb:7', 'F#:min'),
#   ('B', 'Eb:7', 'N'),
#   ('B', 'Eb:9', 'F#:min'),
#   ('B', 'Eb:9', 'N'),
#   ('B', 'Eb:min', 'F#:min'),
#   ('B', 'F#', 'F#:min'),
#   ('B', 'F#:min', 'F:9'),
#   ('B', 'F#:min', 'G#'),
#   ('B', 'F#:min', 'G#:min7'),
#   ('B', 'F#:minmaj7', 'N'),
#   ('B', 'F:9', 'N'),
#   ('B', 'G#', 'N'),
#   ('B', 'G#:min7', 'N'),
#   ('B', 'G:min', 'N'),
#   ('B:7', 'B:min', 'D'),
#   ('B:7', 'Bb', 'Eb'),
#   ('B:7', 'Bb', 'Eb:7'),
#   ('B:7', 'Bb', 'F'),
#   ('B:7', 'C', 'D'),
#   ('B:7', 'C', 'F'),
#   ('B:7', 'C', 'G'),
#   ('B:7', 'D', 'E:min'),
#   ('B:7', 'D', 'G'),
#   ('B:7', 'D', 'N'),
#   ('B:7', 'E:min', 'G'),
#   ('B:7', 'E:min', 'N'),
#   ('B:7', 'F', 'G'),
#   ('B:7', 'G', 'N'),
#   ('B:maj6', 'B:min', 'D'),
#   ('B:maj6', 'B:min', 'F#:min'),
#   ('B:maj6', 'Bb', 'Eb'),
#   ('B:maj6', 'Bb', 'Eb:7'),
#   ('B:maj6', 'Bb', 'F'),
#   ('B:maj6', 'C', 'D'),
#   ('B:maj6', 'C', 'F'),
#   ('B:maj6', 'C', 'G'),
#   ('B:maj6', 'C#:min', 'F#:min'),
#   ('B:maj6', 'D', 'E:min'),
#   ('B:maj6', 'D', 'G'),
#   ('B:maj6', 'D', 'N'),
#   ('B:maj6', 'E', 'N'),
#   ('B:maj6', 'E:min', 'G'),
#   ('B:maj6', 'E:min', 'N'),
#   ('B:maj6', 'F', 'G'),
#   ('B:maj6', 'F#:min7', 'G#:min7'),
#   ('B:maj6', 'G', 'N'),
#   ('B:min', 'Bb', 'Eb'),
#   ('B:min', 'Bb', 'Eb:7'),
#   ('B:min', 'Bb', 'F'),
#   ('B:min', 'Bb', 'F#:min'),
#   ('B:min', 'Bb:7', 'D'),
#   ('B:min', 'Bb:7', 'F#:min'),
#   ('B:min', 'C', 'F'),
#   ('B:min', 'C', 'F#:min'),
#   ('B:min', 'C', 'G'),
#   ('B:min', 'C#:7', 'F#:min'),
#   ('B:min', 'C#:min/5', 'D'),
#   ('B:min', 'C:min6', 'D'),
#   ('B:min', 'D', 'D/3'),
#   ('B:min', 'D', 'E'),
#   ('B:min', 'D', 'E:7'),
#   ('B:min', 'D', 'E:7/3'),
#   ('B:min', 'D', 'E:9'),
#   ('B:min', 'D', 'E:aug'),
#   ('B:min', 'D', 'E:maj7'),
#   ('B:min', 'D', 'Eb'),
#   ('B:min', 'D', 'Eb:7'),
#   ('B:min', 'D', 'Eb:9'),
#   ('B:min', 'D', 'Eb:min'),
#   ('B:min', 'D', 'F'),
#   ('B:min', 'D', 'F#:9'),
#   ('B:min', 'D', 'F#:min7'),
#   ('B:min', 'D', 'F#:minmaj7'),
#   ('B:min', 'D', 'F:9'),
#   ('B:min', 'D', 'G#'),
#   ('B:min', 'D', 'G#:min'),
#   ('B:min', 'D', 'G#:min7'),
#   ('B:min', 'D', 'G:min'),
#   ('B:min', 'D/2', 'F#:min'),
#   ('B:min', 'D/3', 'F#:min'),
#   ('B:min', 'D:9', 'F#:min'),
#   ('B:min', 'E', 'N'),
#   ('B:min', 'E:7', 'F#:min'),
#   ('B:min', 'E:7/3', 'F#:min'),
#   ('B:min', 'E:9', 'F#:min'),
#   ('B:min', 'E:aug', 'F#:min'),
#   ('B:min', 'E:maj7', 'F#:min'),
#   ('B:min', 'Eb', 'F#:min'),
#   ('B:min', 'Eb:7', 'F#:min'),
#   ('B:min', 'Eb:9', 'F#:min'),
#   ('B:min', 'Eb:min', 'F#:min'),
#   ('B:min', 'F', 'F#:min'),
#   ('B:min', 'F', 'G'),
#   ('B:min', 'F#:9', 'F#:min'),
#   ('B:min', 'F#:min', 'F#:min7'),
#   ('B:min', 'F#:min', 'F:9'),
#   ('B:min', 'F#:min', 'G#'),
#   ('B:min', 'F#:min', 'G#:min'),
#   ('B:min', 'F#:min', 'G#:min7'),
#   ('B:min', 'F#:min7', 'G#:min7'),
#   ('B:min', 'G', 'N'),
#   ('Bb', 'C#:7', 'Eb'),
#   ('Bb', 'C#:7', 'Eb:7'),
#   ('Bb', 'C#:7', 'F'),
#   ('Bb', 'C#:min', 'Eb'),
#   ('Bb', 'C#:min', 'Eb:7'),
#   ('Bb', 'C#:min', 'F'),
#   ('Bb', 'C#:min', 'F#:min'),
#   ('Bb', 'C#:min/5', 'Eb'),
#   ('Bb', 'C#:min/5', 'Eb:7'),
#   ('Bb', 'C#:min/5', 'F'),
#   ('Bb', 'C:min6', 'Eb'),
#   ('Bb', 'C:min6', 'Eb:7'),
#   ('Bb', 'C:min6', 'F'),
#   ('Bb', 'D/2', 'Eb'),
#   ('Bb', 'D/2', 'Eb:7'),
#   ('Bb', 'D/2', 'F'),
#   ('Bb', 'D/3', 'Eb'),
#   ('Bb', 'D/3', 'Eb:7'),
#   ('Bb', 'D/3', 'F'),
#   ('Bb', 'D:9', 'Eb'),
#   ('Bb', 'D:9', 'Eb:7'),
#   ('Bb', 'D:9', 'F'),
#   ('Bb', 'E', 'Eb'),
#   ('Bb', 'E', 'Eb:7'),
#   ('Bb', 'E', 'F'),
#   ('Bb', 'E:7', 'Eb'),
#   ('Bb', 'E:7', 'Eb:7'),
#   ('Bb', 'E:7', 'F'),
#   ('Bb', 'E:7/3', 'Eb'),
#   ('Bb', 'E:7/3', 'Eb:7'),
#   ('Bb', 'E:7/3', 'F'),
#   ('Bb', 'E:9', 'Eb'),
#   ('Bb', 'E:9', 'Eb:7'),
#   ('Bb', 'E:9', 'F'),
#   ('Bb', 'E:aug', 'Eb'),
#   ('Bb', 'E:aug', 'Eb:7'),
#   ('Bb', 'E:aug', 'F'),
#   ('Bb', 'E:maj7', 'Eb'),
#   ('Bb', 'E:maj7', 'Eb:7'),
#   ('Bb', 'E:maj7', 'F'),
#   ('Bb', 'E:min', 'Eb'),
#   ('Bb', 'E:min', 'Eb:7'),
#   ('Bb', 'E:min', 'F'),
#   ('Bb', 'E:min', 'G'),
#   ('Bb', 'Eb', 'F#'),
#   ('Bb', 'Eb', 'F#:9'),
#   ('Bb', 'Eb', 'F#:min'),
#   ('Bb', 'Eb', 'F#:min7'),
#   ('Bb', 'Eb', 'F#:minmaj7'),
#   ('Bb', 'Eb', 'G'),
#   ('Bb', 'Eb', 'G#'),
#   ('Bb', 'Eb', 'G#:min'),
#   ('Bb', 'Eb', 'G#:min7'),
#   ('Bb', 'Eb', 'G:min'),
#   ('Bb', 'Eb:7', 'Eb:min'),
#   ('Bb', 'Eb:7', 'F#'),
#   ('Bb', 'Eb:7', 'F#:9'),
#   ('Bb', 'Eb:7', 'F#:min'),
#   ('Bb', 'Eb:7', 'F#:min7'),
#   ('Bb', 'Eb:7', 'F#:minmaj7'),
#   ('Bb', 'Eb:7', 'G'),
#   ('Bb', 'Eb:7', 'G#'),
#   ('Bb', 'Eb:7', 'G#:min'),
#   ('Bb', 'Eb:7', 'G#:min7'),
#   ('Bb', 'Eb:7', 'G:min'),
#   ('Bb', 'Eb:min', 'F'),
#   ('Bb', 'F', 'F#'),
#   ('Bb', 'F', 'F#:9'),
#   ('Bb', 'F', 'F#:min'),
#   ('Bb', 'F', 'F#:min7'),
#   ('Bb', 'F', 'F#:minmaj7'),
#   ('Bb', 'F', 'G#'),
#   ('Bb', 'F', 'G#:min'),
#   ('Bb', 'F', 'G#:min7'),
#   ('Bb', 'F', 'G:min'),
#   ('Bb', 'F#:min7', 'G#:min7'),
#   ('Bb:7', 'C', 'D'),
#   ('Bb:7', 'C', 'F'),
#   ('Bb:7', 'C', 'G'),
#   ('Bb:7', 'C#:min', 'F#:min'),
#   ('Bb:7', 'D', 'E:min'),
#   ('Bb:7', 'D', 'G'),
#   ('Bb:7', 'D', 'N'),
#   ('Bb:7', 'E', 'N'),
#   ('Bb:7', 'E:min', 'G'),
#   ('Bb:7', 'E:min', 'N'),
#   ('Bb:7', 'F', 'G'),
#   ('Bb:7', 'F#:min7', 'G#:min7'),
#   ('Bb:7', 'G', 'N'),
#   ('C', 'C#:7', 'F'),
#   ('C', 'C#:min', 'D'),
#   ('C', 'C#:min', 'F'),
#   ('C', 'C#:min', 'F#:min'),
#   ('C', 'C#:min', 'G'),
#   ('C', 'C#:min/5', 'D'),
#   ('C', 'C#:min/5', 'F'),
#   ('C', 'C#:min/5', 'G'),
#   ('C', 'C:min6', 'D'),
#   ('C', 'C:min6', 'F'),
#   ('C', 'C:min6', 'G'),
#   ('C', 'D', 'D/3'),
#   ('C', 'D', 'E'),
#   ('C', 'D', 'E:7'),
#   ('C', 'D', 'E:7/3'),
#   ('C', 'D', 'E:9'),
#   ('C', 'D', 'E:aug'),
#   ('C', 'D', 'E:maj7'),
#   ('C', 'D', 'Eb'),
#   ('C', 'D', 'Eb:7'),
#   ('C', 'D', 'Eb:9'),
#   ('C', 'D', 'Eb:min'),
#   ('C', 'D', 'F#'),
#   ('C', 'D', 'F#:9'),
#   ('C', 'D', 'F#:min'),
#   ('C', 'D', 'F#:min7'),
#   ('C', 'D', 'F#:minmaj7'),
#   ('C', 'D', 'F:9'),
#   ('C', 'D', 'G#'),
#   ('C', 'D', 'G#:min'),
#   ('C', 'D', 'G#:min7'),
#   ('C', 'D', 'G:min'),
#   ('C', 'D/2', 'F'),
#   ('C', 'D/2', 'G'),
#   ('C', 'D/3', 'F'),
#   ('C', 'D:9', 'F'),
#   ('C', 'D:9', 'G'),
#   ('C', 'E', 'F'),
#   ('C', 'E:7', 'F'),
#   ('C', 'E:7/3', 'F'),
#   ('C', 'E:7/3', 'G'),
#   ('C', 'E:9', 'F'),
#   ('C', 'E:9', 'G'),
#   ('C', 'E:aug', 'F'),
#   ('C', 'E:aug', 'G'),
#   ('C', 'E:maj7', 'F'),
#   ('C', 'E:maj7', 'G'),
#   ('C', 'Eb', 'G'),
#   ('C', 'Eb:7', 'F'),
#   ('C', 'Eb:7', 'G'),
#   ('C', 'Eb:9', 'F'),
#   ('C', 'Eb:9', 'G'),
#   ('C', 'Eb:min', 'F'),
#   ('C', 'Eb:min', 'G'),
#   ('C', 'F', 'F#'),
#   ('C', 'F', 'F#:9'),
#   ('C', 'F', 'F#:min'),
#   ('C', 'F', 'F#:min7'),
#   ('C', 'F', 'F#:minmaj7'),
#   ('C', 'F', 'F:9'),
#   ('C', 'F', 'G#'),
#   ('C', 'F', 'G#:min'),
#   ('C', 'F', 'G#:min7'),
#   ('C', 'F', 'G:min'),
#   ('C', 'F#', 'G'),
#   ('C', 'F#:9', 'G'),
#   ('C', 'F#:min7', 'G'),
#   ('C', 'F#:min7', 'G#:min7'),
#   ('C', 'F#:minmaj7', 'G'),
#   ('C', 'F:9', 'G'),
#   ('C', 'G', 'G#'),
#   ('C', 'G', 'G#:min7'),
#   ('C#:7', 'C#:min', 'F#:min'),
#   ('C#:7', 'E', 'N'),
#   ('C#:7', 'E:min', 'N'),
#   ('C#:7', 'F#:min7', 'G#:min7'),
#   ('C#:min', 'D', 'E:min'),
#   ('C#:min', 'D', 'F#:min'),
#   ('C#:min', 'D', 'G'),
#   ('C#:min', 'D', 'N'),
#   ('C#:min', 'D/2', 'F#:min'),
#   ('C#:min', 'D/3', 'F#:min'),
#   ('C#:min', 'D:9', 'F#:min'),
#   ('C#:min', 'E:7', 'F#:min'),
#   ('C#:min', 'E:7/3', 'F#:min'),
#   ('C#:min', 'E:9', 'F#:min'),
#   ('C#:min', 'E:aug', 'F#:min'),
#   ('C#:min', 'E:maj7', 'F#:min'),
#   ('C#:min', 'E:min', 'F#:min'),
#   ('C#:min', 'E:min', 'G'),
#   ('C#:min', 'E:min', 'N'),
#   ('C#:min', 'Eb', 'F#:min'),
#   ('C#:min', 'Eb:7', 'F#:min'),
#   ('C#:min', 'Eb:9', 'F#:min'),
#   ('C#:min', 'Eb:min', 'F#:min'),
#   ('C#:min', 'F', 'F#:min'),
#   ('C#:min', 'F', 'G'),
#   ('C#:min', 'F#:9', 'F#:min'),
#   ('C#:min', 'F#:min', 'F#:min7'),
#   ('C#:min', 'F#:min', 'F:9'),
#   ('C#:min', 'F#:min', 'G#:min'),
#   ('C#:min', 'F#:min', 'G#:min7'),
#   ('C#:min', 'F#:min7', 'G#:min7'),
#   ('C#:min', 'G', 'N'),
#   ('C#:min/5', 'D', 'E:min'),
#   ('C#:min/5', 'D', 'G'),
#   ('C#:min/5', 'D', 'N'),
#   ('C#:min/5', 'E', 'N'),
#   ('C#:min/5', 'E:min', 'G'),
#   ('C#:min/5', 'E:min', 'N'),
#   ('C#:min/5', 'F', 'G'),
#   ('C#:min/5', 'F#:min7', 'G#:min7'),
#   ('C#:min/5', 'G', 'N'),
#   ('C:min6', 'D', 'E:min'),
#   ('C:min6', 'D', 'G'),
#   ('C:min6', 'D', 'N'),
#   ('C:min6', 'E:min', 'G'),
#   ('C:min6', 'E:min', 'N'),
#   ('C:min6', 'F', 'G'),
#   ('C:min6', 'F#:min7', 'G#:min7'),
#   ('C:min6', 'G', 'N'),
#   ('D', 'D/3', 'E:min'),
#   ('D', 'D/3', 'N'),
#   ('D', 'E', 'E:min'),
#   ('D', 'E:7', 'E:min'),
#   ('D', 'E:7', 'N'),
#   ('D', 'E:7/3', 'E:min'),
#   ('D', 'E:7/3', 'G'),
#   ('D', 'E:7/3', 'N'),
#   ('D', 'E:9', 'E:min'),
#   ('D', 'E:9', 'G'),
#   ('D', 'E:aug', 'E:min'),
#   ('D', 'E:aug', 'G'),
#   ('D', 'E:aug', 'N'),
#   ('D', 'E:maj7', 'E:min'),
#   ('D', 'E:maj7', 'G'),
#   ('D', 'E:maj7', 'N'),
#   ('D', 'E:min', 'Eb'),
#   ('D', 'E:min', 'Eb:7'),
#   ('D', 'E:min', 'Eb:9'),
#   ('D', 'E:min', 'Eb:min'),
#   ('D', 'E:min', 'F'),
#   ('D', 'E:min', 'F#'),
# ...
#   ('E:7', 'F#:minmaj7', 'A:7'),
#   ('F', 'Bb', 'Eb:min'),
#   ('E:min', 'G:min', 'B:maj6'),
#   ('G', 'E:min', 'F#:9'),
#   ('A', 'E:min', 'A:maj7/5'),
#   ('A:min', 'G#:min7', 'A:maj7'),
#   ('D/2', 'F#:min', 'D:9'),
#   ('Eb:7', 'F:9', 'G#:min7'),
#   ('A:min/b3', 'C', 'F#:min'),
#   ('N', 'E:min', 'F:9'),
#   ('Bb', 'C#:min', 'B:maj6'),
#   ('E', 'D/2', 'C#:7'),
#   ('C', 'Eb:7', 'A:7'),
#   ('E', 'C', 'F#:9'),
#   ('A:min', 'B:min', 'F#:min7'),
#   ('B:7', 'A:maj7/5', 'A:7'),
#   ('N', 'C', 'G#:min7'),
#   ('A:min/b3', 'G:min', 'Bb'),
#   ('D', 'F#:9', 'F#:minmaj7'),
#   ('E:7/3', 'F:9', 'F#'),
#   ('E:aug', 'A:maj7', 'F#:minmaj7'),
#   ('A', 'D/2', 'B:7'),
#   ('A', 'A:min', 'F#'),
#   ('F:9', 'G#:min', 'C#:min/5'),
#   ('A:min/b3', 'Bb', 'D:9'),
#   ('G', 'G#', 'A:maj7'),
#   ('D/3', 'A:maj7', 'F#'),
#   ('E:min', 'Eb', 'D:9'),
#   ('D/3', 'Eb:9', 'C#:7'),
#   ('F#:9', 'C:min6', 'F#'),
#   ('Bb', 'G#:min', 'D:9'),
#   ('E:7/3', 'E:9', 'A:7'),
#   ('E:9', 'G#:min', 'C#:min/5'),
#   ('E:maj7', 'F#:min7', 'A:maj7/5'),
#   ('E:maj7', 'G#:min', 'A:7'),
#   ('E', 'Eb:min', 'G#:min7'),
#   ('G', 'G:min', 'A:maj7/5'),
#   ('A:min', 'D', 'Eb:9'),
#   ('D', 'Eb:7', 'G#:min7'),
#   ('N', 'Eb', 'B:maj6'),
#   ('C', 'D/3', 'B:7'),
#   ('B:maj6', 'F#:min', 'D:9'),
#   ('C', 'F#:9', 'A:maj7'),
#   ('Eb:7', 'Eb:9', 'B:7'),
#   ('F#:minmaj7', 'F#', 'D:9'),
#   ('A:min', 'G#:min', 'C#:7'),
#   ('N', 'E:7/3', 'E:9'),
#   ('N', 'F', 'C'),
#   ('E:9', 'F', 'D:9'),
#   ('N', 'A:min', 'G#:min'),
#   ('N', 'Eb:min', 'E:aug'),
#   ('E', 'F:9', 'F#:min'),
#   ('Eb:7', 'E:maj7', 'F#:minmaj7'),
#   ('B', 'Bb:7', 'D:9'),
#   ('D', 'A:maj7/5', 'F#:min'),
#   ('Eb', 'Eb:min', 'C#:7'),
#   ('Eb', 'B:maj6', 'C#:7'),
#   ('F:9', 'Eb:9', 'F#:minmaj7'),
#   ('E:7/3', 'F:9', 'G#:min'),
#   ('A:min/b3', 'D/3', 'G#:min7'),
#   ('E:7/3', 'C#:7', 'C:min6'),
#   ('G', 'E:7', 'A:maj7'),
#   ('E:9', 'Eb:9', 'F#:minmaj7'),
#   ('D/3', 'A:maj7', 'G#:min'),
#   ('B', 'G#:min7', 'B:7'),
#   ('E', 'E:aug', 'A:maj7/5'),
#   ('E:9', 'F', 'Eb:9'),
#   ('B', 'D', 'Eb:9'),
#   ('B', 'Bb:7', 'G#'),
#   ('E:7/3', 'E:7', 'Bb:7'),
#   ('E:7/3', 'Bb', 'B:7'),
#   ('F', 'G#', 'A:maj7/5'),
#   ('B:min', 'D/3', 'G:min'),
#   ('G', 'D/2', 'E:maj7'),
#   ('C', 'Eb:9', 'B:maj6'),
#   ('F#:9', 'A:maj7/5', 'C:min6'),
#   ('B:min', 'D/3', 'E:aug'),
#   ('N', 'E:min', 'G:min'),
#   ('E:maj7', 'G#:min7', 'G#'),
#   ('E', 'D', 'B:maj6'),
#   ('E', 'F', 'E:7'),
#   ('C', 'C#:min/5', 'D:9'),
#   ('E:9', 'D/3', 'E:7'),
#   ('N', 'E:min', 'E:aug'),
#   ('G', 'Bb:7', 'E:aug'),
#   ('E:7/3', 'Eb:min', 'A:maj7'),
#   ('Eb', 'C:min6', 'F#'),
#   ('A:min', 'F:9', 'F#'),
#   ('E:9', 'A:min', 'Eb:min'),
#   ('D/2', 'F#:9', 'C#:7'),
#   ('F', 'B:min', 'Bb:7'),
#   ('G', 'G#:min7', 'F#:9'),
#   ('B:min', 'Eb', 'B:maj6'),
#   ('A', 'B:min', 'B:7'),
#   ('Eb:9', 'Eb:min', 'F#:min'),
#   ('G', 'Bb', 'D:9'),
#   ('Eb:9', 'B:maj6', 'F#:min'),
#   ('E:maj7', 'A:maj7', 'A:maj7/5'),
#   ('N', 'C', 'F#:9'),
#   ('B:min', 'Bb:7', 'E:maj7'),
#   ('E:7', 'A:maj7/5', 'D:9'),
#   ('D', 'Eb:9', 'D:9'),
#   ('E', 'B:min', 'C:min6'),
#   ('E', 'Bb:7', 'F#'),
#   ('E:9', 'D/3', 'F#:min7'),
#   ('G', 'F#:minmaj7', 'A:7'),
#   ('B', 'G#:min', 'C:min6'),
#   ('C', 'Bb', 'C#:min'),
#   ('D/3', 'E:aug', 'C#:7'),
#   ('Eb:7', 'G#', 'C#:min/5'),
#   ('N', 'Bb:7', 'C#:7'),
#   ('E:7/3', 'G:min', 'A:maj7/5'),
#   ('E:7', 'F:9', 'Bb:7'),
#   ('E:maj7', 'B:7', 'C#:min'),
#   ('D/3', 'E:7', 'Bb'),
#   ('D', 'Eb', 'C#:min'),
#   ('G#', 'F#:9', 'D:9'),
#   ('G', 'Bb', 'G#'),
#   ('F#:min7', 'C#:min', 'F#'),
#   ('G#', 'E:aug', 'F#'),
#   ('Bb:7', 'Eb', 'B:maj6'),
#   ('N', 'D/2', 'C:min6'),
#   ('D', 'Eb:9', 'G#'),
#   ('F', 'E:7', 'A:maj7/5'),
#   ('B', 'G', 'G#'),
#   ('A:min/b3', 'F:9', 'F#:min'),
#   ('E:9', 'B:min', 'A:maj7'),
#   ('E:9', 'G', 'D/2'),
#   ('E:7/3', 'E:min', 'A:maj7'),
#   ('D', 'E:7', 'A:maj7/5'),
#   ('Bb', 'F#:9', 'A:maj7/5'),
#   ('N', 'E', 'F#:min'),
#   ('E:7', 'Eb', 'E:aug'),
#   ('E', 'C#:7', 'D:9'),
#   ('B', 'F:9', 'F#'),
#   ('A:min', 'D/3', 'A:maj7'),
#   ('F', 'A:min', 'Eb:min'),
#   ('Eb:9', 'A:maj7/5', 'F#:minmaj7'),
#   ('E', 'G#:min7', 'D:9'),
#   ('G#', 'B:maj6', 'F#:minmaj7'),
#   ('A', 'E:7/3', 'D/2'),
#   ('Bb', 'Eb:9', 'C#:min'),
#   ('E', 'D/3', 'F:9'),
#   ('A', 'C#:min', 'B:maj6'),
#   ('A:min', 'F:9', 'G#:min'),
#   ('E:7', 'Eb:min', 'C#:min/5'),
#   ('Eb:min', 'B:maj6', 'C:min6'),
#   ('B', 'Eb:7', 'G#'),
#   ('E:maj7', 'C#:min/5', 'C#:7'),
#   ('Eb', 'A:maj7/5', 'C:min6'),
#   ('D/2', 'G#:min', 'F#:min'),
#   ('A', 'C:min6', 'A:7'),
#   ('F#:9', 'A:maj7', 'C#:min/5'),
#   ('F:9', 'E:aug', 'F#:minmaj7'),
#   ('E', 'A', 'E:7/3'),
#   ('D/2', 'G:min', 'G#'),
#   ('N', 'A', 'G#'),
#   ('A:min/b3', 'G', 'D/3'),
#   ('A:min', 'E:7', 'Bb:7'),
#   ('A:min/b3', 'D', 'B:maj6'),
#   ('E', 'Bb:7', 'G#:min'),
#   ('E:9', 'E:aug', 'F#:minmaj7'),
#   ('E:7/3', 'C', 'F#:min'),
#   ('F#:min7', 'A:maj7', 'C:min6'),
#   ('E', 'E:7/3', 'D/3'),
#   ('F', 'F#:min', 'C#:7'),
#   ('E:9', 'F#:min7', 'C#:7'),
#   ('G:min', 'F#:min7', 'G#'),
#   ('N', 'E:min', 'Eb:9'),
#   ('Eb:9', 'E:maj7', 'C#:min/5'),
#   ('E:9', 'D/2', 'Eb:7'),
#   ('A', 'G', 'Eb:7'),
#   ('E:min', 'F:9', 'C#:7'),
#   ('E', 'E:min', 'Eb'),
#   ('A:min/b3', 'A:min', 'D:9'),
#   ('D', 'E:maj7', 'B:7'),
#   ('F:9', 'B:7', 'C#:min/5'),
#   ('D/2', 'Bb:7', 'Eb:min'),
#   ('Bb:7', 'F#:min7', 'C#:7'),
#   ('G#', 'E:aug', 'G#:min'),
#   ('A:min/b3', 'E:9', 'C'),
#   ('G', 'D/2', 'F#:minmaj7'),
#   ('A:min/b3', 'Bb:7', 'F#'),
#   ('C', 'Bb', 'A:7'),
#   ('E:7', 'G#:min7', 'D:9'),
#   ('A', 'E:maj7', 'C:min6'),
#   ('E:min', 'Bb:7', 'D:9'),
#   ('A:min/b3', 'Eb:min', 'C#:min/5'),
#   ('D', 'Eb', 'A:7'),
#   ('G:min', 'E:maj7', 'C#:min'),
#   ('N', 'D/3', 'F#'),
#   ('N', 'Eb:7', 'C#:7'),
#   ('E:9', 'G:min', 'E:maj7'),
#   ('E', 'G#', 'A:maj7'),
#   ('F', 'E:7', 'Bb'),
#   ('F', 'Eb:9', 'F#'),
#   ('G:min', 'Eb:min', 'C:min6'),
#   ('Bb', 'G#:min7', 'B:maj6'),
#   ('N', 'F', 'E:7'),
#   ('D', 'E:7', 'Bb'),
#   ('Eb:min', 'F#:min7', 'F#'),
#   ('D', 'E:aug', 'D:9'),
#   ('E:min', 'C#:min/5', 'F#'),
#   ('A', 'E:9', 'F#:minmaj7'),
#   ('E:7', 'G#:min7', 'G#'),
#   ('Eb:9', 'Eb', 'D:9'),
#   ('C', 'E:min', 'C#:min'),
#   ('E:min', 'G#:min7', 'B:7'),
#   ('A:maj7', 'G#:min', 'C#:7'),
#   ('B:min', 'Bb:7', 'F#:minmaj7'),
#   ('B', 'E:7', 'Bb:7'),
#   ('E:min', 'Bb:7', 'G#'),
#   ('B:7', 'G#', 'C:min6'),
#   ('B:min', 'E:min', 'D:9'),
#   ('E:maj7', 'E:aug', 'F#:min'),
#   ('N', 'F', 'F#:min7'),
#   ('E', 'B:7', 'D:9'),
#   ('D', 'Bb', 'G#:min7'),
#   ('Bb', 'Eb:9', 'A:7'),
#   ('E:9', 'Eb:min', 'C#:min'),
#   ('A:min/b3', 'G#:min7', 'D:9'),
#   ('E', 'G', 'F:9'),
#   ('B', 'Eb:min', 'A:maj7'),
#   ('G:min', 'A:maj7', 'D:9'),
#   ('F#:min7', 'G#:min', 'F#'),
#   ('E:7/3', 'A:min', 'B:7'),
#   ('N', 'B', 'F#:min'),
#   ('E:7/3', 'D/3', 'G#:min7'),
#   ('E:7', 'C#:min', 'E:aug'),
#   ('E', 'D/3', 'G:min'),
#   ('A:min/b3', 'Bb:7', 'G#:min'),
#   ('A:min/b3', 'G#:min7', 'G#'),
#   ('A', 'G', 'F#:min'),
#   ('E:9', 'D/2', 'F#:min'),
#   ('G', 'D/3', 'C#:min/5'),
#   ('F:9', 'A:maj7', 'C#:7'),
#   ('G#', 'A:maj7/5', 'A:7'),
#   ('D/3', 'G:min', 'C#:7'),
#   ('E', 'E:7', 'A:maj7'),
#   ('E', 'D/3', 'E:aug'),
#   ('N', 'D/3', 'G#:min'),
#   ('E', 'A:min/b3', 'C#:min/5'),
#   ('F', 'Eb:9', 'G#:min'),
#   ('A:min/b3', 'G', 'Eb'),
#   ('F#:min7', 'F#:9', 'A:maj7/5'),
#   ('A', 'Bb', 'A:maj7'),
#   ('A', 'D/3', 'A:maj7/5'),
#   ('B', 'B:min', 'A:maj7/5'),
#   ('G:min', 'G#', 'B:maj6'),
#   ('Eb:7', 'Eb:min', 'F#:min7'),
#   ('Bb:7', 'G#:min', 'D:9'),
#   ('A:min/b3', 'F', 'C#:min'),
#   ('G:min', 'Eb:7', 'G#:min7'),
#   ('Eb:min', 'F#:min7', 'G#:min'),
#   ('E', 'D/2', 'E:maj7'),
#   ('G', 'A:min', 'D:9'),
#   ('G', 'Eb', 'E:aug'),
#   ('G:min', 'E:maj7', 'A:7'),
#   ('G', 'D', 'F#'),
#   ('Bb', 'B:7', 'B:maj6'),
#   ('E:aug', 'C:min6', 'A:7'),
#   ('F:9', 'F#:min7', 'F#'),
#   ('F', 'Eb:min', 'C#:min'),
#   ('N', 'G', 'F#'),
#   ('Eb:7', 'G#:min7', 'A:maj7/5'),
#   ('C', 'A:min', 'C#:min'),
#   ('N', 'E:maj7', 'A:maj7/5'),
#   ('B', 'Eb:9', 'B:maj6'),
#   ('E:7', 'B:7', 'G#'),
#   ('A:min/b3', 'Eb:7', 'Eb'),
#   ('C', 'E:min', 'A:7'),
#   ('Eb:min', 'A:maj7', 'F#'),
#   ('Bb', 'B:7', 'F#'),
#   ('B:7', 'E:aug', 'A:maj7'),
#   ('B:7', 'A:maj7', 'F#:min'),
#   ('E:7/3', 'G#:min7', 'B:7'),
#   ('D/3', 'Eb:9', 'E:maj7'),
#   ('G', 'A:min', 'G#'),
#   ('F', 'E:maj7', 'D:9'),
#   ('F:9', 'B:maj6', 'A:7'),
#   ('E:min', 'E:7', 'F#:minmaj7'),
#   ('N', 'Eb:9', 'G#:min7'),
#   ('E', 'F#:9', 'E:aug'),
#   ('E', 'F#:minmaj7', 'A:7'),
#   ('E:min', 'Eb:7', 'G#'),
#   ('F', 'E:aug', 'F#'),
#   ('E:maj7', 'C#:min', 'A:maj7/5'),
#   ('E:9', 'Eb:min', 'A:7'),
#   ('E:9', 'B:maj6', 'A:7'),
#   ('Eb', 'F#:min7', 'E:aug'),
#   ('E:min', 'D/2', 'A:maj7/5'),
#   ('A:min', 'Bb', 'G#'),
#   ('E:9', 'G:min', 'F#:minmaj7'),
#   ('F', 'Bb', 'C#:min/5'),
#   ('A:min/b3', 'G', 'F:9'),
#   ('N', 'D', 'A:maj7'),
#   ('C', 'E:maj7', 'C#:min/5'),
#   ('F', 'E:maj7', 'G#'),
#   ('A', 'Eb:9', 'C#:min'),
#   ('C', 'G:min', 'B:maj6'),
#   ('A:min/b3', 'B:7', 'G#'),
#   ('F#:min7', 'G#:min7', 'B:maj6'),
#   ('C', 'B:min', 'B:maj6'),
#   ('D', 'F#:9', 'C:min6'),
#   ('Bb', 'G#', 'D:9'),
#   ('A', 'F', 'C#:7'),
#   ('Eb', 'E:aug', 'D:9'),
#   ('Bb:7', 'Eb:min', 'C#:min/5'),
#   ('C', 'G#:min7', 'C#:min'),
#   ('B', 'B:min', 'Bb'),
#   ('E:min', 'G:min', 'Bb:7'),
#   ('C#:min/5', 'C#:7', 'A:7'),
#   ('N', 'A:min/b3', 'B:maj6'),
#   ('A:min/b3', 'E:7', 'A:maj7'),
#   ('G', 'F:9', 'A:maj7'),
#   ('A:maj7/5', 'C#:7', 'F#:minmaj7'),
#   ('F:9', 'F#:min7', 'G#:min'),
#   ('E:7/3', 'G#:min', 'F#:minmaj7'),
#   ('F', 'B:min', 'C#:7'),
#   ('Eb:7', 'C#:min', 'B:maj6'),
#   ('Eb', 'Eb:min', 'E:maj7'),
#   ('E', 'G', 'E:aug'),
#   ('E', 'D/3', 'Eb:9'),
#   ('B', 'E:maj7', 'E:aug'),
#   ('A:min/b3', 'F', 'A:7'),
#   ('E', 'D', 'Eb:7'),
#   ('N', 'G', 'G#:min'),
#   ('A:min/b3', 'Eb:7', 'F:9'),
#   ('F#:9', 'B:maj6', 'C#:7'),
#   ('E:7/3', 'F:9', 'Bb:7'),
#   ('Eb:7', 'C:min6', 'A:7'),
#   ('E:9', 'E:maj7', 'F#'),
#   ('A', 'A:min', 'Bb:7'),
#   ('B', 'F', 'Eb:min'),
#   ('Eb:min', 'A:maj7', 'G#:min'),
#   ('E:7/3', 'G', 'D/3'),
#   ('A:min/b3', 'E:9', 'E:7'),
#   ('F', 'D/2', 'F#'),
#   ('A:min', 'G#', 'C#:7'),
#   ('Bb:7', 'G#', 'F#:9'),
#   ('E:7/3', 'D/3', 'F#:9'),
#   ('F', 'Eb:min', 'A:7'),
#   ('N', 'Eb', 'F#:min'),
#   ('C', 'Eb', 'D:9'),
#   ('B:min', 'E:maj7', 'A:maj7/5'),
#   ('E:9', 'Bb:7', 'A:maj7/5'),
#   ('Bb:7', 'C#:7', 'D:9'),
#   ('C', 'A:min', 'A:7'),
#   ('B', 'Bb', 'G#'),
#   ('F', 'E:aug', 'G#:min'),
#   ('E:7/3', 'D', 'F#'),
#   ('F', 'Eb', 'F#:min7'),
#   ('A', 'G#:min7', 'B:maj6'),
#   ('A:min/b3', 'E:9', 'F#:min7'),
#   ('E:maj7', 'F#:9', 'F#'),
#   ('E:7/3', 'E:9', 'C'),
#   ('Eb:7', 'E:maj7', 'C:min6'),
#   ('C#:min', 'F#:9', 'F#'),
#   ('E:min', 'D/2', 'Bb'),
#   ('E', 'D/2', 'F#:minmaj7'),
#   ('E:min', 'Eb:min', 'A:maj7'),
#   ('G', 'Eb:7', 'Eb'),
#   ('E:min', 'Bb', 'F#:min7'),
#   ('G', 'C', 'G#:min7'),
#   ('Bb:7', 'F#:9', 'A:maj7/5'),
#   ('B', 'E:aug', 'B:maj6'),
#   ('Eb:min', 'E:aug', 'C#:7'),
#   ('E:7/3', 'Eb:min', 'F#:9'),
#   ('E', 'Bb', 'F#'),
#   ('E', 'E:min', 'D:9'),
#   ('A', 'Eb:9', 'A:7'),
#   ('Eb:9', 'Bb:7', 'D:9'),
#   ('N', 'Bb:7', 'E:maj7'),
#   ('F', 'E:min', 'A:7'),
#   ('E:aug', 'G#:min', 'F#'),
#   ('N', 'Bb', 'C#:7'),
#   ('F', 'F:9', 'A:maj7/5'),
#   ('B', 'E:7/3', 'B:7'),
#   ('D/3', 'Eb:9', 'F#:minmaj7'),
#   ('N', 'F#', 'D:9'),
#   ('C', 'Eb:9', 'F#:min'),
#   ('C', 'G#:min7', 'A:7'),
#   ('E:9', 'E:maj7', 'G#:min'),
#   ('C', 'B:7', 'C#:min'),
#   ('A:min', 'E:7', 'C#:7'),
#   ('F:9', 'F#:minmaj7', 'D:9'),
#   ('G#', 'C#:min/5', 'F#:minmaj7'),
#   ('E:9', 'G', 'A:maj7/5'),
#   ('Eb:9', 'G#:min7', 'B:7'),
#   ('F#:min7', 'B:7', 'F#'),
#   ('E', 'D', 'F#:min'),
#   ('E:7', 'G:min', 'Eb:7'),
#   ('Eb:9', 'Bb:7', 'G#'),
#   ('D/2', 'C#:min/5', 'A:7'),
#   ('Bb:7', 'C#:min', 'E:aug'),
#   ('A:min/b3', 'C', 'A:min'),
#   ('A:maj7/5', 'C#:min/5', 'D:9'),
#   ('B', 'G#', 'C:min6'),
#   ('E:min', 'Eb:9', 'B:maj6'),
#   ('Eb', 'C#:min', 'A:7'),
#   ('E', 'A:maj7/5', 'D:9'),
#   ('E:maj7', 'F#:9', 'G#:min'),
#   ('E:9', 'A:min', 'C#:min/5'),
#   ('A:min', 'G#:min', 'F#:minmaj7'),
#   ('F#:min7', 'F#:min', 'A:7'),
#   ('A:min', 'F:9', 'Bb:7'),
#   ('C#:min', 'F#:9', 'G#:min'),
#   ('Bb', 'F:9', 'Eb'),
#   ('Eb:7', 'F:9', 'C#:min/5'),
#   ('E:9', 'Eb:7', 'A:maj7/5'),
#   ('B:min', 'Eb:7', 'G#:min'),
#   ('D', 'G#', 'A:maj7/5'),
#   ('A', 'B:7', 'B:maj6'),
#   ('E:7/3', 'G', 'Eb'),
#   ('D/2', 'Eb:min', 'C:min6'),
#   ('Eb:min', 'C:min6', 'F#:minmaj7'),
#   ('E:7/3', 'F', 'C#:min'),
#   ('Eb', 'B:maj6', 'F#:minmaj7'),
#   ('D/3', 'G#:min7', 'C#:min/5'),
#   ('F#:min7', 'G#', 'D:9'),
#   ('F#:min7', 'E:aug', 'A:7'),
#   ('E', 'Bb', 'G#:min'),
#   ('A:min/b3', 'G:min', 'Eb:7'),
#   ('Eb:9', 'G#:min', 'C:min6'),
#   ('B', 'E:7', 'C#:7'),
#   ('A:min', 'Eb', 'E:aug'),
#   ('E:min', 'F:9', 'E:maj7'),
#   ('B', 'E:min', 'G#'),
#   ('A:min', 'D', 'F#'),
#   ('A:min/b3', 'C', 'A:maj7'),
#   ('E', 'A:min', 'D:9'),
#   ('B:7', 'C#:min/5', 'C:min6'),
#   ('G:min', 'Bb', 'G#:min7'),
#   ('Eb:7', 'A:maj7', 'A:7'),
#   ('N', 'A:min/b3', 'G'),
#   ('F:9', 'Eb:min', 'F#:min7'),
#   ('E:7/3', 'Eb:7', 'Eb'),
#   ('E:min', 'Eb', 'F#'),
#   ('F#:min7', 'B:7', 'G#:min'),
#   ('A:min', 'G:min', 'B:maj6'),
#   ('E', 'Eb:min', 'C#:min/5'),
#   ('E', 'B:maj6', 'C#:min/5'),
#   ('N', 'Eb:7', 'E:maj7'),
#   ('C', 'B:7', 'A:7'),
#   ('F', 'A:min', 'C#:min/5'),
#   ('E:min', 'E:maj7', 'E:aug'),
#   ('E:9', 'G', 'Bb'),
#   ('B', 'F:9', 'Bb:7'),
#   ('D/2', 'F#:9', 'F#:minmaj7'),
#   ('Bb', 'C#:7', 'F#:minmaj7'),
#   ('G', 'C', 'F#:9'),
#   ('A:min/b3', 'E:min', 'D/3'),
#   ('A:min/b3', 'D', 'F#:min'),
#   ('A', 'E:aug', 'A:7'),
#   ('C', 'D/3', 'C#:min'),
#   ('Bb', 'A:maj7/5', 'F#'),
#   ('E', 'B', 'B:maj6'),
#   ('Eb:min', 'C#:min', 'A:7'),
#   ('Bb', 'Bb:7', 'A:maj7'),
#   ('A:min/b3', 'G', 'Eb:9'),
#   ('Eb:7', 'Eb:9', 'C#:min'),
#   ('D/3', 'E:aug', 'F#:minmaj7'),
#   ('N', 'Bb:7', 'F#:minmaj7'),
#   ('E:9', 'F', 'F#'),
#   ('B', 'D', 'F#'),
#   ('A', 'D/2', 'G#'),
#   ('D/3', 'F#:min7', 'C#:7'),
#   ('N', 'C#:min', 'F#'),
#   ('G', 'D/2', 'C:min6'),
#   ('A:min/b3', 'D/3', 'C#:min/5'),
#   ('A:min', 'D', 'G#:min'),
#   ('C', 'F:9', 'C#:7'),
#   ('E:7/3', 'F', 'A:7'),
#   ('C', 'Eb:7', 'F#:min7'),
#   ('D/3', 'B:7', 'C#:min/5'),
#   ('E', 'F:9', 'A:maj7'),
#   ('B', 'G:min', 'B:maj6'),
#   ('E:min', 'E:aug', 'B:maj6'),
#   ('Bb', 'G#:min7', 'F#:min'),
#   ('A:min/b3', 'Eb:7', 'Eb:9'),
#   ('F', 'G#:min7', 'C#:min/5'),
#   ('E', 'Eb:7', 'Bb:7'),
#   ('A', 'E:9', 'C:min6'),
#   ('E:7/3', 'E:9', 'E:7'),
#   ('E:min', 'Eb', 'G#:min'),
#   ('D/3', 'G:min', 'E:maj7'),
#   ('Eb:7', 'F#:min7', 'B:7'),
#   ('E:9', 'C', 'Eb:min'),
#   ('Bb:7', 'B:7', 'F#'),
#   ('B:min', 'B:maj6', 'D:9'),
#   ('N', 'D/3', 'Bb:7'),
#   ('N', 'G:min', 'G#:min7'),
#   ('F', 'Eb:9', 'Bb:7'),
#   ('B:7', 'F#', 'A:7'),
#   ('B:min', 'F#:min', 'C#:min/5'),
#   ('G', 'G:min', 'Eb:7'),
#   ('B:min', 'G#', 'D:9'),
#   ('D', 'G#:min7', 'F#:9'),
#   ('E:maj7', 'C#:min/5', 'F#:minmaj7'),
#   ('N', 'Eb:min', 'B:maj6'),
#   ('E:7/3', 'E:9', 'F#:min7'),
#   ('E', 'E:7', 'F#:9'),
#   ('A:min', 'C#:7', 'A:7'),
#   ('Bb:7', 'F#:min', 'A:7'),
#   ('B', 'A:min/b3', 'D/3'),
#   ('A:min/b3', 'F#:9', 'C#:min/5'),
#   ('E:9', 'F', 'G#:min'),
#   ('E:min', 'G#', 'C:min6'),
#   ('E:min', 'F:9', 'F#:minmaj7'),
#   ('N', 'A:min', 'C#:7'),
#   ('E', 'C#:min', 'E:aug'),
#   ('N', 'C#:min', 'G#:min'),
#   ('A', 'C', 'D/2'),
#   ('E:9', 'G', 'D'),
#   ('G:min', 'C#:min', 'F#:9'),
#   ('A:maj7', 'B:maj6', 'F#:min'),
#   ('Eb:9', 'Eb:min', 'A:maj7'),
#   ('Bb', 'Eb:7', 'A:maj7'),
#   ('B:min', 'D/3', 'B:maj6'),
#   ('G', 'E:min', 'D/3'),
#   ('A', 'A:min', 'C#:7'),
#   ('A:min/b3', 'E:min', 'Eb'),
#   ('G:min', 'G#', 'F#:min'),
#   ('N', 'Eb:7', 'F#:minmaj7'),
#   ('D/2', 'Eb:9', 'D:9'),
#   ('D/3', 'A:maj7', 'C#:7'),
#   ('G', 'Eb:7', 'D:9'),
#   ('B', 'A:maj7', 'A:maj7/5'),
#   ('E', 'C', 'D/3'),
#   ('G', 'Bb:7', 'B:maj6'),
#   ('B:min', 'A:7', 'D:9'),
#   ('B:min', 'D/2', 'A:7'),
#   ('Bb:7', 'B:7', 'G#:min'),
#   ('E', 'A', 'B:7'),
#   ('E:9', 'D', 'C:min6'),
#   ('F', 'D/3', 'C#:min'),
#   ('D', 'F#:min7', 'D:9'),
#   ('B:min', 'E:7', 'D:9'),
#   ('F', 'B:7', 'C#:min/5'),
#   ('B', 'C#:7', 'A:7'),
#   ('G#', 'A:maj7', 'F#'),
#   ('A:maj7', 'G#:min', 'F#:minmaj7'),
#   ('A:min/b3', 'F:9', 'A:maj7'),
#   ('A', 'F:9', 'Eb'),
#   ('E:7/3', 'C', 'A:min'),
#   ('A', 'F', 'E:maj7'),
#   ('D/2', 'Eb', 'C#:min'),
#   ('N', 'E:min', 'F#'),
#   ('E', 'G#:min7', 'F#'),
#   ('B:min', 'G:min', 'G#:min7'),
#   ('E:9', 'Eb:9', 'B:7'),
#   ('F#:min7', 'C#:7', 'F#:minmaj7'),
#   ('G', 'D', 'Bb:7'),
#   ('E:maj7', 'F#:min7', 'F#:min'),
#   ('N', 'G#:min7', 'C#:7'),
#   ('F', 'B:min', 'E:maj7'),
#   ('A', 'D', 'C#:min/5'),
#   ...},
#  '300': {('A', 'B', 'E'),
#   ('A', 'B', 'F#:min'),
#   ('A', 'B:min', 'D'),
#   ('A', 'B:min', 'F#:min'),
#   ('A', 'D', 'G'),
#   ('B', 'C#:min', 'F#:min'),
#   ('B', 'E', 'N'),
#   ('C', 'D', 'G'),
#   ('C', 'F', 'G'),
#   ('D', 'E:min', 'G'),
#   ('D', 'E:min', 'N'),
#   ('D', 'G', 'N'),
#   ('E:min', 'G', 'N')}}
