# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
album01 = pd.read_csv('album_04_edges.csv')
G = nx.from_pandas_edgelist(album01, source="Source", target="Target", create_using=nx.DiGraph())
nx.draw(G, with_labels=True)

# %% [markdown]
# ## Visuals

# %%
nx.draw(G,node_size=300,font_size=8,  with_labels=True)

# %%
plt.figure(3,figsize=(12,12)) 
nx.draw(G, node_size=400,font_size=12,  with_labels=True)

# %% [markdown]
# ## Triads

# %%
''' Conesus Motifs are: 
        021C
        111D
        201
        030C
        120C
        210
                    '''
# Out:
# ' Conesus Motifs are: \n        021C\n        111D\n        201\n        030C\n        120C\n        210\n                    '

# %%
# Triad Consensus
nx.triadic_census(G)
# Out:
# {'003': 30452,
#  '012': 4723,
#  '102': 1661,
#  '021D': 96,
#  '021U': 77,
#  '021C': 201,
#  '111D': 196,
#  '111U': 224,
#  '030T': 10,
#  '030C': 8,
#  '201': 82,
#  '120D': 7,
#  '120U': 7,
#  '120C': 30,
#  '210': 27,
#  '300': 19}

# %%
import networkx as nx
import itertools

def _tricode(G, v, u, w):
    """Returns the integer code of the given triad.

    This is some fancy magic that comes from Batagelj and Mrvar's paper. It
    treats each edge joining a pair of `v`, `u`, and `w` as a bit in
    the binary representation of an integer.

    """
    combos = ((v, u, 1), (u, v, 2), (v, w, 4), (w, v, 8), (u, w, 16),
              (w, u, 32))
    return sum(x for u, v, x in combos if v in G[u])


# G = nx.DiGraph()
# G.add_nodes_from([1, 2, 3, 4, 5])
# G.add_edges_from([(1, 2), (2, 3), (2, 4), (4, 5)])

#: The integer codes representing each type of triad.
#: Triads that are the same up to symmetry have the same code.
TRICODES = (1, 2, 2, 3, 2, 4, 6, 8, 2, 6, 5, 7, 3, 8, 7, 11, 2, 6, 4, 8, 5, 9,
            9, 13, 6, 10, 9, 14, 7, 14, 12, 15, 2, 5, 6, 7, 6, 9, 10, 14, 4, 9,
            9, 12, 8, 13, 14, 15, 3, 7, 8, 11, 7, 12, 14, 15, 8, 14, 13, 15,
            11, 15, 15, 16)

#: The names of each type of triad. The order of the elements is
#: important: it corresponds to the tricodes given in :data:`TRICODES`.
TRIAD_NAMES = ('003', '012', '102', '021D', '021U', '021C', '111D', '111U',
               '030T', '030C', '201', '120D', '120U', '120C', '210', '300')

#: A dictionary mapping triad code to triad name.
TRICODE_TO_NAME = {i: TRIAD_NAMES[code - 1] for i, code in enumerate(TRICODES)}

triad_nodes = {name: set([]) for name in TRIAD_NAMES}
m = {v: i for i, v in enumerate(G)}
for v in G:
    vnbrs = set(G.pred[v]) | set(G.succ[v])
    for u in vnbrs:
        if m[u] > m[v]:
            unbrs = set(G.pred[u]) | set(G.succ[u])
            neighbors = (vnbrs | unbrs) - {u, v}
            not_neighbors = set(G.nodes()) - neighbors - {u, v}
            # Find dyadic triads
            for w in not_neighbors:
                if v in G[u] and u in G[v]:
                    triad_nodes['102'].add(tuple(sorted([u, v, w])))
                else:
                    triad_nodes['012'].add(tuple(sorted([u, v, w])))
            for w in neighbors:
                if m[u] < m[w] or (m[v] < m[w] < m[u] and
                                   v not in G.pred[w] and
                                   v not in G.succ[w]):
                    code = _tricode(G, v, u, w)
                    triad_nodes[TRICODE_TO_NAME[code]].add(
                        tuple(sorted([u, v, w])))
# find null triads
all_tuples = set()
for s in triad_nodes.values():
    all_tuples = all_tuples.union(s)
    
new = triad_nodes['210'] = set(itertools.combinations(G.nodes(), 3)).difference(all_tuples)

triad_nodes
# Out:
# {'003': set(),
#  '012': {('A:min', 'C:maj6', 'F:7'),
#   ('E/#4', 'E/4', 'E:7(#9)'),
#   ('D#:7', 'G', 'G/b7'),
#   ('D:min', 'E/5', 'E:min'),
#   ('A/3', 'D', 'E/5'),
#   ('E:9', 'G/5', 'N'),
#   ('D:9', 'E/4', 'G'),
#   ('B:min', 'D/5', 'F#:min7'),
#   ('E', 'E/4', 'F#:min7'),
#   ('A:min7', 'C', 'C:maj6'),
#   ('E:9', 'E:min', 'G'),
#   ('A:9', 'D#:7', 'E'),
#   ('A:min', 'C:maj6', 'D:min'),
#   ('A', 'B:min', 'G:maj6/5'),
#   ('A:7', 'D', 'F#:sus4'),
#   ('A:min/6', 'D', 'G/5'),
#   ('A', 'B:min', 'C#:7'),
#   ('E:min', 'E:min/5', 'N'),
#   ('C:maj9', 'D:min', 'G'),
#   ('E:7(#9)', 'G', 'G:7'),
#   ('A:7/3', 'D:7(#9)', 'E:min'),
#   ('B', 'C:maj9', 'E'),
#   ('A:7', 'D:7', 'E:min/b3'),
#   ('D/7', 'E/#4', 'E/5'),
#   ('C#:7', 'E:7(#9)', 'G#'),
#   ('D#:7', 'D/5', 'F#'),
#   ('C:maj6', 'E/b7', 'G/5'),
#   ('A:9', 'E:7', 'E:7(#9)'),
#   ('C:maj9', 'E/4', 'N'),
#   ('A:7', 'E:7', 'G'),
#   ('C:maj9', 'F:7', 'G'),
#   ('A:(1)', 'B:min', 'E:min'),
#   ('A:7/3', 'D', 'F:maj9'),
#   ('D:sus4', 'F:maj9', 'G/5'),
#   ('D', 'E/#4', 'E:min/5'),
#   ('A:7', 'D:min', 'F'),
#   ('A:7', 'C:7', 'D'),
#   ('E:min', 'G:7', 'N'),
#   ('D:min', 'F', 'F:maj7'),
#   ('D/5', 'D:sus4', 'E/3'),
#   ('C', 'D:min', 'F#'),
#   ('A:min7', 'C#:7', 'F#'),
#   ('A:(1)', 'C:7', 'N'),
#   ('C', 'E:min/5', 'G:maj6/5'),
#   ('B:min', 'D/5', 'E:9'),
#   ('A/3', 'D/7', 'G/5'),
#   ('C#:7', 'E/5', 'G#'),
#   ('E/4', 'E:9', 'N'),
#   ('E', 'E/4', 'E:9'),
#   ('A:9', 'E', 'F:7'),
#   ('C:7', 'D:(1)', 'D:min'),
#   ('A', 'E:min/b3', 'F#:min7'),
#   ('B', 'D', 'E:min7'),
#   ('A:(1)', 'C/3', 'D:7'),
#   ('B:min', 'C:maj6', 'D'),
#   ('B:min', 'C:7', 'D:min'),
#   ('B', 'C:7', 'D'),
#   ('A/3', 'D', 'E/4'),
#   ('C#', 'D:(1)', 'N'),
#   ('C', 'G:7', 'G:maj6/5'),
#   ('A:9', 'D:min', 'E:min'),
#   ('C:7', 'D:min', 'F:maj7'),
#   ('C#', 'D:7', 'D:9'),
#   ('A:(1)', 'G', 'G:7'),
#   ('A:7', 'C', 'C:7'),
#   ('B', 'E/b7', 'E:min'),
#   ('D:min', 'F#:min7', 'F:min'),
#   ('C#', 'D', 'F:min'),
#   ('D/7', 'E:7', 'E:9'),
#   ('A/3', 'B:7', 'D/7'),
#   ('D/5', 'E/3', 'G/b7'),
#   ('B:min', 'D', 'D#:7'),
#   ('D#:7', 'E/#4', 'G#'),
#   ('A', 'C', 'E:7(#9)'),
#   ('C:maj9', 'E/b7', 'G/5'),
#   ('B:7', 'C', 'C:7'),
#   ('C', 'C#', 'D#:min'),
#   ('A:7/3', 'A:min', 'A:min/6'),
#   ('D', 'D/5', 'G/5'),
#   ('B', 'D:(1)', 'F#:min7'),
#   ('B', 'D#:min', 'D:maj6'),
#   ('A:7', 'D', 'G#'),
#   ('D#:7', 'E:min/b3', 'F#'),
#   ('D/7', 'E/#4', 'E/4'),
#   ('A', 'B:7', 'F#:min7'),
#   ('A:7/3', 'E:min', 'N'),
#   ('D:7(#9)', 'E:maj6/b7', 'E:min'),
#   ('A:7', 'C', 'E:min/5'),
#   ('E/4', 'E:7', 'N'),
#   ('A:min', 'B', 'B:min'),
#   ('C#', 'E:min', 'G'),
#   ('A/3', 'B', 'E:min'),
#   ('B:7', 'D:(1)', 'N'),
#   ('A/3', 'D', 'D/5'),
#   ('C#:7', 'E/b7', 'F#'),
#   ('B:min', 'D/2', 'D/5'),
#   ('E/#4', 'E/5', 'F:maj7'),
#   ('D:maj6', 'F:min', 'G'),
#   ('A:7/3', 'C:maj9', 'F:maj7'),
#   ('C/3', 'D/7', 'D:7'),
#   ('B:7', 'C', 'E:min/5'),
#   ('D/5', 'E/3', 'F#'),
#   ('A', 'E/5', 'E:min'),
#   ('A', 'B:9', 'D/2'),
#   ('A', 'A:7', 'D:(1)'),
#   ('D:maj6', 'E:min7', 'G'),
#   ('B:7', 'D', 'D:(1)'),
#   ('B', 'D#:min', 'E:min/b3'),
#   ('A:(1)', 'A:min7', 'N'),
#   ('A:min', 'F', 'G/5'),
#   ('A', 'A:7', 'F:min'),
#   ('A/3', 'D/7', 'F#:min7'),
#   ('D/2', 'D:7', 'N'),
#   ('A:9', 'C:7', 'E'),
#   ('D', 'D:(1)', 'E:maj6/b7'),
#   ('E:min', 'E:min7', 'G'),
#   ('D:maj6', 'D:min', 'F:min'),
#   ('B:min', 'E/b7', 'G/5'),
#   ('A:7/3', 'C', 'F:7'),
#   ('C:maj9', 'D', 'E:min'),
#   ('B', 'E:7', 'E:min'),
#   ('D:9', 'D:sus4', 'G'),
#   ('A', 'B:9', 'D#:min'),
#   ('A', 'A:7/3', 'E:maj6/b7'),
#   ('A/3', 'B:7', 'D'),
#   ('B', 'E', 'F:maj9'),
#   ('D:min', 'E:min', 'F:maj9'),
#   ('D', 'F#:min7', 'G/5'),
#   ('D:min', 'F#:sus4', 'F:min'),
#   ('D#:min', 'E/3', 'F#:sus4'),
#   ('A:9', 'B:9', 'F:7'),
#   ('E', 'E:7', 'G:maj6/5'),
#   ('B:7', 'E:min', 'G'),
#   ('D:min', 'F:min', 'G#'),
#   ('A:7', 'D/5', 'E/3'),
#   ('A:(1)', 'A:7', 'G'),
#   ('A', 'D:maj6', 'D:min'),
#   ('A:9', 'B:min', 'D/5'),
#   ('A:7/3', 'C', 'D:min'),
#   ('D:(1)', 'D:7(#9)', 'E:min'),
#   ('D:9', 'E/5', 'N'),
#   ('C:maj9', 'D:sus4', 'N'),
#   ('B', 'E:min', 'G/5'),
#   ('C#:7', 'F#', 'F:maj9'),
#   ('C#:7', 'E:7', 'F#'),
#   ('A:7/3', 'C#:7', 'G#'),
#   ('B:9', 'C:maj9', 'E:7(#9)'),
#   ('A:min', 'E/#4', 'E/5'),
#   ('B:9', 'E:7(#9)', 'F:min'),
#   ('C:maj9', 'D:sus4', 'E:min7'),
#   ('D/7', 'D:7', 'F'),
#   ('A:(1)', 'E:7', 'E:9'),
#   ('C', 'C:maj6', 'D:maj6'),
#   ('D/7', 'E', 'E/4'),
#   ('D', 'D:9', 'E:min/5'),
#   ('A:min', 'A:min/6', 'F:7'),
#   ('D:sus4', 'E/3', 'E:min7'),
#   ('D', 'D:sus4', 'F:maj9'),
#   ('A:9', 'B:9', 'D:min'),
#   ('A:min', 'C:maj6', 'D:(1)'),
#   ('C#:7', 'D:sus4', 'F:maj9'),
#   ('A:min', 'C:maj6', 'F:min'),
#   ('D:9', 'E:min', 'G:maj6/5'),
#   ('A:min', 'F', 'F#:min7'),
#   ('B:min', 'D:sus4', 'E:min'),
#   ('A:min', 'C:maj9', 'F'),
#   ('A:7', 'B:7', 'G'),
#   ('D:7', 'E:min', 'E:min/b3'),
#   ('A:7/3', 'D:7', 'E:min/b3'),
#   ('B:min', 'D/5', 'G:7'),
#   ('A', 'C', 'E/4'),
#   ('E', 'E/4', 'G:7'),
#   ('A', 'D#:min', 'F#:min7'),
#   ('B:min', 'D/5', 'E/#4'),
#   ('C', 'C:maj6', 'E:min/b3'),
#   ('C:maj6', 'E:7', 'E:9'),
#   ('A/3', 'C', 'D/7'),
#   ('D', 'F#:sus4', 'G/5'),
#   ('A', 'D:min', 'E/5'),
#   ('D:7(#9)', 'E:9', 'E:min'),
#   ('D:7', 'F', 'F:maj9'),
#   ('A:min', 'A:min/6', 'D:min'),
#   ('D', 'E/4', 'E:min'),
#   ('A', 'A:min7', 'E:min'),
#   ('B', 'E/#4', 'E:min'),
#   ('C', 'E/#4', 'G:7'),
#   ('A:min', 'E:7', 'E:9'),
#   ('A/3', 'B:min', 'C'),
#   ('C', 'C#', 'D:7(#9)'),
#   ('C#:7', 'G', 'G#'),
#   ('D:9', 'E/3', 'E:min'),
#   ('D', 'D/7', 'G:maj6/5'),
#   ('C/3', 'D:7', 'E:7'),
#   ('C#:7', 'D:min', 'G'),
#   ('A:min', 'E/#4', 'E/4'),
#   ('C:maj9', 'E', 'E:7(#9)'),
#   ('B', 'C#', 'E'),
#   ('A:9', 'D:(1)', 'E:7'),
#   ('A', 'A:7/3', 'C:maj9'),
#   ('A', 'A:(1)', 'D:min'),
#   ('A/3', 'B:min', 'G:maj6/5'),
#   ('D#:min', 'D/5', 'E/3'),
#   ('A', 'C', 'D/5'),
#   ('B', 'C', 'F:maj9'),
#   ('A', 'E:min/b3', 'G:7'),
#   ('A/3', 'B:min', 'C#:7'),
#   ('C:7', 'C:maj6', 'D:min'),
#   ('B', 'D#:min', 'E:min7'),
#   ('D:sus4', 'E/5', 'N'),
#   ('B:min', 'E', 'E/3'),
#   ('C/3', 'E:min', 'F:maj9'),
#   ('A:7', 'C/3', 'F:maj9'),
#   ('A:min7', 'E/5', 'G'),
#   ('A', 'E:min', 'F:maj9'),
#   ('D/2', 'D:(1)', 'D:7'),
#   ('B', 'D#:min', 'F'),
#   ('D#:7', 'F:min', 'G#'),
#   ('D:(1)', 'D:maj6', 'G'),
#   ('C#', 'D', 'E:9'),
#   ('C:maj6', 'D', 'D/7'),
#   ('A', 'B:9', 'D:7(#9)'),
#   ('A', 'D:min', 'E/4'),
#   ('D', 'D#:7', 'D:(1)'),
#   ('B:7', 'B:min', 'D/5'),
#   ('A', 'A:7/3', 'A:min/6'),
#   ('D/5', 'E/#4', 'E/5'),
#   ('C/3', 'F:maj7', 'F:maj9'),
#   ('D:min', 'E:7', 'F:min'),
#   ('A:min', 'C:maj6', 'E:min7'),
#   ('E:9', 'G:maj6/5', 'N'),
#   ('A', 'D:(1)', 'E:min'),
#   ('B', 'D', 'D:9'),
#   ('D#:7', 'E:7', 'F#'),
#   ('A:min7', 'B:9', 'E:7(#9)'),
#   ('B', 'E:7(#9)', 'E:min'),
#   ('A', 'B:min', 'F:maj9'),
#   ('D#:7', 'F#', 'F:maj9'),
#   ('C:maj9', 'D', 'E/b7'),
#   ('B', 'E', 'F#:sus4'),
#   ('C#:7', 'E/b7', 'G/5'),
#   ('E/#4', 'E/4', 'E/b7'),
#   ('C#', 'D:7', 'N'),
#   ('D/5', 'E/3', 'G/5'),
#   ('B', 'F#:min7', 'F:maj7'),
#   ('B:min', 'E:7', 'E:9'),
#   ('A:min/6', 'D/2', 'E/3'),
#   ('A:min/6', 'D/2', 'E'),
#   ('E', 'F#:min7', 'G'),
#   ('D:sus4', 'F#:sus4', 'F:maj9'),
#   ('E', 'E:7(#9)', 'F:7'),
#   ('A', 'B:min', 'E:7(#9)'),
#   ('E:9', 'E:maj6/b7', 'N'),
#   ('C#:7', 'D/2', 'G#'),
#   ('B:min', 'D:9', 'E'),
#   ('A', 'A:7', 'E:9'),
#   ('B', 'D:7(#9)', 'E'),
#   ('A/3', 'D/7', 'G:7'),
#   ('B:min', 'E/#4', 'E/4'),
#   ('A:7/3', 'D/5', 'E/3'),
#   ('A:min/6', 'D:9', 'G'),
#   ('D:(1)', 'D:7', 'N'),
#   ('E:7', 'F:maj9', 'N'),
#   ('A', 'A:7', 'C:7'),
#   ('D:7(#9)', 'E:7', 'G'),
#   ('A/3', 'E:min7', 'G/b7'),
#   ('A', 'A:7/3', 'G:maj6/5'),
#   ('A', 'B:7', 'B:9'),
#   ('A:7/3', 'C', 'F:min'),
#   ('A', 'A:7/3', 'C#:7'),
#   ('D/2', 'D:7', 'D:7(#9)'),
#   ('A:min', 'A:min/6', 'E:min/b3'),
#   ('D:7', 'E:min/b3', 'E:min7'),
#   ('B:min', 'D/7', 'E'),
#   ('A/3', 'D', 'F:7'),
#   ('C', 'C:maj6', 'E:min7'),
#   ('C', 'D:min', 'E:9'),
#   ('A:(1)', 'D:min', 'F:min'),
#   ('E:min', 'E:min/b3', 'G'),
#   ('D/2', 'D:min', 'F:min'),
#   ('D', 'D:sus4', 'E:min'),
#   ('A:9', 'E', 'E:min7'),
#   ('A:7', 'D', 'G/b7'),
#   ('A:9', 'B:9', 'F:min'),
#   ('B:9', 'D:7(#9)', 'G'),
#   ('A:9', 'E', 'F'),
#   ('C:maj6', 'F:min', 'G'),
#   ('A/3', 'A:min/6', 'B:min'),
#   ('A', 'E/3', 'E:7(#9)'),
#   ('A', 'A:7', 'E:min/5'),
#   ('B:9', 'C', 'E/5'),
#   ('B:7', 'D', 'E:min/5'),
#   ('D:min', 'D:sus4', 'E:min'),
#   ('C#:7', 'D:7', 'F#'),
#   ('A:min', 'B', 'C/3'),
#   ('A:7', 'D', 'E:min/b3'),
#   ('B', 'E', 'G#'),
#   ('B:9', 'D:(1)', 'E:7(#9)'),
#   ('D/5', 'E/3', 'F#:min7'),
#   ('A/3', 'A:min7', 'G'),
#   ('B:9', 'E:7(#9)', 'E:9'),
#   ('D:7', 'F', 'F#:sus4'),
#   ('C:maj6', 'D:(1)', 'F'),
#   ('A', 'A:min/6', 'B:min'),
#   ('C', 'C:7', 'D#:7'),
#   ('E:7', 'E:9', 'E:min'),
#   ('E', 'F#:sus4', 'G'),
#   ('D', 'E/4', 'E/b7'),
#   ('A/3', 'D', 'D:min'),
#   ('A', 'D/2', 'F#:min7'),
#   ('A', 'A:7', 'B'),
#   ('A/3', 'A:9', 'E:7'),
#   ('D/7', 'E:9', 'N'),
#   ('B:min', 'D', 'F:maj7'),
#   ('A:min/6', 'D/2', 'E/5'),
#   ('A:min7', 'D/2', 'D:7'),
#   ('C', 'D/7', 'G:7'),
#   ('C:maj9', 'E/4', 'F:maj7'),
#   ('A:min', 'F', 'G:7'),
#   ('A/3', 'D/7', 'D:9'),
#   ('A:min', 'C#', 'C:maj6'),
#   ('E:7', 'E:min/b3', 'N'),
#   ('A:7/3', 'D#:min', 'F#:sus4'),
#   ('C', 'E:min7', 'G/b7'),
#   ('C', 'F:7', 'G/b7'),
#   ('B', 'C#:7', 'E'),
#   ('C', 'C/3', 'F:min'),
#   ('A:min', 'A:min/6', 'B:7'),
#   ('D#:7', 'E/4', 'G#'),
#   ('A:7/3', 'F:7', 'G'),
#   ('C#', 'D', 'D:9'),
#   ('C#:7', 'G#', 'G/b7'),
#   ('A:min', 'C#', 'F'),
#   ('B', 'C', 'F#:sus4'),
#   ('C', 'C#', 'C/3'),
#   ('B:9', 'E:7(#9)', 'E:min/5'),
#   ('A', 'E/3', 'E/5'),
#   ('D:min', 'F:min', 'G/b7'),
#   ('A:min/6', 'B', 'E:min'),
#   ('A', 'B:9', 'F:maj7'),
#   ('C#:7', 'D:sus4', 'G#'),
#   ('A', 'E:min', 'F#:sus4'),
#   ('A/3', 'D/7', 'F'),
#   ('E', 'E:7', 'F:maj9'),
#   ('A:7/3', 'C', 'C:maj6'),
#   ('D:7(#9)', 'E:7(#9)', 'E:min'),
#   ('A', 'D:7', 'D:min'),
#   ('A:min', 'C:maj6', 'E:min/5'),
#   ('A:min', 'E:maj6/b7', 'F'),
#   ('A', 'B:9', 'D:7'),
#   ('B', 'E:min', 'G:7'),
#   ('C#', 'D:(1)', 'D:7'),
#   ('B', 'E:min/5', 'F#:min7'),
#   ('C', 'D#:min', 'F#:sus4'),
#   ('E:7', 'E:9', 'G#'),
#   ('D/7', 'E:7', 'N'),
#   ('D:(1)', 'E:maj6/b7', 'N'),
#   ('C:maj9', 'D:9', 'E:min'),
#   ('C:7', 'E', 'E:7(#9)'),
#   ('A:9', 'B:9', 'C:maj6'),
#   ('C:maj6', 'G', 'G/5'),
#   ('D:7', 'F', 'G#'),
#   ('D/7', 'E:min', 'G'),
#   ('A:7', 'E/4', 'G'),
#   ('D/2', 'D:min', 'F'),
#   ('A', 'B:min', 'F#:sus4'),
#   ('A:9', 'B:9', 'E:min7'),
#   ('A', 'A:7', 'D:9'),
#   ('C#:7', 'E', 'E:7(#9)'),
#   ('A:min/6', 'D/2', 'E/4'),
#   ('D/5', 'D:(1)', 'E/3'),
#   ('D:(1)', 'G:7', 'N'),
#   ('A:9', 'B:9', 'F'),
#   ('E', 'E:9', 'G'),
#   ('F:7', 'F:maj9', 'G'),
#   ('A', 'B:9', 'C/3'),
#   ('D:9', 'E:min', 'F:maj9'),
#   ('C/3', 'E:min/5', 'F:maj9'),
#   ('C', 'E/4', 'F:7'),
#   ('A:(1)', 'D:maj6', 'N'),
#   ('F:7', 'G', 'G#'),
#   ('A', 'F#:min7', 'G:maj6/5'),
#   ('C:maj6', 'D:7(#9)', 'F'),
#   ('D#:7', 'E', 'G'),
#   ('A:9', 'A:min', 'C:maj6'),
#   ('D', 'E:min', 'F:7'),
#   ('E', 'E:7(#9)', 'E:min/b3'),
#   ('D/5', 'D:7(#9)', 'G'),
#   ('C#:7', 'E:7', 'E:9'),
#   ('C:7', 'E/#4', 'E/4'),
#   ('D:min', 'E:7', 'E:9'),
#   ('A:7', 'D/2', 'G'),
#   ('A', 'E/3', 'E/4'),
#   ('A', 'C/3', 'D:7'),
#   ('A:min', 'A:min/6', 'E:min7'),
#   ('B', 'C', 'G#'),
#   ('A:9', 'A:min', 'F'),
#   ('A:min', 'D:7(#9)', 'F'),
#   ('E', 'F#', 'G'),
#   ('A', 'A:9', 'F#:min7'),
#   ('B', 'D/5', 'F#:min7'),
#   ('C#:7', 'G', 'G/b7'),
#   ('A', 'C:maj6', 'E:min'),
#   ('A:(1)', 'E:min', 'F'),
#   ('A:7', 'D', 'D:sus4'),
#   ('D:9', 'D:min', 'F:min'),
#   ('E/#4', 'E/4', 'F#'),
#   ('C', 'D:min', 'E/#4'),
#   ('D', 'D/7', 'E/3'),
#   ('D:sus4', 'E:min7', 'F#:sus4'),
#   ('C#', 'D:7', 'D:7(#9)'),
#   ('B', 'D:sus4', 'F:maj9'),
#   ('D', 'D#:7', 'E:min/5'),
#   ('B:9', 'E:9', 'N'),
#   ('E/4', 'F:7', 'G'),
#   ('A:min', 'C:maj6', 'D:9'),
#   ('A', 'B:min', 'G#'),
#   ('A/3', 'A:9', 'D'),
#   ('A:min', 'C', 'C:7'),
#   ('D#:7', 'D:9', 'G'),
#   ('D', 'D/7', 'E:7(#9)'),
#   ('A:min7', 'D:(1)', 'N'),
#   ('A:9', 'E:7', 'F#'),
#   ('A:7/3', 'D', 'E:min/b3'),
#   ('C#:7', 'D', 'D/7'),
#   ('B:9', 'D:maj6', 'G'),
#   ('B:min', 'D', 'E:maj6/b7'),
#   ('A/3', 'B:min', 'E:7(#9)'),
#   ('B', 'C:maj6', 'D'),
#   ('A:(1)', 'C:maj6', 'F'),
#   ('D#:7', 'E:min/b3', 'G:7'),
#   ('C', 'E:min/5', 'G#'),
#   ('A:(1)', 'D#:7', 'N'),
#   ('A/3', 'D', 'F:min'),
#   ('E:min7', 'G/b7', 'N'),
#   ('D:sus4', 'E:min', 'F:maj9'),
#   ('A:min', 'C#:7', 'C:maj6'),
#   ('A:7/3', 'C:7', 'D:min'),
#   ('E:7', 'G#', 'N'),
#   ('D/5', 'E', 'E:7'),
#   ('B', 'D:min', 'G'),
#   ('E/b7', 'E:9', 'N'),
#   ('B:7', 'F:7', 'G'),
#   ('A', 'D:min', 'F:7'),
#   ('C:7', 'E', 'E/4'),
#   ('B:9', 'E/#4', 'E/5'),
#   ('A:(1)', 'D/5', 'E/3'),
#   ('A:9', 'C#', 'E:7'),
#   ('A:9', 'B:9', 'C:7'),
#   ('A:min', 'C#:7', 'F'),
#   ('B', 'D', 'D#:7'),
#   ('B:9', 'C:maj6', 'E:7(#9)'),
#   ('D/5', 'E/3', 'G:7'),
#   ('D:sus4', 'F:maj7', 'F:maj9'),
#   ('B', 'D', 'D/2'),
#   ('B:9', 'E:7', 'N'),
#   ('C#:7', 'E/#4', 'G#'),
#   ('A:7/3', 'C', 'E:min/5'),
#   ('B', 'C', 'E/b7'),
#   ('A/3', 'E:min', 'G'),
#   ('A:7', 'A:9', 'G'),
#   ('E', 'E:7', 'F#:sus4'),
#   ('A:min', 'E:7', 'N'),
#   ('A', 'C', 'F#'),
#   ('A:9', 'C:7', 'D:min'),
#   ('D#:7', 'E:7', 'E:9'),
#   ('E', 'E:7', 'E:min'),
#   ('C:maj9', 'D', 'D:(1)'),
#   ('A:9', 'B:9', 'E:min/5'),
#   ('D:7', 'D:9', 'E:min'),
#   ('D', 'D:(1)', 'F:maj9'),
#   ('E/5', 'E:min7', 'N'),
#   ('A:7', 'C:maj9', 'D'),
#   ('E/#4', 'E/4', 'F:min'),
#   ('E/5', 'F:7', 'N'),
#   ('B:9', 'D:7', 'E:7(#9)'),
#   ('B:min', 'D:(1)', 'E:min'),
#   ('E:min', 'G:maj6/5', 'N'),
#   ('C', 'C/3', 'C:7'),
#   ('E', 'E:7(#9)', 'E:min7'),
#   ('C#:7', 'D/2', 'F#'),
#   ('B', 'E/b7', 'G/5'),
#   ('A:(1)', 'C', 'G:7'),
#   ('E', 'E:7(#9)', 'F'),
#   ('C#', 'D#:7', 'F#'),
#   ('D:9', 'E:min', 'F#:sus4'),
#   ('A', 'B', 'E/3'),
#   ('A', 'B:min', 'E/b7'),
#   ('C', 'F:7', 'G/5'),
#   ('C:7', 'D', 'D:min'),
#   ('B', 'E', 'G/b7'),
#   ('C#:7', 'G#', 'G/5'),
#   ('A', 'A:7/3', 'E:7(#9)'),
#   ('C#', 'D:sus4', 'F:maj9'),
#   ('D:min', 'F:maj9', 'F:min'),
#   ('D/5', 'E:9', 'N'),
#   ('D:min', 'F:min', 'G/5'),
#   ('D:min', 'E:min7', 'G'),
#   ('C:maj6', 'C:maj9', 'N'),
#   ('C#', 'C:maj6', 'D:7'),
#   ('A/3', 'C:maj6', 'G'),
#   ('B', 'E', 'E:min/b3'),
#   ('A', 'E/#4', 'F#:min7'),
#   ('A:9', 'D:7(#9)', 'E:7'),
#   ('C', 'C/3', 'E:min/5'),
#   ('A:9', 'E:7', 'F:min'),
#   ('D:min', 'E:min', 'E:min/b3'),
#   ('A:9', 'A:min/6', 'E:7'),
#   ('A/3', 'D', 'E:min7'),
#   ('A:min/6', 'E/#4', 'E/5'),
#   ('A:min/6', 'C:maj6', 'G'),
#   ('A:7/3', 'D:min', 'E:min'),
#   ('A', 'B:7', 'B:min'),
#   ('D', 'D/7', 'E/4'),
#   ('D:7(#9)', 'D:sus4', 'F:maj9'),
#   ('A:min', 'C:maj9', 'N'),
#   ('C#:7', 'D:9', 'E:min'),
#   ('E', 'E:7', 'G#'),
#   ('C#', 'D:7', 'F:maj7'),
#   ('D:(1)', 'D:sus4', 'F:maj9'),
#   ('A:7/3', 'D', 'D:sus4'),
#   ('A:min', 'C', 'G:7'),
#   ('C#', 'C:7', 'D:min'),
#   ('B:7', 'D:min', 'F'),
#   ('D:maj6', 'E', 'E:7'),
#   ('C', 'C:7', 'D/7'),
#   ('B', 'D:maj6', 'F#:min7'),
#   ('D', 'E:min/5', 'F:7'),
#   ('C', 'E/4', 'F:min'),
#   ('A', 'C#:7', 'D:min'),
#   ('B:7', 'D:sus4', 'F:maj9'),
#   ('C#', 'D:min', 'G'),
#   ('D', 'E:min', 'F:min'),
#   ('B', 'D:sus4', 'E:min'),
#   ('D:7(#9)', 'F:maj9', 'G'),
#   ('D:min', 'E:9', 'G'),
#   ('C:7', 'D:min', 'E/5'),
#   ('B', 'E/b7', 'F#:min7'),
#   ('A:9', 'B:9', 'D:9'),
#   ('D/5', 'E:7', 'N'),
#   ('A', 'C', 'D:(1)'),
#   ('E/#4', 'E:9', 'N'),
#   ('D:maj6', 'G', 'G:maj6/5'),
#   ('C#', 'D', 'D/2'),
#   ('D:9', 'E:min', 'G#'),
#   ('D:min', 'E/4', 'F:min'),
#   ('C/3', 'D:7', 'G:maj6/5'),
#   ('D/5', 'D:7', 'E/3'),
#   ('B', 'E/3', 'E:min'),
#   ('A', 'D:7', 'F'),
#   ('A/3', 'D/7', 'E:7'),
#   ('D#:7', 'E/4', 'F#'),
#   ('D:7', 'F', 'G/b7'),
#   ('C#', 'D', 'D#:min'),
#   ('D:(1)', 'D:min', 'G'),
#   ('D:min', 'F#', 'G'),
#   ('B:7', 'C:7', 'D:min'),
#   ('C/3', 'E/b7', 'F:maj9'),
#   ('B', 'B:7', 'D'),
#   ('C#:7', 'D:9', 'G#'),
#   ('A:min', 'B:min', 'D/5'),
#   ('A:9', 'C/3', 'D:7'),
#   ('A/3', 'B', 'F#:min7'),
#   ('E/b7', 'E:min', 'N'),
#   ('A:9', 'C#:7', 'E:7'),
#   ('C:maj9', 'F:maj7', 'F:maj9'),
#   ('D/5', 'D:min', 'E:min'),
#   ('B', 'C', 'D:maj6'),
#   ('A', 'E/5', 'F#:min7'),
#   ('B', 'D', 'D:7(#9)'),
#   ('B:9', 'E:7(#9)', 'N'),
#   ('E:7', 'E:9', 'F#'),
#   ('B:min', 'C:maj9', 'N'),
#   ('C#', 'E/b7', 'G/5'),
#   ('A:7', 'E/#4', 'G'),
#   ('A', 'A:7', 'D/2'),
#   ('C:maj6', 'F', 'F:7'),
#   ('D', 'D#:min', 'D/7'),
#   ('A:min/6', 'D/2', 'F:7'),
#   ('B', 'C', 'G/b7'),
#   ('C/3', 'D:7(#9)', 'G'),
#   ('D:7(#9)', 'E/4', 'G'),
#   ('A', 'A:min', 'A:min/6'),
#   ('B:min', 'C', 'G:7'),
#   ('B', 'E:7', 'F#:min7'),
#   ('D#:min', 'E:min/5', 'F#:sus4'),
#   ('A:min', 'C:maj6', 'N'),
#   ('B:9', 'C#:7', 'G#'),
#   ('A/3', 'A:7/3', 'D/7'),
#   ('A', 'A:7', 'D#:min'),
#   ('B:9', 'C#', 'D:7'),
#   ('D', 'D:(1)', 'F#:sus4'),
#   ('D#:7', 'D:min', 'F:min'),
#   ('D', 'E/4', 'G/5'),
#   ('A', 'A:7/3', 'F#:sus4'),
#   ('D:(1)', 'F', 'N'),
#   ('A', 'E:min', 'E:min/b3'),
#   ('D:(1)', 'E/b7', 'G/5'),
#   ('A:(1)', 'D', 'E:min/b3'),
#   ('D', 'E:min', 'E:min7'),
#   ('A:min/6', 'D/2', 'D:min'),
#   ('E:min/b3', 'F:maj9', 'G:7'),
#   ('C:maj6', 'E:min/5', 'G'),
#   ('A', 'B:min', 'G/b7'),
#   ('A', 'D:9', 'F#:min7'),
#   ('D:sus4', 'E:min/5', 'E:min7'),
#   ('C:7', 'D:(1)', 'N'),
#   ('C/3', 'F', 'F:maj9'),
#   ('A:7/3', 'E/5', 'N'),
#   ('A:min7', 'D#:7', 'G#'),
#   ('C:7', 'D', 'D:(1)'),
#   ('E/#4', 'E/4', 'E:9'),
#   ('D:min', 'E:min/b3', 'F'),
#   ('B:min', 'C/3', 'D:7'),
#   ('A:min', 'C:maj6', 'D#:7'),
#   ('A:min', 'C:maj6', 'D/2'),
#   ('A:min/6', 'D#:7', 'G#'),
#   ('B:min', 'C:maj6', 'E:min'),
#   ('B', 'G', 'G/b7'),
#   ('A:7/3', 'D/2', 'D:7'),
#   ('D:7(#9)', 'D:sus4', 'E:min'),
#   ('A', 'B:min', 'F#'),
#   ('E:maj6/b7', 'E:min', 'F'),
#   ('B:min', 'C/3', 'D'),
#   ('C:maj6', 'D/5', 'G'),
#   ('D', 'D:(1)', 'G#'),
#   ('B', 'D/7', 'E'),
#   ('A', 'A:min7', 'F#:min7'),
#   ('D', 'E:min/5', 'E:min/b3'),
#   ('C#:7', 'D:(1)', 'G#'),
#   ('A', 'A:7/3', 'G#'),
#   ('C', 'C:7', 'E:maj6/b7'),
#   ('A', 'A:min/6', 'C'),
#   ('D:maj6', 'E:7', 'G'),
#   ('C/3', 'C:7', 'D:7'),
#   ('D:min', 'E:7', 'N'),
#   ('E/#4', 'E/4', 'E:min/5'),
#   ('C:maj9', 'D#:7', 'G#'),
#   ('B:9', 'C', 'D:maj6'),
#   ('C', 'E:min/5', 'F#'),
#   ('A:9', 'D/2', 'D:7'),
#   ('B', 'E', 'G/5'),
#   ('C#', 'D', 'D:7(#9)'),
#   ('D#:7', 'D:7', 'E:min/b3'),
#   ('A:min7', 'C:maj9', 'G'),
#   ('A/3', 'B:min', 'E/b7'),
#   ('D:7', 'E/b7', 'G/5'),
#   ('B:9', 'D/2', 'E:7(#9)'),
#   ('D/7', 'F:7', 'G'),
#   ('D/5', 'D:7(#9)', 'E/3'),
#   ('C:7', 'D:7(#9)', 'E:min'),
#   ('C/3', 'E/#4', 'F:maj9'),
#   ('A:min', 'B', 'E/3'),
#   ('D:sus4', 'E:min7', 'G'),
#   ('C', 'C:maj6', 'D#:7'),
#   ('A', 'D:min', 'E:min7'),
#   ('C', 'C:maj6', 'D/2'),
#   ('D/5', 'E/5', 'N'),
#   ('A:min', 'D#:min', 'F'),
#   ('C#:7', 'E/#4', 'F#'),
#   ('B:9', 'C', 'E:min/b3'),
#   ('B', 'D', 'F:maj7'),
#   ('A:9', 'D/7', 'E'),
#   ('D:7', 'E/5', 'E:min/b3'),
#   ('B', 'C', 'D:sus4'),
#   ('A:9', 'E:7', 'E:min/5'),
#   ('A/3', 'D', 'D:9'),
#   ('D:maj6', 'D:sus4', 'E:min7'),
#   ('A', 'C', 'E:9'),
#   ('A:(1)', 'F:maj9', 'N'),
#   ('C', 'E:min7', 'G:7'),
#   ('D:9', 'E:maj6/b7', 'G'),
#   ('A', 'A:7', 'D:7(#9)'),
#   ('A', 'F#:min7', 'F#:sus4'),
#   ('D', 'D:sus4', 'G/5'),
#   ('B:min', 'E', 'F:min'),
#   ('A', 'D:(1)', 'F#:min7'),
#   ('C#:7', 'G#', 'G:7'),
#   ('C#:7', 'C:maj9', 'N'),
#   ('B', 'E:7(#9)', 'F#:min7'),
#   ('D#:7', 'E:min', 'F'),
#   ('A:(1)', 'D:min', 'N'),
#   ('D:min', 'F:min', 'G:7'),
#   ('C', 'C#', 'E/3'),
#   ('A:9', 'D', 'D/7'),
#   ('C', 'E/4', 'E:min/5'),
#   ('A:(1)', 'D', 'E:min7'),
#   ('D:7(#9)', 'E/5', 'N'),
#   ('C:maj6', 'E', 'E:7'),
#   ('E', 'E:7', 'G/b7'),
#   ('E:7', 'F', 'N'),
#   ('A:9', 'B:9', 'N'),
#   ('A', 'B:min', 'D:sus4'),
#   ('D', 'E/b7', 'F:7'),
#   ('D:sus4', 'E:maj6/b7', 'E:min7'),
#   ('A:min/6', 'C#', 'D/2'),
#   ('D:maj6', 'E/#4', 'G'),
#   ('D:7', 'F', 'G/5'),
#   ('A:min/6', 'E', 'E:7'),
#   ('C#', 'G', 'G/b7'),
#   ('C:maj9', 'E:maj6/b7', 'N'),
#   ('C:7', 'E:min', 'N'),
#   ('A:(1)', 'G/b7', 'N'),
#   ('D:7', 'D:9', 'E:min/b3'),
#   ('B', 'F#:min7', 'F:maj9'),
#   ('C/3', 'E:7(#9)', 'F:maj9'),
#   ('B:9', 'B:min', 'D'),
#   ('C:7', 'D:9', 'D:min'),
#   ('A', 'A:7/3', 'E/b7'),
#   ('C', 'E:9', 'G:7'),
#   ('B', 'D:min', 'E'),
#   ('A:min', 'B', 'E/5'),
#   ('B', 'D:7', 'F#:min7'),
#   ('B:9', 'D', 'E:7(#9)'),
#   ('C/3', 'E', 'F:maj9'),
#   ('A:min/6', 'D/2', 'F:min'),
#   ('C:maj6', 'F', 'F:min'),
#   ('C', 'C:7', 'C:maj9'),
#   ('C:maj6', 'F#:sus4', 'G'),
#   ('F:7', 'G', 'G/5'),
#   ('C/3', 'E/5', 'F:maj9'),
#   ('E', 'E:7', 'F#'),
#   ('D/5', 'E/3', 'E:7'),
#   ('B:min', 'E:maj6/b7', 'E:min'),
#   ('D:9', 'E:min', 'G/b7'),
#   ('D#:min', 'E', 'E:7'),
#   ('A/3', 'D:9', 'E:min'),
#   ('B:7', 'E:7', 'E:9'),
#   ('C:maj9', 'F:maj7', 'G#'),
#   ('C#:7', 'E', 'F#'),
#   ('C/3', 'E:7', 'N'),
#   ('D:(1)', 'G', 'G/b7'),
#   ('A:min', 'C:maj6', 'D:7(#9)'),
#   ('B', 'C', 'G/5'),
#   ('A:(1)', 'C:maj9', 'F:maj7'),
#   ('A:7', 'A:9', 'E'),
#   ('A:min/6', 'C', 'C#'),
#   ('A:7', 'B', 'E:min'),
#   ('B:7', 'D/2', 'D:7'),
#   ('A', 'F#:min7', 'G#'),
#   ('C#:7', 'C/3', 'D:7'),
#   ('A:9', 'B:9', 'D#:7'),
#   ('A', 'E/3', 'F:min'),
#   ('D', 'E:min/5', 'E:min7'),
#   ('A:9', 'B:9', 'D/2'),
#   ('A', 'E:min', 'G/5'),
#   ('A:7', 'C#:7', 'D'),
#   ('B', 'D#:min', 'E:7'),
#   ('C#:7', 'G', 'G:7'),
#   ('B:9', 'D:min', 'G'),
#   ('C', 'D:maj6', 'F:7'),
#   ('C:maj9', 'D:7(#9)', 'N'),
#   ('A:(1)', 'C#:7', 'N'),
#   ('A:(1)', 'B', 'F#:min7'),
#   ('C', 'C#', 'E/5'),
#   ('C/3', 'D:7', 'E:7(#9)'),
#   ('E:7', 'E:9', 'F#:min7'),
#   ('D:9', 'E:min', 'F#'),
#   ('G', 'G#', 'G:7'),
#   ('C:maj6', 'D:min', 'F:min'),
#   ('C#', 'D', 'F:maj7'),
#   ('A/3', 'B:9', 'B:min'),
#   ('D#:7', 'D:7', 'F'),
#   ('C:maj6', 'C:maj9', 'F:maj7'),
#   ('A/3', 'A:min/6', 'D/2'),
#   ('A:min', 'D/7', 'F'),
#   ('C/3', 'D:9', 'F:maj9'),
#   ('A:min', 'A:min/6', 'D#:7'),
#   ('A', 'B:min', 'G/5'),
#   ('D#:7', 'F#', 'G/5'),
#   ('A:min/6', 'E:9', 'N'),
#   ('D:sus4', 'E/b7', 'F:maj9'),
#   ('A:min', 'B', 'E/4'),
#   ('A:(1)', 'C:maj9', 'D'),
#   ('A', 'D:min', 'E:min/5'),
#   ('A:min', 'C:maj9', 'F:maj7'),
#   ('B:min', 'D', 'F:maj9'),
#   ('C#:7', 'D:9', 'F#'),
#   ('B:9', 'C', 'E:min7'),
#   ('C', 'D:maj6', 'D:min'),
#   ('A/3', 'A:min', 'B:min'),
#   ('A', 'C', 'D:9'),
#   ('B:7', 'D', 'D/7'),
#   ('A:9', 'D#:min', 'E:7'),
#   ('C', 'D:9', 'E:min'),
#   ('D:7', 'E:7', 'E:9'),
#   ('C:7', 'D:7', 'E:min/b3'),
#   ('E/b7', 'F:7', 'G'),
#   ('A:min/6', 'B', 'F#:min7'),
#   ('D#:min', 'E:9', 'N'),
#   ('D:9', 'E', 'E:7'),
#   ('D', 'D/7', 'F#'),
#   ('C', 'C:7', 'G:maj6/5'),
#   ('C:7', 'D:min', 'F:7'),
#   ('C:7', 'D', 'E:min/5'),
#   ('A', 'A:9', 'B:min'),
#   ('A', 'A:7', 'F:maj7'),
#   ('C#:7', 'C:maj6', 'G#'),
#   ('B:9', 'E/b7', 'G/5'),
#   ('D:sus4', 'E:9', 'E:min7'),
#   ('A:min/6', 'D/2', 'E:min7'),
#   ('C:maj9', 'D:min', 'F:min'),
#   ('A:min/6', 'D/2', 'F'),
#   ('A', 'C', 'E/#4'),
#   ('A/3', 'B:min', 'F#'),
#   ('B:9', 'C#:7', 'F#'),
#   ('C#', 'C#:7', 'F#'),
#   ('D#:min', 'D:maj6', 'G'),
#   ('C', 'C#', 'E/4'),
#   ('A:min7', 'F#:min7', 'G'),
#   ('A', 'A:7', 'D:7'),
#   ('D:9', 'G', 'G:maj6/5'),
#   ('D:sus4', 'E:min7', 'G/5'),
#   ('D:sus4', 'E:7', 'F:maj9'),
#   ('C', 'D#:7', 'F:7'),
#   ('A:min7', 'C#', 'G'),
#   ('B', 'D#:min', 'D/7'),
#   ('C/3', 'D/5', 'D:7'),
#   ('A', 'F#', 'F#:min7'),
#   ('A', 'A:7', 'C/3'),
#   ('D:9', 'E/b7', 'E:min'),
#   ('C:maj6', 'E:7', 'G'),
#   ('A', 'B', 'D:min'),
#   ('A', 'C/3', 'F:maj9'),
#   ('D', 'D:(1)', 'G/b7'),
#   ('A:min7', 'D#:7', 'F#'),
#   ('D:maj6', 'E:min/b3', 'G:7'),
#   ('B:9', 'E:7(#9)', 'F:maj7'),
#   ('B:min', 'C:maj9', 'F:maj7'),
#   ('A:min', 'C:maj6', 'D/7'),
#   ('B:min', 'E', 'E:9'),
#   ('A/3', 'D#:7', 'F#'),
#   ('A', 'A:7/3', 'G/b7'),
#   ('A:min/6', 'D:min', 'E:min'),
#   ('A', 'D:sus4', 'F#:min7'),
#   ('C', 'D#:7', 'D:min'),
#   ('C', 'E:min/5', 'F#:min7'),
#   ('C', 'E:min', 'G:7'),
#   ('D', 'D:(1)', 'E:min/b3'),
#   ('A', 'D/7', 'D:min'),
#   ('D/2', 'D:7', 'E/5'),
#   ('A:min', 'D#:7', 'F#'),
#   ('A:min/6', 'D#:7', 'F#'),
#   ('A:min', 'C:maj6', 'F:maj7'),
#   ('D/2', 'D:sus4', 'E:min7'),
#   ('D:9', 'E:9', 'N'),
#   ('A/3', 'D:sus4', 'F:maj9'),
#   ('B:9', 'E/#4', 'E:7(#9)'),
#   ('E:7', 'G', 'G/b7'),
#   ('D', 'E:maj6/b7', 'E:min'),
#   ('E/5', 'F:7', 'G'),
#   ('A:(1)', 'G#', 'N'),
#   ('C', 'F:maj7', 'G:7'),
#   ('D', 'G/5', 'G/b7'),
#   ('C', 'C:maj9', 'F:7'),
#   ('A:min', 'C:maj6', 'D:7'),
#   ('C', 'F#:sus4', 'F:min'),
#   ('D:min', 'E:maj6/b7', 'E:min'),
#   ('A', 'D:7(#9)', 'E/3'),
#   ('D:(1)', 'D:9', 'E:min'),
#   ('A', 'A:min/6', 'E/3'),
#   ('E:9', 'E:min', 'F'),
#   ('D', 'E/b7', 'F:min'),
#   ('A:9', 'B:9', 'D:7(#9)'),
#   ('A', 'A:7/3', 'F#'),
#   ('C/3', 'D:7', 'E:min'),
#   ('B:min', 'C:maj9', 'D'),
#   ('A:7/3', 'A:9', 'E'),
#   ('E', 'E:7', 'G/5'),
#   ('B:min', 'E', 'E:min/5'),
#   ('D', 'D/7', 'F:min'),
#   ('C:maj9', 'D#:7', 'F#'),
#   ('C:maj9', 'D:min', 'F'),
#   ('A:min/6', 'D:sus4', 'E:min7'),
#   ('D:sus4', 'F:maj9', 'G:maj6/5'),
#   ('A:min', 'C:7', 'D:min'),
#   ('D:min', 'F#:min7', 'G'),
#   ('A/3', 'B:min', 'D:(1)'),
#   ('D:sus4', 'E/#4', 'F:maj9'),
#   ('A:9', 'E:min', 'F'),
#   ('E/3', 'E:9', 'N'),
#   ('C', 'C:maj6', 'D/7'),
#   ('A/3', 'D:min', 'G'),
#   ('A', 'B:9', 'C#'),
#   ('C', 'C:maj9', 'D:min'),
#   ('A/3', 'D/7', 'G:maj6/5'),
#   ('E/#4', 'E/4', 'N'),
#   ('D#:min', 'E:min', 'F#:sus4'),
#   ('C:maj9', 'D:maj6', 'N'),
#   ('C#:7', 'C:7', 'G#'),
#   ('C', 'C:maj6', 'F:maj7'),
#   ('A', 'E/3', 'E:9'),
#   ('A/3', 'D', 'D/2'),
#   ('B:min', 'D', 'F#:sus4'),
#   ('D#:min', 'E:min/b3', 'F#:sus4'),
#   ('E:9', 'E:min/5', 'N'),
#   ('C:7', 'D:7', 'F'),
#   ('D:9', 'E:min', 'G/5'),
#   ('A:9', 'E', 'F:maj7'),
#   ('A:7', 'F#', 'G'),
#   ('E:min/b3', 'F#:min7', 'G:7'),
#   ('C', 'D:sus4', 'F:maj9'),
#   ('C#:7', 'E:maj6/b7', 'G#'),
#   ('A/3', 'D', 'D#:min'),
#   ('C', 'D:maj6', 'F:min'),
#   ('B:min', 'D:min', 'F'),
#   ('B:min', 'C:7', 'D'),
#   ('E:7', 'E:9', 'G:7'),
#   ('A:9', 'B:7', 'B:9'),
#   ('C:7', 'E:min7', 'G/b7'),
#   ('B', 'C/3', 'E'),
#   ('C/3', 'D:7', 'G#'),
#   ('D:7', 'F', 'G:7'),
#   ('C:7', 'D:min', 'E:min/b3'),
#   ('A:7', 'E/#4', 'E/5'),
#   ('A/3', 'C#', 'D/7'),
#   ('E', 'E:7', 'F#:min7'),
#   ('C:maj6', 'D/5', 'E/3'),
#   ('D:sus4', 'E:min/b3', 'E:min7'),
#   ('D:7(#9)', 'E:min', 'F:maj9'),
#   ('E/#4', 'E/b7', 'G/5'),
#   ('A', 'E/3', 'E:min/5'),
#   ('A/3', 'E/b7', 'G/5'),
#   ('B:min', 'D#:min', 'E'),
#   ('C:maj9', 'F:maj7', 'G/b7'),
#   ('B', 'C:maj9', 'N'),
#   ('D', 'E/b7', 'E:min7'),
#   ('D', 'E:9', 'E:min'),
#   ('A:min7', 'C#:7', 'G'),
#   ('A:7', 'D', 'E:7'),
#   ('D', 'D:(1)', 'D:sus4'),
#   ('A:(1)', 'E', 'G'),
#   ('A', 'F#:min7', 'G/b7'),
#   ('B:min', 'E/4', 'E:min'),
#   ('C:7', 'D#:min', 'F#:sus4'),
#   ('D/2', 'E', 'G'),
#   ('B', 'D#:min', 'E:maj6/b7'),
#   ('C:7', 'F:7', 'G'),
#   ('E/#4', 'E/5', 'E:min/b3'),
#   ('A:min/6', 'E/5', 'N'),
#   ('A:min/6', 'C#:7', 'G#'),
#   ('B', 'D#:7', 'D#:min'),
#   ('D:sus4', 'E', 'F:maj9'),
#   ('A:min/6', 'C#', 'D:7'),
#   ('B:min', 'D', 'G#'),
#   ('D:sus4', 'E/5', 'F:maj9'),
#   ('D:9', 'E:min', 'F#:min7'),
#   ('D:9', 'D:sus4', 'E:min7'),
#   ('E:min', 'E:min7', 'F'),
#   ('B:9', 'D', 'E/b7'),
#   ('D:sus4', 'E:7(#9)', 'E:min7'),
#   ('B:9', 'D:9', 'E:7(#9)'),
#   ('C#:7', 'D:min', 'F:min'),
#   ('C#:7', 'C:maj9', 'F:maj7'),
#   ('A:9', 'B:9', 'D/7'),
#   ('E:min/b3', 'G:7', 'N'),
#   ('A:9', 'D:min', 'E:7'),
#   ('E:7(#9)', 'E:min/b3', 'G:7'),
#   ('A:7', 'E/#4', 'E/4'),
#   ('A/3', 'E', 'G'),
#   ('A:9', 'C:maj9', 'N'),
#   ('B:7', 'E:min', 'F'),
#   ('A', 'B:min', 'G:7'),
#   ('C', 'D#:7', 'F:min'),
#   ('A/3', 'B', 'B:min'),
#   ('B', 'E:min', 'G:maj6/5'),
#   ('A:9', 'B:9', 'F:maj7'),
#   ('A', 'B:min', 'E/#4'),
#   ('A:min/6', 'D/2', 'D:9'),
#   ('A:min/6', 'B:7', 'D/2'),
#   ('C:maj6', 'D#:min', 'F#:sus4'),
#   ('A:9', 'C', 'G:7'),
#   ('A/3', 'A:min/6', 'D/7'),
#   ('C', 'E/b7', 'G/5'),
#   ('A:(1)', 'D:9', 'G'),
#   ('C', 'D:7', 'D:min'),
#   ('A:(1)', 'A:min', 'C:maj6'),
#   ('D/2', 'D:9', 'G'),
#   ('A:9', 'B:9', 'D:7'),
#   ('D:7', 'D:7(#9)', 'F'),
#   ('A:min', 'B', 'F:7'),
#   ('A:(1)', 'F:min', 'N'),
#   ('A:min', 'A:min/6', 'D/7'),
#   ('C#:7', 'E:9', 'G#'),
#   ('C/3', 'D:7', 'E/b7'),
#   ('B', 'C:maj9', 'D#:min'),
#   ('A:(1)', 'A:min', 'F'),
#   ('A:7/3', 'C/3', 'D:7'),
#   ('D:9', 'E:7(#9)', 'E:min'),
#   ('A/3', 'B:min', 'F#:min7'),
#   ('B', 'G', 'G:7'),
#   ('D#:7', 'E:maj6/b7', 'G#'),
#   ('D:7', 'E:min7', 'F'),
#   ('D:min', 'E/b7', 'G/5'),
#   ('A:min', 'A:min/6', 'F:maj7'),
#   ('A:(1)', 'E:min/b3', 'G:7'),
#   ('E:min/b3', 'E:min7', 'G/b7'),
#   ('C', 'C:7', 'F:maj9'),
#   ('D/2', 'E:min/b3', 'G:7'),
#   ('D/5', 'E', 'E:7(#9)'),
#   ('B', 'E/3', 'F#:min7'),
#   ...},
#  '102': {('C', 'F', 'F#'),
#   ('E:7', 'F:maj7', 'G'),
#   ('A:min', 'D', 'E/5'),
#   ('A:min7', 'C', 'F'),
#   ('E/#4', 'E/b7', 'E:maj6/b7'),
#   ('A/3', 'E/b7', 'E:maj6/b7'),
#   ('E:9', 'F:maj7', 'G'),
#   ('A:(1)', 'F#', 'F#:sus4'),
#   ('E/b7', 'E:maj6/b7', 'F#:min7'),
#   ('A:min', 'D:maj6', 'E:min7'),
#   ('E:maj6/b7', 'G', 'N'),
#   ('C:7', 'D:7', 'G'),
#   ('D/2', 'D:7(#9)', 'D:9'),
#   ('B:min', 'G', 'G#'),
#   ('D', 'D:7', 'D:7(#9)'),
#   ('C', 'D', 'E/5'),
#   ('A:(1)', 'G/5', 'G:maj6/5'),
#   ('F', 'F#', 'N'),
#   ('A:min', 'D', 'E/4'),
#   ('A:min', 'F#', 'F#:sus4'),
#   ('D', 'E', 'E:9'),
#   ('C', 'D:7(#9)', 'N'),
#   ('E/3', 'G', 'N'),
#   ('A', 'A:min', 'N'),
#   ('D', 'D:maj6', 'E:maj6/b7'),
#   ('A:7', 'D#:min', 'E:7(#9)'),
#   ('D', 'D/2', 'N'),
#   ('C', 'E/b7', 'E:maj6/b7'),
#   ('A:min7', 'D', 'D/5'),
#   ('A:9', 'D', 'F'),
#   ('A/3', 'F#', 'N'),
#   ('A', 'C/3', 'N'),
#   ('A:min', 'D:sus4', 'E:min'),
#   ('A:min', 'D', 'D/5'),
#   ('D:7', 'D:maj6', 'E'),
#   ('D:min', 'E/b7', 'E:maj6/b7'),
#   ('A:min7', 'B:7', 'D'),
#   ('B:7', 'D#:7', 'E'),
#   ('C/3', 'G', 'N'),
#   ('A:min', 'B:7', 'D'),
#   ('E', 'G/5', 'G:maj6/5'),
#   ('C:7', 'D', 'E'),
#   ('B:min', 'F#', 'F#:sus4'),
#   ('F#', 'F#:min7', 'N'),
#   ('A:7/3', 'B:min', 'G'),
#   ('D', 'E:7', 'G'),
#   ('B:7', 'E', 'F:7'),
#   ('C:7', 'F#:sus4', 'G:7'),
#   ('B', 'E:min/5', 'F#'),
#   ('D:7', 'E:min7', 'G'),
#   ('A:min', 'D:maj6', 'E:min/5'),
#   ('C#:7', 'F', 'G'),
#   ('C#:7', 'D', 'N'),
#   ('B:min', 'G/5', 'G:maj6/5'),
#   ('A', 'E:7', 'F:7'),
#   ('D:7(#9)', 'D:9', 'F:7'),
#   ('D', 'D:7', 'F:maj7'),
#   ('B:7', 'D', 'F'),
#   ('D', 'E/3', 'N'),
#   ('D:7(#9)', 'D:9', 'D:min'),
#   ('D:7', 'E:9', 'G'),
#   ('A:min', 'C#', 'D:maj6'),
#   ('E/b7', 'E:maj6/b7', 'G:7'),
#   ('A', 'F:min', 'N'),
#   ('C/3', 'E/b7', 'E:maj6/b7'),
#   ('F', 'G/5', 'G:maj6/5'),
#   ('B:7', 'C:7', 'E'),
#   ('A:7', 'C#', 'E:7(#9)'),
#   ('D:sus4', 'E', 'N'),
#   ('C', 'D#:7', 'G'),
#   ('A', 'D/7', 'G'),
#   ('F#', 'F:7', 'N'),
#   ('B:min', 'E/3', 'G'),
#   ('A', 'E', 'E/b7'),
#   ('D:7', 'G', 'G:maj6/5'),
#   ('A:min/6', 'D', 'G:7'),
#   ('F#:sus4', 'G/5', 'G:maj6/5'),
#   ('A/3', 'A:7', 'E:7(#9)'),
#   ('C:maj6', 'D', 'D:7'),
#   ('A:9', 'A:min', 'D:maj6'),
#   ('C', 'C:maj9', 'G'),
#   ('A:min', 'D:7(#9)', 'D:maj6'),
#   ('D#:7', 'F', 'G'),
#   ('C/3', 'F#', 'N'),
#   ('C:7', 'D#:7', 'G:7'),
#   ('D', 'E:7(#9)', 'G'),
#   ('C', 'E', 'E:maj6/b7'),
#   ('G#', 'G/5', 'G:maj6/5'),
#   ('B:9', 'D:(1)', 'E'),
#   ('D', 'E/5', 'G'),
#   ('A:min', 'D', 'F:7'),
#   ('E:min/5', 'G', 'N'),
#   ('D', 'E/#4', 'N'),
#   ('A:min7', 'E', 'N'),
#   ('D', 'D/5', 'G:7'),
#   ('D:min', 'G/5', 'G:maj6/5'),
#   ('D:7', 'E', 'F:maj9'),
#   ('B:7', 'E', 'F:min'),
#   ('E:min', 'E:min/5', 'F:maj7'),
#   ('A:min', 'E:min7', 'G'),
#   ('A:7', 'E/b7', 'E:7(#9)'),
#   ('A:min', 'D', 'D:min'),
#   ('A', 'E:7', 'F:min'),
#   ('A', 'A:min/6', 'E:7'),
#   ('D:7(#9)', 'D:9', 'F:min'),
#   ('A:7', 'A:min', 'E:min'),
#   ('D', 'F#:min7', 'G:7'),
#   ('B', 'D:maj6', 'F#'),
#   ('E', 'E:min/b3', 'N'),
#   ('A:7', 'C', 'N'),
#   ('A:7/3', 'C', 'F'),
#   ('A:min7', 'D', 'F#'),
#   ('D:9', 'E/b7', 'E:maj6/b7'),
#   ('A:min', 'D:(1)', 'G'),
#   ('G', 'G/5', 'G:maj6/5'),
#   ('A:7/3', 'E:min', 'F:maj7'),
#   ('A', 'F#', 'F#:sus4'),
#   ('E/4', 'G', 'N'),
#   ('B:min', 'E:min7', 'G'),
#   ('A', 'C:7', 'N'),
#   ('A', 'E', 'F#'),
#   ('A', 'F:maj7', 'N'),
#   ('A:min', 'D/5', 'E:min'),
#   ('D', 'F#:sus4', 'G:7'),
#   ('C/3', 'G/5', 'G:maj6/5'),
#   ('B', 'E:7', 'F#'),
#   ('A', 'G/5', 'G:maj6/5'),
#   ('C', 'E:maj6/b7', 'F'),
#   ('D:7(#9)', 'D:9', 'E:min7'),
#   ('D', 'D:9', 'N'),
#   ('D:7(#9)', 'D:9', 'F'),
#   ('C:7', 'F:7', 'G:7'),
#   ('A:min', 'D:maj6', 'N'),
#   ('B', 'F', 'G'),
#   ('D:9', 'F#', 'N'),
#   ('C', 'E', 'G:maj6/5'),
#   ('D:7', 'E', 'F#:sus4'),
#   ('A:(1)', 'B:9', 'E'),
#   ('D:sus4', 'E/b7', 'E:maj6/b7'),
#   ('E:9', 'F', 'G'),
#   ('D:7', 'E', 'E:min'),
#   ('B:9', 'C:maj6', 'E'),
#   ('C', 'D:maj6', 'E'),
#   ('A', 'E:min/5', 'G'),
#   ('D:7', 'D:7(#9)', 'E'),
#   ('A:9', 'F', 'G'),
#   ('A:min', 'D', 'F:min'),
#   ('D', 'D:maj6', 'F:maj9'),
#   ('A:(1)', 'F:maj7', 'G'),
#   ('A:(1)', 'A:7', 'E:7(#9)'),
#   ('C#:7', 'D', 'D:7'),
#   ('B:7', 'E', 'E:9'),
#   ('A:7', 'B:7', 'E'),
#   ('F', 'F#', 'G'),
#   ('F#', 'F#:sus4', 'F:maj7'),
#   ('C', 'F:maj9', 'G'),
#   ('D:(1)', 'E:min', 'F:maj7'),
#   ('D:7', 'E', 'G#'),
#   ('D:sus4', 'F#', 'N'),
#   ('C', 'F#:min7', 'N'),
#   ('D', 'D/2', 'G'),
#   ('B:7', 'E', 'E:min/5'),
#   ('A:7', 'E/5', 'E:7(#9)'),
#   ('C#', 'F', 'G'),
#   ('C', 'D#:7', 'E'),
#   ('A:(1)', 'D:7', 'G'),
#   ('A', 'E:7', 'E:min/5'),
#   ('D:7(#9)', 'D:9', 'E:min/5'),
#   ('F#', 'G:maj6/5', 'N'),
#   ('C:7', 'F:maj9', 'G:7'),
#   ('A', 'G:7', 'N'),
#   ('B:7', 'F', 'G'),
#   ('B:7', 'D', 'N'),
#   ('C', 'C#:7', 'G'),
#   ('B', 'D:7', 'F#'),
#   ('D/5', 'D:7', 'E'),
#   ('C', 'C:maj9', 'E'),
#   ('A:min', 'D#:min', 'D:maj6'),
#   ('C:maj6', 'D:7(#9)', 'D:9'),
#   ('A', 'D/5', 'N'),
#   ('C', 'G', 'G:maj6/5'),
#   ('A:min7', 'F#', 'N'),
#   ('A:min/6', 'D:7(#9)', 'D:9'),
#   ('E/#4', 'F#', 'N'),
#   ('C', 'D', 'E:min7'),
#   ('A:7', 'A:min', 'D:maj6'),
#   ('D', 'D:maj6', 'F#:sus4'),
#   ('A:9', 'G/5', 'G:maj6/5'),
#   ('A:(1)', 'B', 'F#'),
#   ('D', 'E/3', 'G'),
#   ('B:9', 'D:7(#9)', 'E'),
#   ('D#:min', 'D:7(#9)', 'D:9'),
#   ('A:min7', 'D', 'E:9'),
#   ('E:7', 'E:min', 'F:maj7'),
#   ('A:7/3', 'B:7', 'E'),
#   ('C:maj9', 'D:7(#9)', 'D:9'),
#   ('A:min', 'D', 'E:9'),
#   ('A', 'E:min7', 'G'),
#   ('C', 'E/4', 'F'),
#   ('A', 'E', 'E:9'),
#   ('A:min/6', 'B', 'F#'),
#   ('F:maj7', 'G', 'G#'),
#   ('A:7/3', 'E', 'N'),
#   ('D:7', 'G', 'G#'),
#   ('A:min', 'D/5', 'D:maj6'),
#   ('A:min', 'E:min/5', 'G'),
#   ('D/7', 'G', 'N'),
#   ('B', 'E:maj6/b7', 'F#'),
#   ('D', 'E', 'F:maj7'),
#   ('C', 'E', 'F:maj9'),
#   ('A', 'E:9', 'G'),
#   ('E:min', 'F:maj7', 'F:maj9'),
#   ('A', 'F#:sus4', 'N'),
#   ('D', 'D:7', 'F:maj9'),
#   ('A', 'D', 'E:maj6/b7'),
#   ('D', 'D#:7', 'N'),
#   ('D:7', 'E', 'G/b7'),
#   ('A:min', 'D:maj6', 'F:maj7'),
#   ('B:min', 'E:min/5', 'G'),
#   ('C:7', 'G#', 'G:7'),
#   ('A', 'D:maj6', 'N'),
#   ('C#', 'E', 'N'),
#   ('A:7/3', 'A:min', 'D:maj6'),
#   ('A:min', 'D', 'D:9'),
#   ('A:min', 'B:7', 'E:min'),
#   ('A:7/3', 'C', 'N'),
#   ('A:min7', 'D', 'E/#4'),
#   ('B:9', 'E', 'G:maj6/5'),
#   ('D:7(#9)', 'E', 'N'),
#   ('F#:min7', 'F:maj7', 'G'),
#   ('B:9', 'D:maj6', 'E'),
#   ('A', 'E', 'G:7'),
#   ('A', 'E', 'E/#4'),
#   ('B:9', 'G', 'N'),
#   ('C:maj9', 'D', 'G:7'),
#   ('B:7', 'C', 'G'),
#   ('C', 'D', 'D:9'),
#   ('C', 'E', 'F#:sus4'),
#   ('E/b7', 'E:maj6/b7', 'G'),
#   ('C#:7', 'D:7(#9)', 'D:9'),
#   ('D:7(#9)', 'D:9', 'N'),
#   ('A:7/3', 'G', 'N'),
#   ('C', 'E', 'E:min'),
#   ('D#:7', 'F:maj7', 'G'),
#   ('A', 'E:min/b3', 'G'),
#   ('A:(1)', 'B:7', 'E'),
#   ('D#:min', 'E/b7', 'E:maj6/b7'),
#   ('A:7', 'D:sus4', 'E:7(#9)'),
#   ('E:min7', 'F#', 'N'),
#   ('B:7', 'D/7', 'E'),
#   ('D', 'F', 'F:7'),
#   ('E', 'G/b7', 'N'),
#   ('A:(1)', 'D:7', 'E'),
#   ('A', 'B:7', 'G'),
#   ('D', 'E/4', 'G:7'),
#   ('C', 'E', 'G#'),
#   ('A', 'D', 'G:maj6/5'),
#   ('E:min', 'G/5', 'G:maj6/5'),
#   ('A:min', 'E/b7', 'G'),
#   ('A/3', 'C:7', 'G:7'),
#   ('B:min', 'F#:sus4', 'G'),
#   ('D/5', 'G', 'N'),
#   ('A:min', 'C:maj9', 'D'),
#   ('A:min/6', 'C:7', 'G:7'),
#   ('B:7', 'D', 'D:7'),
#   ('D#:min', 'F#', 'N'),
#   ('B', 'E/3', 'F#'),
#   ('A:min/6', 'D:7', 'E'),
#   ('A:7/3', 'E/b7', 'E:maj6/b7'),
#   ('D', 'D:maj6', 'E:min/b3'),
#   ('C', 'C#:7', 'E'),
#   ('E/b7', 'E:min', 'F:maj7'),
#   ('E:min/b3', 'F#', 'N'),
#   ('D:7', 'E', 'G/5'),
#   ('A:min', 'E:7', 'G'),
#   ('F', 'G', 'G#'),
#   ('A/3', 'F', 'G'),
#   ('C', 'D/7', 'G'),
#   ('B:9', 'D#:min', 'E'),
#   ('A:(1)', 'A:min', 'D:maj6'),
#   ('B:min', 'E/b7', 'G'),
#   ('A', 'D:7(#9)', 'E'),
#   ('A', 'D#:min', 'G'),
#   ('A', 'A:min/6', 'E'),
#   ('C', 'E', 'E/b7'),
#   ('A:7/3', 'F#', 'N'),
#   ('D', 'F#:min7', 'G'),
#   ('C:7', 'G:7', 'N'),
#   ('A:min', 'E/4', 'E:min'),
#   ('D:7', 'E', 'F#:min7'),
#   ('A', 'D:7', 'N'),
#   ('D', 'D:sus4', 'G:7'),
#   ('F:maj7', 'F:min', 'G'),
#   ('D:7', 'D:min', 'E'),
#   ('A:min', 'D', 'D/2'),
#   ('A:min7', 'D', 'D#:min'),
#   ('C:7', 'D/7', 'G:7'),
#   ('D:7', 'F:min', 'G'),
#   ('B:min', 'E:7', 'G'),
#   ('D:7(#9)', 'E/b7', 'E:maj6/b7'),
#   ('D', 'D:maj6', 'D:sus4'),
#   ('E', 'G#', 'N'),
#   ('A:min', 'D', 'D#:min'),
#   ('D', 'F', 'F:min'),
#   ('D', 'F#:sus4', 'G'),
#   ('G', 'G:maj6/5', 'N'),
#   ('A:7', 'E:7(#9)', 'F:min'),
#   ('D', 'D#:7', 'D:7'),
#   ('F#', 'F#:sus4', 'F:maj9'),
#   ('C', 'G', 'G#'),
#   ('F:7', 'G/5', 'G:maj6/5'),
#   ('A', 'D/5', 'G'),
#   ('D/7', 'E', 'N'),
#   ('F:maj9', 'G/5', 'G:maj6/5'),
#   ('C', 'E/4', 'N'),
#   ('C', 'D', 'D#:7'),
#   ('C', 'D', 'D/2'),
#   ('A', 'G:maj6/5', 'N'),
#   ('D', 'E:min/b3', 'N'),
#   ('D', 'F:maj7', 'N'),
#   ('F:maj7', 'G', 'G/5'),
#   ('A:min', 'E:7(#9)', 'G'),
#   ('D:7(#9)', 'F#', 'N'),
#   ('A:7', 'D:7(#9)', 'D:9'),
#   ('D:7', 'G', 'G/5'),
#   ('A:min', 'E/5', 'G'),
#   ('D', 'E:7', 'F'),
#   ('C:7', 'E:min', 'F:maj7'),
#   ('B', 'D:7(#9)', 'D:9'),
#   ('G/5', 'G:maj6/5', 'N'),
#   ('C', 'E', 'G/b7'),
#   ('B:7', 'E', 'F:maj7'),
#   ('A', 'D/2', 'G'),
#   ('A:7/3', 'G/5', 'G:maj6/5'),
#   ('A', 'F:maj9', 'N'),
#   ('C', 'F#', 'F#:sus4'),
#   ('A', 'E:7', 'F:maj7'),
#   ('A:min7', 'D', 'D:7(#9)'),
#   ('D:7(#9)', 'D:9', 'F:maj7'),
#   ('D#:min', 'D:7', 'G'),
#   ('C', 'E', 'F#'),
#   ('A', 'D', 'E:7(#9)'),
#   ('C:maj9', 'D:7', 'G'),
#   ('A:min', 'D', 'D:7(#9)'),
#   ('B:9', 'E', 'E:min'),
#   ('A:9', 'A:min', 'D'),
#   ('B:min', 'E:7(#9)', 'G'),
#   ('A:(1)', 'C', 'G'),
#   ('C', 'G/5', 'G:maj6/5'),
#   ('D:7', 'E', 'G:7'),
#   ('D', 'D#:7', 'G'),
#   ('C:7', 'D', 'N'),
#   ('B:9', 'D:min', 'E'),
#   ('B', 'D/7', 'F#'),
#   ('C', 'D#:7', 'F'),
#   ('E', 'E/b7', 'E:maj6/b7'),
#   ('E', 'E:min7', 'N'),
#   ('C:maj6', 'D', 'D:maj6'),
#   ('A/3', 'A:min', 'G'),
#   ('A:min', 'D:(1)', 'D:maj6'),
#   ('A:min/6', 'D', 'E'),
#   ('A:min', 'E:min', 'F:7'),
#   ('B:9', 'E', 'G#'),
#   ('A:7', 'D:(1)', 'E:7(#9)'),
#   ('A:7', 'E:7(#9)', 'E:9'),
#   ('A', 'A:9', 'G'),
#   ('A', 'A:min7', 'E:7'),
#   ('D:(1)', 'F#', 'F#:sus4'),
#   ('A:min/6', 'G', 'N'),
#   ('A:min', 'C/3', 'G'),
#   ('A', 'E/b7', 'G'),
#   ('A:min', 'C#:7', 'D'),
#   ('C', 'C:maj9', 'F'),
#   ('A', 'C:maj9', 'D'),
#   ('F#:sus4', 'G', 'N'),
#   ('D:7(#9)', 'G/5', 'G:maj6/5'),
#   ('D', 'E:7(#9)', 'F'),
#   ('F#', 'F#:sus4', 'G#'),
#   ('A:7', 'E:7(#9)', 'E:min/5'),
#   ('D:(1)', 'G/5', 'G:maj6/5'),
#   ('D:7', 'D:sus4', 'G'),
#   ('D', 'D:7', 'D:sus4'),
#   ('A', 'D', 'F#:sus4'),
#   ('D', 'D/5', 'E'),
#   ('E:7(#9)', 'F#', 'F#:sus4'),
#   ('C#:7', 'F:maj7', 'G'),
#   ('D:7(#9)', 'D:9', 'E:maj6/b7'),
#   ('A:min', 'D', 'F:maj7'),
#   ('C', 'C/3', 'G'),
#   ('A', 'D:(1)', 'E:7'),
#   ('A:min', 'D:maj6', 'F:maj9'),
#   ('C', 'D/7', 'E'),
#   ('A', 'C#', 'E:7'),
#   ('B:9', 'E', 'E/b7'),
#   ('A:min/6', 'C', 'F'),
#   ('F', 'F:min', 'G'),
#   ('A', 'D#:min', 'E'),
#   ('C', 'E', 'G/5'),
#   ('A:min/6', 'E/b7', 'E:maj6/b7'),
#   ('D:7', 'D:7(#9)', 'D:9'),
#   ('A', 'D', 'G#'),
#   ('C', 'D', 'F:maj7'),
#   ('A', 'G#', 'N'),
#   ('C#:7', 'D:7', 'G'),
#   ('A', 'A:min', 'D:maj6'),
#   ('D/2', 'F#', 'N'),
#   ('D', 'D/2', 'D:maj6'),
#   ('A', 'E/#4', 'G'),
#   ('C:7', 'F#:min7', 'G:7'),
#   ('C', 'E', 'F#:min7'),
#   ('E/b7', 'G', 'N'),
#   ('F', 'G', 'G/5'),
#   ('D:7', 'E:min/5', 'G'),
#   ('E:7', 'G/5', 'G:maj6/5'),
#   ('A:7', 'C:maj6', 'E:7(#9)'),
#   ('A:min', 'E:min', 'F:min'),
#   ('C:7', 'E', 'N'),
#   ('D:sus4', 'F', 'G'),
#   ('C', 'E:min7', 'G'),
#   ('B:min', 'D/2', 'G'),
#   ('A', 'E:7(#9)', 'G'),
#   ('A:7', 'D:7', 'E:7(#9)'),
#   ('D', 'F:7', 'N'),
#   ('A:min', 'D:sus4', 'G'),
#   ('C#:7', 'D', 'D:maj6'),
#   ('A:min7', 'C:7', 'G:7'),
#   ('A', 'E/5', 'G'),
#   ('D:9', 'F#', 'F#:sus4'),
#   ('A:min', 'E/3', 'G'),
#   ('C:7', 'D:7(#9)', 'G:7'),
#   ('C:maj9', 'D', 'G'),
#   ('A:(1)', 'D:7(#9)', 'D:9'),
#   ('C:7', 'E:min7', 'G:7'),
#   ('A', 'C:maj6', 'E:7'),
#   ('C', 'F#:sus4', 'N'),
#   ('A', 'D/2', 'E'),
#   ('D', 'F:maj9', 'G'),
#   ('C', 'D', 'E:maj6/b7'),
#   ('F#', 'G:7', 'N'),
#   ('C', 'G', 'G/5'),
#   ('B:9', 'E', 'F#'),
#   ('D#:min', 'D:7', 'E'),
#   ('A:min', 'E:min', 'E:min7'),
#   ('F#', 'F#:sus4', 'G/b7'),
#   ('B:9', 'D:7(#9)', 'D:9'),
#   ('C:maj9', 'D:7', 'E'),
#   ('C', 'D:7(#9)', 'F'),
#   ('D#:7', 'E:min', 'F:maj7'),
#   ('A:(1)', 'C', 'E'),
#   ('C:7', 'E:9', 'G:7'),
#   ('D', 'D/2', 'F'),
#   ('B:min', 'D:sus4', 'G'),
#   ('C:7', 'D', 'D:7'),
#   ('D/2', 'F:maj7', 'G'),
#   ('E/b7', 'E:7', 'E:maj6/b7'),
#   ('A/3', 'B:9', 'E'),
#   ('C', 'D:maj6', 'N'),
#   ('A:min', 'B:9', 'E'),
#   ('C:7', 'F#', 'G:7'),
#   ('D', 'E:min/b3', 'G'),
#   ('A:7', 'E:7(#9)', 'N'),
#   ('A:min', 'C', 'E'),
#   ('E/b7', 'E:maj6/b7', 'F:7'),
#   ('C', 'E', 'E/#4'),
#   ('C:7', 'G', 'N'),
#   ('B:7', 'B:min', 'G'),
#   ('A', 'D', 'G/b7'),
#   ('C', 'C#:7', 'F'),
#   ('A:min', 'C:maj9', 'E:min'),
#   ('A', 'C#:7', 'D'),
#   ('E/5', 'F#', 'F#:sus4'),
#   ('A', 'B', 'N'),
#   ('D/5', 'D:7(#9)', 'D:9'),
#   ('C', 'D#:7', 'N'),
#   ('A', 'D', 'F#'),
#   ('D', 'G/b7', 'N'),
#   ('A', 'D/7', 'N'),
#   ('A:min', 'E:min', 'E:min/5'),
#   ('D', 'E/3', 'F'),
#   ('E/#4', 'F#', 'F#:sus4'),
#   ('B', 'E:min7', 'F#'),
#   ('B', 'D:7', 'G'),
#   ('D/2', 'E:min', 'F:maj7'),
#   ('E', 'F#:min7', 'N'),
#   ('B:min', 'E/#4', 'G'),
#   ('B:9', 'D', 'G:7'),
#   ('D', 'E:7(#9)', 'N'),
#   ('D:7', 'E:7', 'G'),
#   ('B', 'E:9', 'F#'),
#   ('C#:7', 'C:7', 'G:7'),
#   ('D', 'D:maj6', 'E:7'),
#   ('D', 'E:maj6/b7', 'G:7'),
#   ('F#', 'F#:sus4', 'G/5'),
#   ('D', 'E', 'E:min/b3'),
#   ('D:(1)', 'F:maj7', 'G'),
#   ('E:9', 'E:min', 'F:maj7'),
#   ('D:7(#9)', 'D:9', 'F:maj9'),
#   ('B:9', 'E', 'F#:min7'),
#   ('E', 'F#:sus4', 'N'),
#   ('B:7', 'D/5', 'E'),
#   ('D', 'D:9', 'D:maj6'),
#   ('C:7', 'F', 'G'),
#   ('D', 'D:7(#9)', 'G:7'),
#   ('F#', 'G/5', 'N'),
#   ('E/b7', 'E:maj6/b7', 'F:min'),
#   ('D', 'E:min7', 'G:7'),
#   ('D', 'E/#4', 'F'),
#   ('E:7(#9)', 'F:maj7', 'G'),
#   ('A:min', 'D:maj6', 'E:min/b3'),
#   ('B:9', 'E', 'E:9'),
#   ('A:9', 'C', 'G'),
#   ('A', 'F#', 'G'),
#   ('C', 'D:7', 'N'),
#   ('A:min', 'C#', 'E:min'),
#   ('D', 'G#', 'N'),
#   ('B:7', 'C#', 'E'),
#   ('A', 'D:sus4', 'G'),
#   ('D', 'E:9', 'G:7'),
#   ('C#', 'E:min', 'F:maj7'),
#   ('A:min', 'E:maj6/b7', 'E:min'),
#   ('D#:7', 'E', 'N'),
#   ('C:7', 'D#:min', 'G:7'),
#   ('C:maj9', 'D', 'E'),
#   ('A:7', 'C', 'F'),
#   ('E:min', 'E:min7', 'F:maj7'),
#   ('E:min', 'F:7', 'F:maj7'),
#   ('B:7', 'C', 'F'),
#   ('D', 'E', 'E:min7'),
#   ('E/b7', 'E:maj6/b7', 'E:min7'),
#   ('C', 'D/5', 'G'),
#   ('A:min7', 'D', 'E/5'),
#   ('B', 'E:min/b3', 'F#'),
#   ('E:min/b3', 'F', 'G'),
#   ('B:7', 'E:min', 'F:maj7'),
#   ('A', 'D:9', 'E'),
#   ('C/3', 'D:7(#9)', 'D:9'),
#   ('A:9', 'A:min', 'E:min'),
#   ('A', 'D:7(#9)', 'D:9'),
#   ('A:min', 'D', 'F:maj9'),
#   ('D:7(#9)', 'D:9', 'F#:sus4'),
#   ('A:min', 'C:maj9', 'D:maj6'),
#   ('A', 'E', 'E/5'),
#   ('A:min7', 'E/b7', 'E:maj6/b7'),
#   ('D', 'F', 'F:maj7'),
#   ('A:min', 'D:maj6', 'D:sus4'),
#   ('A:7', 'E:7(#9)', 'F:maj7'),
#   ('A', 'E:min/5', 'N'),
#   ('D', 'D:9', 'F'),
#   ('A', 'D', 'E:9'),
#   ('A:min', 'F#:sus4', 'G'),
#   ('A', 'A:min7', 'E'),
#   ('B:7', 'D', 'D:maj6'),
#   ('C:7', 'G/5', 'G:maj6/5'),
#   ('C:7', 'D/5', 'G:7'),
#   ('B:min', 'D:(1)', 'G'),
#   ('A:min7', 'D', 'E/4'),
#   ('B:9', 'E', 'G:7'),
#   ('C:maj6', 'F#', 'F#:sus4'),
#   ('B:9', 'E', 'E/#4'),
#   ('C', 'D', 'F:maj9'),
#   ('C', 'F:maj9', 'N'),
#   ('D:7(#9)', 'D:9', 'G#'),
#   ('A:min', 'C#:7', 'E:min'),
#   ('C:maj6', 'G/5', 'G:maj6/5'),
#   ('D:7', 'E', 'G:maj6/5'),
#   ('D', 'D:7', 'E:7'),
#   ('C', 'F#:sus4', 'G'),
#   ('A:min/6', 'F#', 'N'),
#   ('A', 'D:(1)', 'E'),
#   ('D:7', 'E:maj6/b7', 'G'),
#   ('E/b7', 'E:maj6/b7', 'E:min/5'),
#   ('B:9', 'C:maj9', 'E'),
#   ('A:min', 'D:7', 'D:maj6'),
#   ('F:maj7', 'F:maj9', 'G'),
#   ('C', 'C#:7', 'N'),
#   ('D:maj6', 'E:min', 'F:maj7'),
#   ('D', 'D:sus4', 'E'),
#   ('C', 'E/b7', 'G'),
#   ('E/3', 'E/b7', 'E:maj6/b7'),
#   ('E:min', 'E:min/b3', 'F:maj7'),
#   ('C/3', 'D', 'G:7'),
#   ('A:min', 'D#:7', 'G'),
#   ('C', 'C:maj9', 'D'),
#   ('D:min', 'F#', 'N'),
#   ('B:9', 'D:7', 'G'),
#   ('A:7', 'D:9', 'E:7(#9)'),
#   ('A', 'D', 'E/#4'),
#   ('D', 'D#:7', 'D:maj6'),
#   ('B', 'F#', 'G:maj6/5'),
#   ('E:maj6/b7', 'F#', 'N'),
#   ('C', 'D', 'F#:sus4'),
#   ('A', 'D:7(#9)', 'N'),
#   ('B', 'D/5', 'F#'),
#   ('A', 'A:min/6', 'N'),
#   ('A', 'B', 'G'),
#   ('A:9', 'D:7(#9)', 'D:9'),
#   ('C', 'E:7', 'G'),
#   ('A', 'E:min7', 'N'),
#   ('A', 'F:7', 'N'),
#   ('E/5', 'F:maj7', 'G'),
#   ('E/3', 'F#', 'N'),
#   ('A:min7', 'B:9', 'E'),
#   ('A:7', 'A:min', 'E:7(#9)'),
#   ('D', 'D#:min', 'G:7'),
#   ('A:min/6', 'C', 'D'),
#   ('F:maj7', 'G', 'G:maj6/5'),
#   ('A:7', 'C/3', 'E:7(#9)'),
#   ('D/7', 'E:min', 'F:maj7'),
#   ('D', 'D:maj6', 'G:maj6/5'),
#   ('E/#4', 'F:maj7', 'G'),
#   ('C', 'D', 'G#'),
#   ('A:min', 'C:7', 'G'),
#   ('D/5', 'D:7', 'G'),
#   ('A', 'D:sus4', 'E'),
#   ('B', 'D/2', 'F#'),
#   ('B:7', 'E', 'E:min/b3'),
#   ('D:7(#9)', 'D:9', 'D:maj6'),
#   ('A:min7', 'D', 'F:7'),
#   ('A', 'A:min', 'E:7'),
#   ('A:min', 'B:7', 'G'),
#   ('D:7(#9)', 'D:9', 'G/b7'),
#   ('A', 'E:7', 'E:min/b3'),
#   ('A', 'C/3', 'E:7'),
#   ('D:7(#9)', 'D:9', 'E:min/b3'),
#   ('C#:7', 'G/5', 'G:maj6/5'),
#   ('D', 'D:7', 'E:maj6/b7'),
#   ('C', 'D/5', 'E'),
#   ('D:7', 'E', 'E/3'),
#   ('A:(1)', 'C', 'F'),
#   ('A/3', 'D:7', 'G'),
#   ('A', 'E', 'F:7'),
#   ('A:min7', 'D', 'D:min'),
#   ('D', 'D#:7', 'F'),
#   ('D:7', 'E/3', 'G'),
#   ('A:min', 'D#:min', 'E:min'),
#   ('A:min', 'C#:7', 'D:maj6'),
#   ('B:min', 'E:maj6/b7', 'G'),
#   ('C', 'E:7(#9)', 'G'),
#   ('E:maj6/b7', 'F:maj7', 'G'),
#   ('F#:min7', 'G/5', 'G:maj6/5'),
#   ('A/3', 'E:min', 'F:maj7'),
#   ('D:7', 'D:9', 'E'),
#   ('A:min', 'E:9', 'G'),
#   ('B', 'E/b7', 'F#'),
#   ('A:9', 'D', 'G:7'),
#   ('B:7', 'C', 'N'),
#   ('E/b7', 'E:maj6/b7', 'N'),
#   ('C', 'D/2', 'E'),
#   ('A:min7', 'B', 'F#'),
#   ('D/2', 'F', 'G'),
#   ('A', 'E:min/b3', 'N'),
#   ('A/3', 'B', 'F#'),
#   ('B:7', 'E', 'E:min7'),
#   ('B:7', 'E', 'F'),
#   ('D#:7', 'G/5', 'G:maj6/5'),
#   ('A:9', 'E/b7', 'E:maj6/b7'),
#   ('D:7(#9)', 'D:9', 'D:sus4'),
#   ('B', 'F#', 'F:maj9'),
#   ('D:maj6', 'E', 'N'),
#   ('B:min', 'C', 'F'),
#   ('A', 'E:7', 'E:min7'),
#   ('C', 'C/3', 'F'),
#   ('A:min/6', 'D', 'N'),
#   ('B:7', 'G', 'N'),
#   ('A', 'C/3', 'D'),
#   ('A', 'E:7', 'F'),
#   ('D', 'D:min', 'G:7'),
#   ('A', 'B:7', 'N'),
#   ('B:min', 'E:9', 'G'),
#   ('A:min', 'D', 'E:min/b3'),
#   ('D:7', 'E/#4', 'G'),
#   ('B:9', 'C#:7', 'E'),
#   ('E:min/5', 'F#', 'N'),
#   ('B:9', 'D', 'G'),
#   ('A:7', 'E/3', 'E:7(#9)'),
#   ('A:7', 'D#:7', 'E:7(#9)'),
#   ('A:min7', 'D', 'F:min'),
#   ('E:min', 'F:maj7', 'G:maj6/5'),
#   ('A:9', 'F#', 'N'),
#   ('E/4', 'E/b7', 'E:maj6/b7'),
#   ('D', 'D:7', 'G:maj6/5'),
#   ('C', 'D', 'G/b7'),
#   ('B:9', 'C:7', 'G:7'),
#   ('D:7(#9)', 'D:9', 'G/5'),
#   ('D', 'D/5', 'N'),
#   ('E:min7', 'F:maj7', 'G'),
#   ('C', 'D', 'E:min/b3'),
#   ('A', 'E', 'F:min'),
#   ('B', 'E/#4', 'F#'),
#   ('A:7/3', 'A:min', 'E:min'),
#   ('C:7', 'F:min', 'G:7'),
#   ('D', 'D:maj6', 'E:7(#9)'),
#   ('D/2', 'F#', 'F#:sus4'),
#   ('C', 'D/7', 'N'),
#   ('A:min', 'E:min/b3', 'G'),
#   ('B:7', 'E/b7', 'E:maj6/b7'),
#   ('F', 'G', 'G:maj6/5'),
#   ('A', 'D#:min', 'N'),
#   ('D', 'F#:min7', 'N'),
#   ('D', 'E:min7', 'G'),
#   ('A', 'E/4', 'E:7'),
#   ('D/2', 'G/5', 'G:maj6/5'),
#   ('E/4', 'F#', 'N'),
#   ('D#:min', 'F:maj7', 'G'),
#   ('A:min7', 'D', 'E:min7'),
#   ('A:7', 'C:7', 'E:7(#9)'),
#   ('B', 'E:7(#9)', 'F#'),
#   ('D', 'F', 'F:maj9'),
#   ('A:min', 'D', 'E:min7'),
#   ('A:7', 'F#', 'N'),
#   ('B', 'E/5', 'F#'),
#   ('A', 'E', 'E:min7'),
#   ('D', 'E:9', 'G'),
#   ('B:7', 'D:sus4', 'E'),
#   ('B:7', 'F#', 'N'),
#   ('A', 'E', 'F'),
#   ('A:min/6', 'D:7', 'G'),
#   ('B:min', 'E:min/b3', 'G'),
#   ('D', 'F#:sus4', 'N'),
#   ('A', 'E:maj6/b7', 'G'),
#   ('C:maj9', 'D', 'F'),
#   ('D', 'F#', 'G'),
#   ('C', 'D', 'D:sus4'),
#   ('D:7', 'E', 'E/b7'),
#   ('E:9', 'G/5', 'G:maj6/5'),
#   ('A/3', 'B:7', 'E'),
#   ('D/2', 'E', 'N'),
#   ('B', 'D:9', 'F#'),
#   ('A:7', 'A:min7', 'E:7(#9)'),
#   ('A', 'C:7', 'E:7'),
#   ('B', 'F#', 'G#'),
#   ('C:7', 'E/4', 'G:7'),
#   ('A:min', 'B:7', 'E'),
#   ('C:7', 'D', 'D:maj6'),
#   ('A:min7', 'D:7', 'E'),
#   ('A', 'A:min/6', 'G'),
#   ('A/3', 'E', 'N'),
#   ('A/3', 'D:7', 'E'),
#   ('A:min', 'E', 'N'),
#   ('E/5', 'F', 'G'),
#   ('B', 'B:9', 'F#'),
#   ('A:min', 'D:maj6', 'E:7'),
#   ('C#', 'F#', 'F#:sus4'),
#   ('D', 'E:min/b3', 'F'),
#   ('C', 'D:sus4', 'G'),
#   ('A', 'D/2', 'N'),
#   ('D', 'D:maj6', 'G#'),
#   ('C', 'E', 'E/3'),
#   ('C#', 'G/5', 'G:maj6/5'),
#   ('E/b7', 'E:maj6/b7', 'F:maj7'),
#   ('C', 'E/3', 'G'),
#   ('A:(1)', 'A:min', 'E:min'),
#   ('A', 'E', 'E:min/5'),
#   ('A:7', 'B', 'E:7(#9)'),
#   ('A:7/3', 'D:7(#9)', 'D:9'),
#   ('A:min', 'D/7', 'D:maj6'),
#   ('B:9', 'D/2', 'E'),
#   ('B:7', 'C', 'D'),
#   ('B:min', 'D#:min', 'G'),
#   ('A/3', 'C', 'E'),
#   ('B:7', 'G/5', 'G:maj6/5'),
#   ('C', 'D', 'F#:min7'),
#   ('C', 'D:9', 'E'),
#   ('D', 'D:7', 'E:7(#9)'),
#   ('A', 'C:7', 'D'),
#   ('A:min', 'C', 'N'),
#   ('A:min/6', 'D', 'D:7'),
#   ('C', 'E', 'E/5'),
#   ('A:min7', 'D', 'D:9'),
#   ('D:7', 'F#', 'F#:sus4'),
#   ('E', 'F:min', 'N'),
#   ('D', 'F:min', 'G:7'),
#   ('D/7', 'E/b7', 'E:maj6/b7'),
#   ('A', 'A:9', 'N'),
#   ('C:7', 'D', 'F'),
#   ('D:7', 'E', 'F#'),
#   ('A', 'E/b7', 'N'),
#   ('A', 'B:7', 'D'),
#   ('F:maj7', 'G/5', 'G:maj6/5'),
#   ('A:9', 'B', 'F#'),
#   ('C/3', 'D', 'G'),
#   ('A:min', 'D/2', 'G'),
#   ('F#', 'F#:sus4', 'G:maj6/5'),
#   ('D', 'D/5', 'D:7'),
#   ('C', 'E/#4', 'G'),
#   ('B:9', 'D/7', 'E'),
#   ('D', 'E', 'E:maj6/b7'),
#   ('B:min', 'C', 'N'),
#   ('D:(1)', 'D:7(#9)', 'D:9'),
#   ('C', 'C/3', 'N'),
#   ('D/7', 'F#', 'N'),
#   ('A', 'E/4', 'G'),
#   ('B', 'F#', 'G/b7'),
#   ('D', 'D:7', 'F#:sus4'),
#   ('D', 'D:7(#9)', 'E'),
#   ('D', 'D#:min', 'G'),
#   ('A:7', 'E:7(#9)', 'F:7'),
#   ('D:7', 'E', 'F:min'),
#   ('A:min', 'A:min7', 'E:min'),
#   ('A:min/6', 'D', 'G'),
#   ('C', 'F', 'F:maj7'),
#   ('A:min', 'D:maj6', 'E:maj6/b7'),
#   ('D:maj6', 'G/5', 'G:maj6/5'),
#   ('A:9', 'C', 'F'),
#   ('A:min7', 'E:min', 'F:maj7'),
#   ('B', 'D:sus4', 'F#'),
#   ('A:min', 'E/b7', 'E:maj6/b7'),
#   ('A', 'E/#4', 'N'),
#   ('D', 'D:maj6', 'G/b7'),
#   ('E:min', 'F:maj7', 'G#'),
#   ('A:min', 'E:min', 'F:maj9'),
#   ('D', 'D:7', 'G#'),
# ...
#   ('F:min', 'G:7', 'E/3'),
#   ('E', 'B:9', 'B:7'),
#   ('C', 'F#', 'C#'),
#   ('A:min', 'G:7', 'E/5'),
#   ('F:maj7', 'A:7', 'E:7'),
#   ('F:maj7', 'C:maj9', 'B:9'),
#   ('F#:sus4', 'B:9', 'A:(1)'),
#   ('A:min', 'A', 'G#'),
#   ('E:min', 'D:sus4', 'C/3'),
#   ('F:maj7', 'A:min7', 'B'),
#   ('C', 'E/4', 'D/2'),
#   ('F#:min7', 'E:min/5', 'C/3'),
#   ('C', 'E/5', 'G/b7'),
#   ('D:maj6', 'F#:min7', 'G:maj6/5'),
#   ('A:7/3', 'G#', 'E/4'),
#   ('F:maj7', 'D:min', 'E/4'),
#   ('C:maj6', 'E:maj6/b7', 'D:sus4'),
#   ('A:min', 'C:7', 'D:(1)'),
#   ('E:min', 'D', 'A:9'),
#   ('A', 'A/3', 'E:min/b3'),
#   ('E', 'D:maj6', 'G:7'),
#   ('E', 'D:7', 'B:min'),
#   ('F', 'A:7/3', 'E/#4'),
#   ('E/b7', 'E:maj6/b7', 'E/3'),
#   ('C', 'G/b7', 'D:sus4'),
#   ('D:maj6', 'E/4', 'D:sus4'),
#   ('E', 'A:7/3', 'A:7'),
#   ('E', 'A:7', 'G:maj6/5'),
#   ('E:min/5', 'F#:sus4', 'E:min/b3'),
#   ('A:min', 'E:maj6/b7', 'A:9'),
#   ('C:7', 'E/#4', 'B:9'),
#   ('E', 'D#:min', 'D/5'),
#   ('F#:min7', 'B:7', 'E:7(#9)'),
#   ('A:min7', 'G:7', 'G/b7'),
#   ('F:maj7', 'D:7', 'G:7'),
#   ('A:min', 'D#:min', 'D#:7'),
#   ('E:min7', 'F:maj9', 'E:min/b3'),
#   ('F#', 'E/3', 'E:7(#9)'),
#   ('C:maj9', 'G:maj6/5', 'E:min/b3'),
#   ('A:min7', 'A:min/6', 'A:9'),
#   ('D#:min', 'B:min', 'D/7'),
#   ('E:7', 'F#:sus4', 'D#:min'),
#   ('D:7', 'F:maj9', 'A:min/6'),
#   ('F:maj7', 'D', 'A:min7'),
#   ('D', 'D:7', 'B:7'),
#   ('A:min', 'F:min', 'B:7'),
#   ('C:maj6', 'B:9', 'A/3'),
#   ('C', 'A:min7', 'E:min/b3'),
#   ('N', 'D:min', 'E/3'),
#   ('G', 'F:maj7', 'E/5'),
#   ('A:min', 'E', 'A:min7'),
#   ('A:min', 'F#:sus4', 'E/#4'),
#   ('G', 'G#', 'D:7(#9)'),
#   ('F#:sus4', 'D/7', 'D:9'),
#   ('A:min', 'D:min', 'A'),
#   ('N', 'D#:7', 'G:7'),
#   ('D', 'E:maj6/b7', 'G/b7'),
#   ('F#:sus4', 'D#:7', 'A:min/6'),
#   ('E:min7', 'C/3', 'A:min/6'),
#   ('A:7/3', 'F:7', 'B:7'),
#   ('F:min', 'F#:sus4', 'A:9'),
#   ('D:7', 'C#', 'D:9'),
#   ('G', 'D/7', 'A/3'),
#   ('D:maj6', 'A:7', 'A:(1)'),
#   ('C', 'E:min', 'B:min'),
#   ('F:maj7', 'A:7/3', 'A:(1)'),
#   ('C:maj9', 'E/b7', 'E/3'),
#   ('D', 'E/b7', 'D:9'),
#   ('C:maj6', 'A:min', 'E:min'),
#   ('F#:sus4', 'D#:min', 'E/4'),
#   ('C:maj6', 'F:7', 'G/5'),
#   ('D:7', 'F#:sus4', 'G#'),
#   ('E/5', 'C/3', 'E:7(#9)'),
#   ('D:min', 'D#:min', 'E/5'),
#   ('C', 'E:7', 'C:7'),
#   ('C:maj6', 'D:maj6', 'E/5'),
#   ('C:maj9', 'A:7/3', 'C/3'),
#   ('N', 'G#', 'A/3'),
#   ('D:7', 'E/b7', 'B:min'),
#   ('N', 'C#', 'E/4'),
#   ('C#:7', 'G/b7', 'E:9'),
#   ('C#', 'E:min7', 'E:7(#9)'),
#   ('F:maj7', 'F#', 'A/3'),
#   ('N', 'D:sus4', 'E:min/b3'),
#   ('N', 'C:maj9', 'E/#4'),
#   ('D:maj6', 'B:9', 'E/3'),
#   ('G:7', 'E/4', 'D:7(#9)'),
#   ('E:7', 'F:7', 'B:min'),
#   ('N', 'E/5', 'D:9'),
#   ('C:maj6', 'D/7', 'D/2'),
#   ('A', 'B', 'E:min/5'),
#   ('F', 'E:7', 'G:7'),
#   ('E:min', 'A', 'G/5'),
#   ('A:7', 'G/b7', 'F:maj9'),
#   ('C', 'F#:sus4', 'B:9'),
#   ('F', 'A:min', 'D/2'),
#   ('F', 'C:maj6', 'E:9'),
#   ('F:7', 'G/b7', 'D:(1)'),
#   ('G:maj6/5', 'D/2', 'A:min/6'),
#   ('D:7', 'E:maj6/b7', 'B:9'),
#   ('E:min', 'B:min', 'D/2'),
#   ('F', 'E/4', 'C/3'),
#   ('C', 'G#', 'D:sus4'),
#   ('F:7', 'E:maj6/b7', 'G:maj6/5'),
#   ('A:7/3', 'E/b7', 'F:maj9'),
#   ('E:min', 'A:7', 'E:min/b3'),
#   ('B:9', 'A/3', 'G/b7'),
#   ('C', 'C:maj9', 'A/3'),
#   ('G/5', 'E/#4', 'B:9'),
#   ('D:7', 'D/5', 'A:(1)'),
#   ('A:min7', 'D#:7', 'G:7'),
#   ('A:min', 'A/3', 'G/b7'),
#   ('C', 'A:7/3', 'A:7'),
#   ('B:min', 'E/4', 'G/b7'),
#   ('F', 'F#', 'E:min/b3'),
#   ('C:maj9', 'F#:min7', 'D#:7'),
#   ('A:min', 'G/5', 'F:maj9'),
#   ('D:min', 'D:maj6', 'E/#4'),
#   ('E:7', 'G:maj6/5', 'B:9'),
#   ('B', 'D#:7', 'C/3'),
#   ('A:7', 'D/5', 'D:7(#9)'),
#   ('A:min', 'E/b7', 'E/4'),
#   ('C:maj9', 'D:sus4', 'A:(1)'),
#   ('F', 'D', 'F#'),
#   ('F:7', 'G#', 'A:(1)'),
#   ('E:7', 'D/5', 'D:9'),
#   ('G', 'D/2', 'D:7(#9)'),
#   ('D#:min', 'D#:7', 'G:7'),
#   ('F', 'E:min/b3', 'A:9'),
#   ('D#:min', 'B:7', 'D/7'),
#   ('A:min7', 'C#', 'E/4'),
#   ('D/7', 'D/5', 'A:(1)'),
#   ('D:maj6', 'G#', 'G/5'),
#   ('F#', 'E/4', 'E:9'),
#   ('A:7', 'D:sus4', 'D:(1)'),
#   ('E:7', 'F#', 'D/5'),
#   ('E', 'F#', 'E:min7'),
#   ('A:min7', 'D:sus4', 'E:min/b3'),
#   ('A:7/3', 'E:7', 'B:9'),
#   ('A', 'B:9', 'B:7'),
#   ('C:maj6', 'A:7', 'F:7'),
#   ('E:min/5', 'A/3', 'A:min/6'),
#   ('D#:min', 'E/#4', 'E:7(#9)'),
#   ('G', 'B:9', 'F:maj9'),
#   ('E:maj6/b7', 'D/2', 'E:min/b3'),
#   ('A', 'F#', 'B:min'),
#   ('N', 'F#:sus4', 'B:min'),
#   ('A:7/3', 'F#:min7', 'D/2'),
#   ('G', 'D:7', 'E:maj6/b7'),
#   ('D', 'E:min7', 'D:(1)'),
#   ('G', 'C:maj9', 'A:min/6'),
#   ('D:min', 'A:7', 'C#'),
#   ('F', 'B:min', 'F:maj9'),
#   ('D:maj6', 'G:7', 'E:min7'),
#   ('F:maj7', 'F#:min7', 'E:min/b3'),
#   ('F:maj7', 'C:maj9', 'D:7(#9)'),
#   ('E:min', 'D:7', 'F#:sus4'),
#   ('G', 'A:min', 'E:7(#9)'),
#   ('E', 'D#:min', 'A:(1)'),
#   ('D#:7', 'B:9', 'E:min7'),
#   ('G', 'C:maj6', 'F#:min7'),
#   ('G', 'E/#4', 'D/2'),
#   ('D:min', 'G:7', 'B:min'),
#   ('N', 'C', 'A'),
#   ('A', 'A:7/3', 'A:7'),
#   ('A:7', 'G#', 'F:maj9'),
#   ('A', 'D#:min', 'D/5'),
#   ('F#:min7', 'F:7', 'D:sus4'),
#   ('C:maj6', 'F:min', 'D:9'),
#   ('F', 'A:min/6', 'E:9'),
#   ('N', 'C:maj6', 'C#'),
#   ('F', 'D:maj6', 'D#:min'),
#   ('N', 'E', 'G/b7'),
#   ('G', 'B', 'A:(1)'),
#   ('D:7', 'D:maj6', 'C/3'),
#   ('D:maj6', 'F#:min7', 'F#:sus4'),
#   ('A:min', 'E', 'E/5'),
#   ('C:7', 'E/#4', 'D:7(#9)'),
#   ('F:min', 'B:min', 'A:min/6'),
#   ('D:min', 'F#', 'B:7'),
#   ('A:min7', 'F#:sus4', 'B:min'),
#   ('A:7', 'E:maj6/b7', 'E:7(#9)'),
#   ('E/4', 'B:7', 'E:min/b3'),
#   ('E:min/5', 'C#:7', 'E/b7'),
#   ('A:min', 'F:7', 'E/#4'),
#   ('E:7', 'F:7', 'C/3'),
#   ('N', 'G', 'A'),
#   ('N', 'A:7/3', 'E:min/5'),
#   ('E:min', 'F:7', 'D#:7'),
#   ('D', 'B:min', 'E/5'),
#   ('C:maj6', 'A:min', 'D:maj6'),
#   ('E:min', 'F#:sus4', 'C/3'),
#   ('F:7', 'E/b7', 'B:min'),
#   ('D:maj6', 'F:7', 'D#:min'),
#   ('E', 'E:min7', 'C/3'),
#   ('E', 'A:7', 'F#:sus4'),
#   ('F#:sus4', 'E:min7', 'E:9'),
#   ('F', 'G:maj6/5', 'E/#4'),
#   ('E:min', 'C#', 'D/5'),
#   ('E', 'F:min', 'E/3'),
#   ('G:7', 'B:min', 'A:min/6'),
#   ('G:maj6/5', 'C/3', 'D:(1)'),
#   ('C#:7', 'E/4', 'B:7'),
#   ('E', 'D#:min', 'D:(1)'),
#   ('D', 'E:7', 'D#:7'),
#   ('E:7', 'E/#4', 'E:9'),
#   ('E', 'F:7', 'F:maj9'),
#   ('D:7', 'F:7', 'G#'),
#   ('D/7', 'D:7(#9)', 'E:7(#9)'),
#   ('C:maj6', 'D:7', 'E/4'),
#   ('A', 'F#:sus4', 'F:maj9'),
#   ('D#:7', 'D:sus4', 'E:7(#9)'),
#   ('C:maj6', 'B', 'D:9'),
#   ('D:7', 'E:min/b3', 'E:7(#9)'),
#   ('A:min', 'E:min/b3', 'E:9'),
#   ('E:min/5', 'E/4', 'A:(1)'),
#   ('F:maj7', 'E/5', 'D/7'),
#   ('D:7', 'B:min', 'G/b7'),
#   ('N', 'F:min', 'E:7(#9)'),
#   ('E:min/5', 'E:min7', 'A:9'),
#   ('N', 'D:(1)', 'A:(1)'),
#   ('F:7', 'F#:sus4', 'E/3'),
#   ('E', 'E:min/b3', 'A:(1)'),
#   ('F', 'E:min', 'C#:7'),
#   ('A:min', 'C#', 'F:maj9'),
#   ('C:7', 'F:min', 'F#:sus4'),
#   ('D:min', 'B', 'C#:7'),
#   ('F', 'B:7', 'F:maj9'),
#   ('F', 'E:min7', 'D:9'),
#   ('B', 'E:maj6/b7', 'C/3'),
#   ('A:min', 'F:maj7', 'E:min/5'),
#   ('B:min', 'B:9', 'E:min/b3'),
#   ('A:7/3', 'C#', 'E/3'),
#   ('E:min', 'D:maj6', 'D:sus4'),
#   ('A', 'A:min7', 'C#:7'),
#   ('F', 'D', 'E:9'),
#   ('B', 'A/3', 'D:9'),
#   ('E', 'C:maj9', 'G#'),
#   ('C', 'F#:sus4', 'D:7(#9)'),
#   ('A', 'C#', 'A:min/6'),
#   ('C:maj9', 'D/5', 'A:9'),
#   ('D:7', 'E:maj6/b7', 'D:7(#9)'),
#   ('E:min/5', 'C#:7', 'G/b7'),
#   ('G', 'D#:7', 'F:maj9'),
#   ('G/5', 'E/#4', 'D:7(#9)'),
#   ('A', 'E/3', 'C/3'),
#   ('G', 'F:maj9', 'A:min/6'),
#   ('F#:min7', 'C:7', 'F:min'),
#   ('F#', 'E/b7', 'E:min7'),
#   ('F:min', 'B:7', 'A:min/6'),
#   ('A:min7', 'F:min', 'E:7(#9)'),
#   ('D:min', 'C:7', 'F:maj9'),
#   ('E', 'D/7', 'A:9'),
#   ('A:min7', 'D:(1)', 'A:(1)'),
#   ('A:7', 'G:maj6/5', 'D/2'),
#   ('F:maj7', 'F:maj9', 'D:7(#9)'),
#   ('C:maj6', 'D:min', 'D'),
#   ('F', 'C#:7', 'E/#4'),
#   ('C:maj9', 'E/5', 'D/2'),
#   ('D', 'F#:min7', 'F:7'),
#   ('E:7', 'G:maj6/5', 'D:7(#9)'),
#   ('F:maj7', 'B:min', 'D:sus4'),
#   ('E/4', 'D/7', 'F:maj9'),
#   ('A:7/3', 'E/#4', 'A:min/6'),
#   ('F#:min7', 'B:min', 'E:9'),
#   ('A', 'F:7', 'E:9'),
#   ('G:maj6/5', 'B:min', 'E/3'),
#   ('N', 'A:7', 'C#:7'),
#   ('G:7', 'B:7', 'A:min/6'),
#   ('C:maj6', 'C:7', 'B:9'),
#   ('D:7', 'A/3', 'E:9'),
#   ('A:7/3', 'E:7', 'D:7(#9)'),
#   ('N', 'G/5', 'B:7'),
#   ('F:maj7', 'E:min/5', 'E:7(#9)'),
#   ('N', 'E/b7', 'E:maj6/b7'),
#   ('C:maj6', 'E:min/5', 'C:7'),
#   ('G#', 'G:7', 'E:min/b3'),
#   ('G', 'E:7', 'C#'),
#   ('D:7', 'B:7', 'G/b7'),
#   ('F:7', 'E/b7', 'C/3'),
#   ('C:maj6', 'A:7/3', 'G:maj6/5'),
#   ('C:maj9', 'C#', 'E:maj6/b7'),
#   ('E:7', 'C:7', 'A:9'),
#   ('A', 'E/5', 'E/3'),
#   ('A:min', 'D#:min', 'G:maj6/5'),
#   ('D', 'C:7', 'C#'),
#   ('C:maj9', 'F:min', 'D/2'),
#   ('A:min7', 'B', 'E:7(#9)'),
#   ('G:7', 'E:min7', 'F:maj9'),
#   ('G', 'D', 'F#:min7'),
#   ('F', 'C#', 'D/2'),
#   ('C:maj6', 'F#:sus4', 'E:min7'),
#   ('G', 'E', 'D/7'),
#   ('G', 'E:maj6/b7', 'B:9'),
#   ('D:min', 'D#:7', 'G#'),
#   ('F:min', 'D:sus4', 'C/3'),
#   ('D:7', 'G:7', 'E/5'),
#   ('C:maj6', 'G#', 'E/b7'),
#   ('A:min7', 'G#', 'E/b7'),
#   ('E:7', 'E/5', 'B:9'),
#   ('A:min', 'D:min', 'E:maj6/b7'),
#   ('G', 'D/5', 'A:(1)'),
#   ('F:min', 'F#:sus4', 'C#'),
#   ('C:maj6', 'F:7', 'B:min'),
#   ('F:maj7', 'A:min7', 'E:maj6/b7'),
#   ('D:7', 'D#:7', 'G/5'),
#   ('C', 'B', 'E/3'),
#   ('A:min7', 'A:7', 'C#:7'),
#   ('B:7', 'G/b7', 'D:9'),
#   ('G/b7', 'E:min7', 'F:maj9'),
#   ('D:min', 'C#:7', 'B:9'),
#   ('F:7', 'E:min/b3', 'E:7(#9)'),
#   ('D:min', 'F#:sus4', 'A:(1)'),
#   ('D', 'C/3', 'D/2'),
#   ('F#', 'D#:min', 'E:min/b3'),
#   ('E:min', 'A', 'B:min'),
#   ('A', 'D#:min', 'D:(1)'),
#   ('G#', 'G/b7', 'D:9'),
#   ('E:min/5', 'F#', 'E:min7'),
#   ('F:maj7', 'B:7', 'D:sus4'),
#   ('F:7', 'D#:7', 'A:9'),
#   ('E/4', 'E:min/b3', 'A:9'),
#   ('A:7', 'D#:min', 'E/3'),
#   ('D/7', 'G/b7', 'E:min7'),
#   ('F#:min7', 'D#:min', 'G/5'),
#   ('F:7', 'A:(1)', 'A:9'),
#   ('D:maj6', 'F:maj9', 'E:min/b3'),
#   ('E/b7', 'G:maj6/5', 'A:min/6'),
#   ('F#:min7', 'D/5', 'D:(1)'),
#   ('G/b7', 'D:sus4', 'C/3'),
#   ('F#:min7', 'B:7', 'E:9'),
#   ('A:min', 'D#:7', 'C/3'),
#   ('G/5', 'E/#4', 'A:9'),
#   ('E:7', 'F:min', 'B:9'),
#   ('C:maj6', 'D/5', 'D:9'),
#   ('G:maj6/5', 'B:7', 'E/3'),
#   ('G', 'A:min', 'F#'),
#   ('E:maj6/b7', 'E/4', 'E/3'),
#   ('F:maj7', 'G:7', 'D/5'),
#   ('D:7', 'D#:min', 'D#:7'),
#   ('D:min', 'A:7', 'E:min7'),
#   ('F#', 'E/3', 'E:9'),
#   ('E:min', 'F#:min7', 'E/3'),
#   ('D:min', 'A:min7', 'D/5'),
#   ('D:maj6', 'G#', 'B:min'),
#   ('G', 'C#', 'E:7(#9)'),
#   ('F', 'F#', 'D/2'),
#   ('C:maj9', 'F#:min7', 'G:maj6/5'),
#   ('F:min', 'G:7', 'D:9'),
#   ('E', 'E:min/5', 'D:sus4'),
#   ('N', 'C:7', 'G/b7'),
#   ('E:min', 'C#', 'D:(1)'),
#   ('D', 'G/b7', 'C/3'),
#   ('D:7', 'B:9', 'A:min/6'),
#   ('E:min/5', 'C/3', 'E:7(#9)'),
#   ('G#', 'C#:7', 'F:maj9'),
#   ('A:7/3', 'E:7', 'A:9'),
#   ('D:sus4', 'A:min/6', 'A:(1)'),
#   ('A', 'C:maj9', 'G#'),
#   ('B', 'E:7', 'D/5'),
#   ('N', 'C:maj6', 'E:min7'),
#   ('E/b7', 'A:(1)', 'E:7(#9)'),
#   ('F#', 'G:maj6/5', 'D:sus4'),
#   ('F#:sus4', 'B:min', 'D/2'),
#   ('C:maj9', 'F:7', 'A:min/6'),
#   ('E:min', 'F#', 'A:(1)'),
#   ('D:min', 'F:7', 'D/2'),
#   ('E:min/5', 'E:maj6/b7', 'E/5'),
#   ('C#', 'E:min7', 'E:9'),
#   ('F:maj7', 'F:min', 'E:min7'),
#   ('A', 'D/7', 'A:9'),
#   ('G', 'D:7(#9)', 'E:7(#9)'),
#   ('N', 'D/5', 'E:7(#9)'),
#   ('D:7', 'B', 'F:min'),
#   ('E:min', 'D:7(#9)', 'D:(1)'),
#   ('A:7/3', 'D/7', 'A/3'),
#   ('D#:min', 'D:sus4', 'D/2'),
#   ('G', 'A:7/3', 'B:7'),
#   ('E/b7', 'E:maj6/b7', 'D:9'),
#   ('F', 'G:7', 'E/3'),
#   ('F#:min7', 'B', 'A/3'),
#   ('F', 'B', 'E/b7'),
#   ('C:maj6', 'D#:7', 'A/3'),
#   ('N', 'F:min', 'F#'),
#   ('E/#4', 'E:min7', 'D:7(#9)'),
#   ('F:7', 'E:min/5', 'A:min/6'),
#   ('G', 'E', 'C:maj9'),
#   ('G', 'D:maj6', 'E:min/b3'),
#   ('F#:min7', 'F#', 'E:7(#9)'),
#   ('N', 'C', 'E:maj6/b7'),
#   ('C:maj9', 'D:7', 'F:min'),
#   ('C', 'E:min', 'E/4'),
#   ('G', 'E/b7', 'E:min/b3'),
#   ('D:7', 'D:maj6', 'E/4'),
#   ('F#:min7', 'A:7', 'A/3'),
#   ('E:min', 'E:min7', 'A:min/6'),
#   ('D', 'G:maj6/5', 'D/7'),
#   ('F:7', 'G:7', 'E/5'),
#   ('C:7', 'G:maj6/5', 'A:min/6'),
#   ('D:7', 'E/b7', 'E/4'),
#   ('F', 'D:min', 'E:min/5'),
#   ('G', 'F#', 'E:7(#9)'),
#   ('C:maj6', 'C:7', 'D:7(#9)'),
#   ('E:7', 'F#', 'G:7'),
#   ('N', 'F', 'B:9'),
#   ('E/b7', 'E/#4', 'A:9'),
#   ('B:9', 'D:7(#9)', 'A:9'),
#   ('E:7', 'F:7', 'E/4'),
#   ('E', 'B:min', 'D/7'),
#   ('C#', 'B:9', 'A:(1)'),
#   ('F#:sus4', 'G:7', 'E:7(#9)'),
#   ('G#', 'E:maj6/b7', 'E/3'),
#   ('C:maj6', 'C#', 'B:7'),
#   ('C:maj9', 'B:9', 'E/3'),
#   ('D:maj6', 'D#:7', 'E/3'),
#   ('A:7', 'G#', 'G/5'),
#   ('A:min7', 'D/5', 'E:7(#9)'),
#   ('B', 'G:maj6/5', 'E/5'),
#   ('F#:min7', 'E/b7', 'A:min/6'),
#   ('F:7', 'B:9', 'E:min7'),
#   ('N', 'G', 'E:maj6/b7'),
#   ('N', 'B:7', 'E:min7'),
#   ('C', 'D:7', 'C/3'),
#   ('N', 'F#', 'D/7'),
#   ('A:min', 'E:min/5', 'D/2'),
#   ('N', 'B', 'F#'),
#   ('C:maj6', 'A:7', 'D/2'),
#   ('D#:min', 'E/b7', 'E/#4'),
#   ('D#:min', 'C#', 'B:7'),
#   ('A:min7', 'F:min', 'F#'),
#   ('G', 'E:maj6/b7', 'D:7(#9)'),
#   ('N', 'E/4', 'A:(1)'),
#   ('D', 'E:7', 'G:maj6/5'),
#   ('D:maj6', 'B:9', 'D:9'),
#   ('E:7', 'E/5', 'D:7(#9)'),
#   ('F#:sus4', 'B:7', 'D/2'),
#   ('D:maj6', 'E:7', 'D#:7'),
#   ('D:maj6', 'G#', 'C/3'),
#   ('G', 'A:min', 'E:9'),
#   ('F', 'E:min/5', 'D/5'),
#   ('F#:min7', 'D:9', 'A:9'),
#   ('F:maj7', 'E:min/5', 'F#'),
#   ('G#', 'D/2', 'D:9'),
#   ('E/3', 'A:min/6', 'A:(1)'),
#   ('D#:7', 'G#', 'E/5'),
#   ('N', 'E:maj6/b7', 'A/3'),
#   ('E', 'F:7', 'G/5'),
#   ('F:7', 'F:min', 'B:7'),
#   ('E', 'D:maj6', 'E/5'),
#   ('E/5', 'D:sus4', 'A:min/6'),
#   ('F#:min7', 'E:7', 'E:min7'),
#   ('B:9', 'E/3', 'D:9'),
#   ('D:min', 'C/3', 'A:9'),
#   ('A', 'F#', 'E/4'),
#   ('E/#4', 'B:7', 'E:min7'),
#   ('C:7', 'C#:7', 'A:min/6'),
#   ('C/3', 'A:min/6', 'D:7(#9)'),
#   ('A', 'A:min/6', 'D:7(#9)'),
#   ('F:7', 'D:sus4', 'E:7(#9)'),
#   ('F:maj7', 'C:maj9', 'C#'),
#   ('F:maj7', 'F:7', 'G:7'),
#   ('G', 'E:7', 'E:min7'),
#   ('F:maj7', 'D:7', 'E/5'),
#   ('A:7', 'E:maj6/b7', 'E:9'),
#   ('D:7', 'F:7', 'E/#4'),
#   ('A:min', 'C#', 'G/5'),
#   ('G', 'C:7', 'D/7'),
#   ('C', 'E:maj6/b7', 'D:sus4'),
#   ('A:min7', 'E/4', 'A:(1)'),
#   ('A:min', 'E:min', 'D'),
#   ('E/#4', 'E/4', 'A:(1)'),
#   ('B', 'C#:7', 'E/5'),
#   ('D', 'C:7', 'E:min7'),
#   ('E/#4', 'E:min7', 'A:9'),
#   ('A:7/3', 'A/3', 'E:7(#9)'),
#   ('E', 'E/5', 'E:min/b3'),
#   ('D:min', 'E', 'A:min/6'),
#   ('E:min', 'F:maj7', 'A:min/6'),
#   ('E', 'D#:7', 'G:7'),
#   ('D:maj6', 'A:7/3', 'D/7'),
#   ('E', 'B:7', 'D/7'),
#   ('E:min/5', 'E/#4', 'E/3'),
#   ('G/5', 'E/5', 'A:(1)'),
#   ('A', 'D:9', 'A:(1)'),
#   ('A:min', 'G:maj6/5', 'A/3'),
#   ('E', 'F#:sus4', 'A:min/6'),
#   ('D/7', 'D:7(#9)', 'E:9'),
#   ('N', 'D#:7', 'E/5'),
#   ('A:min', 'C:maj9', 'G:7'),
#   ('N', 'D', 'E:min7'),
#   ('D#:7', 'D:sus4', 'E:9'),
#   ('D/5', 'D/2', 'E:min/b3'),
#   ('F:maj7', 'G:7', 'D:(1)'),
#   ('A:min7', 'E:maj6/b7', 'A/3'),
#   ('C:maj6', 'C:7', 'A:9'),
#   ('E:min/5', 'G:7', 'B:9'),
#   ('F#:sus4', 'D/7', 'F:maj9'),
#   ('E:min', 'E:min/5', 'E:maj6/b7'),
#   ('G', 'D#:7', 'G/5'),
#   ('N', 'F:min', 'E:9'),
#   ('F:maj7', 'E', 'D/5'),
#   ('C:maj9', 'F#:min7', 'F#:sus4'),
#   ('B', 'A:7', 'E:min/5'),
#   ('E:min', 'E', 'D#:7'),
#   ('D:min', 'A:min7', 'D:(1)'),
#   ('E', 'C:maj9', 'E/#4'),
#   ('D:min', 'C:7', 'G/5'),
#   ('D:7', 'C#', 'F:maj9'),
#   ('F#:min7', 'F:maj9', 'A:(1)'),
#   ('D#:min', 'E:maj6/b7', 'A/3'),
#   ('C:maj6', 'E/5', 'B:9'),
#   ('C:maj6', 'E/3', 'D:(1)'),
#   ('E', 'G#', 'G/b7'),
#   ('F:7', 'E/b7', 'E/4'),
#   ('E:7', 'C:7', 'C#'),
#   ('C:maj9', 'C#:7', 'B:9'),
#   ('F', 'E', 'A:7/3'),
#   ('N', 'A', 'A:min/6'),
#   ('B', 'E:7', 'D:(1)'),
#   ('C#:7', 'G:7', 'D/2'),
#   ('E/4', 'E/3', 'C/3'),
#   ('E:min/5', 'F#', 'D#:min'),
#   ('B', 'G#', 'G:7'),
#   ('E', 'D:sus4', 'D/2'),
#   ('E:7', 'C/3', 'E:min/b3'),
#   ('C:maj9', 'D#:7', 'E/3'),
#   ('F#', 'D:9', 'E:min/b3'),
#   ('G/5', 'G:maj6/5', 'A:(1)'),
#   ('A:7/3', 'G#', 'D/7'),
#   ('D:min', 'E/b7', 'E:7(#9)'),
#   ('N', 'E/5', 'F:maj9'),
#   ('D#:min', 'E/3', 'D:(1)'),
#   ('C', 'A:min', 'E:min'),
#   ('A:7', 'A/3', 'D:sus4'),
#   ('D:7', 'D#:7', 'B:min'),
#   ('D:maj6', 'B:min', 'E/#4'),
#   ('A:min7', 'D#:7', 'E/5'),
#   ('D:min', 'A', 'A:(1)'),
#   ('C', 'E/b7', 'E/5'),
#   ('A:min7', 'F:min', 'E:9'),
#   ('C', 'D/7', 'D/2'),
#   ('C:7', 'E:maj6/b7', 'E:7(#9)'),
#   ('E', 'F:min', 'D:9'),
#   ('G', 'G:maj6/5', 'B:7'),
#   ('D:min', 'E:min/5', 'E/b7'),
#   ('E:7', 'E:min7', 'A:(1)'),
#   ('C:maj6', 'G:maj6/5', 'B:9'),
#   ('C:maj6', 'G:7', 'C/3'),
#   ('D', 'F#:min7', 'D/2'),
#   ...},
#  '300': {('A', 'D', 'E'),
#   ('A', 'D', 'G'),
#   ('A', 'D', 'N'),
#   ('A', 'E', 'N'),
#   ('A', 'G', 'N'),
#   ('A:min', 'D', 'D:maj6'),
#   ('A:min', 'D', 'G'),
#   ('C', 'D', 'E'),
#   ('C', 'D', 'F'),
#   ('C', 'D', 'G'),
#   ('C', 'D', 'N'),
#   ('C', 'E', 'N'),
#   ('C', 'F', 'G'),
#   ('C', 'G', 'N'),
#   ('D', 'D:7', 'E'),
#   ('D', 'D:7', 'G'),
#   ('D', 'E', 'N'),
#   ('D', 'F', 'G'),
#   ('D', 'G', 'N')}}
