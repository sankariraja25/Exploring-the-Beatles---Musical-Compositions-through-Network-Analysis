# %%
#9, 10, 11
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
#motifs, chord pregressoionn and trials

# %%
pwd
# Out:
# '/content'

# %%
album01 = pd.read_csv('/content/album_10_edges.csv')
G = nx.from_pandas_edgelist(album01, source="Source", target="Target", create_using=nx.DiGraph())
nx.draw(G, with_labels=True)

# %% [markdown]
# ## Visuals

# %%
nx.draw(G,node_size=300,font_size=8,  with_labels=True)

# %%
plt.figure(3,figsize=(12,12)) 
nx.draw(G, node_size=400,font_size=12,  with_labels=True)

# %% [markdown]
# ## Triads

# %%
# Triad Consensus
nx.triadic_census(G)
# Out:
# {'003': 201919,
#  '012': 19159,
#  '021C': 533,
#  '021D': 193,
#  '021U': 214,
#  '030C': 13,
#  '030T': 15,
#  '102': 4744,
#  '111D': 434,
#  '111U': 383,
#  '120C': 40,
#  '120D': 9,
#  '120U': 7,
#  '201': 170,
#  '210': 58,
#  '300': 29}

# %%
import networkx as nx
import itertools


def _tricode(G, v, u, w):
    """Returns the integer code of the given triad.

    This is some fancy magic that comes from Batagelj and Mrvar's paper. It
    treats each edge joining a pair of `v`, `u`, and `w` as a bit in
    the binary representation of an integer.

    """
    combos = ((v, u, 1), (u, v, 2), (v, w, 4), (w, v, 8), (u, w, 16),
              (w, u, 32))
    return sum(x for u, v, x in combos if v in G[u])


# G = nx.DiGraph()
# G.add_nodes_from([1, 2, 3, 4, 5])
# G.add_edges_from([(1, 2), (2, 3), (2, 4), (4, 5)])

#: The integer codes representing each type of triad.
#: Triads that are the same up to symmetry have the same code.
TRICODES = (1, 2, 2, 3, 2, 4, 6, 8, 2, 6, 5, 7, 3, 8, 7, 11, 2, 6, 4, 8, 5, 9,
            9, 13, 6, 10, 9, 14, 7, 14, 12, 15, 2, 5, 6, 7, 6, 9, 10, 14, 4, 9,
            9, 12, 8, 13, 14, 15, 3, 7, 8, 11, 7, 12, 14, 15, 8, 14, 13, 15,
            11, 15, 15, 16)

#: The names of each type of triad. The order of the elements is
#: important: it corresponds to the tricodes given in :data:`TRICODES`.
TRIAD_NAMES = ('003', '012', '102', '021D', '021U', '021C', '111D', '111U',
               '030T', '030C', '201', '120D', '120U', '120C', '210', '300')

#: A dictionary mapping triad code to triad name.
TRICODE_TO_NAME = {i: TRIAD_NAMES[code - 1] for i, code in enumerate(TRICODES)}

triad_nodes = {name: set([]) for name in TRIAD_NAMES}
m = {v: i for i, v in enumerate(G)}
for v in G:
    vnbrs = set(G.pred[v]) | set(G.succ[v])
    for u in vnbrs:
        if m[u] > m[v]:
            unbrs = set(G.pred[u]) | set(G.succ[u])
            neighbors = (vnbrs | unbrs) - {u, v}
            not_neighbors = set(G.nodes()) - neighbors - {u, v}
            # Find dyadic triads
            for w in not_neighbors:
                if v in G[u] and u in G[v]:
                    triad_nodes['102'].add(tuple(sorted([u, v, w])))
                else:
                    triad_nodes['012'].add(tuple(sorted([u, v, w])))
            for w in neighbors:
                if m[u] < m[w] or (m[v] < m[w] < m[u] and
                                   v not in G.pred[w] and
                                   v not in G.succ[w]):
                    code = _tricode(G, v, u, w)
                    triad_nodes[TRICODE_TO_NAME[code]].add(
                        tuple(sorted([u, v, w])))
# find null triads
all_tuples = set()
for s in triad_nodes.values():
    all_tuples = all_tuples.union(s)
new = triad_nodes['003'] = set(itertools.combinations(G.nodes(), 3)).difference(all_tuples)

triad_nodes
# Out:
# {'003': {('Bb:dim7/7', 'Eb', 'F/6'),
#   ('E:min', 'A:7', 'F#:min6'),
#   ('F:7', 'G:min', 'G:dim'),
#   ('E/3', 'C/7', 'C/5'),
#   ('G:minmaj7/b3', 'D:dim7', 'A:min9'),
#   ('Bb:maj7', 'Ab', 'F#:min6'),
#   ('F:7', 'A:dim7', 'A:min/5'),
#   ('E:7', 'G:maj7/3', 'A:min6'),
#   ('A', 'A:7', 'C:min'),
#   ('C/9', 'C:(1)', 'G:dim/b3'),
#   ('D/5', 'E:min(9)', 'Ab:min'),
#   ('D/b7', 'C:(1)', 'Db'),
#   ('N', 'D:7', 'Eb'),
#   ('G#', 'E:min(2)', 'F#:min'),
#   ('D:sus4(9)', 'E/4', 'Bb:maj7'),
#   ('A:dim/b5', 'G:min/b7', 'Ab:maj9'),
#   ('G#', 'G:9', 'A:min9'),
#   ('F#:dim/b3', 'G:7', 'G:min/5'),
#   ('Bb:sus2(b7)', 'E/2', 'G/3'),
#   ('B', 'A:dim/b5', 'Ab'),
#   ('A:dim7', 'D#:dim', 'D:maj7'),
#   ('N', 'B:min', 'C:7/3'),
#   ('F:7(b9)', 'E/3', 'Bb:7'),
#   ('G:7', 'A:min/6', 'B:min7'),
#   ('A:min/6', 'F:maj6', 'G:dim/b3'),
#   ('A:min/5', 'E/2', 'D#:dim'),
#   ('F/3', 'Eb:7', 'A:min/b7'),
#   ('B', 'A:min/6', 'C#:min'),
#   ('E:min(9)', 'G:min/b7', 'D:maj7'),
#   ('F/b7', 'A:min/6', 'G/3'),
#   ('E/5', 'Ab:min', 'A:min9'),
#   ('B', 'E/5', 'D#:dim'),
#   ('G/5', 'D#:dim', 'C:sus4'),
#   ('G', 'D:min', 'Bb:min'),
#   ('A:dim/b5', 'E/b6', 'F#:min6'),
#   ('E', 'A:dim7', 'C#:min'),
#   ('D#', 'G:7', 'C/5'),
#   ('G:minmaj7/5', 'E/4', 'Ab:maj7'),
#   ('F:7', 'F/5', 'C:7'),
#   ('G#', 'F:7(b9)', 'A:min/5'),
#   ('F:7(b9)', 'A:min/6', 'C#:dim'),
#   ('D:7', 'C:(1)', 'C:min'),
#   ('F', 'C:dim7', 'Db'),
#   ('A:min7', 'D:min', 'Bb:min'),
#   ('F:7(b9)', 'D:(1)', 'G:7'),
#   ('C:dim7/2', 'C:7', 'F:dim'),
#   ('Eb', 'Db', 'C/5'),
#   ('C/9', 'E:min', 'Db'),
#   ('G:minmaj7/5', 'F', 'F:maj6'),
#   ('C', 'C:dim7/2', 'Eb:aug'),
#   ('D:dim7', 'Bb:7', 'E:aug'),
#   ('F', 'C:maj(4)', 'F#:min6'),
#   ('E:7', 'C', 'C:(1)'),
#   ('Eb:7', 'A:min6', 'G:dim'),
#   ('Bb', 'F:maj6', 'F#:min7'),
#   ('A:min7', 'E/b7', 'Ab:maj9'),
#   ('G:min', 'F/b7', 'F:maj6'),
#   ('C:dim7/2', 'E/b6', 'A:min/b7'),
#   ('Bb:dim7/5', 'D:min7', 'C/5'),
#   ('A/3', 'A:min/b7', 'C#:dim'),
#   ('A:min/b7', 'Bb:7', 'F:dim'),
#   ('G:min', 'E:min', 'C:7/3'),
#   ('G:minmaj7/b3', 'E/3', 'C#:dim'),
#   ('F/3', 'A:min6', 'G:min/5'),
#   ('B', 'F#:min7', 'F#:min6'),
#   ('F', 'E/b7', 'C/7'),
#   ('F#:min', 'A:7', 'C/3'),
#   ('C:dim7', 'Eb:aug', 'D/3'),
#   ('C', 'E/b7', 'A:min/6'),
#   ('G/5', 'D:dim7', 'E:min'),
#   ('D/5', 'Bb:sus4(9)', 'D:maj7'),
#   ('Bb:dim7/5', 'D:(1)', 'C:(1)'),
#   ('D', 'G:minmaj7/b3', 'C/7'),
#   ('F:7', 'Bb:dim7/7', 'F:dim'),
#   ('F#:dim/b3', 'Bb:7', 'Ab:maj7'),
#   ('F/5', 'A:min6', 'G:9'),
#   ('C/9', 'G#', 'G:9'),
#   ('Bb:min', 'Bb:min/b3', 'F#:min7'),
#   ('F:min', 'G:dim/b3', 'D:maj7'),
#   ('E', 'D#', 'Bb:dim7/7'),
#   ('A/b3', 'E:min', 'B:min7'),
#   ('G:minmaj7/5', 'F', 'Bb:dim7/5'),
#   ('Bb:dim7/5', 'E/2', 'C:min'),
#   ('A/b3', 'D:7', 'E/b6'),
#   ('E', 'F/6', 'E:min'),
#   ('G:7', 'F:min', 'C:7/3'),
#   ('D', 'E/5', 'G:min/4'),
#   ('C', 'G:maj7/3', 'A:min9'),
#   ('E', 'E:min', 'Bb:7'),
#   ('C', 'A:min/5', 'F#:min7'),
#   ('C', 'A/2', 'E/5'),
#   ('A/2', 'E/5', 'F#:min'),
#   ('A/b3', 'F#:dim/b3', 'G:min/4'),
#   ('F:7(b9)', 'Bb:min', 'C:maj(4)'),
#   ('C/9', 'E/3', 'Bb:min'),
#   ('A/4', 'G#', 'Eb:aug'),
#   ('Bb:dim7/5', 'Bb', 'Db'),
#   ('F/3', 'A:min7', 'F#:min6'),
#   ('G#', 'A:7', 'C:maj(4)'),
#   ('D:(1)', 'Bb:7', 'D/3'),
#   ('A:min6', 'C#:dim', 'Bb:min'),
#   ('F:7', 'C:dim7', 'G/3'),
#   ('A/4', 'F:min', 'F#:min7'),
#   ('A/4', 'D:7', 'C:min'),
#   ('C/9', 'D:(1)', 'Bb:min/b3'),
#   ('F', 'F/5', 'Eb:aug'),
#   ('C:dim7', 'Ab:maj9', 'B:min7'),
#   ('E/3', 'C:min', 'A:min9'),
#   ('A:min6', 'G:min/4', 'D:maj7'),
#   ('Bb:sus2(b7)', 'F/5', 'E/5'),
#   ('G/5', 'C:dim7/2', 'E:min(2)'),
#   ('A', 'D', 'C:maj(4)'),
#   ('D/b7', 'E/b7', 'F#:min'),
#   ('A/b3', 'Eb:7', 'E:(1)'),
#   ('D/b7', 'A:min7', 'C/5'),
#   ('G/5', 'E/b7', 'G:min/5'),
#   ('G:maj7/3', 'F', 'D:sus4'),
#   ('G:maj7/3', 'Bb:sus4(9)', 'A:min9'),
#   ('E/3', 'Bb:7', 'C:maj(4)'),
#   ('G:min', 'Ab:maj7', 'F#:dim'),
#   ('A/b3', 'G:min/4', 'C/7'),
#   ('C/9', 'D:7', 'Bb/5'),
#   ('G:minmaj7/5', 'D:min', 'G:dim'),
#   ('A/b3', 'A:min/6', 'A:min9'),
#   ('N', 'E:min(9)', 'G:min/b7'),
#   ('F:7', 'Bb:dim7/5', 'E:min(9)'),
#   ('D:(1)', 'Ab:maj9', 'G:dim'),
#   ('G/5', 'C:7', 'C:min'),
#   ('G/5', 'F:7', 'A:min7'),
#   ('F/3', 'Ab:min', 'F#:min6'),
#   ('A:min/5', 'C#:min', 'A:7'),
#   ('D:sus4(9)', 'E:min(2)', 'F#:min'),
#   ('A:min/6', 'E:(1)', 'D#:dim'),
#   ('D:7', 'A:min/5', 'Bb/5'),
#   ('E:7', 'Ab:min', 'A:min9'),
#   ('F:7', 'A:min/6', 'Bb:7'),
#   ('B:dim7/b9', 'Bb:7', 'C/7'),
#   ('A', 'G:minmaj7/b3', 'Bb:min/b3'),
#   ('G/5', 'F/b7', 'C:sus4'),
#   ('F/3', 'F/5', 'D:min'),
#   ('F#:min', 'B:min', 'G:min/4'),
#   ('N', 'G:minmaj7/5', 'Ab:maj7'),
#   ('G/5', 'Ab:min', 'C/5'),
#   ('Bb:sus4(9)', 'G:7', 'Db'),
#   ('D:min', 'Bb:7', 'Eb:aug'),
#   ('C', 'G:minmaj7/5', 'A:min9'),
#   ('G/5', 'G:min7', 'Ab:maj9'),
#   ('A/4', 'C:dim7/2', 'Bb:maj7'),
#   ('C:dim7/2', 'G:dim/b3', 'C:sus4'),
#   ('C/3', 'D:min7', 'C:sus4'),
#   ('F#:dim/b3', 'D#:dim', 'C/5'),
#   ('C:dim7/2', 'F/6', 'G:9'),
#   ('D', 'D#', 'C:dim7'),
#   ('F/b7', 'A:min/b7', 'Ab:maj7'),
#   ('F', 'G:min7', 'A:dim/b5'),
#   ('D:dim7', 'D:(1)', 'Bb'),
#   ('F/5', 'F:dim', 'F#:dim'),
#   ('A/3', 'D/b7', 'D#:dim'),
#   ('C', 'F', 'D:sus4'),
#   ('F:7', 'Bb:dim7/7', 'E:(1)'),
#   ('D:dim7', 'A:min/5', 'G:min/5'),
#   ('D/5', 'A:min/5', 'C/3'),
#   ('D/b7', 'Bb:dim7/5', 'Db'),
#   ('B', 'E:(1)', 'Ab:min'),
#   ('A:min', 'Ab:maj9', 'Bb:min'),
#   ('G:minmaj7/5', 'G', 'D:(1)'),
#   ('E:aug', 'C:maj(4)', 'A:min9'),
#   ('E', 'C', 'Eb:aug'),
#   ('E:7', 'A:min/6', 'C:maj(4)'),
#   ('D', 'Eb', 'C:7/3'),
#   ('A:dim/b5', 'Eb:7', 'C#:dim'),
#   ('F:min', 'A:min/6', 'Ab'),
#   ('D/b7', 'D:sus4', 'Bb:min/b3'),
#   ('A/b3', 'A/3', 'Bb:min/b3'),
#   ('F#:dim/b3', 'B:dim7/b9', 'Bb:sus2(b7)'),
#   ('E/b7', 'F#:min', 'Ab:maj9'),
#   ('D#', 'C#:min', 'C:min'),
#   ('A/3', 'Ab:maj7', 'C:sus4'),
#   ('B:dim7/b9', 'C#:dim', 'C:min'),
#   ('B', 'F/3', 'B:dim7/b9'),
#   ('Bb:sus2(b7)', 'D:min', 'E/b7'),
#   ('Bb/5', 'A:7', 'E:aug'),
#   ('G:min/4', 'G:9', 'D#:dim'),
#   ('D:sus4(9)', 'F/5', 'D:min7'),
#   ('G', 'E:(1)', 'F:maj6'),
#   ('F/b7', 'G:7', 'Bb:min'),
#   ('D:dim7', 'G/3', 'F#:min7'),
#   ('E/b7', 'E:(1)', 'C:maj(4)'),
#   ('E/b6', 'C/3', 'Bb:maj7'),
#   ('E:min(9)', 'Bb:maj7', 'G:dim/b3'),
#   ('F:min', 'F:dim', 'Db'),
#   ('C:min', 'D:sus4(b7)', 'D/3'),
#   ('G:min', 'G:7', 'G:min/5'),
#   ('A/3', 'A:min', 'A:dim7'),
#   ('F', 'Bb:min', 'A:min9'),
#   ('Eb', 'C:7', 'Bb:min/b3'),
#   ('E:(1)', 'E:min', 'E:aug'),
#   ('D', 'A:min', 'E:aug'),
#   ('D:dim7', 'A:min/b7', 'E:min(9)'),
#   ('E', 'A/b3', 'F:7(b9)'),
#   ('G:7', 'G:min/5', 'Bb:maj7'),
#   ('A:min/6', 'G:min/5', 'Eb:aug'),
#   ('C:dim7', 'E:(1)', 'E:min'),
#   ('Bb:dim7/7', 'Ab:maj9', 'D:sus4(b7)'),
#   ('E:7', 'F/3', 'Eb'),
#   ('C/9', 'Ab:maj7', 'F:maj6'),
#   ('F', 'B:min', 'Bb:maj7'),
#   ('A:min7', 'C:dim7', 'C:min'),
#   ('F:min', 'G:min/5', 'G:min/4'),
#   ('C:dim7', 'F#:dim', 'B:min7'),
#   ('C/9', 'E:min(9)', 'C/5'),
#   ('E:7', 'F/5', 'C#:dim'),
#   ('G', 'E:aug', 'Bb:min/b3'),
#   ('B', 'E/2', 'A:7'),
#   ('E/5', 'E:(1)', 'E:aug'),
#   ('A/2', 'D/5', 'C/3'),
#   ('A:min7', 'F/5', 'E:min(2)'),
#   ('B', 'E:min(2)', 'F#:min6'),
#   ('F#:dim/b3', 'Eb', 'Bb:min'),
#   ('A', 'B:min', 'C/3'),
#   ('Ab:maj7', 'C:sus4', 'D:maj7'),
#   ('C', 'A:min/5', 'G:dim/b3'),
#   ('E', 'A:min9', 'D:maj7'),
#   ('C#:min', 'Ab:min', 'C:sus4'),
#   ('F:min', 'G:dim/b3', 'D/3'),
#   ('C', 'F#:dim', 'F#:min7'),
#   ('D:sus4(9)', 'D:sus4(b7)', 'G:dim'),
#   ('F/3', 'A:dim7', 'A:min/b7'),
#   ('G:maj7/3', 'Ab:maj9', 'F#:dim'),
#   ('G:dim', 'Bb:min', 'C/7'),
#   ('Bb:sus4(9)', 'E:aug', 'F#:dim'),
#   ('A:min/b7', 'Bb:7', 'Ab:min'),
#   ('F', 'G:min', 'Bb:min/b3'),
#   ('F:maj6', 'C#:dim', 'C:min'),
#   ('A', 'Ab', 'C/5'),
#   ('C/9', 'C:dim7/2', 'D:min'),
#   ('B:min', 'C:sus4', 'C:maj(4)'),
#   ('G#', 'A:min/5', 'D:maj7'),
#   ('G', 'F#:dim/b3', 'A:min6'),
#   ('D:sus4(9)', 'B:min', 'Ab'),
#   ('A:dim/b5', 'Bb:sus4(9)', 'G:min/b7'),
#   ('G:minmaj7/5', 'F:dim', 'Bb:min/b3'),
#   ('A/4', 'Bb/5', 'C#:dim'),
#   ('A:min', 'A:dim7', 'F:maj6'),
#   ('G#', 'G:min7', 'A:7'),
#   ('D', 'F:7(b9)', 'G:min'),
#   ('G:min7', 'F#:dim/b3', 'D#:dim'),
#   ('A/b3', 'G:minmaj7/b3', 'Bb:min/b3'),
#   ('E:(1)', 'C:maj(4)', 'D/3'),
#   ('A', 'G#', 'A:min/b7'),
#   ('E:7', 'E:min(2)', 'C#:min'),
#   ('F/b7', 'C:(1)', 'C:min'),
#   ('Bb:sus4(9)', 'F/b7', 'E/2'),
#   ('A/3', 'A:dim/b5', 'Bb:7'),
#   ('F/3', 'G:dim', 'D:sus4'),
#   ('A/4', 'D:sus4(9)', 'G:dim/b3'),
#   ('Bb', 'B:min', 'C/5'),
#   ('G#', 'F/3', 'A:min6'),
#   ('G:min7', 'C:dim7/2', 'D:(1)'),
#   ('A/2', 'C:min', 'Bb:min/b3'),
#   ('B', 'Bb:dim7/5', 'Bb:sus4(9)'),
#   ('D:dim7', 'Ab', 'Ab:min'),
#   ('F:7', 'D:(1)', 'A:min9'),
#   ('F:7(b9)', 'G:min/b7', 'Eb:aug'),
#   ('C', 'E:min(9)', 'Ab:maj9'),
#   ('D:dim7', 'G:min/b7', 'C:7/3'),
#   ('E:7', 'G:min/4', 'D:sus4(b7)'),
#   ('D/5', 'D/b7', 'B:dim7/b9'),
#   ('D:7', 'Bb:sus2(b7)', 'A:min6'),
#   ('F/3', 'B:dim7/b9', 'C:7/3'),
#   ('G', 'C:sus4', 'D/3'),
#   ('Bb:sus2(b7)', 'C:min', 'A:min9'),
#   ('A/b3', 'A:min/b7', 'Bb:min'),
#   ('D:(1)', 'G:dim', 'F#:min7'),
#   ('E/2', 'E:aug', 'Bb:min'),
#   ('A:min/5', 'D:(1)', 'E:min'),
#   ('C', 'A/b3', 'E:aug'),
#   ('F#:dim/b3', 'A:dim7', 'F:maj6'),
#   ('A:min', 'Bb:sus4(9)', 'C#:min'),
#   ('F:7(b9)', 'E/5', 'G:9'),
#   ('E/5', 'A:min/6', 'Bb:7'),
#   ('D/5', 'F#:dim/b3', 'D:min'),
#   ('A:dim/b5', 'G:min/4', 'G/3'),
#   ('Bb', 'E/b7', 'G:dim'),
#   ('E/b7', 'C:min', 'D:sus4'),
#   ('D/5', 'G:min', 'Ab:maj7'),
#   ('A/4', 'Bb:sus2(b7)', 'B:min7'),
#   ('E:min(9)', 'C:7', 'A:min9'),
#   ('G:7', 'A:7', 'D:min7'),
#   ('A/b3', 'B', 'G'),
#   ('C', 'Eb:7', 'A:7'),
#   ('G:min7', 'F/6', 'A:min6'),
#   ('D', 'A:dim/b5', 'Eb'),
#   ('Bb:sus2(b7)', 'C:7', 'G:min/4'),
#   ('A/2', 'A:dim7', 'G:min/5'),
#   ('G:minmaj7/b3', 'G:min/b7', 'Bb:min'),
#   ('D#', 'D:sus4(9)', 'F#:min7'),
#   ('F/3', 'E/2', 'Bb:min'),
#   ('G:7', 'E/4', 'C#:dim'),
#   ('A/b3', 'F/3', 'Eb'),
#   ('F:7', 'F:min', 'F#:min7'),
#   ('F:7(b9)', 'A:min/6', 'D:min7'),
#   ('N', 'Bb:maj7', 'C#:dim'),
#   ('G', 'Bb', 'Bb:sus2(b7)'),
#   ('A/3', 'G:min/5', 'E:aug'),
#   ('F', 'Bb:sus4(9)', 'C/3'),
#   ('Bb:sus4(9)', 'F/5', 'F#:min7'),
#   ('Bb:7', 'G:9', 'Bb:min'),
#   ('A/3', 'G:maj7/3', 'E:aug'),
#   ('G:min/b7', 'Bb:min/b3', 'D/3'),
#   ('A/3', 'F:7(b9)', 'D:sus4'),
#   ('D/b7', 'G:maj7/3', 'C:min'),
#   ('G:minmaj7/5', 'F#:dim/b3', 'F:7(b9)'),
#   ('Bb:sus4(9)', 'D:min', 'B:min7'),
#   ('F#:min', 'F#:dim', 'D:maj7'),
#   ('F/6', 'E/5', 'F#:dim'),
#   ('C', 'F', 'C:(1)'),
#   ('A:min/b7', 'A:min6', 'C:maj(4)'),
#   ('D', 'A/4', 'G:maj7/3'),
#   ('F:7(b9)', 'A:dim7', 'Eb:aug'),
#   ('D#', 'Bb:sus4(9)', 'Bb:min'),
#   ('G:min7', 'Bb:dim7/7', 'E:min(9)'),
#   ('F#:dim/b3', 'E:min(9)', 'F#:min7'),
#   ('A:min/5', 'Bb:7', 'G:9'),
#   ('Eb:7', 'A:min6', 'Ab:maj9'),
#   ('A:dim7', 'Bb:sus2(b7)', 'E/b6'),
#   ('A:dim/b5', 'G:min', 'A:min6'),
#   ('Eb', 'E/3', 'Bb:7'),
#   ('Bb:sus4(9)', 'F/5', 'G:7'),
#   ('D:7', 'E/b6', 'C#:dim'),
#   ('C', 'G:min', 'D#:dim'),
#   ('N', 'C#:min', 'F#:min'),
#   ('Bb:sus2(b7)', 'E/5', 'G:min/5'),
#   ('B', 'C/3', 'G:min/4'),
#   ('A/4', 'A:dim/b5', 'E/2'),
#   ('B:dim7/b9', 'C:7', 'Ab'),
#   ('A/b3', 'G:minmaj7/b3', 'Bb:sus2(b7)'),
#   ('D:7', 'Bb', 'Eb:aug'),
#   ('D', 'G/5', 'A:min'),
#   ('E:aug', 'F#:dim', 'Db'),
#   ('E:7', 'A:min6', 'C:7'),
#   ('F#:dim/b3', 'C:dim7', 'E:min(9)'),
#   ('A:dim/b5', 'F/6', 'E:min(2)'),
#   ('C:dim7', 'E/3', 'E:(1)'),
#   ('A:min/6', 'G:dim', 'C:maj(4)'),
#   ('G:minmaj7/b3', 'A:min7', 'F/b7'),
#   ('Eb', 'E/5', 'C:maj(4)'),
#   ('D:sus4(9)', 'G:min', 'D:sus4(b7)'),
#   ('F/3', 'F#:min', 'D#:dim'),
#   ('F/5', 'E:(1)', 'C:maj(4)'),
#   ('A:min', 'A:min/6', 'D#:dim'),
#   ('A/b3', 'C:min', 'Ab'),
#   ('G:minmaj7/5', 'F', 'Bb:7'),
#   ('A:min/5', 'Db', 'Ab:min'),
#   ('E:(1)', 'C#:dim', 'A:min9'),
#   ('N', 'F:7(b9)', 'C:7/3'),
#   ('F/3', 'C:dim7', 'F#:dim'),
#   ('A:dim7', 'F/5', 'Ab:min'),
#   ('Bb:7', 'D:min7', 'B:min7'),
#   ('B', 'G:7', 'C:7/3'),
#   ('F', 'B:dim7/b9', 'Bb:min'),
#   ('F:7(b9)', 'F/b7', 'E:min(2)'),
#   ('E/3', 'G:min/4', 'E:aug'),
#   ('A/4', 'C:(1)', 'F:maj6'),
#   ('D', 'A/b3', 'A:min'),
#   ('C:7/3', 'Ab:maj9', 'G:dim'),
#   ('E/2', 'Eb:aug', 'Ab'),
#   ('G/5', 'E:min(9)', 'F:maj6'),
#   ('A/3', 'C:7/3', 'G:min/4'),
#   ('Bb:dim7/7', 'D:dim7', 'Ab:min'),
#   ('A/4', 'D:(1)', 'E:(1)'),
#   ('B:dim7/b9', 'Eb', 'E:(1)'),
#   ('G:minmaj7/5', 'Bb', 'G:min/b7'),
#   ('A/3', 'Bb:maj7', 'Ab'),
#   ('C:dim7/2', 'Eb:7', 'G:min/4'),
#   ('C#:min', 'D:min7', 'G:dim/b3'),
#   ('C:dim7', 'G:min/b7', 'C/3'),
#   ('A/b3', 'E/b6', 'Bb:7'),
#   ('F:maj6', 'F#:min7', 'D/3'),
#   ('F/5', 'G:min/4', 'G/3'),
#   ('A/b3', 'E/5', 'Bb:7'),
#   ('E', 'D#', 'Ab:maj7'),
#   ('E', 'D:7', 'A:dim7'),
#   ('D:sus4(9)', 'A:min7', 'G:dim'),
#   ('D', 'C:dim7/2', 'G:dim'),
#   ('G:min', 'C#:min', 'D#:dim'),
#   ('A/4', 'G:minmaj7/b3', 'F:7'),
#   ('A:min6', 'D:sus4', 'D/3'),
#   ('D:dim7', 'Bb:sus4(9)', 'G:min/b7'),
#   ('A:dim/b5', 'E/3', 'E:aug'),
#   ('A:min/6', 'Bb:maj7', 'C:maj(4)'),
#   ('C/9', 'B:dim7/b9', 'E/4'),
#   ('F#:dim/b3', 'C:dim7/2', 'C:maj(4)'),
#   ('G', 'D:dim7', 'E:aug'),
#   ('C:dim7/2', 'A:dim7', 'E/b7'),
#   ('G', 'C:dim7/2', 'F:maj6'),
#   ('C:7', 'G:min/5', 'C/5'),
#   ('B', 'C:dim7', 'E:min(2)'),
#   ('F#:dim/b3', 'Bb:sus2(b7)', 'C:7'),
#   ('F#:dim/b3', 'C:dim7/2', 'Bb:min/b3'),
#   ('E:min(9)', 'Eb:aug', 'F:dim'),
#   ('D', 'Bb:maj7', 'G:dim'),
#   ('A:min/5', 'C#:dim', 'C/5'),
#   ('G/5', 'F:7(b9)', 'C:sus4'),
#   ('Eb', 'Eb:7', 'E:(1)'),
#   ('G/5', 'A:7', 'F:dim'),
#   ('F', 'E:(1)', 'Bb:7'),
#   ('A/4', 'F/3', 'Ab:min'),
#   ('G:7', 'Ab:maj9', 'F:maj6'),
#   ('G:min', 'C#:min', 'D:sus4'),
#   ('G:maj7/3', 'A:min/b7', 'D:maj7'),
#   ('B:dim7/b9', 'C#:min', 'E:min'),
#   ('D/b7', 'F#:dim/b3', 'Bb:dim7/7'),
#   ('F', 'Bb:dim7/5', 'A:min/b7'),
#   ('C/9', 'D:min7', 'Bb:maj7'),
#   ('A:min6', 'C:7/3', 'F#:min6'),
#   ('E/b6', 'A:min6', 'Ab:maj9'),
#   ('E', 'G:min7', 'E/3'),
#   ('C', 'A/4', 'C:maj(4)'),
#   ('C', 'F/3', 'D:dim7'),
#   ('D#', 'C/3', 'C/5'),
#   ('D', 'F#:min', 'E/4'),
#   ('G:maj7/3', 'G:minmaj7/5', 'C:7'),
#   ('A:min', 'F:7(b9)', 'B:dim7/b9'),
#   ('D#', 'Bb/5', 'Ab'),
#   ('D:7', 'E/3', 'Bb:min'),
#   ('A', 'G:min/5', 'G:min/b7'),
#   ('Bb:sus2(b7)', 'C:7', 'Bb:maj7'),
#   ('A', 'F:7(b9)', 'C/5'),
#   ('F/5', 'G:min/4', 'Ab'),
#   ('G', 'A:min/5', 'D:min'),
#   ('A:dim7', 'E/3', 'D:sus4(b7)'),
#   ('A/b3', 'A:min7', 'Ab:maj9'),
#   ('A:min/6', 'C:7/3', 'F:maj6'),
#   ('A:min7', 'F/6', 'Bb:min'),
#   ('E/b7', 'E:min', 'F#:min6'),
#   ('E:7', 'Eb', 'F:maj6'),
#   ('A:dim/b5', 'E/b6', 'Ab:min'),
#   ('D:sus4(9)', 'C:dim7', 'E:(1)'),
#   ('Ab:maj7', 'Db', 'F#:min6'),
#   ('A:dim/b5', 'Bb:sus4(9)', 'C/3'),
#   ('D/b7', 'Eb:7', 'F#:min6'),
#   ('E:min', 'G:min/5', 'B:min7'),
#   ('D:min', 'C#:dim', 'F:dim'),
#   ('D/b7', 'C:7', 'Bb:min'),
#   ('C/9', 'Eb', 'Ab:min'),
#   ('D:7', 'A:dim/b5', 'E/3'),
#   ('E:7', 'Bb:min', 'C/5'),
#   ('B', 'G#', 'G:min/4'),
#   ('F', 'Ab', 'D/3'),
#   ('F:min', 'C:7/3', 'Eb:aug'),
#   ('A/2', 'G#', 'C:sus4'),
#   ('C:dim7/2', 'C#:min', 'F#:min'),
#   ('N', 'A:dim7', 'A:min/b7'),
#   ('C/9', 'E/5', 'C:7'),
#   ('C/9', 'C/3', 'Ab:maj7'),
#   ('C/9', 'F/b7', 'E/4'),
#   ('Eb', 'Ab:maj9', 'G:9'),
#   ('Eb', 'Bb/5', 'F#:min7'),
#   ('A:min', 'A:dim/b5', 'F:maj6'),
#   ('F', 'D:sus4', 'C/7'),
#   ('A/3', 'F', 'A:min9'),
#   ('A/2', 'A:min6', 'F:maj6'),
#   ('E:7', 'D:sus4(9)', 'E/2'),
#   ('G:minmaj7/5', 'A:7', 'G:dim/b3'),
#   ('E:7', 'F:7(b9)', 'Bb:dim7/7'),
#   ('E:(1)', 'C:min', 'C/5'),
#   ('D', 'Eb:7', 'F:dim'),
#   ('A', 'A/b3', 'A:7'),
#   ('B', 'F', 'F:min'),
#   ('D/b7', 'F/3', 'C/7'),
#   ('C:dim7', 'Bb:sus4(9)', 'B:min'),
#   ('D', 'Bb:sus2(b7)', 'E:min(2)'),
#   ('A:min', 'D:dim7', 'C/5'),
#   ('A:7', 'C/3', 'D:sus4'),
#   ('N', 'Ab:maj9', 'C/7'),
#   ('G/5', 'Bb:sus4(9)', 'E/b6'),
#   ('G:min/5', 'D#:dim', 'Bb:min/b3'),
#   ('G/5', 'Bb/5', 'Db'),
#   ('G:minmaj7/b3', 'B:min', 'D:sus4'),
#   ('G:7', 'E:min(9)', 'C:sus4'),
#   ('A/3', 'A:min/6', 'G:9'),
#   ('C/9', 'F:7', 'C:maj(4)'),
#   ('D/5', 'G:minmaj7/5', 'C/7'),
#   ('A:min', 'Bb', 'A:min6'),
#   ('E:(1)', 'A:7', 'F#:min7'),
#   ('A/2', 'E:(1)', 'F#:min6'),
#   ('B', 'Bb:7', 'Bb:min/b3'),
#   ('G:minmaj7/b3', 'C:min', 'D:sus4(b7)'),
#   ('N', 'E:(1)', 'C#:dim'),
#   ('F/3', 'A:dim/b5', 'Bb:7'),
#   ('F/b7', 'G:min/4', 'C:min'),
#   ('G:maj7/3', 'A:dim7', 'G:dim/b3'),
#   ('D/b7', 'F:7', 'D/3'),
#   ('G:minmaj7/5', 'F/b7', 'F:min'),
#   ('Bb:sus2(b7)', 'G:min/5', 'B:min7'),
#   ('A:min7', 'E:aug', 'C/5'),
#   ('A/b3', 'Bb:sus2(b7)', 'A:min/6'),
#   ('Bb:dim7/7', 'A:min/6', 'C:maj(4)'),
#   ('A/2', 'Bb:sus4(9)', 'Bb/5'),
#   ('A', 'C:(1)', 'Bb:min/b3'),
#   ('F#:dim/b3', 'E:min', 'F#:dim'),
#   ('D/5', 'G:minmaj7/5', 'E/4'),
#   ('C:dim7', 'C:(1)', 'C/3'),
#   ('C/9', 'C:7', 'Ab:maj7'),
#   ('F:7', 'Bb:dim7/5', 'C:dim7'),
#   ('A/b3', 'A:min/5', 'A:min/b7'),
#   ('A/4', 'A:min', 'Bb:7'),
#   ('G:minmaj7/b3', 'B:min', 'C:(1)'),
#   ('Bb:sus2(b7)', 'Bb/5', 'G:min/4'),
#   ('B', 'E:(1)', 'D:sus4(b7)'),
#   ('Bb:sus2(b7)', 'A:min/b7', 'D:maj7'),
#   ('D#', 'F#:dim/b3', 'D#:dim'),
#   ('Eb', 'G:dim/b3', 'C:maj(4)'),
#   ('G', 'E/5', 'A:min/b7'),
#   ('G:maj7/3', 'D:dim7', 'Ab:maj9'),
#   ('G:maj7/3', 'A:min', 'Ab:maj9'),
#   ('C/3', 'F:maj6', 'D:maj7'),
#   ('D:min', 'A:min/b7', 'F:maj6'),
#   ('A:min', 'D:sus4', 'F#:min6'),
#   ('A:min', 'A:min6', 'Ab:maj7'),
#   ('F/5', 'E/b7', 'Bb:maj7'),
#   ('E:(1)', 'Bb:maj7', 'G/3'),
#   ('G#', 'F/b7', 'F:min'),
#   ('Bb/5', 'A:min/6', 'E:min'),
#   ('A/4', 'Bb/5', 'D/3'),
#   ('E:min(9)', 'C#:dim', 'C/5'),
#   ('D#', 'A:7', 'G:9'),
#   ('E/b6', 'G:min/b7', 'Eb:aug'),
#   ('F:min', 'G/3', 'F:dim'),
#   ('A/4', 'F/5', 'G:7'),
#   ('G:min', 'E/2', 'C:7'),
#   ('D#', 'C#:dim', 'Bb:min'),
#   ('F/6', 'C:7/3', 'G:dim/b3'),
#   ('C:(1)', 'F#:dim', 'C/7'),
#   ('Bb:dim7/7', 'C:7/3', 'D:sus4(b7)'),
#   ('C/9', 'Bb:maj7', 'C:min'),
#   ('F#:dim/b3', 'A:min/5', 'C:7/3'),
#   ('A/b3', 'D:(1)', 'A:min9'),
#   ('D#', 'F/b7', 'C#:dim'),
#   ('G/5', 'E:min(2)', 'Ab:min'),
#   ('E/4', 'G:dim', 'D:maj7'),
#   ('Bb:dim7/5', 'D:dim7', 'C:maj(4)'),
#   ('Eb:7', 'C#:dim', 'F#:min7'),
#   ('Bb:dim7/5', 'Eb:7', 'A:min6'),
#   ('Eb', 'A:min9', 'D/3'),
#   ('C/9', 'A:dim/b5', 'F#:min'),
#   ('F#:dim/b3', 'C/3', 'Bb:maj7'),
#   ('N', 'Bb/5', 'Ab'),
#   ('B', 'E/2', 'Ab:min'),
#   ('E/b6', 'G:min/4', 'C:min'),
#   ('G:minmaj7/b3', 'F/3', 'B:min'),
#   ('B', 'A:min/5', 'G:dim/b3'),
#   ('A/3', 'G:min', 'D:sus4(b7)'),
#   ('E/2', 'C#:dim', 'A:min9'),
#   ('G#', 'C:dim7', 'G:min/4'),
#   ('D:sus4(9)', 'Bb:sus4(9)', 'C:sus4'),
#   ('D#', 'Bb/5', 'G:dim/b3'),
#   ('D:min7', 'G:min/4', 'E:aug'),
#   ('Bb:dim7/7', 'G:7', 'C:min'),
#   ('F:7(b9)', 'Bb:sus2(b7)', 'Bb:7'),
#   ('E/b7', 'E:min', 'F:dim'),
#   ('G#', 'G:min7', 'Bb:7'),
#   ('A:min7', 'D:min7', 'G:min/4'),
#   ('E:7', 'A', 'E:min(9)'),
#   ('D:7', 'Eb:7', 'D:min'),
#   ('G:maj7/3', 'Bb:dim7/5', 'A:7'),
#   ('D:7', 'F:7(b9)', 'Bb:dim7/5'),
#   ('B', 'F:7', 'Bb:7'),
#   ('G', 'C:(1)', 'Bb:7'),
#   ('F/3', 'C:7/3', 'Db'),
#   ('D#', 'E/3', 'G:min/b7'),
#   ('N', 'C#:dim', 'C/5'),
#   ('G/5', 'G:9', 'Bb:min/b3'),
#   ('F', 'A:min6', 'D:min7'),
#   ('Bb:sus2(b7)', 'C/3', 'C:maj(4)'),
#   ('G:maj7/3', 'A:min/b7', 'D#:dim'),
#   ('F/5', 'G:min/5', 'D:maj7'),
#   ('D:min', 'A:min/b7', 'A:7'),
#   ('A', 'E:min(9)', 'D:sus4(b7)'),
#   ('N', 'G:min/5', 'A:min9'),
#   ('D:sus4(9)', 'F#:dim', 'Bb:min/b3'),
#   ('B:dim7/b9', 'C#:min', 'Ab:maj9'),
#   ('E/2', 'D:min7', 'C:sus4'),
#   ('E:7', 'A/3', 'G:dim'),
#   ('A:min', 'C:dim7', 'Bb:min/b3'),
#   ('C:dim7', 'E/b6', 'E:min'),
#   ('D:dim7', 'A:dim/b5', 'F/5'),
#   ('G:7', 'E:aug', 'C/7'),
#   ('D#', 'G:dim/b3', 'F#:min6'),
#   ('A:min', 'A:7', 'D:sus4(b7)'),
#   ('D/5', 'C:(1)', 'D:sus4(b7)'),
#   ('G/3', 'G:dim', 'C:sus4'),
#   ('D:7', 'Eb', 'Ab:min'),
#   ('D/5', 'C:dim7', 'E/4'),
#   ('A:min', 'A:min7', 'G:min'),
#   ('G', 'F/b7', 'D:min7'),
#   ('A:min6', 'C/3', 'F#:min7'),
#   ('A:7', 'Bb:min', 'C:maj(4)'),
#   ('A:min7', 'G:min', 'F:min'),
#   ('A:min/6', 'F#:min', 'Bb:min'),
#   ('F#:dim/b3', 'E:(1)', 'C#:dim'),
#   ('G', 'C:7/3', 'G:dim'),
#   ('F/3', 'Bb:7', 'C/7'),
#   ('A:min/5', 'A:dim/b5', 'D:maj7'),
#   ('F/3', 'D:(1)', 'E:aug'),
#   ('Bb:sus4(9)', 'Bb:sus2(b7)', 'E:min(9)'),
#   ('E:min(2)', 'F:maj6', 'E:aug'),
#   ('D:dim7', 'D#:dim', 'Ab'),
#   ('D:(1)', 'G:dim/b3', 'Bb:min'),
#   ('E:7', 'F#:dim', 'Bb:min/b3'),
#   ('F:min', 'E:min(9)', 'C:(1)'),
#   ('C:dim7', 'E/b7', 'C/7'),
#   ('A/3', 'D:sus4', 'C/5'),
#   ('G:maj7/3', 'A:min6', 'E:aug'),
#   ('D:min', 'F:dim', 'Bb:min/b3'),
#   ('C:dim7', 'G:min', 'A:min9'),
#   ('Bb:maj7', 'G/3', 'F#:min6'),
#   ('G:min', 'Bb:sus2(b7)', 'F/6'),
#   ('A/4', 'D/5', 'G:dim'),
#   ('G:min7', 'Bb:maj7', 'C#:dim'),
#   ('C:(1)', 'G:min/b7', 'F#:min7'),
#   ('D', 'G:min', 'E/3'),
#   ('A/3', 'C#:min', 'F:maj6'),
#   ('N', 'D:sus4(9)', 'A:min/6'),
#   ('Bb:sus4(9)', 'F:dim', 'D:maj7'),
#   ('G:min', 'Bb:maj7', 'F#:min6'),
#   ('C/9', 'A:dim7', 'F:maj6'),
#   ('G/5', 'D:7', 'Bb/5'),
#   ('Bb:sus2(b7)', 'G:9', 'F#:min6'),
#   ('D:(1)', 'Ab:maj7', 'F#:min7'),
#   ('F', 'F:7', 'C:maj(4)'),
#   ('A/b3', 'F:7(b9)', 'F#:min6'),
#   ('A/4', 'G:dim', 'B:min7'),
#   ('F', 'E:min(2)', 'Ab:maj7'),
#   ('A/3', 'A:min6', 'D:maj7'),
#   ('C', 'Bb', 'G:7'),
#   ('B', 'D/b7', 'C:maj(4)'),
#   ('F/5', 'C/3', 'D/3'),
#   ('Bb:dim7/5', 'E:min(9)', 'C:7'),
#   ('F/3', 'Bb', 'Bb:7'),
#   ('D:min', 'C/3', 'C:maj(4)'),
#   ('Bb:dim7/7', 'G:min', 'E/b7'),
#   ('A/2', 'Ab:maj7', 'F#:min7'),
#   ('F:7', 'G:7', 'E/4'),
#   ('E:7', 'F:min', 'G/3'),
#   ('G:min', 'E:min(9)', 'C:maj(4)'),
#   ('D', 'Ab:maj7', 'G:9'),
#   ('D:7', 'G:min/5', 'G:min/b7'),
#   ('A:min7', 'A:min/5', 'A:7'),
#   ('E:min(2)', 'Eb:aug', 'D:maj7'),
#   ('F', 'C:(1)', 'D#:dim'),
#   ('A/2', 'C:dim7/2', 'G:dim/b3'),
#   ('E/2', 'E:min(9)', 'D#:dim'),
#   ('A/3', 'D:sus4(9)', 'A:7'),
#   ('D/b7', 'C:dim7/2', 'D:min'),
#   ('D/b7', 'Bb:dim7/7', 'D:(1)'),
#   ('A/3', 'F/3', 'Bb:sus2(b7)'),
#   ('C', 'A/4', 'E:min(9)'),
#   ('D:dim7', 'E/3', 'G:9'),
#   ('G:min7', 'E:aug', 'A:min9'),
#   ('C', 'D:sus4(9)', 'A:dim7'),
#   ('A', 'C:dim7', 'F/5'),
#   ('G:minmaj7/5', 'E/b6', 'F#:dim'),
#   ('G', 'G/3', 'D:sus4(b7)'),
#   ('Eb', 'G:min/4', 'Bb:min/b3'),
#   ('F/3', 'E:min(2)', 'A:min6'),
#   ('F:7(b9)', 'F#:min', 'Bb:min/b3'),
#   ('E', 'A:min7', 'A:min9'),
#   ('A/3', 'G:min/b7', 'G/3'),
#   ('F/5', 'C:7', 'C:sus4'),
#   ('Eb', 'E/b6', 'C#:min'),
#   ('C:dim7/2', 'Bb:sus4(9)', 'Eb:aug'),
#   ('C/9', 'D:min', 'Bb:maj7'),
#   ('D/5', 'A:min7', 'C/7'),
#   ('D/5', 'D:dim7', 'C:(1)'),
#   ('Bb:dim7/5', 'F/b7', 'D:sus4(b7)'),
#   ('D/b7', 'Bb:sus2(b7)', 'Bb:min/b3'),
#   ('G:dim/b3', 'G:dim', 'B:min7'),
#   ('D:7', 'D:min', 'Bb:7'),
#   ('G:minmaj7/b3', 'A:min', 'A:min/6'),
#   ('A:dim7', 'G:min/4', 'Bb:min'),
#   ('A:dim/b5', 'Ab:maj9', 'Bb:min'),
#   ('A:dim7', 'F/6', 'G:min/5'),
#   ('G/5', 'F#:dim/b3', 'Bb:sus4(9)'),
#   ('C/9', 'E/5', 'C:sus4'),
#   ('A:dim7', 'E:(1)', 'B:min7'),
#   ('A:min6', 'E:min', 'G:dim/b3'),
#   ('A/b3', 'D#:dim', 'F#:min6'),
#   ('E/5', 'E/4', 'Bb:7'),
#   ('F/3', 'Bb:sus2(b7)', 'E:aug'),
#   ('G:minmaj7/b3', 'F', 'G:9'),
#   ('D:(1)', 'E/b7', 'F#:min7'),
#   ('C:dim7/2', 'C/3', 'Ab'),
#   ('D:7', 'E/2', 'Eb:aug'),
#   ('B:dim7/b9', 'E:(1)', 'G/3'),
#   ('F/6', 'Eb:aug', 'Ab:min'),
#   ('D/5', 'E/5', 'Ab:min'),
#   ('F#:dim/b3', 'B:dim7/b9', 'E:aug'),
#   ('G:7', 'G:9', 'G:dim/b3'),
#   ('F/b7', 'E/5', 'Bb:min'),
#   ('Eb:7', 'Bb:7', 'D:min7'),
#   ('E:(1)', 'G:dim', 'Bb:min'),
#   ('E/b6', 'D:min7', 'D/3'),
#   ('D:7', 'F', 'C/3'),
#   ('Eb:7', 'E:min', 'D#:dim'),
#   ('N', 'G:dim/b3', 'Ab'),
#   ('B', 'Eb:7', 'F#:min7'),
#   ('D:min', 'D:sus4', 'F#:min6'),
#   ('G:maj7/3', 'E/2', 'F#:min7'),
#   ('E:7', 'D#', 'E:aug'),
#   ('D:sus4(9)', 'E/b7', 'F#:min6'),
#   ('A:min6', 'Ab:min', 'C:sus4'),
#   ('F:7(b9)', 'B:dim7/b9', 'C/5'),
#   ('A:min/6', 'C:7', 'Ab:maj9'),
#   ('D/b7', 'G:minmaj7/5', 'A:min/5'),
#   ('C#:min', 'B:min', 'F#:dim'),
#   ('C#:min', 'E:min(9)', 'G:dim'),
#   ('B:dim7/b9', 'D:min', 'C:7/3'),
#   ('A/3', 'A:min/b7', 'Ab:min'),
#   ('G/5', 'A/4', 'D/5'),
#   ('C:7', 'Ab:maj9', 'B:min7'),
#   ('A:dim/b5', 'G:min', 'Bb:maj7'),
#   ('A:min/5', 'D:min7', 'B:min7'),
#   ('G:7', 'G/3', 'C/7'),
#   ('E', 'D:(1)', 'E:(1)'),
#   ('C', 'C#:min', 'D#:dim'),
#   ('G/5', 'D:sus4(9)', 'A:min6'),
#   ('C/9', 'A/4', 'C:(1)'),
#   ('D#', 'D:7', 'E/b6'),
#   ('G/5', 'G:min', 'D#:dim'),
#   ('G:min', 'Bb:sus2(b7)', 'C:(1)'),
#   ('F/3', 'Bb:dim7/5', 'Bb:sus4(9)'),
#   ('D:(1)', 'C:sus4', 'F#:min6'),
#   ('D:dim7', 'Bb:sus2(b7)', 'C:7/3'),
#   ('G', 'G:min/4', 'D#:dim'),
#   ('G:minmaj7/b3', 'G/3', 'F#:min7'),
#   ('G:minmaj7/5', 'F:7(b9)', 'Bb:maj7'),
#   ('E/5', 'F#:dim', 'Bb:min'),
#   ('A', 'G:min/b7', 'Bb:min/b3'),
#   ('B:dim7/b9', 'E/b7', 'A:min/b7'),
#   ('D:sus4(9)', 'C#:min', 'G:9'),
#   ('E:7', 'C', 'G:min/5'),
#   ('G:maj7/3', 'G:7', 'G:9'),
#   ('F:7', 'E/b7', 'Bb:maj7'),
#   ('E/4', 'C:(1)', 'C/3'),
#   ('C:(1)', 'C/5', 'D:maj7'),
#   ('F:7(b9)', 'A:dim/b5', 'F:maj6'),
#   ('Bb:sus4(9)', 'E/4', 'G:min/b7'),
#   ('G#', 'E/b6', 'E:min'),
#   ('C:dim7/2', 'D:min', 'E/b6'),
#   ('Eb', 'A:min/b7', 'G:min/b7'),
#   ('C/9', 'D/b7', 'C:sus4'),
#   ('N', 'E:7', 'G:7'),
#   ('G:maj7/3', 'Bb:sus2(b7)', 'G:dim/b3'),
#   ('C:dim7', 'Bb:sus2(b7)', 'Db'),
#   ('D:dim7', 'C#:min', 'F#:min7'),
#   ('G:min7', 'E/5', 'Bb:min/b3'),
#   ('E', 'Bb:sus4(9)', 'D:sus4(b7)'),
#   ('A', 'A:min/b7', 'G:9'),
#   ('F:7(b9)', 'A:dim/b5', 'Eb:aug'),
#   ('A:min/5', 'E/3', 'C:7/3'),
#   ('C:dim7/2', 'G:min/b7', 'D:min7'),
#   ('D', 'Eb:7', 'G:min/4'),
#   ('C/9', 'Eb:7', 'D:maj7'),
#   ('A/b3', 'B:dim7/b9', 'F#:dim'),
#   ('C', 'F:min', 'Ab'),
#   ('C/3', 'C:min', 'D:maj7'),
#   ('F/3', 'E:(1)', 'F:maj6'),
#   ('G:min', 'E/5', 'Ab:min'),
#   ('D:min', 'Ab:maj7', 'Ab:min'),
#   ('D#', 'G:dim', 'B:min7'),
#   ('G', 'Ab:min', 'D:sus4'),
#   ('A:min', 'E/2', 'D/3'),
#   ('G:min', 'C:(1)', 'C:sus4'),
#   ('C:dim7', 'Ab:min', 'C:sus4'),
#   ('F/b7', 'C#:min', 'B:min7'),
#   ('N', 'D', 'A:min9'),
#   ('E/5', 'C#:min', 'F:maj6'),
#   ('A/b3', 'A:min/5', 'E:aug'),
#   ('D/5', 'D:min', 'G:dim'),
#   ('D:sus4(9)', 'F/b7', 'Eb:aug'),
#   ('F', 'Bb:dim7/7', 'D:sus4(b7)'),
#   ('E:(1)', 'G:min/b7', 'Bb:min/b3'),
#   ('G:min/5', 'D:min7', 'C/7'),
#   ('G#', 'Ab:maj9', 'D:maj7'),
#   ('F:maj6', 'B:min7', 'A:min9'),
#   ('G:maj7/3', 'C:(1)', 'D#:dim'),
#   ('B', 'D/5', 'A:min'),
#   ('A:min', 'F/b7', 'E/b6'),
#   ('A/3', 'F#:dim/b3', 'Ab:min'),
#   ('D:(1)', 'A:min6', 'C:(1)'),
#   ('E/3', 'C:(1)', 'Ab:min'),
#   ('N', 'F', 'Bb:7'),
#   ('N', 'G', 'C:dim7'),
#   ('A', 'D/b7', 'Ab:maj7'),
#   ('F/3', 'A:min/5', 'C:7/3'),
#   ('A', 'F/5', 'E/b6'),
#   ('A/b3', 'Bb:sus4(9)', 'E/b6'),
#   ('G#', 'B:min', 'Ab:min'),
#   ('A', 'Eb:7', 'Eb:aug'),
#   ('B:min', 'C:sus4', 'Bb:min/b3'),
#   ('D/5', 'G', 'E/b7'),
#   ('F:7(b9)', 'E:min', 'C:sus4'),
#   ('F:7', 'G:min/4', 'D:sus4'),
#   ('E/b7', 'E:min', 'C:(1)'),
#   ('D', 'A:min/5', 'Bb/5'),
#   ('N', 'G:min', 'Bb:sus2(b7)'),
#   ('G:minmaj7/5', 'A:dim7', 'C:sus4'),
#   ('A:dim7', 'F/5', 'F#:min6'),
#   ('C/9', 'B:dim7/b9', 'Eb'),
#   ('D#', 'D/5', 'D:sus4(9)'),
#   ('D/5', 'F/6', 'F#:min6'),
#   ('A', 'Bb:dim7/7', 'C:(1)'),
#   ('G', 'F/5', 'E/2'),
#   ('D#', 'Bb:7', 'E:aug'),
#   ('Bb/5', 'F#:dim', 'Db'),
#   ('F#:dim/b3', 'G:min/b7', 'Bb:min/b3'),
#   ('A/2', 'E:min(9)', 'E:aug'),
#   ('E', 'Bb/5', 'D:maj7'),
#   ('F#:min', 'G:min/b7', 'C#:dim'),
#   ('C', 'D:sus4(9)', 'C:7/3'),
#   ('B:dim7/b9', 'C:dim7', 'E/b7'),
#   ('Eb:7', 'E/2', 'F#:min6'),
#   ('D#', 'D/5', 'C#:dim'),
#   ('A:dim7', 'C#:min', 'E:aug'),
#   ('E', 'A:min/b7', 'E:aug'),
#   ('C/3', 'F#:dim', 'C/7'),
#   ('D:(1)', 'D#:dim', 'Eb:aug'),
#   ('F/5', 'C:maj(4)', 'F#:min7'),
#   ('A:dim/b5', 'G:dim/b3', 'Ab'),
#   ('F:7(b9)', 'B:dim7/b9', 'F#:dim'),
#   ('Bb:sus4(9)', 'Db', 'C/7'),
#   ('C/9', 'F/3', 'A:min/5'),
#   ('G/5', 'G:min/b7', 'Ab'),
#   ('F/b7', 'G:min/5', 'A:min9'),
#   ('A:min7', 'G:dim/b3', 'C:maj(4)'),
#   ('G:minmaj7/b3', 'E/4', 'D/3'),
#   ('E:7', 'A:min', 'A:min/5'),
#   ('A:min7', 'F:min', 'Db'),
#   ('D/5', 'E/3', 'B:min7'),
#   ('Bb', 'F/5', 'E:(1)'),
#   ('A:min', 'D:(1)', 'B:min7'),
#   ('C/9', 'G:min/b7', 'A:min9'),
#   ('G:minmaj7/b3', 'G:min/5', 'D:min7'),
#   ('F:7(b9)', 'F:maj6', 'D:maj7'),
#   ('E/4', 'A:min6', 'F#:dim'),
#   ('E:7', 'Bb:dim7/7', 'F#:dim'),
#   ('F/5', 'D:min', 'C:7'),
#   ('E:min', 'Bb:min/b3', 'F#:min7'),
#   ('G:min/b7', 'Bb:7', 'Ab:min'),
#   ('A/b3', 'F#:min', 'F:maj6'),
#   ('A/b3', 'G:minmaj7/b3', 'E/b6'),
#   ('F/3', 'A:min6', 'C:7'),
#   ('F#:dim/b3', 'E/b6', 'C/3'),
#   ('C/9', 'D:min7', 'F#:min7'),
#   ('B', 'C:7', 'F#:min7'),
#   ('Bb:dim7/5', 'E/b6', 'G:dim/b3'),
#   ('Eb', 'E/2', 'G:min/4'),
#   ('C:dim7', 'E:min', 'F#:min6'),
#   ('B', 'F#:dim/b3', 'C/7'),
#   ('E/5', 'A:min6', 'Eb:aug'),
#   ('F:7(b9)', 'G:min', 'C/5'),
#   ('G:minmaj7/b3', 'F#:dim', 'C/5'),
#   ('Bb:dim7/5', 'G:min', 'C/5'),
#   ('C/9', 'Ab:maj9', 'Ab:maj7'),
#   ('A:min6', 'C:7', 'D:sus4(b7)'),
#   ('N', 'A/4', 'A:dim7'),
#   ('C/9', 'Eb', 'F/5'),
#   ('C:(1)', 'F:maj6', 'G:dim/b3'),
#   ('G:min', 'C:(1)', 'A:min9'),
#   ('B:dim7/b9', 'D:dim7', 'E:min(2)'),
#   ('C/9', 'F:7(b9)', 'G:min/b7'),
#   ('C', 'D:7', 'A:7'),
#   ('F/6', 'E:min(2)', 'D:sus4(b7)'),
#   ('N', 'F/3', 'F#:dim/b3'),
#   ('E:min(2)', 'A:min/b7', 'F:dim'),
#   ('G:9', 'C:sus4', 'D/3'),
#   ('F:7', 'C#:dim', 'D/3'),
#   ('C', 'F/3', 'G:min/5'),
#   ('C:dim7/2', 'E:min(2)', 'Eb:aug'),
#   ('D#', 'D:sus4(9)', 'E:(1)'),
#   ('A/b3', 'Ab:maj9', 'D:sus4'),
#   ('G/5', 'G:maj7/3', 'G:dim'),
#   ('A', 'G/5', 'E/2'),
#   ('D/5', 'A:min', 'G:9'),
#   ('C/9', 'E/b6', 'G/3'),
#   ('G', 'E:(1)', 'E:aug'),
#   ('C:dim7/2', 'E/2', 'G:min/b7'),
#   ('D/5', 'A:dim7', 'F#:min7'),
#   ('D:7', 'Ab:min', 'D:maj7'),
#   ('A/2', 'E:min', 'G:dim'),
#   ('B', 'G', 'Bb:dim7/5'),
#   ('A:dim7', 'D:sus4', 'D/3'),
#   ('Bb:dim7/7', 'E:min', 'C:7/3'),
#   ('Ab:maj9', 'B:min7', 'D:maj7'),
#   ('E/3', 'C:maj(4)', 'B:min7'),
#   ('F#:dim/b3', 'F/6', 'A:min6'),
#   ('E', 'D/5', 'E:min'),
#   ('D:sus4(9)', 'A:min/5', 'F:dim'),
#   ('E', 'F:7(b9)', 'Bb:sus4(9)'),
#   ('D:7', 'Ab:maj9', 'G:min/4'),
#   ('Bb', 'G:min/5', 'D:maj7'),
#   ('G:7', 'C#:dim', 'C:min'),
#   ('E', 'A/4', 'C/7'),
#   ('A', 'D:7', 'C:7'),
#   ('A:min7', 'Bb/5', 'Ab'),
#   ('E:7', 'D:7', 'E:aug'),
#   ('D:dim7', 'G:min/5', 'F:dim'),
#   ('G/5', 'B:dim7/b9', 'E:min(2)'),
#   ('D/5', 'A:dim/b5', 'G:min'),
#   ('D', 'Eb', 'Bb:sus4(9)'),
#   ('D#', 'A:min', 'D:(1)'),
#   ('D', 'Bb', 'A:min/b7'),
#   ('G', 'C:dim7', 'E:aug'),
#   ('F/5', 'G:min/5', 'F#:dim'),
#   ('A/2', 'E/b6', 'C:(1)'),
#   ('G:minmaj7/5', 'C:dim7', 'E/5'),
#   ('D/5', 'E/2', 'D:min7'),
#   ('Bb:sus2(b7)', 'Bb:min', 'D/3'),
#   ('G#', 'G:dim', 'Bb:min'),
#   ('Eb:7', 'C/3', 'Ab'),
#   ('D/5', 'C:7/3', 'G:9'),
#   ('G#', 'Db', 'A:min9'),
#   ('D:sus4(9)', 'A:min', 'A:dim/b5'),
#   ('D#', 'F/3', 'F:maj6'),
#   ('F#:dim/b3', 'F:7(b9)', 'F/b7'),
#   ('F/6', 'F/5', 'D:maj7'),
#   ('F:maj6', 'Eb:aug', 'G:dim/b3'),
#   ('F:min', 'A:min/b7', 'D#:dim'),
#   ('D', 'C/3', 'C/5'),
#   ('A/3', 'C/3', 'Ab:maj9'),
#   ('G', 'A:min7', 'Eb:aug'),
#   ('D:7', 'D:min7', 'F:dim'),
#   ('N', 'A:dim/b5', 'D:(1)'),
#   ('E/3', 'G/3', 'A:min9'),
#   ('A:min/5', 'C/3', 'G:dim'),
#   ('C:dim7/2', 'E/5', 'C/5'),
#   ('A:min', 'Eb:7', 'D:sus4'),
#   ('F/3', 'D:dim7', 'G:7'),
#   ('A', 'E:min(9)', 'G:dim/b3'),
#   ('Bb:dim7/7', 'A:min/5', 'Bb:min'),
#   ('G:minmaj7/5', 'F#:dim/b3', 'Ab'),
#   ('C:7', 'Bb:7', 'Bb:min/b3'),
#   ('A:min7', 'E/4', 'B:min7'),
#   ('B:dim7/b9', 'C:(1)', 'E:aug'),
#   ('C', 'Bb:dim7/7', 'C/3'),
#   ('A', 'D:7', 'Bb:sus4(9)'),
#   ('D:min', 'E/b7', 'A:min/6'),
#   ('C:7', 'Ab:maj7', 'F:dim'),
#   ('C:7', 'Bb:min', 'Db'),
#   ('C:dim7/2', 'E/2', 'Ab:min'),
#   ('A', 'B:min', 'E:min'),
#   ('F/3', 'G:min', 'E:(1)'),
#   ('F:7(b9)', 'C:7', 'F:dim'),
#   ('A/4', 'F/b7', 'B:min7'),
#   ('D:min', 'G:min/5', 'Bb:min'),
#   ('A:min7', 'G:min', 'Bb:7'),
#   ('D:7', 'Eb', 'F#:min6'),
#   ('B', 'E/5', 'E/2'),
#   ('A:min', 'Bb:maj7', 'E:aug'),
#   ('Bb:sus2(b7)', 'C:(1)', 'Ab'),
#   ('G:minmaj7/5', 'F/5', 'Ab'),
#   ('G:min', 'C:7/3', 'G:dim'),
#   ('A:dim7', 'Bb:min', 'D/3'),
#   ('A:min6', 'C/3', 'D:maj7'),
#   ('C:dim7/2', 'C:7/3', 'D#:dim'),
#   ('G:maj7/3', 'G#', 'F#:min'),
#   ('G/5', 'Bb/5', 'F#:min6'),
#   ('G:min7', 'Bb:dim7/5', 'A:min6'),
#   ('A', 'A:min6', 'Ab:maj9'),
#   ('G:maj7/3', 'A:dim7', 'G:min/5'),
#   ('G:minmaj7/b3', 'G:minmaj7/5', 'C#:dim'),
#   ('Bb/5', 'D:min', 'E/2'),
#   ('A:min/6', 'E/4', 'Ab:maj9'),
#   ('A/b3', 'B', 'C:sus4'),
#   ('G#', 'A:min7', 'E/3'),
#   ('N', 'F/b7', 'F#:min'),
#   ('C:dim7/2', 'A:dim7', 'C#:dim'),
#   ('A:7', 'Bb:7', 'D/3'),
#   ('Bb:dim7/7', 'A:7', 'Bb:7'),
#   ('Ab', 'Ab:min', 'D/3'),
#   ('Eb', 'F:dim', 'D:sus4'),
#   ('C', 'E/4', 'C:sus4'),
#   ('G:min/b7', 'D:min7', 'Db'),
#   ('F:7', 'C:(1)', 'G:min/4'),
#   ('G', 'F:7', 'Bb:min'),
#   ('E/5', 'C:min', 'Ab'),
#   ('N', 'Bb:dim7/5', 'Ab:maj9'),
#   ('C', 'A/b3', 'D:sus4'),
#   ('C:dim7', 'A:dim/b5', 'E/5'),
#   ('N', 'F#:dim/b3', 'E:(1)'),
#   ('G:minmaj7/5', 'F:dim', 'C:sus4'),
#   ('F:min', 'B:min', 'F:dim'),
#   ('F:7(b9)', 'Bb', 'E/3'),
#   ('A:min/b7', 'D:min7', 'C:sus4'),
#   ('G:7', 'G:9', 'D/3'),
#   ('D:sus4(9)', 'E/4', 'F#:min7'),
#   ('G:min/5', 'D:sus4', 'C/7'),
#   ('E/5', 'C#:dim', 'Ab'),
#   ...},
#  '012': {('A/3', 'A:min7', 'E:(1)'),
#   ('C/3', 'G/3', 'G:dim/b3'),
#   ('A', 'E:aug', 'Eb:aug'),
#   ('C', 'Db', 'F#:min6'),
#   ('A:min/5', 'A:min9', 'B'),
#   ('B:min', 'C#:min', 'C:7/3'),
#   ('A:min7', 'B:min7', 'D/b7'),
#   ('Bb:dim7/5', 'C:sus4', 'N'),
#   ('C', 'E/b6', 'G:min'),
#   ('A:min', 'E/b6', 'F:min'),
#   ('B', 'E', 'F:7'),
#   ('A:min7', 'D:sus4', 'F/6'),
#   ('A:min', 'C:7', 'F:maj6'),
#   ('C/3', 'D:maj7', 'D:min'),
#   ('D#:dim', 'E/5', 'E/b6'),
#   ('D', 'D:7', 'E:min(2)'),
#   ('A:min/6', 'F', 'F/5'),
#   ('F#:dim', 'F:dim', 'F:min'),
#   ('A:7', 'A:min', 'Bb:min/b3'),
#   ('A', 'F#:min6', 'N'),
#   ('A', 'A/2', 'E:min(9)'),
#   ('A:min', 'G/3', 'G:min7'),
#   ('C:dim7', 'C:dim7/2', 'G:min/4'),
#   ('D/3', 'D:sus4(9)', 'F#:min6'),
#   ('A', 'A/2', 'F:dim'),
#   ('C:7/3', 'D:sus4', 'F'),
#   ('D/5', 'D/b7', 'G:dim/b3'),
#   ('A:min', 'C/7', 'E'),
#   ('B:min7', 'Bb', 'F#:min7'),
#   ('C:(1)', 'F#:min6', 'N'),
#   ('A:min7', 'A:min9', 'Ab'),
#   ('B', 'E', 'F:maj6'),
#   ('Ab:maj9', 'D:7', 'G:7'),
#   ('Ab:maj7', 'D:7', 'N'),
#   ('Bb/5', 'D', 'Eb:aug'),
#   ('Eb', 'F:min', 'G/5'),
#   ('A/4', 'C#:min', 'C/9'),
#   ('E/b7', 'G', 'G/3'),
#   ('B:min7', 'F#:min', 'G:minmaj7/b3'),
#   ('Ab', 'D:sus4(9)', 'N'),
#   ('Bb:maj7', 'C:7', 'F/6'),
#   ('C/3', 'F', 'G:9'),
#   ('A:min', 'C/5', 'E'),
#   ('A/3', 'C', 'E/3'),
#   ('C/3', 'D/5', 'G:minmaj7/b3'),
#   ('Ab:min', 'E:(1)', 'F'),
#   ('A:7', 'A:min', 'E:min'),
#   ('A:min', 'Bb', 'C:sus4'),
#   ('A:dim/b5', 'B:dim7/b9', 'F:7(b9)'),
#   ('D:sus4(9)', 'E:7', 'Eb:7'),
#   ('Bb:min/b3', 'D', 'D#'),
#   ('A:min7', 'F:7', 'F:dim'),
#   ('D/b7', 'G:min', 'G:min/5'),
#   ('Bb:dim7/5', 'Bb:min/b3', 'F/5'),
#   ('E/4', 'G/3', 'G:dim/b3'),
#   ('Bb:dim7/7', 'C:7', 'D:dim7'),
#   ('C', 'C:min', 'G:maj7/3'),
#   ('A:min', 'D/5', 'G:min7'),
#   ('D', 'D:sus4', 'Db'),
#   ('D', 'D:sus4(b7)', 'G:minmaj7/b3'),
#   ('Eb', 'Eb:aug', 'G:min/5'),
#   ('Bb:min/b3', 'D:min', 'F:7'),
#   ('A', 'E/2', 'G#'),
#   ('A:min6', 'E:min(9)', 'G:min/5'),
#   ('D:sus4(9)', 'G/3', 'G:dim/b3'),
#   ('C:maj(4)', 'D:min', 'E'),
#   ('D', 'E:(1)', 'Eb:aug'),
#   ('D', 'G#', 'G:min/4'),
#   ('B', 'C:maj(4)', 'E'),
#   ('Bb:maj7', 'C:7/3', 'F'),
#   ('Bb/5', 'E:min(2)', 'Eb'),
#   ('C:dim7/2', 'D', 'G#'),
#   ('Bb:min/b3', 'D:maj7', 'D:min'),
#   ('Bb:sus4(9)', 'E/3', 'E/4'),
#   ('A:dim/b5', 'E', 'E/2'),
#   ('Bb/5', 'C:dim7', 'Eb'),
#   ('A:7', 'E:min(2)', 'N'),
#   ('A:min', 'Bb', 'C/7'),
#   ('C', 'C:7', 'D/b7'),
#   ('F', 'F#:dim/b3', 'G#'),
#   ('Ab:maj9', 'Bb:7', 'G#'),
#   ('A/4', 'C/9', 'G:maj7/3'),
#   ('Bb:dim7/7', 'C:dim7/2', 'F#:min7'),
#   ('C:min', 'E:min', 'Eb:aug'),
#   ('A/4', 'A:min6', 'E:min(9)'),
#   ('A:dim7', 'A:min', 'C:7'),
#   ('A', 'A/2', 'A:min/6'),
#   ('D', 'D:sus4', 'Eb'),
#   ('A:min7', 'G', 'G:min/b7'),
#   ('B:min7', 'Db', 'G:min'),
#   ('D', 'Eb', 'F:dim'),
#   ('D', 'F:7', 'G#'),
#   ('A:min7', 'D:7', 'F#:min7'),
#   ('A/b3', 'A:7', 'C:7'),
#   ('D:min', 'G:min/4', 'N'),
#   ('A:min', 'E:(1)', 'F:min'),
#   ('Bb:maj7', 'Eb', 'G:min7'),
#   ('A:min6', 'A:min7', 'F:maj6'),
#   ('A:dim7', 'C#:min', 'F:7(b9)'),
#   ('Bb/5', 'C/3', 'D:min'),
#   ('B', 'Bb:maj7', 'E'),
#   ('Ab:maj9', 'G:9', 'G:min7'),
#   ('E', 'E/2', 'E:aug'),
#   ('A/2', 'Bb:min/b3', 'D:min'),
#   ('A', 'Eb', 'F/5'),
#   ('C#:min', 'G:maj7/3', 'G:minmaj7/5'),
#   ('A', 'Ab:maj9', 'E/4'),
#   ('Bb:dim7/7', 'C', 'E:min(2)'),
#   ('A/3', 'A/b3', 'E:min(2)'),
#   ('Bb:sus2(b7)', 'D/3', 'F#:min6'),
#   ('A', 'A:min6', 'E:min(9)'),
#   ('A:dim7', 'Db', 'Eb'),
#   ('A:min7', 'Ab:min', 'D:sus4'),
#   ('Ab:maj7', 'F', 'F/b7'),
#   ('Bb:7', 'Bb:dim7/7', 'D:min'),
#   ('C/3', 'D:7', 'G:7'),
#   ('Bb', 'D:(1)', 'E/3'),
#   ('D/5', 'D:7', 'G/5'),
#   ('Eb', 'F#:min6', 'G:min7'),
#   ('A:dim7', 'D', 'D#'),
#   ('D:sus4(b7)', 'E:(1)', 'F'),
#   ('Bb:min', 'Eb', 'F#:dim'),
#   ('D#:dim', 'E:7', 'E:min'),
#   ('A:min', 'E/5', 'Eb'),
#   ('A', 'B:min', 'D:maj7'),
#   ('Bb:dim7/7', 'C:maj(4)', 'G:min7'),
#   ('C/3', 'D:sus4(b7)', 'G:dim/b3'),
#   ('Bb:sus2(b7)', 'E', 'E/2'),
#   ('A', 'A:dim7', 'N'),
#   ('F/6', 'F/b7', 'G:maj7/3'),
#   ('A', 'A/4', 'D:7'),
#   ('F', 'F#:min6', 'F:7'),
#   ('Bb/5', 'D:min', 'G'),
#   ('A', 'B:min7', 'E/4'),
#   ('Bb:maj7', 'F:maj6', 'G:min7'),
#   ('Ab', 'F/b7', 'G:dim'),
#   ('Bb:sus2(b7)', 'E/4', 'Eb'),
#   ('A', 'C#:min', 'G:min'),
#   ('D/5', 'D/b7', 'Db'),
#   ('G:maj7/3', 'G:min', 'G:min/5'),
#   ('A/2', 'A/b3', 'Bb:min/b3'),
#   ('Ab', 'C/9', 'D/5'),
#   ('D#:dim', 'F/6', 'F/b7'),
#   ('D/5', 'D/b7', 'Eb'),
#   ('B', 'D:min', 'N'),
#   ('D#', 'Eb', 'G:min7'),
#   ('B:dim7/b9', 'F:7(b9)', 'G:7'),
#   ('A', 'C/9', 'E/4'),
#   ('A:min7', 'B:min7', 'Bb:7'),
#   ('B:dim7/b9', 'C:dim7', 'F:7(b9)'),
#   ('D:sus4', 'E/5', 'E/b6'),
#   ('D:sus4(b7)', 'E', 'E:7'),
#   ('A:min6', 'E:min(9)', 'F:min'),
#   ('D#', 'D:min', 'F#:min'),
#   ('A/3', 'A/b3', 'C:dim7/2'),
#   ('Bb:dim7/7', 'C', 'C:dim7/2'),
#   ('A:7', 'A:min/b7', 'G/3'),
#   ('C', 'E:min(2)', 'G:minmaj7/5'),
#   ('B:dim7/b9', 'E/b6', 'E/b7'),
#   ('A:min', 'A:min/b7', 'C:7/3'),
#   ('F/5', 'G:7', 'G:min7'),
#   ('A', 'D/b7', 'D:maj7'),
#   ('Ab:min', 'E/5', 'E/b6'),
#   ('C', 'G:9', 'G:min'),
#   ('E/4', 'G:7', 'G:min7'),
#   ('A:dim7', 'D:(1)', 'D:dim7'),
#   ('A:min7', 'D:sus4', 'Db'),
#   ('C#:min', 'C:dim7', 'C:dim7/2'),
#   ('A:min/5', 'Ab', 'G:dim'),
#   ('A:min', 'C/3', 'C:7'),
#   ('A', 'D:maj7', 'E:min(2)'),
#   ('A:min9', 'B', 'D:maj7'),
#   ('A:min/5', 'D:min7', 'F'),
#   ('A:min', 'Bb', 'G:7'),
#   ('F:maj6', 'G:dim/b3', 'G:min7'),
#   ('Bb:min', 'C:dim7', 'Eb'),
#   ('A/2', 'A/b3', 'F/3'),
#   ('D:min', 'D:min7', 'E/5'),
#   ('B', 'D:sus4', 'E'),
#   ('A:min7', 'D/3', 'E:min'),
#   ('A/2', 'A/b3', 'C#:dim'),
#   ('E/4', 'E:min', 'E:min(9)'),
#   ('A', 'Eb', 'F:7'),
#   ('A:7', 'A:dim7', 'A:min'),
#   ('Bb/5', 'C:sus4', 'G'),
#   ('A:min7', 'Bb:min', 'D:sus4'),
#   ('A/3', 'G/3', 'G:dim/b3'),
#   ('E:min', 'G:7', 'G:min7'),
#   ('D', 'D#', 'E:min(2)'),
#   ('A/4', 'A:min', 'F/3'),
#   ('Bb:dim7/5', 'C#:min', 'C:dim7'),
#   ('Bb:sus2(b7)', 'Eb', 'G'),
#   ('A:min/5', 'C/9', 'G/5'),
#   ('G:9', 'G:min', 'G:min/5'),
#   ('A:min7', 'Bb:min/b3', 'F/5'),
#   ('A:dim/b5', 'A:dim7', 'A:min/5'),
#   ('A:min/b7', 'D:min', 'N'),
#   ('D', 'D#', 'E/4'),
#   ('D:min', 'D:min7', 'G/5'),
#   ('Bb:dim7/7', 'D:dim7', 'F#:min7'),
#   ('C:sus4', 'E:aug', 'F#:min'),
#   ('A:min/6', 'Ab:maj9', 'Bb:7'),
#   ('D#', 'E', 'F#:min7'),
#   ('A/4', 'Bb/5', 'C/9'),
#   ('C', 'C:sus4', 'E/5'),
#   ('Bb:sus4(9)', 'E', 'E/2'),
#   ('B:min', 'Bb:7', 'D:min7'),
#   ('Bb:7', 'D:min7', 'F:min'),
#   ('D:7', 'Eb:7', 'F:maj6'),
#   ('A:min/b7', 'Db', 'F'),
#   ('Bb:dim7/7', 'C:dim7/2', 'E:(1)'),
#   ('Ab', 'D:7', 'Db'),
#   ('B:min7', 'D:sus4(b7)', 'G:dim/b3'),
#   ('A', 'A/2', 'Bb:7'),
#   ('A', 'Ab:maj7', 'E:aug'),
#   ('C', 'D/b7', 'E:min'),
#   ('D:dim7', 'D:min', 'E:min'),
#   ('D#', 'D:sus4(b7)', 'G:dim/b3'),
#   ('A:min', 'D/3', 'F#:min'),
#   ('C/3', 'C:maj(4)', 'G:min7'),
#   ('D/5', 'G:minmaj7/b3', 'N'),
#   ('C/9', 'F:dim', 'G/5'),
#   ('Ab:maj9', 'F#:dim/b3', 'F/3'),
#   ('A:dim7', 'E:min(9)', 'F:7(b9)'),
#   ('D/b7', 'Eb', 'F:min'),
#   ('A:7', 'D:dim7', 'G/3'),
#   ('A', 'A:7', 'D:maj7'),
#   ('Bb', 'E/2', 'F:7'),
#   ('Bb:maj7', 'D/5', 'G:minmaj7/5'),
#   ('A:min9', 'F#:dim/b3', 'F/3'),
#   ('C:sus4', 'E:min(9)', 'G'),
#   ('A:min7', 'E:min(2)', 'G/3'),
#   ('A:dim7', 'Bb:maj7', 'D:min'),
#   ('A:min7', 'E/b7', 'E:min'),
#   ('A/2', 'C', 'C:sus4'),
#   ('C/7', 'Db', 'Eb'),
#   ('B:min', 'Eb', 'F:min'),
#   ('Ab:maj7', 'D:min', 'E'),
#   ('B', 'E/3', 'G:7'),
#   ('B:dim7/b9', 'F:7(b9)', 'G:dim'),
#   ('B:dim7/b9', 'F:7(b9)', 'G:min/4'),
#   ('C/7', 'D/3', 'F#:min'),
#   ('E:aug', 'F#:min', 'G:maj7/3'),
#   ('A:7', 'B', 'E'),
#   ('E/3', 'E/4', 'F'),
#   ('A', 'B:min7', 'E:7'),
#   ('C', 'F#:min6', 'F#:min7'),
#   ('E/b7', 'Eb', 'F:min'),
#   ('Bb:min', 'C/3', 'Eb'),
#   ('A:min7', 'B:min7', 'C:sus4'),
#   ('A:min', 'A:min7', 'D'),
#   ('C:dim7', 'D:sus4(b7)', 'G:dim/b3'),
#   ('E/2', 'G:maj7/3', 'G:minmaj7/b3'),
#   ('A:min7', 'Bb:sus4(9)', 'D:7'),
#   ('F', 'F/b7', 'G:min7'),
#   ('A:min6', 'C#:min', 'E:min(9)'),
#   ('C/3', 'F#:min', 'G:min/b7'),
#   ('Bb:sus4(9)', 'D', 'D:sus4'),
#   ('A:min7', 'C/9', 'E:(1)'),
#   ('A:dim/b5', 'D', 'Eb:aug'),
#   ('D/5', 'D:7', 'D:maj7'),
#   ('C:maj(4)', 'C:min', 'G/3'),
#   ('D/3', 'G:maj7/3', 'G:minmaj7/5'),
#   ('Bb:maj7', 'G:maj7/3', 'G:minmaj7/b3'),
#   ('D/5', 'E:min(2)', 'G:minmaj7/b3'),
#   ('C', 'C/7', 'D:dim7'),
#   ('Bb:maj7', 'D:min', 'E/b6'),
#   ('A:dim/b5', 'C:7/3', 'F'),
#   ('Bb:min/b3', 'C', 'C:min'),
#   ('C', 'C:sus4', 'F/6'),
#   ('C', 'E/5', 'G:7'),
#   ('D:sus4(b7)', 'Db', 'G:dim/b3'),
#   ('D:7', 'D:min7', 'G:7'),
#   ('E/b6', 'F:7', 'G'),
#   ('A/4', 'F/5', 'F/6'),
#   ('Bb:dim7/5', 'C/3', 'F'),
#   ('A:min/b7', 'E/b6', 'E/b7'),
#   ('D#', 'E:7', 'Eb:7'),
#   ('C:min', 'D', 'G:7'),
#   ('B:dim7/b9', 'B:min7', 'C:dim7/2'),
#   ('A/4', 'E:aug', 'F#:min'),
#   ('E:(1)', 'F', 'F#:min'),
#   ('Ab', 'G:9', 'G:dim'),
#   ('A:min', 'Bb', 'G:min/4'),
#   ('Bb:min/b3', 'D:min', 'E/b7'),
#   ('A:min7', 'C', 'D:dim7'),
#   ('Bb:dim7/5', 'C#:dim', 'C:dim7'),
#   ('A:min9', 'B', 'C/3'),
#   ('Bb', 'F#:min6', 'F:7'),
#   ('C/3', 'F', 'G:minmaj7/5'),
#   ('A', 'Eb:7', 'N'),
#   ('A:min7', 'B:min7', 'F#:min6'),
#   ('A/4', 'B', 'C'),
#   ('A:min7', 'D:7', 'F'),
#   ('F', 'G#', 'G:maj7/3'),
#   ('A:dim7', 'D/3', 'F:7(b9)'),
#   ('D:7', 'E/b6', 'N'),
#   ('A:min7', 'Bb:sus2(b7)', 'E:(1)'),
#   ('A:dim7', 'A:min', 'N'),
#   ('E', 'E/2', 'G:min7'),
#   ('C', 'E:min(2)', 'F#:min'),
#   ('B:dim7/b9', 'C:7/3', 'C:dim7/2'),
#   ('Bb:7', 'Bb:dim7/5', 'D:min'),
#   ('A/3', 'B:min7', 'F#:min'),
#   ('C', 'F/6', 'F:7'),
#   ('Bb', 'E', 'G:min'),
#   ('D/3', 'D:min', 'E:min'),
#   ('A:min7', 'Ab:maj7', 'F#:dim/b3'),
#   ('D/3', 'F#:min6', 'G/3'),
#   ('C:7/3', 'F', 'F/5'),
#   ('A:min/5', 'Bb:maj7', 'C:7'),
#   ('A:7', 'Bb', 'E:7'),
#   ('A/2', 'A/b3', 'A:min/5'),
#   ('D/b7', 'F:7(b9)', 'G'),
#   ('A:min/6', 'B:min', 'F'),
#   ('A/b3', 'A:min', 'Bb'),
#   ('E/3', 'E/4', 'Eb:7'),
#   ('E/5', 'G/3', 'G:dim/b3'),
#   ('Eb', 'F:dim', 'G:maj7/3'),
#   ('Bb:maj7', 'E', 'E/2'),
#   ('Bb:7', 'C', 'D/b7'),
#   ('F#:dim', 'G:dim', 'N'),
#   ('Bb', 'F#:min6', 'G:min'),
#   ('A', 'C:maj(4)', 'N'),
#   ('A:min7', 'E:min', 'F:dim'),
#   ('D:7', 'G:min', 'G:min/5'),
#   ('C:7', 'E/3', 'G:9'),
#   ('B:dim7/b9', 'Db', 'F'),
#   ('Db', 'E', 'E/b7'),
#   ('Bb/5', 'E/b7', 'F'),
#   ('A/3', 'A/b3', 'D:(1)'),
#   ('Ab:maj9', 'C:maj(4)', 'G:min7'),
#   ('Bb', 'Bb:sus2(b7)', 'C/7'),
#   ('E/b6', 'F', 'F/b7'),
#   ('Bb:min/b3', 'D#:dim', 'D:min'),
#   ('A:7', 'Bb:7', 'Eb'),
#   ('Ab', 'Bb', 'Db'),
#   ('A:min7', 'C', 'G:dim/b3'),
#   ('D:min', 'D:min7', 'E/2'),
#   ('B', 'C:7/3', 'G:9'),
#   ('E/b6', 'G/3', 'G:dim/b3'),
#   ('Bb:dim7/5', 'C:dim7', 'F'),
#   ('Bb:dim7/7', 'E:min(2)', 'N'),
#   ('A:min', 'E/2', 'E/4'),
#   ('C:min', 'G:9', 'G:min7'),
#   ('A/4', 'C', 'G/5'),
#   ('A:min7', 'A:min9', 'E:min(9)'),
#   ('Ab', 'Ab:min', 'N'),
#   ('E', 'E/2', 'G:min/5'),
#   ('D/5', 'D:7', 'F:maj6'),
#   ('Bb', 'Bb:maj7', 'D:min'),
#   ('D:7', 'E/b6', 'E/b7'),
#   ('C:7', 'D', 'D/b7'),
#   ('D:min', 'E', 'F:7'),
#   ('B:dim7/b9', 'C:dim7/2', 'G:7'),
#   ('Eb:aug', 'F#:dim', 'G:dim'),
#   ('A:min/5', 'Bb:maj7', 'F'),
#   ('A:7', 'A:min', 'B:min'),
#   ('A/4', 'D/3', 'F#:min'),
#   ('E:min(2)', 'F:7', 'N'),
#   ('A:dim/b5', 'A:min', 'E'),
#   ('A/b3', 'D:sus4(b7)', 'G'),
#   ('A:dim/b5', 'D:(1)', 'G#'),
#   ('A:min/5', 'C/5', 'F'),
#   ('C:dim7', 'C:dim7/2', 'G'),
#   ('F#:min6', 'F#:min7', 'F:min'),
#   ('Bb:min', 'Eb', 'F/5'),
#   ('A:min9', 'F#:min6', 'F#:min7'),
#   ('Bb:dim7/5', 'D/5', 'G:minmaj7/5'),
#   ('A:min', 'F#:min7', 'G:min7'),
#   ('B:dim7/b9', 'C:dim7/2', 'G:9'),
#   ('A/3', 'A:min6', 'A:min7'),
#   ('Bb:7', 'G:min', 'G:min/b7'),
#   ('A:min7', 'D', 'D:(1)'),
#   ('Ab', 'D:sus4(b7)', 'G'),
#   ('D:7', 'Eb:7', 'F:min'),
#   ('D/5', 'D:7', 'F'),
#   ('A:min', 'C:dim7', 'E/5'),
#   ('E:7', 'F/5', 'F/6'),
#   ('A:min7', 'D:sus4', 'D:sus4(9)'),
#   ('Bb:maj7', 'C:7', 'D:sus4(b7)'),
#   ('Bb:7', 'D:min7', 'E:min'),
#   ('Db', 'Eb', 'G'),
#   ('A:min', 'C/9', 'D/5'),
#   ('A:7', 'E', 'E/2'),
#   ('A:min/b7', 'A:min7', 'D'),
#   ('D:min', 'F#:min6', 'G'),
#   ('E/4', 'F:maj6', 'G:min7'),
#   ('Bb:maj7', 'Bb:min', 'Eb'),
#   ('B:min7', 'F#:min7', 'F:dim'),
#   ('A:min9', 'B', 'D/3'),
#   ('A:min7', 'D#', 'F:7'),
#   ('A', 'A/2', 'D:(1)'),
#   ('A', 'Bb:min/b3', 'D:maj7'),
#   ('A:min7', 'Bb:sus4(9)', 'N'),
#   ('E/2', 'F', 'G#'),
#   ('A', 'A:min', 'B:min'),
#   ('A:min/6', 'A:min/b7', 'E/5'),
#   ('A/4', 'A:min', 'N'),
#   ('A:7', 'B', 'G:9'),
#   ('B:dim7/b9', 'F/5', 'F/6'),
#   ('C', 'E/3', 'E/4'),
#   ('Bb/5', 'D/5', 'Eb'),
#   ('A:min7', 'Db', 'N'),
#   ('Bb:maj7', 'C/3', 'C:7/3'),
#   ('Ab:maj9', 'Bb:7', 'D'),
#   ('A:min', 'E:7', 'Eb:7'),
#   ('E/2', 'E/3', 'G:9'),
#   ('D', 'E/2', 'G:7'),
#   ('D:sus4', 'E:(1)', 'N'),
#   ('A:min', 'D', 'D:7'),
#   ('Ab:maj9', 'Bb', 'D:min'),
#   ('A:min/b7', 'E:7', 'F:7'),
#   ('F#:min6', 'F:min', 'N'),
#   ('A', 'C#:min', 'D:(1)'),
#   ('A', 'Eb', 'G:min'),
#   ('A:min/6', 'A:min/b7', 'E/3'),
#   ('B', 'Bb', 'Bb:sus2(b7)'),
#   ('C/3', 'Eb', 'F'),
#   ('C/9', 'Eb', 'F:dim'),
#   ('A:7', 'A:min9', 'C:7'),
#   ('Bb/5', 'C/5', 'F'),
#   ('A:7', 'Bb/5', 'Eb'),
#   ('C/3', 'D:7', 'Eb:7'),
#   ('B:dim7/b9', 'Bb:dim7/5', 'C/5'),
#   ('A:min/5', 'Eb:7', 'F'),
#   ('A:min/6', 'A:min/b7', 'D#'),
#   ('A', 'C:7', 'D:maj7'),
#   ('Ab', 'C', 'D:sus4(9)'),
#   ('A/3', 'E/2', 'E/3'),
#   ('C', 'C:sus4', 'F:dim'),
#   ('C:sus4', 'F/3', 'G'),
#   ('E:aug', 'Eb', 'G:min/5'),
#   ('A/3', 'A/b3', 'Bb:sus4(9)'),
#   ('A:min6', 'A:min7', 'E:7'),
#   ('C:dim7', 'C:dim7/2', 'G:min/b7'),
#   ('A:min', 'A:min6', 'C:7'),
#   ('A:min7', 'A:min9', 'C/5'),
#   ('Bb', 'F:7(b9)', 'G:min'),
#   ('Ab:maj9', 'Bb:dim7/5', 'N'),
#   ('A/3', 'A/b3', 'G:minmaj7/5'),
#   ('Bb:sus2(b7)', 'C/3', 'Eb'),
#   ('Bb:maj7', 'D:min', 'E:min(9)'),
#   ('Bb', 'D:sus4', 'G:min'),
#   ('D/5', 'D:7', 'G/3'),
#   ('A', 'G:minmaj7/5', 'N'),
#   ('C/3', 'C:sus4', 'D:min'),
#   ('Ab', 'D/3', 'G:dim'),
#   ('A:min', 'D:maj7', 'F/3'),
#   ('C:7', 'E/4', 'G:9'),
#   ('A:min', 'E', 'G:dim/b3'),
#   ('D:sus4(b7)', 'F/5', 'G'),
#   ('A:min9', 'C', 'G:7'),
#   ('A:min', 'D:min7', 'E/4'),
#   ('A:min7', 'C:7/3', 'N'),
#   ('A', 'E:aug', 'F'),
#   ('A', 'A:min/b7', 'G#'),
#   ('Bb', 'F#:dim', 'F:7'),
#   ('Bb', 'C:dim7', 'D:(1)'),
#   ('F#:dim', 'F/b7', 'G:dim'),
#   ('Ab', 'F:maj6', 'G:dim'),
#   ('Ab', 'C', 'F#:dim'),
#   ('B:min7', 'F/5', 'G/3'),
#   ('A', 'C#:min', 'G:9'),
#   ('Ab:min', 'D:min7', 'G:min7'),
#   ('Bb:dim7/5', 'C:dim7', 'F/6'),
#   ('C/3', 'D:sus4', 'G:min/b7'),
#   ('A', 'A/2', 'F'),
#   ('Bb:dim7/7', 'D:7', 'G:7'),
#   ('A:dim7', 'D:dim7', 'F/b7'),
#   ('A:min7', 'E:7', 'F#:dim/b3'),
#   ('A/4', 'Eb', 'G/5'),
#   ('D:min', 'E/3', 'E:min'),
#   ('E:min(2)', 'G:minmaj7/b3', 'N'),
#   ('B:min', 'D/5', 'D:7'),
#   ('Bb:min', 'E/2', 'E/3'),
#   ('A:7', 'E:min(9)', 'G/3'),
#   ('A', 'B:min', 'G#'),
#   ('A:min/6', 'A:min/b7', 'Bb:maj7'),
#   ('C/9', 'D/5', 'E:min(9)'),
#   ('A:min', 'D/3', 'F/3'),
#   ('D:min', 'E', 'F/6'),
#   ('A:min', 'F/6', 'F:min'),
#   ('D', 'D/b7', 'G:dim/b3'),
#   ('D/5', 'G:min', 'G:minmaj7/5'),
#   ('D/5', 'G:min', 'G:min/b7'),
#   ('Ab', 'C/5', 'Db'),
#   ('C/9', 'D:min', 'E:min'),
#   ('A', 'Ab:maj7', 'D:7'),
#   ('E', 'E/b7', 'F/3'),
#   ('D', 'D:7', 'D:min7'),
#   ('D/5', 'Eb:aug', 'G:minmaj7/5'),
#   ('D', 'F', 'G:min/4'),
#   ('D#', 'G:maj7/3', 'G:minmaj7/5'),
#   ('C:(1)', 'D', 'F'),
#   ('A:min7', 'Bb:min/b3', 'G'),
#   ('C', 'F#:dim', 'F:7'),
#   ('F', 'G:9', 'G:min7'),
#   ('A:min6', 'A:min7', 'D#:dim'),
#   ('B:dim7/b9', 'D/3', 'F#:min'),
#   ('A/b3', 'B:min7', 'F#:min7'),
#   ('B:min7', 'C/3', 'G:min'),
#   ('C', 'F:7', 'G:9'),
#   ('A:min', 'E', 'G:7'),
#   ('Ab', 'F:7', 'G'),
#   ('B:min7', 'F:7', 'G'),
#   ('B', 'D:dim7', 'G:9'),
#   ('D:sus4(b7)', 'Eb:aug', 'G:dim/b3'),
#   ('Ab', 'F:maj6', 'N'),
#   ('E:aug', 'F:7(b9)', 'G'),
#   ('C:maj(4)', 'F', 'F:min'),
#   ('C/3', 'E', 'E:7'),
#   ('A/4', 'F#:min7', 'G/5'),
#   ('C:dim7', 'F:maj6', 'G:min7'),
#   ('A/b3', 'A:7', 'Bb'),
#   ('B:min', 'D#:dim', 'E'),
#   ('D:min', 'F#:min', 'F/3'),
#   ('A:min7', 'Bb:7', 'D:7'),
#   ('C/3', 'C:7', 'G:9'),
#   ('C:min', 'E/5', 'G/3'),
#   ('Ab:maj9', 'D:min', 'G'),
#   ('A:dim7', 'Db', 'F:7(b9)'),
#   ('A', 'D/b7', 'G#'),
#   ('A', 'A:min9', 'B'),
#   ('C:sus4', 'E/4', 'G'),
#   ('A:7', 'A:min', 'F:7(b9)'),
#   ('A:min', 'C:sus4', 'G:min7'),
#   ('E/3', 'E/4', 'E/b6'),
#   ('D:7', 'Eb:7', 'F'),
#   ('C', 'Eb', 'F:7'),
#   ('A:dim/b5', 'Bb', 'F:7'),
#   ('Db', 'G:9', 'G:min7'),
#   ('F#:dim', 'F:dim', 'G:min/b7'),
#   ('A:min/6', 'C:sus4', 'F'),
#   ('C/3', 'D#:dim', 'D:min'),
#   ('A:7', 'D:sus4(9)', 'D:sus4(b7)'),
#   ('A', 'A:min', 'D:sus4(9)'),
#   ('A:dim/b5', 'C', 'C:sus4'),
#   ('A:7', 'G/3', 'G/5'),
#   ('E/5', 'G:9', 'G:min7'),
#   ('D/5', 'F:min', 'G:minmaj7/b3'),
#   ('D', 'F/5', 'G#'),
#   ('A:min7', 'A:min9', 'E:min(2)'),
#   ('A:dim7', 'D', 'G:7'),
#   ('A:dim7', 'A:min/b7', 'D:dim7'),
#   ('A:min7', 'D:sus4', 'E/4'),
#   ('A/4', 'F:7', 'G/5'),
#   ('C:sus4', 'Eb', 'G:min/5'),
#   ('A/3', 'D/5', 'D/b7'),
#   ('Ab:maj9', 'Bb:7', 'F/5'),
#   ('F:7', 'F:maj6', 'G:min/4'),
#   ('A', 'E/4', 'E/b6'),
#   ('A:dim7', 'D:dim7', 'D:sus4(9)'),
#   ('A:min/6', 'D:min7', 'G:min7'),
#   ('A/b3', 'A:min7', 'G'),
#   ('C/7', 'Eb', 'F:min'),
#   ('F', 'F/b7', 'G:min/b7'),
# ...
#   ('A', 'F#:min', 'G#'),
#   ('A', 'F#:min', 'N'),
#   ('A', 'F:7(b9)', 'G'),
#   ('A/3', 'B:min7', 'D'),
#   ('A/3', 'D', 'D#'),
#   ('A/3', 'D', 'D#:dim'),
#   ('A/3', 'D', 'D/b7'),
#   ('A/3', 'D', 'D:7'),
#   ('A/3', 'D', 'F'),
#   ('A/3', 'D', 'G:7'),
#   ('A:7', 'A:min', 'C'),
#   ('A:7', 'A:min', 'D:min'),
#   ('A:7', 'A:min', 'F'),
#   ('A:7', 'A:min', 'F:7'),
#   ('A:7', 'A:min', 'G'),
#   ('A:7', 'Bb', 'Bb:sus4(9)'),
#   ('A:7', 'Bb', 'C'),
#   ('A:7', 'Bb', 'Eb'),
#   ('A:7', 'Bb', 'F'),
#   ('A:7', 'Bb', 'F:min'),
#   ('A:7', 'C', 'G/3'),
#   ('A:min', 'A:min/5', 'F'),
#   ('A:min', 'A:min/b7', 'C'),
#   ('A:min', 'A:min/b7', 'D:min'),
#   ('A:min', 'A:min/b7', 'F'),
#   ('A:min', 'A:min/b7', 'F:7'),
#   ('A:min', 'A:min/b7', 'G'),
#   ('A:min', 'A:min7', 'C'),
#   ('A:min', 'A:min7', 'G'),
#   ('A:min', 'B', 'C'),
#   ('A:min', 'Bb', 'Bb:sus4(9)'),
#   ('A:min', 'Bb', 'Eb'),
#   ('A:min', 'Bb:min/b3', 'D:min'),
#   ('A:min', 'C', 'C/7'),
#   ('A:min', 'C', 'C:min'),
#   ('A:min', 'C', 'Db'),
#   ('A:min', 'C', 'F/3'),
#   ('A:min', 'C/3', 'F'),
#   ('A:min', 'C:sus4', 'G'),
#   ('A:min', 'D', 'E'),
#   ('A:min', 'D', 'G'),
#   ('A:min', 'D', 'N'),
#   ('A:min', 'D:min', 'F/3'),
#   ('A:min', 'D:min', 'F:min'),
#   ('A:min', 'D:min', 'G:min'),
#   ('A:min', 'E:7', 'F:7'),
#   ('A:min', 'Eb', 'N'),
#   ('A:min', 'F', 'F/3'),
#   ('A:min', 'F', 'F/b7'),
#   ('A:min', 'F', 'F:min'),
#   ('A:min', 'F', 'G#'),
#   ('A:min', 'F', 'G:min7'),
#   ('A:min', 'F/3', 'F:7'),
#   ('A:min', 'F/3', 'G'),
#   ('A:min', 'F:7', 'F:min'),
#   ('A:min', 'F:7', 'G:min7'),
#   ('A:min', 'F:7(b9)', 'G'),
#   ('A:min', 'G', 'G:min7'),
#   ('A:min', 'G:7', 'N'),
#   ('A:min/5', 'Bb', 'F'),
#   ('A:min/5', 'C', 'F'),
#   ('A:min/5', 'D:min', 'F'),
#   ('A:min/5', 'F', 'G'),
#   ('A:min/5', 'F', 'G:min'),
#   ('A:min/5', 'F', 'N'),
#   ('A:min7', 'Bb', 'C'),
#   ('A:min7', 'Bb:min', 'C'),
#   ('A:min7', 'C', 'C#:dim'),
#   ('A:min7', 'C', 'C/5'),
#   ('A:min7', 'C', 'D:min'),
#   ('A:min7', 'C', 'E'),
#   ('A:min7', 'C', 'F'),
#   ('A:min7', 'C', 'F:min'),
#   ('A:min7', 'C', 'G:min/4'),
#   ('A:min7', 'C', 'G:min7'),
#   ('A:min7', 'E', 'G'),
#   ('A:min7', 'E', 'N'),
#   ('A:min7', 'Eb', 'N'),
#   ('A:min7', 'F', 'G'),
#   ('A:min7', 'F', 'N'),
#   ('A:min7', 'F:min', 'G'),
#   ('A:min7', 'G:7', 'N'),
#   ('Ab', 'Bb/5', 'Eb'),
#   ('Ab', 'Bb:min', 'Eb'),
#   ('Ab', 'C', 'Eb'),
#   ('Ab', 'D', 'N'),
#   ('Ab', 'E', 'N'),
#   ('Ab', 'Eb', 'F:dim'),
#   ('Ab', 'Eb', 'F:min'),
#   ('Ab', 'Eb', 'G:min/5'),
#   ('Ab', 'F', 'N'),
#   ('Ab', 'G', 'N'),
#   ('Ab', 'G:7', 'N'),
#   ('Ab:maj7', 'Bb:7', 'D:min'),
#   ('Ab:maj7', 'Bb:7', 'D:min7'),
#   ('Ab:maj7', 'Bb:7', 'Eb'),
#   ('Ab:maj9', 'Bb', 'Bb:sus4(9)'),
#   ('Ab:maj9', 'Bb', 'C'),
#   ('Ab:maj9', 'Bb', 'Eb'),
#   ('Ab:maj9', 'Bb', 'F'),
#   ('Ab:maj9', 'Bb', 'F:min'),
#   ('Ab:min', 'Bb/5', 'Eb'),
#   ('Ab:min', 'Bb:min', 'Eb'),
#   ('Ab:min', 'Eb', 'F:dim'),
#   ('Ab:min', 'Eb', 'F:min'),
#   ('Ab:min', 'Eb', 'G:min/5'),
#   ('B', 'Bb', 'C'),
#   ('B', 'Bb:min', 'C'),
#   ('B', 'C', 'C#:dim'),
#   ('B', 'C', 'C/5'),
#   ('B', 'C', 'D'),
#   ('B', 'C', 'D:min'),
#   ('B', 'C', 'F'),
#   ('B', 'C', 'F:min'),
#   ('B', 'C', 'G'),
#   ('B', 'C', 'G/3'),
#   ('B', 'C', 'G:min/4'),
#   ('B', 'C', 'G:min7'),
#   ('B', 'C', 'N'),
#   ('B:min', 'C#:min', 'D'),
#   ('B:min', 'C#:min', 'F#:min'),
#   ('B:min7', 'C', 'D'),
#   ('B:min7', 'C#:dim', 'D'),
#   ('B:min7', 'C#:min', 'D'),
#   ('B:min7', 'C/9', 'D'),
#   ('B:min7', 'D', 'D:sus4(9)'),
#   ('B:min7', 'D', 'E'),
#   ('B:min7', 'D', 'N'),
#   ('Bb', 'Bb/5', 'Eb'),
#   ('Bb', 'Bb:min', 'Eb'),
#   ('Bb', 'Bb:sus2(b7)', 'Bb:sus4(9)'),
#   ('Bb', 'Bb:sus2(b7)', 'C'),
#   ('Bb', 'Bb:sus2(b7)', 'F'),
#   ('Bb', 'Bb:sus2(b7)', 'F:min'),
#   ('Bb', 'Bb:sus4(9)', 'N'),
#   ('Bb', 'C', 'C/7'),
#   ('Bb', 'C', 'C:min'),
#   ('Bb', 'C', 'Db'),
#   ('Bb', 'C/3', 'F'),
#   ('Bb', 'D:7', 'F:7'),
#   ('Bb', 'Eb', 'F:dim'),
#   ('Bb', 'Eb', 'G:min/5'),
#   ('Bb', 'F', 'F/b7'),
#   ('Bb', 'F', 'G#'),
#   ('Bb', 'F:7', 'G:7'),
#   ('Bb/5', 'Eb', 'N'),
#   ('Bb:min', 'C', 'C/7'),
#   ('Bb:min', 'C', 'C:min'),
#   ('Bb:min', 'C', 'Db'),
#   ('Bb:min', 'C', 'F:7'),
#   ('Bb:min', 'Eb', 'N'),
#   ('Bb:min/b3', 'C', 'D:min'),
#   ('Bb:min/b3', 'D:min', 'F'),
#   ('Bb:min/b3', 'D:min', 'G:9'),
#   ('Bb:min/b3', 'D:min', 'G:min7'),
#   ('C', 'C#:dim', 'C/7'),
#   ('C', 'C#:dim', 'C:min'),
#   ('C', 'C#:dim', 'Db'),
#   ('C', 'C#:dim', 'F:7'),
#   ('C', 'C/3', 'F'),
#   ('C', 'C/5', 'C/7'),
#   ('C', 'C/5', 'C:min'),
#   ('C', 'C/5', 'Db'),
#   ('C', 'C/5', 'F:7'),
#   ('C', 'C/7', 'D'),
#   ('C', 'C/7', 'D:min'),
#   ('C', 'C/7', 'E'),
#   ('C', 'C/7', 'F'),
#   ('C', 'C/7', 'F:min'),
#   ('C', 'C/7', 'G'),
#   ('C', 'C/7', 'G/3'),
#   ('C', 'C/7', 'G:min/4'),
#   ('C', 'C/7', 'G:min7'),
#   ('C', 'C/7', 'N'),
#   ('C', 'C:maj(4)', 'G:min7'),
#   ('C', 'C:min', 'D'),
#   ('C', 'C:min', 'D:min'),
#   ('C', 'C:min', 'E'),
#   ('C', 'C:min', 'F'),
#   ('C', 'C:min', 'F:min'),
#   ('C', 'C:min', 'G'),
#   ('C', 'C:min', 'G:min/4'),
#   ('C', 'C:min', 'G:min7'),
#   ('C', 'C:min', 'N'),
#   ('C', 'D', 'D#'),
#   ('C', 'D', 'D#:dim'),
#   ('C', 'D', 'D:7'),
#   ('C', 'D', 'Db'),
#   ('C', 'D', 'F:7'),
#   ('C', 'D:min', 'Db'),
#   ('C', 'D:min', 'F:7'),
#   ('C', 'Db', 'E'),
#   ('C', 'Db', 'F:min'),
#   ('C', 'Db', 'G'),
#   ('C', 'Db', 'G/3'),
#   ('C', 'Db', 'G:min/4'),
#   ('C', 'Db', 'G:min7'),
#   ('C', 'Db', 'N'),
#   ('C', 'E', 'E/2'),
#   ('C', 'E', 'E/b7'),
#   ('C', 'E', 'E:7'),
#   ('C', 'E', 'F:7'),
#   ('C', 'E:(1)', 'N'),
#   ('C', 'Eb', 'G:min7'),
#   ('C', 'F', 'F/b7'),
#   ('C', 'F', 'G#'),
#   ('C', 'F:7', 'F:min'),
#   ('C', 'F:7', 'G/3'),
#   ('C', 'F:7', 'G:min/4'),
#   ('C', 'F:7', 'G:min7'),
#   ('C', 'F:7', 'N'),
#   ('C', 'F:7(b9)', 'G'),
#   ('C', 'F:maj6', 'G:min7'),
#   ('C', 'G/3', 'G:dim/b3'),
#   ('C#:dim', 'D', 'D#'),
#   ('C#:dim', 'D', 'D#:dim'),
#   ('C#:dim', 'D', 'D/b7'),
#   ('C#:dim', 'D', 'D:7'),
#   ('C#:dim', 'D', 'F'),
#   ('C#:dim', 'D', 'G:7'),
#   ('C#:min', 'D', 'D#'),
#   ('C#:min', 'D', 'D#:dim'),
#   ('C#:min', 'D', 'D/b7'),
#   ('C#:min', 'D', 'D:7'),
#   ('C#:min', 'D', 'F'),
#   ('C#:min', 'D', 'G:7'),
#   ('C#:min', 'D:min', 'F#:min'),
#   ('C#:min', 'D:min7', 'F#:min'),
#   ('C/3', 'F', 'G'),
#   ('C/3', 'F', 'G:min'),
#   ('C/3', 'F', 'N'),
#   ('C/9', 'D', 'D#'),
#   ('C/9', 'D', 'D#:dim'),
#   ('C/9', 'D', 'D/5'),
#   ('C/9', 'D', 'D/b7'),
#   ('C/9', 'D', 'D:7'),
#   ('C/9', 'D', 'F'),
#   ('C/9', 'D', 'G/5'),
#   ('C/9', 'D', 'G:7'),
#   ('C:(1)', 'D', 'N'),
#   ('C:(1)', 'E', 'N'),
#   ('C:(1)', 'Eb', 'N'),
#   ('C:(1)', 'F', 'N'),
#   ('C:(1)', 'G', 'N'),
#   ('C:(1)', 'G:7', 'N'),
#   ('C:7', 'D:min', 'G:9'),
#   ('C:maj(4)', 'D:min', 'G:min7'),
#   ('C:sus4', 'D:7', 'G'),
#   ('C:sus4', 'E', 'G'),
#   ('C:sus4', 'F', 'G'),
#   ('C:sus4', 'F:min', 'G'),
#   ('C:sus4', 'G', 'N'),
#   ('D', 'D#', 'D:sus4(9)'),
#   ('D', 'D#', 'F#:min'),
#   ('D', 'D#', 'N'),
#   ('D', 'D#:dim', 'D:sus4(9)'),
#   ('D', 'D#:dim', 'E'),
#   ('D', 'D#:dim', 'F#:min'),
#   ('D', 'D#:dim', 'N'),
#   ('D', 'D/b7', 'D:sus4(9)'),
#   ('D', 'D/b7', 'E'),
#   ('D', 'D/b7', 'F#:min'),
#   ('D', 'D/b7', 'N'),
#   ('D', 'D:7', 'D:sus4(9)'),
#   ('D', 'D:7', 'E'),
#   ('D', 'D:7', 'F#:min'),
#   ('D', 'D:min', 'F#:min'),
#   ('D', 'D:min', 'G:min7'),
#   ('D', 'D:min7', 'F#:min'),
#   ('D', 'D:sus4(9)', 'F'),
#   ('D', 'D:sus4(9)', 'G:7'),
#   ('D', 'E', 'E/2'),
#   ('D', 'E', 'E/b7'),
#   ('D', 'E', 'E:7'),
#   ('D', 'E', 'F'),
#   ('D', 'E', 'G:7'),
#   ('D', 'E:(1)', 'N'),
#   ('D', 'E:min(2)', 'N'),
#   ('D', 'F', 'F#:min'),
#   ('D', 'F#:min', 'G:7'),
#   ('D', 'F:min', 'G'),
#   ('D:7', 'E:7', 'F:7'),
#   ('D:7', 'F:7', 'G:maj7/3'),
#   ('D:7', 'F:7', 'N'),
#   ('D:7', 'F:7(b9)', 'G'),
#   ('D:7', 'G', 'G:7'),
#   ('D:7', 'G', 'G:maj7/3'),
#   ('D:min', 'E', 'F'),
#   ('D:min', 'E', 'G:9'),
#   ('D:min', 'E', 'G:min7'),
#   ('D:min', 'Eb', 'G:min7'),
#   ('D:min', 'F', 'F/b7'),
#   ('D:min', 'F', 'F:7'),
#   ('D:min', 'F', 'G#'),
#   ('D:min', 'F:maj6', 'G:min7'),
#   ('D:min', 'G', 'G:9'),
#   ('D:min', 'G', 'G:min7'),
#   ('D:min', 'G:9', 'G:min'),
#   ('D:min', 'G:9', 'N'),
#   ('D:min', 'G:min', 'G:min7'),
#   ('D:min', 'G:min7', 'N'),
#   ('E', 'E/2', 'G'),
#   ('E', 'E/2', 'N'),
#   ('E', 'E/b7', 'G'),
#   ('E', 'E/b7', 'N'),
#   ('E', 'E:(1)', 'N'),
#   ('E', 'E:7', 'G'),
#   ('E', 'E:7', 'N'),
#   ('E', 'E:min(2)', 'N'),
#   ('E', 'F:7(b9)', 'G'),
#   ('E:(1)', 'Eb', 'N'),
#   ('E:(1)', 'G', 'N'),
#   ('E:(1)', 'G:7', 'N'),
#   ('E:7', 'F:7', 'G:7'),
#   ('E:min(2)', 'Eb', 'N'),
#   ('E:min(2)', 'F', 'N'),
#   ('E:min(2)', 'G', 'N'),
#   ('E:min(2)', 'G:7', 'N'),
#   ('Eb', 'F:dim', 'N'),
#   ('Eb', 'G:min/5', 'N'),
#   ('F', 'F/b7', 'G'),
#   ('F', 'F/b7', 'G:min'),
#   ('F', 'F/b7', 'N'),
#   ('F', 'F:7', 'G:min'),
#   ('F', 'F:7', 'N'),
#   ('F', 'F:7(b9)', 'G'),
#   ('F', 'G#', 'G:min'),
#   ('F', 'G#', 'N'),
#   ('F', 'G:min', 'G:min/b7'),
#   ('F:7', 'G', 'G:7'),
#   ('F:7', 'G:7', 'G:min7'),
#   ('F:7(b9)', 'F:min', 'G'),
#   ('F:7(b9)', 'G', 'N'),
#   ('G:7', 'G:min7', 'N')},
#  '120C': {('A', 'A:min', 'E'),
#   ('A', 'D', 'D:7'),
#   ('A', 'D', 'G#'),
#   ('A', 'E', 'E:7'),
#   ('A', 'E:aug', 'F#:min'),
#   ('A', 'Eb', 'N'),
#   ('A', 'G', 'G#'),
#   ('A:min', 'Bb', 'F:7'),
#   ('A:min', 'Bb', 'F:min'),
#   ('A:min', 'D:min', 'E'),
#   ('A:min', 'D:min', 'N'),
#   ('A:min7', 'C', 'D'),
#   ('A:min7', 'C', 'G/3'),
#   ('A:min7', 'D', 'N'),
#   ('A:min7', 'D:7', 'G'),
#   ('Ab', 'C', 'N'),
#   ('B', 'C', 'E'),
#   ('B:min7', 'D', 'F#:min'),
#   ('Bb', 'Bb:sus2(b7)', 'Eb'),
#   ('Bb', 'C', 'F:7'),
#   ('Bb', 'F', 'F:7'),
#   ('C', 'C:(1)', 'N'),
#   ('C', 'C:min', 'G/3'),
#   ('C', 'C:sus4', 'G'),
#   ('C', 'D', 'D/b7'),
#   ('C', 'D', 'G:7'),
#   ('C', 'D:min', 'G:min'),
#   ('C', 'Db', 'F'),
#   ('C', 'E:min(2)', 'N'),
#   ('C', 'F:7', 'G'),
#   ('C', 'F:7', 'G:7'),
#   ('C/3', 'D:min', 'F'),
#   ('D', 'D#', 'E'),
#   ('D', 'D:7', 'G'),
#   ('D', 'D:7', 'N'),
#   ('D', 'F', 'G'),
#   ('E:(1)', 'F', 'N'),
#   ('Eb', 'F:min', 'N'),
#   ('F', 'F:7', 'G'),
#   ('F', 'G', 'G#')},
#  '120D': {('A:min7', 'D:7', 'F:7'),
#   ('Ab', 'Db', 'Eb'),
#   ('Bb', 'C', 'G:min'),
#   ('C', 'G:7', 'G:min7'),
#   ('D:7', 'G:7', 'N'),
#   ('D:min', 'D:min7', 'G:min7'),
#   ('D:min', 'E', 'G'),
#   ('D:min', 'E', 'N'),
#   ('D:min', 'G', 'N')},
#  '120U': {('A', 'D:min', 'N'),
#   ('A:min', 'E', 'N'),
#   ('A:min7', 'C', 'G'),
#   ('A:min7', 'C', 'N'),
#   ('A:min7', 'G', 'N'),
#   ('Bb', 'F:min', 'N'),
#   ('C', 'F', 'F:7')},
#  '201': {('A', 'A/3', 'D'),
#   ('A', 'Bb', 'C'),
#   ('A', 'Bb:min', 'C'),
#   ('A', 'C', 'C#:dim'),
#   ('A', 'C', 'C/5'),
#   ('A', 'C', 'F'),
#   ('A', 'C', 'F#:min'),
#   ('A', 'C', 'F:min'),
#   ('A', 'C', 'G/3'),
#   ('A', 'C', 'G:min/4'),
#   ('A', 'C', 'G:min7'),
#   ('A', 'C#:dim', 'D'),
#   ('A', 'C/9', 'D'),
#   ('A', 'D', 'D:min'),
#   ('A', 'D', 'D:sus4(9)'),
#   ('A', 'D:min', 'F'),
#   ('A', 'D:min', 'G:9'),
#   ('A', 'D:min', 'G:min7'),
#   ('A', 'E', 'F#:min'),
#   ('A', 'F', 'G'),
#   ('A', 'F#:min', 'G'),
#   ('A', 'F:min', 'G'),
#   ('A/3', 'C#:dim', 'D'),
#   ('A/3', 'C#:min', 'D'),
#   ('A/3', 'C/9', 'D'),
#   ('A/3', 'D', 'D:sus4(9)'),
#   ('A/3', 'D', 'E'),
#   ('A/3', 'D', 'F#:min'),
#   ('A/3', 'D', 'N'),
#   ('A:min', 'Bb:min', 'C'),
#   ('A:min', 'C', 'C#:dim'),
#   ('A:min', 'C', 'C/5'),
#   ('A:min', 'C', 'D'),
#   ('A:min', 'C', 'G/3'),
#   ('A:min', 'C', 'G:min/4'),
#   ('A:min', 'D:7', 'F:7'),
#   ('A:min', 'D:7', 'G'),
#   ('A:min', 'D:min', 'F:7'),
#   ('A:min', 'D:min', 'G:9'),
#   ('A:min', 'F', 'G:min'),
#   ('A:min', 'F:7', 'G:7'),
#   ('Ab', 'Ab:min', 'Eb'),
#   ('Ab', 'Bb', 'Eb'),
#   ('Ab:min', 'Bb', 'Eb'),
#   ('Ab:min', 'Eb', 'N'),
#   ('Bb', 'Bb:min', 'C'),
#   ('Bb', 'Bb:sus4(9)', 'C'),
#   ('Bb', 'Bb:sus4(9)', 'Eb'),
#   ('Bb', 'Bb:sus4(9)', 'F'),
#   ('Bb', 'Bb:sus4(9)', 'F:min'),
#   ('Bb', 'C', 'C#:dim'),
#   ('Bb', 'C', 'C/5'),
#   ('Bb', 'C', 'D'),
#   ('Bb', 'C', 'D:min'),
#   ('Bb', 'C', 'E'),
#   ('Bb', 'C', 'Eb'),
#   ('Bb', 'C', 'G'),
#   ('Bb', 'C', 'G/3'),
#   ('Bb', 'C', 'G:min/4'),
#   ('Bb', 'C', 'G:min7'),
#   ('Bb', 'D:min', 'F'),
#   ('Bb', 'Eb', 'F'),
#   ('Bb', 'F', 'F:min'),
#   ('Bb', 'F', 'G'),
#   ('Bb', 'F:min', 'G'),
#   ('Bb:min', 'C', 'C#:dim'),
#   ('Bb:min', 'C', 'C/5'),
#   ('Bb:min', 'C', 'D'),
#   ('Bb:min', 'C', 'D:min'),
#   ('Bb:min', 'C', 'E'),
#   ('Bb:min', 'C', 'F'),
#   ('Bb:min', 'C', 'F:min'),
#   ('Bb:min', 'C', 'G'),
#   ('Bb:min', 'C', 'G/3'),
#   ('Bb:min', 'C', 'G:min/4'),
#   ('Bb:min', 'C', 'G:min7'),
#   ('Bb:min', 'C', 'N'),
#   ('C', 'C#:dim', 'C/5'),
#   ('C', 'C#:dim', 'D:min'),
#   ('C', 'C#:dim', 'E'),
#   ('C', 'C#:dim', 'F'),
#   ('C', 'C#:dim', 'F:min'),
#   ('C', 'C#:dim', 'G'),
#   ('C', 'C#:dim', 'G/3'),
#   ('C', 'C#:dim', 'G:min/4'),
#   ('C', 'C#:dim', 'G:min7'),
#   ('C', 'C#:dim', 'N'),
#   ('C', 'C#:min', 'D'),
#   ('C', 'C/5', 'D'),
#   ('C', 'C/5', 'D:min'),
#   ('C', 'C/5', 'E'),
#   ('C', 'C/5', 'F'),
#   ('C', 'C/5', 'F:min'),
#   ('C', 'C/5', 'G'),
#   ('C', 'C/5', 'G/3'),
#   ('C', 'C/5', 'G:min/4'),
#   ('C', 'C/5', 'G:min7'),
#   ('C', 'C/5', 'N'),
#   ('C', 'C/9', 'D'),
#   ('C', 'D', 'D:min'),
#   ('C', 'D', 'D:sus4(9)'),
#   ('C', 'D', 'F#:min'),
#   ('C', 'D', 'F:min'),
#   ('C', 'D', 'G/3'),
#   ('C', 'D', 'G:min/4'),
#   ('C', 'D:7', 'G'),
#   ('C', 'D:min', 'F:min'),
#   ('C', 'D:min', 'G/3'),
#   ('C', 'D:min', 'G:9'),
#   ('C', 'D:min', 'G:min/4'),
#   ('C', 'E', 'F'),
#   ('C', 'E', 'F:min'),
#   ('C', 'E', 'G/3'),
#   ('C', 'E', 'G:min/4'),
#   ('C', 'E', 'G:min7'),
#   ('C', 'Eb', 'N'),
#   ('C', 'F', 'F:min'),
#   ('C', 'F', 'G/3'),
#   ('C', 'F', 'G:min/4'),
#   ('C', 'F', 'G:min7'),
#   ('C', 'F:min', 'G/3'),
#   ('C', 'F:min', 'G:min/4'),
#   ('C', 'F:min', 'G:min7'),
#   ('C', 'G', 'G:min/4'),
#   ('C', 'G', 'G:min7'),
#   ('C', 'G/3', 'G:min/4'),
#   ('C', 'G/3', 'G:min7'),
#   ('C', 'G/3', 'N'),
#   ('C', 'G:min/4', 'G:min7'),
#   ('C', 'G:min/4', 'N'),
#   ('C', 'G:min7', 'N'),
#   ('C#:dim', 'C#:min', 'D'),
#   ('C#:dim', 'C/9', 'D'),
#   ('C#:dim', 'D', 'D:sus4(9)'),
#   ('C#:dim', 'D', 'E'),
#   ('C#:dim', 'D', 'F#:min'),
#   ('C#:dim', 'D', 'N'),
#   ('C#:min', 'C/9', 'D'),
#   ('C#:min', 'D', 'D:sus4(9)'),
#   ('C#:min', 'D', 'E'),
#   ('C#:min', 'D', 'N'),
#   ('C/9', 'D', 'D:sus4(9)'),
#   ('C/9', 'D', 'E'),
#   ('C/9', 'D', 'F#:min'),
#   ('C/9', 'D', 'N'),
#   ('D', 'D:sus4(9)', 'E'),
#   ('D', 'D:sus4(9)', 'F#:min'),
#   ('D', 'D:sus4(9)', 'N'),
#   ('D', 'E', 'F#:min'),
#   ('D', 'Eb', 'N'),
#   ('D', 'F#:min', 'N'),
#   ('D:7', 'E', 'G'),
#   ('D:7', 'F', 'G'),
#   ('D:7', 'F:min', 'G'),
#   ('D:min', 'F', 'G:9'),
#   ('D:min', 'F', 'G:min7'),
#   ('E', 'Eb', 'N'),
#   ('E', 'F', 'G'),
#   ('E', 'F', 'N'),
#   ('E', 'F:min', 'G'),
#   ('E', 'G:7', 'N'),
#   ('Eb', 'F', 'N'),
#   ('Eb', 'G', 'N'),
#   ('Eb', 'G:7', 'N'),
#   ('F', 'F:min', 'G'),
#   ('F', 'G', 'G:min'),
#   ('F', 'G:7', 'N'),
#   ('F', 'G:min', 'N'),
#   ('F:7', 'G:7', 'N'),
#   ('G', 'G:7', 'N')},
#  '210': {('A', 'A:min', 'C'),
#   ('A', 'A:min', 'D:min'),
#   ('A', 'A:min', 'G'),
#   ('A', 'C', 'N'),
#   ('A', 'C#:min', 'D'),
#   ('A', 'C#:min', 'F#:min'),
#   ('A', 'D', 'G'),
#   ('A', 'D', 'N'),
#   ('A', 'D:7', 'G'),
#   ('A', 'D:min', 'E'),
#   ('A', 'D:min', 'F#:min'),
#   ('A', 'D:min', 'G'),
#   ('A', 'E', 'N'),
#   ('A', 'G', 'N'),
#   ('A/3', 'C', 'D'),
#   ('A:min', 'Bb', 'C'),
#   ('A:min', 'Bb', 'F'),
#   ('A:min', 'C', 'E'),
#   ('A:min', 'C', 'F:7'),
#   ('A:min', 'C', 'F:min'),
#   ('A:min', 'C', 'G:min7'),
#   ('A:min', 'C', 'N'),
#   ('A:min', 'D:min', 'G'),
#   ('A:min', 'D:min', 'G:min7'),
#   ('A:min', 'E', 'G'),
#   ('A:min', 'F', 'F:7'),
#   ('A:min', 'F', 'N'),
#   ('A:min', 'F:7', 'G'),
#   ('A:min', 'F:min', 'G'),
#   ('A:min', 'G', 'N'),
#   ('Ab', 'Eb', 'N'),
#   ('Bb', 'C', 'N'),
#   ('Bb', 'Eb', 'F:min'),
#   ('Bb', 'Eb', 'N'),
#   ('Bb', 'F', 'G:min'),
#   ('Bb', 'F', 'N'),
#   ('C', 'D', 'F'),
#   ('C', 'D', 'G'),
#   ('C', 'D', 'G:min7'),
#   ('C', 'D:min', 'E'),
#   ('C', 'D:min', 'G'),
#   ('C', 'D:min', 'N'),
#   ('C', 'F', 'G:min'),
#   ('C', 'F:min', 'N'),
#   ('C', 'G', 'G/3'),
#   ('C', 'G:7', 'N'),
#   ('D', 'E', 'G'),
#   ('D', 'F', 'N'),
#   ('D', 'G', 'N'),
#   ('D', 'G:7', 'N'),
#   ('D:7', 'F:7', 'G'),
#   ('D:7', 'F:7', 'G:7'),
#   ('D:7', 'G', 'N'),
#   ('D:min', 'F', 'G'),
#   ('D:min', 'F', 'G:min'),
#   ('D:min', 'F', 'N'),
#   ('D:min', 'G:9', 'G:min7'),
#   ('F:min', 'G', 'N')},
#  '300': {('A', 'C', 'D'),
#   ('A', 'C', 'D:min'),
#   ('A', 'C', 'E'),
#   ('A', 'C', 'G'),
#   ('A', 'D', 'E'),
#   ('A', 'D', 'F#:min'),
#   ('A', 'E', 'G'),
#   ('A:min', 'C', 'D:min'),
#   ('A:min', 'C', 'F'),
#   ('A:min', 'C', 'G'),
#   ('A:min', 'D:min', 'F'),
#   ('A:min', 'F', 'G'),
#   ('Bb', 'C', 'F'),
#   ('Bb', 'C', 'F:min'),
#   ('C', 'C#:dim', 'D'),
#   ('C', 'D', 'E'),
#   ('C', 'D', 'N'),
#   ('C', 'D:min', 'F'),
#   ('C', 'D:min', 'G:min7'),
#   ('C', 'E', 'G'),
#   ('C', 'E', 'N'),
#   ('C', 'F', 'G'),
#   ('C', 'F', 'N'),
#   ('C', 'F:min', 'G'),
#   ('C', 'G', 'N'),
#   ('C#:min', 'D', 'F#:min'),
#   ('D', 'E', 'N'),
#   ('E', 'G', 'N'),
#   ('F', 'G', 'N')}}

# %%
from collections import Counter
counter=Counter(new)
print(counter)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
