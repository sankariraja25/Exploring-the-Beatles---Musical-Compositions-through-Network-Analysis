# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
album07 = pd.read_csv('album_07_edges.csv')
G = nx.from_pandas_edgelist(album07, source="Source", target="Target", create_using=nx.DiGraph())
nx.draw(G, with_labels=True)

# %% [markdown]
# ## Visuals

# %%
nx.draw(G,node_size=300,font_size=8,  with_labels=True)

# %%
plt.figure(3,figsize=(12,12)) 
nx.draw(G, node_size=400,font_size=12,  with_labels=True)

# %% [markdown]
# ## Triads

# %%
# Triad Consensus
nx.triadic_census(G)
# Out:
# {'003': 62579,
#  '012': 7390,
#  '021C': 241,
#  '021D': 79,
#  '021U': 94,
#  '030C': 11,
#  '030T': 11,
#  '102': 2332,
#  '111D': 149,
#  '111U': 150,
#  '120C': 9,
#  '120D': 4,
#  '120U': 2,
#  '201': 81,
#  '210': 12,
#  '300': 6}

# %%
import networkx as nx
import itertools


def _tricode(G, v, u, w):
    """Returns the integer code of the given triad.

    This is some fancy magic that comes from Batagelj and Mrvar's paper. It
    treats each edge joining a pair of `v`, `u`, and `w` as a bit in
    the binary representation of an integer.

    """
    combos = ((v, u, 1), (u, v, 2), (v, w, 4), (w, v, 8), (u, w, 16),
              (w, u, 32))
    return sum(x for u, v, x in combos if v in G[u])


# G = nx.DiGraph()
# G.add_nodes_from([1, 2, 3, 4, 5])
# G.add_edges_from([(1, 2), (2, 3), (2, 4), (4, 5)])

#: The integer codes representing each type of triad.
#: Triads that are the same up to symmetry have the same code.
TRICODES = (1, 2, 2, 3, 2, 4, 6, 8, 2, 6, 5, 7, 3, 8, 7, 11, 2, 6, 4, 8, 5, 9,
            9, 13, 6, 10, 9, 14, 7, 14, 12, 15, 2, 5, 6, 7, 6, 9, 10, 14, 4, 9,
            9, 12, 8, 13, 14, 15, 3, 7, 8, 11, 7, 12, 14, 15, 8, 14, 13, 15,
            11, 15, 15, 16)

#: The names of each type of triad. The order of the elements is
#: important: it corresponds to the tricodes given in :data:`TRICODES`.
TRIAD_NAMES = ('003', '012', '102', '021D', '021U', '021C', '111D', '111U',
               '030T', '030C', '201', '120D', '120U', '120C', '210', '300')

#: A dictionary mapping triad code to triad name.
TRICODE_TO_NAME = {i: TRIAD_NAMES[code - 1] for i, code in enumerate(TRICODES)}

triad_nodes = {name: set([]) for name in TRIAD_NAMES}
m = {v: i for i, v in enumerate(G)}
for v in G:
    vnbrs = set(G.pred[v]) | set(G.succ[v])
    for u in vnbrs:
        if m[u] > m[v]:
            unbrs = set(G.pred[u]) | set(G.succ[u])
            neighbors = (vnbrs | unbrs) - {u, v}
            not_neighbors = set(G.nodes()) - neighbors - {u, v}
            # Find dyadic triads
            for w in not_neighbors:
                if v in G[u] and u in G[v]:
                    triad_nodes['102'].add(tuple(sorted([u, v, w])))
                else:
                    triad_nodes['012'].add(tuple(sorted([u, v, w])))
            for w in neighbors:
                if m[u] < m[w] or (m[v] < m[w] < m[u] and
                                   v not in G.pred[w] and
                                   v not in G.succ[w]):
                    code = _tricode(G, v, u, w)
                    triad_nodes[TRICODE_TO_NAME[code]].add(
                        tuple(sorted([u, v, w])))
# find null triads
all_tuples = set()
for s in triad_nodes.values():
    all_tuples = all_tuples.union(s)
new = triad_nodes['003'] = set(itertools.combinations(G.nodes(), 3)).difference(all_tuples)

triad_nodes
# Out:
# {'003': {('B', 'B:7', 'C:min'),
#   ('D', 'D#:min', 'B:maj/9'),
#   ('Bb:min', 'Bb:min7', 'A/5'),
#   ('D:7(#9)', 'G:7', 'Bb:7'),
#   ('B', 'Bb:min', 'G:aug'),
#   ('B', 'B:maj7', 'B:7'),
#   ('B', 'Bb:7', 'G/3'),
#   ('G:7', 'Eb:7', 'C#'),
#   ('Eb:min', 'Ab:maj(9)', 'F:maj(9)/9'),
#   ('Gb', 'G', 'B:min/6'),
#   ('C', 'C:min(*b3)', 'E:7'),
#   ('A:7', 'C/7', 'F:maj/9'),
#   ('Bb:min7', 'F', 'E:maj(b9)'),
#   ('E:min6', 'Ab:min', 'D:sus4/5'),
#   ('Eb:7', 'E/5', 'F#:sus4'),
#   ('C/3', 'D#:min', 'Ab:maj(9)'),
#   ('D#:min', 'G:aug', 'G:sus4(2)'),
#   ('N', 'A:min7', 'A/5'),
#   ('E', 'A:min7', 'E/5'),
#   ('D#:min', 'Eb', 'B/5'),
#   ('Ab:maj(9)', 'F#:7', 'B:maj/9'),
#   ('Bb:min', 'D#:min', 'E/6'),
#   ('D:7', 'F:7', 'E:min/b7'),
#   ('Gb', 'Bb:7', 'Bb'),
#   ('G:min', 'B/5', 'B:min/b7'),
#   ('D:7(#9)', 'Bb:min', 'F#:min'),
#   ('Gb', 'Bb:7', 'Eb'),
#   ('F#:min7', 'F#', 'B:maj/9'),
#   ('F#:min7', 'E:7', 'E:maj(b9)'),
#   ('F#:min7', 'B:7', 'G#:7'),
#   ('F#:min7', 'G#:7', 'B:maj/9'),
#   ('Bb:min7', 'A:sus4', 'D'),
#   ('D:7', 'E:min', 'C/3'),
#   ('N', 'C', 'C/3'),
#   ('F#:min', 'E/5', 'G:sus4(2)'),
#   ('B', 'F:maj/9', 'C:sus4/4'),
#   ('C:9', 'E/7', 'A/5'),
#   ('A:min', 'C/7', 'B:maj/9'),
#   ('D', 'Eb', 'F:maj(9)/9'),
#   ('E:min/b7', 'C:min(*b3)', 'A/5'),
#   ('G', 'G#:min', 'E/7'),
#   ('D#:min', 'F:dim', 'F#:sus4'),
#   ('A:min7', 'F:maj(9)/9', 'B:min/b7'),
#   ('C:min', 'F#', 'B/7'),
#   ('B:7', 'Ab:maj(9)', 'F#:7'),
#   ('F:7', 'Ab:min7', 'F:min'),
#   ('G', 'D', 'F#:sus4'),
#   ('Ab:min7', 'B:min/6', 'B:maj/9'),
#   ('C:9', 'G#:7', 'B:dim'),
#   ('G/3', 'G#:7', 'B:min/b7'),
#   ('Bb:min', 'C#:min', 'B:min/6'),
#   ('F:7', 'C/3', 'A'),
#   ('B/5', 'F:dim', 'B:min/6'),
#   ('E:min/b7', 'Bb:min', 'B:min'),
#   ('N', 'G/3', 'F#:sus4'),
#   ('Ab:maj(9)', 'B/7', 'F:maj/9'),
#   ('G', 'F:maj(9)/9', 'B:min/6'),
#   ('G:7', 'F#:min', 'F:maj/9'),
#   ('B:min', 'Ab', 'B:min/6'),
#   ('G:7', 'Bb', 'C/7'),
#   ('B:maj7', 'E:7', 'G:sus4(2)'),
#   ('Bb:min7', 'F:min', 'F:maj(9)/9'),
#   ('E:min', 'G', 'F#:7'),
#   ('C:9', 'E/7', 'E/6'),
#   ('E:min6', 'F#:7', 'E/7'),
#   ('Db:min', 'B:min', 'C:min'),
#   ('Gb', 'A:sus4', 'C:min'),
#   ('F#:min7', 'E', 'B:min/7'),
#   ('C/3', 'F:min', 'F#:sus4'),
#   ('D#:min', 'G#:min', 'F#:7'),
#   ('F:7', 'Ab:min7', 'E/5'),
#   ('G', 'E/7', 'E/6'),
#   ('E:min/b7', 'B/7', 'F:maj/9'),
#   ('A:min7', 'Ab', 'F:dim'),
#   ('N', 'F#', 'A:7'),
#   ('Ab:min7', 'G:min', 'Ab:maj(9)'),
#   ('G:7', 'Bb:7', 'A:7'),
#   ('C:9', 'A/5', 'G:sus4(2)'),
#   ('E:min/b7', 'Gb', 'Bb:maj/9'),
#   ('Bb:min7', 'B/7', 'F:maj(9)/9'),
#   ('C:min', 'G:sus4(2)', 'Bb:maj/9'),
#   ('C/3', 'Bb:min7', 'B:maj/9'),
#   ('E:min/b7', 'Bb:min', 'B:min/7'),
#   ('N', 'Eb:7', 'G:sus4(2)'),
#   ('E:min6', 'Bb:min7', 'B:maj/9'),
#   ('C:min(*b3)', 'B:7', 'F#:sus4'),
#   ('E:min/b7', 'E:7', 'G#:7'),
#   ('B/7', 'G:sus4(2)', 'B:maj/9'),
#   ('G:7', 'A/5', 'B/7'),
#   ('Eb:min', 'E:maj(b9)', 'F:maj(9)/9'),
#   ('C#', 'E/5', 'D/5'),
#   ('G:7', 'Ab:min7', 'C:min(*b3)'),
#   ('A:min7', 'G:sus4(2)', 'Bb:maj(9)/9'),
#   ('Ab:min', 'Gb', 'E/6'),
#   ('A:min', 'G#:min', 'Bb:maj(9)/9'),
#   ('E:min', 'E', 'D#:min'),
#   ('G#:min', 'F#:7', 'A:7'),
#   ('Eb:min', 'Bb:7', 'E/6'),
#   ('Bb', 'B:min', 'D/5'),
#   ('Gb', 'F', 'A'),
#   ('C:9', 'E/6', 'B:min/b7'),
#   ('D:7(#9)', 'E', 'B:min/b7'),
#   ('E:min/b7', 'G:min', 'Bb:maj(9)/9'),
#   ('A:min7', 'B/5', 'C/7'),
#   ('Gb', 'G#:min', 'E:maj(b9)'),
#   ('Ab:min7', 'B:7', 'D/5'),
#   ('C:9', 'G', 'B/5'),
#   ('C#:min', 'F#:sus4', 'B:maj/9'),
#   ('C:min(*b3)', 'D:sus4/5', 'B:dim'),
#   ('C:min', 'A', 'A/5'),
#   ('D:7(#9)', 'E', 'B:dim'),
#   ('E/7', 'G#:7', 'B:min/7'),
#   ('C:min(*b3)', 'A:min', 'Ab:maj(9)'),
#   ('E:min7', 'F#:7', 'F:dim'),
#   ('Bb', 'C#', 'A:7'),
#   ('B:min', 'A', 'E/5'),
#   ('E:min', 'F', 'A/5'),
#   ('Eb:min', 'C:min', 'C#:min'),
#   ('E:min7', 'E:min6', 'B/7'),
#   ('D:7(#9)', 'B:min', 'F#'),
#   ('B:7', 'A', 'B:maj/9'),
#   ('A:min7', 'F#:7', 'F#:sus4'),
#   ('A:min7', 'F:min', 'F#:sus4'),
#   ('Bb:7', 'Bb:min', 'F#'),
#   ('Ab', 'F#:7', 'C#:min'),
#   ('F#:min', 'A/5', 'F#:sus4'),
#   ('C', 'Bb', 'Eb'),
#   ('F#:min', 'D#:min', 'Ab:maj(9)'),
#   ('B:min', 'F#', 'F:maj/9'),
#   ('Ab:min', 'E:7', 'E:maj(b9)'),
#   ('N', 'E:min', 'E'),
#   ('Ab', 'B/7', 'B:min/6'),
#   ('Db:min', 'C:min(*b3)', 'A:7'),
#   ('E:min6', 'B:dim', 'F:maj(9)/9'),
#   ('C', 'Gb', 'F:maj/9'),
#   ('Eb:7', 'A:sus4', 'A:min'),
#   ('C:min(*b3)', 'B:min/b7', 'G:sus4(2)'),
#   ('C/3', 'A', 'E/7'),
#   ('B:maj7', 'Bb:min7', 'B:dim'),
#   ('G#:min', 'F:min', 'E:maj(b9)'),
#   ('C:9', 'Eb:min', 'A/5'),
#   ('E/7', 'D/5', 'E:maj(b9)'),
#   ('F:7', 'Bb:min7', 'C#:min'),
#   ('Ab', 'F:min', 'B:min/7'),
#   ('Ab:min', 'D', 'E:7'),
#   ('Bb:min7', 'B/7', 'B:min/b7'),
#   ('B:min', 'G:min', 'F:dim'),
#   ('Bb:min', 'Bb:min7', 'Eb'),
#   ('C/3', 'Bb', 'C/7'),
#   ('C/3', 'A:min', 'B/5'),
#   ('Eb:7', 'D#:min', 'A:7'),
#   ('C:min(*b3)', 'Eb', 'G#:7'),
#   ('G:7', 'G:min', 'C:sus4/4'),
#   ('B:maj7', 'Eb', 'G#:7'),
#   ('F', 'F#', 'A:7'),
#   ('F:7', 'A:min', 'A/5'),
#   ('A:min', 'C#', 'F:min'),
#   ('F#:min', 'Ab', 'C#:min'),
#   ('C', 'Eb:7', 'D:sus4/5'),
#   ('Eb', 'G:aug', 'B/5'),
#   ('C', 'C#:min', 'Bb:maj/9'),
#   ('B:7', 'Eb', 'B:dim'),
#   ('Gb', 'B', 'E/7'),
#   ('E:min/b7', 'D#:min', 'B:min/b7'),
#   ('G:min', 'E/5', 'D/5'),
#   ('Db:min', 'G:min', 'E/7'),
#   ('Bb:7', 'B:maj7', 'G#:7'),
#   ('Ab:maj(9)', 'E:maj(b9)', 'B:min/6'),
#   ('N', 'Gb', 'Ab:min7'),
#   ('Eb:7', 'E', 'C#'),
#   ('E:min6', 'B/5', 'B:maj/9'),
#   ('B/5', 'F:dim', 'B/7'),
#   ('Gb', 'A:min7', 'Ab:maj(9)'),
#   ('E:min', 'C:min(*b3)', 'G'),
#   ('Ab:min7', 'A:7', 'B:min/6'),
#   ('N', 'G#:7', 'Bb:maj/9'),
#   ('G/3', 'Eb', 'A'),
#   ('C:9', 'B/5', 'G#:7'),
#   ('C', 'Bb:min7', 'A:min7'),
#   ('G', 'B:min/7', 'B:min/b7'),
#   ('G:aug', 'E/7', 'D:sus4/5'),
#   ('E:min7', 'Bb:min7', 'E:7'),
#   ('C/3', 'E', 'A/5'),
#   ('A:7', 'C#:min', 'E:maj(b9)'),
#   ('B', 'G', 'B/5'),
#   ('Eb:min', 'B/7', 'D/5'),
#   ('Eb:min', 'Bb:min', 'B:min'),
#   ('G:7', 'A:min', 'B:min/b7'),
#   ('C:9', 'Bb:min7', 'B:7'),
#   ('E:min6', 'C:min', 'B:min/7'),
#   ('F:7', 'Eb:min', 'E/7'),
#   ('C:9', 'B:min', 'Bb:maj/9'),
#   ('D:7(#9)', 'G:7', 'C:min'),
#   ('G:7', 'F:7', 'Bb:maj(9)/9'),
#   ('E:min6', 'Ab:min', 'B:min/6'),
#   ('B:min', 'F#', 'C#'),
#   ('B:min/6', 'Bb:maj(9)/9', 'Bb:maj/9'),
#   ('A:sus4', 'B/7', 'B:min/6'),
#   ('C', 'E:min', 'B'),
#   ('Ab:min7', 'F:dim', 'B:min/6'),
#   ('F:7', 'G', 'F:min'),
#   ('G:aug', 'E/5', 'F:maj(9)/9'),
#   ('E:min7', 'Eb:7', 'A'),
#   ('Bb:7', 'Bb:min', 'F:maj/9'),
#   ('F#:min7', 'B', 'Bb:min7'),
#   ('F#:7', 'B/7', 'C#:min'),
#   ('E:min6', 'Eb', 'F#:sus4'),
#   ('A:sus4', 'F:dim', 'C/7'),
#   ('E:min/b7', 'E', 'B:min/6'),
#   ('F', 'D#:min', 'B:maj/9'),
#   ('G:7', 'Ab:min', 'Ab:maj(9)'),
#   ('Eb:7', 'Ab:min7', 'A'),
#   ('Eb', 'A/5', 'G:sus4(2)'),
#   ('D:7(#9)', 'A:min', 'G#:7'),
#   ('D:7(#9)', 'F:min', 'F:maj/9'),
#   ('E:min7', 'E/5', 'Bb:maj(9)/9'),
#   ('N', 'Eb:7', 'A/5'),
#   ('F#:7', 'B:min/7', 'C:sus4/4'),
#   ('E:7', 'A/5', 'E:maj(b9)'),
#   ('B/5', 'B/7', 'B:maj/9'),
#   ('Gb', 'E:7', 'G:sus4(2)'),
#   ('F:7', 'D#:min', 'F#:7'),
#   ('F#:min', 'A', 'B/5'),
#   ('B:maj7', 'F#:min', 'D#:min'),
#   ('Db:min', 'Eb', 'F#:sus4'),
#   ('B:7', 'Ab:maj(9)', 'C/7'),
#   ('E:min6', 'F#:min7', 'E'),
#   ('E:min7', 'F#:min7', 'B:7'),
#   ('F#:7', 'B/5', 'C:sus4/4'),
#   ('B', 'Bb:7', 'B:min'),
#   ('Bb:7', 'F:min', 'D/5'),
#   ('Bb:7', 'G:min', 'F:dim'),
#   ('Bb:min', 'Bb:min7', 'C/7'),
#   ('C', 'A', 'E/5'),
#   ('E:min7', 'C:min', 'G#:min'),
#   ('G#:7', 'D/5', 'B:min/7'),
#   ('A:min', 'A/5', 'Bb:maj/9'),
#   ('N', 'B', 'Bb:maj/9'),
#   ('F', 'G#:min', 'D/5'),
#   ('G:7', 'Eb:7', 'C:sus4/4'),
#   ('E:min/b7', 'E:7', 'C#:min'),
#   ('Ab:min', 'B:min', 'Bb:maj(9)/9'),
#   ('E/5', 'B:min/7', 'G:sus4(2)'),
#   ('B:maj7', 'C:min', 'C#:min'),
#   ('Bb:min7', 'G', 'C#'),
#   ('C/3', 'G/3', 'C/7'),
#   ('Eb:7', 'D', 'D:sus4/5'),
#   ('G:7', 'E:maj(b9)', 'Bb:maj/9'),
#   ('Bb:7', 'A:min7', 'D#:min'),
#   ('D:7', 'Eb:min', 'B:min/7'),
#   ('B:7', 'B:min/b7', 'C:sus4/4'),
#   ('C:9', 'F#:min7', 'A:min7'),
#   ('N', 'C:min(*b3)', 'B:7'),
#   ('Eb:7', 'G#:min', 'A:7'),
#   ('Bb:min', 'E:7', 'F:maj/9'),
#   ('F#:min', 'A/5', 'B:min/b7'),
#   ('G:7', 'Bb:7', 'F:min'),
#   ('D', 'F', 'B:min/b7'),
#   ('D:7', 'E:min', 'Eb:min'),
#   ('Bb:7', 'E:maj(b9)', 'C/7'),
#   ('C:9', 'B:maj7', 'B:maj/9'),
#   ('E:min', 'C:min', 'F:min'),
#   ('Eb:min', 'F', 'G:sus4(2)'),
#   ('F#:min', 'F:min', 'C/7'),
#   ('B:7', 'D#:min', 'A'),
#   ('G/3', 'F', 'B/5'),
#   ('C', 'Ab:min7', 'B:min'),
#   ('D:7(#9)', 'Bb:7', 'G'),
#   ('F#:min7', 'Bb:min', 'A:7'),
#   ('C', 'Bb:7', 'F:maj/9'),
#   ('C/3', 'Eb:7', 'A:min'),
#   ('F#:min', 'G#:min', 'Bb:maj/9'),
#   ('Bb:min7', 'E:7', 'F:maj(9)/9'),
#   ('F:7', 'E/6', 'C/7'),
#   ('B', 'A:min', 'B/7'),
#   ('Bb:7', 'F#', 'G:aug'),
#   ('Db:min', 'A:sus4', 'Bb:maj(9)/9'),
#   ('C:min(*b3)', 'F#:min', 'D/5'),
#   ('Ab:maj(9)', 'B/5', 'Bb:maj(9)/9'),
#   ('C:min(*b3)', 'B:min', 'B/5'),
#   ('D:7(#9)', 'B:min', 'Bb:maj/9'),
#   ('Bb:min', 'A:min7', 'D/5'),
#   ('A:min', 'F:maj(9)/9', 'B:min/b7'),
#   ('D:7', 'F#:7', 'B:min/6'),
#   ('C:min(*b3)', 'F#', 'F#:7'),
#   ('G', 'Ab', 'C#:min'),
#   ('C:min(*b3)', 'G:min', 'C:min'),
#   ('Bb:7', 'B:dim', 'G:sus4(2)'),
#   ('C:min(*b3)', 'F#:min', 'F:dim'),
#   ('C', 'Bb', 'Ab:maj(9)'),
#   ('C', 'E:min6', 'B/5'),
#   ('E:min7', 'D', 'Bb:maj(9)/9'),
#   ('E:min7', 'G:min', 'A'),
#   ('E:maj(b9)', 'F:maj(9)/9', 'F:maj/9'),
#   ('E:min', 'E:min/b7', 'Bb:min7'),
#   ('C:min(*b3)', 'B:7', 'F#:7'),
#   ('Bb:min7', 'Eb:7', 'Bb'),
#   ('G:7', 'E/5', 'G#:7'),
#   ('C/3', 'B:maj7', 'C/7'),
#   ('Eb', 'F:min', 'Bb:maj(9)/9'),
#   ('Gb', 'B', 'F'),
#   ('E:min/b7', 'C:min', 'E:maj(b9)'),
#   ('Bb:7', 'E/7', 'B:min/6'),
#   ('Ab:min', 'F#', 'C#'),
#   ('G:min', 'E/6', 'F#:sus4'),
#   ('D:7(#9)', 'Ab:maj(9)', 'E:7'),
#   ('Ab:min7', 'B:min/b7', 'B:maj/9'),
#   ('Gb', 'Ab:min7', 'A:sus4'),
#   ('Bb:7', 'A:min7', 'A'),
#   ('Db:min', 'F#:min', 'C:min'),
#   ('G:7', 'A:min', 'A:min7'),
#   ('C', 'C:min', 'C#:min'),
#   ('F:maj/9', 'C:sus4/4', 'B:maj/9'),
#   ('E:min', 'E:7', 'B:dim'),
#   ('C:9', 'Db:min', 'E/7'),
#   ('F#:sus4', 'F:maj(9)/9', 'F:maj/9'),
#   ('G/3', 'F#:min', 'F:min'),
#   ('Db:min', 'G#:min', 'C/7'),
#   ('N', 'D:7', 'Eb:7'),
#   ('F#', 'G#:min', 'B/7'),
#   ('C#', 'Eb', 'E:7'),
#   ('E:min', 'D', 'A:min7'),
#   ('A:min', 'B:7', 'E:maj(b9)'),
#   ('C:min(*b3)', 'E/6', 'F:maj(9)/9'),
#   ('Ab:maj(9)', 'A/5', 'B:maj/9'),
#   ('D:7', 'D#:min', 'A'),
#   ('G', 'F', 'C#:min'),
#   ('Bb:min', 'F:min', 'B/5'),
#   ('Eb:7', 'Eb', 'B/7'),
#   ('B:maj7', 'A:sus4', 'A:min'),
#   ('Bb:7', 'F', 'Bb:maj(9)/9'),
#   ('G/3', 'C#', 'Bb:maj/9'),
#   ('N', 'Bb:min', 'C#'),
#   ('G:7', 'Ab:maj(9)', 'B:min/b7'),
#   ('N', 'Bb:7', 'G/3'),
#   ('Bb', 'A:sus4', 'C#:min'),
#   ('E/5', 'B/7', 'E:maj(b9)'),
#   ('F#', 'G:aug', 'B/7'),
#   ('Bb:min7', 'Bb', 'F:maj/9'),
#   ('B:min', 'F#', 'G#:7'),
#   ('E:min/b7', 'G#:7', 'F:maj(9)/9'),
#   ('A:min7', 'G#:min', 'Ab'),
#   ('N', 'E', 'E/7'),
#   ('F#:min7', 'E/5', 'B:min/b7'),
#   ('B:maj7', 'B:min', 'E/7'),
#   ('F#:min7', 'D', 'B:min/6'),
#   ('B:min', 'F#:min', 'B:7'),
#   ('D:7', 'B', 'E/6'),
#   ('F:7', 'C:sus4/4', 'Bb:maj/9'),
#   ('Bb:min', 'B:min/b7', 'G:sus4(2)'),
#   ('Ab:min7', 'Ab:maj(9)', 'C/7'),
#   ('C/3', 'G/3', 'A'),
#   ('Eb:min', 'A:min7', 'F:maj/9'),
#   ('Gb', 'D#:min', 'C/7'),
#   ('Eb:min', 'Gb', 'F#:7'),
#   ('N', 'C#', 'E/7'),
#   ('N', 'Eb:min', 'C:min'),
#   ('D:7(#9)', 'C:min(*b3)', 'C:min'),
#   ('F:7', 'E', 'A:min'),
#   ('B:min', 'Eb', 'C:sus4/4'),
#   ('Eb:7', 'Ab', 'A:7'),
#   ('A:min7', 'D#:min', 'B:maj/9'),
#   ('F:min', 'G#:7', 'D/5'),
#   ('Bb', 'C#', 'E:maj(b9)'),
#   ('N', 'B/7', 'C:sus4/4'),
#   ('E:min/b7', 'G:aug', 'E:maj(b9)'),
#   ('Db:min', 'E/6', 'D/5'),
#   ('C/3', 'A:7', 'B:min/b7'),
#   ('G:7', 'G', 'B/7'),
#   ('N', 'C/3', 'Bb'),
#   ('B:min', 'B/7', 'B:maj/9'),
#   ('E:min7', 'B:7', 'B/7'),
#   ('C', 'C:min', 'D:sus4/5'),
#   ('A/5', 'D/5', 'F:maj/9'),
#   ('E:min/b7', 'C:min(*b3)', 'D:sus4/5'),
#   ('C/3', 'B:dim', 'B:min/b7'),
#   ('E', 'A/5', 'F:maj(9)/9'),
#   ('Eb:7', 'G', 'A:7'),
#   ('E', 'A/5', 'B:maj/9'),
#   ('D#:min', 'D:sus4/5', 'F:maj/9'),
#   ('B:maj7', 'B/5', 'F:maj/9'),
#   ('C/3', 'F', 'C/7'),
#   ('Ab', 'A', 'E/5'),
#   ('Bb:7', 'Bb:min7', 'D'),
#   ('E:min6', 'Db:min', 'F#:min'),
#   ('G:7', 'D', 'G:min'),
#   ('B:maj7', 'E/5', 'B:min/b7'),
#   ('D:7', 'D:sus4/5', 'G:sus4(2)'),
#   ('Bb:min7', 'A:sus4', 'C:min'),
#   ('N', 'B:maj7', 'B:min/6'),
#   ('G:7', 'E:min6', 'Gb'),
#   ('G:7', 'F#:min', 'D#:min'),
#   ('Gb', 'G/3', 'B:dim'),
#   ('Bb', 'A', 'E/5'),
#   ('C:sus4/4', 'Bb:maj(9)/9', 'Bb:maj/9'),
#   ('F:7', 'G:aug', 'B:dim'),
#   ('B:maj7', 'A/5', 'F#:sus4'),
#   ('E:min/b7', 'Ab:min', 'C:sus4/4'),
#   ('Db:min', 'F:dim', 'B:min/6'),
#   ('B:min', 'C:min', 'F#'),
#   ('Bb:7', 'G#:7', 'F#:sus4'),
#   ('E:min/b7', 'Db:min', 'Bb:maj(9)/9'),
#   ('Eb:min', 'G', 'A:sus4'),
#   ('Db:min', 'F', 'F#:sus4'),
#   ('F#:min7', 'G', 'D#:min'),
#   ('E:min', 'B:maj7', 'B:min'),
#   ('Bb:min7', 'F#:min', 'D/5'),
#   ('C/3', 'Ab:min7', 'F#:sus4'),
#   ('C#', 'Ab:maj(9)', 'B:min/7'),
#   ('C:min(*b3)', 'Ab', 'B:min/b7'),
#   ('C:9', 'F#:sus4', 'C:sus4/4'),
#   ('Ab:min7', 'G:aug', 'Bb:maj(9)/9'),
#   ('Bb:min', 'A/5', 'B:dim'),
#   ('Eb:min', 'F#:min', 'B:7'),
#   ('F:7', 'Bb:7', 'B:min/7'),
#   ('Db:min', 'F#', 'Ab:maj(9)'),
#   ('A:7', 'B/7', 'C#:min'),
#   ('Ab:maj(9)', 'G:aug', 'F:maj(9)/9'),
#   ('Bb:min7', 'G/3', 'G#:min'),
#   ('Ab:min', 'C#', 'F:maj/9'),
#   ('Eb:min', 'C:min(*b3)', 'D:sus4/5'),
#   ('Db:min', 'A:sus4', 'B/7'),
#   ('Ab:maj(9)', 'B/5', 'B/7'),
#   ('B', 'D#:min', 'C:sus4/4'),
#   ('C/3', 'E/6', 'C#:min'),
#   ('Bb:7', 'G', 'C#'),
#   ('D', 'F:dim', 'Bb:maj(9)/9'),
#   ('Ab:min', 'C:min(*b3)', 'A:sus4'),
#   ('Eb:7', 'F:min', 'E/5'),
#   ('C:9', 'A:min', 'B:maj/9'),
#   ('C:min(*b3)', 'F#', 'C#:min'),
#   ('G/3', 'B:dim', 'Bb:maj(9)/9'),
#   ('F#:min7', 'F:min', 'B:maj/9'),
#   ('Eb:min', 'A:min7', 'F:min'),
#   ('E:min', 'C/3', 'E/5'),
#   ('B', 'A', 'B/7'),
#   ('Bb:7', 'E', 'F'),
#   ('N', 'Bb:min', 'Eb'),
#   ('E:min7', 'Ab:min7', 'B:min/b7'),
#   ('B', 'Ab:min7', 'E:7'),
#   ('E:min7', 'Eb:min', 'B/7'),
#   ('Bb', 'A:min', 'G/3'),
#   ('F:7', 'B', 'Db:min'),
#   ('B:maj7', 'C#', 'Bb:maj/9'),
#   ('B:min', 'D', 'C:sus4/4'),
#   ('G:min', 'A/5', 'F:maj/9'),
#   ('C:9', 'Ab:maj(9)', 'C:sus4/4'),
#   ('E:min6', 'F:dim', 'B:min/b7'),
#   ('A:min', 'B/5', 'F:maj/9'),
#   ('Bb:min7', 'C:min', 'F:maj/9'),
#   ('Bb:7', 'A:min7', 'F:dim'),
#   ('E:min7', 'Ab:maj(9)', 'F#:sus4'),
#   ('G', 'B:7', 'B:min/6'),
#   ('Eb:min', 'A:min7', 'Bb:maj(9)/9'),
#   ('A:min', 'G:min', 'B/7'),
#   ('A:7', 'A/5', 'B:min/7'),
#   ('Bb:min', 'B/5', 'G#:7'),
#   ('C:9', 'E:min6', 'B:7'),
#   ('E:min7', 'G', 'B/5'),
#   ('G:7', 'A:sus4', 'F#:min'),
#   ('E:min7', 'Bb:min7', 'B:maj/9'),
#   ('Eb:min', 'F#:min', 'E/6'),
#   ('A:min', 'A:7', 'A/5'),
#   ('Eb:min', 'Eb:7', 'A:sus4'),
#   ('Eb:7', 'C:min(*b3)', 'D/5'),
#   ('Ab:maj(9)', 'D/5', 'C/7'),
#   ('Db:min', 'Ab:min7', 'E/6'),
#   ('C/3', 'Eb', 'B:min/b7'),
#   ('B', 'E/6', 'B:maj/9'),
#   ('E:min7', 'G:min', 'F:dim'),
#   ('D#:min', 'F:min', 'B:min/b7'),
#   ('Bb', 'F#:min', 'F#:7'),
#   ('C:9', 'Eb:min', 'D'),
#   ('F#:min7', 'B', 'E/6'),
#   ('F#', 'F#:7', 'C:sus4/4'),
#   ('D#:min', 'G:aug', 'E/6'),
#   ('Eb:7', 'Eb', 'F#:sus4'),
#   ('E:min7', 'C/3', 'A:min'),
#   ('E:min7', 'Bb:min7', 'F'),
#   ('N', 'Gb', 'B:min/b7'),
#   ('D', 'F#:min', 'Ab:maj(9)'),
#   ('A:sus4', 'F', 'Bb:maj(9)/9'),
#   ('E:min', 'E:min/b7', 'A'),
#   ('E', 'A:min7', 'G#:7'),
#   ('Bb:min7', 'E:maj(b9)', 'G:sus4(2)'),
#   ('G:7', 'G:min', 'Bb:maj(9)/9'),
#   ('G:7', 'G:min', 'A:7'),
#   ('Eb:7', 'C#', 'D/5'),
#   ('G', 'E/7', 'D:sus4/5'),
#   ('Eb:7', 'F', 'B:min/7'),
#   ('G', 'F#:sus4', 'Bb:maj(9)/9'),
#   ('C:min(*b3)', 'B:min/b7', 'Bb:maj(9)/9'),
#   ('C#', 'F:min', 'C/7'),
#   ('Ab', 'A/5', 'C/7'),
#   ('E:min', 'E/6', 'B:maj/9'),
#   ('D:7', 'Bb', 'F:dim'),
#   ('Bb', 'A:sus4', 'D#:min'),
#   ('F:min', 'B:maj/9', 'Bb:maj/9'),
#   ('D/5', 'Bb:maj(9)/9', 'Bb:maj/9'),
#   ('Eb:min', 'Bb:min7', 'B/7'),
#   ('D', 'B/5', 'B/7'),
#   ('C/3', 'G:aug', 'F#:sus4'),
#   ('F:7', 'B', 'E'),
#   ('Ab:min7', 'C#', 'D:sus4/5'),
#   ('D:7', 'C/3', 'F#:min7'),
#   ('B', 'D:sus4/5', 'C/7'),
#   ('Db:min', 'F#:min', 'E/7'),
#   ('E:7', 'G:aug', 'B:min/6'),
#   ('E:min/b7', 'Gb', 'B:min/7'),
#   ('G/3', 'D#:min', 'A'),
#   ('D:7', 'B:7', 'Ab:maj(9)'),
#   ('F:7', 'D#:min', 'C/7'),
#   ('F#:min7', 'Gb', 'Ab'),
#   ('B:min/b7', 'F:maj/9', 'Bb:maj(9)/9'),
#   ('B', 'B:min/6', 'C:sus4/4'),
#   ('B:min', 'D', 'G#:7'),
#   ('Db:min', 'F#:min', 'E/6'),
#   ('D:7', 'F:7', 'Eb:7'),
#   ('Ab:min7', 'A/5', 'E:maj(b9)'),
#   ('E:min', 'A:sus4', 'E/7'),
#   ('D:7', 'E:min7', 'F#:sus4'),
#   ('D:7(#9)', 'C', 'G:7'),
#   ('E:min', 'B:min', 'B:min/b7'),
#   ('Ab', 'F#:7', 'Bb:maj/9'),
#   ('C', 'Bb:7', 'A:min'),
#   ('C/3', 'Eb:7', 'F:maj/9'),
#   ('E', 'C#', 'B:min/7'),
#   ('Bb:min7', 'C:min', 'Bb:maj(9)/9'),
#   ('A:min7', 'E/6', 'E:maj(b9)'),
#   ('C:9', 'A', 'C:sus4/4'),
#   ('G:7', 'B', 'C#:min'),
#   ('Ab:min', 'G', 'Bb:maj/9'),
#   ('F#:min7', 'C#', 'F:min'),
#   ('C:9', 'Bb', 'E:7'),
#   ('Ab:min', 'G:aug', 'Bb:maj/9'),
#   ('E:min/b7', 'F:min', 'B/5'),
#   ('G', 'B:min', 'G:min'),
#   ('E:min7', 'E/7', 'B/7'),
#   ('G:7', 'F#:7', 'G:sus4(2)'),
#   ('A:sus4', 'E/6', 'D:sus4/5'),
#   ('D:7', 'Gb', 'E/6'),
#   ('F:7', 'F:maj(9)/9', 'B:maj/9'),
#   ('G', 'F#', 'B:min/6'),
#   ('C/3', 'Bb', 'C#:min'),
#   ('F#:min', 'F#:7', 'C/7'),
#   ('E:min', 'G:min', 'E/6'),
#   ('D:7', 'F#:min', 'C:sus4/4'),
#   ('C', 'Bb:min7', 'A:7'),
#   ('Bb:7', 'C:min(*b3)', 'B/5'),
#   ('B/5', 'E/6', 'G#:7'),
#   ('G:7', 'C/3', 'Ab:maj(9)'),
#   ('D:7(#9)', 'C#', 'F#:7'),
#   ('C:9', 'Db:min', 'D'),
#   ('C', 'E:min', 'A'),
#   ('Ab:min7', 'E:7', 'C#:min'),
#   ('A:sus4', 'D', 'A/5'),
#   ('C#', 'E/7', 'B:maj/9'),
#   ('Ab:min', 'Ab:maj(9)', 'B:min/b7'),
#   ('Ab', 'Ab:maj(9)', 'Bb:maj(9)/9'),
#   ('F:7', 'G/3', 'F#'),
#   ('F#:min7', 'C:min(*b3)', 'Ab'),
#   ('Gb', 'F#:min', 'Ab'),
#   ('A:7', 'F:dim', 'B:dim'),
#   ('D:7', 'G', 'D/5'),
#   ('E:min/b7', 'Bb:min', 'G:aug'),
#   ('Bb', 'F', 'Ab:maj(9)'),
#   ('C', 'A:7', 'G:aug'),
#   ('E:min', 'Db:min', 'Ab:min7'),
#   ('B:maj7', 'D', 'B/7'),
#   ('D', 'A:min7', 'B:min/7'),
#   ('B:maj7', 'E', 'F:maj/9'),
#   ('Bb', 'F#', 'B/7'),
#   ('C:min(*b3)', 'G:min', 'F#:sus4'),
#   ('C:9', 'F:dim', 'B:dim'),
#   ('E:min7', 'Db:min', 'E:7'),
#   ('B:maj7', 'A:min', 'E/6'),
#   ('G:7', 'A:sus4', 'E:7'),
#   ('F#:min7', 'Bb:7', 'Ab:min7'),
#   ('Bb:min', 'C#:min', 'B:min/7'),
#   ('Ab', 'F#:7', 'D:sus4/5'),
#   ('F', 'F:min', 'G#:7'),
#   ('Gb', 'B:maj7', 'G:min'),
#   ('D:7(#9)', 'B:min/7', 'Bb:maj(9)/9'),
#   ('E/6', 'C:sus4/4', 'G:sus4(2)'),
#   ('Eb:7', 'F#', 'E/7'),
#   ('C:min(*b3)', 'G#:min', 'C#:min'),
#   ('Bb:min', 'Eb:7', 'D:sus4/5'),
#   ('Ab', 'C:sus4/4', 'Bb:maj(9)/9'),
#   ('F:7', 'E:min6', 'A:min7'),
#   ('Gb', 'Bb:7', 'B:maj7'),
#   ('F#:min7', 'Bb:7', 'E/7'),
#   ('B:7', 'G#:min', 'B:maj/9'),
#   ('F#:min7', 'F#:min', 'E:maj(b9)'),
#   ('G/3', 'F:dim', 'B/7'),
#   ('F#:7', 'B:min/b7', 'B:maj/9'),
#   ('F#:min7', 'F', 'F#:sus4'),
#   ('F:7', 'Ab:maj(9)', 'B:min/6'),
#   ('G:7', 'G/3', 'Ab:maj(9)'),
#   ('C/3', 'F:maj/9', 'G:sus4(2)'),
#   ('C/3', 'Bb:min', 'D/5'),
#   ('N', 'Bb:min7', 'A'),
#   ('G:7', 'C/3', 'G:min'),
#   ('F#:min7', 'C:min(*b3)', 'E/5'),
#   ('E', 'F:dim', 'E/6'),
#   ('D:7', 'F#:sus4', 'C/7'),
#   ('G:7', 'E:min7', 'F'),
#   ('D:7', 'G:7', 'Ab:min7'),
#   ('C', 'E:min', 'Bb:min'),
#   ('Db:min', 'C#', 'C/7'),
#   ('B', 'B/5', 'C/7'),
#   ('Bb:min', 'E/6', 'E/5'),
#   ('B', 'G:min', 'G:aug'),
#   ('E/7', 'E/6', 'F:maj(9)/9'),
#   ('C:9', 'C/7', 'F:maj/9'),
#   ('E:min7', 'Bb', 'E/6'),
#   ('E:min', 'B:maj7', 'G#:min'),
#   ('F:min', 'C#:min', 'C:sus4/4'),
#   ('E:min/b7', 'Bb:min7', 'Ab:maj(9)'),
#   ('A:min7', 'G:min', 'B:maj/9'),
#   ('A:min', 'B:dim', 'F:maj/9'),
#   ('C#', 'B:min/6', 'B:maj/9'),
#   ('Eb:7', 'B/5', 'E/6'),
#   ('E', 'C:min', 'B:min/6'),
#   ('D#:min', 'B:min/6', 'C/7'),
#   ('D:7', 'C:min', 'C:sus4/4'),
#   ('C:9', 'Ab', 'B/7'),
#   ('E:min/b7', 'E/5', 'Bb:maj/9'),
#   ('Ab:min', 'G:min', 'Ab'),
#   ('A:sus4', 'A:min7', 'D/5'),
#   ('G', 'C#:min', 'C/7'),
#   ('B:maj7', 'Bb:min7', 'Bb'),
#   ('E:min', 'G/3', 'B/7'),
#   ('E', 'A:min7', 'C#'),
#   ('Db:min', 'F#', 'B:min/7'),
#   ('Gb', 'A:min', 'B:7'),
#   ('G/3', 'G:min', 'Ab'),
#   ('F#:7', 'C#:min', 'G:sus4(2)'),
#   ('E', 'C#:min', 'F:maj/9'),
#   ('C:min(*b3)', 'B:dim', 'C/7'),
#   ('D:7', 'B/7', 'E:maj(b9)'),
#   ('F:7', 'A:min', 'F#:7'),
#   ('C:min(*b3)', 'Bb', 'Bb:maj(9)/9'),
#   ('Bb', 'G#:min', 'Ab'),
#   ('C:9', 'Ab:maj(9)', 'G#:7'),
#   ('Eb:7', 'E', 'F#'),
#   ('F#:min7', 'F#:7', 'E:maj(b9)'),
#   ('D:7', 'F:maj/9', 'C:sus4/4'),
#   ('Eb:min', 'F:maj(9)/9', 'G:sus4(2)'),
#   ('F#:min7', 'G:aug', 'E/6'),
#   ('Ab:min', 'A:min7', 'E:7'),
#   ('G:7', 'Ab:min7', 'E:7'),
#   ('C', 'B:7', 'C:sus4/4'),
#   ('F#:min7', 'Bb', 'C#'),
#   ('A:7', 'B/5', 'F:maj(9)/9'),
#   ('B/5', 'F:maj(9)/9', 'C/7'),
#   ('C', 'B:maj7', 'F#'),
#   ('E:min', 'D/5', 'C:sus4/4'),
#   ('C', 'Ab:min', 'G'),
#   ('C/3', 'Eb:min', 'F:maj/9'),
#   ('E', 'F#', 'D:sus4/5'),
#   ('Bb:min', 'G:aug', 'E:maj(b9)'),
#   ('E:min7', 'B:min', 'B:dim'),
#   ('F#:min7', 'Ab:min', 'A:min'),
#   ('E:min', 'B:maj7', 'Bb:maj(9)/9'),
#   ('B', 'E/5', 'A/5'),
#   ('Bb:7', 'A:min7', 'C:min'),
#   ('E:min', 'D#:min', 'F:dim'),
#   ('B', 'A:min7', 'F#:7'),
#   ('F#:min7', 'D#:min', 'B:min/6'),
#   ('D', 'A:min7', 'F#:sus4'),
#   ('D:7', 'A:min7', 'B:min/b7'),
#   ('E:min/b7', 'D', 'F#:7'),
#   ('F#:7', 'G:aug', 'B:maj/9'),
#   ('F:7', 'A/5', 'C/7'),
#   ('E:min', 'Db:min', 'E'),
#   ('Eb:min', 'F', 'A'),
#   ('D:7(#9)', 'G/3', 'C/7'),
#   ('G:7', 'C:9', 'E:min'),
#   ('Bb:min7', 'E/5', 'E:maj(b9)'),
#   ('E:min', 'Db:min', 'A:min7'),
#   ('G:min', 'D/5', 'Bb:maj/9'),
#   ('F:dim', 'A/5', 'C#:min'),
#   ('G', 'D#:min', 'E/5'),
#   ('A:min', 'E/5', 'B/7'),
#   ('A:min7', 'Ab:maj(9)', 'E/5'),
#   ('E:min7', 'B:min', 'A:7'),
#   ('E', 'B/7', 'B:maj/9'),
#   ('E:min7', 'G/3', 'F#'),
#   ('D', 'G/3', 'F:min'),
#   ('C/3', 'C:min', 'B/7'),
#   ('Bb:min', 'F:dim', 'F:maj(9)/9'),
#   ('Gb', 'B:min', 'E:maj(b9)'),
#   ('E', 'G#:min', 'B/5'),
#   ('Ab', 'F:maj(9)/9', 'F:maj/9'),
#   ('D:7(#9)', 'A', 'E/5'),
#   ('A:7', 'B:min/b7', 'G:sus4(2)'),
#   ('F', 'Ab', 'B:min/b7'),
#   ('D:7(#9)', 'A/5', 'B:maj/9'),
#   ('D:7', 'A:min', 'B:min/b7'),
#   ('G:7', 'C:9', 'C:sus4/4'),
#   ('E:min6', 'Bb:7', 'G:aug'),
#   ('A:min7', 'B:min/b7', 'C:sus4/4'),
#   ('F#:min7', 'G/3', 'E/6'),
#   ('Bb:7', 'F#', 'Ab:maj(9)'),
#   ('D:7', 'Ab', 'G:aug'),
#   ('Ab:min7', 'B:min', 'A:min'),
#   ('F#:min7', 'Eb:min', 'B:maj7'),
#   ('F', 'G:min', 'F#'),
#   ('B:min', 'Eb', 'Bb:maj(9)/9'),
#   ('Eb:min', 'D', 'C/7'),
#   ('E/5', 'E:maj(b9)', 'C/7'),
#   ('Eb:min', 'D/5', 'B:dim'),
#   ('C#', 'F#:7', 'F#:sus4'),
#   ('B', 'F:dim', 'E/7'),
#   ('C:9', 'A:sus4', 'C#'),
#   ('E:min/b7', 'E', 'F#:min'),
#   ('Bb:min7', 'A:sus4', 'G:min'),
#   ('A:sus4', 'C:min', 'A'),
#   ('B', 'A:min7', 'E:7'),
#   ('G:aug', 'A/5', 'G:sus4(2)'),
#   ('C:9', 'Eb:min', 'A'),
#   ('D:7(#9)', 'Gb', 'B:7'),
#   ('Db:min', 'G/3', 'Eb'),
#   ('D:7(#9)', 'C', 'E:min/b7'),
#   ('G', 'F', 'G:aug'),
#   ('G/3', 'A/5', 'C/7'),
#   ('D:7(#9)', 'Bb', 'G:min'),
#   ('F:7', 'E:min/b7', 'F#:min7'),
#   ('Ab:min', 'A:min7', 'F#:7'),
#   ('Ab:min', 'G#:7', 'E:maj(b9)'),
#   ('E:min', 'Bb', 'B/5'),
#   ('C:min', 'G:aug', 'B/7'),
#   ('E:min7', 'A:min7', 'F'),
#   ('G', 'G/3', 'F#:7'),
#   ('E:min7', 'E:min6', 'F#:sus4'),
#   ('E:min', 'G', 'F#'),
#   ('B', 'F:min', 'A:7'),
#   ('D:7', 'E:7', 'C:sus4/4'),
#   ('F#:7', 'G#:7', 'C:sus4/4'),
#   ('Bb:min7', 'A:7', 'F:maj(9)/9'),
#   ('A:7', 'C#:min', 'G:sus4(2)'),
#   ('E:min6', 'B', 'C:sus4/4'),
#   ('G:7', 'Db:min', 'A:7'),
#   ('Bb:min7', 'E:maj(b9)', 'B:min/b7'),
#   ('F', 'F#:sus4', 'C:sus4/4'),
#   ('E', 'B:min', 'E/7'),
#   ('E:min', 'G:aug', 'D:sus4/5'),
#   ('C', 'F:7', 'C#'),
#   ('Ab:min', 'F:min', 'G:sus4(2)'),
#   ('Bb:min', 'F#:min', 'C:min'),
#   ('Bb:min', 'B:maj7', 'Bb:min7'),
#   ('F:7', 'G:aug', 'A/5'),
#   ('F#:min7', 'Ab', 'C/7'),
#   ('E:min', 'Gb', 'B:dim'),
#   ('E:min6', 'Eb', 'A'),
#   ('Gb', 'C:min', 'A:7'),
#   ('E:min6', 'Ab:maj(9)', 'C/7'),
#   ('E:min7', 'G:aug', 'B:dim'),
#   ('E:min6', 'E/5', 'B:maj/9'),
#   ('Bb', 'F#:min', 'C/7'),
#   ('D:7', 'F', 'G:aug'),
#   ('N', 'Bb:min7', 'F:min'),
#   ('A:min', 'Ab', 'F:maj/9'),
#   ('Bb:min7', 'F#:7', 'E/6'),
#   ('Eb:7', 'Ab:maj(9)', 'G#:7'),
#   ('Eb:7', 'Ab:min7', 'C:min(*b3)'),
#   ('B:maj7', 'Db:min', 'C:min'),
#   ('G:7', 'G/3', 'G:sus4(2)'),
#   ('C:9', 'B:dim', 'B:maj/9'),
#   ('G/3', 'C#', 'B:min/b7'),
#   ('E:min7', 'Bb:7', 'G/3'),
#   ('Eb:min', 'E:7', 'F:maj/9'),
#   ('Bb:7', 'B:min/7', 'F:maj/9'),
#   ('E:min/b7', 'A:sus4', 'G#:7'),
#   ('C:9', 'B/5', 'G:sus4(2)'),
#   ('D', 'C:min', 'E:7'),
#   ('E:min/b7', 'D#:min', 'C/7'),
#   ('F:7', 'B:maj7', 'F#:sus4'),
#   ('E:min6', 'C:min', 'B:min/6'),
#   ('Eb:7', 'D/5', 'B:maj/9'),
#   ('Bb:7', 'G:min', 'F:maj/9'),
#   ('N', 'D/5', 'F:maj(9)/9'),
#   ('E:min6', 'C#', 'F#:7'),
#   ('Eb:min', 'B:min/b7', 'C:sus4/4'),
#   ('E:min6', 'G:min', 'A/5'),
#   ('E:min', 'Bb:7', 'B/7'),
#   ('F#:min', 'C#', 'Ab:maj(9)'),
#   ('B', 'C:min', 'F#:7'),
#   ('E:min7', 'B:7', 'C#:min'),
#   ('G', 'F:min', 'F:maj/9'),
#   ('D', 'F', 'D/5'),
#   ('E:min', 'F#', 'A:7'),
#   ('F#:min7', 'G:aug', 'Bb:maj/9'),
#   ('B:maj7', 'G', 'E:7'),
#   ('A:sus4', 'D#:min', 'F:maj/9'),
#   ('C', 'F#:min7', 'B:min/6'),
#   ('Bb', 'E:maj(b9)', 'F:maj/9'),
#   ('Ab:min7', 'B:dim', 'C/7'),
#   ('A', 'F#:7', 'A/5'),
#   ('E:min6', 'C#', 'G:sus4(2)'),
#   ('C/3', 'Eb:7', 'Bb:maj/9'),
#   ('Gb', 'Eb', 'D:sus4/5'),
#   ('A:min7', 'F#', 'E:7'),
#   ('Ab:min', 'F#:min', 'F:dim'),
#   ('Ab:min7', 'E:7', 'F:maj(9)/9'),
#   ('C:9', 'F#:min7', 'Ab:min'),
#   ('B:min', 'B:dim', 'C/7'),
#   ('F#:min', 'C#', 'Bb:maj(9)/9'),
#   ('Ab:min', 'Ab:maj(9)', 'F#:sus4'),
#   ('D:7(#9)', 'F#', 'F:dim'),
#   ('E:min/b7', 'Ab:min', 'C#:min'),
#   ('B:maj7', 'A', 'B:dim'),
#   ('C:9', 'E:min7', 'C/3'),
#   ('C:9', 'D', 'G/3'),
#   ('F#:min7', 'F:min', 'B:min/7'),
#   ('C:9', 'Gb', 'A'),
#   ('C:9', 'D/5', 'B:dim'),
#   ('F#:min7', 'A:sus4', 'Ab'),
#   ('C/3', 'Eb:min', 'E:maj(b9)'),
#   ('D:7', 'E:min', 'Ab:min'),
#   ('Eb:min', 'G:min', 'C#:min'),
#   ('Db:min', 'B:min', 'F#:sus4'),
#   ('B:min', 'A:7', 'E/5'),
#   ('Gb', 'F#:sus4', 'C:sus4/4'),
#   ('E:min', 'E/7', 'G#:7'),
#   ('D:7(#9)', 'F#:sus4', 'B:min/b7'),
#   ('Db:min', 'C:min', 'B/5'),
#   ('A:sus4', 'E:maj(b9)', 'B:min/b7'),
#   ('G#:min', 'Ab:maj(9)', 'F:min'),
#   ('F#:min7', 'Eb:min', 'A/5'),
#   ('G:7', 'Ab:min', 'B'),
#   ('E:min6', 'A:min7', 'F#:7'),
#   ('Gb', 'G/3', 'F'),
#   ('E:min/b7', 'C:min', 'G#:7'),
#   ('F#:min', 'C:min', 'A:7'),
#   ('F', 'B/5', 'B:maj/9'),
#   ('B:maj7', 'F#:7', 'C/7'),
#   ('G:7', 'B:min', 'E/6'),
#   ('C', 'B', 'A'),
#   ('Bb:7', 'F#:min', 'B:dim'),
#   ('G:7', 'Bb:min7', 'B:maj/9'),
#   ('F:7', 'G:min', 'F#:7'),
#   ('G', 'F#:7', 'E:maj(b9)'),
#   ('B:maj7', 'F', 'Bb:maj(9)/9'),
#   ('Gb', 'B:7', 'E/6'),
#   ('G/3', 'C#', 'G:aug'),
#   ('Eb', 'Ab:maj(9)', 'F#:7'),
#   ('E:min6', 'Eb:min', 'B:min/6'),
#   ('A:7', 'E/6', 'B:min/6'),
#   ('B:min', 'F:dim', 'B:min/b7'),
#   ('Eb:7', 'G/3', 'F:dim'),
#   ('Ab', 'A:7', 'D:sus4/5'),
#   ('N', 'G#:7', 'B:dim'),
#   ('D:7', 'E/7', 'F#:sus4'),
#   ('G:7', 'F#', 'F#:sus4'),
#   ('Gb', 'E', 'A/5'),
#   ('D:7(#9)', 'B', 'Bb:min'),
#   ('C', 'G/3', 'Ab'),
#   ('Ab:min', 'F#', 'E:maj(b9)'),
#   ('D', 'Ab:maj(9)', 'B:min/b7'),
#   ('D:7(#9)', 'Bb:min7', 'F:maj(9)/9'),
#   ('E:min6', 'Bb:min7', 'C#:min'),
#   ('Bb', 'D/5', 'Bb:maj(9)/9'),
#   ('A:min7', 'A:7', 'G#:7'),
#   ('B:min', 'F#', 'E:maj(b9)'),
#   ('C:min(*b3)', 'E/6', 'A/5'),
#   ('D:7', 'E/6', 'F:maj/9'),
#   ('Eb:min', 'B:min', 'B/5'),
#   ('B:maj7', 'E', 'F:maj(9)/9'),
#   ('Ab:min7', 'C:min(*b3)', 'C#'),
#   ('D:sus4/5', 'B:min/7', 'B:min/b7'),
#   ('D:7', 'Bb:min7', 'B/7'),
#   ('D:7(#9)', 'Db:min', 'B:min/7'),
#   ('E:min7', 'C:min(*b3)', 'F#:7'),
#   ('N', 'Bb:7', 'B:min/b7'),
#   ('G:7', 'Gb', 'C/7'),
#   ('E/6', 'F#:sus4', 'C/7'),
#   ('Gb', 'Ab:min7', 'G'),
#   ('D:7', 'A', 'E/5'),
#   ('E:min', 'Eb:min', 'C:min'),
#   ('N', 'E:7', 'E/7'),
#   ('Bb:min7', 'Eb:7', 'B:min/b7'),
#   ('B:min', 'B:7', 'B/5'),
#   ('E', 'D#:min', 'D:sus4/5'),
#   ('D:7', 'A:min', 'D:sus4/5'),
#   ('E', 'A:min', 'Bb:maj/9'),
#   ('F:7', 'G', 'G:aug'),
#   ('E:min6', 'Bb:min', 'Ab'),
#   ('C/3', 'B/5', 'E:maj(b9)'),
#   ('C', 'Bb:min', 'B:dim'),
#   ('Bb:min', 'B:min/b7', 'B:min/6'),
#   ('F#:min', 'F', 'Ab:maj(9)'),
#   ('B:min', 'A:sus4', 'A:min7'),
#   ('A:7', 'E/7', 'E/5'),
#   ('C/3', 'Ab', 'Bb:maj(9)/9'),
#   ('Bb', 'E:7', 'A/5'),
#   ('G', 'Eb', 'F#:sus4'),
#   ('D:7', 'E/5', 'F#:sus4'),
#   ('E:min6', 'E/6', 'F:maj/9'),
#   ('F:min', 'A/5', 'B:min/7'),
#   ('E:min6', 'E', 'A:7'),
#   ('G#:min', 'A', 'A/5'),
#   ('N', 'A:sus4', 'G:min'),
#   ('Eb:7', 'B:min', 'A/5'),
#   ('Ab:min', 'C#', 'A/5'),
#   ('C:min(*b3)', 'D', 'B:min/b7'),
#   ('D:7(#9)', 'D#:min', 'E/6'),
#   ('F#', 'Ab', 'F:min'),
#   ('Ab:maj(9)', 'F:dim', 'B:maj/9'),
#   ('F', 'B:min/b7', 'C:sus4/4'),
#   ('F:min', 'B:min/b7', 'Bb:maj/9'),
#   ('Gb', 'Ab:maj(9)', 'D/5'),
#   ('E:7', 'A/5', 'F#:sus4'),
#   ('Eb:min', 'Bb:7', 'Ab'),
#   ('C:min(*b3)', 'B:7', 'A'),
#   ('Bb:min7', 'B:min/b7', 'F:maj/9'),
#   ('E:min/b7', 'A:sus4', 'C#'),
#   ('B:min', 'G:min', 'Bb:maj/9'),
#   ('C', 'F:7', 'Eb:7'),
#   ('D:7(#9)', 'D/5', 'C:sus4/4'),
#   ('C#:min', 'D/5', 'B:maj/9'),
#   ('G:7', 'A:min', 'F'),
#   ('Eb:min', 'Ab:min7', 'C#'),
#   ('D', 'E:7', 'A/5'),
#   ('B', 'Ab:min7', 'F#:7'),
#   ('N', 'Bb:min7', 'G'),
#   ('Eb', 'F:dim', 'E/6'),
#   ('D:7', 'Eb:min', 'D/5'),
#   ('F#:min', 'G:aug', 'Bb:maj/9'),
#   ('E', 'F:min', 'F:dim'),
#   ('A:min7', 'G:min', 'A/5'),
#   ('G:7', 'D/5', 'F:maj(9)/9'),
#   ('C/3', 'G#:min', 'F:min'),
#   ('Gb', 'B', 'C#'),
#   ('F#:min7', 'B', 'G:aug'),
#   ('F#', 'F#:7', 'Bb:maj(9)/9'),
#   ('E:min6', 'G:min', 'Eb'),
#   ('Eb:7', 'A:sus4', 'Bb:maj(9)/9'),
#   ('E:7', 'E/5', 'D/5'),
#   ('E:min6', 'B:maj7', 'F'),
#   ('D:7(#9)', 'F#:min7', 'Db:min'),
#   ('C/3', 'F:maj(9)/9', 'B:min/7'),
#   ('Bb:min', 'Bb', 'G#:7'),
#   ('E:min6', 'E/6', 'D:sus4/5'),
#   ('D:7(#9)', 'Bb:min7', 'F#'),
#   ('C', 'Ab:maj(9)', 'F:min'),
#   ('N', 'D', 'F#'),
#   ('B:maj7', 'A:sus4', 'C#:min'),
#   ('G:min', 'C/7', 'Bb:maj/9'),
#   ('N', 'Eb:7', 'G'),
#   ('E', 'D', 'D:sus4/5'),
#   ('E:min6', 'F', 'B:min/b7'),
#   ('E:min', 'Bb:7', 'Eb:7'),
#   ('C/3', 'G#:min', 'Bb:maj(9)/9'),
#   ('E/7', 'B:min/7', 'Bb:maj/9'),
#   ('G:7', 'G:min', 'E:maj(b9)'),
#   ('Ab:min', 'C#', 'D:sus4/5'),
#   ('Ab:min', 'G:aug', 'C#:min'),
#   ('D/5', 'B:dim', 'B:maj/9'),
#   ('A/5', 'C#:min', 'C:sus4/4'),
#   ('B:min', 'G:aug', 'B/7'),
#   ('F#:min7', 'D/5', 'Bb:maj/9'),
#   ('Eb:7', 'F#:sus4', 'F:maj(9)/9'),
#   ('E', 'F:min', 'F:maj(9)/9'),
#   ('Eb:7', 'C:min(*b3)', 'Bb:maj(9)/9'),
#   ('D:7', 'B', 'G/3'),
#   ('D:7(#9)', 'B:min', 'E:7'),
#   ('G:min', 'F#', 'B/7'),
#   ('G/3', 'E/7', 'D:sus4/5'),
#   ('D:7', 'Eb:7', 'F#:sus4'),
#   ('Bb:min', 'Eb:7', 'B:min/7'),
#   ('C:min(*b3)', 'B:min', 'G:sus4(2)'),
#   ('E', 'B/7', 'B:dim'),
#   ('C:9', 'Eb:min', 'G'),
#   ('E:min', 'Ab:min', 'Eb'),
#   ('E/6', 'B:min/b7', 'C:sus4/4'),
#   ('D:7', 'Bb:min7', 'C#'),
#   ('Ab:min7', 'A:min', 'Bb:maj(9)/9'),
#   ('C:9', 'E:min/b7', 'F#:7'),
#   ('G#:min', 'C#:min', 'Bb:maj(9)/9'),
#   ('C/3', 'F:maj(9)/9', 'B:min/6'),
#   ('D:7(#9)', 'Bb:min', 'F:maj/9'),
#   ('C:9', 'Db:min', 'B:min/7'),
#   ('F#:min7', 'Bb:min7', 'A:7'),
#   ('A:min', 'Eb', 'B:min/7'),
#   ('B:maj7', 'C:min(*b3)', 'B:dim'),
#   ('E:min6', 'G/3', 'D/5'),
#   ('D', 'B:7', 'B/7'),
#   ('A:min', 'Ab', 'E:maj(b9)'),
#   ('C/3', 'F#:min', 'B/7'),
#   ('F#:min7', 'Ab:min', 'G#:7'),
#   ('N', 'G:aug', 'D:sus4/5'),
#   ('C/3', 'E/7', 'Bb:maj(9)/9'),
#   ('C', 'G', 'B:min/6'),
#   ('Ab:maj(9)', 'A:7', 'G:aug'),
#   ('F#:min', 'B:dim', 'B:min/b7'),
#   ('E:min', 'B:7', 'G:sus4(2)'),
#   ('A:min', 'C:min', 'A:7'),
#   ('E:maj(b9)', 'B:min/b7', 'G:sus4(2)'),
#   ('E', 'A', 'G#:7'),
#   ...},
#  '012': {('Bb:min7', 'E:min', 'E:min/b7'),
#   ('Bb:maj/9', 'C:sus4/4', 'F:maj/9'),
#   ('B:dim', 'E:min', 'N'),
#   ('A:7', 'D', 'E:min6'),
#   ('Ab:maj(9)', 'E:7', 'Eb'),
#   ('Ab', 'C:9', 'Eb'),
#   ('E:maj(b9)', 'F:maj/9', 'G'),
#   ('B:7', 'F#:7', 'N'),
#   ('A:min', 'D', 'G:sus4(2)'),
#   ('E', 'Eb', 'F#:min'),
#   ('B:min/6', 'Db:min', 'Eb:7'),
#   ('D/5', 'E', 'N'),
#   ('C/3', 'E:maj(b9)', 'G'),
#   ('B:dim', 'E', 'F:dim'),
#   ('A:min7', 'D', 'E/7'),
#   ('A:min7', 'E:min7', 'G/3'),
#   ('B/5', 'C#', 'G:aug'),
#   ('B:min', 'E:min', 'F:maj(9)/9'),
#   ('Ab:maj(9)', 'C', 'D:7'),
#   ('B:min/6', 'C', 'C/3'),
#   ('C/7', 'E:min', 'E:min/b7'),
#   ('A:sus4', 'B:min/b7', 'Bb'),
#   ('B/7', 'C/3', 'G'),
#   ('A:min7', 'C', 'G:7'),
#   ('A:min', 'E:min', 'F#'),
#   ('Bb:min', 'E', 'G#:min'),
#   ('B', 'C:9', 'E:7'),
#   ('C:min', 'D:7', 'E/5'),
#   ('B/7', 'B:min', 'B:min/7'),
#   ('B:7', 'Db:min', 'E:min'),
#   ('C/3', 'G#:min', 'G:aug'),
#   ('B/5', 'C', 'E:min/b7'),
#   ('C', 'D', 'Eb:7'),
#   ('Ab:min', 'D:7', 'Eb:min'),
#   ('Bb:7', 'E/6', 'E/7'),
#   ('D:sus4/5', 'E', 'E/7'),
#   ('E', 'F:dim', 'G:7'),
#   ('Ab:maj(9)', 'D#:min', 'Eb'),
#   ('B:dim', 'B:min', 'Eb:min'),
#   ('E/6', 'E/7', 'E:maj(b9)'),
#   ('B:min/6', 'B:min/b7', 'Bb:maj/9'),
#   ('A:7', 'Ab:maj(9)', 'E:7'),
#   ('C/3', 'C:sus4/4', 'E/5'),
#   ('A:min', 'C', 'F#:min'),
#   ('E', 'Eb:7', 'Eb:min'),
#   ('D:7(#9)', 'F:7', 'N'),
#   ('B:min/b7', 'D#:min', 'G#:min'),
#   ('B:maj7', 'Eb:min', 'F:7'),
#   ('A:min', 'B:min/6', 'B:min/b7'),
#   ('B:dim', 'Bb:7', 'Gb'),
#   ('Bb', 'Db:min', 'Eb:7'),
#   ('B', 'E/7', 'F#:min'),
#   ('D#:min', 'D:7', 'G:7'),
#   ('A:min7', 'C/3', 'G/3'),
#   ('A:min7', 'Bb:maj(9)/9', 'G'),
#   ('B/7', 'C', 'F#:min'),
#   ('E', 'E/7', 'F:7'),
#   ('C', 'G#:7', 'G:7'),
#   ('Ab:min', 'B:7', 'E'),
#   ('B:min/6', 'C', 'G:aug'),
#   ('E/5', 'F#', 'F#:sus4'),
#   ('G#:min', 'G:7', 'G:aug'),
#   ('B/7', 'C:9', 'G#:min'),
#   ('B:min', 'E:min', 'G'),
#   ('C/3', 'D/5', 'D:sus4/5'),
#   ('C', 'D:7', 'G#:min'),
#   ('A:7', 'D', 'G#:7'),
#   ('Ab:min', 'E', 'G'),
#   ('Ab:min7', 'B:maj7', 'D'),
#   ('B/7', 'E', 'F:dim'),
#   ('A', 'A:7', 'E/5'),
#   ('Bb:min', 'F#', 'F#:sus4'),
#   ('C:sus4/4', 'E:min', 'F:maj/9'),
#   ('D#:min', 'G#:min', 'G:sus4(2)'),
#   ('Ab:maj(9)', 'Bb', 'E:min/b7'),
#   ('C', 'D:7', 'E'),
#   ('A', 'Ab', 'E:maj(b9)'),
#   ('A', 'Ab:maj(9)', 'E'),
#   ('A', 'E:maj(b9)', 'E:min6'),
#   ('B', 'D', 'G#:7'),
#   ('Ab:maj(9)', 'C/3', 'C:sus4/4'),
#   ('E', 'Eb:7', 'G'),
#   ('A', 'E:maj(b9)', 'G:aug'),
#   ('A', 'B:7', 'E:min'),
#   ('A', 'F#', 'Gb'),
#   ('B', 'Bb:maj(9)/9', 'C#:min'),
#   ('D/5', 'G#:min', 'G:aug'),
#   ('B:maj7', 'Eb:min', 'F:dim'),
#   ('C/3', 'E', 'E/7'),
#   ('A', 'B:dim', 'G/3'),
#   ('E:7', 'F:7', 'G:sus4(2)'),
#   ('Ab:min', 'E:min', 'Eb:min'),
#   ('A', 'B:maj7', 'Eb:min'),
#   ('B:min/6', 'C:min', 'G:min'),
#   ('A', 'B/7', 'D'),
#   ('Bb', 'F', 'F:dim'),
#   ('Bb:maj(9)/9', 'C/3', 'E:min'),
#   ('Bb:7', 'F#', 'Gb'),
#   ('E:min', 'E:min/b7', 'G'),
#   ('E', 'G#:min', 'G:7'),
#   ('B', 'C', 'E:7'),
#   ('D:sus4/5', 'E', 'N'),
#   ('C/3', 'E:min6', 'F:maj(9)/9'),
#   ('A:min', 'E:min', 'F:min'),
#   ('B:min', 'F:maj(9)/9', 'G#:min'),
#   ('Bb:min7', 'F:7', 'N'),
#   ('A:min', 'A:sus4', 'G:sus4(2)'),
#   ('B:min/7', 'E', 'F#:min'),
#   ('Bb:maj/9', 'E:min', 'N'),
#   ('Ab:min', 'C:min', 'D'),
#   ('C#', 'E', 'E/5'),
#   ('A:min', 'E:min', 'G#:min'),
#   ('B', 'C#:min', 'D:7(#9)'),
#   ('A', 'A/5', 'F#:7'),
#   ('B/5', 'E:min', 'G:aug'),
#   ('B/7', 'D:7(#9)', 'G#:min'),
#   ('Ab:min7', 'Eb:7', 'Eb:min'),
#   ('Ab:min', 'B:maj7', 'Eb'),
#   ('C:min', 'D', 'E:min7'),
#   ('A:min7', 'E', 'G#:min'),
#   ('Bb:min7', 'F#', 'F#:sus4'),
#   ('A:sus4', 'Bb', 'E/7'),
#   ('A:7', 'A:min', 'A:min7'),
#   ('A:7', 'D', 'Gb'),
#   ('C#', 'F#:7', 'G#:min'),
#   ('Ab:min7', 'E:min', 'E:min/b7'),
#   ('B:7', 'C#', 'G#:min'),
#   ('B:maj7', 'Eb:min', 'F#:min7'),
#   ('Ab:min', 'B:maj7', 'C:min(*b3)'),
#   ('A', 'B:dim', 'C:sus4/4'),
#   ('Bb:7', 'C/7', 'Eb:min'),
#   ('A', 'B:min', 'D:sus4/5'),
#   ('D/5', 'D:sus4/5', 'N'),
#   ('B:min', 'C', 'D:7'),
#   ('Db:min', 'Eb:min', 'F:dim'),
#   ('B:min/b7', 'D:7', 'G'),
#   ('A', 'A:7', 'F#:min'),
#   ('A:sus4', 'G#:min', 'G:aug'),
#   ('B:maj7', 'E:min', 'E:min/b7'),
#   ('C:min', 'C:min(*b3)', 'G:min'),
#   ('Ab:min7', 'E:min7', 'Eb:min'),
#   ('F:maj/9', 'G', 'G:7'),
#   ('B:min/7', 'B:min/b7', 'Gb'),
#   ('A:min', 'A:min7', 'B:7'),
#   ('Ab:min7', 'B/5', 'E'),
#   ('A:7', 'E/6', 'E:7'),
#   ('Bb:7', 'E/5', 'Eb:min'),
#   ('A:min', 'A:sus4', 'Bb:7'),
#   ('A', 'A/5', 'D'),
#   ('C#:min', 'F#:sus4', 'Gb'),
#   ('Ab:min', 'D:sus4/5', 'E'),
#   ('B/5', 'C#', 'E'),
#   ('B:min/6', 'B:min/b7', 'G#:min'),
#   ('Ab:min', 'Eb:7', 'F:maj/9'),
#   ('B/5', 'Db:min', 'Eb:min'),
#   ('A/5', 'B:7', 'E:min'),
#   ('B/5', 'C/7', 'F:dim'),
#   ('B/7', 'B:7', 'D'),
#   ('B:maj7', 'B:min', 'D/5'),
#   ('A:min7', 'C#', 'G#:min'),
#   ('A:7', 'E:7', 'G#:min'),
#   ('A:7', 'B:dim', 'B:min'),
#   ('C', 'G#:7', 'G/3'),
#   ('C:min', 'D#:min', 'G#:min'),
#   ('Ab:min', 'C:min', 'G:min'),
#   ('A:7', 'Ab:min7', 'B:maj7'),
#   ('C', 'Eb', 'G:7'),
#   ('B', 'B:min', 'E:min7'),
#   ('D:7', 'Db:min', 'G:min'),
#   ('E/5', 'E/6', 'G:7'),
#   ('A', 'C#:min', 'F#:sus4'),
#   ('B/5', 'C', 'G:aug'),
#   ('Ab:maj(9)', 'Bb', 'E/5'),
#   ('B:7', 'B:min/6', 'E:7'),
#   ('C#', 'C:min', 'D:7'),
#   ('A:min', 'A:sus4', 'C:min'),
#   ('B/5', 'E', 'E:maj(b9)'),
#   ('A', 'C/7', 'F#:7'),
#   ('A/5', 'E', 'E:min6'),
#   ('C/3', 'Db:min', 'G'),
#   ('A:min', 'D', 'F:dim'),
#   ('B:min/b7', 'D#:min', 'F#'),
#   ('A', 'E/5', 'F#:min7'),
#   ('A:sus4', 'B/5', 'F:dim'),
#   ('A:min', 'C/7', 'E:7'),
#   ('Bb:min', 'C:sus4/4', 'F:maj/9'),
#   ('B', 'B/7', 'D:7'),
#   ('D:7', 'E', 'G'),
#   ('C', 'F#:7', 'G:7'),
#   ('A', 'E:maj(b9)', 'G:7'),
#   ('A/5', 'Ab:min7', 'Eb:min'),
#   ('C:min(*b3)', 'E:min', 'E:min/b7'),
#   ('A', 'B/5', 'F#:min'),
#   ('B:7', 'F#', 'F#:7'),
#   ('B/5', 'B:min/6', 'B:min/b7'),
#   ('A', 'Ab:maj(9)', 'B:dim'),
#   ('Ab', 'B', 'Eb'),
#   ('B', 'C#:min', 'G:aug'),
#   ('A', 'Ab', 'F#'),
#   ('A:min', 'C/7', 'E/6'),
#   ('B:7', 'D', 'F#'),
#   ('Ab:min', 'Eb:7', 'G:sus4(2)'),
#   ('B:min/6', 'E:min6', 'E:min7'),
#   ('A', 'Ab:min', 'Eb:min'),
#   ('B:maj7', 'C#:min', 'F#:sus4'),
#   ('Bb:7', 'D:7(#9)', 'Gb'),
#   ('C:min', 'D:7', 'F:min'),
#   ('C#:min', 'F#:sus4', 'G:aug'),
#   ('Db:min', 'Eb:min', 'F#:min7'),
#   ('Bb', 'E/6', 'E/7'),
#   ('A:min7', 'D/5', 'D:sus4/5'),
#   ('C/3', 'D#:min', 'G#:min'),
#   ('A/5', 'C', 'F#:min'),
#   ('D', 'E', 'F#:min'),
#   ('B:min', 'D#:min', 'D/5'),
#   ('A:sus4', 'B:dim', 'Bb'),
#   ('E', 'E/7', 'F#:min7'),
#   ('Ab:min', 'E:min', 'Eb:7'),
#   ('A:7', 'B', 'Bb:maj/9'),
#   ('E:min', 'F#:min', 'N'),
#   ('D', 'E:7', 'G'),
#   ('E:7', 'E:min7', 'F:7'),
#   ('A:min7', 'D', 'G:min'),
#   ('A:min7', 'B/5', 'G#:min'),
#   ('Bb:7', 'D:sus4/5', 'Gb'),
#   ('B:min/b7', 'G#:min', 'G:aug'),
#   ('B:min', 'D/5', 'G#:min'),
#   ('B:min/6', 'E', 'F#:min'),
#   ('Ab:maj(9)', 'D', 'G'),
#   ('B', 'C:min', 'E:maj(b9)'),
#   ('A:7', 'Ab:maj(9)', 'Bb'),
#   ('C:min', 'D', 'D/5'),
#   ('A:7', 'E:min', 'N'),
#   ('Ab:maj(9)', 'Bb', 'C#:min'),
#   ('A:min7', 'B:min/7', 'D:7'),
#   ('E', 'E/6', 'Eb:7'),
#   ('C:min', 'D', 'F:dim'),
#   ('E', 'F#:min7', 'F:dim'),
#   ('Bb', 'F', 'F#:sus4'),
#   ('D:7', 'G#:min', 'G:aug'),
#   ('Ab:min', 'D:sus4/5', 'Eb:min'),
#   ('Bb', 'E', 'F'),
#   ('Bb:7', 'E', 'Eb:7'),
#   ('B:min', 'F#:7', 'F:maj(9)/9'),
#   ('C', 'C/7', 'C:min(*b3)'),
#   ('Bb:7', 'E:7', 'F:7'),
#   ('B', 'B/7', 'C:9'),
#   ('Bb:min', 'D', 'F'),
#   ('B:7', 'D', 'G:aug'),
#   ('D/5', 'F:7', 'N'),
#   ('Db:min', 'E', 'E/5'),
#   ('B:dim', 'B:min', 'C/3'),
#   ('C', 'C#:min', 'G:7'),
#   ('Ab:maj(9)', 'G#:min', 'G:aug'),
#   ('A:min7', 'D', 'F#:min'),
#   ('B:7', 'Eb', 'F#:7'),
#   ('A:min', 'B:7', 'F#:7'),
#   ('Ab', 'Db:min', 'Eb'),
#   ('B:7', 'E', 'E:7'),
#   ('Ab', 'Eb', 'G'),
#   ('B:7', 'E:min', 'F#:sus4'),
#   ('D:7', 'E:min7', 'G:min'),
#   ('A', 'Ab:min7', 'F#'),
#   ('B:7', 'Bb:7', 'E:7'),
#   ('B', 'C#:min', 'F#:7'),
#   ('B:7', 'C:min(*b3)', 'D'),
#   ('Ab:min7', 'B:maj7', 'F'),
#   ('B:7', 'E:7', 'F:maj(9)/9'),
#   ('A', 'Bb:min7', 'D:sus4/5'),
#   ('B', 'D', 'D:7(#9)'),
#   ('A:min', 'A:sus4', 'Ab:maj(9)'),
#   ('C', 'C/7', 'F:dim'),
#   ('C:min', 'D:7', 'F#'),
#   ('Ab:min', 'Eb:min', 'F:dim'),
#   ('Ab:min', 'B:7', 'D'),
#   ('B', 'E:min', 'G:min'),
#   ('B/7', 'Bb:min7', 'G#:min'),
#   ('D:7', 'F:maj(9)/9', 'G:7'),
#   ('A:7', 'D', 'Eb'),
#   ('B:min/b7', 'Bb', 'G:min'),
#   ('Db:min', 'E', 'E/7'),
#   ('A', 'B:min/6', 'F#:min'),
#   ('Ab:min7', 'B:min/7', 'B:min/b7'),
#   ('Ab:min', 'C:min(*b3)', 'E'),
#   ('C:sus4/4', 'E/5', 'F:maj/9'),
#   ('Ab:min7', 'B', 'F#:min'),
#   ('E/6', 'E/7', 'F'),
#   ('C:min', 'Eb:7', 'G:min'),
#   ('A:7', 'Bb:min7', 'E'),
#   ('A', 'D/5', 'G#:min'),
#   ('A:sus4', 'D#:min', 'G#:min'),
#   ('D:7(#9)', 'E', 'Eb:7'),
#   ('D:7', 'E/5', 'G:7'),
#   ('B/5', 'C', 'C/7'),
#   ('B', 'B:dim', 'D'),
#   ('Ab:min7', 'B:maj7', 'N'),
#   ('Ab:min7', 'Bb:maj/9', 'Eb:min'),
#   ('Ab', 'Eb', 'Gb'),
#   ('Ab:maj(9)', 'Bb', 'Bb:min'),
#   ('D#:min', 'D/5', 'F#'),
#   ('C/3', 'F#:min7', 'G'),
#   ('D:7', 'F:dim', 'G:min'),
#   ('C', 'C:9', 'E:min/b7'),
#   ('Ab:min', 'B:min/7', 'Eb:7'),
#   ('C:min', 'E', 'Eb:7'),
#   ('E', 'F:dim', 'G:min'),
#   ('Bb:min7', 'E:7', 'F:7'),
#   ('Bb:7', 'C', 'F#:min'),
#   ('A:min', 'Ab:maj(9)', 'Bb'),
#   ('A', 'D:sus4/5', 'G/3'),
#   ('Ab', 'E:7', 'Eb'),
#   ('Bb', 'E:min', 'E:min/b7'),
#   ('Ab:min', 'C#', 'G#:min'),
#   ('B/5', 'D:sus4/5', 'G#:min'),
#   ('A', 'B:7', 'E/5'),
#   ('D#:min', 'E:min7', 'G#:min'),
#   ('C/3', 'C:min', 'G:min'),
#   ('B:min', 'C:min', 'D:7'),
#   ('A', 'E:7', 'Gb'),
#   ('D#:min', 'E:7', 'F:7'),
#   ('A:min', 'A:min7', 'Eb:7'),
#   ('D:7', 'G:7', 'G:aug'),
#   ('B', 'E:7', 'G'),
#   ('Ab:min', 'B:maj7', 'F:min'),
#   ('B', 'B/7', 'F:maj(9)/9'),
#   ('C/3', 'E', 'E:min'),
#   ('Ab:maj(9)', 'Bb', 'Bb:maj/9'),
#   ('Bb:min7', 'C/3', 'E:min6'),
#   ('A', 'A/5', 'E:maj(b9)'),
#   ('C:sus4/4', 'D:7', 'G:min'),
#   ('Ab:min', 'B:min/6', 'B:min/b7'),
#   ('E', 'F#:min', 'Gb'),
#   ('B:maj7', 'Eb:min', 'F'),
#   ('Bb', 'D', 'D:7'),
#   ('C#', 'E/5', 'G#:min'),
#   ('C/3', 'C:sus4/4', 'G#:7'),
#   ('C:min', 'E:7', 'F#'),
#   ('C', 'E:min6', 'G/3'),
#   ('Ab', 'B/5', 'G#:min'),
#   ('Ab', 'E', 'Eb'),
#   ('B/7', 'C', 'D:7'),
#   ('B/5', 'F:7', 'G:aug'),
#   ('A/5', 'Db:min', 'Eb:7'),
#   ('E:7', 'F#', 'Gb'),
#   ('A', 'Bb:min', 'F#:7'),
#   ('Bb', 'E/5', 'G:min'),
#   ('Ab:min7', 'Eb:min', 'G:7'),
#   ('Ab:min', 'Eb:7', 'F#:sus4'),
#   ('A', 'A:7', 'B:dim'),
#   ('B', 'Bb:min7', 'E:7'),
#   ('A', 'Bb:maj(9)/9', 'D:sus4/5'),
#   ('A', 'C:9', 'D/5'),
#   ('C:sus4/4', 'F:7', 'F:maj/9'),
#   ('A', 'F#:min', 'G#:min'),
#   ('Ab:min7', 'B:maj7', 'D:sus4/5'),
#   ('C', 'D:7', 'F#:min7'),
#   ('A:min', 'D', 'F#:sus4'),
#   ('A:sus4', 'B', 'E:7'),
#   ('A/5', 'C', 'G/3'),
#   ('B:min/7', 'B:min/b7', 'C/7'),
#   ('C', 'E/5', 'E:min/b7'),
#   ('B', 'B:7', 'F#:7'),
#   ('A:min7', 'B:dim', 'B:min'),
#   ('Ab:min', 'Eb:min', 'G:7'),
#   ('Bb', 'Db:min', 'Eb:min'),
#   ('A:min', 'Bb', 'E:min'),
#   ('B:maj7', 'E:7', 'F#'),
#   ('A:7', 'B', 'Eb:min'),
#   ('B:maj/9', 'C:min', 'D:7'),
#   ('A:sus4', 'Bb', 'E:7'),
#   ('A:min', 'C/7', 'E:min6'),
#   ('C/3', 'E/7', 'G'),
#   ('Ab:min7', 'C/3', 'E:min6'),
#   ('C:min', 'D:7', 'E:min'),
#   ('B:min/6', 'B:min/b7', 'G:7'),
#   ('A:min', 'A:sus4', 'E'),
#   ('C', 'D#:min', 'E:min/b7'),
#   ('A/5', 'E', 'F:maj(9)/9'),
#   ('Ab:min7', 'E/5', 'E/6'),
#   ('Bb:7', 'Eb:min', 'G'),
#   ('C', 'F:dim', 'G/3'),
#   ('B:min', 'F', 'G'),
#   ('B:dim', 'C#', 'G#:min'),
#   ('C:min(*b3)', 'D#:min', 'G#:min'),
#   ('B/5', 'B:7', 'E:7'),
#   ('B', 'C#:min', 'C/7'),
#   ('E/5', 'E/6', 'F#:sus4'),
#   ('A/5', 'B', 'E:min'),
#   ('A', 'B:min/b7', 'F#:min'),
#   ('Bb', 'C/3', 'C:sus4/4'),
#   ('D', 'D/5', 'D:7'),
#   ('B/7', 'B:7', 'F#:7'),
#   ('A:min7', 'G', 'G:min'),
#   ('Ab:maj(9)', 'Bb', 'C:min'),
#   ('B:7', 'E:min', 'G:7'),
#   ('D/5', 'F:maj/9', 'G'),
#   ('E/7', 'G#:min', 'G:aug'),
#   ('A', 'E:7', 'F:min'),
#   ('Bb:maj(9)/9', 'E:min', 'N'),
#   ('Bb:maj/9', 'C/3', 'C:sus4/4'),
#   ('A:7', 'C/3', 'E:min6'),
#   ('Ab:min', 'B/5', 'B:maj7'),
#   ('B:min/6', 'Db:min', 'Eb:min'),
#   ('Bb:maj(9)/9', 'F:7', 'N'),
#   ('B:min', 'E/7', 'G'),
#   ('A', 'F#:7', 'G#:min'),
#   ('A:min7', 'B:min', 'Bb'),
#   ('F:maj/9', 'F:min', 'G'),
#   ('B/5', 'F:7', 'G#:min'),
#   ('A', 'B:dim', 'E:min6'),
#   ('A:min', 'E:min', 'G'),
#   ('E', 'G:7', 'N'),
#   ('C:min', 'D', 'G:7'),
#   ('B/5', 'F:7', 'N'),
#   ('A:min', 'A:min7', 'D:sus4/5'),
#   ('C', 'F#', 'G/3'),
#   ('C', 'E:min/b7', 'G#:min'),
#   ('C/3', 'C:sus4/4', 'Gb'),
#   ('Bb:maj(9)/9', 'E', 'F:dim'),
#   ('B', 'D', 'F:min'),
#   ('C:min', 'D', 'E:7'),
#   ('Ab:min7', 'E', 'N'),
#   ('A:7', 'B:maj/9', 'E'),
#   ('D', 'D:7', 'Db:min'),
#   ('B:dim', 'C', 'D'),
#   ('Ab:min', 'E', 'F:min'),
#   ('E', 'F:dim', 'G:sus4(2)'),
#   ('A:min7', 'B:min/b7', 'G'),
#   ('B:7', 'D', 'D#:min'),
#   ('C#', 'E:7', 'G#:min'),
#   ('A:7', 'Bb:min', 'D'),
#   ('B/7', 'C:min', 'D:7'),
#   ('Ab:min', 'C', 'Eb:min'),
#   ('B/7', 'E:min6', 'G#:min'),
#   ('B:min', 'B:min/b7', 'G'),
#   ('A:min7', 'Eb:7', 'G/3'),
#   ('B/5', 'E:min6', 'G:aug'),
#   ('C#:min', 'D#:min', 'G#:min'),
#   ('B:min/7', 'B:min/b7', 'G'),
#   ('B:7', 'F#:7', 'Gb'),
#   ('C', 'D:7(#9)', 'F#:min'),
#   ('B:min', 'C', 'F#:min'),
#   ('Ab:min', 'C:9', 'Eb:min'),
#   ('Bb:min7', 'E', 'E/5'),
#   ('A:min', 'Bb:min7', 'D'),
#   ('A', 'E:7', 'F:maj/9'),
#   ('F#:sus4', 'F:maj/9', 'G'),
#   ('B/5', 'B:min/7', 'G:aug'),
#   ('E:7', 'F#:7', 'F:7'),
#   ('E', 'F#:7', 'F:dim'),
#   ('A:min', 'A:sus4', 'Db:min'),
#   ('A', 'E/5', 'Gb'),
#   ('E/5', 'E/6', 'F'),
#   ('B:min', 'C:min', 'G'),
#   ('B/7', 'E', 'E/5'),
#   ('Ab', 'E/7', 'Eb'),
#   ('B', 'E:min', 'G:sus4(2)'),
#   ('A', 'B:dim', 'G#:7'),
#   ('A', 'A:min7', 'F#'),
#   ('F#', 'F#:7', 'F#:sus4'),
#   ('B:maj7', 'Bb:maj(9)/9', 'Eb:min'),
#   ('E:min6', 'E:min7', 'G:7'),
#   ('A/5', 'G:sus4(2)', 'N'),
#   ('A', 'E:min7', 'F#:7'),
#   ('Ab:min7', 'B', 'E:maj(b9)'),
#   ('A:min', 'Ab:min', 'C/7'),
#   ('A:min', 'A:min7', 'B/7'),
#   ('A:7', 'B:7', 'E'),
#   ('A', 'E:maj(b9)', 'G#:7'),
#   ('C', 'C:sus4/4', 'D:7'),
#   ('B', 'B:min', 'D:7'),
#   ('C', 'C/7', 'F:min'),
#   ('Ab:min7', 'B:maj7', 'B:min'),
#   ('F', 'F#', 'F#:sus4'),
#   ('A', 'E:maj(b9)', 'G:min'),
#   ('B:7', 'C', 'G:7'),
#   ('C:min', 'D', 'E/7'),
#   ('C', 'D#:min', 'F#:min'),
#   ('B', 'C:sus4/4', 'E:maj(b9)'),
#   ('B:7', 'E:7', 'F:maj/9'),
#   ('A:7', 'Ab:min', 'Eb:7'),
#   ('C/7', 'F:7', 'N'),
#   ('B/5', 'Bb:min7', 'F:dim'),
#   ('A:sus4', 'D:7', 'G:7'),
#   ('B:7', 'B:min', 'B:min/7'),
#   ('Ab:min', 'Eb:min', 'G:sus4(2)'),
#   ('B:maj/9', 'D:7', 'G:min'),
#   ('A/5', 'A:min7', 'D:7'),
#   ('B/5', 'Bb:min', 'G#:min'),
#   ('B:min', 'C#', 'D/5'),
#   ('B:7', 'E:7', 'E:min/b7'),
#   ('B:dim', 'C/3', 'E:min'),
#   ('A', 'F#:7', 'G/3'),
#   ('Bb:7', 'E:maj(b9)', 'Gb'),
#   ('B', 'Bb:min', 'E:7'),
#   ('B:min', 'B:min/6', 'E/6'),
#   ('Bb', 'Eb:7', 'G:min'),
#   ('Bb:maj(9)/9', 'E', 'N'),
#   ('C/3', 'C/7', 'E:min6'),
#   ('Ab:min7', 'Bb:min', 'Eb:min'),
#   ('E', 'G#:7', 'N'),
#   ('A:min7', 'D', 'F:maj(9)/9'),
#   ('E', 'E:min7', 'Eb:7'),
#   ('Ab:min7', 'B:maj7', 'F#:min7'),
#   ('B/7', 'F#:sus4', 'G#:min'),
#   ('D:7', 'D:sus4/5', 'G:7'),
#   ('B', 'B:dim', 'E:maj(b9)'),
#   ('A/5', 'C#:min', 'N'),
#   ('B', 'E:maj(b9)', 'G#:min'),
#   ('B', 'C#:min', 'C:min'),
#   ('C', 'F', 'G/3'),
#   ('Ab:maj(9)', 'Db:min', 'Eb:min'),
#   ('C:min', 'G#:min', 'G:min'),
#   ('Bb:min7', 'E', 'E/7'),
#   ('A:7', 'B', 'E:min/b7'),
#   ('Ab:min', 'E/5', 'Eb:min'),
#   ('D', 'G', 'G#:min'),
#   ('Bb:7', 'Bb:maj(9)/9', 'Gb'),
#   ('A', 'Ab:min', 'E/5'),
#   ('B:min', 'Bb', 'E/5'),
#   ('Ab:min', 'E', 'F#:7'),
#   ('D', 'Db:min', 'G'),
#   ('A', 'B:dim', 'G:aug'),
#   ('B:7', 'E:min', 'Eb:min'),
#   ('B:7', 'C#:min', 'D'),
#   ('A', 'E/5', 'G#:7'),
#   ('C:min', 'D/5', 'G:min'),
#   ('A:min7', 'D:7', 'F#'),
#   ('C#', 'E:min/b7', 'G#:min'),
#   ('A:7', 'D', 'F#:min7'),
#   ('B', 'E:7', 'F'),
#   ('B:min', 'E/6', 'E/7'),
#   ('B:min/b7', 'Bb:7', 'Gb'),
#   ('Bb:min7', 'E', 'F#:min'),
#   ('D', 'F', 'F#:sus4'),
#   ('Bb', 'Bb:7', 'Gb'),
#   ('Bb:7', 'D#:min', 'Gb'),
#   ('E:7', 'F#', 'F#:7'),
#   ('C:sus4/4', 'E:min6', 'E:min7'),
#   ('Bb:maj(9)/9', 'D#:min', 'F#'),
#   ('A:7', 'E', 'F:min'),
#   ('B', 'E:7', 'Eb:7'),
#   ('D:7', 'E/6', 'G'),
#   ('E', 'E:min6', 'G#:min'),
#   ('D', 'D:7', 'E/6'),
#   ('A:min', 'E:min', 'G#:7'),
#   ('A:min7', 'Ab:maj(9)', 'D:7'),
#   ('A', 'D', 'G#:7'),
#   ('A:min7', 'Ab:min', 'B:maj7'),
#   ('B', 'B:min', 'C:9'),
#   ('B/5', 'Eb', 'G#:min'),
#   ('D:7', 'E/7', 'G:min'),
#   ('A', 'D:sus4/5', 'Db:min'),
#   ('B:min/7', 'Bb', 'G:min'),
#   ('A:min7', 'D#:min', 'G#:min'),
#   ('C:min', 'E:min6', 'G:min'),
#   ('C', 'C:9', 'F#:min'),
#   ('Ab:min7', 'B:dim', 'B:maj7'),
#   ('B/5', 'B:maj/9', 'G:aug'),
#   ('C:9', 'E', 'N'),
#   ('C', 'F#:min', 'F:dim'),
#   ('Ab', 'E', 'E/5'),
#   ('A:min', 'C/7', 'Eb:min'),
#   ('Bb:7', 'E/6', 'Gb'),
#   ('Ab:min7', 'B:maj7', 'G'),
#   ('C', 'D#:min', 'G:7'),
#   ('B:7', 'C#:min', 'F#:7'),
#   ('A', 'D:sus4/5', 'G:aug'),
#   ('Ab:min', 'Eb:7', 'F:min'),
#   ('A:sus4', 'Bb', 'D/5'),
#   ('C:9', 'F#', 'F#:sus4'),
#   ('Bb', 'C/3', 'E:min6'),
#   ('Ab:min', 'B:maj7', 'E:min7'),
#   ('B/5', 'Bb:maj/9', 'E'),
#   ('Bb:7', 'Eb:min', 'F'),
#   ('Ab:maj(9)', 'B:min', 'G'),
#   ('B:min', 'C/7', 'G'),
#   ('D:7', 'G#:min', 'G:7'),
#   ('A', 'Ab:min', 'E:7'),
#   ('E:7', 'F:7', 'G:min'),
#   ('B:7', 'E:7', 'Eb'),
#   ('A', 'B:min', 'B:min/6'),
#   ('C/3', 'F', 'G'),
#   ('Ab:maj(9)', 'Eb', 'F#:min7'),
#   ('A:min7', 'C:min', 'G/3'),
#   ('C:sus4/4', 'E:7', 'F#'),
#   ('D/5', 'D:7', 'G:7'),
#   ('Ab:maj(9)', 'C/7', 'Eb'),
#   ('A:min', 'D', 'G#:7'),
#   ('C', 'C:9', 'G/3'),
#   ('A', 'C#', 'D'),
#   ('Bb', 'Bb:7', 'G:min'),
#   ('B:min/7', 'B:min/b7', 'F:maj(9)/9'),
#   ('B:min/7', 'B:min/b7', 'C#:min'),
#   ('Bb', 'D/5', 'G:min'),
#   ('B:min/b7', 'D', 'D:7'),
#   ('B/5', 'Bb', 'F:dim'),
#   ('Ab:min', 'B:min', 'E'),
#   ('C', 'D:7', 'F'),
#   ('A', 'C', 'G:7'),
#   ('C:sus4/4', 'F:maj/9', 'G:min'),
#   ('Bb:maj(9)/9', 'D', 'F'),
#   ('Ab:min7', 'E', 'E/5'),
#   ('A:min', 'C/7', 'F#:sus4'),
#   ('C:min', 'D:7', 'G#:7'),
#   ('A:7', 'C', 'D:7'),
#   ('E:min7', 'F:7', 'N'),
#   ('E:min6', 'E:min7', 'F:dim'),
#   ('Ab:maj(9)', 'B:min/6', 'B:min/b7'),
#   ('B', 'E:maj(b9)', 'F:7'),
#   ('Ab:min', 'C/7', 'E'),
#   ('B:maj7', 'Eb:min', 'G#:min'),
#   ('Ab:maj(9)', 'B/7', 'Bb'),
# ...
#   ('Bb', 'E:min/b7', 'F:min'),
#   ('B:maj/9', 'C#:min', 'G#:7'),
#   ('A', 'Ab:min', 'N'),
#   ('A', 'B', 'G:min'),
#   ('Bb:min', 'C:min(*b3)', 'N'),
#   ('B', 'B/5', 'N'),
#   ('B:maj7', 'D:7', 'N'),
#   ('Bb:maj(9)/9', 'C', 'F#'),
#   ('B', 'E/5', 'E:min6'),
#   ('Bb:maj/9', 'C#', 'F#'),
#   ('A', 'B', 'B:maj7'),
#   ('Ab', 'Bb', 'D:sus4/5'),
#   ('A:min', 'F#', 'N'),
#   ('C#:min', 'D:sus4/5', 'G#:7'),
#   ('Bb', 'G#:min', 'N'),
#   ('Ab', 'Bb', 'D:7'),
#   ('B', 'E', 'F:min'),
#   ('Bb:maj(9)/9', 'D:7', 'N'),
#   ('A', 'A:sus4', 'D#:min'),
#   ('B', 'C#', 'F'),
#   ('B:7', 'Bb:7', 'F#:min'),
#   ('B:min', 'Bb:maj(9)/9', 'C'),
#   ('C#:min', 'Eb', 'G#:7'),
#   ('C#:min', 'D#:min', 'G#:7'),
#   ('C#', 'F#', 'F:min'),
#   ('B:maj7', 'C', 'G'),
#   ('Bb', 'Bb:maj(9)/9', 'C'),
#   ('B:maj/9', 'F:maj(9)/9', 'G'),
#   ('Bb', 'F:min', 'G'),
#   ('A', 'Ab', 'B'),
#   ('B', 'B:maj/9', 'E/5'),
#   ('B', 'D:7(#9)', 'Gb'),
#   ('A:7', 'Bb', 'N'),
#   ('Ab:maj(9)', 'C#:min', 'G#:7'),
#   ('Ab:maj(9)', 'D:7', 'N'),
#   ('C:min', 'Eb:min', 'N'),
#   ('Ab', 'B:maj7', 'Bb'),
#   ('Ab', 'Bb', 'C:9'),
#   ('F:maj(9)/9', 'G', 'G:min'),
#   ('F', 'F:maj(9)/9', 'G'),
#   ('A', 'A:sus4', 'Ab:min'),
#   ('A', 'G:7', 'N'),
#   ('Bb:maj(9)/9', 'Eb:min', 'N'),
#   ('Bb:min7', 'D:7', 'D:7(#9)'),
#   ('B:min', 'E', 'F#'),
#   ('C#', 'D:7', 'F#'),
#   ('Bb', 'Eb', 'G:7'),
#   ('A', 'B', 'Bb:maj(9)/9'),
#   ('Ab:maj(9)', 'F#', 'N'),
#   ('B:maj/9', 'C', 'C:min'),
#   ('A', 'B:maj/9', 'C'),
#   ('C', 'D#:min', 'G'),
#   ('Ab:min', 'Bb:min7', 'E:min7'),
#   ('C:9', 'G', 'G:sus4(2)'),
#   ('C', 'G:aug', 'N'),
#   ('D:7', 'G:sus4(2)', 'N'),
#   ('D:7', 'D:7(#9)', 'F#:min7'),
#   ('A:7', 'D:7', 'D:7(#9)'),
#   ('Ab:min', 'C', 'Gb'),
#   ('B', 'C/7', 'F#'),
#   ('Ab:min', 'C:sus4/4', 'Gb'),
#   ('D:7', 'D:7(#9)', 'E/6'),
#   ('Bb', 'Bb:min', 'N'),
#   ('A:sus4', 'Ab:min', 'Bb:min7'),
#   ('Ab:min', 'Bb:min', 'G:aug'),
#   ('B:7', 'Bb', 'Eb'),
#   ('Bb', 'C:min(*b3)', 'D:sus4/5'),
#   ('C', 'Eb:7', 'N'),
#   ('Ab', 'B', 'Bb'),
#   ('A', 'B', 'C'),
#   ('Bb', 'Eb', 'G#:min'),
#   ('F#', 'Gb', 'N'),
#   ('C', 'C:sus4/4', 'E:min'),
#   ('B:min/7', 'C:9', 'D:7'),
#   ('B', 'E/5', 'F:maj/9'),
#   ('Ab:maj(9)', 'C:9', 'D:7'),
#   ('C#:min', 'C:min(*b3)', 'G#:7'),
#   ('Bb:maj/9', 'F:maj(9)/9', 'G'),
#   ('A/5', 'D:7', 'D:7(#9)'),
#   ('A:sus4', 'Bb:maj/9', 'C'),
#   ('D#:min', 'G', 'G:sus4(2)'),
#   ('B', 'Bb:min7', 'F#'),
#   ('B:min/6', 'D:7', 'D:7(#9)'),
#   ('Eb', 'F#', 'N'),
#   ('B', 'C:9', 'F#'),
#   ('B', 'Bb:maj(9)/9', 'C#'),
#   ('D:sus4/5', 'E', 'F#'),
#   ('B', 'Bb', 'C#'),
#   ('C', 'Gb', 'N'),
#   ('B', 'D:sus4/5', 'N'),
#   ('C#:min', 'E:min', 'F#:min7'),
#   ('A', 'Db:min', 'N'),
#   ('B:7', 'Bb:maj/9', 'C'),
#   ('B:7', 'D/5', 'F#:min'),
#   ('Bb:7', 'D:7', 'D:7(#9)'),
#   ('B', 'F#', 'G:aug'),
#   ('A', 'B', 'Bb:min7'),
#   ('A', 'B', 'Bb:min'),
#   ('F', 'F#', 'N'),
#   ('B:7', 'F#:min', 'F#:sus4'),
#   ('Bb', 'C:min(*b3)', 'D'),
#   ('C/7', 'D:7', 'D:7(#9)'),
#   ('B', 'D:7(#9)', 'E'),
#   ('Bb', 'C', 'F:min'),
#   ('Bb:maj(9)/9', 'C', 'F:min'),
#   ('Eb:7', 'F:maj(9)/9', 'G'),
#   ('D/5', 'G', 'N'),
#   ('B:maj7', 'C:9', 'D:7'),
#   ('Ab', 'Bb', 'F:maj/9'),
#   ('C:9', 'D:7', 'G/3'),
#   ('A/5', 'C#:min', 'G#:7'),
#   ('B', 'E', 'E:min7'),
#   ('Bb:maj(9)/9', 'C', 'D/5'),
#   ('B', 'C#', 'D:sus4/5'),
#   ('A', 'A:sus4', 'C:sus4/4'),
#   ('C', 'C#:min', 'N'),
#   ('C:9', 'D:7', 'G:sus4(2)'),
#   ('Bb:maj(9)/9', 'C', 'G:sus4(2)'),
#   ('B', 'F#', 'F:maj(9)/9'),
#   ('Bb:min', 'Eb:min', 'N'),
#   ('A', 'B:7', 'N'),
#   ('B', 'C#', 'D:7'),
#   ('Bb:min', 'E', 'F#'),
#   ('Bb', 'Eb:min', 'F:min'),
#   ('C#', 'F#', 'F#:min'),
#   ('B', 'B:min/7', 'N'),
#   ('E:min', 'G', 'G:sus4(2)'),
#   ('Bb', 'E', 'F#'),
#   ('Db:min', 'G', 'N'),
#   ('C', 'E:min', 'G#:7'),
#   ('Ab:min', 'B', 'E/5'),
#   ('Ab', 'B', 'Gb'),
#   ('B:maj/9', 'C', 'E:min6'),
#   ('C:min(*b3)', 'G:min', 'N'),
#   ('A:sus4', 'D:7', 'D:7(#9)'),
#   ('C', 'E:min', 'G:aug'),
#   ('C:min(*b3)', 'Db:min', 'N'),
#   ('Bb:maj(9)/9', 'C', 'Eb:min'),
#   ('A:7', 'C#:min', 'G#:7'),
#   ('B:maj/9', 'C#', 'F#'),
#   ('D', 'E', 'F#'),
#   ('A:sus4', 'E:min', 'F#:min7'),
#   ('Ab:min', 'Bb:min', 'F'),
#   ('A', 'B', 'Bb:maj/9'),
#   ('B:7', 'D:7', 'F:7'),
#   ('C', 'C#', 'N'),
#   ('B', 'Bb:maj(9)/9', 'F#'),
#   ('B', 'E/5', 'G#:7'),
#   ('C:min(*b3)', 'E:min6', 'N'),
#   ('A:7', 'Bb:maj(9)/9', 'C'),
#   ('B', 'Bb:min7', 'N'),
#   ('Bb:maj/9', 'C', 'E/6'),
#   ('Bb:maj/9', 'C', 'G:sus4(2)'),
#   ('E:min', 'F#:min7', 'G:sus4(2)'),
#   ('D:7', 'F:7', 'F:maj(9)/9'),
#   ('Bb:maj/9', 'C', 'F#:min7'),
#   ('G', 'G/3', 'N'),
#   ('C#', 'F#', 'G:7'),
#   ('A:7', 'G', 'G:sus4(2)'),
#   ('Ab:min7', 'F:maj(9)/9', 'G'),
#   ('C#', 'F#', 'G:aug'),
#   ('B', 'C:min(*b3)', 'E/5'),
#   ('A', 'C/7', 'N'),
#   ('C#:min', 'G#:7', 'G#:min'),
#   ('C#:min', 'Db:min', 'G#:7'),
#   ('A', 'A:sus4', 'C/7'),
#   ('B:7', 'F#:min', 'G:min'),
#   ('Ab:min', 'D:7', 'N'),
#   ('Ab:min', 'Bb:min7', 'F:maj/9'),
#   ('C:9', 'D:7', 'Eb:7'),
#   ('A', 'A:sus4', 'Ab'),
#   ('B/5', 'B:7', 'F#:min'),
#   ('A', 'A:sus4', 'D:7'),
#   ('G', 'G:sus4(2)', 'Gb'),
#   ('Ab:maj(9)', 'G', 'N'),
#   ('A:7', 'C:9', 'D:7'),
#   ('Ab:min', 'B/7', 'Gb'),
#   ('B', 'B/5', 'C#'),
#   ('Bb', 'E/7', 'N'),
#   ('C', 'C:min(*b3)', 'G'),
#   ('B', 'F:maj/9', 'N'),
#   ('B', 'Bb:7', 'C#'),
#   ('D:7', 'D:7(#9)', 'F:maj(9)/9'),
#   ('Bb', 'Eb', 'F:maj/9'),
#   ('B', 'E', 'Eb:min'),
#   ('Bb', 'F:maj(9)/9', 'N'),
#   ('Bb:min', 'C#', 'F#'),
#   ('A', 'A:sus4', 'Ab:min7'),
#   ('A:sus4', 'B', 'C#'),
#   ('Bb:maj/9', 'E:min', 'F#:min7'),
#   ('B', 'B:maj7', 'E'),
#   ('D:7', 'Db:min', 'F:7'),
#   ('B:dim', 'Bb:maj(9)/9', 'C'),
#   ('A:7', 'E:min', 'F#:min7'),
#   ('B', 'B/5', 'Gb'),
#   ('A:min', 'Bb', 'C:min(*b3)'),
#   ('B:maj/9', 'C', 'F:dim'),
#   ('Ab:maj(9)', 'Ab:min', 'Bb:min7'),
#   ...},
#  '111D': {('A', 'A/5', 'N'),
#   ('A', 'A:7', 'B'),
#   ('A', 'A:sus4', 'B:dim'),
#   ('A', 'A:sus4', 'Bb'),
#   ('A', 'A:sus4', 'D/5'),
#   ('A', 'A:sus4', 'E/5'),
#   ('A', 'A:sus4', 'E:7'),
#   ('A', 'A:sus4', 'E:maj(b9)'),
#   ('A', 'A:sus4', 'F#:min'),
#   ('A', 'B', 'B:dim'),
#   ('A', 'B', 'D/5'),
#   ('A', 'B:dim', 'N'),
#   ('A', 'C#', 'F#'),
#   ('A', 'D/5', 'N'),
#   ('A', 'E/5', 'N'),
#   ('A', 'E:7', 'N'),
#   ('A', 'E:maj(b9)', 'N'),
#   ('A', 'E:min', 'N'),
#   ('A', 'F#:min', 'N'),
#   ('A', 'F:7', 'N'),
#   ('A/5', 'B', 'N'),
#   ('A/5', 'Bb', 'N'),
#   ('A/5', 'C', 'N'),
#   ('A/5', 'C:min(*b3)', 'N'),
#   ('A/5', 'D:7', 'N'),
#   ('A/5', 'Eb:min', 'N'),
#   ('A/5', 'F#', 'N'),
#   ('A/5', 'G', 'N'),
#   ('A:7', 'B', 'C#'),
#   ('A:7', 'B', 'E/5'),
#   ('A:7', 'B', 'F#'),
#   ('A:7', 'B', 'Gb'),
#   ('A:7', 'B', 'N'),
#   ('A:min7', 'C:9', 'D:7'),
#   ('A:min7', 'D:7', 'D:7(#9)'),
#   ('A:min7', 'D:7', 'F:7'),
#   ('A:min7', 'D:7', 'N'),
#   ('Ab', 'B:min', 'Bb'),
#   ('Ab', 'Bb', 'F'),
#   ('Ab:min', 'B', 'E'),
#   ('Ab:min', 'Bb:min', 'Eb:7'),
#   ('Ab:min', 'Bb:min', 'Eb:min'),
#   ('Ab:min', 'Bb:min7', 'Eb:7'),
#   ('Ab:min', 'Bb:min7', 'Eb:min'),
#   ('Ab:min', 'E', 'F#'),
#   ('Ab:min', 'Eb:7', 'Gb'),
#   ('Ab:min', 'Eb:min', 'Gb'),
#   ('Ab:min7', 'Eb:min', 'N'),
#   ('B', 'B/5', 'E'),
#   ('B', 'C', 'E:min'),
#   ('B', 'C#', 'D'),
#   ('B', 'C#', 'E:7'),
#   ('B', 'C#', 'F#:min'),
#   ('B', 'C#', 'G#:min'),
#   ('B', 'C#:min', 'G#:7'),
#   ('B', 'D', 'E'),
#   ('B', 'D', 'E/5'),
#   ('B', 'D', 'F#'),
#   ('B', 'D', 'Gb'),
#   ('B', 'D', 'N'),
#   ('B', 'E', 'E:7'),
#   ('B', 'E', 'F:dim'),
#   ('B', 'E/5', 'E/6'),
#   ('B', 'E/5', 'E:7'),
#   ('B', 'E/5', 'F#:min'),
#   ('B', 'E:7', 'Gb'),
#   ('B', 'E:7', 'N'),
#   ('B', 'E:min', 'F#:min7'),
#   ('B', 'F#', 'F#:min'),
#   ('B', 'F#', 'F#:sus4'),
#   ('B', 'F#:min', 'Gb'),
#   ('B', 'F#:min', 'N'),
#   ('B', 'F:7', 'N'),
#   ('B/5', 'E', 'F#'),
#   ('B:7', 'C', 'E:min'),
#   ('B:7', 'C', 'F#:min'),
#   ('B:7', 'D', 'F#:min'),
#   ('B:7', 'E', 'F#:min'),
#   ('B:7', 'E:min', 'F#:min7'),
#   ('B:7', 'F#:7', 'F#:min'),
#   ('B:maj/9', 'B:min/6', 'C'),
#   ('B:maj/9', 'C', 'D:7'),
#   ('B:maj/9', 'C', 'E:min/b7'),
#   ('B:maj/9', 'C', 'G/3'),
#   ('B:maj7', 'Eb:min', 'N'),
#   ('B:min', 'Bb', 'C:min(*b3)'),
#   ('B:min', 'Bb', 'Eb'),
#   ('B:min', 'Bb', 'F:min'),
#   ('B:min', 'Bb', 'N'),
#   ('B:min/6', 'Bb:maj(9)/9', 'C'),
#   ('B:min/6', 'Bb:maj/9', 'C'),
#   ('B:min/6', 'C', 'E:min'),
#   ('B:min/6', 'C', 'G'),
#   ('B:min/6', 'C', 'N'),
#   ('Bb', 'C:min(*b3)', 'F'),
#   ('Bb', 'E:min', 'N'),
#   ('Bb', 'Eb', 'F'),
#   ('Bb', 'F', 'F:min'),
#   ('Bb', 'F', 'N'),
#   ('Bb', 'F:7', 'N'),
#   ('Bb:7', 'Eb:min', 'N'),
#   ('Bb:maj(9)/9', 'C', 'D:7'),
#   ('Bb:maj(9)/9', 'C', 'E:min/b7'),
#   ('Bb:maj(9)/9', 'C', 'G/3'),
#   ('Bb:maj/9', 'C', 'D:7'),
#   ('Bb:maj/9', 'C', 'E:min/b7'),
#   ('Bb:maj/9', 'C', 'G/3'),
#   ('C', 'C/3', 'E:min'),
#   ('C', 'C/3', 'G'),
#   ('C', 'D:7', 'E:min'),
#   ('C', 'E:min', 'G/3'),
#   ('C', 'E:min/b7', 'G'),
#   ('C', 'E:min/b7', 'N'),
#   ('C', 'F:7', 'N'),
#   ('C', 'G', 'G/3'),
#   ('C', 'G/3', 'N'),
#   ('C#', 'F#', 'F#:sus4'),
#   ('C#', 'F#', 'G#:min'),
#   ('C/3', 'E:min', 'F#:min7'),
#   ('C/3', 'F:maj(9)/9', 'G'),
#   ('C/3', 'G', 'G:sus4(2)'),
#   ('C/3', 'G', 'N'),
#   ('C:9', 'C:min', 'D:7'),
#   ('C:9', 'D:7', 'G:7'),
#   ('C:min', 'D:7', 'D:7(#9)'),
#   ('C:min', 'D:7', 'F:7'),
#   ('C:min', 'D:7', 'N'),
#   ('C:min(*b3)', 'E:min', 'N'),
#   ('C:min(*b3)', 'F:7', 'N'),
#   ('D', 'F:maj(9)/9', 'G'),
#   ('D', 'G', 'G:sus4(2)'),
#   ('D', 'G', 'N'),
#   ('D:7', 'D:7(#9)', 'G:7'),
#   ('D:7', 'E:7', 'F:7'),
#   ('D:7', 'E:min', 'N'),
#   ('D:7', 'F:7', 'G:7'),
#   ('D:7', 'F:maj(9)/9', 'G'),
#   ('D:7', 'G', 'G:sus4(2)'),
#   ('D:7', 'G:7', 'N'),
#   ('E', 'E/5', 'F#'),
#   ('E', 'F#', 'F#:sus4'),
#   ('E', 'F#', 'F:dim'),
#   ('E:min', 'Eb:min', 'N'),
#   ('E:min', 'F#', 'N'),
#   ('E:min', 'G', 'N'),
#   ('Eb:min', 'F:7', 'N'),
#   ('F#', 'F#:sus4', 'N'),
#   ('F#', 'F:7', 'N'),
#   ('F:7', 'G', 'N')},
#  '111U': {('A', 'A:min', 'A:sus4'),
#   ('A', 'A:sus4', 'D'),
#   ('A', 'A:sus4', 'D:sus4/5'),
#   ('A', 'A:sus4', 'E'),
#   ('A', 'A:sus4', 'F#'),
#   ('A', 'A:sus4', 'F#:7'),
#   ('A', 'B', 'B/7'),
#   ('A', 'B', 'B:min'),
#   ('A', 'B', 'C#:min'),
#   ('A', 'B', 'D:sus4/5'),
#   ('A', 'B', 'E:min'),
#   ('A', 'B', 'F#:7'),
#   ('A', 'B:7', 'F#:min'),
#   ('A', 'D', 'N'),
#   ('A', 'D:sus4/5', 'N'),
#   ('A', 'F#:7', 'N'),
#   ('A/5', 'B', 'E'),
#   ('A/5', 'E', 'F#'),
#   ('A:7', 'E', 'F#'),
#   ('A:min', 'C', 'E:min'),
#   ('A:min', 'E:min', 'F#:min7'),
#   ('A:min7', 'C', 'G'),
#   ('A:min7', 'F:maj(9)/9', 'G'),
#   ('A:min7', 'G', 'G:sus4(2)'),
#   ('A:min7', 'G', 'N'),
#   ('A:sus4', 'Ab', 'Bb'),
#   ('A:sus4', 'Bb', 'C:min(*b3)'),
#   ('A:sus4', 'Bb', 'Eb'),
#   ('A:sus4', 'Bb', 'F:min'),
#   ('A:sus4', 'Bb', 'N'),
#   ('Ab', 'Ab:maj(9)', 'Bb'),
#   ('Ab', 'Bb', 'G:min'),
#   ('Ab:maj(9)', 'Bb', 'C:min(*b3)'),
#   ('Ab:maj(9)', 'Bb', 'F:min'),
#   ('Ab:maj(9)', 'Bb', 'N'),
#   ('Ab:min', 'B:maj7', 'Bb:min'),
#   ('Ab:min', 'B:maj7', 'Bb:min7'),
#   ('Ab:min', 'B:maj7', 'Gb'),
#   ('Ab:min', 'Bb:7', 'Gb'),
#   ('Ab:min', 'Bb:min', 'E'),
#   ('Ab:min', 'Bb:min7', 'E'),
#   ('Ab:min', 'E', 'Gb'),
#   ('Ab:min', 'Eb:min', 'N'),
#   ('B', 'B/7', 'C#'),
#   ('B', 'B/7', 'E'),
#   ('B', 'B/7', 'E/5'),
#   ('B', 'B/7', 'F#'),
#   ('B', 'B/7', 'Gb'),
#   ('B', 'B/7', 'N'),
#   ('B', 'B:7', 'F#:min'),
#   ('B', 'B:min', 'C#'),
#   ('B', 'B:min', 'E'),
#   ('B', 'B:min', 'E/5'),
#   ('B', 'B:min', 'F#'),
#   ('B', 'B:min', 'Gb'),
#   ('B', 'B:min', 'N'),
#   ('B', 'Bb:7', 'Gb'),
#   ('B', 'C#', 'C#:min'),
#   ('B', 'C#', 'E:maj(b9)'),
#   ('B', 'C#', 'E:min'),
#   ('B', 'C#:min', 'E'),
#   ('B', 'C#:min', 'E/5'),
#   ('B', 'C#:min', 'F#'),
#   ('B', 'C#:min', 'Gb'),
#   ('B', 'C#:min', 'N'),
#   ('B', 'D#:min', 'F#'),
#   ('B', 'E', 'E/7'),
#   ('B', 'E', 'E:maj(b9)'),
#   ('B', 'E', 'E:min'),
#   ('B', 'E', 'Eb:7'),
#   ('B', 'E', 'G#:min'),
#   ('B', 'E/5', 'E:maj(b9)'),
#   ('B', 'E/5', 'E:min'),
#   ('B', 'E:maj(b9)', 'F#'),
#   ('B', 'E:maj(b9)', 'Gb'),
#   ('B', 'E:maj(b9)', 'N'),
#   ('B', 'E:min', 'F#'),
#   ('B', 'E:min', 'Gb'),
#   ('B:7', 'E:7', 'F#:min'),
#   ('B:7', 'E:min', 'F#:min'),
#   ('B:maj/9', 'C', 'C/7'),
#   ('B:maj/9', 'C', 'D'),
#   ('B:maj/9', 'C', 'F#:min'),
#   ('B:maj/9', 'C', 'G:7'),
#   ('B:min', 'C', 'G'),
#   ('B:min', 'G', 'G:sus4(2)'),
#   ('B:min', 'G', 'N'),
#   ('Bb', 'C:min(*b3)', 'G:min'),
#   ('Bb', 'E', 'N'),
#   ('Bb', 'Eb', 'G:min'),
#   ('Bb', 'F:min', 'G:min'),
#   ('Bb', 'G:min', 'N'),
#   ('Bb:maj(9)/9', 'C', 'C/7'),
#   ('Bb:maj(9)/9', 'C', 'D'),
#   ('Bb:maj(9)/9', 'C', 'F#:min'),
#   ('Bb:maj(9)/9', 'C', 'G:7'),
#   ('Bb:maj/9', 'C', 'C/7'),
#   ('Bb:maj/9', 'C', 'D'),
#   ('Bb:maj/9', 'C', 'F#:min'),
#   ('Bb:maj/9', 'C', 'G:7'),
#   ('C', 'C/7', 'E:min'),
#   ('C', 'C/7', 'G'),
#   ('C', 'C/7', 'N'),
#   ('C', 'C:9', 'D:7'),
#   ('C', 'D', 'E:min'),
#   ('C', 'D', 'N'),
#   ('C', 'D:7', 'D:7(#9)'),
#   ('C', 'D:7', 'F:7'),
#   ('C', 'E', 'N'),
#   ('C', 'E:min', 'E:min7'),
#   ('C', 'E:min', 'F#:min'),
#   ('C', 'E:min', 'G:7'),
#   ('C', 'F#:min', 'G'),
#   ('C', 'F#:min', 'N'),
#   ('C', 'F:maj/9', 'G'),
#   ('C', 'G', 'G:7'),
#   ('C', 'G:7', 'N'),
#   ('C#', 'D#:min', 'F#'),
#   ('C#', 'E:7', 'F#'),
#   ('C#:min', 'F#:sus4', 'G#:7'),
#   ('C:9', 'D', 'D:7'),
#   ('C:9', 'D:7', 'G'),
#   ('C:9', 'D:7', 'G:min'),
#   ('C:min(*b3)', 'E', 'N'),
#   ('D', 'D:7', 'D:7(#9)'),
#   ('D', 'D:7', 'F:7'),
#   ('D', 'D:7', 'N'),
#   ('D#:min', 'E', 'F#'),
#   ('D#:min', 'F#', 'N'),
#   ('D:7', 'D:7(#9)', 'G'),
#   ('D:7', 'D:7(#9)', 'G:min'),
#   ('D:7', 'E', 'N'),
#   ('D:7', 'F:7', 'G'),
#   ('D:7', 'F:7', 'G:min'),
#   ('D:7', 'G:min', 'N'),
#   ('Db:min', 'Eb:min', 'N'),
#   ('E', 'E/7', 'F#'),
#   ('E', 'E:7', 'F#'),
#   ('E', 'Eb:7', 'F#'),
#   ('E', 'Eb:min', 'N'),
#   ('E', 'F#', 'F#:min'),
#   ('E', 'F#', 'G#:min'),
#   ('E', 'G', 'N'),
#   ('E:7', 'F#', 'N'),
#   ('E:min', 'E:min/b7', 'F#:min7'),
#   ('E:min', 'E:min7', 'F#:min7'),
#   ('E:min', 'F#:min7', 'N'),
#   ('F:maj(9)/9', 'F:maj/9', 'G'),
#   ('F:maj/9', 'G', 'G:sus4(2)'),
#   ('F:maj/9', 'G', 'N')},
#  '120C': {('A', 'B', 'D'),
#   ('A', 'B', 'E:maj(b9)'),
#   ('A:7', 'B', 'E'),
#   ('Ab:maj(9)', 'Bb', 'Eb'),
#   ('B', 'E', 'F#:min'),
#   ('B', 'E:7', 'F#'),
#   ('B', 'E:min', 'N'),
#   ('C', 'D', 'G'),
#   ('C', 'E:min', 'E:min/b7')},
#  '120D': {('A', 'B', 'E:7'),
#   ('A', 'B', 'F#:min'),
#   ('A', 'E', 'F#'),
#   ('C', 'D:7', 'G')},
#  '120U': {('A', 'E', 'N'), ('B:min', 'F:maj(9)/9', 'G')},
#  '201': {('A', 'A:sus4', 'B'),
#   ('A', 'A:sus4', 'N'),
#   ('A', 'B', 'C#'),
#   ('A', 'B', 'Gb'),
#   ('A', 'Bb', 'N'),
#   ('A', 'C', 'N'),
#   ('A', 'C:min(*b3)', 'N'),
#   ('A', 'D:7', 'N'),
#   ('A', 'Eb:min', 'N'),
#   ('A', 'G', 'N'),
#   ('Ab', 'Bb', 'C:min(*b3)'),
#   ('Ab', 'Bb', 'F:min'),
#   ('Ab', 'Bb', 'N'),
#   ('Ab:min', 'B', 'Gb'),
#   ('Ab:min', 'Bb:min', 'Bb:min7'),
#   ('Ab:min', 'Bb:min', 'Gb'),
#   ('Ab:min', 'Bb:min7', 'Gb'),
#   ('B', 'Bb', 'N'),
#   ('B', 'C', 'N'),
#   ('B', 'C#', 'E'),
#   ('B', 'C#', 'E/5'),
#   ('B', 'C#', 'Gb'),
#   ('B', 'C#', 'N'),
#   ('B', 'C:min(*b3)', 'N'),
#   ('B', 'D:7', 'N'),
#   ('B', 'E', 'Gb'),
#   ('B', 'E/5', 'F#'),
#   ('B', 'E/5', 'Gb'),
#   ('B', 'E/5', 'N'),
#   ('B', 'Eb:min', 'N'),
#   ('B', 'F#', 'Gb'),
#   ('B', 'G', 'N'),
#   ('B', 'Gb', 'N'),
#   ('B:maj/9', 'Bb:maj(9)/9', 'C'),
#   ('B:maj/9', 'Bb:maj/9', 'C'),
#   ('B:maj/9', 'C', 'E:min'),
#   ('B:maj/9', 'C', 'G'),
#   ('B:maj/9', 'C', 'N'),
#   ('Bb', 'C', 'N'),
#   ('Bb', 'C:min(*b3)', 'Eb'),
#   ('Bb', 'C:min(*b3)', 'F:min'),
#   ('Bb', 'D:7', 'N'),
#   ('Bb', 'Eb', 'F:min'),
#   ('Bb', 'Eb', 'N'),
#   ('Bb', 'Eb:min', 'N'),
#   ('Bb', 'F#', 'N'),
#   ('Bb', 'F:min', 'N'),
#   ('Bb', 'G', 'N'),
#   ('Bb:maj(9)/9', 'Bb:maj/9', 'C'),
#   ('Bb:maj(9)/9', 'C', 'E:min'),
#   ('Bb:maj(9)/9', 'C', 'G'),
#   ('Bb:maj(9)/9', 'C', 'N'),
#   ('Bb:maj/9', 'C', 'E:min'),
#   ('Bb:maj/9', 'C', 'G'),
#   ('Bb:maj/9', 'C', 'N'),
#   ('C', 'C:min(*b3)', 'N'),
#   ('C', 'E:min', 'F#:min7'),
#   ('C', 'E:min', 'G'),
#   ('C', 'Eb:min', 'N'),
#   ('C', 'F#', 'N'),
#   ('C', 'F:maj(9)/9', 'G'),
#   ('C', 'G', 'G:sus4(2)'),
#   ('C#', 'E', 'F#'),
#   ('C#', 'F#', 'N'),
#   ('C:9', 'D:7', 'D:7(#9)'),
#   ('C:9', 'D:7', 'F:7'),
#   ('C:9', 'D:7', 'N'),
#   ('C:min(*b3)', 'D:7', 'N'),
#   ('C:min(*b3)', 'Eb:min', 'N'),
#   ('C:min(*b3)', 'F#', 'N'),
#   ('C:min(*b3)', 'G', 'N'),
#   ('D:7', 'D:7(#9)', 'F:7'),
#   ('D:7', 'D:7(#9)', 'N'),
#   ('D:7', 'Eb:min', 'N'),
#   ('D:7', 'F#', 'N'),
#   ('Eb:min', 'F#', 'N'),
#   ('Eb:min', 'G', 'N'),
#   ('F#', 'G', 'N'),
#   ('F:maj(9)/9', 'G', 'G:sus4(2)'),
#   ('F:maj(9)/9', 'G', 'N'),
#   ('G', 'G:sus4(2)', 'N')},
#  '210': {('A', 'B', 'E'),
#   ('A', 'B', 'E/5'),
#   ('A', 'B', 'F#'),
#   ('A', 'F#', 'N'),
#   ('Ab', 'Bb', 'Eb'),
#   ('B', 'E', 'E/5'),
#   ('B', 'E', 'N'),
#   ('C', 'D:7', 'N'),
#   ('C', 'E:min', 'N'),
#   ('D:7', 'F:7', 'N'),
#   ('D:7', 'G', 'N'),
#   ('E', 'F#', 'N')},
#  '300': {('A', 'B', 'N'),
#   ('B', 'C#', 'F#'),
#   ('B', 'E', 'F#'),
#   ('B', 'F#', 'N'),
#   ('Bb', 'C:min(*b3)', 'N'),
#   ('C', 'G', 'N')}}

# %%
from collections import Counter
counter=Counter(new)
print(counter)
# Out:
# Counter({('B', 'B:7', 'C:min'): 1, ('D', 'D#:min', 'B:maj/9'): 1, ('Bb:min', 'Bb:min7', 'A/5'): 1, ('D:7(#9)', 'G:7', 'Bb:7'): 1, ('B', 'Bb:min', 'G:aug'): 1, ('B', 'B:maj7', 'B:7'): 1, ('B', 'Bb:7', 'G/3'): 1, ('G:7', 'Eb:7', 'C#'): 1, ('Eb:min', 'Ab:maj(9)', 'F:maj(9)/9'): 1, ('Gb', 'G', 'B:min/6'): 1, ('C', 'C:min(*b3)', 'E:7'): 1, ('A:7', 'C/7', 'F:maj/9'): 1, ('Bb:min7', 'F', 'E:maj(b9)'): 1, ('E:min6', 'Ab:min', 'D:sus4/5'): 1, ('Eb:7', 'E/5', 'F#:sus4'): 1, ('C/3', 'D#:min', 'Ab:maj(9)'): 1, ('D#:min', 'G:aug', 'G:sus4(2)'): 1, ('N', 'A:min7', 'A/5'): 1, ('E', 'A:min7', 'E/5'): 1, ('D#:min', 'Eb', 'B/5'): 1, ('Ab:maj(9)', 'F#:7', 'B:maj/9'): 1, ('Bb:min', 'D#:min', 'E/6'): 1, ('D:7', 'F:7', 'E:min/b7'): 1, ('Gb', 'Bb:7', 'Bb'): 1, ('G:min', 'B/5', 'B:min/b7'): 1, ('D:7(#9)', 'Bb:min', 'F#:min'): 1, ('Gb', 'Bb:7', 'Eb'): 1, ('F#:min7', 'F#', 'B:maj/9'): 1, ('F#:min7', 'E:7', 'E:maj(b9)'): 1, ('F#:min7', 'B:7', 'G#:7'): 1, ('F#:min7', 'G#:7', 'B:maj/9'): 1, ('Bb:min7', 'A:sus4', 'D'): 1, ('D:7', 'E:min', 'C/3'): 1, ('N', 'C', 'C/3'): 1, ('F#:min', 'E/5', 'G:sus4(2)'): 1, ('B', 'F:maj/9', 'C:sus4/4'): 1, ('C:9', 'E/7', 'A/5'): 1, ('A:min', 'C/7', 'B:maj/9'): 1, ('D', 'Eb', 'F:maj(9)/9'): 1, ('E:min/b7', 'C:min(*b3)', 'A/5'): 1, ('G', 'G#:min', 'E/7'): 1, ('D#:min', 'F:dim', 'F#:sus4'): 1, ('A:min7', 'F:maj(9)/9', 'B:min/b7'): 1, ('C:min', 'F#', 'B/7'): 1, ('B:7', 'Ab:maj(9)', 'F#:7'): 1, ('F:7', 'Ab:min7', 'F:min'): 1, ('G', 'D', 'F#:sus4'): 1, ('Ab:min7', 'B:min/6', 'B:maj/9'): 1, ('C:9', 'G#:7', 'B:dim'): 1, ('G/3', 'G#:7', 'B:min/b7'): 1, ('Bb:min', 'C#:min', 'B:min/6'): 1, ('F:7', 'C/3', 'A'): 1, ('B/5', 'F:dim', 'B:min/6'): 1, ('E:min/b7', 'Bb:min', 'B:min'): 1, ('N', 'G/3', 'F#:sus4'): 1, ('Ab:maj(9)', 'B/7', 'F:maj/9'): 1, ('G', 'F:maj(9)/9', 'B:min/6'): 1, ('G:7', 'F#:min', 'F:maj/9'): 1, ('B:min', 'Ab', 'B:min/6'): 1, ('G:7', 'Bb', 'C/7'): 1, ('B:maj7', 'E:7', 'G:sus4(2)'): 1, ('Bb:min7', 'F:min', 'F:maj(9)/9'): 1, ('E:min', 'G', 'F#:7'): 1, ('C:9', 'E/7', 'E/6'): 1, ('E:min6', 'F#:7', 'E/7'): 1, ('Db:min', 'B:min', 'C:min'): 1, ('Gb', 'A:sus4', 'C:min'): 1, ('F#:min7', 'E', 'B:min/7'): 1, ('C/3', 'F:min', 'F#:sus4'): 1, ('D#:min', 'G#:min', 'F#:7'): 1, ('F:7', 'Ab:min7', 'E/5'): 1, ('G', 'E/7', 'E/6'): 1, ('E:min/b7', 'B/7', 'F:maj/9'): 1, ('A:min7', 'Ab', 'F:dim'): 1, ('N', 'F#', 'A:7'): 1, ('Ab:min7', 'G:min', 'Ab:maj(9)'): 1, ('G:7', 'Bb:7', 'A:7'): 1, ('C:9', 'A/5', 'G:sus4(2)'): 1, ('E:min/b7', 'Gb', 'Bb:maj/9'): 1, ('Bb:min7', 'B/7', 'F:maj(9)/9'): 1, ('C:min', 'G:sus4(2)', 'Bb:maj/9'): 1, ('C/3', 'Bb:min7', 'B:maj/9'): 1, ('E:min/b7', 'Bb:min', 'B:min/7'): 1, ('N', 'Eb:7', 'G:sus4(2)'): 1, ('E:min6', 'Bb:min7', 'B:maj/9'): 1, ('C:min(*b3)', 'B:7', 'F#:sus4'): 1, ('E:min/b7', 'E:7', 'G#:7'): 1, ('B/7', 'G:sus4(2)', 'B:maj/9'): 1, ('G:7', 'A/5', 'B/7'): 1, ('Eb:min', 'E:maj(b9)', 'F:maj(9)/9'): 1, ('C#', 'E/5', 'D/5'): 1, ('G:7', 'Ab:min7', 'C:min(*b3)'): 1, ('A:min7', 'G:sus4(2)', 'Bb:maj(9)/9'): 1, ('Ab:min', 'Gb', 'E/6'): 1, ('A:min', 'G#:min', 'Bb:maj(9)/9'): 1, ('E:min', 'E', 'D#:min'): 1, ('G#:min', 'F#:7', 'A:7'): 1, ('Eb:min', 'Bb:7', 'E/6'): 1, ('Bb', 'B:min', 'D/5'): 1, ('Gb', 'F', 'A'): 1, ('C:9', 'E/6', 'B:min/b7'): 1, ('D:7(#9)', 'E', 'B:min/b7'): 1, ('E:min/b7', 'G:min', 'Bb:maj(9)/9'): 1, ('A:min7', 'B/5', 'C/7'): 1, ('Gb', 'G#:min', 'E:maj(b9)'): 1, ('Ab:min7', 'B:7', 'D/5'): 1, ('C:9', 'G', 'B/5'): 1, ('C#:min', 'F#:sus4', 'B:maj/9'): 1, ('C:min(*b3)', 'D:sus4/5', 'B:dim'): 1, ('C:min', 'A', 'A/5'): 1, ('D:7(#9)', 'E', 'B:dim'): 1, ('E/7', 'G#:7', 'B:min/7'): 1, ('C:min(*b3)', 'A:min', 'Ab:maj(9)'): 1, ('E:min7', 'F#:7', 'F:dim'): 1, ('Bb', 'C#', 'A:7'): 1, ('B:min', 'A', 'E/5'): 1, ('E:min', 'F', 'A/5'): 1, ('Eb:min', 'C:min', 'C#:min'): 1, ('E:min7', 'E:min6', 'B/7'): 1, ('D:7(#9)', 'B:min', 'F#'): 1, ('B:7', 'A', 'B:maj/9'): 1, ('A:min7', 'F#:7', 'F#:sus4'): 1, ('A:min7', 'F:min', 'F#:sus4'): 1, ('Bb:7', 'Bb:min', 'F#'): 1, ('Ab', 'F#:7', 'C#:min'): 1, ('F#:min', 'A/5', 'F#:sus4'): 1, ('C ...
