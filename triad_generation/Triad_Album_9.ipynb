# %%
#9, 10, 11
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
#motifs, chord pregressoionn and trials

# %%
pwd
# Out:
# '/content'

# %%
album01 = pd.read_csv('/content/album_09_edges.csv')
G = nx.from_pandas_edgelist(album01, source="Source", target="Target", create_using=nx.DiGraph())
nx.draw(G, with_labels=True)

# %% [markdown]
# ## Visuals

# %%
nx.draw(G,node_size=300,font_size=8,  with_labels=True)

# %%
plt.figure(3,figsize=(12,12)) 
nx.draw(G, node_size=400,font_size=12,  with_labels=True)

# %% [markdown]
# ## Triads

# %%
# Triad Consensus
nx.triadic_census(G)
# Out:
# {'003': 120233,
#  '012': 13654,
#  '021C': 407,
#  '021D': 135,
#  '021U': 205,
#  '030C': 10,
#  '030T': 16,
#  '102': 3011,
#  '111D': 315,
#  '111U': 248,
#  '120C': 25,
#  '120D': 11,
#  '120U': 7,
#  '201': 97,
#  '210': 28,
#  '300': 13}

# %%
import networkx as nx
import itertools


def _tricode(G, v, u, w):
    """Returns the integer code of the given triad.

    This is some fancy magic that comes from Batagelj and Mrvar's paper. It
    treats each edge joining a pair of `v`, `u`, and `w` as a bit in
    the binary representation of an integer.

    """
    combos = ((v, u, 1), (u, v, 2), (v, w, 4), (w, v, 8), (u, w, 16),
              (w, u, 32))
    return sum(x for u, v, x in combos if v in G[u])


# G = nx.DiGraph()
# G.add_nodes_from([1, 2, 3, 4, 5])
# G.add_edges_from([(1, 2), (2, 3), (2, 4), (4, 5)])

#: The integer codes representing each type of triad.
#: Triads that are the same up to symmetry have the same code.
TRICODES = (1, 2, 2, 3, 2, 4, 6, 8, 2, 6, 5, 7, 3, 8, 7, 11, 2, 6, 4, 8, 5, 9,
            9, 13, 6, 10, 9, 14, 7, 14, 12, 15, 2, 5, 6, 7, 6, 9, 10, 14, 4, 9,
            9, 12, 8, 13, 14, 15, 3, 7, 8, 11, 7, 12, 14, 15, 8, 14, 13, 15,
            11, 15, 15, 16)

#: The names of each type of triad. The order of the elements is
#: important: it corresponds to the tricodes given in :data:`TRICODES`.
TRIAD_NAMES = ('003', '012', '102', '021D', '021U', '021C', '111D', '111U',
               '030T', '030C', '201', '120D', '120U', '120C', '210', '300')

#: A dictionary mapping triad code to triad name.
TRICODE_TO_NAME = {i: TRIAD_NAMES[code - 1] for i, code in enumerate(TRICODES)}

triad_nodes = {name: set([]) for name in TRIAD_NAMES}
m = {v: i for i, v in enumerate(G)}
for v in G:
    vnbrs = set(G.pred[v]) | set(G.succ[v])
    for u in vnbrs:
        if m[u] > m[v]:
            unbrs = set(G.pred[u]) | set(G.succ[u])
            neighbors = (vnbrs | unbrs) - {u, v}
            not_neighbors = set(G.nodes()) - neighbors - {u, v}
            # Find dyadic triads
            for w in not_neighbors:
                if v in G[u] and u in G[v]:
                    triad_nodes['102'].add(tuple(sorted([u, v, w])))
                else:
                    triad_nodes['012'].add(tuple(sorted([u, v, w])))
            for w in neighbors:
                if m[u] < m[w] or (m[v] < m[w] < m[u] and
                                   v not in G.pred[w] and
                                   v not in G.succ[w]):
                    code = _tricode(G, v, u, w)
                    triad_nodes[TRICODE_TO_NAME[code]].add(
                        tuple(sorted([u, v, w])))
# find null triads
all_tuples = set()
for s in triad_nodes.values():
    all_tuples = all_tuples.union(s)
new = triad_nodes['003'] = set(itertools.combinations(G.nodes(), 3)).difference(all_tuples)

triad_nodes
# Out:
# {'003': {('E:min', 'F:7', 'B/7'),
#   ('A', 'F:min7', 'B/5'),
#   ('D', 'F#:min7', 'D:min'),
#   ('E', 'C', 'E:7'),
#   ('E:min', 'C/9', 'D/3'),
#   ('G:min/5', 'G:maj6/5', 'F#:dim'),
#   ('F:7', 'A/5', 'F/5'),
#   ('Eb/5', 'Eb/3', 'G/5'),
#   ('N', 'D:7', 'Eb'),
#   ('E', 'D:min7/4', 'Eb'),
#   ('A:7', 'C:maj(#11)', 'E:min/b7'),
#   ('A/b7', 'A:dim7/b3', 'F:min/b7'),
#   ('F:maj6', 'D/3', 'F#:dim/b7'),
#   ('G', 'E:7', 'D:7/2'),
#   ('D:min', 'C:7', 'E:min/b7'),
#   ('D:maj6', 'D:min7', 'C/9'),
#   ('G:maj6', 'A:min/5', 'F:min'),
#   ('F#:min7', 'A/b7', 'Eb/2'),
#   ('Eb', 'F#:dim/b7', 'G:maj7/5'),
#   ('Bb/3', 'A:dim/b5', 'E:min/b7'),
#   ('F', 'D:min7/4', 'C/9'),
#   ('F/3', 'F:7/b7', 'B:min'),
#   ('A:min/5', 'Bb/b7', 'G#:hdim7'),
#   ('D/b7', 'A:dim7/b3', 'Eb/3'),
#   ('G:maj6/2', 'D:7', 'A:dim7/b3'),
#   ('D:maj(11)', 'F:maj6', 'A:min/5'),
#   ('G:7', 'A/b7', 'D:dim'),
#   ('G:maj6/5', 'F:7/b7', 'F#:dim/b7'),
#   ('G#:(1)', 'Ab/7', 'G#:hdim7'),
#   ('G/3', 'G:maj6', 'G:9(*3)'),
#   ('D:min', 'D:maj(9)', 'Ab'),
#   ('A:7', 'Eb', 'B/6'),
#   ('D/5', 'D:maj6', 'F#:sus4'),
#   ('D:maj6/5', 'D:dim', 'E:min/b7'),
#   ('B', 'A/3', 'E/5'),
#   ('D:maj(9)', 'G:min', 'A:dim/b3'),
#   ('A:min', 'A:dim7/b3', 'Eb/5'),
#   ('G:min/5', 'F:7', 'A:dim7/b3'),
#   ('D:min', 'F/5', 'F#:sus4'),
#   ('G', 'C/7', 'G:9(*3)'),
#   ('G:min(9)/b3', 'B', 'F#'),
#   ('F:maj7', 'A:dim7/b3', 'B/6'),
#   ('Bb', 'A:min', 'C/9'),
#   ('B:min7', 'D:7', 'Eb:dim'),
#   ('A:dim/b5', 'D:dim', 'G/5'),
#   ('F:7', 'A:dim/b3', 'B/3'),
#   ('F:min7', 'G/5', 'E:min/b7'),
#   ('D/b7', 'G:min/5', 'D:7/2'),
#   ('A', 'B:min7', 'Bb:(1)'),
#   ('D:maj(9)', 'Eb:dim', 'F:(1)'),
#   ('F', 'F:maj/9', 'B:min'),
#   ('F#:dim', 'F:maj7', 'D:min7/4'),
#   ('G/3', 'G:min', 'B/7'),
#   ('A:7', 'F:maj6', 'B/6'),
#   ('F:(1)', 'B/5', 'A/3'),
#   ('A:min', 'A:dim/b3', 'G/5'),
#   ('B:min7', 'Bb:(1)', 'B/5'),
#   ('G/3', 'A:7', 'E/5'),
#   ('A', 'Eb:dim', 'F#:dim/b7'),
#   ('C/5', 'D:min7', 'E/5'),
#   ('C', 'D:min7', 'D:7'),
#   ('G/3', 'G:7', 'F#:dim/b7'),
#   ('G#:(1)', 'D:min/b3', 'Eb/3'),
#   ('A', 'Eb/3', 'D:7/2'),
#   ('E', 'D:7', 'F:min7'),
#   ('A', 'F:min/b7', 'D/3'),
#   ('F#:min7', 'D:maj6', 'G/5'),
#   ('G', 'D:min7', 'Ab/b7'),
#   ('G:min/5', 'Bb/b7', 'C/9'),
#   ('D:min7', 'Eb/2', 'C#:min7'),
#   ('F:7', 'F#:dim', 'E:maj6'),
#   ('Bb:(1)', 'E:maj6', 'F#:sus4'),
#   ('G:maj6/3', 'F/3', 'F:(1)'),
#   ('C/7', 'F#:sus4', 'F#'),
#   ('F#:dim', 'D:min/b3', 'F:min/b7'),
#   ('F#:min7', 'F#', 'C/9'),
#   ('C/7', 'F:maj/9', 'A/3'),
#   ('Ab', 'E:maj6', 'F#'),
#   ('B', 'F:min7', 'C#:min7'),
#   ('G/3', 'G:min(9)/b3', 'B:min7'),
#   ('G:min', 'F:min7', 'F#'),
#   ('G', 'D:maj6/5', 'G:9(*3)'),
#   ('F#:dim', 'D#:dim7', 'A/b7'),
#   ('D:maj(9)', 'A:min/5', 'A/3'),
#   ('B', 'G:maj6', 'F:min'),
#   ('D:maj(9)', 'G:min/b7', 'Eb/3'),
#   ('N', 'D:7', 'C:maj(#11)'),
#   ('Bb/3', 'F:maj6', 'F#:sus4'),
#   ('D:min7', 'G:9(*3)', 'G:(1)'),
#   ('D', 'Bb:(1)', 'C#:min7'),
#   ('A:min', 'D:min7/4', 'A:dim/b5'),
#   ('G/3', 'D:min', 'F:min'),
#   ('N', 'B/6', 'E/5'),
#   ('N', 'D:min/b3', 'D:maj(11)'),
#   ('G:maj6/5', 'Eb:dim', 'Bb/b7'),
#   ('A/5', 'F:(1)', 'C#:min7'),
#   ('C/5', 'G:7', 'Eb'),
#   ('C', 'F/5', 'F:min7'),
#   ('G:7', 'D/3', 'D:7/2'),
#   ('G', 'G/3', 'Eb:dim'),
#   ('B', 'A/5', 'D:7/2'),
#   ('C', 'G:maj6/5', 'A/3'),
#   ('G', 'G:maj6/2', 'A/5'),
#   ('F#:min7', 'B:min', 'D/3'),
#   ('C/5', 'A:min/5', 'A:dim/b5'),
#   ('D:maj6', 'D#:dim7', 'G#:hdim7'),
#   ('F:7', 'B/5', 'D:7/2'),
#   ('G:9(*3)', 'D:maj(11)', 'F/5'),
#   ('B:min7', 'F/3', 'F#'),
#   ('D:maj6', 'G:9(*3)', 'G:maj7/5'),
#   ('D:min7/4', 'Ab/7', 'F:min'),
#   ('D/b7', 'F:7/b7', 'G:(1)'),
#   ('D:maj6', 'Eb', 'E/5'),
#   ('G:min(9)/b3', 'B:min7', 'F:min7'),
#   ('A', 'Bb/3', 'F'),
#   ('F', 'G/5', 'Bb:(1)'),
#   ('D/5', 'G/5', 'G:maj7'),
#   ('D:min/b3', 'Eb/3', 'B/5'),
#   ('G:9(*3)', 'F:maj6', 'Ab/b7'),
#   ('G', 'D:min7/4', 'F:min7'),
#   ('G:maj7', 'B/3', 'F#:dim/b7'),
#   ('G', 'D:min7/4', 'G:(1)'),
#   ('G:9(*3)', 'A:dim7/b3', 'B:min'),
#   ('D:maj6', 'Bb/3', 'C#:min7'),
#   ('Bb', 'D:7', 'F:min/b7'),
#   ('C/5', 'Eb:dim', 'G:maj7/5'),
#   ('Ab', 'Eb:dim', 'A/3'),
#   ('E', 'F#:dim', 'G/5'),
#   ('G#:(1)', 'G:min/5', 'D:7'),
#   ('G:min/5', 'Bb/3', 'F'),
#   ('Ab/b7', 'A:min/5', 'D/3'),
#   ('G:maj6/3', 'B:min7', 'G:9(*3)'),
#   ('Eb/5', 'B:min', 'F#:dim/b7'),
#   ('F:maj6', 'D:7/2', 'G:maj7/5'),
#   ('A:7', 'D:7', 'C:maj(#11)'),
#   ('G:min(9)/b3', 'A/5', 'D:7'),
#   ('F:min/b7', 'B/5', 'F/9'),
#   ('C:7', 'A:7', 'D:7/2'),
#   ('A:dim7/b3', 'G:maj7', 'F/9'),
#   ('G:maj6/3', 'Eb', 'F/5'),
#   ('B', 'C', 'Ab'),
#   ('E', 'Eb/3', 'B/7'),
#   ('E', 'A/5', 'F:maj6'),
#   ('G:min/5', 'A/5', 'F#'),
#   ('F#:dim', 'Eb', 'G:min'),
#   ('D:min/b3', 'F#', 'G#:hdim7'),
#   ('D:min7/4', 'A:dim/b3', 'F#:sus4'),
#   ('F#:min7', 'D:min', 'F/3'),
#   ('A', 'A/5', 'B/7'),
#   ('N', 'G:maj6/3', 'F:maj/9'),
#   ('A:dim7/b3', 'G:min/b7', 'E:min/b7'),
#   ('G:9(*3)', 'A/b7', 'Eb:dim'),
#   ('B:min7', 'E:7', 'E:maj6'),
#   ('A:dim/b5', 'Eb/2', 'F#:sus4'),
#   ('G#:(1)', 'G:maj6/5', 'G:min'),
#   ('Ab/b7', 'F:7/b7', 'B/3'),
#   ('D/b7', 'D:dim', 'G:maj7/5'),
#   ('G/3', 'D/5', 'C#:min7'),
#   ('B:min7', 'F:7', 'Eb/3'),
#   ('F:maj/9', 'Bb/b7', 'D/3'),
#   ('N', 'G:maj6/5', 'F:7'),
#   ('Eb/5', 'D:dim', 'F/9'),
#   ('C/5', 'G#:hdim7', 'E/5'),
#   ('F:7', 'G:min/b7', 'B/6'),
#   ('G#:(1)', 'Bb', 'Ab'),
#   ('G:maj6', 'A:7', 'Ab/b7'),
#   ('C', 'E:maj6', 'F#:dim/b7'),
#   ('E', 'Ab/7', 'D/3'),
#   ('D:min/b3', 'G:(1)', 'D/3'),
#   ('C:7', 'G:min', 'C#:min7'),
#   ('D/5', 'C#:min7', 'F/9'),
#   ('D:maj6', 'F#:dim', 'C/7'),
#   ('D/5', 'G:min', 'E:min/b7'),
#   ('D:maj6', 'Eb/2', 'F/9'),
#   ('N', 'D/b7', 'G#:(1)'),
#   ('F:(1)', 'C#:min7', 'C/9'),
#   ('D', 'F:7', 'D:min7/4'),
#   ('G:(1)', 'B/5', 'G#:hdim7'),
#   ('G:maj6/2', 'F:maj/9', 'Bb/b7'),
#   ('F:maj/9', 'Eb/3', 'B/5'),
#   ('A:min/5', 'A:dim/b3', 'B/6'),
#   ('A', 'G:7', 'B/6'),
#   ('G:min(9)/b3', 'B:min7', 'B:min'),
#   ('G:maj6', 'Eb', 'F#:sus4'),
#   ('D#:dim7', 'G:9(*3)', 'D:dim'),
#   ('G:min/5', 'D:min/b3', 'G:maj7'),
#   ('F#:min7', 'A/5', 'A:dim7/b3'),
#   ('D', 'A:dim/b5', 'Eb'),
#   ('D/b7', 'F/5', 'G:maj7/5'),
#   ('E', 'G:min/5', 'A:dim/b5'),
#   ('D:maj(9)', 'A:dim/b5', 'G:min'),
#   ('Eb', 'F:min', 'E:maj6'),
#   ('C', 'C/7', 'B/5'),
#   ('D', 'F:maj6', 'F/3'),
#   ('D:min', 'G:min', 'F#'),
#   ('G:maj6/5', 'D:min7/4', 'F#:dim/b7'),
#   ('E', 'A:min', 'C/9'),
#   ('Eb/3', 'E:maj6', 'F#'),
#   ('D:maj6/5', 'D:7', 'E:7'),
#   ('D:min', 'G:9(*3)', 'F:min/b7'),
#   ('G#:(1)', 'F:(1)', 'G:(1)'),
#   ('C:maj(#11)', 'Bb/b7', 'D/3'),
#   ('D:maj(11)', 'Ab/b7', 'F:(1)'),
#   ('D', 'G:maj6/2', 'F#:dim/b7'),
#   ('A/5', 'Ab/b7', 'A:dim/b3'),
#   ('D:maj(11)', 'D:dim', 'Bb/b7'),
#   ('F:maj/9', 'F:min7', 'F/9'),
#   ('G:min/5', 'F:7', 'A:dim/b3'),
#   ('Eb/3', 'B/6', 'B:min'),
#   ('F:maj6', 'Ab/b7', 'D:7/2'),
#   ('G:maj6/5', 'A:min', 'E:min/b7'),
#   ('D:min/b3', 'F/3', 'A:dim/b3'),
#   ('C/5', 'D:min7', 'D/3'),
#   ('G#:(1)', 'Bb/3', 'B/5'),
#   ('G:maj6/3', 'B:min7', 'G:(1)'),
#   ('G:7', 'F:(1)', 'F#:dim/b7'),
#   ('G:maj6/2', 'D:7', 'D:maj(9)'),
#   ('D:min', 'D#:dim7', 'F/3'),
#   ('G:maj6/5', 'F/3', 'E:maj6'),
#   ('G:maj6', 'Eb', 'Eb/3'),
#   ('A', 'Eb:dim', 'B/6'),
#   ('G', 'D/5', 'Eb/2'),
#   ('F:maj7', 'F:min/b7', 'F#:sus4'),
#   ('Eb/5', 'F#', 'E/5'),
#   ('G:7', 'G:9(*3)', 'C:maj(#11)'),
#   ('C/7', 'G/5', 'B:min'),
#   ('C:maj(#11)', 'A:dim7/b3', 'G:maj7'),
#   ('D:min/b3', 'G:min', 'G:maj7'),
#   ('G:maj6/3', 'Bb/3', 'D:dim'),
#   ('G:min(9)/b3', 'Ab', 'F/9'),
#   ('F#:min7', 'F:min', 'B:min'),
#   ('G:7', 'G:9(*3)', 'Ab/b7'),
#   ('G#:(1)', 'D:maj6', 'F:(1)'),
#   ('G:maj6', 'A:7', 'F#:sus4'),
#   ('C:7', 'Ab/7', 'A:dim/b5'),
#   ('F:7', 'E:7', 'B/7'),
#   ('B:min7', 'A/b7', 'F:min/b7'),
#   ('N', 'G:9(*3)', 'C#:min7'),
#   ('A:min', 'Ab/b7', 'E/5'),
#   ('F', 'G:9(*3)', 'B/5'),
#   ('A/b7', 'D:maj(11)', 'F:(1)'),
#   ('Ab/b7', 'A:dim7/b3', 'Bb/b7'),
#   ('G', 'G/5', 'F/9'),
#   ('G:maj6', 'A:dim/b5', 'A/3'),
#   ('G:maj6', 'F/5', 'F/3'),
#   ('C/7', 'E:7', 'Bb/b7'),
#   ('C:maj(#11)', 'Eb', 'F:min7'),
#   ('B:min7', 'A:dim/b3', 'F/9'),
#   ('A:dim7/b3', 'A:dim/b3', 'F#'),
#   ('Eb:dim', 'G:maj7', 'F#:dim/b7'),
#   ('D:maj6/5', 'G:7', 'F#:dim'),
#   ('A:min/5', 'Eb:dim', 'E/5'),
#   ('D:dim', 'F:7/b7', 'F#:sus4'),
#   ('D:min', 'F/3', 'B/5'),
#   ('G:maj6/5', 'Eb:dim', 'E:min/b7'),
#   ('E', 'E:maj6', 'F#:sus4'),
#   ('G:maj7', 'B/3', 'C/9'),
#   ('N', 'A:dim/b3', 'G#:hdim7'),
#   ('F', 'D:min/b3', 'Ab/7'),
#   ('G#:(1)', 'G/5', 'C#:min7'),
#   ('E:min', 'A:dim7/b3', 'Eb:dim'),
#   ('D:maj6', 'F:min/b7', 'F:7/b7'),
#   ('C', 'G:maj6', 'E:min/b7'),
#   ('D/b7', 'D:7', 'D:maj(9)'),
#   ('G:maj6', 'B/6', 'F/9'),
#   ('Ab/b7', 'Eb:dim', 'F:(1)'),
#   ('N', 'A/5', 'G:min'),
#   ('D#:dim7', 'D:min7/4', 'Eb/5'),
#   ('E', 'F:maj7', 'F/5'),
#   ('G:maj6/2', 'E:7', 'G:(1)'),
#   ('F:maj7', 'B/6', 'G#:hdim7'),
#   ('D:min', 'G:maj6/2', 'F:7/b7'),
#   ('C/5', 'F:(1)', 'B/6'),
#   ('G:7', 'G:(1)', 'F#:dim/b7'),
#   ('F', 'A:dim/b5', 'B/6'),
#   ('G#:(1)', 'B:min7', 'D:7'),
#   ('A', 'Bb', 'A:dim7/b3'),
#   ('D:maj6/5', 'D:7', 'F/9'),
#   ('G:min(9)/b3', 'D:maj(11)', 'D:7/2'),
#   ('E:min', 'Eb:dim', 'G:maj7'),
#   ('D/b7', 'F:min', 'F#'),
#   ('D:7', 'G:(1)', 'B:min'),
#   ('A', 'F:7/b7', 'G/5'),
#   ('G:min/b7', 'A:dim/b3', 'A/3'),
#   ('Bb/3', 'F:(1)', 'C#:min7'),
#   ('F', 'Ab', 'D/3'),
#   ('D#:dim7', 'D:7', 'A/b7'),
#   ('G:maj6/3', 'G:7', 'F#'),
#   ('G:min', 'F:(1)', 'C/9'),
#   ('B', 'D#:dim7', 'A:dim/b5'),
#   ('A', 'F:7', 'G:(1)'),
#   ('G#:(1)', 'D:7', 'E:min/b7'),
#   ('Bb/3', 'A:min/5', 'F:min/b7'),
#   ('G:maj6/3', 'G:(1)', 'C#:min7'),
#   ('D:min/b3', 'Bb/b7', 'B/5'),
#   ('C', 'B/7', 'E:min/b7'),
#   ('F:7/b7', 'G:(1)', 'E:maj6'),
#   ('A:dim/b3', 'F:min7', 'B/6'),
#   ('N', 'E:7', 'B/5'),
#   ('D', 'A:dim/b5', 'F#:dim/b7'),
#   ('G:min/b7', 'D/3', 'G:maj7/5'),
#   ('F#:min7', 'Ab/b7', 'F:min/b7'),
#   ('G:min(9)/b3', 'A:dim/b3', 'D:7/2'),
#   ('E:min', 'G#:hdim7', 'E/5'),
#   ('N', 'A', 'D:7/2'),
#   ('D', 'A', 'D:dim'),
#   ('B', 'A/b7', 'A:min/5'),
#   ('Bb/3', 'Eb/2', 'Bb/b7'),
#   ('D:min', 'G:7', 'A/5'),
#   ('G:min/5', 'F:7/b7', 'F#:sus4'),
#   ('G', 'G:maj6/3', 'F:maj/9'),
#   ('D', 'G:min/b7', 'G:maj7/5'),
#   ('F#:min7', 'A/b7', 'A/3'),
#   ('G/3', 'D:maj(9)', 'F:7/b7'),
#   ('Eb', 'A/3', 'B/3'),
#   ('D/b7', 'F:7', 'D/3'),
#   ('G:maj6/5', 'F:(1)', 'D/3'),
#   ('A:dim7/b3', 'F#', 'D/3'),
#   ('D:min', 'A/5', 'G:9(*3)'),
#   ('Bb/3', 'A/b7', 'B/6'),
#   ('Eb', 'G#:hdim7', 'F/9'),
#   ('F:7/b7', 'F#:sus4', 'F#'),
#   ('D#:dim7', 'C/7', 'Eb/2'),
#   ('A', 'B/6', 'G:maj7/5'),
#   ('D/b7', 'B:min7', 'C#:min7'),
#   ('A', 'G/3', 'D#:dim7'),
#   ('D/b7', 'F:7', 'E:maj6'),
#   ('A:min', 'F:min/b7', 'G:maj7/5'),
#   ('A:dim/b3', 'E:maj6', 'G:maj7/5'),
#   ('F:(1)', 'F#:sus4', 'C/9'),
#   ('G/3', 'D:min7/4', 'A:dim/b5'),
#   ('B:min7', 'D#:dim7', 'B/5'),
#   ('G/3', 'F:7/b7', 'C#:min7'),
#   ('D:maj(9)', 'F:maj/9', 'Ab/b7'),
#   ('C', 'F:min7', 'Bb/b7'),
#   ('D:min/b3', 'G:min/b7', 'B/7'),
#   ('A:min/5', 'F/5', 'D:dim'),
#   ('A:min', 'F/5', 'F:7/b7'),
#   ('G:7', 'F/5', 'F#:sus4'),
#   ('A:min', 'F:maj/9', 'G:min/b7'),
#   ('A', 'A:min/5', 'E:maj6'),
#   ('E', 'Bb', 'F:maj7'),
#   ('D:maj(9)', 'A/3', 'D:7/2'),
#   ('G:min(9)/b3', 'F:min/b7', 'C/9'),
#   ('Ab/7', 'E:maj6', 'B:min'),
#   ('G/3', 'F#:min7', 'Bb'),
#   ('F:7', 'C:maj(#11)', 'E:maj6'),
#   ('Bb', 'Eb/2', 'E/5'),
#   ('D/5', 'G:min/b7', 'F#:dim/b7'),
#   ('C:maj(#11)', 'Eb:dim', 'B/7'),
#   ('D', 'G:maj6/3', 'D:min/b3'),
#   ('B:min7', 'G:9(*3)', 'B/7'),
#   ('Ab/b7', 'A:dim/b3', 'A/3'),
#   ('D:maj6', 'D:maj(11)', 'Ab/7'),
#   ('D', 'F:min', 'Bb/b7'),
#   ('G:maj6/5', 'Eb', 'F#:dim/b7'),
#   ('Eb/5', 'D:dim', 'G#:hdim7'),
#   ('G/3', 'Bb', 'F'),
#   ('Ab/b7', 'C/9', 'D:7/2'),
#   ('D:maj6', 'G:maj6/2', 'Ab/b7'),
#   ('G', 'G:maj6/3', 'Eb'),
#   ('E:min', 'C:maj(#11)', 'B/7'),
#   ('G/3', 'Eb/5', 'D:dim'),
#   ('B', 'Eb:dim', 'F/9'),
#   ('C', 'Eb:dim', 'Bb:(1)'),
#   ('C/7', 'Eb', 'Bb:(1)'),
#   ('A:dim/b5', 'Eb/5', 'E:maj6'),
#   ('E:min', 'A:7', 'G/5'),
#   ('Bb/3', 'F/5', 'C#:min7'),
#   ('G', 'G:maj6/2', 'C/7'),
#   ('Ab/7', 'B:min', 'D/3'),
#   ('F', 'Ab/b7', 'Eb/2'),
#   ('G:7', 'D:7', 'E:maj6'),
#   ('Bb', 'F/5', 'G/5'),
#   ('D#:dim7', 'A/5', 'G:9(*3)'),
#   ('F:min/b7', 'Eb:dim', 'B/6'),
#   ('D/b7', 'E:min', 'F/5'),
#   ('G:maj6/3', 'F:(1)', 'B/7'),
#   ('F:7/b7', 'B/6', 'D:7/2'),
#   ('A:dim/b5', 'Eb/5', 'D/3'),
#   ('A', 'A:min', 'Ab'),
#   ('D/5', 'D:min7', 'D:min7/4'),
#   ('G/3', 'A:dim/b3', 'E:min/b7'),
#   ('F/3', 'A:dim/b3', 'G/5'),
#   ('Bb', 'F:min', 'A/3'),
#   ('D:maj6/5', 'C:7', 'G:min'),
#   ('G:min/5', 'A:min', 'F#:sus4'),
#   ('A:dim/b5', 'F:min', 'G#:hdim7'),
#   ('E', 'F/5', 'Eb:dim'),
#   ('F', 'G:7', 'D:dim'),
#   ('F', 'C/7', 'Eb/3'),
#   ('B', 'G#:(1)', 'E/5'),
#   ('G:maj6/3', 'D:min7/4', 'Eb/5'),
#   ('D/b7', 'Eb/5', 'B/5'),
#   ('G:maj6/5', 'G:min', 'D:7/2'),
#   ('F:min', 'D:dim', 'G:maj7'),
#   ('D:min', 'E:7', 'G#:hdim7'),
#   ('A', 'F#:min7', 'E:7'),
#   ('D/5', 'F', 'F#'),
#   ('D', 'F#:dim', 'F:maj6'),
#   ('A:min/5', 'G:(1)', 'G#:hdim7'),
#   ('D/5', 'A:min/5', 'Bb/b7'),
#   ('C', 'A:7', 'B:min'),
#   ('A:dim7/b3', 'B/5', 'C#:min7'),
#   ('F', 'D:min7/4', 'Ab/7'),
#   ('D#:dim7', 'G:min', 'A/3'),
#   ('F#:min7', 'E:min', 'Ab/b7'),
#   ('D:maj(9)', 'F:7/b7', 'E/5'),
#   ('G', 'Ab/b7', 'Bb:(1)'),
#   ('D:maj6/5', 'A:min', 'F#'),
#   ('F#:min7', 'F:min/b7', 'Bb/b7'),
#   ('G:(1)', 'B/3', 'E/5'),
#   ('C/5', 'D/3', 'G:maj7/5'),
#   ('E', 'G:min(9)/b3', 'D/3'),
#   ('E', 'D:dim', 'D/3'),
#   ('Eb', 'D:dim', 'C/9'),
#   ('G:maj6', 'G:min', 'F:min7'),
#   ('Ab', 'G:min', 'A/3'),
#   ('N', 'Ab/7', 'F:min7'),
#   ('G', 'G:maj6/5', 'A:7'),
#   ('D/5', 'Eb/3', 'A:dim/b3'),
#   ('D', 'G:maj6/2', 'Eb'),
#   ('G:7', 'D:min/b3', 'Eb/3'),
#   ('E', 'D:maj(9)', 'C/9'),
#   ('C/5', 'B/7', 'G#:hdim7'),
#   ('D:min', 'G:min/5', 'C'),
#   ('G', 'F:min', 'D:7/2'),
#   ('G:min', 'Eb/3', 'Bb:(1)'),
#   ('Bb/3', 'C', 'E:maj6'),
#   ('E', 'C:7', 'F#'),
#   ('E', 'G:9(*3)', 'E:maj6'),
#   ('N', 'C', 'G:maj7/5'),
#   ('G:9(*3)', 'B/5', 'B/3'),
#   ('G:maj6', 'A/5', 'G:maj7/5'),
#   ('Eb:dim', 'Eb/3', 'G:maj7/5'),
#   ('D:min', 'Ab', 'G:maj7'),
#   ('C/5', 'Ab/7', 'C#:min7'),
#   ('D/b7', 'B/3', 'C/9'),
#   ('D:min', 'A:min', 'F#:dim/b7'),
#   ('G:min(9)/b3', 'C:7', 'A:min/5'),
#   ('C/5', 'D#:dim7', 'D:7/2'),
#   ('F:7/b7', 'E:maj6', 'F/9'),
#   ('D:maj6', 'Bb/3', 'G:maj6'),
#   ('F:maj7', 'D:min7/4', 'Ab/7'),
#   ('G:min', 'B/5', 'F#'),
#   ('F:7', 'F:min/b7', 'D/3'),
#   ('G:min(9)/b3', 'C:7', 'F:min'),
#   ('F#:min7', 'E:min', 'G:maj7/5'),
#   ('G', 'F:min', 'F:min/b7'),
#   ('Eb/5', 'G:min', 'G:min/b7'),
#   ('Eb/5', 'Eb:dim', 'B/7'),
#   ('D:maj6', 'G:maj6/2', 'D:dim'),
#   ('D:maj6/5', 'F/5', 'F#:sus4'),
#   ('D/5', 'B', 'D:maj(9)'),
#   ('A:7', 'E:7', 'A:dim7/b3'),
#   ('D:maj6/5', 'A:min', 'G:min/b7'),
#   ('D/b7', 'D:7/2', 'G:maj7/5'),
#   ('B:min7', 'C#:min7', 'F#'),
#   ('G:maj6/5', 'C/9', 'E:min/b7'),
#   ('D:maj6', 'C', 'B/3'),
#   ('D', 'F:min7', 'G#:hdim7'),
#   ('D', 'Bb', 'F#'),
#   ('G:9(*3)', 'Ab/b7', 'F#:dim/b7'),
#   ('G:maj6/3', 'G:(1)', 'G:maj7/5'),
#   ('F:maj/9', 'F:7/b7', 'F:min7'),
#   ('D:min', 'G:min/b7', 'B/7'),
#   ('C/7', 'F:min', 'C/9'),
#   ('G:7', 'Bb/b7', 'F#'),
#   ('N', 'A:7', 'F:7/b7'),
#   ('D:maj(11)', 'C:maj(#11)', 'F:min/b7'),
#   ('B', 'F:min/b7', 'E/5'),
#   ('Ab', 'Ab/b7', 'G/5'),
#   ('Ab/b7', 'F:min7', 'F#:sus4'),
#   ('D:min', 'F:maj6', 'Ab/7'),
#   ('D:maj6', 'Bb/b7', 'D/3'),
#   ('D/5', 'G:min/5', 'E/5'),
#   ('G:min/5', 'A:min', 'F:min/b7'),
#   ('A:dim7/b3', 'F:7/b7', 'Bb:(1)'),
#   ('A:dim7/b3', 'F:min', 'F#:sus4'),
#   ('G:maj6/3', 'G:min', 'F#:sus4'),
#   ('G:min(9)/b3', 'B', 'D:min7'),
#   ('D:min7', 'D:maj6/5', 'F#:dim/b7'),
#   ('D/b7', 'C:maj(#11)', 'Eb/5'),
#   ('D:maj6/5', 'F', 'G#:hdim7'),
#   ('E:min', 'Bb/b7', 'B/5'),
#   ('E', 'G:maj6/3', 'Bb/b7'),
#   ('G:maj6', 'A:dim7/b3', 'F:min'),
#   ('F:(1)', 'B/3', 'C/9'),
#   ('F:min/b7', 'G/5', 'G#:hdim7'),
#   ('C', 'G:min', 'G#:hdim7'),
#   ('B', 'A/b7', 'G#:hdim7'),
#   ('G#:(1)', 'D:7', 'E:7'),
#   ('A', 'D:dim', 'B/7'),
#   ('F', 'E:maj6', 'F#'),
#   ('C/7', 'A:7', 'A:dim/b3'),
#   ('A', 'B:min', 'E:min/b7'),
#   ('G:maj6/3', 'C', 'E/5'),
#   ('G:maj6', 'A:min/5', 'A:dim7/b3'),
#   ('G:maj6/5', 'Bb:(1)', 'A/3'),
#   ('E:7', 'F:min/b7', 'B:min'),
#   ('F:maj6', 'E:maj6', 'B:min'),
#   ('D:min7', 'A/b7', 'F:min/b7'),
#   ('D:min7', 'F:min/b7', 'E/5'),
#   ('A:min', 'D:min/b3', 'B:min'),
#   ('G:min(9)/b3', 'D:7', 'F:min/b7'),
#   ('G:min/5', 'D:min7', 'C/7'),
#   ('D#:dim7', 'G:(1)', 'D/3'),
#   ('D:maj6/5', 'F#:dim', 'D/3'),
#   ('N', 'Eb/2', 'A:dim/b3'),
#   ('F/5', 'F/3', 'G:(1)'),
#   ('Eb:dim', 'F:(1)', 'F:min7'),
#   ('Eb:dim', 'G:min/b7', 'Eb/3'),
#   ('C:7', 'D:dim', 'C#:min7'),
#   ('G', 'Bb', 'Ab/7'),
#   ('F#:min7', 'E:7', 'F:(1)'),
#   ('Bb', 'E:min', 'A:min'),
#   ('C', 'D:min/b3', 'A/3'),
#   ('D', 'G:min/5', 'E:7'),
#   ('Bb/3', 'F:min', 'C#:min7'),
#   ('F/3', 'G/5', 'F#:dim/b7'),
#   ('B:min7', 'F:min7', 'G:maj7/5'),
#   ('A:min/5', 'B/5', 'D:7/2'),
#   ('G', 'G:min(9)/b3', 'F#:dim/b7'),
#   ('D:min/b3', 'A:dim7/b3', 'D:7/2'),
#   ('G#:(1)', 'Bb/3', 'C'),
#   ('D:min', 'Eb/2', 'F#:sus4'),
#   ('D/5', 'A:dim/b3', 'G#:hdim7'),
#   ('A:dim/b5', 'G/5', 'A/3'),
#   ('G#:(1)', 'Bb/3', 'F:maj7'),
#   ('D:min', 'E:min', 'B/7'),
#   ('B:min7', 'G:7', 'F:min7'),
#   ('F:maj6', 'Ab/7', 'B/3'),
#   ('A', 'C/5', 'B/3'),
#   ('Bb/3', 'Eb/5', 'F:min7'),
#   ('A:min/5', 'F/3', 'G:(1)'),
#   ('Bb', 'C:7', 'G:maj7'),
#   ('N', 'Eb/2', 'A/3'),
#   ('G:min/b7', 'A/3', 'B/3'),
#   ('G', 'F:min', 'G:(1)'),
#   ('D/5', 'D:dim', 'F#:dim/b7'),
#   ('G:maj6/5', 'D:maj(11)', 'Bb:(1)'),
#   ('F#:min7', 'D:maj(9)', 'E/5'),
#   ('C/5', 'F:(1)', 'F#:sus4'),
#   ('N', 'G:7', 'C:maj(#11)'),
#   ('B', 'G:7', 'A:min/5'),
#   ('F#:min7', 'A:dim/b3', 'F:min7'),
#   ('N', 'G', 'E:7'),
#   ('G:maj6/3', 'D:dim', 'G:min/b7'),
#   ('G', 'Bb', 'Eb:dim'),
#   ('D:min/b3', 'A:dim/b3', 'B/7'),
#   ('D', 'C/9', 'D:7/2'),
#   ('E', 'D:7', 'F#:dim/b7'),
#   ('D#:dim7', 'A/5', 'B/3'),
#   ('E:min', 'F:min', 'F#:sus4'),
#   ('G#:(1)', 'D:7', 'Ab'),
#   ('F:maj/9', 'Eb/3', 'B/6'),
#   ('G:maj6/5', 'C/7', 'G:min'),
#   ('E', 'C#:min7', 'E:min/b7'),
#   ('B', 'Ab', 'F:min/b7'),
#   ('G#:(1)', 'G:maj6/2', 'F#:dim/b7'),
#   ('D', 'G:maj6/2', 'D:min/b3'),
#   ('D:min7', 'Eb:dim', 'A:dim/b3'),
#   ('Ab/7', 'Eb/2', 'F#:sus4'),
#   ('D:7', 'Eb/2', 'Bb/b7'),
#   ('G:maj6/3', 'F:7', 'E:min/b7'),
#   ('B', 'A/5', 'D:7'),
#   ('C/5', 'Ab/7', 'G:maj7/5'),
#   ('F#:min7', 'D:min/b3', 'F:min'),
#   ('F:7/b7', 'F#:sus4', 'G:maj7'),
#   ('D:7', 'Eb/5', 'Eb/2'),
#   ('B:min7', 'D:min/b3', 'G:min'),
#   ('C', 'A/b7', 'A:dim/b5'),
#   ('F#:min7', 'C:7', 'D:min7/4'),
#   ('D:min7', 'A/5', 'D:maj(11)'),
#   ('F#:min7', 'C/7', 'G#:hdim7'),
#   ('G:(1)', 'G/5', 'G#:hdim7'),
#   ('G:maj6/3', 'B/6', 'B/3'),
#   ('F', 'F/3', 'B/6'),
#   ('G:7', 'A/5', 'D:dim'),
#   ('A:dim/b3', 'Bb/b7', 'G:maj7'),
#   ('G:min/5', 'C:maj(#11)', 'Eb:dim'),
#   ('G:min(9)/b3', 'F#:dim', 'G#:hdim7'),
#   ('Bb/b7', 'B/7', 'F#'),
#   ('D', 'Bb/3', 'D:7'),
#   ('D', 'C:maj(#11)', 'F#:sus4'),
#   ('F:maj6', 'F:maj/9', 'E/5'),
#   ('D:min', 'F', 'E/5'),
#   ('G', 'D:maj6', 'A:7'),
#   ('D:maj6', 'F:(1)', 'B/7'),
#   ('Bb', 'A:7', 'D:dim'),
#   ('E', 'D/5', 'E:min'),
#   ('D:min7/4', 'A:dim/b5', 'F/9'),
#   ('A/5', 'Ab', 'G:min/b7'),
#   ('G:min(9)/b3', 'F:maj7', 'Bb/b7'),
#   ('G:maj6/3', 'C', 'D:maj(9)'),
#   ('B', 'Ab/7', 'F#:sus4'),
#   ('G:min/5', 'G:9(*3)', 'G#:hdim7'),
#   ('F', 'F:maj7', 'Bb/b7'),
#   ('C:7', 'C/9', 'D/3'),
#   ('C/7', 'Ab/b7', 'D/3'),
#   ('D:maj6/5', 'G:maj6', 'Eb/3'),
#   ('D/5', 'A:dim/b5', 'G:min'),
#   ('B:min7', 'D:min7', 'F:7'),
#   ('G:min(9)/b3', 'E:7', 'E:min/b7'),
#   ('Eb:dim', 'Eb/3', 'F:(1)'),
#   ('G:maj6', 'F#:dim', 'Eb'),
#   ('G:min(9)/b3', 'D#:dim7', 'D:dim'),
#   ('D/b7', 'D:maj(11)', 'F:maj/9'),
#   ('D:min7', 'D:dim', 'Eb/2'),
#   ('G:7', 'D:maj(9)', 'B/6'),
#   ('N', 'F#:dim', 'D:dim'),
#   ('F:maj/9', 'A:dim/b3', 'B/7'),
#   ('G:7', 'F/5', 'F/3'),
#   ('D:7', 'G:min/b7', 'F:min7'),
#   ('N', 'D:7', 'F:min7'),
#   ('Bb', 'E:min/b7', 'D:7/2'),
#   ('D/b7', 'G/5', 'E:maj6'),
#   ('D:maj(11)', 'A:min/5', 'F#:dim/b7'),
#   ('E', 'B:min7', 'D:maj6/5'),
#   ('G:maj6/2', 'F:maj7', 'C:maj(#11)'),
#   ('G', 'G:min(9)/b3', 'C/5'),
#   ('G:maj6/5', 'Eb/3', 'B/5'),
#   ('F/3', 'F:7/b7', 'G:min/b7'),
#   ('G:7', 'F:min/b7', 'Eb:dim'),
#   ('F#:dim', 'Ab', 'B/3'),
#   ('F/3', 'F/9', 'D:7/2'),
#   ('G:maj6/3', 'Eb:dim', 'F#'),
#   ('F:7/b7', 'E:min/b7', 'G:maj7/5'),
#   ('F#:dim', 'F:maj/9', 'Ab/b7'),
#   ('G/3', 'F:maj6', 'Bb/b7'),
#   ('A', 'G/3', 'Bb:(1)'),
#   ('Bb/3', 'D:min7/4', 'E/5'),
#   ('C/7', 'F:maj6', 'E:min/b7'),
#   ('G/5', 'E/5', 'F/9'),
#   ('D/5', 'D:min7', 'A/3'),
#   ('D:min/b3', 'E:7', 'F/3'),
#   ('B:min7', 'D:7', 'F:7/b7'),
#   ('B', 'F:maj/9', 'A:dim7/b3'),
#   ('D:7', 'Bb:(1)', 'B/3'),
#   ('F', 'A:7', 'G:maj7/5'),
#   ('G:maj6/3', 'C/5', 'Ab/b7'),
#   ('G:7', 'Bb:(1)', 'F#:sus4'),
#   ('C:7', 'A:min', 'Bb:(1)'),
#   ('G:min/5', 'E/5', 'F#:dim/b7'),
#   ('Bb/3', 'B/7', 'G:maj7/5'),
#   ('N', 'Eb/5', 'F:min7'),
#   ('A', 'F:maj/9', 'D/3'),
#   ('C/5', 'G:maj6/2', 'A:dim/b3'),
#   ('C:7', 'D#:dim7', 'F#'),
#   ('D:min', 'F:min7', 'B/3'),
#   ('A', 'F:min', 'G:min'),
#   ('F', 'Eb/5', 'C/9'),
#   ('G/3', 'G:min/5', 'F:min7'),
#   ('D:min7', 'D#:dim7', 'D/3'),
#   ('D', 'A:min', 'D:maj(11)'),
#   ('B', 'B:min7', 'F:min'),
#   ('A:7', 'D:min/b3', 'E:min/b7'),
#   ('G', 'A/b7', 'F:7/b7'),
#   ('A:7', 'F:maj6', 'G:maj7/5'),
#   ('G:maj6/3', 'G:min/5', 'C:maj(#11)'),
#   ('Eb/3', 'G/5', 'B/6'),
#   ('D:min7', 'G:7', 'D:dim'),
#   ('D:min', 'G:min/5', 'F:maj7'),
#   ('G:min/5', 'E:7', 'F#'),
#   ('A:min', 'A:dim7/b3', 'G:min'),
#   ('Bb', 'A:min', 'G:maj7'),
#   ('G:7', 'G:9(*3)', 'B/7'),
#   ('B', 'Eb:dim', 'E:maj6'),
#   ('D/b7', 'G:min(9)/b3', 'A:dim7/b3'),
#   ('D:maj6/5', 'G:min', 'F#:dim/b7'),
#   ('C/5', 'C', 'Bb/b7'),
#   ('F:7/b7', 'Eb/3', 'Bb:(1)'),
#   ('D/5', 'F:maj7', 'Eb/2'),
#   ('D#:dim7', 'F:maj7', 'C/7'),
#   ('D:7', 'F:7/b7', 'G:maj7/5'),
#   ('D:min7/4', 'Ab/b7', 'C/9'),
#   ('F:maj7', 'Eb', 'F/5'),
#   ('E:7', 'Bb:(1)', 'G#:hdim7'),
#   ('D#:dim7', 'Bb:(1)', 'C#:min7'),
#   ('D:7', 'F/5', 'F:min/b7'),
#   ('G:maj6/3', 'G:9(*3)', 'G#:hdim7'),
#   ('D:min7', 'D:7', 'G:min/b7'),
#   ('N', 'D:min', 'C'),
#   ('N', 'D:min7/4', 'Ab'),
#   ('D/b7', 'G:min/5', 'G#:hdim7'),
#   ('A', 'E:7', 'G#:hdim7'),
#   ('G:maj6', 'F/3', 'B/7'),
#   ('Ab/b7', 'A:min/5', 'D:7/2'),
#   ('G#:(1)', 'Eb/3', 'F#:dim/b7'),
#   ('E', 'G:maj6', 'G/5'),
#   ('A:min/5', 'E:maj6', 'E/5'),
#   ('F:maj7', 'F:maj/9', 'A:dim/b5'),
#   ('G:min(9)/b3', 'D:maj(9)', 'F:min'),
#   ('D#:dim7', 'E:maj6', 'C/9'),
#   ('G:maj6/5', 'D:min7/4', 'D/3'),
#   ('Bb:(1)', 'E/5', 'C/9'),
#   ('N', 'Bb/3', 'C/5'),
#   ('Bb/3', 'C/7', 'Eb/5'),
#   ('D:maj(9)', 'Eb', 'F/9'),
#   ('F#:min7', 'Bb', 'A/3'),
#   ('F:7', 'F:min', 'Eb/3'),
#   ('F:maj7', 'Ab', 'G:min/b7'),
#   ('Eb', 'F:min', 'F:(1)'),
#   ('D:maj6/5', 'C:7', 'D:7/2'),
#   ('C:7', 'F:maj6', 'Bb/b7'),
#   ('D/5', 'G:maj6/5', 'Ab'),
#   ('E', 'D:maj6/5', 'G#:hdim7'),
#   ('A:7', 'A/b7', 'F:min/b7'),
#   ('G:maj6/2', 'C:7', 'E/5'),
#   ('Ab', 'G:(1)', 'F#'),
#   ('G:9(*3)', 'F:7/b7', 'E:min/b7'),
#   ('A', 'Ab/b7', 'D/3'),
#   ('F#:dim', 'F:maj6', 'E:maj6'),
#   ('D:min7', 'Eb/5', 'F#:dim/b7'),
#   ('G:maj6/3', 'G:maj6', 'A:dim/b5'),
#   ('G:maj6/2', 'G:9(*3)', 'B/6'),
#   ('N', 'D#:dim7', 'F:min'),
#   ('F', 'Bb/b7', 'G:maj7'),
#   ('D:min7', 'C:7', 'D:min7/4'),
#   ('D:maj6/5', 'A:dim/b5', 'F#'),
#   ('E', 'G/5', 'C/9'),
#   ('Bb/3', 'B/3', 'E:min/b7'),
#   ('F:(1)', 'Bb:(1)', 'E:min/b7'),
#   ('G:maj6', 'D:7', 'F:maj6'),
#   ('D:min7', 'F:7', 'D:min/b3'),
#   ('D:7', 'Ab/7', 'C#:min7'),
#   ('G', 'G:maj6/5', 'A/5'),
#   ('A:dim/b5', 'F:min', 'A:dim/b3'),
#   ('G:min/5', 'A:7', 'C/9'),
#   ('F:7', 'F', 'F/3'),
#   ('F', 'Bb/b7', 'A/3'),
#   ('G:maj6', 'A:min/5', 'B/5'),
#   ('B:min7', 'D:dim', 'B/7'),
#   ('Eb/5', 'A:dim/b3', 'C#:min7'),
#   ('G:maj6/5', 'D:7', 'D:min7/4'),
#   ('B', 'G:min/b7', 'G#:hdim7'),
#   ('C/7', 'D:maj(11)', 'G:min/b7'),
#   ('G:9(*3)', 'Eb/2', 'G:(1)'),
#   ('B', 'B:min7', 'G:maj7/5'),
#   ('Bb/3', 'G:maj6/2', 'C/7'),
#   ('F#:min7', 'C/7', 'D:7'),
#   ('G:maj6/3', 'A/5', 'B/6'),
#   ('B:min7', 'Eb/3', 'F/9'),
#   ('D:maj6/5', 'G:maj6/2', 'Eb/3'),
#   ('G/3', 'A:dim7/b3', 'F/9'),
#   ('D:maj6', 'F/3', 'Bb/b7'),
#   ('D#:dim7', 'Eb/3', 'B/7'),
#   ('F:min', 'G:(1)', 'F/9'),
#   ('G/3', 'D:maj6', 'A:dim7/b3'),
#   ('B', 'A:7', 'A:dim7/b3'),
#   ('G#:(1)', 'G:min/b7', 'G:maj7/5'),
#   ('G:9(*3)', 'F:min', 'G:(1)'),
#   ('C:maj(#11)', 'Eb/5', 'D:dim'),
#   ('D/5', 'Ab', 'Bb:(1)'),
#   ('D:maj6', 'F:min7', 'B:min'),
#   ('G/3', 'A/b7', 'B/6'),
#   ('F#:min7', 'D:min', 'B:min7'),
#   ('Ab', 'Ab/b7', 'D:7/2'),
#   ('G:min(9)/b3', 'D:maj6', 'G:9(*3)'),
#   ('E:min', 'B:min', 'D:7/2'),
#   ('G:min/5', 'G:maj6/2', 'E:7'),
#   ('D:maj6/5', 'G/5', 'F#:dim/b7'),
#   ('G#:(1)', 'D:7', 'F:7/b7'),
#   ('Bb/3', 'G:9(*3)', 'A:dim/b5'),
#   ('A', 'F/5', 'G/5'),
#   ('E', 'D:maj(11)', 'Eb/5'),
#   ('F:7', 'F#:dim', 'A:dim7/b3'),
#   ('F#:min7', 'F#:dim', 'A/b7'),
#   ('D/5', 'Ab', 'Ab/b7'),
#   ('Ab/7', 'A:min/5', 'B:min'),
#   ('Bb:(1)', 'G#:hdim7', 'C/9'),
#   ('D:maj(11)', 'G:(1)', 'A/3'),
#   ('E', 'B:min7', 'A:min/5'),
#   ('Eb/2', 'Bb:(1)', 'C/9'),
#   ('D', 'D:maj(9)', 'F:(1)'),
#   ('D:maj6', 'A/5', 'F:min'),
#   ('D:min', 'Bb/b7', 'E:min/b7'),
#   ('D:maj6/5', 'F:min7', 'D/3'),
#   ('C:7', 'E:7', 'B/7'),
#   ('D:min', 'A:7', 'A:dim/b5'),
#   ('D:min7', 'Bb:(1)', 'B/6'),
#   ('F#:dim', 'D:min7/4', 'F#:sus4'),
#   ('G:maj6', 'B/6', 'E:maj6'),
#   ('D:maj6/5', 'C:7', 'F#:dim/b7'),
#   ('G/3', 'G:min/b7', 'C/9'),
#   ('F#:min7', 'Eb:dim', 'A:dim/b3'),
#   ('G:maj6/3', 'B:min7', 'Ab/7'),
#   ('D:maj6/5', 'F:min/b7', 'A:dim/b3'),
#   ('B:min7', 'Eb', 'F#'),
#   ('Bb', 'Eb/5', 'A/3'),
#   ('G:maj6/3', 'A:dim7/b3', 'Eb/2'),
#   ('A:dim7/b3', 'F:min7', 'Bb/b7'),
#   ('Bb/3', 'C:7', 'D:min7/4'),
#   ('Bb/3', 'D:7', 'Eb/5'),
#   ('F:min7', 'C/9', 'F#:dim/b7'),
#   ('G:maj6/2', 'G:(1)', 'A/3'),
#   ('E', 'D/5', 'F#:dim/b7'),
#   ('G:maj6', 'Ab/7', 'F#'),
#   ('F:7', 'D:7', 'A:min/5'),
#   ('G:min/b7', 'G:(1)', 'G#:hdim7'),
#   ('D:maj6/5', 'G:9(*3)', 'Eb/3'),
#   ('F#:dim', 'A:dim/b5', 'A/3'),
#   ('G:min/5', 'Bb/3', 'F:maj7'),
#   ('D', 'D:7', 'B/7'),
#   ('Bb', 'E:min', 'A:dim7/b3'),
#   ('D:maj6', 'G:maj6/2', 'D:7/2'),
#   ('A:dim/b5', 'G:min', 'F:min/b7'),
#   ('E:min', 'C/5', 'A:min'),
#   ('Bb', 'F:maj7', 'F:7/b7'),
#   ('C:7', 'F:min7', 'G:maj7/5'),
#   ('D:min/b3', 'Eb/5', 'Bb:(1)'),
#   ('F#:min7', 'G:min/5', 'C:7'),
#   ('D:min7', 'F:maj/9', 'C#:min7'),
#   ('E', 'Ab/7', 'B:min'),
#   ('D:min', 'C/5', 'D:min/b3'),
#   ('D:maj6/5', 'G:9(*3)', 'A/b7'),
#   ('A:min', 'Eb:dim', 'Eb/3'),
#   ('A:min', 'F:min/b7', 'F:min7'),
#   ('G:maj6/2', 'F#:dim', 'E/5'),
#   ('E:7', 'B/6', 'G#:hdim7'),
#   ('A:7', 'D:dim', 'G:(1)'),
#   ('C/5', 'F:maj6', 'C/9'),
#   ('F#:dim', 'C:maj(#11)', 'D:min7/4'),
#   ('D:maj(9)', 'G:min/b7', 'B/6'),
#   ('Ab', 'Bb/b7', 'G:maj7/5'),
#   ('A:dim/b3', 'G#:hdim7', 'E:min/b7'),
#   ('D:maj(11)', 'G#:hdim7', 'C/9'),
#   ('F#:sus4', 'E/5', 'F#:dim/b7'),
#   ('D:maj6/5', 'C:maj(#11)', 'Eb:dim'),
#   ('Eb/2', 'B/7', 'C/9'),
#   ('F#:min7', 'G:7', 'G/5'),
#   ('Eb:dim', 'C/9', 'F#:dim/b7'),
#   ('D:maj6/5', 'F:min', 'B/5'),
#   ('F/3', 'G/5', 'F#'),
#   ('Bb/3', 'F:min', 'G:min'),
#   ('C:7', 'D:maj(9)', 'A:dim7/b3'),
#   ('G', 'C#:min7', 'D/3'),
#   ('F', 'E:7', 'A:dim7/b3'),
#   ('Eb/3', 'B/3', 'F/9'),
#   ('D#:dim7', 'D:maj(11)', 'D:dim'),
#   ('G:maj6/5', 'D:min7/4', 'A:min/5'),
#   ('C/5', 'C:maj(#11)', 'Bb/b7'),
#   ('G/3', 'F:maj7', 'F#:sus4'),
#   ('D', 'C:7', 'E:min/b7'),
#   ('G', 'G:min(9)/b3', 'Bb/3'),
#   ('C/5', 'A:dim/b5', 'Eb:dim'),
#   ('C', 'E:maj6', 'D/3'),
#   ('E', 'A/5', 'A:dim7/b3'),
#   ('G', 'C', 'G:9(*3)'),
#   ('F#:min7', 'F#:sus4', 'B/3'),
#   ('Ab', 'Eb', 'D:7/2'),
#   ('D:7', 'F/5', 'B/3'),
#   ('A', 'A/5', 'Bb:(1)'),
#   ('D#:dim7', 'A:7', 'Eb/5'),
#   ('G:maj6/5', 'D#:dim7', 'F:maj6'),
#   ('C/5', 'Eb/5', 'F#'),
#   ('N', 'F:(1)', 'A/3'),
#   ('D:maj6/5', 'F/3', 'B/3'),
#   ('D:min', 'F#:dim', 'A/3'),
#   ('Bb', 'Bb/3', 'F:min7'),
#   ('C:7', 'A:dim7/b3', 'F/3'),
#   ('A/5', 'G:9(*3)', 'D:maj(11)'),
#   ('C:7', 'F:7/b7', 'Eb/3'),
#   ('D:min', 'F:maj7', 'D:maj(11)'),
#   ('D:min7/4', 'Eb/5', 'F:7/b7'),
#   ('A:dim/b5', 'Eb/2', 'A/3'),
#   ('N', 'Eb', 'F/3'),
#   ('F#:dim', 'Ab', 'F:min/b7'),
#   ('Bb', 'D:maj6', 'Bb/3'),
#   ('E:7', 'F:min', 'B/6'),
#   ('Bb/3', 'G:9(*3)', 'B/6'),
#   ('D:maj(11)', 'F:maj/9', 'F/5'),
#   ('C/5', 'B/6', 'G#:hdim7'),
#   ('Bb', 'F#', 'G:maj7'),
#   ('A:min/5', 'G:min', 'A/3'),
#   ('D:7', 'D:min/b3', 'E:maj6'),
#   ('C/5', 'B:min', 'C/9'),
#   ('F#:min7', 'G:maj6/2', 'A/3'),
#   ('G/3', 'Bb/3', 'G:min/b7'),
#   ('D:maj6', 'Ab/7', 'Bb:(1)'),
#   ('G:maj6/5', 'C/7', 'D:7/2'),
#   ('A/b7', 'F:7/b7', 'B/7'),
#   ('F:7', 'F#:dim', 'G:maj7'),
#   ('F:7', 'D:7', 'D:min7/4'),
#   ('E', 'F:min', 'D:7/2'),
#   ('F/3', 'B/7', 'E/5'),
#   ('G:maj6/3', 'D:maj6/5', 'D:maj(11)'),
#   ('G:min', 'Eb/2', 'E:min/b7'),
#   ('G:maj6', 'D:maj(9)', 'A:dim/b3'),
#   ('C/7', 'Eb', 'C#:min7'),
#   ('D/b7', 'G#:hdim7', 'A/3'),
#   ('E', 'A/3', 'E:min/b7'),
#   ('A:min', 'F#:sus4', 'F/9'),
#   ('F#:dim', 'D:maj(9)', 'F:maj6'),
#   ('D', 'B/6', 'C#:min7'),
#   ('Bb/3', 'F#:dim', 'C#:min7'),
#   ('G:min(9)/b3', 'D:min', 'Bb/b7'),
#   ('D:min/b3', 'D:maj(11)', 'C:maj(#11)'),
#   ('G:min(9)/b3', 'Eb', 'F:7/b7'),
#   ('F:7', 'E:maj6', 'F#:dim/b7'),
#   ('A', 'F/3', 'F#:sus4'),
#   ('F', 'G:9(*3)', 'D:maj(9)'),
#   ('G:min(9)/b3', 'F:(1)', 'E:min/b7'),
#   ('A:dim7/b3', 'E/5', 'G:maj7/5'),
#   ('D:min', 'A:7', 'D:maj(11)'),
#   ('F:7/b7', 'B/7', 'E/5'),
#   ('C/5', 'F:maj7', 'Ab/7'),
#   ('D:min7/4', 'Eb/3', 'E:maj6'),
#   ('D:maj(11)', 'Eb/2', 'Bb:(1)'),
#   ('D:maj6', 'B:min7', 'G:maj6'),
#   ('A', 'F:(1)', 'F/9'),
#   ('G:min(9)/b3', 'F:(1)', 'E:maj6'),
#   ('G:maj6/2', 'Eb/2', 'G:maj7/5'),
#   ('G:min/5', 'C/5', 'G:maj7/5'),
#   ('A', 'F#:dim', 'A:7'),
#   ('Bb', 'C/7', 'D:min7/4'),
#   ('F/3', 'A:dim/b3', 'C/9'),
#   ('F#:min7', 'D:maj6/5', 'F'),
#   ('F:maj/9', 'A:dim/b3', 'B/3'),
#   ('A:dim7/b3', 'Bb:(1)', 'F#'),
#   ('C/5', 'F:7', 'C:7'),
#   ('F#:min7', 'D:maj6/5', 'E:min/b7'),
#   ('D:maj(11)', 'Ab/7', 'E/5'),
#   ('Ab/7', 'F/5', 'Eb/5'),
#   ('F:7', 'Ab/7', 'G:min'),
#   ('E:min', 'C', 'Ab/b7'),
#   ('A:min/5', 'A:dim7/b3', 'G:maj7/5'),
#   ('D/5', 'B', 'D:maj6'),
#   ('D/b7', 'C:7', 'F#:dim/b7'),
#   ('D/5', 'G#:(1)', 'G#:hdim7'),
#   ('D:min7/4', 'A:dim/b3', 'B/6'),
#   ('N', 'A', 'F/9'),
#   ('F/3', 'Eb/3', 'G:(1)'),
#   ('C:7', 'F#:dim', 'D#:dim7'),
#   ('D/5', 'Eb:dim', 'B/3'),
#   ('F:maj6', 'Eb', 'D/3'),
#   ('E:min', 'D:maj6/5', 'G:(1)'),
#   ('Bb/3', 'G:7', 'A:7'),
#   ('A:dim7/b3', 'F:min', 'F/3'),
#   ('B:min7', 'C/5', 'A:7'),
#   ('D:7', 'C#:min7', 'G:maj7/5'),
#   ('D:min7', 'D:maj(9)', 'F#:sus4'),
#   ('Bb/3', 'C:maj(#11)', 'G:maj7'),
#   ('F', 'C/7', 'G:maj7'),
#   ('B:min7', 'G:maj6/5', 'G:(1)'),
#   ('C/5', 'G:7', 'E/5'),
#   ('G#:(1)', 'C:maj(#11)', 'A/3'),
#   ('C/5', 'C/7', 'E/5'),
#   ('F#:min7', 'B:min7', 'F:min'),
#   ('E', 'G:min', 'E/5'),
#   ('G:maj6/3', 'Ab', 'Eb:dim'),
#   ('D:maj6', 'A:min/5', 'C#:min7'),
#   ('D:min7', 'Ab/7', 'G:maj7'),
#   ('D:min7/4', 'F/3', 'D:7/2'),
#   ('Eb/2', 'B/5', 'G:maj7'),
#   ('G', 'G:min(9)/b3', 'F:7'),
#   ('E', 'B', 'F:maj/9'),
#   ('Bb/3', 'G:9(*3)', 'G#:hdim7'),
#   ('G/3', 'D/5', 'B/3'),
#   ('A:min', 'D#:dim7', 'A/5'),
#   ('E:min', 'A/3', 'E:min/b7'),
#   ('D/b7', 'B:min', 'G#:hdim7'),
#   ('N', 'D:maj(9)', 'F:7/b7'),
#   ('G:maj6', 'F:min', 'D:dim'),
#   ('C', 'A:min', 'G:maj7'),
#   ('G#:(1)', 'C/5', 'B/7'),
#   ('G:maj6', 'G:min/b7', 'B/7'),
#   ('G:maj6/2', 'F#:sus4', 'G:maj7/5'),
#   ('D', 'E:min', 'E:maj6'),
#   ('E', 'D:min/b3', 'E:maj6'),
#   ('N', 'G:min/5', 'A:min/5'),
#   ('D', 'B:min7', 'A:dim/b5'),
#   ('F:7', 'G:(1)', 'B/7'),
#   ('G:min', 'F:min/b7', 'C/9'),
#   ('C', 'G:7', 'Ab/b7'),
#   ('G:min', 'G:(1)', 'G:maj7'),
#   ('G#:(1)', 'G:9(*3)', 'E:7'),
#   ('G:maj6/5', 'D:min7/4', 'G:min'),
#   ('G', 'Eb/3', 'B/3'),
#   ('A:dim/b3', 'G#:hdim7', 'C/9'),
#   ('G:min(9)/b3', 'F#:min7', 'Ab/7'),
#   ('A:min', 'A/5', 'G:maj7'),
#   ('E:min', 'G:min/5', 'D:7'),
#   ('Ab/b7', 'F:min7', 'Bb/b7'),
#   ('D/5', 'F:maj/9', 'Eb/2'),
#   ('E', 'A:min', 'F:maj7'),
#   ('D', 'F:maj7', 'F#:sus4'),
#   ('D:min', 'D:maj6/5', 'F#'),
#   ('E:7', 'F/5', 'G#:hdim7'),
#   ('G', 'G#:(1)', 'G:9(*3)'),
#   ('D:min', 'D:maj6/5', 'B/3'),
#   ('D', 'F#:min7', 'C/9'),
#   ('C/7', 'Ab/b7', 'A:min/5'),
#   ('E:min', 'B:min7', 'A/b7'),
#   ('E', 'A:min/5', 'B/7'),
#   ('G:min/5', 'D:dim', 'B/5'),
#   ('D:min7', 'F:min', 'B/6'),
#   ('F:maj7', 'A/b7', 'F:7/b7'),
#   ('A/b7', 'Eb/5', 'F:min'),
#   ('A', 'G:maj6', 'E:maj6'),
#   ...},
#  '012': {('B/7', 'C:maj(#11)', 'D:maj(9)'),
#   ('A:min', 'A:min/5', 'F:maj7'),
#   ('B/5', 'B/6', 'F:min/b7'),
#   ('A:min', 'B:min7', 'C'),
#   ('D', 'D:maj6/5', 'G:maj6/2'),
#   ('Bb', 'D:min', 'Eb/5'),
#   ('A', 'C:maj(#11)', 'D/5'),
#   ('D/5', 'E:7', 'N'),
#   ('A/3', 'D', 'D:maj6/5'),
#   ('Bb', 'Bb:(1)', 'G:min/b7'),
#   ('E:min', 'F#:dim', 'G:min'),
#   ('A', 'C/7', 'G#:hdim7'),
#   ('D:maj6', 'Eb/5', 'G:maj6/3'),
#   ('Ab', 'F', 'G:(1)'),
#   ('A:min/5', 'Ab/7', 'F:7/b7'),
#   ('A:dim/b5', 'D:maj(9)', 'Eb'),
#   ('A', 'A/3', 'D:7/2'),
#   ('A:7', 'G:maj6/5', 'N'),
#   ('B/6', 'E:min', 'G:maj6/3'),
#   ('C', 'F:maj/9', 'G#:(1)'),
#   ('B/5', 'C:maj(#11)', 'D:maj(9)'),
#   ('Ab', 'B:min', 'G#:hdim7'),
#   ('B:min', 'Eb:dim', 'G#:hdim7'),
#   ('F', 'F:maj7', 'G:maj7/5'),
#   ('A', 'G#:(1)', 'G:maj7/5'),
#   ('Bb/3', 'D:min', 'G/3'),
#   ('C#:min7', 'F', 'F:maj7'),
#   ('A:dim/b5', 'C', 'Eb'),
#   ('E:maj6', 'E:min', 'G:maj7/5'),
#   ('D:maj6/5', 'F:min', 'F:min/b7'),
#   ('A/5', 'F:maj/9', 'F:maj7'),
#   ('F', 'F/9', 'F:maj/9'),
#   ('Eb/5', 'Eb:dim', 'F/5'),
#   ('Eb', 'F:min', 'G/5'),
#   ('A/b7', 'F', 'G:7'),
#   ('F:7', 'F:maj/9', 'F:maj7'),
#   ('A:min/5', 'Ab/b7', 'F:7/b7'),
#   ('D', 'E/5', 'G:maj6/2'),
#   ('B', 'D:min7', 'E/5'),
#   ('C/9', 'G/5', 'G:maj6/5'),
#   ('A/b7', 'A:7', 'D:7'),
#   ('D/3', 'D:dim', 'E:min'),
#   ('A/b7', 'A:min/5', 'F#:min7'),
#   ('B/7', 'Bb:(1)', 'N'),
#   ('A', 'A/3', 'Bb/b7'),
#   ('D/b7', 'G/3', 'G:(1)'),
#   ('A:7', 'C/7', 'G/5'),
#   ('Eb/2', 'G#:hdim7', 'G:maj7'),
#   ('Bb/3', 'C/5', 'G#:hdim7'),
#   ('E:maj6', 'F:(1)', 'G:(1)'),
#   ('Bb', 'Eb/2', 'G:(1)'),
#   ('Bb', 'D:maj6', 'D:min7'),
#   ('A:min', 'Bb', 'C/7'),
#   ('Bb', 'F#', 'F/3'),
#   ('C', 'C:7', 'D/b7'),
#   ('A:dim7/b3', 'B/3', 'G:min/5'),
#   ('D:7', 'F#:dim', 'G:min'),
#   ('B/6', 'D/3', 'G'),
#   ('A', 'D:min', 'E:maj6'),
#   ('D:maj6', 'D:min7/4', 'G'),
#   ('A/5', 'B', 'E:min'),
#   ('F:7', 'G:maj6', 'G:maj6/5'),
#   ('Eb', 'F/9', 'G/5'),
#   ('Ab/b7', 'Bb', 'D/5'),
#   ('D:7', 'E:min', 'G:maj7/5'),
#   ('C#:min7', 'F#:sus4', 'G:maj7/5'),
#   ('Ab', 'Bb', 'G:(1)'),
#   ('E:min/b7', 'F#:min7', 'G#:(1)'),
#   ('Ab/7', 'F', 'F:maj7'),
#   ('F/3', 'F:(1)', 'G:min'),
#   ('D:min7', 'F:(1)', 'G:(1)'),
#   ('Eb:dim', 'G:min/5', 'N'),
#   ('A/b7', 'C', 'G:maj6/5'),
#   ('F#:min7', 'F:maj/9', 'G#:(1)'),
#   ('E:min', 'G:7', 'G:maj6/3'),
#   ('C', 'E', 'F:min'),
#   ('D:7', 'D:min', 'N'),
#   ('A:7', 'Bb/3', 'C/5'),
#   ('D', 'D#:dim7', 'D/b7'),
#   ('D/3', 'D:7/2', 'G:maj7'),
#   ('F#:dim', 'F:7', 'G#:(1)'),
#   ('F#:sus4', 'F:min', 'G:7'),
#   ('C#:min7', 'D#:dim7', 'F#:sus4'),
#   ('G', 'G:7', 'G:maj6/5'),
#   ('Bb:(1)', 'E:min', 'G:maj6/2'),
#   ('C', 'D:min7', 'G/3'),
#   ('D', 'F:min', 'F:min7'),
#   ('F#:min7', 'G#:(1)', 'G:9(*3)'),
#   ('D', 'F:maj7', 'G:maj6/2'),
#   ('Bb/3', 'C/5', 'F/9'),
#   ('G:(1)', 'G:min/5', 'G:min/b7'),
#   ('A:dim/b3', 'D', 'D:7/2'),
#   ('Ab', 'D:min7/4', 'F'),
#   ('Ab', 'C', 'F#'),
#   ('E:maj6', 'G:maj6/5', 'N'),
#   ('Bb/3', 'D', 'F#'),
#   ('B', 'C/9', 'E:min'),
#   ('Bb/3', 'D:maj(9)', 'E:7'),
#   ('Ab/7', 'Eb', 'F:7/b7'),
#   ('D:min', 'D:min7', 'Eb:dim'),
#   ('D/3', 'D:7/2', 'F/9'),
#   ('F#:dim', 'F:7/b7', 'N'),
#   ('Ab', 'Ab/7', 'G:(1)'),
#   ('D:min', 'D:min7', 'Eb/5'),
#   ('C/5', 'F', 'F:7/b7'),
#   ('A/3', 'Ab/7', 'Ab/b7'),
#   ('A:min/5', 'D:min7', 'F'),
#   ('D', 'E:min/b7', 'G:maj6/2'),
#   ('A:7', 'B/5', 'B:min'),
#   ('F', 'F#', 'F#:min7'),
#   ('D:min', 'D:min7', 'E/5'),
#   ('A:dim/b3', 'A:min', 'F:maj7'),
#   ('D/5', 'F:min7', 'G/5'),
#   ('Bb', 'D', 'F#'),
#   ('A:min/5', 'D', 'F#'),
#   ('A/5', 'A:7', 'F:maj7'),
#   ('A:7', 'D/3', 'E:min'),
#   ('E', 'Eb/5', 'N'),
#   ('A', 'C#:min7', 'F:maj7'),
#   ('D/b7', 'G/3', 'G:maj6/2'),
#   ('D:min/b3', 'G#:hdim7', 'G:9(*3)'),
#   ('A:min/5', 'D:min7/4', 'F:maj/9'),
#   ('D:min', 'D:min7', 'G/5'),
#   ('D:min/b3', 'E:min', 'G:maj6'),
#   ('A:min/5', 'C/9', 'G/5'),
#   ('F', 'F#:dim', 'F#:min7'),
#   ('D:min/b3', 'Eb/5', 'F/5'),
#   ('E', 'F:maj7', 'N'),
#   ('D', 'F:min/b7', 'G/3'),
#   ('C#:min7', 'E:7', 'N'),
#   ('F/9', 'G', 'G:(1)'),
#   ('C', 'D:min7/4', 'G/3'),
#   ('E', 'E:7', 'F:maj/9'),
#   ('B', 'Bb', 'E:min'),
#   ('D:min7/4', 'E/5', 'F:maj/9'),
#   ('D/b7', 'Eb/3', 'F:(1)'),
#   ('C/9', 'F/3', 'G'),
#   ('Ab', 'Bb:(1)', 'F'),
#   ('F:7', 'F:maj7', 'G:min/b7'),
#   ('C/9', 'E:7', 'G'),
#   ('C', 'D/b7', 'E:min'),
#   ('A:min', 'Eb', 'Eb:dim'),
#   ('A:min', 'D:maj(9)', 'N'),
#   ('C#:min7', 'D:7', 'F#:sus4'),
#   ('D/b7', 'Eb/2', 'G/3'),
#   ('E:min', 'F:7/b7', 'G:maj6/2'),
#   ('Bb', 'Eb/3', 'F/9'),
#   ('A:dim/b3', 'D:min', 'G:7'),
#   ('Ab', 'Ab/7', 'G/5'),
#   ('D:dim', 'Eb', 'G:maj6/3'),
#   ('A:dim/b5', 'B/7', 'Eb'),
#   ('A:dim/b3', 'Bb/3', 'Eb'),
#   ('D:maj6', 'D:min7/4', 'N'),
#   ('A:dim/b3', 'Eb', 'G#:hdim7'),
#   ('C', 'D:dim', 'F:min/b7'),
#   ('B:min', 'D/3', 'D:7'),
#   ('A', 'A/b7', 'E:maj6'),
#   ('Eb', 'G:7', 'G:maj6/2'),
#   ('A', 'G/3', 'G:maj7'),
#   ('Ab/7', 'D:dim', 'F:min/b7'),
#   ('E:min', 'G', 'G:maj6'),
#   ('Ab', 'G', 'G:7'),
#   ('D:min7/4', 'Eb', 'Eb/2'),
#   ('E:7', 'F', 'G:maj6/5'),
#   ('A:dim/b3', 'Bb', 'G:min'),
#   ('A:min', 'C', 'Eb/3'),
#   ('B:min7', 'C', 'G:9(*3)'),
#   ('D:min/b3', 'E:maj6', 'G:9(*3)'),
#   ('A:dim7/b3', 'D:dim', 'G:min/5'),
#   ('Eb/5', 'F#:sus4', 'F/5'),
#   ('D:7', 'D:min7', 'G:7'),
#   ('A/3', 'A:dim/b3', 'A:min/5'),
#   ('A/b7', 'Bb', 'G:(1)'),
#   ('D', 'F#:dim', 'F:7'),
#   ('A', 'B/7', 'C'),
#   ('Eb/3', 'G', 'G/5'),
#   ('A:7', 'C/7', 'G:9(*3)'),
#   ('F:maj/9', 'G:maj6', 'G:maj6/5'),
#   ('A:dim/b3', 'B/5', 'E:maj6'),
#   ('A:dim/b3', 'Bb/3', 'C/5'),
#   ('B/7', 'F:7', 'F:maj7'),
#   ('B', 'G', 'G:min(9)/b3'),
#   ('A/3', 'A:min', 'F:maj7'),
#   ('A:dim7/b3', 'F#:dim', 'G:min'),
#   ('C', 'E:min/b7', 'G:min/b7'),
#   ('B/5', 'C', 'D:min'),
#   ('F#:dim', 'G:7', 'G:min'),
#   ('D:7/2', 'G#:hdim7', 'G:maj7'),
#   ('A', 'A/b7', 'F:(1)'),
#   ('Ab', 'B/6', 'C'),
#   ('C', 'F/9', 'F:maj/9'),
#   ('C#:min7', 'D:min', 'F#:sus4'),
#   ('D:min7/4', 'G', 'G:min/b7'),
#   ('C:maj(#11)', 'G/3', 'G:maj7/5'),
#   ('B', 'Bb/3', 'C/5'),
#   ('Bb', 'E', 'G:min'),
#   ('D/3', 'D:min', 'E:min'),
#   ('Bb/b7', 'D', 'F#'),
#   ('E:7', 'G/5', 'N'),
#   ('Bb', 'D/5', 'G:maj6'),
#   ('B/3', 'D:7', 'G:7'),
#   ('A:dim/b3', 'C:maj(#11)', 'Eb'),
#   ('A:dim7/b3', 'F#:dim', 'F:7'),
#   ('Eb', 'F#:dim/b7', 'F:(1)'),
#   ('B/5', 'F#:sus4', 'G:maj7'),
#   ('Ab/7', 'D:maj6', 'G:maj6/3'),
#   ('B/7', 'G/3', 'G:min(9)/b3'),
#   ('C/5', 'Eb', 'G:min'),
#   ('A', 'D/5', 'D:maj6/5'),
#   ('E', 'G:maj6', 'N'),
#   ('F', 'F#', 'F:maj7'),
#   ('A', 'A:min/5', 'F:maj7'),
#   ('Ab', 'D:maj(9)', 'F'),
#   ('B:min7', 'E:min', 'F:7'),
#   ('F/5', 'G:maj6/3', 'G:min/5'),
#   ('B/3', 'E', 'G:maj6/5'),
#   ('A:min', 'C/7', 'D:maj(11)'),
#   ('Ab/7', 'Ab/b7', 'G:min/b7'),
#   ('A:min/5', 'F', 'G:maj7/5'),
#   ('B/6', 'Eb', 'G/5'),
#   ('A:min', 'C', 'C:maj(#11)'),
#   ('C:7', 'D', 'D/b7'),
#   ('D:maj6', 'G:maj6/3', 'G:maj7'),
#   ('C/7', 'D:min/b3', 'F:maj7'),
#   ('D:maj6/5', 'F:7/b7', 'G:maj6/5'),
#   ('C#:min7', 'D#:dim7', 'E:maj6'),
#   ('A:dim/b5', 'A:min', 'E'),
#   ('Eb/2', 'G/3', 'G:min(9)/b3'),
#   ('C:maj(#11)', 'F:maj6', 'G/3'),
#   ('C', 'D/5', 'G:maj7/5'),
#   ('B/6', 'C', 'C:7'),
#   ('B/3', 'D:maj6/5', 'G:maj6/5'),
#   ('Ab', 'D:min/b3', 'F'),
#   ('B/5', 'B:min', 'N'),
#   ('F#', 'G:maj6', 'G:maj6/5'),
#   ('D:min/b3', 'F:min7', 'G/5'),
#   ('A:dim/b3', 'Eb', 'F:min'),
#   ('Bb/3', 'E', 'E/5'),
#   ('Ab', 'D', 'D:min'),
#   ('C#:min7', 'D', 'D:7/2'),
#   ('B', 'D:7/2', 'G'),
#   ('D', 'F/9', 'N'),
#   ('A:dim/b5', 'C:maj(#11)', 'Eb'),
#   ('F', 'F/3', 'F/9'),
#   ('Eb', 'Eb/3', 'F/5'),
#   ('B/3', 'C:maj(#11)', 'D:maj(9)'),
#   ('B/6', 'E:min', 'G:maj7/5'),
#   ('F', 'F/9', 'G/3'),
#   ('F#:dim', 'G:maj7', 'N'),
#   ('F', 'F#:min7', 'F:7/b7'),
#   ('D:dim', 'F:min/b7', 'G:min/b7'),
#   ('A/b7', 'F:min7', 'G/5'),
#   ('B', 'E:min', 'F/5'),
#   ('Bb/b7', 'C', 'D:min'),
#   ('A/b7', 'C', 'C/9'),
#   ('A:7', 'C#:min7', 'D:7'),
#   ('A:7', 'D:7', 'E/5'),
#   ('A:dim/b3', 'C', 'F'),
#   ('B/5', 'B/6', 'D:maj6/5'),
#   ('D:min/b3', 'G', 'G:7'),
#   ('Bb/3', 'D:min', 'F:maj/9'),
#   ('A/5', 'A:dim/b5', 'F:maj7'),
#   ('B/6', 'B:min', 'G#:hdim7'),
#   ('A:dim/b3', 'A:min/5', 'C/7'),
#   ('B:min7', 'D:min7/4', 'G'),
#   ('Eb', 'G/3', 'G/5'),
#   ('B', 'B/3', 'Eb/2'),
#   ('A:min', 'D', 'G/3'),
#   ('Bb/3', 'C#:min7', 'F#:sus4'),
#   ('F', 'F#:min7', 'G:min/b7'),
#   ('A', 'A/3', 'G:min'),
#   ('C', 'G/3', 'G:maj6/5'),
#   ('B/3', 'B/5', 'E'),
#   ('D/b7', 'D:maj6', 'G/3'),
#   ('Ab/b7', 'Bb', 'Eb/5'),
#   ('D', 'D:min', 'G#:(1)'),
#   ('A:min', 'Eb', 'F#:dim'),
#   ('A/5', 'D:dim', 'F:maj7'),
#   ('D:min7/4', 'E', 'F:maj/9'),
#   ('D:dim', 'F:min/b7', 'G'),
#   ('C/9', 'D:maj(9)', 'G/5'),
#   ('A:min/5', 'C', 'G/3'),
#   ('A', 'Eb', 'G:min'),
#   ('F:maj6', 'F:min', 'F:min7'),
#   ('A:7', 'D:maj6/5', 'G:maj6/5'),
#   ('D:min7', 'F', 'F/9'),
#   ('A:dim/b5', 'A:min/5', 'G:maj6'),
#   ('C:7', 'E/5', 'F'),
#   ('D/3', 'D:7', 'F:7'),
#   ('B/6', 'B/7', 'F#:sus4'),
#   ('Bb', 'Bb:(1)', 'D:7/2'),
#   ('E:min', 'F', 'F:maj7'),
#   ('E', 'E:7', 'Eb/3'),
#   ('A:dim/b3', 'A:min/5', 'G:maj6/5'),
#   ('D:min7/4', 'G', 'G:maj6/3'),
#   ('C', 'G/5', 'G:maj7/5'),
#   ('B', 'F/3', 'G'),
#   ('G/3', 'G/5', 'G:min(9)/b3'),
#   ('A/3', 'Eb', 'Eb:dim'),
#   ('D:min', 'D:min/b3', 'F:maj7'),
#   ('C:7', 'Eb', 'G:7'),
#   ('C/7', 'F#:dim', 'F:7'),
#   ('Ab/7', 'Ab/b7', 'D:maj(9)'),
#   ('Bb:(1)', 'C:maj(#11)', 'D:maj(9)'),
#   ('A:dim/b3', 'F:min', 'F:min/b7'),
#   ('A:min', 'F#:dim', 'G:maj6/3'),
#   ('A:dim/b5', 'D:maj6/5', 'Eb'),
#   ('C:maj(#11)', 'D:maj(9)', 'F#'),
#   ('A:7', 'A:dim/b3', 'D:7'),
#   ('Bb', 'F#:dim', 'F:7'),
#   ('C#:min7', 'F#:sus4', 'F:7/b7'),
#   ('A', 'F#:dim/b7', 'G#:(1)'),
#   ('A:min', 'F/9', 'F:maj7'),
#   ('A:min', 'E:min/b7', 'Eb'),
#   ('Ab', 'C', 'F#:dim'),
#   ('A:min', 'E:min/b7', 'Eb/5'),
#   ('G:maj6/2', 'G:min/5', 'G:min/b7'),
#   ('Ab/b7', 'F:7', 'G/3'),
#   ('A:min', 'Eb:dim', 'G:min/5'),
#   ('D', 'D:min', 'F/5'),
#   ('A', 'A:dim/b3', 'E:min'),
#   ('D:maj(9)', 'E:7', 'G:maj7'),
#   ('A/b7', 'E:min', 'G:maj6'),
#   ('B:min', 'F#:min7', 'G#:hdim7'),
#   ('D/3', 'D:dim', 'F:min/b7'),
#   ('A/3', 'E', 'G'),
#   ('E', 'E:min', 'G:maj6'),
#   ('D#:dim7', 'D:maj6', 'N'),
#   ('Bb:(1)', 'D', 'G/3'),
#   ('C', 'E', 'G#:hdim7'),
#   ('A', 'F/5', 'G:min/5'),
#   ('D/b7', 'Eb', 'Eb/3'),
#   ('A', 'A/b7', 'D:min7/4'),
#   ('Eb:dim', 'F#', 'G:min/5'),
#   ('C:maj(#11)', 'G#:hdim7', 'G/3'),
#   ('A:dim/b3', 'D:min/b3', 'G:9(*3)'),
#   ('A:min', 'E', 'G:7'),
#   ('B:min', 'F:maj/9', 'G#:hdim7'),
#   ('D:min', 'Eb', 'G/5'),
#   ('Bb/3', 'E:min', 'E:min/b7'),
#   ('B:min7', 'E:min', 'Eb'),
#   ('A/5', 'C:maj(#11)', 'D:maj(9)'),
#   ('Ab', 'F:maj6', 'N'),
#   ('D:min', 'G:(1)', 'G:7'),
#   ('Ab/b7', 'F', 'F#:min7'),
#   ('A:dim7/b3', 'E:min', 'G:maj7/5'),
#   ('Ab/7', 'Eb/3', 'F:(1)'),
#   ('D:maj(11)', 'G:min/5', 'G:min/b7'),
#   ('D', 'D/b7', 'G:7'),
#   ('A/5', 'E:maj6', 'F:maj7'),
#   ('Bb/3', 'F#:dim', 'G:min'),
#   ('C#:min7', 'F:(1)', 'G:(1)'),
#   ('A:min', 'D:maj6/5', 'E:min/b7'),
#   ('A/5', 'Ab', 'D:min'),
#   ('Bb/b7', 'Eb/5', 'F/5'),
#   ('B', 'B/7', 'E:min/b7'),
#   ('Ab', 'D:maj(11)', 'F'),
#   ('Bb/3', 'C/5', 'F:min'),
#   ('A/b7', 'C', 'F#:sus4'),
#   ('B/5', 'D:maj(11)', 'E:maj6'),
#   ('A/3', 'D/3', 'D:7/2'),
#   ('D:min7', 'F:min', 'F:min7'),
#   ('E/5', 'F', 'F:maj7'),
#   ('Eb', 'Eb/3', 'F:maj7'),
#   ('A/5', 'D:maj(9)', 'D:min'),
#   ('Eb', 'Eb/3', 'N'),
#   ('Eb', 'Eb:dim', 'F#:dim/b7'),
#   ('D:7/2', 'Eb', 'G:min/b7'),
#   ('D', 'Eb', 'F#'),
#   ('B/3', 'E', 'F:maj7'),
#   ('A:7', 'B/3', 'D:7'),
#   ('B:min7', 'Eb', 'F:(1)'),
#   ('B', 'B/7', 'Eb/2'),
#   ('F:min7', 'G', 'G:7'),
#   ('C#:min7', 'C:7', 'F#:sus4'),
#   ('C/5', 'E:min', 'G:maj6/2'),
#   ('D#:dim7', 'F#:dim', 'N'),
#   ('Eb/3', 'F:(1)', 'N'),
#   ('E', 'E/5', 'E:maj6'),
#   ('A:dim/b5', 'D:min7/4', 'G'),
#   ('D:maj6/5', 'Eb/2', 'Eb/3'),
#   ('B:min', 'D/3', 'G#:hdim7'),
#   ('A:dim/b3', 'D:7', 'G:7'),
#   ('D', 'F:7', 'F:maj7'),
#   ('A:dim/b3', 'A:min/5', 'D:maj(9)'),
#   ('A:min', 'E:min/b7', 'G:min'),
#   ('D/5', 'F#', 'G:min(9)/b3'),
#   ('Bb', 'D/b7', 'F/3'),
#   ('Ab/b7', 'B:min7', 'F:7'),
#   ('C#:min7', 'D:maj6', 'G:maj6/3'),
#   ('F/9', 'F:maj6', 'G'),
#   ('F:maj/9', 'F:min', 'F:min7'),
#   ('Eb', 'F:min7', 'G:min/b7'),
#   ('Bb', 'Bb:(1)', 'C:maj(#11)'),
#   ('D:7', 'Eb/3', 'F:(1)'),
#   ('Bb', 'E/5', 'F/3'),
#   ('D:min/b3', 'G#:(1)', 'G:9(*3)'),
#   ('A:dim7/b3', 'C:maj(#11)', 'Eb'),
#   ('Bb', 'Eb/5', 'F/9'),
#   ('Eb:dim', 'F', 'G:min/5'),
#   ('Bb/3', 'C', 'E:min'),
#   ('D:maj(9)', 'D:min/b3', 'F:maj7'),
#   ('D/b7', 'G/3', 'G/5'),
#   ('F#:min7', 'F:(1)', 'G#:(1)'),
#   ('A:min', 'E:maj6', 'N'),
#   ('A/5', 'Eb', 'G:7'),
#   ('Bb', 'E/5', 'F:min'),
#   ('A:7', 'C/7', 'G:(1)'),
#   ('A/b7', 'F', 'F:min/b7'),
#   ('C', 'F:min7', 'G:maj7/5'),
#   ('B/5', 'F', 'N'),
#   ('A:7', 'F:(1)', 'G:(1)'),
#   ('D:min7/4', 'E:maj6', 'G'),
#   ('E:min', 'F:maj/9', 'G:maj6'),
#   ('B', 'B/3', 'C:maj(#11)'),
#   ('C/9', 'G:maj6/5', 'N'),
#   ('E:min', 'E:min/b7', 'G:min(9)/b3'),
#   ('A/b7', 'C', 'G:maj6'),
#   ('A', 'G:min/5', 'G:min/b7'),
#   ('A:min', 'F:maj7', 'G:min/b7'),
#   ('D', 'E:7', 'G:maj6/5'),
#   ('C:maj(#11)', 'D/3', 'D:maj(9)'),
#   ('F', 'F/9', 'G:maj6/5'),
#   ('Ab', 'B:min7', 'E:min'),
#   ('A/3', 'A:min', 'E'),
#   ('Ab', 'F', 'G/5'),
#   ('A:min/5', 'B/6', 'F:7/b7'),
#   ('B/3', 'E:7', 'F'),
#   ('D', 'E:7', 'F:7/b7'),
#   ('D:dim', 'Eb', 'G#:(1)'),
#   ('Bb/3', 'E:min', 'G:maj6/2'),
#   ('Bb/3', 'G/3', 'G:min(9)/b3'),
#   ('D:7', 'F#:dim', 'F:7'),
#   ('C', 'D/3', 'G/3'),
#   ('A/3', 'E:min', 'G:maj6/2'),
#   ('C', 'C/7', 'E:7'),
#   ('F', 'F/9', 'F:(1)'),
#   ('F:maj/9', 'F:min', 'F:min/b7'),
#   ('Bb', 'Eb/5', 'G#:(1)'),
#   ('D:7', 'F:7/b7', 'G:7'),
#   ('Eb', 'Eb:dim', 'G:maj6/3'),
#   ('A:dim/b3', 'E:min/b7', 'Eb'),
#   ('F/9', 'F:7', 'G'),
#   ('G/3', 'G:maj6/3', 'G:min(9)/b3'),
#   ('A:7', 'D:7', 'F:min'),
#   ('Bb:(1)', 'E:min', 'G:maj6'),
#   ('E:min', 'E:min/b7', 'F#:sus4'),
#   ('Bb/b7', 'G/3', 'G:min(9)/b3'),
#   ('E', 'E/5', 'G:maj6/5'),
#   ('C/9', 'D#:dim7', 'G/5'),
#   ('A', 'C#:min7', 'G/3'),
#   ('F:maj6', 'G:maj7', 'N'),
#   ('Eb/3', 'F:7', 'F:maj7'),
#   ('E:maj6', 'F#:min7', 'G#:(1)'),
#   ('A:min', 'D:min7/4', 'F#:dim'),
#   ('B/6', 'B/7', 'G/3'),
#   ('Eb/2', 'Eb/3', 'G:7'),
#   ('B/6', 'D:maj(9)', 'E:7'),
#   ('Bb', 'Eb/5', 'G#:hdim7'),
#   ('B/3', 'B:min7', 'D:maj6'),
#   ('B', 'F', 'F:min'),
#   ('C', 'E:min/b7', 'G:maj6/3'),
#   ('Bb:(1)', 'D/3', 'D:7'),
#   ('A', 'B/5', 'C/7'),
#   ('A:dim7/b3', 'Eb', 'G:maj6/5'),
#   ('A/b7', 'A:7', 'F'),
#   ('A:dim/b3', 'D:min7/4', 'G'),
#   ('D/3', 'F/3', 'G'),
#   ('B', 'E:min', 'G/3'),
#   ('D', 'G:min/5', 'N'),
#   ('F/3', 'F:min', 'G:min'),
#   ('Bb', 'Eb/3', 'F:maj7'),
#   ('A:7', 'D:7', 'D:min7'),
#   ('Bb/3', 'D', 'N'),
#   ('C/5', 'Eb', 'Eb/2'),
#   ('C:maj(#11)', 'G/3', 'G:maj6'),
#   ('Bb/3', 'D:min', 'E:7'),
#   ('E:min', 'F:maj7', 'G:maj6'),
#   ('D/5', 'D:min7/4', 'G:min(9)/b3'),
#   ('G#:hdim7', 'G:min/5', 'G:min/b7'),
#   ('A:dim/b3', 'A:min/5', 'G/5'),
#   ('B:min', 'Bb', 'G#:hdim7'),
#   ('Eb/3', 'F:(1)', 'G'),
#   ('D/3', 'D:min', 'F#:dim/b7'),
#   ('A:dim/b5', 'B', 'F'),
#   ('B', 'C:7', 'G'),
#   ('A/3', 'D', 'F:7/b7'),
#   ('Bb', 'E:min/b7', 'G'),
#   ('F:min7', 'G/5', 'G:maj7/5'),
#   ('A', 'A/3', 'F/5'),
#   ('Bb/b7', 'C:maj(#11)', 'D:maj(9)'),
#   ('C/9', 'C:7', 'G'),
#   ('A:min/5', 'E:maj6', 'F'),
#   ('F/9', 'G/3', 'G:min(9)/b3'),
#   ('Ab/b7', 'C', 'G/3'),
#   ('A/b7', 'F#:min7', 'F:maj7'),
#   ('E:min', 'F', 'F/9'),
#   ('A', 'D/3', 'F#:dim/b7'),
#   ('C:maj(#11)', 'D/3', 'D:7'),
#   ('B', 'D', 'E/5'),
#   ('A/5', 'D:min', 'F:min'),
#   ('B', 'B/7', 'C/7'),
#   ('A:min/5', 'E:min/b7', 'G'),
#   ('F#:dim', 'G:min/5', 'G:min/b7'),
#   ('Bb/b7', 'G#:hdim7', 'G:maj7'),
#   ('D:min', 'D:min7', 'F:maj6'),
#   ('D:7/2', 'Eb', 'F:(1)'),
#   ('A/b7', 'B:min7', 'F#:min7'),
#   ('Ab', 'F', 'F:maj6'),
#   ('F#:dim', 'F:7', 'G:maj6/5'),
#   ('B/5', 'G:maj6', 'G:maj6/5'),
#   ('D:7', 'E', 'G:7'),
#   ('F:min', 'G:7', 'G:maj6/3'),
#   ('A:min/5', 'C/9', 'F:7/b7'),
#   ('D:min/b3', 'Eb/5', 'F:maj7'),
#   ('E:min/b7', 'F:7/b7', 'G'),
#   ('Bb/3', 'F#:sus4', 'G:maj7'),
#   ('E:7', 'Eb:dim', 'G:min/5'),
#   ('C:maj(#11)', 'G/3', 'G:maj7'),
#   ('D', 'D/3', 'N'),
#   ('C', 'E', 'F:min7'),
#   ('Eb/2', 'Eb/3', 'F:min/b7'),
#   ('A:dim/b3', 'A:min/5', 'G:maj6/2'),
#   ('Bb', 'C:maj(#11)', 'Eb/5'),
#   ('C', 'E:min', 'F#:dim/b7'),
#   ('A/b7', 'B/7', 'F#:min7'),
#   ('Ab', 'D:dim', 'Eb'),
#   ('D/5', 'F', 'F:maj7'),
#   ('E:min', 'E:min/b7', 'Eb/3'),
#   ('A', 'B/3', 'G/3'),
#   ('C/9', 'D/3', 'G/5'),
#   ('D:maj6', 'D:min7', 'F:(1)'),
#   ('A:7', 'D:maj6', 'G:maj6/3'),
#   ('Ab', 'C', 'D/3'),
#   ('A:7', 'E', 'G'),
#   ('A/b7', 'F', 'F:7/b7'),
#   ('B:min7', 'D:maj6', 'G:9(*3)'),
#   ('C:maj(#11)', 'F/9', 'G'),
#   ('D#:dim7', 'F', 'G:min'),
#   ('A', 'Ab', 'C/7'),
#   ('D:maj6', 'D:min/b3', 'G:maj6/3'),
#   ('Bb/3', 'C/5', 'C/7'),
#   ('D:maj6/5', 'G:maj6/3', 'G:maj6/5'),
#   ('Eb', 'G:maj6/3', 'G:min'),
#   ('Bb', 'F#', 'G:(1)'),
#   ('A', 'B/3', 'D/5'),
#   ('A:dim/b3', 'D', 'E:7'),
#   ('Bb', 'Eb:dim', 'G:min'),
#   ('C#:min7', 'F:7', 'F:maj7'),
#   ('D:min/b3', 'E', 'N'),
#   ('C', 'E:min/b7', 'Eb/2'),
#   ('D/3', 'E:min/b7', 'F#:dim/b7'),
#   ('D:dim', 'D:min', 'N'),
#   ('C', 'C:maj(#11)', 'G:maj7/5'),
#   ('C/7', 'D', 'D:7/2'),
#   ('C/9', 'D', 'D:min'),
#   ('D/3', 'D:maj6/5', 'G'),
#   ('Eb', 'F#:sus4', 'F:(1)'),
#   ('B/7', 'D:min', 'G:7'),
#   ('A/5', 'F#:dim', 'F:maj7'),
#   ('Eb/3', 'F:(1)', 'G:9(*3)'),
#   ('D', 'D/b7', 'G:9(*3)'),
#   ('F#:dim', 'F:maj7', 'N'),
#   ('C', 'F', 'G:maj6/5'),
#   ('G:7', 'G:min/5', 'G:min/b7'),
#   ('D:7/2', 'Eb', 'G:min'),
#   ('Ab', 'D:min7/4', 'F:maj/9'),
#   ('C/9', 'G/5', 'G:maj6/2'),
#   ('D/3', 'Eb/5', 'F#:dim/b7'),
#   ('A', 'D:min', 'G:min(9)/b3'),
#   ('F#:min7', 'F/9', 'G#:(1)'),
#   ('C/7', 'E:min', 'E:min/b7'),
#   ('D', 'G/3', 'G:min/5'),
# ...
#   ('A:dim/b3', 'Eb', 'G'),
#   ('A:dim/b5', 'Bb', 'Eb'),
#   ('A:dim/b5', 'Eb', 'F'),
#   ('A:dim/b5', 'Eb', 'G'),
#   ('A:dim7/b3', 'D:min', 'G:min/5'),
#   ('A:min', 'Bb/3', 'C/5'),
#   ('A:min', 'C/5', 'C/7'),
#   ('A:min', 'C/5', 'E'),
#   ('A:min', 'C/5', 'E:min/b7'),
#   ('A:min', 'C/5', 'N'),
#   ('A:min', 'C/7', 'G'),
#   ('A:min', 'C/9', 'G'),
#   ('A:min', 'D/b7', 'G'),
#   ('A:min', 'G', 'G:7'),
#   ('Ab', 'B', 'C'),
#   ('Ab', 'Bb', 'C'),
#   ('Ab', 'C', 'C/5'),
#   ('Ab', 'C', 'D'),
#   ('Ab', 'C', 'D#:dim7'),
#   ('Ab', 'C', 'F:7'),
#   ('Ab', 'C', 'F:maj6'),
#   ('Ab', 'C', 'G'),
#   ('Ab', 'C', 'G:7'),
#   ('Ab', 'C', 'N'),
#   ('Ab/b7', 'C', 'F:7'),
#   ('B', 'C', 'E/5'),
#   ('B', 'C', 'E:min/b7'),
#   ('B', 'C', 'F#'),
#   ('B', 'C', 'F:maj/9'),
#   ('B', 'C', 'G/3'),
#   ('B', 'C', 'G:9(*3)'),
#   ('B', 'C', 'G:maj7/5'),
#   ('B', 'D:min', 'N'),
#   ('B', 'E/5', 'F#:min7'),
#   ('B', 'E/5', 'N'),
#   ('B', 'E:7', 'N'),
#   ('B', 'F#', 'F#:min7'),
#   ('B', 'F#', 'N'),
#   ('B', 'F#:dim', 'N'),
#   ('B', 'F#:min7', 'G'),
#   ('B', 'G:maj6/5', 'N'),
#   ('B/3', 'D', 'E'),
#   ('B/3', 'E', 'F'),
#   ('Bb', 'Bb/b7', 'Bb:(1)'),
#   ('Bb', 'Bb/b7', 'Eb/5'),
#   ('Bb', 'Bb:(1)', 'C'),
#   ('Bb', 'Bb:(1)', 'Eb'),
#   ('Bb', 'Bb:(1)', 'F'),
#   ('Bb', 'Bb:(1)', 'G/3'),
#   ('Bb', 'C', 'E:min'),
#   ('Bb', 'C', 'E:min/b7'),
#   ('Bb', 'C', 'Eb/5'),
#   ('Bb', 'C', 'F:maj/9'),
#   ('Bb', 'C', 'G:9(*3)'),
#   ('Bb', 'C', 'G:maj7/5'),
#   ('Bb', 'C/5', 'F'),
#   ('Bb', 'C:7', 'F'),
#   ('Bb', 'C:maj(#11)', 'G/3'),
#   ('Bb', 'D', 'D/5'),
#   ('Bb', 'D/b7', 'G/3'),
#   ('Bb', 'D:dim', 'Eb'),
#   ('Bb', 'D:min', 'N'),
#   ('Bb', 'E', 'N'),
#   ('Bb', 'E:7', 'N'),
#   ('Bb', 'Eb', 'Eb/2'),
#   ('Bb', 'Eb', 'Eb/5'),
#   ('Bb', 'Eb', 'F:(1)'),
#   ('Bb', 'Eb', 'F:7/b7'),
#   ('Bb', 'Eb', 'G/5'),
#   ('Bb', 'Eb', 'G:7'),
#   ('Bb', 'Eb', 'G:min/b7'),
#   ('Bb', 'Eb/5', 'F'),
#   ('Bb', 'Eb/5', 'G/3'),
#   ('Bb', 'Eb/5', 'N'),
#   ('Bb', 'F', 'F#:min7'),
#   ('Bb', 'F', 'F/9'),
#   ('Bb', 'F#:dim', 'N'),
#   ('Bb', 'G:maj6/5', 'N'),
#   ('Bb/3', 'C', 'C/5'),
#   ('Bb/3', 'C/5', 'G'),
#   ('Bb/3', 'C/5', 'G:7'),
#   ('C', 'C/5', 'E:min'),
#   ('C', 'C/5', 'E:min/b7'),
#   ('C', 'C/5', 'F:maj/9'),
#   ('C', 'C/5', 'G/3'),
#   ('C', 'C/5', 'G:9(*3)'),
#   ('C', 'C/5', 'G:maj7/5'),
#   ('C', 'C/9', 'G'),
#   ('C', 'D', 'D:7/2'),
#   ('C', 'D', 'E:7'),
#   ('C', 'D', 'E:min'),
#   ('C', 'D', 'E:min/b7'),
#   ('C', 'D', 'F'),
#   ('C', 'D', 'F#:dim/b7'),
#   ('C', 'D', 'F:maj/9'),
#   ('C', 'D', 'G:9(*3)'),
#   ('C', 'D', 'G:maj6/2'),
#   ('C', 'D', 'G:maj7/5'),
#   ('C', 'D#:dim7', 'E:min'),
#   ('C', 'D#:dim7', 'E:min/b7'),
#   ('C', 'D#:dim7', 'F'),
#   ('C', 'D#:dim7', 'F:maj/9'),
#   ('C', 'D#:dim7', 'G/3'),
#   ('C', 'D#:dim7', 'G:9(*3)'),
#   ('C', 'D#:dim7', 'G:maj7/5'),
#   ('C', 'D/b7', 'G'),
#   ('C', 'D:7', 'G:7'),
#   ('C', 'D:min', 'G:min/5'),
#   ('C', 'E:7', 'N'),
#   ('C', 'E:min', 'F:7'),
#   ('C', 'E:min', 'F:maj6'),
#   ('C', 'E:min', 'G'),
#   ('C', 'E:min', 'G:7'),
#   ('C', 'E:min', 'N'),
#   ('C', 'E:min/b7', 'F:7'),
#   ('C', 'E:min/b7', 'F:maj6'),
#   ('C', 'E:min/b7', 'G:7'),
#   ('C', 'E:min/b7', 'N'),
#   ('C', 'F', 'F:7'),
#   ('C', 'F', 'F:maj6'),
#   ('C', 'F', 'G:7'),
#   ('C', 'F#:dim', 'N'),
#   ('C', 'F:7', 'F:maj/9'),
#   ('C', 'F:7', 'F:maj7'),
#   ('C', 'F:7', 'G/3'),
#   ('C', 'F:7', 'G:9(*3)'),
#   ('C', 'F:7', 'G:maj7/5'),
#   ('C', 'F:maj/9', 'F:maj6'),
#   ('C', 'F:maj/9', 'G'),
#   ('C', 'F:maj/9', 'G:7'),
#   ('C', 'F:maj/9', 'N'),
#   ('C', 'F:maj6', 'G/3'),
#   ('C', 'F:maj6', 'G:9(*3)'),
#   ('C', 'F:maj6', 'G:maj7/5'),
#   ('C', 'F:min', 'G:7'),
#   ('C', 'G', 'G/3'),
#   ('C', 'G', 'G:9(*3)'),
#   ('C', 'G', 'G:maj7/5'),
#   ('C', 'G/3', 'G:7'),
#   ('C', 'G/3', 'N'),
#   ('C', 'G:7', 'G:9(*3)'),
#   ('C', 'G:7', 'G:maj7/5'),
#   ('C', 'G:9(*3)', 'N'),
#   ('C', 'G:maj6/5', 'N'),
#   ('C', 'G:maj7/5', 'N'),
#   ('C#:min7', 'F#', 'F#:sus4'),
#   ('C/5', 'C/9', 'G'),
#   ('C/5', 'D/b7', 'G'),
#   ('C/5', 'D:7', 'G:7'),
#   ('C/5', 'D:min', 'G:7'),
#   ('C/5', 'E', 'F'),
#   ('C/5', 'E', 'G'),
#   ('C/5', 'E:min/b7', 'G'),
#   ('C/5', 'Eb', 'F'),
#   ('C/5', 'F:min', 'G:7'),
#   ('C/9', 'D', 'G'),
#   ('C/9', 'Eb', 'G'),
#   ('C/9', 'F', 'G'),
#   ('C/9', 'G', 'N'),
#   ('C:7', 'E', 'F'),
#   ('C:7', 'Eb', 'F'),
#   ('C:7', 'F', 'G'),
#   ('D', 'D/3', 'D:7'),
#   ('D', 'D/5', 'D:7/2'),
#   ('D', 'D/5', 'E:7'),
#   ('D', 'D/5', 'F#:dim/b7'),
#   ('D', 'D/5', 'G/3'),
#   ('D', 'D/5', 'G:maj6/2'),
#   ('D', 'D/5', 'G:min(9)/b3'),
#   ('D', 'D/5', 'N'),
#   ('D', 'D:7', 'D:7/2'),
#   ('D', 'D:7', 'E:7'),
#   ('D', 'D:7', 'F#:dim/b7'),
#   ('D', 'D:7', 'G/3'),
#   ('D', 'D:7', 'G:maj6/2'),
#   ('D', 'D:7', 'N'),
#   ('D', 'D:7/2', 'E'),
#   ('D', 'D:7/2', 'G'),
#   ('D', 'D:7/2', 'G:maj6/3'),
#   ('D', 'D:maj6', 'G:maj6/3'),
#   ('D', 'D:min', 'G:min/5'),
#   ('D', 'E', 'F#:dim/b7'),
#   ('D', 'E', 'G/3'),
#   ('D', 'E', 'G:maj6/2'),
#   ('D', 'E:7', 'G'),
#   ('D', 'E:7', 'G:maj6/3'),
#   ('D', 'E:min/b7', 'G'),
#   ('D', 'F#', 'F#:sus4'),
#   ('D', 'F#:dim/b7', 'G'),
#   ('D', 'F#:dim/b7', 'G:maj6/3'),
#   ('D', 'G', 'G/3'),
#   ('D', 'G', 'G:7'),
#   ('D', 'G', 'G:maj6/2'),
#   ('D', 'G/3', 'G:maj6/3'),
#   ('D', 'G:maj6/2', 'G:maj6/3'),
#   ('D', 'G:maj6/3', 'N'),
#   ('D/5', 'G:maj6/2', 'G:maj6/5'),
#   ('D/b7', 'Eb', 'G'),
#   ('D/b7', 'F', 'G'),
#   ('D/b7', 'G', 'N'),
#   ('D:dim', 'Eb', 'F'),
#   ('D:dim', 'Eb', 'G'),
#   ('D:maj6', 'D:maj6/5', 'D:min7'),
#   ('D:maj6', 'D:maj6/5', 'N'),
#   ('D:maj6/5', 'G:maj6/2', 'G:maj6/5'),
#   ('D:min', 'Eb:dim', 'G:min/5'),
#   ('D:min', 'G', 'N'),
#   ('E', 'Eb', 'G'),
#   ('E', 'F', 'F#'),
#   ('E', 'F', 'F#:min7'),
#   ('E', 'F', 'F/9'),
#   ('E', 'F', 'G:min'),
#   ('E:7', 'G', 'N'),
#   ('E:min/b7', 'Eb', 'G'),
#   ('E:min/b7', 'F', 'G'),
#   ('E:min/b7', 'G', 'N'),
#   ('Eb', 'Eb/2', 'F'),
#   ('Eb', 'Eb/2', 'G'),
#   ('Eb', 'F', 'F#:min7'),
#   ('Eb', 'F', 'F/9'),
#   ('Eb', 'F', 'F:(1)'),
#   ('Eb', 'F', 'F:7/b7'),
#   ('Eb', 'F', 'G/5'),
#   ('Eb', 'F', 'G:7'),
#   ('Eb', 'F', 'G:min/b7'),
#   ('Eb', 'F', 'N'),
#   ('Eb', 'F:(1)', 'G'),
#   ('Eb', 'F:7/b7', 'G'),
#   ('Eb', 'G', 'G:min'),
#   ('Eb', 'G', 'G:min/b7'),
#   ('F', 'F#:min7', 'G'),
#   ('F', 'G', 'G:7'),
#   ('F', 'G', 'G:min'),
#   ('F#', 'F#:sus4', 'G:maj7'),
#   ('F#:dim', 'G', 'N'),
#   ('G', 'G:7', 'N'),
#   ('G', 'G:maj6/5', 'N')},
#  '111U': {('A', 'A/3', 'B'),
#   ('A', 'A/3', 'D:7'),
#   ('A', 'A/3', 'D:maj(11)'),
#   ('A', 'A/3', 'E'),
#   ('A', 'A/3', 'G'),
#   ('A', 'A/b7', 'B'),
#   ('A', 'A/b7', 'D'),
#   ('A', 'A/b7', 'D:7'),
#   ('A', 'A/b7', 'D:maj(11)'),
#   ('A', 'A/b7', 'E'),
#   ('A', 'A/b7', 'G'),
#   ('A', 'A:min', 'E'),
#   ('A', 'B', 'B/3'),
#   ('A', 'B', 'B/7'),
#   ('A', 'B', 'D:maj6'),
#   ('A', 'B', 'D:min'),
#   ('A', 'Bb', 'C'),
#   ('A', 'Bb', 'G/3'),
#   ('A', 'C', 'C/5'),
#   ('A', 'C', 'D#:dim7'),
#   ('A', 'C', 'F:7'),
#   ('A', 'C', 'F:maj6'),
#   ('A', 'C', 'G:7'),
#   ('A', 'C', 'N'),
#   ('A', 'D', 'D/b7'),
#   ('A', 'D', 'D:maj6'),
#   ('A', 'D', 'F#'),
#   ('A', 'D/3', 'G'),
#   ('A', 'D:7', 'D:maj6'),
#   ('A', 'D:7', 'D:min'),
#   ('A', 'D:7', 'G:7'),
#   ('A', 'D:maj(11)', 'D:maj6'),
#   ('A', 'D:maj(11)', 'D:min'),
#   ('A', 'D:maj6', 'E'),
#   ('A', 'D:maj6', 'G'),
#   ('A', 'D:min', 'E'),
#   ('A', 'D:min', 'G'),
#   ('A', 'D:min7/4', 'G'),
#   ('A', 'E', 'E/5'),
#   ('A', 'E', 'E:7'),
#   ('A', 'E', 'N'),
#   ('A', 'F/9', 'G'),
#   ('A', 'G', 'G/5'),
#   ('A:dim7/b3', 'Bb', 'Eb'),
#   ('A:dim7/b3', 'Eb', 'F'),
#   ('A:dim7/b3', 'Eb', 'G'),
#   ('A:min', 'B', 'C'),
#   ('A:min', 'B', 'E'),
#   ('A:min', 'B', 'G'),
#   ('A:min', 'B', 'N'),
#   ('A:min', 'Bb', 'C'),
#   ('A:min', 'Bb', 'N'),
#   ('A:min', 'C', 'D'),
#   ('A:min', 'C', 'D#:dim7'),
#   ('A:min', 'C', 'F:7'),
#   ('A:min', 'C', 'F:maj6'),
#   ('A:min', 'C', 'G:7'),
#   ('A:min', 'C/5', 'F'),
#   ('A:min', 'C/5', 'F#:dim'),
#   ('A:min', 'C/5', 'F:maj7'),
#   ('A:min', 'D', 'E'),
#   ('A:min', 'D/3', 'G'),
#   ('A:min', 'D:min7/4', 'G'),
#   ('A:min', 'E', 'F'),
#   ('A:min', 'F#:dim', 'G'),
#   ('A:min', 'F/9', 'G'),
#   ('A:min', 'F:maj7', 'G'),
#   ('A:min', 'G', 'G/5'),
#   ('A:min/5', 'Bb', 'F'),
#   ('A:min/5', 'E', 'F'),
#   ('A:min/5', 'Eb', 'F'),
#   ('A:min/5', 'F', 'G'),
#   ('Ab', 'Bb', 'F'),
#   ('Ab', 'E', 'F'),
#   ('Ab', 'Eb', 'F'),
#   ('Ab', 'F', 'G'),
#   ('B', 'B/3', 'C'),
#   ('B', 'B/3', 'F#:min7'),
#   ('B', 'B/3', 'N'),
#   ('B', 'B/7', 'C'),
#   ('B', 'B/7', 'E'),
#   ('B', 'B/7', 'F#:min7'),
#   ('B', 'B/7', 'N'),
#   ('B', 'Bb', 'F'),
#   ('B', 'Bb:(1)', 'N'),
#   ('B', 'C', 'C/7'),
#   ('B', 'C', 'C:7'),
#   ('B', 'C', 'D:min'),
#   ('B', 'C/5', 'G'),
#   ('B', 'D', 'G'),
#   ('B', 'D', 'N'),
#   ('B', 'D:maj6', 'N'),
#   ('B', 'E', 'E:7'),
#   ('B', 'E', 'E:min'),
#   ('B', 'E:min', 'F#:min7'),
#   ('B', 'E:min', 'N'),
#   ('B', 'Eb', 'F'),
#   ('B', 'Eb', 'G'),
#   ('B', 'F#', 'F#:sus4'),
#   ('B', 'F#:min7', 'G#:(1)'),
#   ('B', 'F:maj6', 'N'),
#   ('B:min7', 'D:maj6', 'D:maj6/5'),
#   ('Bb', 'Bb/b7', 'D/5'),
#   ('Bb', 'Bb/b7', 'Eb/3'),
#   ('Bb', 'Bb/b7', 'F/3'),
#   ('Bb', 'Bb/b7', 'F:min'),
#   ('Bb', 'Bb/b7', 'G:(1)'),
#   ('Bb', 'Bb/b7', 'G:min'),
#   ('Bb', 'C', 'C/7'),
#   ('Bb', 'C', 'C:7'),
#   ('Bb', 'C', 'D/5'),
#   ('Bb', 'C', 'D:min'),
#   ('Bb', 'C', 'E'),
#   ('Bb', 'C', 'Eb/3'),
#   ('Bb', 'C', 'F/3'),
#   ('Bb', 'C', 'F:min'),
#   ('Bb', 'C', 'G:(1)'),
#   ('Bb', 'C', 'G:min'),
#   ('Bb', 'D', 'G/3'),
#   ('Bb', 'D', 'N'),
#   ('Bb', 'D/5', 'Eb'),
#   ('Bb', 'D/5', 'F'),
#   ('Bb', 'D/5', 'G/3'),
#   ('Bb', 'D/5', 'N'),
#   ('Bb', 'D:maj6', 'N'),
#   ('Bb', 'E:7', 'F'),
#   ('Bb', 'Eb', 'Eb:dim'),
#   ('Bb', 'Eb', 'F/3'),
#   ('Bb', 'Eb', 'F:min'),
#   ('Bb', 'Eb/3', 'F'),
#   ('Bb', 'Eb/3', 'G/3'),
#   ('Bb', 'Eb/3', 'N'),
#   ('Bb', 'F', 'F/3'),
#   ('Bb', 'F', 'F:maj7'),
#   ('Bb', 'F', 'F:min'),
#   ('Bb', 'F', 'G:(1)'),
#   ('Bb', 'F/3', 'G/3'),
#   ('Bb', 'F/3', 'N'),
#   ('Bb', 'F:maj6', 'N'),
#   ('Bb', 'F:min', 'G/3'),
#   ('Bb', 'F:min', 'N'),
#   ('Bb', 'G/3', 'G:(1)'),
#   ('Bb', 'G/3', 'G:min'),
#   ('Bb', 'G/3', 'G:min(9)/b3'),
#   ('Bb', 'G:(1)', 'N'),
#   ('Bb', 'G:min', 'N'),
#   ('Bb/3', 'D:min', 'G:min/5'),
#   ('Bb:(1)', 'C', 'N'),
#   ('Bb:(1)', 'G', 'N'),
#   ('C', 'C/5', 'C/7'),
#   ('C', 'C/5', 'C:7'),
#   ('C', 'C/5', 'D:min'),
#   ('C', 'C/5', 'E'),
#   ('C', 'C/7', 'D'),
#   ('C', 'C/7', 'D#:dim7'),
#   ('C', 'C/7', 'F:7'),
#   ('C', 'C/7', 'F:maj6'),
#   ('C', 'C/7', 'G'),
#   ('C', 'C/7', 'G:7'),
#   ('C', 'C/7', 'N'),
#   ('C', 'C:7', 'D'),
#   ('C', 'C:7', 'D#:dim7'),
#   ('C', 'C:7', 'F:7'),
#   ('C', 'C:7', 'F:maj6'),
#   ('C', 'C:7', 'G'),
#   ('C', 'C:7', 'G:7'),
#   ('C', 'C:7', 'N'),
#   ('C', 'D', 'D/b7'),
#   ('C', 'D', 'F#'),
#   ('C', 'D#:dim7', 'D:min'),
#   ('C', 'D#:dim7', 'E'),
#   ('C', 'D/3', 'G'),
#   ('C', 'D:maj6', 'N'),
#   ('C', 'D:min', 'F:7'),
#   ('C', 'D:min', 'F:maj6'),
#   ('C', 'D:min', 'G'),
#   ('C', 'D:min7/4', 'G'),
#   ('C', 'E', 'F:7'),
#   ('C', 'E', 'F:maj6'),
#   ('C', 'E', 'G:7'),
#   ('C', 'Eb', 'F'),
#   ('C', 'Eb', 'G:7'),
#   ('C', 'F#:dim', 'F:7'),
#   ('C', 'F/9', 'G'),
#   ('C', 'G', 'G/5'),
#   ('C/5', 'D/3', 'G'),
#   ('C/5', 'D:min7/4', 'G'),
#   ('C/5', 'Eb', 'G:7'),
#   ('C/5', 'F', 'G:7'),
#   ('C/5', 'F/9', 'G'),
#   ('C/5', 'G', 'G/5'),
#   ('D', 'D/3', 'G'),
#   ('D', 'D/5', 'D/b7'),
#   ('D', 'D/5', 'D:min'),
#   ('D', 'D/5', 'F#'),
#   ('D', 'D/5', 'G:maj6/5'),
#   ('D', 'D/b7', 'D:7'),
#   ('D', 'D/b7', 'E'),
#   ('D', 'D/b7', 'G:maj6/3'),
#   ('D', 'D:7', 'D:min'),
#   ('D', 'D:7', 'F#'),
#   ('D', 'D:7', 'G:7'),
#   ('D', 'D:min', 'E'),
#   ('D', 'D:min', 'G'),
#   ('D', 'D:min', 'G:maj6/3'),
#   ('D', 'D:min7/4', 'G'),
#   ('D', 'E', 'E/5'),
#   ('D', 'E:min', 'G:maj6/3'),
#   ('D', 'F#', 'G'),
#   ('D', 'F#', 'G:maj6/3'),
#   ('D', 'F/9', 'G'),
#   ('D', 'G', 'G/5'),
#   ('D', 'G:maj6/2', 'G:maj6/5'),
#   ('D/3', 'Eb', 'G'),
#   ('D/3', 'F', 'G'),
#   ('D/3', 'G', 'N'),
#   ('D:maj6', 'D:maj6/5', 'G:maj6/3'),
#   ('D:maj6', 'D:maj6/5', 'G:maj6/5'),
#   ('D:maj6', 'G', 'N'),
#   ('D:min', 'D:min7', 'G:min/5'),
#   ('D:min', 'F/5', 'G:min/5'),
#   ('D:min', 'G:7', 'G:min/5'),
#   ('D:min', 'G:min/5', 'G:min/b7'),
#   ('D:min', 'G:min/5', 'N'),
#   ('D:min7/4', 'Eb', 'G'),
#   ('D:min7/4', 'F', 'G'),
#   ('D:min7/4', 'G', 'N'),
#   ('E', 'E/5', 'F'),
#   ('E', 'F', 'F:maj7'),
#   ('E', 'F#', 'F#:sus4'),
#   ('E:7', 'Eb', 'F'),
#   ('E:7', 'F', 'G'),
#   ('E:min', 'G:maj6/2', 'G:maj6/5'),
#   ('Eb', 'Eb/3', 'F'),
#   ('Eb', 'Eb/3', 'G'),
#   ('Eb', 'Eb:dim', 'F'),
#   ('Eb', 'Eb:dim', 'G'),
#   ('Eb', 'F', 'F:maj7'),
#   ('Eb', 'F', 'G:(1)'),
#   ('Eb', 'F/9', 'G'),
#   ('Eb', 'G', 'G:(1)'),
#   ('F', 'F:maj7', 'G'),
#   ('F', 'G', 'G/5'),
#   ('F/9', 'G', 'N'),
#   ('F:maj6', 'G', 'N'),
#   ('G', 'G/5', 'N'),
#   ('G:maj6', 'G:maj6/2', 'G:maj6/5'),
#   ('G:maj6/2', 'G:maj6/5', 'N')},
#  '120C': {('A', 'A/3', 'D'),
#   ('A', 'B', 'E:min'),
#   ('B', 'B/3', 'E'),
#   ('B', 'C', 'E:min'),
#   ('B', 'E', 'E/5'),
#   ('B', 'E', 'G'),
#   ('B', 'F', 'F#:min7'),
#   ('B', 'F', 'N'),
#   ('Bb', 'Bb:(1)', 'N'),
#   ('Bb', 'Eb', 'G:min'),
#   ('Bb', 'F', 'G:min'),
#   ('C', 'C/5', 'F'),
#   ('C', 'D:min', 'G:7'),
#   ('C', 'D:min', 'N'),
#   ('C', 'E', 'F'),
#   ('C', 'E', 'G'),
#   ('C', 'E', 'N'),
#   ('C', 'F', 'N'),
#   ('D', 'D/b7', 'G'),
#   ('D', 'E', 'E:7'),
#   ('D', 'E', 'F#'),
#   ('D', 'E', 'N'),
#   ('E', 'F', 'N'),
#   ('Eb', 'G', 'G/5'),
#   ('F', 'F/9', 'G')},
#  '120D': {('A', 'C', 'E'),
#   ('A', 'D', 'G/3'),
#   ('A:min', 'E', 'G'),
#   ('A:min', 'E:min/b7', 'G'),
#   ('B', 'C', 'F'),
#   ('B', 'E', 'F#'),
#   ('C', 'D', 'G/3'),
#   ('C', 'E:min/b7', 'G'),
#   ('E', 'G', 'N'),
#   ('Eb', 'F', 'G:min'),
#   ('Eb', 'G', 'G:7')},
#  '120U': {('A', 'D', 'D:min'),
#   ('A:min', 'C', 'N'),
#   ('B', 'F', 'G'),
#   ('Bb', 'Eb', 'Eb/3'),
#   ('Bb', 'Eb', 'G:(1)'),
#   ('C', 'D', 'D:min'),
#   ('E', 'E:7', 'F')},
#  '201': {('A', 'A:min', 'G'),
#   ('A', 'B', 'D'),
#   ('A', 'B', 'D:7'),
#   ('A', 'B', 'D:maj(11)'),
#   ('A', 'B', 'F#:min7'),
#   ('A', 'B', 'N'),
#   ('A', 'C/5', 'G'),
#   ('A', 'D', 'D:maj(11)'),
#   ('A', 'D', 'G:maj6/3'),
#   ('A', 'D:7', 'D:maj(11)'),
#   ('A', 'D:7', 'E'),
#   ('A', 'D:7', 'G'),
#   ('A', 'D:maj(11)', 'E'),
#   ('A', 'D:maj(11)', 'G'),
#   ('A', 'E', 'F'),
#   ('A', 'Eb', 'G'),
#   ('A', 'F', 'G'),
#   ('A', 'G', 'N'),
#   ('A:min', 'C/5', 'G:7'),
#   ('A:min', 'D', 'G'),
#   ('A:min', 'Eb', 'G'),
#   ('A:min', 'F', 'G'),
#   ('B', 'Bb', 'C'),
#   ('B', 'Bb', 'N'),
#   ('B', 'C', 'C/5'),
#   ('B', 'C', 'D'),
#   ('B', 'C', 'D#:dim7'),
#   ('B', 'C', 'F#:min7'),
#   ('B', 'C', 'F:7'),
#   ('B', 'C', 'F:maj6'),
#   ('B', 'C', 'G:7'),
#   ('B', 'D', 'E'),
#   ('B', 'E', 'F#:min7'),
#   ('B', 'F#:min7', 'N'),
#   ('Bb', 'Bb/b7', 'C'),
#   ('Bb', 'Bb/b7', 'Eb'),
#   ('Bb', 'Bb/b7', 'F'),
#   ('Bb', 'Bb/b7', 'G/3'),
#   ('Bb', 'Bb/b7', 'N'),
#   ('Bb', 'C', 'C/5'),
#   ('Bb', 'C', 'D'),
#   ('Bb', 'C', 'D#:dim7'),
#   ('Bb', 'C', 'Eb'),
#   ('Bb', 'C', 'F:7'),
#   ('Bb', 'C', 'F:maj6'),
#   ('Bb', 'C', 'G'),
#   ('Bb', 'C', 'G:7'),
#   ('Bb', 'E', 'F'),
#   ('Bb', 'Eb', 'G'),
#   ('Bb', 'Eb', 'G/3'),
#   ('Bb', 'Eb', 'N'),
#   ('Bb', 'F', 'G'),
#   ('Bb', 'F', 'G/3'),
#   ('Bb', 'G', 'N'),
#   ('Bb', 'G/3', 'N'),
#   ('C', 'C/5', 'D'),
#   ('C', 'C/5', 'D#:dim7'),
#   ('C', 'C/5', 'F:7'),
#   ('C', 'C/5', 'F:maj6'),
#   ('C', 'C/5', 'N'),
#   ('C', 'D', 'D#:dim7'),
#   ('C', 'D', 'D/5'),
#   ('C', 'D', 'D:7'),
#   ('C', 'D', 'F:7'),
#   ('C', 'D', 'F:maj6'),
#   ('C', 'D', 'G:7'),
#   ('C', 'D', 'G:maj6/3'),
#   ('C', 'D#:dim7', 'F:7'),
#   ('C', 'D#:dim7', 'F:maj6'),
#   ('C', 'D#:dim7', 'G'),
#   ('C', 'D#:dim7', 'G:7'),
#   ('C', 'D#:dim7', 'N'),
#   ('C', 'Eb', 'G'),
#   ('C', 'F:7', 'F:maj6'),
#   ('C', 'F:7', 'G'),
#   ('C', 'F:7', 'G:7'),
#   ('C', 'F:7', 'N'),
#   ('C', 'F:maj6', 'G'),
#   ('C', 'F:maj6', 'G:7'),
#   ('C', 'G:7', 'N'),
#   ('C/5', 'D', 'G'),
#   ('C/5', 'Eb', 'G'),
#   ('C/5', 'G', 'N'),
#   ('D', 'D/5', 'D:7'),
#   ('D', 'D/5', 'E'),
#   ('D', 'D/5', 'G'),
#   ('D', 'D/5', 'G:maj6/3'),
#   ('D', 'D:7', 'E'),
#   ('D', 'D:7', 'G'),
#   ('D', 'D:7', 'G:maj6/3'),
#   ('D', 'E', 'F'),
#   ('D', 'E', 'G:maj6/3'),
#   ('D', 'Eb', 'G'),
#   ('D', 'F', 'G'),
#   ('D', 'G', 'G:maj6/3'),
#   ('E', 'Eb', 'F'),
#   ('Eb', 'G', 'N')},
#  '210': {('A', 'B', 'C'),
#   ('A', 'B', 'G'),
#   ('A', 'C', 'D'),
#   ('A', 'C', 'G'),
#   ('A', 'D', 'D/5'),
#   ('A', 'E', 'G'),
#   ('A:min', 'C', 'C/5'),
#   ('A:min', 'C', 'G'),
#   ('A:min', 'G', 'N'),
#   ('B', 'C', 'E'),
#   ('B', 'C', 'G'),
#   ('B', 'E', 'F'),
#   ('B', 'E', 'N'),
#   ('B', 'G', 'N'),
#   ('Bb', 'C', 'F'),
#   ('Bb', 'C', 'G/3'),
#   ('Bb', 'F', 'N'),
#   ('C', 'D', 'E'),
#   ('C', 'D', 'N'),
#   ('C', 'F', 'G'),
#   ('C', 'F:maj6', 'N'),
#   ('C', 'G', 'G:7'),
#   ('C/5', 'F', 'G'),
#   ('C/5', 'G', 'G:7'),
#   ('D', 'E', 'G'),
#   ('D', 'G', 'N'),
#   ('E', 'F', 'G'),
#   ('F', 'G', 'N')},
#  '300': {('A', 'B', 'E'),
#   ('A', 'D', 'D:7'),
#   ('A', 'D', 'E'),
#   ('A', 'D', 'G'),
#   ('A:min', 'C/5', 'G'),
#   ('B', 'C', 'N'),
#   ('Bb', 'C', 'N'),
#   ('Bb', 'Eb', 'F'),
#   ('C', 'C/5', 'G'),
#   ('C', 'C/5', 'G:7'),
#   ('C', 'D', 'G'),
#   ('C', 'G', 'N'),
#   ('Eb', 'F', 'G')}}

# %%
from collections import Counter
counter=Counter(new)
print(counter)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
