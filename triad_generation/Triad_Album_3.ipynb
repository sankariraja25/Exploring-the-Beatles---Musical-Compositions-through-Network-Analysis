# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
album01 = pd.read_csv('album_03_edges.csv')
G = nx.from_pandas_edgelist(album01, source="Source", target="Target", create_using=nx.DiGraph())
nx.draw(G, with_labels=True)

# %% [markdown]
# ## Visuals

# %%
nx.draw(G,node_size=300,font_size=8,  with_labels=True)

# %%
plt.figure(3,figsize=(12,12)) 
nx.draw(G, node_size=400,font_size=12,  with_labels=True)

# %% [markdown]
# ## Triads

# %%
''' Conesus Motifs are: 
        021C
        111D
        201
        030C
        120C
        210
                    '''
# Out:
# ' Conesus Motifs are: \n        021C\n        111D\n        201\n        030C\n        120C\n        210\n                    '

# %%
# Triad Consensus
nx.triadic_census(G)
# Out:
# {'003': 15176,
#  '012': 3235,
#  '102': 1395,
#  '021D': 90,
#  '021U': 76,
#  '021C': 166,
#  '111D': 213,
#  '111U': 239,
#  '030T': 9,
#  '030C': 10,
#  '201': 92,
#  '120D': 8,
#  '120U': 7,
#  '120C': 36,
#  '210': 47,
#  '300': 26}

# %%
import networkx as nx
import itertools

def _tricode(G, v, u, w):
    """Returns the integer code of the given triad.

    This is some fancy magic that comes from Batagelj and Mrvar's paper. It
    treats each edge joining a pair of `v`, `u`, and `w` as a bit in
    the binary representation of an integer.

    """
    combos = ((v, u, 1), (u, v, 2), (v, w, 4), (w, v, 8), (u, w, 16),
              (w, u, 32))
    return sum(x for u, v, x in combos if v in G[u])


# G = nx.DiGraph()
# G.add_nodes_from([1, 2, 3, 4, 5])
# G.add_edges_from([(1, 2), (2, 3), (2, 4), (4, 5)])

#: The integer codes representing each type of triad.
#: Triads that are the same up to symmetry have the same code.
TRICODES = (1, 2, 2, 3, 2, 4, 6, 8, 2, 6, 5, 7, 3, 8, 7, 11, 2, 6, 4, 8, 5, 9,
            9, 13, 6, 10, 9, 14, 7, 14, 12, 15, 2, 5, 6, 7, 6, 9, 10, 14, 4, 9,
            9, 12, 8, 13, 14, 15, 3, 7, 8, 11, 7, 12, 14, 15, 8, 14, 13, 15,
            11, 15, 15, 16)

#: The names of each type of triad. The order of the elements is
#: important: it corresponds to the tricodes given in :data:`TRICODES`.
TRIAD_NAMES = ('003', '012', '102', '021D', '021U', '021C', '111D', '111U',
               '030T', '030C', '201', '120D', '120U', '120C', '210', '300')

#: A dictionary mapping triad code to triad name.
TRICODE_TO_NAME = {i: TRIAD_NAMES[code - 1] for i, code in enumerate(TRICODES)}

triad_nodes = {name: set([]) for name in TRIAD_NAMES}
m = {v: i for i, v in enumerate(G)}
for v in G:
    vnbrs = set(G.pred[v]) | set(G.succ[v])
    for u in vnbrs:
        if m[u] > m[v]:
            unbrs = set(G.pred[u]) | set(G.succ[u])
            neighbors = (vnbrs | unbrs) - {u, v}
            not_neighbors = set(G.nodes()) - neighbors - {u, v}
            # Find dyadic triads
            for w in not_neighbors:
                if v in G[u] and u in G[v]:
                    triad_nodes['102'].add(tuple(sorted([u, v, w])))
                else:
                    triad_nodes['012'].add(tuple(sorted([u, v, w])))
            for w in neighbors:
                if m[u] < m[w] or (m[v] < m[w] < m[u] and
                                   v not in G.pred[w] and
                                   v not in G.succ[w]):
                    code = _tricode(G, v, u, w)
                    triad_nodes[TRICODE_TO_NAME[code]].add(
                        tuple(sorted([u, v, w])))
# find null triads
all_tuples = set()
for s in triad_nodes.values():
    all_tuples = all_tuples.union(s)
    
new = triad_nodes['210'] = set(itertools.combinations(G.nodes(), 3)).difference(all_tuples)

triad_nodes
# Out:
# {'003': set(),
#  '012': {('A:9(11)', 'C', 'D:7'),
#   ('C', 'E:maj6', 'F:maj9(*7)'),
#   ('A', 'A:7', 'Bb'),
#   ('C', 'F:maj9(*7)', 'G:sus4/5'),
#   ('B:aug', 'E:min', 'F#:min'),
#   ('D:min', 'E:min', 'E:min/b3'),
#   ('Bb:min', 'Db', 'E:min7'),
#   ('C:7', 'D/5', 'E:min'),
#   ('A', 'Db', 'F#:(1,4,b7)'),
#   ('A', 'F#:(1,4,b7)', 'F:maj9(*7)'),
#   ('A', 'Db', 'G:min'),
#   ('C', 'D/5', 'D:7'),
#   ('F#', 'F#:min/5', 'G'),
#   ('A', 'A:7/b7', 'A:sus4'),
#   ('A:7/5', 'A:7/b7', 'Bb'),
#   ('F#:min', 'G', 'G#:min'),
#   ('A:7/5', 'G', 'G:min'),
#   ('A:sus4', 'F:7', 'G'),
#   ('A:7/5', 'C:9', 'D'),
#   ('A:7', 'E:min7', 'F:dim'),
#   ('Bb:min', 'C:9', 'Db'),
#   ('B:aug', 'C:7', 'E'),
#   ('F#:min', 'G#:min', 'G/5'),
#   ('Bb:7', 'C', 'C:9'),
#   ('A:sus4', 'B:min', 'Bb:7'),
#   ('C:9', 'F', 'F#:min'),
#   ('B', 'E:7', 'G#'),
#   ('D:9', 'E:min', 'F#:min'),
#   ('C', 'C:9', 'D/5'),
#   ('A:7/5', 'E', 'F'),
#   ('Bb', 'D:min', 'E'),
#   ('Bb:min', 'D/5', 'G:min/b3'),
#   ('A:7/b7', 'B:min/5', 'C:9'),
#   ('C', 'C#:min', 'G:7'),
#   ('Bb:7', 'E', 'G:min'),
#   ('B:aug', 'C', 'D:7'),
#   ('A:sus4', 'D:min', 'G'),
#   ('D', 'F#:min/5', 'G:sus4/5'),
#   ('D', 'D:min', 'E:min'),
#   ('A:min', 'Bb', 'D:7'),
#   ('A:7/b7', 'G', 'G:sus4(b7)'),
#   ('E:7', 'E:min', 'E:min/b3'),
#   ('F#:min', 'F:7', 'G'),
#   ('A:sus4', 'C', 'D'),
#   ('A:min', 'B:min', 'G#'),
#   ('C:7', 'D:9', 'E:min'),
#   ('Bb', 'F:maj9(*7)', 'N'),
#   ('A:7/b7', 'B:min', 'E'),
#   ('Eb:min', 'G:sus4/5', 'N'),
#   ('B:min', 'Db', 'F#:min/5'),
#   ('A:min', 'E', 'E:7'),
#   ('A', 'A:7/b7', 'B:7'),
#   ('A/3', 'A:7/5', 'B:min/5'),
#   ('A:9(11)', 'A:sus4', 'E:min7'),
#   ('C', 'E:min/b3', 'F:maj9(*7)'),
#   ('F#', 'F#:(1,4,b7)', 'G'),
#   ('B', 'E:min', 'E:min7'),
#   ('A', 'B:aug', 'C'),
#   ('C#:min', 'E:min7', 'G#'),
#   ('Bb:min', 'Db', 'G#'),
#   ('A/3', 'B', 'G:7'),
#   ('E:maj6', 'E:min', 'F#:min'),
#   ('A:min', 'D/5', 'E'),
#   ('B:min', 'E:min/b3', 'G:min/b3'),
#   ('G:min/b3', 'G:sus4(b7)', 'N'),
#   ('B:7', 'D', 'Db'),
#   ('A/3', 'D', 'G/5'),
#   ('B', 'B:min/5', 'E:7'),
#   ('A:sus4', 'E', 'G#:min'),
#   ('A:min', 'E', 'G:sus4/5'),
#   ('Bb:7', 'F#', 'G'),
#   ('A:min', 'D:7', 'F'),
#   ('A', 'A:7', 'F#:min/5'),
#   ('E:7', 'E:min7', 'F:dim'),
#   ('B:min', 'D:9', 'F#:min'),
#   ('B:min/5', 'D/5', 'G:min/b3'),
#   ('D:9', 'E:min', 'E:min/b3'),
#   ('E:min7', 'F:7', 'G'),
#   ('A:7/b7', 'Bb', 'C'),
#   ('A:7/5', 'B:min/5', 'C:9'),
#   ('C', 'C#:min', 'C:9'),
#   ('C#:min', 'Db', 'N'),
#   ('B:min', 'C#:min', 'F#:(1,4,b7)'),
#   ('C:9', 'Db', 'F'),
#   ('A', 'A/3', 'F#:(1,4,b7)'),
#   ('A:7/5', 'A:7/b7', 'F#:min/5'),
#   ('B', 'E:7', 'G:min'),
#   ('B:min', 'C#:min', 'G:min'),
#   ('A', 'B:aug', 'F:maj9(*7)'),
#   ('C', 'D:7', 'G/5'),
#   ('B:aug', 'E', 'N'),
#   ('F#:(1,4,b7)', 'F#:min/5', 'N'),
#   ('D', 'G:7', 'G:sus4/5'),
#   ('A:7/b7', 'C#:min', 'N'),
#   ('D/5', 'D:7', 'G:min/b3'),
#   ('A:7/5', 'G', 'G:sus4(b7)'),
#   ('D', 'E:min7', 'G:min/b3'),
#   ('G/5', 'G:sus4(b7)', 'N'),
#   ('C', 'F#:min', 'G:7'),
#   ('B', 'B:min', 'G:min/b3'),
#   ('A', 'C:7', 'E:7'),
#   ('F#', 'F#:min', 'G#'),
#   ('E', 'G#:min', 'G/5'),
#   ('B:7', 'E:min', 'G#'),
#   ('C#:min', 'F#', 'G#'),
#   ('A:min', 'B:min', 'G:min'),
#   ('F', 'F#:(1,4,b7)', 'N'),
#   ('C:7', 'Db', 'N'),
#   ('B:aug', 'B:min', 'Bb'),
#   ('A', 'E:7', 'F:dim'),
#   ('C:9', 'F', 'N'),
#   ('Bb:7', 'C:9', 'F'),
#   ('B:min', 'C#:min', 'C:7'),
#   ('A', 'D/5', 'F#:min'),
#   ('G#:min', 'G:sus4(b7)', 'N'),
#   ('A', 'Db', 'E:7'),
#   ('Bb', 'Bb:7', 'E:min7'),
#   ('A', 'F#:(1,4,b7)', 'G:sus4/5'),
#   ('A', 'Bb:min', 'Db'),
#   ('Bb', 'D:min', 'G:7'),
#   ('D:9', 'E:min7', 'F:dim'),
#   ('C#:min', 'C:7', 'E:min'),
#   ('C#:min', 'E', 'G:7'),
#   ('A:9(11)', 'G', 'G:7'),
#   ('D', 'E:min7', 'F#:(1,4,b7)'),
#   ('Bb:min', 'Db', 'G:min'),
#   ('A:min', 'C:7', 'D:min'),
#   ('A:7/5', 'A:7/b7', 'F'),
#   ('E:min/b3', 'E:min7', 'F:dim'),
#   ('A:min', 'B:min', 'C:7'),
#   ('E', 'F', 'F:dim'),
#   ('A', 'E:7', 'G#:min'),
#   ('A', 'B:aug', 'F:dim'),
#   ('Bb', 'D', 'E:min7'),
#   ('A', 'B:aug', 'D:min'),
#   ('B:7', 'Bb', 'D:min'),
#   ('A:sus4', 'B:7', 'E:min'),
#   ('D:7', 'Eb:min', 'N'),
#   ('A:7/5', 'Bb', 'C'),
#   ('B:min', 'G:min', 'G:min/b3'),
#   ('Bb', 'C', 'F:dim'),
#   ('B:7', 'E:min', 'G:min/b3'),
#   ('Db', 'F#:min', 'G#'),
#   ('A:sus4', 'Bb:7', 'E:min'),
#   ('D', 'E:min7', 'F:maj9(*7)'),
#   ('E:min', 'E:min/b3', 'F:7'),
#   ('A/3', 'D', 'D:9'),
#   ('B', 'Eb:min', 'N'),
#   ('A', 'A:7/b7', 'F:7'),
#   ('A:7', 'G', 'G:7'),
#   ('A:7/b7', 'B:min/5', 'E:min7'),
#   ('B', 'B:7', 'E:7'),
#   ('E:maj6', 'E:min7', 'F:dim'),
#   ('B:min', 'F#:min', 'G:min'),
#   ('A', 'Bb:min', 'G'),
#   ('E:min', 'E:min/b3', 'F'),
#   ('D/5', 'E:min', 'F#:min'),
#   ('Bb:7', 'C#:min', 'N'),
#   ('A:7/b7', 'D', 'E:min/b3'),
#   ('A', 'B:aug', 'G#:min'),
#   ('A', 'A:7/b7', 'F'),
#   ('B:min', 'D:9', 'N'),
#   ('C', 'E:7', 'F:maj9(*7)'),
#   ('B:7', 'E:min', 'F#:(1,4,b7)'),
#   ('A', 'D:9', 'F#:min/5'),
#   ('C', 'D:7', 'D:9'),
#   ('C#:min', 'G#', 'G:min/b3'),
#   ('Eb:min', 'F:dim', 'N'),
#   ('B:7', 'C', 'F:7'),
#   ('A/3', 'D', 'G:sus4(b7)'),
#   ('B:7', 'E:min', 'G:min'),
#   ('Bb', 'C', 'G#:min'),
#   ('A', 'C', 'D:9'),
#   ('A:9(11)', 'A:sus4', 'G/5'),
#   ('A:7/5', 'A:7/b7', 'D:7'),
#   ('F#:(1,4,b7)', 'G/5', 'N'),
#   ('C#:min', 'D', 'E:min7'),
#   ('B', 'D/5', 'G:7'),
#   ('A:min', 'B:min', 'D:9'),
#   ('E:min7', 'F:dim', 'G:min/b3'),
#   ('B', 'E:min', 'G/5'),
#   ('B:7', 'E', 'G:min'),
#   ('A:sus4', 'F#:min', 'N'),
#   ('B:min', 'E:7', 'G:min/b3'),
#   ('B', 'E:7', 'G:sus4(b7)'),
#   ('B', 'F:maj9(*7)', 'G#:min'),
#   ('C:7', 'D:7', 'E'),
#   ('B:min', 'Bb:7', 'F#:min'),
#   ('A:min', 'Bb:min', 'Db'),
#   ('Bb:7', 'D', 'G:7'),
#   ('D', 'D/5', 'G:min/b3'),
#   ('C', 'D:7', 'G:sus4(b7)'),
#   ('B:aug', 'B:min', 'F#:min/5'),
#   ('A/3', 'C', 'C:9'),
#   ('A', 'A:9(11)', 'E:min7'),
#   ('A', 'D:9', 'F:7'),
#   ('A/3', 'A:7/5', 'D/5'),
#   ('C#:min', 'G#', 'G:min'),
#   ('A', 'F#', 'F#:(1,4,b7)'),
#   ('C:7', 'D', 'E:min7'),
#   ('A', 'F#', 'G:min'),
#   ('A:min', 'B:min', 'G:sus4(b7)'),
#   ('B:min', 'Eb:min', 'G:min/b3'),
#   ('A:9(11)', 'A:min', 'E'),
#   ('B:min', 'C#:min', 'E:7'),
#   ('E', 'G#:min', 'G:sus4(b7)'),
#   ('B:7', 'C#:min', 'G#'),
#   ('A:7', 'A:min', 'Bb'),
#   ('E', 'F:7', 'G#:min'),
#   ('A', 'D:9', 'F'),
#   ('A:9(11)', 'Eb:min', 'N'),
#   ('B:min', 'C#:min', 'Eb:min'),
#   ('B', 'E:7', 'Eb:min'),
#   ('A/3', 'E', 'G:min'),
#   ('A:9(11)', 'B:aug', 'E'),
#   ('D', 'E:min/b3', 'F:7'),
#   ('A', 'C#:min', 'G:min/b3'),
#   ('A:min', 'B', 'E:7'),
#   ('B', 'Bb', 'F#:min/5'),
#   ('B:aug', 'Bb:min', 'C#:min'),
#   ('A:7', 'F:maj9(*7)', 'N'),
#   ('A:7/5', 'B:min/5', 'E:min7'),
#   ('A:9(11)', 'B', 'E:7'),
#   ('A', 'A:7/b7', 'D:7'),
#   ('A/3', 'B:aug', 'C#:min'),
#   ('C', 'D:7', 'Eb:min'),
#   ('E:7', 'G', 'G:min'),
#   ('Bb:7', 'G', 'G:7'),
#   ('Bb:min', 'Db', 'G:sus4(b7)'),
#   ('A:7', 'Bb:min', 'Db'),
#   ('B:min/5', 'C:7', 'D:7'),
#   ('A:min', 'B:min', 'E:7'),
#   ('B', 'D:9', 'G:7'),
#   ('D', 'Db', 'G#'),
#   ('A:sus4', 'Bb:7', 'C#:min'),
#   ('A:7/b7', 'E:min', 'F#:min'),
#   ('Bb', 'C:9', 'D:min'),
#   ('A:min', 'B:min', 'Eb:min'),
#   ('E:min7', 'F:dim', 'F:maj9(*7)'),
#   ('D:9', 'Eb:min', 'G'),
#   ('B:aug', 'D:9', 'E'),
#   ('C', 'F#:min/5', 'G:7'),
#   ('B:min', 'C#:min', 'G:sus4/5'),
#   ('A:min', 'D:min', 'Db'),
#   ('C:9', 'G:sus4(b7)', 'N'),
#   ('A/3', 'D', 'F#'),
#   ('A:9(11)', 'D', 'D:min'),
#   ('Bb', 'Bb:7', 'G/5'),
#   ('Bb:min', 'F:maj9(*7)', 'N'),
#   ('B:min/5', 'Bb:min', 'Eb:min'),
#   ('F:maj9(*7)', 'G', 'G:7'),
#   ('A:min', 'D:min', 'F#:min'),
#   ('B', 'B:min', 'E:7'),
#   ('Bb:min', 'Db', 'E:7'),
#   ('B', 'E:7', 'F#'),
#   ('A:7', 'B', 'E:7'),
#   ('A:min', 'Bb', 'Db'),
#   ('C', 'D:7', 'F#'),
#   ('B:min', 'F#:min', 'G:sus4(b7)'),
#   ('A:min', 'Bb', 'F#:min'),
#   ('A/3', 'D:9', 'G'),
#   ('A:9(11)', 'A:sus4', 'D:9'),
#   ('B:aug', 'F', 'F#'),
#   ('E', 'E:min', 'F'),
#   ('A:7/b7', 'C', 'D:7'),
#   ('A:9(11)', 'D', 'G#:min'),
#   ('B:min', 'B:min/5', 'F#:min'),
#   ('D/5', 'E:min7', 'F:dim'),
#   ('A:min', 'B:min', 'F#'),
#   ('A', 'C#:min', 'F:maj9(*7)'),
#   ('D', 'Db', 'G:min/b3'),
#   ('A:sus4', 'B:min', 'Bb'),
#   ('A/3', 'Bb', 'F'),
#   ('C#:min', 'E:7', 'G#'),
#   ('Bb', 'Bb:7', 'C:7'),
#   ('D', 'E:min7', 'G:sus4/5'),
#   ('C:9', 'D', 'E:min'),
#   ('A:min', 'B:min', 'B:min/5'),
#   ('A:9(11)', 'B:min', 'C#:min'),
#   ('D', 'E:maj6', 'E:min7'),
#   ('A', 'D/5', 'E:min7'),
#   ('D', 'F:dim', 'G:7'),
#   ('A', 'A:sus4', 'B:aug'),
#   ('A:9(11)', 'A:sus4', 'G:sus4(b7)'),
#   ('B:min', 'Db', 'E'),
#   ('B:min', 'Bb:7', 'N'),
#   ('C', 'C#:min', 'G#'),
#   ('A:7/b7', 'B:min/5', 'G/5'),
#   ('F#:(1,4,b7)', 'F#:min', 'F:dim'),
#   ('B', 'E:min', 'G:sus4(b7)'),
#   ('A/3', 'D', 'E:maj6'),
#   ('Bb:min', 'Db', 'F#'),
#   ('E:min7', 'Eb:min', 'F:dim'),
#   ('E:7', 'F:maj9(*7)', 'N'),
#   ('A:7/5', 'E:min', 'F#:min'),
#   ('Db', 'E', 'F'),
#   ('Bb:7', 'Bb:min', 'Db'),
#   ('A:7/b7', 'B:aug', 'B:min/5'),
#   ('B:aug', 'E', 'G/5'),
#   ('D', 'Db', 'F#:(1,4,b7)'),
#   ('B:min', 'F#:min/5', 'G:min'),
#   ('B', 'C:7', 'D:7'),
#   ('B:7', 'E:min', 'Eb:min'),
#   ('B:min/5', 'F:maj9(*7)', 'N'),
#   ('A', 'E:maj6', 'E:min7'),
#   ('C', 'D:7', 'E:maj6'),
#   ('E:min7', 'F:dim', 'G#:min'),
#   ('A:min', 'D:min', 'E:min/b3'),
#   ('B', 'Bb:min', 'E:7'),
#   ('A', 'F#:min', 'F:7'),
#   ('Bb', 'D:min', 'E:min7'),
#   ('A:7/b7', 'B:min/5', 'C:7'),
#   ('D:9', 'F#:min', 'G#:min'),
#   ('B', 'E:min', 'Eb:min'),
#   ('D:7', 'F', 'F#'),
#   ('B:min', 'F', 'F#:min'),
#   ('A', 'C#:min', 'F:dim'),
#   ('C', 'G#:min', 'G:7'),
#   ('A:min', 'B:min', 'E:maj6'),
#   ('B:min', 'C:9', 'F'),
#   ('A', 'Bb:7', 'F#:(1,4,b7)'),
#   ('B:min', 'F#:min/5', 'F:maj9(*7)'),
#   ('A', 'Bb:7', 'G:min'),
#   ('B:7', 'E:min', 'G:sus4/5'),
#   ('Bb', 'Bb:7', 'D:9'),
#   ('A:min', 'Bb', 'E:min/b3'),
#   ('A:7/5', 'C', 'D:7'),
#   ('A:min', 'Bb', 'F#:(1,4,b7)'),
#   ('C:7', 'E:min', 'E:min7'),
#   ('D/5', 'F:maj9(*7)', 'G:min/b3'),
#   ('A:min', 'D', 'F'),
#   ('Bb:min', 'Db', 'E:maj6'),
#   ('A:7', 'E:maj6', 'N'),
#   ('A:7', 'A:min', 'F'),
#   ('D/5', 'G#:min', 'G:min/b3'),
#   ('A', 'A:7/5', 'F#:min'),
#   ('Bb:min', 'D', 'E:min7'),
#   ('B:min/5', 'Bb', 'Bb:7'),
#   ('A:7/5', 'B:min/5', 'G/5'),
#   ('A', 'G', 'G:min/b3'),
#   ('C#:min', 'G#', 'G:sus4/5'),
#   ('B:aug', 'Bb:7', 'E'),
#   ('Bb', 'Bb:7', 'G:sus4(b7)'),
#   ('A:9(11)', 'A:sus4', 'F#'),
#   ('D', 'D:9', 'E:min'),
#   ('B', 'E:min', 'F#'),
#   ('A:9(11)', 'A:sus4', 'B:min/5'),
#   ('A/3', 'D/5', 'E'),
#   ('E:min7', 'F:dim', 'G:sus4/5'),
#   ('E:maj6', 'F#:min', 'G#:min'),
#   ('A:7/5', 'B:aug', 'B:min/5'),
#   ('A:7', 'F#:min', 'G#'),
#   ('C', 'F#:min', 'G#'),
#   ('B:min', 'B:min/5', 'N'),
#   ('Bb', 'Eb:min', 'N'),
#   ('Bb', 'F', 'G/5'),
#   ('Bb:7', 'E:min', 'E:min/b3'),
#   ('A:7/b7', 'B:min/5', 'D:9'),
#   ('B:min', 'F#:min/5', 'F:dim'),
#   ('D:9', 'G', 'G#:min'),
#   ('B:aug', 'C#:min', 'G:7'),
#   ('C#:min', 'E:min', 'G#'),
#   ('Bb', 'Bb:7', 'Eb:min'),
#   ('B', 'G#:min', 'N'),
#   ('A:7/5', 'B:min/5', 'C:7'),
#   ('C', 'C#:min', 'F:maj9(*7)'),
#   ('Bb', 'D:min', 'G#'),
#   ('B:aug', 'F:7', 'G'),
#   ('A', 'A:7/5', 'G'),
#   ('A:9(11)', 'F', 'F#'),
#   ('A:min', 'D', 'D:7'),
#   ('A:7/b7', 'B:min/5', 'G:sus4(b7)'),
#   ('Bb', 'Bb:min', 'C'),
#   ('A', 'C#:min', 'G:sus4/5'),
#   ('A:9(11)', 'C#:min', 'E'),
#   ('E', 'G:7', 'G:min'),
#   ('A:7/5', 'E:min7', 'F:dim'),
#   ('E:min', 'F#', 'F#:min'),
#   ('A:min', 'C#:min', 'D:min'),
#   ('C:7', 'E:min', 'G#'),
#   ('C#:min', 'D:min', 'E'),
#   ('F#:min', 'G:min', 'N'),
#   ('B:7', 'B:min', 'F#:min'),
#   ('A:9(11)', 'A:sus4', 'E:maj6'),
#   ('C#:min', 'F:dim', 'N'),
#   ('B:min/5', 'D', 'E:min7'),
#   ('C:9', 'D', 'F#:min/5'),
#   ('B', 'C:9', 'E:7'),
#   ('Bb:7', 'E:min7', 'F:dim'),
#   ('D:7', 'G:sus4(b7)', 'N'),
#   ('C', 'C:9', 'E'),
#   ('B:min', 'C#:min', 'D/5'),
#   ('A', 'A:sus4', 'F#:(1,4,b7)'),
#   ('B:min', 'F', 'N'),
#   ('A', 'B:7', 'C#:min'),
#   ('A', 'A:9(11)', 'D:9'),
#   ('F:7', 'F:maj9(*7)', 'G'),
#   ('A:7/5', 'B:min', 'Bb'),
#   ('A', 'A:sus4', 'G:min'),
#   ('A', 'A:7', 'G:7'),
#   ('B:min', 'C', 'C#:min'),
#   ('Bb', 'Bb:7', 'F#'),
#   ('B', 'G:sus4(b7)', 'N'),
#   ('A/3', 'G', 'G:7'),
#   ('Bb:min', 'E:min7', 'Eb:min'),
#   ('E:min/b3', 'F:7', 'G'),
#   ('D', 'E:min', 'G:min/b3'),
#   ('A:7/b7', 'B:min/5', 'Eb:min'),
#   ('F#:min', 'F:7', 'F:dim'),
#   ('D', 'Db', 'E:7'),
#   ('E', 'F:dim', 'G:min'),
#   ('C#:min', 'E', 'G:min/b3'),
#   ('A:min', 'B:min', 'D/5'),
#   ('F#:min/5', 'F:maj9(*7)', 'N'),
#   ('A/3', 'B:min', 'F#:min'),
#   ('C:9', 'F#:min', 'G#'),
#   ('A:7/5', 'B:min/5', 'D:9'),
#   ('C:7', 'G:min/b3', 'N'),
#   ('B:aug', 'C#:min', 'C:9'),
#   ('E', 'Eb:min', 'G:min'),
#   ('A:7', 'B:7', 'E:min'),
#   ('C:9', 'F', 'F:dim'),
#   ('D/5', 'F', 'F#'),
#   ('C:9', 'D', 'F'),
#   ('A', 'A:7/b7', 'Db'),
#   ('A', 'Bb:7', 'E:7'),
#   ('C#:min', 'D', 'Eb:min'),
#   ('A', 'F', 'F#:(1,4,b7)'),
#   ('D', 'E:min', 'F#:(1,4,b7)'),
#   ('B:min', 'F#:min/5', 'G:sus4/5'),
#   ('A/3', 'A:9(11)', 'A:sus4'),
#   ('A:7/5', 'A:7/b7', 'G'),
#   ('D', 'Db', 'G:sus4/5'),
#   ('D:min', 'F#:min', 'G'),
#   ('F#:min', 'F:7', 'G#:min'),
#   ('E:maj6', 'F:7', 'G'),
#   ('C#:min', 'E', 'F#:(1,4,b7)'),
#   ('A:7/5', 'B:min/5', 'G:sus4(b7)'),
#   ('A:9(11)', 'G', 'G:min'),
#   ('B:min', 'C', 'F#:min/5'),
#   ('D/5', 'E:maj6', 'G:min/b3'),
#   ('A:7/b7', 'B:min/5', 'F#'),
#   ('A:7/5', 'B:min', 'C#:min'),
#   ('A:7/b7', 'B:min/5', 'Bb:7'),
#   ('C:7', 'E:min', 'G/5'),
#   ('B:7', 'C', 'Db'),
#   ('Bb', 'D:9', 'G'),
#   ('Bb', 'Bb:7', 'E:maj6'),
#   ('B', 'D:7', 'E:7'),
#   ('Bb', 'D/5', 'D:min'),
#   ('E:min7', 'F:7', 'F:dim'),
#   ('C:9', 'F', 'G#:min'),
#   ('D', 'F:7', 'G:7'),
#   ('B:7', 'C', 'F#:min'),
#   ('D', 'E:min', 'F:maj9(*7)'),
#   ('A:min', 'F#:min', 'F:dim'),
#   ('A:9(11)', 'F#:min', 'F:dim'),
#   ('E', 'G:min', 'G:sus4(b7)'),
#   ('A:min', 'Bb:7', 'D:min'),
#   ('A:7/5', 'A:7/b7', 'E:min/b3'),
#   ('B:7', 'Eb:min', 'N'),
#   ('Bb', 'F', 'G:sus4(b7)'),
#   ('Bb', 'Db', 'F'),
#   ('D', 'D:9', 'F#:min/5'),
#   ('A:min', 'B:min/5', 'F'),
#   ('A:7/5', 'B:min/5', 'Eb:min'),
#   ('C:7', 'D:7', 'E:min7'),
#   ('B', 'D/5', 'G:min/b3'),
#   ('A', 'D:9', 'Db'),
#   ('A:7', 'G', 'G:min'),
#   ('A/3', 'A:7/b7', 'B:min/5'),
#   ('E', 'F#:(1,4,b7)', 'G#:min'),
#   ('B:7', 'B:min', 'N'),
#   ('C#:min', 'C:7', 'E'),
#   ('A', 'D/5', 'D:9'),
#   ('A:7/b7', 'A:min', 'E'),
#   ('A:min', 'F', 'G:min/b3'),
#   ('A:7/b7', 'D/5', 'G:min/b3'),
#   ('D', 'D:min', 'G:7'),
#   ('A:min', 'F#:min', 'G#:min'),
#   ('B', 'F#:min/5', 'G'),
#   ('F#:min', 'F#:min/5', 'G#'),
#   ('Bb', 'C', 'C#:min'),
#   ('A:9(11)', 'F#:min', 'G#:min'),
#   ('A:min', 'E:min/b3', 'F'),
#   ('A:7/5', 'B:min', 'F#:min/5'),
#   ('C#:min', 'D:9', 'G'),
#   ('B:min', 'Bb:min', 'Db'),
#   ('A', 'E:7', 'F#:min/5'),
#   ('A:7/b7', 'B:min/5', 'E:maj6'),
#   ('A/3', 'B:aug', 'E'),
#   ('A:7', 'E', 'F'),
#   ('A/3', 'B', 'E:7'),
#   ('Bb', 'C:7', 'D:7'),
#   ('B:min', 'Bb:min', 'F#:min'),
#   ('D', 'E:min/b3', 'F#:min'),
#   ('A:sus4', 'Bb:7', 'E'),
#   ('B:min', 'E:min7', 'G:min/b3'),
#   ('A:sus4', 'F#', 'G'),
#   ('D', 'E:min', 'F:dim'),
#   ('A:7/5', 'B:min/5', 'F#'),
#   ('A', 'D:min', 'F#:(1,4,b7)'),
#   ('A:min', 'F', 'F#:(1,4,b7)'),
#   ('A/3', 'B:min', 'N'),
#   ('A:7/5', 'B:min/5', 'Bb:7'),
#   ('A', 'Bb', 'C'),
#   ('E:min', 'F#:min', 'F#:min/5'),
#   ('C#:min', 'D:7', 'G#'),
#   ('E', 'F', 'F#:min/5'),
#   ('A', 'A:sus4', 'E:7'),
#   ('A', 'Bb', 'F#:(1,4,b7)'),
#   ('A', 'Bb', 'G:min'),
#   ('A:7/5', 'A:sus4', 'Bb:7'),
#   ('A:7/5', 'A:sus4', 'B:min/5'),
#   ('A:7/5', 'D', 'F:maj9(*7)'),
#   ('C#:min', 'F', 'N'),
#   ('C', 'C:7', 'D'),
#   ('D', 'E:maj6', 'Eb:min'),
#   ('Bb', 'C', 'F#:min/5'),
#   ('A:min', 'F', 'F:maj9(*7)'),
#   ('D', 'E:min', 'G#:min'),
#   ('E:7', 'F#:min', 'N'),
#   ('F', 'F#', 'G/5'),
#   ('C:7', 'D:7', 'G#'),
#   ('Bb', 'C#:min', 'E'),
#   ('Bb', 'D:min', 'G:sus4(b7)'),
#   ('C#:min', 'Eb:min', 'G#'),
#   ('B:aug', 'D', 'E:min'),
#   ('A:sus4', 'C:9', 'F'),
#   ('Bb:7', 'G', 'G:min'),
#   ('B', 'F#:(1,4,b7)', 'G'),
#   ('C:9', 'G', 'G:min'),
#   ('A', 'D:9', 'E:min/b3'),
#   ('D/5', 'F:7', 'G'),
#   ('Bb:min', 'D:9', 'Eb:min'),
#   ('A:9(11)', 'B:min', 'E'),
#   ('A', 'A/3', 'A:7'),
#   ('C:7', 'F', 'N'),
#   ('A:min', 'A:sus4', 'D:min'),
#   ('A:7', 'B:min', 'Bb'),
#   ('B:aug', 'Bb', 'E'),
#   ('Db', 'E:min', 'F#:min'),
#   ('C:7', 'E:min', 'G:sus4(b7)'),
#   ('A:7/5', 'F', 'F#'),
#   ('B:aug', 'C#:min', 'E:min7'),
#   ('A:7/5', 'B:min/5', 'E:maj6'),
#   ('C:9', 'E:min', 'F'),
#   ('A:min', 'B:7', 'F'),
#   ('B:min', 'D:min', 'F#:min/5'),
#   ('B', 'F:dim', 'G:7'),
#   ('Bb', 'D:min', 'E:7'),
#   ('B:min', 'Bb', 'E:min7'),
#   ('C#:min', 'E', 'E:7'),
#   ('Bb', 'D:min', 'Eb:min'),
#   ('F:maj9(*7)', 'G', 'G:min'),
#   ('A:7/5', 'C#:min', 'E'),
#   ('A:min', 'A:sus4', 'B:min'),
#   ('B', 'Db', 'G'),
#   ('C#:min', 'E', 'Eb:min'),
#   ('B', 'G#:min', 'G/5'),
#   ('A:7', 'G', 'G:sus4(b7)'),
#   ('B:min', 'E', 'E:min/b3'),
#   ('C#:min', 'F:7', 'N'),
#   ('A:7/5', 'D', 'F:dim'),
#   ('C', 'F#:min/5', 'F:maj9(*7)'),
#   ('Bb', 'E:maj6', 'F'),
#   ('A:7/5', 'D', 'D:min'),
#   ('C:7', 'D:7', 'G:min/b3'),
#   ('A', 'C:9', 'E:min7'),
#   ('C:7', 'E:min', 'Eb:min'),
#   ('A:min', 'F', 'F:dim'),
#   ('D', 'E:min', 'G:sus4/5'),
#   ('E:min7', 'F#', 'G'),
#   ('B:min', 'C:9', 'F#:min'),
#   ('D:7', 'F#:(1,4,b7)', 'N'),
#   ('Bb:min', 'C', 'C:9'),
#   ('E:min/b3', 'F#:min', 'N'),
#   ('C#:min', 'E', 'G:sus4/5'),
#   ('B:min', 'Bb:min', 'N'),
#   ('D/5', 'G:min', 'G:min/b3'),
#   ('A:9(11)', 'A:sus4', 'Bb'),
#   ('A:min', 'D', 'Db'),
#   ('A:sus4', 'Bb:7', 'G:7'),
#   ('B:min', 'E:min7', 'F:dim'),
#   ('Bb', 'D:min', 'F#'),
#   ('C:9', 'D:min', 'F'),
#   ('A/3', 'D', 'F:7'),
#   ('A:7/5', 'D', 'G#:min'),
#   ('C:7', 'D:7', 'F#:(1,4,b7)'),
#   ('B', 'C:7', 'N'),
#   ('C:7', 'D:7', 'G:min'),
#   ('B', 'Bb', 'C:9'),
#   ('Bb:min', 'E', 'G:min'),
#   ('A:min', 'E:7', 'F'),
#   ('A:7/b7', 'F:7', 'G'),
#   ('A:min', 'F', 'G#:min'),
#   ('A/3', 'F#:(1,4,b7)', 'N'),
#   ('Bb:7', 'F:maj9(*7)', 'N'),
#   ('A', 'D:7', 'F#:(1,4,b7)'),
#   ('B', 'E:7', 'F:7'),
#   ('A', 'D:7', 'G:min'),
#   ('A', 'E:min7', 'G:7'),
#   ('D/5', 'E', 'G#:min'),
#   ('A/3', 'D', 'F'),
#   ('Db', 'E:min', 'E:min/b3'),
#   ('C:7', 'E:min', 'F#'),
#   ('A:7/5', 'A:7/b7', 'B:aug'),
#   ('A:7', 'A:7/5', 'A:7/b7'),
#   ('B', 'D/5', 'E:7'),
#   ('B:7', 'Bb:min', 'Eb:min'),
#   ('C:7', 'D:min', 'N'),
#   ('C', 'D:7', 'F:7'),
#   ('A:7/b7', 'B:min', 'B:min/5'),
#   ('B', 'E:7', 'F'),
#   ('Eb:min', 'F:7', 'G'),
#   ('A:7', 'D:9', 'G'),
#   ('A:7/5', 'B:aug', 'D'),
#   ('B', 'F', 'G#:min'),
#   ('A', 'D:min', 'E:7'),
#   ('B:7', 'F', 'F#'),
#   ('A:min', 'B:min', 'F:7'),
#   ('C', 'F#:(1,4,b7)', 'F:maj9(*7)'),
#   ('E', 'E:min7', 'F:dim'),
#   ('A/3', 'D/5', 'E:min7'),
#   ('A', 'Eb:min', 'G:min'),
#   ('A:7', 'B:min', 'F#:min/5'),
#   ('F', 'F#', 'G:sus4(b7)'),
#   ('B:aug', 'D:7', 'E'),
#   ('C:9', 'G', 'G:sus4(b7)'),
#   ('C#:min', 'G', 'G:7'),
#   ('F#:min', 'F:dim', 'G/5'),
#   ('D/5', 'F:dim', 'G:min/b3'),
#   ('A', 'Bb', 'E:7'),
#   ('B:min/5', 'C', 'C:9'),
#   ('A:sus4', 'C:7', 'D:7'),
#   ('A:7/b7', 'Bb:min', 'Eb:min'),
#   ('Bb', 'D', 'E:min'),
#   ('B:min', 'F#:(1,4,b7)', 'G:min/b3'),
#   ('F:maj9(*7)', 'G:sus4/5', 'N'),
#   ('B:min/5', 'D', 'Eb:min'),
#   ('B:min', 'D:7', 'F#:min'),
#   ('Bb', 'D:min', 'E:maj6'),
#   ('Bb:min', 'F#', 'G'),
#   ('Bb:min', 'Db', 'F:7'),
#   ('B:min', 'C:7', 'F#:min/5'),
#   ('Db', 'E:min7', 'F:dim'),
#   ('A:sus4', 'G', 'G:7'),
#   ('D', 'D:7', 'F:dim'),
#   ('A:min', 'D:min', 'F:dim'),
#   ('C', 'Db', 'F:maj9(*7)'),
#   ('D', 'D:7', 'D:min'),
#   ('A:sus4', 'Bb:7', 'C:9'),
#   ('A:7/b7', 'B:7', 'C'),
#   ('B:min/5', 'E', 'G:min'),
#   ('F#:(1,4,b7)', 'F:7', 'N'),
#   ('E', 'E:min7', 'G#:min'),
#   ('B', 'D:9', 'E:7'),
#   ('A:sus4', 'B:min', 'F#:min'),
#   ('A/3', 'A:min', 'B:min'),
#   ('A:min', 'Bb', 'F:dim'),
#   ('A:7/5', 'F:7', 'G'),
#   ('B:min', 'Db', 'G:min/b3'),
#   ('B', 'G#:min', 'G:sus4(b7)'),
#   ('B:aug', 'E', 'E:min'),
#   ('B', 'F:7', 'G#:min'),
#   ('A:7/b7', 'E', 'G#:min'),
#   ('B:min', 'C:9', 'N'),
#   ('D:min', 'F#:(1,4,b7)', 'N'),
#   ('D', 'D:7', 'G#:min'),
#   ('A:min', 'D:min', 'G#:min'),
#   ('A:9(11)', 'A:sus4', 'F#:min/5'),
#   ('B:min', 'F#:min', 'F:7'),
#   ('C', 'C:9', 'E:min7'),
#   ('Bb', 'Bb:7', 'D'),
#   ('F#:min', 'G', 'G:7'),
#   ('B:aug', 'C#:min', 'G:min'),
#   ('B:min', 'Bb', 'G/5'),
#   ('C:7', 'Db', 'E:min'),
#   ('A', 'C', 'D:7'),
#   ('B:aug', 'F#:min', 'G#'),
#   ('A/3', 'B', 'D/5'),
#   ('A:min', 'B:min', 'D:7'),
#   ('A:min', 'Bb', 'G#:min'),
#   ('A:7/5', 'D:min', 'G'),
#   ('A', 'A:7', 'G:min/b3'),
#   ('A/3', 'D/5', 'G#'),
#   ('A', 'A:9(11)', 'A:sus4'),
#   ('C:7', 'D:7', 'G:sus4(b7)'),
#   ('D', 'F', 'F#:min/5'),
#   ('C:9', 'D:7', 'F'),
#   ('F#:(1,4,b7)', 'G#:min', 'N'),
#   ('B:min/5', 'F#', 'G'),
#   ('A', 'B:min/5', 'G'),
#   ('A:7/5', 'Bb:min', 'Eb:min'),
#   ('Bb', 'E', 'G#:min'),
#   ('A:9(11)', 'A:sus4', 'F:7'),
#   ('E', 'F#', 'G#:min'),
#   ('B:aug', 'C#:min', 'C:7'),
#   ('A', 'C:9', 'G:min'),
#   ('B', 'E:min', 'F:7'),
#   ('Bb:7', 'C', 'D'),
#   ('A:sus4', 'F:maj9(*7)', 'N'),
#   ('B:7', 'G:sus4(b7)', 'N'),
#   ('B:min/5', 'Bb', 'F'),
#   ('Bb:min', 'E:min', 'Eb:min'),
#   ('A:9(11)', 'A:sus4', 'F'),
#   ('A:sus4', 'Bb:min', 'Db'),
#   ('D:7', 'F#:min', 'F:dim'),
#   ('A:9(11)', 'B:7', 'E:min'),
#   ('C:7', 'D:7', 'E:7'),
#   ('C:9', 'D', 'G:7'),
#   ('B:7', 'Bb:7', 'E:min'),
#   ('B', 'E:min7', 'G'),
#   ('B', 'E:min', 'F'),
#   ('Bb:min', 'E', 'Eb:min'),
#   ('A', 'E:min/b3', 'G'),
#   ('C:9', 'Eb:min', 'F'),
#   ('D:min', 'F', 'F#'),
#   ('A/3', 'G', 'G:min'),
#   ('C:7', 'D:7', 'Eb:min'),
#   ('F#', 'G', 'G:min/b3'),
#   ('A:7/5', 'A:7/b7', 'C'),
#   ('A:7/b7', 'B:min/5', 'D'),
#   ('A:9(11)', 'E:min', 'F#:min'),
#   ('E', 'G#', 'G#:min'),
#   ('A:7/5', 'E', 'G#:min'),
#   ('B:min', 'C:7', 'D:7'),
#   ('F#:min', 'F:dim', 'G:sus4(b7)'),
#   ('A/3', 'F#:min', 'F:dim'),
#   ('A/3', 'B:7', 'D'),
#   ('C:7', 'D/5', 'G:min/b3'),
#   ('A:sus4', 'B', 'E:7'),
#   ('A', 'A:7', 'C:7'),
#   ('A', 'A:7', 'F:maj9(*7)'),
#   ('C:7', 'D:7', 'G:sus4/5'),
#   ('C', 'E:maj6', 'G:7'),
#   ('E:min', 'E:min7', 'F:dim'),
#   ('A/3', 'A:7/b7', 'D'),
#   ('A:min', 'D:7', 'D:min'),
#   ('Bb:min', 'Eb:min', 'G/5'),
#   ('A', 'A:7', 'Bb:min'),
#   ('A:min', 'Db', 'E'),
#   ('A/3', 'D/5', 'G/5'),
#   ('B:aug', 'C#:min', 'D:9'),
#   ('A:7/5', 'A:7/b7', 'F:maj9(*7)'),
#   ('C:7', 'D:7', 'F#'),
#   ('C:9', 'D', 'E:min/b3'),
#   ('D:min', 'G', 'G:min/b3'),
#   ('Bb', 'D', 'F#:min/5'),
#   ('B:min', 'Bb', 'D:9'),
#   ('Bb', 'Bb:7', 'F:7'),
#   ('A/3', 'F#:min', 'G#:min'),
#   ('A:9(11)', 'A:sus4', 'D:7'),
#   ('B:min', 'C', 'G:7'),
#   ('B:aug', 'C#:min', 'G:sus4(b7)'),
#   ('A', 'C:9', 'D:9'),
#   ('C#:min', 'F#:min/5', 'N'),
#   ('C', 'C#:min', 'D'),
#   ('A:sus4', 'B', 'Bb:7'),
#   ('D', 'E:min/b3', 'G/5'),
#   ('B:min', 'Bb', 'G:sus4(b7)'),
#   ('A', 'B:7', 'G'),
#   ('E:maj6', 'G:min', 'N'),
#   ('E:min7', 'F:maj9(*7)', 'N'),
#   ('A:7', 'C', 'D:7'),
#   ('B:aug', 'E', 'F#:min/5'),
#   ('Bb:min', 'G', 'G:7'),
#   ('B', 'Bb', 'G#'),
#   ('C:7', 'E:maj6', 'E:min'),
#   ('A:7/5', 'A:sus4', 'D'),
#   ('Bb', 'F#:(1,4,b7)', 'N'),
#   ('B:aug', 'C#:min', 'E:7'),
#   ('Bb', 'D', 'F'),
#   ('B:aug', 'C#:min', 'Eb:min'),
#   ('A:7/5', 'A:7/b7', 'F:dim'),
#   ('C', 'C:9', 'G/5'),
#   ('A:7/b7', 'B:min/5', 'F:7'),
#   ('Bb', 'C:7', 'N'),
#   ('Bb:min', 'G:sus4(b7)', 'N'),
#   ('D:min', 'F#:min', 'F:dim'),
#   ('A:7/5', 'A:7/b7', 'D:min'),
#   ('A:sus4', 'D', 'E:min7'),
#   ('C:9', 'F', 'F#:min/5'),
#   ('C', 'E:min/b3', 'G:7'),
#   ('B:aug', 'B:min', 'G:min/b3'),
#   ('D/5', 'F:7', 'G:min/b3'),
#   ('A:7/5', 'A:7/b7', 'B'),
#   ('A', 'E:7', 'G:7'),
#   ('A:7/b7', 'B:min/5', 'F'),
#   ('B', 'G:7', 'G:min/b3'),
#   ('B:min', 'G:sus4/5', 'N'),
#   ('C:9', 'E:min', 'F#:min'),
#   ('A', 'C:9', 'E:7'),
#   ('A:7/5', 'A:7/b7', 'B:min'),
#   ('C#:min', 'C:7', 'G#'),
#   ('B:aug', 'C#:min', 'G:sus4/5'),
#   ('C:7', 'D', 'F#:min/5'),
#   ('A:sus4', 'E:maj6', 'N'),
#   ('Bb', 'Bb:7', 'D:7'),
#   ('A:7/5', 'A:7/b7', 'G#:min'),
#   ('A/3', 'D/5', 'D:9'),
#   ('D:min', 'F#:min', 'G#:min'),
#   ('B', 'Bb', 'G:min/b3'),
#   ('B:7', 'E:maj6', 'E:min'),
#   ('E', 'E:maj6', 'G:min'),
#   ('D', 'D:9', 'E:min/b3'),
#   ('E:maj6', 'F:dim', 'N'),
#   ('E:min', 'F#:min', 'G:7'),
#   ('B:aug', 'C#:min', 'F#'),
#   ('A:7/b7', 'C', 'F:maj9(*7)'),
#   ('B:min', 'E', 'F#:(1,4,b7)'),
#   ('E', 'F', 'G:7'),
#   ('B', 'G:7', 'G:min'),
#   ('Eb:min', 'F#', 'N'),
#   ('A', 'B:aug', 'G:7'),
#   ('B:min/5', 'G', 'G:7'),
#   ('A', 'A:7/b7', 'D:min'),
#   ('F#', 'G', 'G#:min'),
#   ('B:min', 'Bb', 'F#'),
#   ('A:sus4', 'Bb:7', 'G#'),
#   ('Bb:7', 'F#:min', 'N'),
#   ('Bb', 'D', 'D:7'),
#   ('Bb:min', 'Eb:min', 'G:sus4(b7)'),
#   ('A/3', 'D/5', 'G:sus4(b7)'),
#   ('Bb:7', 'C', 'D:7'),
#   ('D', 'Eb:min', 'G#'),
#   ('B', 'Bb', 'F#:(1,4,b7)'),
#   ('A', 'E:7', 'E:min/b3'),
#   ('A', 'A:7', 'G:sus4/5'),
#   ('B', 'Bb', 'G:min'),
#   ('A/3', 'Bb', 'C'),
#   ('B', 'F:maj9(*7)', 'G:7'),
#   ('A:7/5', 'B:min/5', 'F:7'),
#   ('B:7', 'C', 'D:min'),
#   ('B:7', 'D', 'F#:min/5'),
#   ('B:min', 'D:9', 'F#:min/5'),
#   ('B:aug', 'F#', 'G'),
#   ('F:7', 'F:dim', 'G'),
#   ('B:min', 'E', 'F:maj9(*7)'),
#   ('E:min', 'E:min/b3', 'G#:min'),
#   ('A:7/b7', 'B:min/5', 'D:7'),
#   ('E', 'G', 'G#:min'),
#   ('A', 'Bb:min', 'C#:min'),
#   ('B:aug', 'Db', 'E'),
#   ('A:7/5', 'B:min/5', 'F'),
#   ('C', 'F:maj9(*7)', 'G#'),
#   ('Bb', 'C#:min', 'G#'),
#   ('B', 'Bb:7', 'G'),
#   ('A/3', 'D', 'F#:min'),
#   ('A/3', 'D/5', 'Eb:min'),
#   ('B', 'F#:min/5', 'G#:min'),
#   ('Bb', 'F', 'F:7'),
#   ('B', 'Bb', 'C:7'),
#   ('C', 'C:9', 'D:9'),
#   ('C#:min', 'F', 'F#'),
#   ('B', 'Bb', 'F:maj9(*7)'),
#   ('A:sus4', 'Bb:7', 'G:min/b3'),
#   ('A', 'D:9', 'F:dim'),
#   ('D:min', 'G', 'G#:min'),
#   ('A', 'D:9', 'D:min'),
#   ('B:7', 'C', 'G#:min'),
#   ('C', 'D:7', 'Db'),
#   ('C#:min', 'D', 'D:7'),
#   ('B:7', 'F#:min', 'G#'),
#   ('A:min', 'E', 'E:min7'),
#   ('B:min', 'Bb', 'E:maj6'),
#   ('B', 'Bb', 'Bb:min'),
#   ('B:min', 'E:min/b3', 'F#:min'),
#   ('B', 'C', 'G#'),
#   ('A:7/5', 'C', 'F:maj9(*7)'),
#   ('A:sus4', 'B:7', 'C'),
#   ('C', 'D:7', 'F#:min'),
#   ('E:min/b3', 'F#', 'G'),
#   ('C', 'D', 'G#'),
#   ('B:aug', 'G', 'G:sus4(b7)'),
#   ('A:min', 'B:min', 'Db'),
#   ('A', 'B:aug', 'C:9'),
#   ('B:aug', 'C:9', 'F'),
#   ('C', 'C:9', 'G:sus4(b7)'),
#   ('E', 'F:7', 'G'),
#   ('A:7/5', 'C#:min', 'G#'),
#   ('A:sus4', 'Bb:7', 'F#:(1,4,b7)'),
#   ('B:min', 'E', 'F:dim'),
#   ('A:sus4', 'Bb:7', 'G:min'),
#   ('A', 'D:9', 'G#:min'),
#   ('B:min/5', 'Bb:min', 'Db'),
#   ('Bb:min', 'Eb:min', 'F#'),
#   ('A/3', 'D/5', 'F#'),
#   ('D', 'Eb:min', 'G/5'),
#   ('Eb:min', 'F', 'N'),
#   ('C', 'E:7', 'G:7'),
#   ('Db', 'F:7', 'G'),
#   ('B', 'D:min', 'E:min'),
#   ('Bb:min', 'Db', 'F#:min'),
#   ('Bb', 'F#:min', 'F:dim'),
#   ('A:7/5', 'B:min/5', 'D:7'),
#   ('Bb', 'E:maj6', 'N'),
#   ('C', 'C:9', 'Eb:min'),
#   ('E:maj6', 'F#', 'G'),
#   ('A:sus4', 'Bb:7', 'C:7'),
#   ('A:sus4', 'Bb:7', 'F:maj9(*7)'),
#   ('F:dim', 'G', 'G:7'),
#   ('Eb:min', 'F#:min', 'G#'),
#   ('B', 'F#:(1,4,b7)', 'G#:min'),
#   ('B', 'C', 'G:min/b3'),
#   ('D:9', 'E:min/b3', 'G'),
#   ('C', 'D', 'G:min/b3'),
#   ('C', 'Eb:min', 'G:7'),
#   ('B', 'C:7', 'G#:min'),
#   ('C', 'F:maj9(*7)', 'G:min'),
#   ('A', 'C:7', 'E:min7'),
#   ('A/3', 'Bb', 'D:min'),
#   ('A:sus4', 'Bb:7', 'Bb:min'),
#   ('D', 'E:min/b3', 'F#'),
#   ('E:min7', 'F#', 'F:dim'),
#   ('Bb:min', 'D:min', 'G'),
#   ('D', 'F#', 'G:7'),
#   ('C', 'F:dim', 'F:maj9(*7)'),
#   ('C#:min', 'G', 'G:min'),
#   ('Bb', 'D:min', 'F:7'),
#   ('B', 'Db', 'G#:min'),
#   ('C#:min', 'E', 'F:7'),
#   ('A', 'Db', 'E:min7'),
#   ('C', 'D:7', 'E:min/b3'),
#   ('D:min', 'F:maj9(*7)', 'G'),
#   ('B:min', 'B:min/5', 'Bb'),
#   ('A', 'B:7', 'B:aug'),
#   ('E', 'E:min', 'G#:min'),
#   ('A/3', 'D/5', 'E:maj6'),
#   ('B:min', 'G#', 'N'),
#   ('B', 'C', 'F#:(1,4,b7)'),
#   ('A:sus4', 'G', 'G:min'),
#   ('Bb:min', 'C', 'Eb:min'),
#   ('C', 'D', 'F#:(1,4,b7)'),
#   ('B', 'C', 'G:min'),
#   ('C', 'C:9', 'F#'),
#   ('B:min', 'F:dim', 'G:min/b3'),
#   ('F#:min/5', 'G', 'G:7'),
#   ('A:7', 'F#:(1,4,b7)', 'N'),
#   ('B:min', 'Bb:7', 'F#:min/5'),
#   ('A:9(11)', 'A:sus4', 'Db'),
#   ('D', 'F#:min/5', 'G/5'),
#   ('B', 'E:7', 'N'),
#   ('E:min7', 'F:dim', 'G:7'),
#   ('B:aug', 'D', 'G:7'),
#   ('C:7', 'E:min', 'F'),
#   ('B:min', 'E:min/b3', 'N'),
#   ('B', 'G:7', 'G:sus4/5'),
#   ('B', 'C', 'C:7'),
#   ('C:7', 'F#:min', 'F:dim'),
#   ('B:aug', 'C#:min', 'D/5'),
#   ('Db', 'E', 'G#:min'),
#   ('C:7', 'E', 'F'),
#   ('B:aug', 'C', 'C#:min'),
#   ('A', 'B:min/5', 'F#:(1,4,b7)'),
#   ('F#:min', 'G', 'G:min'),
#   ('A:min', 'Bb', 'C#:min'),
#   ('A/3', 'E:min', 'F#:min'),
#   ('B', 'Bb', 'G:sus4/5'),
#   ('B:min/5', 'D:min', 'G'),
#   ('B:aug', 'C:7', 'D:7'),
#   ('D:9', 'F#:min', 'G'),
#   ('A:min', 'D', 'D:min'),
#   ('A:7', 'A:min', 'D:min'),
#   ('B:min', 'E:7', 'F#:min'),
#   ('F', 'G:sus4(b7)', 'N'),
#   ('C', 'C:9', 'E:maj6'),
#   ('A:7/5', 'Bb:min', 'D'),
#   ('C#:min', 'E:min7', 'N'),
#   ('B', 'B:min', 'N'),
#   ('C:9', 'E:min7', 'F'),
#   ('F:7', 'G:sus4(b7)', 'N'),
#   ('Bb:min', 'Db', 'N'),
#   ('A', 'E:min/b3', 'F#:(1,4,b7)'),
#   ('A:min', 'E', 'G/5'),
#   ('D', 'Eb:min', 'G:sus4(b7)'),
#   ('A', 'E:min/b3', 'G:min'),
#   ('A', 'E:min7', 'G:sus4(b7)'),
#   ('E:min7', 'F', 'F:dim'),
#   ('A:min', 'Bb:min', 'F'),
#   ('A:9(11)', 'A:sus4', 'G'),
#   ('D', 'F', 'G:7'),
#   ('D/5', 'F#:min/5', 'G:min/b3'),
#   ('A:7', 'A:min', 'B:min'),
#   ('A', 'A:7', 'D/5'),
#   ('A:7', 'C#:min', 'E'),
#   ('A:min', 'D:min', 'F#:min/5'),
#   ('A:sus4', 'Bb:7', 'E:7'),
#   ('A:sus4', 'Bb:7', 'Eb:min'),
#   ('D/5', 'F#', 'G'),
#   ('C:7', 'E:min7', 'N'),
#   ('A/3', 'C', 'D:7'),
#   ('Bb', 'Bb:7', 'Db'),
#   ('E:7', 'F#:(1,4,b7)', 'N'),
#   ('C', 'F:maj9(*7)', 'G:sus4(b7)'),
#   ('A:min', 'Bb', 'F#:min/5'),
#   ('Bb', 'Bb:7', 'F#:min'),
#   ('A', 'E:min7', 'Eb:min'),
#   ('A:9(11)', 'A:sus4', 'E:min/b3'),
#   ('E:min/b3', 'G', 'G:7'),
#   ...},
#  '102': {('B', 'C#:min', 'C:7'),
#   ('B', 'E', 'N'),
#   ('D', 'F', 'N'),
#   ('A', 'G#', 'G#:min'),
#   ('A:7', 'C', 'N'),
#   ('A', 'A/3', 'A:min'),
#   ('A:7/b7', 'C#:min', 'F#:min'),
#   ('B', 'F#:min', 'F#:min/5'),
#   ('D:min', 'F#', 'G:min'),
#   ('A:min', 'C:9', 'E:min'),
#   ('A', 'E', 'F#'),
#   ('E:7', 'E:min', 'G'),
#   ('C', 'Db', 'F'),
#   ('B:7', 'B:min', 'D'),
#   ('E:min', 'G#:min', 'N'),
#   ('D/5', 'G', 'G:sus4/5'),
#   ('A', 'B:min', 'G/5'),
#   ('Eb:min', 'F', 'G:min'),
#   ('A/3', 'D:7', 'G:7'),
#   ('C:7', 'E:7', 'G:7'),
#   ('A/3', 'C:7', 'G'),
#   ('A:7/b7', 'B', 'D'),
#   ('B', 'C#:min', 'D:9'),
#   ('E', 'F#:(1,4,b7)', 'F#:min'),
#   ('A:min', 'C', 'E:min7'),
#   ('A', 'B', 'C:7'),
#   ('A:7/b7', 'C', 'E:min'),
#   ('B', 'D', 'G/5'),
#   ('A', 'E', 'E:maj6'),
#   ('A', 'A:min', 'A:sus4'),
#   ('A:9(11)', 'C:7', 'G:7'),
#   ('B:7', 'G', 'G:sus4/5'),
#   ('B', 'C#:min', 'G:sus4(b7)'),
#   ('B', 'Eb:min', 'F#:min'),
#   ('Bb', 'D', 'N'),
#   ('B', 'E', 'E:min7'),
#   ('B:aug', 'B:min', 'E:min'),
#   ('Bb:7', 'C#:min', 'F#:min'),
#   ('E:min', 'Eb:min', 'G'),
#   ('B:aug', 'E:min', 'N'),
#   ('A:7/b7', 'G', 'G:sus4/5'),
#   ('A:min', 'Bb:7', 'G'),
#   ('A:min', 'F#:min', 'G'),
#   ('B', 'C#:min', 'Eb:min'),
#   ('D', 'G#:min', 'N'),
#   ('E', 'F#:min', 'F:7'),
#   ('Bb:min', 'F', 'G'),
#   ('Eb:min', 'G', 'G:sus4/5'),
#   ('A:min', 'C', 'G#'),
#   ('B:min/5', 'D', 'E'),
#   ('C#:min', 'E:maj6', 'F#:min'),
#   ('A:7/5', 'C', 'E:min'),
#   ('D:9', 'E:min', 'N'),
#   ('G', 'G#', 'G#:min'),
#   ('Bb', 'G', 'G:sus4/5'),
#   ('A', 'B', 'G:sus4(b7)'),
#   ('B', 'C#:min', 'F#'),
#   ('A', 'B:min', 'G:sus4(b7)'),
#   ('B', 'D:9', 'E'),
#   ('B:min', 'Bb:min', 'D'),
#   ('A', 'F#', 'G#'),
#   ('A:7/b7', 'D', 'G'),
#   ('B', 'C:7', 'D'),
#   ('A', 'B', 'Eb:min'),
#   ('A:7/5', 'G', 'G:sus4/5'),
#   ('C', 'E:min', 'F:7'),
#   ('B:min/5', 'F', 'G'),
#   ('Bb:7', 'C:7', 'G:7'),
#   ('B:min/5', 'C:7', 'F:7'),
#   ('A:min', 'E:min', 'G/5'),
#   ('B:7', 'D', 'N'),
#   ('C:7', 'F', 'F:7'),
#   ('A:7', 'A:min', 'E:min'),
#   ('A', 'A/3', 'B'),
#   ('D/5', 'E', 'F#:min'),
#   ('A:min', 'A:sus4', 'G'),
#   ('B:aug', 'D:min', 'G:min'),
#   ('A:min', 'C', 'G:min'),
#   ('A:7', 'A:7/b7', 'D'),
#   ('Bb:7', 'C:7', 'G'),
#   ('A', 'A/3', 'B:min'),
#   ('B', 'D', 'D:min'),
#   ('A', 'B', 'F#'),
#   ('A', 'B', 'Bb:7'),
#   ('A', 'B', 'B:min/5'),
#   ('A', 'A:min', 'F#:min/5'),
#   ('B', 'F', 'F#:min'),
#   ('B', 'E', 'G/5'),
#   ('A', 'B:min', 'F#'),
#   ('A', 'B:min', 'Bb:7'),
#   ('A:min', 'C', 'C:7'),
#   ('A', 'D/5', 'N'),
#   ('A', 'E:min', 'F:dim'),
#   ('A:sus4', 'B', 'E'),
#   ('A:7/b7', 'C', 'F'),
#   ('A', 'A:min', 'F:7'),
#   ('E:min', 'G', 'G#:min'),
#   ('C', 'E:min7', 'N'),
#   ('B:min', 'E:min', 'F:7'),
#   ('B:min', 'C:9', 'D'),
#   ('D:7', 'D:9', 'G:7'),
#   ('D', 'D/5', 'G:min'),
#   ('C:7', 'C:9', 'G:7'),
#   ('D:7', 'D:min', 'G:min'),
#   ('B:min', 'E:min7', 'G'),
#   ('B:min', 'E:min', 'F'),
#   ('B', 'C:7', 'F:7'),
#   ('B', 'B:aug', 'D'),
#   ('A', 'B:min/5', 'E:min'),
#   ('A:7/b7', 'E', 'F#:min'),
#   ('A', 'E:min', 'G#:min'),
#   ('A', 'B:min', 'E:maj6'),
#   ('F', 'G#', 'G:min'),
#   ('D:7', 'F:dim', 'G'),
#   ('B', 'Bb:7', 'E:maj6'),
#   ('A', 'Bb:7', 'G#'),
#   ('A/3', 'D:min', 'G:min'),
#   ('A:min', 'C', 'D:9'),
#   ('C', 'F#:min/5', 'G'),
#   ('D/5', 'E:min', 'N'),
#   ('C#:min', 'F#:min', 'F#:min/5'),
#   ('A/3', 'C#:min', 'F#:min'),
#   ('A:sus4', 'F', 'G:min'),
#   ('C', 'F#', 'N'),
#   ('C#:min', 'D:7', 'G:7'),
#   ('B', 'D:min', 'F#:min'),
#   ('Bb:min', 'D', 'N'),
#   ('D:7', 'G:7', 'N'),
#   ('Bb', 'E', 'F#:min'),
#   ('A:min', 'F#:min/5', 'N'),
#   ('E', 'F#', 'F#:min'),
#   ('D', 'F#:(1,4,b7)', 'G:min'),
#   ('A:min', 'C', 'G:sus4(b7)'),
#   ('B', 'E:maj6', 'F:dim'),
#   ('D:min', 'E:min', 'G:min'),
#   ('A:7/5', 'C', 'F'),
#   ('A/3', 'A:min', 'G'),
#   ('B', 'C#:min', 'D/5'),
#   ('A', 'A:min', 'D:7'),
#   ('B:aug', 'C', 'G'),
#   ('A:min', 'Bb:min', 'N'),
#   ('A', 'D:7', 'G:7'),
#   ('A', 'C:9', 'E'),
#   ('B', 'E', 'G:sus4(b7)'),
#   ('A:min', 'C', 'E:7'),
#   ('A:sus4', 'B:min', 'D'),
#   ('A:9(11)', 'C', 'N'),
#   ('A:7/5', 'E', 'F#:min'),
#   ('A:min', 'C', 'Eb:min'),
#   ('C', 'F#:(1,4,b7)', 'G'),
#   ('C', 'D/5', 'N'),
#   ('B:7', 'C:7', 'G:7'),
#   ('F', 'G:min', 'G:min/b3'),
#   ('A:7/b7', 'E:min', 'N'),
#   ('E', 'E:min/b3', 'F#:min'),
#   ('E:min7', 'G', 'N'),
#   ('B', 'E', 'Eb:min'),
#   ('B:min', 'D/5', 'G'),
#   ('C', 'Db', 'G'),
#   ('D:7', 'F#:min', 'G:7'),
#   ('A', 'D', 'G/5'),
#   ('A:min', 'C', 'F#'),
#   ('A:sus4', 'D:min', 'G:min'),
#   ('A', 'A:sus4', 'G#'),
#   ('A', 'B', 'D/5'),
#   ('Bb:7', 'E:min', 'G'),
#   ('A:7', 'B', 'E:maj6'),
#   ('F', 'G/5', 'G:min'),
#   ('D:7', 'F#:min', 'G'),
#   ('A:min', 'G#:min', 'N'),
#   ('B', 'E', 'F#'),
#   ('C:7', 'F:maj9(*7)', 'G:7'),
#   ('E:min/b3', 'F', 'G'),
#   ('A:7', 'D', 'F'),
#   ('E:7', 'G', 'G:sus4/5'),
#   ('A:7/5', 'B:min', 'E:min'),
#   ('A', 'F', 'G#'),
#   ('C:7', 'F:maj9(*7)', 'G'),
#   ('A', 'E', 'F:7'),
#   ('A:min', 'Bb:7', 'C'),
#   ('A:7/5', 'E:min', 'N'),
#   ('E:min', 'E:min7', 'G'),
#   ('A:9(11)', 'G', 'G#'),
#   ('A:min', 'C', 'E:maj6'),
#   ('D', 'D:min', 'E'),
#   ('E:maj6', 'F', 'G'),
#   ('A:7', 'D:7', 'G:7'),
#   ('F', 'F:maj9(*7)', 'G'),
#   ('A:min', 'Db', 'E:min'),
#   ('D', 'E:maj6', 'G:min'),
#   ('Bb:min', 'F', 'G:min'),
#   ('A:7/b7', 'B', 'F#:min'),
#   ('A:7', 'G', 'G#'),
#   ('Bb:min', 'C:7', 'G:7'),
#   ('A:min', 'C#:min', 'G#:min'),
#   ('A:7', 'D:7', 'G'),
#   ('A:min', 'G', 'G:min/b3'),
#   ('D', 'E', 'G:min/b3'),
#   ('D', 'G:sus4/5', 'N'),
#   ('Bb:min', 'C:7', 'G'),
#   ('C:7', 'F#:min/5', 'F:7'),
#   ('E', 'E:7', 'F#:min'),
#   ('Bb', 'C:7', 'F:7'),
#   ('A:min', 'D:7', 'N'),
#   ('A', 'D', 'G:sus4(b7)'),
#   ('B:min', 'D:min', 'E:min'),
#   ('C#:min', 'F', 'F#:min'),
#   ('A', 'B', 'B:7'),
#   ('A', 'D:min', 'G#'),
#   ('D:min', 'Eb:min', 'G:min'),
#   ('D', 'E', 'F#:(1,4,b7)'),
#   ('C', 'E', 'F#:min'),
#   ('C:7', 'D/5', 'G:7'),
#   ('A', 'G:sus4/5', 'N'),
#   ('A', 'Bb', 'G#'),
#   ('A:min', 'A:sus4', 'C'),
#   ('C:7', 'D/5', 'G'),
#   ('A:7/5', 'B', 'F#:min'),
#   ('D', 'E', 'F:maj9(*7)'),
#   ('C', 'F', 'G#'),
#   ('C:9', 'G', 'G#'),
#   ('E:min', 'F#', 'N'),
#   ('B', 'Bb:7', 'D'),
#   ('B', 'B:7', 'D'),
#   ('D:7', 'F#:min/5', 'G'),
#   ('A:min', 'C:9', 'G'),
#   ('Bb:7', 'D:7', 'G'),
#   ('B:min/5', 'C:7', 'G'),
#   ('F', 'G:min', 'G:sus4/5'),
#   ('A:min', 'C', 'D/5'),
#   ('C:7', 'F#:(1,4,b7)', 'F:7'),
#   ('B', 'C#:min', 'F:7'),
#   ('A', 'A:min', 'Db'),
#   ('C:7', 'D:9', 'G:7'),
#   ('F:maj9(*7)', 'G', 'G#'),
#   ('A', 'D', 'F#'),
#   ('A:sus4', 'C', 'N'),
#   ('B', 'C#:min', 'F'),
#   ('E:min', 'G#', 'N'),
#   ('B', 'F#:(1,4,b7)', 'F#:min'),
#   ('A:7', 'B:min', 'E:min'),
#   ('Bb:7', 'D', 'G:min'),
#   ('B', 'C:7', 'F#:min'),
#   ('Bb:7', 'C#:min', 'G#:min'),
#   ('D', 'E', 'F:dim'),
#   ('E:min7', 'G', 'G/5'),
#   ('A:7/b7', 'C', 'G'),
#   ('A:min', 'G:sus4/5', 'N'),
#   ('A:sus4', 'D', 'E'),
#   ('B', 'Db', 'F#:min'),
#   ('C', 'D:min', 'F'),
#   ('C', 'E', 'N'),
#   ('C', 'F', 'G/5'),
#   ('A:min', 'G', 'G#:min'),
#   ('B', 'D:7', 'E:maj6'),
#   ('A:7', 'F', 'G:min'),
#   ('B:aug', 'B:min', 'G'),
#   ('A', 'B', 'F:7'),
#   ('A', 'D', 'E:maj6'),
#   ('B', 'C#:min', 'D:7'),
#   ('A', 'B:min', 'F:7'),
#   ('A', 'B', 'F'),
#   ('Db', 'E', 'F#:min'),
#   ('A:7/b7', 'F', 'G'),
#   ('A', 'A:min', 'E:min/b3'),
#   ('A/3', 'A:min', 'C'),
#   ('A', 'Eb:min', 'G#'),
#   ('A', 'B:min', 'F'),
#   ('D', 'G#', 'N'),
#   ('C#:min', 'C:7', 'G:7'),
#   ('A:sus4', 'C:7', 'F:7'),
#   ('A', 'F:dim', 'N'),
#   ('A:7/5', 'C', 'G'),
#   ('A:7', 'C', 'E:min'),
#   ('A:9(11)', 'G', 'G:sus4/5'),
#   ('Db', 'E:min', 'G'),
#   ('D', 'E', 'G:sus4/5'),
#   ('D', 'F:dim', 'G:min'),
#   ('B', 'B:aug', 'F#:min'),
#   ('E:min', 'G:min', 'N'),
#   ('C#:min', 'F#:min', 'G'),
#   ('C:7', 'F#:min', 'G:7'),
#   ('B:aug', 'G', 'N'),
#   ('C', 'C:7', 'F:7'),
#   ('A', 'B', 'D:7'),
#   ('E:7', 'F', 'G:min'),
#   ('A:7', 'D:min', 'G:min'),
#   ('A:min', 'F:maj9(*7)', 'G'),
#   ('A', 'B:min', 'D:7'),
#   ('E', 'E:min', 'N'),
#   ('C:7', 'F#:min', 'G'),
#   ('B', 'F#:min', 'G:min/b3'),
#   ('C', 'F:dim', 'G'),
#   ('A', 'C', 'F'),
#   ('C', 'F', 'G:sus4(b7)'),
#   ('A', 'C:9', 'G#'),
#   ('A:7', 'A:min', 'G'),
#   ('Bb:min', 'C', 'N'),
#   ('A:min', 'D:9', 'N'),
#   ('A:min', 'C#:min', 'E:min'),
#   ('B:min', 'D', 'G#'),
#   ('A', 'D', 'D/5'),
#   ('B', 'E:maj6', 'F#:min/5'),
#   ('E:min7', 'F', 'G'),
#   ('D:9', 'F', 'G:min'),
#   ('A/3', 'G', 'G#'),
#   ('B', 'F#:min', 'G:min'),
#   ('E:min/b3', 'F', 'G:min'),
#   ('A:min', 'E:min', 'F#:min/5'),
#   ('A', 'C:7', 'E'),
#   ('C:7', 'E:min7', 'F:7'),
#   ('D', 'G/5', 'N'),
#   ('B:min', 'C:7', 'F:7'),
#   ('D:7', 'G', 'G:min/b3'),
#   ('B', 'F#:min', 'F:maj9(*7)'),
#   ('A', 'Db', 'E'),
#   ('A', 'G#', 'G:7'),
#   ('Bb:7', 'G', 'G:sus4/5'),
#   ('A:7/b7', 'A:min', 'N'),
#   ('A:min', 'C', 'F:7'),
#   ('A/3', 'C#:min', 'G#:min'),
#   ('E:maj6', 'F', 'G:min'),
#   ('A:sus4', 'B:min', 'G'),
#   ('A:min', 'E:min7', 'G'),
#   ('D', 'E:7', 'N'),
#   ('B:min/5', 'C#:min', 'F#:min'),
#   ('F:maj9(*7)', 'G', 'G:sus4/5'),
#   ('B', 'C:9', 'D'),
#   ('B:min', 'D', 'F#:(1,4,b7)'),
#   ('C:7', 'F#', 'F:7'),
#   ('B', 'E', 'F:7'),
#   ('E:min', 'F#:min/5', 'N'),
#   ('C', 'E:min', 'G/5'),
#   ('B', 'F#', 'F#:min'),
#   ('B:aug', 'D:7', 'G:7'),
#   ('B:min', 'D', 'F:maj9(*7)'),
#   ('A:9(11)', 'E', 'F#:min'),
#   ('A', 'F:7', 'G#'),
#   ('C:9', 'D', 'G'),
#   ('A:7', 'C', 'F'),
#   ('B:min', 'D:9', 'E:min'),
#   ('A:7/5', 'A:min', 'N'),
#   ('C#:min', 'F#:(1,4,b7)', 'F#:min'),
#   ('C:7', 'F#:min/5', 'G'),
#   ('C#:min', 'F:maj9(*7)', 'G#:min'),
#   ('A', 'A:7/5', 'B'),
#   ('B', 'B:min/5', 'F#:min'),
#   ('A', 'A:7/5', 'B:min'),
#   ('B', 'C#:min', 'Db'),
#   ('A:7', 'E', 'F#:min'),
#   ('A', 'A/3', 'E'),
#   ('D/5', 'G', 'N'),
#   ('D', 'F:7', 'G:min'),
#   ('B', 'E:min/b3', 'F#:min'),
#   ('F', 'F#:min/5', 'G:min'),
#   ('C:7', 'F:7', 'G/5'),
#   ('A', 'Bb:min', 'E:min'),
#   ('A:min', 'E:min/b3', 'G'),
#   ('B', 'F#:min', 'G:sus4/5'),
#   ('B:aug', 'G', 'G/5'),
#   ('Bb:7', 'C', 'F'),
#   ('D:min', 'G#', 'G:min'),
#   ('A', 'F#:min/5', 'N'),
#   ('A:9(11)', 'E:min', 'N'),
#   ('C#:min', 'G#:min', 'G:min'),
#   ('A', 'B', 'Db'),
#   ('C:7', 'F:dim', 'G:7'),
#   ('A:min', 'B:min/5', 'N'),
#   ('A', 'B:min', 'Db'),
#   ('A:sus4', 'B', 'E:maj6'),
#   ('B:min', 'D', 'E:7'),
#   ('C:9', 'E', 'F#:min'),
#   ('A:min', 'C:7', 'G:7'),
#   ('A:7/b7', 'G', 'N'),
#   ('C#:min', 'D/5', 'G#:min'),
#   ('B', 'B:7', 'F#:min'),
#   ('C:7', 'D', 'F:7'),
#   ('B:min', 'D', 'G:sus4/5'),
#   ('A:7', 'Bb:7', 'D'),
#   ('D:7', 'F:maj9(*7)', 'G:7'),
#   ('B:min', 'Bb:7', 'E:min'),
#   ('A', 'A:min', 'F:maj9(*7)'),
#   ('B:min', 'E:min', 'F:maj9(*7)'),
#   ('A', 'D', 'F:7'),
#   ('A:7/b7', 'F', 'G:min'),
#   ('F', 'G#:min', 'G:min'),
#   ('A:min', 'Bb:min', 'E:min'),
#   ('F', 'F:dim', 'G'),
#   ('A/3', 'G', 'G:sus4/5'),
#   ('Bb', 'G', 'N'),
#   ('A', 'D', 'F'),
#   ('A:9(11)', 'C', 'E:min'),
#   ('C#:min', 'F#:min', 'G:min/b3'),
#   ('D:7', 'F:maj9(*7)', 'G'),
#   ('D:min', 'G:min', 'G:min/b3'),
#   ('C', 'D/5', 'E:min'),
#   ('C#:min', 'D:9', 'G#:min'),
#   ('G', 'G:min/b3', 'G:sus4/5'),
#   ('A:sus4', 'D:7', 'G:7'),
#   ('A:7/b7', 'B:min', 'D'),
#   ('A:7/5', 'G', 'N'),
#   ('A:sus4', 'C:7', 'G'),
#   ('A', 'B:min', 'E:min/b3'),
#   ('A:sus4', 'G', 'G#'),
#   ('D', 'D/5', 'E'),
#   ('A:9(11)', 'B', 'F#:min'),
#   ('A', 'A:min', 'F:dim'),
#   ('B:min', 'E:min', 'F:dim'),
#   ('A:sus4', 'D:7', 'G'),
#   ('D:min', 'G/5', 'G:min'),
#   ('A:min', 'E:7', 'G'),
#   ('C:9', 'E:min', 'N'),
#   ('A:min', 'B:7', 'N'),
#   ('C#:min', 'G#:min', 'G:sus4(b7)'),
#   ('B:aug', 'C', 'E:min'),
#   ('A', 'E:min', 'G:7'),
#   ('C#:min', 'F#:min', 'F:maj9(*7)'),
#   ('A:7', 'A:min', 'C'),
#   ('C#:min', 'E:min7', 'F#:min'),
#   ('Bb:7', 'F', 'G:min'),
#   ('B:min', 'B:min/5', 'E:min'),
#   ('A', 'A:min', 'G#:min'),
#   ('B:min', 'E:min', 'G#:min'),
#   ('A:7', 'B', 'F#:min'),
#   ('C#:min', 'E:min/b3', 'G#:min'),
#   ('Db', 'G', 'G:sus4/5'),
#   ('A:sus4', 'C#:min', 'G#:min'),
#   ('B:aug', 'C:7', 'F:7'),
#   ('A:7', 'D', 'G:min/b3'),
#   ('B:7', 'G', 'G#'),
#   ('A', 'E:min/b3', 'G#'),
#   ('C', 'Eb:min', 'G'),
#   ('D', 'G:min', 'G:sus4(b7)'),
#   ('A:7', 'D', 'F#:(1,4,b7)'),
#   ('A:min', 'C', 'Db'),
#   ('D:7', 'E:maj6', 'G:7'),
#   ('E:min', 'G:sus4/5', 'N'),
#   ('D/5', 'G', 'G/5'),
#   ('A', 'G#', 'G:min/b3'),
#   ('C#:min', 'F#', 'F#:min'),
#   ('A:min', 'C', 'F#:min'),
#   ('A:7', 'B:min', 'G'),
#   ('C:7', 'E', 'F:7'),
#   ('B:7', 'E', 'F#:min'),
#   ('C:7', 'E:min7', 'G'),
#   ('A/3', 'C', 'F'),
#   ('D:7', 'E:maj6', 'G'),
#   ('B', 'Bb:min', 'F#:min'),
#   ('A:7', 'D', 'F:maj9(*7)'),
#   ('C', 'G/5', 'N'),
#   ('A', 'A:7/5', 'E:min'),
#   ('Bb:7', 'D:min', 'G:min'),
#   ('B:7', 'G', 'G/5'),
#   ('A:min', 'D:7', 'E:min'),
#   ('A/3', 'E', 'F#:min'),
#   ('B:min', 'D', 'D/5'),
#   ('A:7/b7', 'G', 'G/5'),
#   ('D:7', 'E:min/b3', 'G:7'),
#   ('A:7', 'D', 'F:dim'),
#   ('A:7', 'D', 'D:min'),
#   ('Bb:min', 'G', 'G#'),
#   ('A:7', 'C', 'G'),
#   ('D:min', 'G:min', 'G:sus4/5'),
#   ('Eb:min', 'G', 'G/5'),
#   ('Bb:min', 'D:7', 'G'),
#   ('D', 'G', 'G#:min'),
#   ('D:7', 'E:min/b3', 'G'),
#   ('A:9(11)', 'F', 'G'),
#   ('C', 'F', 'F:7'),
#   ('A:sus4', 'B', 'D'),
#   ('A/3', 'B', 'E'),
#   ('B', 'E', 'E:min/b3'),
#   ('Bb', 'G', 'G/5'),
#   ('A:7', 'D', 'G#:min'),
#   ('A:sus4', 'C', 'E:min'),
#   ('B', 'C:9', 'F#:min'),
#   ('B:7', 'C#:min', 'F#:min'),
#   ('C', 'G:sus4/5', 'N'),
#   ('Bb:min', 'C#:min', 'G#:min'),
#   ('A/3', 'B:min', 'E:min'),
#   ('A', 'A:sus4', 'E'),
#   ('C:7', 'G:7', 'G:min/b3'),
#   ('G', 'G#', 'G:min/b3'),
#   ('A:7', 'B:aug', 'D'),
#   ('A/3', 'E:min', 'N'),
#   ('A:7/5', 'G', 'G/5'),
#   ('C#:min', 'Db', 'F#:min'),
#   ('C#:min', 'G', 'G:sus4/5'),
#   ('B', 'B:aug', 'E:maj6'),
#   ('B:min/5', 'G', 'G#'),
#   ('B:min/5', 'D:7', 'G'),
#   ('C', 'E', 'E:min'),
#   ('A:sus4', 'G', 'G:sus4/5'),
#   ('Bb', 'D', 'G'),
#   ('A:min', 'C#:min', 'G'),
#   ('D/5', 'F', 'G'),
#   ('A/3', 'F', 'G:min'),
#   ('A:7', 'D', 'G:sus4/5'),
#   ('C#:min', 'D', 'F#:min'),
#   ('A', 'B', 'G/5'),
#   ('A/3', 'C:7', 'G:7'),
#   ('A', 'A/3', 'G#'),
#   ('A:7/b7', 'D', 'E'),
#   ('B:aug', 'E:min', 'G'),
#   ('B', 'D:7', 'F#:min'),
#   ('B:min/5', 'C#:min', 'G#:min'),
#   ('A', 'C:9', 'D'),
#   ('A', 'G#', 'G:sus4/5'),
#   ('C:7', 'Eb:min', 'F:7'),
#   ('F#:min', 'G', 'G:sus4/5'),
#   ('A', 'Bb:min', 'E'),
#   ('C', 'C#:min', 'F#:min'),
#   ('C#:min', 'D', 'G'),
#   ('F', 'F#:(1,4,b7)', 'G'),
#   ('C:7', 'Db', 'G'),
#   ('A', 'B:min', 'C'),
#   ('B:min', 'Bb:min', 'E:min'),
#   ('F', 'F:dim', 'G:min'),
#   ('Bb:7', 'C', 'N'),
#   ('E', 'F#:min', 'F#:min/5'),
#   ('A:7/b7', 'C:7', 'F:7'),
#   ('A', 'B:7', 'B:min'),
#   ('B', 'D', 'G:min/b3'),
#   ('B', 'C#:min', 'D:min'),
#   ('Db', 'F', 'G:min'),
#   ('B', 'D/5', 'E'),
#   ('G', 'G/5', 'G:min/b3'),
#   ('E:min', 'G', 'G:min/b3'),
#   ('F:dim', 'G', 'G#'),
#   ('A', 'D:min', 'E'),
#   ('D:7', 'Eb:min', 'G'),
#   ('Bb:7', 'D', 'E'),
#   ('A', 'B:min', 'F:maj9(*7)'),
#   ('E:maj6', 'E:min', 'G'),
#   ('C', 'D:9', 'N'),
#   ('A', 'Bb', 'E'),
#   ('B:min', 'D:min', 'G:min'),
#   ('B', 'D', 'F#:(1,4,b7)'),
#   ('A', 'Bb:7', 'N'),
#   ('A', 'E:min', 'G:min/b3'),
#   ('A:7/5', 'B', 'C#:min'),
#   ('B:7', 'D', 'G'),
#   ('A', 'A:9(11)', 'N'),
#   ('A:min', 'D:9', 'E:min'),
#   ('C', 'E:min', 'F#:min/5'),
#   ('E', 'Eb:min', 'F#:min'),
#   ('B', 'D', 'F:maj9(*7)'),
#   ('B', 'E:maj6', 'G#'),
#   ('A:sus4', 'C', 'F'),
#   ('A:7/5', 'F', 'G'),
#   ('A:7/5', 'C:7', 'F:7'),
#   ('A', 'B', 'D:min'),
#   ('A', 'B:min', 'F:dim'),
#   ('C:7', 'E:maj6', 'G:7'),
#   ('A', 'B:min', 'D:min'),
#   ('A:7', 'C:9', 'D'),
#   ('B:min', 'C:9', 'E:min'),
#   ('E:7', 'G', 'G#'),
#   ('Bb:min', 'G', 'G:sus4/5'),
#   ('B', 'B:min/5', 'E:maj6'),
#   ('A', 'E:min', 'F:maj9(*7)'),
#   ('C', 'E:min7', 'G'),
#   ('C:7', 'E:maj6', 'G'),
#   ('A:min', 'C', 'G/5'),
#   ('C:7', 'E', 'F#:min'),
#   ('D:min', 'E:7', 'G:min'),
#   ('D', 'F#', 'G:min'),
#   ('B', 'E:maj6', 'G:min/b3'),
#   ('A', 'B:min', 'G#:min'),
#   ('B', 'D', 'F:dim'),
#   ('E:min', 'F', 'G:min'),
#   ('A:min', 'E:min', 'G:min/b3'),
#   ('A', 'D:7', 'E'),
#   ('A', 'A:sus4', 'N'),
#   ('B', 'E:maj6', 'F#:(1,4,b7)'),
#   ('B', 'E:maj6', 'G:min'),
#   ('D/5', 'E:min', 'G'),
#   ('E:min/b3', 'G', 'G#'),
#   ('B:aug', 'D', 'G:min'),
#   ('B:7', 'F', 'G'),
#   ('Bb:min', 'D', 'G'),
#   ('B:min/5', 'G', 'G:sus4/5'),
#   ('A:min', 'E:min', 'F#:(1,4,b7)'),
#   ('B:min', 'D:7', 'E:min'),
#   ('E:7', 'G', 'G/5'),
#   ('A:min', 'F#:min/5', 'G'),
#   ('B', 'E:maj6', 'F:maj9(*7)'),
#   ('D:7', 'F:dim', 'G:7'),
#   ('B:min', 'Bb:7', 'G'),
#   ('A', 'F', 'N'),
#   ('A:sus4', 'B:min', 'E:min'),
#   ('A:min', 'E:min', 'F:maj9(*7)'),
#   ('A:min', 'Bb:min', 'G'),
#   ('E:maj6', 'G', 'G#'),
#   ('A:9(11)', 'C', 'G'),
#   ('C:7', 'D:min', 'F:7'),
#   ('B', 'B:7', 'E:maj6'),
#   ('C', 'F', 'F#:min'),
#   ('B', 'D:9', 'F#:min'),
#   ('B', 'D', 'G:sus4/5'),
#   ('A/3', 'C', 'N'),
#   ('C', 'D/5', 'G'),
#   ('A', 'E:min', 'Eb:min'),
#   ('A:7/b7', 'E:min', 'G'),
#   ('A:7', 'G', 'N'),
#   ('A:min', 'D/5', 'N'),
#   ('Bb:min', 'C', 'F'),
#   ('A', 'E:min', 'G:sus4/5'),
#   ('A:min', 'E:min', 'F:dim'),
#   ('B:min', 'B:min/5', 'G'),
#   ('F:dim', 'G', 'G:sus4/5'),
#   ('A:min', 'B', 'E:maj6'),
#   ('A:9(11)', 'B', 'E:maj6'),
#   ('Bb:min', 'E', 'F#:min'),
#   ('A:min', 'B:min/5', 'E:min'),
#   ('C#:min', 'Eb:min', 'F#:min'),
#   ('A:min', 'E:min', 'G#:min'),
#   ('B', 'E', 'F:dim'),
#   ('B:min/5', 'D', 'N'),
#   ('A:7/5', 'E:min', 'G'),
#   ('E:min', 'F:dim', 'N'),
#   ('A:sus4', 'B', 'F#:min'),
#   ('B', 'B:min', 'E:maj6'),
#   ('D:min', 'G#:min', 'G:min'),
#   ('F#:min/5', 'G', 'G:sus4/5'),
#   ('B:min/5', 'C', 'F'),
#   ('C:9', 'G', 'N'),
#   ('B', 'E:maj6', 'G:sus4/5'),
#   ('A', 'E', 'F#:min/5'),
#   ('D', 'F:maj9(*7)', 'G'),
#   ('B:min', 'G', 'G#:min'),
#   ('B:min/5', 'E', 'F#:min'),
#   ('A:min', 'D:7', 'G:7'),
#   ('C:7', 'Eb:min', 'G'),
#   ('C', 'D:min', 'E:min'),
#   ('D', 'E', 'G#'),
#   ('Bb:min', 'E:min', 'N'),
#   ('D:7', 'E:min7', 'G'),
#   ('B', 'B:min/5', 'D'),
#   ('D', 'F:dim', 'N'),
#   ('B', 'Bb:min', 'E:maj6'),
#   ('A', 'Bb:min', 'G#'),
#   ('F', 'F#:min', 'G'),
#   ('E', 'F#:min', 'G:7'),
#   ('D', 'G:min/b3', 'N'),
#   ('A:7/b7', 'D:7', 'G'),
#   ('A:9(11)', 'A:min', 'N'),
#   ('E:min/b3', 'G', 'G:sus4/5'),
#   ('B:7', 'C#:min', 'G#:min'),
#   ('B:7', 'D', 'G:min'),
#   ('A', 'C:7', 'D'),
#   ('E', 'F#:min', 'G'),
#   ('A:min', 'B:aug', 'N'),
#   ('C', 'G#:min', 'N'),
#   ('B:7', 'B:min', 'G'),
#   ('A', 'G:min/b3', 'N'),
#   ('C#:min', 'Db', 'G#:min'),
#   ('F', 'G:min', 'G:sus4(b7)'),
#   ('A:9(11)', 'G', 'G/5'),
#   ('B:min/5', 'E:min', 'N'),
#   ('A:7/b7', 'C#:min', 'G#:min'),
#   ('A:7/b7', 'D', 'G:min'),
#   ('A:min', 'E:7', 'E:min'),
#   ('A:sus4', 'C', 'G'),
#   ('E:maj6', 'G', 'G:sus4/5'),
#   ('C#:min', 'D', 'G#:min'),
#   ('A', 'A:9(11)', 'B'),
#   ('A', 'D', 'D:min'),
#   ('A/3', 'B:min', 'G'),
#   ('D:7', 'F#:min/5', 'G:7'),
#   ('B:min/5', 'F', 'G:min'),
#   ('A', 'A:9(11)', 'B:min'),
#   ('Bb:7', 'D:7', 'G:7'),
#   ('B', 'C#:min', 'F#:min/5'),
#   ('B:min/5', 'C:7', 'G:7'),
#   ('A:7', 'G', 'G/5'),
#   ('A:7/5', 'D:7', 'G'),
#   ('C#:min', 'F', 'G'),
#   ('Bb:7', 'G', 'G#'),
#   ('C:7', 'F', 'G:7'),
#   ('B', 'C:9', 'E:maj6'),
#   ('C', 'E', 'G'),
#   ('D:7', 'G:7', 'G:min/b3'),
#   ('B', 'Bb:7', 'C#:min'),
#   ('A', 'C:7', 'F:7'),
#   ('A', 'C:9', 'N'),
#   ('C:7', 'G', 'G#:min'),
#   ('A:9(11)', 'C#:min', 'F#:min'),
#   ('C#:min', 'D:min', 'F#:min'),
#   ('D:7', 'F#:(1,4,b7)', 'G:7'),
#   ('A', 'A:min', 'G:7'),
#   ('D:7', 'G:7', 'G:min'),
#   ('B:min', 'E:min', 'G:7'),
#   ('A', 'B', 'F#:min/5'),
#   ('A:7', 'C:7', 'D'),
#   ('A:min', 'Bb:min', 'C'),
#   ('B', 'F', 'G:min'),
#   ('Bb:7', 'G', 'G/5'),
#   ('D:7', 'F#:(1,4,b7)', 'G'),
#   ('A:min', 'B', 'D'),
#   ('C:9', 'G', 'G/5'),
#   ('B:min', 'Bb:min', 'G'),
#   ('D:7', 'Db', 'G:7'),
#   ('D', 'E', 'G:sus4(b7)'),
#   ('A', 'D:7', 'G#'),
#   ('G', 'G:min/b3', 'N'),
#   ('C#:min', 'E:maj6', 'G#:min'),
#   ('A', 'G:7', 'N'),
#   ('F:maj9(*7)', 'G', 'G/5'),
#   ('D:7', 'Db', 'G'),
#   ('D:9', 'E', 'F#:min'),
#   ('D', 'E', 'E:7'),
#   ('E', 'E:min', 'G'),
#   ('D', 'F:7', 'N'),
#   ('A', 'A:min', 'C:9'),
#   ('C#:min', 'F#:min', 'G:7'),
#   ('A:7', 'B', 'C#:min'),
#   ('A/3', 'B', 'E:maj6'),
#   ('A', 'A:7/5', 'A:min'),
#   ('A', 'B:min/5', 'E'),
#   ('Bb:min', 'C', 'G'),
#   ('A', 'F:7', 'N'),
#   ('D', 'D:min', 'N'),
#   ('A:min', 'F:dim', 'G'),
#   ('D', 'F#:min', 'G'),
#   ('D', 'E', 'F#'),
#   ('A', 'A:7/5', 'G#'),
#   ('A:7', 'C:7', 'F:7'),
#   ('C', 'G', 'G#:min'),
#   ('B:min', 'C:9', 'G'),
#   ('C', 'C:7', 'F'),
#   ('A:min', 'G:7', 'N'),
#   ('C:9', 'D', 'E'),
#   ('B', 'Bb:min', 'D'),
#   ('A:7/b7', 'A:min', 'G'),
#   ('Bb:7', 'C', 'E:min'),
#   ('B', 'F#:min', 'G/5'),
#   ('D', 'E', 'E:maj6'),
#   ('D', 'E:7', 'G'),
#   ('A:min', 'F:dim', 'N'),
#   ('Bb', 'C#:min', 'F#:min'),
#   ('D:7', 'G:7', 'G:sus4/5'),
#   ('B:min', 'D:7', 'G:7'),
#   ('E:min', 'F#:min/5', 'G'),
#   ('A:min', 'C', 'F#:min/5'),
#   ('D:7', 'E', 'F#:min'),
#   ('D:min', 'E:min/b3', 'G:min'),
#   ('A', 'B:7', 'E'),
# ...
#   ('D:7', 'F:maj9(*7)', 'G:min'),
#   ('G', 'D:min', 'A:9(11)'),
#   ('E:min', 'E:min/b3', 'C#:min'),
#   ('E', 'F:7', 'G:min/b3'),
#   ('N', 'G:min', 'G#'),
#   ('C', 'Db', 'A:9(11)'),
#   ('G:7', 'G#', 'D:min'),
#   ('B', 'F:dim', 'D/5'),
#   ('G/5', 'B:7', 'C:9'),
#   ('N', 'B', 'B:aug'),
#   ('G:min', 'E:maj6', 'C:9'),
#   ('E', 'A:7/5', 'F#'),
#   ('B:min', 'Eb:min', 'E:min7'),
#   ('G#', 'E:maj6', 'B:min/5'),
#   ('F#:min', 'D/5', 'B:min/5'),
#   ('G/5', 'F:7', 'A:7/b7'),
#   ('G#:min', 'Bb:7', 'F#:(1,4,b7)'),
#   ('G#:min', 'A:9(11)', 'D/5'),
#   ('G#:min', 'A:sus4', 'A:min'),
#   ('D:7', 'C#:min', 'Bb:7'),
#   ('C', 'E:maj6', 'F#'),
#   ('E:min7', 'F:7', 'C:9'),
#   ('G', 'F:maj9(*7)', 'Db'),
#   ('E:maj6', 'A:min', 'F:7'),
#   ('F', 'E', 'A:min'),
#   ('G#:min', 'D:min', 'A:7/5'),
#   ('F:dim', 'D:min', 'F#'),
#   ('B', 'A:7', 'F#:min/5'),
#   ('G:sus4/5', 'A:min', 'C:9'),
#   ('D', 'G#', 'F#:min/5'),
#   ('D', 'F#:min', 'Bb'),
#   ('B:aug', 'A:9(11)', 'G:min/b3'),
#   ('E:min/b3', 'E:min7', 'E:7'),
#   ('D', 'G:min', 'Bb'),
#   ('G:7', 'D:9', 'Bb'),
#   ('C', 'Eb:min', 'Bb:min'),
#   ('D', 'E:min7', 'D:9'),
#   ('G#:min', 'A:sus4', 'F#:(1,4,b7)'),
#   ('G/5', 'B', 'G#:min'),
#   ('G/5', 'E:maj6', 'D/5'),
#   ('C', 'F#:min/5', 'A/3'),
#   ('F:maj9(*7)', 'Db', 'C:7'),
#   ('E:min7', 'A:7', 'D:min'),
#   ('E:maj6', 'C:7', 'G:min/b3'),
#   ('C', 'B:min', 'Bb:min'),
#   ('B:aug', 'A:9(11)', 'C:7'),
#   ('E:min', 'F:maj9(*7)', 'F#'),
#   ('B', 'E:maj6', 'C:7'),
#   ('F#:min', 'A:7/b7', 'E:7'),
#   ('E:min7', 'F:dim', 'C:7'),
#   ('D:7', 'Eb:min', 'A:7/b7'),
#   ('E:min', 'D:7', 'B:aug'),
#   ('F', 'E', 'F#:(1,4,b7)'),
#   ('D:7', 'G:min', 'F:7'),
#   ('D', 'Bb', 'A:min'),
#   ('B:min', 'C#:min', 'Bb:7'),
#   ('A', 'A/3', 'B:min/5'),
#   ('F:maj9(*7)', 'B:7', 'F:dim'),
#   ('E', 'Bb:7', 'D/5'),
#   ('D:7', 'E:min/b3', 'G:min'),
#   ('E:min7', 'G#', 'E:maj6'),
#   ('A', 'G#:min', 'C:9'),
#   ('G:7', 'Bb', 'F#'),
#   ('G:7', 'E:min7', 'G:min'),
#   ('G', 'Db', 'F#'),
#   ('Bb:min', 'Bb:7', 'D/5'),
#   ('C', 'G/5', 'B:min/5'),
#   ('D:9', 'Bb:7', 'C:9'),
#   ('G:sus4/5', 'G:7', 'A'),
#   ('Eb:min', 'Bb', 'B:min/5'),
#   ('D', 'B:7', 'F:7'),
#   ('F#:min', 'A:sus4', 'C:7'),
#   ('D:7', 'F:dim', 'C:9'),
#   ('F', 'B:min', 'E:min7'),
#   ('A', 'F#:min', 'A:7'),
#   ('G:sus4/5', 'F:7', 'A:7/5'),
#   ('G:sus4(b7)', 'Bb:min', 'E:maj6'),
#   ('B:min', 'A', 'F:7'),
#   ('E:min', 'G/5', 'A:9(11)'),
#   ('G', 'E:min/b3', 'Db'),
#   ('D:7', 'E:maj6', 'E:7'),
#   ('E:min7', 'G:min', 'F#'),
#   ('G', 'B', 'A'),
#   ('C', 'Bb:min', 'A:sus4'),
#   ('G:sus4/5', 'B', 'A'),
#   ('Eb:min', 'A', 'F#:min'),
#   ('B', 'A:sus4', 'A:7/b7'),
#   ('G:sus4/5', 'G#:min', 'A:7/5'),
#   ('D', 'Bb', 'F#:(1,4,b7)'),
#   ('B', 'E:min7', 'C#:min'),
#   ('E:min7', 'G:min/b3', 'E:7'),
#   ('G:sus4/5', 'E:min/b3', 'F#:min/5'),
#   ('B:min', 'D:7', 'A:7'),
#   ('D:7', 'A', 'D:9'),
#   ('C#:min', 'A:min', 'D/5'),
#   ('E:min', 'A:7', 'B:aug'),
#   ('A:7', 'A/3', 'F#'),
#   ('C#:min', 'G#', 'Bb:7'),
#   ('Eb:min', 'E:min7', 'C#:min'),
#   ('D:9', 'A:sus4', 'C:9'),
#   ('D:7', 'G:7', 'A:7/5'),
#   ('F:maj9(*7)', 'D:min', 'A/3'),
#   ('A:min', 'F#:min/5', 'A:7/5'),
#   ('Eb:min', 'E', 'G#:min'),
#   ('N', 'A:min', 'F#'),
#   ('C', 'F:maj9(*7)', 'F:7'),
#   ('Db', 'F#:min', 'F#'),
#   ('N', 'B:aug', 'Bb:7'),
#   ('D:7', 'E', 'F:7'),
#   ('E:min', 'A:7', 'G#'),
#   ('C', 'D/5', 'A:7/5'),
#   ('B:min', 'A:min', 'G:min/b3'),
#   ('F:maj9(*7)', 'G#', 'D/5'),
#   ('E', 'B:aug', 'A:9(11)'),
#   ('N', 'F:maj9(*7)', 'E'),
#   ('G:sus4(b7)', 'Bb', 'A/3'),
#   ('B:7', 'E:maj6', 'A:min'),
#   ('C', 'D:9', 'D:min'),
#   ('E:min7', 'G#', 'A:sus4'),
#   ('N', 'Db', 'A:min'),
#   ('F', 'F:maj9(*7)', 'C:9'),
#   ('D:7', 'G:sus4/5', 'C:7'),
#   ('G:sus4/5', 'D:min', 'G:min/b3'),
#   ('B', 'G#', 'F#:min/5'),
#   ('G:sus4(b7)', 'Bb:min', 'A:sus4'),
#   ('F#:min', 'D:9', 'G#:min'),
#   ('N', 'G:sus4(b7)', 'F:7'),
#   ('G/5', 'B:aug', 'A:7/b7'),
#   ('G/5', 'B', 'Bb'),
#   ('G', 'C#:min', 'E:7'),
#   ('N', 'E:maj6', 'A:7/5'),
#   ('A', 'Bb:7', 'B:min/5'),
#   ('N', 'Bb:min', 'E:min7'),
#   ('F:maj9(*7)', 'F#:min/5', 'A:7/5'),
#   ('D:7', 'Eb:min', 'G#:min'),
#   ('N', 'F:maj9(*7)', 'A/3'),
#   ('B:7', 'E:maj6', 'F#:(1,4,b7)'),
#   ('E:maj6', 'D:min', 'C:9'),
#   ('G/5', 'B:7', 'F#'),
#   ('N', 'Db', 'F#:(1,4,b7)'),
#   ('D', 'A:9(11)', 'A:7/5'),
#   ('G:min', 'E:maj6', 'F#'),
#   ('D', 'C:9', 'F#:(1,4,b7)'),
#   ('N', 'G:sus4(b7)', 'D:7'),
#   ('B:7', 'Db', 'A:7'),
#   ('C', 'A', 'F#:min/5'),
#   ('F:maj9(*7)', 'Eb:min', 'F#:min'),
#   ('D:7', 'E:min7', 'A:7/5'),
#   ('F:7', 'E:7', 'F#'),
#   ('G', 'F:maj9(*7)', 'F:dim'),
#   ('B:aug', 'D:min', 'A:sus4'),
#   ('E:min7', 'F:7', 'F#'),
#   ('G:7', 'Bb:7', 'E:7'),
#   ('D:7', 'F:dim', 'G:min'),
#   ('G', 'Bb:min', 'G:min/b3'),
#   ('B:aug', 'F#:min/5', 'A/3'),
#   ('E:min/b3', 'A', 'G#:min'),
#   ('C', 'E:min/b3', 'F:7'),
#   ('G:7', 'G#:min', 'A:min'),
#   ('G:7', 'B:7', 'F#:min/5'),
#   ('B', 'B:7', 'F:7'),
#   ('B:min', 'Db', 'E:min7'),
#   ('A', 'A:sus4', 'B:min/5'),
#   ('C', 'A/3', 'A:7/5'),
#   ('G', 'G:7', 'F#:min'),
#   ('B:7', 'G#', 'C:7'),
#   ('E:maj6', 'Bb', 'E:7'),
#   ('A:7', 'Bb:7', 'F#'),
#   ('F:maj9(*7)', 'F#:min', 'D:9'),
#   ('Bb:min', 'G:min', 'A:7/b7'),
#   ('G:sus4/5', 'A:min', 'F#'),
#   ('N', 'E:min/b3', 'E'),
#   ('D', 'D:7', 'C:7'),
#   ('G:min', 'F#:min/5', 'A/3'),
#   ('B', 'E', 'Bb'),
#   ('N', 'D', 'B'),
#   ('E:maj6', 'G#:min', 'A:7/b7'),
#   ('N', 'B:7', 'B:min/5'),
#   ('E:min', 'G#', 'B:aug'),
#   ('C', 'E', 'A:7/5'),
#   ('N', 'F', 'G:7'),
#   ('G/5', 'E:min7', 'A:min'),
#   ('Eb:min', 'E', 'Bb'),
#   ('B:7', 'A:7', 'A:7/b7'),
#   ('G:7', 'G#:min', 'F#:(1,4,b7)'),
#   ('G/5', 'A:9(11)', 'F:7'),
#   ('Bb:7', 'F:7', 'A/3'),
#   ('D:min', 'Bb:7', 'F:7'),
#   ('Bb:min', 'F:dim', 'A:7/5'),
#   ('G:sus4(b7)', 'D:9', 'E:maj6'),
#   ('F:maj9(*7)', 'G:7', 'Db'),
#   ('G:sus4/5', 'G:7', 'G#'),
#   ('G:sus4/5', 'B:aug', 'A:7/5'),
#   ('G', 'E:maj6', 'D:min'),
#   ('G/5', 'Bb:7', 'A:9(11)'),
#   ('Bb:7', 'A:9(11)', 'B:min/5'),
#   ('C', 'Db', 'Bb:min'),
#   ('A', 'F:dim', 'A:7/b7'),
#   ('A:7', 'A:sus4', 'F#'),
#   ('N', 'B:min', 'Eb:min'),
#   ('B:7', 'G#:min', 'D:min'),
#   ('C', 'D:9', 'A:sus4'),
#   ('B:7', 'E', 'F#:min/5'),
#   ('N', 'E:min/b3', 'A/3'),
#   ('Bb:min', 'A:sus4', 'D/5'),
#   ('A', 'G#:min', 'F#'),
#   ('Bb:7', 'A:7/5', 'A:7/b7'),
#   ('G', 'B', 'G#'),
#   ('B', 'F:7', 'E:7'),
#   ('B:min', 'G:min', 'F:7'),
#   ('G:sus4/5', 'B', 'G#'),
#   ('D:9', 'Bb:7', 'F#'),
#   ('D:7', 'Db', 'A:7/b7'),
#   ('N', 'E:min/b3', 'G:7'),
#   ('F:maj9(*7)', 'C:7', 'F:7'),
#   ('G:sus4(b7)', 'G#', 'A:9(11)'),
#   ('G:sus4(b7)', 'A/3', 'A:7/5'),
#   ('G:7', 'G#', 'E'),
#   ('G:7', 'E', 'E:7'),
#   ('D:7', 'F:dim', 'F#'),
#   ('G:sus4(b7)', 'Eb:min', 'C#:min'),
#   ('F#:min', 'F#:min/5', 'F#'),
#   ('F:maj9(*7)', 'B', 'F#:min/5'),
#   ('D:min', 'F#:min/5', 'A:7/5'),
#   ('G/5', 'E:min7', 'F#:(1,4,b7)'),
#   ('A/3', 'E:7', 'F#:(1,4,b7)'),
#   ('N', 'A', 'C:7'),
#   ('D:7', 'F#:min', 'D:9'),
#   ('F', 'D', 'G:min'),
#   ('F:7', 'C:9', 'F#'),
#   ('G', 'G:sus4/5', 'A:min'),
#   ('N', 'E:min', 'D:min'),
#   ('N', 'G:7', 'A:9(11)'),
#   ('B:min', 'E:min7', 'E:maj6'),
#   ('A', 'D:9', 'A:min'),
#   ('B:min', 'F:dim', 'C:9'),
#   ('E:min', 'C#:min', 'G:min/b3'),
#   ('D:7', 'G#:min', 'F#:min/5'),
#   ('G/5', 'A:sus4', 'A:9(11)'),
#   ('G', 'E:min7', 'F#:min'),
#   ('A:9(11)', 'A:7/5', 'F#:(1,4,b7)'),
#   ('B:min', 'E:min', 'A:min'),
#   ('D', 'G:sus4/5', 'B'),
#   ('D', 'G:min/b3', 'F#'),
#   ('G:sus4/5', 'E:min7', 'B:aug'),
#   ('G:7', 'Eb:min', 'C:7'),
#   ('G:sus4(b7)', 'G', 'B:min/5'),
#   ('C', 'E:min7', 'D/5'),
#   ('N', 'B', 'A:9(11)'),
#   ('Db', 'A:9(11)', 'C:7'),
#   ('F#:min', 'C:7', 'B:min/5'),
#   ('D:9', 'A:sus4', 'F#'),
#   ('G', 'D:min', 'B:min/5'),
#   ('C', 'Bb', 'Bb:7'),
#   ('B:7', 'F:dim', 'C#:min'),
#   ('F:dim', 'Bb:7', 'A:7/b7'),
#   ('C', 'Db', 'B:min/5'),
#   ('D', 'G/5', 'B:aug'),
#   ('G:sus4(b7)', 'C', 'C#:min'),
#   ('G:sus4(b7)', 'Db', 'Bb:min'),
#   ('Eb:min', 'Db', 'E'),
#   ('N', 'G:sus4(b7)', 'E:min/b3'),
#   ('G:sus4/5', 'A:9(11)', 'C:9'),
#   ('G:sus4(b7)', 'D:9', 'A:sus4'),
#   ('G', 'G:sus4/5', 'F#:(1,4,b7)'),
#   ('D', 'E:maj6', 'Bb'),
#   ('B:min', 'A:7', 'B:aug'),
#   ('Eb:min', 'G:min', 'E:7'),
#   ('Bb:min', 'F:7', 'A:7/b7'),
#   ('E:min/b3', 'A', 'Bb'),
#   ('G:sus4/5', 'E:min7', 'G#'),
#   ('G', 'D', 'E:min'),
#   ('G:sus4(b7)', 'G:sus4/5', 'C:9'),
#   ('D:7', 'C:7', 'F:7'),
#   ('Db', 'F:dim', 'Bb'),
#   ('F#:min', 'A/3', 'E:7'),
#   ('Bb:min', 'G:min', 'G#:min'),
#   ('F:maj9(*7)', 'B:7', 'A'),
#   ('D', 'G/5', 'G#'),
#   ('B', 'C:7', 'F#:(1,4,b7)'),
#   ('A:9(11)', 'A/3', 'A:7/b7'),
#   ('F', 'Eb:min', 'A:7/b7'),
#   ('C', 'F#:min/5', 'D/5'),
#   ('F', 'G:min', 'F:7'),
#   ('F:maj9(*7)', 'D:min', 'Bb:7'),
#   ('G', 'D:7', 'G:sus4/5'),
#   ('F:maj9(*7)', 'A:min', 'A:7/b7'),
#   ('G:sus4(b7)', 'B:min', 'D:9'),
#   ('E:min/b3', 'F:7', 'B:min/5'),
#   ('D:9', 'A:7', 'G#'),
#   ('F:dim', 'A:sus4', 'A:7/b7'),
#   ('Eb:min', 'Db', 'A/3'),
#   ('G:sus4(b7)', 'G:min', 'Bb:7'),
#   ('E:min', 'G/5', 'Bb:min'),
#   ('E:min', 'G:sus4/5', 'F#:min'),
#   ('F', 'E:min', 'Bb'),
#   ('D', 'C:7', 'F#:(1,4,b7)'),
#   ('Eb:min', 'Bb:min', 'C:9'),
#   ('B:min', 'E:min7', 'A:sus4'),
#   ('B:7', 'A:7', 'G#:min'),
#   ('N', 'Eb:min', 'D:min'),
#   ('G', 'D:9', 'G:min/b3'),
#   ('F', 'F:dim', 'C:9'),
#   ('B:min', 'Bb:min', 'F:dim'),
#   ('G:7', 'G:min/b3', 'B:min/5'),
#   ('B:min', 'G:sus4/5', 'A:7/b7'),
#   ('A', 'E', 'A:min'),
#   ('E:min', 'D:7', 'A:9(11)'),
#   ('C', 'F#:min', 'F#:min/5'),
#   ('C', 'Bb:7', 'F#:min/5'),
#   ('E', 'A:min', 'F#:min/5'),
#   ('G:sus4(b7)', 'Bb', 'Bb:7'),
#   ('B', 'Bb:7', 'C:9'),
#   ('G:sus4(b7)', 'Bb:7', 'A:7/5'),
#   ('E:maj6', 'D:min', 'F#'),
#   ('D:7', 'D/5', 'A/3'),
#   ('F', 'E:maj6', 'E:7'),
#   ('E:min/b3', 'F:dim', 'B:aug'),
#   ('Bb:min', 'A:min', 'F#:min/5'),
#   ('G:sus4/5', 'F#', 'F#:(1,4,b7)'),
#   ('F:maj9(*7)', 'F:dim', 'A:min'),
#   ('F#:min', 'A:7', 'E'),
#   ('B', 'C#:min', 'A:7/5'),
#   ('Db', 'Bb:min', 'D:min'),
#   ('N', 'F:dim', 'A/3'),
#   ('D:9', 'B:aug', 'F:7'),
#   ('N', 'F:7', 'G:min/b3'),
#   ('N', 'G/5', 'F#:min/5'),
#   ('G/5', 'D/5', 'B:min/5'),
#   ('F', 'A:7', 'B:aug'),
#   ('A:7', 'D:min', 'A:sus4'),
#   ('A:7', 'A:9(11)', 'C:7'),
#   ('N', 'C', 'D:min'),
#   ('G:sus4(b7)', 'F#:min/5', 'D/5'),
#   ('N', 'F:maj9(*7)', 'Bb:7'),
#   ('F:dim', 'G#', 'F#:min/5'),
#   ('F:maj9(*7)', 'Db', 'F#:min'),
#   ('C', 'G#:min', 'A:sus4'),
#   ('C', 'A:sus4', 'F#:min/5'),
#   ('G:sus4(b7)', 'A:sus4', 'A:7/5'),
#   ('E:min', 'G/5', 'B:min/5'),
#   ('F:maj9(*7)', 'D:min', 'D/5'),
#   ('N', 'G', 'F#:min/5'),
#   ('G:sus4(b7)', 'G', 'Bb'),
#   ('Db', 'E:maj6', 'F#'),
#   ('F:maj9(*7)', 'B', 'Db'),
#   ('F', 'G:min/b3', 'F#:(1,4,b7)'),
#   ('F#:min', 'A:7', 'A/3'),
#   ('F:maj9(*7)', 'F:dim', 'F#:(1,4,b7)'),
#   ('E:min', 'A:7', 'A:9(11)'),
#   ('E:min', 'Bb', 'A/3'),
#   ('B:aug', 'B:min/5', 'A:7/b7'),
#   ('N', 'F', 'B'),
#   ('F:dim', 'C:7', 'B:min/5'),
#   ('E:min7', 'A:sus4', 'E:7'),
#   ('Eb:min', 'F:7', 'E:7'),
#   ('G:sus4(b7)', 'F', 'A:7/5'),
#   ('Eb:min', 'E:maj6', 'B:aug'),
#   ('F:dim', 'D/5', 'F#:(1,4,b7)'),
#   ('G:sus4(b7)', 'C#:min', 'Bb'),
#   ('Eb:min', 'A/3', 'C:9'),
#   ('A', 'F#:min', 'E:7'),
#   ('G:sus4/5', 'E:min/b3', 'F:dim'),
#   ('C', 'B:7', 'E:min7'),
#   ('D', 'F:maj9(*7)', 'C#:min'),
#   ('G:sus4(b7)', 'Bb', 'D/5'),
#   ('G:7', 'A', 'C#:min'),
#   ('F#:min', 'G#:min', 'A:min'),
#   ('C', 'C:7', 'A:7/5'),
#   ('G:min', 'Bb:7', 'F:7'),
#   ('G', 'B:7', 'Bb'),
#   ('G:min', 'B:min/5', 'A:7/b7'),
#   ('G/5', 'Db', 'E:maj6'),
#   ('B:min', 'G#', 'B:aug'),
#   ('D:9', 'D:min', 'A:sus4'),
#   ('B:min', 'D:7', 'E:7'),
#   ('N', 'F#:min', 'C:7'),
#   ('G/5', 'F:7', 'C:9'),
#   ('E', 'A:9(11)', 'A:7/5'),
#   ('D:min', 'F:7', 'F#:min/5'),
#   ('G/5', 'G:sus4/5', 'A:7/5'),
#   ('F', 'Eb:min', 'G#:min'),
#   ('A:9(11)', 'A:min', 'F#:min/5'),
#   ('E', 'B:aug', 'B:min/5'),
#   ('G:sus4/5', 'A:sus4', 'A/3'),
#   ('B:7', 'C:7', 'F#:min/5'),
#   ('D', 'B', 'F:7'),
#   ('G/5', 'A/3', 'B:min/5'),
#   ('G:min', 'D:9', 'D:min'),
#   ('G#', 'D:min', 'C:7'),
#   ('N', 'F:maj9(*7)', 'D/5'),
#   ('E:min', 'D/5', 'A:7/5'),
#   ('G:7', 'A:7', 'D/5'),
#   ('G:sus4/5', 'B:7', 'G#:min'),
#   ('D', 'A:min', 'C:7'),
#   ('F:dim', 'E', 'Bb'),
#   ('C', 'D:7', 'A:min'),
#   ('B:min', 'F:dim', 'F#'),
#   ('F#:min', 'G#:min', 'F#:(1,4,b7)'),
#   ('F', 'E:min7', 'A:7/5'),
#   ('D', 'G:7', 'D:min'),
#   ('B:min', 'G:sus4/5', 'G#:min'),
#   ('G/5', 'F#:min', 'A:7'),
#   ('B', 'Db', 'D/5'),
#   ('Bb:min', 'F#:min/5', 'F#:(1,4,b7)'),
#   ('B:min', 'G#:min', 'F#:min/5'),
#   ('G', 'A:7/5', 'F#'),
#   ('G', 'G#:min', 'A:9(11)'),
#   ('G:7', 'B:aug', 'A:min'),
#   ('G:sus4(b7)', 'B:7', 'E:min7'),
#   ('G/5', 'A:7', 'D:min'),
#   ('E:min/b3', 'F#:min', 'Bb'),
#   ('G/5', 'B', 'G:min'),
#   ('G#', 'B:aug', 'A:sus4'),
#   ('G:sus4(b7)', 'A:9(11)', 'E:7'),
#   ('G/5', 'F:dim', 'C:7'),
#   ('F:maj9(*7)', 'B:7', 'G#'),
#   ('G:sus4/5', 'A:9(11)', 'F#'),
#   ('D:7', 'G:sus4/5', 'F#:min'),
#   ('F#:min', 'G#', 'E'),
#   ('B:min', 'D:min', 'C:7'),
#   ('E:min/b3', 'E:min7', 'D:9'),
#   ('D:7', 'Eb:min', 'C:9'),
#   ('G:min', 'Bb', 'A:7/5'),
#   ('C', 'A:7', 'Bb'),
#   ('G', 'Eb:min', 'F#:min/5'),
#   ('F:maj9(*7)', 'B:aug', 'F#:min/5'),
#   ('G', 'D:7', 'F:7'),
#   ('D', 'E:min/b3', 'C#:min'),
#   ('C', 'A', 'F:dim'),
#   ('B:aug', 'Bb:7', 'F#:min/5'),
#   ('G/5', 'Db', 'A:sus4'),
#   ('G:sus4(b7)', 'G:sus4/5', 'F#'),
#   ('N', 'D:7', 'F#:min/5'),
#   ('E:min/b3', 'D:min', 'F:7'),
#   ('D:9', 'C#:min', 'C:7'),
#   ('F', 'G#', 'B:aug'),
#   ('G:7', 'B:7', 'F:dim'),
#   ('D:7', 'G/5', 'C#:min'),
#   ('G:7', 'B:aug', 'F#:(1,4,b7)'),
#   ('E:min/b3', 'Bb', 'A:min'),
#   ('B:7', 'Db', 'E:7'),
#   ('D:7', 'F:maj9(*7)', 'Eb:min'),
#   ('F#:min', 'G#', 'A/3'),
#   ('N', 'G:7', 'Bb:min'),
#   ('E:min', 'G#', 'A:9(11)'),
#   ('A:7', 'F#:min/5', 'A/3'),
#   ('D', 'Db', 'B:aug'),
#   ('Eb:min', 'Bb:min', 'F#'),
#   ('F', 'Db', 'A:7/b7'),
#   ('Db', 'D:9', 'D:min'),
#   ('B:7', 'B:aug', 'D:min'),
#   ('F', 'F:dim', 'F#'),
#   ('N', 'E:min/b3', 'D/5'),
#   ('G', 'C', 'F#:min/5'),
#   ('E', 'F:7', 'E:7'),
#   ('B', 'A:sus4', 'C:9'),
#   ('F:maj9(*7)', 'E:min/b3', 'Eb:min'),
#   ('Bb:min', 'E:min7', 'A:min'),
#   ('D', 'E:min7', 'D:min'),
#   ('G/5', 'F:maj9(*7)', 'G#:min'),
#   ('N', 'B:min', 'Db'),
#   ('Eb:min', 'D:9', 'C#:min'),
#   ('B:min', 'G/5', 'Bb:min'),
#   ('N', 'B', 'Bb:min'),
#   ('G', 'F#:min', 'D/5'),
#   ('G', 'A:7', 'F:7'),
#   ('F', 'G#:min', 'F#:min/5'),
#   ('G:sus4/5', 'Bb:7', 'D/5'),
#   ('A:9(11)', 'C:7', 'A:7/b7'),
#   ('G/5', 'Bb:7', 'B:min/5'),
#   ('E:min/b3', 'Bb', 'F#:(1,4,b7)'),
#   ('B', 'G:7', 'F:7'),
#   ('N', 'G:sus4/5', 'F:7'),
#   ('E', 'G#:min', 'E:7'),
#   ('Db', 'G:min', 'A:7/5'),
#   ('Eb:min', 'Db', 'Bb:7'),
#   ('D:7', 'B:aug', 'F#:min/5'),
#   ('G:7', 'D:min', 'A/3'),
#   ('Bb:min', 'G#:min', 'E:7'),
#   ('G:sus4(b7)', 'A:7', 'A:min'),
#   ('Bb', 'F:7', 'A:7/5'),
#   ('G:sus4(b7)', 'G#', 'B:min/5'),
#   ('Db', 'Bb', 'A:7/5'),
#   ('B:aug', 'C:7', 'A:7/5'),
#   ('Db', 'A', 'F#:min/5'),
#   ('Bb:min', 'E:min7', 'F#:(1,4,b7)'),
#   ('G:7', 'G#', 'D/5'),
#   ('F:maj9(*7)', 'A', 'E:maj6'),
#   ('Eb:min', 'C#:min', 'F#:min/5'),
#   ('F:maj9(*7)', 'B', 'F:dim'),
#   ('G#:min', 'D:min', 'C:7'),
#   ('N', 'G:7', 'B:min/5'),
#   ('N', 'E:min', 'G:7'),
#   ('N', 'A:7/5', 'F#:(1,4,b7)'),
#   ('G:sus4/5', 'E:min7', 'A:9(11)'),
#   ('G', 'F:maj9(*7)', 'B:aug'),
#   ('E:min/b3', 'C#:min', 'E:maj6'),
#   ('G/5', 'A:sus4', 'B:min/5'),
#   ('G:7', 'F#:min', 'C#:min'),
#   ('N', 'F:dim', 'Bb:7'),
#   ('C', 'A:min', 'F#:(1,4,b7)'),
#   ('G/5', 'B:aug', 'C:9'),
#   ('G', 'D', 'B:aug'),
#   ('D', 'G/5', 'A:9(11)'),
#   ('G/5', 'G#', 'D:min'),
#   ('D:7', 'E:min/b3', 'Eb:min'),
#   ('D:7', 'A', 'D:min'),
#   ('F:maj9(*7)', 'G#:min', 'A/3'),
#   ('G:sus4(b7)', 'A:7', 'F#:(1,4,b7)'),
#   ('G/5', 'C#:min', 'E'),
#   ('B:min', 'A:7', 'A:9(11)'),
#   ('D:7', 'Eb:min', 'G:min'),
#   ('B:min', 'Bb:min', 'A'),
#   ('F:maj9(*7)', 'G:min', 'E:maj6'),
#   ('F:maj9(*7)', 'A:9(11)', 'A:7/b7'),
#   ('N', 'A', 'F#:min'),
#   ('G', 'F:maj9(*7)', 'G#'),
#   ('F:dim', 'C#:min', 'A:7/5'),
#   ('Bb:min', 'C#:min', 'F:7'),
#   ('G:min/b3', 'F#', 'F#:(1,4,b7)'),
#   ('N', 'Eb:min', 'E'),
#   ('C', 'G#', 'Bb'),
#   ('F#:min', 'A:7', 'Bb:7'),
#   ('F', 'G/5', 'Bb:min'),
#   ...},
#  '300': {('A', 'A:min', 'E:min'),
#   ('A', 'A:min', 'N'),
#   ('A', 'B', 'D'),
#   ('A', 'B', 'E'),
#   ('A', 'B:min', 'D'),
#   ('A', 'B:min', 'E:min'),
#   ('A', 'D', 'E'),
#   ('A', 'D', 'N'),
#   ('A', 'E:min', 'N'),
#   ('A:min', 'C', 'E:min'),
#   ('A:min', 'C', 'G'),
#   ('A:min', 'C', 'N'),
#   ('A:min', 'E:min', 'G'),
#   ('A:min', 'E:min', 'N'),
#   ('A:min', 'G', 'N'),
#   ('B', 'C#:min', 'F#:min'),
#   ('B', 'D', 'E'),
#   ('B', 'E', 'F#:min'),
#   ('B:min', 'D', 'G'),
#   ('B:min', 'E:min', 'G'),
#   ('C', 'E:min', 'G'),
#   ('C', 'E:min', 'N'),
#   ('C', 'F', 'G'),
#   ('C', 'G', 'N'),
#   ('D', 'G', 'N'),
#   ('E:min', 'G', 'N')}}
