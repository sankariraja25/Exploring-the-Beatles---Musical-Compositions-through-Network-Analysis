# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
album05 = pd.read_csv('album_05_edges.csv')
G = nx.from_pandas_edgelist(album05, source="Source", target="Target", create_using=nx.DiGraph())
nx.draw(G, with_labels=True)

# %% [markdown]
# ## Visuals

# %%
nx.draw(G,node_size=300,font_size=8,  with_labels=True)

# %%
plt.figure(3,figsize=(12,12)) 
nx.draw(G, node_size=400,font_size=12,  with_labels=True)

# %% [markdown]
# ## Triads

# %%
# Triad Consensus
nx.triadic_census(G)
# Out:
# {'003': 27222,
#  '012': 4860,
#  '021C': 243,
#  '021D': 100,
#  '021U': 87,
#  '030C': 11,
#  '030T': 12,
#  '102': 1229,
#  '111D': 160,
#  '111U': 164,
#  '120C': 21,
#  '120D': 5,
#  '120U': 10,
#  '201': 58,
#  '210': 21,
#  '300': 17}

# %%
import networkx as nx
import itertools


def _tricode(G, v, u, w):
    """Returns the integer code of the given triad.

    This is some fancy magic that comes from Batagelj and Mrvar's paper. It
    treats each edge joining a pair of `v`, `u`, and `w` as a bit in
    the binary representation of an integer.

    """
    combos = ((v, u, 1), (u, v, 2), (v, w, 4), (w, v, 8), (u, w, 16),
              (w, u, 32))
    return sum(x for u, v, x in combos if v in G[u])


# G = nx.DiGraph()
# G.add_nodes_from([1, 2, 3, 4, 5])
# G.add_edges_from([(1, 2), (2, 3), (2, 4), (4, 5)])

#: The integer codes representing each type of triad.
#: Triads that are the same up to symmetry have the same code.
TRICODES = (1, 2, 2, 3, 2, 4, 6, 8, 2, 6, 5, 7, 3, 8, 7, 11, 2, 6, 4, 8, 5, 9,
            9, 13, 6, 10, 9, 14, 7, 14, 12, 15, 2, 5, 6, 7, 6, 9, 10, 14, 4, 9,
            9, 12, 8, 13, 14, 15, 3, 7, 8, 11, 7, 12, 14, 15, 8, 14, 13, 15,
            11, 15, 15, 16)

#: The names of each type of triad. The order of the elements is
#: important: it corresponds to the tricodes given in :data:`TRICODES`.
TRIAD_NAMES = ('003', '012', '102', '021D', '021U', '021C', '111D', '111U',
               '030T', '030C', '201', '120D', '120U', '120C', '210', '300')

#: A dictionary mapping triad code to triad name.
TRICODE_TO_NAME = {i: TRIAD_NAMES[code - 1] for i, code in enumerate(TRICODES)}

triad_nodes = {name: set([]) for name in TRIAD_NAMES}
m = {v: i for i, v in enumerate(G)}
for v in G:
    vnbrs = set(G.pred[v]) | set(G.succ[v])
    for u in vnbrs:
        if m[u] > m[v]:
            unbrs = set(G.pred[u]) | set(G.succ[u])
            neighbors = (vnbrs | unbrs) - {u, v}
            not_neighbors = set(G.nodes()) - neighbors - {u, v}
            # Find dyadic triads
            for w in not_neighbors:
                if v in G[u] and u in G[v]:
                    triad_nodes['102'].add(tuple(sorted([u, v, w])))
                else:
                    triad_nodes['012'].add(tuple(sorted([u, v, w])))
            for w in neighbors:
                if m[u] < m[w] or (m[v] < m[w] < m[u] and
                                   v not in G.pred[w] and
                                   v not in G.succ[w]):
                    code = _tricode(G, v, u, w)
                    triad_nodes[TRICODE_TO_NAME[code]].add(
                        tuple(sorted([u, v, w])))
# find null triads
all_tuples = set()
for s in triad_nodes.values():
    all_tuples = all_tuples.union(s)
new = triad_nodes['003'] = set(itertools.combinations(G.nodes(), 3)).difference(all_tuples)

triad_nodes
# Out:
# {'003': {('F#:min9', 'E:min/5', 'F:7'),
#   ('G:(7)', 'E:min', 'Bb/7'),
#   ('F#:min', 'F:7', 'C:maj6'),
#   ('A:maj6', 'A:min7', 'G:maj6/5'),
#   ('A:maj6', 'A:min/b3', 'E:min7(4)'),
#   ('D', 'C', 'A:sus2'),
#   ('A:sus4', 'G:maj7', 'A:min7'),
#   ('A:sus4', 'F#:min9', 'Bb/5'),
#   ('A:7', 'A:min7', 'D:min7'),
#   ('D', 'A:7', 'B:(1)'),
#   ('D:sus4', 'D:min/b7', 'Bb:maj'),
#   ('B:(6)', 'Bb:maj7', 'A:min/b3'),
#   ('N', 'A:sus2', 'D:min/b7'),
#   ('D', 'A:min7', 'Bb:maj'),
#   ('D/b7', 'F#:min9', 'Bb'),
#   ('Bb', 'G:7', 'G/3'),
#   ('A:min/b3', 'D:min7', 'F/5'),
#   ('G#', 'G:aug', 'Bb/7'),
#   ('G:maj7', 'E:min', 'F:maj(*3)'),
#   ('C#:min', 'A:min', 'F/7'),
#   ('D', 'D:sus4', 'C:maj7'),
#   ('F', 'E:min7(4)', 'F:7'),
#   ('A', 'G:7', 'F/7'),
#   ('D', 'D:sus4', 'B:(1)'),
#   ('D:7(#9)', 'G:maj6/5', 'D:min/b7'),
#   ('D:7(#9)', 'B:min7', 'Bb/7'),
#   ('A:maj6', 'A:sus2', 'C:maj6'),
#   ('D/6', 'A:sus4/5', 'Bb:maj'),
#   ('G:maj7', 'G:maj6/5', 'Bb:maj7'),
#   ('A:7', 'G:(7)', 'A:min/b3'),
#   ('E', 'B', 'C:maj6'),
#   ('E', 'D:7(#9)', 'G:7'),
#   ('A:sus4/5', 'Bb/7', 'F:7'),
#   ('D', 'C', 'F/7'),
#   ('B:(6)', 'G:aug', 'Bb:maj'),
#   ('E', 'A', 'F#:min9'),
#   ('D', 'G:(6)', 'E:min7(4)'),
#   ('D', 'A:7', 'C:maj6'),
#   ('B:min', 'D', 'Bb:maj'),
#   ('N', 'B:(1)', 'Bb/7'),
#   ('F#:min', 'D:7', 'Bb:maj'),
#   ('D/6', 'F#:min9', 'G:(7)'),
#   ('E:min/5', 'A:min/b3', 'F/5'),
#   ('A:7', 'D/5', 'B:(1)'),
#   ('G:(1)', 'E:min', 'C:7'),
#   ('G', 'G#', 'G:(7)'),
#   ('G:maj7', 'F:maj(*3)', 'A:min/b3'),
#   ('B:min', 'C#:min', 'G:(1)'),
#   ('D/5', 'B:(6)', 'G:aug'),
#   ('G:maj7', 'E/5', 'Bb/7'),
#   ('B:min7', 'D:min/b7', 'F:7'),
#   ('A', 'D:7(#9)', 'Bb:maj'),
#   ('A:maj6', 'D/5', 'G:(6)'),
#   ('C#:min', 'A:7', 'G:7'),
#   ('E:min/5', 'G:maj6/5', 'A:sus4/5'),
#   ('A', 'F:maj(*3)', 'C:7'),
#   ('C#:min', 'D', 'C'),
#   ('A:maj6', 'D/5', 'B:(6)'),
#   ('G:aug', 'G:7', 'G/3'),
#   ('B:min7', 'E:min', 'Bb:maj7/5'),
#   ('A', 'G:aug', 'E:min7(4)'),
#   ('D:sus4', 'B:min7', 'F/7'),
#   ('B', 'G:maj7', 'D:min'),
#   ('G:maj6/5', 'F/7', 'F:7'),
#   ('F', 'B:(1)', 'A:min7'),
#   ('A:min', 'D:7(#9)', 'B:min7'),
#   ('F#:min', 'B:(1)', 'E:min'),
#   ('A:7', 'B', 'D:7(#9)'),
#   ('E', 'A:7', 'F/7'),
#   ('F#:min', 'G:aug', 'C:maj7'),
#   ('F', 'A:min', 'C:7'),
#   ('E', 'G:min', 'G:(7)'),
#   ('A:min', 'D:sus4', 'A:min/b3'),
#   ('D/6', 'B', 'D:7(#9)'),
#   ('F#:min', 'G:aug', 'D:7(#9)'),
#   ('B:(1)', 'B:min7', 'Bb/5'),
#   ('F', 'A:sus2', 'C:7'),
#   ('C', 'A:min7', 'C:maj6'),
#   ('A:sus4', 'E/5', 'Bb/7'),
#   ('G:aug', 'E:min7(4)', 'F:7'),
#   ('B:(1)', 'B:min7', 'A:sus4/5'),
#   ('B:min', 'C#:min', 'C:maj7'),
#   ('G', 'D:7(#9)', 'E:min7(4)'),
#   ('A:sus2', 'B', 'Bb'),
#   ('C#:min', 'D/5', 'G:(1)'),
#   ('F#:min', 'B:(6)', 'C:maj7'),
#   ('D/6', 'D:maj(2)', 'A:min7'),
#   ('F#:min', 'A:sus4', 'G:(1)'),
#   ('B:(1)', 'G#', 'G/3'),
#   ('G', 'A', 'F#:min'),
#   ('A:sus4', 'B', 'E/5'),
#   ('Bb/7', 'F:7', 'Bb:maj7/5'),
#   ('B:min', 'A:sus2', 'G:(7)'),
#   ('B', 'B:(1)', 'E:min7(4)'),
#   ('D:7', 'Bb', 'C:maj7'),
#   ('B:min7', 'A:min/b3', 'Bb/5'),
#   ('D/6', 'G:(1)', 'C:maj6'),
#   ('D:7', 'A:min7', 'C:maj7'),
#   ('C#:min', 'G:maj7', 'Bb:maj7'),
#   ('G#', 'G:(1)', 'Bb:maj'),
#   ('D/5', 'D:sus4', 'E:min/5'),
#   ('E', 'F#:min9', 'G/3'),
#   ('B', 'D:min', 'E:min7(4)'),
#   ('D/6', 'Bb:maj7', 'F/5'),
#   ('E', 'A:7', 'A:sus2'),
#   ('C', 'B:(6)', 'C:7'),
#   ('F', 'A:sus2', 'Bb:maj7'),
#   ('B', 'A:min7', 'E:min7(4)'),
#   ('E', 'D/6', 'E:min/5'),
#   ('F#:min', 'D', 'F/5'),
#   ('F#:min', 'B:min7', 'A:min7'),
#   ('F', 'D/b7', 'F:maj(*3)'),
#   ('F#:min', 'B', 'Bb/5'),
#   ('A:min', 'B', 'Bb/5'),
#   ('C', 'E/5', 'F:7'),
#   ('D/5', 'B:(6)', 'B:(1)'),
#   ('D:sus4', 'F/7', 'G/3'),
#   ('E', 'F', 'D/6'),
#   ('E', 'C', 'A:sus4'),
#   ('C', 'F#:min9', 'E:min7(4)'),
#   ('D:maj(2)', 'G:aug', 'D:min7'),
#   ('D', 'D/6', 'G#'),
#   ('B:(1)', 'G#', 'Bb:maj'),
#   ('B:min7', 'C:maj6', 'F/5'),
#   ('N', 'F#:min', 'C'),
#   ('N', 'D/5', 'E:min/5'),
#   ('F#:min9', 'A:min7', 'Bb:maj7/5'),
#   ('C#:min', 'G:min', 'G:7'),
#   ('D/b7', 'Bb:maj7', 'F/5'),
#   ('D:sus4', 'G:maj7', 'E:min/5'),
#   ('B', 'B:(1)', 'C:maj7'),
#   ('N', 'G:(6)', 'Bb:maj7/5'),
#   ('D:maj(2)', 'E:min/5', 'D:7(#9)'),
#   ('C:maj7', 'F:maj(*3)', 'F/5'),
#   ('Bb', 'G:maj6/5', 'D:min/b7'),
#   ('B:(6)', 'E:min', 'G/3'),
#   ('B:(1)', 'E:min', 'Bb/7'),
#   ('D:sus4', 'G:7', 'Bb:maj7'),
#   ('C:7', 'A:sus4/5', 'F:7'),
#   ('F#:min', 'A:min', 'D:min7'),
#   ('B:min', 'A:maj6', 'D:7(#9)'),
#   ('A:7', 'G:aug', 'E:min7(4)'),
#   ('D/6', 'D/5', 'G:maj6/5'),
#   ('G#', 'D:min7', 'Bb/7'),
#   ('N', 'G:min', 'E:min'),
#   ('G:maj7', 'C:maj7', 'E:min7(4)'),
#   ('B:(1)', 'A:sus4/5', 'E:min7(4)'),
#   ('G#', 'G:maj7', 'Bb'),
#   ('C', 'C:7', 'A:sus4/5'),
#   ('N', 'B:(6)', 'F:7'),
#   ('D', 'G:7', 'A:min/b3'),
#   ('D/6', 'C:7', 'Bb/5'),
#   ('C', 'C:maj7', 'F/5'),
#   ('F#:min', 'A:7', 'B:(1)'),
#   ('F', 'D:maj(2)', 'D:min7'),
#   ('D/6', 'G:aug', 'E:min'),
#   ('C#:min', 'D:7(#9)', 'A:min7'),
#   ('F#:min9', 'A:min7', 'Bb/7'),
#   ('F#:min9', 'G:aug', 'E:min7(4)'),
#   ('E', 'B', 'D:min/b7'),
#   ('F', 'A:min7', 'A:sus4/5'),
#   ('F:maj(*3)', 'D:min/b7', 'F:7'),
#   ('C:maj7', 'A:sus4/5', 'D:min7'),
#   ('A:7', 'B:(6)', 'Bb'),
#   ('F#:min', 'F#:min9', 'D:min'),
#   ('A', 'D', 'A:sus4'),
#   ('B:min', 'A:maj6', 'G:aug'),
#   ('G:min', 'E:min7(4)', 'Bb/7'),
#   ('F#:min9', 'F:maj(*3)', 'E:min7(4)'),
#   ('F#:min', 'E:min', 'F:7'),
#   ('F#:min', 'D:min', 'Bb:maj7'),
#   ('A:sus4', 'F:maj(*3)', 'Bb:maj'),
#   ('G:(6)', 'G:7', 'Bb:maj7'),
#   ('B:min', 'D/b7', 'A:min/b3'),
#   ('N', 'D', 'D/5'),
#   ('N', 'G:(1)', 'D:min'),
#   ('B:(6)', 'Bb:maj7', 'F:7'),
#   ('F#:min', 'E/5', 'A:min/b3'),
#   ('A:sus2', 'G:(7)', 'F:7'),
#   ('D', 'B', 'A:min7'),
#   ('G:maj7', 'E/5', 'F:7'),
#   ('G:(7)', 'G:aug', 'E:min7(4)'),
#   ('A:sus4', 'A:sus4/5', 'Bb:maj7/5'),
#   ('D/5', 'C:maj7', 'G/3'),
#   ('D:maj(2)', 'A:sus2', 'D:min/b7'),
#   ('D/5', 'Bb:maj7', 'A:min/b3'),
#   ('E', 'E/5', 'C:7'),
#   ('G:(6)', 'A:min7', 'D:min'),
#   ('G:min', 'A:min', 'Bb:maj'),
#   ('A:sus2', 'B:(6)', 'G:(6)'),
#   ('G', 'D/6', 'A:sus4'),
#   ('E', 'A:sus4', 'A:min/b3'),
#   ('E', 'A:min', 'D/b7'),
#   ('A:sus4', 'B:(1)', 'G:maj7'),
#   ('F#:min9', 'G:aug', 'Bb/5'),
#   ('E:min', 'F:7', 'F/5'),
#   ('B', 'G:7', 'E/5'),
#   ('B:min', 'E:min/5', 'E:min'),
#   ('A', 'Bb/5', 'C:maj6'),
#   ('A:min', 'A:sus2', 'D:min'),
#   ('N', 'F#:min9', 'G:(7)'),
#   ('B:(1)', 'Bb', 'A:sus4/5'),
#   ('F#:min', 'G:min', 'Bb/7'),
#   ('E:min/5', 'D:min7', 'Bb/7'),
#   ('B:min', 'C#:min', 'C'),
#   ('G', 'D:sus4', 'G:(1)'),
#   ('A:maj6', 'D:7(#9)', 'F:maj(*3)'),
#   ('C#:min', 'G:(1)', 'Bb/5'),
#   ('A:maj6', 'A:7', 'Bb:maj7'),
#   ('F#:min', 'C', 'A:min7'),
#   ('C#:min', 'C:7', 'G/3'),
#   ('D:sus4', 'B:min7', 'Bb:maj7/5'),
#   ('A', 'D/5', 'A:sus4'),
#   ('D', 'G:(7)', 'E:min/5'),
#   ('E:min', 'D:min', 'C:7'),
#   ('C:maj7', 'D:min', 'Bb:maj7'),
#   ('B:min7', 'E:min', 'F/7'),
#   ('N', 'G#', 'Bb:maj7'),
#   ('C#:min', 'A:maj6', 'G#'),
#   ('G:min', 'Bb', 'G:maj6/5'),
#   ('D:sus4', 'Bb:maj7', 'D:min7'),
#   ('D/b7', 'B:(1)', 'Bb:maj7'),
#   ('G:maj7', 'G:(1)', 'C:7'),
#   ('N', 'G:(7)', 'G:(6)'),
#   ('F#:min', 'C', 'B'),
#   ('G:7', 'E:min', 'C:7'),
#   ('F#:min', 'B:(1)', 'Bb:maj7'),
#   ('N', 'A:maj6', 'D/6'),
#   ('E:min/5', 'D:min7', 'C:maj6'),
#   ('D/b7', 'G:7', 'G/3'),
#   ('G:(6)', 'D:7(#9)', 'F:7'),
#   ('A:7', 'G:(1)', 'D:min'),
#   ('D', 'A:7', 'D:sus4'),
#   ('E', 'A:min/b3', 'Bb/5'),
#   ('E/5', 'C:7', 'Bb/5'),
#   ('B:(1)', 'C:maj7', 'Bb:maj7/5'),
#   ('N', 'B:(6)', 'F#:min9'),
#   ('G', 'G:aug', 'Bb:maj'),
#   ('B', 'F/7', 'F/5'),
#   ('G', 'D:sus4', 'G:7'),
#   ('D:sus4', 'F#:min9', 'C:maj7'),
#   ('F#:min', 'D:sus4', 'G:7'),
#   ('G:maj6/5', 'Bb:maj', 'E:min7(4)'),
#   ('Bb:maj', 'D:min7', 'C:maj6'),
#   ('B:min', 'A', 'E:min'),
#   ('G', 'G:maj7', 'Bb/7'),
#   ('A:maj6', 'D:7', 'A:min7'),
#   ('G', 'D/b7', 'G:(6)'),
#   ('F', 'D/b7', 'G:(7)'),
#   ('F:maj(*3)', 'C:7', 'Bb:maj'),
#   ('E:min/5', 'D:min7', 'Bb:maj7/5'),
#   ('A', 'B:min7', 'Bb:maj7'),
#   ('D/6', 'D:min/b7', 'Bb:maj7/5'),
#   ('B:min', 'F#:min', 'Bb'),
#   ('D/6', 'C:maj7', 'G:maj6/5'),
#   ('A:sus2', 'A:sus4', 'A:min/b3'),
#   ('A:7', 'D/5', 'Bb:maj7'),
#   ('F#:min', 'B:(6)', 'Bb:maj7/5'),
#   ('F#:min9', 'B:min7', 'G:maj6/5'),
#   ('B:min7', 'D:min', 'Bb:maj7'),
#   ('A:maj6', 'D:min/b7', 'Bb/5'),
#   ('E', 'E:min/5', 'Bb/7'),
#   ('B:min', 'D:sus4', 'E:min'),
#   ('B:min', 'F#:min9', 'G:7'),
#   ('F#:min9', 'Bb', 'D:min7'),
#   ('G', 'G:maj7', 'A:min7'),
#   ('D', 'G:min', 'D:7(#9)'),
#   ('C:7', 'A:sus4/5', 'Bb/7'),
#   ('A:min', 'E:min/5', 'E:min7(4)'),
#   ('A:maj6', 'A:min', 'Bb:maj7'),
#   ('D/5', 'G:(7)', 'Bb:maj7'),
#   ('A:7', 'F#:min9', 'Bb/5'),
#   ('A:7', 'D:sus4', 'Bb:maj7'),
#   ('A:min', 'E:min', 'Bb:maj'),
#   ('N', 'G:7', 'C:maj6'),
#   ('N', 'Bb', 'Bb/7'),
#   ('B:min', 'F#:min', 'Bb:maj7'),
#   ('F#:min', 'C:maj7', 'Bb:maj7'),
#   ('N', 'D/5', 'C:maj6'),
#   ('D/6', 'Bb', 'D:min'),
#   ('A:min7', 'G:maj6/5', 'A:min/b3'),
#   ('D:sus4', 'A:sus2', 'F/7'),
#   ('G:aug', 'E/5', 'E:min7(4)'),
#   ('G:min', 'D/b7', 'D:sus4'),
#   ('A:min7', 'E:min', 'E/5'),
#   ('D:min/b7', 'A:sus4/5', 'A:min/b3'),
#   ('D:min', 'Bb:maj7', 'C:maj6'),
#   ('A:maj6', 'D:7', 'Bb'),
#   ('A:sus2', 'C:maj7', 'C:7'),
#   ('D', 'A:min7', 'F:maj(*3)'),
#   ('G:min', 'G:(1)', 'C:7'),
#   ('N', 'D:maj(2)', 'G:maj6/5'),
#   ('B', 'E:min7(4)', 'F/5'),
#   ('A', 'C:maj7', 'C:maj6'),
#   ('D:7', 'G:(6)', 'Bb:maj7'),
#   ('F:7', 'F/5', 'G/3'),
#   ('G', 'G:(7)', 'A:min7'),
#   ('D:sus4', 'G:(6)', 'F:maj(*3)'),
#   ('B:min', 'D/5', 'Bb/7'),
#   ('G:(7)', 'G:7', 'F:7'),
#   ('N', 'F', 'A:sus2'),
#   ('C', 'F/7', 'A:min/b3'),
#   ('G:(6)', 'Bb/5', 'D:min7'),
#   ('A:min7', 'C:7', 'Bb:maj7/5'),
#   ('A:sus2', 'A:min7', 'Bb:maj'),
#   ('A:maj6', 'D/b7', 'D:min/b7'),
#   ('N', 'D:min/b7', 'F/7'),
#   ('B', 'D:7', 'Bb:maj7'),
#   ('A', 'D', 'A:7'),
#   ('B', 'D:7', 'C:maj7'),
#   ('G', 'E:min/5', 'Bb'),
#   ('A:sus4', 'G:maj7', 'G:7'),
#   ('G', 'C#:min', 'D/6'),
#   ('A:maj6', 'F', 'Bb'),
#   ('B:min', 'G:(7)', 'Bb'),
#   ('E', 'B:(6)', 'C:7'),
#   ('A:min7', 'C:7', 'C:maj6'),
#   ('B:min', 'G:(1)', 'E/5'),
#   ('G:aug', 'C:maj7', 'F:7'),
#   ('D/b7', 'A:sus4/5', 'D:min7'),
#   ('G', 'D:7(#9)', 'D:min7'),
#   ('N', 'E:min/5', 'Bb:maj'),
#   ('B:(1)', 'D:min/b7', 'D:min7'),
#   ('G', 'F#:min', 'G:maj6/5'),
#   ('B:(6)', 'E:min/5', 'B:min7'),
#   ('A', 'G:(1)', 'F:7'),
#   ('B:(6)', 'Bb', 'D:min'),
#   ('G:(1)', 'A:min/b3', 'Bb/7'),
#   ('D:maj(2)', 'D:7(#9)', 'E:min7(4)'),
#   ('A', 'E/5', 'D:min/b7'),
#   ('B:(6)', 'D:min', 'Bb:maj'),
#   ('B:min', 'G:(7)', 'Bb:maj'),
#   ('A:7', 'D:maj(2)', 'F/7'),
#   ('F', 'D/6', 'B'),
#   ('G', 'C:maj6', 'G/3'),
#   ('B:min', 'A:maj6', 'A:min7'),
#   ('A:maj6', 'D:7(#9)', 'Bb/5'),
#   ('A:min', 'D:7', 'F/7'),
#   ('N', 'A:7', 'D:7'),
#   ('A:maj6', 'D:sus4', 'G:7'),
#   ('E', 'C#:min', 'D:min7'),
#   ('G:maj7', 'D:7', 'D:min7'),
#   ('C#:min', 'E/5', 'A:min/b3'),
#   ('A:min7', 'D:min', 'C:maj6'),
#   ('A:sus4', 'B:(6)', 'Bb/5'),
#   ('E', 'Bb:maj7', 'F:7'),
#   ('G:min', 'Bb:maj7', 'Bb:maj'),
#   ('C:maj7', 'D:min', 'Bb:maj7/5'),
#   ('G:min', 'D:7', 'G/3'),
#   ('B:min7', 'A:min7', 'Bb:maj'),
#   ('E', 'A:7', 'F/5'),
#   ('D:7', 'E:min', 'D:min'),
#   ('D', 'E:min', 'E/5'),
#   ('F', 'G:(7)', 'F:7'),
#   ('A:sus2', 'G#', 'D:7'),
#   ('E', 'G:min', 'F#:min9'),
#   ('C', 'D/b7', 'E:min'),
#   ('G:aug', 'E:min', 'A:min/b3'),
#   ('A:min', 'Bb:maj', 'Bb/7'),
#   ('G:(6)', 'C:7', 'A:min/b3'),
#   ('D/b7', 'C:maj6', 'G/3'),
#   ('D:7(#9)', 'Bb/7', 'F:7'),
#   ('G', 'A:min', 'A:sus4/5'),
#   ('G', 'C#:min', 'B:min7'),
#   ('E', 'D:min', 'C:maj6'),
#   ('A', 'C:7', 'D:min7'),
#   ('B', 'E:min/5', 'Bb/5'),
#   ('G:maj7', 'G:maj6/5', 'F/5'),
#   ('A:min7', 'D:min/b7', 'A:sus4/5'),
#   ('B:min', 'D/5', 'G:(6)'),
#   ('G:(7)', 'E:min', 'D:min'),
#   ('G', 'D:sus4', 'E:min7(4)'),
#   ('B:min7', 'Bb:maj7', 'A:min/b3'),
#   ('C#:min', 'Bb:maj7', 'Bb/7'),
#   ('B:(1)', 'G:(6)', 'F:maj(*3)'),
#   ('G', 'G:maj7', 'G:maj6/5'),
#   ('F', 'A:7', 'F/5'),
#   ('E', 'D:7(#9)', 'E/5'),
#   ('A:min', 'D/b7', 'E:min7(4)'),
#   ('D/6', 'D:7(#9)', 'B:min7'),
#   ('C', 'A:min', 'F:maj(*3)'),
#   ('C#:min', 'A:maj6', 'C:7'),
#   ('N', 'E', 'D:sus4'),
#   ('D/5', 'G:(1)', 'C:7'),
#   ('D:maj(2)', 'D:min', 'Bb/5'),
#   ('E', 'Bb', 'C:maj7'),
#   ('D/6', 'A:sus4', 'Bb:maj7'),
#   ('D:maj(2)', 'G:(6)', 'B:min7'),
#   ('B:min', 'G:(7)', 'B:min7'),
#   ('A:sus2', 'G#', 'E:min7(4)'),
#   ('G:maj7', 'G:(6)', 'E:min'),
#   ('D:maj(2)', 'G:(7)', 'E/5'),
#   ('A:maj6', 'F#:min9', 'D:7(#9)'),
#   ('G', 'E', 'F'),
#   ('D', 'G:(6)', 'D:min'),
#   ('F#:min', 'B:min7', 'Bb:maj7/5'),
#   ('C', 'D:min/b7', 'A:sus4/5'),
#   ('G#', 'E/5', 'C:7'),
#   ('G', 'E:min/5', 'G:7'),
#   ('E:min', 'E/5', 'A:sus4/5'),
#   ('B:min', 'G:aug', 'G:7'),
#   ('G:(1)', 'G:aug', 'G:7'),
#   ('A:7', 'D/b7', 'D:7(#9)'),
#   ('C', 'G:(6)', 'E:min7(4)'),
#   ('B:(6)', 'G#', 'B:min7'),
#   ('C#:min', 'A:sus2', 'D:min/b7'),
#   ('B:(1)', 'F:maj(*3)', 'C:maj6'),
#   ('D/b7', 'G:maj6/5', 'A:sus4/5'),
#   ('F#:min9', 'G:(6)', 'Bb/7'),
#   ('N', 'C', 'A:min'),
#   ('A', 'C:maj7', 'Bb/7'),
#   ('A:min', 'G:aug', 'G:maj6/5'),
#   ('D/5', 'B:(6)', 'F/7'),
#   ('A', 'D:maj(2)', 'G#'),
#   ('A:min', 'Bb/7', 'F:7'),
#   ('F#:min', 'G:min', 'C:maj7'),
#   ('D:sus4', 'A:sus4', 'G:(1)'),
#   ('G#', 'G:aug', 'G/3'),
#   ('E', 'G:min', 'D:min7'),
#   ('G:aug', 'C:maj6', 'F/5'),
#   ('D', 'D:7', 'A:sus4/5'),
#   ('B:(6)', 'D:min/b7', 'F/5'),
#   ('G', 'A:sus4', 'B:(6)'),
#   ('B:(6)', 'D:min/b7', 'A:min/b3'),
#   ('B:min7', 'E:min', 'G:maj6/5'),
#   ('N', 'D/6', 'E:min7(4)'),
#   ('F#:min', 'Bb:maj', 'Bb:maj7/5'),
#   ('B:(6)', 'F#:min9', 'B:min7'),
#   ('A', 'E:min/5', 'D:min/b7'),
#   ('A:sus4', 'G:(6)', 'C:maj7'),
#   ('B:min', 'G:(7)', 'E:min/5'),
#   ('C#:min', 'C', 'G:min'),
#   ('C:maj7', 'E:min', 'Bb:maj7/5'),
#   ('A:sus4', 'B:(1)', 'D:min/b7'),
#   ('E', 'C#:min', 'F#:min9'),
#   ('B:min', 'D:maj(2)', 'D:min7'),
#   ('N', 'D', 'A:maj6'),
#   ('B:(1)', 'Bb:maj', 'G/3'),
#   ('D', 'G:aug', 'B:min7'),
#   ('A', 'G:(1)', 'Bb/7'),
#   ('G:(1)', 'A:min/b3', 'F:7'),
#   ('B:min', 'G#', 'G:aug'),
#   ('D/6', 'C:maj7', 'Bb:maj7/5'),
#   ('A:maj6', 'C', 'A:sus4/5'),
#   ('B:(1)', 'G:(6)', 'Bb:maj7'),
#   ('D/b7', 'B', 'E:min/5'),
#   ('N', 'D:7(#9)', 'Bb:maj7'),
#   ('G:min', 'A:min', 'C:maj6'),
#   ('D:maj(2)', 'B', 'Bb:maj'),
#   ('A', 'F#:min9', 'D:min'),
#   ('G', 'G:maj7', 'D:7(#9)'),
#   ('D', 'G:min', 'A:min7'),
#   ('D', 'G:min', 'C:maj6'),
#   ('B', 'G:(1)', 'F/5'),
#   ('F#:min', 'D/b7', 'B:(6)'),
#   ('N', 'D:sus4', 'D:7'),
#   ('D:sus4', 'G#', 'F:7'),
#   ('F#:min9', 'G:(1)', 'D:min'),
#   ('N', 'G', 'D/5'),
#   ('A:maj6', 'C', 'A:sus2'),
#   ('D/b7', 'C:maj7', 'F:maj(*3)'),
#   ('D', 'A:maj6', 'C:7'),
#   ('G:(7)', 'D:7(#9)', 'E:min7(4)'),
#   ('B:(1)', 'C:maj7', 'D:min/b7'),
#   ('D:sus4', 'B', 'C:maj6'),
#   ('F#:min', 'B:(1)', 'C:7'),
#   ('D/5', 'F#:min9', 'A:min/b3'),
#   ('B:(6)', 'F:maj(*3)', 'C:maj6'),
#   ('B:min', 'E:min/5', 'D:7(#9)'),
#   ('C:maj7', 'E:min', 'Bb/7'),
#   ('A', 'B:(1)', 'C:maj6'),
#   ('A:min', 'D:7', 'D:7(#9)'),
#   ('C', 'C:7', 'Bb:maj'),
#   ('E', 'G:7', 'D:min'),
#   ('D/5', 'B:(1)', 'A:min/b3'),
#   ('C#:min', 'C:maj7', 'A:min/b3'),
#   ('D', 'G:(7)', 'D:min/b7'),
#   ('C#:min', 'G:(7)', 'Bb/7'),
#   ('A:sus2', 'G:aug', 'Bb/5'),
#   ('A:sus2', 'F#:min9', 'G:(1)'),
#   ('G', 'G:(6)', 'E:min'),
#   ('G:min', 'B', 'E:min'),
#   ('F#:min', 'A:maj6', 'A:sus2'),
#   ('D:sus4', 'D:7', 'D:min/b7'),
#   ('G', 'B:(6)', 'B:(1)'),
#   ('A:7', 'D/5', 'C:7'),
#   ('E', 'F#:min', 'E:min/5'),
#   ('A:maj6', 'E:min/5', 'G:maj6/5'),
#   ('B:min', 'G:min', 'B:min7'),
#   ('F', 'A:sus2', 'D:7(#9)'),
#   ('D:7(#9)', 'Bb:maj7', 'Bb/5'),
#   ('G', 'Bb', 'D:min7'),
#   ('C#:min', 'B:min7', 'Bb:maj7/5'),
#   ('F#:min', 'A:maj6', 'G/3'),
#   ('C#:min', 'B:(1)', 'G:(6)'),
#   ('B', 'A:min7', 'G:7'),
#   ('F#:min', 'A:maj6', 'A:sus4/5'),
#   ('D/5', 'F#:min9', 'D:min7'),
#   ('A:7', 'C:maj7', 'G/3'),
#   ('A:sus4', 'G:(7)', 'D:7(#9)'),
#   ('G#', 'E:min7(4)', 'F:7'),
#   ('A', 'C', 'Bb:maj7'),
#   ('B:min', 'F', 'A:sus4/5'),
#   ('G:min', 'E:min/5', 'G/3'),
#   ('G:(6)', 'G:aug', 'Bb/5'),
#   ('G#', 'G:maj7', 'E:min'),
#   ('A:maj6', 'F', 'B'),
#   ('D', 'B:min7', 'D:min/b7'),
#   ('A:7', 'D:maj(2)', 'F:7'),
#   ('B', 'G:7', 'F:maj(*3)'),
#   ('F#:min', 'C:7', 'Bb/5'),
#   ('A', 'B:min7', 'G:maj6/5'),
#   ('G:aug', 'G:7', 'Bb:maj7/5'),
#   ('B:(1)', 'G:maj7', 'D:min7'),
#   ('B:min', 'D:sus4', 'G:(1)'),
#   ('A:7', 'G#', 'D:7'),
#   ('B:(1)', 'G#', 'A:min7'),
#   ('A:maj6', 'F#:min9', 'G:(7)'),
#   ('G', 'D:sus4', 'F/7'),
#   ('F#:min', 'D:maj(2)', 'Bb/5'),
#   ('B:min', 'F', 'A:sus2'),
#   ('D', 'A:min7', 'C:7'),
#   ('A:maj6', 'G:min', 'A:sus4'),
#   ('B:min', 'D:maj(2)', 'A:sus4'),
#   ('G#', 'C:7', 'E:min7(4)'),
#   ('F', 'F:maj(*3)', 'E:min7(4)'),
#   ('D/6', 'B', 'G:(6)'),
#   ('D:sus4', 'Bb', 'A:min7'),
#   ('D:7', 'G:(6)', 'D:7(#9)'),
#   ('B', 'G#', 'A:min7'),
#   ('A:7', 'G:maj6/5', 'D:min/b7'),
#   ('G#', 'E/5', 'Bb:maj'),
#   ('A', 'G:aug', 'G:7'),
#   ('B:(1)', 'B:min7', 'C:maj6'),
#   ('E', 'F#:min', 'E/5'),
#   ('G:min', 'A:sus4', 'E:min7(4)'),
#   ('E', 'A', 'Bb:maj7'),
#   ('D/6', 'G:aug', 'G:7'),
#   ('D/b7', 'A:sus2', 'A:sus4'),
#   ('F', 'D:7', 'Bb:maj7/5'),
#   ('A:7', 'B:(6)', 'C:maj6'),
#   ('B', 'C:maj7', 'C:7'),
#   ('E', 'D/b7', 'E/5'),
#   ('E', 'Bb:maj7', 'C:maj6'),
#   ('D/5', 'C:7', 'Bb:maj'),
#   ('A:maj6', 'F/7', 'Bb/7'),
#   ('A:sus4', 'G:(7)', 'F/5'),
#   ('N', 'D:maj(2)', 'G:maj7'),
#   ('C', 'D/b7', 'D:min'),
#   ('A:maj6', 'B', 'G:aug'),
#   ('D/5', 'B:(6)', 'C:7'),
#   ('C:maj7', 'F:maj(*3)', 'A:sus4/5'),
#   ('D:min/b7', 'A:min/b3', 'E:min7(4)'),
#   ('D/5', 'E:min7(4)', 'G/3'),
#   ('E:min/5', 'A:min7', 'Bb/7'),
#   ('D/5', 'D:min', 'Bb:maj7'),
#   ('A:min7', 'G:maj6/5', 'D:min7'),
#   ('A:min', 'B:(6)', 'Bb/7'),
#   ('B:min', 'F#:min', 'B'),
#   ('A:min', 'Bb:maj', 'Bb/5'),
#   ('D/6', 'D:maj(2)', 'G:aug'),
#   ('G:(1)', 'D:min', 'D:min/b7'),
#   ('A:7', 'G:(6)', 'F:maj(*3)'),
#   ('A:min', 'A:sus4/5', 'F:7'),
#   ('N', 'D:sus4', 'C:maj7'),
#   ('E', 'A:min7', 'C:maj7'),
#   ('F#:min9', 'A:min7', 'G/3'),
#   ('N', 'D', 'D:7(#9)'),
#   ('E', 'G:min', 'D/6'),
#   ('F#:min', 'G#', 'F:7'),
#   ('F', 'E/5', 'Bb:maj7'),
#   ('G', 'A', 'C'),
#   ('A', 'G:(1)', 'C:maj6'),
#   ('F', 'G:(6)', 'C:7'),
#   ('D/6', 'D:sus4', 'G:(7)'),
#   ('C', 'A:sus2', 'D:min/b7'),
#   ('D/b7', 'G:maj6/5', 'Bb/5'),
#   ('D/b7', 'A:min/b3', 'G/3'),
#   ('B:(1)', 'A:min7', 'A:sus4/5'),
#   ('E:min/5', 'G:aug', 'Bb/5'),
#   ('G:aug', 'C:maj7', 'C:maj6'),
#   ('D:sus4', 'G:aug', 'G/3'),
#   ('Bb/5', 'D:min7', 'Bb:maj7/5'),
#   ('D', 'E:min/5', 'E:min'),
#   ('B:(6)', 'G#', 'G:maj7'),
#   ('G:(6)', 'G:7', 'G:maj6/5'),
#   ('F', 'F#:min9', 'Bb/5'),
#   ('A:sus2', 'B:(6)', 'G:maj6/5'),
#   ('E:min', 'G:maj6/5', 'Bb:maj7/5'),
#   ('D/b7', 'G:(7)', 'G:7'),
#   ('C#:min', 'G:min', 'E:min'),
#   ('F#:min', 'D', 'D/b7'),
#   ('A:sus2', 'A:min/b3', 'Bb:maj'),
#   ('D/6', 'E:min', 'C:maj6'),
#   ('E:min/5', 'F/7', 'E:min7(4)'),
#   ('C', 'B:(6)', 'G:(7)'),
#   ('F', 'B', 'D:7'),
#   ('G:min', 'B:(1)', 'Bb'),
#   ('C:maj7', 'G:maj6/5', 'C:maj6'),
#   ('D:7', 'G:aug', 'E:min7(4)'),
#   ('G:maj7', 'G:aug', 'D:min7'),
#   ('C#:min', 'F/7', 'A:min/b3'),
#   ('D/5', 'F:maj(*3)', 'E:min7(4)'),
#   ('A', 'D:sus4', 'F:7'),
#   ('C:7', 'F/7', 'G/3'),
#   ('G', 'C', 'B'),
#   ('D:sus4', 'B:(6)', 'E/5'),
#   ('D', 'A:maj6', 'A:min7'),
#   ('D:min', 'D:min7', 'E:min7(4)'),
#   ('G', 'F', 'F#:min9'),
#   ('N', 'E', 'B:(1)'),
#   ('F#:min9', 'G:(1)', 'D:min7'),
#   ('F#:min9', 'G:maj6/5', 'C:7'),
#   ('E', 'D:min', 'D:min/b7'),
#   ('D/b7', 'D/5', 'F:7'),
#   ('E:min', 'D:min/b7', 'Bb/5'),
#   ('G', 'E', 'A:min7'),
#   ('B', 'G:maj6/5', 'E:min7(4)'),
#   ('A', 'B:(6)', 'F#:min9'),
#   ('E', 'A:min/b3', 'F/5'),
#   ('D/b7', 'F:maj(*3)', 'D:min/b7'),
#   ('B', 'G:(1)', 'A:min/b3'),
#   ('D:maj(2)', 'A:min/b3', 'E:min7(4)'),
#   ('A', 'F', 'E:min/5'),
#   ('B:(1)', 'E:min/5', 'D:min'),
#   ('D', 'B:(1)', 'D:min'),
#   ('F#:min', 'A:7', 'F:maj(*3)'),
#   ('D/5', 'C:7', 'A:min/b3'),
#   ('F#:min9', 'Bb', 'F/7'),
#   ('C:maj7', 'F:maj(*3)', 'C:7'),
#   ('F#:min', 'G:aug', 'C:maj6'),
#   ('F', 'D:sus4', 'G/3'),
#   ('N', 'G:7', 'D:min'),
#   ('E', 'G:7', 'Bb:maj7/5'),
#   ('D:sus4', 'B', 'G:(1)'),
#   ('D', 'C:maj6', 'Bb:maj7/5'),
#   ('D/6', 'D:7(#9)', 'F:maj(*3)'),
#   ('E', 'A:sus4', 'D:min7'),
#   ('D/5', 'E:min', 'D:min/b7'),
#   ('A:sus2', 'B', 'F:maj(*3)'),
#   ('F', 'G:maj6/5', 'F:maj(*3)'),
#   ('A:7', 'D:maj(2)', 'C:maj7'),
#   ('B:min', 'B:(1)', 'A:min/b3'),
#   ('A:maj6', 'D/b7', 'G:7'),
#   ('G:maj7', 'E:min/5', 'C:maj7'),
#   ('A:sus4', 'A:sus4/5', 'G/3'),
#   ('G:aug', 'G:maj6/5', 'F:7'),
#   ('A', 'D:maj(2)', 'F:7'),
#   ('A', 'D/5', 'A:sus4/5'),
#   ('B:min', 'D/5', 'A:sus2'),
#   ('A:min', 'A:sus4', 'B:(1)'),
#   ('E:min/5', 'Bb:maj7', 'E:min7(4)'),
#   ('A:maj6', 'A:min', 'D/b7'),
#   ('A', 'D:sus4', 'A:sus4'),
#   ('D/b7', 'G#', 'E:min7(4)'),
#   ('G#', 'D:min', 'Bb/5'),
#   ('C#:min', 'F#:min9', 'C:7'),
#   ('F', 'D:maj(2)', 'G:aug'),
#   ('B:(6)', 'B:(1)', 'F:7'),
#   ('G', 'D/5', 'C:maj7'),
#   ('G', 'B:(1)', 'Bb/7'),
#   ('A:maj6', 'A:min7', 'A:sus4/5'),
#   ('B', 'G:(7)', 'Bb'),
#   ('F', 'A:sus2', 'F/7'),
#   ('B:min', 'D/5', 'A:sus4/5'),
#   ('B:min', 'G:(1)', 'G:7'),
#   ('B:min', 'Bb:maj7', 'F:7'),
#   ('E', 'E:min/5', 'G/3'),
#   ('A:sus4', 'B:(1)', 'Bb:maj7/5'),
#   ('E:min', 'E/5', 'C:maj6'),
#   ('G:maj7', 'G:(7)', 'D:min7'),
#   ('E', 'A:maj6', 'G:7'),
#   ('A:maj6', 'D:7', 'G/3'),
#   ('A:min', 'G:maj7', 'C:maj7'),
#   ('F#:min9', 'Bb/7', 'Bb:maj7/5'),
#   ('G', 'D:sus4', 'D:7(#9)'),
#   ('G#', 'G:(7)', 'B:min7'),
#   ('D', 'D:7(#9)', 'G/3'),
#   ('G:(7)', 'Bb/5', 'Bb:maj7/5'),
#   ('N', 'A', 'D:maj(2)'),
#   ('A:min', 'G:maj7', 'D:7(#9)'),
#   ('A:maj6', 'E:min', 'F/7'),
#   ('D/b7', 'D/6', 'D:7(#9)'),
#   ('D:7(#9)', 'C:7', 'A:sus4/5'),
#   ('A:sus2', 'G:(1)', 'C:maj6'),
#   ('B:(1)', 'G:(6)', 'D:min'),
#   ('A:7', 'B:(6)', 'D:min/b7'),
#   ('D:7(#9)', 'C:7', 'Bb/5'),
#   ('N', 'F', 'D:sus4'),
#   ('A:min7', 'G:7', 'F:7'),
#   ('A:7', 'B:min7', 'Bb:maj7/5'),
#   ('A:maj6', 'G:maj7', 'B:min7'),
#   ('E', 'D:min', 'A:sus4/5'),
#   ('A:maj6', 'G:(1)', 'G:maj6/5'),
#   ('A:7', 'A:min', 'D:maj(2)'),
#   ('G:maj6/5', 'F:maj(*3)', 'G/3'),
#   ('E', 'A:sus2', 'A:min7'),
#   ('A:min7', 'D:min/b7', 'C:maj6'),
#   ('A', 'G:min', 'G#'),
#   ('B:(6)', 'C:7', 'A:min/b3'),
#   ('G:maj7', 'Bb/7', 'Bb:maj7/5'),
#   ('D', 'Bb', 'Bb:maj'),
#   ('A:min', 'A:sus4', 'B:min7'),
#   ('G:min', 'Bb', 'F:maj(*3)'),
#   ('B:min', 'G:(6)', 'E:min/5'),
#   ('F#:min', 'B:(1)', 'A:sus4/5'),
#   ('E', 'B:(6)', 'E:min'),
#   ('D/b7', 'D:maj(2)', 'F/5'),
#   ('D:7', 'Bb/5', 'F:7'),
#   ('D', 'G:min', 'D:min/b7'),
#   ('D/b7', 'A:sus2', 'F#:min9'),
#   ('A:7', 'G:(6)', 'C:7'),
#   ('C', 'A:sus2', 'C:maj6'),
#   ('F#:min', 'E:min/5', 'C:maj6'),
#   ('D:maj(2)', 'G:maj6/5', 'C:maj6'),
#   ('Bb:maj7', 'A:min/b3', 'F/5'),
#   ('D', 'D/b7', 'Bb:maj7/5'),
#   ('G:maj7', 'D:min/b7', 'Bb:maj7/5'),
#   ('A:7', 'G:min', 'E:min'),
#   ('B:(6)', 'F#:min9', 'C:7'),
#   ('A:maj6', 'A:min7', 'Bb/5'),
#   ('G#', 'B:min7', 'F/7'),
#   ('A', 'E:min', 'Bb:maj7'),
#   ('G:maj7', 'B:min7', 'A:sus4/5'),
#   ('A:sus2', 'G#', 'Bb:maj'),
#   ('E/5', 'Bb:maj7', 'A:min/b3'),
#   ('D/6', 'A:sus2', 'Bb:maj7'),
#   ('E', 'A:min/b3', 'E:min7(4)'),
#   ('G:7', 'C:7', 'Bb/5'),
#   ('C#:min', 'B:min7', 'D:min/b7'),
#   ('E', 'D', 'A:sus4'),
#   ('E/5', 'C:7', 'E:min7(4)'),
#   ('G:(7)', 'C:7', 'Bb:maj'),
#   ('G', 'B:(6)', 'Bb:maj'),
#   ('D:sus4', 'D:min', 'G/3'),
#   ('N', 'A', 'Bb:maj'),
#   ('G:min', 'G:(1)', 'D:min7'),
#   ('A:7', 'F#:min9', 'Bb:maj7/5'),
#   ('D/b7', 'D/5', 'Bb/7'),
#   ('D', 'A:sus2', 'E/5'),
#   ('E:min', 'C:7', 'F:7'),
#   ('F#:min', 'D:7(#9)', 'Bb:maj7/5'),
#   ('B:min', 'A:sus2', 'Bb:maj7'),
#   ('B', 'E:min/5', 'G:aug'),
#   ('A', 'D:sus4', 'Bb/5'),
#   ('A:sus4', 'B', 'D:min/b7'),
#   ('D:7', 'G:(1)', 'Bb'),
#   ('N', 'D/b7', 'F/7'),
#   ('G', 'E:min/5', 'G:aug'),
#   ('F', 'G#', 'D:min/b7'),
#   ('E', 'D/b7', 'G:maj7'),
#   ('C#:min', 'F#:min', 'B:min7'),
#   ('C#:min', 'G:min', 'A:min7'),
#   ('C', 'B', 'G:7'),
#   ('D/5', 'D:min', 'Bb/7'),
#   ('F#:min', 'D:7', 'F:maj(*3)'),
#   ('A:min', 'A:sus2', 'B:min7'),
#   ('N', 'G:(6)', 'F:maj(*3)'),
#   ('A:sus4', 'G:7', 'F/5'),
#   ('G', 'E', 'Bb:maj7'),
#   ('E', 'D:7', 'F:maj(*3)'),
#   ('B:min', 'G:(1)', 'F:7'),
#   ('A:sus4', 'B:(6)', 'D:7'),
#   ('D/b7', 'Bb:maj', 'F:7'),
#   ('C#:min', 'A:maj6', 'F:7'),
#   ('C#:min', 'G:7', 'D:min'),
#   ('G', 'C:7', 'A:min/b3'),
#   ('B:min', 'A:min', 'G#'),
#   ('A:7', 'C', 'F:7'),
#   ('N', 'G', 'B'),
#   ('A', 'F', 'C:maj6'),
#   ('N', 'D/b7', 'A:sus2'),
#   ('F', 'D:7', 'D:min/b7'),
#   ('E', 'A', 'Bb/7'),
#   ('E', 'G:7', 'F:maj(*3)'),
#   ('F', 'D:min', 'Bb:maj7/5'),
#   ('F', 'A:sus2', 'E:min7(4)'),
#   ('G', 'C', 'A:min7'),
#   ('G:min', 'C:maj7', 'A:min/b3'),
#   ('A:sus4', 'G:(1)', 'F/7'),
#   ('F#:min9', 'Bb', 'G:maj6/5'),
#   ('Bb/5', 'C:maj6', 'F/5'),
#   ('D:7(#9)', 'C:maj7', 'F/5'),
#   ('E', 'C:7', 'D:min7'),
#   ('A:sus4', 'B:min7', 'Bb/7'),
#   ('C#:min', 'Bb:maj7', 'G/3'),
#   ('G:maj7', 'F:maj(*3)', 'D:min7'),
#   ('E', 'C', 'Bb:maj7'),
#   ('A:min/b3', 'Bb/5', 'C:maj6'),
#   ('G:maj7', 'D:min', 'G/3'),
#   ('C', 'D/b7', 'B:(1)'),
#   ('G:(7)', 'G:(6)', 'Bb'),
#   ('A', 'F', 'Bb/7'),
#   ('A:sus4', 'A:min7', 'G/3'),
#   ('B', 'Bb:maj7', 'F/5'),
#   ('D', 'B:min7', 'A:sus4/5'),
#   ('F#:min9', 'G:aug', 'B:min7'),
#   ('B', 'D:7(#9)', 'D:min7'),
#   ('A:7', 'Bb', 'F:7'),
#   ('B:(1)', 'G:aug', 'E/5'),
#   ('B:min7', 'G:maj6/5', 'C:7'),
#   ('G:min', 'B:(6)', 'E:min7(4)'),
#   ('A:maj6', 'B:(1)', 'E:min/5'),
#   ('A:min', 'D:maj(2)', 'G:7'),
#   ('D:7', 'G:(1)', 'F/5'),
#   ('E/5', 'Bb:maj7', 'Bb:maj'),
#   ('B:(1)', 'G:aug', 'D:min'),
#   ('G#', 'F:7', 'C:maj6'),
#   ('G:(6)', 'D:min7', 'Bb/7'),
#   ('G:min', 'D/5', 'Bb:maj7/5'),
#   ('D/5', 'G#', 'G:(6)'),
#   ('D/5', 'G:maj6/5', 'F:7'),
#   ('G:min', 'B:min7', 'D:min/b7'),
#   ('G', 'D/b7', 'G:maj7'),
#   ('G', 'A:maj6', 'Bb/7'),
#   ('N', 'D/6', 'G:(7)'),
#   ('D:sus4', 'D:7(#9)', 'C:7'),
#   ('A:min7', 'F:maj(*3)', 'A:sus4/5'),
#   ('G:maj7', 'C:maj7', 'Bb:maj7'),
#   ('C', 'B:(1)', 'A:min7'),
#   ('B', 'G:aug', 'Bb:maj7/5'),
#   ('E', 'A:min', 'D/6'),
#   ('A:min', 'D:sus4', 'D:7(#9)'),
#   ('B', 'B:(6)', 'B:(1)'),
#   ('A:sus2', 'E:min/5', 'G/3'),
#   ('D/6', 'B:(6)', 'G:maj7'),
#   ('D', 'Bb:maj7', 'Bb/5'),
#   ('N', 'D:7(#9)', 'D:min/b7'),
#   ('D:sus4', 'E/5', 'E:min7(4)'),
#   ('E', 'G:maj7', 'G:7'),
#   ('G:(1)', 'G:(6)', 'E:min'),
#   ('A:7', 'D:min', 'A:min/b3'),
#   ('A:sus4', 'A:min7', 'D:min7'),
#   ('C#:min', 'A:sus2', 'E:min/5'),
#   ('C', 'G:aug', 'Bb/5'),
#   ('D:sus4', 'F/7', 'A:min/b3'),
#   ('G:min', 'E:min', 'D:min'),
#   ('A:sus2', 'G:maj6/5', 'Bb/5'),
#   ('G:min', 'D:7(#9)', 'G:maj6/5'),
#   ('A', 'B:(1)', 'G:aug'),
#   ('A:min', 'D/5', 'B:(1)'),
#   ('D/6', 'D:min', 'Bb:maj'),
#   ('C#:min', 'D:7(#9)', 'E:min'),
#   ('N', 'D:sus4', 'F#:min9'),
#   ('G:maj7', 'E:min', 'F:7'),
#   ('D/6', 'G:aug', 'A:min7'),
#   ('D/6', 'D/5', 'F/7'),
#   ('G', 'G:(6)', 'A:min7'),
#   ('G:min', 'B', 'A:min7'),
#   ('F', 'D/5', 'D:7(#9)'),
#   ('D:maj(2)', 'A:min/b3', 'D:min7'),
#   ('B:(6)', 'D:min7', 'Bb:maj7/5'),
#   ('E', 'A:maj6', 'D:min/b7'),
#   ('G', 'A:min/b3', 'E:min7(4)'),
#   ('F#:min', 'B:(1)', 'G:(1)'),
#   ('A:maj6', 'B', 'G/3'),
#   ('D/6', 'F:maj(*3)', 'D:min7'),
#   ('B:min7', 'A:sus4/5', 'Bb/5'),
#   ('B:min', 'G:(7)', 'F:maj(*3)'),
#   ('D', 'D:7', 'Bb/7'),
#   ('B', 'G:maj7', 'Bb:maj7'),
#   ('G:(1)', 'G:7', 'G/3'),
#   ('E:min/5', 'G:maj6/5', 'Bb:maj7'),
#   ('Bb', 'G:aug', 'F/7'),
#   ('A:7', 'D:sus4', 'A:min/b3'),
#   ('C', 'G:min', 'F:7'),
#   ('G', 'G:7', 'A:sus4/5'),
#   ('A:sus4/5', 'A:min/b3', 'F:7'),
#   ('A:sus2', 'B:(1)', 'G:(6)'),
#   ('F#:min', 'E:min', 'C:maj6'),
#   ('C#:min', 'A:7', 'A:min/b3'),
#   ('A:maj6', 'D:maj(2)', 'C:maj7'),
#   ('G:(1)', 'G:maj6/5', 'F/5'),
#   ('D:sus4', 'G:aug', 'A:min7'),
#   ('A:min', 'B:(1)', 'Bb/7'),
#   ('G', 'A', 'B:min7'),
#   ('A:7', 'G:(1)', 'Bb:maj7/5'),
#   ('D/5', 'D:min', 'F:7'),
#   ('A:min', 'Bb:maj7', 'A:sus4/5'),
#   ('D:sus4', 'G:7', 'F:7'),
#   ('D/5', 'Bb:maj7', 'F/5'),
#   ('G:(7)', 'F:maj(*3)', 'G/3'),
#   ('B:(1)', 'F#:min9', 'F:maj(*3)'),
#   ('A', 'D/5', 'Bb:maj7'),
#   ('D/5', 'A:sus4', 'A:min7'),
#   ('F', 'G:min', 'F/7'),
#   ('A:min', 'F#:min9', 'E:min'),
#   ('G:maj7', 'B:min7', 'Bb/5'),
#   ('N', 'D/6', 'G#'),
#   ('B:min', 'C', 'F/5'),
#   ('F', 'D:min', 'Bb:maj7'),
#   ('G:maj7', 'G:(7)', 'E:min7(4)'),
#   ('D:7(#9)', 'C:7', 'Bb/7'),
#   ('E', 'D', 'D:min'),
#   ('C', 'B:(1)', 'G:(1)'),
#   ('F', 'B', 'D:min'),
#   ('D:sus4', 'G:(1)', 'G:aug'),
#   ('B', 'D:min', 'F/5'),
#   ('A:sus4', 'G:maj7', 'C:maj6'),
#   ('E', 'F', 'D:7(#9)'),
#   ('E', 'Bb', 'C:maj6'),
#   ('F#:min', 'F', 'G:maj7'),
#   ('A', 'C:maj7', 'Bb:maj7'),
#   ('D/6', 'C:7', 'Bb:maj7/5'),
#   ('D:7', 'Bb', 'D:min'),
#   ('A:sus2', 'D:min/b7', 'A:sus4/5'),
#   ('G:(6)', 'G:aug', 'E/5'),
#   ('E', 'D/6', 'G:(1)'),
#   ('C:maj7', 'Bb/5', 'D:min7'),
#   ('D:7', 'G:7', 'C:7'),
#   ('N', 'D/6', 'D:7'),
#   ('A:maj6', 'A:min', 'G:maj7'),
#   ('G:min', 'G:maj7', 'C:7'),
#   ('Bb:maj7', 'A:sus4/5', 'G/3'),
#   ('B', 'G:(7)', 'D:min7'),
#   ('F', 'D/5', 'Bb:maj'),
#   ('G', 'F#:min', 'A:maj6'),
#   ('B:min', 'E:min', 'F/7'),
#   ('B:min', 'A:min7', 'F:7'),
#   ('B:(6)', 'C:maj7', 'D:min'),
#   ('D:min/b7', 'C:maj6', 'F/5'),
#   ('A:7', 'D:sus4', 'C:maj6'),
#   ('D:sus4', 'Bb:maj', 'C:maj6'),
#   ('D:7', 'G:(1)', 'E:min7(4)'),
#   ('G:(1)', 'F:7', 'C:maj6'),
#   ('E:min/5', 'E:min', 'Bb/5'),
#   ('A:maj6', 'E:min', 'Bb:maj7/5'),
#   ('G#', 'G:maj6/5', 'E:min7(4)'),
#   ('A:sus4', 'B:(6)', 'D:min7'),
#   ('A:min7', 'C:maj7', 'Bb:maj'),
#   ('E:min', 'A:min/b3', 'F/5'),
#   ('G:min', 'A:sus4', 'G:(7)'),
#   ('D/5', 'G:(6)', 'D:min7'),
#   ('F', 'D:7', 'Bb:maj'),
#   ('D:sus4', 'Bb', 'F/7'),
#   ('B:min', 'G:maj7', 'C:maj6'),
#   ('G', 'B:(6)', 'G:maj6/5'),
#   ('F', 'B:(6)', 'Bb/7'),
#   ('A:min', 'B:(1)', 'G:(1)'),
#   ('G', 'E', 'G:maj6/5'),
#   ('A:maj6', 'A:sus4', 'E/5'),
#   ('F', 'G:min', 'D/6'),
#   ('G:maj7', 'G:aug', 'F/7'),
#   ('G', 'D/6', 'C:7'),
#   ('G:(6)', 'Bb:maj7/5', 'G/3'),
#   ('D:7', 'E/5', 'F/7'),
#   ('A:7', 'F#:min9', 'G:7'),
#   ('B', 'A:sus4/5', 'G/3'),
#   ('A:7', 'Bb:maj7', 'Bb:maj'),
#   ('C#:min', 'B:(1)', 'D:7(#9)'),
#   ('G:min', 'D/b7', 'G:7'),
#   ('F#:min', 'A:sus4/5', 'Bb:maj7/5'),
#   ('F#:min', 'D:7', 'G:(6)'),
#   ('G:aug', 'B:min7', 'Bb/7'),
#   ('D/b7', 'D:sus4', 'E:min/5'),
#   ('B:min', 'E:min/5', 'G/3'),
#   ('F', 'B', 'C:7'),
#   ('E/5', 'C:7', 'D:min7'),
#   ('D:maj(2)', 'G#', 'Bb/7'),
#   ('G:maj6/5', 'A:sus4/5', 'A:min/b3'),
#   ('A:maj6', 'D/5', 'A:sus2'),
#   ('D:maj(2)', 'A:min7', 'F:maj(*3)'),
#   ('G:aug', 'Bb/7', 'Bb:maj7/5'),
#   ('A:maj6', 'D/b7', 'B'),
#   ('G:maj7', 'D:7(#9)', 'Bb/7'),
#   ('D:7(#9)', 'F:maj(*3)', 'Bb:maj7/5'),
#   ('E:min', 'D:min', 'F/7'),
#   ('D/5', 'A:min7', 'D:min'),
#   ('G:maj7', 'C:7', 'Bb/5'),
#   ('F#:min9', 'Bb:maj', 'D:min7'),
#   ('B:min', 'G:7', 'F:maj(*3)'),
#   ('Bb:maj', 'D:min7', 'Bb:maj7/5'),
#   ('C:maj7', 'E/5', 'Bb/7'),
#   ('F', 'A:sus2', 'G:(1)'),
#   ('A:sus4', 'Bb/7', 'C:maj6'),
#   ('C#:min', 'D/b7', 'D/6'),
#   ('E', 'C:maj7', 'C:maj6'),
#   ('D/b7', 'D/5', 'G:maj7'),
#   ('G', 'G:min', 'Bb/7'),
#   ('A:maj6', 'D:maj(2)', 'G#'),
#   ('B', 'G:(6)', 'Bb/5'),
#   ('E:min/5', 'D:min/b7', 'C:maj6'),
#   ('D:maj(2)', 'G:maj7', 'A:sus4/5'),
#   ('A:sus2', 'G:maj7', 'F:maj(*3)'),
#   ('B:(1)', 'Bb/7', 'F:7'),
#   ('E', 'A', 'Bb/5'),
#   ('G:min', 'D:sus4', 'G:(1)'),
#   ('A:min', 'D:sus4', 'B:(6)'),
#   ('A:maj6', 'F', 'Bb/7'),
#   ('G:maj7', 'Bb:maj', 'F:7'),
#   ('C#:min', 'G:(1)', 'E:min'),
#   ('D', 'D:7', 'Bb:maj7'),
#   ('A:sus4', 'G:maj6/5', 'Bb/5'),
#   ('D', 'F#:min9', 'B:min7'),
#   ('B:min7', 'A:sus4/5', 'F:7'),
#   ('B', 'E:min7(4)', 'C:maj6'),
#   ('F:maj(*3)', 'Bb/5', 'F:7'),
#   ('G:min', 'D/6', 'A:min/b3'),
#   ('D/b7', 'E:min/5', 'E:min7(4)'),
#   ('A:sus2', 'F:7', 'G/3'),
#   ...},
#  '012': {('A:min7', 'A:sus4', 'G:7'),
#   ('A:7', 'D:maj(2)', 'G'),
#   ('A', 'A:sus4/5', 'F/5'),
#   ('A', 'A:7', 'B'),
#   ('Bb', 'C', 'G:(7)'),
#   ('A:min', 'Bb', 'G:aug'),
#   ('C', 'E:min', 'G:min'),
#   ('Bb:maj7/5', 'D:7', 'F'),
#   ('B:min', 'Bb:maj7', 'C:7'),
#   ('Bb:maj7/5', 'E', 'N'),
#   ('D/5', 'F#:min9', 'G'),
#   ('A', 'D/b7', 'D:min'),
#   ('A:min', 'Bb', 'G:(6)'),
#   ('A', 'A:min7', 'A:sus2'),
#   ('B:(6)', 'D:7(#9)', 'E'),
#   ('Bb', 'Bb:maj7', 'G:7'),
#   ('D/b7', 'G:(1)', 'G:(7)'),
#   ('C', 'E', 'G:(6)'),
#   ('B:min', 'D:sus4', 'E'),
#   ('A', 'A:sus2', 'G/3'),
#   ('Bb:maj7', 'D:min', 'G'),
#   ('Bb', 'D:maj(2)', 'G/3'),
#   ('B', 'Bb', 'G:7'),
#   ('C#:min', 'F:maj(*3)', 'N'),
#   ('A:maj6', 'B:min7', 'G:7'),
#   ('A:sus4/5', 'B:min', 'N'),
#   ('D:min7', 'E:min', 'F:maj(*3)'),
#   ('F', 'G:aug', 'G:min'),
#   ('Bb/7', 'F/7', 'G:min'),
#   ('B:(6)', 'E', 'G:min'),
#   ('B:(6)', 'G:maj7', 'N'),
#   ('A', 'A:sus2', 'G:min'),
#   ('C:7', 'F', 'G#'),
#   ('Bb:maj7/5', 'C:maj6', 'F#:min9'),
#   ('A', 'A:min', 'Bb'),
#   ('D:7', 'F:maj(*3)', 'G'),
#   ('D:min', 'F/7', 'G:maj7'),
#   ('B:min7', 'Bb/7', 'D:7'),
#   ('F/5', 'G/3', 'G:(1)'),
#   ('A', 'A:sus4/5', 'D:min/b7'),
#   ('Bb/7', 'D:min', 'G:min'),
#   ('B:(1)', 'C:maj7', 'G:7'),
#   ('Bb', 'D:min/b7', 'E:min7(4)'),
#   ('C#:min', 'D:7', 'G'),
#   ('F:7', 'G', 'G:aug'),
#   ('A', 'A:sus4/5', 'G:(6)'),
#   ('A:min7', 'G', 'G/3'),
#   ('Bb', 'Bb:maj7/5', 'C'),
#   ('A:min7', 'C:maj7', 'G:(7)'),
#   ('A:min/b3', 'D:min', 'D:sus4'),
#   ('D:7', 'F/7', 'G'),
#   ('Bb:maj7/5', 'F', 'F#:min9'),
#   ('A:min', 'F/5', 'G'),
#   ('A:7', 'A:sus4', 'Bb:maj7'),
#   ('D:7', 'G:(6)', 'G:(7)'),
#   ('Bb/5', 'C:maj7', 'G:7'),
#   ('A:min', 'E:min7(4)', 'G'),
#   ('A:7', 'C:7', 'D:min'),
#   ('A:min7', 'E', 'F'),
#   ('D', 'D:7', 'D:min7'),
#   ('D', 'F/5', 'G:(6)'),
#   ('B:(6)', 'C:7', 'F'),
#   ('Bb/5', 'C', 'F:maj(*3)'),
#   ('D/5', 'E/5', 'G:(6)'),
#   ('A:min7', 'A:sus2', 'A:sus4'),
#   ('B:min7', 'D/b7', 'D:7'),
#   ('C', 'D:maj(2)', 'G:min'),
#   ('C:maj7', 'G#', 'G:7'),
#   ('B:min', 'D:min', 'F/7'),
#   ('A:7', 'C', 'E:min'),
#   ('D/6', 'D:7', 'G:7'),
#   ('B:min', 'E', 'E/5'),
#   ('A:min7', 'G', 'G#'),
#   ('A:min7', 'C:maj6', 'D'),
#   ('G#', 'G:(6)', 'G:(7)'),
#   ('A:sus4/5', 'D:min/b7', 'F'),
#   ('A:7', 'A:sus4', 'C#:min'),
#   ('C', 'D:7', 'D:min/b7'),
#   ('A', 'A:min', 'A:min7'),
#   ('A:min7', 'A:sus2', 'G:7'),
#   ('Bb', 'G/3', 'G:min'),
#   ('B', 'E:min7(4)', 'F:7'),
#   ('A:sus4/5', 'E', 'N'),
#   ('A:maj6', 'Bb:maj', 'C'),
#   ('B:(1)', 'D', 'D:7'),
#   ('A:sus4', 'B:(6)', 'E'),
#   ('Bb', 'C#:min', 'F'),
#   ('E:min7(4)', 'F/5', 'G/3'),
#   ('F', 'F/7', 'G:maj6/5'),
#   ('E/5', 'G:(1)', 'N'),
#   ('C:maj6', 'D:min', 'D:min/b7'),
#   ('C:maj7', 'F/7', 'G'),
#   ('A:min/b3', 'Bb', 'D/b7'),
#   ('A:maj6', 'E', 'F'),
#   ('Bb:maj', 'D:7', 'E:min'),
#   ('A', 'A:min7', 'E:min'),
#   ('C:maj7', 'E/5', 'G'),
#   ('B:(6)', 'D:min', 'G'),
#   ('C', 'D:min', 'G:7'),
#   ('D/5', 'D/6', 'D:maj(2)'),
#   ('B:(1)', 'B:min', 'E'),
#   ('A:sus2', 'D/5', 'G'),
#   ('A', 'E:min', 'G:maj6/5'),
#   ('C#:min', 'E', 'G:(1)'),
#   ('Bb/7', 'C', 'G:7'),
#   ('D:min7', 'E', 'G'),
#   ('Bb:maj7/5', 'E/5', 'F'),
#   ('G#', 'G:(1)', 'G:(7)'),
#   ('D:7(#9)', 'F:maj(*3)', 'G'),
#   ('C', 'E:min/5', 'F/7'),
#   ('D:7(#9)', 'D:min7', 'F'),
#   ('E', 'F#:min9', 'G'),
#   ('A:min', 'B:(6)', 'E'),
#   ('G', 'G:(6)', 'G:aug'),
#   ('D/5', 'D/6', 'D:sus4'),
#   ('A:min/b3', 'D:7(#9)', 'D:min'),
#   ('Bb/7', 'Bb:maj7/5', 'F'),
#   ('A', 'A:maj6', 'G#'),
#   ('B:(6)', 'B:min7', 'E'),
#   ('F', 'F:maj(*3)', 'G:aug'),
#   ('Bb:maj7', 'C', 'D:sus4'),
#   ('F#:min', 'G#', 'G:aug'),
#   ('E/5', 'F', 'F/7'),
#   ('F', 'G#', 'N'),
#   ('B:min7', 'Bb', 'F'),
#   ('D:maj(2)', 'F#:min', 'G#'),
#   ('A:sus4/5', 'F', 'G:maj6/5'),
#   ('D', 'D:sus4', 'G/3'),
#   ('A:7', 'E:min', 'F:7'),
#   ('A', 'A:sus4', 'F/7'),
#   ('Bb:maj7/5', 'C:maj6', 'C:maj7'),
#   ('D:7', 'E:min', 'F:7'),
#   ('Bb:maj7/5', 'C:maj6', 'G'),
#   ('A:min7', 'B:(6)', 'G:7'),
#   ('A:sus4/5', 'F', 'G/3'),
#   ('A:7', 'E:min', 'G#'),
#   ('Bb', 'C#:min', 'G/3'),
#   ('Bb/5', 'C', 'D:maj(2)'),
#   ('C:maj7', 'E:min/5', 'G'),
#   ('D/b7', 'D:min7', 'F'),
#   ('Bb/7', 'C:maj7', 'G:min'),
#   ('A:min7', 'B', 'C:maj7'),
#   ('A:min/b3', 'D:min', 'F:maj(*3)'),
#   ('Bb', 'D:min7', 'G/3'),
#   ('D', 'F/5', 'G/3'),
#   ('F:7', 'G', 'G:7'),
#   ('D', 'D/5', 'G:min'),
#   ('A:min7', 'F', 'N'),
#   ('A:min7', 'B', 'D:7'),
#   ('Bb:maj7', 'Bb:maj7/5', 'C:7'),
#   ('C:maj6', 'F/5', 'G/3'),
#   ('A:7', 'Bb', 'F'),
#   ('C', 'C#:min', 'E:min/5'),
#   ('F', 'F/5', 'G:7'),
#   ('A', 'B', 'D/5'),
#   ('A:min', 'A:min/b3', 'G'),
#   ('D:7(#9)', 'G', 'G/3'),
#   ('A:min7', 'A:sus4', 'D'),
#   ('Bb', 'D', 'D:sus4'),
#   ('Bb', 'G:(1)', 'N'),
#   ('D', 'G:(1)', 'G:(6)'),
#   ('A:7', 'A:maj6', 'A:sus4'),
#   ('C#:min', 'D:min', 'D:min/b7'),
#   ('D:7(#9)', 'G', 'G:(1)'),
#   ('B:(6)', 'C:7', 'E'),
#   ('C', 'D:7', 'G/3'),
#   ('A:sus4/5', 'C:maj7', 'G:7'),
#   ('A:7', 'Bb', 'D'),
#   ('A:min/b3', 'B:min', 'E'),
#   ('A:min/b3', 'G', 'G:aug'),
#   ('A:sus2', 'D/5', 'D/6'),
#   ('D/5', 'F#:min', 'G#'),
#   ('C', 'D:7', 'F#:min'),
#   ('D/5', 'D/6', 'D:min7'),
#   ('D/5', 'D:min7', 'F'),
#   ('C', 'C:maj6', 'E:min/5'),
#   ('C:maj7', 'D', 'E/5'),
#   ('A:min', 'B', 'F#:min9'),
#   ('A:min/b3', 'Bb', 'D:maj(2)'),
#   ('A:min/b3', 'Bb/7', 'D:min'),
#   ('Bb:maj7', 'C:7', 'D:min7'),
#   ('D/6', 'D/b7', 'D:min'),
#   ('D:7', 'G#', 'G:7'),
#   ('G', 'G:7', 'G:maj6/5'),
#   ('A', 'D:min', 'F:7'),
#   ('A:sus2', 'G', 'G:7'),
#   ('F', 'F#:min', 'G#'),
#   ('A:sus4', 'D:7(#9)', 'G'),
#   ('A:min', 'A:min7', 'F:maj(*3)'),
#   ('A:sus4', 'Bb', 'E:min/5'),
#   ('Bb', 'Bb/7', 'Bb:maj7'),
#   ('Bb', 'Bb/7', 'Bb:maj'),
#   ('A:min7', 'A:sus4/5', 'G'),
#   ('A:sus4/5', 'C', 'G:7'),
#   ('A:sus4/5', 'F', 'G:(1)'),
#   ('B:(1)', 'D/5', 'E/5'),
#   ('B:(6)', 'D', 'G:(6)'),
#   ('A:7', 'A:sus4/5', 'D'),
#   ('A:min7', 'D', 'D:7(#9)'),
#   ('A:min', 'B:min7', 'G'),
#   ('Bb/5', 'D:sus4', 'F'),
#   ('E:min/5', 'F', 'F:7'),
#   ('Bb:maj7', 'D:min/b7', 'F:7'),
#   ('C', 'E:min7(4)', 'F:7'),
#   ('Bb/5', 'C', 'G:maj6/5'),
#   ('A:7', 'C:maj7', 'D'),
#   ('A:min/b3', 'D', 'E/5'),
#   ('C', 'D/6', 'E'),
#   ('Bb:maj', 'F', 'N'),
#   ('B:min7', 'F', 'F/7'),
#   ('B', 'D:min7', 'G:7'),
#   ('A:7', 'C#:min', 'E:min'),
#   ('B:(6)', 'Bb/5', 'N'),
#   ('B:min7', 'D/6', 'D/b7'),
#   ('D:7', 'D:sus4', 'E:min'),
#   ('F', 'F#:min9', 'F/7'),
#   ('B:min', 'B:min7', 'F/7'),
#   ('A', 'A:sus4/5', 'F:maj(*3)'),
#   ('A', 'A:sus2', 'B:(1)'),
#   ('D/6', 'F:maj(*3)', 'N'),
#   ('A:7', 'Bb/7', 'D'),
#   ('C:maj7', 'D/5', 'E/5'),
#   ('D:7', 'E:min', 'E:min7(4)'),
#   ('B:min', 'Bb/5', 'E'),
#   ('A:7', 'B:min7', 'G:7'),
#   ('B:min', 'F/5', 'N'),
#   ('A', 'A:7', 'D/b7'),
#   ('A:min', 'A:min7', 'B:(1)'),
#   ('Bb', 'D/6', 'D:min/b7'),
#   ('Bb/5', 'G', 'G:7'),
#   ('D:min', 'F:maj(*3)', 'N'),
#   ('G', 'G/3', 'G:7'),
#   ('Bb:maj', 'D:7(#9)', 'G'),
#   ('F', 'G:(6)', 'G:aug'),
#   ('Bb:maj7', 'C:7', 'D/b7'),
#   ('D:min', 'G:(1)', 'N'),
#   ('B:min', 'F#:min', 'G:(1)'),
#   ('A', 'A:7', 'G:maj7'),
#   ('Bb', 'F', 'F#:min'),
#   ('B:(6)', 'E', 'G/3'),
#   ('C', 'C#:min', 'G:aug'),
#   ('B:(1)', 'Bb/7', 'G:min'),
#   ('E:min', 'F#:min', 'F:maj(*3)'),
#   ('A:maj6', 'E:min7(4)', 'F'),
#   ('G:(1)', 'G:(7)', 'G:maj6/5'),
#   ('C#:min', 'G', 'G:aug'),
#   ('A', 'Bb:maj7', 'D/5'),
#   ('A', 'A:sus4/5', 'B'),
#   ('A', 'A:7', 'F/5'),
#   ('A', 'Bb', 'E:min'),
#   ('A:min7', 'B', 'D'),
#   ('Bb/7', 'D/6', 'D/b7'),
#   ('Bb:maj7', 'D:min/b7', 'F/5'),
#   ('B:min7', 'D:7', 'F:maj(*3)'),
#   ('D:7(#9)', 'F', 'N'),
#   ('Bb', 'D:min', 'F/7'),
#   ('D/b7', 'F/5', 'G/3'),
#   ('A', 'A:sus4/5', 'Bb/7'),
#   ('A:7', 'C:7', 'D'),
#   ('A', 'D/5', 'G:maj7'),
#   ('Bb', 'D/6', 'D:7(#9)'),
#   ('D:7', 'F:maj(*3)', 'N'),
#   ('D', 'D/b7', 'E:min/5'),
#   ('Bb:maj7', 'D/b7', 'D:min/b7'),
#   ('B:(6)', 'Bb:maj', 'E'),
#   ('C:maj7', 'D', 'D:7'),
#   ('E:min7(4)', 'F#:min9', 'F:7'),
#   ('A:sus4', 'F#:min', 'G#'),
#   ('A:min', 'A:min7', 'F#:min'),
#   ('Bb:maj7/5', 'C:maj6', 'G:(7)'),
#   ('A:min/b3', 'Bb', 'E:min7(4)'),
#   ('D:min', 'D:min/b7', 'F'),
#   ('A:min', 'Bb', 'Bb:maj'),
#   ('A', 'A:sus4/5', 'B:(6)'),
#   ('A:sus2', 'G:(6)', 'G:(7)'),
#   ('Bb/7', 'G:(1)', 'N'),
#   ('A:min7', 'Bb/5', 'D:7'),
#   ('G', 'G:(1)', 'G:(7)'),
#   ('A:sus2', 'D:7', 'G:7'),
#   ('A:7', 'A:min7', 'D:7'),
#   ('C:maj7', 'E:min', 'G:7'),
#   ('Bb', 'D', 'D:7(#9)'),
#   ('E:min7(4)', 'F', 'G:min'),
#   ('A', 'Bb', 'F'),
#   ('E:min', 'F', 'F/7'),
#   ('C:maj6', 'E', 'N'),
#   ('C:7', 'D/5', 'G'),
#   ('C', 'D:sus4', 'G:(6)'),
#   ('Bb/5', 'D/6', 'D/b7'),
#   ('A:min7', 'G', 'G:maj7'),
#   ('E', 'E:min/5', 'G#'),
#   ('D', 'F/7', 'G:min'),
#   ('Bb:maj', 'C', 'D/5'),
#   ('A:min7', 'F', 'F/5'),
#   ('D:7', 'G:7', 'G:aug'),
#   ('A:min/b3', 'D:min', 'E'),
#   ('B:min7', 'D:7', 'G:maj7'),
#   ('D:min', 'F', 'F:7'),
#   ('B:min7', 'C:7', 'F'),
#   ('F', 'F/5', 'G#'),
#   ('A:sus4/5', 'G', 'G:7'),
#   ('B:(1)', 'E:min7(4)', 'F'),
#   ('B:min', 'D:min7', 'E'),
#   ('D:min7', 'F', 'F#:min9'),
#   ('B:min7', 'D:7', 'D:sus4'),
#   ('Bb', 'E:min/5', 'F:maj(*3)'),
#   ('A', 'A:sus4/5', 'Bb:maj7'),
#   ('B:(1)', 'Bb', 'F'),
#   ('A:7', 'C:7', 'G'),
#   ('E:min/5', 'G:(1)', 'G:(7)'),
#   ('Bb/5', 'C#:min', 'E'),
#   ('B:min', 'D:maj(2)', 'N'),
#   ('A:maj6', 'A:sus4/5', 'N'),
#   ('B:(6)', 'Bb', 'F'),
#   ('Bb:maj7/5', 'G:(1)', 'G:(7)'),
#   ('F', 'F:7', 'G:(1)'),
#   ('D/6', 'E', 'N'),
#   ('D:min', 'F:maj(*3)', 'G'),
#   ('B:min', 'D:7', 'F#:min'),
#   ('C:maj7', 'G:(7)', 'G:7'),
#   ('D', 'D/b7', 'E:min'),
#   ('A', 'Bb/5', 'E:min7(4)'),
#   ('F#:min', 'G#', 'N'),
#   ('A:7', 'E:min', 'G:7'),
#   ('A:sus2', 'D:7', 'E:min'),
#   ('Bb:maj7', 'C:7', 'E:min/5'),
#   ('C:7', 'C:maj7', 'F'),
#   ('A:min', 'F', 'F/5'),
#   ('B:(6)', 'D/5', 'N'),
#   ('D:sus4', 'F', 'F/5'),
#   ('B', 'D/b7', 'F#:min9'),
#   ('Bb:maj7', 'C:7', 'G:(1)'),
#   ('Bb', 'D:7(#9)', 'F/7'),
#   ('A:sus2', 'A:sus4', 'Bb/5'),
#   ('A:sus2', 'A:sus4', 'D:7(#9)'),
#   ('Bb', 'Bb/7', 'G:maj7'),
#   ('A:7', 'D/b7', 'E:min'),
#   ('B:min', 'F#:min9', 'N'),
#   ('B:min', 'B:min7', 'F'),
#   ('A:min7', 'B:min', 'B:min7'),
#   ('A', 'A:maj6', 'G:7'),
#   ('Bb', 'G#', 'G:7'),
#   ('A:min7', 'G:7', 'N'),
#   ('Bb:maj7', 'D/6', 'D:min/b7'),
#   ('A:min', 'A:min7', 'G:min'),
#   ('A:sus4', 'D:min', 'G'),
#   ('C#:min', 'E/5', 'F#:min9'),
#   ('A', 'A:7', 'D:7(#9)'),
#   ('A:sus4/5', 'B:min7', 'F'),
#   ('Bb/7', 'D:min7', 'F'),
#   ('B:min', 'D:7', 'E:min'),
#   ('D:7', 'G:(7)', 'G:7'),
#   ('D', 'D/6', 'D:7'),
#   ('D:7', 'F', 'F/5'),
#   ('A:7', 'D:7(#9)', 'D:min'),
#   ('B:(1)', 'Bb', 'G/3'),
#   ('A:min/b3', 'D:min', 'G:maj7'),
#   ('E:min/5', 'G', 'G:7'),
#   ('A:min/b3', 'C#:min', 'E'),
#   ('A:min7', 'C:maj7', 'G#'),
#   ('E', 'F:maj(*3)', 'G#'),
#   ('Bb:maj7', 'D:min/b7', 'E:min'),
#   ('A:sus2', 'C:7', 'F'),
#   ('A', 'A:maj6', 'Bb'),
#   ('B:min', 'B:min7', 'D'),
#   ('A:maj6', 'D', 'D:7'),
#   ('D/6', 'F', 'F/7'),
#   ('A:sus4/5', 'C', 'G:min'),
#   ('B:(1)', 'Bb:maj', 'C'),
#   ('A', 'D:7', 'G:min'),
#   ('B', 'B:min7', 'F#:min9'),
#   ('Bb:maj7', 'E:min', 'F:maj(*3)'),
#   ('C#:min', 'D:maj(2)', 'E'),
#   ('A:min', 'F', 'F/7'),
#   ('D:sus4', 'F', 'F/7'),
#   ('B', 'Bb', 'G/3'),
#   ('Bb:maj7/5', 'C:maj6', 'E:min7(4)'),
#   ('B:(6)', 'F/5', 'N'),
#   ('Bb', 'D:min/b7', 'D:sus4'),
#   ('D:min7', 'F:maj(*3)', 'G:7'),
#   ('D:min', 'D:min7', 'G:7'),
#   ('C', 'C:maj7', 'D:sus4'),
#   ('E', 'E:min', 'N'),
#   ('C:7', 'G', 'G:7'),
#   ('A:maj6', 'D/5', 'D/6'),
#   ('G', 'G:(1)', 'G:7'),
#   ('Bb/5', 'Bb:maj7/5', 'C:maj6'),
#   ('A:min/b3', 'A:min7', 'Bb:maj'),
#   ('C:maj7', 'D:7', 'E:min'),
#   ('A', 'D:7', 'G#'),
#   ('A', 'D/5', 'G:(7)'),
#   ('Bb', 'D:min/b7', 'G:maj7'),
#   ('D:7', 'F', 'G:aug'),
#   ('D', 'D/b7', 'G:aug'),
#   ('D/6', 'D/b7', 'G:maj6/5'),
#   ('A:sus4/5', 'G', 'G:aug'),
#   ('B', 'C:maj7', 'G'),
#   ('A:maj6', 'Bb:maj7', 'C:7'),
#   ('B:min', 'E', 'G:(6)'),
#   ('B:(6)', 'D:min', 'E'),
#   ('D:7(#9)', 'D:min7', 'G:7'),
#   ('E:min7(4)', 'F#:min', 'F:7'),
#   ('Bb', 'D:7(#9)', 'G:min'),
#   ('A:min/b3', 'Bb', 'D:sus4'),
#   ('A:7', 'A:min/b3', 'A:sus4'),
#   ('E:min7(4)', 'F', 'G:(7)'),
#   ('Bb:maj', 'C', 'D:min7'),
#   ('Bb:maj', 'C:maj7', 'G'),
#   ('G', 'G:aug', 'G:maj7'),
#   ('B:min', 'B:min7', 'G:maj7'),
#   ('A', 'A:sus4', 'Bb:maj7/5'),
#   ('A:min7', 'Bb:maj', 'C'),
#   ('B:min', 'D/5', 'D/6'),
#   ('A:min7', 'G:(6)', 'G:7'),
#   ('C:7', 'F', 'G:7'),
#   ('A:min7', 'C', 'D:sus4'),
#   ('A:7', 'D:min', 'G/3'),
#   ('Bb:maj7', 'D:min/b7', 'E:min7(4)'),
#   ('B:(6)', 'E:min', 'F:maj(*3)'),
#   ('A:min/b3', 'Bb:maj', 'Bb:maj7'),
#   ('D', 'D:7', 'G:aug'),
#   ('A', 'C:maj6', 'D:min'),
#   ('C:7', 'D', 'G:min'),
#   ('B:(6)', 'C:maj7', 'G:7'),
#   ('A:min/b3', 'Bb:maj', 'G:(6)'),
#   ('D:min7', 'G:7', 'G:maj7'),
#   ('Bb/7', 'Bb:maj', 'C'),
#   ('D/6', 'D:min', 'G'),
#   ('Bb/7', 'F', 'G:aug'),
#   ('D:7(#9)', 'E:min', 'F:maj(*3)'),
#   ('Bb/7', 'D/5', 'E/5'),
#   ('A:maj6', 'F', 'F/7'),
#   ('C:maj6', 'D:7', 'G'),
#   ('A', 'A:sus4', 'F'),
#   ('A:min', 'B:min', 'B:min7'),
#   ('D', 'D/b7', 'F/5'),
#   ('A', 'A:7', 'Bb:maj7/5'),
#   ('Bb/5', 'E/5', 'F'),
#   ('C:maj6', 'D', 'G:min'),
#   ('A:min/b3', 'G:(6)', 'G:(7)'),
#   ('Bb', 'D:min/b7', 'G:(1)'),
#   ('Bb', 'D:min/b7', 'D:min7'),
#   ('D', 'E:min7(4)', 'F:7'),
#   ('D/6', 'E', 'G'),
#   ('D', 'D:7', 'G#'),
#   ('Bb:maj', 'Bb:maj7', 'C:7'),
#   ('A', 'A:7', 'F:maj(*3)'),
#   ('A:min7', 'D', 'G:(7)'),
#   ('D:min', 'G:(1)', 'G:(7)'),
#   ('Bb:maj', 'F', 'F/7'),
#   ('C#:min', 'D:min', 'F#:min9'),
#   ('F:maj(*3)', 'G/3', 'N'),
#   ('B:min', 'Bb:maj7', 'N'),
#   ('D', 'E/5', 'G:maj7'),
#   ('Bb', 'D:min/b7', 'E'),
#   ('D:min', 'G', 'G:min'),
#   ('C', 'D:sus4', 'F#:min'),
#   ('B:(1)', 'D:min7', 'G:7'),
#   ('A:min', 'D:7', 'G:7'),
#   ('D:min', 'F/7', 'F:maj(*3)'),
#   ('A:sus4', 'D:7', 'G'),
#   ('A:maj6', 'D/5', 'G'),
#   ('C:7', 'F', 'G:(7)'),
#   ('A:min7', 'D/b7', 'G'),
#   ('A:sus2', 'A:sus4', 'D/b7'),
#   ('B:min7', 'D:7', 'G:(7)'),
#   ('A:7', 'E/5', 'G'),
#   ('E', 'E/5', 'G'),
#   ('Bb', 'E:min/5', 'F#:min'),
#   ('Bb:maj7', 'F#:min', 'G#'),
#   ('Bb', 'D:7(#9)', 'E/5'),
#   ('A:sus4', 'Bb:maj7/5', 'C:maj6'),
#   ('E:min7(4)', 'F:7', 'G/3'),
#   ('A:min/b3', 'Bb:maj', 'C:7'),
#   ('E:min7(4)', 'F:7', 'G:(1)'),
#   ('A', 'C:7', 'E:min7(4)'),
#   ('Bb', 'D:7', 'F'),
#   ('C', 'C:maj6', 'G:aug'),
#   ('F', 'G:(1)', 'G:aug'),
#   ('Bb:maj7/5', 'E', 'G'),
#   ('Bb/5', 'C:maj7', 'F'),
#   ('A:min/b3', 'Bb/5', 'C'),
#   ('Bb:maj', 'C', 'G:maj6/5'),
#   ('A', 'A:7', 'Bb/5'),
#   ('C#:min', 'E', 'G:maj6/5'),
#   ('Bb/7', 'G/3', 'G:min'),
#   ('A', 'C:maj6', 'D:7'),
#   ('F', 'F:7', 'G:min'),
#   ('B:min', 'B:min7', 'D:sus4'),
#   ('A:sus2', 'A:sus4', 'E:min'),
#   ('A', 'Bb:maj', 'D/5'),
#   ('D/b7', 'F', 'F/7'),
#   ('A:sus4', 'A:sus4/5', 'F'),
#   ('C', 'D/5', 'E:min/5'),
#   ('C#:min', 'D:min/b7', 'F#:min9'),
#   ('C:7', 'F', 'G:(1)'),
#   ('Bb/7', 'D:7', 'E:min'),
#   ('A', 'A:sus4/5', 'D:maj(2)'),
#   ('D/5', 'E:min', 'F:maj(*3)'),
#   ('B:(6)', 'G', 'G:7'),
#   ('C:maj7', 'G:(1)', 'G:7'),
#   ('A:maj6', 'Bb', 'Bb/7'),
#   ('Bb', 'C', 'F#:min9'),
#   ('A:min/b3', 'Bb:maj', 'G/3'),
#   ('A:min7', 'Bb', 'E:min/5'),
#   ('D/b7', 'F', 'F/5'),
#   ('Bb', 'E/5', 'G:7'),
#   ('Bb', 'C', 'F/7'),
#   ('Bb:maj7/5', 'C', 'D:sus4'),
#   ('B:min7', 'G:(6)', 'G:7'),
#   ('D', 'E/5', 'E:min7(4)'),
#   ('A:min', 'C:maj6', 'G'),
#   ('A', 'C#:min', 'G:(6)'),
#   ('D/5', 'F', 'F/5'),
#   ('Bb:maj7/5', 'G:(1)', 'N'),
#   ('A:sus4/5', 'E', 'G'),
#   ('C', 'E:min', 'E:min/5'),
#   ('D:7(#9)', 'F', 'F/5'),
#   ('A:min/b3', 'Bb', 'D/5'),
#   ('G:(6)', 'G:(7)', 'N'),
#   ('Bb:maj7/5', 'C:maj6', 'D'),
#   ('B', 'Bb:maj7/5', 'F#:min9'),
#   ('D/5', 'D/6', 'D:min'),
#   ('Bb:maj7', 'D:min/b7', 'N'),
#   ('A:min7', 'E:min', 'F:maj(*3)'),
#   ('A:min/b3', 'Bb:maj', 'D:maj(2)'),
#   ('Bb:maj7/5', 'D:7(#9)', 'G'),
#   ('F#:min', 'G', 'G:7'),
#   ('A:maj6', 'C', 'E:min/5'),
#   ('Bb:maj7/5', 'D:min7', 'G:7'),
#   ('D:7', 'F#:min9', 'G'),
#   ('A:7', 'Bb:maj7/5', 'G'),
#   ('A:min7', 'G', 'G:(1)'),
#   ('A:7', 'A:sus4', 'N'),
#   ('C', 'G:(1)', 'G:aug'),
#   ('A', 'D/6', 'D/b7'),
#   ('B:(6)', 'D:min', 'F/7'),
#   ('A:7', 'Bb:maj7/5', 'C:maj6'),
#   ('A', 'A:sus2', 'G:(6)'),
#   ('Bb', 'F#:min', 'G#'),
#   ('B:min', 'B:min7', 'G:(1)'),
#   ('C', 'E/5', 'G:aug'),
#   ('Bb/5', 'F', 'G/3'),
#   ('D:7', 'D:min/b7', 'E:min'),
#   ('F:maj(*3)', 'G:min', 'N'),
#   ('A:min', 'Bb', 'D/b7'),
#   ('D/6', 'D/b7', 'E:min7(4)'),
#   ('B:min7', 'D:7', 'D:maj(2)'),
#   ('F:maj(*3)', 'G:(6)', 'G:(7)'),
#   ('A:sus4', 'F:maj(*3)', 'N'),
#   ('D', 'G:(1)', 'G:(7)'),
#   ('A:min7', 'C:maj7', 'D:sus4'),
#   ('A:min/b3', 'Bb:maj', 'G:min'),
#   ('B', 'D:min', 'F#:min9'),
#   ('B:min', 'F#:min', 'F/7'),
#   ('Bb:maj7', 'C', 'E:min/5'),
#   ('F/5', 'G#', 'G/3'),
#   ('A:sus2', 'D:7(#9)', 'G'),
#   ('D', 'F/5', 'G:min'),
#   ('Bb:maj7/5', 'C#:min', 'F'),
#   ('A:7', 'E:min/5', 'G'),
#   ('Bb:maj7', 'E:min7(4)', 'F'),
#   ('B:(6)', 'C', 'G:aug'),
#   ('A:sus2', 'E', 'N'),
#   ('Bb:maj7', 'D:min/b7', 'G:maj6/5'),
#   ('A:min/b3', 'Bb:maj', 'E'),
#   ('C:7', 'F', 'G:maj6/5'),
#   ('A:7', 'C:maj7', 'G:7'),
#   ('A:7', 'A:sus4', 'G#'),
#   ('E:min7(4)', 'F:7', 'G:7'),
#   ('D:7(#9)', 'F:7', 'G'),
#   ('Bb:maj7/5', 'E', 'G#'),
#   ('E:min/5', 'E:min7(4)', 'F'),
#   ('C', 'E', 'F#:min9'),
#   ('A', 'D/6', 'D:min'),
#   ('E:min', 'G:(1)', 'G:(7)'),
#   ('C#:min', 'D', 'D/b7'),
#   ('A:min7', 'G/3', 'G:7'),
#   ('A:min', 'F:maj(*3)', 'N'),
#   ('D:sus4', 'F:maj(*3)', 'N'),
#   ('Bb:maj7', 'C:maj6', 'F#:min9'),
#   ('B:(1)', 'F/5', 'G/3'),
#   ('A:7', 'B', 'F#:min9'),
#   ('A:min/b3', 'D:min', 'G/3'),
#   ('A:min', 'Bb', 'C:7'),
#   ('B', 'B:min', 'N'),
#   ('Bb:maj', 'F#:min', 'G#'),
#   ('D/5', 'D/6', 'F/7'),
#   ('A:min/b3', 'D:min', 'F#:min'),
#   ('E:min', 'F/7', 'F:maj(*3)'),
#   ('C:maj7', 'E:min7(4)', 'F:7'),
#   ('A:min/b3', 'D:7', 'D:min'),
#   ('D/5', 'D:min7', 'G'),
#   ('Bb:maj7', 'C:maj6', 'F/5'),
#   ('B:(6)', 'Bb', 'N'),
#   ('A:min7', 'Bb:maj7/5', 'C:maj6'),
#   ('A', 'Bb/5', 'C'),
#   ('D/5', 'E/5', 'G/3'),
#   ('Bb/5', 'F', 'G:(7)'),
#   ('Bb:maj7', 'D:min', 'F/7'),
#   ('B:min', 'Bb:maj7/5', 'C:maj6'),
#   ('A:min7', 'D:7', 'G:maj6/5'),
#   ('A:sus4/5', 'B:(6)', 'E'),
#   ('A:min', 'A:min7', 'D:maj(2)'),
#   ('E', 'E:min', 'F:maj(*3)'),
#   ('F', 'F/7', 'G#'),
#   ('Bb/7', 'F#:min9', 'G:min'),
#   ('B:(1)', 'D:min', 'D:min/b7'),
#   ('E:min7(4)', 'F', 'G:(1)'),
#   ('B:min', 'E/5', 'F#:min'),
#   ('B:min7', 'Bb:maj7/5', 'F'),
#   ('A:min/b3', 'A:min7', 'D:7'),
#   ('A', 'D/5', 'F/5'),
#   ('C:maj7', 'D', 'G:(6)'),
#   ('Bb', 'D:7(#9)', 'G:aug'),
#   ('A', 'D/5', 'D:sus4'),
#   ('C:7', 'D/b7', 'F'),
#   ('D/6', 'D/b7', 'E:min'),
# ...
#   ('B', 'F#:min', 'G:maj6/5'),
#   ('C', 'F/7', 'G'),
#   ('D', 'D/5', 'D:maj(2)'),
#   ('B:(1)', 'D', 'G:maj6/5'),
#   ('B:min7', 'D', 'N'),
#   ('A', 'A:min/b3', 'D'),
#   ('A', 'Bb/7', 'F#:min'),
#   ('Bb/5', 'D', 'N'),
#   ('Bb', 'D:7', 'E'),
#   ('B:(1)', 'B:(6)', 'G/3'),
#   ('A:min', 'A:sus2', 'C'),
#   ('C:maj7', 'D', 'G:maj6/5'),
#   ('A', 'Bb:maj7/5', 'F#:min'),
#   ('B', 'D:min/b7', 'E'),
#   ('Bb', 'G', 'G:maj6/5'),
#   ('D', 'G#', 'G:maj6/5'),
#   ('B:min7', 'G', 'N'),
#   ('A:min', 'D', 'D:min'),
#   ('B', 'E', 'G:maj7'),
#   ('A', 'D', 'F/5'),
#   ('A:sus4/5', 'B:min', 'G:min'),
#   ('A', 'B:min7', 'G'),
#   ('B', 'B:(1)', 'E'),
#   ('A', 'B:min7', 'F#:min'),
#   ('A', 'B', 'D'),
#   ('B:(1)', 'B:(6)', 'C#:min'),
#   ('C', 'F', 'F#:min9'),
#   ('A', 'C', 'F#:min'),
#   ('Bb:maj7/5', 'C', 'G'),
#   ('Bb/7', 'G', 'N'),
#   ('A', 'B:min', 'Bb:maj'),
#   ('C', 'F:maj(*3)', 'G'),
#   ('C', 'D:maj(2)', 'N'),
#   ('B:(1)', 'B:(6)', 'Bb:maj7'),
#   ('B:min7', 'F#:min', 'G:maj7'),
#   ('C', 'D', 'E:min7(4)'),
#   ('D', 'F', 'G:maj7'),
#   ('B:(1)', 'B:(6)', 'Bb:maj'),
#   ('Bb:maj7', 'D:7', 'E'),
#   ('E:min7(4)', 'F#:min', 'G:maj7'),
#   ('D', 'D:maj(2)', 'G:7'),
#   ('A', 'Bb:maj', 'D'),
#   ('B:min', 'G:aug', 'G:min'),
#   ('D:maj(2)', 'F', 'G'),
#   ('A', 'E:min/5', 'G'),
#   ('Bb:maj7/5', 'D', 'F#:min'),
#   ('D/5', 'E', 'F#:min'),
#   ('C', 'C#:min', 'G'),
#   ('B:min', 'E:min/5', 'G:min'),
#   ('B:(1)', 'B:(6)', 'F#:min9'),
#   ('E', 'F#:min', 'G:maj6/5'),
#   ('A:sus4/5', 'D', 'G'),
#   ('B:(1)', 'B:(6)', 'Bb'),
#   ('A', 'B:min', 'C:maj6'),
#   ('D', 'F#:min', 'F#:min9'),
#   ('D', 'F#:min', 'F/5'),
#   ('B', 'F#:min', 'F/7'),
#   ('E', 'F#:min', 'G:7'),
#   ('D', 'D:min7', 'E'),
#   ('B:min', 'Bb/5', 'G:min'),
#   ('D', 'G:7', 'N'),
#   ('C', 'G', 'G/3'),
#   ('Bb:maj7', 'G', 'N'),
#   ('A', 'B', 'N'),
#   ('A', 'F/7', 'G'),
#   ('B:min7', 'D', 'D:maj(2)'),
#   ('C:maj7', 'E', 'F#:min'),
#   ('D', 'F#:min', 'G:aug'),
#   ('A:min', 'B:(1)', 'D'),
#   ('C#:min', 'E:min', 'F#:min'),
#   ('D:7', 'D:min7', 'E'),
#   ('C:maj7', 'D', 'N'),
#   ('A:min', 'D', 'D:7(#9)'),
#   ('A:sus4/5', 'B', 'F#:min'),
#   ('B:min7', 'D', 'F#:min'),
#   ('D:sus4', 'G', 'N'),
#   ('A:sus2', 'C', 'N'),
#   ('A', 'C:maj6', 'G'),
#   ('F#:min', 'F:maj(*3)', 'G:maj7'),
#   ('D', 'F#:min', 'G:(1)'),
#   ('A:sus2', 'F#:min', 'G:maj7'),
#   ('F#:min', 'G:(1)', 'G:maj7'),
#   ('A', 'F#:min9', 'G'),
#   ('A:min', 'D', 'D:min/b7'),
#   ('Bb/7', 'D', 'F#:min'),
#   ('A', 'Bb:maj7/5', 'N'),
#   ('A', 'A:min7', 'F#:min'),
#   ('A:min', 'C', 'D/5'),
#   ('F#:min', 'G/3', 'G:maj7'),
#   ('E', 'E:min7(4)', 'F#:min'),
#   ('A:min', 'C', 'F#:min9'),
#   ('A:min', 'B:min7', 'D'),
#   ('D', 'D/6', 'N'),
#   ('A:sus4/5', 'Bb', 'G'),
#   ('C', 'D/b7', 'F'),
#   ('A:min7', 'B:(1)', 'B:(6)'),
#   ('F#:min', 'F:7', 'G:maj7'),
#   ('A:sus4', 'D', 'D:maj(2)'),
#   ('C', 'D:min7', 'G'),
#   ('A', 'G:7', 'N'),
#   ('E', 'F#:min', 'G:min'),
#   ('A', 'B:min', 'E:min/5'),
#   ('B', 'C:7', 'F#:min'),
#   ('B:min', 'F:7', 'G:min'),
#   ('B', 'E', 'G:maj6/5'),
#   ('Bb', 'F/5', 'G'),
#   ('B:min', 'D:maj(2)', 'G:min'),
#   ('Bb:maj7', 'D', 'E'),
#   ('A:sus4', 'C', 'G'),
#   ('A:min', 'C:maj6', 'D'),
#   ('A', 'F#:min', 'F#:min9'),
#   ('D', 'D:maj(2)', 'F:7'),
#   ('A', 'E', 'G:aug'),
#   ('D', 'D/5', 'G:maj6/5'),
#   ('D:7', 'E', 'G:(7)'),
#   ('A:min', 'D', 'D/6'),
#   ('Bb/5', 'D', 'F#:min'),
#   ('A:min', 'D', 'G:(1)'),
#   ('C', 'C:7', 'N'),
#   ('A:maj6', 'C', 'D'),
#   ('A', 'F#:min', 'G:aug'),
#   ('C#:min', 'F', 'F#:min'),
#   ('D', 'D:maj(2)', 'F/5'),
#   ('A', 'D/b7', 'N'),
#   ('C:maj7', 'D', 'D:maj(2)'),
#   ('Bb', 'D:min7', 'G'),
#   ('B:(1)', 'B:(6)', 'C:maj7'),
#   ('C', 'C:maj7', 'F'),
#   ('C#:min', 'C:7', 'F#:min'),
#   ('A', 'C:maj7', 'E'),
#   ('F', 'F#:min', 'G:maj7'),
#   ('B:min', 'G', 'G#'),
#   ('D', 'E:min', 'F'),
#   ('E:min/5', 'F', 'G'),
#   ('B:(1)', 'B:(6)', 'Bb:maj7/5'),
#   ('C', 'D/b7', 'G'),
#   ('A', 'D', 'D:7(#9)'),
#   ('Bb/7', 'C#:min', 'F#:min'),
#   ('B:min', 'D', 'G:maj6/5'),
#   ('Bb', 'C#:min', 'F#:min'),
#   ('D', 'D:min/b7', 'G'),
#   ('D:7', 'E', 'G:maj6/5'),
#   ('B:min', 'D:sus4', 'G:min'),
#   ('A:sus2', 'C', 'D'),
#   ('A', 'B:(1)', 'G'),
#   ('B', 'F', 'G'),
#   ('D', 'D:maj(2)', 'E:min/5'),
#   ('B:(1)', 'B:(6)', 'F:7'),
#   ('A', 'A:min/b3', 'E'),
#   ('D', 'D/6', 'F'),
#   ('Bb:maj7', 'C', 'G'),
#   ('A', 'B:min', 'F'),
#   ('D:min/b7', 'E', 'F#:min'),
#   ('C', 'E/5', 'N'),
#   ('D', 'G:maj7', 'N'),
#   ('D/6', 'G', 'N'),
#   ('F', 'F#:min', 'G'),
#   ('B', 'D:min', 'F#:min'),
#   ('Bb:maj7/5', 'G', 'N'),
#   ('C', 'F#:min9', 'N'),
#   ('A', 'G:maj7', 'N'),
#   ('A:7', 'B', 'F#:min'),
#   ('Bb/5', 'D', 'G:maj6/5'),
#   ('B:min', 'G', 'G:(7)'),
#   ('C', 'C:7', 'G'),
#   ('D:maj(2)', 'G', 'N'),
#   ('B', 'F#:min', 'G/3'),
#   ('A', 'F:7', 'N'),
#   ('D', 'E', 'G:7'),
#   ('A:min', 'C', 'C:maj6'),
#   ('B', 'B:min', 'G:min'),
#   ('A:maj6', 'C', 'F'),
#   ('A:min/b3', 'G', 'N'),
#   ('A', 'A:min/b3', 'N'),
#   ('D', 'D:maj(2)', 'F#:min9'),
#   ('A:maj6', 'D', 'E'),
#   ('C#:min', 'C:maj7', 'F#:min'),
#   ('F/5', 'G', 'N'),
#   ('C', 'G:(7)', 'N'),
#   ('A:min', 'A:sus4/5', 'C'),
#   ('A', 'F#:min9', 'N'),
#   ('Bb:maj7', 'C', 'N'),
#   ('A:sus4/5', 'G', 'N'),
#   ...},
#  '111D': {('A', 'A:sus4', 'B:min'),
#   ('A', 'A:sus4', 'D'),
#   ('A', 'A:sus4', 'E'),
#   ('A', 'A:sus4', 'F#:min'),
#   ('A', 'A:sus4', 'G'),
#   ('A', 'A:sus4', 'N'),
#   ('A', 'A:sus4/5', 'B:min'),
#   ('A', 'A:sus4/5', 'D'),
#   ('A', 'A:sus4/5', 'E'),
#   ('A', 'A:sus4/5', 'F#:min'),
#   ('A', 'A:sus4/5', 'G'),
#   ('A', 'A:sus4/5', 'N'),
#   ('A', 'B:(6)', 'E'),
#   ('A', 'B:min', 'D/5'),
#   ('A', 'B:min', 'E:min'),
#   ('A', 'B:min', 'E:min7(4)'),
#   ('A', 'C', 'E'),
#   ('A', 'C:maj7', 'G'),
#   ('A', 'D', 'D/5'),
#   ('A', 'D', 'D:sus4'),
#   ('A', 'D', 'E:min'),
#   ('A', 'D', 'E:min7(4)'),
#   ('A', 'D', 'G:(6)'),
#   ('A', 'D', 'G:min'),
#   ('A', 'D/5', 'E'),
#   ('A', 'D/5', 'F#:min'),
#   ('A', 'D/5', 'N'),
#   ('A', 'D:7(#9)', 'G'),
#   ('A', 'E', 'E:min'),
#   ('A', 'E', 'E:min7(4)'),
#   ('A', 'E', 'F'),
#   ('A', 'E:min', 'F#:min'),
#   ('A', 'E:min', 'G'),
#   ('A', 'E:min', 'N'),
#   ('A', 'E:min7(4)', 'F#:min'),
#   ('A', 'E:min7(4)', 'G'),
#   ('A', 'E:min7(4)', 'N'),
#   ('A', 'F', 'N'),
#   ('A', 'F#:min', 'G#'),
#   ('A:7', 'A:min', 'D'),
#   ('A:7', 'C', 'D'),
#   ('A:7', 'D', 'D:maj(2)'),
#   ('A:7', 'D', 'E'),
#   ('A:7', 'D', 'F'),
#   ('A:7', 'D', 'F#:min'),
#   ('A:7', 'D', 'G:maj6/5'),
#   ('A:7', 'D', 'N'),
#   ('A:maj6', 'C', 'N'),
#   ('A:maj6', 'D', 'N'),
#   ('A:maj6', 'G', 'N'),
#   ('A:min', 'Bb:maj', 'C'),
#   ('A:min', 'C', 'G:7'),
#   ('A:min', 'C', 'G:aug'),
#   ('A:min', 'C', 'G:min'),
#   ('A:min', 'D', 'D:sus4'),
#   ('A:min', 'D', 'G:(6)'),
#   ('A:min', 'D', 'G:min'),
#   ('A:min/b3', 'Bb', 'G'),
#   ('B', 'B:(6)', 'E'),
#   ('B', 'B:min', 'E'),
#   ('B', 'C', 'E'),
#   ('B', 'E', 'F'),
#   ('B', 'E', 'F#:min9'),
#   ('B', 'E', 'G'),
#   ('B', 'F#:min', 'F#:min9'),
#   ('B', 'F#:min', 'G#'),
#   ('B:(1)', 'B:(6)', 'N'),
#   ('B:(6)', 'D', 'E'),
#   ('B:(6)', 'D:7', 'E'),
#   ('B:(6)', 'E', 'F#:min'),
#   ('B:min', 'Bb/7', 'G:min'),
#   ('B:min', 'C:maj7', 'G'),
#   ('B:min', 'D', 'E'),
#   ('B:min', 'D/5', 'G'),
#   ('B:min', 'D:7', 'E'),
#   ('B:min', 'D:7', 'G'),
#   ('B:min', 'D:7(#9)', 'G'),
#   ('B:min', 'D:min', 'G'),
#   ('B:min', 'F#:min', 'G'),
#   ('B:min', 'F#:min', 'G:min'),
#   ('B:min', 'G:min', 'N'),
#   ('B:min7', 'D:7', 'E'),
#   ('Bb', 'C', 'D'),
#   ('Bb', 'C', 'N'),
#   ('Bb', 'C:maj7', 'G'),
#   ('Bb', 'D', 'F'),
#   ('Bb', 'D/5', 'G'),
#   ('Bb', 'D:7', 'G'),
#   ('Bb', 'D:min', 'G'),
#   ('Bb', 'D:min/b7', 'G'),
#   ('Bb', 'E:min/5', 'G'),
#   ('Bb', 'G', 'G/3'),
#   ('Bb/5', 'D', 'F'),
#   ('Bb/5', 'F', 'G'),
#   ('Bb:maj', 'C', 'D'),
#   ('Bb:maj', 'C', 'F'),
#   ('Bb:maj', 'C', 'G'),
#   ('Bb:maj', 'C', 'N'),
#   ('Bb:maj7/5', 'C', 'F'),
#   ('Bb:maj7/5', 'D', 'F'),
#   ('Bb:maj7/5', 'F', 'G'),
#   ('C', 'C:7', 'F'),
#   ('C', 'C:maj7', 'G'),
#   ('C', 'D', 'G:(6)'),
#   ('C', 'D', 'G:7'),
#   ('C', 'D', 'G:aug'),
#   ('C', 'D/5', 'G'),
#   ('C', 'D:7(#9)', 'G'),
#   ('C', 'D:min', 'G'),
#   ('C', 'E', 'F#:min'),
#   ('C', 'F', 'G:7'),
#   ('C', 'F', 'G:min'),
#   ('C', 'G', 'G:min'),
#   ('C', 'G:7', 'N'),
#   ('C', 'G:aug', 'N'),
#   ('C', 'G:min', 'N'),
#   ('C#:min', 'F#:min', 'G#'),
#   ('C:7', 'D', 'F'),
#   ('C:7', 'F', 'G'),
#   ('C:maj7', 'D', 'G'),
#   ('C:maj7', 'F', 'G'),
#   ('C:maj7', 'G', 'N'),
#   ('D', 'D/5', 'G'),
#   ('D', 'D:7(#9)', 'G'),
#   ('D', 'D:maj(2)', 'D:sus4'),
#   ('D', 'D:maj(2)', 'G:(6)'),
#   ('D', 'D:maj(2)', 'G:min'),
#   ('D', 'D:min', 'G'),
#   ('D', 'D:sus4', 'E'),
#   ('D', 'D:sus4', 'F'),
#   ('D', 'D:sus4', 'F#:min'),
#   ('D', 'D:sus4', 'G'),
#   ('D', 'D:sus4', 'G:maj6/5'),
#   ('D', 'D:sus4', 'N'),
#   ('D', 'E', 'G:(6)'),
#   ('D', 'E', 'G:min'),
#   ('D', 'F', 'G:(6)'),
#   ('D', 'F', 'G:aug'),
#   ('D', 'F', 'G:min'),
#   ('D', 'F#:min', 'G#'),
#   ('D', 'F#:min', 'G:(6)'),
#   ('D', 'F#:min', 'G:min'),
#   ('D', 'G', 'G:(6)'),
#   ('D', 'G', 'G:min'),
#   ('D', 'G:(6)', 'G:maj6/5'),
#   ('D', 'G:(6)', 'N'),
#   ('D', 'G:maj6/5', 'G:min'),
#   ('D', 'G:min', 'N'),
#   ('D/5', 'F', 'G'),
#   ('D/5', 'G', 'N'),
#   ('D:7', 'E', 'F'),
#   ('D:7', 'F', 'G'),
#   ('D:7', 'G', 'N'),
#   ('D:7(#9)', 'F', 'G'),
#   ('D:7(#9)', 'G', 'N'),
#   ('D:min', 'F', 'G'),
#   ('D:min', 'G', 'N'),
#   ('E', 'F', 'F#:min'),
#   ('E', 'F#:min', 'G'),
#   ('F#:min', 'G#', 'G:maj7')},
#  '111U': {('A', 'A:7', 'B:min'),
#   ('A', 'A:7', 'E'),
#   ('A', 'A:7', 'F#:min'),
#   ('A', 'A:7', 'N'),
#   ('A', 'A:maj6', 'B:min'),
#   ('A', 'A:maj6', 'D'),
#   ('A', 'A:maj6', 'E'),
#   ('A', 'A:maj6', 'F#:min'),
#   ('A', 'A:maj6', 'G'),
#   ('A', 'A:min', 'G'),
#   ('A', 'A:min7', 'D'),
#   ('A', 'A:min7', 'G'),
#   ('A', 'A:sus2', 'B:min'),
#   ('A', 'A:sus2', 'D'),
#   ('A', 'A:sus2', 'E'),
#   ('A', 'A:sus2', 'F#:min'),
#   ('A', 'A:sus2', 'G'),
#   ('A', 'A:sus2', 'N'),
#   ('A', 'B:(6)', 'N'),
#   ('A', 'B:min', 'B:min7'),
#   ('A', 'B:min', 'C#:min'),
#   ('A', 'B:min', 'D:7'),
#   ('A', 'B:min', 'D:min'),
#   ('A', 'C#:min', 'D'),
#   ('A', 'C#:min', 'G'),
#   ('A', 'C#:min', 'N'),
#   ('A', 'D', 'D/b7'),
#   ('A', 'D', 'D:min'),
#   ('A', 'D', 'E/5'),
#   ('A', 'D:7', 'F#:min'),
#   ('A', 'D:7', 'N'),
#   ('A', 'D:min', 'E'),
#   ('A', 'D:min', 'F#:min'),
#   ('A', 'D:min', 'N'),
#   ('A', 'E', 'G#'),
#   ('A', 'F:maj(*3)', 'N'),
#   ('A', 'G', 'G:7'),
#   ('A', 'G', 'G:aug'),
#   ('A', 'G:(1)', 'N'),
#   ('A:7', 'B:min', 'G'),
#   ('A:7', 'Bb', 'G'),
#   ('A:7', 'C', 'G'),
#   ('A:7', 'F', 'G'),
#   ('A:7', 'G', 'N'),
#   ('A:min', 'A:min7', 'C'),
#   ('A:min', 'B:min', 'G'),
#   ('A:min', 'Bb', 'D'),
#   ('A:min', 'Bb/5', 'C'),
#   ('A:min', 'C', 'D:7'),
#   ('A:min', 'C', 'D:sus4'),
#   ('A:min', 'C', 'E'),
#   ('A:min', 'C', 'E:min/5'),
#   ('A:min', 'D', 'D/b7'),
#   ('A:min', 'D', 'D:7'),
#   ('A:min', 'D', 'E/5'),
#   ('A:min', 'F', 'G'),
#   ('A:min', 'G', 'N'),
#   ('A:min7', 'B:min', 'G'),
#   ('A:min7', 'Bb', 'G'),
#   ('A:min7', 'C', 'D'),
#   ('A:min7', 'C', 'G'),
#   ('A:min7', 'D', 'D:maj(2)'),
#   ('A:min7', 'D', 'E'),
#   ('A:min7', 'D', 'F'),
#   ('A:min7', 'D', 'F#:min'),
#   ('A:min7', 'D', 'G:maj6/5'),
#   ('A:min7', 'D', 'N'),
#   ('A:min7', 'D:7', 'E'),
#   ('A:min7', 'F', 'G'),
#   ('A:min7', 'G', 'N'),
#   ('A:sus4/5', 'C', 'F'),
#   ('A:sus4/5', 'D', 'F'),
#   ('A:sus4/5', 'F', 'G'),
#   ('B', 'B:min', 'F#:min'),
#   ('B', 'C#:min', 'E'),
#   ('B', 'E', 'G#'),
#   ('B', 'E', 'N'),
#   ('B:(1)', 'B:(6)', 'E'),
#   ('B:(6)', 'C', 'N'),
#   ('B:(6)', 'D', 'N'),
#   ('B:(6)', 'G', 'N'),
#   ('B:min', 'B:min7', 'G'),
#   ('B:min', 'B:min7', 'G:min'),
#   ('B:min', 'C', 'G:min'),
#   ('B:min', 'C', 'N'),
#   ('B:min', 'C#:min', 'F#:min'),
#   ('B:min', 'D', 'F#:min'),
#   ('B:min', 'D', 'G:min'),
#   ('B:min', 'D', 'N'),
#   ('B:min', 'E', 'G:min'),
#   ('B:min', 'F#:min', 'G:maj7'),
#   ('B:min', 'G', 'G:7'),
#   ('B:min', 'G', 'G:aug'),
#   ('Bb', 'Bb/7', 'G'),
#   ('Bb', 'E', 'G'),
#   ('Bb', 'G', 'G:aug'),
#   ('Bb/5', 'C', 'D'),
#   ('Bb/5', 'C', 'G'),
#   ('Bb/5', 'C', 'N'),
#   ('C', 'D', 'D/b7'),
#   ('C', 'D', 'E/5'),
#   ('C', 'D', 'E:min/5'),
#   ('C', 'D:7', 'F'),
#   ('C', 'D:7', 'N'),
#   ('C', 'D:min7', 'F'),
#   ('C', 'D:sus4', 'F'),
#   ('C', 'D:sus4', 'G'),
#   ('C', 'D:sus4', 'N'),
#   ('C', 'E:min/5', 'F'),
#   ('C', 'E:min/5', 'G'),
#   ('C', 'E:min/5', 'N'),
#   ('C', 'E:min7(4)', 'F'),
#   ('C', 'F', 'F/5'),
#   ('C', 'F', 'F/7'),
#   ('C', 'F', 'F:7'),
#   ('C', 'F:maj(*3)', 'N'),
#   ('C', 'G:(1)', 'N'),
#   ('C#:min', 'D', 'E'),
#   ('C#:min', 'D:7', 'E'),
#   ('C#:min', 'F#:min', 'F#:min9'),
#   ('D', 'D/b7', 'D:maj(2)'),
#   ('D', 'D/b7', 'E'),
#   ('D', 'D/b7', 'F'),
#   ('D', 'D/b7', 'F#:min'),
#   ('D', 'D/b7', 'G'),
#   ('D', 'D/b7', 'G:maj6/5'),
#   ('D', 'D/b7', 'N'),
#   ('D', 'D:7', 'D:maj(2)'),
#   ('D', 'D:7', 'F'),
#   ('D', 'D:7', 'F#:min'),
#   ('D', 'D:7', 'G:maj6/5'),
#   ('D', 'D:7', 'N'),
#   ('D', 'D:maj(2)', 'E/5'),
#   ('D', 'D:min7', 'F'),
#   ('D', 'E', 'E/5'),
#   ('D', 'E', 'G#'),
#   ('D', 'E/5', 'F'),
#   ('D', 'E/5', 'F#:min'),
#   ('D', 'E/5', 'G'),
#   ('D', 'E/5', 'G:maj6/5'),
#   ('D', 'E/5', 'N'),
#   ('D', 'E:min7(4)', 'F'),
#   ('D', 'F', 'F/5'),
#   ('D', 'F', 'F/7'),
#   ('D', 'F', 'F:7'),
#   ('D', 'F:maj(*3)', 'N'),
#   ('D', 'G', 'G:7'),
#   ('D', 'G', 'G:aug'),
#   ('D', 'G:(1)', 'N'),
#   ('D:7', 'E', 'E:min'),
#   ('D:7', 'E', 'G#'),
#   ('D:7', 'E', 'G:7'),
#   ('D:7', 'E', 'N'),
#   ('D:min7', 'F', 'G'),
#   ('E', 'F#:min', 'N'),
#   ('E:min7(4)', 'F', 'G'),
#   ('F', 'F/5', 'G'),
#   ('F', 'F/7', 'G'),
#   ('F', 'F:7', 'G'),
#   ('F', 'G', 'G:7'),
#   ('F:maj(*3)', 'G', 'N'),
#   ('G', 'G:(1)', 'N'),
#   ('G', 'G:7', 'N'),
#   ('G', 'G:aug', 'N')},
#  '120C': {('A', 'A:7', 'D'),
#   ('A', 'A:maj6', 'N'),
#   ('A', 'D:7', 'G'),
#   ('A', 'D:min', 'G'),
#   ('A:7', 'D', 'G'),
#   ('A:min', 'Bb', 'C'),
#   ('A:min', 'Bb', 'G'),
#   ('B:min', 'E', 'F#:min'),
#   ('Bb', 'D:7(#9)', 'G'),
#   ('Bb', 'G', 'G:7'),
#   ('Bb/5', 'C', 'F'),
#   ('C', 'D', 'D:sus4'),
#   ('C', 'D:7', 'G'),
#   ('C', 'E', 'N'),
#   ('C', 'G', 'G:7'),
#   ('C', 'G', 'G:aug'),
#   ('D', 'D:7', 'G'),
#   ('D:7', 'E', 'G'),
#   ('E', 'F#:min', 'G#'),
#   ('E', 'G', 'N'),
#   ('F', 'G', 'G:aug')},
#  '120D': {('A', 'D/5', 'G'),
#   ('Bb', 'C', 'F'),
#   ('C', 'D', 'G:min'),
#   ('C', 'D:7', 'E'),
#   ('C', 'F', 'G:aug')},
#  '120U': {('A', 'A:7', 'G'),
#   ('A', 'C#:min', 'E'),
#   ('A', 'D', 'D:7'),
#   ('A:min', 'A:min7', 'D'),
#   ('A:min7', 'D', 'G'),
#   ('B:min', 'E', 'G'),
#   ('C', 'D', 'D:7'),
#   ('C', 'E', 'F'),
#   ('C', 'E', 'G'),
#   ('E', 'F', 'G')},
#  '201': {('A', 'A:min', 'D'),
#   ('A', 'B', 'E'),
#   ('A', 'B', 'F#:min'),
#   ('A', 'B:min', 'D'),
#   ('A', 'B:min', 'G:min'),
#   ('A', 'Bb', 'G'),
#   ('A', 'C', 'D'),
#   ('A', 'C', 'G'),
#   ('A', 'C', 'N'),
#   ('A', 'D', 'D:maj(2)'),
#   ('A', 'D', 'F'),
#   ('A', 'D', 'G:maj6/5'),
#   ('A', 'F', 'G'),
#   ('A', 'F#:min', 'G'),
#   ('A', 'F#:min', 'G:maj7'),
#   ('A', 'F#:min', 'N'),
#   ('A:min', 'C', 'F'),
#   ('A:min', 'C', 'N'),
#   ('A:min', 'D', 'D:maj(2)'),
#   ('A:min', 'D', 'E'),
#   ('A:min', 'D', 'F'),
#   ('A:min', 'D', 'F#:min'),
#   ('A:min', 'D', 'G:maj6/5'),
#   ('A:min', 'D', 'N'),
#   ('B', 'C#:min', 'F#:min'),
#   ('B', 'D', 'E'),
#   ('B', 'D', 'F#:min'),
#   ('B', 'D:7', 'E'),
#   ('B', 'F#:min', 'G:maj7'),
#   ('B:min', 'Bb', 'G'),
#   ('B:min', 'C', 'G'),
#   ('B:min', 'D', 'G'),
#   ('B:min', 'F', 'G'),
#   ('B:min', 'G', 'G:min'),
#   ('Bb', 'D', 'G'),
#   ('Bb', 'G', 'N'),
#   ('C', 'D', 'D:maj(2)'),
#   ('C', 'D', 'F#:min'),
#   ('C', 'D', 'G:maj6/5'),
#   ('C#:min', 'D', 'F#:min'),
#   ('C#:min', 'F#:min', 'G:maj7'),
#   ('D', 'D:maj(2)', 'E'),
#   ('D', 'D:maj(2)', 'F'),
#   ('D', 'D:maj(2)', 'F#:min'),
#   ('D', 'D:maj(2)', 'G'),
#   ('D', 'D:maj(2)', 'G:maj6/5'),
#   ('D', 'D:maj(2)', 'N'),
#   ('D', 'E', 'G:maj6/5'),
#   ('D', 'F', 'F#:min'),
#   ('D', 'F', 'G:maj6/5'),
#   ('D', 'F#:min', 'G'),
#   ('D', 'F#:min', 'G:maj6/5'),
#   ('D', 'F#:min', 'G:maj7'),
#   ('D', 'F#:min', 'N'),
#   ('D', 'G', 'G:maj6/5'),
#   ('D', 'G:maj6/5', 'N'),
#   ('D:7', 'E', 'F#:min'),
#   ('E', 'F#:min', 'G:maj7')},
#  '210': {('A', 'B:min', 'E'),
#   ('A', 'B:min', 'F#:min'),
#   ('A', 'B:min', 'N'),
#   ('A', 'C#:min', 'F#:min'),
#   ('A', 'D:7', 'E'),
#   ('A', 'E', 'G'),
#   ('A', 'E', 'N'),
#   ('A:min', 'C', 'G'),
#   ('A:min', 'D', 'G'),
#   ('B:min', 'G', 'N'),
#   ('Bb', 'C', 'G'),
#   ('Bb', 'F', 'G'),
#   ('C', 'D', 'E'),
#   ('C', 'F', 'N'),
#   ('C#:min', 'E', 'F#:min'),
#   ('D', 'D:7', 'E'),
#   ('D', 'E', 'F'),
#   ('D', 'E', 'G'),
#   ('D', 'E', 'N'),
#   ('D', 'F', 'N'),
#   ('F', 'G', 'N')},
#  '300': {('A', 'B:min', 'G'),
#   ('A', 'D', 'E'),
#   ('A', 'D', 'F#:min'),
#   ('A', 'D', 'G'),
#   ('A', 'D', 'N'),
#   ('A', 'E', 'F#:min'),
#   ('A', 'G', 'N'),
#   ('A:min', 'C', 'D'),
#   ('B', 'E', 'F#:min'),
#   ('C', 'D', 'F'),
#   ('C', 'D', 'G'),
#   ('C', 'D', 'N'),
#   ('C', 'F', 'G'),
#   ('C', 'G', 'N'),
#   ('D', 'E', 'F#:min'),
#   ('D', 'F', 'G'),
#   ('D', 'G', 'N')}}

# %%
from collections import Counter
counter=Counter(new)
print(counter)
# Out:
# Counter({('F#:min9', 'E:min/5', 'F:7'): 1, ('G:(7)', 'E:min', 'Bb/7'): 1, ('F#:min', 'F:7', 'C:maj6'): 1, ('A:maj6', 'A:min7', 'G:maj6/5'): 1, ('A:maj6', 'A:min/b3', 'E:min7(4)'): 1, ('D', 'C', 'A:sus2'): 1, ('A:sus4', 'G:maj7', 'A:min7'): 1, ('A:sus4', 'F#:min9', 'Bb/5'): 1, ('A:7', 'A:min7', 'D:min7'): 1, ('D', 'A:7', 'B:(1)'): 1, ('D:sus4', 'D:min/b7', 'Bb:maj'): 1, ('B:(6)', 'Bb:maj7', 'A:min/b3'): 1, ('N', 'A:sus2', 'D:min/b7'): 1, ('D', 'A:min7', 'Bb:maj'): 1, ('D/b7', 'F#:min9', 'Bb'): 1, ('Bb', 'G:7', 'G/3'): 1, ('A:min/b3', 'D:min7', 'F/5'): 1, ('G#', 'G:aug', 'Bb/7'): 1, ('G:maj7', 'E:min', 'F:maj(*3)'): 1, ('C#:min', 'A:min', 'F/7'): 1, ('D', 'D:sus4', 'C:maj7'): 1, ('F', 'E:min7(4)', 'F:7'): 1, ('A', 'G:7', 'F/7'): 1, ('D', 'D:sus4', 'B:(1)'): 1, ('D:7(#9)', 'G:maj6/5', 'D:min/b7'): 1, ('D:7(#9)', 'B:min7', 'Bb/7'): 1, ('A:maj6', 'A:sus2', 'C:maj6'): 1, ('D/6', 'A:sus4/5', 'Bb:maj'): 1, ('G:maj7', 'G:maj6/5', 'Bb:maj7'): 1, ('A:7', 'G:(7)', 'A:min/b3'): 1, ('E', 'B', 'C:maj6'): 1, ('E', 'D:7(#9)', 'G:7'): 1, ('A:sus4/5', 'Bb/7', 'F:7'): 1, ('D', 'C', 'F/7'): 1, ('B:(6)', 'G:aug', 'Bb:maj'): 1, ('E', 'A', 'F#:min9'): 1, ('D', 'G:(6)', 'E:min7(4)'): 1, ('D', 'A:7', 'C:maj6'): 1, ('B:min', 'D', 'Bb:maj'): 1, ('N', 'B:(1)', 'Bb/7'): 1, ('F#:min', 'D:7', 'Bb:maj'): 1, ('D/6', 'F#:min9', 'G:(7)'): 1, ('E:min/5', 'A:min/b3', 'F/5'): 1, ('A:7', 'D/5', 'B:(1)'): 1, ('G:(1)', 'E:min', 'C:7'): 1, ('G', 'G#', 'G:(7)'): 1, ('G:maj7', 'F:maj(*3)', 'A:min/b3'): 1, ('B:min', 'C#:min', 'G:(1)'): 1, ('D/5', 'B:(6)', 'G:aug'): 1, ('G:maj7', 'E/5', 'Bb/7'): 1, ('B:min7', 'D:min/b7', 'F:7'): 1, ('A', 'D:7(#9)', 'Bb:maj'): 1, ('A:maj6', 'D/5', 'G:(6)'): 1, ('C#:min', 'A:7', 'G:7'): 1, ('E:min/5', 'G:maj6/5', 'A:sus4/5'): 1, ('A', 'F:maj(*3)', 'C:7'): 1, ('C#:min', 'D', 'C'): 1, ('A:maj6', 'D/5', 'B:(6)'): 1, ('G:aug', 'G:7', 'G/3'): 1, ('B:min7', 'E:min', 'Bb:maj7/5'): 1, ('A', 'G:aug', 'E:min7(4)'): 1, ('D:sus4', 'B:min7', 'F/7'): 1, ('B', 'G:maj7', 'D:min'): 1, ('G:maj6/5', 'F/7', 'F:7'): 1, ('F', 'B:(1)', 'A:min7'): 1, ('A:min', 'D:7(#9)', 'B:min7'): 1, ('F#:min', 'B:(1)', 'E:min'): 1, ('A:7', 'B', 'D:7(#9)'): 1, ('E', 'A:7', 'F/7'): 1, ('F#:min', 'G:aug', 'C:maj7'): 1, ('F', 'A:min', 'C:7'): 1, ('E', 'G:min', 'G:(7)'): 1, ('A:min', 'D:sus4', 'A:min/b3'): 1, ('D/6', 'B', 'D:7(#9)'): 1, ('F#:min', 'G:aug', 'D:7(#9)'): 1, ('B:(1)', 'B:min7', 'Bb/5'): 1, ('F', 'A:sus2', 'C:7'): 1, ('C', 'A:min7', 'C:maj6'): 1, ('A:sus4', 'E/5', 'Bb/7'): 1, ('G:aug', 'E:min7(4)', 'F:7'): 1, ('B:(1)', 'B:min7', 'A:sus4/5'): 1, ('B:min', 'C#:min', 'C:maj7'): 1, ('G', 'D:7(#9)', 'E:min7(4)'): 1, ('A:sus2', 'B', 'Bb'): 1, ('C#:min', 'D/5', 'G:(1)'): 1, ('F#:min', 'B:(6)', 'C:maj7'): 1, ('D/6', 'D:maj(2)', 'A:min7'): 1, ('F#:min', 'A:sus4', 'G:(1)'): 1, ('B:(1)', 'G#', 'G/3'): 1, ('G', 'A', 'F#:min'): 1, ('A:sus4', 'B', 'E/5'): 1, ('Bb/7', 'F:7', 'Bb:maj7/5'): 1, ('B:min', 'A:sus2', 'G:(7)'): 1, ('B', 'B:(1)', 'E:min7(4)'): 1, ('D:7', 'Bb', 'C:maj7'): 1, ('B:min7', 'A:min/b3', 'Bb/5'): 1, ('D/6', 'G:(1)', 'C:maj6'): 1, ('D:7', 'A:min7', 'C:maj7'): 1, ('C#:min', 'G:maj7', 'Bb:maj7'): 1, ('G#', 'G:(1)', 'Bb:maj'): 1, ('D/5', 'D:sus4', 'E:min/5'): 1, ('E', 'F#:min9', 'G/3'): 1, ('B', 'D:min', 'E:min7(4)'): 1, ('D/6', 'Bb:maj7', 'F/5'): 1, ('E', 'A:7', 'A:sus2'): 1, ('C', 'B:(6)', 'C:7'): 1, ('F', 'A:sus2', 'Bb:maj7'): 1, ('B', 'A:min7', 'E:min7(4)'): 1, ('E', 'D/6', 'E:min/5'): 1, ('F#:min', 'D', 'F/5'): 1, ('F#:min', 'B:min7', 'A:min7'): 1, ('F', 'D/b7', 'F:maj(*3)'): 1, ('F#:min', 'B', 'Bb/5'): 1, ('A:min', 'B', 'Bb/5'): 1, ('C', 'E/5', 'F:7'): 1, ('D/5', 'B:(6)', 'B:(1)'): 1, ('D:sus4', 'F/7', 'G/3'): 1, ('E', 'F', 'D/6'): 1, ('E', 'C', 'A:sus4'): 1, ('C', 'F#:min9', 'E:min7(4)'): 1, ('D:maj(2)', 'G:aug', 'D:min7'): 1, ('D', 'D/6', 'G#'): 1, ('B:(1)', 'G#', 'Bb:maj'): 1, ('B:min7', 'C:maj6', 'F/5'): 1, ('N', 'F#:min', 'C'): 1, ('N', 'D/5', 'E:min/5'): 1, ('F#:min9', 'A:min7', 'Bb:maj7/5'): 1, ('C#:min', 'G:min', 'G:7'): 1, ('D/b7', 'Bb:maj7', 'F/5'): 1, ('D:s ...
