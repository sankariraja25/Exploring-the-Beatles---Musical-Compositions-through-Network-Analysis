# %%
#9, 10, 11
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
#motifs, chord pregressoionn and trials

# %%
pwd
# Out:
# '/content'

# %%
album01 = pd.read_csv('/content/album_11_edges.csv')
G = nx.from_pandas_edgelist(album01, source="Source", target="Target", create_using=nx.DiGraph())
nx.draw(G, with_labels=True)

# %% [markdown]
# ## Visuals

# %%
nx.draw(G,node_size=300,font_size=8,  with_labels=True)

# %%
plt.figure(3,figsize=(12,12)) 
nx.draw(G, node_size=400,font_size=12,  with_labels=True)

# %% [markdown]
# ## Triads

# %%
# Triad Consensus
nx.triadic_census(G)
# Out:
# {'003': 270747,
#  '012': 24716,
#  '021C': 948,
#  '021D': 377,
#  '021U': 426,
#  '030C': 14,
#  '030T': 38,
#  '102': 4133,
#  '111D': 470,
#  '111U': 466,
#  '120C': 48,
#  '120D': 20,
#  '120U': 20,
#  '201': 147,
#  '210': 38,
#  '300': 13}

# %%
import networkx as nx
import itertools


def _tricode(G, v, u, w):
    """Returns the integer code of the given triad.

    This is some fancy magic that comes from Batagelj and Mrvar's paper. It
    treats each edge joining a pair of `v`, `u`, and `w` as a bit in
    the binary representation of an integer.

    """
    combos = ((v, u, 1), (u, v, 2), (v, w, 4), (w, v, 8), (u, w, 16),
              (w, u, 32))
    return sum(x for u, v, x in combos if v in G[u])


# G = nx.DiGraph()
# G.add_nodes_from([1, 2, 3, 4, 5])
# G.add_edges_from([(1, 2), (2, 3), (2, 4), (4, 5)])

#: The integer codes representing each type of triad.
#: Triads that are the same up to symmetry have the same code.
TRICODES = (1, 2, 2, 3, 2, 4, 6, 8, 2, 6, 5, 7, 3, 8, 7, 11, 2, 6, 4, 8, 5, 9,
            9, 13, 6, 10, 9, 14, 7, 14, 12, 15, 2, 5, 6, 7, 6, 9, 10, 14, 4, 9,
            9, 12, 8, 13, 14, 15, 3, 7, 8, 11, 7, 12, 14, 15, 8, 14, 13, 15,
            11, 15, 15, 16)

#: The names of each type of triad. The order of the elements is
#: important: it corresponds to the tricodes given in :data:`TRICODES`.
TRIAD_NAMES = ('003', '012', '102', '021D', '021U', '021C', '111D', '111U',
               '030T', '030C', '201', '120D', '120U', '120C', '210', '300')

#: A dictionary mapping triad code to triad name.
TRICODE_TO_NAME = {i: TRIAD_NAMES[code - 1] for i, code in enumerate(TRICODES)}

triad_nodes = {name: set([]) for name in TRIAD_NAMES}
m = {v: i for i, v in enumerate(G)}
for v in G:
    vnbrs = set(G.pred[v]) | set(G.succ[v])
    for u in vnbrs:
        if m[u] > m[v]:
            unbrs = set(G.pred[u]) | set(G.succ[u])
            neighbors = (vnbrs | unbrs) - {u, v}
            not_neighbors = set(G.nodes()) - neighbors - {u, v}
            # Find dyadic triads
            for w in not_neighbors:
                if v in G[u] and u in G[v]:
                    triad_nodes['102'].add(tuple(sorted([u, v, w])))
                else:
                    triad_nodes['012'].add(tuple(sorted([u, v, w])))
            for w in neighbors:
                if m[u] < m[w] or (m[v] < m[w] < m[u] and
                                   v not in G.pred[w] and
                                   v not in G.succ[w]):
                    code = _tricode(G, v, u, w)
                    triad_nodes[TRICODE_TO_NAME[code]].add(
                        tuple(sorted([u, v, w])))
# find null triads
all_tuples = set()
for s in triad_nodes.values():
    all_tuples = all_tuples.union(s)
new = triad_nodes['003'] = set(itertools.combinations(G.nodes(), 3)).difference(all_tuples)

triad_nodes
# Out:
# {'003': {('D', 'Bb', 'E:sus4(b7)'),
#   ('G/3', 'A/2', 'D/3'),
#   ('E:min', 'B/5', 'D:min/4'),
#   ('A', 'E:sus4', 'C:maj7'),
#   ('Bb', 'A:7(13)', 'D:dim7'),
#   ('N', 'A/2', 'G#:aug'),
#   ('A/7', 'A:7/3', 'B:9'),
#   ('C/2', 'E:aug', 'E/6'),
#   ('D/6', 'E', 'C#:min/b7'),
#   ('D/3', 'G#:min7/b3', 'E/b7'),
#   ('C:7', 'D:maj6', 'E/b7'),
#   ('C#:min/5', 'D:min7(2,*b3,4)', 'D#:(1,4)'),
#   ('D:min', 'C:7', 'E:min/b7'),
#   ('E:sus4(b7)', 'G:min7', 'D/2'),
#   ('C', 'C:(1)', 'G#:min7/b3'),
#   ('G/2', 'D#:hdim7', 'A:7(13)'),
#   ('C#:min/5', 'A:maj(9)/3', 'D:min7/b3'),
#   ('D:7', 'A/b7', 'E/b7'),
#   ('D:maj(*1)/#1', 'A:7/3', 'C:maj7'),
#   ('A:min', 'D:min7(2,*b3,4)', 'A:maj(9)/3'),
#   ('F#:min', 'B:9', 'D:min/6'),
#   ('E/5', 'D:min/5', 'G#:min7/b3'),
#   ('B/5', 'A:7/3', 'A:min/5'),
#   ('A', 'F#/5', 'D:min7/b3'),
#   ('G:sus4(2)/2', 'A/2', 'G#'),
#   ('A:min', 'A:7', 'F#/5'),
#   ('A/5', 'G#:aug', 'D/2'),
#   ('A:7/5', 'A:7/3', 'A:(1)'),
#   ('Eb', 'A:min7', 'A:7(*5,13)'),
#   ('F#:min/5', 'D#', 'C#'),
#   ('C/2', 'D:min/4', 'D:dim7'),
#   ('B:9', 'D:min/4', 'C:maj6/5'),
#   ('A/7', 'Bb:7', 'D:dim7'),
#   ('C#:min/5', 'Bb', 'A:maj(9)/3'),
#   ('C', 'G/#4', 'A:7(*5,13)'),
#   ('G/2', 'D#:(1,4)', 'B:maj6'),
#   ('E:(1,4)', 'A:9', 'F:maj7'),
#   ('E:7', 'A:9', 'G:9(*3,11)'),
#   ('N', 'C:(1)', 'B:maj6'),
#   ('G', 'A/5', 'A/6'),
#   ('C:7', 'G:sus4(2)', 'A/2'),
#   ('E:min', 'Bb:7', 'E:sus4(b7)'),
#   ('G:sus4(2)', 'B/5', 'C#'),
#   ('G/5', 'D:min7(2,*b3,4)', 'D/3'),
#   ('C#:min/5', 'D/3', 'B:sus2'),
#   ('A/5', 'G/#4', 'D:min9'),
#   ('G', 'A/2', 'B:sus2'),
#   ('C', 'A:7(13)', 'C:maj7/7'),
#   ('B', 'E:min/b7', 'D/b7'),
#   ('G/3', 'A:7', 'E/5'),
#   ('N', 'D:min/b3', 'B:(1)'),
#   ('A', 'G', 'C#'),
#   ('A/6', 'E:min', 'G/2'),
#   ('D/6', 'D:maj(*1)/#1', 'D/2'),
#   ('D:min', 'D#', 'B:dim'),
#   ('G/3', 'A:min', 'E:sus4(b7)'),
#   ('A/b7', 'F#/5', 'B:9'),
#   ('E:min', 'G/#4', 'D:min/5'),
#   ('B', 'D:dim', 'D:min/6'),
#   ('B:min', 'E:min', 'D:min7/b3'),
#   ('A/b7', 'D/3', 'D:min9'),
#   ('D:min', 'D/3', 'C:maj6/5'),
#   ('C/7', 'C/6', 'A:7/3'),
#   ('D/6', 'G/2', 'A:aug'),
#   ('A:7', 'A:min/5', 'A:(1)'),
#   ('D/7', 'E:7', 'G#'),
#   ('A', 'G:7', 'D:min/5'),
#   ('B:min', 'A:7/3', 'A:(1)'),
#   ('D:maj(*1)/#1', 'E', 'B:9'),
#   ('C', 'A/2', 'E/5'),
#   ('A', 'G', 'C:maj7/7'),
#   ('G', 'A/7', 'D/5'),
#   ('B:min', 'D#:(1,4)', 'E:sus4'),
#   ('C/7', 'C#:min', 'D#:(1,4)'),
#   ('G:7', 'G/3', 'E:sus4(b7)'),
#   ('E:min/5', 'E/5', 'C#:min'),
#   ('A:min', 'C/7', 'D#:hdim7'),
#   ('E:min/b7', 'C#', 'B:sus2'),
#   ('A:7(13)', 'G#:7', 'D/b7'),
#   ('D', 'Bb:7', 'C#:min/b7'),
#   ('A', 'C:maj7', 'E:dim/b3'),
#   ('C#:min', 'D:min7/b3', 'A:min/5'),
#   ('A/3', 'B:dim', 'D/2'),
#   ('D:min/4', 'G#', 'A:7(13)'),
#   ('C#:min/b7', 'C:maj7/7', 'D#:dim/b5'),
#   ('F#:min/5', 'G#:min7/b3', 'C:maj7/7'),
#   ('N', 'G:sus4(2)', 'D/6'),
#   ('C:7', 'C/2', 'D:(1,4)'),
#   ('Ab:aug', 'F#:min', 'D:min/b7'),
#   ('D:min/4', 'F:maj7', 'G#:min7/b3'),
#   ('F#:min', 'D:min/6', 'B:sus2'),
#   ('D/5', 'C#:min', 'F/5'),
#   ('B/5', 'B:9', 'D:min7/b3'),
#   ('G', 'D:7/5', 'D:min/2'),
#   ('D:min/5', 'D#:hdim7', 'D/b7'),
#   ('B:9', 'D:min/6', 'A:(1)'),
#   ('G/3', 'D:min/5', 'D:min/b7'),
#   ('E:7/5', 'E:aug', 'E:maj6'),
#   ('E:9', 'D:(1,4)', 'F#'),
#   ('Ab:aug', 'D:dim7', 'E:maj6'),
#   ('G:sus4(2)', 'A:aug', 'D#:hdim7'),
#   ('B:(1)', 'F/3', 'E:dim/b3'),
#   ('N', 'D:7/5', 'B:sus2'),
#   ('N', 'A:7(*5,13)', 'A:7(13)'),
#   ('F#:min/5', 'Ab', 'A:min/5'),
#   ('D/6', 'D:(1,4)', 'Ab'),
#   ('C#:min/5', 'F:7', 'Gb'),
#   ('A/7', 'F#:min7', 'E/6'),
#   ('B/5', 'G/#4', 'D:min/2'),
#   ('E/5', 'Ab', 'B:sus2'),
#   ('F', 'D:7/5', 'E:(1,4)'),
#   ('A/7', 'D:maj(*1)/#1', 'B:sus2'),
#   ('F', 'F:maj7', 'G:min7'),
#   ('B:min', 'C#:min/b7', 'A:7(13)'),
#   ('Eb', 'C/5', 'B:sus2'),
#   ('D/5', 'C:sus4', 'E:min7'),
#   ('B:(1)', 'D#:hdim7', 'D:min/b7'),
#   ('N', 'D:maj(*1)/#1', 'F:7'),
#   ('G:sus4(2)', 'Bb:7', 'D:min/6'),
#   ('E', 'E:sus4', 'E:min7'),
#   ('F#:min/5', 'D#', 'A:min/5'),
#   ('D:min', 'A/b7', 'D:min7/b3'),
#   ('G/#4', 'E:sus4', 'B:sus2'),
#   ('E:min/5', 'E/5', 'A:7(*5,13)'),
#   ('F#:min/5', 'A:7(13)', 'F/3'),
#   ('G/5', 'F#:min/5', 'C:sus4'),
#   ('G/3', 'A:7/5', 'A:9'),
#   ('E:min/6', 'E/7', 'D:min/b3'),
#   ('G#:aug', 'D#:hdim7', 'F#:min7'),
#   ('G#', 'D/b7', 'F/5'),
#   ('A:min', 'C/2', 'Ab'),
#   ('C/6', 'E:min/b7', 'D:min7(2,*b3,4)'),
#   ('A:min', 'D:7', 'D:maj6'),
#   ('C/2', 'E:aug', 'F#:min7'),
#   ('D/5', 'D:min/4', 'D:dim7'),
#   ('D:min/5', 'D:min9', 'D:min7/b3'),
#   ('C#:min/b7', 'C:(1)', 'E/6'),
#   ('G/5', 'D/6', 'C:maj7'),
#   ('B', 'D#:(1,4)', 'Gb'),
#   ('C/5', 'D/5', 'E:maj6'),
#   ('D', 'C/7', 'C:maj7/7'),
#   ('A/b6', 'E:7/5', 'D:min9'),
#   ('Ab:aug', 'E:7', 'B:sus2'),
#   ('E:sus4(b7)', 'D/3', 'F/3'),
#   ('G:sus4(2)/2', 'D:min9', 'D:min/b7'),
#   ('C#:min/5', 'G#', 'F:maj7'),
#   ('A/b7', 'D#', 'D:min/b3'),
#   ('D:min', 'F#', 'C#'),
#   ('C/3', 'A:7/5', 'B:dim'),
#   ('G:sus4(2)', 'A/2', 'E'),
#   ('C:7', 'E/b7', 'D:min/6'),
#   ('B:min', 'F#/5', 'Bb:7'),
#   ('D', 'A:min', 'E:aug'),
#   ('D', 'D/2', 'D:min/b7'),
#   ('C/6', 'E/5', 'F#:min7'),
#   ('A:min', 'C#:min/5', 'A:7/3'),
#   ('B', 'G#:aug', 'F/3'),
#   ('C/2', 'F:7', 'E/6'),
#   ('D:7/5', 'D/2', 'E:dim/b3'),
#   ('G/#4', 'A:7/3', 'G:min7'),
#   ('E:min/5', 'A/b6', 'F:7'),
#   ('D:maj(*1)/#1', 'A:7', 'E:(1,4)'),
#   ('Ab:aug', 'A:aug', 'D:dim7'),
#   ('N', 'E:sus4', 'C:sus4'),
#   ('D:7', 'D:dim', 'C:maj6/5'),
#   ('A/b6', 'E/5', 'D#:dim/b5'),
#   ('A/5', 'E:7', 'B:(1)'),
#   ('E:aug', 'C#:min/b7', 'E:sus4(b7)'),
#   ('E:min/5', 'F:7', 'B:maj6'),
#   ('D/5', 'B:9', 'E/5'),
#   ('E:min', 'C#:min/b7', 'D:min/6'),
#   ('G/3', 'E:sus4(b7)', 'G#:min7/b3'),
#   ('A:7/5', 'F#:min7', 'D:min/b7'),
#   ('Ab:aug', 'D:min/b7', 'D:min/6'),
#   ('G:7', 'D/7', 'Gb'),
#   ('D:7', 'E:7', 'D#:(1,4)'),
#   ('A/b6', 'Bb', 'E/6'),
#   ('C#:min/5', 'E:7/5', 'Bb'),
#   ('A/5', 'B:(1)', 'C:maj7'),
#   ('E:min/b7', 'A:7/3', 'A:maj(9)/3'),
#   ('A:7/3', 'D:min/b3', 'C:maj6/5'),
#   ('F:7', 'Bb', 'A:7(*5,13)'),
#   ('G', 'C/7', 'G/#4'),
#   ('N', 'D', 'D:7/5'),
#   ('C/7', 'E:(1,4)', 'D:maj6'),
#   ('A:min', 'G/#4', 'F#'),
#   ('E', 'C#:min', 'E/6'),
#   ('C/5', 'D:min/5', 'G:min7'),
#   ('C#:min/5', 'G#:7', 'E/b7'),
#   ('E/5', 'A:aug', 'D:min7(2,*b3,4)'),
#   ('C#:min/5', 'F#:min7', 'D#:dim/b5'),
#   ('A/3', 'A:aug', 'D:dim'),
#   ('A/b7', 'A:9', 'E:maj6'),
#   ('E:min/5', 'E:7/5', 'C#:min'),
#   ('F', 'Bb:7', 'E/6'),
#   ('C', 'A:min7', 'A:9'),
#   ('E:min/b7', 'A:7(13)', 'D/2'),
#   ('A:9', 'B:dim', 'B:maj6'),
#   ('E:min', 'E:min/6', 'A/3'),
#   ('A/6', 'B/5', 'C:maj7'),
#   ('D', 'D:min/6', 'C:maj7/7'),
#   ('C/2', 'E:aug', 'Bb'),
#   ('B:min', 'C:maj7/7', 'B:sus2'),
#   ('A', 'G:sus4(2)/2', 'E/b7'),
#   ('A/b6', 'E:(1,4)', 'D/b7'),
#   ('G#:aug', 'E:(1,4)', 'Ab'),
#   ('A', 'Eb', 'B:sus2'),
#   ('C/5', 'D:min/b3', 'C:(1)'),
#   ('E:min/5', 'E/5', 'D/2'),
#   ('G:sus4(2)', 'D:min/b3', 'C:sus4'),
#   ('E/7', 'D#:dim/b5', 'D:min7/b3'),
#   ('E:7', 'D:min/6', 'A:(1)'),
#   ('D/5', 'E:7/5', 'D/b7'),
#   ('G:7', 'F:7', 'E:maj6'),
#   ('G/3', 'G:sus4(2)', 'B:sus2'),
#   ('G:sus4(2)', 'F#:min/5', 'D:maj(*1)/#1'),
#   ('C/2', 'D:min/b7', 'D:min/6'),
#   ('A/7', 'G:sus4(2)', 'F#'),
#   ('Ab:aug', 'E/7', 'C:maj7'),
#   ('A:7/5', 'G:min7', 'F/5'),
#   ('C', 'C/7', 'B/5'),
#   ('E:min/b7', 'D/5', 'E:dim/b3'),
#   ('D:min', 'F#', 'B:maj6'),
#   ('D:7', 'F#/5', 'D:min/b3'),
#   ('E:min', 'D/6', 'D#:hdim7'),
#   ('A/7', 'F#:min/5', 'D:min/5'),
#   ('A', 'E:7', 'D#:dim/b5'),
#   ('A:min', 'E:min/b7', 'D:maj(*1)/#1'),
#   ('D#:(1,4)', 'A:maj(9)/3', 'C:maj7'),
#   ('E/5', 'D#', 'C#:min'),
#   ('C', 'C/6', 'G#'),
#   ('B:min', 'A:7', 'Bb'),
#   ('C#:min/b7', 'D:min7(2,*b3,4)', 'E:min7'),
#   ('A:aug', 'D/3', 'E:min7'),
#   ('G:7', 'D/2', 'A:min/5'),
#   ('Eb', 'Gb', 'G:9(*3,11)'),
#   ('E:aug', 'E:maj6', 'C:maj7'),
#   ('C/3', 'Bb', 'A:maj(9)/3'),
#   ('C/6', 'G/#4', 'G:min7'),
#   ('E:min/5', 'B:(1)', 'D/2'),
#   ('E:7/5', 'C#:min/b7', 'D:dim'),
#   ('D:7', 'B:(1)', 'Eb/6'),
#   ('F:7', 'Bb', 'D:min7/b3'),
#   ('E:9', 'F#', 'A:(1)'),
#   ('A:maj(9)/3', 'E:sus4', 'D/2'),
#   ('F', 'A:9', 'F#'),
#   ('C#:min/5', 'A/b7', 'E:maj6'),
#   ('G', 'G:sus4(2)', 'D/5'),
#   ('E:7', 'E:sus4', 'A:7(13)'),
#   ('Bb:7', 'C#:min', 'D/3'),
#   ('G/5', 'D:maj6', 'A:(1)'),
#   ('G/3', 'A:aug', 'B:(1)'),
#   ('F:7', 'B:9', 'E:9'),
#   ('E/5', 'D/3', 'D:dim7'),
#   ('C#:min/b7', 'G#:min7/b3', 'C:maj7'),
#   ('A/6', 'E:7/5', 'D/b7'),
#   ('D#:hdim7', 'C:sus4', 'A:min/5'),
#   ('A:7/5', 'F:7', 'D#:hdim7'),
#   ('Ab:aug', 'D/6', 'F/5'),
#   ('C/5', 'E:aug', 'E'),
#   ('G:sus4(2)/2', 'A/2', 'D:maj(*1)/#1'),
#   ('D:7', 'C/2', 'E:sus4(b7)'),
#   ('C', 'C/5', 'G#'),
#   ('C', 'A/2', 'D:maj(*1)/#1'),
#   ('G#:aug', 'E:(1,4)', 'E/b7'),
#   ('A/7', 'Bb:7', 'E:sus4'),
#   ('C/7', 'C/6', 'F:7'),
#   ('G:sus4(2)/2', 'D/5', 'D:min/6'),
#   ('D/6', 'E:7/5', 'F/5'),
#   ('G:7', 'D:7', 'F:7'),
#   ('F#:min', 'E/b7', 'A:(1)'),
#   ('D:min', 'E:aug', 'D:(1,4)'),
#   ('G/5', 'A/2', 'Ab'),
#   ('G/3', 'C/7', 'A:7/3'),
#   ('Ab:aug', 'A:7/3', 'E:9'),
#   ('D:min9', 'Gb', 'Ab'),
#   ('D:min', 'A/7', 'A:aug'),
#   ('G/5', 'D:7/5', 'A:maj(9)/3'),
#   ('D:min', 'C/5', 'D:min/6'),
#   ('F#/5', 'C:maj7/7', 'B:sus2'),
#   ('E:min/b7', 'G#:min7/b3', 'C:maj7'),
#   ('F#:min', 'E:min/b7', 'D:min/4'),
#   ('G', 'E:maj6', 'Eb/6'),
#   ('C/3', 'D:min/4', 'D:dim'),
#   ('E:7/5', 'E/7', 'Bb'),
#   ('E:min/5', 'A:9', 'B:sus2'),
#   ('F#', 'Ab', 'E:maj6'),
#   ('B:min', 'A/6', 'D/7'),
#   ('C#:min/5', 'G#:7', 'Ab'),
#   ('D:maj(*1)/#1', 'B:maj6', 'C:maj7'),
#   ('G#', 'D:min7/b3', 'Eb/6'),
#   ('A:7/3', 'F:7', 'D:min7/b3'),
#   ('C/3', 'C/6', 'B:maj6'),
#   ('D:maj(*1)/#1', 'E/7', 'E:min7'),
#   ('A', 'D/2', 'F/3'),
#   ('Eb', 'E/7', 'D/b7'),
#   ('G:sus4(2)/2', 'A/3', 'Gb'),
#   ('A:min', 'D:(1,4)', 'B:maj6'),
#   ('E:min', 'A:7/5', 'C#:min'),
#   ('A/6', 'E:7', 'A:min/5'),
#   ('A:7/5', 'Bb', 'D#:(1,4)'),
#   ('G/5', 'D', 'D#:(1,4)'),
#   ('D:min', 'G#', 'D:min/6'),
#   ('C/7', 'C/6', 'G:sus4(2)'),
#   ('D:7/5', 'F:maj7', 'C:maj7/7'),
#   ('C#', 'E/b7', 'Eb/6'),
#   ('G/3', 'D#:hdim7', 'F#'),
#   ('C:7', 'C/2', 'E/7'),
#   ('C:sus4', 'Ab', 'E/6'),
#   ('G:7', 'D:dim', 'B:maj6'),
#   ('A:min7', 'F#', 'D:dim7'),
#   ('E:min/5', 'A:maj(9)/3', 'D:dim'),
#   ('G/5', 'D#', 'B:dim'),
#   ('A:min', 'A:aug', 'E:sus4'),
#   ('N', 'A:7/5', 'F#'),
#   ('D:min/4', 'E:dim/b3', 'A:(1)'),
#   ('G/2', 'C#:min', 'D:min/5'),
#   ('F#', 'C:maj7', 'C:maj7/7'),
#   ('A/7', 'A:min7', 'A:7(13)'),
#   ('A/6', 'B:(1)', 'D/b7'),
#   ('F#/5', 'D#:(1,4)', 'F:maj7'),
#   ('E:min/6', 'G#', 'D/2'),
#   ('C#:min/5', 'E:7/5', 'F:7'),
#   ('E:9', 'G#:aug', 'D:min7/b3'),
#   ('G', 'Bb:7', 'D:maj6'),
#   ('B:(1)', 'D:maj6', 'A:min7'),
#   ('C/2', 'F#:min/5', 'F/3'),
#   ('A:7/5', 'A:7/3', 'D#:hdim7'),
#   ('C:(1)', 'B:dim', 'G#:min7/b3'),
#   ('A/6', 'F:7', 'D:min/4'),
#   ('D:min/b3', 'A:aug', 'D/2'),
#   ('F', 'A/6', 'A:maj(9)/3'),
#   ('B/5', 'A:9', 'D:min/6'),
#   ('A:7/5', 'D:min/2', 'G#'),
#   ('D#:hdim7', 'Ab', 'D:min/6'),
#   ('E:min/6', 'B/5', 'G:min7'),
#   ('D:min/2', 'D:min/5', 'A:min7'),
#   ('C:7', 'D:min/5', 'C:maj6/5'),
#   ('G:sus4(2)', 'B', 'E/5'),
#   ('D/6', 'A:7', 'D/3'),
#   ('G/2', 'A:min7', 'C:maj7/7'),
#   ('Ab:aug', 'C#:min/5', 'A:(1)'),
#   ('A', 'G:7', 'A:9'),
#   ('F', 'G:sus4(2)/2', 'A:9'),
#   ('D:7/5', 'F:7', 'Ab'),
#   ('A/7', 'A:7(13)', 'G:9(*3,11)'),
#   ('Bb:7', 'D#:hdim7', 'Ab'),
#   ('E:sus4(b7)', 'E:sus4', 'A:min/5'),
#   ('C/7', 'G#', 'E:maj6'),
#   ('C#:min', 'E:sus4(b7)', 'E:sus4'),
#   ('B/5', 'C:sus4', 'D/2'),
#   ('C/5', 'D:maj6', 'D:min9'),
#   ('E:min', 'A:9', 'C:maj6/5'),
#   ('E/7', 'G:min7', 'A:(1)'),
#   ('D:maj(*1)/#1', 'A:7(*5,13)', 'D:dim7'),
#   ('D:(1,4)', 'F#:min7', 'C:maj6/5'),
#   ('A:7/3', 'D:min/4', 'G#:7'),
#   ('C/5', 'E/5', 'E:min7'),
#   ('C/5', 'Bb:7', 'E:sus4(b7)'),
#   ('C/7', 'A/3', 'A:7(13)'),
#   ('C', 'A/5', 'E:dim/b3'),
#   ('A:min', 'D:7/5', 'D:dim7'),
#   ('D:min', 'E/7', 'E/6'),
#   ('B:9', 'D/3', 'E:dim/b3'),
#   ('G', 'C/5', 'G:sus4(2)'),
#   ('G/5', 'A/7', 'Ab'),
#   ('G:7', 'A:7(*5,13)', 'G:9(*3,11)'),
#   ('E:7', 'E/5', 'D:min/2'),
#   ('A/b6', 'C/2', 'B:sus2'),
#   ('C:7', 'E', 'D/b7'),
#   ('C#:min/5', 'A/2', 'G/2'),
#   ('A/7', 'D:min/b3', 'C:maj6/5'),
#   ('E:min/6', 'G/#4', 'D#:dim/b5'),
#   ('A:7/5', 'F:maj7', 'Ab'),
#   ('A/5', 'A/6', 'E:min'),
#   ('B:9', 'G#:7', 'F/5'),
#   ('A/5', 'D:(1,4)', 'Ab'),
#   ('G/#4', 'G:9(*3,11)', 'E:dim/b3'),
#   ('C/5', 'D:min/2', 'F/3'),
#   ('A/3', 'B/5', 'D#:(1,4)'),
#   ('A:7/3', 'Ab', 'D/2'),
#   ('E:sus4(b7)', 'D:dim7', 'G#:min7/b3'),
#   ('C#:min/5', 'F#:min/5', 'D/5'),
#   ('C#:min/5', 'D/6', 'B:(1)'),
#   ('B/5', 'A:7/3', 'C:maj6/5'),
#   ('E:7/5', 'F#', 'D:min9'),
#   ('F#:min', 'G/2', 'E:maj6'),
#   ('G/3', 'F#:min7', 'Eb/6'),
#   ('D/7', 'D:dim7', 'F/5'),
#   ('E:min/5', 'Bb:7', 'C:sus4'),
#   ('D:min/5', 'E:maj6', 'C:maj7/7'),
#   ('C/5', 'F#/5', 'B:9'),
#   ('E:min/6', 'A:9', 'G:min7'),
#   ('C/2', 'Gb', 'D#:dim/b5'),
#   ('E', 'Bb', 'F:maj7'),
#   ('Ab:aug', 'C/6', 'G#:min7/b3'),
#   ('E:min', 'A:aug', 'A:7(*5,13)'),
#   ('Eb', 'D:dim7', 'C:maj7/7'),
#   ('A:min/5', 'B:sus2', 'A:(1)'),
#   ('E:7/5', 'G#:min7/b3', 'D#:dim/b5'),
#   ('B:min', 'Bb:7', 'G:9(*3,11)'),
#   ('A/6', 'A:7/3', 'D:dim7'),
#   ('D:min', 'E:min/b7', 'F#'),
#   ('E:min/b7', 'D:maj6', 'F#:min7'),
#   ('C/7', 'C:(1)', 'G:min7'),
#   ('B:9', 'Ab', 'Eb/6'),
#   ('D:maj(*1)/#1', 'E', 'E/6'),
#   ('D:maj6', 'A:maj(9)/3', 'G#'),
#   ('G#:aug', 'D/2', 'B:sus2'),
#   ('F#/5', 'G:min7', 'E/6'),
#   ('C#:min/5', 'G/2', 'D:min/6'),
#   ('E:min', 'A:aug', 'F:maj7'),
#   ('F#:min/5', 'Ab', 'D/2'),
#   ('D:7', 'E:min/b7', 'A:aug'),
#   ('C/7', 'E:sus4', 'G#:7'),
#   ('E:(1,4)', 'F#', 'Eb/6'),
#   ('A/5', 'A/7', 'D:min/b3'),
#   ('B:(1)', 'A:7(13)', 'A:min/5'),
#   ('B:min', 'E:9', 'G:min7'),
#   ('A', 'G/5', 'C:maj7'),
#   ('D:maj(*1)/#1', 'A:7', 'D:min/b3'),
#   ('D/7', 'G/2', 'C#'),
#   ('D/6', 'D:min7(2,*b3,4)', 'B:(1)'),
#   ('A:7/5', 'F:maj7', 'A:(1)'),
#   ('E', 'D:min/b3', 'C:sus4'),
#   ('A:7/5', 'F#/5', 'C:maj7/7'),
#   ('C#:min/5', 'B/5', 'D:min9'),
#   ('C#', 'D:min7/b3', 'B:sus2'),
#   ('G/5', 'E:min7', 'E:dim/b3'),
#   ('F#:min/5', 'A:7(13)', 'D/2'),
#   ('A/6', 'F#:min/5', 'D/7'),
#   ('B:min', 'E/7', 'E:min7'),
#   ('E/5', 'D/3', 'E:dim/b3'),
#   ('Ab:aug', 'A/2', 'D#:dim/b5'),
#   ('D/7', 'D#', 'D:dim7'),
#   ('G:7', 'D:7', 'E:maj6'),
#   ('Bb:7', 'E:9', 'Bb'),
#   ('A/6', 'D#', 'A:7(13)'),
#   ('A', 'A/b6', 'B:sus2'),
#   ('B:9', 'A:min/5', 'F/5'),
#   ('A:min', 'G/2', 'D:min7(2,*b3,4)'),
#   ('B', 'E:min/6', 'E:aug'),
#   ('A:min', 'E:min', 'A:7(*5,13)'),
#   ('A:7', 'A:7(*5,13)', 'C#'),
#   ('C', 'E:(1,4)', 'F/3'),
#   ('E:min/6', 'D:maj(*1)/#1', 'A:min7'),
#   ('A:maj(9)/3', 'A:7(13)', 'E:dim/b3'),
#   ('E', 'E/5', 'A:min/5'),
#   ('C', 'E/7', 'D#:dim/b5'),
#   ('B:min', 'Ab:aug', 'D:min/6'),
#   ('F#:min/5', 'C#:min', 'D/2'),
#   ('N', 'D:min7(2,*b3,4)', 'A:maj(9)/3'),
#   ('Ab:aug', 'C:maj7/7', 'A:(1)'),
#   ('A/6', 'E/5', 'A:(1)'),
#   ('A:min', 'D:7', 'D:min/5'),
#   ('B:min', 'E:(1,4)', 'E:maj6'),
#   ('D:maj(*1)/#1', 'F#/5', 'B:maj6'),
#   ('A/2', 'D:min7(2,*b3,4)', 'F/3'),
#   ('B:maj6', 'G#:min7/b3', 'C:maj6/5'),
#   ('Bb', 'D:min9', 'C#'),
#   ('A:min', 'G/#4', 'D:min7/b3'),
#   ('F#:min', 'A/b6', 'D:min/4'),
#   ('C/2', 'D:min/b3', 'E:(1,4)'),
#   ('B/5', 'G#:aug', 'E:(1,4)'),
#   ('Ab:aug', 'E/6', 'D:min7/b3'),
#   ('C/5', 'D:7/5', 'D:dim'),
#   ('G#:aug', 'Ab', 'G:9(*3,11)'),
#   ('N', 'F#:min', 'Bb'),
#   ('E:min/5', 'C#:min/5', 'B'),
#   ('A/b7', 'Bb:7', 'C#'),
#   ('C/6', 'D/3', 'A:7(*5,13)'),
#   ('C/3', 'A/b7', 'E:sus4(b7)'),
#   ('G#:aug', 'G#:min7/b3', 'D/2'),
#   ('A/b6', 'A/2', 'C:maj7'),
#   ('F', 'G:min7', 'G#:min7/b3'),
#   ('G/3', 'Ab:aug', 'B'),
#   ('D/7', 'D#', 'E:sus4'),
#   ('A/5', 'C/6', 'A:min7'),
#   ('Ab:aug', 'A:7/5', 'F#:min7'),
#   ('Bb', 'D#:(1,4)', 'A:9'),
#   ('G:7', 'D/3', 'C#'),
#   ('E:7/5', 'A:7', 'A:7(*5,13)'),
#   ('A/2', 'D#:hdim7', 'E/6'),
#   ('G#:7', 'E:maj6', 'C:maj6/5'),
#   ('G:sus4(2)', 'D:7/5', 'Gb'),
#   ('E:min', 'A:aug', 'D/2'),
#   ('A', 'Gb', 'F/5'),
#   ('D:min', 'G/5', 'A/7'),
#   ('D:min/2', 'C:(1)', 'D:maj6'),
#   ('D:maj6', 'B:maj6', 'G#:min7/b3'),
#   ('B:min', 'D:min/5', 'B:sus2'),
#   ('E:aug', 'Gb', 'B:sus2'),
#   ('G/5', 'E', 'F#:min7'),
#   ('D/5', 'A:7(13)', 'E:dim/b3'),
#   ('G:7', 'A:aug', 'D:min7/b3'),
#   ('C/2', 'D:min9', 'C:maj6/5'),
#   ('C#:min', 'F#:min7', 'G:9(*3,11)'),
#   ('A:min', 'A:aug', 'D:min9'),
#   ('D/5', 'C#:min', 'G#:aug'),
#   ('Eb', 'G:sus4(2)/2', 'D/6'),
#   ('E:min/b7', 'E/7', 'D:min/b3'),
#   ('C/3', 'A/7', 'E:sus4(b7)'),
#   ('N', 'D/7', 'C:maj6/5'),
#   ('A:9', 'A:min/5', 'Eb/6'),
#   ('C/7', 'D:(1,4)', 'Gb'),
#   ('E:aug', 'G#:7', 'D:dim7'),
#   ('F', 'A:9', 'D:min7/b3'),
#   ('D:7', 'E:aug', 'G:min7'),
#   ('G/5', 'D:min7(2,*b3,4)', 'D#:hdim7'),
#   ('D#', 'D:min/b7', 'A:(1)'),
#   ('E:aug', 'D#:dim/b5', 'A:min/5'),
#   ('A:7', 'E:9', 'C:maj6/5'),
#   ('E:min/b7', 'Bb:7', 'C:(1)'),
#   ('N', 'A:maj(9)/3', 'G:min7'),
#   ('D:7', 'A/3', 'G/2'),
#   ('F#:min', 'D#', 'Ab'),
#   ('G:7', 'E/5', 'E:sus4'),
#   ('D:maj6', 'F#', 'Eb/6'),
#   ('B/5', 'D:min9', 'D:min/b7'),
#   ('A/6', 'D:min/b3', 'F/5'),
#   ('G:sus4(2)', 'E:7', 'E/6'),
#   ('C/6', 'E:sus4', 'G:9(*3,11)'),
#   ('D:maj(*1)/#1', 'E:7/5', 'D/b7'),
#   ('G:7', 'D:7', 'G:min7'),
#   ('A/2', 'D:min/2', 'C:sus4'),
#   ('F', 'E:aug', 'F/3'),
#   ('A:7/3', 'D:min/6', 'D#:dim/b5'),
#   ('C/2', 'E:9', 'A:min7'),
#   ('N', 'A/6', 'A:7/3'),
#   ('A:7(*5,13)', 'B:maj6', 'D/b7'),
#   ('D', 'Bb', 'F#'),
#   ('C', 'Ab:aug', 'D/5'),
#   ('A:min', 'A:aug', 'D:dim7'),
#   ('A/6', 'D#', 'D:maj6'),
#   ('F#:min/5', 'E:aug', 'C:maj6/5'),
#   ('C#:min/b7', 'G#:aug', 'D:dim7'),
#   ('N', 'E:7/5', 'D:7/5'),
#   ('D:7/5', 'E/5', 'D:dim7'),
#   ('A', 'D', 'B:maj6'),
#   ('A/2', 'E/5', 'A:7(13)'),
#   ('A:aug', 'G#', 'F#'),
#   ('Ab:aug', 'A/7', 'F#:min7'),
#   ('D:7', 'A/2', 'D/5'),
#   ('Eb', 'C#:min/5', 'A/5'),
#   ('C:7', 'G:sus4(2)', 'C#:min/b7'),
#   ('F#:min', 'D:min9', 'F/5'),
#   ('A/2', 'Bb:7', 'G#:aug'),
#   ('D:min/4', 'E:sus4', 'B:sus2'),
#   ('G', 'D:7', 'F#:min'),
#   ('G/2', 'A:9', 'D#:dim/b5'),
#   ('E:9', 'Bb', 'F#'),
#   ('E:min/5', 'F:7', 'C:maj7'),
#   ('C', 'A:maj(9)/3', 'G:min7'),
#   ('D:7', 'E:7/5', 'B:9'),
#   ('G/5', 'G/2', 'B:dim'),
#   ('F#/5', 'B:9', 'Eb/6'),
#   ('E:min/b7', 'D:min7(2,*b3,4)', 'A:(1)'),
#   ('F#:min/5', 'Gb', 'G:9(*3,11)'),
#   ('E:min/5', 'A:7(13)', 'E:maj6'),
#   ('C/5', 'A:7/5', 'D:min9'),
#   ('C:7', 'A/7', 'F/5'),
#   ('G:sus4(2)', 'D#', 'C:maj7/7'),
#   ('C#:min', 'E:sus4(b7)', 'D:dim7'),
#   ('C/2', 'Bb', 'Ab'),
#   ('C:7', 'E:(1,4)', 'B:dim'),
#   ('C/6', 'E:7', 'B:dim'),
#   ('D/7', 'D:min9', 'C:maj6/5'),
#   ('G/#4', 'F#:min7', 'F/3'),
#   ('E/7', 'C:sus4', 'G:min7'),
#   ('A/7', 'C/6', 'E'),
#   ('A:min', 'A/6', 'E:sus4'),
#   ('N', 'G:sus4(2)/2', 'A:min7'),
#   ('G:7', 'A:9', 'A:min/5'),
#   ('G', 'C#', 'Eb/6'),
#   ('D', 'G/2', 'D:min7(2,*b3,4)'),
#   ('B:min', 'C#:min/5', 'G:min7'),
#   ('B:9', 'D:min7(2,*b3,4)', 'E/6'),
#   ('D:7/5', 'E/5', 'E:sus4'),
#   ('N', 'F', 'Bb:7'),
#   ('A/2', 'A:7', 'B:maj6'),
#   ('B:min', 'E:min', 'F:7'),
#   ('C/5', 'A/5', 'A:aug'),
#   ('F:7', 'F:maj7', 'Eb/6'),
#   ('C/7', 'D:7/5', 'E:min7'),
#   ('A:aug', 'A:maj(9)/3', 'E:sus4'),
#   ('A:9', 'G:min7', 'D/2'),
#   ('A/5', 'E:9', 'E/6'),
#   ('N', 'F#:min', 'A:aug'),
#   ('G', 'E:7', 'E:7/5'),
#   ('G/3', 'A/5', 'G:min7'),
#   ('D#:hdim7', 'Gb', 'A:(1)'),
#   ('D/3', 'E/6', 'E:dim/b3'),
#   ('A/7', 'F:7', 'D:min9'),
#   ('A/6', 'G/2', 'G/#4'),
#   ('B/5', 'A:7/5', 'G/#4'),
#   ('G:sus4(2)/2', 'E:aug', 'B:(1)'),
#   ('D:min', 'Ab:aug', 'D:(1,4)'),
#   ('D:min/5', 'D/3', 'F#'),
#   ('D/7', 'C#:min/b7', 'A:min7'),
#   ('Eb', 'D:dim7', 'G:9(*3,11)'),
#   ('G:sus4(2)', 'D#:hdim7', 'F#:min7'),
#   ('C/7', 'E/5', 'A:7(*5,13)'),
#   ('D:7', 'D:7/5', 'Ab'),
#   ('C/7', 'E:min', 'F/5'),
#   ('D/5', 'D:min/b3', 'D:min7(2,*b3,4)'),
#   ('G/5', 'E:min', 'D:maj(*1)/#1'),
#   ('Eb', 'G#:7', 'A:min/5'),
#   ('A/b7', 'E:maj6', 'D:min/b7'),
#   ('E/7', 'D:(1,4)', 'G#:7'),
#   ('G:sus4(2)/2', 'G/#4', 'E'),
#   ('C:(1)', 'D/3', 'E:dim/b3'),
#   ('E', 'Bb:7', 'C#'),
#   ('C/3', 'C/6', 'C:(1)'),
#   ('C/7', 'E:sus4(b7)', 'F:maj7'),
#   ('C#:min', 'F:maj7', 'A:(1)'),
#   ('D:maj(*1)/#1', 'Bb', 'C:maj6/5'),
#   ('D:7/5', 'G:min7', 'E/6'),
#   ('G:7', 'D#', 'C#'),
#   ('C#:min', 'E:sus4', 'A:min/5'),
#   ('E:(1,4)', 'E/6', 'C:maj6/5'),
#   ('C#:min/5', 'A/6', 'D:min/6'),
#   ('A/5', 'C/7', 'Eb/6'),
#   ('G/3', 'A/b7', 'E:(1,4)'),
#   ('A/b6', 'Bb:7', 'F/3'),
#   ('N', 'B/5', 'E:7'),
#   ('A:7', 'E:sus4', 'A:min7'),
#   ('D:min/4', 'Gb', 'C:maj6/5'),
#   ('D:min/5', 'B:maj6', 'C:maj6/5'),
#   ('C/5', 'A:9', 'A:min/5'),
#   ('G/5', 'C:sus4', 'D:min/6'),
#   ('C/2', 'B/5', 'D/b7'),
#   ('A/b7', 'F#:min/5', 'C:(1)'),
#   ('C/2', 'Bb:7', 'D#:(1,4)'),
#   ('D', 'F#/5', 'D#:dim/b5'),
#   ('E:min/b7', 'C:sus4', 'B:maj6'),
#   ('B/5', 'D:(1,4)', 'D#:(1,4)'),
#   ('E:min/5', 'C#:min/5', 'E:dim/b3'),
#   ('D:min/4', 'A:maj(9)/3', 'A:7(13)'),
#   ('D:(1,4)', 'F/3', 'D:min7/b3'),
#   ('D/7', 'E:(1,4)', 'B:dim'),
#   ('C/5', 'D:7/5', 'A:min7'),
#   ('A', 'C/7', 'D:dim7'),
#   ('A/5', 'D/5', 'D:7/5'),
#   ('G', 'D:min7(2,*b3,4)', 'F#:min7'),
#   ('E:7', 'E', 'B:sus2'),
#   ('B:min', 'A/5', 'E:maj6'),
#   ('G/5', 'G/2', 'G#:min7/b3'),
#   ('E:min/b7', 'E:(1,4)', 'D#:dim/b5'),
#   ('F:7', 'E/7', 'A:min/5'),
#   ('E:sus4', 'E/6', 'C:maj7/7'),
#   ('E:min/5', 'A/7', 'B:maj6'),
#   ('C#:min/5', 'D#:hdim7', 'Gb'),
#   ('A:7', 'A:7(*5,13)', 'A:min/5'),
#   ('A/7', 'E:min/b7', 'D/3'),
#   ('A/b6', 'G:9(*3,11)', 'D:min/b7'),
#   ('F#:min', 'D:dim7', 'C:maj6/5'),
#   ('N', 'F#:min', 'D/6'),
#   ('G:7', 'A/5', 'D/2'),
#   ('G:7', 'A/5', 'D:dim'),
#   ('D', 'E:aug', 'G#'),
#   ('G/#4', 'E/5', 'E:(1,4)'),
#   ('C/3', 'G#', 'A:7(*5,13)'),
#   ('C/2', 'F#/5', 'G/#4'),
#   ('A/6', 'B', 'A:9'),
#   ('F#:min/5', 'E:9', 'G#:aug'),
#   ('C/7', 'F:maj7', 'F#:min7'),
#   ('C/2', 'E:min/6', 'E'),
#   ('B:min', 'D:min9', 'C:maj7/7'),
#   ('A:maj(9)/3', 'Ab', 'G#:min7/b3'),
#   ('G:7', 'E:min/5', 'F#'),
#   ('A:min', 'C/5', 'D:dim'),
#   ('C/7', 'D:min7(2,*b3,4)', 'C#'),
#   ('G/5', 'A:9', 'D#:dim/b5'),
#   ('G/3', 'G#', 'A:7(*5,13)'),
#   ('B:min', 'F#:min/5', 'F:maj7'),
#   ('A:min', 'Ab:aug', 'A/6'),
#   ('A:aug', 'E:(1,4)', 'C:maj6/5'),
#   ('C#:min/5', 'D/5', 'Ab'),
#   ('E', 'E:min7', 'E/6'),
#   ('G/5', 'E:min/6', 'G/2'),
#   ('G#', 'D:min7/b3', 'B:sus2'),
#   ('D:maj(*1)/#1', 'F:maj7', 'E/6'),
#   ('G/5', 'A:7/3', 'C:maj7/7'),
#   ('G/3', 'E:7', 'D:min/5'),
#   ('G', 'D/7', 'F#'),
#   ('G', 'D:min/2', 'E:9'),
#   ('G/3', 'G#:aug', 'D:min7/b3'),
#   ('E:(1,4)', 'G#:7', 'D:dim7'),
#   ('N', 'D:maj(*1)/#1', 'F/5'),
#   ('E:min/5', 'D/6', 'C:maj6/5'),
#   ('D/5', 'D:min/4', 'D/b7'),
#   ('A', 'C/7', 'C#:min'),
#   ('A/3', 'D/7', 'G#:aug'),
#   ('A:7/5', 'D#', 'C#:min'),
#   ('G:7', 'E:aug', 'D:dim'),
#   ('A/b7', 'E:(1,4)', 'D/3'),
#   ('Ab:aug', 'F#:min/5', 'Bb'),
#   ('Ab:aug', 'A:7/5', 'D:maj6'),
#   ('Eb', 'D#', 'Eb/6'),
#   ('G/2', 'A:aug', 'F/5'),
#   ('G', 'F#:min', 'A:9'),
#   ('A:7', 'C:sus4', 'C:maj7'),
#   ('C', 'D/7', 'F/3'),
#   ('B', 'G#', 'G#:7'),
#   ('D#', 'E/7', 'D:min/6'),
#   ('E:min/b7', 'Bb', 'A:min/5'),
#   ('D:7', 'B', 'E:(1,4)'),
#   ('G#:7', 'D:dim7', 'G:min7'),
#   ('A:7/5', 'E/5', 'D:min/b7'),
#   ('D:7', 'G/#4', 'B:9'),
#   ('F', 'C/5', 'E/b7'),
#   ('E:sus4(b7)', 'A:7(*5,13)', 'E:dim/b3'),
#   ('E:min', 'E:aug', 'D:(1,4)'),
#   ('F#/5', 'E:9', 'F/3'),
#   ('G', 'A/7', 'G/2'),
#   ('C/3', 'A:7', 'E:(1,4)'),
#   ('C/3', 'D#:(1,4)', 'D:min7/b3'),
#   ('Bb:7', 'D:min/b7', 'C:maj6/5'),
#   ('A', 'F#', 'F/5'),
#   ('E/7', 'C#:min/b7', 'A:min/5'),
#   ('B:9', 'D#:hdim7', 'D/b7'),
#   ('Eb', 'C/5', 'D:min/b3'),
#   ('E:min', 'Gb', 'C#'),
#   ('A/5', 'F#:min/5', 'D:min/6'),
#   ('C/5', 'C:sus4', 'C:maj7'),
#   ('A:min', 'E/5', 'D/b7'),
#   ('E:min/6', 'F#/5', 'D#:hdim7'),
#   ('B:min', 'D/6', 'D:min/5'),
#   ('F', 'A/3', 'G/#4'),
#   ('G/5', 'E:aug', 'G:min7'),
#   ('C/2', 'E/7', 'A:aug'),
#   ('D:min/b3', 'G#:aug', 'G:min7'),
#   ('C/6', 'A:7(*5,13)', 'C:maj7'),
#   ('A', 'E:(1,4)', 'A:9'),
#   ('E:aug', 'C#:min', 'D:min/b3'),
#   ('Bb:7', 'C#:min', 'D:min7/b3'),
#   ('A/b7', 'D/5', 'D:min9'),
#   ('Bb', 'D#:hdim7', 'D:min9'),
#   ('N', 'D:min/2', 'D:min/5'),
#   ('D/5', 'C:(1)', 'C#'),
#   ('A', 'E:min/6', 'C:(1)'),
#   ('C/2', 'A:7(13)', 'E:dim/b3'),
#   ('A/7', 'D:min/5', 'D:(1,4)'),
#   ('A/2', 'D:min7(2,*b3,4)', 'D/2'),
#   ('C:7', 'A:min', 'B:(1)'),
#   ('A', 'E:min/6', 'G:min7'),
#   ('B:min', 'A:7/3', 'C:maj7/7'),
#   ('C/6', 'A/3', 'E:dim/b3'),
#   ('F#:min', 'E:7', 'F/3'),
#   ('F', 'A/7', 'D:dim'),
#   ('A:min', 'A/3', 'D#:hdim7'),
#   ('G/5', 'A/2', 'E:7'),
#   ('E:min/5', 'B:maj6', 'E:dim/b3'),
#   ('C#:min/5', 'D:min/b3', 'E:sus4(b7)'),
#   ('Bb:7', 'F#:min7', 'B:maj6'),
#   ('G#:aug', 'B:maj6', 'Eb/6'),
#   ('D/7', 'D/5', 'C:(1)'),
#   ('A:7/3', 'D:min7(2,*b3,4)', 'D:min7/b3'),
#   ('A:min7', 'F:maj7', 'B:maj6'),
#   ('Eb', 'D:dim', 'F:maj7'),
#   ('F#:min', 'E:(1,4)', 'D/b7'),
#   ('A/7', 'D:maj6', 'F:maj7'),
#   ('G:7', 'E:7/5', 'B:9'),
#   ('D', 'D:(1,4)', 'B:(1)'),
#   ('C', 'F:7', 'C#:min'),
#   ('D', 'A:7/3', 'Gb'),
#   ('A:9', 'G#:7', 'C#'),
#   ('Eb', 'G/5', 'G/2'),
#   ('C#:min/5', 'E:aug', 'C#:min/b7'),
#   ('A', 'C/7', 'D:min/b7'),
#   ('D', 'E/7', 'D:maj6'),
#   ('A:min', 'C/5', 'G:min7'),
#   ('C/5', 'E:min/b7', 'G#'),
#   ('C/2', 'D:min/5', 'E/6'),
#   ('A:7/3', 'D:min/2', 'D:min/4'),
#   ('G:7', 'B', 'D:min7(2,*b3,4)'),
#   ('D:dim', 'Ab', 'F/3'),
#   ('A/b7', 'C/7', 'A/3'),
#   ('A/b6', 'E:min/b7', 'D:min7/b3'),
#   ('D:(1,4)', 'A:min/5', 'F/5'),
#   ('C/3', 'C/6', 'F#:min/5'),
#   ('F#:min/5', 'A:maj(9)/3', 'F:maj7'),
#   ('D:7', 'A:7/5', 'D:min/5'),
#   ('C:7', 'B', 'D#:dim/b5'),
#   ('G#:min7/b3', 'G:9(*3,11)', 'C:maj7'),
#   ('Ab:aug', 'G/#4', 'D:min/6'),
#   ('D:7', 'F#', 'Eb/6'),
#   ('G:7', 'G/#4', 'E/5'),
#   ('Eb', 'A:7/3', 'D:min/b7'),
#   ('E:aug', 'D:min/4', 'Bb'),
#   ('D/5', 'F#:min7', 'E/b7'),
#   ('C/5', 'E:9', 'B:(1)'),
#   ('N', 'D:min', 'D#:dim/b5'),
#   ('A', 'E:min/b7', 'A:(1)'),
#   ('E/7', 'D#:hdim7', 'A:9'),
#   ('D:(1,4)', 'C:(1)', 'A:min/5'),
#   ('Bb', 'E:sus4(b7)', 'Ab'),
#   ('D', 'E:7/5', 'D:min7/b3'),
#   ('C#:min/5', 'C/7', 'A:min/5'),
#   ('Ab:aug', 'A/6', 'D:min/5'),
#   ('C/2', 'Ab', 'C:maj6/5'),
#   ('F#/5', 'E', 'D:min7/b3'),
#   ('C', 'D:(1,4)', 'Eb/6'),
#   ('C#:min/5', 'Bb:7', 'E:sus4(b7)'),
#   ('E/7', 'D:min/6', 'F/5'),
#   ('A:7', 'D:min/b3', 'E:dim/b3'),
#   ('D/7', 'A:aug', 'A:maj(9)/3'),
#   ('C/2', 'F#:min/5', 'D:min/2'),
#   ('C/7', 'C/2', 'E:dim/b3'),
#   ('A', 'F#:min/5', 'D#:(1,4)'),
#   ('F', 'E/7', 'F#:min7'),
#   ('B', 'A:7/5', 'A:maj(9)/3'),
#   ('A:min', 'D:min/4', 'Bb'),
#   ('D', 'A:7(*5,13)', 'A:(1)'),
#   ('C/6', 'F#:min/5', 'D:min/5'),
#   ('C:7', 'B/5', 'E:7'),
#   ('D/6', 'D:7/5', 'E:aug'),
#   ('F#:min/5', 'E:7/5', 'D:min/5'),
#   ('D/7', 'A:7(13)', 'C:maj6/5'),
#   ('B:min', 'A:7/3', 'E:maj6'),
#   ('G/3', 'A/b6', 'B:dim'),
#   ('A/2', 'A:7/5', 'G#:aug'),
#   ('D:maj(*1)/#1', 'C#:min/b7', 'D/3'),
#   ('G:7', 'D:7/5', 'Eb/6'),
#   ('D/6', 'D:7/5', 'Gb'),
#   ('A/7', 'F:maj7', 'E/b7'),
#   ('B:maj6', 'C:maj7', 'E:dim/b3'),
#   ('C/5', 'D/7', 'D:min/4'),
#   ('D:min', 'A:9', 'D:dim'),
#   ('E:min/5', 'D', 'D:min9'),
#   ('A/3', 'F#', 'C:maj7/7'),
#   ('E:min/b7', 'D:dim7', 'D:min7/b3'),
#   ('N', 'B:min', 'E:maj6'),
#   ('F#:min/5', 'A:min7', 'F/3'),
#   ('B:min', 'A:min', 'C:(1)'),
#   ('C/6', 'G/#4', 'D/b7'),
#   ('D:min', 'D:maj6', 'D:min/b7'),
#   ('E/7', 'D:maj6', 'G#'),
#   ('G/3', 'A:7/3', 'C:maj7/7'),
#   ('A', 'A/3', 'A/2'),
#   ('C:7', 'A/2', 'D:min/6'),
#   ('C/6', 'D#:dim/b5', 'F/5'),
#   ('F', 'A:9', 'B:maj6'),
#   ('Ab:aug', 'E:min', 'E:sus4(b7)'),
#   ('A', 'A:7/5', 'C:maj6/5'),
#   ('C/2', 'F#:min/5', 'C:maj7'),
#   ('E:min', 'A:min7', 'D#:hdim7'),
#   ('A:7/3', 'F/3', 'Eb/6'),
#   ('G/3', 'D:7', 'E:9'),
#   ('Eb', 'D:min9', 'C:maj6/5'),
#   ('F#:min/5', 'D:min/b7', 'C:maj6/5'),
#   ('B', 'D:maj(*1)/#1', 'F#'),
#   ('D:7', 'C#:min/5', 'E/5'),
#   ('A:min', 'E:min', 'D:maj6'),
#   ('A:min', 'G#:7', 'A:min/5'),
#   ('A', 'C:(1)', 'F#:min7'),
#   ('G/#4', 'E', 'B:(1)'),
#   ('G', 'G:sus4(2)', 'G/2'),
#   ('E:min', 'E:min/b7', 'D/7'),
#   ('F#:min/5', 'G#:7', 'B:maj6'),
#   ('G/3', 'F#:min', 'D:(1,4)'),
#   ('D:min/b3', 'D:min7(2,*b3,4)', 'D:dim7'),
#   ('E:7', 'A:7', 'E/5'),
#   ('E:sus4(b7)', 'F#', 'D#:dim/b5'),
#   ('G:7', 'C#:min/5', 'A:7(13)'),
#   ('C/5', 'Gb', 'D:min/b7'),
#   ('F', 'A:maj(9)/3', 'C:maj7'),
#   ('G/5', 'E', 'E/7'),
#   ('F#/5', 'A:9', 'Ab'),
#   ('G:sus4(2)', 'C#:min', 'D:maj6'),
#   ('F#:min7', 'C:maj7/7', 'B:sus2'),
#   ('F#/5', 'D#', 'C#:min/b7'),
#   ('D/7', 'E:9', 'D#:(1,4)'),
#   ('A:min7', 'F:maj7', 'D/2'),
#   ('C/3', 'E:9', 'G#'),
#   ('D:min/4', 'D:maj6', 'A:9'),
#   ('D#', 'D:min7(2,*b3,4)', 'D#:hdim7'),
#   ('D:7', 'D/6', 'A:(1)'),
#   ('D/5', 'D:min/4', 'D:min/b7'),
#   ('D:min/b3', 'E:maj6', 'C#'),
#   ('Eb', 'G/#4', 'D:min/2'),
#   ('C:7', 'E:maj6', 'B:sus2'),
#   ('B:min', 'D:min7/b3', 'Eb/6'),
#   ('F#:min', 'A:9', 'F#'),
#   ('E/7', 'D/2', 'A:(1)'),
#   ('Ab:aug', 'D:min/2', 'F#:min7'),
#   ('G:sus4(2)/2', 'D:min/5', 'G:min7'),
#   ('A:7/3', 'B:9', 'C:sus4'),
#   ('F#:min', 'Bb:7', 'E:maj6'),
#   ('E:sus4(b7)', 'D/3', 'D/2'),
#   ('C/5', 'G#', 'C#'),
#   ('A', 'C:maj7/7', 'D:min7/b3'),
#   ('F#:min', 'G#:min7/b3', 'D:min7/b3'),
#   ('D:min7(2,*b3,4)', 'E/b7', 'C:maj6/5'),
#   ('B:9', 'Gb', 'E:dim/b3'),
#   ('G/3', 'E:maj6', 'A:(1)'),
#   ('E:7/5', 'A:7/5', 'G:min7'),
#   ('E:min', 'D#:dim/b5', 'D:min7/b3'),
#   ('E:min', 'C:sus4', 'C#'),
#   ('E:7', 'A:aug', 'F#'),
#   ('Bb', 'B:(1)', 'F/5'),
#   ('A/6', 'D:dim', 'B:sus2'),
#   ('E:min/5', 'A/5', 'D:maj(*1)/#1'),
#   ('A/b7', 'A:7', 'Ab'),
#   ('D:7', 'D/6', 'D:min/2'),
#   ('F#:min', 'A/b7', 'D/2'),
#   ('B:min', 'A:7', 'C#'),
#   ('D/7', 'A:maj(9)/3', 'D:min9'),
#   ('C#:min/5', 'C#:min/b7', 'E:dim/b3'),
#   ('D:min', 'B:min', 'F#'),
#   ('A/7', 'D:min9', 'C#'),
#   ('A:7/5', 'E:aug', 'F#'),
#   ('G:7', 'C/6', 'G#'),
#   ('Bb', 'D:min/6', 'F/5'),
#   ('A/5', 'E:(1,4)', 'D/2'),
#   ('D:7/5', 'Ab', 'E/6'),
#   ('G:min7', 'E:min7', 'B:sus2'),
#   ('G:7', 'A:7(13)', 'Eb/6'),
#   ('E:min', 'E:aug', 'A:aug'),
#   ('A/2', 'E:aug', 'A:(1)'),
#   ('A:min', 'E:min', 'A:maj(9)/3'),
#   ('N', 'Eb', 'F/3'),
#   ('D/7', 'G#:aug', 'F#:min7'),
#   ('C/7', 'D:dim7', 'D/b7'),
#   ('D:7', 'B', 'D:min/b3'),
#   ('G/5', 'C/7', 'A:aug'),
#   ('B:min', 'D:maj6', 'F#:min7'),
#   ('B', 'A:7(*5,13)', 'D:dim'),
#   ('D:7', 'E:min/6', 'G#'),
#   ('D:min', 'F#:min/5', 'A:min/5'),
#   ('G/5', 'G:sus4(2)', 'A:9'),
#   ('N', 'C#:min/5', 'D:min9'),
#   ('A/b6', 'G#:aug', 'E/6'),
#   ('A:7', 'E:(1,4)', 'B:dim'),
#   ('A', 'E:min/6', 'D:min/b3'),
#   ('D:maj(*1)/#1', 'D#:hdim7', 'E:dim/b3'),
#   ('Bb:7', 'A:9', 'F#:min7'),
#   ('C/7', 'D:min/b3', 'E:sus4(b7)'),
#   ('A/3', 'D:min/5', 'E:min7'),
#   ('E:7', 'A:7/5', 'Gb'),
#   ('C', 'A:7/3', 'A:(1)'),
#   ('E:min', 'E:9', 'D:min7(2,*b3,4)'),
#   ('A:7/5', 'E', 'D/b7'),
#   ('A/6', 'G:sus4(2)', 'E:dim/b3'),
#   ('E/5', 'D:min7(2,*b3,4)', 'D:maj6'),
#   ('G:7', 'A:min7', 'D:min/b7'),
#   ('A', 'G:7', 'D'),
#   ('G', 'C', 'A:min7'),
#   ('G:7', 'G:sus4(2)/2', 'B/5'),
#   ('B/5', 'D:min9', 'G:min7'),
#   ('G', 'A:7', 'D#:dim/b5'),
#   ('C/2', 'E/7', 'A:min/5'),
#   ('C/2', 'E:min/b7', 'G#:aug'),
#   ('A:7', 'D:min/2', 'Gb'),
#   ('G:sus4(2)', 'Bb:7', 'G#'),
#   ('E:min', 'E:min/6', 'G/#4'),
#   ('A/2', 'E/5', 'G:min7'),
#   ('D/5', 'E:(1,4)', 'D:min/b7'),
#   ('B/5', 'D:min7(2,*b3,4)', 'D:maj6'),
#   ('G#:min7/b3', 'Eb/6', 'F/5'),
#   ('B:min', 'E:min/6', 'A:min/5'),
#   ('D:7/5', 'D/3', 'E:min7'),
#   ('D:7/5', 'E:(1,4)', 'F/5'),
#   ('Eb', 'C#:min', 'D#:hdim7'),
#   ('B', 'G/#4', 'D#:(1,4)'),
#   ('C/3', 'G:sus4(2)/2', 'F/5'),
#   ('D/5', 'G#:min7/b3', 'F/3'),
#   ('G:7', 'A/b7', 'C#'),
#   ('A/5', 'D:min/2', 'A:7(13)'),
#   ('G:7', 'A/b7', 'B:(1)'),
#   ('Ab:aug', 'A:7/3', 'C#:min'),
#   ('C#:min/b7', 'D:(1,4)', 'E:sus4'),
#   ('G:sus4(2)', 'F:7', 'Gb'),
#   ('C#:min/5', 'D#:(1,4)', 'Eb/6'),
#   ('B/5', 'D#', 'Eb/6'),
#   ('G:sus4(2)/2', 'A/b7', 'D/3'),
#   ('E/5', 'D#:dim/b5', 'D/b7'),
#   ('D:min/2', 'D/3', 'G#:7'),
#   ('C/2', 'D:maj(*1)/#1', 'Bb:7'),
#   ('B:min', 'E:aug', 'E:min7'),
#   ('C/7', 'G:sus4(2)', 'E:7'),
#   ('E:7', 'Eb/6', 'A:(1)'),
#   ('G/5', 'D#', 'Ab'),
#   ('A/b7', 'Bb', 'G#:7'),
#   ('C', 'D:maj(*1)/#1', 'A:min7'),
#   ('A/3', 'A:aug', 'A:7(*5,13)'),
#   ('F#:min', 'A:7/3', 'F/3'),
#   ('D:(1,4)', 'A:9', 'G:min7'),
#   ('Eb', 'E/7', 'A:aug'),
#   ('A/2', 'F#/5', 'D:dim7'),
#   ('C#:min', 'E/7', 'C:maj6/5'),
#   ('F#/5', 'C:sus4', 'Eb/6'),
#   ('C#:min/b7', 'C#', 'B:sus2'),
#   ('Eb', 'D#:(1,4)', 'G:9(*3,11)'),
#   ('G:sus4(2)/2', 'C/6', 'D/6'),
#   ('G/3', 'D:7', 'C:maj7'),
#   ('E/5', 'D#', 'E/b7'),
#   ('A:7(13)', 'G#:7', 'D:dim7'),
#   ('D:min/b3', 'D:min9', 'C#'),
#   ('Bb', 'G#', 'D:min9'),
#   ...},
#  '012': {('D#:(1,4)', 'D:(1,4)', 'F#/5'),
#   ('C#:min/b7', 'D:min', 'E:9'),
#   ('C#:min', 'D#:hdim7', 'D:maj(*1)/#1'),
#   ('B:min', 'D:min/5', 'G'),
#   ('A:min', 'B:sus2', 'D:min'),
#   ('A:min', 'C', 'D:7/5'),
#   ('Bb', 'C#:min', 'D:(1,4)'),
#   ('D:min', 'D:min/2', 'F:7'),
#   ('A:7(13)', 'A:9', 'D:7'),
#   ('A/b6', 'D:min7(2,*b3,4)', 'F'),
#   ('A:maj(9)/3', 'B:min', 'C:sus4'),
#   ('B:min', 'C#:min', 'C#:min/b7'),
#   ('A:min7', 'D#:(1,4)', 'E:7'),
#   ('A:aug', 'C/6', 'D:min'),
#   ('A/2', 'B/5', 'D'),
#   ('A:min7', 'C:maj6/5', 'F/3'),
#   ('Bb:7', 'D', 'F#:min'),
#   ('A:7(*5,13)', 'E:min', 'E:min/b7'),
#   ('Ab:aug', 'B:min', 'G:7'),
#   ('C/3', 'C:7', 'E:min7'),
#   ('A', 'E:sus4(b7)', 'F/5'),
#   ('A:maj(9)/3', 'D', 'D:dim'),
#   ('A/5', 'B', 'E:min'),
#   ('G#:7', 'G:7', 'N'),
#   ('A/6', 'A:min', 'E:7'),
#   ('A/2', 'F#', 'G#:7'),
#   ('C#:min', 'C#:min/b7', 'D:min7/b3'),
#   ('B', 'C#:min', 'E:sus4(b7)'),
#   ('A/5', 'F#:min', 'G#:aug'),
#   ('D:min/6', 'D:min/b7', 'G/3'),
#   ('D:dim', 'D:min', 'G'),
#   ('E:sus4', 'Eb/6', 'F/5'),
#   ('A', 'A:7/5', 'F:7'),
#   ('C#', 'Eb', 'G'),
#   ('D:min/5', 'G/2', 'G/3'),
#   ('B', 'D:min/5', 'F#:min/5'),
#   ('A:(1)', 'C#:min', 'N'),
#   ('C:7', 'C:maj6/5', 'E:min/5'),
#   ('A:7', 'E:7', 'F#/5'),
#   ('C/6', 'E:maj6', 'G:9(*3,11)'),
#   ('A:min7', 'C', 'E/6'),
#   ('E:maj6', 'G#:min7/b3', 'G/5'),
#   ('C#:min/5', 'D', 'D/3'),
#   ('A:7(*5,13)', 'D', 'E/7'),
#   ('Ab:aug', 'D', 'D#'),
#   ('D', 'E/7', 'F#:min/5'),
#   ('D:maj(*1)/#1', 'G', 'Gb'),
#   ('D:dim', 'G', 'G#:aug'),
#   ('A', 'C#:min/5', 'D#'),
#   ('Bb:7', 'C#:min/5', 'E:9'),
#   ('F', 'F#', 'F#:min7'),
#   ('C/2', 'D:dim', 'F#'),
#   ('A', 'C/6', 'D:7'),
#   ('E:(1,4)', 'E:9', 'F#:min/5'),
#   ('D:min7(2,*b3,4)', 'E:maj6', 'G#:min7/b3'),
#   ('D', 'D:maj(*1)/#1', 'G:7'),
#   ('B', 'D#:(1,4)', 'D:(1,4)'),
#   ('C/3', 'D:7', 'G'),
#   ('C', 'C:maj6/5', 'C:sus4'),
#   ('D#', 'E', 'F#:min7'),
#   ('A:min', 'E/5', 'E:dim/b3'),
#   ('A', 'E:min/5', 'F#'),
#   ('C/5', 'D:7', 'F#/5'),
#   ('A/3', 'E/5', 'E:7'),
#   ('E:min/6', 'G', 'G:sus4(2)'),
#   ('A:maj(9)/3', 'C:maj7', 'G'),
#   ('C/6', 'C/7', 'D:min/6'),
#   ('E', 'E/7', 'E:dim/b3'),
#   ('D:min/4', 'E:9', 'G'),
#   ('C', 'D/b7', 'E:min'),
#   ('A/5', 'C:sus4', 'D'),
#   ('D/3', 'E:min/5', 'E:min/6'),
#   ('A:min', 'D:min7/b3', 'E:7'),
#   ('C/5', 'C/6', 'D/6'),
#   ('A/5', 'A/b7', 'E:9'),
#   ('A:(1)', 'B:(1)', 'Bb:7'),
#   ('A', 'A/b7', 'E:maj6'),
#   ('A:7(*5,13)', 'C#:min/5', 'D'),
#   ('A', 'A/7', 'D#'),
#   ('D#:(1,4)', 'E', 'E/7'),
#   ('A/2', 'A/5', 'F#:min'),
#   ('A:9', 'C#:min', 'D#'),
#   ('C/5', 'D:7', 'E/5'),
#   ('C', 'C:maj7', 'E:7/5'),
#   ('A/6', 'A/b7', 'D:maj(*1)/#1'),
#   ('A:aug', 'D:min/6', 'D:min/b7'),
#   ('C/3', 'D/5', 'E:9'),
#   ('D:(1,4)', 'E:dim/b3', 'G'),
#   ('A:9', 'C#:min', 'E:(1,4)'),
#   ('A', 'C#:min/b7', 'D/7'),
#   ('C#:min', 'C/5', 'N'),
#   ('A/5', 'A/7', 'F#:min'),
#   ('D:dim', 'E:sus4', 'F#'),
#   ('B:min', 'D:7/5', 'F#'),
#   ('E/6', 'E/b7', 'E:7'),
#   ('C', 'D:dim7', 'D:min7(2,*b3,4)'),
#   ('B:maj6', 'D:min', 'E:9'),
#   ('D:min', 'D:min/2', 'E:dim/b3'),
#   ('D:min9', 'F', 'F#:min7'),
#   ('B', 'D:min', 'E:9'),
#   ('C', 'D:min/4', 'E:9'),
#   ('A:7', 'Bb:7', 'C#'),
#   ('A:min', 'F#:min7', 'G:min7'),
#   ('Bb:7', 'C#', 'E:9'),
#   ('A/3', 'E:7', 'G/#4'),
#   ('C:maj6/5', 'F/3', 'G#:aug'),
#   ('A', 'C#:min/b7', 'F#'),
#   ('A', 'Ab', 'C/5'),
#   ('D', 'D:maj6', 'F#:min/5'),
#   ('A:(1)', 'F', 'G'),
#   ('B:min', 'C:sus4', 'D:7/5'),
#   ('A/5', 'C', 'D/2'),
#   ('A:min7', 'D:min9', 'F#/5'),
#   ('A:min', 'B:9', 'C:maj7/7'),
#   ('B', 'B:(1)', 'G'),
#   ('A/5', 'A/b6', 'D/7'),
#   ('A:7/3', 'D:7/5', 'G'),
#   ('C#:min', 'E/7', 'F#:min7'),
#   ('C#', 'F', 'G'),
#   ('B:min', 'D', 'Gb'),
#   ('D/2', 'E:min/5', 'E:min/6'),
#   ('D:dim7', 'Eb/6', 'F/5'),
#   ('D:min', 'D:min7/b3', 'G:7'),
#   ('F:maj7', 'G', 'Gb'),
#   ('C/7', 'D:min/5', 'D:min/6'),
#   ('A', 'G#', 'G/#4'),
#   ('B:sus2', 'E:min/6', 'E:min/b7'),
#   ('C', 'D:dim', 'G:7'),
#   ('A:min', 'F/3', 'G/2'),
#   ('B', 'F/3', 'G'),
#   ('E:7/5', 'E:aug', 'N'),
#   ('A:min', 'Ab:aug', 'E/6'),
#   ('A:7(13)', 'A:min', 'C:7'),
#   ('A:(1)', 'B:min', 'G:7'),
#   ('A:7/5', 'D:dim', 'F#'),
#   ('A:7', 'E:(1,4)', 'E:min'),
#   ('D:7/5', 'F#/5', 'G'),
#   ('D/3', 'G/3', 'G:sus4(2)/2'),
#   ('C#:min', 'D:min/b3', 'G#:7'),
#   ('C', 'C:maj7/7', 'D:min/b3'),
#   ('A/7', 'A/b7', 'Eb/6'),
#   ('A:7(13)', 'A:9', 'C/5'),
#   ('C', 'C/7', 'C:maj6/5'),
#   ('Ab', 'F:7', 'G'),
#   ('C', 'E/5', 'F#'),
#   ('B:sus2', 'Eb', 'F'),
#   ('A:min/5', 'B:maj6', 'D:min7/b3'),
#   ('A:9', 'G/#4', 'G/3'),
#   ('B:dim', 'E/b7', 'F'),
#   ('C', 'Eb', 'F:7'),
#   ('A:min7', 'D:min/5', 'G/2'),
#   ('A:9', 'C:maj6/5', 'F/3'),
#   ('A/5', 'A/7', 'D/2'),
#   ('A:maj(9)/3', 'C', 'G:7'),
#   ('A/3', 'A/7', 'A/b7'),
#   ('D#:(1,4)', 'E:(1,4)', 'E:maj6'),
#   ('A/5', 'A/b7', 'A:min7'),
#   ('B/5', 'E:7', 'E:sus4(b7)'),
#   ('A:min', 'B:(1)', 'C:(1)'),
#   ('E/5', 'Eb', 'Gb'),
#   ('D:7', 'E/5', 'G'),
#   ('D/2', 'E', 'G:sus4(2)'),
#   ('D:maj(*1)/#1', 'E/5', 'E/6'),
#   ('C#:min', 'C#:min/b7', 'C:(1)'),
#   ('Bb:7', 'D#:hdim7', 'E:9'),
#   ('C/5', 'C/6', 'D:min/4'),
#   ('A:min', 'C/2', 'C:7'),
#   ('A:9', 'A:min', 'C:7'),
#   ('A:(1)', 'D#:(1,4)', 'D:(1,4)'),
#   ('A', 'A:7', 'C/2'),
#   ('F', 'G:min7', 'N'),
#   ('A/3', 'D', 'D:min/2'),
#   ('C/2', 'C/3', 'E:(1,4)'),
#   ('C:maj7', 'E/7', 'G'),
#   ('A', 'A:7', 'D#'),
#   ('C/6', 'C/7', 'C:maj6/5'),
#   ('A:min', 'A:min7', 'E:min/5'),
#   ('E:9', 'Eb', 'G'),
#   ('A:7(*5,13)', 'B', 'C#:min'),
#   ('B:dim', 'E:maj6', 'F:maj7'),
#   ('C', 'E/6', 'E/b7'),
#   ('F/3', 'G/2', 'G:7'),
#   ('E:dim/b3', 'G/3', 'G:sus4(2)'),
#   ('A:7', 'C#:min/5', 'E:7'),
#   ('A:min', 'D:min9', 'G:9(*3,11)'),
#   ('C', 'C#:min', 'G:9(*3,11)'),
#   ('A:7(13)', 'E', 'G'),
#   ('D:7', 'E:sus4(b7)', 'G'),
#   ('C:7', 'C:sus4', 'E:min7'),
#   ('A/6', 'A/b6', 'D#:dim/b5'),
#   ('C', 'D/3', 'G/3'),
#   ('C:maj6/5', 'D:min/5', 'F/3'),
#   ('B', 'D', 'E:maj6'),
#   ('E:maj6', 'E:min7', 'G:9(*3,11)'),
#   ('A:7/3', 'A:maj(9)/3', 'B:min'),
#   ('D:min', 'E:9', 'G#:7'),
#   ('A:7', 'Bb:7', 'D:min/4'),
#   ('C:(1)', 'D', 'F:7'),
#   ('D/6', 'Eb/6', 'F/5'),
#   ('C', 'C#:min/b7', 'C/7'),
#   ('A:min', 'D:min9', 'Eb/6'),
#   ('C#:min/5', 'F#:min', 'G/5'),
#   ('A:7/3', 'D/5', 'E:min'),
#   ('A:7(*5,13)', 'D/3', 'G'),
#   ('G#:min7/b3', 'G/3', 'G:sus4(2)/2'),
#   ('B/5', 'E:min/6', 'E:min/b7'),
#   ('C#:min', 'C:7', 'N'),
#   ('A:min/5', 'D', 'D:min7/b3'),
#   ('A:7(*5,13)', 'F', 'G'),
#   ('D#:dim/b5', 'E', 'E:aug'),
#   ('Eb/6', 'F#:min7', 'G:min7'),
#   ('C#:min', 'D:dim', 'E:aug'),
#   ('C/5', 'D#:(1,4)', 'D:7'),
#   ('C/2', 'C/3', 'E:7/5'),
#   ('A/6', 'A:maj(9)/3', 'B:min'),
#   ('A:(1)', 'Eb', 'Gb'),
#   ('E:(1,4)', 'E:7', 'E:sus4(b7)'),
#   ('D:min/5', 'E/b7', 'E:9'),
#   ('D:maj(*1)/#1', 'E:7', 'G#:7'),
#   ('A:min', 'D:min7/b3', 'G#:aug'),
#   ('A:7(13)', 'D', 'E:sus4(b7)'),
#   ('B:maj6', 'E', 'E/7'),
#   ('A:(1)', 'D', 'E:min7'),
#   ('D', 'E:min/5', 'G/5'),
#   ('B', 'E/6', 'E/b7'),
#   ('A:7', 'A:maj(9)/3', 'B:min'),
#   ('A:7', 'A:7/3', 'E:7/5'),
#   ('A/5', 'Bb:7', 'F#:min'),
#   ('D:min', 'E:min/5', 'G'),
#   ('A', 'A/b7', 'E:min7'),
#   ('D', 'D/3', 'E:aug'),
#   ('A/5', 'A/b7', 'E:7/5'),
#   ('A/3', 'B:dim', 'F:maj7'),
#   ('A', 'C:sus4', 'D:maj6'),
#   ('D:min', 'E', 'E:9'),
#   ('D/b7', 'E:(1,4)', 'Eb/6'),
#   ('E', 'E/b7', 'F#:min7'),
#   ('Ab:aug', 'C#:min', 'D:dim7'),
#   ('A/3', 'G/3', 'N'),
#   ('A:maj(9)/3', 'C#:min/5', 'D:maj6'),
#   ('A:min', 'B', 'G/3'),
#   ('A:9', 'C#:min', 'G:sus4(2)/2'),
#   ('A:min', 'D:7', 'G/3'),
#   ('A:min7', 'E', 'E:aug'),
#   ('A:min', 'D', 'F#:min/5'),
#   ('A:7(*5,13)', 'D', 'E:min/6'),
#   ('A:7/3', 'C', 'Eb'),
#   ('A', 'F', 'G#:min7/b3'),
#   ('D/6', 'E:min/6', 'E:min/b7'),
#   ('A/b6', 'C:7', 'E:min/5'),
#   ('A', 'E:dim/b3', 'G#'),
#   ('C:maj7', 'D/7', 'G'),
#   ('B', 'E:min/b7', 'G'),
#   ('A/2', 'E:min', 'E:min/b7'),
#   ('C', 'E:7', 'Eb'),
#   ('A:7/3', 'D#:dim/b5', 'E:min'),
#   ('D/5', 'F#:min7', 'G/2'),
#   ('F#', 'F:7', 'G#:7'),
#   ('C', 'D:min/5', 'G/5'),
#   ('D:min', 'E:9', 'E:min7'),
#   ('Bb:7', 'E:9', 'G'),
#   ('C', 'D/7', 'G/5'),
#   ('B:sus2', 'D:7', 'D:min/2'),
#   ('E:maj6', 'E:min/5', 'G:9(*3,11)'),
#   ('A:maj(9)/3', 'D:min/6', 'D:min/b7'),
#   ('D:dim', 'E', 'E/7'),
#   ('A:min', 'D/7', 'D:min9'),
#   ('A/5', 'A/b7', 'G#:aug'),
#   ('A:7', 'C', 'C:maj7/7'),
#   ('D:7', 'E:(1,4)', 'E:9'),
#   ('Bb:7', 'D:min/2', 'E:9'),
#   ('A:7(13)', 'D:dim7', 'N'),
#   ('E', 'E:aug', 'F/5'),
#   ('A/7', 'A/b7', 'A:7(13)'),
#   ('A:min7', 'D:min', 'G/#4'),
#   ('Ab:aug', 'D#', 'E'),
#   ('C/7', 'G', 'Gb'),
#   ('C', 'D#:hdim7', 'D:min7(2,*b3,4)'),
#   ('A:7/3', 'F#', 'G#:7'),
#   ('B:(1)', 'Bb:7', 'G#:aug'),
#   ('A:(1)', 'G/3', 'G:sus4(2)'),
#   ('B:min', 'E:min/6', 'E:min/b7'),
#   ('A:7(13)', 'C', 'C:maj7/7'),
#   ('Ab', 'C', 'G:7'),
#   ('A:9', 'C#:min', 'G:min7'),
#   ('E:min/5', 'F', 'N'),
#   ('B:dim', 'E:sus4', 'F:maj7'),
#   ('Eb/6', 'F/5', 'F:7'),
#   ('D:min', 'F#', 'G#:7'),
#   ('C/6', 'E/5', 'G'),
#   ('B', 'C:(1)', 'D'),
#   ('A:(1)', 'A:min', 'E/5'),
#   ('C#:min/5', 'E:aug', 'F#:min'),
#   ('D:min9', 'G#:aug', 'G:7'),
#   ('C:maj7/7', 'D:min/4', 'E:9'),
#   ('A/5', 'B:min', 'F#:min'),
#   ('B', 'C:maj6/5', 'F/3'),
#   ('A:min', 'C:7', 'E:sus4(b7)'),
#   ('C:7', 'Eb', 'G'),
#   ('A/6', 'C', 'N'),
#   ('D:maj6', 'D:min', 'D:min9'),
#   ('D/5', 'D/6', 'D:min/6'),
#   ('C:maj6/5', 'C:maj7', 'G'),
#   ('B', 'F', 'N'),
#   ('C#:min/5', 'F#:min', 'F/5'),
#   ('Ab:aug', 'D:min/5', 'D:min/6'),
#   ('Bb', 'D:min/6', 'F'),
#   ('A:min7', 'D#', 'E:7'),
#   ('D:min/5', 'E/7', 'G'),
#   ('F', 'F#', 'G#:7'),
#   ('B:min', 'B:sus2', 'D#:hdim7'),
#   ('A/7', 'D:min/5', 'G'),
#   ('B:9', 'G', 'G#:aug'),
#   ('A:maj(9)/3', 'B:maj6', 'D:maj6'),
#   ('A/5', 'A/b6', 'E:(1,4)'),
#   ('A/3', 'E:7', 'E:min/6'),
#   ('D:dim7', 'E:(1,4)', 'N'),
#   ('D#', 'D/b7', 'Eb/6'),
#   ('A', 'D#:hdim7', 'G/2'),
#   ('A/b6', 'D#:hdim7', 'G#'),
#   ('A:min', 'B:9', 'E:9'),
#   ('A/3', 'D#', 'E'),
#   ('D:min/5', 'D:min9', 'G'),
#   ('E/5', 'E/6', 'G/2'),
#   ('A:9', 'A:min', 'C:maj7/7'),
#   ('A/2', 'B:min', 'F#/5'),
#   ('B:maj6', 'Eb', 'F'),
#   ('A/3', 'Eb', 'Gb'),
#   ('A:maj(9)/3', 'B:min', 'G#:7'),
#   ('A:(1)', 'A:aug', 'D'),
#   ('D/6', 'E:maj6', 'G#:min7/b3'),
#   ('B', 'C#:min', 'C/7'),
#   ('D', 'E:min7', 'F:7'),
#   ('C/5', 'D:7', 'Gb'),
#   ('A:min7', 'C:maj6/5', 'G/2'),
#   ('A:min', 'D:min', 'F:maj7'),
#   ('D:min', 'D:min/2', 'G#:min7/b3'),
#   ('E', 'E/b7', 'F/5'),
#   ('E:maj6', 'F:7', 'G:9(*3,11)'),
#   ('A:7', 'E:7', 'G'),
#   ('A:min', 'C:maj7/7', 'D/5'),
#   ('A:(1)', 'D', 'G:9(*3,11)'),
#   ('Bb:7', 'E', 'E:9'),
#   ('A:min7', 'E:min7', 'N'),
#   ('A', 'D:min/b3', 'F'),
#   ('A', 'G/#4', 'G/5'),
#   ('A', 'B:9', 'E/5'),
#   ('B:min', 'E:maj6', 'G#:aug'),
#   ('D/7', 'E:dim/b3', 'G'),
#   ('A:min/5', 'B:min', 'F#/5'),
#   ('E:min/5', 'G', 'Gb'),
#   ('D:min/4', 'Eb', 'Gb'),
#   ('E/5', 'G', 'G/2'),
#   ('B', 'E:7/5', 'F#:min/5'),
#   ('A:7(*5,13)', 'D/2', 'E'),
#   ('E', 'E:aug', 'G#:aug'),
#   ('D:min/4', 'E:9', 'F#/5'),
#   ('D#', 'G/2', 'G/3'),
#   ('D/5', 'D/6', 'D:min7/b3'),
#   ('C/5', 'C/6', 'D:min9'),
#   ('A:7/5', 'D', 'D:dim'),
#   ('Bb', 'E:aug', 'F'),
#   ('A:min7', 'C', 'C#:min/b7'),
#   ('A:min7', 'C:maj7/7', 'G/2'),
#   ('A:min', 'D/b7', 'Eb/6'),
#   ('A:min7', 'C:maj6/5', 'D:min7/b3'),
#   ('C', 'E/b7', 'E:min/5'),
#   ('A', 'C/7', 'G#'),
#   ('B', 'D', 'D/6'),
#   ('Bb', 'C', 'C/5'),
#   ('A:min/5', 'C', 'D:7'),
#   ('A:7(13)', 'B:(1)', 'Bb:7'),
#   ('C/2', 'Eb', 'F'),
#   ('C', 'C:maj7/7', 'D:maj6'),
#   ('B', 'D/2', 'F:maj7'),
#   ('D', 'D:(1,4)', 'G/5'),
#   ('C#:min', 'D#:hdim7', 'D:min/b3'),
#   ('E', 'F#:min', 'G:sus4(2)/2'),
#   ('E:maj6', 'F/5', 'G:9(*3,11)'),
#   ('C:7', 'D#:(1,4)', 'E:min/5'),
#   ('C/3', 'E:maj6', 'F#:min7'),
#   ('A/7', 'A:min', 'G/3'),
#   ('D:7', 'F/3', 'G'),
#   ('D:min/5', 'D:min/6', 'G/5'),
#   ('A:7/3', 'D:dim7', 'N'),
#   ('C', 'C#:min/5', 'G:9(*3,11)'),
#   ('A:7(*5,13)', 'A:9', 'D:min/5'),
#   ('C', 'D#:dim/b5', 'D/b7'),
#   ('C', 'D:min/6', 'E:min/5'),
#   ('C#:min', 'D:7', 'D:dim'),
#   ('A:7/3', 'D:min7(2,*b3,4)', 'F'),
#   ('D#:hdim7', 'F#:min/5', 'G#'),
#   ('A:min', 'B', 'E/5'),
#   ('D/5', 'D:dim7', 'G/2'),
#   ('D:min/2', 'D:min/4', 'D:min/5'),
#   ('A:aug', 'B/5', 'Bb:7'),
#   ('A/6', 'A/b7', 'Eb/6'),
#   ('A/b7', 'A:aug', 'Bb:7'),
#   ('E:maj6', 'E:min', 'G#:aug'),
#   ('D/2', 'E', 'G/3'),
#   ('A:min7', 'D:min9', 'E/5'),
#   ('D:(1,4)', 'F/3', 'G/2'),
#   ('E/5', 'E/6', 'G:9(*3,11)'),
#   ('A', 'A:(1)', 'E:aug'),
#   ('D:min', 'D:min7/b3', 'D:min9'),
#   ('Bb', 'C#:min/b7', 'F'),
#   ('A', 'D/b7', 'D:min/4'),
#   ('A', 'A:7(13)', 'G/3'),
#   ('A/3', 'D:min7(2,*b3,4)', 'E:7'),
#   ('C/5', 'C/6', 'G/2'),
#   ('Eb', 'F:7', 'Gb'),
#   ('B/5', 'C', 'Gb'),
#   ('A:(1)', 'B:dim', 'F'),
#   ('E/b7', 'G/3', 'N'),
#   ('C:maj6/5', 'D#:hdim7', 'G#'),
#   ('E:dim/b3', 'G', 'G#:min7/b3'),
#   ('A:min7', 'B:min', 'G:7'),
#   ('Bb', 'D:(1,4)', 'D:7'),
#   ('D:dim', 'D:dim7', 'F#'),
#   ('A:min', 'C/6', 'G#:aug'),
#   ('C/5', 'D/6', 'D/7'),
#   ('A:min', 'D:min/5', 'D:min9'),
#   ('B:dim', 'D/b7', 'F'),
#   ('B', 'D/2', 'E:7/5'),
#   ('A:min', 'B/5', 'E'),
#   ('C/6', 'E:min7', 'G'),
#   ('C', 'D/2', 'E:min/5'),
#   ('A:7', 'Bb:7', 'D/3'),
#   ('A', 'D/b7', 'E:min'),
#   ('B', 'D:min7(2,*b3,4)', 'F'),
#   ('A:7', 'E:maj6', 'E:min'),
#   ('E:maj6', 'F/5', 'G#:aug'),
#   ('D:min/b3', 'D:min9', 'G:7'),
#   ('A/2', 'F/3', 'G/2'),
#   ('A', 'A/b6', 'G#'),
#   ('A/3', 'D:min/4', 'E:9'),
#   ('A:min', 'D#:(1,4)', 'E/5'),
#   ('A/b7', 'E:dim/b3', 'G'),
#   ('F/3', 'G/3', 'G:sus4(2)/2'),
#   ('D#', 'E', 'Eb/6'),
#   ('C#:min', 'D#:hdim7', 'G/3'),
#   ('A', 'A/7', 'D#:(1,4)'),
#   ('A:min7', 'E:7', 'G:sus4(2)/2'),
#   ('C:(1)', 'E:9', 'G:sus4(2)'),
#   ('C#:min', 'D#:dim/b5', 'G#:7'),
#   ('B:dim', 'Bb', 'C'),
#   ('E', 'E/7', 'E:7/5'),
#   ('C/5', 'D:7', 'F#:min/5'),
#   ('E', 'F/3', 'G/2'),
#   ('D#:hdim7', 'E:7/5', 'G#'),
#   ('E:(1,4)', 'Eb', 'G'),
#   ('E:dim/b3', 'Eb', 'G/5'),
#   ('D:min/4', 'E:min/5', 'E:min/6'),
#   ('A/2', 'B:dim', 'E:7'),
#   ('Ab:aug', 'E/5', 'E/6'),
#   ('B:sus2', 'D#:(1,4)', 'E:(1,4)'),
#   ('A:7', 'B:9', 'E:min'),
#   ('A', 'A/b7', 'D:min/b3'),
#   ('C#:min', 'D:dim', 'D:min/6'),
#   ('C', 'D:min/b3', 'D:min7(2,*b3,4)'),
#   ('C#:min', 'D:(1,4)', 'E/7'),
#   ('A:min/5', 'D:min7/b3', 'E:min/b7'),
#   ('C/6', 'D', 'D:dim'),
#   ('A:aug', 'A:min', 'E:min/6'),
#   ('A/3', 'B:dim', 'D/6'),
#   ('C#:min', 'D:dim', 'E:9'),
#   ('A:min7', 'E:min/6', 'N'),
#   ('B', 'D/2', 'E/5'),
#   ('A:min7', 'D:min/4', 'D:min9'),
#   ('D:min', 'D:min/2', 'G:sus4(2)'),
#   ('A/3', 'D', 'D:min7(2,*b3,4)'),
#   ('D:7/5', 'D:min', 'F'),
#   ('A/5', 'E', 'G/2'),
#   ('B:dim', 'E:7', 'F#:min/5'),
#   ('Bb', 'C', 'C#:min/5'),
#   ('A', 'E/6', 'E:9'),
#   ('A:7(*5,13)', 'C:(1)', 'D'),
#   ('A:7/3', 'A:min', 'G'),
#   ('Ab', 'C', 'Gb'),
#   ('A:min7', 'D#:hdim7', 'E:7'),
#   ('C:maj7', 'D:min/6', 'D:min/b7'),
#   ('A/2', 'D', 'D:7'),
#   ('C/7', 'E:min/6', 'E:min/b7'),
#   ('B', 'D:min/4', 'D:min/5'),
#   ('D:maj(*1)/#1', 'E:7', 'N'),
#   ('A/6', 'E', 'E/b7'),
#   ('B', 'E:9', 'G'),
#   ('A', 'F/5', 'G/5'),
#   ('D:maj6', 'F/3', 'G/2'),
#   ('D:min/4', 'D:min/b3', 'E'),
#   ('A', 'D:min/4', 'E/7'),
#   ('C:7', 'D:7', 'G'),
#   ('A:7', 'A:7/3', 'Eb'),
#   ('D', 'E/5', 'Gb'),
#   ('Bb', 'C', 'E:7/5'),
#   ('A:7(13)', 'D', 'D:(1,4)'),
#   ('A:7(*5,13)', 'C/5', 'C/6'),
#   ('A:7/3', 'A:min7', 'D:min'),
#   ('A', 'B:dim', 'E:sus4(b7)'),
#   ('C:maj6/5', 'D/5', 'D/6'),
#   ('A:7', 'A:7/3', 'Gb'),
#   ('A:9', 'C#:min', 'C:7'),
#   ('A:min7', 'Ab', 'G'),
#   ('A', 'A:min', 'C#'),
#   ('A', 'A:7', 'B/5'),
#   ('D#', 'D:maj(*1)/#1', 'E'),
#   ('A:(1)', 'C', 'D:7'),
#   ('D:min9', 'G#:7', 'G:7'),
#   ('Bb', 'G/3', 'G:sus4(2)/2'),
#   ('D:min/6', 'D:min/b7', 'Eb/6'),
#   ('C', 'F/5', 'G#'),
#   ('E:dim/b3', 'F:7', 'G'),
#   ('A:min', 'D:min', 'G/#4'),
#   ('A:7', 'B', 'Bb:7'),
#   ('B:dim', 'E/5', 'E:7'),
#   ('A/6', 'A/b7', 'A:7'),
#   ('C', 'C:maj7', 'E:7'),
#   ('C', 'G#:aug', 'G:9(*3,11)'),
#   ('E/6', 'E/b7', 'G/3'),
#   ('C/5', 'D:7', 'E/7'),
#   ('B:maj6', 'C:maj7', 'G'),
#   ('C:maj7', 'C:sus4', 'G'),
#   ('C#:min', 'D#:hdim7', 'F#/5'),
#   ('C#:min', 'E', 'G:sus4(2)'),
#   ('A:min', 'D:min/2', 'E:9'),
#   ('C:maj7', 'G', 'G#'),
#   ('E:7', 'E:maj6', 'G:9(*3,11)'),
#   ('A:aug', 'A:min', 'F:maj7'),
#   ('B:9', 'C', 'C:maj7'),
#   ('D:min/b7', 'Eb', 'F'),
#   ('C/3', 'D', 'Gb'),
#   ('B:maj6', 'F#:min7', 'G'),
#   ('Ab', 'E:min', 'E:min/b7'),
#   ('A', 'E:min/b7', 'G#'),
#   ('E/7', 'G', 'G:sus4(2)'),
#   ('B/5', 'C', 'E:min7'),
#   ('A', 'D/2', 'G/5'),
#   ('D/6', 'D/7', 'D:min/2'),
#   ('A:7(*5,13)', 'D', 'D:min9'),
#   ('C#:min', 'D:min/5', 'D:min/6'),
#   ('A:7', 'G', 'G/2'),
#   ('A:min', 'D:min/4', 'G/3'),
#   ('Ab:aug', 'E:aug', 'N'),
#   ('E:aug', 'G#:7', 'N'),
#   ('B', 'C/2', 'E:7'),
#   ('C:(1)', 'D:min7(2,*b3,4)', 'E:9'),
#   ('A:7/3', 'D:min/5', 'G'),
#   ('B:(1)', 'C:7', 'E:min/5'),
#   ('A:min', 'D#:dim/b5', 'E:7'),
#   ('A/b6', 'C:maj6/5', 'F/3'),
#   ('D:(1,4)', 'E', 'E/7'),
#   ('A:7', 'A:7/3', 'A:min/5'),
#   ('C/2', 'E:dim/b3', 'G'),
#   ('B', 'D#:hdim7', 'D/2'),
#   ('A/5', 'C:(1)', 'F#:min'),
#   ('C:sus4', 'E:9', 'G:7'),
#   ('D:min/4', 'D:min/b3', 'F#/5'),
#   ('A:7(13)', 'A:9', 'D/7'),
#   ('D#', 'E:min/5', 'E:min/6'),
#   ('Bb:7', 'C:7', 'E:9'),
#   ('A:min/5', 'D#:(1,4)', 'D:(1,4)'),
#   ('C', 'C/2', 'D:min/6'),
#   ('C', 'D#:dim/b5', 'G/3'),
#   ('C#:min/5', 'F#:min', 'G:9(*3,11)'),
#   ('A/5', 'A/b6', 'E:sus4(b7)'),
#   ('A:7/5', 'A:min', 'E:9'),
#   ('D:min/2', 'D:min/b3', 'F#/5'),
#   ('A:7', 'D:min/b3', 'E:min'),
#   ('C:(1)', 'D:dim', 'E:9'),
#   ('A/5', 'A/b7', 'D/7'),
#   ('A/6', 'A/b6', 'D:min/b7'),
#   ('A', 'A:7(*5,13)', 'D/6'),
#   ('A:maj(9)/3', 'C/6', 'G'),
#   ('B', 'C:sus4', 'D'),
#   ('A', 'A:7(13)', 'C#:min/b7'),
#   ('B:min', 'C', 'E:min/5'),
#   ('A/5', 'A/b6', 'D:min/6'),
#   ('C/5', 'C/6', 'D#'),
#   ('A:min', 'E/6', 'E:7'),
# ...
#   ('A', 'Bb:7', 'C#:min/5'),
#   ('A', 'Bb:7', 'D:maj6'),
#   ('A', 'Bb:7', 'E:sus4(b7)'),
#   ('A', 'Bb:7', 'F'),
#   ('A', 'Bb:7', 'F#:min'),
#   ('A', 'Bb:7', 'G/2'),
#   ('A', 'Bb:7', 'G:7'),
#   ('A', 'Bb:7', 'Gb'),
#   ('A', 'C', 'C#:min/5'),
#   ('A', 'C', 'C/7'),
#   ('A', 'C', 'C:maj7'),
#   ('A', 'C', 'C:maj7/7'),
#   ('A', 'C', 'D/b7'),
#   ('A', 'C', 'D:maj6'),
#   ('A', 'C', 'D:min7(2,*b3,4)'),
#   ('A', 'C', 'E:min7'),
#   ('A', 'C', 'E:sus4(b7)'),
#   ('A', 'C', 'F#:min'),
#   ('A', 'C', 'G/2'),
#   ('A', 'C#:min', 'C#:min/5'),
#   ('A', 'C#:min', 'D#:hdim7'),
#   ('A', 'C#:min', 'D:maj6'),
#   ('A', 'C#:min', 'E:sus4(b7)'),
#   ('A', 'C#:min', 'F'),
#   ('A', 'C#:min', 'F#:min'),
#   ('A', 'C#:min', 'G/2'),
#   ('A', 'C#:min', 'G:7'),
#   ('A', 'C#:min', 'Gb'),
#   ('A', 'C#:min/5', 'D'),
#   ('A', 'C#:min/5', 'D#:dim/b5'),
#   ('A', 'C#:min/5', 'D:min'),
#   ('A', 'C#:min/5', 'E'),
#   ('A', 'C#:min/5', 'E:7'),
#   ('A', 'C#:min/5', 'Eb'),
#   ('A', 'C#:min/5', 'G'),
#   ('A', 'C#:min/5', 'N'),
#   ('A', 'D', 'D#'),
#   ('A', 'D', 'D/7'),
#   ('A', 'D', 'D:dim'),
#   ('A', 'D', 'D:dim7'),
#   ('A', 'D', 'D:maj(*1)/#1'),
#   ('A', 'D', 'D:maj6'),
#   ('A', 'D', 'E:sus4(b7)'),
#   ('A', 'D', 'F'),
#   ('A', 'D', 'F#/5'),
#   ('A', 'D', 'F#:min/5'),
#   ('A', 'D', 'G/2'),
#   ('A', 'D', 'G:7'),
#   ('A', 'D', 'Gb'),
#   ('A', 'D#:dim/b5', 'D:maj6'),
#   ('A', 'D#:dim/b5', 'E:sus4(b7)'),
#   ('A', 'D#:dim/b5', 'F'),
#   ('A', 'D#:dim/b5', 'F#:min'),
#   ('A', 'D#:dim/b5', 'G/2'),
#   ('A', 'D#:dim/b5', 'G:7'),
#   ('A', 'D#:dim/b5', 'Gb'),
#   ('A', 'D/2', 'E'),
#   ('A', 'D/3', 'G'),
#   ('A', 'D:maj6', 'D:min'),
#   ('A', 'D:maj6', 'E'),
#   ('A', 'D:maj6', 'E:7'),
#   ('A', 'D:maj6', 'Eb'),
#   ('A', 'D:maj6', 'G'),
#   ('A', 'D:maj6', 'N'),
#   ('A', 'D:min', 'D:min/2'),
#   ('A', 'D:min', 'D:min/b7'),
#   ('A', 'D:min', 'E:sus4(b7)'),
#   ('A', 'D:min', 'F#:min'),
#   ('A', 'D:min', 'G/2'),
#   ('A', 'D:min', 'Gb'),
#   ('A', 'E', 'E/7'),
#   ('A', 'E', 'E/b7'),
#   ('A', 'E', 'E:sus4(b7)'),
#   ('A', 'E', 'F'),
#   ('A', 'E', 'G/2'),
#   ('A', 'E', 'G:7'),
#   ('A', 'E', 'Gb'),
#   ('A', 'E:7', 'F'),
#   ('A', 'E:7', 'F#:min'),
#   ('A', 'E:7', 'G/2'),
#   ('A', 'E:7', 'G:7'),
#   ('A', 'E:7', 'Gb'),
#   ('A', 'E:dim/b3', 'G'),
#   ('A', 'E:sus4(b7)', 'Eb'),
#   ('A', 'E:sus4(b7)', 'G'),
#   ('A', 'E:sus4(b7)', 'N'),
#   ('A', 'Eb', 'F#:min'),
#   ('A', 'Eb', 'G/2'),
#   ('A', 'Eb', 'G:7'),
#   ('A', 'F#:min', 'G'),
#   ('A', 'F#:min', 'N'),
#   ('A', 'G', 'G#:aug'),
#   ('A', 'G', 'G:7'),
#   ('A', 'G', 'G:sus4(2)'),
#   ('A', 'G', 'G:sus4(2)/2'),
#   ('A', 'G/2', 'N'),
#   ('A', 'Gb', 'N'),
#   ('A/2', 'A/3', 'E:7'),
#   ('A/3', 'A/5', 'E'),
#   ('A/3', 'A/5', 'E:7'),
#   ('A:(1)', 'C#', 'D'),
#   ('A:(1)', 'D', 'D/5'),
#   ('A:(1)', 'D', 'E'),
#   ('A:(1)', 'D', 'G'),
#   ('A:(1)', 'D', 'N'),
#   ('A:7', 'A:7/3', 'D:7'),
#   ('A:7', 'A:7/3', 'N'),
#   ('A:7', 'A:7/5', 'D'),
#   ('A:7', 'A:7/5', 'E:min'),
#   ('A:7', 'A:min7', 'N'),
#   ('A:7', 'C', 'D:7'),
#   ('A:7', 'C#:min', 'N'),
#   ('A:7', 'D', 'D:7'),
#   ('A:7', 'D:7', 'E:min'),
#   ('A:7', 'D:7', 'G'),
#   ('A:7', 'E:7', 'E:7/5'),
#   ('A:7', 'E:aug', 'N'),
#   ('A:7', 'E:min', 'N'),
#   ('A:7', 'F', 'N'),
#   ('A:7/3', 'A:7/5', 'E:min'),
#   ('A:min', 'B', 'E'),
#   ('A:min', 'B:9', 'E'),
#   ('A:min', 'B:min', 'E'),
#   ('A:min', 'D', 'E'),
#   ('A:min', 'E', 'E:maj6'),
#   ('A:min', 'E', 'E:sus4'),
#   ('A:min', 'E', 'F:7'),
#   ('A:min', 'E', 'N'),
#   ('A:min', 'E:7', 'E:7/5'),
#   ('A:min7', 'B', 'C'),
#   ('A:min7', 'C', 'C#'),
#   ('A:min7', 'C', 'E'),
#   ('A:min7', 'C', 'F'),
#   ('A:min7', 'C', 'F:maj7'),
#   ('A:min7', 'C', 'G'),
#   ('A:min7', 'D', 'N'),
#   ('A:min7', 'E', 'N'),
#   ('A:min7', 'E:7', 'E:7/5'),
#   ('Ab', 'C', 'G'),
#   ('Ab', 'C/5', 'G'),
#   ('Ab', 'D', 'G'),
#   ('B', 'B/5', 'C#:min'),
#   ('B', 'B/5', 'D/2'),
#   ('B', 'B/5', 'E:7'),
#   ('B', 'B/5', 'E:min'),
#   ('B', 'Bb', 'C'),
#   ('B', 'C', 'C#:min'),
#   ('B', 'C', 'C/7'),
#   ('B', 'C', 'C:maj7'),
#   ('B', 'C', 'C:maj7/7'),
#   ('B', 'C', 'D/2'),
#   ('B', 'C', 'D/b7'),
#   ('B', 'C', 'D:min7(2,*b3,4)'),
#   ('B', 'C', 'E/5'),
#   ('B', 'C', 'E:7'),
#   ('B', 'C', 'E:min'),
#   ('B', 'C', 'E:min/5'),
#   ('B', 'C', 'E:min7'),
#   ('B', 'C', 'G/3'),
#   ('B', 'C', 'Gb'),
#   ('B', 'C', 'N'),
#   ('B', 'C#', 'D'),
#   ('B', 'C/5', 'G'),
#   ('B', 'D', 'D/5'),
#   ('B', 'D', 'N'),
#   ('B', 'E', 'E/5'),
#   ('B', 'E', 'E/7'),
#   ('B', 'E', 'E/b7'),
#   ('B', 'E', 'E:aug'),
#   ('B', 'E', 'E:min'),
#   ('B', 'E', 'F#:min'),
#   ('B:9', 'C#:min', 'E'),
#   ('B:9', 'D/2', 'E'),
#   ('B:9', 'E', 'E/5'),
#   ('B:9', 'E', 'E/7'),
#   ('B:9', 'E', 'E/b7'),
#   ('B:9', 'E', 'E:7'),
#   ('B:9', 'E', 'E:aug'),
#   ('B:9', 'E', 'F#:min'),
#   ('B:9', 'E', 'G'),
#   ('B:dim', 'C', 'F'),
#   ('B:dim', 'C', 'F:maj7'),
#   ('B:dim', 'D:7', 'F'),
#   ('B:min', 'B:sus2', 'E'),
#   ('B:min', 'C#', 'D'),
#   ('B:min', 'C#:min', 'E'),
#   ('B:min', 'D', 'D/5'),
#   ('B:min', 'D', 'G'),
#   ('B:min', 'D', 'N'),
#   ('B:min', 'D/2', 'E'),
#   ('B:min', 'D:7/5', 'E'),
#   ('B:min', 'E', 'E/5'),
#   ('B:min', 'E', 'E/7'),
#   ('B:min', 'E', 'E/b7'),
#   ('B:min', 'E', 'E:7'),
#   ('B:min', 'E', 'E:aug'),
#   ('B:min', 'E', 'F#:min'),
#   ('B:min', 'E', 'G'),
#   ('Bb', 'C', 'C#'),
#   ('Bb', 'C', 'E'),
#   ('Bb', 'C', 'F:maj7'),
#   ('Bb', 'C', 'G'),
#   ('C', 'C#', 'C/7'),
#   ('C', 'C#', 'C:maj7'),
#   ('C', 'C#', 'C:maj7/7'),
#   ('C', 'C#', 'D/b7'),
#   ('C', 'C#', 'D:min7(2,*b3,4)'),
#   ('C', 'C#', 'E/5'),
#   ('C', 'C#', 'E:min/5'),
#   ('C', 'C#', 'E:min7'),
#   ('C', 'C#', 'G/3'),
#   ('C', 'C#', 'Gb'),
#   ('C', 'C#', 'N'),
#   ('C', 'C#:min', 'E'),
#   ('C', 'C/3', 'F'),
#   ('C', 'C/7', 'E'),
#   ('C', 'C/7', 'F'),
#   ('C', 'C/7', 'F:maj7'),
#   ('C', 'C/7', 'G'),
#   ('C', 'C:maj7', 'E'),
#   ('C', 'C:maj7', 'F'),
#   ('C', 'C:maj7', 'F:maj7'),
#   ('C', 'C:maj7/7', 'E'),
#   ('C', 'C:maj7/7', 'F'),
#   ('C', 'C:maj7/7', 'F:maj7'),
#   ('C', 'C:maj7/7', 'G'),
#   ('C', 'D', 'F'),
#   ('C', 'D', 'F:maj7'),
#   ('C', 'D/2', 'E'),
#   ('C', 'D/3', 'G'),
#   ('C', 'D/b7', 'E'),
#   ('C', 'D/b7', 'F'),
#   ('C', 'D/b7', 'F:maj7'),
#   ('C', 'D/b7', 'G'),
#   ('C', 'D:min', 'G/5'),
#   ('C', 'D:min7(2,*b3,4)', 'E'),
#   ('C', 'D:min7(2,*b3,4)', 'F:maj7'),
#   ('C', 'D:min7(2,*b3,4)', 'G'),
#   ('C', 'E', 'E/7'),
#   ('C', 'E', 'E/b7'),
#   ('C', 'E', 'E:7'),
#   ('C', 'E', 'E:aug'),
#   ('C', 'E', 'E:min/5'),
#   ('C', 'E', 'E:min7'),
#   ('C', 'E', 'F#:min'),
#   ('C', 'E', 'G/3'),
#   ('C', 'E', 'Gb'),
#   ('C', 'E/5', 'F'),
#   ('C', 'E/5', 'F:maj7'),
#   ('C', 'E/5', 'G'),
#   ('C', 'E:dim/b3', 'G'),
#   ('C', 'E:min/5', 'F'),
#   ('C', 'E:min/5', 'F:maj7'),
#   ('C', 'E:min/5', 'G'),
#   ('C', 'E:min7', 'F'),
#   ('C', 'E:min7', 'F:maj7'),
#   ('C', 'E:min7', 'G'),
#   ('C', 'F', 'F#:min7'),
#   ('C', 'F', 'G/3'),
#   ('C', 'F', 'Gb'),
#   ('C', 'F:maj7', 'G/3'),
#   ('C', 'F:maj7', 'Gb'),
#   ('C', 'F:maj7', 'N'),
#   ('C', 'G', 'G#:aug'),
#   ('C', 'G', 'G/2'),
#   ('C', 'G', 'G/3'),
#   ('C', 'G', 'G:sus4(2)'),
#   ('C', 'G', 'G:sus4(2)/2'),
#   ('C', 'G', 'N'),
#   ('C#', 'D', 'D#'),
#   ('C#', 'D', 'D/7'),
#   ('C#', 'D', 'D:dim'),
#   ('C#', 'D', 'D:dim7'),
#   ('C#', 'D', 'D:maj(*1)/#1'),
#   ('C#', 'D', 'Eb'),
#   ('C#', 'D', 'F#/5'),
#   ('C#', 'D', 'F#:min/5'),
#   ('C#', 'D', 'F:7'),
#   ('C#:min', 'D', 'E'),
#   ('C#:min', 'D', 'N'),
#   ('C#:min', 'D:min', 'N'),
#   ('C#:min', 'E', 'E:maj6'),
#   ('C#:min', 'E', 'E:sus4'),
#   ('C#:min', 'E', 'F:7'),
#   ('C/3', 'C/5', 'G'),
#   ('C/3', 'D:7', 'F'),
#   ('C/5', 'D/3', 'G'),
#   ('C/5', 'E:dim/b3', 'G'),
#   ('C/5', 'G', 'G#:aug'),
#   ('C/5', 'G', 'G/2'),
#   ('C/5', 'G', 'G/5'),
#   ('C/5', 'G', 'G:sus4(2)'),
#   ('C/5', 'G', 'G:sus4(2)/2'),
#   ('C:7', 'E:min', 'E:min/5'),
#   ('D', 'D#', 'D/5'),
#   ('D', 'D#', 'G'),
#   ('D', 'D#', 'N'),
#   ('D', 'D/2', 'E'),
#   ('D', 'D/5', 'D/7'),
#   ('D', 'D/5', 'D:dim'),
#   ('D', 'D/5', 'D:dim7'),
#   ('D', 'D/5', 'D:maj(*1)/#1'),
#   ('D', 'D/5', 'E:9'),
#   ('D', 'D/5', 'Eb'),
#   ('D', 'D/5', 'F#/5'),
#   ('D', 'D/5', 'F#:min/5'),
#   ('D', 'D/5', 'F:7'),
#   ('D', 'D/7', 'E'),
#   ('D', 'D/7', 'G'),
#   ('D', 'D/7', 'N'),
#   ('D', 'D:dim', 'E'),
#   ('D', 'D:dim', 'G'),
#   ('D', 'D:dim', 'N'),
#   ('D', 'D:dim7', 'E'),
#   ('D', 'D:dim7', 'G'),
#   ('D', 'D:maj(*1)/#1', 'E'),
#   ('D', 'D:maj(*1)/#1', 'G'),
#   ('D', 'D:maj(*1)/#1', 'N'),
#   ('D', 'D:min', 'G/5'),
#   ('D', 'E', 'E/7'),
#   ('D', 'E', 'E/b7'),
#   ('D', 'E', 'E:7'),
#   ('D', 'E', 'E:aug'),
#   ('D', 'E', 'Eb'),
#   ('D', 'E', 'F#/5'),
#   ('D', 'E', 'F#:min/5'),
#   ('D', 'E:aug', 'N'),
#   ('D', 'Eb', 'N'),
#   ('D', 'F', 'N'),
#   ('D', 'F#/5', 'G'),
#   ('D', 'F#/5', 'N'),
#   ('D', 'F#:min/5', 'G'),
#   ('D', 'F#:min/5', 'N'),
#   ('D', 'F:7', 'G'),
#   ('D', 'F:7', 'N'),
#   ('D', 'G', 'G#:aug'),
#   ('D', 'G', 'G/2'),
#   ('D', 'G', 'G:sus4(2)'),
#   ('D', 'G', 'G:sus4(2)/2'),
#   ('D/2', 'E', 'E:maj6'),
#   ('D/2', 'E', 'E:sus4'),
#   ('D/2', 'E', 'F:7'),
#   ('D/2', 'E', 'N'),
#   ('D:7', 'Eb', 'F'),
#   ('D:7', 'F', 'F#:min7'),
#   ('D:min', 'D:min/2', 'G/5'),
#   ('D:min', 'D:min/2', 'N'),
#   ('D:min', 'D:min/b7', 'G/5'),
#   ('D:min', 'D:min/b7', 'N'),
#   ('D:min', 'E:aug', 'N'),
#   ('D:min', 'F', 'G/5'),
#   ('D:min', 'G', 'N'),
#   ('D:min', 'G/5', 'G:7'),
#   ('E', 'E/5', 'E:maj6'),
#   ('E', 'E/5', 'E:sus4'),
#   ('E', 'E/5', 'F:7'),
#   ('E', 'E/5', 'N'),
#   ('E', 'E/7', 'E:maj6'),
#   ('E', 'E/7', 'E:sus4'),
#   ('E', 'E/7', 'F:7'),
#   ('E', 'E/7', 'N'),
#   ('E', 'E/b7', 'E:maj6'),
#   ('E', 'E/b7', 'E:sus4'),
#   ('E', 'E/b7', 'F:7'),
#   ('E', 'E/b7', 'N'),
#   ('E', 'E:7', 'E:maj6'),
#   ('E', 'E:7', 'E:sus4'),
#   ('E', 'E:7', 'F:7'),
#   ('E', 'E:7', 'N'),
#   ('E', 'E:aug', 'E:maj6'),
#   ('E', 'E:aug', 'E:sus4'),
#   ('E', 'E:aug', 'F:7'),
#   ('E', 'E:maj6', 'F#:min'),
#   ('E', 'E:maj6', 'F#:min7'),
#   ('E', 'E:maj6', 'G'),
#   ('E', 'E:maj6', 'G:9(*3,11)'),
#   ('E', 'E:sus4', 'F#:min'),
#   ('E', 'E:sus4', 'G'),
#   ('E', 'F', 'N'),
#   ('E', 'F#:min', 'F:7'),
#   ('E', 'F#:min', 'N'),
#   ('E', 'F:7', 'G'),
#   ('E', 'G', 'N'),
#   ('E:min', 'E:min/5', 'E:min/b7')},
#  '120C': {('A', 'A:7', 'D'),
#   ('A', 'A:7', 'D:7'),
#   ('A', 'A:min', 'E'),
#   ('A', 'A:min', 'E:7'),
#   ('A', 'Ab', 'G'),
#   ('A', 'B', 'E:min'),
#   ('A', 'B:min', 'G:7'),
#   ('A', 'C', 'E/5'),
#   ('A', 'C', 'E:min/5'),
#   ('A', 'C', 'G/3'),
#   ('A', 'C', 'G:7'),
#   ('A', 'C#:min', 'C#:min/b7'),
#   ('A', 'D', 'F#:min'),
#   ('A', 'D', 'F:7'),
#   ('A', 'D:7', 'F'),
#   ('A', 'E', 'E/5'),
#   ('A', 'E', 'E:aug'),
#   ('A', 'E:7', 'E:sus4(b7)'),
#   ('A', 'E:aug', 'N'),
#   ('A', 'Eb', 'F'),
#   ('A', 'Eb', 'G/5'),
#   ('A', 'Eb', 'Gb'),
#   ('A', 'F', 'G'),
#   ('A', 'G', 'G/5'),
#   ('A', 'G', 'Gb'),
#   ('A', 'G:7', 'N'),
#   ('A:min', 'C', 'E'),
#   ('A:min7', 'D:min', 'N'),
#   ('B', 'C', 'D'),
#   ('B', 'E', 'G'),
#   ('Bb', 'C', 'F'),
#   ('C', 'C:maj7', 'G'),
#   ('C', 'D:min7(2,*b3,4)', 'F'),
#   ('C', 'Eb', 'F'),
#   ('C', 'F', 'N'),
#   ('C', 'G', 'G/5'),
#   ('C', 'G', 'Gb'),
#   ('C/5', 'D:7', 'G'),
#   ('D', 'D#', 'E'),
#   ('D', 'D/3', 'G'),
#   ('D', 'D:dim7', 'N'),
#   ('D', 'E', 'E/5'),
#   ('D', 'E', 'F#:min'),
#   ('D', 'E:dim/b3', 'G'),
#   ('D', 'Eb', 'G'),
#   ('D', 'G', 'G/5'),
#   ('D:min', 'G', 'G/5'),
#   ('D:min', 'G:7', 'N')},
#  '120D': {('A', 'A/3', 'D/6'),
#   ('A', 'A/5', 'D'),
#   ('A', 'A/5', 'E'),
#   ('A', 'A:min', 'C'),
#   ('A', 'A:min', 'D:min'),
#   ('A', 'A:min', 'G'),
#   ('A', 'Bb:7', 'E:9'),
#   ('A', 'C', 'D:7'),
#   ('A', 'C', 'G/5'),
#   ('A', 'D', 'E/5'),
#   ('A', 'D', 'G/5'),
#   ('A', 'D:7', 'G'),
#   ('A', 'D:min', 'E:9'),
#   ('A', 'G/3', 'N'),
#   ('A/5', 'D', 'E'),
#   ('A:min', 'C', 'G'),
#   ('C', 'D', 'N'),
#   ('C', 'D:7', 'G'),
#   ('C', 'Eb', 'G'),
#   ('C/5', 'C/6', 'G')},
#  '120U': {('A', 'A:7', 'Bb:7'),
#   ('A', 'A:7', 'E:7'),
#   ('A', 'C', 'Gb'),
#   ('A', 'D:min', 'F'),
#   ('A', 'D:min', 'G:7'),
#   ('A', 'E', 'F#:min'),
#   ('A', 'E:min', 'E:min/5'),
#   ('A', 'F', 'N'),
#   ('A', 'G', 'G/2'),
#   ('A/2', 'A/3', 'D'),
#   ('A/3', 'A/5', 'D'),
#   ('B', 'C#:min', 'E'),
#   ('B', 'D', 'G'),
#   ('B', 'D/2', 'E'),
#   ('B', 'E', 'E:7'),
#   ('C', 'E', 'E/5'),
#   ('C#:min', 'E', 'N'),
#   ('D:7', 'F', 'G'),
#   ('D:min', 'F', 'N'),
#   ('E', 'E:aug', 'N')},
#  '201': {('A', 'A/2', 'B'),
#   ('A', 'A/2', 'B:min'),
#   ('A', 'A/2', 'Bb:7'),
#   ('A', 'A/2', 'C'),
#   ('A', 'A/2', 'C#:min'),
#   ('A', 'A/2', 'D#:dim/b5'),
#   ('A', 'A/2', 'D:min'),
#   ('A', 'A/2', 'E'),
#   ('A', 'A/2', 'E:7'),
#   ('A', 'A/2', 'Eb'),
#   ('A', 'A/2', 'G'),
#   ('A', 'A/2', 'N'),
#   ('A', 'A/3', 'B'),
#   ('A', 'A/3', 'B:min'),
#   ('A', 'A/3', 'Bb:7'),
#   ('A', 'A/3', 'C'),
#   ('A', 'A/3', 'C#:min'),
#   ('A', 'A/3', 'D#:dim/b5'),
#   ('A', 'A/3', 'D:min'),
#   ('A', 'A/3', 'E'),
#   ('A', 'A/3', 'Eb'),
#   ('A', 'A/3', 'G'),
#   ('A', 'A/3', 'N'),
#   ('A', 'B', 'B/5'),
#   ('A', 'B', 'B:min'),
#   ('A', 'B', 'Bb:7'),
#   ('A', 'B', 'D#:dim/b5'),
#   ('A', 'B', 'D:min'),
#   ('A', 'B', 'Eb'),
#   ('A', 'B', 'N'),
#   ('A', 'B:9', 'E'),
#   ('A', 'B:min', 'Bb:7'),
#   ('A', 'B:min', 'C'),
#   ('A', 'B:min', 'C#:min'),
#   ('A', 'B:min', 'D#:dim/b5'),
#   ('A', 'B:min', 'D:min'),
#   ('A', 'B:min', 'E:7'),
#   ('A', 'B:min', 'Eb'),
#   ('A', 'B:min', 'G'),
#   ('A', 'B:min', 'N'),
#   ('A', 'Bb:7', 'C'),
#   ('A', 'Bb:7', 'C#:min'),
#   ('A', 'Bb:7', 'D'),
#   ('A', 'Bb:7', 'D#:dim/b5'),
#   ('A', 'Bb:7', 'D:min'),
#   ('A', 'Bb:7', 'E'),
#   ('A', 'Bb:7', 'E:7'),
#   ('A', 'Bb:7', 'Eb'),
#   ('A', 'Bb:7', 'G'),
#   ('A', 'Bb:7', 'N'),
#   ('A', 'C', 'C#'),
#   ('A', 'C', 'C#:min'),
#   ('A', 'C', 'D#:dim/b5'),
#   ('A', 'C', 'D:min'),
#   ('A', 'C', 'E:7'),
#   ('A', 'C', 'F:maj7'),
#   ('A', 'C#', 'D'),
#   ('A', 'C#:min', 'D'),
#   ('A', 'C#:min', 'D#:dim/b5'),
#   ('A', 'C#:min', 'D:min'),
#   ('A', 'C#:min', 'E:7'),
#   ('A', 'C#:min', 'Eb'),
#   ('A', 'C#:min', 'G'),
#   ('A', 'C/5', 'G'),
#   ('A', 'D', 'D#:dim/b5'),
#   ('A', 'D', 'D/5'),
#   ('A', 'D', 'D:min'),
#   ('A', 'D', 'E:7'),
#   ('A', 'D#:dim/b5', 'D:min'),
#   ('A', 'D#:dim/b5', 'E'),
#   ('A', 'D#:dim/b5', 'E:7'),
#   ('A', 'D#:dim/b5', 'Eb'),
#   ('A', 'D#:dim/b5', 'G'),
#   ('A', 'D#:dim/b5', 'N'),
#   ('A', 'D:min', 'E'),
#   ('A', 'D:min', 'E:7'),
#   ('A', 'D:min', 'Eb'),
#   ('A', 'E', 'E:maj6'),
#   ('A', 'E', 'E:sus4'),
#   ('A', 'E', 'Eb'),
#   ('A', 'E:7', 'E:7/5'),
#   ('A', 'E:7', 'Eb'),
#   ('A', 'E:7', 'G'),
#   ('A', 'E:7', 'N'),
#   ('A', 'Eb', 'N'),
#   ('A', 'G', 'N'),
#   ('A/2', 'A/3', 'A/5'),
#   ('A:7', 'A:7/5', 'D:7'),
#   ('A:7', 'A:7/5', 'N'),
#   ('A:7', 'D:7', 'F'),
#   ('A:7', 'D:7', 'N'),
#   ('A:7', 'D:min', 'N'),
#   ('A:7', 'E', 'N'),
#   ('B', 'B/5', 'C'),
#   ('B', 'B/5', 'E'),
#   ('B', 'B:9', 'E'),
#   ('B', 'B:min', 'E'),
#   ('B', 'C', 'C#'),
#   ('B', 'C', 'F'),
#   ('B', 'C', 'F:maj7'),
#   ('B', 'E', 'E:maj6'),
#   ('B', 'E', 'E:sus4'),
#   ('B', 'E', 'F:7'),
#   ('B', 'E', 'N'),
#   ('B:9', 'B:min', 'E'),
#   ('B:9', 'C', 'E'),
#   ('B:9', 'D', 'E'),
#   ('B:9', 'E', 'E:maj6'),
#   ('B:9', 'E', 'E:sus4'),
#   ('B:9', 'E', 'F:7'),
#   ('B:9', 'E', 'N'),
#   ('B:min', 'C', 'E'),
#   ('B:min', 'E', 'E:maj6'),
#   ('B:min', 'E', 'E:sus4'),
#   ('B:min', 'E', 'F:7'),
#   ('B:min', 'E', 'N'),
#   ('C', 'C#', 'E'),
#   ('C', 'C#', 'F'),
#   ('C', 'C#', 'F:maj7'),
#   ('C', 'C#', 'G'),
#   ('C', 'C/5', 'G'),
#   ('C', 'E', 'E:maj6'),
#   ('C', 'E', 'E:sus4'),
#   ('C', 'E', 'F'),
#   ('C', 'E', 'F:7'),
#   ('C', 'E', 'F:maj7'),
#   ('C', 'F', 'F:maj7'),
#   ('C', 'F:maj7', 'G'),
#   ('C#', 'D', 'D/5'),
#   ('C#', 'D', 'E'),
#   ('C#', 'D', 'G'),
#   ('C#', 'D', 'N'),
#   ('C/5', 'D', 'G'),
#   ('D', 'D/5', 'E'),
#   ('D', 'D/5', 'G'),
#   ('D', 'D/5', 'N'),
#   ('D', 'D:min', 'N'),
#   ('D', 'E', 'E:maj6'),
#   ('D', 'E', 'E:sus4'),
#   ('D', 'G', 'N'),
#   ('D:min', 'E', 'N'),
#   ('D:min', 'G/5', 'N'),
#   ('E', 'E:maj6', 'E:sus4'),
#   ('E', 'E:maj6', 'F:7'),
#   ('E', 'E:sus4', 'F:7'),
#   ('E', 'E:sus4', 'N'),
#   ('E', 'F:7', 'N')},
#  '210': {('A', 'A/2', 'D'),
#   ('A', 'A/3', 'A/5'),
#   ('A', 'A/3', 'D'),
#   ('A', 'A/3', 'E:7'),
#   ('A', 'A:7', 'N'),
#   ('A', 'B', 'C#:min'),
#   ('A', 'B', 'D'),
#   ('A', 'B', 'E:7'),
#   ('A', 'B', 'G'),
#   ('A', 'B:min', 'D'),
#   ('A', 'C', 'D'),
#   ('A', 'C', 'Eb'),
#   ('A', 'C', 'F'),
#   ('A', 'C', 'N'),
#   ('A', 'C#:min', 'E'),
#   ('A', 'C#:min', 'N'),
#   ('A', 'D', 'Eb'),
#   ('A', 'D:min', 'G'),
#   ('A', 'D:min', 'G/5'),
#   ('A', 'E', 'E:7'),
#   ('A', 'E', 'F:7'),
#   ('A', 'E', 'G'),
#   ('A', 'Eb', 'G'),
#   ('A:7', 'A:7/3', 'A:7/5'),
#   ('A:7', 'D', 'N'),
#   ('B', 'C', 'G'),
#   ('B', 'D', 'E'),
#   ('B:min', 'D', 'E'),
#   ('C', 'C#', 'D'),
#   ('C', 'D', 'E'),
#   ('C', 'D', 'G'),
#   ('C', 'D:7', 'F'),
#   ('C', 'E', 'G'),
#   ('C', 'E', 'N'),
#   ('C', 'F', 'G'),
#   ('D', 'E', 'F:7'),
#   ('D', 'E', 'G'),
#   ('E', 'E:maj6', 'N')},
#  '300': {('A', 'A/2', 'A/3'),
#   ('A', 'B', 'C'),
#   ('A', 'B', 'E'),
#   ('A', 'B:min', 'E'),
#   ('A', 'C', 'E'),
#   ('A', 'C', 'G'),
#   ('A', 'D', 'E'),
#   ('A', 'D', 'G'),
#   ('A', 'D', 'N'),
#   ('A', 'D:min', 'N'),
#   ('A', 'E', 'N'),
#   ('B', 'C', 'E'),
#   ('D', 'E', 'N')}}

# %%
from collections import Counter
counter=Counter(new)
print(counter)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
