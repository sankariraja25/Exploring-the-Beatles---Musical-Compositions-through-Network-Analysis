# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
album12 = pd.read_csv('album_12_edges.csv')
G = nx.from_pandas_edgelist(album12, source="Source", target="Target", create_using=nx.DiGraph())
nx.draw(G, with_labels=True)

# %% [markdown]
# Visuals

# %%
nx.draw(G,node_size=300,font_size=8,  with_labels=True)

# %%
plt.figure(3,figsize=(12,12)) 
nx.draw(G, node_size=400,font_size=12,  with_labels=True)

# %% [markdown]
# Triads

# %%
# Triad Consensus
nx.triadic_census(G)
# Out:
# {'003': 41103,
#  '012': 6701,
#  '021C': 281,
#  '021D': 130,
#  '021U': 96,
#  '030C': 13,
#  '030T': 17,
#  '102': 1435,
#  '111D': 114,
#  '111U': 134,
#  '120C': 12,
#  '120D': 4,
#  '120U': 6,
#  '201': 46,
#  '210': 21,
#  '300': 3}

# %%
import networkx as nx
import itertools


def _tricode(G, v, u, w):
    """Returns the integer code of the given triad.

    This is some fancy magic that comes from Batagelj and Mrvar's paper. It
    treats each edge joining a pair of `v`, `u`, and `w` as a bit in
    the binary representation of an integer.

    """
    combos = ((v, u, 1), (u, v, 2), (v, w, 4), (w, v, 8), (u, w, 16),
              (w, u, 32))
    return sum(x for u, v, x in combos if v in G[u])


# G = nx.DiGraph()
# G.add_nodes_from([1, 2, 3, 4, 5])
# G.add_edges_from([(1, 2), (2, 3), (2, 4), (4, 5)])

#: The integer codes representing each type of triad.
#: Triads that are the same up to symmetry have the same code.
TRICODES = (1, 2, 2, 3, 2, 4, 6, 8, 2, 6, 5, 7, 3, 8, 7, 11, 2, 6, 4, 8, 5, 9,
            9, 13, 6, 10, 9, 14, 7, 14, 12, 15, 2, 5, 6, 7, 6, 9, 10, 14, 4, 9,
            9, 12, 8, 13, 14, 15, 3, 7, 8, 11, 7, 12, 14, 15, 8, 14, 13, 15,
            11, 15, 15, 16)

#: The names of each type of triad. The order of the elements is
#: important: it corresponds to the tricodes given in :data:`TRICODES`.
TRIAD_NAMES = ('003', '012', '102', '021D', '021U', '021C', '111D', '111U',
               '030T', '030C', '201', '120D', '120U', '120C', '210', '300')

#: A dictionary mapping triad code to triad name.
TRICODE_TO_NAME = {i: TRIAD_NAMES[code - 1] for i, code in enumerate(TRICODES)}

triad_nodes = {name: set([]) for name in TRIAD_NAMES}
m = {v: i for i, v in enumerate(G)}
for v in G:
    vnbrs = set(G.pred[v]) | set(G.succ[v])
    for u in vnbrs:
        if m[u] > m[v]:
            unbrs = set(G.pred[u]) | set(G.succ[u])
            neighbors = (vnbrs | unbrs) - {u, v}
            not_neighbors = set(G.nodes()) - neighbors - {u, v}
            # Find dyadic triads
            for w in not_neighbors:
                if v in G[u] and u in G[v]:
                    triad_nodes['102'].add(tuple(sorted([u, v, w])))
                else:
                    triad_nodes['012'].add(tuple(sorted([u, v, w])))
            for w in neighbors:
                if m[u] < m[w] or (m[v] < m[w] < m[u] and
                                   v not in G.pred[w] and
                                   v not in G.succ[w]):
                    code = _tricode(G, v, u, w)
                    triad_nodes[TRICODE_TO_NAME[code]].add(
                        tuple(sorted([u, v, w])))
# find null triads
all_tuples = set()
for s in triad_nodes.values():
    all_tuples = all_tuples.union(s)
new = triad_nodes['003'] = set(itertools.combinations(G.nodes(), 3)).difference(all_tuples)

triad_nodes
# Out:
# {'003': {('F:maj6', 'C/7', 'D/3'),
#   ('Gb', 'E:7', 'Eb'),
#   ('Gb:min', 'F#', 'G:7'),
#   ('N', 'C/5', 'Bb:min'),
#   ('E:7', 'D:min/b3', 'D:7'),
#   ('G/3', 'F#:hdim7/b7', 'Eb/5'),
#   ('G', 'C/7', 'B'),
#   ('D:min7', 'Eb:7', 'Eb/3'),
#   ('G:min', 'F#:min', 'A:min/b7'),
#   ('F#:hdim7/b7', 'A:dim7', 'Eb:7/b7'),
#   ('G:maj(*1)/5', 'F#:min', 'B'),
#   ('D', 'G#:aug', 'Eb'),
#   ('Ab:maj6', 'Eb/5', 'G:(1,5)'),
#   ('E:7', 'C:min', 'F:min7'),
#   ('Eb:min7', 'A:(1)', 'D:7'),
#   ('C', 'Gb', 'F#'),
#   ('A', 'E:min/b3', 'B'),
#   ('A:min', 'F:min7', 'Eb:7'),
#   ('Ab', 'F:min7', 'D:7'),
#   ('D:min', 'D/3', 'Eb:7'),
#   ('F#:hdim7/b7', 'A:min/b7', 'F#:aug'),
#   ('Bb', 'Eb:min7', 'D:min7'),
#   ('G:maj(*1)/5', 'Ab', 'F:7'),
#   ('Bb:min', 'A:7', 'Eb/3'),
#   ('A:min/b7', 'F', 'D/3'),
#   ('D:min7', 'A:dim7', 'F:min7'),
#   ('G/3', 'F#:hdim7/b7', 'F#:hdim7'),
#   ('D:min', 'B:min', 'Eb:7'),
#   ('E:7', 'C:min', 'G:(1,5)'),
#   ('A:min', 'Bb:min', 'Ab:maj(2)/2'),
#   ('G:maj(*1)/5', 'D/5', 'Ab/5'),
#   ('Db', 'F', 'C:min'),
#   ('Db', 'Ab', 'G:7'),
#   ('Bb', 'Gb', 'D/3'),
#   ('D', 'D:min7', 'Eb:7/b7'),
#   ('A:min7', 'G#:aug', 'G#:dim7'),
#   ('G:maj(*1)/5', 'C/5', 'A:dim7'),
#   ('D:min/b3', 'F', 'F:min7'),
#   ('Eb:min7', 'G#:aug', 'C#'),
#   ('D:min/b3', 'G#:aug', 'Eb:7/b7'),
#   ('B:min', 'B:hdim7/b7', 'F#:aug'),
#   ('E', 'Gb:min', 'B:hdim7/b7'),
#   ('B:hdim7/b7', 'Eb', 'Ab/5'),
#   ('Gb:min', 'C/7', 'G/2'),
#   ('G#:dim7', 'B:hdim7/b7', 'F#:aug'),
#   ('N', 'A:min/b3', 'A:(1)'),
#   ('G', 'F:maj7', 'Ab/5'),
#   ('G/3', 'D:min/b3', 'A:dim7'),
#   ('F#:min', 'E', 'F:min'),
#   ('Db:maj7', 'D:min/b3', 'Eb/5'),
#   ('N', 'B:min', 'Ab:7'),
#   ('A:min7', 'D:min7', 'C:min'),
#   ('Bb:min', 'Ab', 'A:(1)'),
#   ('Gb', 'A:min/b3', 'G:7/3'),
#   ('G:maj(*1)/5', 'F:maj6', 'G:7/3'),
#   ('C/5', 'Eb:min7', 'Ab/5'),
#   ('A:min7', 'F:maj6/5', 'Ab:maj(2)/2'),
#   ('A:min/b3', 'F#:aug', 'Ab/5'),
#   ('F:min', 'Ab:7', 'G:7/3'),
#   ('N', 'C', 'B:hdim7/b7'),
#   ('Ab:7', 'F:maj6', 'A:aug'),
#   ('B:min', 'F:maj6/5', 'G#:dim7'),
#   ('G:maj(*1)/5', 'F:maj6/5', 'F#:aug'),
#   ('G', 'G#:aug', 'F:maj6/5'),
#   ('G/3', 'F:7', 'Ab:maj(2)/2'),
#   ('Bb:min', 'F:7', 'B:hdim7/b7'),
#   ('D:min/b3', 'C#', 'F:min7'),
#   ('C', 'B:hdim7/b7', 'Ab/5'),
#   ('Ab:maj6', 'Gb', 'Ab:maj(2)/2'),
#   ('A:min', 'Db', 'Ab'),
#   ('Gb', 'A:dim7', 'A:aug'),
#   ('D:min7', 'Ab:maj(2)/2', 'Eb'),
#   ('G/3', 'F#:hdim7/b7', 'A:dim7'),
#   ('G/3', 'Bb', 'D:min'),
#   ('G#:aug', 'F#', 'C#'),
#   ('Eb:min7', 'G:(1,5)', 'D:7'),
#   ('A:min/b3', 'E:min/b3', 'A:(1)'),
#   ('A:min7', 'D:min/b3', 'G#:dim7'),
#   ('G#:aug', 'F#', 'Eb/5'),
#   ('Db', 'F:min', 'D/5'),
#   ('Ab:maj6', 'Ab:7', 'B:hdim7/b7'),
#   ('Ab:7', 'C:min', 'Eb/5'),
#   ('N', 'F#:min', 'D:min7'),
#   ('Eb/5', 'G/2', 'D:7'),
#   ('G/3', 'D:min7', 'D:7'),
#   ('G/3', 'Ab', 'Gb'),
#   ('A:min/b3', 'F:maj6/5', 'Ab:maj(2)/2'),
#   ('E:7', 'D/5', 'Eb'),
#   ('G/3', 'B:hdim7/b7', 'Ab:maj(2)/2'),
#   ('Bb', 'D:min', 'A:min'),
#   ('D:min7', 'C/7', 'D/3'),
#   ('N', 'A:min7', 'A'),
#   ('F#:hdim7/b7', 'F#:hdim7', 'F:min7'),
#   ('F:maj7', 'A:7', 'Eb'),
#   ('Eb:min7', 'D:min7', 'D:7'),
#   ('E', 'G#:aug', 'A:min/b7'),
#   ('G:min', 'F:min', 'G#:aug'),
#   ('C/5', 'F:min', 'Ab/5'),
#   ('B:min', 'F#:hdim7/b7', 'D:min7'),
#   ('G#:aug', 'F#:hdim7', 'A:7'),
#   ('Db:maj7', 'D/5', 'Ab:maj(2)/2'),
#   ('C', 'F:maj6/5', 'F#'),
#   ('A:min', 'D/3', 'B:hdim7/b7'),
#   ('B:min', 'Ab', 'F'),
#   ('F:min', 'Eb:min7', 'F:maj7'),
#   ('C/5', 'Db', 'F:min7'),
#   ('A:min7', 'Gb', 'G:(1,5)'),
#   ('G/3', 'B:(b3,5)', 'C#'),
#   ('F#:aug', 'Eb', 'F:min7'),
#   ('Eb:min7', 'Ab', 'F'),
#   ('B:min', 'F#:aug', 'C:min'),
#   ('Ab:7', 'F:maj6', 'F#:aug'),
#   ('G/3', 'F#:min', 'G:7'),
#   ('G:maj(*1)/5', 'D:min7', 'E:min/b3'),
#   ('G', 'C/7', 'B:hdim7/b7'),
#   ('Db:maj7', 'F:maj7', 'F'),
#   ('G:maj(*1)/5', 'Ab:7', 'B:hdim7/b7'),
#   ('F#:hdim7/b7', 'B:hdim7/b7', 'Ab:maj(2)/2'),
#   ('G:maj(*1)/5', 'Bb:min', 'G#:dim7'),
#   ('Db:maj7', 'Ab:maj6', 'A:aug'),
#   ('G', 'F:min7', 'A:(1)'),
#   ('Bb:min', 'B', 'Eb:7'),
#   ('F#:min', 'A:min/b7', 'Ab:maj(2)/2'),
#   ('Ab:maj6', 'F', 'B'),
#   ('Ab', 'A:min/b3', 'G:7/3'),
#   ('B:min', 'E:min/b3', 'Ab:maj(2)/2'),
#   ('C', 'Gb:min', 'D/3'),
#   ('N', 'A:min7', 'F:maj7'),
#   ('A:min7', 'Gb', 'Ab:maj(2)/2'),
#   ('F:7', 'F:maj6', 'Ab/5'),
#   ('G', 'Gb', 'C/7'),
#   ('G:maj(*1)/5', 'Bb', 'F#'),
#   ('Gb', 'F', 'Eb:7'),
#   ('G/3', 'Bb:min', 'Eb/3'),
#   ('C/7', 'B:(b3,5)', 'C:min'),
#   ('Db', 'Gb', 'F:maj7'),
#   ('C/5', 'E:min/b3', 'B'),
#   ('Db:maj7', 'A:7', 'C#'),
#   ('A:min7', 'F:maj6/5', 'Eb'),
#   ('Ab', 'F:maj7', 'F#:aug'),
#   ('C/5', 'F#', 'F:min7'),
#   ('D:min/b3', 'B', 'Eb:7'),
#   ('C', 'G:min', 'E'),
#   ('G:min', 'B:min', 'Ab:maj6'),
#   ('A:min/b3', 'G#:aug', 'F#:hdim7'),
#   ('E:7', 'C:min', 'G/2'),
#   ('G:maj(*1)/5', 'C', 'F#:min'),
#   ('A:min/b7', 'C#', 'Ab/5'),
#   ('G#:aug', 'E:min/b3', 'C#'),
#   ('D', 'Bb', 'C#'),
#   ('G/3', 'A:min/b7', 'D/3'),
#   ('C/7', 'E:min/b3', 'D:7'),
#   ('Bb:min', 'Ab', 'D:min/b3'),
#   ('G', 'A', 'F:7'),
#   ('B:hdim7/b7', 'A:aug', 'D:7'),
#   ('Ab', 'F', 'F:maj6/5'),
#   ('Db:maj7', 'E:min/b3', 'Eb/3'),
#   ('A:min/b3', 'D/5', 'A:aug'),
#   ('Ab:7', 'F#:hdim7', 'B:hdim7/b7'),
#   ('C/5', 'B:min', 'F:min7'),
#   ('D:min', 'Ab:maj(2)/2', 'G/2'),
#   ('G:maj(*1)/5', 'C/7', 'G#:dim7'),
#   ('G:maj(*1)/5', 'Gb', 'F#:aug'),
#   ('G:maj(*1)/5', 'A', 'Bb:min'),
#   ('F:maj6', 'C/7', 'F:min7'),
#   ('E', 'Ab:7', 'Eb:7'),
#   ('Db', 'Gb', 'C/7'),
#   ('B:min', 'Db', 'F#:aug'),
#   ('A', 'B:min', 'F#'),
#   ('F:maj6/5', 'Eb', 'Eb:7'),
#   ('Ab', 'F#:hdim7/b7', 'B'),
#   ('C', 'E', 'Eb:7/b7'),
#   ('G', 'A', 'Ab:maj(2)/2'),
#   ('A:min7', 'Ab:maj6', 'B:hdim7/b7'),
#   ('Gb:min', 'G#:dim7', 'A:aug'),
#   ('A:min7', 'A:min/b3', 'C#'),
#   ('G:maj(*1)/5', 'Gb:min', 'B:hdim7/b7'),
#   ('F:7', 'C:min', 'A:(1)'),
#   ('Ab:maj6', 'D:min7', 'D/3'),
#   ('Db:maj7', 'D:min/b3', 'B:hdim7/b7'),
#   ('B:hdim7/b7', 'Eb/3', 'G:(1,5)'),
#   ('A:min7', 'G:min', 'F:7'),
#   ('Gb', 'C/7', 'B:(b3,5)'),
#   ('D:min', 'B:min', 'Ab:maj(2)/2'),
#   ('G:min', 'F', 'Eb:7'),
#   ('F#:min', 'Ab', 'D/5'),
#   ('E', 'B:(b3,5)', 'G/2'),
#   ('Gb', 'D:min/b3', 'F:7'),
#   ('F#:hdim7/b7', 'Ab/5', 'G:(1,5)'),
#   ('F#:min', 'Ab', 'E:7'),
#   ('D/3', 'A:dim7', 'G:7'),
#   ('B:min', 'F:maj6/5', 'D/3'),
#   ('Gb:min', 'F:maj6/5', 'Eb'),
#   ('D/3', 'B:hdim7/b7', 'C:min'),
#   ('A:min7', 'A:min/b3', 'Eb:7'),
#   ('F:7', 'F:maj6/5', 'G/2'),
#   ('F:min', 'F#:hdim7', 'F'),
#   ('G:min', 'Eb/5', 'A:(1)'),
#   ('F', 'D/3', 'D:7'),
#   ('D/3', 'C:min', 'G:7/3'),
#   ('F#:hdim7/b7', 'D:min7', 'G:7/3'),
#   ('F#:min', 'Ab', 'G:7'),
#   ('F', 'Eb:7/b7', 'Eb/5'),
#   ('G', 'C', 'Ab:maj(2)/2'),
#   ('F:maj6/5', 'C:min', 'G:(1,5)'),
#   ('E', 'Eb:min7', 'D/3'),
#   ('D:min', 'F#:hdim7', 'C#'),
#   ('G:min', 'Ab:maj(2)/2', 'Eb:7'),
#   ('Gb:min', 'F:7', 'Ab/5'),
#   ('Db', 'F#:hdim7/b7', 'G#:aug'),
#   ('Db', 'A:dim7', 'G/2'),
#   ('C/5', 'Ab:7', 'A:(1)'),
#   ('C#', 'Eb:7', 'Ab/5'),
#   ('G/3', 'Gb:min', 'Eb/5'),
#   ('G/3', 'F:maj7', 'C#'),
#   ('F:min', 'E:7', 'E:min/b3'),
#   ('G/3', 'D:min/b3', 'G#:aug'),
#   ('E:7', 'B:hdim7/b7', 'Ab:maj(2)/2'),
#   ('A', 'F:maj6/5', 'A:aug'),
#   ('N', 'G:maj(*1)/5', 'E'),
#   ('G/3', 'F:maj7', 'Eb/5'),
#   ('D:min/b3', 'F:7', 'G:7'),
#   ('G', 'C', 'Ab'),
#   ('Eb', 'Ab/5', 'D:7'),
#   ('G:maj(*1)/5', 'G#:dim7', 'Ab/5'),
#   ('Bb', 'A', 'Eb'),
#   ('G/3', 'F:7', 'Eb:7'),
#   ('D', 'A:min/b7', 'G#:dim7'),
#   ('Ab:maj6', 'F:maj7', 'G#:dim7'),
#   ('Eb:min7', 'C#', 'Eb:7'),
#   ('F#:hdim7', 'A:dim7', 'G:7/3'),
#   ('B:min', 'D:min/b3', 'B:(b3,5)'),
#   ('G:min', 'Gb:min', 'A:aug'),
#   ('Ab:7', 'F:maj6/5', 'G/2'),
#   ('D:min', 'Ab', 'A:min/b3'),
#   ('G', 'A:min/b7', 'D/5'),
#   ('Ab:7', 'A:min/b7', 'C/7'),
#   ('Ab:7', 'B:(b3,5)', 'Eb/3'),
#   ('B:min', 'D/5', 'Ab:maj(2)/2'),
#   ('D:min', 'Ab:7', 'F:maj6/5'),
#   ('Ab:7', 'Gb', 'F#:hdim7'),
#   ('D:min/b3', 'Ab/5', 'G:7/3'),
#   ('G:maj(*1)/5', 'Ab', 'D:min7'),
#   ('A', 'Ab', 'F'),
#   ('Bb', 'Db', 'Ab'),
#   ('F:maj7', 'A:7', 'F#'),
#   ('G', 'D:min/b3', 'B'),
#   ('A:7', 'F#', 'A:(1)'),
#   ('D', 'Db:maj7', 'Ab:maj(2)/2'),
#   ('D:min7', 'F:min7', 'Eb:7'),
#   ('D', 'A:dim7', 'G:(1,5)'),
#   ('Bb', 'D:min/b3', 'B:(b3,5)'),
#   ('E:7', 'G#:aug', 'F:maj6'),
#   ('G:maj(*1)/5', 'G:min', 'F#:min'),
#   ('G/3', 'D/3', 'B:hdim7/b7'),
#   ('B:min', 'Gb', 'A:aug'),
#   ('Bb:min', 'Ab:7', 'D:min/b3'),
#   ('F#:min', 'A:min/b7', 'F:maj6/5'),
#   ('F:7', 'B:hdim7/b7', 'Eb:7/b7'),
#   ('F:maj7', 'F', 'C:min'),
#   ('Gb', 'F:maj7', 'C#'),
#   ('C/5', 'D:min7', 'A:7'),
#   ('G#:aug', 'Eb:7/b7', 'Ab/5'),
#   ('F#:min', 'Ab:7', 'D:min/b3'),
#   ('A', 'C:min', 'G:7/3'),
#   ('C/5', 'E', 'D:min/b3'),
#   ('F#:min', 'Db', 'G:(1,5)'),
#   ('G:maj(*1)/5', 'E', 'A:min/b7'),
#   ('A:min7', 'D/3', 'D:7'),
#   ('D', 'F#:aug', 'Eb'),
#   ('G:maj(*1)/5', 'C/5', 'Gb:min'),
#   ('Bb', 'E:7', 'F:maj7'),
#   ('B:min', 'F:7', 'C/7'),
#   ('Db', 'D/3', 'D:7'),
#   ('G#:dim7', 'Ab/5', 'D:7'),
#   ('G', 'Ab', 'Gb'),
#   ('C/5', 'F#:min', 'Eb/3'),
#   ('G#:aug', 'F#:hdim7', 'D:7'),
#   ('Gb:min', 'F:maj7', 'Ab:maj(2)/2'),
#   ('D', 'F:7', 'F:maj6/5'),
#   ('D/5', 'D/3', 'G#:dim7'),
#   ('E:min/b3', 'D/3', 'G:(1,5)'),
#   ('G', 'G/3', 'B:min'),
#   ('N', 'A:7', 'C#'),
#   ('G#:aug', 'D:min7', 'F:maj6'),
#   ('C', 'C/5', 'G:(1,5)'),
#   ('F#:min', 'E', 'Ab'),
#   ('Db', 'F#', 'A:(1)'),
#   ('Db', 'G#:aug', 'G:7/3'),
#   ('C/5', 'A:min/b7', 'Ab/5'),
#   ('D:min7', 'F:7', 'F:maj6/5'),
#   ('D:min7', 'B:(b3,5)', 'G/2'),
#   ('E', 'A:dim7', 'C:min'),
#   ('C/5', 'D:min', 'E:7'),
#   ('G:min', 'Db:maj7', 'A:aug'),
#   ('Bb', 'E', 'D:min7'),
#   ('C/7', 'Ab:maj(2)/2', 'F:min7'),
#   ('D:min', 'Ab:maj6', 'G#:aug'),
#   ('C/5', 'E', 'F:maj7'),
#   ('F', 'B:(b3,5)', 'C:min'),
#   ('C/5', 'Bb:min', 'Eb:7'),
#   ('Eb:min7', 'C:min', 'Eb/5'),
#   ('F:7', 'B:hdim7/b7', 'G/2'),
#   ('C/5', 'B:(b3,5)', 'Eb/5'),
#   ('F:min', 'F:maj7', 'B:hdim7/b7'),
#   ('A:min', 'F#:hdim7', 'C/7'),
#   ('A:min', 'F:min', 'Gb:min'),
#   ('D:min/b3', 'D/5', 'Eb'),
#   ('A:min7', 'D', 'B:(b3,5)'),
#   ('Bb', 'F#:min', 'F#'),
#   ('G:maj(*1)/5', 'G:7/3', 'G/2'),
#   ('Db:maj7', 'B:(b3,5)', 'Ab:maj(2)/2'),
#   ('C/7', 'F:maj6/5', 'F#'),
#   ('Db', 'F:min', 'G:7'),
#   ('D/5', 'Ab:maj(2)/2', 'A:aug'),
#   ('A', 'E', 'B:(b3,5)'),
#   ('G/3', 'Db:maj7', 'D:min/b3'),
#   ('Ab:7', 'F#:hdim7', 'G:(1,5)'),
#   ('D', 'Ab:7', 'A:dim7'),
#   ('B:min', 'Bb:min', 'Ab:7'),
#   ('Eb:min7', 'Ab', 'F:7'),
#   ('D:min7', 'F:maj6', 'G:7/3'),
#   ('D:min', 'Eb:min7', 'B:hdim7/b7'),
#   ('B:min', 'F', 'Ab:maj(2)/2'),
#   ('Db:maj7', 'F:min', 'F:maj6/5'),
#   ('G', 'F:7', 'F:maj6/5'),
#   ('G:min', 'F:maj6/5', 'B:(b3,5)'),
#   ('G:maj(*1)/5', 'A:min', 'Eb:7/b7'),
#   ('Ab', 'F:maj6', 'E:min/b3'),
#   ('C/5', 'Bb:min', 'A:min/b3'),
#   ('F#:hdim7/b7', 'G#:aug', 'Eb:7/b7'),
#   ('B:min', 'Db:maj7', 'F:maj7'),
#   ('G:maj(*1)/5', 'B:hdim7/b7', 'A:(1)'),
#   ('D', 'F#:hdim7', 'Eb'),
#   ('Bb', 'D:min/b3', 'D:7'),
#   ('Ab:maj6', 'F:7', 'C:min'),
#   ('C/7', 'B:(b3,5)', 'Ab/5'),
#   ('F:maj7', 'C/7', 'G:(1,5)'),
#   ('G', 'A:min7', 'F:7'),
#   ('N', 'Db', 'F:maj7'),
#   ('B:min', 'Db:maj7', 'Eb/5'),
#   ('F:min', 'B:hdim7/b7', 'C:min'),
#   ('Db:maj7', 'A:7', 'F#:aug'),
#   ('A:min/b3', 'F:maj6/5', 'Eb/3'),
#   ('F:7', 'F#:aug', 'Ab/5'),
#   ('Ab', 'C/7', 'D/5'),
#   ('Ab:maj6', 'A:7', 'F#:aug'),
#   ('A:min7', 'Ab:7', 'A:dim7'),
#   ('Ab', 'G#:aug', 'F:7'),
#   ('B', 'C:min', 'G:7/3'),
#   ('F:min', 'A:min/b3', 'C#'),
#   ('Bb:min', 'G#:aug', 'B:(b3,5)'),
#   ('Bb', 'C#', 'A:(1)'),
#   ('Gb', 'C#', 'C:min'),
#   ('G#:aug', 'E:min/b3', 'F#:aug'),
#   ('F:maj6', 'Eb/5', 'Ab/5'),
#   ('E:min/b3', 'C#', 'A:aug'),
#   ('D:min/b3', 'G#:dim7', 'Ab:maj(2)/2'),
#   ('D:min7', 'F:min7', 'G:7'),
#   ('C', 'G:min', 'Eb:7'),
#   ('A:min7', 'F:7', 'G#:dim7'),
#   ('D:min/b3', 'F:maj6', 'B:(b3,5)'),
#   ('Bb:min', 'A:dim7', 'B:(b3,5)'),
#   ('G:maj(*1)/5', 'D:min/b3', 'Eb:7'),
#   ('Ab:maj6', 'F#:hdim7/b7', 'Eb'),
#   ('Gb', 'B:(b3,5)', 'Ab:maj(2)/2'),
#   ('Db:maj7', 'A:dim7', 'G/2'),
#   ('F#:hdim7', 'E:min/b3', 'B:(b3,5)'),
#   ('F#:hdim7', 'F:7', 'A:(1)'),
#   ('Bb', 'F:maj7', 'G:7'),
#   ('G/3', 'G:min', 'D:min/b3'),
#   ('C/7', 'Eb', 'G:(1,5)'),
#   ('E:7', 'C#', 'G:(1,5)'),
#   ('G/3', 'F', 'C/7'),
#   ('A:min', 'F#:hdim7/b7', 'F#:aug'),
#   ('C', 'E:min/b3', 'A:aug'),
#   ('E:min/b3', 'A:7', 'Ab/5'),
#   ('Bb', 'C:min', 'A:(1)'),
#   ('G:min', 'F:maj7', 'G:7'),
#   ('C', 'G#:aug', 'F#:hdim7'),
#   ('D', 'E', 'C/7'),
#   ('A:min', 'Eb:min7', 'Eb:7/b7'),
#   ('Db', 'C/7', 'G/2'),
#   ('G:maj(*1)/5', 'G#:dim7', 'C#'),
#   ('B:min', 'E:min/b3', 'Eb/3'),
#   ('C/5', 'F#:hdim7/b7', 'G:7'),
#   ('C/7', 'D/5', 'G:7/3'),
#   ('C/5', 'B:min', 'Bb:min'),
#   ('F:maj6/5', 'B:hdim7/b7', 'G/2'),
#   ('F:maj7', 'F#:aug', 'F:min7'),
#   ('G#:aug', 'D/5', 'A:dim7'),
#   ('G:maj(*1)/5', 'A:min7', 'F#:hdim7/b7'),
#   ('N', 'C/5', 'B:min'),
#   ('G/3', 'Db', 'B:(b3,5)'),
#   ('A:min/b3', 'A:min/b7', 'Ab/5'),
#   ('C/5', 'G#:aug', 'F:min7'),
#   ('F#:hdim7', 'B:(b3,5)', 'F#:aug'),
#   ('F:maj6', 'A:dim7', 'F#'),
#   ('F:maj6', 'B:(b3,5)', 'F:min7'),
#   ('Ab', 'F#:hdim7', 'F:maj6/5'),
#   ('E', 'D/3', 'F#'),
#   ('G', 'Bb', 'D/3'),
#   ('A:min/b7', 'F#', 'Eb/3'),
#   ('Db', 'D:min/b3', 'C:min'),
#   ('A', 'F:min', 'Ab'),
#   ('G', 'Gb', 'F#:hdim7/b7'),
#   ('C/5', 'F', 'Eb/3'),
#   ('F#:hdim7/b7', 'Ab:maj(2)/2', 'Eb/5'),
#   ('E', 'F#:hdim7', 'G/2'),
#   ('G:min', 'Ab', 'B:hdim7/b7'),
#   ('A:min7', 'E:7', 'Eb/3'),
#   ('G:maj(*1)/5', 'B:min', 'A:min/b7'),
#   ('Db', 'D:min7', 'Eb'),
#   ('F#:min', 'Ab:maj6', 'B:(b3,5)'),
#   ('Db', 'C/7', 'A:aug'),
#   ('G#:aug', 'Eb:7/b7', 'G:(1,5)'),
#   ('F:min', 'F', 'G/2'),
#   ('Eb:7/b7', 'Ab/5', 'A:(1)'),
#   ('Eb/3', 'G:7/3', 'D:7'),
#   ('D', 'B:hdim7/b7', 'A:(1)'),
#   ('G', 'F:7', 'C:min'),
#   ('Ab:7', 'A:min/b7', 'F#'),
#   ('Bb', 'Db', 'G:(1,5)'),
#   ('F#:hdim7/b7', 'F:maj7', 'G:(1,5)'),
#   ('F#:hdim7', 'C#', 'Eb/3'),
#   ('Ab', 'Gb', 'F:maj6'),
#   ('A:min7', 'B:min', 'A:min/b3'),
#   ('N', 'A:min', 'Ab:maj6'),
#   ('A:min/b3', 'F:maj7', 'D/5'),
#   ('G#:dim7', 'Ab:maj(2)/2', 'A:(1)'),
#   ('C', 'A', 'G:7'),
#   ('D:min/b3', 'A:min/b7', 'E:min/b3'),
#   ('C', 'Ab:7', 'A:min/b7'),
#   ('A:dim7', 'B:(b3,5)', 'B'),
#   ('Db', 'Gb', 'F:7'),
#   ('F#:min', 'Ab:maj6', 'F#:hdim7/b7'),
#   ('F:maj6', 'B:hdim7/b7', 'Eb:7/b7'),
#   ('G:min', 'Ab:7', 'B:hdim7/b7'),
#   ('N', 'F:7', 'A:(1)'),
#   ('Db', 'A:7', 'A:(1)'),
#   ('Ab', 'E:min/b3', 'F:min7'),
#   ('D:min7', 'C#', 'D:7'),
#   ('D:min7', 'C:min', 'Eb:7'),
#   ('N', 'B:min', 'Ab'),
#   ('G', 'F:7', 'G/2'),
#   ('G', 'B:hdim7/b7', 'Eb'),
#   ('A:min7', 'F', 'B:hdim7/b7'),
#   ('N', 'Ab', 'C:min'),
#   ('C/5', 'D', 'Db'),
#   ('F#:hdim7', 'F:maj6/5', 'A:7'),
#   ('D/5', 'Eb/3', 'G:7/3'),
#   ('B:hdim7/b7', 'B:(b3,5)', 'Eb:7'),
#   ('D', 'E', 'Ab/5'),
#   ('E:7', 'E:min/b3', 'Ab/5'),
#   ('D:min', 'F#', 'A:(1)'),
#   ('G:maj(*1)/5', 'C#', 'G:7/3'),
#   ('G', 'A:dim7', 'F:min7'),
#   ('B:min', 'D:min/b3', 'F:min7'),
#   ('Eb:min7', 'F#:hdim7', 'F:7'),
#   ('B:min', 'F#:hdim7', 'A:(1)'),
#   ('Ab:maj6', 'B:(b3,5)', 'A:(1)'),
#   ('Gb', 'D:min7', 'Ab/5'),
#   ('Db:maj7', 'Gb:min', 'B:(b3,5)'),
#   ('G', 'D:min7', 'F:min7'),
#   ('A:min', 'F:maj6/5', 'G:(1,5)'),
#   ('G#:aug', 'A:7', 'A:(1)'),
#   ('Bb', 'Ab', 'Eb'),
#   ('G:min', 'A:min/b3', 'Eb:7/b7'),
#   ('A:min', 'Eb/3', 'A:(1)'),
#   ('B:min', 'D/3', 'A:aug'),
#   ('Db:maj7', 'C#', 'Eb:7'),
#   ('F#:hdim7/b7', 'C/7', 'F:min7'),
#   ('E:7', 'D/5', 'B'),
#   ('Eb:min7', 'Gb:min', 'F:7'),
#   ('A:min', 'F:min', 'F#:aug'),
#   ('F:maj7', 'F:maj6/5', 'B'),
#   ('G/3', 'B:min', 'Ab:maj6'),
#   ('C', 'E', 'Ab:maj6'),
#   ('G:maj(*1)/5', 'F#:hdim7', 'F:min7'),
#   ('G', 'F:maj7', 'D:7'),
#   ('E:7', 'B', 'Eb:7'),
#   ('G#:aug', 'B', 'Ab/5'),
#   ('G:maj(*1)/5', 'F:min', 'B:(b3,5)'),
#   ('F#:min', 'F:min', 'F#'),
#   ('D:min/b3', 'F#:hdim7/b7', 'B'),
#   ('A:min', 'Db:maj7', 'A:7'),
#   ('B:min', 'Ab', 'Ab:maj(2)/2'),
#   ('D:min', 'A:min/b3', 'F#:hdim7'),
#   ('N', 'D', 'Ab'),
#   ('Eb:min7', 'Ab:7', 'F:7'),
#   ('G', 'Eb:7/b7', 'A:aug'),
#   ('A', 'G#:dim7', 'D:7'),
#   ('F:min', 'Ab:maj6', 'D/3'),
#   ('N', 'F:maj7', 'A:dim7'),
#   ('G#:dim7', 'Ab/5', 'G:(1,5)'),
#   ('G:min', 'E:7', 'A:7'),
#   ('Eb', 'G:7', 'A:(1)'),
#   ('G', 'Db', 'D/3'),
#   ('Bb:min', 'D:min/b3', 'F:7'),
#   ('F#:hdim7/b7', 'D/3', 'G:7'),
#   ('N', 'A:min', 'A:(1)'),
#   ('E', 'F:7', 'A:aug'),
#   ('C', 'D', 'B:(b3,5)'),
#   ('F#:min', 'G:7/3', 'G:7'),
#   ('D:min', 'F', 'A:aug'),
#   ('A:min', 'E:7', 'B:hdim7/b7'),
#   ('Bb', 'A:dim7', 'Ab/5'),
#   ('F#:min', 'Eb', 'G:7/3'),
#   ('C/5', 'B:min', 'F:7'),
#   ('G:maj(*1)/5', 'Bb:min', 'Ab'),
#   ('Bb', 'G:min', 'F:min'),
#   ('F:min', 'F#:aug', 'G:(1,5)'),
#   ('Ab:maj6', 'G#:aug', 'A:min/b7'),
#   ('A:min/b3', 'F#:hdim7/b7', 'F:maj7'),
#   ('Ab:7', 'F:maj6', 'D/3'),
#   ('A:min', 'F:maj6', 'Ab/5'),
#   ('D:min/b3', 'A:7', 'D:7'),
#   ('A:min7', 'E:7', 'E:min/b3'),
#   ('Ab', 'D/5', 'F#:aug'),
#   ('Bb', 'F#:hdim7/b7', 'A:dim7'),
#   ('G', 'E', 'F#'),
#   ('F:maj7', 'G#:dim7', 'G:(1,5)'),
#   ('D:min', 'Eb:min7', 'G:7/3'),
#   ('Bb', 'F', 'Eb'),
#   ('G:min', 'A', 'B:hdim7/b7'),
#   ('G', 'A', 'C/7'),
#   ('C', 'A:min/b7', 'C#'),
#   ('G:min', 'E:7', 'G#:aug'),
#   ('N', 'G:maj(*1)/5', 'G'),
#   ('Gb', 'F#:hdim7/b7', 'Eb/5'),
#   ('C', 'F:7', 'D:7'),
#   ('G', 'C', 'D'),
#   ('G:maj(*1)/5', 'B:min', 'D:7'),
#   ('G:maj(*1)/5', 'F#:hdim7/b7', 'F#'),
#   ('B:min', 'F:min', 'Gb'),
#   ('Eb:min7', 'Eb/5', 'G/2'),
#   ('Gb:min', 'F:maj7', 'D:min7'),
#   ('G', 'G:min', 'E'),
#   ('D:min/b3', 'A:dim7', 'B:(b3,5)'),
#   ('E:min/b3', 'C:min', 'A:(1)'),
#   ('E', 'F:7', 'F#:aug'),
#   ('Db:maj7', 'D:min7', 'E:min/b3'),
#   ('Bb:min', 'F#:hdim7/b7', 'D:min7'),
#   ('G/3', 'E', 'B'),
#   ('A:min7', 'G#:dim7', 'A:dim7'),
#   ('C', 'A', 'F#'),
#   ('F:min', 'D:min/b3', 'F#:hdim7/b7'),
#   ('F#:hdim7/b7', 'F:7', 'B'),
#   ('C#', 'F:min7', 'A:(1)'),
#   ('G/3', 'F#:min', 'G:7/3'),
#   ('F', 'Eb', 'Eb:7/b7'),
#   ('B:min', 'Ab:maj6', 'Bb:min'),
#   ('A:min/b3', 'F:7', 'Eb/5'),
#   ('Ab', 'Eb', 'D:7'),
#   ('Gb', 'C#', 'Ab:maj(2)/2'),
#   ('N', 'Eb/3', 'G/2'),
#   ('C/5', 'F', 'G/2'),
#   ('D:min', 'Gb', 'C/7'),
#   ('G:maj(*1)/5', 'F#', 'G/2'),
#   ('G:min', 'F:maj6', 'D/5'),
#   ('G', 'A:min', 'G:7'),
#   ('C', 'Bb:min', 'Gb'),
#   ('C/5', 'D', 'F'),
#   ('Eb:7/b7', 'Eb/5', 'G:7'),
#   ('Db', 'Ab', 'E:7'),
#   ('C', 'F:min', 'G:(1,5)'),
#   ('F:maj7', 'B:(b3,5)', 'F#'),
#   ('A:min7', 'C/5', 'A:7'),
#   ('F:maj6', 'G#:dim7', 'Ab/5'),
#   ('N', 'Db', 'Eb/5'),
#   ('F#:min', 'G#:aug', 'D:min7'),
#   ('B:min', 'G#:dim7', 'Ab/5'),
#   ('F#:min', 'F:7', 'G:(1,5)'),
#   ('Ab:maj6', 'Bb:min', 'F#:hdim7/b7'),
#   ('F:maj6/5', 'D/3', 'A:aug'),
#   ('Eb:7/b7', 'Eb/5', 'Ab/5'),
#   ('B:(b3,5)', 'C:min', 'Eb/3'),
#   ('Db', 'Eb:min7', 'Eb:7'),
#   ('C/5', 'Db', 'Eb:min7'),
#   ('F#:hdim7/b7', 'Eb', 'Eb/5'),
#   ('G#:aug', 'F#:hdim7', 'F:maj6/5'),
#   ('A:min7', 'Eb:7', 'G:(1,5)'),
#   ('A', 'Gb:min', 'F:maj6'),
#   ('D/3', 'Eb/5', 'G:7/3'),
#   ('G:min', 'B', 'G:(1,5)'),
#   ('F#:hdim7/b7', 'G#:dim7', 'Eb/5'),
#   ('G', 'A:min/b3', 'A:dim7'),
#   ('B:min', 'Eb/3', 'G:(1,5)'),
#   ('F#:min', 'F#:hdim7/b7', 'D:7'),
#   ('Bb:min', 'F#', 'F:min7'),
#   ('C', 'F#:aug', 'G:7'),
#   ('G#:aug', 'A:dim7', 'F#:aug'),
#   ('F:maj7', 'F#', 'G:7'),
#   ('C/5', 'F:7', 'G#:dim7'),
#   ('G', 'Bb', 'F#:hdim7'),
#   ('G#:dim7', 'Eb:7/b7', 'A:(1)'),
#   ('Ab', 'F:maj7', 'D:min7'),
#   ('B:min', 'D:min/b3', 'A:7'),
#   ('E:7', 'F:maj6', 'A:dim7'),
#   ('D:min', 'B:min', 'F:min'),
#   ('D', 'E:min/b3', 'G:(1,5)'),
#   ('C/7', 'B', 'A:aug'),
#   ('A:min/b3', 'G#:aug', 'D:min7'),
#   ('A:min/b3', 'B:(b3,5)', 'C#'),
#   ('G', 'Db', 'F'),
#   ('C', 'A', 'E:min/b3'),
#   ('F#:min', 'F:min', 'G:7/3'),
#   ('Bb:min', 'F#:aug', 'Eb'),
#   ('F:7', 'F:maj6/5', 'B:(b3,5)'),
#   ('A:min', 'Eb/5', 'Eb/3'),
#   ('B:(b3,5)', 'B', 'F:min7'),
#   ('Eb', 'Eb:7/b7', 'Eb/5'),
#   ('G', 'A:min/b3', 'G:7'),
#   ('G/3', 'Ab:7', 'D:min/b3'),
#   ('D:min/b3', 'F:maj6', 'Eb:7/b7'),
#   ('Ab', 'F:maj6', 'G:7/3'),
#   ('Db', 'C#', 'C:min'),
#   ('Ab:7', 'Gb:min', 'E:min/b3'),
#   ('G', 'Ab', 'B:hdim7/b7'),
#   ('C#', 'Ab/5', 'G/2'),
#   ('Bb:min', 'D:min/b3', 'F:maj7'),
#   ('G:min', 'Gb', 'Eb'),
#   ('C', 'Db', 'G/2'),
#   ('F#:hdim7', 'A:(1)', 'D:7'),
#   ('G:min', 'Gb', 'F:maj6/5'),
#   ('F:maj7', 'G:7', 'G:(1,5)'),
#   ('Ab:7', 'D/5', 'B:hdim7/b7'),
#   ('N', 'F#:min', 'B:min'),
#   ('N', 'E:7', 'A:dim7'),
#   ('G', 'G#:aug', 'Ab/5'),
#   ('F#:min', 'G#:aug', 'C:min'),
#   ('A:min', 'Db:maj7', 'Ab/5'),
#   ('Gb:min', 'F#:hdim7/b7', 'C#'),
#   ('G:min', 'Bb:min', 'Eb/3'),
#   ('G/3', 'C/5', 'E:min/b3'),
#   ('Gb', 'C/7', 'D:7'),
#   ('Ab', 'Gb:min', 'Gb'),
#   ('D', 'G#:aug', 'F:maj6'),
#   ('Bb:min', 'C/7', 'A:aug'),
#   ('G:maj(*1)/5', 'Ab:maj6', 'Ab/5'),
#   ('F:maj6', 'C/7', 'F#:aug'),
#   ('G/3', 'G#:aug', 'F#:aug'),
#   ('C', 'D:min7', 'Ab:maj(2)/2'),
#   ('Gb', 'D/5', 'G:7/3'),
#   ('G:min', 'Eb:min7', 'A:min/b3'),
#   ('Bb', 'Eb', 'A:aug'),
#   ('F#:min', 'Db', 'Eb:7'),
#   ('G/3', 'F:min7', 'A:(1)'),
#   ('C', 'F#', 'A:aug'),
#   ('G:min', 'E:min/b3', 'B:hdim7/b7'),
#   ('F#:hdim7/b7', 'A:min/b7', 'A:dim7'),
#   ('G#:dim7', 'Ab:maj(2)/2', 'G/2'),
#   ('G:min', 'B:(b3,5)', 'C#'),
#   ('A:min', 'Db', 'D:min/b3'),
#   ('N', 'Eb:7', 'G:(1,5)'),
#   ('Bb', 'C/7', 'A:7'),
#   ('F:7', 'G#:dim7', 'Ab:maj(2)/2'),
#   ('G:maj(*1)/5', 'F:maj6/5', 'A:(1)'),
#   ('C/5', 'F#:hdim7', 'A:dim7'),
#   ('A:min7', 'A:min', 'F#'),
#   ('G/3', 'D', 'Eb:7'),
#   ('G:maj(*1)/5', 'F:maj7', 'A:dim7'),
#   ('Bb', 'G:(1,5)', 'G/2'),
#   ('F:maj7', 'B:(b3,5)', 'A:aug'),
#   ('C', 'Bb', 'Ab:7'),
#   ('B:min', 'Ab/5', 'A:aug'),
#   ('G:min', 'C/7', 'B'),
#   ('D:min', 'F#:min', 'G#:aug'),
#   ('C/5', 'Ab', 'G#:aug'),
#   ('G:min', 'Db', 'Ab'),
#   ('E', 'Ab:maj(2)/2', 'Eb:7/b7'),
#   ('G', 'F#:min', 'E:7'),
#   ('F:min', 'Ab:7', 'A:dim7'),
#   ('Db:maj7', 'B:(b3,5)', 'Eb/5'),
#   ('Gb:min', 'B:hdim7/b7', 'F:min7'),
#   ('G:min', 'Bb:min', 'F'),
#   ('F:min', 'A:min/b7', 'G/2'),
#   ('F', 'C:min', 'Eb:7'),
#   ('D:min7', 'C#', 'A:aug'),
#   ('G', 'B:min', 'F:maj7'),
#   ('G:min', 'Bb:min', 'D/5'),
#   ('Bb', 'A', 'F#:hdim7/b7'),
#   ('G', 'Ab', 'B'),
#   ('G:maj(*1)/5', 'Bb', 'Ab/5'),
#   ('G:maj(*1)/5', 'B:(b3,5)', 'G/2'),
#   ('Db:maj7', 'F:maj6/5', 'A:7'),
#   ('D:min/b3', 'F:maj6/5', 'F:min7'),
#   ('E:7', 'G#:dim7', 'F#'),
#   ('G:maj(*1)/5', 'C', 'F'),
#   ('G/3', 'F', 'Ab:maj(2)/2'),
#   ('Db:maj7', 'Eb', 'G:7'),
#   ('G:maj(*1)/5', 'G:min', 'D/5'),
#   ('Ab:maj6', 'F#', 'A:aug'),
#   ('G', 'Bb', 'E:7'),
#   ('Bb', 'A:min', 'C#'),
#   ('Bb:min', 'B:hdim7/b7', 'G/2'),
#   ('A:min', 'F', 'A:(1)'),
#   ('D:min', 'G:(1,5)', 'D:7'),
#   ('Db', 'A:min/b3', 'D:min/b3'),
#   ('F:maj6', 'D/5', 'Eb:7'),
#   ('C/5', 'B', 'A:aug'),
#   ('B:(b3,5)', 'Eb:7/b7', 'Eb/3'),
#   ('N', 'G', 'D:min/b3'),
#   ('C', 'B:min', 'D:7'),
#   ('E', 'Ab:maj6', 'Bb:min'),
#   ('E', 'G#:aug', 'B:hdim7/b7'),
#   ('Bb:min', 'A:min/b3', 'G:(1,5)'),
#   ('Db:maj7', 'F', 'Eb/5'),
#   ('Ab', 'A:min/b7', 'D/5'),
#   ('E:7', 'A:min/b7', 'F:min7'),
#   ('A:min/b7', 'F:maj6/5', 'D/5'),
#   ('N', 'F:min', 'B'),
#   ('F#:min', 'F#:hdim7/b7', 'Eb'),
#   ('F:min', 'E:min/b3', 'D/5'),
#   ('Gb:min', 'D:min/b3', 'A:dim7'),
#   ('F#:min', 'F#:hdim7/b7', 'F:maj6/5'),
#   ('G:maj(*1)/5', 'C/5', 'Ab/5'),
#   ('C#', 'Ab:maj(2)/2', 'G:7/3'),
#   ('A:min7', 'A:dim7', 'Eb:7/b7'),
#   ('A:min7', 'B:hdim7/b7', 'B:(b3,5)'),
#   ('G:maj(*1)/5', 'Ab:7', 'A:min/b7'),
#   ('C', 'A:min/b3', 'Eb'),
#   ('G', 'G/3', 'G#:aug'),
#   ('C', 'F:maj7', 'Eb/5'),
#   ('D', 'F:maj7', 'B'),
#   ('F#:hdim7', 'F:maj7', 'B'),
#   ('D:min', 'B:(b3,5)', 'Ab:maj(2)/2'),
#   ('C', 'E:min/b3', 'A:7'),
#   ('A', 'Gb', 'A:min/b7'),
#   ('E', 'Db', 'Eb:min7'),
#   ('D', 'Bb', 'Gb'),
#   ('G/3', 'A:min7', 'Eb/5'),
#   ('A', 'F:maj6', 'B:hdim7/b7'),
#   ('F:maj6/5', 'Eb', 'F:min7'),
#   ('D', 'Gb', 'Eb:7/b7'),
#   ('Ab:7', 'F:7', 'G:7'),
#   ('G/3', 'Db:maj7', 'A:min/b3'),
#   ('A:min7', 'Db:maj7', 'G#:aug'),
#   ('E', 'F:maj6', 'Eb:7/b7'),
#   ('G', 'Ab:maj6', 'A:dim7'),
#   ('A:min7', 'C/7', 'G:7/3'),
#   ('Eb:min7', 'G#:aug', 'E:min/b3'),
#   ('Ab', 'A:min/b7', 'Ab:maj(2)/2'),
#   ('G', 'Ab:7', 'C:min'),
#   ('D:min7', 'D/3', 'F#:aug'),
#   ('C/5', 'Bb:min', 'A:7'),
#   ('A:min7', 'Ab:maj6', 'F:maj6'),
#   ('F:min', 'A:7', 'C#'),
#   ('Bb', 'Ab:maj6', 'D/3'),
#   ('Ab:maj6', 'F#:hdim7/b7', 'C#'),
#   ('D:min', 'B:(b3,5)', 'G:(1,5)'),
#   ('Ab:7', 'F:maj6/5', 'C:min'),
#   ('N', 'C/5', 'G:7/3'),
#   ('F#:min', 'Eb:min7', 'G:7'),
#   ('D', 'F#:aug', 'Eb:7/b7'),
#   ('G:maj(*1)/5', 'D', 'D/5'),
#   ('E', 'F#:hdim7/b7', 'Eb/3'),
#   ('Db', 'Ab:maj6', 'F:maj6/5'),
#   ('Db:maj7', 'F#:hdim7', 'C/7'),
#   ('D:min7', 'G#:dim7', 'A:aug'),
#   ('Db:maj7', 'G#:dim7', 'B'),
#   ('D:min', 'F:min7', 'D:7'),
#   ('Db', 'Ab:maj6', 'Eb'),
#   ('D/3', 'B', 'G:7/3'),
#   ('A:min', 'G#:aug', 'Eb:7/b7'),
#   ('Ab:maj6', 'Ab:maj(2)/2', 'D:7'),
#   ('Ab:maj6', 'F#:hdim7/b7', 'C:min'),
#   ('D', 'B:min', 'A:dim7'),
#   ('A', 'F#:hdim7', 'B:hdim7/b7'),
#   ('Bb', 'C:min', 'Ab/5'),
#   ('G', 'Eb:7', 'D:7'),
#   ('D/5', 'F#', 'C:min'),
#   ('F:maj7', 'G#:dim7', 'F:min7'),
#   ('D', 'D:min7', 'C:min'),
#   ('D:min7', 'B:(b3,5)', 'A:(1)'),
#   ('Db', 'F:maj6', 'B:(b3,5)'),
#   ('Ab:maj6', 'F#:hdim7/b7', 'Eb:7'),
#   ('F', 'Eb/5', 'A:aug'),
#   ('A:min7', 'Bb', 'Gb'),
#   ('Db:maj7', 'G#:dim7', 'G:(1,5)'),
#   ('D:min', 'F#:hdim7/b7', 'G:7/3'),
#   ('F:min', 'F', 'B:hdim7/b7'),
#   ('D:min', 'A', 'F'),
#   ('G:maj(*1)/5', 'Bb:min', 'A:aug'),
#   ('G', 'G:min', 'D:7'),
#   ('G:maj(*1)/5', 'G', 'Eb:min7'),
#   ('N', 'F:7', 'F:maj6/5'),
#   ('B:min', 'Ab', 'F:min7'),
#   ('G#:aug', 'B:hdim7/b7', 'Eb:7/b7'),
#   ('Ab:maj6', 'B:hdim7/b7', 'C:min'),
#   ('F#:hdim7/b7', 'C/7', 'A:(1)'),
#   ('A:min/b7', 'C/7', 'G:(1,5)'),
#   ('G', 'F:min', 'G#:aug'),
#   ('N', 'Db', 'F:maj6/5'),
#   ('Db:maj7', 'A:7', 'F:min7'),
#   ('F:maj7', 'A:7', 'Ab/5'),
#   ('G:maj(*1)/5', 'Eb:min7', 'G#:dim7'),
#   ('G/3', 'F#:hdim7', 'F:min7'),
#   ('D/5', 'F#:aug', 'A:(1)'),
#   ('Bb:min', 'G#:dim7', 'Eb/5'),
#   ('Db', 'Bb:min', 'F:min7'),
#   ('F:maj7', 'B:(b3,5)', 'F:min7'),
#   ('G:maj(*1)/5', 'D:min', 'D/3'),
#   ('D', 'F:maj7', 'G:(1,5)'),
#   ('G/3', 'C/7', 'Ab/5'),
#   ('G#:aug', 'E:min/b3', 'F:min7'),
#   ('F#:min', 'A:min/b7', 'Ab/5'),
#   ('F#:hdim7/b7', 'A:dim7', 'F:min7'),
#   ('N', 'B', 'A:aug'),
#   ('Bb:min', 'E:min/b3', 'C#'),
#   ('Db', 'C/7', 'F#:aug'),
#   ('D:min7', 'F:maj6', 'Ab:maj(2)/2'),
#   ('G', 'Gb:min', 'F#:aug'),
#   ('Eb', 'Eb:7/b7', 'Eb/3'),
#   ('B:hdim7/b7', 'F#', 'Eb/3'),
#   ('G/3', 'C/5', 'G:7'),
#   ('D:min', 'E:min/b3', 'B:(b3,5)'),
#   ('D:min/b3', 'Eb', 'G:7/3'),
#   ('D:min7', 'G#:dim7', 'A:(1)'),
#   ('Ab:maj(2)/2', 'A:aug', 'D:7'),
#   ('E', 'E:min/b3', 'Eb/3'),
#   ('G:maj(*1)/5', 'F#:hdim7', 'G:(1,5)'),
#   ('D:min/b3', 'A:min/b7', 'D/5'),
#   ('F#:hdim7/b7', 'F:maj6/5', 'F#'),
#   ('F:min', 'F:7', 'F#'),
#   ('Gb:min', 'A:dim7', 'C#'),
#   ('Bb', 'A:min', 'Ab:maj(2)/2'),
#   ('E', 'Db', 'G:(1,5)'),
#   ('C', 'D:min/b3', 'G:(1,5)'),
#   ('A:min7', 'D:min/b3', 'A:dim7'),
#   ('Bb:min', 'D:min/b3', 'Eb'),
#   ('C', 'Db:maj7', 'Eb:min7'),
#   ('E', 'E:7', 'D/5'),
#   ('Bb:min', 'Ab:7', 'F'),
#   ('F:7', 'F:maj6', 'Eb'),
#   ('E:min/b3', 'A:dim7', 'D:7'),
#   ('Ab', 'F:maj6', 'B:(b3,5)'),
#   ('Ab:7', 'Eb:7/b7', 'A:(1)'),
#   ('Ab:maj(2)/2', 'Eb:7', 'Eb/3'),
#   ('A', 'B:(b3,5)', 'Eb:7'),
#   ('B:min', 'Eb:min7', 'Ab:7'),
#   ('D:min/b3', 'G:7/3', 'G:7'),
#   ('F:min', 'Bb:min', 'A:(1)'),
#   ('F:min', 'Gb:min', 'F#'),
#   ('F:maj6', 'F', 'E:min/b3'),
#   ('D:min/b3', 'C#', 'Eb:7'),
#   ('A:min7', 'Eb:min7', 'F#:aug'),
#   ('Ab', 'D/3', 'Eb'),
#   ('F:min', 'Eb/3', 'G/2'),
#   ('G:maj(*1)/5', 'Db:maj7', 'E:min/b3'),
#   ('A', 'F:maj6', 'B'),
#   ('A:min/b7', 'F:maj6/5', 'A:(1)'),
#   ('D:min', 'Gb', 'D:7'),
#   ('F:7', 'C/7', 'Eb/5'),
#   ('G:maj(*1)/5', 'F:maj6/5', 'Eb:7/b7'),
#   ('A:min7', 'F#:hdim7/b7', 'A:dim7'),
#   ('C/5', 'A:min/b3', 'Eb/3'),
#   ('Ab', 'C:min', 'Ab/5'),
#   ('Db:maj7', 'F:maj6', 'A:dim7'),
#   ('C:min', 'G:7', 'G/2'),
#   ('B', 'Ab/5', 'A:aug'),
#   ('E', 'B:(b3,5)', 'D:7'),
#   ('B:hdim7/b7', 'F#:aug', 'A:(1)'),
#   ('Db', 'E:min/b3', 'Eb'),
#   ('D/3', 'C:min', 'A:aug'),
#   ('G', 'G:min', 'Bb:min'),
#   ('N', 'D', 'Ab:7'),
#   ('Bb', 'D/3', 'Eb/3'),
#   ('A:min7', 'G:min', 'A'),
#   ('N', 'Eb:min7', 'Eb/3'),
#   ('Bb:min', 'F:7', 'A:aug'),
#   ('F:maj6/5', 'Eb', 'G/2'),
#   ('Db', 'F#:hdim7', 'Eb/5'),
#   ('G#:aug', 'F:maj6/5', 'G#:dim7'),
#   ('G:maj(*1)/5', 'F#:min', 'B:(b3,5)'),
#   ('C/5', 'G#:aug', 'Ab:maj(2)/2'),
#   ('N', 'E', 'A:aug'),
#   ('C', 'E', 'A:min/b7'),
#   ('C', 'A:min', 'A:min/b3'),
#   ('D:min/b3', 'Eb/3', 'G:(1,5)'),
#   ('G:maj(*1)/5', 'Bb', 'F#:hdim7/b7'),
#   ('G/3', 'F', 'G:7'),
#   ('G:maj(*1)/5', 'Ab/5', 'G:7'),
#   ('E', 'Ab', 'G#:dim7'),
#   ('F:min', 'A:dim7', 'A:aug'),
#   ('Eb', 'G:(1,5)', 'D:7'),
#   ('G#:aug', 'C#', 'F#:aug'),
#   ('Db:maj7', 'Ab:maj6', 'D:min7'),
#   ('F:min', 'Ab', 'G:7/3'),
#   ('G:min', 'Ab:7', 'C:min'),
#   ('Eb/3', 'G:(1,5)', 'G/2'),
#   ('B:min', 'A:dim7', 'C:min'),
#   ('F:min', 'Ab:7', 'D/3'),
#   ('G/3', 'F:maj6', 'D:7'),
#   ('D', 'Eb:7', 'D:7'),
#   ('A:min7', 'A:min/b3', 'G/2'),
#   ('F:maj7', 'A:min/b7', 'G#:dim7'),
#   ('F#:min', 'A:min/b3', 'A:aug'),
#   ('G/3', 'A:7', 'B'),
#   ('F:7', 'Eb:7/b7', 'G:(1,5)'),
#   ('G/3', 'Db:maj7', 'G/2'),
#   ('D:min7', 'A:dim7', 'C#'),
#   ('A:min/b7', 'D/3', 'B:hdim7/b7'),
#   ('G/3', 'Gb', 'B'),
#   ('Bb', 'G#:aug', 'C#'),
#   ('D', 'D:min', 'Db:maj7'),
#   ('A:min/b3', 'E:7', 'A:aug'),
#   ('D', 'B:(b3,5)', 'F#'),
#   ('G', 'D:min/b3', 'F:min7'),
#   ('Eb:min7', 'Gb', 'A:aug'),
#   ('C/7', 'B:(b3,5)', 'G:7/3'),
#   ('C', 'F:min', 'D:min7'),
#   ('D:min', 'D/3', 'G:(1,5)'),
#   ('G:maj(*1)/5', 'F#:aug', 'Eb'),
#   ('F:min', 'Ab', 'Ab/5'),
#   ('C', 'D:min/b3', 'D:min7'),
#   ('E:7', 'A:min/b7', 'B:(b3,5)'),
#   ('C/5', 'G#:dim7', 'Eb/3'),
#   ('B:hdim7/b7', 'F#', 'Eb'),
#   ('E:min/b3', 'A:7', 'F#'),
#   ('A:min7', 'F:min', 'D/3'),
#   ('D:min', 'B:min', 'A:min/b3'),
#   ('G:min', 'D:min/b3', 'A:aug'),
#   ('F#:min', 'F', 'B'),
#   ('F:min', 'D:min7', 'G/2'),
#   ('A:min/b3', 'F:maj7', 'C/7'),
#   ('B:min', 'A:min/b7', 'D/3'),
#   ('A', 'F#:hdim7/b7', 'A:7'),
#   ('A:min/b3', 'F', 'C/7'),
#   ('F#:min', 'Ab:maj6', 'D/5'),
#   ('G:min', 'G#:aug', 'F#:hdim7'),
#   ('Bb:min', 'Ab:maj(2)/2', 'G:(1,5)'),
#   ('D:min/b3', 'G:7/3', 'A:aug'),
#   ('G/3', 'A', 'D/5'),
#   ('G#:aug', 'A:min/b7', 'F:min7'),
#   ('G', 'F:min', 'Gb:min'),
#   ('D', 'A:dim7', 'B:hdim7/b7'),
#   ('Ab', 'Ab:7', 'A:dim7'),
#   ('Bb', 'Bb:min', 'G:7'),
#   ('A:min/b7', 'Eb/5', 'G:7'),
#   ('G:maj(*1)/5', 'Gb:min', 'E:min/b3'),
#   ('Gb', 'C/7', 'E:min/b3'),
#   ('B:min', 'F#:aug', 'D:7'),
#   ('Ab', 'Gb:min', 'D:7'),
#   ('G#:aug', 'F:maj7', 'F:maj6/5'),
#   ('N', 'E', 'Eb/5'),
#   ('F:maj6', 'A:7', 'D/3'),
#   ('G:min', 'A', 'D:min7'),
#   ('Gb:min', 'D:min7', 'A:(1)'),
#   ('N', 'A', 'Db:maj7'),
#   ('Ab:7', 'G#:aug', 'E:min/b3'),
#   ('G:maj(*1)/5', 'E:7', 'B:(b3,5)'),
#   ('Bb', 'F:7', 'F#'),
#   ('Gb:min', 'F:maj6/5', 'A:dim7'),
#   ('G:min', 'B:min', 'G:7'),
#   ('Ab:maj6', 'F#:hdim7/b7', 'Ab:maj(2)/2'),
#   ('E', 'Bb:min', 'A:dim7'),
#   ('F:min7', 'Ab/5', 'G:(1,5)'),
#   ('A:min', 'D:min/b3', 'Ab:maj(2)/2'),
#   ('D/5', 'F#', 'Ab:maj(2)/2'),
#   ('A:min', 'Gb:min', 'C/7'),
#   ('G#:dim7', 'C#', 'D:7'),
#   ('A:min/b3', 'F:7', 'E:min/b3'),
#   ('N', 'G#:aug', 'F#'),
#   ('A:min/b7', 'F', 'Eb:7'),
#   ('A', 'Eb/5', 'Ab/5'),
#   ('F:7', 'B:(b3,5)', 'Eb/5'),
#   ('Ab:7', 'F:maj7', 'G#:dim7'),
#   ('F#:hdim7', 'G#:dim7', 'C:min'),
#   ('G', 'B:(b3,5)', 'A:aug'),
#   ('G#:aug', 'F', 'G/2'),
#   ('D:min/b3', 'D/5', 'D:7'),
#   ('F:maj6', 'D/3', 'A:aug'),
#   ('Eb/5', 'G:7/3', 'G/2'),
#   ('F#:min', 'Db:maj7', 'D:7'),
#   ('G:maj(*1)/5', 'Db:maj7', 'B:(b3,5)'),
#   ('G/3', 'D:min7', 'G:7/3'),
#   ('A', 'F:min7', 'D:7'),
#   ('F#:min', 'F:7', 'B'),
#   ('E', 'F:7', 'D/3'),
#   ('D:min7', 'F:maj6', 'A:dim7'),
#   ('Gb', 'F#:hdim7/b7', 'E:min/b3'),
#   ('A:min7', 'F:maj6', 'G:(1,5)'),
#   ('Bb:min', 'A:7', 'D/3'),
#   ('G/3', 'Eb/5', 'Ab/5'),
#   ('E:7', 'Eb:7/b7', 'G:7'),
#   ('Eb:min7', 'D:min7', 'G:7/3'),
#   ('D/3', 'B:hdim7/b7', 'G:7/3'),
#   ('C/5', 'Db:maj7', 'E:min/b3'),
#   ('A:min7', 'E:7', 'Eb/5'),
#   ('A:min7', 'F:maj6/5', 'C:min'),
#   ('Eb:min7', 'F:maj7', 'F:7'),
#   ('E:7', 'E:min/b3', 'F#'),
#   ('G#:dim7', 'C:min', 'G:7'),
#   ('E', 'F#:hdim7/b7', 'F#:aug'),
#   ('F#', 'Ab/5', 'G/2'),
#   ('G', 'Gb', 'G#:dim7'),
#   ('B:min', 'D/5', 'F#'),
#   ('Bb', 'Ab:7', 'D:min7'),
#   ('F#:min', 'F#:hdim7/b7', 'B:(b3,5)'),
#   ...},
#  '012': {('Bb', 'Eb/5', 'G:7'),
#   ('E:7', 'Eb:min7', 'F#:hdim7/b7'),
#   ('C:min', 'D/3', 'G'),
#   ('A:min7', 'D:min', 'D:min/b3'),
#   ('C', 'D/5', 'G:min'),
#   ('B:hdim7/b7', 'F:maj7', 'N'),
#   ('Bb', 'C/7', 'Eb'),
#   ('A', 'D:min/b3', 'F#:min'),
#   ('A:min', 'C#', 'F#:aug'),
#   ('Ab/5', 'Bb', 'C:min'),
#   ('Ab:maj(2)/2', 'D', 'E'),
#   ('A:min', 'A:min/b3', 'B:hdim7/b7'),
#   ('Ab/5', 'Ab:maj(2)/2', 'Eb:min7'),
#   ('Ab/5', 'Ab:maj(2)/2', 'Eb:7'),
#   ('Bb:min', 'G:maj(*1)/5', 'N'),
#   ('A:(1)', 'Bb', 'C:min'),
#   ('A:min', 'F#:hdim7', 'G:min'),
#   ('F:7', 'F:maj6/5', 'N'),
#   ('C', 'D/5', 'F:maj7'),
#   ('Bb:min', 'D', 'N'),
#   ('Bb', 'Eb/5', 'F#:aug'),
#   ('A:min7', 'D:7', 'G/3'),
#   ('A:7', 'F:min7', 'G/2'),
#   ('A:min', 'Db', 'G'),
#   ('A:7', 'A:min7', 'C/5'),
#   ('Ab', 'B:hdim7/b7', 'Eb/5'),
#   ('Ab', 'F:maj7', 'N'),
#   ('A:min', 'F#:hdim7', 'F:maj7'),
#   ('A:aug', 'D', 'G#:dim7'),
#   ('Ab', 'Eb/3', 'G:(1,5)'),
#   ('E:7', 'F#:hdim7/b7', 'F:7'),
#   ('B', 'C', 'F:maj6/5'),
#   ('A:min', 'C/5', 'G:min'),
#   ('C:min', 'D:min/b3', 'E'),
#   ('A:min', 'Bb', 'E:min/b3'),
#   ('Ab', 'Eb:min7', 'F:maj6/5'),
#   ('C', 'D/5', 'E:7'),
#   ('Bb', 'D', 'D:7'),
#   ('Eb:min7', 'F:min', 'G:(1,5)'),
#   ('A:7', 'Ab/5', 'Ab:maj(2)/2'),
#   ('Ab', 'Ab:maj(2)/2', 'G:(1,5)'),
#   ('C:min', 'F:maj7', 'F:min7'),
#   ('A:min7', 'D', 'F#:hdim7/b7'),
#   ('Ab:maj6', 'C', 'G/3'),
#   ('C#', 'D/3', 'F#:aug'),
#   ('E', 'F:min7', 'N'),
#   ('A:min', 'F#:aug', 'G#:aug'),
#   ('D:min/b3', 'Eb/3', 'F:min'),
#   ('Ab', 'F#:min', 'G:min'),
#   ('A:min/b3', 'C', 'D/5'),
#   ('A:min/b3', 'Ab:maj6', 'F:min'),
#   ('A', 'A:min/b7', 'F'),
#   ('D:min', 'D:min/b3', 'Eb:7/b7'),
#   ('A', 'F#', 'G/2'),
#   ('D:7', 'Db:maj7', 'F:min'),
#   ('C:min', 'E:7', 'F#:hdim7/b7'),
#   ('Ab', 'Ab:7', 'F:7'),
#   ('A:min', 'E:7', 'F:min'),
#   ('Db', 'Eb', 'Gb'),
#   ('A:min', 'Db', 'Gb'),
#   ('C', 'F:maj7', 'G/3'),
#   ('A:(1)', 'B:min', 'F#:min'),
#   ('Ab:maj(2)/2', 'B:(b3,5)', 'N'),
#   ('A:min/b7', 'C/5', 'F#:hdim7'),
#   ('A', 'Ab/5', 'G:7'),
#   ('Bb', 'Eb/5', 'F#'),
#   ('A:(1)', 'A:min/b7', 'F'),
#   ('B', 'B:(b3,5)', 'G:(1,5)'),
#   ('A', 'A:min/b7', 'G'),
#   ('Bb', 'E:7', 'G'),
#   ('D/3', 'G:maj(*1)/5', 'N'),
#   ('A:min', 'A:min/b7', 'B:min'),
#   ('B:min', 'F#:min', 'G#:dim7'),
#   ('A:min', 'Ab:maj6', 'D:min'),
#   ('C:min', 'F:min', 'G'),
#   ('C:min', 'D/5', 'G:min'),
#   ('A:min', 'Bb:min', 'G:min'),
#   ('Bb', 'Db', 'F:min7'),
#   ('E:min/b3', 'F', 'G:(1,5)'),
#   ('C:min', 'F:min7', 'G/2'),
#   ('A:(1)', 'F:maj6/5', 'F:maj7'),
#   ('A:min', 'B:hdim7/b7', 'E'),
#   ('D:min7', 'Eb/3', 'F:min'),
#   ('Ab', 'B:(b3,5)', 'Eb:min7'),
#   ('A:dim7', 'C', 'C/7'),
#   ('B', 'B:(b3,5)', 'Eb:7/b7'),
#   ('D', 'Db', 'Db:maj7'),
#   ('E:7', 'Eb', 'F#:hdim7/b7'),
#   ('B', 'Bb:min', 'Db'),
#   ('D', 'Db', 'G:7/3'),
#   ('A:min/b7', 'Ab:7', 'F'),
#   ('A:dim7', 'E', 'F#'),
#   ('C:min', 'D/3', 'G:min'),
#   ('Bb', 'Eb', 'G/2'),
#   ('C:min', 'G#:aug', 'N'),
#   ('A:min', 'A:min/b3', 'Ab:maj(2)/2'),
#   ('A:min', 'C', 'C#'),
#   ('A', 'D:min', 'G'),
#   ('Ab', 'F#:aug', 'Gb'),
#   ('C', 'C/7', 'G:(1,5)'),
#   ('E', 'G#:aug', 'N'),
#   ('A:7', 'Eb', 'Eb:7'),
#   ('A:7', 'A:min', 'F'),
#   ('C/7', 'Eb:min7', 'F:min'),
#   ('A:7', 'Db', 'Gb'),
#   ('A:min', 'C', 'Eb:7'),
#   ('Eb/3', 'F:maj7', 'F:min'),
#   ('A:min/b7', 'Ab', 'Eb:min7'),
#   ('A:min/b7', 'Ab:maj6', 'F'),
#   ('Bb:min', 'C', 'G/3'),
#   ('A', 'F#:min', 'Gb:min'),
#   ('A:min', 'F', 'F:maj6/5'),
#   ('D', 'D:7', 'Eb/5'),
#   ('A', 'A:min', 'G#:dim7'),
#   ('Bb', 'D:min', 'G/3'),
#   ('A:min7', 'G/3', 'G:(1,5)'),
#   ('A:min', 'C/7', 'Eb:min7'),
#   ('A:min', 'C:min', 'G#:aug'),
#   ('A', 'E', 'Eb:min7'),
#   ('A:min/b7', 'A:min7', 'E'),
#   ('D:min/b3', 'E:7', 'G:7/3'),
#   ('A:aug', 'Eb:7', 'G'),
#   ('C', 'F#:min', 'F:maj6/5'),
#   ('Ab/5', 'B', 'B:(b3,5)'),
#   ('A', 'C', 'G/3'),
#   ('Ab:7', 'Db', 'G/2'),
#   ('Ab/5', 'Eb', 'F:min7'),
#   ('Eb', 'Eb/3', 'F:min'),
#   ('Ab', 'C', 'Eb/5'),
#   ('Eb:min7', 'F:7', 'F:min'),
#   ('A:7', 'Bb', 'Eb'),
#   ('B:min', 'F#:min', 'F:maj7'),
#   ('A:min', 'D:7', 'G#:aug'),
#   ('A:7', 'C#', 'G/2'),
#   ('A', 'Ab:maj(2)/2', 'G:7'),
#   ('E', 'Eb/3', 'F:min'),
#   ('A:aug', 'Ab', 'Eb:min7'),
#   ('B:hdim7/b7', 'D', 'G:7/3'),
#   ('A:min', 'Ab:maj(2)/2', 'D'),
#   ('Ab', 'Ab:maj(2)/2', 'G:maj(*1)/5'),
#   ('Ab:maj6', 'D', 'D:7'),
#   ('A:aug', 'D:min', 'G:min'),
#   ('Ab', 'Ab/5', 'Eb:min7'),
#   ('Ab', 'F:min', 'Gb'),
#   ('A', 'Bb:min', 'G'),
#   ('A:min/b7', 'C', 'C/7'),
#   ('C/5', 'F#:hdim7', 'G#:dim7'),
#   ('C', 'D:min', 'F:maj6'),
#   ('C', 'C:min', 'D'),
#   ('Ab', 'Bb:min', 'G:min'),
#   ('C:min', 'F:min', 'G#:aug'),
#   ('A:min', 'A:min/b3', 'Eb/5'),
#   ('A:7', 'Ab:maj6', 'G/2'),
#   ('Bb', 'C:min', 'G:(1,5)'),
#   ('A', 'Eb', 'G:7'),
#   ('Ab:maj6', 'B:hdim7/b7', 'F:min'),
#   ('Bb', 'Db:maj7', 'Eb:7'),
#   ('Ab:maj(2)/2', 'Eb', 'F'),
#   ('Ab:maj6', 'F:min', 'G/2'),
#   ('Db', 'Db:maj7', 'E:7'),
#   ('A:min/b3', 'A:min/b7', 'D'),
#   ('A', 'A:min', 'G:7'),
#   ('Eb:7/b7', 'Eb:min7', 'F:min'),
#   ('C', 'G/3', 'Gb:min'),
#   ('A', 'Ab:maj6', 'G/2'),
#   ('Ab:maj6', 'E', 'N'),
#   ('A', 'A:min/b7', 'F:maj7'),
#   ('A:min/b7', 'Ab', 'Eb/3'),
#   ('Bb:min', 'F:7', 'N'),
#   ('Eb:7', 'G', 'G#:dim7'),
#   ('A:min7', 'Ab', 'C/5'),
#   ('A:7', 'A:min7', 'G/2'),
#   ('A', 'F:maj7', 'G'),
#   ('D', 'Db', 'Gb'),
#   ('A', 'G:(1,5)', 'G:min'),
#   ('A:min', 'C/7', 'Eb/3'),
#   ('C#', 'F#', 'G:min'),
#   ('A:min/b3', 'D', 'G/2'),
#   ('Ab:maj(2)/2', 'C#', 'Eb'),
#   ('Eb:min7', 'F:min', 'Gb'),
#   ('A:aug', 'Ab:maj6', 'G'),
#   ('A:min7', 'E', 'Eb:7/b7'),
#   ('C', 'G/3', 'G:7/3'),
#   ('B', 'B:(b3,5)', 'F:min'),
#   ('Eb/3', 'F:min', 'G#:aug'),
#   ('D', 'Eb:min7', 'N'),
#   ('A:7', 'E:7', 'F:maj6'),
#   ('Ab', 'Eb/3', 'F'),
#   ('Ab:maj6', 'Db', 'F:maj6/5'),
#   ('B:min', 'Bb:min', 'F:min'),
#   ('Ab:maj6', 'Db', 'Eb'),
#   ('B:min', 'C#', 'F#'),
#   ('C:min', 'D:min7', 'G:min'),
#   ('C', 'F:maj6/5', 'G:maj(*1)/5'),
#   ('C#', 'C/5', 'G'),
#   ('Bb', 'D', 'E'),
#   ('Ab/5', 'D', 'E'),
#   ('Ab:maj6', 'E', 'F#:hdim7/b7'),
#   ('C:min', 'D/3', 'Eb'),
#   ('Bb', 'C:min', 'G:7/3'),
#   ('Ab:7', 'Db', 'E'),
#   ('E:7', 'E:min/b3', 'F'),
#   ('A:min7', 'Ab/5', 'E'),
#   ('A:aug', 'F:maj6/5', 'G'),
#   ('F#', 'F:maj6', 'F:maj7'),
#   ('Ab:7', 'Db', 'F#:aug'),
#   ('E:7', 'Eb/3', 'G:7/3'),
#   ('C#', 'F#:aug', 'F:maj7'),
#   ('A:min/b7', 'Eb', 'Eb/5'),
#   ('Db:maj7', 'F:min', 'G#:dim7'),
#   ('Ab/5', 'Ab:maj(2)/2', 'D/5'),
#   ('Ab', 'Eb:7', 'F#:hdim7'),
#   ('Ab', 'E:7', 'G:7/3'),
#   ('C:min', 'F#:aug', 'G:min'),
#   ('Bb:min', 'F:maj6/5', 'F:maj7'),
#   ('A:min', 'Ab', 'D'),
#   ('Bb', 'C:min', 'Gb:min'),
#   ('B:(b3,5)', 'Bb', 'Eb/5'),
#   ('D', 'E', 'F#:min'),
#   ('C', 'D', 'D:min/b3'),
#   ('A', 'F#:hdim7', 'F#:min'),
#   ('C#', 'F#:aug', 'G:min'),
#   ('A:aug', 'E', 'N'),
#   ('D:min', 'G:min', 'Gb'),
#   ('F#:min', 'F:maj6', 'F:maj7'),
#   ('C/7', 'D:min', 'G:min'),
#   ('Ab', 'G/2', 'G:min'),
#   ('A:min', 'D:min7', 'E:7'),
#   ('D:min/b3', 'E', 'F:min'),
#   ('A', 'A:7', 'E:min/b3'),
#   ('B:min', 'Eb', 'N'),
#   ('Ab', 'F#', 'G:min'),
#   ('Ab', 'Ab:7', 'F:min'),
#   ('C#', 'F#:hdim7', 'F:maj7'),
#   ('Ab/5', 'Ab:maj(2)/2', 'G:(1,5)'),
#   ('G#:dim7', 'G:maj(*1)/5', 'N'),
#   ('C', 'D/5', 'Eb/3'),
#   ('A:min', 'A:min/b7', 'D/5'),
#   ('A', 'F:min', 'G/2'),
#   ('A:(1)', 'Eb', 'Eb:7/b7'),
#   ('A:7', 'D/3', 'G'),
#   ('A:min', 'E', 'Eb:7'),
#   ('A:min', 'C/7', 'Eb:7'),
#   ('C/5', 'D:min/b3', 'E'),
#   ('A:7', 'E:7', 'F:min7'),
#   ('Bb', 'Eb:7', 'F#:aug'),
#   ('D:min', 'F:maj6/5', 'G:min'),
#   ('A:min7', 'E', 'Gb'),
#   ('A:7', 'D:min/b3', 'G/2'),
#   ('A:(1)', 'C', 'F:maj6'),
#   ('A:min7', 'C/7', 'F:maj7'),
#   ('Ab:maj6', 'Db', 'E'),
#   ('B', 'C#', 'Eb/5'),
#   ('A:min', 'C', 'Eb'),
#   ('A', 'A:dim7', 'A:min'),
#   ('A:dim7', 'B', 'C#'),
#   ('F', 'F:maj6/5', 'G'),
#   ('Ab', 'Ab:maj(2)/2', 'G/2'),
#   ('A:min', 'A:min7', 'G'),
#   ('Bb', 'E:min/b3', 'F'),
#   ('A:(1)', 'E:7', 'G'),
#   ('A', 'F', 'G:7'),
#   ('E', 'G:7', 'N'),
#   ('D:min/b3', 'E', 'Eb'),
#   ('A:min7', 'Bb', 'Eb/5'),
#   ('E:7', 'G', 'G:min'),
#   ('A', 'Bb', 'C:min'),
#   ('C#', 'F:maj6/5', 'F:maj7'),
#   ('Ab/5', 'Ab:maj(2)/2', 'F:7'),
#   ('B', 'C#', 'G/3'),
#   ('D', 'D/5', 'G/3'),
#   ('A:min/b7', 'D:7', 'N'),
#   ('A:min/b7', 'Ab', 'G:min'),
#   ('Ab:7', 'F:maj6/5', 'F:maj7'),
#   ('F:7', 'G:7/3', 'N'),
#   ('Db:maj7', 'F:min', 'G/2'),
#   ('A:min/b3', 'D', 'G:maj(*1)/5'),
#   ('Ab', 'Bb', 'F:min7'),
#   ('C:min', 'G:maj(*1)/5', 'G:min'),
#   ('A', 'C/7', 'G:7'),
#   ('A:min7', 'Eb/5', 'F:maj7'),
#   ('A:min/b7', 'Ab', 'Eb/5'),
#   ('Bb', 'G', 'G#:dim7'),
#   ('Ab/5', 'E', 'F#'),
#   ('Ab', 'Ab:7', 'D:min7'),
#   ('A:min7', 'D/5', 'Eb:min7'),
#   ('A:min/b7', 'F:maj7', 'G:7/3'),
#   ('A', 'A:dim7', 'Ab:maj6'),
#   ('A:7', 'E:7', 'F#'),
#   ('A:(1)', 'Ab', 'Ab:7'),
#   ('A:7', 'Ab', 'Ab:7'),
#   ('B:min', 'F#:min', 'F:maj6/5'),
#   ('Ab', 'Ab:maj(2)/2', 'Db:maj7'),
#   ('E:7', 'G', 'G/3'),
#   ('A:aug', 'A:min/b3', 'G'),
#   ('D:7', 'F:maj6/5', 'N'),
#   ('Ab', 'D', 'D:7'),
#   ('Eb:min7', 'F:maj6', 'Gb:min'),
#   ('C/5', 'F:maj6', 'G'),
#   ('D', 'D/3', 'Eb:min7'),
#   ('Eb', 'F', 'G'),
#   ('A:min/b7', 'F:maj7', 'Gb:min'),
#   ('C#', 'F#', 'Gb'),
#   ('B:hdim7/b7', 'D:7', 'N'),
#   ('A:aug', 'D', 'F#:hdim7'),
#   ('C:min', 'D:min', 'D:min/b3'),
#   ('Ab', 'E:min/b3', 'Eb:7'),
#   ('A:min', 'Ab/5', 'G#:aug'),
#   ('A:dim7', 'A:min', 'A:min/b3'),
#   ('A:min', 'F', 'G:7/3'),
#   ('A:min7', 'D/5', 'Eb/5'),
#   ('A:aug', 'Eb', 'Eb:7/b7'),
#   ('A:min7', 'D', 'Eb:7/b7'),
#   ('A:min/b7', 'B:(b3,5)', 'F'),
#   ('D/3', 'F#:hdim7', 'G'),
#   ('A:min', 'E:min/b3', 'G:maj(*1)/5'),
#   ('A', 'A:aug', 'G/2'),
#   ('C', 'F#:hdim7', 'F:maj7'),
#   ('A:min7', 'F#:min', 'F:maj7'),
#   ('B:min', 'F#:min', 'G:maj(*1)/5'),
#   ('Ab:maj(2)/2', 'Bb', 'Eb:7'),
#   ('C#', 'F#', 'G:maj(*1)/5'),
#   ('A:aug', 'Ab', 'Eb/3'),
#   ('Ab:maj6', 'F:min', 'G#:dim7'),
#   ('Ab', 'E', 'Eb/3'),
#   ('A', 'G:(1,5)', 'G:maj(*1)/5'),
#   ('C#', 'C:min', 'G:min'),
#   ('A:7', 'Ab:maj(2)/2', 'Eb'),
#   ('A:7', 'Ab', 'Ab:maj(2)/2'),
#   ('A:min7', 'Eb', 'Eb/5'),
#   ('Db', 'F:maj6/5', 'Gb'),
#   ('A:min', 'A:min7', 'D/5'),
#   ('C/5', 'F#:hdim7', 'G/2'),
#   ('Ab/5', 'Eb', 'F#:hdim7/b7'),
#   ('Db', 'G', 'G#:dim7'),
#   ('E', 'F#:hdim7/b7', 'F:min7'),
#   ('Ab/5', 'G:(1,5)', 'N'),
#   ('Ab', 'Ab:7', 'B'),
#   ('C', 'D/3', 'D/5'),
#   ('D:7', 'F#', 'N'),
#   ('Bb', 'C:min', 'D/5'),
#   ('D:min', 'Eb:min7', 'Gb:min'),
#   ('A', 'A:dim7', 'F:maj6/5'),
#   ('C:min', 'E:7', 'G:7/3'),
#   ('A', 'A:dim7', 'Eb'),
#   ('B', 'C#', 'F#:hdim7'),
#   ('B:min', 'F#:min', 'G#:aug'),
#   ('Eb', 'Eb:7/b7', 'F#:hdim7'),
#   ('Ab:7', 'Db', 'G#:dim7'),
#   ('A:min', 'A:min/b7', 'F#:min'),
#   ('Ab/5', 'Ab:maj(2)/2', 'E:min/b3'),
#   ('A:min', 'Bb:min', 'E:7'),
#   ('F:maj6', 'G:(1,5)', 'N'),
#   ('A:dim7', 'F:7', 'N'),
#   ('A', 'Bb:min', 'E'),
#   ('A:(1)', 'C#', 'F#'),
#   ('A', 'A:min', 'G/2'),
#   ('C', 'F:maj6/5', 'Gb:min'),
#   ('A', 'Eb/5', 'G'),
#   ('Ab/5', 'D/5', 'G/2'),
#   ('Ab:maj(2)/2', 'C/5', 'G'),
#   ('Ab:maj6', 'C/5', 'F:min'),
#   ('B:(b3,5)', 'Eb', 'Eb/5'),
#   ('D', 'D:7', 'Eb'),
#   ('D', 'D:7', 'F:maj6/5'),
#   ('Bb', 'Eb', 'F#:aug'),
#   ('C#', 'Eb:min7', 'F:min'),
#   ('B', 'F:7', 'N'),
#   ('Ab/5', 'Ab:maj(2)/2', 'F#:min'),
#   ('B', 'F', 'G'),
#   ('D/5', 'Eb:min7', 'G/2'),
#   ('A:min', 'Ab/5', 'Ab:maj(2)/2'),
#   ('A', 'A:min7', 'G/3'),
#   ('A:min', 'D:7', 'E:7'),
#   ('A:min', 'A:min/b7', 'Gb'),
#   ('A', 'Db', 'G:(1,5)'),
#   ('Ab:maj6', 'D:min', 'G:min'),
#   ('Bb', 'Db:maj7', 'Eb/5'),
#   ('Ab/5', 'E', 'N'),
#   ('Eb:min7', 'F#', 'F#:aug'),
#   ('C', 'D', 'E:min/b3'),
#   ('Ab:maj(2)/2', 'Eb', 'F:min7'),
#   ('A:min/b7', 'E', 'N'),
#   ('D:7', 'F', 'G'),
#   ('D/5', 'D:7', 'G/2'),
#   ('A:aug', 'D', 'F#:hdim7/b7'),
#   ('A:min7', 'D', 'Eb:7'),
#   ('D:min', 'D:min/b3', 'E:min/b3'),
#   ('Bb', 'Eb', 'G#:dim7'),
#   ('A:min', 'B:(b3,5)', 'G'),
#   ('A:dim7', 'A:min', 'G'),
#   ('E:7', 'F#:hdim7/b7', 'F:maj6'),
#   ('B', 'C#', 'G/2'),
#   ('A:min', 'B:min', 'E'),
#   ('Bb', 'Eb:7', 'F#'),
#   ('A:min', 'C:min', 'E:7'),
#   ('Db', 'F#:min', 'Gb:min'),
#   ('D:7', 'F#', 'F#:aug'),
#   ('A', 'Bb:min', 'G#:dim7'),
#   ('A:min', 'C', 'Eb:min7'),
#   ('Ab', 'C/5', 'G#:aug'),
#   ('A', 'A:min', 'G#:aug'),
#   ('F:maj7', 'F:min', 'N'),
#   ('A:min7', 'C:min', 'F:min'),
#   ('A', 'B:min', 'E'),
#   ('D:min', 'D:min/b3', 'F#:min'),
#   ('Ab', 'Db', 'G'),
#   ('A:7', 'Ab', 'G/2'),
#   ('A:aug', 'D:7', 'N'),
#   ('Ab', 'C/7', 'C:min'),
#   ('C:min', 'F:min7', 'G#:dim7'),
#   ('A:min', 'E', 'Gb'),
#   ('Ab', 'Eb:min7', 'F#:aug'),
#   ('A:min/b7', 'G:maj(*1)/5', 'N'),
#   ('A:min/b3', 'B', 'B:(b3,5)'),
#   ('D', 'D:7', 'Gb:min'),
#   ('A', 'E', 'G:min'),
#   ('D:min', 'E:7', 'F#:hdim7/b7'),
#   ('Db', 'G', 'Gb:min'),
#   ('A:min', 'Eb/3', 'N'),
#   ('A', 'D:7', 'G#:dim7'),
#   ('A:min', 'G#:dim7', 'N'),
#   ('C:min', 'Eb', 'F:maj6'),
#   ('D:min', 'F:maj6', 'G:min'),
#   ('Ab/5', 'Eb', 'G/3'),
#   ('C/5', 'G', 'G:min'),
#   ('B', 'C#', 'Db:maj7'),
#   ('C:min', 'F:min', 'G/3'),
#   ('Ab:maj(2)/2', 'D', 'D/3'),
#   ('D:7', 'Db', 'Gb'),
#   ('Eb:7', 'F', 'G'),
#   ('A:min7', 'Ab/5', 'C/5'),
#   ('Bb', 'F:min', 'G#:aug'),
#   ('A:min/b7', 'Bb', 'F'),
#   ('Eb:7', 'Eb:min7', 'F:min'),
#   ('A:min', 'F#:hdim7/b7', 'G'),
#   ('D', 'D:7', 'F:7'),
#   ('D/5', 'F:min', 'G/2'),
#   ('Ab', 'C/5', 'Gb'),
#   ('A:min7', 'Ab', 'D'),
#   ('D:min', 'F:7', 'G:min'),
#   ('C/7', 'F:maj6', 'F:maj7'),
#   ('A:7', 'A:min/b3', 'E'),
#   ('Ab:7', 'B:(b3,5)', 'Db'),
#   ('A:7', 'D:min7', 'E'),
#   ('Bb', 'Eb', 'G:min'),
#   ('Ab', 'C#', 'F#:aug'),
#   ('B:(b3,5)', 'F:min', 'N'),
#   ('C/5', 'G', 'G:(1,5)'),
#   ('Ab:maj6', 'B', 'Db'),
#   ('F#', 'F#:aug', 'G:7'),
#   ('G', 'G#:dim7', 'Gb:min'),
#   ('A:min', 'Eb/3', 'G#:aug'),
#   ('A', 'F', 'G:(1,5)'),
#   ('B', 'Bb:min', 'F:min'),
#   ('B:(b3,5)', 'D', 'D/3'),
#   ('Ab/5', 'D:min', 'D:min/b3'),
#   ('C/7', 'E', 'N'),
#   ('C:min', 'F#:hdim7', 'F:min7'),
#   ('A', 'Ab:maj6', 'G:(1,5)'),
#   ('A:min7', 'B:min', 'F#:min'),
#   ('B:min', 'D:min', 'D:min/b3'),
#   ('B:(b3,5)', 'F#', 'F#:aug'),
#   ('A:min', 'A:min/b3', 'F:7'),
#   ('Bb', 'Eb/5', 'F:maj7'),
#   ('A:min', 'F:maj6/5', 'G:min'),
#   ('A:min', 'C', 'C:min'),
#   ('D:min', 'Eb', 'N'),
#   ('C', 'D/5', 'F#:aug'),
#   ('D/5', 'Db:maj7', 'F:min'),
#   ('Eb', 'F:min', 'N'),
#   ('Ab:maj6', 'E:7', 'F:min'),
#   ('Eb/3', 'F:min', 'N'),
#   ('A:min7', 'D/5', 'F:min'),
#   ('Db', 'F:maj7', 'Gb:min'),
#   ('A:min/b7', 'D:min', 'D:min/b3'),
#   ('A:aug', 'G', 'G:(1,5)'),
#   ('A:min7', 'C/5', 'G:maj(*1)/5'),
#   ('Ab', 'Eb:7', 'F:min7'),
#   ('Eb', 'Eb/5', 'F#:hdim7/b7'),
#   ('A', 'A:dim7', 'A:min/b7'),
#   ('A:7', 'E:7', 'Eb:7/b7'),
#   ('A:dim7', 'Bb', 'F:min7'),
#   ('B:min', 'F#:min', 'Gb'),
#   ('D:7', 'Eb', 'Eb:7/b7'),
#   ('A:min/b7', 'Eb', 'Eb:7/b7'),
#   ('Ab:maj(2)/2', 'Bb', 'F:min'),
#   ('D', 'D:7', 'G#:aug'),
#   ('A', 'Ab:maj6', 'E'),
#   ('D/3', 'D:min', 'G:min'),
#   ('Ab:maj6', 'Db', 'F#:hdim7/b7'),
#   ('C/5', 'F#:min', 'G'),
#   ('E:7', 'E:min/b3', 'G:7/3'),
#   ('Bb', 'E', 'Eb:7'),
#   ('Ab/5', 'E:7', 'Eb'),
#   ('A:min7', 'Ab:maj(2)/2', 'E'),
#   ('A', 'F#:aug', 'G'),
#   ('Bb', 'C:min', 'G#:aug'),
#   ('C', 'Eb:7/b7', 'F:maj6/5'),
#   ('Bb', 'Eb', 'G/3'),
#   ('D:min', 'D:min/b3', 'G:7'),
#   ('A:min', 'G/2', 'G:min'),
#   ('B:hdim7/b7', 'D', 'D:7'),
#   ('D:min', 'E:7', 'G:7/3'),
#   ('Bb:min', 'C', 'Db'),
#   ('E', 'F', 'N'),
#   ('Eb', 'Eb:7', 'Eb:min7'),
#   ('Ab', 'D/5', 'Gb'),
#   ('D:min/b3', 'E', 'Gb'),
#   ('A:min7', 'C/5', 'F:maj6'),
#   ('A:min7', 'D', 'F:maj6/5'),
#   ('A:min', 'F:maj7', 'G:min'),
#   ('A', 'Ab', 'Eb:min7'),
#   ('Db:maj7', 'Eb:7', 'F:min'),
#   ('A:aug', 'D', 'F#:aug'),
#   ('Db:maj7', 'E:7', 'G:7/3'),
#   ('Ab:maj(2)/2', 'E:min/b3', 'Eb'),
#   ('C', 'D:7', 'G/3'),
#   ('Db:maj7', 'Eb', 'N'),
#   ('F', 'G', 'G/2'),
#   ('A:min7', 'E', 'F:maj6/5'),
#   ('Eb/3', 'F:7', 'F:min'),
#   ('A:min7', 'E', 'Eb'),
#   ('Bb', 'Eb/5', 'G#:dim7'),
#   ('A', 'Eb', 'G#:dim7'),
#   ('Db', 'Eb/5', 'Gb'),
#   ('A', 'B', 'G#:dim7'),
#   ('Ab', 'D:min/b3', 'Eb/5'),
#   ('B:(b3,5)', 'F#:hdim7', 'F:maj7'),
#   ('A:min/b3', 'G:maj(*1)/5', 'N'),
#   ('Ab:maj6', 'Db', 'Eb:7/b7'),
#   ('Ab:maj6', 'D:7', 'F:min'),
#   ('F#', 'G:(1,5)', 'N'),
#   ('Ab', 'Ab:maj(2)/2', 'E:min/b3'),
#   ('Eb:min7', 'F:maj6/5', 'F:maj7'),
#   ('A:min', 'Ab:maj6', 'E'),
#   ('Ab', 'D:min/b3', 'Db'),
#   ('Ab', 'Ab:7', 'F#:hdim7'),
#   ('Bb', 'Eb:7', 'G:7'),
#   ('A:min', 'D:min', 'G:7/3'),
#   ('Ab', 'E', 'G:min'),
#   ('Bb', 'D:min', 'G'),
#   ('E:7', 'F:7', 'G:7/3'),
#   ('A:aug', 'C/5', 'G#:aug'),
#   ('A', 'F#:min', 'F:maj7'),
#   ('A:7', 'D:min', 'G/2'),
#   ('C:min', 'Eb', 'G'),
#   ('Ab', 'Eb:7/b7', 'F#:hdim7/b7'),
#   ('A:min/b7', 'Ab', 'Eb:7/b7'),
#   ('A', 'Eb:7', 'G'),
#   ('A:min7', 'C/5', 'D:min'),
#   ('E:7', 'F#:hdim7', 'G:7/3'),
#   ('E:7', 'G', 'G#:aug'),
#   ('B:(b3,5)', 'C/5', 'G'),
#   ('D', 'F:min7', 'N'),
#   ('A', 'Ab:maj(2)/2', 'G:(1,5)'),
#   ('D', 'E:7', 'F#:hdim7/b7'),
#   ('Ab', 'Ab:maj(2)/2', 'Bb'),
#   ('A', 'F#:min', 'G:min'),
#   ('Ab/5', 'C/5', 'G'),
#   ('A:min', 'C#', 'G'),
#   ('Ab', 'F', 'Gb'),
#   ('Eb/3', 'F:min', 'G/2'),
#   ('G/2', 'G:(1,5)', 'N'),
#   ('D', 'G:7/3', 'Gb:min'),
#   ('Ab/5', 'C/5', 'F#:hdim7'),
#   ('Ab', 'Ab:maj(2)/2', 'F'),
#   ('C:min', 'G/2', 'N'),
#   ('Db', 'G/3', 'Gb:min'),
#   ('Eb:min7', 'F#:hdim7', 'Gb:min'),
#   ('A:min', 'D:min7', 'G'),
#   ('A', 'A:min/b7', 'F#:min'),
#   ('Ab:maj6', 'F:maj6', 'F:min'),
#   ('Db:maj7', 'F', 'F:min'),
#   ('C', 'D', 'F:min7'),
#   ('A:min', 'A:min/b7', 'G:maj(*1)/5'),
#   ('A:min', 'D:min/b3', 'G#:aug'),
#   ('A:min7', 'D/5', 'Eb:7/b7'),
#   ('A:aug', 'Eb', 'Eb/5'),
#   ('A:(1)', 'A:min', 'D:min'),
#   ('A:aug', 'G', 'G/3'),
#   ('Ab:maj(2)/2', 'Ab:maj6', 'Db'),
#   ('A:min/b7', 'B:(b3,5)', 'N'),
#   ('Db', 'F:maj6/5', 'Gb:min'),
#   ('Ab:maj(2)/2', 'Eb', 'F#:min'),
#   ('A', 'A:7', 'B:min'),
#   ('C', 'C:min', 'F:min'),
#   ('D', 'D/3', 'Db:maj7'),
#   ('A:(1)', 'A:min7', 'E'),
#   ('D', 'F:7', 'G:7/3'),
#   ('A:7', 'Ab:7', 'G/2'),
#   ('Bb', 'E', 'F#:hdim7/b7'),
#   ('Eb:min7', 'F#:hdim7/b7', 'Gb:min'),
#   ('C', 'Eb:7/b7', 'F:maj6'),
#   ('C/7', 'C:min', 'F:min'),
# ...
#   ('A:dim7', 'B:hdim7/b7', 'G/3'),
#   ('B:min', 'F#:hdim7/b7', 'G'),
#   ('Ab:maj6', 'D', 'G:7'),
#   ('C#', 'E', 'G'),
#   ('A:7', 'B:hdim7/b7', 'F#:hdim7/b7'),
#   ('A:7', 'A:aug', 'A:dim7'),
#   ('A:dim7', 'B:hdim7/b7', 'G#:dim7'),
#   ('A:(1)', 'D:min7', 'N'),
#   ('A:7', 'B', 'F#:aug'),
#   ('B', 'D', 'F#:aug'),
#   ('C', 'Eb/5', 'F'),
#   ('Bb', 'C', 'G:7/3'),
#   ('C', 'F', 'F#:hdim7'),
#   ('A:7', 'A:dim7', 'Eb:7/b7'),
#   ('D', 'F#', 'G'),
#   ('Db', 'G/3', 'N'),
#   ('A:7', 'Ab', 'N'),
#   ('C', 'Eb:min7', 'F'),
#   ('A:min7', 'D:min7', 'F:maj6/5'),
#   ('A:min7', 'D:min7', 'Eb'),
#   ('B:hdim7/b7', 'D', 'G'),
#   ('Bb', 'C', 'F#:aug'),
#   ('A', 'Ab', 'D/5'),
#   ('A:dim7', 'Bb', 'N'),
#   ('A:dim7', 'B:hdim7/b7', 'N'),
#   ('A:7', 'B:hdim7/b7', 'Db'),
#   ('A:min7', 'B:hdim7/b7', 'D:min7'),
#   ('F#:hdim7/b7', 'G', 'N'),
#   ('A:7', 'Ab:7', 'N'),
#   ('A:min7', 'D:min7', 'G:7/3'),
#   ('A:7', 'A:min7', 'N'),
#   ('A', 'D:min7', 'N'),
#   ('A:7', 'A:dim7', 'F#'),
#   ('C', 'F#:hdim7', 'G'),
#   ('D', 'G:(1,5)', 'G:7'),
#   ('A', 'D', 'Eb:7'),
#   ('A:7', 'D', 'G#:dim7'),
#   ('C', 'F', 'G#:dim7'),
#   ('B', 'C', 'G'),
#   ('A:7', 'D/5', 'G:7/3'),
#   ('Bb', 'F:7', 'G:7'),
#   ('B', 'F#', 'F#:hdim7/b7'),
#   ('A', 'Ab', 'B:hdim7/b7'),
#   ('C', 'C:min', 'G'),
#   ('Ab:7', 'C', 'G'),
#   ('B', 'D:min', 'F#'),
#   ('Bb', 'Eb:min7', 'N'),
#   ('G', 'G#:aug', 'G:maj(*1)/5'),
#   ('D', 'E:min/b3', 'G'),
#   ('A:7', 'D/5', 'F#:hdim7'),
#   ('Bb', 'D/5', 'F:7'),
#   ('C', 'Db:maj7', 'N'),
#   ('B:min', 'D:7', 'G'),
#   ('D:min', 'G', 'G:maj(*1)/5'),
#   ('A:7', 'G:min', 'N'),
#   ('Db', 'F#', 'N'),
#   ('A:7', 'D/5', 'F#:aug'),
#   ('A:dim7', 'A:min/b7', 'B:hdim7/b7'),
#   ('B', 'C', 'F#'),
#   ('A:7', 'Ab:7', 'D'),
#   ('Bb', 'D', 'G'),
#   ('Bb', 'F#:hdim7', 'N'),
#   ('A:dim7', 'G', 'N'),
#   ('A:7', 'D/5', 'Eb/3'),
#   ('A:min7', 'D:min7', 'G'),
#   ('A:7', 'B:hdim7/b7', 'F'),
#   ('B', 'D:min7', 'F#'),
#   ('A:7', 'Bb', 'F:7'),
#   ('A:7', 'D/5', 'D:min'),
#   ('A:min7', 'D:min7', 'F#:min'),
#   ('B', 'F#:aug', 'F#:hdim7'),
#   ('B', 'F#', 'N'),
#   ('A', 'F#:hdim7', 'N'),
#   ('A:min/b3', 'B', 'F#:aug'),
#   ('A', 'D:min/b3', 'N'),
#   ('A:7', 'A:dim7', 'G/3'),
#   ('A:7', 'F#', 'N'),
#   ('A:dim7', 'B:hdim7/b7', 'G:(1,5)'),
#   ('Ab', 'D', 'G'),
#   ('A:7', 'A:min/b3', 'N'),
#   ('A:7', 'A:min', 'B:hdim7/b7'),
#   ('Ab:7', 'E', 'G'),
#   ('B', 'D/3', 'F#:aug'),
#   ('A:min/b3', 'Bb', 'C'),
#   ('A:7', 'D', 'G/3'),
#   ('F#:min', 'G', 'G:maj(*1)/5'),
#   ('Bb', 'C', 'Db:maj7'),
#   ('A:(1)', 'Eb/3', 'N'),
#   ('Bb', 'G/2', 'N'),
#   ('Db', 'G:7/3', 'N'),
#   ('Bb', 'F:maj6/5', 'N'),
#   ('D', 'F:min', 'G:7'),
#   ('A', 'A:min/b7', 'D'),
#   ('A:7', 'Ab/5', 'B:hdim7/b7'),
#   ('E', 'Eb:7/b7', 'G'),
#   ('A', 'D', 'Db'),
#   ('C', 'E:min/b3', 'G'),
#   ('B', 'Db:maj7', 'F#'),
#   ('A', 'D/5', 'F#'),
#   ('C', 'F', 'F:maj7'),
#   ('C', 'C#', 'N'),
#   ('Eb:7', 'G', 'N'),
#   ('A', 'A:min/b3', 'N'),
#   ('A:7', 'Ab:maj(2)/2', 'D'),
#   ('A:7', 'D', 'Eb:7'),
#   ('D', 'D:min/b3', 'G:7'),
#   ('A:dim7', 'B:hdim7/b7', 'F#'),
#   ('E', 'G', 'G:min'),
#   ('A:7', 'D', 'G:(1,5)'),
#   ('Ab:maj(2)/2', 'D', 'G'),
#   ('Ab/5', 'B', 'F#:aug'),
#   ('A:7', 'Db:maj7', 'N'),
#   ('Ab:maj(2)/2', 'D', 'G:7'),
#   ('A:7', 'D/5', 'Eb:7/b7'),
#   ('A:min7', 'D:min7', 'G:min'),
#   ('A:7', 'Ab', 'D/5'),
#   ('B:min', 'Bb:min', 'G'),
#   ('A:7', 'D/5', 'Db:maj7'),
#   ('A', 'D/5', 'F:maj6'),
#   ('A:7', 'B:hdim7/b7', 'D:7'),
#   ('Bb', 'D:7', 'F:7'),
#   ('A:min7', 'D:min7', 'G#:aug'),
#   ('A', 'Ab:maj(2)/2', 'B:hdim7/b7'),
#   ('A:7', 'Ab:7', 'D/5'),
#   ('B', 'F#', 'G/3'),
#   ('A', 'D', 'G:min'),
#   ('A', 'B', 'F#:aug'),
#   ('A:dim7', 'B:hdim7/b7', 'Eb:7/b7'),
#   ('A:7', 'A:dim7', 'C'),
#   ('A', 'B:hdim7/b7', 'F:maj6/5'),
#   ('Db', 'F:maj6', 'N'),
#   ('A:dim7', 'A:min', 'B:hdim7/b7'),
#   ('A', 'B:hdim7/b7', 'Eb'),
#   ('A:min7', 'C:min', 'D:min7'),
#   ('B:min', 'D/5', 'G'),
#   ('A:(1)', 'A:aug', 'N'),
#   ('A:7', 'D', 'Gb:min'),
#   ('A:7', 'A:dim7', 'Db'),
#   ('A:7', 'B:hdim7/b7', 'F:min'),
#   ('A', 'B:hdim7/b7', 'G:7/3'),
#   ('A:7', 'E:min/b3', 'N'),
#   ('C#', 'Db', 'N'),
#   ('Ab/5', 'B', 'F#'),
#   ('D', 'E:min/b3', 'G:7'),
#   ('Bb:min', 'C', 'N'),
#   ('Ab', 'C', 'G'),
#   ('A', 'Ab:7', 'N'),
#   ('Ab', 'B:min', 'G'),
#   ('A:min7', 'Ab', 'D:min7'),
#   ('D', 'F:7', 'G'),
#   ('A:(1)', 'C', 'G'),
#   ('A:(1)', 'B', 'F#'),
#   ('A', 'D', 'F'),
#   ('Bb', 'F#:hdim7/b7', 'N'),
#   ('B', 'C/7', 'E'),
#   ('B', 'D:7', 'E'),
#   ('A:7', 'C/7', 'D'),
#   ('A:min/b7', 'E', 'G'),
#   ('B', 'F#:aug', 'N'),
#   ('A:dim7', 'B:(b3,5)', 'B:hdim7/b7'),
#   ('A:min7', 'Ab:7', 'D:min7'),
#   ('F#', 'G', 'N'),
#   ('A:dim7', 'Db', 'N'),
#   ('A', 'D/5', 'G#:aug'),
#   ('A:aug', 'C', 'N'),
#   ('A:7', 'D/5', 'G/3'),
#   ('A:min/b7', 'Bb', 'C'),
#   ('E', 'Eb', 'G'),
#   ('A', 'B:hdim7/b7', 'D:min7'),
#   ('Ab:maj6', 'C', 'F'),
#   ('A:dim7', 'B', 'B:hdim7/b7'),
#   ('A:dim7', 'B:hdim7/b7', 'G'),
#   ('A:(1)', 'D:min/b3', 'N'),
#   ('B:min', 'Bb', 'N'),
#   ('A', 'Eb/3', 'N'),
#   ('Ab/5', 'C', 'G'),
#   ('Bb', 'C', 'Eb:7/b7'),
#   ('B', 'E', 'G:maj(*1)/5'),
#   ('A:(1)', 'D:min', 'N'),
#   ('A:min7', 'B:min', 'G'),
#   ('A:7', 'B:hdim7/b7', 'F:7'),
#   ('C', 'D:min', 'G'),
#   ('Db', 'G#:dim7', 'N'),
#   ('A:(1)', 'F', 'N'),
#   ('A', 'A:aug', 'D/5'),
#   ('A:(1)', 'A:7', 'A:dim7'),
#   ('B:hdim7/b7', 'C', 'F'),
#   ('A:dim7', 'C', 'N'),
#   ('D', 'E:7', 'G:7'),
#   ('Bb', 'F:7', 'F:maj6'),
#   ('Bb', 'F:7', 'Gb'),
#   ('D', 'Eb', 'G'),
#   ('D', 'Eb', 'G:7'),
#   ('B', 'F#:aug', 'G:min'),
#   ('Ab/5', 'D', 'G'),
#   ('A:7', 'G#:dim7', 'N'),
#   ('A:7', 'D', 'Eb:7/b7'),
#   ('A', 'D', 'F#:hdim7'),
#   ('A:dim7', 'B:hdim7/b7', 'C'),
#   ('A:7', 'D/5', 'Eb/5'),
#   ('C', 'D:min/b3', 'G'),
#   ('A:dim7', 'Ab:maj6', 'B:hdim7/b7'),
#   ('A:dim7', 'B:hdim7/b7', 'G:maj(*1)/5'),
#   ('A', 'D/5', 'G/3'),
#   ('A:7', 'Ab/5', 'N'),
#   ('A', 'D', 'Eb/5'),
#   ('A', 'B:hdim7/b7', 'G#:aug'),
#   ('C', 'G#:dim7', 'N'),
#   ('A:min7', 'D:min', 'D:min7'),
#   ('F#', 'G', 'G:maj(*1)/5'),
#   ('A:(1)', 'A:min7', 'N'),
#   ('C', 'D:7', 'G'),
#   ('B', 'F#', 'F:maj7'),
#   ('C', 'G:7', 'N'),
#   ('A:min', 'B', 'F#'),
#   ('A:7', 'A:min7', 'B:hdim7/b7'),
#   ('B:min', 'C:min', 'G'),
#   ('Bb', 'C', 'C#'),
#   ('A', 'F:min', 'N'),
#   ('A:7', 'D', 'Gb'),
#   ('Ab/5', 'Bb', 'C'),
#   ('F#:min', 'G', 'N'),
#   ('B', 'Db', 'E'),
#   ('D:min/b3', 'G', 'N'),
#   ('A', 'F#', 'N'),
#   ('D', 'F:maj6/5', 'G:7'),
#   ('A', 'B:(b3,5)', 'D'),
#   ('B', 'F#', 'G:min'),
#   ('Bb', 'G:7/3', 'N'),
#   ('Db', 'G/2', 'N'),
#   ('A:min7', 'D:min7', 'F#:hdim7'),
#   ('D', 'D:min', 'G:7'),
#   ('B', 'F#:aug', 'F#:min'),
#   ('B', 'C/5', 'E'),
#   ('B', 'B:min', 'G'),
#   ('D', 'F:7', 'G:7'),
#   ('D', 'Eb/3', 'G:7'),
#   ('A', 'C/7', 'N'),
#   ('A:min7', 'B:min', 'D:min7'),
#   ('C:min', 'D', 'G:7'),
#   ('A:7', 'A:dim7', 'F#:hdim7/b7'),
#   ('A:7', 'F#:hdim7/b7', 'N'),
#   ('A:7', 'Bb', 'C'),
#   ('A:7', 'Bb', 'D'),
#   ('B:min', 'Eb/5', 'G'),
#   ('D', 'G/2', 'G:7'),
#   ('Bb', 'C', 'F#'),
#   ('A:7', 'A:dim7', 'Gb'),
#   ('A:min7', 'B:(b3,5)', 'D:min7'),
#   ('B:min', 'G', 'G/2'),
#   ('A:dim7', 'G', 'G:maj(*1)/5'),
#   ('C', 'F:min7', 'G'),
#   ('A', 'G#:aug', 'N'),
#   ('B', 'E', 'G/2'),
#   ('C', 'D:min7', 'N'),
#   ('A', 'A:min7', 'D:min7'),
#   ('A:7', 'A:dim7', 'G:maj(*1)/5'),
#   ('A:min/b3', 'B:min', 'G'),
#   ('B', 'D:7', 'F#:aug'),
#   ('A', 'C:min', 'D/5'),
#   ('A', 'D', 'D:min'),
#   ('A', 'Bb', 'D/5'),
#   ('C#', 'D', 'G'),
#   ('Bb', 'Bb:min', 'N'),
#   ('B', 'Eb/5', 'F#'),
#   ('A:min/b7', 'D', 'G:7'),
#   ('A:dim7', 'B:hdim7/b7', 'Eb:7'),
#   ('D', 'F:maj6', 'G'),
#   ('Eb/5', 'G', 'G:maj(*1)/5'),
#   ('A', 'F:maj6/5', 'N'),
#   ('C', 'F', 'G:(1,5)'),
#   ('Bb', 'Bb:min', 'C'),
#   ('Db', 'E:min/b3', 'N'),
#   ('A', 'B:hdim7/b7', 'E:min/b3'),
#   ('A:dim7', 'B:hdim7/b7', 'C#'),
#   ('A', 'B:hdim7/b7', 'F:7'),
#   ('C', 'Eb/3', 'F'),
#   ('A', 'A:min/b3', 'D/5'),
#   ('A:7', 'B:hdim7/b7', 'Eb/3'),
#   ('A:7', 'D/5', 'F:min'),
#   ('Eb:7/b7', 'G', 'N'),
#   ('Ab:maj(2)/2', 'B:min', 'G'),
#   ('A:7', 'A:aug', 'B:hdim7/b7'),
#   ('A:7', 'A:dim7', 'D/3'),
#   ('E', 'G', 'G#:aug'),
#   ('A:7', 'A:dim7', 'G'),
#   ('Ab:7', 'Bb', 'F:7'),
#   ('B:min', 'Eb:7/b7', 'G'),
#   ...},
#  '111D': {('A', 'A:aug', 'D'),
#   ('A', 'A:min', 'D'),
#   ('A', 'A:min/b3', 'D'),
#   ('A', 'A:min7', 'D'),
#   ('A', 'B:hdim7/b7', 'E'),
#   ('A', 'B:hdim7/b7', 'G#:dim7'),
#   ('A', 'B:hdim7/b7', 'G:(1,5)'),
#   ('A', 'B:min', 'G'),
#   ('A', 'C', 'D/5'),
#   ('A', 'C', 'G'),
#   ('A', 'D', 'G#:dim7'),
#   ('A', 'D', 'G:(1,5)'),
#   ('A', 'D/5', 'E'),
#   ('A', 'D/5', 'G#:dim7'),
#   ('A', 'D/5', 'G:(1,5)'),
#   ('A', 'D:7', 'N'),
#   ('A', 'Eb', 'N'),
#   ('A', 'F:maj7', 'N'),
#   ('A', 'G', 'G:maj(*1)/5'),
#   ('A', 'G#:dim7', 'N'),
#   ('A:(1)', 'D', 'N'),
#   ('A:(1)', 'D:7', 'N'),
#   ('A:(1)', 'E', 'N'),
#   ('A:(1)', 'Eb', 'N'),
#   ('A:(1)', 'F:maj7', 'N'),
#   ('A:7', 'A:aug', 'D'),
#   ('A:7', 'A:dim7', 'E:7'),
#   ('A:7', 'A:dim7', 'G/2'),
#   ('A:7', 'A:min', 'D'),
#   ('A:7', 'A:min/b3', 'D'),
#   ('A:7', 'A:min7', 'D'),
#   ('A:7', 'B', 'E'),
#   ('A:7', 'B:hdim7/b7', 'E:7'),
#   ('A:7', 'B:hdim7/b7', 'G/2'),
#   ('A:7', 'C', 'D/5'),
#   ('A:7', 'D', 'E:7'),
#   ('A:7', 'D', 'G/2'),
#   ('A:7', 'D/5', 'E:7'),
#   ('A:7', 'D:7', 'N'),
#   ('A:7', 'E', 'G'),
#   ('A:7', 'E:7', 'N'),
#   ('A:7', 'Eb', 'N'),
#   ('A:7', 'F:maj7', 'N'),
#   ('A:7', 'G/2', 'N'),
#   ('A:aug', 'D', 'G:7'),
#   ('A:min', 'D', 'G:7'),
#   ('A:min/b3', 'D', 'G'),
#   ('A:min/b3', 'D', 'G:7'),
#   ('A:min/b7', 'C', 'F'),
#   ('A:min7', 'B', 'E'),
#   ('A:min7', 'D', 'G'),
#   ('A:min7', 'D', 'G:7'),
#   ('A:min7', 'D/5', 'D:min7'),
#   ('A:min7', 'D:min7', 'F:maj7'),
#   ('A:min7', 'D:min7', 'G/3'),
#   ('A:min7', 'E', 'G'),
#   ('Ab:7', 'Db', 'N'),
#   ('Ab:maj6', 'Db', 'N'),
#   ('B', 'B:(b3,5)', 'E'),
#   ('B', 'B:(b3,5)', 'F#'),
#   ('B', 'B:(b3,5)', 'F#:aug'),
#   ('B', 'D', 'E'),
#   ('B', 'D:min/b3', 'E'),
#   ('B:min', 'C/5', 'G'),
#   ('B:min', 'D/3', 'G'),
#   ('B:min', 'F#:min', 'G'),
#   ('Bb', 'C', 'D'),
#   ('Bb', 'C', 'F:maj6'),
#   ('Bb', 'C', 'F:maj6/5'),
#   ('Bb', 'C', 'F:min'),
#   ('Bb', 'C', 'F:min7'),
#   ('Bb', 'D', 'N'),
#   ('Bb', 'D:7', 'N'),
#   ('Bb', 'E', 'N'),
#   ('Bb', 'F:7', 'F:min'),
#   ('Bb', 'F:7', 'F:min7'),
#   ('Bb', 'F:maj7', 'N'),
#   ('Bb', 'F:min', 'N'),
#   ('Bb', 'F:min7', 'N'),
#   ('C', 'C/5', 'G'),
#   ('C', 'D', 'F'),
#   ('C', 'D/3', 'G'),
#   ('C', 'D:7', 'N'),
#   ('C', 'E', 'N'),
#   ('C', 'E:min/b3', 'F'),
#   ('C', 'Eb', 'N'),
#   ('C', 'F', 'F:maj6'),
#   ('C', 'F', 'F:maj6/5'),
#   ('C', 'F:maj6', 'G'),
#   ('C', 'F:maj6', 'N'),
#   ('C', 'F:maj6/5', 'G'),
#   ('C', 'F:maj6/5', 'N'),
#   ('C', 'F:maj7', 'N'),
#   ('C/5', 'D', 'G'),
#   ('C/5', 'E', 'G'),
#   ('C/5', 'G', 'G:maj(*1)/5'),
#   ('C/5', 'G', 'N'),
#   ('D', 'D/5', 'G'),
#   ('D', 'D/5', 'G:7'),
#   ('D', 'Db', 'N'),
#   ('D/3', 'E', 'G'),
#   ('D/3', 'G', 'G:maj(*1)/5'),
#   ('D/3', 'G', 'N'),
#   ('D:7', 'Db', 'N'),
#   ('D:7', 'G', 'N'),
#   ('D:min/b3', 'E', 'G'),
#   ('Db', 'E', 'N'),
#   ('Db', 'Eb', 'N'),
#   ('Db', 'F:maj7', 'N'),
#   ('Db', 'Gb', 'N'),
#   ('Db', 'Gb:min', 'N'),
#   ('E', 'F#', 'G'),
#   ('Eb', 'G', 'N'),
#   ('F:maj7', 'G', 'N')},
#  '111U': {('A', 'A:dim7', 'D'),
#   ('A', 'A:dim7', 'D/5'),
#   ('A', 'A:dim7', 'N'),
#   ('A', 'A:min', 'N'),
#   ('A', 'A:min7', 'D/5'),
#   ('A', 'B', 'E'),
#   ('A', 'B:(b3,5)', 'N'),
#   ('A', 'B:hdim7/b7', 'F#:min'),
#   ('A', 'B:hdim7/b7', 'G'),
#   ('A', 'B:hdim7/b7', 'G/2'),
#   ('A', 'B:hdim7/b7', 'G:7'),
#   ('A', 'C', 'D'),
#   ('A', 'C:min', 'N'),
#   ('A', 'D', 'D/3'),
#   ('A', 'D', 'D:7'),
#   ('A', 'D', 'F#:min'),
#   ('A', 'D', 'G/2'),
#   ('A', 'D', 'G:7/3'),
#   ('A', 'D/5', 'F#:min'),
#   ('A', 'D/5', 'G'),
#   ('A', 'D/5', 'G:7'),
#   ('A', 'F#:min', 'N'),
#   ('A', 'F:7', 'N'),
#   ('A', 'G/2', 'N'),
#   ('A', 'G:7', 'N'),
#   ('A', 'G:maj(*1)/5', 'N'),
#   ('A:(1)', 'A:min', 'N'),
#   ('A:(1)', 'B:(b3,5)', 'N'),
#   ('A:(1)', 'C:min', 'N'),
#   ('A:(1)', 'F:7', 'N'),
#   ('A:(1)', 'G:(1,5)', 'N'),
#   ('A:(1)', 'G:maj(*1)/5', 'N'),
#   ('A:7', 'A:dim7', 'E'),
#   ('A:7', 'A:min', 'N'),
#   ('A:7', 'A:min7', 'D/5'),
#   ('A:7', 'B:(b3,5)', 'N'),
#   ('A:7', 'B:hdim7/b7', 'E'),
#   ('A:7', 'C', 'D'),
#   ('A:7', 'C:min', 'N'),
#   ('A:7', 'D', 'D/3'),
#   ('A:7', 'D', 'D:7'),
#   ('A:7', 'D', 'G:7/3'),
#   ('A:7', 'D/5', 'E'),
#   ('A:7', 'F:7', 'N'),
#   ('A:7', 'G:(1,5)', 'N'),
#   ('A:7', 'G:maj(*1)/5', 'N'),
#   ('A:aug', 'B:min', 'G'),
#   ('A:aug', 'C', 'G'),
#   ('A:aug', 'E', 'G'),
#   ('A:aug', 'G', 'G:maj(*1)/5'),
#   ('A:aug', 'G', 'N'),
#   ('A:min', 'B', 'E'),
#   ('A:min', 'B:min', 'G'),
#   ('A:min', 'Bb', 'C'),
#   ('A:min', 'Bb', 'N'),
#   ('A:min', 'Db', 'N'),
#   ('A:min', 'G', 'G:maj(*1)/5'),
#   ('A:min7', 'C/5', 'D:min7'),
#   ('A:min7', 'D', 'D:min7'),
#   ('A:min7', 'D:min7', 'E'),
#   ('Ab', 'Db', 'N'),
#   ('B', 'C#', 'E'),
#   ('B', 'E', 'F#:hdim7/b7'),
#   ('B', 'E', 'N'),
#   ('B:(b3,5)', 'Bb', 'N'),
#   ('B:(b3,5)', 'C', 'N'),
#   ('B:(b3,5)', 'Db', 'N'),
#   ('B:(b3,5)', 'G', 'N'),
#   ('B:min', 'E:7', 'G'),
#   ('B:min', 'F', 'G'),
#   ('B:min', 'G', 'G#:dim7'),
#   ('Bb', 'C', 'C/7'),
#   ('Bb', 'C', 'C:min'),
#   ('Bb', 'C', 'D/5'),
#   ('Bb', 'C', 'D:min'),
#   ('Bb', 'C', 'Eb'),
#   ('Bb', 'C', 'Eb/5'),
#   ('Bb', 'C', 'Eb:7'),
#   ('Bb', 'C', 'G/3'),
#   ('Bb', 'C:min', 'F:7'),
#   ('Bb', 'D:min', 'F:7'),
#   ('Bb', 'D:min', 'N'),
#   ('Bb', 'Eb', 'F:7'),
#   ('Bb', 'Eb/5', 'F:7'),
#   ('Bb', 'Eb/5', 'N'),
#   ('Bb', 'Eb:7', 'F:7'),
#   ('Bb', 'Eb:7', 'N'),
#   ('Bb', 'G:(1,5)', 'N'),
#   ('Bb', 'G:maj(*1)/5', 'N'),
#   ('Bb:min', 'Db', 'N'),
#   ('C', 'C/7', 'F'),
#   ('C', 'C/7', 'G'),
#   ('C', 'C/7', 'N'),
#   ('C', 'C:min', 'N'),
#   ('C', 'D', 'G:7'),
#   ('C', 'D/5', 'F'),
#   ('C', 'D/5', 'G'),
#   ('C', 'D/5', 'N'),
#   ('C', 'E:7', 'G'),
#   ('C', 'F', 'G/3'),
#   ('C', 'F:7', 'N'),
#   ('C', 'G', 'G#:dim7'),
#   ('C', 'G', 'G/3'),
#   ('C', 'G/3', 'N'),
#   ('C', 'G:(1,5)', 'N'),
#   ('C', 'G:maj(*1)/5', 'N'),
#   ('C:min', 'Db', 'N'),
#   ('C:min', 'G', 'N'),
#   ('D', 'D/3', 'G:7'),
#   ('D', 'D:7', 'G'),
#   ('D', 'D:7', 'G:7'),
#   ('D', 'E', 'G:7'),
#   ('D', 'E:7', 'G'),
#   ('D', 'F', 'G'),
#   ('D', 'G', 'G#:dim7'),
#   ('D', 'G', 'G:7/3'),
#   ('D', 'G:7', 'G:7/3'),
#   ('D', 'G:7', 'N'),
#   ('Db', 'Db:maj7', 'N'),
#   ('Db', 'F:7', 'N'),
#   ('Db', 'G:(1,5)', 'N'),
#   ('Db', 'G:maj(*1)/5', 'N'),
#   ('E', 'E:7', 'G'),
#   ('E', 'F', 'G'),
#   ('E', 'F#:hdim7/b7', 'G'),
#   ('E', 'G', 'G#:dim7'),
#   ('E:7', 'G', 'G:maj(*1)/5'),
#   ('E:7', 'G', 'N'),
#   ('F', 'G', 'G:maj(*1)/5'),
#   ('F', 'G', 'N'),
#   ('F:7', 'G', 'N'),
#   ('G', 'G#:dim7', 'G:maj(*1)/5'),
#   ('G', 'G#:dim7', 'N'),
#   ('G', 'G:(1,5)', 'N')},
#  '120C': {('A', 'D', 'E'),
#   ('A', 'D/5', 'G/2'),
#   ('A', 'E', 'G'),
#   ('A', 'G:(1,5)', 'N'),
#   ('A:7', 'E', 'N'),
#   ('A:aug', 'D', 'G'),
#   ('A:min', 'C', 'F'),
#   ('A:min', 'D', 'G'),
#   ('B', 'C#', 'F#'),
#   ('B', 'C#', 'F#:aug'),
#   ('Bb', 'Eb', 'N'),
#   ('D', 'D/3', 'G')},
#  '120D': {('A', 'A:7', 'A:dim7'),
#   ('A', 'E', 'N'),
#   ('A:7', 'D/5', 'G/2'),
#   ('C', 'D', 'N')},
#  '120U': {('A:7', 'D', 'E'),
#   ('A:min', 'C', 'G'),
#   ('A:min', 'C', 'N'),
#   ('A:min', 'E', 'G'),
#   ('A:min', 'G', 'N'),
#   ('Bb', 'C:min', 'N')},
#  '201': {('A', 'A:(1)', 'N'),
#   ('A', 'B:hdim7/b7', 'D'),
#   ('A', 'B:hdim7/b7', 'D/5'),
#   ('A', 'B:hdim7/b7', 'N'),
#   ('A', 'Bb', 'N'),
#   ('A', 'C', 'N'),
#   ('A', 'D/5', 'N'),
#   ('A', 'Db', 'N'),
#   ('A:(1)', 'A:7', 'N'),
#   ('A:(1)', 'Bb', 'N'),
#   ('A:(1)', 'C', 'N'),
#   ('A:(1)', 'Db', 'N'),
#   ('A:(1)', 'G', 'N'),
#   ('A:7', 'A:dim7', 'D'),
#   ('A:7', 'A:dim7', 'D/5'),
#   ('A:7', 'A:dim7', 'N'),
#   ('A:7', 'B:hdim7/b7', 'D'),
#   ('A:7', 'B:hdim7/b7', 'D/5'),
#   ('A:7', 'B:hdim7/b7', 'N'),
#   ('A:7', 'Bb', 'N'),
#   ('A:7', 'C', 'N'),
#   ('A:7', 'D', 'G'),
#   ('A:7', 'D', 'G:7'),
#   ('A:7', 'D/5', 'N'),
#   ('A:7', 'Db', 'N'),
#   ('A:7', 'G', 'N'),
#   ('B', 'E', 'F#:aug'),
#   ('B', 'E', 'G'),
#   ('B:min', 'C', 'G'),
#   ('B:min', 'D', 'G'),
#   ('B:min', 'E', 'G'),
#   ('B:min', 'G', 'G:maj(*1)/5'),
#   ('B:min', 'G', 'N'),
#   ('Bb', 'C', 'F'),
#   ('Bb', 'C', 'F:7'),
#   ('Bb', 'C', 'G'),
#   ('Bb', 'Db', 'N'),
#   ('Bb', 'G', 'N'),
#   ('C', 'Db', 'N'),
#   ('C', 'E', 'G'),
#   ('C', 'F', 'N'),
#   ('C', 'G', 'G:maj(*1)/5'),
#   ('D', 'G', 'G:7'),
#   ('D', 'G', 'G:maj(*1)/5'),
#   ('Db', 'G', 'N'),
#   ('E', 'G', 'G:maj(*1)/5')},
#  '210': {('A', 'A:7', 'B:hdim7/b7'),
#   ('A', 'A:7', 'D'),
#   ('A', 'A:7', 'D/5'),
#   ('A', 'A:7', 'N'),
#   ('A', 'A:dim7', 'B:hdim7/b7'),
#   ('A', 'D', 'D/5'),
#   ('A', 'D', 'G'),
#   ('A', 'D', 'G:7'),
#   ('A', 'D', 'N'),
#   ('A', 'G', 'N'),
#   ('A:7', 'D', 'D/5'),
#   ('A:7', 'D', 'N'),
#   ('B', 'E', 'F#'),
#   ('B', 'F#', 'F#:aug'),
#   ('Bb', 'F:7', 'N'),
#   ('C', 'D', 'G'),
#   ('C', 'F', 'G'),
#   ('D', 'E', 'G'),
#   ('D', 'G', 'N'),
#   ('E', 'G', 'N'),
#   ('G', 'G:maj(*1)/5', 'N')},
#  '300': {('A:7', 'A:dim7', 'B:hdim7/b7'), ('Bb', 'C', 'N'), ('C', 'G', 'N')}}

# %%
from collections import Counter
counter=Counter(new)
print(counter)
# Out:
# Counter({('F:maj6', 'C/7', 'D/3'): 1, ('Gb', 'E:7', 'Eb'): 1, ('Gb:min', 'F#', 'G:7'): 1, ('N', 'C/5', 'Bb:min'): 1, ('E:7', 'D:min/b3', 'D:7'): 1, ('G/3', 'F#:hdim7/b7', 'Eb/5'): 1, ('G', 'C/7', 'B'): 1, ('D:min7', 'Eb:7', 'Eb/3'): 1, ('G:min', 'F#:min', 'A:min/b7'): 1, ('F#:hdim7/b7', 'A:dim7', 'Eb:7/b7'): 1, ('G:maj(*1)/5', 'F#:min', 'B'): 1, ('D', 'G#:aug', 'Eb'): 1, ('Ab:maj6', 'Eb/5', 'G:(1,5)'): 1, ('E:7', 'C:min', 'F:min7'): 1, ('Eb:min7', 'A:(1)', 'D:7'): 1, ('C', 'Gb', 'F#'): 1, ('A', 'E:min/b3', 'B'): 1, ('A:min', 'F:min7', 'Eb:7'): 1, ('Ab', 'F:min7', 'D:7'): 1, ('D:min', 'D/3', 'Eb:7'): 1, ('F#:hdim7/b7', 'A:min/b7', 'F#:aug'): 1, ('Bb', 'Eb:min7', 'D:min7'): 1, ('G:maj(*1)/5', 'Ab', 'F:7'): 1, ('Bb:min', 'A:7', 'Eb/3'): 1, ('A:min/b7', 'F', 'D/3'): 1, ('D:min7', 'A:dim7', 'F:min7'): 1, ('G/3', 'F#:hdim7/b7', 'F#:hdim7'): 1, ('D:min', 'B:min', 'Eb:7'): 1, ('E:7', 'C:min', 'G:(1,5)'): 1, ('A:min', 'Bb:min', 'Ab:maj(2)/2'): 1, ('G:maj(*1)/5', 'D/5', 'Ab/5'): 1, ('Db', 'F', 'C:min'): 1, ('Db', 'Ab', 'G:7'): 1, ('Bb', 'Gb', 'D/3'): 1, ('D', 'D:min7', 'Eb:7/b7'): 1, ('A:min7', 'G#:aug', 'G#:dim7'): 1, ('G:maj(*1)/5', 'C/5', 'A:dim7'): 1, ('D:min/b3', 'F', 'F:min7'): 1, ('Eb:min7', 'G#:aug', 'C#'): 1, ('D:min/b3', 'G#:aug', 'Eb:7/b7'): 1, ('B:min', 'B:hdim7/b7', 'F#:aug'): 1, ('E', 'Gb:min', 'B:hdim7/b7'): 1, ('B:hdim7/b7', 'Eb', 'Ab/5'): 1, ('Gb:min', 'C/7', 'G/2'): 1, ('G#:dim7', 'B:hdim7/b7', 'F#:aug'): 1, ('N', 'A:min/b3', 'A:(1)'): 1, ('G', 'F:maj7', 'Ab/5'): 1, ('G/3', 'D:min/b3', 'A:dim7'): 1, ('F#:min', 'E', 'F:min'): 1, ('Db:maj7', 'D:min/b3', 'Eb/5'): 1, ('N', 'B:min', 'Ab:7'): 1, ('A:min7', 'D:min7', 'C:min'): 1, ('Bb:min', 'Ab', 'A:(1)'): 1, ('Gb', 'A:min/b3', 'G:7/3'): 1, ('G:maj(*1)/5', 'F:maj6', 'G:7/3'): 1, ('C/5', 'Eb:min7', 'Ab/5'): 1, ('A:min7', 'F:maj6/5', 'Ab:maj(2)/2'): 1, ('A:min/b3', 'F#:aug', 'Ab/5'): 1, ('F:min', 'Ab:7', 'G:7/3'): 1, ('N', 'C', 'B:hdim7/b7'): 1, ('Ab:7', 'F:maj6', 'A:aug'): 1, ('B:min', 'F:maj6/5', 'G#:dim7'): 1, ('G:maj(*1)/5', 'F:maj6/5', 'F#:aug'): 1, ('G', 'G#:aug', 'F:maj6/5'): 1, ('G/3', 'F:7', 'Ab:maj(2)/2'): 1, ('Bb:min', 'F:7', 'B:hdim7/b7'): 1, ('D:min/b3', 'C#', 'F:min7'): 1, ('C', 'B:hdim7/b7', 'Ab/5'): 1, ('Ab:maj6', 'Gb', 'Ab:maj(2)/2'): 1, ('A:min', 'Db', 'Ab'): 1, ('Gb', 'A:dim7', 'A:aug'): 1, ('D:min7', 'Ab:maj(2)/2', 'Eb'): 1, ('G/3', 'F#:hdim7/b7', 'A:dim7'): 1, ('G/3', 'Bb', 'D:min'): 1, ('G#:aug', 'F#', 'C#'): 1, ('Eb:min7', 'G:(1,5)', 'D:7'): 1, ('A:min/b3', 'E:min/b3', 'A:(1)'): 1, ('A:min7', 'D:min/b3', 'G#:dim7'): 1, ('G#:aug', 'F#', 'Eb/5'): 1, ('Db', 'F:min', 'D/5'): 1, ('Ab:maj6', 'Ab:7', 'B:hdim7/b7'): 1, ('Ab:7', 'C:min', 'Eb/5'): 1, ('N', 'F#:min', 'D:min7'): 1, ('Eb/5', 'G/2', 'D:7'): 1, ('G/3', 'D:min7', 'D:7'): 1, ('G/3', 'Ab', 'Gb'): 1, ('A:min/b3', 'F:maj6/5', 'Ab:maj(2)/2'): 1, ('E:7', 'D/5', 'Eb'): 1, ('G/3', 'B:hdim7/b7', 'Ab:maj(2)/2'): 1, ('Bb', 'D:min', 'A:min'): 1, ('D:min7', 'C/7', 'D/3'): 1, ('N', 'A:min7', 'A'): 1, ('F#:hdim7/b7', 'F#:hdim7', 'F:min7'): 1, ('F:maj7', 'A:7', 'Eb'): 1, ('Eb:min7', 'D:min7', 'D:7'): 1, ('E', 'G#:aug', 'A:min/b7'): 1, ('G:min', 'F:min', 'G#:aug'): 1, ('C/5', 'F:min', 'Ab/5'): 1, ('B:min', 'F#:hdim7/b7', 'D:min7'): 1, ('G#:aug', 'F#:hdim7', 'A:7'): 1, ('Db:maj7', 'D/5', 'Ab:maj(2)/2'): 1, ('C', 'F:maj6/5', 'F#'): 1, ('A:min', 'D/3', 'B:hdim7/b7'): 1, ('B:min', 'Ab', 'F'): 1, ('F:min', 'Eb:min7', 'F:maj7'): 1, ('C/5', 'Db', 'F:min7'): 1, ('A:min7', 'Gb', 'G:(1,5)'): 1, ('G/3', 'B:(b3,5)', 'C#'): 1, ('F#:aug', 'Eb', 'F:min7'): 1, ('Eb:min7', 'Ab', 'F'): 1, ('B:min', 'F#:aug', 'C:min'): 1, ('Ab:7', 'F:maj6', 'F#:aug'): 1, ('G/3', 'F#:min', 'G:7'): 1, ('G:maj(*1)/5', 'D:min7', 'E:min/b3'): 1, ('G', 'C/7', 'B:hdim7/b7'): 1, ('Db:maj7', 'F:maj7', 'F'): 1, ('G:maj(*1)/5', 'Ab:7', 'B:hdim7/b7'): 1, ('F#:hdim7/b7', 'B:hdim7/b7', 'Ab:maj(2)/2'): 1, ('G:maj(*1)/5', 'Bb:min', 'G#:dim7'): 1, ('Db:maj7', 'Ab:maj6', 'A:aug'): 1, ('G', 'F:min7', 'A:(1)'): 1, ('Bb:min', 'B', 'Eb:7'): 1, ('F#:min', 'A:min/b7', 'Ab:maj(2)/ ...
