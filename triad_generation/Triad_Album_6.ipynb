# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
album06 = pd.read_csv('album_06_edges.csv')
G = nx.from_pandas_edgelist(album06, source="Source", target="Target", create_using=nx.DiGraph())
nx.draw(G, with_labels=True)

# %% [markdown]
# ## Visuals

# %%
nx.draw(G,node_size=300,font_size=8,  with_labels=True)

# %%
plt.figure(3,figsize=(12,12)) 
nx.draw(G, node_size=400,font_size=12,  with_labels=True)

# %% [markdown]
# ## Triads

# %%
# Triad Consensus
nx.triadic_census(G)
# Out:
# {'003': 39159,
#  '012': 6038,
#  '021C': 254,
#  '021D': 117,
#  '021U': 88,
#  '030C': 9,
#  '030T': 10,
#  '102': 1728,
#  '111D': 173,
#  '111U': 191,
#  '120C': 20,
#  '120D': 5,
#  '120U': 11,
#  '201': 68,
#  '210': 26,
#  '300': 8}

# %%
import networkx as nx
import itertools


def _tricode(G, v, u, w):
    """Returns the integer code of the given triad.

    This is some fancy magic that comes from Batagelj and Mrvar's paper. It
    treats each edge joining a pair of `v`, `u`, and `w` as a bit in
    the binary representation of an integer.

    """
    combos = ((v, u, 1), (u, v, 2), (v, w, 4), (w, v, 8), (u, w, 16),
              (w, u, 32))
    return sum(x for u, v, x in combos if v in G[u])


# G = nx.DiGraph()
# G.add_nodes_from([1, 2, 3, 4, 5])
# G.add_edges_from([(1, 2), (2, 3), (2, 4), (4, 5)])

#: The integer codes representing each type of triad.
#: Triads that are the same up to symmetry have the same code.
TRICODES = (1, 2, 2, 3, 2, 4, 6, 8, 2, 6, 5, 7, 3, 8, 7, 11, 2, 6, 4, 8, 5, 9,
            9, 13, 6, 10, 9, 14, 7, 14, 12, 15, 2, 5, 6, 7, 6, 9, 10, 14, 4, 9,
            9, 12, 8, 13, 14, 15, 3, 7, 8, 11, 7, 12, 14, 15, 8, 14, 13, 15,
            11, 15, 15, 16)

#: The names of each type of triad. The order of the elements is
#: important: it corresponds to the tricodes given in :data:`TRICODES`.
TRIAD_NAMES = ('003', '012', '102', '021D', '021U', '021C', '111D', '111U',
               '030T', '030C', '201', '120D', '120U', '120C', '210', '300')

#: A dictionary mapping triad code to triad name.
TRICODE_TO_NAME = {i: TRIAD_NAMES[code - 1] for i, code in enumerate(TRICODES)}

triad_nodes = {name: set([]) for name in TRIAD_NAMES}
m = {v: i for i, v in enumerate(G)}
for v in G:
    vnbrs = set(G.pred[v]) | set(G.succ[v])
    for u in vnbrs:
        if m[u] > m[v]:
            unbrs = set(G.pred[u]) | set(G.succ[u])
            neighbors = (vnbrs | unbrs) - {u, v}
            not_neighbors = set(G.nodes()) - neighbors - {u, v}
            # Find dyadic triads
            for w in not_neighbors:
                if v in G[u] and u in G[v]:
                    triad_nodes['102'].add(tuple(sorted([u, v, w])))
                else:
                    triad_nodes['012'].add(tuple(sorted([u, v, w])))
            for w in neighbors:
                if m[u] < m[w] or (m[v] < m[w] < m[u] and
                                   v not in G.pred[w] and
                                   v not in G.succ[w]):
                    code = _tricode(G, v, u, w)
                    triad_nodes[TRICODE_TO_NAME[code]].add(
                        tuple(sorted([u, v, w])))
# find null triads
all_tuples = set()
for s in triad_nodes.values():
    all_tuples = all_tuples.union(s)
new = triad_nodes['003'] = set(itertools.combinations(G.nodes(), 3)).difference(all_tuples)

triad_nodes
# Out:
# {'003': {('E:7', 'G#', 'C:7'),
#   ('Bb:min7', 'G:min/5', 'C#'),
#   ('D:7(#9)', 'B:sus4', 'C#:7'),
#   ('F:maj6', 'C#:maj7/3', 'G:min/5'),
#   ('E:7', 'A', 'E:sus4(b7)'),
#   ('A:min(*5)', 'Eb:sus4', 'C#:sus4'),
#   ('E:min', 'C', 'C:min'),
#   ('B:7', 'C#/3', 'B/5'),
#   ('E:7', 'B', 'Ab:7'),
#   ('D:dim7', 'A:min', 'G#:min'),
#   ('F:min6/5', 'Ab:7', 'C#'),
#   ('E', 'Eb/5', 'F:min'),
#   ('A:min', 'G:min/5', 'F#'),
#   ('G', 'E:7', 'E:min/b3'),
#   ('Ab:7', 'B:min/5', 'C#'),
#   ('E:sus4(b7)', 'Eb', 'C#'),
#   ('A:7(#9)', 'G#', 'F#:min7'),
#   ('N', 'D', 'G:maj/9'),
#   ('G:7', 'Eb', 'Bb:min'),
#   ('Bb:min', 'C#:sus4', 'G:maj/9'),
#   ('N', 'Bb', 'C#/3'),
#   ('A:min(*5)', 'F:min/5', 'B:maj(*3)'),
#   ('E:min', 'B:hdim7/b3', 'F'),
#   ('G:7', 'A:sus4', 'F:min'),
#   ('F#:min', 'B:7', 'Ab:7'),
#   ('G#', 'F:min/5', 'F:min7'),
#   ('F:maj6', 'F:min6/5', 'Bb:min/5'),
#   ('G', 'A:7(#9)', 'A:7'),
#   ('B:min', 'Eb/5', 'Ab'),
#   ('Bb:min/5', 'B/5', 'C#'),
#   ('G', 'A:7', 'D:dim7'),
#   ('E', 'B:dim7', 'B:sus4'),
#   ('D:7(#9)', 'C:maj(9)', 'C#:sus4'),
#   ('C', 'C:maj(9)', 'Bb:min/5'),
#   ('E:7', 'A', 'F#:min7'),
#   ('B:hdim7/b3', 'A:min', 'B:min/5'),
#   ('A', 'F#:min', 'C#/3'),
#   ('G:sus4', 'C#:maj7/3', 'G:min/5'),
#   ('F#:min', 'Eb', 'D:maj7'),
#   ('G#:min', 'F', 'Bb:min7'),
#   ('A:7', 'Eb', 'B/5'),
#   ('D:dim7', 'C:7', 'F:min7'),
#   ('B:hdim7/b3', 'B/5', 'E:min/b3'),
#   ('G', 'C:min', 'Bb:min'),
#   ('N', 'A:sus4', 'C#:sus4'),
#   ('F#:min', 'F:min6/5', 'D:maj7'),
#   ('D', 'A:min', 'F:min7'),
#   ('A:min7(*5,b6)', 'A:sus4', 'C#'),
#   ('E:7', 'D:7(#9)', 'G:maj/9'),
#   ('A:min(*5)', 'Bb', 'E:min/b3'),
#   ('A:min', 'D:7(#9)', 'C#:maj7/3'),
#   ('D:dim7', 'F:min6/5', 'C:min'),
#   ('A:7', 'F:min7', 'B:sus4'),
#   ('A:7(#9)', 'E:min', 'B:dim7'),
#   ('B:dim7', 'Db', 'Ab/5'),
#   ('D', 'A', 'F:min7'),
#   ('B:min', 'D:dim7', 'Ab/5'),
#   ('F#:min', 'D:dim7', 'Eb:maj6'),
#   ('N', 'B:dim7', 'Eb'),
#   ('G#', 'Bb:min/5', 'G:maj/9'),
#   ('D:dim7', 'Ab', 'G:maj/9'),
#   ('D', 'F#:min', 'C:min'),
#   ('B', 'C:maj(9)', 'G:min/5'),
#   ('F:min', 'Eb:sus4', 'B:min/5'),
#   ('C#:maj7/3', 'C#/3', 'D:maj7'),
#   ('G:sus4', 'C#/3', 'B:sus4'),
#   ('E:aug', 'F:min', 'B/5'),
#   ('A', 'Bb:min7', 'F#:min7'),
#   ('N', 'G', 'F:min'),
#   ('Eb/5', 'F:min7', 'Eb'),
#   ('Eb/5', 'F#:min7', 'E:min/b3'),
#   ('A:sus4', 'C#:sus4', 'F#'),
#   ('A:min', 'A:sus4', 'G:min/5'),
#   ('C:maj(9)', 'F:min7', 'F:min'),
#   ('A:7', 'F:maj6', 'Ab'),
#   ('E:7', 'A:min(*5)', 'Db'),
#   ('E:7', 'F:maj6', 'F:min'),
#   ('G#:min', 'G:min/5', 'Bb:min'),
#   ('E:sus4(b7)', 'G#:min', 'C#'),
#   ('E:7', 'F#:min', 'B:sus4'),
#   ('G:7', 'B', 'B:dim7'),
#   ('A:sus4', 'C#/3', 'E:min/b3'),
#   ('C#:maj7/3', 'C#', 'E:min/b3'),
#   ('C:7', 'E:aug', 'F#:min7'),
#   ('F', 'C#', 'E:min/b3'),
#   ('B:min', 'B:7', 'C:7'),
#   ('C:maj(9)', 'Ab:7', 'E:min/b3'),
#   ('A:min7(*5,b6)', 'F#:min', 'G:maj/9'),
#   ('A', 'D:7(#9)', 'B:min/5'),
#   ('A:7(#9)', 'F:min6/5', 'C:min'),
#   ('G:min/5', 'Eb:sus4', 'C#:sus4'),
#   ('D:min', 'G#:min', 'Ab'),
#   ('Bb', 'F#', 'D:maj6'),
#   ('E:7', 'G:min/5', 'G:maj/9'),
#   ('A:7', 'F', 'G:maj/9'),
#   ('F#:min', 'G:min/5', 'Ab'),
#   ('A:7', 'Eb/5', 'G:sus4'),
#   ('A:min(*5)', 'E', 'D:maj7'),
#   ('E', 'F', 'C#:maj7/3'),
#   ('D:min', 'B:7', 'Eb:maj6'),
#   ('E:sus4(b7)', 'C#/3', 'G:min/5'),
#   ('B:min', 'E:sus4(b7)', 'D:maj6'),
#   ('D:dim7', 'F:maj6', 'F:min/5'),
#   ('E:min', 'A:7', 'Eb:maj6'),
#   ('B:7', 'G#:min', 'F#'),
#   ('G#', 'Ab:7', 'C#:sus4'),
#   ('A:min7(*5,b6)', 'B:min/5', 'B:maj(*3)'),
#   ('E:7', 'E', 'B:7'),
#   ('N', 'F:maj6', 'C#:sus4'),
#   ('D', 'E:aug', 'Ab/5'),
#   ('F#:min', 'Ab:7', 'Db'),
#   ('C:maj(9)', 'B:sus4', 'F#:min7'),
#   ('B:hdim7/b3', 'F:min6/5', 'Eb:sus4'),
#   ('A:7', 'A:maj6', 'C#/3'),
#   ('F:maj6', 'Bb:min7', 'E:min/b3'),
#   ('A:min7(*5,b6)', 'A:maj6', 'D:maj7'),
#   ('Bb:min', 'Eb:sus4', 'C#:7'),
#   ('B:min', 'G:min/5', 'D:maj7'),
#   ('A:maj6', 'Bb:min', 'D:maj7'),
#   ('N', 'E:7', 'G:maj/9'),
#   ('D:dim7', 'F', 'Ab:7'),
#   ('D:min', 'Eb', 'D:maj7'),
#   ('B:7', 'Bb:min7', 'Eb:sus4'),
#   ('B', 'F:min6/5', 'C#:maj7/3'),
#   ('B:hdim7/b3', 'F:min7', 'Bb:min'),
#   ('D', 'A:maj6', 'G#'),
#   ('A', 'C', 'D:7(#9)'),
#   ('A', 'Bb', 'F#:min7'),
#   ('D', 'F', 'C:maj(9)'),
#   ('Bb:min/5', 'F#:min7', 'E:min/b3'),
#   ('C:7', 'B:dim7', 'F#'),
#   ('D', 'E:min', 'G:min/5'),
#   ('A:7(#9)', 'C:min', 'Ab'),
#   ('F:min7', 'G:min/5', 'F#'),
#   ('G:7', 'E:7', 'E:min'),
#   ('N', 'C#:maj7/3', 'C#'),
#   ('G', 'E:sus4(b7)', 'D:maj6'),
#   ('G:7', 'E:sus4(b7)', 'F#:min7'),
#   ('C#:maj7/3', 'G:min/5', 'C#:7'),
#   ('A:min(*5)', 'A:min', 'Ab/5'),
#   ('N', 'A:min', 'Bb'),
#   ('A:min(*5)', 'B/5', 'E:min/b3'),
#   ('C:maj(9)', 'C#', 'C#:7'),
#   ('G#:min', 'Eb/5', 'G:maj/9'),
#   ('A:min7(*5,b6)', 'E:min', 'G:min/5'),
#   ('E:sus4(b7)', 'F:min6/5', 'B/5'),
#   ('A:min', 'Eb', 'B:maj(*3)'),
#   ('Db', 'B/5', 'E:min/b3'),
#   ('A:min', 'B:dim7', 'Ab'),
#   ('B:hdim7/b3', 'F:maj6', 'E:aug'),
#   ('D:dim7', 'A:sus4', 'B:maj(*3)'),
#   ('C#/3', 'Ab', 'B:min/5'),
#   ('E:sus4(b7)', 'C#:sus4', 'G:maj/9'),
#   ('A', 'C:maj(9)', 'C#:sus4'),
#   ('G:sus4', 'F:min6/5', 'C:min'),
#   ('C#/3', 'Ab:7', 'Ab/5'),
#   ('B', 'D:dim7', 'C#'),
#   ('A:7(#9)', 'B', 'G:maj/9'),
#   ('A', 'G:sus4', 'C#:sus4'),
#   ('E', 'D:min', 'D:maj6'),
#   ('N', 'F#:min', 'B:7'),
#   ('A', 'A:7(#9)', 'F:min/5'),
#   ('A:maj6', 'G#', 'B:dim7'),
#   ('B:hdim7/b3', 'Bb:min', 'C#:7'),
#   ('D:dim7', 'C', 'Bb:min/5'),
#   ('A:min(*5)', 'Ab:7', 'Eb:sus4'),
#   ('C#/3', 'B:min/5', 'B:maj(*3)'),
#   ('G:7', 'Ab', 'G:maj/9'),
#   ('A:7', 'C#:maj7/3', 'B:dim7'),
#   ('Bb:min/5', 'C:min', 'Ab/5'),
#   ('N', 'A:7', 'D:dim7'),
#   ('G:7', 'G#', 'A:sus4'),
#   ('E:min', 'Bb:min', 'C#:7'),
#   ('E:min', 'A:sus4', 'Eb:maj6'),
#   ('C', 'C:7', 'F#'),
#   ('Eb', 'Ab', 'B/5'),
#   ('F:maj6', 'Eb:maj6', 'C#'),
#   ('F:min', 'Ab', 'C#:7'),
#   ('D:min', 'C', 'Eb:maj6'),
#   ('G#', 'D:7(#9)', 'E:min/b3'),
#   ('A', 'F:min', 'F#'),
#   ('F:maj6', 'Ab/5', 'C#:sus4'),
#   ('G:7', 'A:maj6', 'C:7'),
#   ('E', 'F:maj6', 'F#'),
#   ('E', 'C:7', 'Ab'),
#   ('E:sus4(b7)', 'Eb', 'E:min/b3'),
#   ('A:min(*5)', 'D:min', 'D:maj7'),
#   ('C', 'F:maj6', 'D:maj6'),
#   ('Eb:maj6', 'C#:7', 'G:maj/9'),
#   ('N', 'D:min', 'Eb/5'),
#   ('C#:maj7/3', 'Db', 'E:min/b3'),
#   ('Bb', 'Ab', 'F#:min7'),
#   ('G#', 'F:min/5', 'Db'),
#   ('F:maj6', 'C:min', 'F#:min7'),
#   ('B', 'G#', 'B:sus4'),
#   ('E:min', 'C#/3', 'E:min/b3'),
#   ('N', 'G#:min', 'A:sus4'),
#   ('N', 'C#:maj7/3', 'F#'),
#   ('F:min/5', 'G:min/5', 'C#:sus4'),
#   ('C#/3', 'Bb:min7', 'C#:sus4'),
#   ('A:7(#9)', 'A:7', 'E:sus4(b7)'),
#   ('G#:min', 'Db', 'F#'),
#   ('Eb:maj6', 'C:min', 'G:maj/9'),
#   ('D', 'A:min', 'C#:sus4'),
#   ('D', 'G:min/5', 'B/5'),
#   ('N', 'B:min', 'C:maj(9)'),
#   ('N', 'E:sus4(b7)', 'B:dim7'),
#   ('D', 'C', 'Db'),
#   ('D', 'E:sus4(b7)', 'Bb:min'),
#   ('G:7', 'G:min/5', 'Bb:min'),
#   ('E', 'B', 'C:7'),
#   ('B:dim7', 'Db', 'B:min/5'),
#   ('C', 'B:sus4', 'C#'),
#   ('A:min', 'F:min7', 'C#:7'),
#   ('G#', 'Bb', 'G:maj/9'),
#   ('D', 'A:min(*5)', 'B:min/5'),
#   ('E:sus4(b7)', 'Eb/5', 'Bb:min7'),
#   ('A:min7(*5,b6)', 'C:7', 'D:7(#9)'),
#   ('C:7', 'C#:sus4', 'E:min/b3'),
#   ('A:min7(*5,b6)', 'C', 'Bb:min/5'),
#   ('E:7', 'E:sus4(b7)', 'Ab/5'),
#   ('A:sus4', 'B:min/5', 'C#:7'),
#   ('E:sus4(b7)', 'B:7', 'B:dim7'),
#   ('G', 'E', 'E:aug'),
#   ('B:min', 'Ab:7', 'D:maj6'),
#   ('A:7', 'C#:maj7/3', 'D:maj6'),
#   ('A:maj6', 'Bb', 'Eb:sus4'),
#   ('A', 'F:min6/5', 'B:maj(*3)'),
#   ('F:maj6', 'Eb', 'Ab/5'),
#   ('A:7', 'A:sus4', 'Ab:7'),
#   ('G', 'F:min7', 'C#:7'),
#   ('D:min', 'D:maj7', 'C#:sus4'),
#   ('F:min7', 'C#:maj7/3', 'Ab:7'),
#   ('D', 'C#:maj7/3', 'Bb:min/5'),
#   ('E:min', 'E:aug', 'C#:sus4'),
#   ('A', 'C:7', 'F:min/5'),
#   ('B:min', 'A:min', 'C#/3'),
#   ('B', 'C#:maj7/3', 'C#'),
#   ('C', 'Eb', 'B/5'),
#   ('B:min', 'B:sus4', 'B:min/5'),
#   ('G#', 'F:min/5', 'Ab'),
#   ('D', 'C#/3', 'C:min'),
#   ('B:7', 'Bb', 'B:sus4'),
#   ('A:7(#9)', 'Ab:7', 'B:min/5'),
#   ('F:min/5', 'D:maj7', 'F#'),
#   ('F', 'Bb:min7', 'G:maj/9'),
#   ('G', 'G#:min', 'C#:sus4'),
#   ('Eb/5', 'C:maj(9)', 'Ab:7'),
#   ('E:min', 'B', 'C#:sus4'),
#   ('A:min', 'Eb/5', 'B:maj(*3)'),
#   ('E', 'F:min', 'G:min/5'),
#   ('N', 'Bb', 'C'),
#   ('N', 'A', 'E'),
#   ('A:7(#9)', 'C', 'B/5'),
#   ('F#:min', 'C', 'Db'),
#   ('B', 'Eb/5', 'Eb:sus4'),
#   ('Eb/5', 'F:min6/5', 'E:min/b3'),
#   ('F', 'F:maj6', 'Bb:min/5'),
#   ('E:aug', 'C#:maj7/3', 'B:min/5'),
#   ('A:min7(*5,b6)', 'C#/3', 'F#'),
#   ('Eb:maj6', 'B:maj(*3)', 'E:min/b3'),
#   ('E', 'F', 'Bb:min7'),
#   ('A:7', 'C#/3', 'G:min/5'),
#   ('Eb/5', 'B:sus4', 'G:min/5'),
#   ('E:aug', 'F:min', 'Db'),
#   ('A', 'C:maj(9)', 'B/5'),
#   ('F', 'Ab', 'Bb:min'),
#   ('G', 'B', 'F:min/5'),
#   ('D:min', 'B/5', 'G:maj/9'),
#   ('F#:min7', 'C#:7', 'B:maj(*3)'),
#   ('G', 'A:sus4', 'Eb:sus4'),
#   ('A:min(*5)', 'G#:min', 'G:min/5'),
#   ('B', 'Bb:min/5', 'F#'),
#   ('G#:min', 'C:maj(9)', 'F:maj6'),
#   ('E:sus4(b7)', 'F:maj6', 'G:min/5'),
#   ('G#:min', 'E:aug', 'C#:maj7/3'),
#   ('G:7', 'B', 'C:min'),
#   ('A:min7(*5,b6)', 'A:7(#9)', 'F'),
#   ('D:min', 'E:sus4(b7)', 'C:maj(9)'),
#   ('G:sus4', 'F#:min7', 'C#:7'),
#   ('F#:min', 'B:min/5', 'D:maj6'),
#   ('Bb', 'F:min6/5', 'B/5'),
#   ('Eb', 'G:min/5', 'E:min/b3'),
#   ('B:min', 'F:min6/5', 'Ab'),
#   ('G#:min', 'D:7(#9)', 'Db'),
#   ('Bb:min/5', 'F:min', 'C#:7'),
#   ('C#:maj7/3', 'C#/3', 'Ab:7'),
#   ('B:min', 'A:maj6', 'Db'),
#   ('G:7', 'F:min7', 'B/5'),
#   ('Bb', 'C:maj(9)', 'Ab/5'),
#   ('Bb', 'F:min', 'Eb'),
#   ('N', 'A', 'E:min'),
#   ('E:7', 'Bb:min7', 'B:sus4'),
#   ('A:7', 'Ab', 'B:min/5'),
#   ('G:7', 'Bb:min', 'B/5'),
#   ('D:min', 'B:dim7', 'D:maj6'),
#   ('E:7', 'G:sus4', 'C:min'),
#   ('F#:min', 'A:maj6', 'Bb:min7'),
#   ('A:7(#9)', 'Eb:maj6', 'B:min/5'),
#   ('E:sus4(b7)', 'B:maj(*3)', 'C#:sus4'),
#   ('N', 'B:min', 'G:min/5'),
#   ('A:7(#9)', 'E:min', 'Bb:min7'),
#   ('Eb/5', 'G:sus4', 'B/5'),
#   ('A:sus4', 'B:dim7', 'G:min/5'),
#   ('G:sus4', 'C#', 'B:maj(*3)'),
#   ('F', 'E:aug', 'F:min6/5'),
#   ('A:7(#9)', 'A:7', 'Ab:7'),
#   ('F#:min', 'F:min6/5', 'C#:maj7/3'),
#   ('G', 'C:7', 'Ab'),
#   ('N', 'F#:min', 'C:min'),
#   ('G:sus4', 'Ab', 'C#:sus4'),
#   ('B:7', 'G#', 'G:maj/9'),
#   ('Bb', 'F', 'F:min7'),
#   ('G#', 'C#', 'C#:7'),
#   ('C:7', 'F:min/5', 'Db'),
#   ('D', 'G:7', 'B'),
#   ('B:min', 'A:min', 'F:min/5'),
#   ('A', 'F', 'C#:7'),
#   ('G:7', 'D:7(#9)', 'B:dim7'),
#   ('D:dim7', 'C#:7', 'D:maj6'),
#   ('A:min', 'F:min', 'C:min'),
#   ('B', 'C#', 'G:maj/9'),
#   ('A:min7(*5,b6)', 'F:min6/5', 'Bb:min/5'),
#   ('A:7(#9)', 'C', 'F:maj6'),
#   ('B:dim7', 'B:maj(*3)', 'F#'),
#   ('Ab:7', 'Ab/5', 'Bb:min'),
#   ('A:7', 'G#', 'Bb'),
#   ('D:min', 'A:sus4', 'B/5'),
#   ('F', 'Bb:min7', 'Ab:7'),
#   ('E:sus4(b7)', 'F', 'Bb:min/5'),
#   ('A:7(#9)', 'E:aug', 'C#:maj7/3'),
#   ('B:min', 'C', 'Bb:min'),
#   ('A:7(#9)', 'Bb:min/5', 'B:min/5'),
#   ('A:7', 'B:hdim7/b3', 'C:maj(9)'),
#   ('G#', 'E:aug', 'B:maj(*3)'),
#   ('B:min', 'C:min', 'F#:min7'),
#   ('A:min', 'C#:maj7/3', 'C:min'),
#   ('G:sus4', 'F:min', 'E:min/b3'),
#   ('G:7', 'D:dim7', 'G:min/5'),
#   ('Bb:min7', 'B:sus4', 'G:maj/9'),
#   ('G:sus4', 'G:min/5', 'E:min/b3'),
#   ('C', 'B:min/5', 'G:maj/9'),
#   ('B:hdim7/b3', 'C#:maj7/3', 'G:maj/9'),
#   ('B:min', 'F#:min', 'A:7'),
#   ('A:min(*5)', 'A:min', 'Ab:7'),
#   ('C#/3', 'Ab:7', 'E:min/b3'),
#   ('G#:min', 'C:maj(9)', 'B/5'),
#   ('C:maj(9)', 'Bb:min/5', 'Eb:sus4'),
#   ('F:min/5', 'D:maj7', 'E:min/b3'),
#   ('Bb:min', 'F#:min7', 'E:min/b3'),
#   ('A:maj6', 'F#:min7', 'F#'),
#   ('N', 'E', 'D:7(#9)'),
#   ('D', 'C#:maj7/3', 'G:maj/9'),
#   ('E:min', 'A:sus4', 'B:sus4'),
#   ('D:min', 'B:hdim7/b3', 'C#/3'),
#   ('F', 'B:sus4', 'Eb:sus4'),
#   ('A:min7(*5,b6)', 'E:7', 'A'),
#   ('F:min7', 'Db', 'Ab/5'),
#   ('C#:maj7/3', 'B:dim7', 'Eb'),
#   ('Eb:maj6', 'D:maj7', 'E:min/b3'),
#   ('N', 'F:min/5', 'B:dim7'),
#   ('A:7', 'Eb', 'B:min/5'),
#   ('A:sus4', 'B:sus4', 'C#:sus4'),
#   ('A:min7(*5,b6)', 'C#:maj7/3', 'Eb:maj6'),
#   ('A:min(*5)', 'D:min', 'F#'),
#   ('D:dim7', 'F', 'Ab/5'),
#   ('N', 'A:min7(*5,b6)', 'B:dim7'),
#   ('Eb/5', 'Bb:min7', 'C#:7'),
#   ('N', 'A:7(#9)', 'G#'),
#   ('D:dim7', 'F:min', 'Ab:7'),
#   ('F:maj6', 'E:aug', 'Db'),
#   ('F:min/5', 'C:min', 'C#'),
#   ('G', 'F:maj6', 'C#:7'),
#   ('Eb:maj6', 'G:min/5', 'B:maj(*3)'),
#   ('E:sus4(b7)', 'Bb', 'Eb:sus4'),
#   ('G#:min', 'F:maj6', 'C#:maj7/3'),
#   ('B:hdim7/b3', 'C#', 'C#:7'),
#   ('F:min7', 'F:min', 'B/5'),
#   ('G:7', 'F:maj6', 'B:min/5'),
#   ('A:min7(*5,b6)', 'B:min', 'Ab'),
#   ('N', 'G#:min', 'C:maj(9)'),
#   ('Bb:min7', 'Ab:7', 'Db'),
#   ('G', 'D:7(#9)', 'G:min/5'),
#   ('A:min7(*5,b6)', 'E:7', 'Eb:sus4'),
#   ('A:7', 'Eb/5', 'C#:7'),
#   ('A:7', 'F:min6/5', 'G:maj/9'),
#   ('Eb/5', 'C:min', 'B/5'),
#   ('A:7(#9)', 'B/5', 'F#'),
#   ('D:7(#9)', 'C#:7', 'G:maj/9'),
#   ('C:7', 'C#/3', 'C#:sus4'),
#   ('G:7', 'D:dim7', 'G#'),
#   ('Bb:min/5', 'Db', 'E:min/b3'),
#   ('A:min7(*5,b6)', 'E:7', 'G:maj/9'),
#   ('A:7', 'F:min6/5', 'Eb:sus4'),
#   ('D:min', 'C#:maj7/3', 'B/5'),
#   ('N', 'C:min', 'Bb:min'),
#   ('G', 'F:min/5', 'E:aug'),
#   ('B:sus4', 'B:min/5', 'B:maj(*3)'),
#   ('F', 'B:min/5', 'F#:min7'),
#   ('C:7', 'B:min/5', 'B:maj(*3)'),
#   ('B:min', 'D:7(#9)', 'F:min/5'),
#   ('C', 'Db', 'C#:sus4'),
#   ('C:7', 'F:maj6', 'F:min6/5'),
#   ('D', 'C', 'C#'),
#   ('C:maj(9)', 'Bb:min7', 'C#:7'),
#   ('D:min', 'C#', 'E:min/b3'),
#   ('B:min', 'E:min', 'C:7'),
#   ('E:sus4(b7)', 'C:7', 'C#:7'),
#   ('C', 'F:maj6', 'C:min'),
#   ('E:min', 'A:sus4', 'E:aug'),
#   ('A:min(*5)', 'E', 'C:min'),
#   ('G', 'A', 'A:7(#9)'),
#   ('F:maj6', 'B:dim7', 'F:min'),
#   ('E:7', 'Eb/5', 'C:7'),
#   ('E:sus4(b7)', 'C#/3', 'F#'),
#   ('D:dim7', 'Bb:min/5', 'D:maj7'),
#   ('A:min(*5)', 'Bb', 'B:dim7'),
#   ('A', 'B:hdim7/b3', 'E:sus4(b7)'),
#   ('B:min', 'A:min', 'Bb'),
#   ('B:7', 'B/5', 'F#'),
#   ('Bb', 'E:aug', 'Ab'),
#   ('D:7(#9)', 'Bb:min7', 'F#'),
#   ('F#:min', 'C:maj(9)', 'F:min7'),
#   ('A', 'G#', 'C'),
#   ('E', 'B', 'B:sus4'),
#   ('F', 'C:min', 'D:maj6'),
#   ('G', 'A:min(*5)', 'C#:maj7/3'),
#   ('E', 'F:maj6', 'F:min6/5'),
#   ('A:min', 'Bb', 'G:sus4'),
#   ('A:7(#9)', 'A:min', 'B:min/5'),
#   ('G', 'C#:maj7/3', 'G:min/5'),
#   ('A:maj6', 'F:min/5', 'E:min/b3'),
#   ('A:min7(*5,b6)', 'G:7', 'F:min'),
#   ('Db', 'G:min/5', 'F#:min7'),
#   ('D', 'Eb:sus4', 'B:min/5'),
#   ('A', 'G#:min', 'Bb'),
#   ('G:7', 'A', 'F#:min7'),
#   ('A:sus4', 'C:maj(9)', 'B:dim7'),
#   ('B:min', 'F:min7', 'D:maj6'),
#   ('A:min', 'D:7(#9)', 'B:sus4'),
#   ('D:min', 'F:maj6', 'Bb:min/5'),
#   ('A:min(*5)', 'D:dim7', 'B:maj(*3)'),
#   ('A:min(*5)', 'Bb:min7', 'Bb:min'),
#   ('B:min', 'C', 'E:aug'),
#   ('D:min', 'C:7', 'B:sus4'),
#   ('G:7', 'A:sus4', 'C#'),
#   ('Eb:maj6', 'D:maj7', 'C#:sus4'),
#   ('A:min', 'Ab', 'F#'),
#   ('Bb', 'Eb/5', 'Bb:min/5'),
#   ('B:min', 'B', 'B:dim7'),
#   ('Bb', 'Bb:min7', 'B:maj(*3)'),
#   ('G:7', 'Eb/5', 'B/5'),
#   ('B:min', 'C:7', 'Bb:min7'),
#   ('A:min7(*5,b6)', 'F:maj6', 'B/5'),
#   ('E:7', 'A', 'C#:sus4'),
#   ('E:7', 'A:min', 'Bb:min'),
#   ('E:7', 'G:min/5', 'B:min/5'),
#   ('A:7', 'F', 'B:min/5'),
#   ('D', 'B:sus4', 'B/5'),
#   ('G:sus4', 'F:min7', 'C#:7'),
#   ('N', 'B:dim7', 'C#:sus4'),
#   ('E', 'C#:7', 'C#:sus4'),
#   ('E:min', 'F:min7', 'D:maj7'),
#   ('E:sus4(b7)', 'B:7', 'D:maj7'),
#   ('G#:min', 'F#:min7', 'D:maj6'),
#   ('F#:min', 'B:maj(*3)', 'D:maj6'),
#   ('C:maj(9)', 'F:min/5', 'Ab/5'),
#   ('D:dim7', 'F:min/5', 'C#:sus4'),
#   ('G', 'B', 'G#:min'),
#   ('A:maj6', 'C#', 'G:maj/9'),
#   ('B:min', 'Ab:7', 'Eb:sus4'),
#   ('N', 'D:7(#9)', 'Db'),
#   ('Bb', 'C:7', 'Eb:maj6'),
#   ('A:maj6', 'Eb', 'B:min/5'),
#   ('A:sus4', 'E:aug', 'C#:7'),
#   ('G:sus4', 'C:maj(9)', 'F:min7'),
#   ('C:maj(9)', 'G:min/5', 'Ab/5'),
#   ('B:sus4', 'C:min', 'F#:min7'),
#   ('G:7', 'B:hdim7/b3', 'C#/3'),
#   ('F#:min', 'D:min', 'G#:min'),
#   ('Ab', 'B:min/5', 'C#'),
#   ('F#:min', 'Bb:min/5', 'Eb:maj6'),
#   ('D', 'A:sus4', 'C#:7'),
#   ('B:7', 'C:maj(9)', 'C#:sus4'),
#   ('A:min', 'Eb/5', 'Ab'),
#   ('G', 'A:min7(*5,b6)', 'A:sus4'),
#   ('F', 'C#/3', 'B:dim7'),
#   ('A:maj6', 'C', 'G:min/5'),
#   ('A', 'A:min', 'F:min6/5'),
#   ('G:min/5', 'D:maj7', 'F#'),
#   ('A:maj6', 'F:min/5', 'Ab'),
#   ('C:min', 'Eb', 'B:maj(*3)'),
#   ('A:7(#9)', 'E:aug', 'Bb:min7'),
#   ('E', 'C#:maj7/3', 'F:min'),
#   ('G#', 'Eb/5', 'Bb:min'),
#   ('F:min/5', 'G:min/5', 'B:min/5'),
#   ('Eb/5', 'G:sus4', 'C#/3'),
#   ('A:7(#9)', 'A:7', 'C#/3'),
#   ('N', 'Bb', 'F'),
#   ('D', 'G:sus4', 'Db'),
#   ('A:min(*5)', 'F', 'G:min/5'),
#   ('A:min', 'C#/3', 'G:min/5'),
#   ('F', 'C#:maj7/3', 'C#:7'),
#   ('E:min', 'G#:min', 'F#'),
#   ('F:min6/5', 'C#:sus4', 'F#'),
#   ('D:dim7', 'G#', 'C'),
#   ('F:min', 'C#', 'B:maj(*3)'),
#   ('A:7(#9)', 'A:maj6', 'D:maj7'),
#   ('N', 'D', 'E:min'),
#   ('Bb:min7', 'Ab:7', 'Bb:min'),
#   ('G', 'F:min7', 'B:min/5'),
#   ('A:7', 'E:sus4(b7)', 'B:dim7'),
#   ('A:min7(*5,b6)', 'A:7(#9)', 'D:7(#9)'),
#   ('E', 'A:sus4', 'D:maj7'),
#   ('B:7', 'D:7(#9)', 'Bb:min7'),
#   ('A:min7(*5,b6)', 'E:min', 'F:maj6'),
#   ('G:sus4', 'B:dim7', 'B:min/5'),
#   ('N', 'D:min', 'C:7'),
#   ('E', 'Bb:min7', 'Eb'),
#   ('G', 'G:sus4', 'C#:maj7/3'),
#   ('N', 'F:min', 'Bb:min'),
#   ('N', 'D:7(#9)', 'E:min/b3'),
#   ('A:7(#9)', 'G:sus4', 'F:min'),
#   ('A', 'Eb:maj6', 'Eb:sus4'),
#   ('G:7', 'F:maj6', 'G:min/5'),
#   ('G:7', 'D:min', 'G:sus4'),
#   ('E:sus4(b7)', 'G#', 'B:min/5'),
#   ('G', 'Bb:min/5', 'Db'),
#   ('Eb:maj6', 'B:dim7', 'D:maj7'),
#   ('G', 'E', 'E:min/b3'),
#   ('B', 'Eb/5', 'C#:sus4'),
#   ('G', 'B:min/5', 'F#'),
#   ('E:min', 'C#:maj7/3', 'D:maj6'),
#   ('A:7', 'A:sus4', 'C#'),
#   ('F:min7', 'C#:maj7/3', 'C#'),
#   ('E:7', 'B', 'F'),
#   ('D:7(#9)', 'Bb:min/5', 'B:maj(*3)'),
#   ('D:7(#9)', 'C#:maj7/3', 'Eb'),
#   ('N', 'G:7', 'B:hdim7/b3'),
#   ('D', 'F:min7', 'D:maj6'),
#   ('B:hdim7/b3', 'G#:min', 'F#'),
#   ('D:dim7', 'Eb', 'C#:7'),
#   ('D:dim7', 'C', 'Db'),
#   ('F:min7', 'C:min', 'Ab'),
#   ('F:maj6', 'D:maj7', 'B:maj(*3)'),
#   ('F:min', 'Ab', 'B:min/5'),
#   ('G:7', 'G#', 'Bb:min'),
#   ('A:7(#9)', 'Bb', 'C:maj(9)'),
#   ('F:min6/5', 'C:min', 'Bb:min'),
#   ('B', 'A:sus4', 'F:min7'),
#   ('C:7', 'Bb:min', 'E:min/b3'),
#   ('B:min', 'D:7(#9)', 'Ab:7'),
#   ('G', 'B', 'D:maj6'),
#   ('Bb', 'Eb/5', 'D:maj7'),
#   ('D:7(#9)', 'C:maj(9)', 'C#:maj7/3'),
#   ('C', 'D:7(#9)', 'G:maj/9'),
#   ('E:7', 'Eb', 'F#:min7'),
#   ('A:min7(*5,b6)', 'A:min(*5)', 'A:sus4'),
#   ('G', 'E', 'Ab'),
#   ('A:min7(*5,b6)', 'B', 'Ab/5'),
#   ('D:dim7', 'D:7(#9)', 'B:maj(*3)'),
#   ('A:min(*5)', 'F#:min', 'Eb/5'),
#   ('G:7', 'G#:min', 'F:min6/5'),
#   ('B', 'F:min7', 'Ab'),
#   ('B:7', 'C:7', 'Bb:min'),
#   ('Bb', 'G:sus4', 'C#/3'),
#   ('F#:min', 'B:hdim7/b3', 'F:min'),
#   ('A:7', 'A:min', 'Eb:maj6'),
#   ('D:dim7', 'E:sus4(b7)', 'B:sus4'),
#   ('Bb', 'F:min', 'Db'),
#   ('G:sus4', 'C#/3', 'C#'),
#   ('A:7', 'F:min/5', 'D:maj6'),
#   ('A', 'C', 'A:sus4'),
#   ('G:7', 'B:hdim7/b3', 'B:7'),
#   ('A:7(#9)', 'G#:min', 'C:maj(9)'),
#   ('E:min', 'D:7(#9)', 'Bb:min/5'),
#   ('F#:min', 'Eb/5', 'C#:7'),
#   ('A:7(#9)', 'C#/3', 'C#'),
#   ('B:7', 'Bb:min7', 'F#:min7'),
#   ('B:min', 'A:7(#9)', 'G#'),
#   ('B:hdim7/b3', 'D:7(#9)', 'B:dim7'),
#   ('E:7', 'Bb', 'F'),
#   ('A:sus4', 'Ab:7', 'B:sus4'),
#   ('D:min', 'D:dim7', 'C:7'),
#   ('G#:min', 'F#', 'D:maj6'),
#   ('A:min7(*5,b6)', 'E:aug', 'Bb:min/5'),
#   ('N', 'F#:min', 'D:maj7'),
#   ('F', 'F:min/5', 'E:aug'),
#   ('D:7(#9)', 'G:sus4', 'D:maj6'),
#   ('F', 'Ab/5', 'C#:sus4'),
#   ('D', 'E:sus4(b7)', 'F:maj6'),
#   ('C#:maj7/3', 'C#', 'B:maj(*3)'),
#   ('A:7(#9)', 'B:hdim7/b3', 'F:min'),
#   ('G:7', 'F#:min', 'F#:min7'),
#   ('D', 'F:min/5', 'Eb:maj6'),
#   ('A', 'G#', 'F:min7'),
#   ('D:7(#9)', 'Db', 'B/5'),
#   ('E:min', 'F:maj6', 'C#/3'),
#   ('Bb', 'Ab', 'B/5'),
#   ('B:7', 'Ab:7', 'C#'),
#   ('G#', 'C', 'F:maj6'),
#   ('A:min7(*5,b6)', 'G:7', 'C#/3'),
#   ('D:7(#9)', 'E:aug', 'F#:min7'),
#   ('G:sus4', 'B:dim7', 'F#:min7'),
#   ('F:min6/5', 'C#/3', 'C:min'),
#   ('D:min', 'Eb:maj6', 'G:maj/9'),
#   ('G:7', 'A:min', 'F'),
#   ('G#:min', 'Ab:7', 'B:sus4'),
#   ('F:maj6', 'B/5', 'E:min/b3'),
#   ('A:min7(*5,b6)', 'C:7', 'B:dim7'),
#   ('N', 'A:min7(*5,b6)', 'F:min6/5'),
#   ('F#:min', 'C#/3', 'C:min'),
#   ('A:7', 'B:min/5', 'F#:min7'),
#   ('G:7', 'A:7(#9)', 'G:min/5'),
#   ('B:hdim7/b3', 'Eb', 'D:maj7'),
#   ('A', 'Bb:min/5', 'Eb'),
#   ('D', 'D:min', 'B:sus4'),
#   ('B:min', 'C:maj(9)', 'C:min'),
#   ('A:7', 'Eb:maj6', 'Db'),
#   ('B:dim7', 'Ab/5', 'F#:min7'),
#   ('C:maj(9)', 'Ab:7', 'B/5'),
#   ('D', 'B:7', 'B:dim7'),
#   ('D:min', 'F:maj6', 'F:min/5'),
#   ('A:min7(*5,b6)', 'G:sus4', 'D:maj7'),
#   ('A', 'Eb', 'E:min/b3'),
#   ('F:maj6', 'F:min', 'Ab'),
#   ('D:min', 'B:7', 'D:maj6'),
#   ('F:min', 'G:min/5', 'D:maj6'),
#   ('A:7(#9)', 'A:sus4', 'F#:min7'),
#   ('G', 'A', 'C:min'),
#   ('D', 'C', 'B:maj(*3)'),
#   ('F#:min', 'G#:min', 'C:7'),
#   ('D:min', 'B:sus4', 'G:maj/9'),
#   ('A:min', 'F', 'D:maj6'),
#   ('A', 'Ab:7', 'Ab/5'),
#   ('E', 'A:sus4', 'Ab/5'),
#   ('G#:min', 'G#', 'G:min/5'),
#   ('E:7', 'G#', 'B:sus4'),
#   ('D:dim7', 'F:min/5', 'F#:min7'),
#   ('C', 'D:7(#9)', 'Ab:7'),
#   ('A:min', 'C#:maj7/3', 'B:sus4'),
#   ('Bb', 'C#/3', 'Ab:7'),
#   ('C#:maj7/3', 'D:maj7', 'C#:7'),
#   ('D:min', 'Ab:7', 'E:min/b3'),
#   ('Ab:7', 'C:min', 'F#:min7'),
#   ('G', 'B:dim7', 'D:maj6'),
#   ('G#', 'A:sus4', 'Eb:sus4'),
#   ('E:min', 'C#:maj7/3', 'F#'),
#   ('A:min7(*5,b6)', 'A:maj6', 'B/5'),
#   ('B:hdim7/b3', 'A:min', 'C#:sus4'),
#   ('D:min', 'G:sus4', 'Eb:sus4'),
#   ('E:sus4(b7)', 'B/5', 'B:min/5'),
#   ('E:7', 'A:7', 'B:hdim7/b3'),
#   ('A:7(#9)', 'D:min', 'E:sus4(b7)'),
#   ('A:7', 'B:7', 'F#'),
#   ('D', 'E:sus4(b7)', 'B:7'),
#   ('A:min7(*5,b6)', 'G#:min', 'G:maj/9'),
#   ('A:7(#9)', 'E:sus4(b7)', 'B:maj(*3)'),
#   ('A:min(*5)', 'F:min/5', 'F:min'),
#   ('D', 'G', 'D:7(#9)'),
#   ('A:min', 'Eb', 'B/5'),
#   ('B', 'B:dim7', 'C#'),
#   ('E:7', 'E:min', 'B:7'),
#   ('A:min(*5)', 'B:dim7', 'Ab:7'),
#   ('A:min', 'B/5', 'C#'),
#   ('D', 'E', 'C'),
#   ('Db', 'B:maj(*3)', 'D:maj6'),
#   ('D', 'B:hdim7/b3', 'C#/3'),
#   ('A', 'G#:min', 'A:sus4'),
#   ('A:min(*5)', 'F:min7', 'D:maj6'),
#   ('B:min', 'A:7', 'C'),
#   ('A:min7(*5,b6)', 'A', 'F:min7'),
#   ('D:dim7', 'E:aug', 'B:maj(*3)'),
#   ('A', 'G:sus4', 'B:maj(*3)'),
#   ('C', 'C:7', 'Eb:maj6'),
#   ('D', 'Eb', 'Ab/5'),
#   ('A:7', 'C:maj(9)', 'Bb:min/5'),
#   ('B', 'E:sus4(b7)', 'B:min/5'),
#   ('A:sus4', 'Bb:min/5', 'G:maj/9'),
#   ('C:7', 'C:min', 'Ab'),
#   ('N', 'G:7', 'A:min'),
#   ('G', 'E:min', 'G:maj/9'),
#   ('F#:min', 'A:maj6', 'A:min'),
#   ('E:sus4(b7)', 'Bb:min/5', 'B:min/5'),
#   ('D:7(#9)', 'F', 'D:maj7'),
#   ('E:min', 'G#', 'Db'),
#   ('C', 'C:min', 'F#:min7'),
#   ('A:min(*5)', 'Bb', 'B/5'),
#   ('E:min', 'B:hdim7/b3', 'B:maj(*3)'),
#   ('D:7(#9)', 'A:sus4', 'E:aug'),
#   ('B:hdim7/b3', 'Ab', 'B:min/5'),
#   ('C', 'F:min', 'E:min/b3'),
#   ('E', 'A:min', 'Bb:min'),
#   ('D', 'Bb:min7', 'B:dim7'),
#   ('A:min(*5)', 'D:dim7', 'D:maj7'),
#   ('B', 'C:maj(9)', 'E:aug'),
#   ('D:min', 'A:sus4', 'C:maj(9)'),
#   ('D:min', 'Bb', 'C'),
#   ('C:7', 'F', 'C#'),
#   ('A:min(*5)', 'F:min6/5', 'C#:sus4'),
#   ('E:min', 'C#', 'E:min/b3'),
#   ('B:min', 'A:min', 'F'),
#   ('B:7', 'C#/3', 'E:min/b3'),
#   ('A:min', 'B:min/5', 'D:maj7'),
#   ('B:hdim7/b3', 'Eb/5', 'Ab'),
#   ('B:min', 'B:hdim7/b3', 'D:7(#9)'),
#   ('B:7', 'A:sus4', 'F:min'),
#   ('C#:maj7/3', 'Eb', 'D:maj7'),
#   ('E:min', 'B:min/5', 'E:min/b3'),
#   ('C#/3', 'Ab:7', 'Db'),
#   ('E', 'F:min/5', 'C#:7'),
#   ('Ab:7', 'B:min/5', 'B:maj(*3)'),
#   ('B', 'C#/3', 'F#'),
#   ('A:min', 'F:min6/5', 'C#:7'),
#   ('A:7(#9)', 'E', 'G#'),
#   ('G:7', 'G:sus4', 'Ab'),
#   ('F#:min', 'Ab/5', 'C#:7'),
#   ('E:sus4(b7)', 'A:min', 'D:maj7'),
#   ('G#:min', 'F:min7', 'C#/3'),
#   ('G:sus4', 'E:aug', 'Eb:sus4'),
#   ('N', 'F:min7', 'B:min/5'),
#   ('G#', 'Eb:maj6', 'Bb:min'),
#   ('G', 'A:min', 'Eb:maj6'),
#   ('B:dim7', 'B:maj(*3)', 'E:min/b3'),
#   ('A:7', 'Eb:sus4', 'D:maj6'),
#   ('B:hdim7/b3', 'B/5', 'C#:sus4'),
#   ('A:7(#9)', 'F:min6/5', 'B:min/5'),
#   ('C:maj(9)', 'G:min/5', 'D:maj6'),
#   ('D:min', 'Db', 'D:maj7'),
#   ('E', 'B:dim7', 'F#'),
#   ('E', 'C#:maj7/3', 'C#/3'),
#   ('A:sus4', 'Db', 'Ab/5'),
#   ('B:7', 'G#:min', 'B:min/5'),
#   ('E:7', 'Db', 'Ab'),
#   ('G:7', 'F#:min', 'D:min'),
#   ('G#:min', 'Db', 'B:sus4'),
#   ('F:min7', 'B:sus4', 'C#:7'),
#   ('D', 'C#/3', 'Ab:7'),
#   ('E', 'A:7', 'Ab:7'),
#   ('D:dim7', 'C:maj(9)', 'F#'),
#   ('Bb', 'F:min/5', 'B:min/5'),
#   ('G#:min', 'Db', 'C#:7'),
#   ('Eb:maj6', 'Eb:sus4', 'B:maj(*3)'),
#   ('E:min', 'A:maj6', 'C:min'),
#   ('D', 'F:min', 'C#'),
#   ('G:min/5', 'C#', 'F#:min7'),
#   ('E:min', 'G#:min', 'Bb'),
#   ('E:7', 'E:aug', 'Ab/5'),
#   ('E:min', 'D:maj7', 'F#'),
#   ('D', 'B:hdim7/b3', 'A:sus4'),
#   ('F:min', 'Ab:7', 'Ab'),
#   ('A:7', 'E:aug', 'Bb:min7'),
#   ('B:7', 'C#/3', 'Ab'),
#   ('B:min', 'D:dim7', 'B:7'),
#   ('B:hdim7/b3', 'C#/3', 'G:min/5'),
#   ('Ab:7', 'Eb', 'C#:sus4'),
#   ('A:min(*5)', 'F', 'F:min6/5'),
#   ('F:min/5', 'B:dim7', 'B:min/5'),
#   ('D', 'F:min6/5', 'B:sus4'),
#   ('A:7', 'E:sus4(b7)', 'Eb:sus4'),
#   ('B:min', 'C:min', 'B:min/5'),
#   ('N', 'A:min', 'F#'),
#   ('A:min7(*5,b6)', 'G:7', 'F:min/5'),
#   ('D:min', 'Bb', 'F#:min7'),
#   ('C:maj(9)', 'Bb:min7', 'D:maj6'),
#   ('E:7', 'A:7', 'D:7(#9)'),
#   ('D', 'F#:min', 'C:7'),
#   ('A:7', 'B:dim7', 'C#:7'),
#   ('B:min', 'Bb', 'C#/3'),
#   ('E:sus4(b7)', 'C#:sus4', 'E:min/b3'),
#   ('B:7', 'D:7(#9)', 'C#:7'),
#   ('C:min', 'Ab', 'B/5'),
#   ('B:hdim7/b3', 'F', 'Eb'),
#   ('A:7', 'A:min', 'E:aug'),
#   ('B:7', 'B:sus4', 'F#'),
#   ('A', 'Bb', 'Ab'),
#   ('N', 'A', 'Eb:maj6'),
#   ('G:sus4', 'Ab', 'Eb:sus4'),
#   ('Eb/5', 'Bb:min/5', 'C#'),
#   ('A:7(#9)', 'D:7(#9)', 'F:min'),
#   ('C:maj(9)', 'F:min/5', 'Ab:7'),
#   ('A:min', 'F:maj6', 'F:min7'),
#   ('D', 'F:min', 'E:min/b3'),
#   ('A:min(*5)', 'E:aug', 'C:min'),
#   ('G', 'G:7', 'E:min'),
#   ('B:7', 'B:min/5', 'D:maj6'),
#   ('A', 'E:aug', 'Ab:7'),
#   ('G#:min', 'Eb', 'C#'),
#   ('G:7', 'A:7', 'Eb/5'),
#   ('Bb', 'Eb/5', 'Ab'),
#   ('D:dim7', 'G#', 'Bb:min7'),
#   ('D', 'B:dim7', 'B:sus4'),
#   ('F#:min', 'A:maj6', 'C#/3'),
#   ('N', 'Bb:min/5', 'Db'),
#   ('F#:min', 'A:min', 'Bb:min'),
#   ('A:min(*5)', 'A:maj6', 'B:sus4'),
#   ('E', 'C#:maj7/3', 'Bb:min'),
#   ('G#', 'Eb/5', 'F:min'),
#   ('B:hdim7/b3', 'F', 'F#:min7'),
#   ('E:aug', 'Ab:7', 'E:min/b3'),
#   ('G', 'A:min', 'F:min'),
#   ('D:dim7', 'Bb', 'A:sus4'),
#   ('F:min7', 'Db', 'B/5'),
#   ('Eb:maj6', 'Ab:7', 'C#'),
#   ('B', 'E:sus4(b7)', 'B:dim7'),
#   ('Bb:min', 'F#', 'D:maj6'),
#   ('B', 'Bb:min/5', 'Ab/5'),
#   ('G:7', 'F#:min', 'Eb'),
#   ('B:7', 'F:maj6', 'Db'),
#   ('A:7(#9)', 'F', 'Eb:maj6'),
#   ('G#:min', 'F:maj6', 'B:min/5'),
#   ('E:aug', 'Eb', 'Ab/5'),
#   ('D:dim7', 'G#:min', 'Ab'),
#   ('C:maj(9)', 'F:min/5', 'B:sus4'),
#   ('G#', 'B:dim7', 'D:maj6'),
#   ('Ab:7', 'Ab', 'C#'),
#   ('Bb', 'A:sus4', 'B:sus4'),
#   ('D', 'B:sus4', 'G:maj/9'),
#   ('B:min', 'A:min(*5)', 'G#:min'),
#   ('Ab/5', 'D:maj7', 'E:min/b3'),
#   ('A:7(#9)', 'D:min', 'Eb:maj6'),
#   ('D:min', 'B:7', 'C#:maj7/3'),
#   ('D:min', 'Bb', 'F:min'),
#   ('G:sus4', 'C#:maj7/3', 'Ab:7'),
#   ('N', 'E:sus4(b7)', 'F:min/5'),
#   ('C#:maj7/3', 'Bb:min7', 'F#'),
#   ('A:min7(*5,b6)', 'D:min', 'E:sus4(b7)'),
#   ('A', 'E:sus4(b7)', 'F:maj6'),
#   ('G:7', 'A:7(#9)', 'C'),
#   ('C:7', 'Bb:min/5', 'B:sus4'),
#   ('F', 'F:min6/5', 'Bb:min7'),
#   ('Bb:min/5', 'Ab/5', 'D:maj7'),
#   ('A:7(#9)', 'A:maj6', 'C#:sus4'),
#   ('G:7', 'F:min', 'Bb:min'),
#   ('D', 'A:min(*5)', 'D:maj6'),
#   ('Eb/5', 'A:sus4', 'G:min/5'),
#   ('G#:min', 'Ab', 'D:maj7'),
#   ('B:dim7', 'D:maj7', 'E:min/b3'),
#   ('E:min', 'C', 'Eb:sus4'),
#   ('F:min/5', 'Bb:min/5', 'Eb'),
#   ('D', 'G', 'Eb:sus4'),
#   ('D', 'G:7', 'A:7(#9)'),
#   ('A:min7(*5,b6)', 'E:sus4(b7)', 'F:min7'),
#   ('D:min', 'Bb:min7', 'Ab:7'),
#   ('B:hdim7/b3', 'C', 'F:maj6'),
#   ('Bb:min/5', 'C#', 'D:maj7'),
#   ('G', 'Bb:min/5', 'D:maj7'),
#   ('B:min', 'A:7', 'Db'),
#   ('G:7', 'F:min7', 'Bb:min/5'),
#   ('E:aug', 'Ab:7', 'Ab'),
#   ('B', 'D:7(#9)', 'C:min'),
#   ('G:7', 'F#:min', 'G#:min'),
#   ('G:7', 'D:7(#9)', 'F#:min7'),
#   ('G', 'B:hdim7/b3', 'Eb:maj6'),
#   ('A:min7(*5,b6)', 'Bb:min7', 'F#:min7'),
#   ('B:min', 'A:maj6', 'C'),
#   ('G:7', 'F:maj6', 'C#:maj7/3'),
#   ('C:7', 'D:7(#9)', 'A:sus4'),
#   ('B:dim7', 'C#:7', 'B:maj(*3)'),
#   ('E:min', 'Bb:min/5', 'D:maj7'),
#   ('F:maj6', 'Bb:min7', 'Eb:maj6'),
#   ('E:sus4(b7)', 'C#', 'D:maj6'),
#   ('E', 'A:maj6', 'Ab/5'),
#   ('G:7', 'C:min', 'F#'),
#   ('D', 'C#', 'C#:7'),
#   ('B:hdim7/b3', 'C:7', 'F#:min7'),
#   ('D:7(#9)', 'F:min/5', 'C:min'),
#   ('F', 'G:min/5', 'C#'),
#   ('D:dim7', 'E:sus4(b7)', 'Eb:maj6'),
#   ('G#', 'F:maj6', 'G:min/5'),
#   ('E', 'B', 'D:maj7'),
#   ('B:hdim7/b3', 'D:7(#9)', 'G:sus4'),
#   ('C:7', 'E:aug', 'G:maj/9'),
#   ('B', 'C:min', 'F#:min7'),
#   ('F:maj6', 'Bb:min/5', 'G:min/5'),
#   ('C:maj(9)', 'Eb:maj6', 'E:min/b3'),
#   ('A', 'Eb/5', 'Bb:min/5'),
#   ('E', 'G#:min', 'C#'),
#   ('G:7', 'F', 'F#'),
#   ('A:min7(*5,b6)', 'B', 'B:min/5'),
#   ('A:7', 'A:min', 'Bb:min'),
#   ('E:7', 'D:dim7', 'B:sus4'),
#   ('D:min', 'C:maj(9)', 'F:min6/5'),
#   ('D', 'A:7(#9)', 'Db'),
#   ('G', 'E:min', 'B:maj(*3)'),
#   ('F:maj6', 'Bb:min/5', 'G:maj/9'),
#   ('G:7', 'Bb', 'Bb:min/5'),
#   ('C:maj(9)', 'F:maj6', 'B:dim7'),
#   ('B:hdim7/b3', 'C#:maj7/3', 'Bb:min7'),
#   ('E:min', 'Bb:min/5', 'F#'),
#   ('B', 'D:7(#9)', 'D:maj7'),
#   ('D', 'B:7', 'C#:maj7/3'),
#   ('E', 'F:min7', 'B:sus4'),
#   ('E:7', 'F#:min', 'G:maj/9'),
#   ('F:min/5', 'C#/3', 'C:min'),
#   ('C:min', 'Bb:min', 'F#'),
#   ('Bb:min/5', 'Bb:min7', 'B:dim7'),
#   ('G:7', 'A:min', 'B/5'),
#   ('B:min', 'Eb/5', 'Bb:min7'),
#   ('B:min', 'Ab:7', 'F#:min7'),
#   ('E:sus4(b7)', 'C', 'Eb'),
#   ('G', 'E:aug', 'F:min'),
#   ('A:7(#9)', 'C:min', 'B:maj(*3)'),
#   ('D', 'C:7', 'F'),
#   ('G#', 'G:min/5', 'F#:min7'),
#   ('E', 'B', 'C:min'),
#   ('B:hdim7/b3', 'D:7(#9)', 'B:min/5'),
#   ('Eb/5', 'A:sus4', 'G:maj/9'),
#   ('E', 'F:min7', 'Eb:sus4'),
#   ('A:min', 'C:min', 'F#:min7'),
#   ('B', 'G#:min', 'F#:min7'),
#   ('G:7', 'D:7(#9)', 'Ab:7'),
#   ('F:min/5', 'B:sus4', 'D:maj6'),
#   ('N', 'Eb/5', 'B:sus4'),
#   ('E:7', 'A', 'Eb:sus4'),
#   ('A:min(*5)', 'E', 'B:7'),
#   ('C', 'C:7', 'C#/3'),
#   ('F:min/5', 'C#:maj7/3', 'B:sus4'),
#   ('G', 'G:sus4', 'E:aug'),
#   ('D:min', 'D:7(#9)', 'F:min6/5'),
#   ('G', 'F:min/5', 'Eb:maj6'),
#   ('A:7', 'D:min', 'C#:sus4'),
#   ('B:min', 'G:min/5', 'B/5'),
#   ('A:maj6', 'Bb:min', 'B/5'),
#   ('D:7(#9)', 'C:min', 'G:maj/9'),
#   ('B', 'Bb:min/5', 'Db'),
#   ('F:min6/5', 'C#/3', 'Db'),
#   ('Bb', 'C:maj(9)', 'F:min7'),
#   ('B:min', 'C#', 'C#:7'),
#   ('C', 'Eb:sus4', 'D:maj7'),
#   ('F:min/5', 'F:min7', 'B:maj(*3)'),
#   ('N', 'A:7', 'C#/3'),
#   ('B:min', 'B:7', 'Ab'),
#   ('B:hdim7/b3', 'A:sus4', 'Ab:7'),
#   ('B', 'F', 'F:min7'),
#   ('N', 'A:min7(*5,b6)', 'G:7'),
#   ('B:7', 'G#:min', 'Ab:7'),
#   ('C#:maj7/3', 'Bb:min/5', 'B/5'),
#   ('B:min', 'D:7(#9)', 'B/5'),
#   ('G:7', 'A', 'D:min'),
#   ('G:7', 'Bb', 'G:min/5'),
#   ('B:min', 'B', 'E:sus4(b7)'),
#   ('G:7', 'B/5', 'C#'),
#   ('E:7', 'A:7', 'F:min6/5'),
#   ('A:min', 'Bb:min/5', 'Db'),
#   ('D:min', 'E:aug', 'Bb:min/5'),
#   ('G:sus4', 'F:min7', 'B:min/5'),
#   ('N', 'F', 'Db'),
#   ('A:7', 'B:7', 'F:maj6'),
#   ('D:7(#9)', 'C#:maj7/3', 'Bb:min'),
#   ('Bb:min/5', 'C#/3', 'B:maj(*3)'),
#   ('C:7', 'F:min', 'C#'),
#   ('F:min/5', 'Bb:min/5', 'E:min/b3'),
#   ('F:min/5', 'C#:maj7/3', 'B:min/5'),
#   ('A:7(#9)', 'A:7', 'Eb:sus4'),
#   ('B', 'Bb', 'E:aug'),
#   ('E:7', 'C:7', 'C#:7'),
#   ('C:7', 'D:7(#9)', 'F#:min7'),
#   ('G:sus4', 'E:aug', 'F:min6/5'),
#   ('G:7', 'D:min', 'Eb'),
#   ('Bb:min/5', 'Ab/5', 'G:maj/9'),
#   ('A:sus4', 'F#:min7', 'G:maj/9'),
#   ('G#', 'Eb/5', 'Eb:maj6'),
#   ('D:dim7', 'G#', 'Eb'),
#   ('C:7', 'A:sus4', 'F:min'),
#   ('Db', 'C:min', 'B:min/5'),
#   ('D:7(#9)', 'F:maj6', 'B:sus4'),
#   ('A:7(#9)', 'G:sus4', 'Eb'),
#   ('A:min7(*5,b6)', 'G#', 'B/5'),
#   ('A:7', 'D:dim7', 'F:min6/5'),
#   ('D:7(#9)', 'Ab', 'B:min/5'),
#   ('B:hdim7/b3', 'G#:min', 'F'),
#   ('A', 'E', 'B'),
#   ('D', 'F#:min', 'F#'),
#   ('N', 'A', 'C:min'),
#   ('B:7', 'Eb:maj6', 'B:sus4'),
#   ('E:min', 'C:maj(9)', 'Eb'),
#   ('F#:min', 'B', 'G:maj/9'),
#   ('A:7(#9)', 'E:min', 'Ab:7'),
#   ('E:aug', 'B:maj(*3)', 'C#:sus4'),
#   ('Ab', 'G:maj/9', 'E:min/b3'),
#   ('E', 'E:sus4(b7)', 'B:dim7'),
#   ('A:7(#9)', 'A:7', 'Bb:min7'),
#   ('F#:min', 'C#:maj7/3', 'D:maj7'),
#   ('C#:maj7/3', 'Bb:min/5', 'C#:7'),
#   ('F#:min', 'G#', 'Bb:min/5'),
#   ('A:min(*5)', 'F:min', 'Db'),
#   ('C', 'C:7', 'Bb:min'),
#   ('Eb/5', 'A:sus4', 'Bb:min/5'),
#   ('Eb/5', 'C:maj(9)', 'Ab/5'),
#   ('E:min', 'A:sus4', 'C#:sus4'),
#   ('D', 'B:min', 'Db'),
#   ('E:sus4(b7)', 'B:maj(*3)', 'G:maj/9'),
#   ('B:hdim7/b3', 'A:maj6', 'E:min/b3'),
#   ('F#:min', 'D:7(#9)', 'F:min6/5'),
#   ('G#', 'Eb/5', 'Eb'),
#   ('Bb:min/5', 'Eb:maj6', 'B:sus4'),
#   ('C:maj(9)', 'C#/3', 'C:min'),
#   ('F:maj6', 'F:min6/5', 'Db'),
#   ('B:min', 'C:7', 'G:maj/9'),
#   ...},
#  '012': {('Bb:min/5', 'C#:maj7/3', 'E:sus4(b7)'),
#   ('A:7(#9)', 'Ab:7', 'F:min'),
#   ('Ab/5', 'Eb', 'F:min6/5'),
#   ('Ab', 'Bb:min7', 'F'),
#   ('B:hdim7/b3', 'B:min', 'D:7(#9)'),
#   ('Bb:min/5', 'C#:maj7/3', 'G:min/5'),
#   ('B', 'Bb:min7', 'F'),
#   ('A:min(*5)', 'C#', 'G'),
#   ('A:7', 'D:7(#9)', 'G'),
#   ('Bb', 'C:7', 'D:min'),
#   ('Ab', 'B:min', 'E:min'),
#   ('Bb:min', 'C', 'F:min/5'),
#   ('Ab:7', 'B:min', 'F#'),
#   ('Bb', 'C:maj(9)', 'F:min'),
#   ('Ab/5', 'C', 'C#:maj7/3'),
#   ('C:maj(9)', 'F#:min7', 'F:maj6'),
#   ('A:min', 'B', 'B:min/5'),
#   ('B:maj(*3)', 'B:min/5', 'E'),
#   ('B:min/5', 'C#', 'C#:sus4'),
#   ('B/5', 'B:min/5', 'G'),
#   ('Ab:7', 'Bb', 'Eb'),
#   ('C#', 'C#:sus4', 'E:7'),
#   ('A', 'A:sus4', 'F:min'),
#   ('D:maj6', 'F#:min', 'F#:min7'),
#   ('E', 'Eb/5', 'G'),
#   ('A', 'A:min7(*5,b6)', 'C#:sus4'),
#   ('A:7(#9)', 'B:min', 'F#'),
#   ('Ab/5', 'Bb:min7', 'N'),
#   ('E:aug', 'E:min', 'F:min/5'),
#   ('A:min7(*5,b6)', 'B:min', 'C#:maj7/3'),
#   ('A:min7(*5,b6)', 'D', 'F#:min'),
#   ('Bb', 'D:maj6', 'F:min/5'),
#   ('A:min(*5)', 'B:min', 'C'),
#   ('B', 'D:dim7', 'D:min'),
#   ('C', 'C#/3', 'E:sus4(b7)'),
#   ('Bb:min/5', 'D:min', 'E'),
#   ('Bb', 'C', 'Eb:maj6'),
#   ('A:7(#9)', 'C', 'Db'),
#   ('A:7(#9)', 'D', 'D:dim7'),
#   ('A', 'A:7', 'F:min/5'),
#   ('Bb:min/5', 'Eb/5', 'G'),
#   ('A:min', 'Bb:min7', 'G#'),
#   ('B:min', 'C:7', 'E:min/b3'),
#   ('B:7', 'B:sus4', 'D'),
#   ('A:min', 'Bb:min/5', 'C#/3'),
#   ('C:min', 'E:7', 'Eb'),
#   ('A:min', 'C:7', 'D'),
#   ('A:maj6', 'F:min6/5', 'F:min7'),
#   ('B:min/5', 'G', 'G#'),
#   ('A:min', 'B:min', 'D:min'),
#   ('A:min(*5)', 'Ab/5', 'B:min'),
#   ('A:min(*5)', 'C#/3', 'G'),
#   ('Bb', 'E:min/b3', 'Eb'),
#   ('B:min/5', 'C#/3', 'F#:min'),
#   ('Bb', 'C', 'E:min/b3'),
#   ('A', 'C#', 'C#:7'),
#   ('A:maj6', 'B:hdim7/b3', 'E'),
#   ('A:sus4', 'C#:7', 'D:7(#9)'),
#   ('C:7', 'F#:min7', 'G'),
#   ('C:maj(9)', 'C:min', 'D'),
#   ('B:sus4', 'C', 'C#:maj7/3'),
#   ('A:7', 'Ab/5', 'Eb'),
#   ('B', 'D:maj6', 'G'),
#   ('Ab:7', 'F:min', 'G:7'),
#   ('Bb', 'E:7', 'F:min/5'),
#   ('C:7', 'E:min', 'F#'),
#   ('Bb:min/5', 'C#:maj7/3', 'D:dim7'),
#   ('A:min7(*5,b6)', 'B:min', 'F#:min7'),
#   ('Bb:min/5', 'C#/3', 'C:7'),
#   ('A:7(#9)', 'E:min', 'N'),
#   ('C#:sus4', 'G', 'G:sus4'),
#   ('A', 'D:maj6', 'D:min'),
#   ('C:min', 'E:min', 'F#:min'),
#   ('Ab', 'B:sus4', 'Bb:min'),
#   ('A:min', 'Bb', 'F:min'),
#   ('D:7(#9)', 'E:min/b3', 'G'),
#   ('Bb:min', 'D:min', 'E'),
#   ('A:7', 'F#:min', 'F:min/5'),
#   ('B:min', 'C#/3', 'F#'),
#   ('D:min', 'F#:min', 'F#:min7'),
#   ('A:7(#9)', 'D', 'Eb'),
#   ('B:sus4', 'Bb', 'F:min'),
#   ('A:maj6', 'A:min', 'B:7'),
#   ('D:7(#9)', 'F:min6/5', 'F:min7'),
#   ('C#', 'C#:sus4', 'G#:min'),
#   ('C', 'Eb', 'Eb:sus4'),
#   ('A:7', 'Db', 'Eb'),
#   ('A', 'F#:min7', 'G'),
#   ('C#:maj7/3', 'E:aug', 'F:min6/5'),
#   ('C', 'Eb:maj6', 'F'),
#   ('A:7', 'E', 'E:min'),
#   ('A:7(#9)', 'C#:maj7/3', 'N'),
#   ('A:min', 'F#:min', 'G'),
#   ('A:min(*5)', 'Ab', 'G'),
#   ('B:min', 'E:min/b3', 'G:maj/9'),
#   ('A:7(#9)', 'B:maj(*3)', 'N'),
#   ('A', 'B:min/5', 'G'),
#   ('B:min/5', 'C#:maj7/3', 'F#:min'),
#   ('A:min7(*5,b6)', 'F#:min', 'F#:min7'),
#   ('B:7', 'C#', 'C#:sus4'),
#   ('A:maj6', 'A:min', 'E:sus4(b7)'),
#   ('E', 'Eb', 'G:min/5'),
#   ('B:min', 'D:dim7', 'E:min/b3'),
#   ('A:min', 'A:min(*5)', 'D:min'),
#   ('A:min7(*5,b6)', 'B:min', 'G:sus4'),
#   ('A:min(*5)', 'Bb:min/5', 'G'),
#   ('Ab', 'C:7', 'G'),
#   ('C', 'Db', 'G:maj/9'),
#   ('Bb', 'C:maj(9)', 'D'),
#   ('B', 'C#:sus4', 'D'),
#   ('C#:maj7/3', 'E:min/b3', 'F:min6/5'),
#   ('Bb:min7', 'Eb:maj6', 'F:min/5'),
#   ('B:min', 'F#', 'F#:min7'),
#   ('A:7(#9)', 'B', 'G'),
#   ('Bb', 'Bb:min7', 'F'),
#   ('A:min', 'Eb', 'G:min/5'),
#   ('C', 'F', 'G:7'),
#   ('C', 'Db', 'E:min'),
#   ('C:maj(9)', 'F:maj6', 'G:sus4'),
#   ('A', 'Bb', 'G'),
#   ('B:7', 'D', 'F:min/5'),
#   ('B:min', 'B:min/5', 'F#'),
#   ('B:dim7', 'C:min', 'G'),
#   ('A:maj6', 'E', 'Eb:sus4'),
#   ('A', 'C#:maj7/3', 'C#:sus4'),
#   ('A:maj6', 'C', 'E'),
#   ('C', 'E:7', 'F'),
#   ('A', 'Ab/5', 'C#:sus4'),
#   ('B/5', 'Bb:min7', 'F'),
#   ('D:min', 'E', 'Eb/5'),
#   ('C#:sus4', 'E:min', 'F#'),
#   ('A', 'D:dim7', 'Eb:sus4'),
#   ('A', 'B:7', 'B:dim7'),
#   ('Bb:min', 'C#:maj7/3', 'F:min6/5'),
#   ('B', 'F#:min', 'G:maj/9'),
#   ('Bb', 'D', 'F#:min'),
#   ('C:min', 'E:aug', 'N'),
#   ('B:min/5', 'Eb', 'F#:min'),
#   ('B:min/5', 'E:sus4(b7)', 'F#:min'),
#   ('B:min/5', 'C', 'F#:min'),
#   ('B:7', 'E', 'Eb/5'),
#   ('Db', 'F#:min', 'F#:min7'),
#   ('Ab:7', 'B:dim7', 'F:min'),
#   ('Ab', 'G#:min', 'N'),
#   ('A:min', 'B:hdim7/b3', 'C'),
#   ('A:7(#9)', 'D', 'F:min'),
#   ('B:hdim7/b3', 'Bb', 'F:min'),
#   ('A:sus4', 'B', 'N'),
#   ('F#:min', 'G', 'G:sus4'),
#   ('D:maj6', 'E', 'G'),
#   ('B:hdim7/b3', 'B:min', 'G:maj/9'),
#   ('D:maj7', 'Eb/5', 'G'),
#   ('A', 'D:min', 'G#'),
#   ('Ab/5', 'B:min/5', 'F#:min'),
#   ('Bb', 'F:min/5', 'G:sus4'),
#   ('B:min', 'E:min', 'F:min'),
#   ('B:hdim7/b3', 'D:dim7', 'G:7'),
#   ('C#', 'Eb', 'Eb:sus4'),
#   ('A:min', 'C', 'D:dim7'),
#   ('B:min', 'E:aug', 'F:min7'),
#   ('Bb:min', 'G', 'G:sus4'),
#   ('B:7', 'D', 'D:maj7'),
#   ('F#:min7', 'F:maj6', 'G'),
#   ('A', 'B:min/5', 'C#:sus4'),
#   ('A:min7(*5,b6)', 'F#:min', 'G'),
#   ('Eb', 'Eb:sus4', 'G#:min'),
#   ('Ab', 'F:min', 'G:sus4'),
#   ('Bb:min/5', 'F:maj6', 'G'),
#   ('B:sus4', 'G', 'G#'),
#   ('A:min', 'D', 'G#'),
#   ('B', 'D', 'G#'),
#   ('B', 'Eb/5', 'G'),
#   ('C#', 'C#:sus4', 'D'),
#   ('A', 'C#:sus4', 'D:7(#9)'),
#   ('A', 'B:sus4', 'C#/3'),
#   ('A', 'A:min7(*5,b6)', 'D:min'),
#   ('A:min7(*5,b6)', 'B:min', 'G:min/5'),
#   ('A:min', 'Bb:min/5', 'C'),
#   ('A:min', 'B', 'F:min7'),
#   ('B', 'Bb:min/5', 'D'),
#   ('B/5', 'D:maj7', 'F#:min7'),
#   ('C#', 'C#:sus4', 'F:min/5'),
#   ('A:min', 'B', 'Bb:min7'),
#   ('A', 'C#:7', 'D:7(#9)'),
#   ('C#', 'F#:min7', 'N'),
#   ('A:min(*5)', 'B:dim7', 'B:min'),
#   ('E:min/b3', 'F#', 'G#'),
#   ('Bb', 'E', 'E:min'),
#   ('Ab/5', 'G#', 'N'),
#   ('C#', 'F#:min7', 'F:maj6'),
#   ('C#', 'C#:sus4', 'Eb:maj6'),
#   ('A:7(#9)', 'E:7', 'N'),
#   ('B:maj(*3)', 'C', 'C#:maj7/3'),
#   ('B:min', 'Bb:min7', 'Eb:maj6'),
#   ('Eb:sus4', 'F#:min', 'F#:min7'),
#   ('E:min/b3', 'Eb:maj6', 'N'),
#   ('A:min', 'B', 'B/5'),
#   ('A:min(*5)', 'C', 'C#/3'),
#   ('A', 'A:7', 'F:min'),
#   ('B', 'C#:7', 'E:sus4(b7)'),
#   ('A', 'F#', 'G:sus4'),
#   ('Bb', 'E', 'F#:min'),
#   ('Eb:sus4', 'F:min/5', 'G:min/5'),
#   ('A:maj6', 'D:maj7', 'E'),
#   ('Bb:min7', 'Eb/5', 'G'),
#   ('B:min', 'E:min', 'Eb:sus4'),
#   ('C', 'C#:maj7/3', 'G:min/5'),
#   ('B:7', 'E', 'F:maj6'),
#   ('B', 'Bb:min7', 'E:sus4(b7)'),
#   ('Ab', 'F#:min', 'F#:min7'),
#   ('B/5', 'B:dim7', 'B:min/5'),
#   ('Ab:7', 'Eb/5', 'F:min'),
#   ('A:7(#9)', 'Db', 'G'),
#   ('A:min(*5)', 'C', 'D'),
#   ('B', 'E:sus4(b7)', 'F:min'),
#   ('A:maj6', 'G', 'G:sus4'),
#   ('A', 'A:sus4', 'C#/3'),
#   ('A:7', 'B/5', 'D'),
#   ('B', 'D:7(#9)', 'G'),
#   ('A:min', 'C:maj(9)', 'G'),
#   ('Eb/5', 'F:min6/5', 'F:min7'),
#   ('B:hdim7/b3', 'B:sus4', 'D:dim7'),
#   ('C#:maj7/3', 'Eb:sus4', 'F:min6/5'),
#   ('D', 'Eb/5', 'F#'),
#   ('B', 'B:7', 'Bb:min/5'),
#   ('B', 'C#', 'C#:sus4'),
#   ('E', 'E:sus4(b7)', 'G:maj/9'),
#   ('Ab:7', 'Db', 'G:maj/9'),
#   ('Bb:min7', 'D', 'D:min'),
#   ('Ab/5', 'B', 'F#:min'),
#   ('B:min', 'C#:sus4', 'E:min'),
#   ('Bb:min/5', 'Eb', 'Eb:sus4'),
#   ('A:7(#9)', 'F:min6/5', 'G'),
#   ('B:dim7', 'B:min/5', 'Eb:maj6'),
#   ('Ab/5', 'D:7(#9)', 'N'),
#   ('B:dim7', 'C:maj(9)', 'D'),
#   ('A:sus4', 'D:7(#9)', 'F:maj6'),
#   ('C#', 'C:maj(9)', 'F:maj6'),
#   ('B', 'C', 'N'),
#   ('Bb', 'D:dim7', 'Eb'),
#   ('Bb', 'D:maj7', 'Eb'),
#   ('A:min7(*5,b6)', 'Bb', 'G'),
#   ('B:hdim7/b3', 'B:min', 'F:min'),
#   ('B:min', 'Eb:sus4', 'F#'),
#   ('C#', 'F:min6/5', 'F:min7'),
#   ('A:7', 'Eb', 'G:min/5'),
#   ('F:min/5', 'G:min/5', 'G:sus4'),
#   ('B:min', 'Bb', 'D:min'),
#   ('Ab', 'B:min', 'Bb:min'),
#   ('Ab/5', 'B:min', 'N'),
#   ('B', 'E:min/b3', 'F#:min'),
#   ('B:min/5', 'Bb', 'D:min'),
#   ('A:sus4', 'E:aug', 'F:min7'),
#   ('C', 'C#:maj7/3', 'D:7(#9)'),
#   ('A:sus4', 'D:7(#9)', 'E:sus4(b7)'),
#   ('B/5', 'D:7(#9)', 'F#:min7'),
#   ('A', 'B:sus4', 'G:7'),
#   ('A', 'E:7', 'Eb/5'),
#   ('C:min', 'G:sus4', 'N'),
#   ('A:min', 'C', 'C:min'),
#   ('B:hdim7/b3', 'D:dim7', 'G#:min'),
#   ('A:maj6', 'Eb:maj6', 'N'),
#   ('C:maj(9)', 'F:min6/5', 'F:min7'),
#   ('Ab:7', 'E:aug', 'F:min'),
#   ('A:min7(*5,b6)', 'F:min7', 'G'),
#   ('A:min', 'E:min', 'G'),
#   ('A', 'D:min', 'F#'),
#   ('A:min(*5)', 'Ab:7', 'F:min'),
#   ('B/5', 'D:min', 'E'),
#   ('Db', 'G', 'G#'),
#   ('A:min(*5)', 'Bb', 'C:min'),
#   ('B:min', 'C#', 'D:maj6'),
#   ('B/5', 'F', 'F#:min'),
#   ('A:sus4', 'B/5', 'F#:min'),
#   ('C#:maj7/3', 'F:min/5', 'G:min/5'),
#   ('A:sus4', 'Bb:min/5', 'D:7(#9)'),
#   ('B:sus4', 'E:min', 'F#:min'),
#   ('B/5', 'F#:min7', 'G:min/5'),
#   ('A', 'C:7', 'E:7'),
#   ('B:min', 'C#', 'F#:min7'),
#   ('C:maj(9)', 'Db', 'Eb'),
#   ('B:7', 'C', 'C#:maj7/3'),
#   ('A:sus4', 'B:min', 'E:min/b3'),
#   ('B', 'Db', 'Eb'),
#   ('B', 'B:7', 'F:maj6'),
#   ('Bb', 'Bb:min', 'Eb'),
#   ('A:7(#9)', 'B:hdim7/b3', 'B:min'),
#   ('D', 'D:maj6', 'F#:min'),
#   ('Bb', 'Eb', 'F'),
#   ('Bb', 'E', 'Eb'),
#   ('A:min7(*5,b6)', 'Bb', 'C'),
#   ('Bb:min/5', 'C#:maj7/3', 'Db'),
#   ('Bb', 'C', 'E'),
#   ('C#/3', 'E', 'E:sus4(b7)'),
#   ('D:min', 'G', 'G:sus4'),
#   ('A:min(*5)', 'B:min', 'Eb'),
#   ('E:min', 'F#:min', 'G#:min'),
#   ('A:7(#9)', 'B:hdim7/b3', 'D:dim7'),
#   ('Ab:7', 'C:min', 'Eb'),
#   ('A:min', 'Ab', 'C'),
#   ('B/5', 'F#:min7', 'G#'),
#   ('Ab:7', 'F:maj6', 'G'),
#   ('A', 'B:sus4', 'C:maj(9)'),
#   ('A:7', 'B:7', 'E'),
#   ('B:min/5', 'Bb', 'Eb'),
#   ('Bb:min/5', 'C#/3', 'F:min7'),
#   ('Eb', 'F:min7', 'G:min/5'),
#   ('C:7', 'E:aug', 'G'),
#   ('Bb', 'C', 'C:7'),
#   ('A:min7(*5,b6)', 'C#:7', 'G'),
#   ('B:hdim7/b3', 'C:maj(9)', 'D:dim7'),
#   ('A:min(*5)', 'B:7', 'D'),
#   ('B/5', 'B:hdim7/b3', 'D:dim7'),
#   ('F:min/5', 'G:maj/9', 'G:min/5'),
#   ('D:maj6', 'E:aug', 'G'),
#   ('E', 'F:min/5', 'G#:min'),
#   ('E:aug', 'F#', 'F:min7'),
#   ('C:min', 'F:min/5', 'G'),
#   ('B:min', 'D:maj6', 'E:sus4(b7)'),
#   ('A:min', 'B', 'F:maj6'),
#   ('A:min(*5)', 'B:min', 'N'),
#   ('C', 'F:min/5', 'G#:min'),
#   ('A:7(#9)', 'B:7', 'E'),
#   ('A', 'B/5', 'B:sus4'),
#   ('Bb', 'C', 'C#:sus4'),
#   ('Eb:maj6', 'F#', 'N'),
#   ('A:7', 'B:sus4', 'D'),
#   ('Bb:min/5', 'C:maj(9)', 'F:maj6'),
#   ('C:min', 'E:sus4(b7)', 'G'),
#   ('B:sus4', 'D:min', 'E'),
#   ('A:7(#9)', 'D', 'F:maj6'),
#   ('E:7', 'F', 'G'),
#   ('B/5', 'B:7', 'B:min/5'),
#   ('C', 'C#:maj7/3', 'D:maj7'),
#   ('Ab', 'C#:7', 'N'),
#   ('A:min(*5)', 'B:min', 'D:7(#9)'),
#   ('A', 'B:sus4', 'G:min/5'),
#   ('A', 'D:7(#9)', 'D:dim7'),
#   ('C#', 'G', 'G:sus4'),
#   ('Eb:maj6', 'G:maj/9', 'N'),
#   ('A:min', 'C#', 'G#'),
#   ('A:min(*5)', 'D:min', 'E'),
#   ('C#', 'C#:sus4', 'F:min'),
#   ('A:min7(*5,b6)', 'B', 'G'),
#   ('A:maj6', 'C:maj(9)', 'F:maj6'),
#   ('A:min', 'D:7(#9)', 'G#'),
#   ('Ab', 'D', 'D:min'),
#   ('B', 'D', 'E:aug'),
#   ('B', 'B:sus4', 'Bb'),
#   ('B', 'Bb:min', 'D:min'),
#   ('Ab', 'C', 'C#:maj7/3'),
#   ('C', 'D:dim7', 'Db'),
#   ('Ab:7', 'B:hdim7/b3', 'Db'),
#   ('C#:sus4', 'E', 'G#:min'),
#   ('A', 'A:7', 'Bb'),
#   ('A:7', 'D', 'F#:min7'),
#   ('A:min(*5)', 'B:min', 'E:aug'),
#   ('Ab', 'Bb:min', 'G#'),
#   ('D:maj6', 'Eb:maj6', 'N'),
#   ('A', 'A:sus4', 'Bb:min7'),
#   ('C', 'C#:maj7/3', 'Eb'),
#   ('D', 'E:aug', 'F:min7'),
#   ('A:7(#9)', 'C', 'C#/3'),
#   ('C', 'C:maj(9)', 'Db'),
#   ('C:min', 'Eb', 'G#'),
#   ('A:sus4', 'F:min/5', 'G:min/5'),
#   ('C:maj(9)', 'C:min', 'F:maj6'),
#   ('B/5', 'F#:min', 'G#'),
#   ('A:min', 'B', 'G:maj/9'),
#   ('C#', 'C#:sus4', 'F'),
#   ('C#:sus4', 'G', 'G#'),
#   ('B:maj(*3)', 'C:maj(9)', 'F#:min'),
#   ('E', 'Eb:sus4', 'G#:min'),
#   ('D:maj6', 'D:min', 'G'),
#   ('B:7', 'D', 'G:min/5'),
#   ('A:7', 'C:maj(9)', 'F:maj6'),
#   ('C', 'D', 'F:min7'),
#   ('Ab:7', 'E', 'E:min'),
#   ('B:hdim7/b3', 'D:dim7', 'Eb'),
#   ('C:min', 'E:min/b3', 'N'),
#   ('B:maj(*3)', 'F#:min', 'F:min'),
#   ('A:7(#9)', 'D', 'E:min'),
#   ('C', 'C#:maj7/3', 'D:min'),
#   ('B:min', 'E:min/b3', 'G:min/5'),
#   ('B', 'C#:maj7/3', 'F#:min'),
#   ('A:maj6', 'A:min', 'Eb:sus4'),
#   ('Bb', 'C:min', 'Eb:maj6'),
#   ('B:dim7', 'B:maj(*3)', 'Eb:maj6'),
#   ('Bb', 'D:7(#9)', 'Eb'),
#   ('Ab/5', 'B/5', 'Eb'),
#   ('D:dim7', 'Eb', 'Eb:sus4'),
#   ('F:min/5', 'G#', 'G:min/5'),
#   ('C#:maj7/3', 'E', 'F:min6/5'),
#   ('B', 'D', 'G#:min'),
#   ('B', 'B:hdim7/b3', 'D:dim7'),
#   ('Bb:min7', 'E:7', 'F'),
#   ('A:min(*5)', 'B', 'B:sus4'),
#   ('B:7', 'E', 'G:7'),
#   ('B:min/5', 'D', 'D:min'),
#   ('Ab:7', 'E:min', 'F#:min'),
#   ('A:7', 'E:aug', 'F:min/5'),
#   ('A:min(*5)', 'B:maj(*3)', 'E'),
#   ('Bb', 'C:maj(9)', 'D:min'),
#   ('Bb:min7', 'C#:sus4', 'F'),
#   ('C:min', 'Eb', 'Eb/5'),
#   ('C', 'C#:sus4', 'F'),
#   ('A', 'C', 'C#/3'),
#   ('A:7', 'F#:min', 'F:min6/5'),
#   ('Bb:min', 'D:maj6', 'G'),
#   ('B/5', 'B:min/5', 'D:dim7'),
#   ('Bb', 'E', 'G#:min'),
#   ('B:hdim7/b3', 'B:min', 'F:min/5'),
#   ('B/5', 'B:min', 'F#:min7'),
#   ('C', 'C#:maj7/3', 'E:min/b3'),
#   ('C#', 'F', 'G'),
#   ('A:7(#9)', 'E:aug', 'F:min/5'),
#   ('D:7(#9)', 'D:min', 'G'),
#   ('Bb:min7', 'E:min', 'Eb:maj6'),
#   ('F:min6/5', 'F:min7', 'N'),
#   ('A', 'Ab/5', 'D:dim7'),
#   ('B:min/5', 'Bb', 'F:min/5'),
#   ('B:min', 'D:maj6', 'D:maj7'),
#   ('B:min', 'C#', 'C#:sus4'),
#   ('A:maj6', 'A:min', 'B:hdim7/b3'),
#   ('B', 'C:min', 'Eb'),
#   ('Ab', 'Ab/5', 'Bb:min'),
#   ('A:min(*5)', 'Bb:min7', 'F'),
#   ('A:min', 'D', 'Eb/5'),
#   ('Bb', 'C:min', 'Eb/5'),
#   ('A:sus4', 'Bb', 'C'),
#   ('C#/3', 'F:maj6', 'G'),
#   ('Bb:min/5', 'C#/3', 'E:7'),
#   ('E:min', 'Eb:maj6', 'F#'),
#   ('C#:7', 'D', 'D:min'),
#   ('A:maj6', 'E', 'F:min6/5'),
#   ('B', 'D:min', 'G:sus4'),
#   ('Bb:min7', 'C#:sus4', 'Eb:maj6'),
#   ('Ab:7', 'Db', 'F:min7'),
#   ('B:hdim7/b3', 'E', 'E:min'),
#   ('B/5', 'B:min/5', 'E:sus4(b7)'),
#   ('Ab/5', 'Eb', 'F#'),
#   ('A', 'C#', 'D:min'),
#   ('B', 'C#:maj7/3', 'D:min'),
#   ('D:7(#9)', 'D:maj7', 'G'),
#   ('B', 'B:sus4', 'C#/3'),
#   ('B:hdim7/b3', 'D:dim7', 'F:maj6'),
#   ('Ab/5', 'E', 'E:min'),
#   ('D:7(#9)', 'F:min/5', 'G:min/5'),
#   ('B:7', 'C:7', 'G'),
#   ('A:maj6', 'C:7', 'E'),
#   ('C', 'C:min', 'F:min/5'),
#   ('A', 'A:7', 'Bb:min'),
#   ('B:min', 'Bb:min/5', 'E:min/b3'),
#   ('Bb', 'E:min', 'F:min'),
#   ('C#:7', 'F:min6/5', 'F:min7'),
#   ('A:min7(*5,b6)', 'Eb', 'Eb:sus4'),
#   ('B:min/5', 'D:maj7', 'F#:min'),
#   ('Ab', 'B/5', 'N'),
#   ('A:min(*5)', 'F#', 'G'),
#   ('A:7', 'A:sus4', 'D'),
#   ('E', 'G#', 'G#:min'),
#   ('A', 'B:7', 'G#'),
#   ('C:maj(9)', 'D:maj7', 'F:maj6'),
#   ('B', 'B:min', 'N'),
#   ('A:7(#9)', 'D', 'D:maj6'),
#   ('C:maj(9)', 'E:7', 'F:maj6'),
#   ('F#:min', 'F:min', 'F:min/5'),
#   ('B', 'D:min', 'G:7'),
#   ('B:hdim7/b3', 'Bb', 'C:min'),
#   ('A:min(*5)', 'B:min', 'Eb:maj6'),
#   ('B/5', 'C#:maj7/3', 'F:min6/5'),
#   ('Ab:7', 'B:7', 'F:min'),
#   ('D:maj6', 'E', 'G#:min'),
#   ('A:min', 'D:min', 'F:min7'),
#   ('Bb:min7', 'F', 'F:min6/5'),
#   ('D:min', 'F:maj6', 'G'),
#   ('B:min', 'D:maj6', 'G:sus4'),
#   ('Ab', 'Bb:min', 'E:7'),
#   ('D', 'D:min', 'F:maj6'),
#   ('C#:sus4', 'C:min', 'N'),
#   ('B', 'B:7', 'C:min'),
#   ('A:min', 'F:min7', 'G#'),
#   ('A', 'A:sus4', 'F:min7'),
#   ('B:min', 'C:min', 'D:maj6'),
#   ('D:dim7', 'D:min', 'E'),
#   ('B:hdim7/b3', 'B:min', 'C#:maj7/3'),
#   ('B:min/5', 'Bb', 'C:min'),
#   ('B:min/5', 'D:min', 'E'),
#   ('C#:maj7/3', 'C#:sus4', 'F:min6/5'),
#   ('B:min/5', 'Bb', 'C'),
#   ('Db', 'Eb', 'G#'),
#   ('A:maj6', 'D', 'D:min'),
#   ('Bb', 'C:min', 'E:aug'),
#   ('Ab:7', 'D:7(#9)', 'G'),
#   ('B:min/5', 'C:maj(9)', 'F:maj6'),
#   ('A:maj6', 'C:7', 'D'),
#   ('A', 'A:7', 'E:aug'),
#   ('B', 'D:min', 'F:min/5'),
#   ('Ab', 'F', 'F:min'),
#   ('A:min(*5)', 'Bb:min7', 'G'),
#   ('B/5', 'Bb', 'D:min'),
#   ('Bb:min7', 'C:min', 'F'),
#   ('B:hdim7/b3', 'B:maj(*3)', 'E'),
#   ('A:7', 'C:min', 'N'),
#   ('B', 'C:7', 'E:sus4(b7)'),
#   ('A', 'C', 'C#:7'),
#   ('B', 'B:7', 'D:maj7'),
#   ('A', 'C#:sus4', 'F:min/5'),
#   ('Bb:min7', 'Eb:maj6', 'F:min7'),
#   ('C#', 'C#:sus4', 'C:maj(9)'),
#   ('C:maj(9)', 'E:aug', 'F:maj6'),
#   ('A:7', 'C#:maj7/3', 'D'),
#   ('Bb', 'D:maj6', 'F:min'),
#   ('B:min', 'Bb', 'C'),
#   ('A:maj6', 'A:min', 'F#:min'),
#   ('C:7', 'F#', 'G'),
#   ('Db', 'Eb', 'F#:min'),
#   ('B:dim7', 'C#:maj7/3', 'Eb:maj6'),
#   ('A', 'B:dim7', 'D:dim7'),
#   ('B/5', 'B:min/5', 'E:min/b3'),
#   ('B', 'E:min', 'N'),
#   ('A:7', 'G', 'G:sus4'),
#   ('B', 'Db', 'F#:min'),
#   ('B:hdim7/b3', 'B:min', 'G#'),
#   ('B:min', 'E:min/b3', 'F#:min7'),
#   ('A:min(*5)', 'B:min', 'Eb/5'),
#   ('B', 'Db', 'E:sus4(b7)'),
#   ('C', 'F', 'N'),
#   ('B:hdim7/b3', 'B:min', 'F#:min7'),
#   ('A', 'B:7', 'B:min/5'),
#   ('A:min', 'F:maj6', 'G#'),
#   ('Ab', 'E:sus4(b7)', 'N'),
#   ('Db', 'E:aug', 'Eb:sus4'),
#   ('C', 'C#:maj7/3', 'G:maj/9'),
#   ('A:7', 'E:sus4(b7)', 'F#:min'),
#   ('E:min', 'F#', 'F:maj6'),
#   ('C:maj(9)', 'F#', 'F:maj6'),
#   ('A:min(*5)', 'C', 'Db'),
#   ('A:min', 'C#', 'C#:sus4'),
#   ('A:7', 'F#', 'F#:min'),
#   ('Ab', 'E:min/b3', 'N'),
#   ('D:7(#9)', 'E:7', 'G'),
#   ('A', 'A:sus4', 'G:min/5'),
#   ('Bb:min7', 'D:dim7', 'Eb:maj6'),
#   ('Bb:min', 'C', 'F'),
#   ('A:7(#9)', 'Eb/5', 'N'),
#   ('A:maj6', 'E:min/b3', 'F#'),
#   ('A:min(*5)', 'B:min', 'C#'),
#   ('B', 'C:7', 'G'),
#   ('E:min', 'F#:min', 'F:min'),
#   ('A:maj6', 'E', 'F#:min7'),
#   ('D:min', 'E', 'G#'),
#   ('B', 'B:dim7', 'D:min'),
#   ('A:min7(*5,b6)', 'A:sus4', 'D:7(#9)'),
#   ('Bb:min/5', 'C#', 'F#:min7'),
#   ('A:7', 'B', 'B:sus4'),
#   ('Eb', 'Eb:sus4', 'N'),
#   ('A:7', 'F', 'G'),
#   ('B:7', 'C#:sus4', 'D'),
#   ('B:min', 'C:maj(9)', 'F#'),
#   ('A:7', 'G', 'G#'),
#   ('A', 'B:min', 'E:sus4(b7)'),
#   ('B:maj(*3)', 'E', 'F:min'),
# ...
#   ('A', 'B', 'Eb/5'),
#   ('Ab', 'Db', 'G:sus4'),
#   ('B:min', 'E', 'G#'),
#   ('C#', 'F#:min', 'F:min/5'),
#   ('A', 'C#:maj7/3', 'G#:min'),
#   ('Bb:min', 'Db', 'G:min/5'),
#   ('C#', 'Db', 'F#:min'),
#   ('Ab', 'B:hdim7/b3', 'Db'),
#   ('A', 'B', 'C:maj(9)'),
#   ('D:min', 'F:min/5', 'N'),
#   ('D:dim7', 'G', 'N'),
#   ('A', 'D:maj6', 'F#:min'),
#   ('E', 'E:7', 'G'),
#   ('D', 'Db', 'G'),
#   ('A', 'Ab:7', 'G#:min'),
#   ('C:maj(9)', 'Eb', 'F:min'),
#   ('Bb:min', 'C#:maj7/3', 'Db'),
#   ('A', 'A:min(*5)', 'D:maj7'),
#   ('Bb:min7', 'E', 'N'),
#   ('B:hdim7/b3', 'C#:7', 'F#:min'),
#   ('A:7(#9)', 'Bb:min', 'F:min'),
#   ('C:maj(9)', 'E', 'N'),
#   ('B:min', 'D', 'F:min/5'),
#   ('Bb:min', 'Eb/5', 'F:min'),
#   ('A:min', 'E', 'E:aug'),
#   ('A', 'F#:min', 'G#'),
#   ('B:sus4', 'G', 'N'),
#   ('A', 'Bb:min', 'D:maj7'),
#   ('A:min7(*5,b6)', 'C:min', 'G:7'),
#   ('D:7(#9)', 'E:aug', 'G:7'),
#   ('D:maj7', 'E', 'N'),
#   ('A', 'C#/3', 'E:min'),
#   ('Ab:7', 'E', 'N'),
#   ('C:min', 'D:min', 'G:7'),
#   ('Bb:min', 'Db', 'G:sus4'),
#   ('Ab', 'Eb', 'F:min6/5'),
#   ('A', 'E:min', 'F#:min7'),
#   ('A:min7(*5,b6)', 'Bb:min', 'Db'),
#   ('F:min/5', 'G:7', 'N'),
#   ('C:min', 'F:min', 'F:min7'),
#   ('Bb', 'G', 'N'),
#   ('A', 'B:maj(*3)', 'D'),
#   ('A', 'A:maj6', 'D:maj7'),
#   ('C#', 'G', 'N'),
#   ('A:min', 'E', 'F#:min7'),
#   ('A', 'E', 'F:min6/5'),
#   ('A', 'B', 'Bb:min7'),
#   ('Ab', 'C', 'Eb'),
#   ('Ab', 'Ab/5', 'Db'),
#   ('F', 'F:min/5', 'N'),
#   ('A', 'Bb:min7', 'D:maj7'),
#   ('A:min', 'C#', 'F#:min'),
#   ('B:min', 'C', 'F:min'),
#   ('A', 'D:maj7', 'F:maj6'),
#   ('D', 'E:aug', 'G'),
#   ('C', 'E:min', 'F:min'),
#   ('A', 'E:min/b3', 'G:maj/9'),
#   ('D', 'E', 'F:min'),
#   ('Ab', 'C', 'G'),
#   ('A:min', 'C:min', 'E'),
#   ('B:dim7', 'B:min/5', 'C'),
#   ('B:min', 'C#/3', 'D'),
#   ('B', 'B/5', 'E'),
#   ('A', 'C', 'E'),
#   ('C:min', 'F:min/5', 'G:7'),
#   ('Bb:min', 'D:dim7', 'Db'),
#   ('D', 'G:min/5', 'N'),
#   ('B:7', 'C', 'F:min'),
#   ('A:min', 'Bb:min/5', 'E'),
#   ('D', 'D:maj7', 'G'),
#   ('Ab/5', 'B:min', 'E'),
#   ('Bb:min', 'C#', 'F:min'),
#   ('D', 'F', 'N'),
#   ('D:7(#9)', 'Eb:sus4', 'G:7'),
#   ('B:dim7', 'C', 'F#:min7'),
#   ('A', 'E', 'F#'),
#   ('Ab', 'D:min', 'Eb'),
#   ('A', 'D', 'F:min7'),
#   ('E', 'Eb', 'N'),
#   ('Ab:7', 'C', 'G'),
#   ('C#:7', 'D', 'G'),
#   ('B:min', 'C:min', 'F:min'),
#   ('A:sus4', 'B:min', 'E'),
#   ('A:min7(*5,b6)', 'Ab', 'Eb'),
#   ('A', 'B:dim7', 'F#:min'),
#   ('B:hdim7/b3', 'D:7(#9)', 'G:7'),
#   ('F#:min', 'F:maj6', 'N'),
#   ('B:hdim7/b3', 'D', 'G'),
#   ('A', 'B/5', 'G#:min'),
#   ('B:min', 'C', 'G:7'),
#   ('A:7', 'C', 'G'),
#   ('E:sus4(b7)', 'G', 'N'),
#   ('C', 'Eb:maj6', 'G'),
#   ('B:7', 'Eb', 'F:min'),
#   ('C', 'C#:7', 'G'),
#   ('B:sus4', 'F:min/5', 'N'),
#   ('B:min', 'C:min', 'D'),
#   ('B:sus4', 'Bb:min', 'Db'),
#   ('Ab', 'D', 'E'),
#   ('B:min', 'Db', 'G:7'),
#   ('C#:7', 'F#:min', 'G'),
#   ('A', 'C:7', 'E:min'),
#   ('A', 'D', 'G:7'),
#   ('A', 'C:min', 'F#:min'),
#   ('A:min', 'C:maj(9)', 'E'),
#   ('B:maj(*3)', 'Bb:min', 'F:min'),
#   ('C:min', 'D:min', 'F:min'),
#   ('B:min', 'D', 'G#'),
#   ('B:dim7', 'E', 'E:7'),
#   ('A:min', 'Bb:min7', 'E'),
#   ('C#:7', 'F#:min', 'G:7'),
#   ('C', 'F:min7', 'G'),
#   ('A', 'B', 'F:maj6'),
#   ('B:min', 'Eb', 'F:min'),
#   ...},
#  '111D': {('A', 'A:7(#9)', 'D'),
#   ('A', 'A:7(#9)', 'N'),
#   ('A', 'A:min', 'B'),
#   ('A', 'A:sus4', 'B'),
#   ('A', 'A:sus4', 'D'),
#   ('A', 'A:sus4', 'D:maj7'),
#   ('A', 'A:sus4', 'E'),
#   ('A', 'A:sus4', 'E:min'),
#   ('A', 'A:sus4', 'F#:min'),
#   ('A', 'A:sus4', 'G#:min'),
#   ('A', 'A:sus4', 'G:maj/9'),
#   ('A', 'A:sus4', 'N'),
#   ('A', 'Ab', 'N'),
#   ('A', 'B', 'D:dim7'),
#   ('A', 'B', 'E:7'),
#   ('A', 'B', 'G'),
#   ('A', 'B:maj(*3)', 'E'),
#   ('A', 'B:min', 'G:7'),
#   ('A', 'B:min/5', 'F#:min'),
#   ('A', 'D', 'D:dim7'),
#   ('A', 'D', 'E:7'),
#   ('A', 'D', 'Eb/5'),
#   ('A', 'D:dim7', 'D:maj7'),
#   ('A', 'D:dim7', 'E'),
#   ('A', 'D:dim7', 'E:min'),
#   ('A', 'D:dim7', 'F#:min'),
#   ('A', 'D:dim7', 'G#:min'),
#   ('A', 'D:dim7', 'G:maj/9'),
#   ('A', 'D:dim7', 'N'),
#   ('A', 'D:maj7', 'D:min'),
#   ('A', 'D:maj7', 'E:7'),
#   ('A', 'D:maj7', 'G'),
#   ('A', 'D:min', 'E:min'),
#   ('A', 'D:min', 'F#:min'),
#   ('A', 'D:min', 'G#:min'),
#   ('A', 'D:min', 'G:maj/9'),
#   ('A', 'D:min', 'N'),
#   ('A', 'E', 'E:sus4(b7)'),
#   ('A', 'E', 'G'),
#   ('A', 'E:7', 'E:min'),
#   ('A', 'E:7', 'F#:min'),
#   ('A', 'E:7', 'G#:min'),
#   ('A', 'E:7', 'G:maj/9'),
#   ('A', 'E:7', 'N'),
#   ('A', 'E:min', 'G'),
#   ('A', 'Eb:maj6', 'N'),
#   ('A', 'F#:min', 'G'),
#   ('A', 'G', 'G#:min'),
#   ('A', 'G', 'G:maj/9'),
#   ('A:7', 'B:min', 'D'),
#   ('A:7', 'D', 'D:7(#9)'),
#   ('A:7', 'D', 'E'),
#   ('A:7', 'D', 'G'),
#   ('A:7', 'D', 'N'),
#   ('A:7(#9)', 'B:min', 'D'),
#   ('A:7(#9)', 'D', 'D:7(#9)'),
#   ('A:7(#9)', 'D', 'E'),
#   ('A:7(#9)', 'E', 'N'),
#   ('A:7(#9)', 'F#:min', 'N'),
#   ('A:7(#9)', 'F:min/5', 'N'),
#   ('A:min', 'B:7', 'E'),
#   ('A:min', 'B:dim7', 'C'),
#   ('A:min', 'B:maj(*3)', 'E'),
#   ('A:min', 'C', 'F:min'),
#   ('A:min', 'E', 'E:sus4(b7)'),
#   ('A:min', 'E', 'G'),
#   ('A:min', 'E', 'G#'),
#   ('A:min(*5)', 'B:min', 'D'),
#   ('A:min(*5)', 'B:min', 'E'),
#   ('A:min(*5)', 'B:min', 'G:7'),
#   ('A:min7(*5,b6)', 'B:min', 'D'),
#   ('A:min7(*5,b6)', 'B:min', 'E'),
#   ('A:min7(*5,b6)', 'B:min', 'G:7'),
#   ('Ab', 'Ab/5', 'Eb'),
#   ('Ab', 'Ab:7', 'Db'),
#   ('Ab', 'Bb', 'Eb'),
#   ('Ab', 'Bb:min', 'Eb'),
#   ('Ab', 'C:min', 'Eb'),
#   ('Ab', 'D', 'N'),
#   ('Ab', 'Db', 'F:min'),
#   ('Ab', 'E', 'N'),
#   ('Ab', 'Eb', 'Eb:sus4'),
#   ('Ab', 'F#:min', 'N'),
#   ('Ab', 'F:min/5', 'N'),
#   ('Ab', 'G', 'N'),
#   ('Ab/5', 'Eb', 'F:min'),
#   ('Ab:7', 'Bb:min', 'Db'),
#   ('B', 'B:maj(*3)', 'E'),
#   ('B', 'B:min', 'D'),
#   ('B', 'B:sus4', 'E'),
#   ('B', 'D', 'D:7(#9)'),
#   ('B', 'D', 'G'),
#   ('B:7', 'B:min', 'D'),
#   ('B:7', 'B:min', 'E'),
#   ('B:7', 'D', 'D:7(#9)'),
#   ('B:7', 'D', 'G'),
#   ('B:7', 'D', 'N'),
#   ('B:7', 'E', 'E:7'),
#   ('B:7', 'E', 'N'),
#   ('B:dim7', 'Bb', 'C'),
#   ('B:dim7', 'C', 'C#/3'),
#   ('B:dim7', 'C', 'C#:maj7/3'),
#   ('B:dim7', 'C', 'D'),
#   ('B:dim7', 'C', 'Db'),
#   ('B:dim7', 'C', 'Eb:maj6'),
#   ('B:maj(*3)', 'B:min', 'E'),
#   ('B:maj(*3)', 'D', 'E'),
#   ('B:maj(*3)', 'E', 'E:7'),
#   ('B:maj(*3)', 'E', 'N'),
#   ('B:min', 'D', 'Eb/5'),
#   ('B:min', 'D', 'F#'),
#   ('B:min', 'D', 'F#:min'),
#   ('B:min', 'E', 'E:sus4(b7)'),
#   ('B:min', 'E', 'F#'),
#   ('B:min', 'F#', 'G:7'),
#   ('B:min/5', 'C#', 'F#:min'),
#   ('B:min/5', 'C#:7', 'F#:min'),
#   ('B:min/5', 'F#:min', 'N'),
#   ('Bb', 'Bb:min', 'F:min'),
#   ('Bb', 'C', 'G'),
#   ('Bb', 'C:min', 'G:7'),
#   ('C', 'C#/3', 'F:min'),
#   ('C', 'C#/3', 'G'),
#   ('C', 'C#:maj7/3', 'F:min'),
#   ('C', 'C#:maj7/3', 'G'),
#   ('C', 'C:7', 'G'),
#   ('C', 'D', 'F:min'),
#   ('C', 'D:maj6', 'G'),
#   ('C', 'Db', 'F:min'),
#   ('C', 'Db', 'G'),
#   ('C', 'Eb', 'G'),
#   ('C', 'F:maj6', 'G'),
#   ('C', 'F:min/5', 'N'),
#   ('C', 'G', 'G:sus4'),
#   ('C#', 'C#:sus4', 'F#:min'),
#   ('C#', 'E', 'F#:min'),
#   ('C#', 'E:min', 'F#:min'),
#   ('C#:7', 'E', 'F#:min'),
#   ('C#:7', 'E:min', 'F#:min'),
#   ('C:7', 'G', 'N'),
#   ('C:min', 'F:min', 'G'),
#   ('C:min', 'F:min', 'N'),
#   ('C:min', 'G', 'G:7'),
#   ('C:min', 'G:7', 'N'),
#   ('D', 'D:7(#9)', 'Eb/5'),
#   ('D', 'D:7(#9)', 'F#:min'),
#   ('D', 'D:maj6', 'G'),
#   ('D', 'E', 'E:sus4(b7)'),
#   ('D', 'E', 'Eb/5'),
#   ('D', 'Eb', 'G'),
#   ('D', 'Eb/5', 'N'),
#   ('D', 'Eb:maj6', 'N'),
#   ('D', 'F', 'G'),
#   ('D', 'F#:min', 'G'),
#   ('D', 'F:maj6', 'G'),
#   ('D', 'G', 'G:sus4'),
#   ('D:7(#9)', 'G', 'G:7'),
#   ('D:maj6', 'G', 'N'),
#   ('Db', 'Eb', 'F:min'),
#   ('E', 'E:7', 'E:sus4(b7)'),
#   ('E', 'E:sus4(b7)', 'N'),
#   ('E', 'Eb:maj6', 'N'),
#   ('E:min', 'F#:min', 'N'),
#   ('Eb', 'Eb:sus4', 'F:min'),
#   ('Eb', 'G', 'N'),
#   ('Eb:maj6', 'F#:min', 'N'),
#   ('Eb:maj6', 'F:min/5', 'N'),
#   ('Eb:maj6', 'G', 'N'),
#   ('F', 'G', 'N'),
#   ('F:maj6', 'G', 'N'),
#   ('F:min', 'F:min/5', 'N'),
#   ('F:min/5', 'G:min/5', 'N'),
#   ('G', 'G:sus4', 'N')},
#  '111U': {('A', 'A:7', 'B'),
#   ('A', 'A:7', 'D:maj7'),
#   ('A', 'A:7', 'E'),
#   ('A', 'A:7', 'E:min'),
#   ('A', 'A:7', 'G#:min'),
#   ('A', 'A:7', 'G:maj/9'),
#   ('A', 'A:7', 'N'),
#   ('A', 'A:maj6', 'E'),
#   ('A', 'Ab/5', 'N'),
#   ('A', 'B', 'B:min'),
#   ('A', 'B', 'C#:7'),
#   ('A', 'B', 'C#:sus4'),
#   ('A', 'B', 'E:sus4(b7)'),
#   ('A', 'B', 'G:sus4'),
#   ('A', 'B/5', 'F#:min'),
#   ('A', 'B:7', 'D:maj7'),
#   ('A', 'B:7', 'E:min'),
#   ('A', 'B:7', 'F#:min'),
#   ('A', 'B:7', 'G#:min'),
#   ('A', 'B:7', 'G:maj/9'),
#   ('A', 'B:7', 'N'),
#   ('A', 'B:maj(*3)', 'F#:min'),
#   ('A', 'B:min', 'D:maj7'),
#   ('A', 'B:min', 'F#:min'),
#   ('A', 'B:min', 'G#:min'),
#   ('A', 'B:min', 'G:maj/9'),
#   ('A', 'B:min', 'N'),
#   ('A', 'B:sus4', 'D'),
#   ('A', 'B:sus4', 'D:maj7'),
#   ('A', 'B:sus4', 'E'),
#   ('A', 'B:sus4', 'E:min'),
#   ('A', 'B:sus4', 'F#:min'),
#   ('A', 'B:sus4', 'G#:min'),
#   ('A', 'B:sus4', 'G:maj/9'),
#   ('A', 'B:sus4', 'N'),
#   ('A', 'C', 'D'),
#   ('A', 'C', 'G'),
#   ('A', 'C#:7', 'D'),
#   ('A', 'C#:7', 'D:maj7'),
#   ('A', 'C#:7', 'E'),
#   ('A', 'C#:7', 'E:min'),
#   ('A', 'C#:7', 'G#:min'),
#   ('A', 'C#:7', 'G:maj/9'),
#   ('A', 'C#:7', 'N'),
#   ('A', 'C#:sus4', 'D'),
#   ('A', 'C#:sus4', 'D:maj7'),
#   ('A', 'C#:sus4', 'E'),
#   ('A', 'C#:sus4', 'E:min'),
#   ('A', 'C#:sus4', 'F#:min'),
#   ('A', 'C#:sus4', 'G#:min'),
#   ('A', 'C#:sus4', 'G:maj/9'),
#   ('A', 'C#:sus4', 'N'),
#   ('A', 'C:7', 'D'),
#   ('A', 'C:maj(9)', 'D'),
#   ('A', 'C:min', 'N'),
#   ('A', 'D', 'G:sus4'),
#   ('A', 'D:maj7', 'G:sus4'),
#   ('A', 'E', 'G:sus4'),
#   ('A', 'E:min', 'F#'),
#   ('A', 'E:min', 'G:sus4'),
#   ('A', 'F#:min', 'F#:min7'),
#   ('A', 'F#:min', 'G:sus4'),
#   ('A', 'G#:min', 'G:sus4'),
#   ('A', 'G:maj/9', 'G:sus4'),
#   ('A', 'G:sus4', 'N'),
#   ('A:7', 'C#', 'F#:min'),
#   ('A:7', 'C#:7', 'F#:min'),
#   ('A:7', 'F#:min', 'N'),
#   ('A:7(#9)', 'C', 'G'),
#   ('A:maj6', 'B', 'E'),
#   ('A:maj6', 'B:min', 'E'),
#   ('A:maj6', 'D', 'E'),
#   ('A:maj6', 'E', 'E:7'),
#   ('A:maj6', 'E', 'N'),
#   ('A:min', 'C', 'E'),
#   ('A:min', 'D', 'G'),
#   ('A:min', 'E', 'E:min'),
#   ('A:min', 'E', 'F#:min'),
#   ('A:min', 'E', 'G#:min'),
#   ('A:min', 'G', 'N'),
#   ('A:min(*5)', 'C', 'G'),
#   ('A:min(*5)', 'D', 'G'),
#   ('A:min(*5)', 'G', 'N'),
#   ('A:min7(*5,b6)', 'C', 'G'),
#   ('A:min7(*5,b6)', 'D', 'G'),
#   ('A:min7(*5,b6)', 'G', 'N'),
#   ('A:sus4', 'D', 'D:7(#9)'),
#   ('A:sus4', 'D:7(#9)', 'G:7'),
#   ('Ab', 'C', 'Db'),
#   ('Ab', 'C', 'F:min'),
#   ('Ab', 'C:min', 'F:min'),
#   ('Ab', 'Db', 'Eb:sus4'),
#   ('Ab', 'Db', 'N'),
#   ('Ab', 'Eb', 'G'),
#   ('Ab', 'Eb', 'G:min/5'),
#   ('Ab', 'Eb', 'N'),
#   ('Ab/5', 'D', 'N'),
#   ('Ab/5', 'E', 'N'),
#   ('Ab/5', 'F#:min', 'N'),
#   ('Ab/5', 'F:min/5', 'N'),
#   ('Ab/5', 'G', 'N'),
#   ('Ab:7', 'Bb:min', 'F:min'),
#   ('Ab:7', 'C', 'F:min'),
#   ('Ab:7', 'C:min', 'F:min'),
#   ('Ab:7', 'Eb', 'F:min'),
#   ('B', 'C#', 'F#:min'),
#   ('B', 'C#:7', 'F#:min'),
#   ('B', 'E', 'E:min'),
#   ('B', 'E', 'G#:min'),
#   ('B', 'F:min/5', 'N'),
#   ('B', 'G', 'N'),
#   ('B/5', 'C#', 'F#:min'),
#   ('B/5', 'C#:7', 'F#:min'),
#   ('B/5', 'F#:min', 'N'),
#   ('B:dim7', 'C', 'F'),
#   ('B:dim7', 'C', 'F:min/5'),
#   ('B:hdim7/b3', 'B:min', 'D'),
#   ('B:hdim7/b3', 'B:min', 'E'),
#   ('B:hdim7/b3', 'B:min', 'G:7'),
#   ('B:maj(*3)', 'C#', 'F#:min'),
#   ('B:maj(*3)', 'C#:7', 'F#:min'),
#   ('B:maj(*3)', 'F#:min', 'N'),
#   ('B:min', 'C', 'D'),
#   ('B:min', 'C:7', 'D'),
#   ('B:min', 'C:maj(9)', 'D'),
#   ('B:min', 'D', 'D:maj6'),
#   ('B:min', 'D', 'D:min'),
#   ('B:min', 'D', 'E:7'),
#   ('B:min', 'D', 'E:min'),
#   ('B:min', 'D', 'E:min/b3'),
#   ('B:min', 'D:maj6', 'E'),
#   ('B:min', 'D:maj6', 'G:7'),
#   ('B:min', 'D:min', 'E'),
#   ('B:min', 'E', 'E:min/b3'),
#   ('B:min', 'E', 'F#:min'),
#   ('B:min', 'E', 'G#:min'),
#   ('B:min', 'E:7', 'G:7'),
#   ('B:min', 'E:min', 'G:7'),
#   ('B:min', 'E:min/b3', 'G:7'),
#   ('Bb', 'F:min/5', 'N'),
#   ('Bb:min', 'C', 'Db'),
#   ('Bb:min', 'Db', 'Eb'),
#   ('Bb:min', 'Db', 'Eb:sus4'),
#   ('Bb:min', 'F:min', 'F:min/5'),
#   ('C', 'C:min', 'G'),
#   ('C', 'D', 'D:7(#9)'),
#   ('C', 'D', 'E'),
#   ('C', 'D', 'N'),
#   ('C', 'D:7(#9)', 'G'),
#   ('C', 'Eb/5', 'G'),
#   ('C', 'F', 'F:min'),
#   ('C', 'F:min/5', 'G'),
#   ('C', 'G', 'G#'),
#   ('C#', 'D', 'F#:min'),
#   ('C#:7', 'D', 'F#:min'),
#   ('C#:7', 'F#:min', 'F#:min7'),
#   ('C:7', 'D', 'D:7(#9)'),
#   ('C:7', 'D', 'E'),
#   ('C:7', 'D', 'N'),
#   ('C:maj(9)', 'D', 'D:7(#9)'),
#   ('C:maj(9)', 'D', 'E'),
#   ('C:maj(9)', 'D', 'G'),
#   ('C:maj(9)', 'D', 'N'),
#   ('C:min', 'D', 'G'),
#   ('C:min', 'D', 'N'),
#   ('C:min', 'E', 'N'),
#   ('C:min', 'Eb', 'G:7'),
#   ('C:min', 'F#:min', 'N'),
#   ('C:min', 'F:min', 'F:min/5'),
#   ('C:min', 'F:min/5', 'N'),
#   ('D', 'D:7(#9)', 'D:min'),
#   ('D', 'D:min', 'G'),
#   ('D', 'D:min', 'N'),
#   ('D', 'E', 'E:min'),
#   ('D', 'E', 'G#:min'),
#   ('D', 'G', 'G#'),
#   ('D:7(#9)', 'G', 'N'),
#   ('D:min', 'E', 'E:7'),
#   ('D:min', 'E', 'N'),
#   ('E', 'E:7', 'E:min'),
#   ('E', 'E:7', 'F#:min'),
#   ('E', 'E:7', 'G#:min'),
#   ('E', 'E:min', 'N'),
#   ('E', 'G#:min', 'N'),
#   ('E:aug', 'F:min/5', 'N'),
#   ('Eb', 'F:min', 'F:min/5'),
#   ('Eb', 'F:min', 'G'),
#   ('Eb', 'F:min', 'G:min/5'),
#   ('Eb/5', 'G', 'N'),
#   ('F#:min', 'F#:min7', 'N'),
#   ('G', 'G#', 'N')},
#  '120C': {('A', 'A:7', 'D'),
#   ('A', 'B', 'B:sus4'),
#   ('A', 'B', 'D:min'),
#   ('A', 'B:7', 'D'),
#   ('A', 'B:7', 'E'),
#   ('A', 'B:min', 'E:min'),
#   ('A', 'D', 'D:min'),
#   ('A', 'D:min', 'E'),
#   ('A:7(#9)', 'D', 'G'),
#   ('A:7(#9)', 'G', 'N'),
#   ('A:maj6', 'A:min', 'E'),
#   ('A:min', 'C', 'G'),
#   ('B', 'B:7', 'E'),
#   ('B', 'D', 'N'),
#   ('B', 'E', 'E:sus4(b7)'),
#   ('B', 'E', 'F#:min'),
#   ('C', 'F', 'G'),
#   ('C:7', 'D', 'G'),
#   ('D', 'E', 'F#:min'),
#   ('D', 'Eb/5', 'G')},
#  '120D': {('A:7(#9)', 'D', 'N'),
#   ('B:7', 'D', 'E'),
#   ('Bb', 'C', 'F:min'),
#   ('Bb', 'C:min', 'F:min'),
#   ('Bb', 'Eb', 'F:min')},
#  '120U': {('A', 'A:7', 'F#:min'),
#   ('A', 'B', 'B:7'),
#   ('A:min', 'D:min', 'E'),
#   ('Ab', 'Bb:min', 'F:min'),
#   ('B', 'D:min', 'E'),
#   ('B', 'F#:min', 'N'),
#   ('B:min', 'E', 'E:min'),
#   ('C', 'F:min', 'F:min/5'),
#   ('C#', 'F#:min', 'F#:min7'),
#   ('C:min', 'G', 'N'),
#   ('D', 'D:min', 'E')},
#  '201': {('A', 'A:min', 'E'),
#   ('A', 'B', 'D:maj7'),
#   ('A', 'B', 'E:min'),
#   ('A', 'B', 'G#:min'),
#   ('A', 'B', 'G:maj/9'),
#   ('A', 'C#', 'F#:min'),
#   ('A', 'D', 'D:7(#9)'),
#   ('A', 'D', 'D:maj7'),
#   ('A', 'D', 'E:min'),
#   ('A', 'D', 'G#:min'),
#   ('A', 'D', 'G:maj/9'),
#   ('A', 'D:maj7', 'E'),
#   ('A', 'D:maj7', 'E:min'),
#   ('A', 'D:maj7', 'F#:min'),
#   ('A', 'D:maj7', 'G#:min'),
#   ('A', 'D:maj7', 'G:maj/9'),
#   ('A', 'D:maj7', 'N'),
#   ('A', 'E', 'G:maj/9'),
#   ('A', 'E:min', 'G#:min'),
#   ('A', 'E:min', 'G:maj/9'),
#   ('A', 'E:min', 'N'),
#   ('A', 'F#:min', 'G#:min'),
#   ('A', 'F#:min', 'G:maj/9'),
#   ('A', 'F:min/5', 'N'),
#   ('A', 'G#:min', 'G:maj/9'),
#   ('A', 'G#:min', 'N'),
#   ('A', 'G:maj/9', 'N'),
#   ('A:min', 'B:min', 'E'),
#   ('A:min', 'D', 'E'),
#   ('A:min', 'E', 'E:7'),
#   ('A:min', 'E', 'N'),
#   ('B', 'B:min', 'E'),
#   ('B', 'E', 'E:7'),
#   ('B:dim7', 'C', 'F:min'),
#   ('B:dim7', 'C', 'G'),
#   ('B:min', 'C:min', 'G:7'),
#   ('B:min', 'D', 'D:7(#9)'),
#   ('B:min', 'D', 'G'),
#   ('B:min', 'D', 'G:7'),
#   ('B:min', 'D', 'N'),
#   ('B:min', 'D:7(#9)', 'G:7'),
#   ('B:min', 'E', 'G:7'),
#   ('B:min', 'E', 'N'),
#   ('Bb:min', 'C', 'F:min'),
#   ('Bb:min', 'C:min', 'F:min'),
#   ('Bb:min', 'Db', 'F:min'),
#   ('Bb:min', 'Eb', 'F:min'),
#   ('C', 'C:min', 'F:min'),
#   ('C', 'Eb', 'F:min'),
#   ('C', 'F:min', 'G'),
#   ('C', 'G', 'N'),
#   ('C#', 'C#:7', 'F#:min'),
#   ('C#', 'F#:min', 'N'),
#   ('C#:7', 'F#:min', 'N'),
#   ('C:min', 'D:7(#9)', 'G:7'),
#   ('C:min', 'F:min', 'G:7'),
#   ('D', 'D:7(#9)', 'E'),
#   ('D', 'D:7(#9)', 'G:7'),
#   ('D', 'D:7(#9)', 'N'),
#   ('D', 'E', 'E:7'),
#   ('D', 'E', 'G'),
#   ('D', 'F:min/5', 'N'),
#   ('E', 'E:7', 'N'),
#   ('E', 'F:min/5', 'N'),
#   ('E', 'G', 'N'),
#   ('F#:min', 'F:min/5', 'N'),
#   ('F#:min', 'G', 'N'),
#   ('F:min/5', 'G', 'N')},
#  '210': {('A', 'B', 'D'),
#   ('A', 'B', 'F#:min'),
#   ('A', 'B', 'N'),
#   ('A', 'B:min', 'D'),
#   ('A', 'B:min', 'E'),
#   ('A', 'C#:7', 'F#:min'),
#   ('A', 'D', 'F#:min'),
#   ('A', 'D', 'G'),
#   ('A', 'E', 'E:7'),
#   ('A', 'E', 'E:min'),
#   ('A', 'E', 'F#:min'),
#   ('A', 'E', 'G#:min'),
#   ('A', 'E:min', 'F#:min'),
#   ('A', 'G', 'N'),
#   ('A:min', 'B', 'E'),
#   ('Ab', 'Bb:min', 'Db'),
#   ('Ab', 'Db', 'Eb'),
#   ('Ab', 'Eb', 'F:min'),
#   ('B', 'D', 'E'),
#   ('B', 'E', 'N'),
#   ('B:min', 'E', 'E:7'),
#   ('C', 'D', 'G'),
#   ('C:min', 'Eb', 'F:min'),
#   ('D', 'D:7(#9)', 'G'),
#   ('D', 'F#:min', 'N'),
#   ('E', 'F#:min', 'N')},
#  '300': {('A', 'B', 'E'),
#   ('A', 'D', 'E'),
#   ('A', 'D', 'N'),
#   ('A', 'E', 'N'),
#   ('A', 'F#:min', 'N'),
#   ('B:min', 'D', 'E'),
#   ('D', 'E', 'N'),
#   ('D', 'G', 'N')}}

# %%
from collections import Counter
counter=Counter(new)
print(counter)
# Out:
# Counter({('E:7', 'G#', 'C:7'): 1, ('Bb:min7', 'G:min/5', 'C#'): 1, ('D:7(#9)', 'B:sus4', 'C#:7'): 1, ('F:maj6', 'C#:maj7/3', 'G:min/5'): 1, ('E:7', 'A', 'E:sus4(b7)'): 1, ('A:min(*5)', 'Eb:sus4', 'C#:sus4'): 1, ('E:min', 'C', 'C:min'): 1, ('B:7', 'C#/3', 'B/5'): 1, ('E:7', 'B', 'Ab:7'): 1, ('D:dim7', 'A:min', 'G#:min'): 1, ('F:min6/5', 'Ab:7', 'C#'): 1, ('E', 'Eb/5', 'F:min'): 1, ('A:min', 'G:min/5', 'F#'): 1, ('G', 'E:7', 'E:min/b3'): 1, ('Ab:7', 'B:min/5', 'C#'): 1, ('E:sus4(b7)', 'Eb', 'C#'): 1, ('A:7(#9)', 'G#', 'F#:min7'): 1, ('N', 'D', 'G:maj/9'): 1, ('G:7', 'Eb', 'Bb:min'): 1, ('Bb:min', 'C#:sus4', 'G:maj/9'): 1, ('N', 'Bb', 'C#/3'): 1, ('A:min(*5)', 'F:min/5', 'B:maj(*3)'): 1, ('E:min', 'B:hdim7/b3', 'F'): 1, ('G:7', 'A:sus4', 'F:min'): 1, ('F#:min', 'B:7', 'Ab:7'): 1, ('G#', 'F:min/5', 'F:min7'): 1, ('F:maj6', 'F:min6/5', 'Bb:min/5'): 1, ('G', 'A:7(#9)', 'A:7'): 1, ('B:min', 'Eb/5', 'Ab'): 1, ('Bb:min/5', 'B/5', 'C#'): 1, ('G', 'A:7', 'D:dim7'): 1, ('E', 'B:dim7', 'B:sus4'): 1, ('D:7(#9)', 'C:maj(9)', 'C#:sus4'): 1, ('C', 'C:maj(9)', 'Bb:min/5'): 1, ('E:7', 'A', 'F#:min7'): 1, ('B:hdim7/b3', 'A:min', 'B:min/5'): 1, ('A', 'F#:min', 'C#/3'): 1, ('G:sus4', 'C#:maj7/3', 'G:min/5'): 1, ('F#:min', 'Eb', 'D:maj7'): 1, ('G#:min', 'F', 'Bb:min7'): 1, ('A:7', 'Eb', 'B/5'): 1, ('D:dim7', 'C:7', 'F:min7'): 1, ('B:hdim7/b3', 'B/5', 'E:min/b3'): 1, ('G', 'C:min', 'Bb:min'): 1, ('N', 'A:sus4', 'C#:sus4'): 1, ('F#:min', 'F:min6/5', 'D:maj7'): 1, ('D', 'A:min', 'F:min7'): 1, ('A:min7(*5,b6)', 'A:sus4', 'C#'): 1, ('E:7', 'D:7(#9)', 'G:maj/9'): 1, ('A:min(*5)', 'Bb', 'E:min/b3'): 1, ('A:min', 'D:7(#9)', 'C#:maj7/3'): 1, ('D:dim7', 'F:min6/5', 'C:min'): 1, ('A:7', 'F:min7', 'B:sus4'): 1, ('A:7(#9)', 'E:min', 'B:dim7'): 1, ('B:dim7', 'Db', 'Ab/5'): 1, ('D', 'A', 'F:min7'): 1, ('B:min', 'D:dim7', 'Ab/5'): 1, ('F#:min', 'D:dim7', 'Eb:maj6'): 1, ('N', 'B:dim7', 'Eb'): 1, ('G#', 'Bb:min/5', 'G:maj/9'): 1, ('D:dim7', 'Ab', 'G:maj/9'): 1, ('D', 'F#:min', 'C:min'): 1, ('B', 'C:maj(9)', 'G:min/5'): 1, ('F:min', 'Eb:sus4', 'B:min/5'): 1, ('C#:maj7/3', 'C#/3', 'D:maj7'): 1, ('G:sus4', 'C#/3', 'B:sus4'): 1, ('E:aug', 'F:min', 'B/5'): 1, ('A', 'Bb:min7', 'F#:min7'): 1, ('N', 'G', 'F:min'): 1, ('Eb/5', 'F:min7', 'Eb'): 1, ('Eb/5', 'F#:min7', 'E:min/b3'): 1, ('A:sus4', 'C#:sus4', 'F#'): 1, ('A:min', 'A:sus4', 'G:min/5'): 1, ('C:maj(9)', 'F:min7', 'F:min'): 1, ('A:7', 'F:maj6', 'Ab'): 1, ('E:7', 'A:min(*5)', 'Db'): 1, ('E:7', 'F:maj6', 'F:min'): 1, ('G#:min', 'G:min/5', 'Bb:min'): 1, ('E:sus4(b7)', 'G#:min', 'C#'): 1, ('E:7', 'F#:min', 'B:sus4'): 1, ('G:7', 'B', 'B:dim7'): 1, ('A:sus4', 'C#/3', 'E:min/b3'): 1, ('C#:maj7/3', 'C#', 'E:min/b3'): 1, ('C:7', 'E:aug', 'F#:min7'): 1, ('F', 'C#', 'E:min/b3'): 1, ('B:min', 'B:7', 'C:7'): 1, ('C:maj(9)', 'Ab:7', 'E:min/b3'): 1, ('A:min7(*5,b6)', 'F#:min', 'G:maj/9'): 1, ('A', 'D:7(#9)', 'B:min/5'): 1, ('A:7(#9)', 'F:min6/5', 'C:min'): 1, ('G:min/5', 'Eb:sus4', 'C#:sus4'): 1, ('D:min', 'G#:min', 'Ab'): 1, ('Bb', 'F#', 'D:maj6'): 1, ('E:7', 'G:min/5', 'G:maj/9'): 1, ('A:7', 'F', 'G:maj/9'): 1, ('F#:min', 'G:min/5', 'Ab'): 1, ('A:7', 'Eb/5', 'G:sus4'): 1, ('A:min(*5)', 'E', 'D:maj7'): 1, ('E', 'F', 'C#:maj7/3'): 1, ('D:min', 'B:7', 'Eb:maj6'): 1, ('E:sus4(b7)', 'C#/3', 'G:min/5'): 1, ('B:min', 'E:sus4(b7)', 'D:maj6'): 1, ('D:dim7', 'F:maj6', 'F:min/5'): 1, ('E:min', 'A:7', 'Eb:maj6'): 1, ('B:7', 'G#:min', 'F#'): 1, ('G#', 'Ab:7', 'C#:sus4'): 1, ('A:min7(*5,b6)', 'B:min/5', 'B:maj(*3)'): 1, ('E:7', 'E', 'B:7'): 1, ('N', 'F:maj6', 'C#:sus4'): 1, ('D', 'E:aug', 'Ab/5'): 1, ('F#:min', 'Ab:7', 'Db'): 1, ('C:maj(9)', 'B:sus4', 'F#:min7'): 1, ('B:hdim7/b3', 'F:min6/5', 'Eb:sus4'): 1, ('A:7', 'A:maj6', 'C#/3'): 1, ('F:maj6', 'Bb:min7', 'E:min/b3'): 1, ('A:min7(*5,b6)', 'A:maj6', 'D:maj7'): 1, ('Bb:min', 'Eb:sus4', 'C#:7'): 1, ('B:min', 'G:min/5', 'D:maj7'): 1, ('A:maj6', 'Bb:min', 'D:maj7'): 1, ('N', 'E:7', 'G:maj/9'): 1, ('D:dim7', 'F', 'Ab:7'): 1, ('D:min', 'Eb', 'D:maj7'): 1, ('B:7', 'Bb:min7', 'Eb:sus4'): 1, ('B', 'F:mi ...
