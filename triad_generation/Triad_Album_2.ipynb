# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
album01 = pd.read_csv('album_02_edges.csv')
G = nx.from_pandas_edgelist(album01, source="Source", target="Target", create_using=nx.DiGraph())
nx.draw(G, with_labels=True)

# %% [markdown]
# ## Visuals

# %%
nx.draw(G,node_size=300,font_size=8,  with_labels=True)

# %%
plt.figure(3,figsize=(12,12)) 
nx.draw(G, node_size=400,font_size=12,  with_labels=True)

# %% [markdown]
# ## Triads

# %%
''' Conesus Motifs are: 
        021C
        111D
        201
        030C
        120C
        210
                    '''
# Out:
# ' Conesus Motifs are: \n        021C\n        111D\n        201\n        030C\n        120C\n        210\n                    '

# %%
# Triad Consensus
nx.triadic_census(G)
# Out:
# {'003': 30270,
#  '012': 5049,
#  '102': 1503,
#  '021D': 103,
#  '021U': 80,
#  '021C': 226,
#  '111D': 180,
#  '111U': 224,
#  '030T': 8,
#  '030C': 7,
#  '201': 93,
#  '120D': 9,
#  '120U': 10,
#  '120C': 27,
#  '210': 12,
#  '300': 19}

# %%
import networkx as nx
import itertools

def _tricode(G, v, u, w):
    """Returns the integer code of the given triad.

    This is some fancy magic that comes from Batagelj and Mrvar's paper. It
    treats each edge joining a pair of `v`, `u`, and `w` as a bit in
    the binary representation of an integer.

    """
    combos = ((v, u, 1), (u, v, 2), (v, w, 4), (w, v, 8), (u, w, 16),
              (w, u, 32))
    return sum(x for u, v, x in combos if v in G[u])


# G = nx.DiGraph()
# G.add_nodes_from([1, 2, 3, 4, 5])
# G.add_edges_from([(1, 2), (2, 3), (2, 4), (4, 5)])

#: The integer codes representing each type of triad.
#: Triads that are the same up to symmetry have the same code.
TRICODES = (1, 2, 2, 3, 2, 4, 6, 8, 2, 6, 5, 7, 3, 8, 7, 11, 2, 6, 4, 8, 5, 9,
            9, 13, 6, 10, 9, 14, 7, 14, 12, 15, 2, 5, 6, 7, 6, 9, 10, 14, 4, 9,
            9, 12, 8, 13, 14, 15, 3, 7, 8, 11, 7, 12, 14, 15, 8, 14, 13, 15,
            11, 15, 15, 16)

#: The names of each type of triad. The order of the elements is
#: important: it corresponds to the tricodes given in :data:`TRICODES`.
TRIAD_NAMES = ('003', '012', '102', '021D', '021U', '021C', '111D', '111U',
               '030T', '030C', '201', '120D', '120U', '120C', '210', '300')

#: A dictionary mapping triad code to triad name.
TRICODE_TO_NAME = {i: TRIAD_NAMES[code - 1] for i, code in enumerate(TRICODES)}

triad_nodes = {name: set([]) for name in TRIAD_NAMES}
m = {v: i for i, v in enumerate(G)}
for v in G:
    vnbrs = set(G.pred[v]) | set(G.succ[v])
    for u in vnbrs:
        if m[u] > m[v]:
            unbrs = set(G.pred[u]) | set(G.succ[u])
            neighbors = (vnbrs | unbrs) - {u, v}
            not_neighbors = set(G.nodes()) - neighbors - {u, v}
            # Find dyadic triads
            for w in not_neighbors:
                if v in G[u] and u in G[v]:
                    triad_nodes['102'].add(tuple(sorted([u, v, w])))
                else:
                    triad_nodes['012'].add(tuple(sorted([u, v, w])))
            for w in neighbors:
                if m[u] < m[w] or (m[v] < m[w] < m[u] and
                                   v not in G.pred[w] and
                                   v not in G.succ[w]):
                    code = _tricode(G, v, u, w)
                    triad_nodes[TRICODE_TO_NAME[code]].add(
                        tuple(sorted([u, v, w])))
# find null triads
all_tuples = set()
for s in triad_nodes.values():
    all_tuples = all_tuples.union(s)
    
new = triad_nodes['210'] = set(itertools.combinations(G.nodes(), 3)).difference(all_tuples)

triad_nodes
# Out:
# {'003': set(),
#  '012': {('A:9', 'C:9', 'N'),
#   ('A:7', 'Ab', 'B:7(#9)'),
#   ('C:9', 'D:7/5', 'G:min'),
#   ('C:7/5', 'F', 'G:minmaj7'),
#   ('C:7', 'G:7', 'G:minmaj7'),
#   ('B:min', 'D:9', 'E'),
#   ('B:7', 'C#', 'D'),
#   ('Bb', 'D:maj/2', 'G'),
#   ('A:7(#9)', 'C:7', 'C:9'),
#   ('Bb', 'F', 'F#:min'),
#   ('B:7', 'C:7/5', 'F:7'),
#   ('A', 'F', 'F#'),
#   ('F:maj7', 'G:minmaj7', 'N'),
#   ('F#', 'F#:7', 'G:7'),
#   ('A', 'F#', 'F:7'),
#   ('Bb:min', 'E/5', 'G:min'),
#   ('E', 'F#:dim/b3', 'G:dim7'),
#   ('Bb', 'D/3', 'F'),
#   ('B:7', 'C:7', 'F#:min'),
#   ('A:7', 'B', 'F#:9'),
#   ('A/5', 'C:aug', 'F#:sus4'),
#   ('C:7', 'D:7/5', 'E:min'),
#   ('Bb:min', 'D', 'G:min'),
#   ('D/5', 'F#', 'N'),
#   ('D:7/5', 'E', 'G'),
#   ('Bb', 'C:9', 'F:7'),
#   ('Bb:min', 'E:aug(9,11)', 'G:min'),
#   ('A:7(#9)', 'E', 'F#'),
#   ('A', 'D:maj/2', 'F#:9'),
#   ('A', 'A:9', 'B:7(#9)'),
#   ('B:7', 'C#:min', 'C:7'),
#   ('B:7(#9)', 'C:9', 'F'),
#   ('C#:min/4', 'D/3', 'E'),
#   ('B:min/b3', 'C#:7', 'F#:7(#9)'),
#   ('B:aug/3', 'E', 'G:minmaj7'),
#   ('C#:min/4', 'C#:min/5', 'C:aug'),
#   ('F:maj7', 'G:7', 'G:minmaj7'),
#   ('A:min', 'C', 'E:9'),
#   ('B:aug/3', 'B:min/b3', 'G:min'),
#   ('E:maj7', 'G#:min', 'G:min'),
#   ('C:9', 'E:maj7', 'N'),
#   ('Bb', 'D/5', 'G'),
#   ('B', 'B:7(#9)', 'F#'),
#   ('B:7', 'D', 'D:maj/2'),
#   ('C', 'G', 'G:dim7'),
#   ('F:9', 'G#:min', 'G:min'),
#   ('B', 'Bb', 'F#'),
#   ('A:min', 'G', 'G:7'),
#   ('E:min', 'G:7', 'G:minmaj7'),
#   ('A', 'C', 'F#'),
#   ('B:min', 'F:7', 'G'),
#   ('D:9', 'F', 'F#:sus4'),
#   ('A', 'A/5', 'F#:9'),
#   ('F#:7', 'G:maj6(9)', 'N'),
#   ('C', 'C:min', 'N'),
#   ('F#:min7', 'G:min', 'G:minmaj7'),
#   ('A:min', 'C:7', 'C:9'),
#   ('C', 'C:min', 'E:7'),
#   ('A:9', 'C#', 'F#'),
#   ('A:min', 'Bb:min', 'C'),
#   ('C#', 'E', 'E:7'),
#   ('C#', 'F#', 'G:minmaj7'),
#   ('A', 'F#:min7', 'F#:sus4'),
#   ('A:9', 'C', 'E:min'),
#   ('A:min', 'D/3', 'N'),
#   ('C:7', 'G', 'G:min'),
#   ('D', 'E', 'E:maj7'),
#   ('B', 'C#', 'F#:9'),
#   ('A:7', 'A:min', 'E:7'),
#   ('E:maj7', 'F', 'F:9'),
#   ('D:9', 'F', 'G:dim7'),
#   ('Bb', 'G', 'G:min7'),
#   ('C:9', 'D:7/5', 'G:min7'),
#   ('A:min', 'B:7(#9)', 'F'),
#   ('A:7(#9)', 'B:7(#9)', 'C#:min'),
#   ('D', 'F#:7', 'G:7'),
#   ('A:min', 'C', 'C#'),
#   ('A:min', 'B', 'C'),
#   ('C#:min', 'C#:min/5', 'G:dim7'),
#   ('C#', 'D', 'G:maj6(9)'),
#   ('B:7(#9)', 'F#', 'G'),
#   ('D:7/5', 'G:7', 'G:minmaj7'),
#   ('B:aug/3', 'B:min/b3', 'F:9'),
#   ('B:7', 'C:7', 'E/5'),
#   ('Bb:min', 'F:maj7', 'N'),
#   ('C:min', 'F#:min', 'G'),
#   ('A', 'B:min', 'D:maj/2'),
#   ('D/3', 'F', 'F:9'),
#   ('C:min', 'F#:dim/b3', 'G'),
#   ('B:7', 'D', 'F:7'),
#   ('A', 'D:maj/2', 'E:9'),
#   ('C#:min', 'D/3', 'F#'),
#   ('A', 'C', 'D/3'),
#   ('F#:dim', 'F#:min7', 'G:min'),
#   ('A:9', 'G:dim7', 'N'),
#   ('E:maj7', 'F', 'G:min7'),
#   ('Bb', 'F:9', 'N'),
#   ('A:7(#9)', 'A:min', 'F#:min'),
#   ('D:7/5', 'E', 'G:7'),
#   ('C:9', 'G/3', 'G:min7'),
#   ('B:7(#9)', 'B:min', 'E'),
#   ('A', 'C:9', 'G:min'),
#   ('C#:min', 'F', 'F#:7(#9)'),
#   ('B:7', 'B:min', 'G'),
#   ('D/3', 'G', 'G:maj6(9)'),
#   ('Ab', 'E', 'F#'),
#   ('Bb', 'F#:7(#9)', 'F:7'),
#   ('C#:min', 'F#', 'F#:dim'),
#   ('F#:7', 'G', 'G:7'),
#   ('A', 'A/5', 'E:9'),
#   ('B:7', 'C:7/5', 'C:9'),
#   ('C:7', 'C:9', 'F#:dim'),
#   ('A/5', 'Bb', 'F'),
#   ('D', 'E', 'F#:7(#9)'),
#   ('A', 'D:9', 'F#'),
#   ('C', 'E:min', 'F#:7'),
#   ('A:7(#9)', 'B', 'F#:9'),
#   ('C#:min', 'F#:min', 'F:maj7'),
#   ('A', 'D/5', 'E:9'),
#   ('B:min', 'C#', 'F#'),
#   ('C#:min', 'C#:min/4', 'E:aug(9,11)'),
#   ('B:min', 'E/5', 'G'),
#   ('Bb', 'F#:7', 'G:min'),
#   ('C#:7', 'F', 'F:maj7'),
#   ('D', 'D:9', 'F#:min'),
#   ('C#:min/4', 'C#:min/5', 'D:9'),
#   ('E', 'F#:7(#9)', 'G'),
#   ('A', 'Bb:min', 'D/3'),
#   ('D:9', 'G:min', 'N'),
#   ('C#', 'G#:min', 'G:min'),
#   ('A:7', 'D', 'F#:min'),
#   ('B:min/b3', 'C:9', 'G:7'),
#   ('B:min', 'E:aug(9,11)', 'G'),
#   ('A:7', 'B:7(#9)', 'F#:9'),
#   ('B', 'E:9', 'F#'),
#   ('D:7/5', 'E:min', 'G:min'),
#   ('C:min', 'E:maj7', 'F:7'),
#   ('Ab', 'B:7', 'D'),
#   ('A:min', 'F:maj7', 'G/3'),
#   ('C#:7', 'E', 'G:dim7'),
#   ('A:min', 'F', 'F#:7'),
#   ('Bb', 'Bb:min', 'G:7'),
#   ('A', 'A:9', 'C'),
#   ('A/5', 'D:9', 'F'),
#   ('A', 'D/3', 'G#:min'),
#   ('A', 'C#:min/4', 'C#:min/5'),
#   ('D', 'F', 'F#:min'),
#   ('F', 'F#:dim', 'F#:min7'),
#   ('Bb:min', 'E', 'E:9'),
#   ('E:maj7', 'F:7', 'F:maj7'),
#   ('G:dim7', 'G:min', 'G:minmaj7'),
#   ('B:aug/3', 'B:min/b3', 'C'),
#   ('Bb', 'D', 'F#:min'),
#   ('C:9', 'F#', 'G:min7'),
#   ('A', 'E:aug(9,11)', 'F#'),
#   ('A', 'C:9', 'G:min7'),
#   ('C#:min/4', 'E', 'F#:min7'),
#   ('C', 'G', 'G#:min'),
#   ('B', 'D', 'D/3'),
#   ('A', 'A:7', 'C:min'),
#   ('F#:dim', 'G:min', 'N'),
#   ('A:min', 'C#:7', 'F#:dim/b3'),
#   ('F#:7(#9)', 'G:7', 'G:min'),
#   ('A', 'B:min/b3', 'F#:9'),
#   ('B:aug/3', 'B:min', 'B:min/b3'),
#   ('D:7/5', 'E:min', 'F:9'),
#   ('B:7', 'F#:7', 'F:7'),
#   ('Bb', 'C#:7', 'F'),
#   ('A', 'Bb', 'C:min'),
#   ('D', 'D:7/5', 'E'),
#   ('A:min', 'F#:dim', 'G#:min'),
#   ('A:min', 'C', 'F#:7'),
#   ('A:9', 'D/3', 'G'),
#   ('C', 'C:7/5', 'G'),
#   ('A', 'D/3', 'D/5'),
#   ('B:aug/3', 'E', 'E:maj7'),
#   ('C#', 'D/5', 'E'),
#   ('C#', 'E/5', 'E:7'),
#   ('E:min', 'F', 'F:maj7'),
#   ('A:min', 'Bb', 'F#:min'),
#   ('B:7', 'C:7', 'F:9'),
#   ('D:9', 'F#', 'G:min'),
#   ('E', 'F#:7(#9)', 'G:7'),
#   ('A:7', 'B:7(#9)', 'E:9'),
#   ('B:7', 'C#:min', 'F#'),
#   ('C#:min', 'C#:min/5', 'G#:min'),
#   ('E:maj7', 'F#:dim', 'N'),
#   ('Ab', 'B', 'F#:9'),
#   ('B:aug/3', 'F#:7', 'G:7'),
#   ('Bb', 'G:7', 'G:min'),
#   ('C', 'C:min', 'F#:9'),
#   ('D/3', 'D/5', 'G'),
#   ('C#', 'E:aug(9,11)', 'N'),
#   ('A:7(#9)', 'G:maj6(9)', 'N'),
#   ('C:9', 'E:min', 'G:7'),
#   ('D:7/5', 'E:min', 'G:min7'),
#   ('Bb', 'G', 'G:maj6(9)'),
#   ('C#', 'E', 'F#:9'),
#   ('C:min', 'E', 'E:9'),
#   ('G#:min', 'G:7', 'G:min'),
#   ('B', 'D', 'F#:7'),
#   ('A:min', 'C:min', 'G#:min'),
#   ('A/5', 'D:7/5', 'F#:sus4'),
#   ('B:7(#9)', 'B:aug/3', 'B:min/b3'),
#   ('B:7', 'E:maj7', 'N'),
#   ('A:min', 'C#', 'F#:dim/b3'),
#   ('B:7', 'C#:min', 'C:aug'),
#   ('Bb', 'E/5', 'E:7'),
#   ('B:7', 'C:7/5', 'G:dim7'),
#   ('A:min', 'C#:min/4', 'G/3'),
#   ('Bb', 'C:7/5', 'G:min'),
#   ('A', 'D/3', 'G/3'),
#   ('B:7', 'C#:7', 'D'),
#   ('A:7', 'D:maj/2', 'E:min'),
#   ('A:min', 'F#:min', 'G:min7'),
#   ('E', 'F#:dim', 'G:dim7'),
#   ('A:7(#9)', 'A:min', 'B:7(#9)'),
#   ('A', 'A:7(#9)', 'C:min'),
#   ('C:9', 'F', 'G#:min'),
#   ('A:min', 'B', 'F#:dim/b3'),
#   ('Bb:min', 'D', 'G:maj6(9)'),
#   ('A:7', 'B:7(#9)', 'C#'),
#   ('C#:min', 'C#:min/5', 'D/5'),
#   ('B:min', 'E/5', 'E:min'),
#   ('F', 'F:9', 'G:dim7'),
#   ('A', 'B:7', 'C:7/5'),
#   ('D/5', 'G:min', 'G:minmaj7'),
#   ('B:min/b3', 'C:7', 'C:9'),
#   ('B:aug/3', 'B:min/b3', 'G:maj6(9)'),
#   ('Ab', 'C#:min/4', 'C#:min/5'),
#   ('C#:min/4', 'C#:min/5', 'E:maj7'),
#   ('B:aug/3', 'E', 'F#:7(#9)'),
#   ('A:9', 'Bb', 'F:7'),
#   ('A:7', 'B:7', 'F#:7'),
#   ('A:min', 'F#:dim', 'G/3'),
#   ('Bb', 'F#:sus4', 'G:min'),
#   ('C', 'G/3', 'G:min'),
#   ('Bb', 'C#:min/5', 'F'),
#   ('Ab', 'C:9', 'G:min7'),
#   ('A:7(#9)', 'B:7', 'E:7'),
#   ('A:7', 'Bb', 'E:7'),
#   ('A:min', 'F#:min7', 'G#:min'),
#   ('C#:min/4', 'E', 'F:7'),
#   ('A:7', 'D/5', 'E:min'),
#   ('B:7', 'E:7', 'G'),
#   ('D:9', 'F', 'G/3'),
#   ('D:maj/2', 'F#:7', 'F:7'),
#   ('Bb', 'C:7/5', 'F:9'),
#   ('D', 'D:9', 'G:min'),
#   ('C', 'C#:min', 'C:aug'),
#   ('D:9', 'E', 'G'),
#   ('A:7', 'E:7', 'F#:9'),
#   ('A', 'C#:7', 'F#:7'),
#   ('C', 'C:min', 'E:9'),
#   ('C#:min', 'F#:7', 'F#:min'),
#   ('A', 'C#:min/5', 'G:dim7'),
#   ('C#:min', 'C#:min/5', 'G/3'),
#   ('B:min/b3', 'C#:7', 'E/5'),
#   ('C', 'C:min', 'F#:dim/b3'),
#   ('D', 'F#:dim/b3', 'G:maj6(9)'),
#   ('C#:7', 'C:9', 'G:7'),
#   ('B:min/b3', 'E', 'G:dim7'),
#   ('D/5', 'F#:dim', 'G:min'),
#   ('A:7(#9)', 'E:maj7', 'E:min'),
#   ('C#:min', 'C:aug', 'G:min7'),
#   ('E/5', 'E:7', 'F#:min7'),
#   ('C', 'F#:dim/b3', 'G'),
#   ('A/5', 'C:aug', 'E'),
#   ('Bb:min', 'C:min', 'G:min'),
#   ('B', 'C#:7', 'F#:9'),
#   ('A:7(#9)', 'Bb', 'G:min'),
#   ('F', 'F:7', 'G:dim7'),
#   ('B:min', 'C:9', 'F#:dim/b3'),
#   ('A:7(#9)', 'B:7(#9)', 'F#:min'),
#   ('Bb', 'D:9', 'F:9'),
#   ('Bb', 'F#:sus4', 'F:9'),
#   ('A:7', 'F', 'F:9'),
#   ('C:aug', 'F#:7(#9)', 'G:min'),
#   ('A', 'F#:9', 'G:min'),
#   ('A:7(#9)', 'C:7/5', 'F'),
#   ('A:7(#9)', 'C#:min', 'E:aug(9,11)'),
#   ('B:7', 'D', 'G:dim7'),
#   ('A', 'F', 'F#:7(#9)'),
#   ('C', 'C:7/5', 'E:min'),
#   ('A:min', 'C#:min/5', 'N'),
#   ('Bb', 'D', 'G:min'),
#   ('B', 'G:maj6(9)', 'N'),
#   ('D:maj/2', 'E:maj7', 'N'),
#   ('E:aug(9,11)', 'G:minmaj7', 'N'),
#   ('A:min', 'B:7', 'N'),
#   ('A', 'B:7', 'D/3'),
#   ('Ab', 'C#:min/4', 'E'),
#   ('A:min', 'B:7', 'E:7'),
#   ('C#:min/4', 'C#:min/5', 'F#:7(#9)'),
#   ('D', 'G#:min', 'G:min'),
#   ('B:min', 'E:min', 'G:min7'),
#   ('A', 'A:9', 'F#:dim/b3'),
#   ('D', 'F#:9', 'G:maj6(9)'),
#   ('F#:7(#9)', 'G:maj6(9)', 'G:min'),
#   ('C:aug', 'E', 'E:min'),
#   ('E', 'F:7', 'G:dim7'),
#   ('F', 'F#:sus4', 'F:maj7'),
#   ('A', 'B:7(#9)', 'C:min'),
#   ('B:min', 'Bb', 'F:7'),
#   ('D:9', 'F', 'F#'),
#   ('A:min', 'F#:min7', 'G/3'),
#   ('A:7(#9)', 'Bb', 'F:9'),
#   ('E:aug(9,11)', 'G:7', 'G:minmaj7'),
#   ('B:aug/3', 'B:min/b3', 'F#:dim/b3'),
#   ('A:7(#9)', 'D:9', 'F'),
#   ('B', 'D', 'F'),
#   ('B', 'C:9', 'G:min'),
#   ('A', 'A:7(#9)', 'B:7(#9)'),
#   ('A:min', 'Bb', 'G:min'),
#   ('B:7', 'E:7', 'G:7'),
#   ('A:min', 'B:7(#9)', 'F#:min'),
#   ('C#:min/4', 'C:9', 'G:7'),
#   ('D:9', 'E', 'G:7'),
#   ('A', 'F#:9', 'F:9'),
#   ('D', 'F', 'F:9'),
#   ('B:7', 'Bb:min', 'E:7'),
#   ('A', 'A:7', 'E:7'),
#   ('Bb', 'D', 'F:9'),
#   ('C', 'E:maj7', 'G/3'),
#   ('B:7', 'E:9', 'E:min'),
#   ('A:min', 'C#:min', 'E:aug(9,11)'),
#   ('A', 'A:9', 'C#'),
#   ('E', 'E:9', 'G/3'),
#   ('A:7(#9)', 'B:7(#9)', 'E/5'),
#   ('B', 'D:9', 'F#'),
#   ('A:min', 'B:min/b3', 'N'),
#   ('C:7/5', 'D:7/5', 'E:min'),
#   ('B:aug/3', 'B:min', 'F#:dim/b3'),
#   ('D:7/5', 'E:min', 'G:maj6(9)'),
#   ('G#:min', 'G:maj6(9)', 'G:min'),
#   ('B', 'B:7', 'E:7'),
#   ('B', 'B:min', 'D'),
#   ('E:9', 'F', 'F#:7(#9)'),
#   ('A:7(#9)', 'A:min', 'C'),
#   ('C#:min/4', 'C#:min/5', 'D'),
#   ('A', 'D/3', 'G:minmaj7'),
#   ('A:min', 'C:7', 'G/3'),
#   ('C#:min/5', 'D', 'E'),
#   ('B:aug/3', 'Bb', 'G:min'),
#   ('B:min', 'F#:dim/b3', 'F:maj7'),
#   ('E:aug(9,11)', 'F#:min', 'N'),
#   ('C:7', 'G#:min', 'G:min'),
#   ('A/5', 'F#:7', 'G:7'),
#   ('C#:min', 'F', 'F:maj7'),
#   ('F:maj7', 'G', 'G:min'),
#   ('D', 'F', 'G:min7'),
#   ('B', 'C:7', 'C:9'),
#   ('B:7(#9)', 'C#:min/4', 'G'),
#   ('B:min', 'F#:7(#9)', 'F#:dim/b3'),
#   ('A:7', 'B:7', 'F'),
#   ('A/5', 'D:maj/2', 'F#:sus4'),
#   ('A:min', 'F#:min', 'G:maj6(9)'),
#   ('C', 'G', 'G:minmaj7'),
#   ('A:min', 'Bb', 'F:9'),
#   ('B:aug/3', 'C#:min', 'E:aug(9,11)'),
#   ('E/5', 'E:7', 'F:7'),
#   ('D', 'E', 'F:maj7'),
#   ('C#:7', 'C:7', 'C:9'),
#   ('C#:min', 'E:maj7', 'F#:min'),
#   ('A', 'C#:7', 'F'),
#   ('Bb:min', 'C#:min/5', 'G:min'),
#   ('B', 'E/5', 'F#'),
#   ('E:aug(9,11)', 'G', 'G:min'),
#   ('D/3', 'E/5', 'E:7'),
#   ('B:7', 'E:min', 'G:7'),
#   ('Bb:min', 'F#:7', 'F:7'),
#   ('A/5', 'A:min', 'N'),
#   ('B', 'E:aug(9,11)', 'F#'),
#   ('A', 'C:min', 'D:9'),
#   ('B', 'C:9', 'G:min7'),
#   ('B:aug/3', 'Bb', 'F:9'),
#   ('A:7', 'A:9', 'B:7'),
#   ('A', 'Ab', 'C:min'),
#   ('C#:min', 'C#:min/5', 'G:minmaj7'),
#   ('C#:7', 'E', 'F#'),
#   ('C:7/5', 'D/3', 'F'),
#   ('A/5', 'D/5', 'F#:sus4'),
#   ('B:min/b3', 'Bb:min', 'C#:7'),
#   ('C#:7', 'C:7/5', 'F'),
#   ('E', 'E:aug(9,11)', 'G:dim7'),
#   ('B', 'B:min/b3', 'F#:9'),
#   ('A:9', 'B:min', 'E'),
#   ('A:7', 'G#:min', 'G:min'),
#   ('B:min', 'C#:min/5', 'E'),
#   ('E:aug(9,11)', 'F#:9', 'N'),
#   ('A:min', 'E/5', 'F'),
#   ('F', 'F:7', 'G#:min'),
#   ('A:min', 'Ab', 'F#:min'),
#   ('G', 'G:min', 'G:min7'),
#   ('B:min', 'E', 'E:aug(9,11)'),
#   ('B:min/b3', 'C#:7', 'N'),
#   ('A:7', 'B:7', 'C#:min'),
#   ('B:7', 'C:7/5', 'G/3'),
#   ('Bb:min', 'G/3', 'G:min'),
#   ('Bb', 'D/3', 'G:min'),
#   ('C#', 'E', 'F#:7'),
#   ('A:7(#9)', 'B:7(#9)', 'G:min'),
#   ('A:min', 'E:aug(9,11)', 'F'),
#   ('C#:min', 'C:aug', 'G:maj6(9)'),
#   ('Ab', 'G:maj6(9)', 'N'),
#   ('Bb:min', 'C#:min', 'C:aug'),
#   ('B:7', 'D', 'G#:min'),
#   ('B:7(#9)', 'C:9', 'G:min'),
#   ('A:min', 'F#:dim/b3', 'G:min'),
#   ('Bb', 'F', 'F#:dim/b3'),
#   ('F', 'F:9', 'G/3'),
#   ('A:7', 'A:7(#9)', 'B:7'),
#   ('C#:min/4', 'C:7', 'C:9'),
#   ('E:maj7', 'F', 'F#:dim'),
#   ('B:min', 'F#:min7', 'G'),
#   ('B:min/b3', 'G:maj6(9)', 'N'),
#   ('B:7', 'C:7', 'F#:dim/b3'),
#   ('C#', 'C#:min', 'C#:min/5'),
#   ('F', 'F#:dim', 'F#:sus4'),
#   ('C#', 'F#', 'F#:min'),
#   ('A', 'F#:sus4', 'G:min'),
#   ('A:7(#9)', 'C:aug', 'E'),
#   ('B:aug/3', 'B:min/b3', 'F#:dim'),
#   ('B:min', 'B:min/b3', 'E'),
#   ('A:min', 'Bb', 'C'),
#   ('Bb', 'D/3', 'F:9'),
#   ('A:min', 'E:7', 'F#:min'),
#   ('C:9', 'F#:7(#9)', 'G:min7'),
#   ('B:7(#9)', 'G', 'G:7'),
#   ('A:7(#9)', 'B:7(#9)', 'F:9'),
#   ('F#:7', 'F:7', 'N'),
#   ('F', 'F#:min7', 'F:7'),
#   ('A', 'B:min', 'G#:min'),
#   ('A:min', 'F#:dim/b3', 'F:9'),
#   ('C:aug', 'C:min', 'G'),
#   ('D', 'D:9', 'G:maj6(9)'),
#   ('Bb', 'C#:min', 'C#:min/5'),
#   ('A', 'A:min', 'D/3'),
#   ('A:7', 'E:7', 'F#:7'),
#   ('C:7', 'C:9', 'E:min'),
#   ('Ab', 'B:7', 'E:7'),
#   ('E', 'E:9', 'G:minmaj7'),
#   ('B:7', 'C:7/5', 'F#'),
#   ('F', 'F:7', 'G/3'),
#   ('Bb:min', 'F#', 'G:min'),
#   ('Bb', 'E:7', 'F'),
#   ('A:min', 'G/3', 'G:dim7'),
#   ('C', 'D:9', 'G'),
#   ('C:aug', 'D:9', 'E'),
#   ('F#', 'F#:dim', 'G:min'),
#   ('A/5', 'F#:sus4', 'G:7'),
#   ('B', 'F#:7', 'G:7'),
#   ('A', 'A:7', 'F#:9'),
#   ('B:7(#9)', 'C#:min/4', 'C#:min/5'),
#   ('B:7(#9)', 'E:maj7', 'G'),
#   ('A', 'E:7', 'G:dim7'),
#   ('B:7', 'D', 'G/3'),
#   ('A', 'F#:sus4', 'F:9'),
#   ('B:aug/3', 'F', 'G:min7'),
#   ('A:min', 'E:9', 'N'),
#   ('F', 'F:maj7', 'G:dim7'),
#   ('B:aug/3', 'F:maj7', 'N'),
#   ('B:7(#9)', 'C:9', 'G:min7'),
#   ('A:min', 'F#:dim/b3', 'G:min7'),
#   ('A', 'Bb', 'F#:9'),
#   ('A', 'B:min', 'D/5'),
#   ('B', 'B:7', 'F#:9'),
#   ('D', 'E', 'E:7'),
#   ('A', 'F#:9', 'G:maj6(9)'),
#   ('A', 'F#:7(#9)', 'F#:sus4'),
#   ('D:9', 'G:dim7', 'G:min'),
#   ('D', 'F', 'G:maj6(9)'),
#   ('A/5', 'B:min', 'F#:dim/b3'),
#   ('Bb', 'D', 'G:maj6(9)'),
#   ('A:9', 'A:min', 'E'),
#   ('A:7(#9)', 'B:7', 'C:7/5'),
#   ('A', 'C:min', 'E:maj7'),
#   ('A', 'D/3', 'E:maj7'),
#   ('Ab', 'C#:min', 'E:aug(9,11)'),
#   ('A:7(#9)', 'A:min', 'F#:dim/b3'),
#   ('A/5', 'Bb', 'G:min'),
#   ('D', 'G#:min', 'G:maj6(9)'),
#   ('C', 'E/5', 'G'),
#   ('A', 'F#:sus4', 'G:min7'),
#   ('C#:min/4', 'C#:min/5', 'C:min'),
#   ('B', 'F#:9', 'G:min'),
#   ('B:min/b3', 'C#:min', 'F#:min'),
#   ('A', 'C#:min/5', 'F#'),
#   ('D:9', 'D:maj/2', 'F'),
#   ('B', 'C#:min/4', 'D'),
#   ('B:7', 'D:maj/2', 'E:7'),
#   ('B:min/b3', 'E', 'F#'),
#   ('A/5', 'C#:min', 'E:aug(9,11)'),
#   ('B:7', 'C', 'C:7'),
#   ('D/3', 'E:maj7', 'F:7'),
#   ('A', 'B:min', 'G/3'),
#   ('B:min/b3', 'C:7/5', 'F'),
#   ('A:min', 'D/3', 'F'),
#   ('A:min', 'C:min', 'F'),
#   ('A:7', 'A:min', 'F'),
#   ('A:7(#9)', 'B:7(#9)', 'B:min/b3'),
#   ('F#', 'G:dim7', 'N'),
#   ('F#:min', 'G:min', 'G:minmaj7'),
#   ('B:min/b3', 'C#', 'C#:7'),
#   ('C:7', 'C:9', 'E'),
#   ('Bb:min', 'E', 'G'),
#   ('A:7(#9)', 'B:7(#9)', 'C'),
#   ('C:9', 'C:aug', 'G:7'),
#   ('B:7', 'C:7/5', 'G:minmaj7'),
#   ('A', 'A:7(#9)', 'F#:9'),
#   ('B:aug/3', 'B:min/b3', 'D:7/5'),
#   ('A', 'A:7', 'E:9'),
#   ('B:aug/3', 'E:7', 'N'),
#   ('A/5', 'D:9', 'G:min'),
#   ('C#:min', 'E:7', 'F#'),
#   ('B:7', 'D', 'F#'),
#   ('A:min', 'C#:7', 'G'),
#   ('A', 'F', 'F:maj7'),
#   ('D:7/5', 'E:min', 'F#:dim'),
#   ('F', 'G:min', 'G:min7'),
#   ('A/5', 'Bb', 'F:9'),
#   ('C#:min', 'C#:min/5', 'E:maj7'),
#   ('A', 'Bb', 'E:9'),
#   ('D/5', 'F', 'F:7'),
#   ('C#:min/4', 'C#:min/5', 'F:maj7'),
#   ('B', 'F#:9', 'F:9'),
#   ('A:min', 'B:min/b3', 'F#:dim/b3'),
#   ('F', 'F:9', 'G:minmaj7'),
#   ('B:7', 'D/5', 'E:7'),
#   ('A', 'C#:min/5', 'D/3'),
#   ('B:7', 'F#:7(#9)', 'G:min'),
#   ('A', 'C:min', 'F#:7(#9)'),
#   ('A', 'D/3', 'F#:7(#9)'),
#   ('B:aug/3', 'B:min', 'D:7/5'),
#   ('B:min', 'E', 'F#:min7'),
#   ('Bb', 'F#:min', 'G'),
#   ('B:min', 'D/3', 'E'),
#   ('Bb', 'F#:dim/b3', 'G'),
#   ('A:7', 'E:min', 'G#:min'),
#   ('A', 'F#:9', 'F#:dim/b3'),
#   ('A:9', 'Bb:min', 'N'),
#   ('E/5', 'E:7', 'G:dim7'),
#   ('B:7', 'E/5', 'E:min'),
#   ('B:7', 'C:7/5', 'D:9'),
#   ('A:9', 'C#:min', 'F#'),
#   ('A:7', 'E:7', 'F'),
#   ('A:7(#9)', 'D:maj/2', 'E:min'),
#   ('B:min', 'F#', 'G'),
#   ('B:7', 'C#', 'C:7/5'),
#   ('B:min', 'F', 'F:maj7'),
#   ('B', 'F#', 'G:dim7'),
#   ('A', 'E:9', 'G#:min'),
#   ('C', 'D:9', 'E:min'),
#   ('A:min', 'B:7(#9)', 'C'),
#   ('B:7', 'D', 'D/3'),
#   ('B:7(#9)', 'C:aug', 'G'),
#   ('C#:7', 'C#:min/4', 'E'),
#   ('A:min', 'Bb:min', 'G'),
#   ('A:min', 'C#', 'G'),
#   ('C:7/5', 'E/5', 'E:7'),
#   ('A:min', 'C:7/5', 'F#:min'),
#   ('Bb', 'G:maj6(9)', 'G:min'),
#   ('A:7', 'B:7(#9)', 'Bb:min'),
#   ('A', 'A:7(#9)', 'E:9'),
#   ('A/5', 'A:min', 'F#:dim/b3'),
#   ('E:9', 'F', 'F:maj7'),
#   ('F', 'F:7', 'G:minmaj7'),
#   ('A:min', 'B', 'G'),
#   ('F#', 'F#:7', 'F:7'),
#   ('C#:min', 'C#:min/5', 'F#:7(#9)'),
#   ('C:7/5', 'E:aug(9,11)', 'N'),
#   ('A:7(#9)', 'E:7', 'N'),
#   ('A/5', 'B:min/b3', 'C#:7'),
#   ('Bb:min', 'E', 'G:7'),
#   ('A:min', 'B:aug/3', 'G/3'),
#   ('B:7', 'D', 'G:minmaj7'),
#   ('A:7(#9)', 'D/5', 'E:min'),
#   ('C#', 'F#', 'F:9'),
#   ('B:min/b3', 'C#:7', 'E:9'),
#   ('E:aug(9,11)', 'F#:dim/b3', 'N'),
#   ('A', 'A:min', 'F'),
#   ('B:min/b3', 'F#:7', 'G:7'),
#   ('C#:min', 'C:aug', 'F#:dim'),
#   ('B:min/b3', 'C#:7', 'F#:dim/b3'),
#   ('A:7', 'B:7', 'F#:min'),
#   ('A', 'B:7(#9)', 'F#:9'),
#   ('E', 'E:9', 'E:maj7'),
#   ('Bb', 'E:aug(9,11)', 'N'),
#   ('A:min', 'D:maj/2', 'E:min'),
#   ('C', 'E:min', 'G:min'),
#   ('D', 'E/5', 'E:7'),
#   ('A:7(#9)', 'D', 'F#:min'),
#   ('A:min', 'F#:dim/b3', 'G:maj6(9)'),
#   ('C#:min/4', 'G:maj6(9)', 'N'),
#   ('A:min', 'D:7/5', 'G/3'),
#   ('D', 'E:maj7', 'F:7'),
#   ('A:7', 'E:min', 'G/3'),
#   ('D:maj/2', 'F#:7(#9)', 'G:min'),
#   ('C:aug', 'D/3', 'E'),
#   ('B', 'D', 'E/5'),
#   ('B', 'C:min', 'F#'),
#   ('C:min', 'F:7', 'G'),
#   ('D', 'E', 'F#:9'),
#   ('C:min', 'D', 'E'),
#   ('A/5', 'F', 'G:min7'),
#   ('Bb', 'C#:min/5', 'G:min'),
#   ('E', 'E:maj7', 'G'),
#   ('E', 'G/3', 'G:dim7'),
#   ('B', 'C#:min', 'E:aug(9,11)'),
#   ('D', 'F#:min', 'G:7'),
#   ('A:7(#9)', 'F', 'F:9'),
#   ('Bb', 'Bb:min', 'F#:min7'),
#   ('E', 'E:aug(9,11)', 'F#'),
#   ('A', 'F#:sus4', 'G:maj6(9)'),
#   ('B:min', 'E', 'F:7'),
#   ('A:7(#9)', 'Bb:min', 'E:min'),
#   ('A', 'B:min', 'G:minmaj7'),
#   ('A:min', 'F', 'G:min'),
#   ('A:min', 'C#:7', 'E:min'),
#   ('C#:min/4', 'E', 'G/3'),
#   ('B:7(#9)', 'G:maj6(9)', 'N'),
#   ('B:7', 'Bb', 'D'),
#   ('A:7', 'F', 'F#:dim'),
#   ('A:9', 'B', 'D'),
#   ('D', 'F#:7', 'F:7'),
#   ('A:min', 'E', 'G:min'),
#   ('A:min', 'E/5', 'F#:min'),
#   ('A:min', 'F#', 'G#:min'),
#   ('B:min', 'E:maj7', 'N'),
#   ('A:7', 'C:7', 'E:7'),
#   ('Bb', 'D:maj/2', 'F:7'),
#   ('F#:7(#9)', 'F:9', 'G:min'),
#   ('E:maj7', 'F#:min7', 'N'),
#   ('Bb:min', 'C#', 'F#'),
#   ('C', 'D/5', 'G/3'),
#   ('A', 'Bb:min', 'G:min'),
#   ('A:min', 'E:aug(9,11)', 'F#:min'),
#   ('C#:min/4', 'C#:min/5', 'N'),
#   ('C#:min/4', 'C#:min/5', 'E:7'),
#   ('E:7', 'G:minmaj7', 'N'),
#   ('A:9', 'B:7', 'D'),
#   ('F', 'F:maj7', 'G/3'),
#   ('B:min/b3', 'C:aug', 'E'),
#   ('E', 'E:9', 'F#:7(#9)'),
#   ('Ab', 'E:7', 'N'),
#   ('Bb', 'C#:min/5', 'F:9'),
#   ('A', 'B:7(#9)', 'E:9'),
#   ('C#:7', 'D:9', 'F'),
#   ('A:7', 'B:7', 'B:aug/3'),
#   ('D', 'D/3', 'F#:min'),
#   ('C#:min', 'D:maj/2', 'E:aug(9,11)'),
#   ('Bb', 'E', 'E:9'),
#   ('Ab', 'B:aug/3', 'E'),
#   ('A:min', 'C', 'G:min'),
#   ('A:min', 'F#:7(#9)', 'G#:min'),
#   ('A/5', 'A:7', 'B:7'),
#   ('C', 'E:min', 'G:min7'),
#   ('B:aug/3', 'B:min/b3', 'G'),
#   ('B:7', 'C:7/5', 'E:maj7'),
#   ('E', 'F#:min7', 'G:dim7'),
#   ('A:7(#9)', 'B:7(#9)', 'F#:dim/b3'),
#   ('D/3', 'F', 'G'),
#   ('A:min', 'Bb:min', 'E:min'),
#   ('A/5', 'E:7', 'N'),
#   ('A:7', 'E:min', 'F#'),
#   ('E/5', 'E:7', 'G#:min'),
#   ('A', 'F#:9', 'F#:dim'),
#   ('D', 'F', 'F#:dim'),
#   ('A:min', 'E', 'F:9'),
#   ('A:min', 'E:9', 'F#:dim/b3'),
#   ('A:7', 'A:9', 'E:min'),
#   ('B:min/b3', 'E:7', 'N'),
#   ('G:7', 'G:min7', 'G:minmaj7'),
#   ('A', 'Ab', 'F#:9'),
#   ('Ab', 'D', 'F#:min'),
#   ('C#:7', 'G:maj6(9)', 'N'),
#   ('D:9', 'G:7', 'G:minmaj7'),
#   ('A', 'A:9', 'Bb:min'),
#   ('Bb', 'E:9', 'F'),
#   ('B', 'F#', 'G#:min'),
#   ('A:9', 'C#', 'N'),
#   ('A:7(#9)', 'D:9', 'G:min'),
#   ('B', 'G#:min', 'G:min'),
#   ('E', 'E:maj7', 'G:7'),
#   ('B', 'D', 'G:min'),
#   ('B:aug/3', 'B:min', 'G'),
#   ('C:min', 'E/5', 'G'),
#   ('B', 'B:aug/3', 'F#'),
#   ('Ab', 'B:7', 'C:7/5'),
#   ('F:maj7', 'G#:min', 'N'),
#   ('B', 'F#:9', 'G:maj6(9)'),
#   ('C#:min/4', 'C:7/5', 'F'),
#   ('C#:min', 'D/5', 'E:aug(9,11)'),
#   ('B:min', 'C:9', 'G:7'),
#   ('E:aug(9,11)', 'F', 'F:maj7'),
#   ('A:min', 'F#', 'G/3'),
#   ('A:min', 'D/5', 'E'),
#   ('C:min', 'E:aug(9,11)', 'G'),
#   ('C:9', 'G', 'G:min7'),
#   ('A:7', 'E:maj7', 'F:7'),
#   ('A', 'C:aug', 'G:dim7'),
#   ('A', 'E:7', 'F#'),
#   ('C:7/5', 'F', 'F#:9'),
#   ('B', 'F', 'F:9'),
#   ('C:9', 'D:maj/2', 'G:7'),
#   ('B:7(#9)', 'C#:min', 'E:aug(9,11)'),
#   ('C#:min/4', 'D:9', 'F'),
#   ('E', 'G', 'G:min7'),
#   ('F#:dim', 'G:7', 'G:minmaj7'),
#   ('B:7', 'C:7/5', 'F#:7(#9)'),
#   ('A', 'A:9', 'G:7'),
#   ('B', 'D', 'F:9'),
#   ('A:7', 'B:7', 'G:min'),
#   ('A', 'F#', 'F#:7(#9)'),
#   ('A:min', 'C', 'G:min7'),
#   ('A:7(#9)', 'G#:min', 'G:min'),
#   ('A:9', 'C:7', 'C:9'),
#   ('C#', 'C:aug', 'F#'),
#   ('A:min', 'C#:min/5', 'F'),
#   ('C#', 'C:7/5', 'E'),
#   ('B:aug/3', 'B:min/b3', 'G:7'),
#   ('A', 'Ab', 'E:9'),
#   ('C:9', 'D:7/5', 'E:min'),
#   ('E/5', 'E:7', 'G/3'),
#   ('B:min', 'D:7/5', 'E:aug(9,11)'),
#   ('A:min', 'B:7', 'F'),
#   ('B', 'F', 'G:min7'),
#   ('A:7', 'E:min', 'G:minmaj7'),
#   ('B:aug/3', 'E', 'F#:9'),
#   ('B:7', 'D', 'E:maj7'),
#   ('Bb:min', 'G:dim7', 'G:min'),
#   ('B', 'F#', 'G/3'),
#   ('C:9', 'D/5', 'G:7'),
#   ('C:aug', 'E', 'F#:min7'),
#   ('C', 'D:maj/2', 'G/3'),
#   ('C#:min', 'E:9', 'F#'),
#   ('B', 'D', 'G:min7'),
#   ('B:7', 'G:7', 'G:minmaj7'),
#   ('A:9', 'C#:min/4', 'C#:min/5'),
#   ('F', 'F#:9', 'F:9'),
#   ('C#:min/4', 'E', 'G:minmaj7'),
#   ('F#:9', 'G:maj6(9)', 'N'),
#   ('B:min/b3', 'C#:min', 'E:aug(9,11)'),
#   ('C#:min', 'C:aug', 'F#:sus4'),
#   ('B:aug/3', 'F#:7', 'F:7'),
#   ('A', 'E:9', 'F#:7'),
#   ('A:min', 'C:min', 'F#:min'),
#   ('A:7', 'A:min', 'F#:min'),
#   ('C:9', 'F#:7', 'G:min'),
#   ('Ab', 'D:9', 'G:min'),
#   ('B:7', 'B:7(#9)', 'D'),
#   ('A:7', 'B:7', 'F:9'),
#   ('F#:min', 'F:maj7', 'N'),
#   ('C#', 'E:maj7', 'F#'),
#   ('A:min', 'G/3', 'G:minmaj7'),
#   ('A/5', 'D', 'G:maj6(9)'),
#   ('B', 'F#:9', 'F#:dim/b3'),
#   ('C#:7', 'C#:min', 'E:aug(9,11)'),
#   ('A:7(#9)', 'A:9', 'E:min'),
#   ('B:7', 'C#:7', 'C:7/5'),
#   ('C:7/5', 'F', 'F#:dim/b3'),
#   ('B:aug/3', 'B:min/b3', 'E:min'),
#   ('A:9', 'F#:7(#9)', 'G:min'),
#   ('D/3', 'F#:sus4', 'G'),
#   ('D/3', 'D:9', 'F'),
#   ('B:7', 'C:7', 'G'),
#   ('F', 'F:maj7', 'G:minmaj7'),
#   ('F', 'F#:9', 'G:min7'),
#   ('C:9', 'F', 'F#:min'),
#   ('A', 'Bb', 'F'),
#   ('C#:7', 'C:aug', 'E'),
#   ('A', 'C:min', 'F:maj7'),
#   ('A:7(#9)', 'F:maj7', 'N'),
#   ('B:aug/3', 'B:min/b3', 'C#:min/5'),
#   ('B:min', 'E:min', 'F#:sus4'),
#   ('F#:min7', 'G:7', 'G:minmaj7'),
#   ('A', 'F', 'F#:9'),
#   ('A:7', 'C#:min', 'E:min'),
#   ('C#:min', 'C#:min/5', 'C:min'),
#   ('A', 'E:maj7', 'F:7'),
#   ('A:7', 'B:7', 'G:min7'),
#   ('B:7(#9)', 'D/5', 'G'),
#   ('C:7/5', 'E:9', 'F'),
#   ('B:aug/3', 'B:min', 'E:min'),
#   ('C#:min/4', 'C#:min/5', 'F#:9'),
#   ('E/5', 'E:7', 'F#'),
#   ('C:9', 'D', 'F#:min'),
#   ('B:7', 'D', 'F#:7(#9)'),
#   ('A:7(#9)', 'B:7(#9)', 'C#:7'),
#   ('B:7', 'E:7', 'F#:min7'),
#   ('B:min', 'C:7', 'C:9'),
#   ('A:min', 'C', 'E:aug(9,11)'),
#   ('C', 'E:min', 'G:maj6(9)'),
#   ('D/5', 'E:maj7', 'N'),
#   ('A:7', 'C#:min', 'C#:min/5'),
#   ('E:aug(9,11)', 'F#:7', 'N'),
#   ('D/3', 'F#', 'N'),
#   ('B:aug/3', 'E', 'F#:dim/b3'),
#   ('A', 'C#:7', 'G:min7'),
#   ('C:7', 'C:aug', 'E'),
#   ('Ab', 'G#:min', 'G:min'),
#   ('B:7', 'G', 'G:min'),
#   ('Bb', 'Bb:min', 'C:9'),
#   ('B:7', 'C:min', 'E:min'),
#   ('B:min', 'E', 'F#:sus4'),
#   ('A:min', 'G', 'G:dim7'),
#   ('D', 'E', 'F#:7'),
#   ('C#:min', 'C#:min/4', 'C:aug'),
#   ('B', 'B:7(#9)', 'F#:9'),
#   ('C:7/5', 'E:7', 'F'),
#   ('G:min', 'G:minmaj7', 'N'),
#   ('C#', 'G:min', 'G:minmaj7'),
#   ('A', 'C', 'F#:9'),
#   ('B:7', 'C#:min', 'E:7'),
#   ('Bb:min', 'D', 'E'),
#   ('A:min', 'F', 'G:maj6(9)'),
#   ('C#', 'F#', 'F#:dim/b3'),
#   ('D:maj/2', 'G:7', 'G:minmaj7'),
#   ('A:7', 'Bb', 'Bb:min'),
#   ('C:aug', 'E', 'F:7'),
#   ('D:9', 'E:maj7', 'G:min'),
#   ('A:min', 'E:7', 'F#:dim/b3'),
#   ('Bb', 'E:7', 'G:min'),
#   ('F', 'F#', 'F:7'),
#   ('Bb', 'F', 'G:7'),
#   ('A:min', 'G#:min', 'G:min7'),
#   ('A/5', 'B:min', 'G'),
#   ('A:7', 'B:7', 'B:min/b3'),
#   ('C', 'C#:min/5', 'G'),
#   ('Bb', 'C:7/5', 'G'),
#   ('E:9', 'E:maj7', 'F:7'),
#   ('F#:min7', 'G', 'G:min'),
#   ('A:7', 'B:7', 'C'),
#   ('B:min', 'E:maj7', 'F#:dim/b3'),
#   ('C:7', 'C:9', 'D'),
#   ('B:7', 'C:7', 'G:7'),
#   ('B:7', 'E:min', 'F#:min7'),
#   ('B:min/b3', 'F', 'F:9'),
#   ('A:7(#9)', 'A:min', 'G'),
#   ('B:7(#9)', 'D:7/5', 'E:min'),
#   ('C#:min/5', 'F', 'F:maj7'),
#   ('C', 'D/3', 'E:min'),
#   ('C#:7', 'F#:7', 'G:7'),
#   ('Bb', 'C#:min/4', 'F'),
#   ('A:min', 'C', 'G:maj6(9)'),
#   ('A:7(#9)', 'E', 'E:9'),
#   ('E/5', 'E:7', 'G:minmaj7'),
#   ('C#:min/4', 'E:7', 'N'),
#   ('D:7/5', 'E', 'G:dim7'),
#   ('A:9', 'D:maj/2', 'N'),
#   ('Bb', 'D:9', 'G'),
#   ('B:min', 'F#:7', 'F#:dim/b3'),
#   ('B', 'F#', 'G:minmaj7'),
#   ('A', 'E:9', 'F'),
#   ('Bb', 'E:7', 'F:9'),
#   ('Bb', 'F#:sus4', 'G'),
#   ('A', 'C#:min/4', 'G:dim7'),
#   ('Ab', 'E:maj7', 'F:7'),
#   ('E:aug(9,11)', 'G:7', 'N'),
#   ('B:min/b3', 'F', 'G:min7'),
#   ('D:9', 'D:maj/2', 'G:min'),
#   ('A', 'C#:7', 'E:aug(9,11)'),
#   ('Ab', 'E:aug(9,11)', 'N'),
#   ('C:7', 'F#:7', 'G:7'),
#   ('A', 'C', 'E:9'),
#   ('C#:min', 'D:9', 'F'),
#   ('A:7', 'B:7(#9)', 'G:min7'),
#   ('A:7(#9)', 'B:7(#9)', 'D:7/5'),
#   ('B:7', 'E:7', 'F:7'),
#   ('C#', 'E', 'G:min'),
#   ('D:maj/2', 'G', 'G:min'),
#   ('A', 'D:7/5', 'G:dim7'),
#   ('B', 'F#:9', 'F#:dim'),
#   ('A/5', 'F#:dim/b3', 'F#:sus4'),
#   ('C#:min/4', 'D:7/5', 'E'),
#   ('B:7(#9)', 'D:maj/2', 'G'),
#   ('A:7', 'B:aug/3', 'E:7'),
#   ('C#:min/4', 'C#:min/5', 'C:7/5'),
#   ('B:7(#9)', 'B:aug/3', 'E'),
#   ('C:7/5', 'E', 'F'),
#   ('A:min', 'F:9', 'G'),
#   ('A:7(#9)', 'C#:min', 'C#:min/5'),
#   ('A:7(#9)', 'E:min', 'G#:min'),
#   ('Bb', 'Bb:min', 'F#:sus4'),
#   ('E', 'E:9', 'F:maj7'),
#   ('Bb', 'F#', 'N'),
#   ('Bb', 'F:7', 'G:7'),
#   ('Bb:min', 'C:min', 'G'),
#   ('A:9', 'D/5', 'N'),
#   ('C', 'F#:min', 'G/3'),
#   ('A:7(#9)', 'Bb', 'G'),
#   ('A:min', 'C#:min/4', 'N'),
#   ('A:min', 'C:9', 'G/3'),
#   ('A', 'C:min', 'E:7'),
#   ('B:min', 'C:aug', 'D:7/5'),
#   ('Bb:min', 'F:maj7', 'G:min'),
#   ('C#:min/4', 'E', 'E:maj7'),
#   ('B', 'E:9', 'F#:9'),
#   ('A/5', 'F#:7', 'F:7'),
#   ('Bb', 'Bb:min', 'G:dim7'),
#   ('F#:7', 'F#:min', 'G:7'),
#   ('Bb', 'E', 'F'),
#   ('D/5', 'E', 'G'),
#   ('E:min', 'F#:7', 'G:7'),
#   ('E:aug(9,11)', 'F#:sus4', 'N'),
#   ('A/5', 'C#:min', 'F#:sus4'),
#   ('A:7', 'B:7', 'G:maj6(9)'),
#   ('A:7(#9)', 'Bb', 'Bb:min'),
#   ('D', 'E', 'F'),
#   ('C#:min/5', 'E:maj7', 'N'),
#   ('A:min', 'F#:dim', 'N'),
#   ('A:7(#9)', 'D', 'G:maj6(9)'),
#   ('B:7', 'C:7/5', 'C:min'),
#   ('C:9', 'E:maj7', 'G:min7'),
#   ('C', 'F#', 'G'),
#   ('E:maj7', 'F#:min', 'F:7'),
#   ('E', 'F#', 'G#:min'),
#   ('B:7', 'E:min', 'F:7'),
#   ('C#:7', 'E:7', 'N'),
#   ('Ab', 'E', 'E:9'),
#   ('A', 'C#:7', 'G:maj6(9)'),
#   ('A', 'E:aug(9,11)', 'F#:9'),
#   ('A:7', 'E:7', 'G:min'),
#   ('C:7', 'C:9', 'D:maj/2'),
#   ('E', 'G#:min', 'G:min'),
#   ('F#:7(#9)', 'F:7', 'G:min'),
#   ('C', 'G/3', 'G:7'),
#   ('C#', 'C#:7', 'E'),
#   ('C', 'C#:min/5', 'E:min'),
#   ('C#:min', 'C#:min/5', 'E:7'),
#   ('A', 'D:9', 'E:9'),
#   ('C#', 'E', 'G:min7'),
#   ('A', 'C:aug', 'F#'),
#   ('A/5', 'F', 'F#:dim'),
#   ('B:7', 'C#:min/5', 'C:7'),
#   ('A:7', 'B:7(#9)', 'E:aug(9,11)'),
#   ('B:min', 'Bb:min', 'F#:dim/b3'),
#   ('E', 'F#:7(#9)', 'G:dim7'),
#   ('C#:min/4', 'E', 'F#:7(#9)'),
#   ('A:7(#9)', 'E:min', 'G/3'),
#   ('F', 'F#:min', 'F:9'),
#   ('E:7', 'F#:min', 'N'),
#   ('E', 'F', 'F:9'),
#   ('F', 'F#:dim/b3', 'F:9'),
#   ('A/5', 'A:7', 'E:min'),
#   ('B:7', 'C:7/5', 'F:maj7'),
#   ('C', 'C#', 'C:min'),
#   ('A', 'F#', 'F:maj7'),
#   ('B:aug/3', 'Bb', 'G'),
#   ('A:9', 'C', 'G/3'),
#   ('A:7', 'E:7', 'F:9'),
#   ('A', 'E:maj7', 'F#:sus4'),
#   ('A', 'F#:9', 'G:7'),
#   ('Bb:min', 'C#:min/4', 'G:min'),
#   ('A:7(#9)', 'F', 'F#:dim'),
#   ('E', 'E:min', 'G:dim7'),
#   ('Bb', 'F:9', 'G:min7'),
#   ('B:7', 'C', 'D'),
#   ('E:7', 'G', 'G:min'),
#   ('D/5', 'E', 'G:7'),
#   ('E:maj7', 'G:min', 'G:minmaj7'),
#   ('D', 'D/3', 'G:maj6(9)'),
#   ('C#:min', 'C:7/5', 'F'),
#   ('F', 'F#:dim/b3', 'G:min7'),
#   ('F#', 'G:min', 'N'),
#   ('E', 'F', 'G:min7'),
#   ('F:9', 'G:min', 'G:minmaj7'),
#   ('C#:min/4', 'C#:min/5', 'F#:7'),
#   ('Bb', 'Bb:min', 'C:7'),
#   ('A:9', 'C#:min', 'F#:min'),
#   ('E', 'F#', 'G/3'),
#   ('B', 'E/5', 'E:7'),
#   ('A:min', 'F#:min7', 'N'),
#   ('C', 'E:min', 'F#:dim'),
#   ('A', 'C:7', 'G:dim7'),
#   ('Ab', 'Bb', 'Bb:min'),
#   ('A/5', 'Ab', 'F#:sus4'),
#   ('A:7', 'E:7', 'G:min7'),
#   ('C#', 'C:min', 'G'),
#   ('C#', 'D/3', 'G'),
#   ('D/5', 'F#:7(#9)', 'G:min'),
#   ('A:7', 'F#', 'N'),
#   ('D/3', 'G:min', 'G:minmaj7'),
#   ('C#:min', 'E:aug(9,11)', 'G#:min'),
#   ('Ab', 'D', 'G:maj6(9)'),
#   ('A:7(#9)', 'Bb', 'E:min'),
#   ('B', 'E:maj7', 'F:7'),
#   ('A:7', 'A:min', 'C'),
#   ('B', 'E:aug(9,11)', 'N'),
#   ('Bb:min', 'E:min', 'G:min'),
#   ('B:min/b3', 'F:maj7', 'N'),
#   ('B', 'C:7', 'D'),
#   ('C:7/5', 'F#', 'N'),
#   ('C:9', 'F#:sus4', 'G:min'),
#   ('C', 'E:maj7', 'N'),
#   ('E/5', 'E:7', 'E:maj7'),
#   ('C', 'C:min', 'E:aug(9,11)'),
#   ('A:9', 'F', 'F#:7(#9)'),
#   ('A:7(#9)', 'E:min', 'F#'),
#   ('D:9', 'G:min', 'G:min7'),
#   ...},
#  '102': {('A', 'B', 'E:maj7'),
#   ('B:7', 'B:min/b3', 'E'),
#   ('A', 'B:aug/3', 'D'),
#   ('D', 'F#:7', 'G'),
#   ('C', 'E', 'F#:min7'),
#   ('C#:min', 'D/5', 'E'),
#   ('E:min', 'G#:min', 'N'),
#   ('D/5', 'D:maj/2', 'E'),
#   ('D', 'D/5', 'E:aug(9,11)'),
#   ('C:7', 'D', 'D/5'),
#   ('C#:7', 'D', 'N'),
#   ('A', 'A:7', 'D'),
#   ('C#:min/5', 'E:min', 'N'),
#   ('A', 'F#:min', 'F:7'),
#   ('C#:min', 'E', 'F#:min7'),
#   ('C#', 'C:aug', 'F'),
#   ('C#:min', 'E', 'E:min'),
#   ('A', 'C#', 'E/5'),
#   ('A', 'B', 'E:aug(9,11)'),
#   ('D', 'D:maj/2', 'G'),
#   ('D:maj/2', 'E', 'E:maj7'),
#   ('A', 'C:7/5', 'N'),
#   ('C:7', 'D:maj/2', 'E'),
#   ('E:min', 'F:7', 'N'),
#   ('C#:min', 'E:9', 'N'),
#   ('B:7', 'E', 'G:maj6(9)'),
#   ('A', 'C#:min/5', 'F#:min'),
#   ('A', 'E/5', 'F:7'),
#   ('B:7(#9)', 'C#:min', 'E'),
#   ('D', 'E:min', 'G:dim7'),
#   ('A', 'Bb:min', 'E:min'),
#   ('D', 'E:9', 'G'),
#   ('E:min', 'G/3', 'N'),
#   ('C#:min/5', 'E', 'E/5'),
#   ('A', 'B:min/b3', 'N'),
#   ('A', 'A:7(#9)', 'G'),
#   ('B:min/b3', 'E', 'F#:min'),
#   ('E', 'E/5', 'F#:9'),
#   ('C#:min/4', 'G', 'N'),
#   ('C:7', 'D', 'E:min'),
#   ('A', 'G', 'G/3'),
#   ('A', 'F#:min7', 'N'),
#   ('A', 'E:min', 'F'),
#   ('B', 'F#:min', 'G'),
#   ('A', 'C#:min/4', 'G'),
#   ('A', 'C#:min/5', 'E'),
#   ('D:maj/2', 'E', 'E:aug(9,11)'),
#   ('B', 'D:maj/2', 'F#:min'),
#   ('D', 'D/5', 'F#:7(#9)'),
#   ('C#:min/4', 'D', 'D/5'),
#   ('C#', 'E:maj7', 'F'),
#   ('E:min', 'F#:min7', 'G'),
#   ('C', 'C:9', 'E'),
#   ('A', 'C#:min', 'F:7'),
#   ('B', 'F', 'F#:min7'),
#   ('Ab', 'E:min', 'N'),
#   ('Bb:min', 'D:maj/2', 'E'),
#   ('B:7(#9)', 'E', 'N'),
#   ('B:7', 'E', 'G#:min'),
#   ('A', 'B', 'F#:7(#9)'),
#   ('B', 'D:7/5', 'F#:min7'),
#   ('A/5', 'C:7/5', 'F#:min'),
#   ('C', 'F', 'G:maj6(9)'),
#   ('C#:min/5', 'F', 'N'),
#   ('C:7', 'E/5', 'F'),
#   ('B:min/b3', 'Bb:min', 'F'),
#   ('B:7', 'D:7/5', 'E'),
#   ('B', 'E:maj7', 'F#:min'),
#   ('A/5', 'B:min/b3', 'F#:min'),
#   ('Ab', 'F', 'G'),
#   ('B:min/b3', 'C#:min', 'E'),
#   ('A', 'C:7', 'N'),
#   ('C#:7', 'D:maj/2', 'E'),
#   ('B:min/b3', 'E:min', 'N'),
#   ('C:7', 'E:aug(9,11)', 'F'),
#   ('A:min', 'B:min', 'G:7'),
#   ('E', 'F#:min', 'F:maj7'),
#   ('A:7', 'Ab', 'F'),
#   ('B', 'D/5', 'F#:min'),
#   ('C#:min/5', 'D', 'N'),
#   ('C#:min', 'G:7', 'N'),
#   ('E', 'F#:min', 'G:minmaj7'),
#   ('D:maj/2', 'E', 'F#:7(#9)'),
#   ('C#:7', 'C#:min', 'E'),
#   ('C#', 'F', 'F#:7'),
#   ('C#:min', 'C:min', 'E'),
#   ('A', 'F#:dim/b3', 'G'),
#   ('A:7(#9)', 'C:7', 'F'),
#   ('A', 'B:min/b3', 'C#:min'),
#   ('A:min', 'B:min', 'D/5'),
#   ('C:min', 'D', 'D/5'),
#   ('Ab', 'D', 'G'),
#   ('E:min', 'F#:min', 'N'),
#   ('C', 'D:maj/2', 'F'),
#   ('A:7', 'B', 'F#:min7'),
#   ('A/5', 'B:min', 'F#:min'),
#   ('A', 'B:7', 'G'),
#   ('B', 'F#:7', 'F#:min'),
#   ('B', 'D/5', 'E'),
#   ('B:min/b3', 'E', 'E/5'),
#   ('A', 'Bb', 'E:min'),
#   ('C', 'F', 'G#:min'),
#   ('C', 'E', 'F:7'),
#   ('E', 'E/5', 'F#:min7'),
#   ('A:min', 'D', 'F#:9'),
#   ('E', 'E/5', 'F#:dim/b3'),
#   ('C#:min', 'E', 'F:7'),
#   ('A', 'D', 'F'),
#   ('C', 'C#:min/5', 'E'),
#   ('G', 'G:minmaj7', 'N'),
#   ('C#:min', 'F#:dim', 'N'),
#   ('A:7', 'D:9', 'E'),
#   ('A:7(#9)', 'Ab', 'F'),
#   ('D:maj/2', 'E', 'G:maj6(9)'),
#   ('A:7', 'E', 'G:min7'),
#   ('D', 'F#:dim', 'G'),
#   ('A', 'C#:min', 'F#:7'),
#   ('B', 'C#:min/4', 'F#:min7'),
#   ('A', 'F#:7(#9)', 'G'),
#   ('C:min', 'D', 'E:min'),
#   ('B', 'C#:min', 'N'),
#   ('A', 'A/5', 'E:min'),
#   ('Bb:min', 'C#:min', 'F'),
#   ('E', 'G#:min', 'N'),
#   ('D', 'G', 'G:minmaj7'),
#   ('C#', 'F', 'G:min'),
#   ('A:7', 'C:9', 'E'),
#   ('A:min', 'C#:7', 'D'),
#   ('B:7', 'E', 'G/3'),
#   ('A', 'E/5', 'G:min'),
#   ('B', 'C#', 'F#:min7'),
#   ('A:min', 'B:min', 'C#:min/5'),
#   ('A', 'E', 'G:min'),
#   ('D', 'D:maj/2', 'E:min'),
#   ('E:min', 'F#:9', 'N'),
#   ('B:min/b3', 'D', 'N'),
#   ('A:7', 'A:min', 'B:min'),
#   ('A:min', 'B:min', 'Bb'),
#   ('D:maj/2', 'E', 'G#:min'),
#   ('C#', 'E:min', 'G'),
#   ('Ab', 'F', 'G:7'),
#   ('B', 'E:min', 'F#:min7'),
#   ('C:9', 'E:min', 'G'),
#   ('A', 'B', 'G:7'),
#   ('B', 'E:7', 'F#:min'),
#   ('E', 'G/3', 'N'),
#   ('C#', 'D', 'D/5'),
#   ('A:7', 'D:7/5', 'E'),
#   ('A', 'D:maj/2', 'F#:min'),
#   ('A', 'C#:min/4', 'E:min'),
#   ('A:min', 'C#:min/4', 'D'),
#   ('A', 'C#:min', 'G:min'),
#   ('B', 'C:min', 'F#:min'),
#   ('A', 'C#:min', 'C:9'),
#   ('D', 'E:min', 'G#:min'),
#   ('A:min', 'B:min', 'C:7/5'),
#   ('B:7(#9)', 'D:maj/2', 'E'),
#   ('A:min', 'D', 'F#:min7'),
#   ('C#:min', 'E', 'F#:7'),
#   ('A:min', 'D', 'E:9'),
#   ('A', 'G:min7', 'N'),
#   ('A:7', 'E', 'E:maj7'),
#   ('E', 'E:aug(9,11)', 'F#:min'),
#   ('Ab', 'D', 'D/5'),
#   ('C', 'D', 'N'),
#   ('D', 'D/5', 'F#:min7'),
#   ('F', 'F#:min7', 'N'),
#   ('B', 'C#:min/4', 'F#:min'),
#   ('A', 'E:maj7', 'G'),
#   ('A', 'E/5', 'F:9'),
#   ('C:7', 'F', 'F#:7'),
#   ('A:min', 'Bb:min', 'D'),
#   ('B', 'C:min', 'E'),
#   ('A', 'E', 'F:9'),
#   ('B', 'E', 'F#:dim/b3'),
#   ('D/5', 'E', 'F#:min'),
#   ('B', 'B:aug/3', 'F#:min7'),
#   ('B', 'C:7', 'F#:min7'),
#   ('D', 'D/3', 'E:min'),
#   ('A:7', 'E', 'E:aug(9,11)'),
#   ('A', 'D/5', 'F#:min'),
#   ('C:7/5', 'E:min', 'G'),
#   ('B', 'C#', 'F#:min'),
#   ('A/5', 'F#:min', 'G/3'),
#   ('E', 'E/5', 'F:7'),
#   ('C:aug', 'E:min', 'N'),
#   ('A', 'A/5', 'E'),
#   ('C', 'E:7', 'F'),
#   ('A', 'C#:min', 'F:9'),
#   ('A', 'E/5', 'G:min7'),
#   ('Ab', 'D', 'E:min'),
#   ('D', 'F:7', 'G'),
#   ('C', 'E', 'G:min'),
#   ('A', 'F#:7', 'N'),
#   ('A', 'B', 'C#:min/5'),
#   ('B', 'E:min', 'F#:min'),
#   ('E', 'F#:min7', 'N'),
#   ('A', 'E', 'G:min7'),
#   ('A', 'Ab', 'G'),
#   ('C#', 'E/5', 'F'),
#   ('C:9', 'E', 'N'),
#   ('B:min/b3', 'C#', 'F'),
#   ('A', 'B', 'Bb'),
#   ('C:9', 'D', 'G'),
#   ('A', 'D:maj/2', 'E/5'),
#   ('Bb:min', 'F', 'G'),
#   ('A:min', 'B:min', 'C:min'),
#   ('C#:min', 'E:min', 'G'),
#   ('C#', 'E:aug(9,11)', 'F'),
#   ('E', 'F#:sus4', 'N'),
#   ('D', 'F#:min7', 'N'),
#   ('A:7', 'C:7/5', 'E'),
#   ('E', 'F#:7', 'F#:min'),
#   ('C:7', 'D:maj/2', 'F'),
#   ('A:7(#9)', 'F', 'N'),
#   ('A:7', 'E', 'F#:7(#9)'),
#   ('C', 'F', 'F#'),
#   ('A:min', 'B:min', 'D/3'),
#   ('C#', 'C#:min', 'N'),
#   ('D', 'E:min', 'G/3'),
#   ('E:min', 'G', 'G:dim7'),
#   ('Bb:min', 'E', 'F#:min'),
#   ('A', 'B', 'C:7/5'),
#   ('Bb:min', 'F', 'G:maj6(9)'),
#   ('A:7', 'B:min/b3', 'E'),
#   ('A', 'C#:min', 'F'),
#   ('A:7(#9)', 'E', 'N'),
#   ('E/5', 'G', 'N'),
#   ('A', 'B:7(#9)', 'E:min'),
#   ('A', 'A/5', 'E/5'),
#   ('A', 'A/5', 'B'),
#   ('B', 'B:aug/3', 'F#:min'),
#   ('D/5', 'E', 'E/5'),
#   ('C#', 'F', 'G:dim7'),
#   ('B:7', 'E', 'F#:dim'),
#   ('B', 'F#:min7', 'F:7'),
#   ('C', 'E', 'F:9'),
#   ('A', 'C:aug', 'N'),
#   ('A', 'D:7/5', 'E'),
#   ('B', 'F#:min', 'F:7'),
#   ('B:aug/3', 'E:min', 'G'),
#   ('A:7(#9)', 'B', 'F#:min'),
#   ('A', 'B:min/b3', 'E:min'),
#   ('Bb', 'C#:min', 'N'),
#   ('A:min', 'B:min', 'F:maj7'),
#   ('A:7', 'E', 'G:maj6(9)'),
#   ('C:7/5', 'D', 'G'),
#   ('F', 'G:minmaj7', 'N'),
#   ('A:min', 'D', 'F:7'),
#   ('A', 'E:min', 'F#:dim/b3'),
#   ('C:aug', 'D', 'N'),
#   ('A:9', 'B', 'F#:min7'),
#   ('Bb:min', 'F', 'G#:min'),
#   ('B:7', 'E', 'F:maj7'),
#   ('D', 'D/5', 'F:7'),
#   ('B:7', 'E', 'G:minmaj7'),
#   ('C#:min', 'F#:dim/b3', 'N'),
#   ('B:min/b3', 'C#:min', 'N'),
#   ('A:7(#9)', 'B', 'E'),
#   ('D', 'F#:dim/b3', 'G'),
#   ('A:min', 'B:min', 'F#:7'),
#   ('A:7(#9)', 'C', 'F'),
#   ('D/5', 'F', 'N'),
#   ('D', 'F#', 'G'),
#   ('C', 'D/5', 'E'),
#   ('A', 'C#:min/4', 'E/5'),
#   ('Ab', 'B', 'F#:min7'),
#   ('C#:min/4', 'E:min', 'N'),
#   ('C:min', 'E', 'F#:min'),
#   ('A', 'G:7', 'N'),
#   ('A/5', 'C:aug', 'F#:min'),
#   ('D', 'E/5', 'G'),
#   ('A', 'G', 'G:min7'),
#   ('A', 'E', 'E:aug(9,11)'),
#   ('A:min', 'D', 'E/5'),
#   ('F#:7(#9)', 'G', 'N'),
#   ('C:9', 'G', 'N'),
#   ('C#:min', 'E', 'F'),
#   ('C#:min', 'D', 'G'),
#   ('A/5', 'C#:7', 'F#:min'),
#   ('Bb:min', 'F', 'G:7'),
#   ('A:7', 'E', 'G#:min'),
#   ('D', 'D/5', 'E/5'),
#   ('A', 'D:7/5', 'E/5'),
#   ('D', 'E:min', 'F#'),
#   ('A/5', 'C', 'F#:min'),
#   ('D', 'E:aug(9,11)', 'G'),
#   ('A', 'C:7', 'E:min'),
#   ('Ab', 'C', 'E'),
#   ('E', 'E/5', 'G:min'),
#   ('A:min', 'C:7', 'D'),
#   ('C:9', 'D', 'D/5'),
#   ('A', 'Bb:min', 'N'),
#   ('B:7', 'D:9', 'E'),
#   ('C', 'F', 'G:minmaj7'),
#   ('A', 'Bb:min', 'F'),
#   ('C:7', 'D:7/5', 'F'),
#   ('A', 'C:7/5', 'F#:min'),
#   ('C:7', 'D', 'N'),
#   ('Bb:min', 'E:min', 'G'),
#   ('C#:min', 'E', 'F#:sus4'),
#   ('A', 'C:9', 'G'),
#   ('A/5', 'C', 'E'),
#   ('A', 'B:min/b3', 'F#:min'),
#   ('A:7(#9)', 'G', 'N'),
#   ('A:9', 'A:min', 'B:min'),
#   ('Bb:min', 'D', 'D/5'),
#   ('C:7', 'F', 'F#:sus4'),
#   ('C:min', 'E:min', 'N'),
#   ('A:min', 'D', 'F#:7'),
#   ('A', 'C:7/5', 'E'),
#   ('E:min', 'F:9', 'G'),
#   ('A', 'Ab', 'E:min'),
#   ('A:9', 'B', 'F#:min'),
#   ('C#:7', 'E:min', 'G'),
#   ('B', 'F', 'N'),
#   ('D', 'D/5', 'F#:7'),
#   ('A', 'B:min/b3', 'E'),
#   ('D:maj/2', 'E', 'F#:dim'),
#   ('A', 'F', 'G'),
#   ('A', 'D', 'F#:dim/b3'),
#   ('E:min', 'G', 'G:maj6(9)'),
#   ('Bb:min', 'F', 'G/3'),
#   ('B:7', 'Bb', 'E'),
#   ('F', 'F#:7', 'N'),
#   ('A', 'C#', 'D'),
#   ('Ab', 'B', 'F#:min'),
#   ('B:7(#9)', 'E', 'F#:min'),
#   ('Ab', 'F', 'F#:7'),
#   ('A:9', 'B', 'E'),
#   ('E', 'E/5', 'F:9'),
#   ('A:9', 'C', 'F'),
#   ('C:min', 'E', 'E/5'),
#   ('A', 'B', 'F#:7'),
#   ('Bb', 'C', 'E'),
#   ('D', 'E:min', 'F#:dim'),
#   ('C#:min/4', 'D', 'N'),
#   ('A:7', 'D/5', 'E'),
#   ('A', 'B:aug/3', 'N'),
#   ('B:aug/3', 'C', 'F'),
#   ('A', 'E/5', 'G:maj6(9)'),
#   ('D:maj/2', 'E', 'F:maj7'),
#   ('D:maj/2', 'E', 'G:minmaj7'),
#   ('A', 'C:9', 'D'),
#   ('Ab', 'B', 'E'),
#   ('A', 'Bb:min', 'C#:min'),
#   ('A', 'E', 'G:maj6(9)'),
#   ('A', 'C:7', 'F#:min'),
#   ('A', 'A:7', 'N'),
#   ('B', 'C:aug', 'F#:min7'),
#   ('A:9', 'B:7', 'E'),
#   ('A', 'C#:min', 'C:7'),
#   ('B', 'C#:7', 'F#:min7'),
#   ('E:min', 'G', 'G#:min'),
#   ('C#:min', 'C:7', 'N'),
#   ('A:min', 'D', 'G:min'),
#   ('A', 'Bb', 'N'),
#   ('A', 'C:7/5', 'E/5'),
#   ('A/5', 'F#:min', 'G:min'),
#   ('D', 'E:min', 'F:maj7'),
#   ('E:min', 'F#:7(#9)', 'G'),
#   ('E', 'E/5', 'G:min7'),
#   ('D', 'E:min', 'G:minmaj7'),
#   ('C#:min', 'C:7', 'F'),
#   ('A', 'C:7', 'E'),
#   ('E:9', 'E:min', 'N'),
#   ('A:7', 'Ab', 'E'),
#   ('C#', 'D:maj/2', 'F'),
#   ('F', 'F#:9', 'N'),
#   ('C:min', 'F', 'N'),
#   ('B', 'E', 'G:min'),
#   ('A', 'B:min/b3', 'E/5'),
#   ('C:7/5', 'D', 'E:min'),
#   ('A', 'D', 'D:maj/2'),
#   ('A', 'G#:min', 'N'),
#   ('A', 'E/5', 'G#:min'),
#   ('A', 'E', 'G#:min'),
#   ('B:7', 'F', 'N'),
#   ('A', 'B', 'C:9'),
#   ('A', 'B', 'B:7(#9)'),
#   ('C:min', 'D', 'N'),
#   ('C:7', 'E:min', 'F'),
#   ('E', 'F', 'F#:min'),
#   ('A:7(#9)', 'D', 'N'),
#   ('A:min', 'B:min', 'E:7'),
#   ('B', 'F#:min7', 'F:9'),
#   ('B:aug/3', 'G', 'N'),
#   ('D:9', 'G', 'N'),
#   ('A:min', 'B:7', 'B:min'),
#   ('A/5', 'F#:7(#9)', 'F#:min'),
#   ('D', 'E/5', 'E:min'),
#   ('Bb:min', 'F', 'F#'),
#   ('A', 'F:7', 'G'),
#   ('A', 'B:aug/3', 'C#:min'),
#   ('A/5', 'Bb', 'F#:min'),
#   ('C#:min', 'D', 'E:min'),
#   ('E', 'F#:9', 'N'),
#   ('A:min', 'D', 'F:9'),
#   ('C#', 'D/5', 'F'),
#   ('D', 'D:maj/2', 'N'),
#   ('A', 'C#:min/5', 'D'),
#   ('A', 'A:7', 'C#:min'),
#   ('D', 'E:aug(9,11)', 'E:min'),
#   ('B:min', 'C', 'F'),
#   ('D', 'E:9', 'N'),
#   ('B', 'C:aug', 'F#:min'),
#   ('A', 'C:7', 'E/5'),
#   ('F', 'G:7', 'N'),
#   ('B', 'E', 'F:9'),
#   ('A:min', 'B:min', 'F#:sus4'),
#   ('A/5', 'E:min', 'G'),
#   ('D:maj/2', 'E:min', 'G'),
#   ('E:min', 'G:dim7', 'N'),
#   ('D:7/5', 'E', 'N'),
#   ('A', 'A:7(#9)', 'N'),
#   ('A', 'Bb', 'C#:min'),
#   ('C', 'E', 'G:maj6(9)'),
#   ('A', 'D', 'F:7'),
#   ('A', 'F:9', 'G'),
#   ('B', 'C#:7', 'F#:min'),
#   ('B:7(#9)', 'D', 'D/5'),
#   ('E', 'E:7', 'F#:min'),
#   ('B', 'F#:min', 'N'),
#   ('C#', 'F', 'F#:dim/b3'),
#   ('A', 'C#:min/4', 'N'),
#   ('A:7', 'C:min', 'E'),
#   ('B:7', 'C', 'F'),
#   ('A', 'G', 'G:maj6(9)'),
#   ('E', 'F#:min', 'F#:min7'),
#   ('E:min', 'G', 'G/3'),
#   ('E:min', 'F#:min7', 'N'),
#   ('F:7', 'G', 'N'),
#   ('A/5', 'F#:min', 'G:min7'),
#   ('B', 'C#:7', 'E'),
#   ('F#:dim', 'G', 'N'),
#   ('A', 'D:9', 'G'),
#   ('A:min', 'B:min', 'C#:min'),
#   ('B', 'E', 'G:min7'),
#   ('Ab', 'B:aug/3', 'F'),
#   ('C#', 'F', 'G/3'),
#   ('D', 'D/5', 'F'),
#   ('B', 'F#:min7', 'F#:sus4'),
#   ('C:7', 'F', 'F#:9'),
#   ('A', 'E/5', 'G/3'),
#   ('B', 'F#:min', 'F#:sus4'),
#   ('C', 'E', 'G#:min'),
#   ('D', 'D/3', 'N'),
#   ('A:7', 'C#:7', 'E'),
#   ('C:min', 'D:maj/2', 'E'),
#   ('A/5', 'A:7(#9)', 'F#:min'),
#   ('A', 'E', 'G/3'),
#   ('A', 'E:min', 'G:min'),
#   ('A', 'C#:min', 'F#:dim/b3'),
#   ('C', 'D:7/5', 'E'),
#   ('C#:min', 'F#:9', 'N'),
#   ('B', 'C:7', 'F'),
#   ('C#:min', 'G:min7', 'N'),
#   ('C', 'C:aug', 'F'),
#   ('A', 'B', 'F'),
#   ('A', 'G', 'G#:min'),
#   ('B', 'F#:min7', 'G:dim7'),
#   ('F', 'F#:sus4', 'N'),
#   ('Ab', 'D:7/5', 'F'),
#   ('B', 'F#:7(#9)', 'F#:min7'),
#   ('C', 'C#:7', 'F'),
#   ('A', 'F#:dim/b3', 'N'),
#   ('D', 'D/5', 'F#:sus4'),
#   ('A', 'A:7(#9)', 'C#:min'),
#   ('D:maj/2', 'F', 'N'),
#   ('Bb:min', 'F', 'G:minmaj7'),
#   ('Ab', 'D', 'N'),
#   ('B:7', 'G', 'N'),
#   ('C#:7', 'C:7', 'F'),
#   ('B:7', 'D/3', 'E'),
#   ('B:min/b3', 'F', 'N'),
#   ('A:7', 'E', 'F#:dim'),
#   ('B', 'Bb', 'F#:min7'),
#   ('A', 'C#:min', 'G/3'),
#   ('C#', 'E:7', 'F'),
#   ('B:7', 'B:7(#9)', 'E'),
#   ('A', 'B:7', 'N'),
#   ('A/5', 'E', 'N'),
#   ('E:min', 'F#:dim/b3', 'G'),
#   ('A:min', 'D', 'G:dim7'),
#   ('D:maj/2', 'E', 'E:7'),
#   ('Ab', 'F', 'F#:sus4'),
#   ('B', 'C:7/5', 'F#:min7'),
#   ('A', 'F#:7', 'F#:min'),
#   ('A:7(#9)', 'A:min', 'D'),
#   ('C#', 'C:min', 'F'),
#   ('A', 'G', 'G:7'),
#   ('C:9', 'E', 'F#:min'),
#   ('B', 'B:min/b3', 'F#:min7'),
#   ('A', 'E:aug(9,11)', 'G'),
#   ('D:7/5', 'G', 'N'),
#   ('D', 'F:maj7', 'G'),
#   ('A:7', 'E', 'F:maj7'),
#   ('D', 'F#:dim', 'N'),
#   ('A:7', 'E', 'G:minmaj7'),
#   ('A', 'E:min', 'F:9'),
#   ('C', 'C#:min/4', 'F'),
#   ('A', 'C#:min', 'D:maj/2'),
#   ('C', 'E', 'F#:dim/b3'),
#   ('A', 'F#:7(#9)', 'N'),
#   ('A', 'B:7(#9)', 'N'),
#   ('C#:min', 'E', 'F#:dim/b3'),
#   ('A/5', 'B', 'E'),
#   ('F#:min7', 'G', 'N'),
#   ('Bb', 'E', 'N'),
#   ('F', 'G#:min', 'N'),
#   ('A/5', 'C', 'F'),
#   ('A/5', 'C#:min/5', 'F#:min'),
#   ('C:7', 'F', 'F#:min7'),
#   ('E', 'E/5', 'G:maj6(9)'),
#   ('A/5', 'B:7', 'F#:min'),
#   ('Ab', 'C#:min/4', 'F'),
#   ('E', 'F#:7(#9)', 'N'),
#   ('E:7', 'E:min', 'G'),
#   ('E', 'F#:min', 'F:7'),
#   ('A', 'D', 'G:min'),
#   ('A', 'C:aug', 'F#:min'),
#   ('A', 'E:min', 'G:min7'),
#   ('C#', 'E:min', 'N'),
#   ('A', 'D', 'D:9'),
#   ('C:9', 'E:min', 'N'),
#   ('A:7', 'C#:min/5', 'E'),
#   ('A/5', 'B:7', 'E'),
#   ('A', 'D/5', 'G'),
#   ('A', 'B:7', 'C#:min'),
#   ('C#', 'E:min', 'F'),
#   ('B', 'Bb', 'F#:min'),
#   ('C#:min/4', 'C:7', 'F'),
#   ('F', 'G/3', 'N'),
#   ('B', 'C:7/5', 'F#:min'),
#   ('A/5', 'D/3', 'F#:min'),
#   ('Ab', 'G', 'N'),
#   ('E', 'E/5', 'G#:min'),
#   ('A:min', 'B:min', 'F#:9'),
#   ('B', 'B:min/b3', 'F#:min'),
#   ('B', 'Bb', 'E'),
#   ('C:9', 'E', 'E/5'),
#   ('Ab', 'E:min', 'F'),
#   ('Ab', 'B', 'F'),
#   ('Bb', 'C#:min', 'E'),
#   ('B:7', 'E', 'F#:9'),
#   ('A', 'D:9', 'E:min'),
#   ('A/5', 'G', 'N'),
#   ('D:maj/2', 'G', 'N'),
#   ('B', 'C:7/5', 'E'),
#   ('C#', 'D', 'G'),
#   ('A', 'B:7(#9)', 'C#:min'),
#   ('A:7(#9)', 'C', 'E'),
#   ('B', 'B:min/b3', 'E'),
#   ('A', 'E/5', 'F#:dim'),
#   ('A:7', 'Bb', 'E'),
#   ('A', 'D', 'F:9'),
#   ('A/5', 'F#:min', 'G'),
#   ('A', 'E', 'F#:dim'),
#   ('A', 'C:7', 'F'),
#   ('E:min', 'G', 'G:minmaj7'),
#   ('C#:min/4', 'D', 'E:min'),
#   ('C:7', 'F', 'F#:min'),
#   ('A', 'B:aug/3', 'E:min'),
#   ('C#:min', 'C#:min/4', 'N'),
#   ('A:min', 'B:aug/3', 'D'),
#   ('C:7/5', 'E:min', 'N'),
#   ('A:7(#9)', 'E', 'E/5'),
#   ('A', 'Bb:min', 'F#:min'),
#   ('B', 'F#:dim/b3', 'F#:min7'),
#   ('C#:min', 'F:7', 'N'),
#   ('A/5', 'F#:min', 'G:maj6(9)'),
#   ('C#', 'F', 'G:minmaj7'),
#   ('D', 'E:maj7', 'E:min'),
#   ('A', 'C:aug', 'E/5'),
#   ('D', 'F:7', 'N'),
#   ('A', 'E/5', 'F:maj7'),
#   ('A', 'E/5', 'G:minmaj7'),
#   ('B', 'B:7', 'F#:min7'),
#   ('B', 'E', 'G:maj6(9)'),
#   ('A:min', 'Bb', 'D'),
#   ('C#:min', 'G:dim7', 'N'),
#   ('A', 'B', 'C:7'),
#   ('A', 'E', 'F:maj7'),
#   ('A', 'Ab', 'N'),
#   ('C#', 'C#:min/5', 'F'),
#   ('D', 'E:min', 'F#:7(#9)'),
#   ('C#:min', 'C:7/5', 'N'),
#   ('A', 'E', 'G:minmaj7'),
#   ('D:7/5', 'D:maj/2', 'E'),
#   ('A', 'Bb:min', 'E'),
#   ('C:aug', 'F', 'N'),
#   ('A', 'D', 'G:min7'),
#   ('A/5', 'E:maj7', 'F#:min'),
#   ('A', 'Ab', 'F'),
#   ('C:7', 'C:aug', 'F'),
#   ('F', 'F#:min', 'N'),
#   ('C:9', 'D', 'N'),
#   ('A', 'C', 'E/5'),
#   ('Bb', 'D', 'D/5'),
#   ('A', 'E:7', 'G'),
#   ('F', 'F#:dim/b3', 'N'),
#   ('D', 'D/5', 'F#:9'),
#   ('Ab', 'B:7(#9)', 'F'),
#   ('B', 'F', 'F#:min'),
#   ('A', 'E:aug(9,11)', 'E:min'),
#   ('D', 'F:9', 'N'),
#   ('A', 'F#:min', 'G:min'),
#   ('A:min', 'B:min', 'F#:min7'),
#   ('A:min', 'B:min', 'E:9'),
#   ('E:aug(9,11)', 'E:min', 'G'),
#   ('B', 'D:7/5', 'F#:min'),
#   ('A', 'C#:min', 'G:minmaj7'),
#   ('Ab', 'F', 'F#:9'),
#   ('C', 'F', 'G:7'),
#   ('A/5', 'F#:min', 'G#:min'),
#   ('E', 'E/5', 'G/3'),
#   ('B:7', 'E', 'F#:min7'),
#   ('B', 'E', 'G#:min'),
#   ('B:aug/3', 'Bb:min', 'F'),
#   ('C#:min', 'F#:sus4', 'N'),
#   ('D', 'F#:sus4', 'G'),
#   ('A', 'B:aug/3', 'F#:min'),
#   ('B', 'D:7/5', 'E'),
#   ('A:9', 'C', 'E'),
#   ('B:aug/3', 'E:min', 'N'),
#   ('A', 'A:7', 'F#:min'),
#   ('D', 'E:9', 'E:min'),
#   ('C', 'E', 'F#:dim'),
#   ('Bb:min', 'C#:7', 'F'),
#   ('B', 'F#:dim/b3', 'F#:min'),
#   ('D:maj/2', 'E', 'F#:9'),
#   ('A', 'Bb:min', 'E/5'),
#   ('A/5', 'D:maj/2', 'F#:min'),
#   ('A/5', 'F#:min', 'G:7'),
#   ('A:7', 'B', 'F#:min'),
#   ('C:7/5', 'D', 'N'),
#   ('B', 'C', 'F'),
#   ('A', 'Bb', 'F#:min'),
#   ('A', 'Ab', 'C#:min'),
#   ('A:min', 'B:min', 'C#'),
#   ('G', 'G:min7', 'N'),
#   ('B', 'B:7', 'F#:min'),
#   ('B:7', 'Bb:min', 'E'),
#   ('A', 'F#:min', 'F:9'),
#   ('Ab', 'E:maj7', 'F'),
#   ('D', 'F#:dim/b3', 'N'),
#   ('A', 'C#:min', 'D:9'),
#   ('A', 'F#:dim', 'G'),
#   ('A/5', 'D:maj/2', 'E'),
#   ('C', 'E', 'F:maj7'),
#   ('C', 'E', 'G:minmaj7'),
#   ('D', 'G:minmaj7', 'N'),
#   ('C#:min', 'C:7', 'E'),
#   ('C', 'D:7/5', 'F'),
#   ('A:7', 'C', 'F'),
#   ('A', 'Bb', 'E'),
#   ('D:9', 'E', 'N'),
#   ('B:7', 'C:9', 'E'),
#   ('D', 'D/5', 'E:9'),
#   ('Bb:min', 'C#:min/4', 'F'),
#   ('B:aug/3', 'D', 'G'),
#   ('D', 'E/5', 'N'),
#   ('B', 'F#:min7', 'G/3'),
#   ('A:min', 'C#', 'D'),
#   ('C', 'D', 'F'),
#   ('D', 'D/5', 'F#:dim/b3'),
#   ('A', 'G', 'G:minmaj7'),
#   ('E', 'F#:min', 'F:9'),
#   ('E:maj7', 'E:min', 'G'),
#   ('C#:min', 'G#:min', 'N'),
#   ('A', 'D:9', 'E/5'),
#   ('A', 'E:min', 'G:maj6(9)'),
#   ('C#', 'D', 'E:min'),
#   ('E:min', 'G:7', 'N'),
#   ('A/5', 'D/5', 'F#:min'),
#   ('Ab', 'F', 'F#:min7'),
#   ('E:min', 'G', 'G:min7'),
#   ('A', 'C#:min', 'C#:min/4'),
#   ('A', 'F#:min', 'G:min7'),
#   ('C#:min/4', 'F', 'N'),
#   ('D', 'E:min', 'G:7'),
#   ('C:aug', 'G', 'N'),
#   ('E', 'G:min7', 'N'),
#   ('A', 'B', 'F#:dim/b3'),
#   ('E', 'F#:9', 'F#:min'),
#   ('A', 'C:7/5', 'D'),
#   ('A', 'B:aug/3', 'E/5'),
#   ('A', 'C#:min', 'D:7/5'),
#   ('Bb', 'D:maj/2', 'E'),
#   ('A', 'G:min', 'N'),
#   ('B', 'E', 'G/3'),
#   ('Bb:min', 'E:min', 'N'),
#   ('A', 'A:7', 'E/5'),
#   ('A', 'C:9', 'N'),
#   ('D:7/5', 'E', 'F#:min'),
#   ('A', 'A:7', 'B'),
#   ('A', 'A:7(#9)', 'F#:min'),
#   ('Bb:min', 'E:min', 'F'),
#   ('C#:min', 'G/3', 'N'),
#   ('D:maj/2', 'E', 'F#:min7'),
#   ('C#:min', 'E', 'G:min'),
#   ('A:min', 'B:min', 'F:7'),
#   ('D:maj/2', 'E', 'E:min'),
#   ('A:7', 'G', 'N'),
#   ('Ab', 'E:9', 'F'),
#   ('A:7', 'D/3', 'E'),
#   ('E:min', 'F:9', 'N'),
#   ('A', 'E:min', 'G#:min'),
#   ('A', 'Bb', 'E/5'),
#   ('A', 'C#:min/4', 'F#:min'),
#   ('A:min', 'D', 'D:maj/2'),
#   ('B:7(#9)', 'F', 'N'),
#   ('C#:7', 'E:min', 'N'),
#   ('A', 'A:min', 'C#:min'),
#   ('B:7', 'E', 'F:7'),
#   ('E', 'G:min', 'N'),
#   ('C:7', 'F', 'G:min'),
#   ('D', 'D/5', 'D:maj/2'),
#   ('A', 'A:7(#9)', 'E'),
#   ('A', 'B', 'C#'),
#   ('A:min', 'B:min', 'C:aug'),
#   ('A', 'C#:min', 'G:min7'),
#   ('B:7', 'C#:min/5', 'E'),
#   ('A', 'E', 'E:7'),
#   ('A', 'D:7/5', 'F#:min'),
#   ('Bb:min', 'D', 'G'),
#   ('C#', 'C#:min', 'F'),
#   ('A', 'B', 'D:maj/2'),
#   ('E', 'F#:min', 'F#:sus4'),
#   ('A:min', 'B:min', 'E/5'),
#   ('E', 'E/5', 'F#:dim'),
#   ('A', 'E:min', 'G:7'),
#   ('A:min', 'B:7(#9)', 'D'),
#   ('B', 'C:7', 'F#:min'),
#   ('A:9', 'E:min', 'G'),
#   ('Ab', 'F', 'F#:min'),
#   ('A:9', 'D', 'D/5'),
#   ('Ab', 'D/3', 'F'),
#   ('D:9', 'E:min', 'G'),
#   ('C#:min', 'E', 'F:9'),
#   ('A:min', 'D', 'F#'),
#   ('C#', 'C#:7', 'F'),
#   ('A', 'F#:dim/b3', 'F#:min'),
#   ('B:aug/3', 'D', 'D/5'),
#   ('B:7(#9)', 'C', 'F'),
#   ('B', 'C:7', 'E'),
#   ('E:min', 'F#:7(#9)', 'N'),
#   ('A:7(#9)', 'C#:min', 'N'),
#   ('A', 'C', 'N'),
#   ('E', 'E/5', 'F:maj7'),
#   ('E', 'E/5', 'G:minmaj7'),
#   ('A', 'E/5', 'E:maj7'),
#   ('D/3', 'E', 'N'),
#   ('A', 'C', 'F'),
#   ('D:7/5', 'E', 'E/5'),
#   ('G', 'G:7', 'N'),
#   ('A', 'A:7(#9)', 'E/5'),
#   ('A', 'A:7(#9)', 'B'),
#   ('A', 'E', 'E:maj7'),
#   ('A', 'B:7', 'F#:min'),
#   ('Bb:min', 'F', 'F#:9'),
#   ('C', 'C#:7', 'E'),
#   ('C#:7', 'F', 'N'),
#   ('Ab', 'C:aug', 'F'),
#   ('C', 'E', 'G:min7'),
#   ('B:aug/3', 'C#', 'F'),
# ...
#   ('B:min/b3', 'F:7', 'C:7/5'),
#   ('G:dim7', 'Ab', 'A:9'),
#   ('B', 'C#:min/4', 'D:9'),
#   ('C#:7', 'F#:min7', 'A:7'),
#   ('G:7', 'G:minmaj7', 'G:maj6(9)'),
#   ('E', 'E:maj7', 'C#'),
#   ('G#:min', 'G:minmaj7', 'A:7(#9)'),
#   ('C:7', 'F#:dim/b3', 'E:7'),
#   ('C#:min/4', 'E:9', 'C:7'),
#   ('F#:min7', 'E/5', 'B:7'),
#   ('A:min', 'G:minmaj7', 'G:maj6(9)'),
#   ('E:maj7', 'F#:sus4', 'A:7(#9)'),
#   ('C', 'F', 'B:7'),
#   ('F#:dim', 'Bb:min', 'A:9'),
#   ('F#', 'B:min/b3', 'B:7'),
#   ('C#:min/5', 'G/3', 'F#:dim/b3'),
#   ('C', 'C:7', 'D/5'),
#   ('C:aug', 'C:9', 'Bb'),
#   ('G:min', 'Bb:min', 'F#:7(#9)'),
#   ('F#:7', 'F:7', 'E/5'),
#   ('F:7', 'E:maj7', 'A/5'),
#   ('C:7', 'F#:sus4', 'B:7(#9)'),
#   ('A:min', 'A:7', 'G:min'),
#   ('G', 'F#:dim', 'A:9'),
#   ('E:9', 'D:9', 'F#:7(#9)'),
#   ('C#:min', 'F', 'C:min'),
#   ('F#:min7', 'C:min', 'G:maj6(9)'),
#   ('B', 'G:minmaj7', 'A:7(#9)'),
#   ('F', 'C:7', 'A/5'),
#   ('F#:min', 'C#', 'F#:sus4'),
#   ('F#:9', 'C:7', 'A/5'),
#   ('B:min/b3', 'E/5', 'G:minmaj7'),
#   ('B', 'F#:min7', 'C:9'),
#   ('F#:dim', 'G:minmaj7', 'E:7'),
#   ('G:min7', 'G:minmaj7', 'C:7'),
#   ('E', 'D/5', 'B:7(#9)'),
#   ('F#', 'C#', 'Ab'),
#   ('B:min', 'G:minmaj7', 'D/3'),
#   ('C:9', 'D/5', 'F#:dim/b3'),
#   ('B', 'F#:min', 'B:7(#9)'),
#   ('D:maj/2', 'C:min', 'A:7(#9)'),
#   ('E/5', 'E:min', 'A:7(#9)'),
#   ('E:maj7', 'C:7', 'D:maj/2'),
#   ('E:maj7', 'F#:min', 'Bb:min'),
#   ('B:aug/3', 'C#:min/4', 'Bb'),
#   ('C#:7', 'G:min7', 'A/5'),
#   ('G:dim7', 'F#:min7', 'G:min7'),
#   ('C:9', 'C:7/5', 'D/3'),
#   ('Ab', 'A/5', 'F#:dim/b3'),
#   ('F#:min', 'E/5', 'F'),
#   ('F:maj7', 'F#:dim/b3', 'E:7'),
#   ('G:7', 'F#:min', 'E/5'),
#   ('G:dim7', 'E:min', 'E:9'),
#   ('G:dim7', 'F:9', 'D:7/5'),
#   ('F:9', 'F#:sus4', 'G:maj6(9)'),
#   ('G:minmaj7', 'G/3', 'E:7'),
#   ('B:min/b3', 'D', 'E:9'),
#   ('E', 'C#:min/5', 'F:maj7'),
#   ('F:7', 'D', 'E:7'),
#   ('F:7', 'E:9', 'C:7/5'),
#   ('D', 'F#:dim', 'F:maj7'),
#   ('G:min7', 'Bb', 'G:maj6(9)'),
#   ('G:dim7', 'C#:min/4', 'A:7(#9)'),
#   ('F#:9', 'Bb', 'G:minmaj7'),
#   ('C', 'C:7/5', 'Ab'),
#   ('E:aug(9,11)', 'C:9', 'G:min7'),
#   ('A:7', 'F#:9', 'F#:dim/b3'),
#   ('E:min', 'F#:dim/b3', 'E:7'),
#   ('F:7', 'F:maj7', 'A:9'),
#   ('G:7', 'E:aug(9,11)', 'G#:min'),
#   ('A:min', 'C#:min/4', 'G:minmaj7'),
#   ('B', 'A:min', 'C:min'),
#   ('Bb', 'F:maj7', 'E:7'),
#   ('C:aug', 'A:7', 'A/5'),
#   ('N', 'G:dim7', 'D'),
#   ('B', 'F:9', 'C:min'),
#   ('D/3', 'F#:sus4', 'G:maj6(9)'),
#   ('C#:min/4', 'F', 'D/5'),
#   ('E:min', 'F#:sus4', 'B:7(#9)'),
#   ('G:dim7', 'G:7', 'D:maj/2'),
#   ('B', 'G:min', 'D:7/5'),
#   ('E:aug(9,11)', 'F#:min', 'E:7'),
#   ('C:aug', 'F#:9', 'F#:7(#9)'),
#   ('B:7', 'D:maj/2', 'C:min'),
#   ('F#', 'G:minmaj7', 'C:7'),
#   ('C#:7', 'E:9', 'G:minmaj7'),
#   ('N', 'E:maj7', 'Ab'),
#   ('F#:min7', 'G:7', 'A:9'),
#   ('B:aug/3', 'F#:min', 'A:7(#9)'),
#   ('B', 'F#:7(#9)', 'A/5'),
#   ('C#:7', 'F#:dim', 'F#:sus4'),
#   ('G:7', 'E:aug(9,11)', 'A:min'),
#   ('G:dim7', 'Bb:min', 'F#:7(#9)'),
#   ('C#:min/5', 'C#', 'G/3'),
#   ('F#:7', 'F:maj7', 'C:min'),
#   ('C#:min', 'C:9', 'B:7'),
#   ('C#:7', 'G:minmaj7', 'G:maj6(9)'),
#   ('E', 'G#:min', 'C:7/5'),
#   ('C#', 'D:9', 'F#:dim/b3'),
#   ('F:7', 'F#:sus4', 'B:7(#9)'),
#   ('F#', 'F:7', 'G:min7'),
#   ('B:min/b3', 'G:maj6(9)', 'B:7(#9)'),
#   ('F#', 'E', 'F#:min'),
#   ('B', 'F:7', 'G:minmaj7'),
#   ('N', 'B:7', 'F#:dim/b3'),
#   ('F#', 'Bb', 'G:maj6(9)'),
#   ('D', 'G#:min', 'G:min7'),
#   ('B:aug/3', 'Ab', 'G:maj6(9)'),
#   ('G:dim7', 'E:min', 'C#'),
#   ('B:min/b3', 'D', 'C#'),
#   ('G/3', 'G:maj6(9)', 'A:7(#9)'),
#   ('C#:min/4', 'F#:9', 'C:7/5'),
#   ('G:min7', 'D:9', 'G:maj6(9)'),
#   ('C#:7', 'F#:7', 'F#:9'),
#   ('C#:min', 'F:7', 'C:min'),
#   ('C', 'F#:min7', 'F#:9'),
#   ('A/5', 'G:maj6(9)', 'F#:dim/b3'),
#   ('A', 'F#:min', 'E:9'),
#   ('E:9', 'G:minmaj7', 'F#:dim/b3'),
#   ('E:aug(9,11)', 'E:9', 'D:maj/2'),
#   ('E', 'Bb:min', 'F#:dim/b3'),
#   ('F#', 'C#:7', 'G'),
#   ('C#:7', 'D:maj/2', 'G:maj6(9)'),
#   ('B:min/b3', 'E:9', 'D:9'),
#   ('N', 'B:aug/3', 'F#:sus4'),
#   ('E', 'A', 'E:aug(9,11)'),
#   ('E:maj7', 'C#:min/5', 'G:min'),
#   ('C#', 'G:min7', 'Bb'),
#   ('F#:7', 'E:9', 'C:min'),
#   ('C#:min/4', 'G:min', 'G:min7'),
#   ('N', 'E:min', 'C:min'),
#   ('C#:min', 'G:7', 'E/5'),
#   ('F#:9', 'F#:7(#9)', 'Ab'),
#   ('G#:min', 'G:min7', 'E:7'),
#   ('E', 'F:7', 'C:7'),
#   ('F#:min7', 'D:maj/2', 'C:min'),
#   ('N', 'D/3', 'F#:dim/b3'),
#   ('G:min', 'G#:min', 'D:maj/2'),
#   ('E:aug(9,11)', 'Bb', 'F:maj7'),
#   ('D', 'C:aug', 'A:7'),
#   ('F#', 'E:9', 'G:min'),
#   ('G:dim7', 'C:aug', 'B:7(#9)'),
#   ('A', 'D:9', 'F#:7(#9)'),
#   ('C#:min', 'G#:min', 'Bb'),
#   ('B:min/b3', 'F#:9', 'F'),
#   ('F#:7', 'A:7', 'F#:dim/b3'),
#   ('F#:7', 'F#:dim/b3', 'A:7(#9)'),
#   ('F#:7', 'E:min', 'D:maj/2'),
#   ('A', 'A:min', 'C:7/5'),
#   ('C#:7', 'E/5', 'G#:min'),
#   ('G:dim7', 'A:7', 'G/3'),
#   ('G:7', 'D/3', 'F#:dim/b3'),
#   ('Bb', 'G:minmaj7', 'Ab'),
#   ('C#:7', 'F#:min', 'E/5'),
#   ('E:maj7', 'E:min', 'G:minmaj7'),
#   ('F#:7', 'G:minmaj7', 'D:7/5'),
#   ('C#', 'C:7', 'F:maj7'),
#   ('C:aug', 'G', 'Bb'),
#   ('E', 'A', 'B:min'),
#   ('F:7', 'C#:min/4', 'F#:sus4'),
#   ('E', 'F#:min7', 'A:7'),
#   ('N', 'F#:min7', 'D/5'),
#   ('F#', 'F#:min', 'F#:dim'),
#   ('C:9', 'G#:min', 'D/3'),
#   ('F#', 'E:min', 'E:7'),
#   ('C', 'F#:7(#9)', 'F:maj7'),
#   ('B:min', 'A/5', 'G/3'),
#   ('C#:min', 'G:dim7', 'C#:7'),
#   ('C', 'F#:7', 'F#:sus4'),
#   ('F', 'G:min7', 'A/5'),
#   ('B:aug/3', 'A/5', 'D:7/5'),
#   ('C#:7', 'E:aug(9,11)', 'G#:min'),
#   ('F#:9', 'G:min7', 'A/5'),
#   ('E', 'F#:7', 'F'),
#   ('B:min/b3', 'F:9', 'F#:7(#9)'),
#   ('A', 'F#:min', 'C#'),
#   ('C#:min/4', 'D:maj/2', 'A:7(#9)'),
#   ('G#:min', 'D/3', 'B:7(#9)'),
#   ('G:minmaj7', 'C:min', 'F#:dim/b3'),
#   ('E', 'G:maj6(9)', 'E:7'),
#   ('C', 'A:min', 'B:min'),
#   ('Bb', 'D:9', 'A:7(#9)'),
#   ('Bb', 'F#:sus4', 'A:7(#9)'),
#   ('E:maj7', 'G:min7', 'D:maj/2'),
#   ('C:9', 'B:7', 'C:min'),
#   ('E/5', 'F:9', 'D/5'),
#   ('F#:7', 'F#:min', 'G:maj6(9)'),
#   ('B', 'A:7', 'G:min7'),
#   ('G:dim7', 'C#:7', 'C#:min/4'),
#   ('C#:7', 'E:aug(9,11)', 'A:min'),
#   ('F#', 'A:min', 'F#:sus4'),
#   ('G:7', 'Bb:min', 'D:7/5'),
#   ('C:aug', 'C:7/5', 'Ab'),
#   ('C#:min', 'C:7/5', 'F:maj7'),
#   ('Bb:min', 'D:9', 'B:7'),
#   ('D:9', 'B:7', 'A:9'),
#   ('G:dim7', 'C:aug', 'F:9'),
#   ('A:min', 'Bb:min', 'D:7/5'),
#   ('G:dim7', 'A:min', 'C:aug'),
#   ('G', 'F#:dim', 'F#:sus4'),
#   ('C#:min/4', 'F:9', 'D:9'),
#   ('G:dim7', 'E:9', 'B:7'),
#   ('C:aug', 'E:7', 'A:7(#9)'),
#   ('F#', 'F#:7', 'A/5'),
#   ('A', 'F', 'Bb'),
#   ('A/5', 'A:9', 'A:7(#9)'),
#   ('B:aug/3', 'F#:9', 'G:maj6(9)'),
#   ('B:7', 'F#:sus4', 'G/3'),
#   ('E', 'C', 'D/5'),
#   ('B:min/b3', 'F#:min7', 'G#:min'),
#   ('A', 'F#:dim/b3', 'E:7'),
#   ('B:aug/3', 'C#:min/4', 'F:maj7'),
#   ('E:aug(9,11)', 'D', 'C:min'),
#   ('C#:min/5', 'G:min7', 'D:7/5'),
#   ('B:aug/3', 'A:min', 'F#:dim/b3'),
#   ('E:aug(9,11)', 'G', 'G:min7'),
#   ('G:dim7', 'F#:min7', 'A:7(#9)'),
#   ('B:aug/3', 'G:minmaj7', 'F#:sus4'),
#   ('D', 'C:7', 'F:maj7'),
#   ('F#', 'B', 'G'),
#   ('G:7', 'A:7', 'G:min'),
#   ('G', 'C:7/5', 'D/5'),
#   ('B:aug/3', 'D/5', 'G/3'),
#   ('E:min', 'F:9', 'C:7/5'),
#   ('C:7/5', 'A:9', 'D:7/5'),
#   ('G:dim7', 'G#:min', 'D:maj/2'),
#   ('E:maj7', 'D', 'F#:dim'),
#   ('C#:min/5', 'Bb', 'A/5'),
#   ('F#:9', 'B:7', 'F:maj7'),
#   ('F#:7(#9)', 'A/5', 'A:7(#9)'),
#   ('F#:min7', 'G#:min', 'A:9'),
#   ('G', 'F#:9', 'D/3'),
#   ('B:min/b3', 'F#:min7', 'A:min'),
#   ('E:aug(9,11)', 'C:9', 'A:7(#9)'),
#   ('G:min7', 'Ab', 'D:7/5'),
#   ('E/5', 'F:9', 'G/3'),
#   ('B:min', 'F:9', 'F#:sus4'),
#   ('F#:9', 'F#:dim', 'A:9'),
#   ('D:9', 'D/3', 'A:9'),
#   ('F:7', 'C#:min/5', 'Bb'),
#   ('B:min', 'F#:dim', 'A/5'),
#   ('C:7', 'F#:7(#9)', 'Ab'),
#   ('F#:min7', 'C#:min/4', 'F'),
#   ('C', 'F:7', 'Bb:min'),
#   ('F#:dim', 'Bb', 'A/5'),
#   ('B:min/b3', 'G:minmaj7', 'A:7(#9)'),
#   ('E:aug(9,11)', 'F#:7(#9)', 'D:7/5'),
#   ('C#:7', 'C:7', 'F#:sus4'),
#   ('F#:7', 'F#:9', 'B:7'),
#   ('E', 'C#:min/5', 'E:7'),
#   ('E:maj7', 'C:7/5', 'D:7/5'),
#   ('D', 'F#:dim', 'E:7'),
#   ('G:dim7', 'F#:9', 'C:7/5'),
#   ('C#:7', 'D:9', 'C:7/5'),
#   ('F#', 'B', 'Bb:min'),
#   ('E', 'C', 'G/3'),
#   ('A:min', 'D/5', 'F#:sus4'),
#   ('C#:min/5', 'G:min', 'D/3'),
#   ('F#', 'F:7', 'A:7(#9)'),
#   ('E', 'G:minmaj7', 'G:maj6(9)'),
#   ('F#:dim', 'B:7', 'A:9'),
#   ('A', 'B:7(#9)', 'E:7'),
#   ('B:aug/3', 'F:7', 'F#:min'),
#   ('F#:min7', 'G:min', 'C:min'),
#   ('E:aug(9,11)', 'A:min', 'G#:min'),
#   ('B:min', 'F#:dim/b3', 'E:7'),
#   ('F#', 'G:min', 'D:9'),
#   ('N', 'C#:min', 'B:min'),
#   ('D', 'G#:min', 'A:7(#9)'),
#   ('F#:min7', 'G', 'F'),
#   ('C#:7', 'C:aug', 'D:7/5'),
#   ('C:aug', 'Bb', 'D:maj/2'),
#   ('C:7', 'F:maj7', 'G/3'),
#   ('F#:7', 'Ab', 'F#:dim/b3'),
#   ('F:9', 'C:7', 'D/5'),
#   ('E:maj7', 'C:min', 'E:7'),
#   ('F#:min7', 'G:min7', 'G:maj6(9)'),
#   ('E:aug(9,11)', 'A:9', 'F#:dim/b3'),
#   ('F#:dim', 'D:maj/2', 'E:7'),
#   ('E:9', 'G:min', 'Bb:min'),
#   ('C#:min', 'A', 'G'),
#   ('B:aug/3', 'F:maj7', 'E:7'),
#   ('F#:min', 'E:9', 'G:min'),
#   ('E:9', 'F', 'Bb'),
#   ('E:9', 'F#:dim/b3', 'E:7'),
#   ('G#:min', 'F#:sus4', 'D:7/5'),
#   ('C', 'G:min', 'C:7/5'),
#   ('B:min/b3', 'A:min', 'F:9'),
#   ('B', 'F#:dim', 'F#:7(#9)'),
#   ('C#', 'G:min7', 'F:maj7'),
#   ('D:9', 'G/3', 'D:7/5'),
#   ('A:7', 'Bb:min', 'A:7(#9)'),
#   ('C#:min', 'F#:dim', 'C:9'),
#   ('C', 'C#:min/5', 'F#:dim/b3'),
#   ('G', 'G:minmaj7', 'B:7(#9)'),
#   ('C#:min/4', 'G:min', 'A:7(#9)'),
#   ('F#:min7', 'C:7/5', 'F#:sus4'),
#   ('C#', 'F:maj7', 'D/3'),
#   ('F#:dim', 'D/3', 'A:9'),
#   ('D:9', 'A:9', 'C:min'),
#   ('Bb', 'C:7/5', 'F#:dim/b3'),
#   ('C#:min', 'G:dim7', 'D:7/5'),
#   ('F#', 'E', 'G:min'),
#   ('A', 'F:7', 'Bb'),
#   ('F#:min7', 'E/5', 'G'),
#   ('E:aug(9,11)', 'C:7', 'Ab'),
#   ('F#', 'B:min/b3', 'G'),
#   ('B:min/b3', 'E:maj7', 'D:7/5'),
#   ('N', 'C:aug', 'F#:7(#9)'),
#   ('F#', 'C:aug', 'Bb'),
#   ('C#:min/4', 'B:min', 'Bb'),
#   ('G#:min', 'A/5', 'G:maj6(9)'),
#   ('E', 'F#:min', 'E/5'),
#   ('G:7', 'E:aug(9,11)', 'D/3'),
#   ('C#:min/4', 'B:7', 'C:min'),
#   ('F#', 'F#:dim', 'F:9'),
#   ('C#:7', 'G:7', 'E:9'),
#   ('B', 'F#:min7', 'C:7'),
#   ('B', 'E:aug(9,11)', 'C#:min/4'),
#   ('C#:7', 'D/3', 'E:7'),
#   ('A:min', 'A:7', 'G:maj6(9)'),
#   ('A:7', 'C:min', 'B:7(#9)'),
#   ('C#:min/4', 'E:min', 'Ab'),
#   ('C#:7', 'B:min', 'C:min'),
#   ('F#:7', 'F', 'G:min7'),
#   ('E:aug(9,11)', 'Bb', 'E:7'),
#   ('E:min', 'E:9', 'D/5'),
#   ('N', 'A', 'G#:min'),
#   ('E:min', 'C#', 'G:min7'),
#   ('C#:min/5', 'Ab', 'D:maj/2'),
#   ('G:min', 'Bb:min', 'C:min'),
#   ('E', 'E:aug(9,11)', 'G#:min'),
#   ('G:dim7', 'A:min', 'D:9'),
#   ('B:aug/3', 'Bb', 'A:7(#9)'),
#   ('Bb:min', 'G#:min', 'D:7/5'),
#   ('E:min', 'F:maj7', 'G/3'),
#   ('F#', 'B:min', 'G'),
#   ('E:9', 'D:9', 'C:min'),
#   ('C#', 'C:7', 'E:7'),
#   ('G:dim7', 'G', 'G#:min'),
#   ('B:aug/3', 'C#:min/5', 'Bb:min'),
#   ('F:7', 'C#', 'G:min7'),
#   ('C:9', 'G:minmaj7', 'F#:dim/b3'),
#   ('E:maj7', 'D:9', 'F#:dim/b3'),
#   ('E:9', 'C#', 'G:min7'),
#   ('C', 'F#:7(#9)', 'E:7'),
#   ('G:dim7', 'E/5', 'F#:sus4'),
#   ('G', 'C:7', 'F#:sus4'),
#   ('E:maj7', 'G#:min', 'D:7/5'),
#   ('A', 'F:9', 'C:7/5'),
#   ('F#:dim', 'A:9', 'C:min'),
#   ('N', 'G:maj6(9)', 'D:7/5'),
#   ('G', 'D:9', 'C:7/5'),
#   ('F#', 'D', 'B:min'),
#   ('G', 'G:min', 'G:maj6(9)'),
#   ('B', 'B:min', 'F:maj7'),
#   ('C#:7', 'B', 'E:9'),
#   ('F', 'D:9', 'C:7/5'),
#   ('A', 'B:aug/3', 'C#:min/5'),
#   ('C#:min', 'G', 'F#:dim/b3'),
#   ('C', 'A:9', 'D:maj/2'),
#   ('C#:7', 'G:7', 'C#'),
#   ('E:aug(9,11)', 'G', 'A:7(#9)'),
#   ('G:min7', 'C:7', 'B:7(#9)'),
#   ('N', 'G:dim7', 'F:maj7'),
#   ('A:7', 'G:min', 'A/5'),
#   ('F#', 'B:min', 'Bb:min'),
#   ('E:min', 'E:9', 'G/3'),
#   ('Ab', 'A/5', 'D:7/5'),
#   ('F#', 'C:9', 'C:7/5'),
#   ('C#:min', 'C:7/5', 'E:7'),
#   ('E/5', 'C:aug', 'G:min7'),
#   ('N', 'B:min', 'E:9'),
#   ('F#', 'D:9', 'A/5'),
#   ('F', 'C:7', 'A:9'),
#   ('B:aug/3', 'E:maj7', 'C#:min/4'),
#   ('B:min/b3', 'C:9', 'A/5'),
#   ('E:min', 'C:9', 'Ab'),
#   ('A:7', 'F#:sus4', 'G:maj6(9)'),
#   ('B:aug/3', 'D:9', 'A:7(#9)'),
#   ('G:dim7', 'D', 'A:9'),
#   ('C#:min', 'D', 'B:7(#9)'),
#   ('C#:min/4', 'C:7/5', 'D/3'),
#   ('D', 'G:min7', 'Bb'),
#   ('G:7', 'B:min', 'E:9'),
#   ('B:aug/3', 'C#:min/4', 'E:7'),
#   ('F:7', 'C#:min/5', 'F:maj7'),
#   ('E:maj7', 'E/5', 'E:9'),
#   ('C#:7', 'E/5', 'D/3'),
#   ('C#:7', 'F#:dim', 'G/3'),
#   ('B:min/b3', 'A:7', 'G:min7'),
#   ('C#', 'C:9', 'D:9'),
#   ('D', 'C:7', 'E:7'),
#   ('C:aug', 'F#:9', 'C:min'),
#   ('F:7', 'C:9', 'Ab'),
#   ('C#:7', 'G:min7', 'A:9'),
#   ('N', 'F#:min7', 'G:minmaj7'),
#   ('F#:7', 'E:aug(9,11)', 'Bb'),
#   ('F#:min', 'G:min', 'D:9'),
#   ('C:aug', 'F#:7(#9)', 'F#:dim/b3'),
#   ('E', 'B:aug/3', 'F#:sus4'),
#   ('G:min', 'Ab', 'G/3'),
#   ('C#', 'G:minmaj7', 'D:maj/2'),
#   ('F#:dim', 'C:9', 'B:7(#9)'),
#   ('F#', 'E:aug(9,11)', 'E/5'),
#   ('F#:min7', 'G#:min', 'F#:sus4'),
#   ('B:min/b3', 'C#:min/4', 'D:9'),
#   ('F#:9', 'B:7', 'E:7'),
#   ('G:dim7', 'Bb:min', 'C:min'),
#   ('E:maj7', 'C:aug', 'D/5'),
#   ('D:9', 'D/3', 'F#:sus4'),
#   ('C#:7', 'B', 'C#'),
#   ('E:maj7', 'E:aug(9,11)', 'E:9'),
#   ('C#:7', 'E:aug(9,11)', 'D/3'),
#   ('F#', 'C:7', 'B:7(#9)'),
#   ('F#:9', 'G:minmaj7', 'G:maj6(9)'),
#   ('C', 'G:minmaj7', 'D/5'),
#   ('B:aug/3', 'F:9', 'F#:dim/b3'),
#   ('C:aug', 'G:min', 'C:7/5'),
#   ('Bb:min', 'G/3', 'A:7(#9)'),
#   ('A', 'F#:7', 'G:min'),
#   ('D', 'Bb:min', 'A/5'),
#   ('G:dim7', 'F#:min', 'C:aug'),
#   ('C#:min', 'D/3', 'C:min'),
#   ('C#', 'G#:min', 'B:7'),
#   ('C#:min/5', 'B:7', 'F#:sus4'),
#   ('E/5', 'F:9', 'G:minmaj7'),
#   ('C#', 'D/3', 'G:maj6(9)'),
#   ('C:aug', 'A:7', 'A:9'),
#   ('C#:min/5', 'F#:9', 'D:maj/2'),
#   ('B', 'A:9', 'G:maj6(9)'),
#   ('N', 'B:7', 'D:7/5'),
#   ('F:7', 'A/5', 'A:7(#9)'),
#   ('F:7', 'A:min', 'E/5'),
#   ('N', 'Bb', 'F#:dim/b3'),
#   ('E:maj7', 'C#:min/5', 'G:maj6(9)'),
#   ('C#:min', 'C:7', 'D:maj/2'),
#   ('F#:dim', 'F#:7(#9)', 'G:maj6(9)'),
#   ('N', 'B:aug/3', 'G/3'),
#   ('E:9', 'F:9', 'C:7/5'),
#   ('A:7', 'E:9', 'C:7/5'),
#   ('G:7', 'F#:9', 'G:min'),
#   ('F', 'D/3', 'E:7'),
#   ('F#:7', 'C:aug', 'D:maj/2'),
#   ('E:aug(9,11)', 'G:min7', 'Ab'),
#   ('G:minmaj7', 'C:7', 'D/3'),
#   ('G:7', 'B:min', 'C#'),
#   ('F#:9', 'D/3', 'E:7'),
#   ('E', 'C#:7', 'E:9'),
#   ('N', 'C', 'B'),
#   ('E:maj7', 'E/5', 'C#'),
#   ('B', 'G:minmaj7', 'B:7'),
#   ('F#', 'E:9', 'G:maj6(9)'),
#   ('E', 'C', 'G:minmaj7'),
#   ('F#:dim', 'Bb:min', 'D/5'),
#   ('F', 'D:maj/2', 'G:maj6(9)'),
#   ('A/5', 'G:maj6(9)', 'D:7/5'),
#   ('F#:min', 'C:aug', 'Bb'),
#   ('F#:9', 'D:maj/2', 'G:maj6(9)'),
#   ('E', 'B:7', 'E:7'),
#   ('E', 'Bb:min', 'D:7/5'),
#   ('B', 'F#:min', 'E:9'),
#   ('D', 'C:9', 'D:9'),
#   ('B:min/b3', 'F#:min7', 'D/3'),
#   ('N', 'C', 'B:aug/3'),
#   ('G:7', 'C#', 'Bb:min'),
#   ('F#:min', 'F#:dim', 'F:9'),
#   ('C#:min', 'A:7', 'F'),
#   ('E:maj7', 'C:aug', 'G/3'),
#   ('C#:min/5', 'D/3', 'F#:sus4'),
#   ('A', 'F:7', 'F:maj7'),
#   ('F#:min', 'A:7', 'C:9'),
#   ('E/5', 'E:min', 'B:7'),
#   ('F:7', 'Bb:min', 'F#:dim/b3'),
#   ('E/5', 'G#:min', 'C:min'),
#   ('G', 'A/5', 'E:7'),
#   ('E:maj7', 'E:aug(9,11)', 'C#'),
#   ('A:min', 'C:aug', 'D:9'),
#   ('A:min', 'C#', 'Bb:min'),
#   ('C:aug', 'E:min', 'F:9'),
#   ('C', 'G:minmaj7', 'G/3'),
#   ('A', 'E:9', 'D/5'),
#   ('A', 'C#', 'G:min7'),
#   ('G#:min', 'G/3', 'E:7'),
#   ('B:min/b3', 'G:min', 'C:9'),
#   ('C', 'C#', 'D:9'),
#   ('F#', 'C:aug', 'F:maj7'),
#   ('F#:7', 'A:7', 'D:7/5'),
#   ('C#:min/4', 'B:min', 'F:maj7'),
#   ('A', 'C:7/5', 'G:maj6(9)'),
#   ('B', 'D:9', 'F#:7(#9)'),
#   ('F#:dim', 'D/3', 'F#:sus4'),
#   ('D:9', 'F:maj7', 'A/5'),
#   ('C#', 'G:min7', 'E:7'),
#   ('C#:min', 'C#', 'B:7(#9)'),
#   ('G:dim7', 'C#:min/4', 'B:7'),
#   ('C#:7', 'A/5', 'F#:dim/b3'),
#   ('G:minmaj7', 'A/5', 'A:9'),
#   ('G:dim7', 'Ab', 'G/3'),
#   ('F:9', 'A/5', 'A:7(#9)'),
#   ('Bb:min', 'F#:7(#9)', 'B:7(#9)'),
#   ('G:dim7', 'B:aug/3', 'G:min7'),
#   ('F#', 'E', 'C'),
#   ('G:min', 'B:7', 'A/5'),
#   ('E', 'G:7', 'E:9'),
#   ('Bb:min', 'A/5', 'A:9'),
#   ('F#:7', 'D:9', 'G:maj6(9)'),
#   ('E', 'D/3', 'E:7'),
#   ('N', 'C:7/5', 'A:7(#9)'),
#   ('F:9', 'G:maj6(9)', 'F#:dim/b3'),
#   ('B:min/b3', 'F:9', 'C:min'),
#   ('G', 'G:min7', 'F#:sus4'),
#   ('F#:7', 'F#:min', 'F#:dim'),
#   ('E:min', 'C#', 'A:7(#9)'),
#   ('C:9', 'A:9', 'B:7(#9)'),
#   ('E', 'C#:7', 'C#'),
#   ('C', 'D:9', 'Ab'),
#   ('B', 'Bb', 'B:7(#9)'),
#   ('F#:dim', 'Bb:min', 'G/3'),
#   ('D', 'G', 'C:9'),
#   ...},
#  '300': {('A', 'B', 'E'),
#   ('A', 'B', 'F#:min'),
#   ('A', 'C#:min', 'E'),
#   ('A', 'C#:min', 'N'),
#   ('A', 'D', 'E:min'),
#   ('A', 'D', 'G'),
#   ('A', 'D', 'N'),
#   ('A', 'E', 'E/5'),
#   ('A', 'E', 'F#:min'),
#   ('A', 'E', 'N'),
#   ('A', 'E:min', 'G'),
#   ('A', 'E:min', 'N'),
#   ('A', 'G', 'N'),
#   ('B', 'E', 'F#:min'),
#   ('C#:min', 'E', 'N'),
#   ('D', 'E:min', 'G'),
#   ('D', 'E:min', 'N'),
#   ('D', 'G', 'N'),
#   ('E:min', 'G', 'N')}}
