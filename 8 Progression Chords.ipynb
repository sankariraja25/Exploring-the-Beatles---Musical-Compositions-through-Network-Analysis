# %%
n1 = 4
n2 = 5

# %% [markdown]
# ## 201

# %%
# Python program to print all paths from a source to destination.
  
from collections import defaultdict
  
# This class represents a directed graph
# using adjacency list representation
class Graph:
  
    def __init__(self, vertices):
        # No. of vertices
        self.V = vertices
         
        # default dictionary to store graph
        self.graph = defaultdict(list)
  
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
  
    '''A recursive function to print all paths from 'u' to 'd'.
    visited[] keeps track of vertices in current path.
    path[] stores actual vertices and path_index is current
    index in path[]'''
    def printAllPathsUtil(self, u, d, visited, path):
 
        # Mark the current node as visited and store in path
        visited[u]= False
        path.append(u)
 
        # If current vertex is same as destination, then print
        # current path[]
        if len(path) > n1 and u == d:
            # Using any() + list slicing + generator expression
            res = any(path[idx : idx + len(sublist)] == sublist for idx in range(len(path) - len(sublist) + 1))
            res1 = any(path[idx : idx + len(sublist1)] == sublist1 for idx in range(len(path) - len(sublist1) + 1))
            res2 = any(path[idx : idx + len(sublist2)] == sublist2 for idx in range(len(path) - len(sublist2) + 1))
            res3 = any(path[idx : idx + len(sublist3)] == sublist3 for idx in range(len(path) - len(sublist3) + 1))
            if res and res1 and res2 and res3 == True:
                print (path)
        else:
            # If current vertex is not destination
            # Recur for all the vertices adjacent to this vertex
            for i in self.graph[u]:
                if visited[i]== False:
                    if len(path) < n2:
                        self.printAllPathsUtil(i, d, visited, path)
                     
        # Remove current vertex from path[] and mark it as unvisited
        path.pop()
        visited[u]= False
        #print(path)
  
  
    # Prints all paths from 's' to 'd'
    def printAllPaths(self, s, d):
 
        # Mark all the vertices as not visited
        visited =[False]*(self.V)
 
        # Create an array to store paths
        path = []
 
        # Call the recursive helper function to print all paths
        self.printAllPathsUtil(s, d, visited, path)
        #print(path)
        
  
  
# Create a graph given in the above diagram
g = Graph(3)
g.addEdge(0, 1)
g.addEdge(1, 0)
g.addEdge(1, 2)
g.addEdge(2, 1)

sublist = [0, 1]
sublist1 = [1, 0]
sublist2 = [1, 2]
sublist3 = [2, 1]
  
s = 0 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav
# Out:
# Following are all different paths from  0 to  0 :
# [0, 1, 2, 1, 0]
# Following are all different paths from  0 to  1 :
# Following are all different paths from  0 to  2 :
# Following are all different paths from  1 to  0 :
# Following are all different paths from  1 to  1 :
# [1, 0, 1, 2, 1]
# [1, 2, 1, 0, 1]
# Following are all different paths from  1 to  2 :
# Following are all different paths from  2 to  0 :
# Following are all different paths from  2 to  1 :
# Following are all different paths from  2 to  2 :
# [2, 1, 0, 1, 2]

# %% [markdown]
# ## 030C

# %%
# Python program to print all paths from a source to destination.
  
from collections import defaultdict
  
# This class represents a directed graph
# using adjacency list representation
class Graph:
  
    def __init__(self, vertices):
        # No. of vertices
        self.V = vertices
         
        # default dictionary to store graph
        self.graph = defaultdict(list)
  
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
  
    '''A recursive function to print all paths from 'u' to 'd'.
    visited[] keeps track of vertices in current path.
    path[] stores actual vertices and path_index is current
    index in path[]'''
    def printAllPathsUtil(self, u, d, visited, path):
 
        # Mark the current node as visited and store in path
        visited[u]= False
        path.append(u)
 
        # If current vertex is same as destination, then print
        # current path[]
        if len(path) > 4 and u == d:
            # Using any() + list slicing + generator expression
            res = any(path[idx : idx + len(sublist)] == sublist for idx in range(len(path) - len(sublist) + 1))
            res1 = any(path[idx : idx + len(sublist1)] == sublist1 for idx in range(len(path) - len(sublist1) + 1))
            res2 = any(path[idx : idx + len(sublist2)] == sublist2 for idx in range(len(path) - len(sublist2) + 1))
            if res and res1 and res2 == True:
                print (path)
        else:
            # If current vertex is not destination
            # Recur for all the vertices adjacent to this vertex
            for i in self.graph[u]:
                if visited[i]== False:
                    if len(path) < 5:
                        self.printAllPathsUtil(i, d, visited, path)
                     
        # Remove current vertex from path[] and mark it as unvisited
        path.pop()
        visited[u]= False
        #print(path)
  
  
    # Prints all paths from 's' to 'd'
    def printAllPaths(self, s, d):
 
        # Mark all the vertices as not visited
        visited =[False]*(self.V)
 
        # Create an array to store paths
        path = []
 
        # Call the recursive helper function to print all paths
        self.printAllPathsUtil(s, d, visited, path)
        #print(path)
        
  
  
# Create a graph given in the above diagram
g = Graph(3)
g.addEdge(0, 1)
g.addEdge(1, 2)
g.addEdge(2, 0)

sublist = [0, 1]
sublist1 = [1, 2]
sublist2 = [2, 0]
  
s = 0 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav
# Out:
# Following are all different paths from  0 to  0 :
# Following are all different paths from  0 to  1 :
# [0, 1, 2, 0, 1]
# Following are all different paths from  0 to  2 :
# Following are all different paths from  1 to  0 :
# Following are all different paths from  1 to  1 :
# Following are all different paths from  1 to  2 :
# [1, 2, 0, 1, 2]
# Following are all different paths from  2 to  0 :
# [2, 0, 1, 2, 0]
# Following are all different paths from  2 to  1 :
# Following are all different paths from  2 to  2 :

# %% [markdown]
# ## 120C

# %%
# Python program to print all paths from a source to destination.
  
from collections import defaultdict
  
# This class represents a directed graph
# using adjacency list representation
class Graph:
  
    def __init__(self, vertices):
        # No. of vertices
        self.V = vertices
         
        # default dictionary to store graph
        self.graph = defaultdict(list)
  
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
  
    '''A recursive function to print all paths from 'u' to 'd'.
    visited[] keeps track of vertices in current path.
    path[] stores actual vertices and path_index is current
    index in path[]'''
    def printAllPathsUtil(self, u, d, visited, path):
 
        # Mark the current node as visited and store in path
        visited[u]= False
        path.append(u)
 
        # If current vertex is same as destination, then print
        # current path[]
        if len(path) > n1 and u == d:
            # Using any() + list slicing + generator expression
            res = any(path[idx : idx + len(sublist)] == sublist for idx in range(len(path) - len(sublist) + 1))
            res1 = any(path[idx : idx + len(sublist1)] == sublist1 for idx in range(len(path) - len(sublist1) + 1))
            res2 = any(path[idx : idx + len(sublist2)] == sublist2 for idx in range(len(path) - len(sublist2) + 1))
            res3 = any(path[idx : idx + len(sublist3)] == sublist3 for idx in range(len(path) - len(sublist3) + 1))
            if res and res1 and res2 and res3 == True:
                print (path)
        else:
            # If current vertex is not destination
            # Recur for all the vertices adjacent to this vertex
            for i in self.graph[u]:
                if visited[i]== False:
                    if len(path) < n2:
                        self.printAllPathsUtil(i, d, visited, path)
                     
        # Remove current vertex from path[] and mark it as unvisited
        path.pop()
        visited[u]= False
        #print(path)
  
  
    # Prints all paths from 's' to 'd'
    def printAllPaths(self, s, d):
 
        # Mark all the vertices as not visited
        visited =[False]*(self.V)
 
        # Create an array to store paths
        path = []
 
        # Call the recursive helper function to print all paths
        self.printAllPathsUtil(s, d, visited, path)
        #print(path)
        
  
  
# Create a graph given in the above diagram
g = Graph(3)
g.addEdge(0, 1)
g.addEdge(1, 2)
g.addEdge(2, 1)
g.addEdge(2, 0)

sublist = [0, 1]
sublist1 = [1, 2]
sublist2 = [2, 1]
sublist3 = [2, 0]
  
s = 0 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav
# Out:
# Following are all different paths from  0 to  0 :
# Following are all different paths from  0 to  1 :
# Following are all different paths from  0 to  2 :
# Following are all different paths from  1 to  0 :
# Following are all different paths from  1 to  1 :
# Following are all different paths from  1 to  2 :
# Following are all different paths from  2 to  0 :
# Following are all different paths from  2 to  1 :
# [2, 1, 2, 0, 1]
# [2, 0, 1, 2, 1]
# Following are all different paths from  2 to  2 :

# %% [markdown]
# ## 210

# %%
# Python program to print all paths from a source to destination.
  
from collections import defaultdict
  
# This class represents a directed graph
# using adjacency list representation
class Graph:
  
    def __init__(self, vertices):
        # No. of vertices
        self.V = vertices
         
        # default dictionary to store graph
        self.graph = defaultdict(list)
  
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
  
    '''A recursive function to print all paths from 'u' to 'd'.
    visited[] keeps track of vertices in current path.
    path[] stores actual vertices and path_index is current
    index in path[]'''
    def printAllPathsUtil(self, u, d, visited, path):
 
        # Mark the current node as visited and store in path
        visited[u]= False
        path.append(u)
 
        # If current vertex is same as destination, then print
        # current path[]
        if len(path) > n1 and u == d:
            # Using any() + list slicing + generator expression
            res = any(path[idx : idx + len(sublist)] == sublist for idx in range(len(path) - len(sublist) + 1))
            res1 = any(path[idx : idx + len(sublist1)] == sublist1 for idx in range(len(path) - len(sublist1) + 1))
            res2 = any(path[idx : idx + len(sublist2)] == sublist2 for idx in range(len(path) - len(sublist2) + 1))
            res3 = any(path[idx : idx + len(sublist3)] == sublist3 for idx in range(len(path) - len(sublist3) + 1))
            res4 = any(path[idx : idx + len(sublist4)] == sublist4 for idx in range(len(path) - len(sublist4) + 1))
            if res and res1 and res2 and res3 and res4 == True:
                print (path)
        else:
            # If current vertex is not destination
            # Recur for all the vertices adjacent to this vertex
            for i in self.graph[u]:
                if visited[i]== False:
                    if len(path) < n2:
                        self.printAllPathsUtil(i, d, visited, path)
                     
        # Remove current vertex from path[] and mark it as unvisited
        path.pop()
        visited[u]= False
        #print(path)
  
  
    # Prints all paths from 's' to 'd'
    def printAllPaths(self, s, d):
 
        # Mark all the vertices as not visited
        visited =[False]*(self.V)
 
        # Create an array to store paths
        path = []
 
        # Call the recursive helper function to print all paths
        self.printAllPathsUtil(s, d, visited, path)
        #print(path)
        
  
  
# Create a graph given in the above diagram
g = Graph(3)
g.addEdge(0, 1)
g.addEdge(1, 0)
g.addEdge(1, 2)
g.addEdge(2, 1)
g.addEdge(2, 0)

sublist = [0, 1]
sublist1 = [1, 0]
sublist2 = [1, 2]
sublist3 = [2, 1]
sublist4 = [2, 0]
  
s = 0 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav
# Out:
# Following are all different paths from  0 to  0 :
# Following are all different paths from  0 to  1 :
# Following are all different paths from  0 to  2 :
# Following are all different paths from  1 to  0 :
# Following are all different paths from  1 to  1 :
# Following are all different paths from  1 to  2 :
# Following are all different paths from  2 to  0 :
# Following are all different paths from  2 to  1 :
# Following are all different paths from  2 to  2 :

# %%
n1 = 5
n2 = 6

# %% [markdown]
# ## 201

# %%
# Python program to print all paths from a source to destination.
  
from collections import defaultdict
  
# This class represents a directed graph
# using adjacency list representation
class Graph:
  
    def __init__(self, vertices):
        # No. of vertices
        self.V = vertices
         
        # default dictionary to store graph
        self.graph = defaultdict(list)
  
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
  
    '''A recursive function to print all paths from 'u' to 'd'.
    visited[] keeps track of vertices in current path.
    path[] stores actual vertices and path_index is current
    index in path[]'''
    def printAllPathsUtil(self, u, d, visited, path):
 
        # Mark the current node as visited and store in path
        visited[u]= False
        path.append(u)
 
        # If current vertex is same as destination, then print
        # current path[]
        if len(path) > n1 and u == d:
            # Using any() + list slicing + generator expression
            res = any(path[idx : idx + len(sublist)] == sublist for idx in range(len(path) - len(sublist) + 1))
            res1 = any(path[idx : idx + len(sublist1)] == sublist1 for idx in range(len(path) - len(sublist1) + 1))
            res2 = any(path[idx : idx + len(sublist2)] == sublist2 for idx in range(len(path) - len(sublist2) + 1))
            res3 = any(path[idx : idx + len(sublist3)] == sublist3 for idx in range(len(path) - len(sublist3) + 1))
            if res and res1 and res2 and res3 == True:
                print (path)
        else:
            # If current vertex is not destination
            # Recur for all the vertices adjacent to this vertex
            for i in self.graph[u]:
                if visited[i]== False:
                    if len(path) < n2:
                        self.printAllPathsUtil(i, d, visited, path)
                     
        # Remove current vertex from path[] and mark it as unvisited
        path.pop()
        visited[u]= False
        #print(path)
  
  
    # Prints all paths from 's' to 'd'
    def printAllPaths(self, s, d):
 
        # Mark all the vertices as not visited
        visited =[False]*(self.V)
 
        # Create an array to store paths
        path = []
 
        # Call the recursive helper function to print all paths
        self.printAllPathsUtil(s, d, visited, path)
        #print(path)
        
  
  
# Create a graph given in the above diagram
g = Graph(3)
g.addEdge(0, 1)
g.addEdge(1, 0)
g.addEdge(1, 2)
g.addEdge(2, 1)

sublist = [0, 1]
sublist1 = [1, 0]
sublist2 = [1, 2]
sublist3 = [2, 1]
  
s = 0 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav
# Out:
# Following are all different paths from  0 to  0 :
# Following are all different paths from  0 to  1 :
# [0, 1, 0, 1, 2, 1]
# [0, 1, 2, 1, 0, 1]
# Following are all different paths from  0 to  2 :
# Following are all different paths from  1 to  0 :
# [1, 0, 1, 2, 1, 0]
# [1, 2, 1, 0, 1, 0]
# Following are all different paths from  1 to  1 :
# Following are all different paths from  1 to  2 :
# [1, 0, 1, 2, 1, 2]
# [1, 2, 1, 0, 1, 2]
# Following are all different paths from  2 to  0 :
# Following are all different paths from  2 to  1 :
# [2, 1, 0, 1, 2, 1]
# [2, 1, 2, 1, 0, 1]
# Following are all different paths from  2 to  2 :

# %% [markdown]
# ## 030C

# %%
# Python program to print all paths from a source to destination.
  
from collections import defaultdict
  
# This class represents a directed graph
# using adjacency list representation
class Graph:
  
    def __init__(self, vertices):
        # No. of vertices
        self.V = vertices
         
        # default dictionary to store graph
        self.graph = defaultdict(list)
  
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
  
    '''A recursive function to print all paths from 'u' to 'd'.
    visited[] keeps track of vertices in current path.
    path[] stores actual vertices and path_index is current
    index in path[]'''
    def printAllPathsUtil(self, u, d, visited, path):
 
        # Mark the current node as visited and store in path
        visited[u]= False
        path.append(u)
 
        # If current vertex is same as destination, then print
        # current path[]
        if len(path) > 4 and u == d:
            # Using any() + list slicing + generator expression
            res = any(path[idx : idx + len(sublist)] == sublist for idx in range(len(path) - len(sublist) + 1))
            res1 = any(path[idx : idx + len(sublist1)] == sublist1 for idx in range(len(path) - len(sublist1) + 1))
            res2 = any(path[idx : idx + len(sublist2)] == sublist2 for idx in range(len(path) - len(sublist2) + 1))
            if res and res1 and res2 == True:
                print (path)
        else:
            # If current vertex is not destination
            # Recur for all the vertices adjacent to this vertex
            for i in self.graph[u]:
                if visited[i]== False:
                    if len(path) < 5:
                        self.printAllPathsUtil(i, d, visited, path)
                     
        # Remove current vertex from path[] and mark it as unvisited
        path.pop()
        visited[u]= False
        #print(path)
  
  
    # Prints all paths from 's' to 'd'
    def printAllPaths(self, s, d):
 
        # Mark all the vertices as not visited
        visited =[False]*(self.V)
 
        # Create an array to store paths
        path = []
 
        # Call the recursive helper function to print all paths
        self.printAllPathsUtil(s, d, visited, path)
        #print(path)
        
  
  
# Create a graph given in the above diagram
g = Graph(3)
g.addEdge(0, 1)
g.addEdge(1, 2)
g.addEdge(2, 0)

sublist = [0, 1]
sublist1 = [1, 2]
sublist2 = [2, 0]
  
s = 0 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav
# Out:
# Following are all different paths from  0 to  0 :
# Following are all different paths from  0 to  1 :
# [0, 1, 2, 0, 1]
# Following are all different paths from  0 to  2 :
# Following are all different paths from  1 to  0 :
# Following are all different paths from  1 to  1 :
# Following are all different paths from  1 to  2 :
# [1, 2, 0, 1, 2]
# Following are all different paths from  2 to  0 :
# [2, 0, 1, 2, 0]
# Following are all different paths from  2 to  1 :
# Following are all different paths from  2 to  2 :

# %% [markdown]
# ## 120C

# %%
# Python program to print all paths from a source to destination.
  
from collections import defaultdict
  
# This class represents a directed graph
# using adjacency list representation
class Graph:
  
    def __init__(self, vertices):
        # No. of vertices
        self.V = vertices
         
        # default dictionary to store graph
        self.graph = defaultdict(list)
  
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
  
    '''A recursive function to print all paths from 'u' to 'd'.
    visited[] keeps track of vertices in current path.
    path[] stores actual vertices and path_index is current
    index in path[]'''
    def printAllPathsUtil(self, u, d, visited, path):
 
        # Mark the current node as visited and store in path
        visited[u]= False
        path.append(u)
 
        # If current vertex is same as destination, then print
        # current path[]
        if len(path) > n1 and u == d:
            # Using any() + list slicing + generator expression
            res = any(path[idx : idx + len(sublist)] == sublist for idx in range(len(path) - len(sublist) + 1))
            res1 = any(path[idx : idx + len(sublist1)] == sublist1 for idx in range(len(path) - len(sublist1) + 1))
            res2 = any(path[idx : idx + len(sublist2)] == sublist2 for idx in range(len(path) - len(sublist2) + 1))
            res3 = any(path[idx : idx + len(sublist3)] == sublist3 for idx in range(len(path) - len(sublist3) + 1))
            if res and res1 and res2 and res3 == True:
                print (path)
        else:
            # If current vertex is not destination
            # Recur for all the vertices adjacent to this vertex
            for i in self.graph[u]:
                if visited[i]== False:
                    if len(path) < n2:
                        self.printAllPathsUtil(i, d, visited, path)
                     
        # Remove current vertex from path[] and mark it as unvisited
        path.pop()
        visited[u]= False
        #print(path)
  
  
    # Prints all paths from 's' to 'd'
    def printAllPaths(self, s, d):
 
        # Mark all the vertices as not visited
        visited =[False]*(self.V)
 
        # Create an array to store paths
        path = []
 
        # Call the recursive helper function to print all paths
        self.printAllPathsUtil(s, d, visited, path)
        #print(path)
        
  
  
# Create a graph given in the above diagram
g = Graph(3)
g.addEdge(0, 1)
g.addEdge(1, 2)
g.addEdge(2, 1)
g.addEdge(2, 0)

sublist = [0, 1]
sublist1 = [1, 2]
sublist2 = [2, 1]
sublist3 = [2, 0]
  
s = 0 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav
# Out:
# Following are all different paths from  0 to  0 :
# [0, 1, 2, 1, 2, 0]
# Following are all different paths from  0 to  1 :
# Following are all different paths from  0 to  2 :
# Following are all different paths from  1 to  0 :
# Following are all different paths from  1 to  1 :
# [1, 2, 1, 2, 0, 1]
# [1, 2, 0, 1, 2, 1]
# Following are all different paths from  1 to  2 :
# Following are all different paths from  2 to  0 :
# Following are all different paths from  2 to  1 :
# Following are all different paths from  2 to  2 :
# [2, 1, 2, 0, 1, 2]
# [2, 0, 1, 2, 1, 2]

# %% [markdown]
# ## 210

# %%
# Python program to print all paths from a source to destination.
  
from collections import defaultdict
  
# This class represents a directed graph
# using adjacency list representation
class Graph:
  
    def __init__(self, vertices):
        # No. of vertices
        self.V = vertices
         
        # default dictionary to store graph
        self.graph = defaultdict(list)
  
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
  
    '''A recursive function to print all paths from 'u' to 'd'.
    visited[] keeps track of vertices in current path.
    path[] stores actual vertices and path_index is current
    index in path[]'''
    def printAllPathsUtil(self, u, d, visited, path):
 
        # Mark the current node as visited and store in path
        visited[u]= False
        path.append(u)
 
        # If current vertex is same as destination, then print
        # current path[]
        if len(path) > n1 and u == d:
            # Using any() + list slicing + generator expression
            res = any(path[idx : idx + len(sublist)] == sublist for idx in range(len(path) - len(sublist) + 1))
            res1 = any(path[idx : idx + len(sublist1)] == sublist1 for idx in range(len(path) - len(sublist1) + 1))
            res2 = any(path[idx : idx + len(sublist2)] == sublist2 for idx in range(len(path) - len(sublist2) + 1))
            res3 = any(path[idx : idx + len(sublist3)] == sublist3 for idx in range(len(path) - len(sublist3) + 1))
            res4 = any(path[idx : idx + len(sublist4)] == sublist4 for idx in range(len(path) - len(sublist4) + 1))
            if res and res1 and res2 and res3 and res4 == True:
                print (path)
        else:
            # If current vertex is not destination
            # Recur for all the vertices adjacent to this vertex
            for i in self.graph[u]:
                if visited[i]== False:
                    if len(path) < n2:
                        self.printAllPathsUtil(i, d, visited, path)
                     
        # Remove current vertex from path[] and mark it as unvisited
        path.pop()
        visited[u]= False
        #print(path)
  
  
    # Prints all paths from 's' to 'd'
    def printAllPaths(self, s, d):
 
        # Mark all the vertices as not visited
        visited =[False]*(self.V)
 
        # Create an array to store paths
        path = []
 
        # Call the recursive helper function to print all paths
        self.printAllPathsUtil(s, d, visited, path)
        #print(path)
        
  
  
# Create a graph given in the above diagram
g = Graph(3)
g.addEdge(0, 1)
g.addEdge(1, 0)
g.addEdge(1, 2)
g.addEdge(2, 1)
g.addEdge(2, 0)

sublist = [0, 1]
sublist1 = [1, 0]
sublist2 = [1, 2]
sublist3 = [2, 1]
sublist4 = [2, 0]
  
s = 0 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav
# Out:
# Following are all different paths from  0 to  0 :
# Following are all different paths from  0 to  1 :
# Following are all different paths from  0 to  2 :
# Following are all different paths from  1 to  0 :
# Following are all different paths from  1 to  1 :
# Following are all different paths from  1 to  2 :
# Following are all different paths from  2 to  0 :
# [2, 1, 0, 1, 2, 0]
# [2, 1, 2, 0, 1, 0]
# [2, 0, 1, 2, 1, 0]
# Following are all different paths from  2 to  1 :
# Following are all different paths from  2 to  2 :

# %%
n1 = 6
n2 = 7

# %% [markdown]
# ## 201

# %%
# Python program to print all paths from a source to destination.
  
from collections import defaultdict
  
# This class represents a directed graph
# using adjacency list representation
class Graph:
  
    def __init__(self, vertices):
        # No. of vertices
        self.V = vertices
         
        # default dictionary to store graph
        self.graph = defaultdict(list)
  
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
  
    '''A recursive function to print all paths from 'u' to 'd'.
    visited[] keeps track of vertices in current path.
    path[] stores actual vertices and path_index is current
    index in path[]'''
    def printAllPathsUtil(self, u, d, visited, path):
 
        # Mark the current node as visited and store in path
        visited[u]= False
        path.append(u)
 
        # If current vertex is same as destination, then print
        # current path[]
        if len(path) > n1 and u == d:
            # Using any() + list slicing + generator expression
            res = any(path[idx : idx + len(sublist)] == sublist for idx in range(len(path) - len(sublist) + 1))
            res1 = any(path[idx : idx + len(sublist1)] == sublist1 for idx in range(len(path) - len(sublist1) + 1))
            res2 = any(path[idx : idx + len(sublist2)] == sublist2 for idx in range(len(path) - len(sublist2) + 1))
            res3 = any(path[idx : idx + len(sublist3)] == sublist3 for idx in range(len(path) - len(sublist3) + 1))
            if res and res1 and res2 and res3 == True:
                print (path)
        else:
            # If current vertex is not destination
            # Recur for all the vertices adjacent to this vertex
            for i in self.graph[u]:
                if visited[i]== False:
                    if len(path) < n2:
                        self.printAllPathsUtil(i, d, visited, path)
                     
        # Remove current vertex from path[] and mark it as unvisited
        path.pop()
        visited[u]= False
        #print(path)
  
  
    # Prints all paths from 's' to 'd'
    def printAllPaths(self, s, d):
 
        # Mark all the vertices as not visited
        visited =[False]*(self.V)
 
        # Create an array to store paths
        path = []
 
        # Call the recursive helper function to print all paths
        self.printAllPathsUtil(s, d, visited, path)
        #print(path)
        
  
  
# Create a graph given in the above diagram
g = Graph(3)
g.addEdge(0, 1)
g.addEdge(1, 0)
g.addEdge(1, 2)
g.addEdge(2, 1)

sublist = [0, 1]
sublist1 = [1, 0]
sublist2 = [1, 2]
sublist3 = [2, 1]
  
s = 0 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav
# Out:
# Following are all different paths from  0 to  0 :
# [0, 1, 0, 1, 2, 1, 0]
# [0, 1, 2, 1, 0, 1, 0]
# [0, 1, 2, 1, 2, 1, 0]
# Following are all different paths from  0 to  1 :
# Following are all different paths from  0 to  2 :
# [0, 1, 0, 1, 2, 1, 2]
# [0, 1, 2, 1, 0, 1, 2]
# Following are all different paths from  1 to  0 :
# Following are all different paths from  1 to  1 :
# [1, 0, 1, 0, 1, 2, 1]
# [1, 0, 1, 2, 1, 0, 1]
# [1, 0, 1, 2, 1, 2, 1]
# [1, 2, 1, 0, 1, 0, 1]
# [1, 2, 1, 0, 1, 2, 1]
# [1, 2, 1, 2, 1, 0, 1]
# Following are all different paths from  1 to  2 :
# Following are all different paths from  2 to  0 :
# [2, 1, 0, 1, 2, 1, 0]
# [2, 1, 2, 1, 0, 1, 0]
# Following are all different paths from  2 to  1 :
# Following are all different paths from  2 to  2 :
# [2, 1, 0, 1, 0, 1, 2]
# [2, 1, 0, 1, 2, 1, 2]
# [2, 1, 2, 1, 0, 1, 2]

# %% [markdown]
# ## 030C

# %%
# Python program to print all paths from a source to destination.
  
from collections import defaultdict
  
# This class represents a directed graph
# using adjacency list representation
class Graph:
  
    def __init__(self, vertices):
        # No. of vertices
        self.V = vertices
         
        # default dictionary to store graph
        self.graph = defaultdict(list)
  
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
  
    '''A recursive function to print all paths from 'u' to 'd'.
    visited[] keeps track of vertices in current path.
    path[] stores actual vertices and path_index is current
    index in path[]'''
    def printAllPathsUtil(self, u, d, visited, path):
 
        # Mark the current node as visited and store in path
        visited[u]= False
        path.append(u)
 
        # If current vertex is same as destination, then print
        # current path[]
        if len(path) > 4 and u == d:
            # Using any() + list slicing + generator expression
            res = any(path[idx : idx + len(sublist)] == sublist for idx in range(len(path) - len(sublist) + 1))
            res1 = any(path[idx : idx + len(sublist1)] == sublist1 for idx in range(len(path) - len(sublist1) + 1))
            res2 = any(path[idx : idx + len(sublist2)] == sublist2 for idx in range(len(path) - len(sublist2) + 1))
            if res and res1 and res2 == True:
                print (path)
        else:
            # If current vertex is not destination
            # Recur for all the vertices adjacent to this vertex
            for i in self.graph[u]:
                if visited[i]== False:
                    if len(path) < 5:
                        self.printAllPathsUtil(i, d, visited, path)
                     
        # Remove current vertex from path[] and mark it as unvisited
        path.pop()
        visited[u]= False
        #print(path)
  
  
    # Prints all paths from 's' to 'd'
    def printAllPaths(self, s, d):
 
        # Mark all the vertices as not visited
        visited =[False]*(self.V)
 
        # Create an array to store paths
        path = []
 
        # Call the recursive helper function to print all paths
        self.printAllPathsUtil(s, d, visited, path)
        #print(path)
        
  
  
# Create a graph given in the above diagram
g = Graph(3)
g.addEdge(0, 1)
g.addEdge(1, 2)
g.addEdge(2, 0)

sublist = [0, 1]
sublist1 = [1, 2]
sublist2 = [2, 0]
  
s = 0 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav
# Out:
# Following are all different paths from  0 to  0 :
# Following are all different paths from  0 to  1 :
# [0, 1, 2, 0, 1]
# Following are all different paths from  0 to  2 :
# Following are all different paths from  1 to  0 :
# Following are all different paths from  1 to  1 :
# Following are all different paths from  1 to  2 :
# [1, 2, 0, 1, 2]
# Following are all different paths from  2 to  0 :
# [2, 0, 1, 2, 0]
# Following are all different paths from  2 to  1 :
# Following are all different paths from  2 to  2 :

# %% [markdown]
# ## 120C

# %%
# Python program to print all paths from a source to destination.
  
from collections import defaultdict
  
# This class represents a directed graph
# using adjacency list representation
class Graph:
  
    def __init__(self, vertices):
        # No. of vertices
        self.V = vertices
         
        # default dictionary to store graph
        self.graph = defaultdict(list)
  
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
  
    '''A recursive function to print all paths from 'u' to 'd'.
    visited[] keeps track of vertices in current path.
    path[] stores actual vertices and path_index is current
    index in path[]'''
    def printAllPathsUtil(self, u, d, visited, path):
 
        # Mark the current node as visited and store in path
        visited[u]= False
        path.append(u)
 
        # If current vertex is same as destination, then print
        # current path[]
        if len(path) > n1 and u == d:
            # Using any() + list slicing + generator expression
            res = any(path[idx : idx + len(sublist)] == sublist for idx in range(len(path) - len(sublist) + 1))
            res1 = any(path[idx : idx + len(sublist1)] == sublist1 for idx in range(len(path) - len(sublist1) + 1))
            res2 = any(path[idx : idx + len(sublist2)] == sublist2 for idx in range(len(path) - len(sublist2) + 1))
            res3 = any(path[idx : idx + len(sublist3)] == sublist3 for idx in range(len(path) - len(sublist3) + 1))
            if res and res1 and res2 and res3 == True:
                print (path)
        else:
            # If current vertex is not destination
            # Recur for all the vertices adjacent to this vertex
            for i in self.graph[u]:
                if visited[i]== False:
                    if len(path) < n2:
                        self.printAllPathsUtil(i, d, visited, path)
                     
        # Remove current vertex from path[] and mark it as unvisited
        path.pop()
        visited[u]= False
        #print(path)
  
  
    # Prints all paths from 's' to 'd'
    def printAllPaths(self, s, d):
 
        # Mark all the vertices as not visited
        visited =[False]*(self.V)
 
        # Create an array to store paths
        path = []
 
        # Call the recursive helper function to print all paths
        self.printAllPathsUtil(s, d, visited, path)
        #print(path)
        
  
  
# Create a graph given in the above diagram
g = Graph(3)
g.addEdge(0, 1)
g.addEdge(1, 2)
g.addEdge(2, 1)
g.addEdge(2, 0)

sublist = [0, 1]
sublist1 = [1, 2]
sublist2 = [2, 1]
sublist3 = [2, 0]
  
s = 0 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav
# Out:
# Following are all different paths from  0 to  0 :
# Following are all different paths from  0 to  1 :
# [0, 1, 2, 1, 2, 0, 1]
# [0, 1, 2, 0, 1, 2, 1]
# Following are all different paths from  0 to  2 :
# Following are all different paths from  1 to  0 :
# Following are all different paths from  1 to  1 :
# Following are all different paths from  1 to  2 :
# [1, 2, 1, 2, 0, 1, 2]
# [1, 2, 0, 1, 2, 1, 2]
# Following are all different paths from  2 to  0 :
# [2, 1, 2, 0, 1, 2, 0]
# [2, 0, 1, 2, 1, 2, 0]
# Following are all different paths from  2 to  1 :
# [2, 1, 2, 1, 2, 0, 1]
# [2, 1, 2, 0, 1, 2, 1]
# [2, 0, 1, 2, 1, 2, 1]
# Following are all different paths from  2 to  2 :

# %% [markdown]
# ## 210

# %%
# Python program to print all paths from a source to destination.
  
from collections import defaultdict
  
# This class represents a directed graph
# using adjacency list representation
class Graph:
  
    def __init__(self, vertices):
        # No. of vertices
        self.V = vertices
         
        # default dictionary to store graph
        self.graph = defaultdict(list)
  
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
  
    '''A recursive function to print all paths from 'u' to 'd'.
    visited[] keeps track of vertices in current path.
    path[] stores actual vertices and path_index is current
    index in path[]'''
    def printAllPathsUtil(self, u, d, visited, path):
 
        # Mark the current node as visited and store in path
        visited[u]= False
        path.append(u)
 
        # If current vertex is same as destination, then print
        # current path[]
        if len(path) > n1 and u == d:
            # Using any() + list slicing + generator expression
            res = any(path[idx : idx + len(sublist)] == sublist for idx in range(len(path) - len(sublist) + 1))
            res1 = any(path[idx : idx + len(sublist1)] == sublist1 for idx in range(len(path) - len(sublist1) + 1))
            res2 = any(path[idx : idx + len(sublist2)] == sublist2 for idx in range(len(path) - len(sublist2) + 1))
            res3 = any(path[idx : idx + len(sublist3)] == sublist3 for idx in range(len(path) - len(sublist3) + 1))
            res4 = any(path[idx : idx + len(sublist4)] == sublist4 for idx in range(len(path) - len(sublist4) + 1))
            if res and res1 and res2 and res3 and res4 == True:
                print (path)
        else:
            # If current vertex is not destination
            # Recur for all the vertices adjacent to this vertex
            for i in self.graph[u]:
                if visited[i]== False:
                    if len(path) < n2:
                        self.printAllPathsUtil(i, d, visited, path)
                     
        # Remove current vertex from path[] and mark it as unvisited
        path.pop()
        visited[u]= False
        #print(path)
  
  
    # Prints all paths from 's' to 'd'
    def printAllPaths(self, s, d):
 
        # Mark all the vertices as not visited
        visited =[False]*(self.V)
 
        # Create an array to store paths
        path = []
 
        # Call the recursive helper function to print all paths
        self.printAllPathsUtil(s, d, visited, path)
        #print(path)
        
  
  
# Create a graph given in the above diagram
g = Graph(3)
g.addEdge(0, 1)
g.addEdge(1, 0)
g.addEdge(1, 2)
g.addEdge(2, 1)
g.addEdge(2, 0)

sublist = [0, 1]
sublist1 = [1, 0]
sublist2 = [1, 2]
sublist3 = [2, 1]
sublist4 = [2, 0]
  
s = 0 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav
# Out:
# Following are all different paths from  0 to  0 :
# Following are all different paths from  0 to  1 :
# Following are all different paths from  0 to  2 :
# Following are all different paths from  1 to  0 :
# [1, 0, 1, 2, 1, 2, 0]
# [1, 2, 1, 0, 1, 2, 0]
# [1, 2, 1, 2, 0, 1, 0]
# [1, 2, 0, 1, 2, 1, 0]
# Following are all different paths from  1 to  1 :
# Following are all different paths from  1 to  2 :
# Following are all different paths from  2 to  0 :
# Following are all different paths from  2 to  1 :
# [2, 1, 0, 1, 2, 0, 1]
# [2, 1, 2, 0, 1, 0, 1]
# [2, 0, 1, 0, 1, 2, 1]
# [2, 0, 1, 2, 1, 0, 1]
# Following are all different paths from  2 to  2 :

# %%
n1 = 7
n2 = 8

# %% [markdown]
# ## 201

# %%
# Python program to print all paths from a source to destination.
  
from collections import defaultdict
  
# This class represents a directed graph
# using adjacency list representation
class Graph:
  
    def __init__(self, vertices):
        # No. of vertices
        self.V = vertices
         
        # default dictionary to store graph
        self.graph = defaultdict(list)
  
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
  
    '''A recursive function to print all paths from 'u' to 'd'.
    visited[] keeps track of vertices in current path.
    path[] stores actual vertices and path_index is current
    index in path[]'''
    def printAllPathsUtil(self, u, d, visited, path):
 
        # Mark the current node as visited and store in path
        visited[u]= False
        path.append(u)
 
        # If current vertex is same as destination, then print
        # current path[]
        if len(path) > n1 and u == d:
            # Using any() + list slicing + generator expression
            res = any(path[idx : idx + len(sublist)] == sublist for idx in range(len(path) - len(sublist) + 1))
            res1 = any(path[idx : idx + len(sublist1)] == sublist1 for idx in range(len(path) - len(sublist1) + 1))
            res2 = any(path[idx : idx + len(sublist2)] == sublist2 for idx in range(len(path) - len(sublist2) + 1))
            res3 = any(path[idx : idx + len(sublist3)] == sublist3 for idx in range(len(path) - len(sublist3) + 1))
            if res and res1 and res2 and res3 == True:
                print (path)
        else:
            # If current vertex is not destination
            # Recur for all the vertices adjacent to this vertex
            for i in self.graph[u]:
                if visited[i]== False:
                    if len(path) < n2:
                        self.printAllPathsUtil(i, d, visited, path)
                     
        # Remove current vertex from path[] and mark it as unvisited
        path.pop()
        visited[u]= False
        #print(path)
  
  
    # Prints all paths from 's' to 'd'
    def printAllPaths(self, s, d):
 
        # Mark all the vertices as not visited
        visited =[False]*(self.V)
 
        # Create an array to store paths
        path = []
 
        # Call the recursive helper function to print all paths
        self.printAllPathsUtil(s, d, visited, path)
        #print(path)
        
  
  
# Create a graph given in the above diagram
g = Graph(3)
g.addEdge(0, 1)
g.addEdge(1, 0)
g.addEdge(1, 2)
g.addEdge(2, 1)

sublist = [0, 1]
sublist1 = [1, 0]
sublist2 = [1, 2]
sublist3 = [2, 1]
  
s = 0 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav
# Out:
# Following are all different paths from  0 to  0 :
# Following are all different paths from  0 to  1 :
# [0, 1, 0, 1, 0, 1, 2, 1]
# [0, 1, 0, 1, 2, 1, 0, 1]
# [0, 1, 0, 1, 2, 1, 2, 1]
# [0, 1, 2, 1, 0, 1, 0, 1]
# [0, 1, 2, 1, 0, 1, 2, 1]
# [0, 1, 2, 1, 2, 1, 0, 1]
# Following are all different paths from  0 to  2 :
# Following are all different paths from  1 to  0 :
# [1, 0, 1, 0, 1, 2, 1, 0]
# [1, 0, 1, 2, 1, 0, 1, 0]
# [1, 0, 1, 2, 1, 2, 1, 0]
# [1, 2, 1, 0, 1, 0, 1, 0]
# [1, 2, 1, 0, 1, 2, 1, 0]
# [1, 2, 1, 2, 1, 0, 1, 0]
# Following are all different paths from  1 to  1 :
# Following are all different paths from  1 to  2 :
# [1, 0, 1, 0, 1, 2, 1, 2]
# [1, 0, 1, 2, 1, 0, 1, 2]
# [1, 0, 1, 2, 1, 2, 1, 2]
# [1, 2, 1, 0, 1, 0, 1, 2]
# [1, 2, 1, 0, 1, 2, 1, 2]
# [1, 2, 1, 2, 1, 0, 1, 2]
# Following are all different paths from  2 to  0 :
# Following are all different paths from  2 to  1 :
# [2, 1, 0, 1, 0, 1, 2, 1]
# [2, 1, 0, 1, 2, 1, 0, 1]
# [2, 1, 0, 1, 2, 1, 2, 1]
# ...

# %% [markdown]
# ## 030C

# %%
# Python program to print all paths from a source to destination.
  
from collections import defaultdict
  
# This class represents a directed graph
# using adjacency list representation
class Graph:
  
    def __init__(self, vertices):
        # No. of vertices
        self.V = vertices
         
        # default dictionary to store graph
        self.graph = defaultdict(list)
  
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
  
    '''A recursive function to print all paths from 'u' to 'd'.
    visited[] keeps track of vertices in current path.
    path[] stores actual vertices and path_index is current
    index in path[]'''
    def printAllPathsUtil(self, u, d, visited, path):
 
        # Mark the current node as visited and store in path
        visited[u]= False
        path.append(u)
 
        # If current vertex is same as destination, then print
        # current path[]
        if len(path) > 4 and u == d:
            # Using any() + list slicing + generator expression
            res = any(path[idx : idx + len(sublist)] == sublist for idx in range(len(path) - len(sublist) + 1))
            res1 = any(path[idx : idx + len(sublist1)] == sublist1 for idx in range(len(path) - len(sublist1) + 1))
            res2 = any(path[idx : idx + len(sublist2)] == sublist2 for idx in range(len(path) - len(sublist2) + 1))
            if res and res1 and res2 == True:
                print (path)
        else:
            # If current vertex is not destination
            # Recur for all the vertices adjacent to this vertex
            for i in self.graph[u]:
                if visited[i]== False:
                    if len(path) < 5:
                        self.printAllPathsUtil(i, d, visited, path)
                     
        # Remove current vertex from path[] and mark it as unvisited
        path.pop()
        visited[u]= False
        #print(path)
  
  
    # Prints all paths from 's' to 'd'
    def printAllPaths(self, s, d):
 
        # Mark all the vertices as not visited
        visited =[False]*(self.V)
 
        # Create an array to store paths
        path = []
 
        # Call the recursive helper function to print all paths
        self.printAllPathsUtil(s, d, visited, path)
        #print(path)
        
  
  
# Create a graph given in the above diagram
g = Graph(3)
g.addEdge(0, 1)
g.addEdge(1, 2)
g.addEdge(2, 0)

sublist = [0, 1]
sublist1 = [1, 2]
sublist2 = [2, 0]
  
s = 0 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav
# Out:
# Following are all different paths from  0 to  0 :
# Following are all different paths from  0 to  1 :
# [0, 1, 2, 0, 1]
# Following are all different paths from  0 to  2 :
# Following are all different paths from  1 to  0 :
# Following are all different paths from  1 to  1 :
# Following are all different paths from  1 to  2 :
# [1, 2, 0, 1, 2]
# Following are all different paths from  2 to  0 :
# [2, 0, 1, 2, 0]
# Following are all different paths from  2 to  1 :
# Following are all different paths from  2 to  2 :

# %% [markdown]
# ## 120C

# %%
# Python program to print all paths from a source to destination.
  
from collections import defaultdict
  
# This class represents a directed graph
# using adjacency list representation
class Graph:
  
    def __init__(self, vertices):
        # No. of vertices
        self.V = vertices
         
        # default dictionary to store graph
        self.graph = defaultdict(list)
  
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
  
    '''A recursive function to print all paths from 'u' to 'd'.
    visited[] keeps track of vertices in current path.
    path[] stores actual vertices and path_index is current
    index in path[]'''
    def printAllPathsUtil(self, u, d, visited, path):
 
        # Mark the current node as visited and store in path
        visited[u]= False
        path.append(u)
 
        # If current vertex is same as destination, then print
        # current path[]
        if len(path) > n1 and u == d:
            # Using any() + list slicing + generator expression
            res = any(path[idx : idx + len(sublist)] == sublist for idx in range(len(path) - len(sublist) + 1))
            res1 = any(path[idx : idx + len(sublist1)] == sublist1 for idx in range(len(path) - len(sublist1) + 1))
            res2 = any(path[idx : idx + len(sublist2)] == sublist2 for idx in range(len(path) - len(sublist2) + 1))
            res3 = any(path[idx : idx + len(sublist3)] == sublist3 for idx in range(len(path) - len(sublist3) + 1))
            if res and res1 and res2 and res3 == True:
                print (path)
        else:
            # If current vertex is not destination
            # Recur for all the vertices adjacent to this vertex
            for i in self.graph[u]:
                if visited[i]== False:
                    if len(path) < n2:
                        self.printAllPathsUtil(i, d, visited, path)
                     
        # Remove current vertex from path[] and mark it as unvisited
        path.pop()
        visited[u]= False
        #print(path)
  
  
    # Prints all paths from 's' to 'd'
    def printAllPaths(self, s, d):
 
        # Mark all the vertices as not visited
        visited =[False]*(self.V)
 
        # Create an array to store paths
        path = []
 
        # Call the recursive helper function to print all paths
        self.printAllPathsUtil(s, d, visited, path)
        #print(path)
        
  
  
# Create a graph given in the above diagram
g = Graph(3)
g.addEdge(0, 1)
g.addEdge(1, 2)
g.addEdge(2, 1)
g.addEdge(2, 0)

sublist = [0, 1]
sublist1 = [1, 2]
sublist2 = [2, 1]
sublist3 = [2, 0]
  
s = 0 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav
# Out:
# Following are all different paths from  0 to  0 :
# [0, 1, 2, 1, 2, 1, 2, 0]
# Following are all different paths from  0 to  1 :
# Following are all different paths from  0 to  2 :
# [0, 1, 2, 1, 2, 0, 1, 2]
# [0, 1, 2, 0, 1, 2, 1, 2]
# Following are all different paths from  1 to  0 :
# [1, 2, 1, 2, 0, 1, 2, 0]
# [1, 2, 0, 1, 2, 1, 2, 0]
# Following are all different paths from  1 to  1 :
# [1, 2, 1, 2, 1, 2, 0, 1]
# [1, 2, 1, 2, 0, 1, 2, 1]
# [1, 2, 0, 1, 2, 1, 2, 1]
# Following are all different paths from  1 to  2 :
# Following are all different paths from  2 to  0 :
# Following are all different paths from  2 to  1 :
# [2, 1, 2, 0, 1, 2, 0, 1]
# [2, 0, 1, 2, 1, 2, 0, 1]
# [2, 0, 1, 2, 0, 1, 2, 1]
# Following are all different paths from  2 to  2 :
# [2, 1, 2, 1, 2, 0, 1, 2]
# [2, 1, 2, 0, 1, 2, 1, 2]
# [2, 0, 1, 2, 1, 2, 1, 2]

# %% [markdown]
# ## 210

# %%
# Python program to print all paths from a source to destination.
  
from collections import defaultdict
  
# This class represents a directed graph
# using adjacency list representation
class Graph:
  
    def __init__(self, vertices):
        # No. of vertices
        self.V = vertices
         
        # default dictionary to store graph
        self.graph = defaultdict(list)
  
    # function to add an edge to graph
    def addEdge(self, u, v):
        self.graph[u].append(v)
  
    '''A recursive function to print all paths from 'u' to 'd'.
    visited[] keeps track of vertices in current path.
    path[] stores actual vertices and path_index is current
    index in path[]'''
    def printAllPathsUtil(self, u, d, visited, path):
 
        # Mark the current node as visited and store in path
        visited[u]= False
        path.append(u)
 
        # If current vertex is same as destination, then print
        # current path[]
        if len(path) > n1 and u == d:
            # Using any() + list slicing + generator expression
            res = any(path[idx : idx + len(sublist)] == sublist for idx in range(len(path) - len(sublist) + 1))
            res1 = any(path[idx : idx + len(sublist1)] == sublist1 for idx in range(len(path) - len(sublist1) + 1))
            res2 = any(path[idx : idx + len(sublist2)] == sublist2 for idx in range(len(path) - len(sublist2) + 1))
            res3 = any(path[idx : idx + len(sublist3)] == sublist3 for idx in range(len(path) - len(sublist3) + 1))
            res4 = any(path[idx : idx + len(sublist4)] == sublist4 for idx in range(len(path) - len(sublist4) + 1))
            if res and res1 and res2 and res3 and res4 == True:
                print (path)
        else:
            # If current vertex is not destination
            # Recur for all the vertices adjacent to this vertex
            for i in self.graph[u]:
                if visited[i]== False:
                    if len(path) < n2:
                        self.printAllPathsUtil(i, d, visited, path)
                     
        # Remove current vertex from path[] and mark it as unvisited
        path.pop()
        visited[u]= False
        #print(path)
  
  
    # Prints all paths from 's' to 'd'
    def printAllPaths(self, s, d):
 
        # Mark all the vertices as not visited
        visited =[False]*(self.V)
 
        # Create an array to store paths
        path = []
 
        # Call the recursive helper function to print all paths
        self.printAllPathsUtil(s, d, visited, path)
        #print(path)
        
  
  
# Create a graph given in the above diagram
g = Graph(3)
g.addEdge(0, 1)
g.addEdge(1, 0)
g.addEdge(1, 2)
g.addEdge(2, 1)
g.addEdge(2, 0)

sublist = [0, 1]
sublist1 = [1, 0]
sublist2 = [1, 2]
sublist3 = [2, 1]
sublist4 = [2, 0]
  
s = 0 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 0 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 1 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 0
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 1
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav

s = 2 ; d = 2
print ("Following are all different paths from % d to % d :" %(s, d))
g.printAllPaths(s, d)
# This code is contributed by Neelam Yadav
# Out:
# Following are all different paths from  0 to  0 :
# [0, 1, 0, 1, 2, 1, 2, 0]
# [0, 1, 2, 1, 0, 1, 2, 0]
# [0, 1, 2, 1, 2, 0, 1, 0]
# [0, 1, 2, 0, 1, 2, 1, 0]
# Following are all different paths from  0 to  1 :
# Following are all different paths from  0 to  2 :
# Following are all different paths from  1 to  0 :
# Following are all different paths from  1 to  1 :
# [1, 0, 1, 2, 1, 2, 0, 1]
# [1, 0, 1, 2, 0, 1, 2, 1]
# [1, 2, 1, 0, 1, 2, 0, 1]
# [1, 2, 1, 2, 0, 1, 0, 1]
# [1, 2, 0, 1, 0, 1, 2, 1]
# [1, 2, 0, 1, 2, 1, 0, 1]
# Following are all different paths from  1 to  2 :
# Following are all different paths from  2 to  0 :
# [2, 1, 0, 1, 0, 1, 2, 0]
# [2, 1, 0, 1, 2, 1, 2, 0]
# [2, 1, 0, 1, 2, 0, 1, 0]
# [2, 1, 2, 1, 0, 1, 2, 0]
# [2, 1, 2, 1, 2, 0, 1, 0]
# [2, 1, 2, 0, 1, 0, 1, 0]
# [2, 1, 2, 0, 1, 2, 1, 0]
# [2, 0, 1, 0, 1, 2, 1, 0]
# [2, 0, 1, 2, 1, 0, 1, 0]
# [2, 0, 1, 2, 1, 2, 1, 0]
# Following are all different paths from  2 to  1 :
# ...
