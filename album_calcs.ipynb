# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\Callu\\OneDrive\\Desktop\\Network Beatles Data\\Algos'

# %% [markdown]
# ## Album1

# %%
album01 = pd.read_csv('C:\\Users\\Callu\\OneDrive\\Desktop\\Network Beatles Data\\album_01_Queen_edges.csv')
G1 = nx.from_pandas_edgelist(album01, source="Source", target="Target", create_using=nx.DiGraph())

# %%
import operator

print(nx.average_clustering(G1))
c1 = nx.clustering(G1)
sorted_tuples = sorted(c1.items(), key=operator.itemgetter(1), reverse=True)
sorted_tuples
# Out:
# 0.22088562589849914
# [('D:7', 1.0),
#  ('E:7', 1.0),
#  ('G:maj/3', 1.0),
#  ('Ab/3', 1.0),
#  ('Ab/7', 1.0),
#  ('C:min/5', 1.0),
#  ('E:min/5', 1.0),
#  ('A:7/3', 1.0),
#  ('Bb:maj(9)', 1.0),
#  ('G:sus4', 0.8333333333333334),
#  ('F:min(6)', 0.8),
#  ('E/3', 0.7222222222222222),
#  ('Ab:7', 0.6666666666666666),
#  ('G:min/5', 0.5),
#  ('Bb:9(11)', 0.5),
#  ('Ab:dim', 0.5),
#  ('G:maj/5', 0.5),
#  ('F:(1)', 0.5),
#  ('C:7/b7', 0.5),
#  ('F:7/b7', 0.5),
#  ('Bb:sus4', 0.5),
#  ('B:min7', 0.5),
#  ('G:min/b3', 0.5),
#  ('Eb:maj(13)', 0.5),
#  ('Db:7', 0.5),
#  ('Eb/4', 0.5),
#  ('Bb:maj7', 0.5),
#  ('C/7', 0.5),
#  ('Bb/5', 0.5),
#  ('C:7/3', 0.5),
#  ('F#:min', 0.5),
#  ('A:sus4', 0.4444444444444444),
#  ('Eb:dim', 0.4),
#  ('Eb:7/3', 0.3333333333333333),
#  ('Db/2', 0.3333333333333333),
#  ('A:7', 0.3333333333333333),
#  ('A', 0.3235294117647059),
#  ('C:min7', 0.3076923076923077),
#  ('B:maj', 0.2962962962962963),
#  ('Ab/5', 0.2894736842105263),
# ...

# %%
G1.nodes()
# Out:
# NodeView(('N', 'Bb:maj6', 'C:7', 'F:7', 'C:min7', 'Bb:maj', 'G:min', 'Bb:7', 'Eb:maj', 'C:min', 'B/3', 'Bb/3', 'A/3', 'C#:dim', 'F/5', 'F:maj', 'B:aug', 'Eb/5', 'F/3', 'F:min/b3', 'G:(1)', 'F:min', 'F:min/7', 'F:min/b7', 'F:min/6', 'Ab:min', 'Ab:maj', 'Eb:dim', 'F:min7', 'F:min/3', 'G:min/5', 'Db:maj', 'Db/7', 'Bb:min', 'A:maj', 'D/5', 'A:dim', 'Db/5', 'C/5', 'E:maj', 'Ab/5', 'Eb/3', 'F#:dim', 'B:maj', 'Gb:7', 'B:(5)', 'A', 'D:maj', 'Gb:maj', 'F#', 'Ab', 'B', 'Bb', 'G/3', 'G:7/3', 'Bb:9(11)', 'Bb:min/b3', 'C:7(b9)', 'Ab:dim', 'G:min7', 'E:min', 'A:min', 'C:maj', 'G:maj', 'G:maj/5', 'G', 'A:(1,5)', 'F#:(1,5)', 'E:(1,b7)', 'G:(1,5)', 'A:(1)', 'B:(1,5)', 'C', 'G:sus4', 'A:sus4', 'G:7', 'Bb:aug', 'G:dim', 'D:aug', 'D:min', 'C:(1)', 'F:(1)', 'D:(1)', 'C/3', 'Ab:7/5', 'F#:maj', 'F#:7', 'D:min7/b7', 'E/3', 'C:7/b7', 'F:min(6)', 'G:maj6', 'G/4', 'C:maj/3', 'A:min7', 'D:min7', 'D:7', 'F:7/b7', 'Bb:sus4', 'F', 'D/3', 'E:min7', 'B:min7', 'E:7', 'D/7', 'G:min/b3', 'D/b7', 'G:maj/3', 'D', 'Db:maj
# ...

# %%
indegree1 = list(G1.in_degree(['N', 'E', 'A', 'B', 'E:7/3', 'A:min/b3', 'E:9', 'F', 'G', 'C', 'A:min', 'D', 'B:min', 'E:min', 'D/2', 'D/3', 'E:7', 'G:min', 'Bb', 'Eb:7', 'F:9', 'Eb:9', 'Bb:7', 'Eb', 'Eb:min', 'E:maj7', 'F#:min7', 'G#:min7', 'B:7', 'G#', 'C#:min', 'F#:9', 'E:aug', 'A:maj7', 'A:maj7/5', 'B:maj6', 'G#:min', 'F#:min', 'C#:min/5', 'C#:7', 'C:min6', 'F#:minmaj7', 'F#', 'A:7', 'D:9']))
sorted(indegree1, key=lambda x: x[1], reverse=True)
# Out:
# [('N', 22),
#  ('A:min', 15),
#  ('C', 14),
#  ('G', 12),
#  ('Bb', 12),
#  ('D', 11),
#  ('Bb:7', 11),
#  ('E:min', 10),
#  ('G:min', 10),
#  ('Eb', 8),
#  ('F', 7),
#  ('Eb:7', 7),
#  ('A', 5),
#  ('D/3', 2),
#  ('F#:min7', 2),
#  ('A:7', 2),
#  ('B', 1),
#  ('E:7', 1),
#  ('F#:min', 1),
#  ('F#', 1)]

# %%
outdegree1 = list(G1.out_degree(['N', 'E', 'A', 'B', 'E:7/3', 'A:min/b3', 'E:9', 'F', 'G', 'C', 'A:min', 'D', 'B:min', 'E:min', 'D/2', 'D/3', 'E:7', 'G:min', 'Bb', 'Eb:7', 'F:9', 'Eb:9', 'Bb:7', 'Eb', 'Eb:min', 'E:maj7', 'F#:min7', 'G#:min7', 'B:7', 'G#', 'C#:min', 'F#:9', 'E:aug', 'A:maj7', 'A:maj7/5', 'B:maj6', 'G#:min', 'F#:min', 'C#:min/5', 'C#:7', 'C:min6', 'F#:minmaj7', 'F#', 'A:7', 'D:9']))
sorted(outdegree1, key=lambda x: x[1], reverse=True)
# Out:
# [('N', 19),
#  ('C', 19),
#  ('G:min', 16),
#  ('A:min', 15),
#  ('Bb', 12),
#  ('G', 10),
#  ('D', 9),
#  ('Eb', 9),
#  ('F', 8),
#  ('E:min', 6),
#  ('Eb:7', 6),
#  ('Bb:7', 6),
#  ('A', 4),
#  ('D/3', 2),
#  ('F#:min7', 2),
#  ('B', 1),
#  ('E:7', 1),
#  ('F#:min', 1),
#  ('F#', 1),
#  ('A:7', 1)]

# %%
from networkx.algorithms.community import greedy_modularity_communities
c = greedy_modularity_communities(G1)
sorted(c)
# Out:
# [frozenset({'A',
#             'A:7',
#             'A:7/3',
#             'A:min',
#             'A:min7',
#             'A:sus4',
#             'Bb',
#             'Bb:maj(9)',
#             'Bb:maj7',
#             'C',
#             'C/5',
#             'C/7',
#             'C/b7',
#             'D',
#             'D/3',
#             'D:min7',
#             'E/3',
#             'E:min',
#             'E:min/5',
#             'E:min7',
#             'E:min9',
#             'F#:min',
#             'F#:min7',
#             'F:min/3',
#             'F:min/b3',
#             'G',
#             'G/5',
#             'G:(1)',
#             'G:7'}),
#  frozenset({'Ab/7',
#             'Ab:(1)',
#             'Ab:7',
#             'Ab:7/5',
#             'Ab:maj',
#             'Ab:maj6',
#             'Bb/5',
#             'Bb:aug',
#             'Bb:dim',
#             'Bb:min',
#             'C/3',
#             'C:7/3',
#             'C:min/5',
#             'C:sus4(b7)',
# ...

# %% [markdown]
# ## Album07

# %%
album07 = pd.read_csv('C:\\Users\\Callu\\OneDrive\\Desktop\\Network Beatles Data\\album_07_edges.csv')
G1 = nx.from_pandas_edgelist(album07, source="Source", target="Target", create_using=nx.DiGraph())

# %%
import operator

print(nx.average_clustering(G1))
c1 = nx.clustering(G1)
sorted_tuples = sorted(c1.items(), key=operator.itemgetter(1), reverse=True)
sorted_tuples
# Out:
# 0.18858197292005963
# [('E:min/b7', 1.0),
#  ('C:min(*b3)', 1.0),
#  ('Ab', 1.0),
#  ('Ab:maj(9)', 1.0),
#  ('E:maj(b9)', 1.0),
#  ('Eb', 0.6),
#  ('G:7', 0.5),
#  ('Ab:min7', 0.5),
#  ('C#', 0.5),
#  ('G:aug', 0.5),
#  ('F:dim', 0.5),
#  ('E/5', 0.5),
#  ('A/5', 0.5),
#  ('D:sus4/5', 0.5),
#  ('F:maj(9)/9', 0.5),
#  ('F:7', 0.4),
#  ('B:maj7', 0.3333333333333333),
#  ('C:min', 0.3333333333333333),
#  ('A:7', 0.3333333333333333),
#  ('F#', 0.33064516129032256),
#  ('B/5', 0.25),
#  ('A:min7', 0.2),
#  ('E:7', 0.2),
#  ('F#:min', 0.17857142857142858),
#  ('Eb:7', 0.16666666666666666),
#  ('G:min', 0.16666666666666666),
#  ('D/5', 0.16666666666666666),
#  ('E', 0.16101694915254236),
#  ('A', 0.15037593984962405),
#  ('N', 0.1463963963963964),
#  ('B', 0.14227642276422764),
#  ('G', 0.1206896551724138),
#  ('D:7', 0.10396039603960396),
#  ('D', 0.1),
#  ('E:min', 0.07547169811320754),
#  ('Bb', 0.07),
#  ('G#:min', 0.06666666666666667),
#  ('C', 0.06521739130434782),
# ...

# %%
G1.nodes()
# Out:
# NodeView(('N', 'D:7', 'D:7(#9)', 'C', 'G:7', 'C:9', 'F:7', 'E:min', 'E:min/b7', 'E:min7', 'E:min6', 'C/3', 'F#:min7', 'Eb:min', 'Ab:min', 'Gb', 'B', 'Bb:7', 'Bb:min', 'B:maj7', 'Bb:min7', 'Db:min', 'Eb:7', 'E', 'Ab:min7', 'C:min(*b3)', 'Bb', 'G', 'B:min', 'A:sus4', 'A:min', 'D', 'A:min7', 'G/3', 'F#:min', 'B:7', 'F', 'G:min', 'C:min', 'F#', 'C#', 'D#:min', 'G#:min', 'Ab', 'Eb', 'Ab:maj(9)', 'F:min', 'E:7', 'A', 'F#:7', 'A:7', 'G:aug', 'B/5', 'F:dim', 'E/7', 'E/6', 'E/5', 'A/5', 'B/7', 'C#:min', 'G#:7', 'F#:sus4', 'D:sus4/5', 'D/5', 'E:maj(b9)', 'B:dim', 'F:maj(9)/9', 'B:min/7', 'B:min/b7', 'B:min/6', 'C/7', 'F:maj/9', 'C:sus4/4', 'G:sus4(2)', 'Bb:maj(9)/9', 'B:maj/9', 'Bb:maj/9'))

# %%
indegree1 = list(G1.in_degree(['N', 'D:7', 'D:7(#9)', 'C', 'G:7', 'C:9', 'F:7', 'E:min', 'E:min/b7', 'E:min7', 'E:min6', 'C/3', 'F#:min7', 'Eb:min', 'Ab:min', 'Gb', 'B', 'Bb:7', 'Bb:min', 'B:maj7', 'Bb:min7', 'Db:min', 'Eb:7', 'E', 'Ab:min7', 'C:min(*b3)', 'Bb', 'G', 'B:min', 'A:sus4', 'A:min', 'D', 'A:min7', 'G/3', 'F#:min', 'B:7', 'F', 'G:min', 'C:min', 'F#', 'C#', 'D#:min', 'G#:min', 'Ab', 'Eb', 'Ab:maj(9)', 'F:min', 'E:7', 'A', 'F#:7', 'A:7', 'G:aug', 'B/5', 'F:dim', 'E/7', 'E/6', 'E/5', 'A/5', 'B/7', 'C#:min', 'G#:7', 'F#:sus4', 'D:sus4/5', 'D/5', 'E:maj(b9)', 'B:dim', 'F:maj(9)/9', 'B:min/7', 'B:min/b7', 'B:min/6', 'C/7', 'F:maj/9', 'C:sus4/4', 'G:sus4(2)', 'Bb:maj(9)/9', 'B:maj/9', 'Bb:maj/9']))
sorted(indegree1, key=lambda x: x[1], reverse=True)
# Out:
# [('N', 13),
#  ('B', 12),
#  ('C', 11),
#  ('A', 10),
#  ('E', 9),
#  ('D:7', 8),
#  ('Bb', 8),
#  ('G', 8),
#  ('D', 7),
#  ('F#', 7),
#  ('E:min', 6),
#  ('Eb:min', 5),
#  ('Ab:min', 5),
#  ('B:min', 5),
#  ('C#', 4),
#  ('G#:min', 4),
#  ('C:min(*b3)', 3),
#  ('A:min', 3),
#  ('F#:min', 3),
#  ('B:7', 3),
#  ('Eb', 3),
#  ('C#:min', 3),
#  ('F:7', 2),
#  ('C/3', 2),
#  ('Gb', 2),
#  ('Eb:7', 2),
#  ('A:sus4', 2),
#  ('A:min7', 2),
#  ('G:min', 2),
#  ('E:7', 2),
#  ('A:7', 2),
#  ('B/5', 2),
#  ('E/5', 2),
#  ('D:7(#9)', 1),
#  ('G:7', 1),
#  ('C:9', 1),
#  ('E:min/b7', 1),
#  ('E:min7', 1),
#  ('E:min6', 1),
#  ('F#:min7', 1),
#  ('Bb:7', 1),
#  ('Bb:min', 1),
#  ('B:maj7', 1),
#  ('Bb:min7', 1),
#  ('Db:min', 1),
#  ('Ab:min7', 1),
#  ('G/3', 1),
#  ('F', 1),
#  ('C:min', 1),
#  ('D#:min', 1),
#  ('Ab', 1),
#  ('Ab:maj(9)', 1),
#  ('F:min', 1),
#  ('F#:7', 1),
#  ('G:aug', 1),
#  ('F:dim', 1),
#  ('E/7', 1),
#  ('E/6', 1),
#  ('A/5', 1),
#  ('B/7', 1),
#  ('G#:7', 1),
# ...

# %%
outdegree1 = list(G1.out_degree(['N', 'D:7', 'D:7(#9)', 'C', 'G:7', 'C:9', 'F:7', 'E:min', 'E:min/b7', 'E:min7', 'E:min6', 'C/3', 'F#:min7', 'Eb:min', 'Ab:min', 'Gb', 'B', 'Bb:7', 'Bb:min', 'B:maj7', 'Bb:min7', 'Db:min', 'Eb:7', 'E', 'Ab:min7', 'C:min(*b3)', 'Bb', 'G', 'B:min', 'A:sus4', 'A:min', 'D', 'A:min7', 'G/3', 'F#:min', 'B:7', 'F', 'G:min', 'C:min', 'F#', 'C#', 'D#:min', 'G#:min', 'Ab', 'Eb', 'Ab:maj(9)', 'F:min', 'E:7', 'A', 'F#:7', 'A:7', 'G:aug', 'B/5', 'F:dim', 'E/7', 'E/6', 'E/5', 'A/5', 'B/7', 'C#:min', 'G#:7', 'F#:sus4', 'D:sus4/5', 'D/5', 'E:maj(b9)', 'B:dim', 'F:maj(9)/9', 'B:min/7', 'B:min/b7', 'B:min/6', 'C/7', 'F:maj/9', 'C:sus4/4', 'G:sus4(2)', 'Bb:maj(9)/9', 'B:maj/9', 'Bb:maj/9']))
sorted(outdegree1, key=lambda x: x[1], reverse=True)
# Out:
# [('B', 13),
#  ('N', 11),
#  ('C', 11),
#  ('D:7', 9),
#  ('E', 9),
#  ('Bb', 9),
#  ('A', 9),
#  ('G', 8),
#  ('E:min', 7),
#  ('F#', 7),
#  ('Ab:min', 5),
#  ('Eb:min', 4),
#  ('D', 4),
#  ('G#:min', 4),
#  ('E:7', 4),
#  ('Gb', 3),
#  ('C:min(*b3)', 3),
#  ('B:min', 3),
#  ('A:min7', 3),
#  ('F#:min', 3),
#  ('B:7', 3),
#  ('C#', 3),
#  ('E/5', 3),
#  ('C#:min', 3),
#  ('F:7', 2),
#  ('C/3', 2),
#  ('B:maj7', 2),
#  ('A:sus4', 2),
#  ('A:min', 2),
#  ('C:min', 2),
#  ('Ab', 2),
#  ('A:7', 2),
#  ('B/5', 2),
#  ('D/5', 2),
#  ('F:maj(9)/9', 2),
#  ('B:min/6', 2),
#  ('D:7(#9)', 1),
#  ('G:7', 1),
#  ('C:9', 1),
#  ('E:min/b7', 1),
#  ('E:min7', 1),
#  ('E:min6', 1),
#  ('F#:min7', 1),
#  ('Bb:7', 1),
#  ('Bb:min', 1),
#  ('Bb:min7', 1),
#  ('Db:min', 1),
#  ('Eb:7', 1),
#  ('Ab:min7', 1),
#  ('G/3', 1),
#  ('F', 1),
#  ('G:min', 1),
#  ('D#:min', 1),
#  ('Eb', 1),
#  ('Ab:maj(9)', 1),
#  ('F:min', 1),
#  ('F#:7', 1),
#  ('G:aug', 1),
#  ('F:dim', 1),
#  ('E/7', 1),
#  ('E/6', 1),
# ...

# %%
from networkx.algorithms.community import greedy_modularity_communities
c = greedy_modularity_communities(G1)
sorted(c)
# Out:
# [frozenset({'A',
#             'A:7',
#             'A:sus4',
#             'B',
#             'B/5',
#             'B/7',
#             'C#',
#             'D#:min',
#             'D/5',
#             'D:sus4/5',
#             'E',
#             'E/5',
#             'E/6',
#             'E/7',
#             'E:7',
#             'E:maj(b9)',
#             'F#',
#             'F:dim',
#             'G#:min',
#             'G:aug'}),
#  frozenset({'A:min',
#             'A:min7',
#             'B:7',
#             'B:maj/9',
#             'Bb:maj(9)/9',
#             'Bb:maj/9',
#             'C',
#             'C/7',
#             'D',
#             'E:min',
#             'E:min/b7',
#             'F#:7',
#             'F#:min',
#             'F#:min7',
#             'G/3'}),
#  frozenset({'B:dim',
#             'B:min',
#             'B:min/6',
#             'B:min/7',
#             'B:min/b7',
#             'C/3',
#             'C:sus4/4',
#             'E:min6',
# ...

# %% [markdown]
# ## Album08

# %%
album08 = pd.read_csv('C:\\Users\\Callu\\OneDrive\\Desktop\\Network Beatles Data\\album_08_edges.csv')
G1 = nx.from_pandas_edgelist(album08, source="Source", target="Target", create_using=nx.DiGraph())

# %%
import operator

print(nx.average_clustering(G1))
c1 = nx.clustering(G1)
sorted_tuples = sorted(c1.items(), key=operator.itemgetter(1), reverse=True)
sorted_tuples
# Out:
# 0.22834706509761438
# [('Bb:maj6', 1.0),
#  ('C/4', 1.0),
#  ('F#:min/b3', 1.0),
#  ('G:min', 1.0),
#  ('C#:sus4', 1.0),
#  ('Ab:7', 1.0),
#  ('E/5', 1.0),
#  ('C:maj(2)', 1.0),
#  ('F:maj(9)/5', 0.6),
#  ('D:min/b7', 0.5),
#  ('F:maj6', 0.5),
#  ('D:min7(4)/5', 0.5),
#  ('F:maj(9)/6', 0.5),
#  ('G:(1)', 0.5),
#  ('B:min/b3', 0.5),
#  ('F#:maj(9)', 0.5),
#  ('C:min', 0.5),
#  ('D:min7/b7', 0.5),
#  ('G:min/b3', 0.5),
#  ('F#/5', 0.5),
#  ('Db:7', 0.5),
#  ('A/9', 0.5),
#  ('A:min/5', 0.5),
#  ('F#:hdim7', 0.5),
#  ('D', 0.4878048780487805),
#  ('E:(1)', 0.4444444444444444),
#  ('F#', 0.4),
#  ('A:aug', 0.4),
#  ('F:aug', 0.3333333333333333),
#  ('C:maj(9)', 0.3333333333333333),
#  ('G/3', 0.3333333333333333),
#  ('C/5', 0.325),
#  ('Bb:min', 0.3076923076923077),
#  ('F:maj(9)', 0.3),
#  ('G:aug', 0.3),
#  ('C:7', 0.2777777777777778),
#  ('C#:min/5', 0.25),
#  ('A:min/b3', 0.25),
#  ('E:min7/b7', 0.25),
#  ('A/5', 0.225),
#  ('E:min', 0.2159090909090909),
# ...

# %%
G1.nodes()
# Out:
# NodeView(('N', 'A:7', 'C:7', 'G', 'D', 'G:7', 'C', 'F', 'Bb:maj6', 'A', 'C:sus4', 'C/9', 'F:7', 'E', 'B/3', 'F#:min/5', 'F#:min', 'B', 'C#:min', 'F#', 'C/5', 'D:9/5', 'A/5', 'A:7/b7', 'F#:min7', 'D:min/b3', 'F:aug', 'D:min', 'D:min/b7', 'Bb', 'C:maj(9)', 'F:maj6', 'D:maj(*3)', 'F:maj(9)/5', 'D:min7(4)/5', 'E:min7', 'F:maj(9)/6', 'F:maj(9)', 'D:min7(4)/b7', 'C/3', 'C/4', 'E:min7/b3', 'F/3', 'G/3', 'G:(1)', 'C:aug', 'F:min7', 'Bb:7', 'F:min6/5', 'F:min6', 'C:9(*3)', 'F:min6/b3', 'F:min7/b3', 'B:min', 'A/3', 'C#:min/5', 'A:maj/9', 'B:min/b3', 'F#:9', 'F#:min/b3', 'F#:maj(9)', 'C:min', 'G:aug', 'D:min7/b7', 'G:min/b3', 'G:min', 'A:aug/#5', 'E:min', 'A:aug', 'E:min/b3', 'A:min/b3', 'E:min7/b7', 'C#', 'F#/5', 'C#:sus4', 'Db', 'Gb', 'Ab', 'Db:7', 'E:dim7/b3', 'Db/5', 'Eb:9', 'Bb:min', 'Eb:min', 'Ab:7', 'A/9', 'E/5', 'A:(1,2,4)', 'A:min7(*b3)', 'D:min7(*b3)', 'A:(1)', 'A:min', 'E:(1)', 'C:maj(2)', 'B:min/5', 'E:min/5', 'A:min/5', 'F#:(1,4,b7)', 'A:min(2)', 'E:min(*b3)/5', 'C#:maj7(*5)', 'E:m
# ...

# %%
indegree1 = list(G1.in_degree(['N', 'A:7', 'C:7', 'G', 'D', 'G:7', 'C', 'F', 'Bb:maj6', 'A', 'C:sus4', 'C/9', 'F:7', 'E', 'B/3', 'F#:min/5', 'F#:min', 'B', 'C#:min', 'F#', 'C/5', 'D:9/5', 'A/5', 'A:7/b7', 'F#:min7', 'D:min/b3', 'F:aug', 'D:min', 'D:min/b7', 'Bb', 'C:maj(9)', 'F:maj6', 'D:maj(*3)', 'F:maj(9)/5', 'D:min7(4)/5', 'E:min7', 'F:maj(9)/6', 'F:maj(9)', 'D:min7(4)/b7', 'C/3', 'C/4', 'E:min7/b3', 'F/3', 'G/3', 'G:(1)', 'C:aug', 'F:min7', 'Bb:7', 'F:min6/5', 'F:min6', 'C:9(*3)', 'F:min6/b3', 'F:min7/b3', 'B:min', 'A/3', 'C#:min/5', 'A:maj/9', 'B:min/b3', 'F#:9', 'F#:min/b3', 'F#:maj(9)', 'C:min', 'G:aug', 'D:min7/b7', 'G:min/b3', 'G:min', 'A:aug/#5', 'E:min', 'A:aug', 'E:min/b3', 'A:min/b3', 'E:min7/b7', 'C#', 'F#/5', 'C#:sus4', 'Db', 'Gb', 'Ab', 'Db:7', 'E:dim7/b3', 'Db/5', 'Eb:9', 'Bb:min', 'Eb:min', 'Ab:7', 'A/9', 'E/5', 'A:(1,2,4)', 'A:min7(*b3)', 'D:min7(*b3)', 'A:(1)', 'A:min', 'E:(1)', 'C:maj(2)', 'B:min/5', 'E:min/5', 'A:min/5', 'F#:(1,4,b7)', 'A:min(2)', 'E:min(*b3)/5', 'C#:maj7(*5)', 'E:min(*5)/b7', 'E:min(*5)', 'D:(1)', 'C:(1)', 'F#:hdim7', 'F#:(1,4,b5)', 'C:maj7(*5)', 'E:min7(*5)/b7', 'E:(1,2,5,b6)']))
sorted(indegree1, key=lambda x: x[1], reverse=True)
# Out:
# [('C', 20),
#  ('G', 19),
#  ('A', 18),
#  ('F', 14),
#  ('N', 12),
#  ('E', 11),
#  ('B', 10),
#  ('C#:min', 8),
#  ('Bb', 8),
#  ('F#:min', 7),
#  ('Ab', 6),
#  ('D', 5),
#  ('D:min', 5),
#  ('E:min', 5),
#  ('A/5', 4),
#  ('E:min7', 4),
#  ('A:min/b3', 4),
#  ('C#', 4),
#  ('Db', 4),
#  ('Gb', 4),
#  ('Bb:min', 4),
#  ('A:7', 3),
#  ('G:7', 3),
#  ('C/5', 3),
#  ('F:min7', 3),
#  ('A:maj/9', 3),
#  ('E:min/b3', 3),
#  ('E:min7/b7', 3),
#  ('C:7', 2),
#  ('F#:min/5', 2),
#  ('F#', 2),
#  ('A:7/b7', 2),
#  ('F:maj(9)/5', 2),
#  ('F:maj(9)', 2),
#  ('E:min7/b3', 2),
#  ('G/3', 2),
#  ('G:(1)', 2),
#  ('Bb:7', 2),
#  ('F:min6/b3', 2),
#  ('B:min', 2),
#  ('C#:min/5', 2),
#  ('C:min', 2),
#  ('G:aug', 2),
#  ('G:min/b3', 2),
#  ('A:aug', 2),
#  ('A:min', 2),
#  ('E:(1)', 2),
#  ('E:min(*5)', 2),
#  ('D:(1)', 2),
#  ('Bb:maj6', 1),
#  ('C:sus4', 1),
#  ('C/9', 1),
#  ('F:7', 1),
#  ('B/3', 1),
#  ('D:9/5', 1),
#  ('F#:min7', 1),
#  ('D:min/b3', 1),
#  ('F:aug', 1),
#  ('D:min/b7', 1),
# ...

# %%
outdegree1 = list(G1.out_degree(['N', 'A:7', 'C:7', 'G', 'D', 'G:7', 'C', 'F', 'Bb:maj6', 'A', 'C:sus4', 'C/9', 'F:7', 'E', 'B/3', 'F#:min/5', 'F#:min', 'B', 'C#:min', 'F#', 'C/5', 'D:9/5', 'A/5', 'A:7/b7', 'F#:min7', 'D:min/b3', 'F:aug', 'D:min', 'D:min/b7', 'Bb', 'C:maj(9)', 'F:maj6', 'D:maj(*3)', 'F:maj(9)/5', 'D:min7(4)/5', 'E:min7', 'F:maj(9)/6', 'F:maj(9)', 'D:min7(4)/b7', 'C/3', 'C/4', 'E:min7/b3', 'F/3', 'G/3', 'G:(1)', 'C:aug', 'F:min7', 'Bb:7', 'F:min6/5', 'F:min6', 'C:9(*3)', 'F:min6/b3', 'F:min7/b3', 'B:min', 'A/3', 'C#:min/5', 'A:maj/9', 'B:min/b3', 'F#:9', 'F#:min/b3', 'F#:maj(9)', 'C:min', 'G:aug', 'D:min7/b7', 'G:min/b3', 'G:min', 'A:aug/#5', 'E:min', 'A:aug', 'E:min/b3', 'A:min/b3', 'E:min7/b7', 'C#', 'F#/5', 'C#:sus4', 'Db', 'Gb', 'Ab', 'Db:7', 'E:dim7/b3', 'Db/5', 'Eb:9', 'Bb:min', 'Eb:min', 'Ab:7', 'A/9', 'E/5', 'A:(1,2,4)', 'A:min7(*b3)', 'D:min7(*b3)', 'A:(1)', 'A:min', 'E:(1)', 'C:maj(2)', 'B:min/5', 'E:min/5', 'A:min/5', 'F#:(1,4,b7)', 'A:min(2)', 'E:min(*b3)/5', 'C#:maj7(*5)', 'E:min(*5)/b7', 'E:min(*5)', 'D:(1)', 'C:(1)', 'F#:hdim7', 'F#:(1,4,b5)', 'C:maj7(*5)', 'E:min7(*5)/b7', 'E:(1,2,5,b6)']))
sorted(outdegree1, key=lambda x: x[1], reverse=True)
# Out:
# [('C', 15),
#  ('F', 15),
#  ('G', 14),
#  ('A', 14),
#  ('N', 13),
#  ('E', 10),
#  ('B', 10),
#  ('E:min', 9),
#  ('F#:min', 8),
#  ('D:min', 8),
#  ('D', 7),
#  ('Db', 6),
#  ('Bb', 5),
#  ('F:min7', 5),
#  ('Ab', 5),
#  ('C#:min', 4),
#  ('F#', 4),
#  ('C/5', 4),
#  ('F#:min7', 4),
#  ('E:min7', 4),
#  ('Bb:min', 4),
#  ('A:min', 4),
#  ('C:7', 3),
#  ('A/5', 3),
#  ('F:maj(9)', 3),
#  ('B:min', 3),
#  ('F#:9', 3),
#  ('C#', 3),
#  ('Gb', 3),
#  ('E:(1)', 3),
#  ('A:7', 2),
#  ('G:7', 2),
#  ('F#:min/5', 2),
#  ('A:7/b7', 2),
#  ('F:aug', 2),
#  ('C:maj(9)', 2),
#  ('F:maj(9)/5', 2),
#  ('D:min7(4)/b7', 2),
#  ('E:min7/b3', 2),
#  ('Bb:7', 2),
#  ('F:min6', 2),
#  ('F:min6/b3', 2),
#  ('C#:min/5', 2),
#  ('B:min/b3', 2),
#  ('G:aug', 2),
#  ('A:aug', 2),
#  ('E:min/b3', 2),
#  ('E:min7/b7', 2),
#  ('F#/5', 2),
#  ('A/9', 2),
#  ('B:min/5', 2),
#  ('E:min(*b3)/5', 2),
#  ('E:min(*5)', 2),
#  ('D:(1)', 2),
#  ('Bb:maj6', 1),
#  ('C:sus4', 1),
#  ('C/9', 1),
#  ('F:7', 1),
# ...

# %%
from networkx.algorithms.community import greedy_modularity_communities
c = greedy_modularity_communities(G1)
sorted(c)
# Out:
# [frozenset({'A:(1)',
#             'A:(1,2,4)',
#             'A:min(2)',
#             'A:min7(*b3)',
#             'C#',
#             'C#:maj7(*5)',
#             'C#:sus4',
#             'C:maj7(*5)',
#             'D:min7(*b3)',
#             'E:(1,2,5,b6)',
#             'E:min(*5)',
#             'E:min(*5)/b7',
#             'E:min(*b3)/5',
#             'E:min7(*5)/b7',
#             'F#/5',
#             'G:(1)',
#             'N'}),
#  frozenset({'A:7',
#             'A:min',
#             'A:min/5',
#             'Bb:maj6',
#             'C/5',
#             'C/9',
#             'C:7',
#             'C:min',
#             'C:sus4',
#             'D',
#             'D:9/5',
#             'D:maj(*3)',
#             'E:min/5',
#             'F#:hdim7',
#             'G',
#             'G:7',
#             'G:aug'}),
#  frozenset({'A',
#             'A/3',
#             'A/5',
#             'A:7/b7',
#             'A:aug',
#             'A:aug/#5',
#             'C:(1)',
# ...

# %% [markdown]
# ## Album10CD1

# %%
album10 = pd.read_csv('C:\\Users\\Callu\\OneDrive\\Desktop\\Network Beatles Data\\album_10_edges.csv')
G1 = nx.from_pandas_edgelist(album10, source="Source", target="Target", create_using=nx.DiGraph())

# %%
import operator

print(nx.average_clustering(G1))
c1 = nx.clustering(G1)
sorted_tuples = sorted(c1.items(), key=operator.itemgetter(1), reverse=True)
sorted_tuples
# Out:
# 0.18623135591361348
# [('D#', 1.0),
#  ('Bb:sus2(b7)', 1.0),
#  ('E:min(2)', 1.0),
#  ('C:(1)', 1.0),
#  ('E:aug', 1.0),
#  ('C#:dim', 1.0),
#  ('C:min', 1.0),
#  ('C:sus4', 1.0),
#  ('G#', 0.6666666666666666),
#  ('F:min', 0.6515151515151515),
#  ('C#:min', 0.6153846153846154),
#  ('G/5', 0.5),
#  ('A/4', 0.5),
#  ('E:(1)', 0.5),
#  ('C:7/3', 0.5),
#  ('D:sus4', 0.5),
#  ('C/7', 0.5),
#  ('D:maj7', 0.5),
#  ('Db', 0.4166666666666667),
#  ('A/3', 0.4),
#  ('E', 0.35135135135135137),
#  ('G:7', 0.3382352941176471),
#  ('D:min7', 0.3333333333333333),
#  ('Ab', 0.32142857142857145),
#  ('G', 0.3150684931506849),
#  ('F:7', 0.30158730158730157),
#  ('G:min', 0.2962962962962963),
#  ('A:min', 0.28761061946902655),
#  ('F#:min', 0.27884615384615385),
#  ('A', 0.26720647773279355),
#  ('N', 0.25726744186046513),
#  ('D:7', 0.25),
#  ('C/3', 0.25),
#  ('D:min', 0.22672064777327935),
#  ('G:min7', 0.2265625),
#  ('G/3', 0.225),
#  ('G:9', 0.2222222222222222),
#  ('F', 0.19811320754716982),
# ...

# %%
G1.nodes()
# Out:
# NodeView(('N', 'E', 'E:7', 'A', 'D', 'C', 'D#', 'A/2', 'A/b3', 'A/3', 'B', 'C/9', 'G/5', 'A/4', 'D/5', 'D/b7', 'G:maj7/3', 'G:minmaj7/b3', 'D:7', 'G:minmaj7/5', 'G', 'F', 'G#', 'D:sus4(9)', 'A:min', 'F:7', 'G:min7', 'F/3', 'F#:dim/b3', 'A:min7', 'F:7(b9)', 'B:dim7/b9', 'Bb:dim7/5', 'C:dim7', 'C:dim7/2', 'Bb:dim7/7', 'D:dim7', 'A:dim7', 'A:min/5', 'A:dim/b5', 'D:(1)', 'Bb', 'Eb', 'G:min', 'Bb:sus4(9)', 'Bb:sus2(b7)', 'Bb/5', 'F/b7', 'F/6', 'F/5', 'G:7', 'Eb:7', 'E:min(2)', 'F:min', 'D:min', 'E/b7', 'E/b6', 'E/5', 'A:min/b7', 'A:min/6', 'C#:min', 'F#:min', 'B:min', 'E/2', 'E/3', 'E/4', 'E:(1)', 'A:min6', 'E:min(9)', 'E:min', 'A:7', 'C:7', 'C:(1)', 'G:min/5', 'G:min/b7', 'C/3', 'C:7/3', 'Ab:maj9', 'Bb:7', 'Ab:maj7', 'D:min7', 'F:maj6', 'G:min/4', 'G:9', 'Bb:maj7', 'E:aug', 'G/3', 'C#:dim', 'D#:dim', 'Eb:aug', 'C:min', 'D:sus4(b7)', 'G:dim/b3', 'Ab', 'F:dim', 'F#:dim', 'G:dim', 'Bb:min', 'Db', 'Ab:min', 'D:sus4', 'C/7', 'C/5', 'C:sus4', 'C:maj(4)', 'Bb:min/b3', 'B:min7', 'A:min9', 'F#:mi
# ...

# %%
indegree1 = list(G1.in_degree(['N', 'E', 'E:7', 'A', 'D', 'C', 'D#', 'A/2', 'A/b3', 'A/3', 'B', 'C/9', 'G/5', 'A/4', 'D/5', 'D/b7', 'G:maj7/3', 'G:minmaj7/b3', 'D:7', 'G:minmaj7/5', 'G', 'F', 'G#', 'D:sus4(9)', 'A:min', 'F:7', 'G:min7', 'F/3', 'F#:dim/b3', 'A:min7', 'F:7(b9)', 'B:dim7/b9', 'Bb:dim7/5', 'C:dim7', 'C:dim7/2', 'Bb:dim7/7', 'D:dim7', 'A:dim7', 'A:min/5', 'A:dim/b5', 'D:(1)', 'Bb', 'Eb', 'G:min', 'Bb:sus4(9)', 'Bb:sus2(b7)', 'Bb/5', 'F/b7', 'F/6', 'F/5', 'G:7', 'Eb:7', 'E:min(2)', 'F:min', 'D:min', 'E/b7', 'E/b6', 'E/5', 'A:min/b7', 'A:min/6', 'C#:min', 'F#:min', 'B:min', 'E/2', 'E/3', 'E/4', 'E:(1)', 'A:min6', 'E:min(9)', 'E:min', 'A:7', 'C:7', 'C:(1)', 'G:min/5', 'G:min/b7', 'C/3', 'C:7/3', 'Ab:maj9', 'Bb:7', 'Ab:maj7', 'D:min7', 'F:maj6', 'G:min/4', 'G:9', 'Bb:maj7', 'E:aug', 'G/3', 'C#:dim', 'D#:dim', 'Eb:aug', 'C:min', 'D:sus4(b7)', 'G:dim/b3', 'Ab', 'F:dim', 'F#:dim', 'G:dim', 'Bb:min', 'Db', 'Ab:min', 'D:sus4', 'C/7', 'C/5', 'C:sus4', 'C:maj(4)', 'Bb:min/b3', 'B:min7', 'A:min9', 'F#:min7', 'F#:min6', 'D/3', 'D:maj7']))
sorted(indegree1, key=lambda x: x[1], reverse=True)
# Out:
# [('C', 25),
#  ('D', 18),
#  ('N', 15),
#  ('G', 14),
#  ('F', 14),
#  ('A', 12),
#  ('D:min', 12),
#  ('A:min', 11),
#  ('Bb', 10),
#  ('E', 9),
#  ('A:min7', 9),
#  ('Eb', 9),
#  ('D:7', 7),
#  ('F:7', 6),
#  ('G:min7', 6),
#  ('G:7', 6),
#  ('F#:min', 6),
#  ('F:min', 5),
#  ('G:min', 4),
#  ('Ab', 4),
#  ('D/5', 3),
#  ('C#:min', 3),
#  ('A:7', 3),
#  ('G/3', 3),
#  ('E:7', 2),
#  ('A/3', 2),
#  ('B', 2),
#  ('C/9', 2),
#  ('D/b7', 2),
#  ('G:maj7/3', 2),
#  ('G#', 2),
#  ('F:7(b9)', 2),
#  ('B:dim7/b9', 2),
#  ('F/5', 2),
#  ('E:min', 2),
#  ('C:7', 2),
#  ('C/3', 2),
#  ('Bb:7', 2),
#  ('D:min7', 2),
#  ('G:min/4', 2),
#  ('G:9', 2),
#  ('C#:dim', 2),
#  ('D:sus4(b7)', 2),
#  ('Bb:min', 2),
#  ('B:min7', 2),
#  ('D#', 1),
#  ('A/2', 1),
#  ('A/b3', 1),
#  ('G/5', 1),
#  ('A/4', 1),
#  ('G:minmaj7/b3', 1),
#  ('G:minmaj7/5', 1),
#  ('D:sus4(9)', 1),
#  ('F/3', 1),
#  ('F#:dim/b3', 1),
#  ('Bb:dim7/5', 1),
#  ('C:dim7', 1),
#  ('C:dim7/2', 1),
#  ('Bb:dim7/7', 1),
# ...

# %%
outdegree1 = list(G1.out_degree(['N', 'E', 'E:7', 'A', 'D', 'C', 'D#', 'A/2', 'A/b3', 'A/3', 'B', 'C/9', 'G/5', 'A/4', 'D/5', 'D/b7', 'G:maj7/3', 'G:minmaj7/b3', 'D:7', 'G:minmaj7/5', 'G', 'F', 'G#', 'D:sus4(9)', 'A:min', 'F:7', 'G:min7', 'F/3', 'F#:dim/b3', 'A:min7', 'F:7(b9)', 'B:dim7/b9', 'Bb:dim7/5', 'C:dim7', 'C:dim7/2', 'Bb:dim7/7', 'D:dim7', 'A:dim7', 'A:min/5', 'A:dim/b5', 'D:(1)', 'Bb', 'Eb', 'G:min', 'Bb:sus4(9)', 'Bb:sus2(b7)', 'Bb/5', 'F/b7', 'F/6', 'F/5', 'G:7', 'Eb:7', 'E:min(2)', 'F:min', 'D:min', 'E/b7', 'E/b6', 'E/5', 'A:min/b7', 'A:min/6', 'C#:min', 'F#:min', 'B:min', 'E/2', 'E/3', 'E/4', 'E:(1)', 'A:min6', 'E:min(9)', 'E:min', 'A:7', 'C:7', 'C:(1)', 'G:min/5', 'G:min/b7', 'C/3', 'C:7/3', 'Ab:maj9', 'Bb:7', 'Ab:maj7', 'D:min7', 'F:maj6', 'G:min/4', 'G:9', 'Bb:maj7', 'E:aug', 'G/3', 'C#:dim', 'D#:dim', 'Eb:aug', 'C:min', 'D:sus4(b7)', 'G:dim/b3', 'Ab', 'F:dim', 'F#:dim', 'G:dim', 'Bb:min', 'Db', 'Ab:min', 'D:sus4', 'C/7', 'C/5', 'C:sus4', 'C:maj(4)', 'Bb:min/b3', 'B:min7', 'A:min9', 'F#:min7', 'F#:min6', 'D/3', 'D:maj7']))
sorted(outdegree1, key=lambda x: x[1], reverse=True)
# Out:
# [('C', 23),
#  ('D', 18),
#  ('N', 14),
#  ('A', 13),
#  ('G', 13),
#  ('F', 12),
#  ('A:min', 11),
#  ('Bb', 11),
#  ('Eb', 11),
#  ('D:min', 11),
#  ('E', 9),
#  ('A:min7', 8),
#  ('D:7', 7),
#  ('F:7', 6),
#  ('G:min7', 6),
#  ('G:7', 5),
#  ('F#:min', 5),
#  ('G:min', 4),
#  ('F:min', 4),
#  ('Bb:7', 4),
#  ('G/3', 4),
#  ('B:min7', 4),
#  ('B', 3),
#  ('C/9', 3),
#  ('C#:min', 3),
#  ('E:min', 3),
#  ('G:9', 3),
#  ('Db', 3),
#  ('E:7', 2),
#  ('A/3', 2),
#  ('D/5', 2),
#  ('D/b7', 2),
#  ('G:maj7/3', 2),
#  ('G:minmaj7/b3', 2),
#  ('G#', 2),
#  ('Bb:dim7/5', 2),
#  ('C:dim7/2', 2),
#  ('F/5', 2),
#  ('E/4', 2),
#  ('E:(1)', 2),
#  ('A:7', 2),
#  ('C:7', 2),
#  ('C/3', 2),
#  ('D:min7', 2),
#  ('C#:dim', 2),
#  ('Ab', 2),
#  ('D#', 1),
#  ('A/2', 1),
#  ('A/b3', 1),
#  ('G/5', 1),
#  ('A/4', 1),
#  ('G:minmaj7/5', 1),
#  ('D:sus4(9)', 1),
#  ('F/3', 1),
#  ('F#:dim/b3', 1),
#  ('F:7(b9)', 1),
#  ('B:dim7/b9', 1),
#  ('C:dim7', 1),
#  ('Bb:dim7/7', 1),
#  ('D:dim7', 1),
# ...

# %%
from networkx.algorithms.community import greedy_modularity_communities
c = greedy_modularity_communities(G1)
sorted(c)
# Out:
# [frozenset({'A:dim/b5',
#             'A:min/5',
#             'Ab',
#             'Ab:min',
#             'Bb',
#             'Bb/5',
#             'Bb:sus2(b7)',
#             'Bb:sus4(9)',
#             'C/3',
#             'C:7/3',
#             'D:(1)',
#             'Db',
#             'E:(1)',
#             'Eb',
#             'F',
#             'F#:dim',
#             'F:dim',
#             'F:min',
#             'G:dim',
#             'G:min',
#             'G:min/5',
#             'G:min/b7',
#             'N'}),
#  frozenset({'A',
#             'A/2',
#             'A/3',
#             'A/4',
#             'A/b3',
#             'B:min',
#             'C#:min',
#             'C/9',
#             'D',
#             'D#',
#             'D:maj7',
#             'D:sus4(9)',
#             'E',
#             'E/2',
#             'E/3',
#             'E/4',
#             'E:7',
#             'E:aug',
#             'F#:min',
#             'G#',
#             'G/5'}),
# ...

# %% [markdown]
# ## Album10CD2

# %%
album102 = pd.read_csv('C:\\Users\\Callu\\OneDrive\\Desktop\\Network Beatles Data\\album_10_2_edges.csv')
G1 = nx.from_pandas_edgelist(album102, source="Source", target="Target", create_using=nx.DiGraph())

# %%
import operator

print(nx.average_clustering(G1))
c1 = nx.clustering(G1)
sorted_tuples = sorted(c1.items(), key=operator.itemgetter(1), reverse=True)
sorted_tuples
# Out:
# 0.28541033119441517
# [('E/3', 1.0),
#  ('D:maj(9)', 1.0),
#  ('F/6', 1.0),
#  ('D:sus4(2)', 1.0),
#  ('Ab', 1.0),
#  ('A:9', 1.0),
#  ('E:sus4(2)', 1.0),
#  ('E:min/3', 1.0),
#  ('E:min6', 1.0),
#  ('A:(1)', 1.0),
#  ('D:min', 0.9166666666666666),
#  ('Eb', 0.7142857142857143),
#  ('F#', 0.6346153846153846),
#  ('C:maj7', 0.6111111111111112),
#  ('C#:min', 0.6),
#  ('B:maj7', 0.6),
#  ('E:9', 0.55),
#  ('B', 0.5232558139534884),
#  ('G:(1)', 0.5),
#  ('G:maj6', 0.5),
#  ('D:maj6', 0.5),
#  ('E:(1)', 0.5),
#  ('C:9(*3)', 0.5),
#  ('G:min(4)', 0.5),
#  ('F:min', 0.5),
#  ('D:(1)', 0.5),
#  ('D:(1,5)', 0.5),
#  ('A:7', 0.48),
#  ('D/5', 0.4642857142857143),
#  ('E:7', 0.46153846153846156),
#  ('B:min7', 0.4166666666666667),
#  ('Bb', 0.4117647058823529),
#  ('D/3', 0.35),
#  ('G:min/5', 0.3333333333333333),
#  ('C:7', 0.3333333333333333),
#  ('A:min', 0.2923076923076923),
#  ('F', 0.288135593220339),
#  ('E/5', 0.26666666666666666),
#  ('E:min', 0.25),
#  ('E', 0.21756756756756757),
# ...

# %%
G1.nodes()
# Out:
# NodeView(('N', 'A:7', 'D:7', 'E:7', 'E', 'C', 'G:7', 'G:7/b2', 'G:7/2', 'G:7/b3', 'E/5', 'A', 'G:(1)', 'C/5', 'G', 'B', 'E/3', 'B:7', 'B:min', 'D/5', 'G#:hdim7', 'E:9', 'D', 'D:sus4', 'D:maj(9)', 'G/5', 'F/6', 'D:sus4(2)', 'D:maj7', 'G:min/5', 'A/3', 'A:maj(*5)', 'G:maj6', 'D:maj6', 'E:(1)', 'F#', 'F', 'B:min7', 'A:min', 'Ab', 'E:(1,5)', 'E:(1,b7)/b7', 'C#:(1,b3)', 'C#:(1,b3)/b3', 'C/3', 'G:min', 'G:(1,b3,4)/b3', 'Bb', 'C:9(*3)', 'C:7', 'G:min(4)', 'C:(1)', 'C:(1,5)', 'C:sus4', 'E:sus2(b7)', 'E:maj6', 'E:min', 'A:min/4', 'C:min', 'A:9', 'Eb', 'F#/5', 'F/5', 'E:min/5', 'A:7/3', 'G/3', 'F#:dim/b3', 'B:dim', 'D/2', 'D/3', 'C#:dim/b3', 'C:maj7', 'A:sus4(2)', 'E:sus4(2)', 'Eb:aug', 'C#:hdim7', 'F:min', 'E:min/3', 'C#', 'C#:min', 'E:min6', 'Ab:min', 'D:min', 'A:(1)', 'F#:min/5', 'D:(1)', 'D:(1,5)', 'F#:min', 'B:maj7', 'G:maj7', 'A:min7', 'C:maj(#4)/5'))

# %%
indegree1 = list(G1.in_degree(['N', 'A:7', 'D:7', 'E:7', 'E', 'C', 'G:7', 'G:7/b2', 'G:7/2', 'G:7/b3', 'E/5', 'A', 'G:(1)', 'C/5', 'G', 'B', 'E/3', 'B:7', 'B:min', 'D/5', 'G#:hdim7', 'E:9', 'D', 'D:sus4', 'D:maj(9)', 'G/5', 'F/6', 'D:sus4(2)', 'D:maj7', 'G:min/5', 'A/3', 'A:maj(*5)', 'G:maj6', 'D:maj6', 'E:(1)', 'F#', 'F', 'B:min7', 'A:min', 'Ab', 'E:(1,5)', 'E:(1,b7)/b7', 'C#:(1,b3)', 'C#:(1,b3)/b3', 'C/3', 'G:min', 'G:(1,b3,4)/b3', 'Bb', 'C:9(*3)', 'C:7', 'G:min(4)', 'C:(1)', 'C:(1,5)', 'C:sus4', 'E:sus2(b7)', 'E:maj6', 'E:min', 'A:min/4', 'C:min', 'A:9', 'Eb', 'F#/5', 'F/5', 'E:min/5', 'A:7/3', 'G/3', 'F#:dim/b3', 'B:dim', 'D/2', 'D/3', 'C#:dim/b3', 'C:maj7', 'A:sus4(2)', 'E:sus4(2)', 'Eb:aug', 'C#:hdim7', 'F:min', 'E:min/3', 'C#', 'C#:min', 'E:min6', 'Ab:min', 'D:min', 'A:(1)', 'F#:min/5', 'D:(1)', 'D:(1,5)', 'F#:min', 'B:maj7', 'G:maj7', 'A:min7', 'C:maj(#4)/5']))
sorted(indegree1, key=lambda x: x[1], reverse=True)
# Out:
# [('N', 23),
#  ('C', 18),
#  ('G', 17),
#  ('A', 16),
#  ('D', 16),
#  ('E', 15),
#  ('B:min', 15),
#  ('F', 10),
#  ('E:min', 7),
#  ('B', 6),
#  ('A:7', 5),
#  ('C/5', 5),
#  ('G/5', 5),
#  ('G:min', 5),
#  ('Bb', 5),
#  ('G:maj7', 5),
#  ('E:7', 4),
#  ('A:min', 4),
#  ('D:7', 3),
#  ('E/5', 3),
#  ('F#', 3),
#  ('C/3', 3),
#  ('Eb', 3),
#  ('G:7/b2', 2),
#  ('D/5', 2),
#  ('E:9', 2),
#  ('D:sus4', 2),
#  ('G:min/5', 2),
#  ('B:min7', 2),
#  ('C:7', 2),
#  ('D/3', 2),
#  ('C:maj7', 2),
#  ('C#', 2),
#  ('D:min', 2),
#  ('B:maj7', 2),
#  ('G:7', 1),
#  ('G:7/2', 1),
#  ('G:7/b3', 1),
#  ('G:(1)', 1),
#  ('E/3', 1),
#  ('B:7', 1),
#  ('G#:hdim7', 1),
#  ('D:maj(9)', 1),
#  ('F/6', 1),
#  ('D:sus4(2)', 1),
#  ('D:maj7', 1),
#  ('A/3', 1),
#  ('A:maj(*5)', 1),
#  ('G:maj6', 1),
#  ('D:maj6', 1),
#  ('E:(1)', 1),
#  ('Ab', 1),
#  ('E:(1,5)', 1),
#  ('E:(1,b7)/b7', 1),
#  ('C#:(1,b3)', 1),
#  ('C#:(1,b3)/b3', 1),
#  ('G:(1,b3,4)/b3', 1),
#  ('C:9(*3)', 1),
#  ('G:min(4)', 1),
# ...

# %%
outdegree1 = list(G1.out_degree(['N', 'A:7', 'D:7', 'E:7', 'E', 'C', 'G:7', 'G:7/b2', 'G:7/2', 'G:7/b3', 'E/5', 'A', 'G:(1)', 'C/5', 'G', 'B', 'E/3', 'B:7', 'B:min', 'D/5', 'G#:hdim7', 'E:9', 'D', 'D:sus4', 'D:maj(9)', 'G/5', 'F/6', 'D:sus4(2)', 'D:maj7', 'G:min/5', 'A/3', 'A:maj(*5)', 'G:maj6', 'D:maj6', 'E:(1)', 'F#', 'F', 'B:min7', 'A:min', 'Ab', 'E:(1,5)', 'E:(1,b7)/b7', 'C#:(1,b3)', 'C#:(1,b3)/b3', 'C/3', 'G:min', 'G:(1,b3,4)/b3', 'Bb', 'C:9(*3)', 'C:7', 'G:min(4)', 'C:(1)', 'C:(1,5)', 'C:sus4', 'E:sus2(b7)', 'E:maj6', 'E:min', 'A:min/4', 'C:min', 'A:9', 'Eb', 'F#/5', 'F/5', 'E:min/5', 'A:7/3', 'G/3', 'F#:dim/b3', 'B:dim', 'D/2', 'D/3', 'C#:dim/b3', 'C:maj7', 'A:sus4(2)', 'E:sus4(2)', 'Eb:aug', 'C#:hdim7', 'F:min', 'E:min/3', 'C#', 'C#:min', 'E:min6', 'Ab:min', 'D:min', 'A:(1)', 'F#:min/5', 'D:(1)', 'D:(1,5)', 'F#:min', 'B:maj7', 'G:maj7', 'A:min7', 'C:maj(#4)/5']))
sorted(outdegree1, key=lambda x: x[1], reverse=True)
# Out:
# [('N', 24),
#  ('A', 16),
#  ('G', 16),
#  ('E', 15),
#  ('D', 15),
#  ('C', 14),
#  ('B:min', 12),
#  ('A:min', 8),
#  ('E:min', 7),
#  ('C/5', 6),
#  ('F', 6),
#  ('A:7', 5),
#  ('F#', 5),
#  ('G:min', 5),
#  ('E:7', 4),
#  ('B', 4),
#  ('D/5', 4),
#  ('G/5', 4),
#  ('Bb', 4),
#  ('D:7', 3),
#  ('E/5', 3),
#  ('E:9', 3),
#  ('C/3', 3),
#  ('Eb', 3),
#  ('D/3', 3),
#  ('C:maj7', 3),
#  ('C#:min', 3),
#  ('A:min7', 3),
#  ('G:7', 2),
#  ('G:(1)', 2),
#  ('D:sus4', 2),
#  ('G:min/5', 2),
#  ('D:maj6', 2),
#  ('B:min7', 2),
#  ('C:7', 2),
#  ('C#', 2),
#  ('D:min', 2),
#  ('B:maj7', 2),
#  ('G:maj7', 2),
#  ('C:maj(#4)/5', 2),
#  ('G:7/b2', 1),
#  ('G:7/2', 1),
#  ('G:7/b3', 1),
#  ('E/3', 1),
#  ('B:7', 1),
#  ('G#:hdim7', 1),
#  ('D:maj(9)', 1),
#  ('F/6', 1),
#  ('D:sus4(2)', 1),
#  ('D:maj7', 1),
#  ('A/3', 1),
#  ('A:maj(*5)', 1),
#  ('G:maj6', 1),
#  ('E:(1)', 1),
#  ('Ab', 1),
#  ('E:(1,5)', 1),
#  ('E:(1,b7)/b7', 1),
#  ('C#:(1,b3)', 1),
#  ('C#:(1,b3)/b3', 1),
# ...

# %%
from networkx.algorithms.community import greedy_modularity_communities
c = greedy_modularity_communities(G1)
sorted(c)
# Out:
# [frozenset({'Ab:min',
#             'B',
#             'B:maj7',
#             'B:min',
#             'C#',
#             'C#:min',
#             'C:maj7',
#             'D:(1)',
#             'D:(1,5)',
#             'D:maj6',
#             'E:(1)',
#             'E:min',
#             'E:min/3',
#             'E:min6',
#             'Eb',
#             'F#:min',
#             'F#:min/5',
#             'F:min',
#             'N'}),
#  frozenset({'A:7/3',
#             'A:min/4',
#             'A:min7',
#             'Ab',
#             'B:dim',
#             'B:min7',
#             'C/5',
#             'C:maj(#4)/5',
#             'C:min',
#             'D/3',
#             'D:min',
#             'E:min/5',
#             'F#/5',
#             'F#:dim/b3',
#             'F/5',
#             'G',
#             'G/3',
#             'G:maj7'}),
#  frozenset({'A',
#             'A/3',
#             'A:7',
#             'A:maj(*5)',
#             'A:sus4(2)',
#             'B:7',
# ...

# %% [markdown]
# ## Album12

# %%
album12 = pd.read_csv('C:\\Users\\Callu\\OneDrive\\Desktop\\Network Beatles Data\\album_12_edges.csv')
G1 = nx.from_pandas_edgelist(album12, source="Source", target="Target", create_using=nx.DiGraph())

# %%
import operator

print(nx.average_clustering(G1))
c1 = nx.clustering(G1)
sorted_tuples = sorted(c1.items(), key=operator.itemgetter(1), reverse=True)
sorted_tuples
# Out:
# 0.2770628557918554
# [('G:maj(*1)/5', 1.0),
#  ('F:7', 1.0),
#  ('D/3', 1.0),
#  ('G:7', 1.0),
#  ('A:aug', 1.0),
#  ('G:(1,5)', 1.0),
#  ('A:dim7', 0.875),
#  ('C#', 0.8333333333333334),
#  ('G/2', 0.8333333333333334),
#  ('F#:aug', 0.7),
#  ('B:hdim7/b7', 0.6666666666666666),
#  ('F#', 0.6111111111111112),
#  ('Ab:7', 0.5),
#  ('Gb', 0.5),
#  ('A:min/b3', 0.5),
#  ('C/7', 0.5),
#  ('E:min/b3', 0.5),
#  ('G#:dim7', 0.5),
#  ('F:min7', 0.5),
#  ('Ab/5', 0.5),
#  ('D:7', 0.5),
#  ('D/5', 0.34615384615384615),
#  ('F', 0.32142857142857145),
#  ('A:7', 0.2441860465116279),
#  ('B', 0.24),
#  ('A', 0.20833333333333334),
#  ('E', 0.19078947368421054),
#  ('D', 0.18263473053892215),
#  ('C', 0.17326732673267325),
#  ('G:min', 0.16666666666666666),
#  ('A:min/b7', 0.16666666666666666),
#  ('C:min', 0.16666666666666666),
#  ('Ab:maj(2)/2', 0.16666666666666666),
#  ('Eb:7', 0.16666666666666666),
#  ('Eb/5', 0.16666666666666666),
#  ('G', 0.15489130434782608),
#  ('Bb', 0.14),
# ...

# %%
G1.nodes()
# Out:
# NodeView(('N', 'G:maj(*1)/5', 'G', 'C', 'G/3', 'A:min7', 'C/5', 'D', 'Bb', 'D:min', 'G:min', 'A:min', 'A', 'F#:min', 'B:min', 'E', 'Db', 'Db:maj7', 'F:min', 'Ab:maj6', 'Bb:min', 'Eb:min7', 'Ab', 'Ab:7', 'Gb:min', 'Gb', 'A:min/b3', 'E:7', 'D:min/b3', 'F#:hdim7/b7', 'G#:aug', 'F#:hdim7', 'F:maj7', 'D:min7', 'F:7', 'A:min/b7', 'F:maj6', 'F', 'C/7', 'E:min/b3', 'F:maj6/5', 'D/5', 'A:7', 'D/3', 'G#:dim7', 'A:dim7', 'B:hdim7/b7', 'B:(b3,5)', 'B', 'F#', 'C#', 'F#:aug', 'C:min', 'Ab:maj(2)/2', 'Eb', 'Eb:7/b7', 'F:min7', 'Eb:7', 'Eb/5', 'Eb/3', 'Ab/5', 'G:7/3', 'G:7', 'A:aug', 'A:(1)', 'G:(1,5)', 'G/2', 'D:7'))

# %%
indegree1 = list(G1.in_degree(['N', 'G:maj(*1)/5', 'G', 'C', 'G/3', 'A:min7', 'C/5', 'D', 'Bb', 'D:min', 'G:min', 'A:min', 'A', 'F#:min', 'B:min', 'E', 'Db', 'Db:maj7', 'F:min', 'Ab:maj6', 'Bb:min', 'Eb:min7', 'Ab', 'Ab:7', 'Gb:min', 'Gb', 'A:min/b3', 'E:7', 'D:min/b3', 'F#:hdim7/b7', 'G#:aug', 'F#:hdim7', 'F:maj7', 'D:min7', 'F:7', 'A:min/b7', 'F:maj6', 'F', 'C/7', 'E:min/b3', 'F:maj6/5', 'D/5', 'A:7', 'D/3', 'G#:dim7', 'A:dim7', 'B:hdim7/b7', 'B:(b3,5)', 'B', 'F#', 'C#', 'F#:aug', 'C:min', 'Ab:maj(2)/2', 'Eb', 'Eb:7/b7', 'F:min7', 'Eb:7', 'Eb/5', 'Eb/3', 'Ab/5', 'G:7/3', 'G:7', 'A:aug', 'A:(1)', 'G:(1,5)', 'G/2', 'D:7']))
sorted(indegree1, key=lambda x: x[1], reverse=True)
# Out:
# [('N', 13),
#  ('G', 10),
#  ('D', 9),
#  ('C', 8),
#  ('A:min', 8),
#  ('A', 8),
#  ('A:7', 8),
#  ('E', 7),
#  ('Ab', 7),
#  ('Db', 6),
#  ('Bb', 5),
#  ('F', 5),
#  ('B', 5),
#  ('A:min7', 4),
#  ('F:min', 4),
#  ('D/5', 4),
#  ('C:min', 4),
#  ('E:7', 3),
#  ('A:dim7', 3),
#  ('B:hdim7/b7', 3),
#  ('F#:aug', 3),
#  ('G:maj(*1)/5', 2),
#  ('C/5', 2),
#  ('D:min', 2),
#  ('G:min', 2),
#  ('B:min', 2),
#  ('F:maj7', 2),
#  ('F:7', 2),
#  ('F#', 2),
#  ('Ab:maj(2)/2', 2),
#  ('Eb', 2),
#  ('Eb:7', 2),
#  ('Eb/5', 2),
#  ('G:7', 2),
#  ('G/3', 1),
#  ('F#:min', 1),
#  ('Db:maj7', 1),
#  ('Ab:maj6', 1),
#  ('Bb:min', 1),
#  ('Eb:min7', 1),
#  ('Ab:7', 1),
#  ('Gb:min', 1),
#  ('Gb', 1),
#  ('A:min/b3', 1),
#  ('D:min/b3', 1),
#  ('F#:hdim7/b7', 1),
#  ('G#:aug', 1),
#  ('F#:hdim7', 1),
#  ('D:min7', 1),
#  ('A:min/b7', 1),
#  ('F:maj6', 1),
#  ('C/7', 1),
#  ('E:min/b3', 1),
#  ('F:maj6/5', 1),
#  ('D/3', 1),
#  ('G#:dim7', 1),
#  ('B:(b3,5)', 1),
#  ('C#', 1),
#  ('Eb:7/b7', 1),
# ...

# %%
outdegree1 = list(G1.out_degree(['N', 'G:maj(*1)/5', 'G', 'C', 'G/3', 'A:min7', 'C/5', 'D', 'Bb', 'D:min', 'G:min', 'A:min', 'A', 'F#:min', 'B:min', 'E', 'Db', 'Db:maj7', 'F:min', 'Ab:maj6', 'Bb:min', 'Eb:min7', 'Ab', 'Ab:7', 'Gb:min', 'Gb', 'A:min/b3', 'E:7', 'D:min/b3', 'F#:hdim7/b7', 'G#:aug', 'F#:hdim7', 'F:maj7', 'D:min7', 'F:7', 'A:min/b7', 'F:maj6', 'F', 'C/7', 'E:min/b3', 'F:maj6/5', 'D/5', 'A:7', 'D/3', 'G#:dim7', 'A:dim7', 'B:hdim7/b7', 'B:(b3,5)', 'B', 'F#', 'C#', 'F#:aug', 'C:min', 'Ab:maj(2)/2', 'Eb', 'Eb:7/b7', 'F:min7', 'Eb:7', 'Eb/5', 'Eb/3', 'Ab/5', 'G:7/3', 'G:7', 'A:aug', 'A:(1)', 'G:(1,5)', 'G/2', 'D:7']))
sorted(outdegree1, key=lambda x: x[1], reverse=True)
# Out:
# [('N', 14),
#  ('G', 12),
#  ('A', 11),
#  ('D', 10),
#  ('C', 9),
#  ('Bb', 8),
#  ('A:min', 8),
#  ('E', 6),
#  ('Ab', 6),
#  ('A:7', 6),
#  ('Eb', 6),
#  ('Db', 5),
#  ('B', 5),
#  ('A:min7', 4),
#  ('F:maj7', 4),
#  ('D/5', 4),
#  ('F:min', 3),
#  ('B:hdim7/b7', 3),
#  ('F#', 3),
#  ('C:min', 3),
#  ('C/5', 2),
#  ('D:min', 2),
#  ('G:min', 2),
#  ('Eb:min7', 2),
#  ('E:7', 2),
#  ('A:min/b7', 2),
#  ('A:dim7', 2),
#  ('C#', 2),
#  ('G/2', 2),
#  ('G:maj(*1)/5', 1),
#  ('G/3', 1),
#  ('F#:min', 1),
#  ('B:min', 1),
#  ('Db:maj7', 1),
#  ('Ab:maj6', 1),
#  ('Bb:min', 1),
#  ('Ab:7', 1),
#  ('Gb:min', 1),
#  ('Gb', 1),
#  ('A:min/b3', 1),
#  ('D:min/b3', 1),
#  ('F#:hdim7/b7', 1),
#  ('G#:aug', 1),
#  ('F#:hdim7', 1),
#  ('D:min7', 1),
#  ('F:7', 1),
#  ('F:maj6', 1),
#  ('F', 1),
#  ('C/7', 1),
#  ('E:min/b3', 1),
#  ('F:maj6/5', 1),
#  ('D/3', 1),
#  ('G#:dim7', 1),
#  ('B:(b3,5)', 1),
#  ('F#:aug', 1),
#  ('Ab:maj(2)/2', 1),
#  ('Eb:7/b7', 1),
#  ('F:min7', 1),
#  ('Eb:7', 1),
# ...

# %%
from networkx.algorithms.community import greedy_modularity_communities
c = greedy_modularity_communities(G1)
sorted(c)
# Out:
# [frozenset({'Ab',
#             'Ab/5',
#             'Ab:7',
#             'Ab:maj(2)/2',
#             'Ab:maj6',
#             'Bb:min',
#             'Db',
#             'Db:maj7',
#             'Eb',
#             'Eb/3',
#             'Eb/5',
#             'Eb:7',
#             'Eb:7/b7',
#             'Eb:min7',
#             'F:min',
#             'Gb',
#             'Gb:min'}),
#  frozenset({'A:(1)',
#             'Bb',
#             'C',
#             'C:min',
#             'F:7',
#             'F:maj6',
#             'F:maj6/5',
#             'F:maj7',
#             'F:min7',
#             'N'}),
#  frozenset({'A:aug',
#             'B:min',
#             'D/3',
#             'E:7',
#             'F#:hdim7/b7',
#             'F#:min',
#             'G',
#             'G#:dim7',
#             'G:7/3',
#             'G:maj(*1)/5'}),
#  frozenset({'A',
#             'A:7',
#             'A:dim7',
#             'B:hdim7/b7',
#             'D',
#             'D/5',
# ...

# %%
## Album10CD1

album10 = pd.read_csv('C:\\Users\\Callu\\OneDrive\\Desktop\\Network Beatles Data\\album_10_edges.csv')
G1 = nx.from_pandas_edgelist(album10, source="Source", target="Target", create_using=nx.DiGraph())

import operator

print(nx.average_clustering(G1))
c1 = nx.clustering(G1)
sorted_tuples = sorted(c1.items(), key=operator.itemgetter(1), reverse=True)
sorted_tuples

G1.nodes()

indegree1 = list(G1.in_degree(['N', 'E', 'E:7', 'A', 'D', 'C', 'D#', 'A/2', 'A/b3', 'A/3', 'B', 'C/9', 'G/5', 'A/4', 'D/5', 'D/b7', 'G:maj7/3', 'G:minmaj7/b3', 'D:7', 'G:minmaj7/5', 'G', 'F', 'G#', 'D:sus4(9)', 'A:min', 'F:7', 'G:min7', 'F/3', 'F#:dim/b3', 'A:min7', 'F:7(b9)', 'B:dim7/b9', 'Bb:dim7/5', 'C:dim7', 'C:dim7/2', 'Bb:dim7/7', 'D:dim7', 'A:dim7', 'A:min/5', 'A:dim/b5', 'D:(1)', 'Bb', 'Eb', 'G:min', 'Bb:sus4(9)', 'Bb:sus2(b7)', 'Bb/5', 'F/b7', 'F/6', 'F/5', 'G:7', 'Eb:7', 'E:min(2)', 'F:min', 'D:min', 'E/b7', 'E/b6', 'E/5', 'A:min/b7', 'A:min/6', 'C#:min', 'F#:min', 'B:min', 'E/2', 'E/3', 'E/4', 'E:(1)', 'A:min6', 'E:min(9)', 'E:min', 'A:7', 'C:7', 'C:(1)', 'G:min/5', 'G:min/b7', 'C/3', 'C:7/3', 'Ab:maj9', 'Bb:7', 'Ab:maj7', 'D:min7', 'F:maj6', 'G:min/4', 'G:9', 'Bb:maj7', 'E:aug', 'G/3', 'C#:dim', 'D#:dim', 'Eb:aug', 'C:min', 'D:sus4(b7)', 'G:dim/b3', 'Ab', 'F:dim', 'F#:dim', 'G:dim', 'Bb:min', 'Db', 'Ab:min', 'D:sus4', 'C/7', 'C/5', 'C:sus4', 'C:maj(4)', 'Bb:min/b3', 'B:min7', 'A:min9', 'F#:min7', 'F#:min6', 'D/3', 'D:maj7']))
sorted(indegree1, key=lambda x: x[1], reverse=True)

outdegree1 = list(G1.out_degree(['N', 'E', 'E:7', 'A', 'D', 'C', 'D#', 'A/2', 'A/b3', 'A/3', 'B', 'C/9', 'G/5', 'A/4', 'D/5', 'D/b7', 'G:maj7/3', 'G:minmaj7/b3', 'D:7', 'G:minmaj7/5', 'G', 'F', 'G#', 'D:sus4(9)', 'A:min', 'F:7', 'G:min7', 'F/3', 'F#:dim/b3', 'A:min7', 'F:7(b9)', 'B:dim7/b9', 'Bb:dim7/5', 'C:dim7', 'C:dim7/2', 'Bb:dim7/7', 'D:dim7', 'A:dim7', 'A:min/5', 'A:dim/b5', 'D:(1)', 'Bb', 'Eb', 'G:min', 'Bb:sus4(9)', 'Bb:sus2(b7)', 'Bb/5', 'F/b7', 'F/6', 'F/5', 'G:7', 'Eb:7', 'E:min(2)', 'F:min', 'D:min', 'E/b7', 'E/b6', 'E/5', 'A:min/b7', 'A:min/6', 'C#:min', 'F#:min', 'B:min', 'E/2', 'E/3', 'E/4', 'E:(1)', 'A:min6', 'E:min(9)', 'E:min', 'A:7', 'C:7', 'C:(1)', 'G:min/5', 'G:min/b7', 'C/3', 'C:7/3', 'Ab:maj9', 'Bb:7', 'Ab:maj7', 'D:min7', 'F:maj6', 'G:min/4', 'G:9', 'Bb:maj7', 'E:aug', 'G/3', 'C#:dim', 'D#:dim', 'Eb:aug', 'C:min', 'D:sus4(b7)', 'G:dim/b3', 'Ab', 'F:dim', 'F#:dim', 'G:dim', 'Bb:min', 'Db', 'Ab:min', 'D:sus4', 'C/7', 'C/5', 'C:sus4', 'C:maj(4)', 'Bb:min/b3', 'B:min7', 'A:min9', 'F#:min7', 'F#:min6', 'D/3', 'D:maj7']))
sorted(outdegree1, key=lambda x: x[1], reverse=True)

from networkx.algorithms.community import greedy_modularity_communities
c = greedy_modularity_communities(G1)
sorted(c)

# %%
import random
random.seed(246)        # or any integer
import numpy
numpy.random.seed(4812)
from networkx import path_graph, random_layout

# %%
pos = random_layout(G, seed=None)  # use (either) global default RNG
pos = random_layout(G, seed=42)  # local RNG just for this call
pos = random_layout(G, seed=numpy.random)  # use numpy global RNG

# %%
nx.draw(pos, with_labels=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 nx.draw(pos, with_labels=True)
#
# File ~\miniconda3\lib\site-packages\networkx\drawing\nx_pylab.py:120, in draw(G, pos, ax, **kwds)
#     117 if "with_labels" not in kwds:
#     118     kwds["with_labels"] = "labels" in kwds
# --> 120 draw_networkx(G, pos=pos, ax=ax, **kwds)
#     121 ax.set_axis_off()
#     122 plt.draw_if_interactive()
#
# File ~\miniconda3\lib\site-packages\networkx\drawing\nx_pylab.py:334, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     331     pos = nx.drawing.spring_layout(G)  # default to spring layout
#     333 draw_networkx_nodes(G, pos, **node_kwds)
# --> 334 draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     335 if with_labels:
#     336     draw_networkx_labels(G, pos, **label_kwds)
#
# ...

# %%
import networkx.algorithms.community as nx_comm
nx_comm.modularity(G, nx_comm.label_propagation_communities(G))
# Out:
# 0.2586823621227888

# %%
from networkx.algorithms.community import greedy_modularity_communities
G = nx.from_pandas_edgelist(album01, source="Source", target="Target", create_using=nx.DiGraph())
c = greedy_modularity_communities(G)
sorted(c[0])
# Out:
# ['A',
#  'A:7',
#  'A:maj7',
#  'A:maj7/5',
#  'A:min/b3',
#  'B',
#  'B:7',
#  'B:maj6',
#  'E',
#  'E:7/3',
#  'E:aug',
#  'E:maj7',
#  'F#:9',
#  'F#:min7',
#  'G#:min',
#  'G#:min7']

# %%
c
# Out:
# [frozenset({'A',
#             'A:7',
#             'A:maj7',
#             'A:maj7/5',
#             'A:min/b3',
#             'B',
#             'B:7',
#             'B:maj6',
#             'E',
#             'E:7/3',
#             'E:aug',
#             'E:maj7',
#             'F#:9',
#             'F#:min7',
#             'G#:min',
#             'G#:min7'}),
#  frozenset({'A:min',
#             'C',
#             'C#:7',
#             'D',
#             'D/2',
#             'D/3',
#             'D:9',
#             'E:9',
#             'E:min',
#             'F',
#             'G',
#             'N'}),
#  frozenset({'B:min',
#             'C#:min',
#             'C#:min/5',
#             'C:min6',
#             'F#',
#             'F#:min',
#             'F#:minmaj7',
#             'G#'}),
#  frozenset({'Bb', 'Bb:7', 'Eb', 'Eb:7', 'Eb:9', 'Eb:min', 'F:9'}),
#  frozenset({'E:7', 'G:min'})]

# %%
G = nx.from_pandas_edgelist(album01, source="Source", target="Target")
nx.draw(G, with_labels=True)
nx_comm.modularity(G, nx_comm.label_propagation_communities(G))
# Out:
# 0.2586823621227888

# %%
nx.average_degree_connectivity(G)
# Out:
# {21: 7.380952380952381,
#  25: 6.68,
#  30: 5.666666666666667,
#  16: 7.375,
#  2: 9.075,
#  9: 8.222222222222221,
#  22: 6.909090909090909,
#  14: 7.642857142857143,
#  7: 8.380952380952381,
#  18: 6.611111111111111,
#  11: 10.181818181818182,
#  3: 8.166666666666666,
#  4: 8.375,
#  15: 3.2666666666666666,
#  5: 6.8,
#  12: 8.0}

# %%
nx.average_node_connectivity(G)
# Out:
# 1.55

# %%
nx.diameter(G)
# Out:
# 7

# %%
nx.number_connected_components(G)
# Out:
# ---------------------------------------------------------------------------
# NetworkXNotImplemented                    Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 nx.number_connected_components(G)
#
# File ~\miniconda3\lib\site-packages\networkx\algorithms\components\connected.py:93, in number_connected_components(G)
#      69 def number_connected_components(G):
#      70     """Returns the number of connected components.
#      71
#      72     Parameters
#    (...)
#      91
#      92     """
# ---> 93     return sum(1 for cc in connected_components(G))
#
# File ~\miniconda3\lib\site-packages\networkx\algorithms\components\connected.py:93, in <genexpr>(.0)
#      69 def number_connected_components(G):
#      70     """Returns the number of connected components.
#      71
#      72     Parameters
#    (...)
#      91
#      92     """
# ---> 93     return sum(1 for cc in connected_components(G))
#
# ...

# %%
list(G)
# Out:
# ['N',
#  'E',
#  'A',
#  'B',
#  'E:7/3',
#  'A:min/b3',
#  'E:9',
#  'F',
#  'G',
#  'C',
#  'A:min',
#  'D',
#  'B:min',
#  'E:min',
#  'D/2',
#  'D/3',
#  'E:7',
#  'G:min',
#  'Bb',
#  'Eb:7',
#  'F:9',
#  'Eb:9',
#  'Bb:7',
#  'Eb',
#  'Eb:min',
#  'E:maj7',
#  'F#:min7',
#  'G#:min7',
#  'B:7',
#  'G#',
#  'C#:min',
#  'F#:9',
#  'E:aug',
#  'A:maj7',
#  'A:maj7/5',
#  'B:maj6',
#  'G#:min',
#  'F#:min',
#  'C#:min/5',
#  'C#:7',
#  'C:min6',
#  'F#:minmaj7',
#  'F#',
#  'A:7',
#  'D:9']
